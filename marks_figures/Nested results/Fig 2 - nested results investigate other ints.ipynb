# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py, time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mat
import seaborn as sb
import tensorflow as tf
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
import bpdev as bd
import helper
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import contacts

from Bio import AlignIO
import time as time
import pandas as pd
np.random.seed(42)

# %% [markdown]
# # Contact map by scatter plot - compared to cWW annotation

# %% [markdown]
# ### Get SoM results

# %%
families = [['RF00005', 250], ['RF00059',150], ['RF00023',100], ['RF00010', 100]]

# %%
f = 1
fam = families[f][0]
numhidden = 512
min_dist = 5.0

#get scores
arrayspath = '../../marks/Arrays/%s_mlp_%s_red.npy'%(fam,numhidden)
hol_mut2 = np.load(arrayspath)
seqlen,_, dims,_ = hol_mut2.shape
C = bd.get_wc(arrayspath, seqlen, dims, bpugSQ=0, denoise='APC')

#get coordinates
C[np.tril_indices(seqlen)] = np.min(C)
bp_stretch = np.ravel(C)
minval = np.sort(bp_stretch)[::-1][-1] #just gets the minimum value - can be changed to a different idx
bs = np.where(C > minval)
idx = np.argsort(C[bs])
x = bs[0][idx] #sorts the x and y coords in order from lowest to highest so highest scores will be plotted last
y = bs[1][idx]

score_col = [C[xx,yy] for xx,yy in zip(x,y)] #gets the scores for each coordinate in the needed order

# %%
#Load in the EC annotation
ECannotfile = '../../marks/%s/%s.EC.interaction.txt'%(fam,fam) 
EC_df = pd.read_csv(ECannotfile, delimiter='\s+')

######### QUALITATIVE CONTACTS ###########

#Top L/2 EC scores
topEC = EC_df.loc[:seqlen//2, ['Rfam_reduced_position1', 'Rfam_reduced_position2']]
#All cWW annotated interactions
cWW_int = EC_df[EC_df['interactions'] == 'cWW']
#cWW_int = EC_df[(EC_df['interactions'] == 'None') & (EC_df['interactions'] != 'None')]

#All PDB contacts < 8 angstroms
close_cont = EC_df[EC_df['minimum_atom_distance'] <= min_dist] 

#get the colour map to select colors for plotting
pal = 'Blues'
cmap = mat.cm.get_cmap(pal)


markersize = families[f][1]

#plot
fig = plt.figure(figsize=(15,15))
#plt.scatter(np.tril_indices(seqlen)[0], np.tril_indices(seqlen)[1], c=np.asarray([cmap(0.)]), s=markersize) #plot background 
plt.scatter(x, y, c=score_col, cmap=pal, label = 'SoM', vmin=0., s=markersize)
plt.scatter(cWW_int.iloc[:,2], cWW_int.iloc[:,1], c='m', label = 'WC', s=markersize)
plt.plot(range(seqlen), range(seqlen), 'k--', linewidth=3, alpha=0.6)
plt.title('%s: SoM vs. all WC contacts'%(fam), fontsize=30)
#plt.legend(loc='best', fontsize=15, bbox_to_anchor=(1., 0.5))
plt.xlabel('Sequence Position', fontsize=30)
plt.ylabel('Sequence Position', fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

ax = plt.gca()
ax.invert_yaxis()
ax.set_facecolor(cmap(0.))

#plt.savefig('%s.png'%(fam))
plt.show()
# Out:
# /Users/steffanpaul/anaconda/envs/tensorflow/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
f = 
fam = families[f][0]
ECannotfile = '../../marks/%s/%s.EC.interaction.txt'%(fam,fam) 
EC_df = pd.read_csv(ECannotfile, delimiter='\s+')
EC_df.groupby('interactions').count()
#EC_df[(EC_df['interactions'] != 'None') & (EC_df['interactions'] != EC_df.loc[9756, 'interactions'])]
# Out:
#                 score  Rfam_reduced_position1  Rfam_reduced_position2  \
# interactions
# 2BR                 1                       1                       1
# 5BR                 1                       1                       1
# 6BR                 1                       1                       1
# None             8451                    8451                    8451
# cHS,cSH             2                       2                       2
# cSS                 3                       3                       3
# cSS,n1BR            1                       1                       1
# cWH,cHW             1                       1                       1
# cWS,n6BR,cSW        1                       1                       1
# cWW               101                     101                     101
# n0BR                1                       1                       1
# n1BPh               1                       1                       1
# n1BR                1                       1                       1
# n1BR,ncSS           1                       1                       1
# n2BPh               1                       1                       1
# n2BR                1                       1                       1
# n2BR,cWS,cSW        1                       1                       1
# n2BR,ncSS           2                       2                       2
# n2BR,s55            1                       1                       1
# n3BPh               1                       1                       1
# n3BR                4                       4                       4
# n6BPh               1                       1                       1
# n6BR,tSS            1                       1                       1
# n7BR                1                       1                       1
# n7BR,ntWH,ntHW      1                       1                       1
# n9BR                2                       2                       2
# ncHH                1                       1                       1
# ncSS                8                       8                       8
# ncSW,ncWS           2                       2                       2
# ncWH,ncHW           4                       4                       4
# ncWS,6BR,ncSW       1                       1                       1
# ncWW                5                       5                       5
# ns33                1                       1                       1
# ns35,ns53           3                       3                       3
# ns55                6                       6                       6
# ntHH                2                       2                       2
# ntHS,3BPh,ntSH      1                       1                       1
# ntHS,ntSH,6BR       1                       1                       1
# ntSS                2                       2                       2
# ntSW,ntWS           1                       1                       1
# ntWH,ntHW           1                       1                       1
# ntWW                1                       1                       1
# s33                 3                       3                       3
# s35,n0BR,s53        1                       1                       1
# s35,s53             2                       2                       2
# s35,s53,0BR         1                       1                       1
# s35,s53,n9BR        1                       1                       1
# s55                59                      59                      59
# s55,n3BR            1                       1                       1
# s55,n6BPh,n6BR      1                       1                       1
# tHW,tWH             2                       2                       2
# tSS                 1                       1                       1
#
#                 pdb_resid1  pdb_resname1  pdb_resid2  pdb_resname2  \
# interactions
# 2BR                      1             1           1             1
# 5BR                      1             1           1             1
# 6BR                      1             1           1             1
# None                  8451          8451        8451          8451
# cHS,cSH                  2             2           2             2
# cSS                      3             3           3             3
# cSS,n1BR                 1             1           1             1
# cWH,cHW                  1             1           1             1
# cWS,n6BR,cSW             1             1           1             1
# cWW                    101           101         101           101
# n0BR                     1             1           1             1
# n1BPh                    1             1           1             1
# n1BR                     1             1           1             1
# n1BR,ncSS                1             1           1             1
# n2BPh                    1             1           1             1
# n2BR                     1             1           1             1
# n2BR,cWS,cSW             1             1           1             1
# n2BR,ncSS                2             2           2             2
# n2BR,s55                 1             1           1             1
# n3BPh                    1             1           1             1
# n3BR                     4             4           4             4
# n6BPh                    1             1           1             1
# n6BR,tSS                 1             1           1             1
# n7BR                     1             1           1             1
# n7BR,ntWH,ntHW           1             1           1             1
# n9BR                     2             2           2             2
# ncHH                     1             1           1             1
# ncSS                     8             8           8             8
# ncSW,ncWS                2             2           2             2
# ncWH,ncHW                4             4           4             4
# ncWS,6BR,ncSW            1             1           1             1
# ncWW                     5             5           5             5
# ns33                     1             1           1             1
# ns35,ns53                3             3           3             3
# ns55                     6             6           6             6
# ntHH                     2             2           2             2
# ntHS,3BPh,ntSH           1             1           1             1
# ntHS,ntSH,6BR            1             1           1             1
# ntSS                     2             2           2             2
# ntSW,ntWS                1             1           1             1
# ntWH,ntHW                1             1           1             1
# ntWW                     1             1           1             1
# s33                      3             3           3             3
# s35,n0BR,s53             1             1           1             1
# s35,s53                  2             2           2             2
# s35,s53,0BR              1             1           1             1
# s35,s53,n9BR             1             1           1             1
# s55                     59            59          59            59
# s55,n3BR                 1             1           1             1
# s55,n6BPh,n6BR           1             1           1             1
# tHW,tWH                  2             2           2             2
# tSS                      1             1           1             1
#
#                 secondary_structure_distance  minimum_atom_distance
# interactions
# 2BR                                        1                      1
# 5BR                                        1                      1
# 6BR                                        1                      1
# None                                    8451                   8451
# cHS,cSH                                    2                      2
# cSS                                        3                      3
# cSS,n1BR                                   1                      1
# cWH,cHW                                    1                      1
# cWS,n6BR,cSW                               1                      1
# cWW                                      101                    101
# n0BR                                       1                      1
# n1BPh                                      1                      1
# n1BR                                       1                      1
# n1BR,ncSS                                  1                      1
# n2BPh                                      1                      1
# n2BR                                       1                      1
# n2BR,cWS,cSW                               1                      1
# n2BR,ncSS                                  2                      2
# n2BR,s55                                   1                      1
# n3BPh                                      1                      1
# n3BR                                       4                      4
# n6BPh                                      1                      1
# n6BR,tSS                                   1                      1
# n7BR                                       1                      1
# n7BR,ntWH,ntHW                             1                      1
# n9BR                                       2                      2
# ncHH                                       1                      1
# ncSS                                       8                      8
# ncSW,ncWS                                  2                      2
# ncWH,ncHW                                  4                      4
# ncWS,6BR,ncSW                              1                      1
# ncWW                                       5                      5
# ns33                                       1                      1
# ns35,ns53                                  3                      3
# ns55                                       6                      6
# ntHH                                       2                      2
# ntHS,3BPh,ntSH                             1                      1
# ntHS,ntSH,6BR                              1                      1
# ntSS                                       2                      2
# ntSW,ntWS                                  1                      1
# ntWH,ntHW                                  1                      1
# ntWW                                       1                      1
# s33                                        3                      3
# s35,n0BR,s53                               1                      1
# s35,s53                                    2                      2
# s35,s53,0BR                                1                      1
# s35,s53,n9BR                               1                      1
# s55                                       59                     59
# s55,n3BR                                   1                      1
# s55,n6BPh,n6BR                             1                      1
# tHW,tWH                                    2                      2
# tSS                                        1                      1

# %%
#Load in the EC annotation
ECannotfile = '../../marks/%s/%s.EC.interaction.txt'%(fam,fam) 
EC_df = pd.read_csv(ECannotfile, delimiter='\s+')
#remove NaNs
EC_df = EC_df[~EC_df.interactions.isna()]

intlists = list(set(EC_df.interactions))
intlists.remove('None')

######### QUALITATIVE CONTACTS ###########

#Top L/2 EC scores
topEC = EC_df.loc[:seqlen//2, ['Rfam_reduced_position1', 'Rfam_reduced_position2']]
#All cWW annotated interactions
#cWW_int = EC_df[EC_df['interactions'] != 'None']
#cWW_int = EC_df[(EC_df['interactions'] == 'None') & (EC_df['interactions'] != 'None')]

#All PDB contacts < 8 angstroms
close_cont = EC_df[EC_df['minimum_atom_distance'] <= min_dist] 

#get the colour map to select colors for plotting
pal = 'Blues'
cmap = mat.cm.get_cmap(pal)


markersize = families[f][1]

#plot
fig = plt.figure(figsize=(15,15))
#plt.scatter(np.tril_indices(seqlen)[0], np.tril_indices(seqlen)[1], c=np.asarray([cmap(0.)]), s=markersize) #plot background 
plt.scatter(x, y, c=score_col, cmap=pal, label = 'SoM', vmin=0., s=markersize)
for inter in intlists:
    cWW_int = EC_df[EC_df['interactions'] == inter]
    plt.scatter(cWW_int.iloc[:,2], cWW_int.iloc[:,1], c='m', label = 'WC', s=markersize)
    
plt.plot(range(seqlen), range(seqlen), 'k--', linewidth=3, alpha=0.6)
plt.title('%s: SoM vs. all WC contacts'%(fam), fontsize=30)
#plt.legend(loc='best', fontsize=15, bbox_to_anchor=(1., 0.5))
plt.xlabel('Sequence Position', fontsize=30)
plt.ylabel('Sequence Position', fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

ax = plt.gca()
ax.invert_yaxis()
ax.set_facecolor(cmap(0.))

#plt.savefig('%s.png'%(fam))
plt.show()
# Out:
# /Users/steffanpaul/anaconda/envs/tensorflow/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
#Load in the EC annotation
ECannotfile = '../../marks/%s/%s.EC.interaction.txt'%(fam,fam) 
EC_df = pd.read_csv(ECannotfile, delimiter='\s+')
#remove NaNs
EC_df = EC_df[~EC_df.interactions.isna()]

intlists = list(set(EC_df.interactions))
intlists.remove('None')


######### QUALITATIVE CONTACTS ###########

#Top L/2 EC scores
topEC = EC_df.loc[:seqlen//2, ['Rfam_reduced_position1', 'Rfam_reduced_position2']]
#All cWW annotated interactions
#cWW_int = EC_df[EC_df['interactions'] != 'None']
#cWW_int = EC_df[(EC_df['interactions'] == 'None') & (EC_df['interactions'] != 'None')]

#All PDB contacts < 8 angstroms
close_cont = EC_df[EC_df['minimum_atom_distance'] <= min_dist] 

#get the colour map to select colors for plotting
pal = 'Blues'
cmap = mat.cm.get_cmap(pal)


markersize = families[f][1]

#plot
fig = plt.figure(figsize=(15,15))
plt.scatter(x, y, c=score_col, cmap=pal, label = 'SoM', vmin=0., s=markersize)
plt.scatter(close_cont.iloc[:,1], close_cont.iloc[:,2], c='b', label = 'WC', s=markersize)
for inter in intlists:
    cWW_int = EC_df[EC_df['interactions'] == inter]
    plt.scatter(cWW_int.iloc[:,2], cWW_int.iloc[:,1], c='m', label = 'WC', s=markersize)
    
plt.plot(range(seqlen), range(seqlen), 'k--', linewidth=3, alpha=0.6)
plt.title('%s: SoM vs. all WC contacts'%(fam), fontsize=30)
#plt.legend(loc='best', fontsize=15, bbox_to_anchor=(1., 0.5))
plt.xlabel('Sequence Position', fontsize=30)
plt.ylabel('Sequence Position', fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

ax = plt.gca()
ax.invert_yaxis()
ax.set_facecolor(cmap(0.))

#plt.savefig('%s.png'%(fam))
plt.show()
# Out:
# /Users/steffanpaul/anaconda/envs/tensorflow/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
#Load in the EC annotation
ECannotfile = '../../marks/%s/%s.EC.interaction.txt'%(fam,fam) 
EC_df = pd.read_csv(ECannotfile, delimiter='\s+')
#remove NaNs
EC_df = EC_df[~EC_df.interactions.isna()]

intlists = list(set(EC_df.interactions))
intlists.remove('None')

WCidx = []
wctrtbl = str.maketrans('ACGU', 'UGCA')
for inter in intlists:
    int_df = EC_df[EC_df['interactions'] == inter]
    for ii in int_df.index:
        n1 = int_df.loc[ii, 'pdb_resname1']
        n2_exp = n1.translate(wctrtbl)
        n2 = int_df.loc[ii, 'pdb_resname2']
        if n2_exp == n2:
            WCidx.append(ii)
WCidx = list(set(WCidx))

WC_df = EC_df.loc[WCidx]

######### QUALITATIVE CONTACTS ###########

#Top L/2 EC scores
topEC = EC_df.loc[:seqlen//2, ['Rfam_reduced_position1', 'Rfam_reduced_position2']]
#All cWW annotated interactions
#cWW_int = EC_df[EC_df['interactions'] != 'None']
#cWW_int = EC_df[(EC_df['interactions'] == 'None') & (EC_df['interactions'] != 'None')]

#All PDB contacts < 8 angstroms
close_cont = EC_df[EC_df['minimum_atom_distance'] <= min_dist] 

#get the colour map to select colors for plotting
pal = 'Blues'
cmap = mat.cm.get_cmap(pal)


markersize = families[f][1]

#plot
fig = plt.figure(figsize=(15,15))
#plt.scatter(np.tril_indices(seqlen)[0], np.tril_indices(seqlen)[1], c=np.asarray([cmap(0.)]), s=markersize) #plot background 
plt.scatter(x, y, c=score_col, cmap=pal, label = 'SoM', vmin=0., s=markersize)
plt.scatter(WC_df.iloc[:,2], WC_df.iloc[:,1], c='m', label = 'WC', s=markersize)
plt.plot(range(seqlen), range(seqlen), 'k--', linewidth=3, alpha=0.6)
plt.title('%s: SoM vs. all WC contacts'%(fam), fontsize=30)
#plt.legend(loc='best', fontsize=15, bbox_to_anchor=(1., 0.5))
plt.xlabel('Sequence Position', fontsize=30)
plt.ylabel('Sequence Position', fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

ax = plt.gca()
ax.invert_yaxis()
ax.set_facecolor(cmap(0.))

#plt.savefig('%s.png'%(fam))
plt.show()
# Out:
# /Users/steffanpaul/anaconda/envs/tensorflow/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
