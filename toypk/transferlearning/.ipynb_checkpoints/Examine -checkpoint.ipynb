# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'test_metrics.csv'
df = pd.read_csv(filename, header=0)
df
# Out:
#    modelarch  datatype  trialnum  numepochs    transfer  numpos      loss  \
# 0        mlp         6       1.0        100  notransfer   40000  0.043139
# 1        mlp         6       1.3        100  notransfer    2000  0.017268
# 2        mlp         6       1.4        100  notransfer     800  0.030212
# 3        mlp         6       1.5        100  notransfer     400  0.270290
# 4        mlp         6       1.6       1000  notransfer     200  0.328883
# 5        mlp         6       1.7       2000  notransfer      80  1.037376
# 6        mlp         6       2.0        100    transfer   40000  0.044875
# 7        mlp         6       3.0        100    transfer    2000  0.027180
# 8        mlp         6       4.0        100    transfer     800  0.068334
# 9        mlp         6       5.0       1000    transfer     400  0.010736
# 10       mlp         6       6.0       1000    transfer     200  0.011257
# 11       mlp         6       7.0       2000    transfer      80  1.534906
# 12   resbind         6       1.0        100  notransfer   40000  0.116806
# 13   resbind         6       1.3       1000  notransfer    2000  0.118071
# 14   resbind         6       1.4       2000  notransfer     800  0.650281
# 15   resbind         6       1.5       2000  notransfer     400  0.676117
# 16   resbind         6       1.6       1000  notransfer     200  0.991595
# 17   resbind         6       1.7       1000  notransfer      80  2.038393
# 18   resbind         6       2.0       1000    transfer   40000  0.063431
# 19   resbind         6       3.0       1000    transfer    2000  0.471344
# 20   resbind         6       4.0       1000    transfer     800  0.443414
# 21   resbind         6       5.0       1000    transfer     400  0.803527
# 22   resbind         6       6.0       1000    transfer     200  0.863258
# 23   resbind         6       7.0       1000    transfer      80  0.992718
#
#     accuracy   auc-roc    auc-pr  totscore    bp_ppv
# 0     0.9915  0.994278  0.989513  0.102498  1.000000
# 1     0.9940  1.000000  1.000000  0.106339  1.000000
# 2     1.0000  1.000000  1.000000  0.086406  1.000000
# 3     0.9000  0.965600  0.967520  0.077062  1.000000
# 4     0.9200  0.982400  0.983407  0.076475  1.000000
# 5     0.4500  0.560000  0.591262 -0.003280  0.000000
# 6     0.9910  0.994490  0.990728  0.385755  1.000000
# 7     0.9940  0.997328  0.995621  0.375839  1.000000
# 8     0.9850  0.992500  0.986709  0.336184  1.000000
# 9     1.0000  1.000000  1.000000  0.308709  1.000000
# 10    1.0000  1.000000  1.000000  0.387867  1.000000
# 11    0.5000  0.340000  0.389571  0.330663  0.769231
# 12    0.9732  0.981938  0.970394  0.099398  1.000000
# 13    0.9680  0.993024  0.979140  0.077897  0.000000
# 14    0.6550  0.700300  0.676140  0.073084  0.000000
# 15    0.6100  0.668400  0.631972  0.025316  0.000000
# 16    0.5000  0.560000  0.522831  0.017867  0.000000
# 17    0.5000  0.560000  0.654922  0.027912  0.000000
# 18    0.9900  0.992848  0.988620  0.101788  0.307692
# 19    0.7860  0.849504  0.817942  0.338388  0.846154
# 20    0.8000  0.871200  0.816246  0.356988  0.846154
# 21    0.4400  0.404800  0.439461  0.196008  0.615385
# 22    0.6200  0.614400  0.658593  0.316792  0.769231
# 23    0.4500  0.610000  0.728591  0.327572  0.769231

# %%
df_perf = df[['modelarch', 'transfer', 'numpos', 'accuracy', 'bp_ppv', 'totscore']]
df_perf
# Out:
#    modelarch    transfer  numpos  accuracy    bp_ppv  totscore
# 0        mlp  notransfer   40000    0.9915  1.000000  0.102498
# 1        mlp  notransfer    2000    0.9940  1.000000  0.106339
# 2        mlp  notransfer     800    1.0000  1.000000  0.086406
# 3        mlp  notransfer     400    0.9000  1.000000  0.077062
# 4        mlp  notransfer     200    0.9200  1.000000  0.076475
# 5        mlp  notransfer      80    0.4500  0.000000 -0.003280
# 6        mlp    transfer   40000    0.9910  1.000000  0.385755
# 7        mlp    transfer    2000    0.9940  1.000000  0.375839
# 8        mlp    transfer     800    0.9850  1.000000  0.336184
# 9        mlp    transfer     400    1.0000  1.000000  0.308709
# 10       mlp    transfer     200    1.0000  1.000000  0.387867
# 11       mlp    transfer      80    0.5000  0.769231  0.330663
# 12   resbind  notransfer   40000    0.9732  1.000000  0.099398
# 13   resbind  notransfer    2000    0.9680  0.000000  0.077897
# 14   resbind  notransfer     800    0.6550  0.000000  0.073084
# 15   resbind  notransfer     400    0.6100  0.000000  0.025316
# 16   resbind  notransfer     200    0.5000  0.000000  0.017867
# 17   resbind  notransfer      80    0.5000  0.000000  0.027912
# 18   resbind    transfer   40000    0.9900  0.307692  0.101788
# 19   resbind    transfer    2000    0.7860  0.846154  0.338388
# 20   resbind    transfer     800    0.8000  0.846154  0.356988
# 21   resbind    transfer     400    0.4400  0.615385  0.196008
# 22   resbind    transfer     200    0.6200  0.769231  0.316792
# 23   resbind    transfer      80    0.4500  0.769231  0.327572

# %%
t = sb.factorplot(x='numpos', y='accuracy', col='modelarch',
              hue='transfer', data=df_perf, kind='point')
t.set_xticklabels(rotation=30)
t.set_titles("{col_name}")

# %%
t = sb.factorplot(x='numpos', y='bp_ppv', col='modelarch',
              hue='transfer', data=df_perf, kind='point')
t.set_xticklabels(rotation=30)
t.set_titles("{col_name}")

# %%
t = sb.factorplot(x='numpos', y='totscore', col='modelarch',
              hue='transfer', data=df_perf, kind='point')
t.set_xticklabels(rotation=30)
t.set_titles("{col_name}")
