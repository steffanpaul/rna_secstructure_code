# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = 'test_metrics.csv'
df = pd.read_csv(filename, header=0)
df
# Out:
#     modelarch  datatype  trialnum  numepochs    transfer  numpos      loss  \
# 0         mlp         6       1.0        100  notransfer   40000  0.038646
# 1         mlp         6       1.3        100  notransfer    2000  0.019483
# 2         mlp         6       1.4        100  notransfer     800  0.034295
# 3         mlp         6       1.5       1000  notransfer     400  0.005654
# 4         mlp         6       1.6       1000  notransfer     200  0.258042
# 5         mlp         6       1.7       2000  notransfer      80  0.897526
# 6         mlp         6       2.0        100    transfer   40000  0.037650
# 7         mlp         6       3.0        100    transfer    2000  0.015879
# 8         mlp         6       4.0        100    transfer     800  0.043716
# 9         mlp         6       5.0       1000    transfer     400  0.015521
# 10        mlp         6       6.0       1000    transfer     200  0.380693
# 11        mlp         6       7.0       2000    transfer      80  1.461305
# 12    resbind         6       1.0        100  notransfer   40000  0.114391
# 13    resbind         6       1.3       1000  notransfer    2000  0.118160
# 14    resbind         6       1.4       2000  notransfer     800  0.670657
# 15    resbind         6       1.5       2000  notransfer     400  0.654818
# 16    resbind         6       1.6       1000  notransfer     200  0.686298
# 17    resbind         6       1.7       1000  notransfer      80  2.734198
# 18    resbind         6       2.0       1000    transfer   40000  0.068173
# 19    resbind         6       3.0       1000    transfer    2000  0.457975
# 20    resbind         6       4.0       1000    transfer     800  0.437143
# 21    resbind         6       5.0       1000    transfer     400  0.738910
# 22    resbind         6       6.0       1000    transfer     200  0.859362
# 23    resbind         6       7.0       1000    transfer      80  0.671686
# 24        mlp         6       1.0        100  notransfer   40000  0.040547
# 25        mlp         6       1.3        100  notransfer    2000  0.026670
# 26        mlp         6       1.4        100  notransfer     800  0.033207
# 27        mlp         6       1.5       1000  notransfer     400  0.008136
# 28        mlp         6       1.6       1000  notransfer     200  0.102935
# 29        mlp         6       1.7       2000  notransfer      80  1.390459
# ..        ...       ...       ...        ...         ...     ...       ...
# 210   resbind         6       2.0       1000    transfer   40000  0.070629
# 211   resbind         6       3.0       1000    transfer    2000  0.447565
# 212   resbind         6       4.0       1000    transfer     800  0.410024
# 213   resbind         6       5.0       1000    transfer     400  0.810783
# 214   resbind         6       6.0       1000    transfer     200  0.776626
# 215   resbind         6       7.0       1000    transfer      80  0.799553
# 216       mlp         6       1.0        100  notransfer   40000  0.038566
# 217       mlp         6       1.3        100  notransfer    2000  0.014418
# 218       mlp         6       1.4        100  notransfer     800  0.030282
# 219       mlp         6       1.5       1000  notransfer     400  0.004619
# 220       mlp         6       1.6       1000  notransfer     200  0.177563
# 221       mlp         6       1.7       2000  notransfer      80  1.190675
# 222       mlp         6       2.0        100    transfer   40000  0.048481
# 223       mlp         6       3.0        100    transfer    2000  0.023629
# 224       mlp         6       4.0        100    transfer     800  0.050247
# 225       mlp         6       5.0       1000    transfer     400  0.016972
# 226       mlp         6       6.0       1000    transfer     200  0.285653
# 227       mlp         6       7.0       2000    transfer      80  1.321953
# 228   resbind         6       1.0        100  notransfer   40000  0.118961
# 229   resbind         6       1.3       1000  notransfer    2000  0.126566
# 230   resbind         6       1.4       2000  notransfer     800  0.678689
# 231   resbind         6       1.5       2000  notransfer     400  0.668040
# 232   resbind         6       1.6       1000  notransfer     200  0.772499
# 233   resbind         6       1.7       1000  notransfer      80  1.376040
# 234   resbind         6       2.0       1000    transfer   40000  0.070334
# 235   resbind         6       3.0       1000    transfer    2000  0.441221
# 236   resbind         6       4.0       1000    transfer     800  0.472409
# 237   resbind         6       5.0       1000    transfer     400  0.768815
# 238   resbind         6       6.0       1000    transfer     200  0.797709
# 239   resbind         6       7.0       1000    transfer      80  0.863669
#
#      accuracy   auc-roc    auc-pr  totscore    bp_ppv
# 0      0.9926  0.994677  0.989893  0.102498  1.000000
# 1      0.9940  1.000000  1.000000  0.106339  1.000000
# 2      1.0000  1.000000  1.000000  0.086406  1.000000
# 3      1.0000  1.000000  1.000000  0.095211  1.000000
# 4      0.9000  0.984000  0.984433  0.076475  1.000000
# 5      0.5500  0.700000  0.808261 -0.003280  0.000000
# 6      0.9930  0.995910  0.992765  0.103788  1.000000
# 7      0.9980  1.000000  1.000000  0.100141  1.000000
# 8      1.0000  1.000000  1.000000  0.108387  1.000000
# 9      1.0000  1.000000  1.000000  0.103663  1.000000
# 10     0.8600  0.964800  0.966712  0.084762  1.000000
# 11     0.5000  0.430000  0.428227  0.004637  0.000000
# 12     0.9740  0.981659  0.972016  0.099398  1.000000
# 13     0.9700  0.991616  0.988235  0.077897  0.333333
# 14     0.6050  0.652500  0.648024  0.073084  0.000000
# 15     0.6300  0.704400  0.714682  0.025316  0.000000
# 16     0.6400  0.731200  0.804085  0.017867  0.000000
# 17     0.5000  0.480000  0.530281  0.027912  0.000000
# 18     0.9887  0.991462  0.986293  0.092743  1.000000
# 19     0.7880  0.863424  0.828824  0.056785  0.333333
# 20     0.8300  0.895900  0.871211  0.059208  0.333333
# 21     0.4900  0.522800  0.524675  0.000309  0.000000
# 22     0.5400  0.572800  0.600411  0.001963  0.000000
# 23     0.7500  0.790000  0.782725  0.000227  0.000000
# 24     0.9920  0.995441  0.992689  0.102498  1.000000
# 25     0.9940  0.996960  0.994342  0.106339  1.000000
# 26     1.0000  1.000000  1.000000  0.086406  1.000000
# 27     1.0000  1.000000  1.000000  0.095211  1.000000
# 28     0.9800  0.998400  0.998431  0.076475  1.000000
# 29     0.3500  0.300000  0.372985 -0.003280  0.000000
# ..        ...       ...       ...       ...       ...
# 210    0.9880  0.991691  0.986839  0.092743  1.000000
# 211    0.8220  0.882448  0.866512  0.056785  0.333333
# 212    0.8000  0.909000  0.899536  0.059208  0.333333
# 213    0.4900  0.456800  0.492027  0.000309  0.000000
# 214    0.6200  0.676800  0.707360  0.001963  0.000000
# 215    0.5500  0.610000  0.514293  0.000227  0.000000
# 216    0.9926  0.995357  0.992352  0.102498  1.000000
# 217    0.9980  1.000000  1.000000  0.106339  1.000000
# 218    1.0000  1.000000  1.000000  0.086406  1.000000
# 219    1.0000  1.000000  1.000000  0.095211  1.000000
# 220    0.9400  0.990400  0.990004  0.076475  1.000000
# 221    0.4500  0.430000  0.471593 -0.003280  0.000000
# 222    0.9900  0.993739  0.989274  0.103788  1.000000
# 223    0.9960  0.999488  0.999454  0.100141  1.000000
# 224    0.9950  1.000000  1.000000  0.108387  1.000000
# 225    1.0000  1.000000  1.000000  0.103663  1.000000
# 226    0.9400  0.964800  0.953470  0.084762  1.000000
# 227    0.5000  0.480000  0.555594  0.004637  0.000000
# 228    0.9722  0.981426  0.970814  0.099398  1.000000
# 229    0.9600  0.991376  0.987490  0.077897  0.333333
# 230    0.5750  0.607900  0.625847  0.073084  0.000000
# 231    0.6400  0.688400  0.644391  0.025316  0.000000
# 232    0.6000  0.723200  0.782025  0.017867  0.000000
# 233    0.6500  0.730000  0.629268  0.027912  0.000000
# 234    0.9883  0.990590  0.984300  0.092743  1.000000
# 235    0.8100  0.877520  0.854423  0.056785  0.333333
# 236    0.7900  0.866200  0.843950  0.059208  0.333333
# 237    0.5000  0.512800  0.552840  0.000309  0.000000
# 238    0.6200  0.726400  0.756910  0.001963  0.000000
# 239    0.5000  0.650000  0.564528  0.000227  0.000000
#
# [240 rows x 12 columns]

# %%
df_perf = df[['modelarch', 'transfer', 'numpos', 'accuracy', 'bp_ppv', 'totscore']]
df_perf
# Out:
#     modelarch    transfer  numpos  accuracy    bp_ppv  totscore
# 0         mlp  notransfer   40000    0.9926  1.000000  0.102498
# 1         mlp  notransfer    2000    0.9940  1.000000  0.106339
# 2         mlp  notransfer     800    1.0000  1.000000  0.086406
# 3         mlp  notransfer     400    1.0000  1.000000  0.095211
# 4         mlp  notransfer     200    0.9000  1.000000  0.076475
# 5         mlp  notransfer      80    0.5500  0.000000 -0.003280
# 6         mlp    transfer   40000    0.9930  1.000000  0.103788
# 7         mlp    transfer    2000    0.9980  1.000000  0.100141
# 8         mlp    transfer     800    1.0000  1.000000  0.108387
# 9         mlp    transfer     400    1.0000  1.000000  0.103663
# 10        mlp    transfer     200    0.8600  1.000000  0.084762
# 11        mlp    transfer      80    0.5000  0.000000  0.004637
# 12    resbind  notransfer   40000    0.9740  1.000000  0.099398
# 13    resbind  notransfer    2000    0.9700  0.333333  0.077897
# 14    resbind  notransfer     800    0.6050  0.000000  0.073084
# 15    resbind  notransfer     400    0.6300  0.000000  0.025316
# 16    resbind  notransfer     200    0.6400  0.000000  0.017867
# 17    resbind  notransfer      80    0.5000  0.000000  0.027912
# 18    resbind    transfer   40000    0.9887  1.000000  0.092743
# 19    resbind    transfer    2000    0.7880  0.333333  0.056785
# 20    resbind    transfer     800    0.8300  0.333333  0.059208
# 21    resbind    transfer     400    0.4900  0.000000  0.000309
# 22    resbind    transfer     200    0.5400  0.000000  0.001963
# 23    resbind    transfer      80    0.7500  0.000000  0.000227
# 24        mlp  notransfer   40000    0.9920  1.000000  0.102498
# 25        mlp  notransfer    2000    0.9940  1.000000  0.106339
# 26        mlp  notransfer     800    1.0000  1.000000  0.086406
# 27        mlp  notransfer     400    1.0000  1.000000  0.095211
# 28        mlp  notransfer     200    0.9800  1.000000  0.076475
# 29        mlp  notransfer      80    0.3500  0.000000 -0.003280
# ..        ...         ...     ...       ...       ...       ...
# 210   resbind    transfer   40000    0.9880  1.000000  0.092743
# 211   resbind    transfer    2000    0.8220  0.333333  0.056785
# 212   resbind    transfer     800    0.8000  0.333333  0.059208
# 213   resbind    transfer     400    0.4900  0.000000  0.000309
# 214   resbind    transfer     200    0.6200  0.000000  0.001963
# 215   resbind    transfer      80    0.5500  0.000000  0.000227
# 216       mlp  notransfer   40000    0.9926  1.000000  0.102498
# 217       mlp  notransfer    2000    0.9980  1.000000  0.106339
# 218       mlp  notransfer     800    1.0000  1.000000  0.086406
# 219       mlp  notransfer     400    1.0000  1.000000  0.095211
# 220       mlp  notransfer     200    0.9400  1.000000  0.076475
# 221       mlp  notransfer      80    0.4500  0.000000 -0.003280
# 222       mlp    transfer   40000    0.9900  1.000000  0.103788
# 223       mlp    transfer    2000    0.9960  1.000000  0.100141
# 224       mlp    transfer     800    0.9950  1.000000  0.108387
# 225       mlp    transfer     400    1.0000  1.000000  0.103663
# 226       mlp    transfer     200    0.9400  1.000000  0.084762
# 227       mlp    transfer      80    0.5000  0.000000  0.004637
# 228   resbind  notransfer   40000    0.9722  1.000000  0.099398
# 229   resbind  notransfer    2000    0.9600  0.333333  0.077897
# 230   resbind  notransfer     800    0.5750  0.000000  0.073084
# 231   resbind  notransfer     400    0.6400  0.000000  0.025316
# 232   resbind  notransfer     200    0.6000  0.000000  0.017867
# 233   resbind  notransfer      80    0.6500  0.000000  0.027912
# 234   resbind    transfer   40000    0.9883  1.000000  0.092743
# 235   resbind    transfer    2000    0.8100  0.333333  0.056785
# 236   resbind    transfer     800    0.7900  0.333333  0.059208
# 237   resbind    transfer     400    0.5000  0.000000  0.000309
# 238   resbind    transfer     200    0.6200  0.000000  0.001963
# 239   resbind    transfer      80    0.5000  0.000000  0.000227
#
# [240 rows x 6 columns]

# %%
t = sb.factorplot(x='numpos', y='accuracy', col='modelarch',
              hue='transfer', data=df_perf, kind='point')
t.set_xticklabels(rotation=30)
t.set_titles("{col_name}")

# %%
t = sb.factorplot(x='numpos', y='bp_ppv', col='modelarch',
              hue='transfer', data=df_perf, kind='point')
t.set_xticklabels(rotation=30)
t.set_titles("{col_name}")

# %%
t = sb.factorplot(x='numpos', y='totscore', col='modelarch',
              hue='transfer', data=df_perf, kind='point')
t.set_xticklabels(rotation=30)
t.set_titles("{col_name}")
