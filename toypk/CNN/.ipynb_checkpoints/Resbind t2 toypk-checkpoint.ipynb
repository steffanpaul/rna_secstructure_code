# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
'''SAVE PATHS AND PARAMETERS'''
params_results = '../../../results'
exp_folder = 'toypk'

modelarch = 'resbind'
trial = 't2'
modelsavename = '%s_%s'%(modelarch, trial)

# %%
'''OPEN DATA'''

starttime = time.time()

#Open data from h5py

data_path = '../../../data_toypk/toypk_50_d2.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, dims = X_data.shape
X_data = np.expand_dims(X_data, axis=2)
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 0.33s

# %%
'''BUILD NEURAL NETWORK'''

def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = os.path.join(params_results, exp_folder)
param_path = os.path.join(save_path, modelsavename)
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 54, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
'''TRAIN '''

# initialize session
sess = utils.initialize_session()

#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)


sess.close()
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.90s -- loss=0.62549 -- acc=65.176668%
#
#   valid loss:		0.47407
#   valid accuracy:	0.74960+/-0.00000
#   valid auc-roc:	0.92396+/-0.00000
#   valid auc-pr:		0.91206+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t2_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.32844 -- acc=85.670007%
#
#   valid loss:		0.06071
#   valid accuracy:	0.98360+/-0.00000
#   valid auc-roc:	0.99943+/-0.00000
#   valid auc-pr:		0.99936+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t2_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=4.52s -- loss=0.07672 -- acc=97.550005%
#
#   valid loss:		0.01175
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t2_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=4.56s -- loss=0.02967 -- acc=99.276678%
#
#   valid loss:		0.00826
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t2_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.47s -- loss=0.02010 -- acc=99.553335%
#
#   valid loss:		0.00858
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.36s -- loss=0.01624 -- acc=99.713331%
#
#   valid loss:		0.00783
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t2_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.38s -- loss=0.01507 -- acc=99.735004%
#
#   valid loss:		0.00796
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=4.48s -- loss=0.01315 -- acc=99.821672%
#
#   valid loss:		0.00889
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.46s -- loss=0.01270 -- acc=99.831673%
#
#   valid loss:		0.00812
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.01191 -- acc=99.840004%
#
#   valid loss:		0.00898
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=4.55s -- loss=0.01380 -- acc=99.790009%
#
#   valid loss:		0.00871
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=4.55s -- loss=0.01247 -- acc=99.846675%
#
#   valid loss:		0.00822
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.01033 -- acc=99.906671%
#
#   valid loss:		0.00905
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.01310 -- acc=99.815002%
#
#   valid loss:		0.00874
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=4.38s -- loss=0.01106 -- acc=99.871677%
#
#   valid loss:		0.00949
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.01179 -- acc=99.860006%
#
#   valid loss:		0.00868
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.01176 -- acc=99.886679%
#
#   valid loss:		0.00992
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.01215 -- acc=99.845005%
#
#   valid loss:		0.00987
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.01248 -- acc=99.853335%
#
#   valid loss:		0.00973
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.01130 -- acc=99.890009%
#
#   valid loss:		0.00950
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=4.42s -- loss=0.01102 -- acc=99.903330%
#
#   valid loss:		0.00943
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=4.38s -- loss=0.01108 -- acc=99.901670%
#
#   valid loss:		0.01068
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=4.39s -- loss=0.01210 -- acc=99.885009%
#
#   valid loss:		0.00977
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.01128 -- acc=99.900000%
#
#   valid loss:		0.01038
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=4.43s -- loss=0.01051 -- acc=99.925003%
#
#   valid loss:		0.00949
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=4.42s -- loss=0.00993 -- acc=99.925003%
#
#   valid loss:		0.00885
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.01156 -- acc=99.888339%
#
#   valid loss:		0.00964
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=4.43s -- loss=0.01120 -- acc=99.903330%
#
#   valid loss:		0.00977
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=4.39s -- loss=0.01062 -- acc=99.913331%
#
#   valid loss:		0.00893
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=4.36s -- loss=0.01164 -- acc=99.895000%
#
#   valid loss:		0.00921
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=4.38s -- loss=0.01059 -- acc=99.921672%
#
#   valid loss:		0.01212
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=4.37s -- loss=0.01025 -- acc=99.920002%
#
#   valid loss:		0.01078
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=4.42s -- loss=0.01124 -- acc=99.896670%
#
#   valid loss:		0.00979
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=4.47s -- loss=0.01041 -- acc=99.931673%
#
#   valid loss:		0.01044
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.01131 -- acc=99.903330%
#
#   valid loss:		0.00971
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=4.43s -- loss=0.01042 -- acc=99.930003%
#
#   valid loss:		0.00930
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=4.44s -- loss=0.01034 -- acc=99.921672%
#
#   valid loss:		0.00927
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.01023 -- acc=99.918332%
#
#   valid loss:		0.00975
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.01109 -- acc=99.890009%
#
#   valid loss:		0.00915
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.00998 -- acc=99.926673%
#
#   valid loss:		0.00989
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=4.36s -- loss=0.00974 -- acc=99.938334%
#
#   valid loss:		0.00987
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=4.42s -- loss=0.00969 -- acc=99.940004%
#
#   valid loss:		0.01007
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.01025 -- acc=99.931673%
#
#   valid loss:		0.00993
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.01095 -- acc=99.910001%
#
#   valid loss:		0.00966
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=4.39s -- loss=0.01045 -- acc=99.920002%
#
#   valid loss:		0.00980
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.01073 -- acc=99.910001%
#
#   valid loss:		0.01018
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Patience ran out... Early stopping.

# %%
'''TEST'''
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/toypk/resbind_t2_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/toypk/resbind_t2_best.ckpt
#   test  loss:		0.00829
#   test  accuracy:	0.99950+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
'''SORT ACTIVATIONS'''

predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
'''FIRST ORDER MUTAGENESIS'''
#num_plots=np.linspace(0,20000,5).astype(int)
num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[10000+ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
    plt.savefig('test%s.png'%(ii))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
'''SECOND ORDER MUTAGENESIS'''

num_summary = 2000

arrayspath = 'Arrays/%s_%s%s_so%.0fk.npy'%(exp_folder, modelarch, trial, num_summary/1000)
X = test['inputs'][plot_index[:num_summary]]

mean_mut2 = mf.som_average_ungapped_logodds(X, range(seqlen), arrayspath, nntrainer, sess, progress='on', 
                                           save=True, layer='dense_1_bias')
# Out:
# 0
# ../../../../mutagenesisfunctions.py:554: RuntimeWarning: invalid value encountered in log
#   mut2_scores = np.log(mut2_scores + 1e-7) - np.log(WT_score+1e-7)
# Epoch duration =0.77s
# Cumulative duration =0.77s
#
# 1
# Epoch duration =0.72s
# Cumulative duration =1.49s
#
# 2
# Epoch duration =0.72s
# Cumulative duration =2.21s
#
# 3
# Epoch duration =0.72s
# Cumulative duration =2.93s
#
# 4
# Epoch duration =0.72s
# Cumulative duration =3.65s
#
# 5
# Epoch duration =0.72s
# Cumulative duration =4.37s
#
# 6
# Epoch duration =0.72s
# Cumulative duration =5.09s
#
# 7
# Epoch duration =0.72s
# Cumulative duration =5.81s
#
# 8
# Epoch duration =0.72s
# Cumulative duration =6.53s
#
# 9
# Epoch duration =0.73s
# Cumulative duration =7.26s
#
# 10
# Epoch duration =0.72s
# Cumulative duration =7.98s
#
# 11
# Epoch duration =0.72s
# Cumulative duration =8.71s
#
# 12
# Epoch duration =0.72s
# Cumulative duration =9.43s
#
# 13
# Epoch duration =0.72s
# Cumulative duration =10.15s
#
# 14
# Epoch duration =0.72s
# Cumulative duration =10.87s
#
# 15
# Epoch duration =0.72s
# Cumulative duration =11.59s
#
# 16
# Epoch duration =0.72s
# Cumulative duration =12.31s
#
# 17
# Epoch duration =0.74s
# Cumulative duration =13.05s
#
# 18
# Epoch duration =0.72s
# Cumulative duration =13.77s
#
# 19
# Epoch duration =0.72s
# Cumulative duration =14.49s
#
# 20
# Epoch duration =0.73s
# Cumulative duration =15.22s
#
# 21
# Epoch duration =0.72s
# Cumulative duration =15.94s
#
# 22
# Epoch duration =0.72s
# Cumulative duration =16.66s
#
# 23
# Epoch duration =0.72s
# Cumulative duration =17.37s
#
# 24
# Epoch duration =0.72s
# Cumulative duration =18.1s
#
# 25
# Epoch duration =0.72s
# Cumulative duration =18.82s
#
# 26
# Epoch duration =0.72s
# Cumulative duration =19.53s
#
# 27
# Epoch duration =0.72s
# Cumulative duration =20.25s
#
# 28
# Epoch duration =0.72s
# Cumulative duration =20.97s
#
# 29
# Epoch duration =0.71s
# Cumulative duration =21.69s
#
# 30
# Epoch duration =0.72s
# Cumulative duration =22.41s
#
# 31
# Epoch duration =0.72s
# Cumulative duration =23.13s
#
# 32
# Epoch duration =0.71s
# Cumulative duration =23.84s
#
# 33
# Epoch duration =0.71s
# Cumulative duration =24.56s
#
# 34
# Epoch duration =0.72s
# Cumulative duration =25.28s
#
# 35
# Epoch duration =0.73s
# Cumulative duration =26.01s
#
# 36
# Epoch duration =0.72s
# Cumulative duration =26.73s
#
# 37
# Epoch duration =0.73s
# Cumulative duration =27.46s
#
# 38
# Epoch duration =0.71s
# Cumulative duration =28.17s
#
# 39
# Epoch duration =0.72s
# Cumulative duration =28.89s
#
# 40
# Epoch duration =0.73s
# Cumulative duration =29.62s
#
# 41
# Epoch duration =0.72s
# Cumulative duration =30.34s
#
# 42
# Epoch duration =0.72s
# Cumulative duration =31.06s
#
# 43
# Epoch duration =0.73s
# Cumulative duration =31.79s
#
# 44
# Epoch duration =0.72s
# Cumulative duration =32.51s
#
# 45
# Epoch duration =0.77s
# Cumulative duration =33.28s
#
# 46
# Epoch duration =0.71s
# Cumulative duration =33.99s
#
# 47
# Epoch duration =0.72s
# Cumulative duration =34.72s
#
# 48
# Epoch duration =0.73s
# Cumulative duration =35.44s
#
# 49
# Epoch duration =0.72s
# Cumulative duration =36.16s
#
# 50
# Epoch duration =0.72s
# Cumulative duration =36.88s
#
# 51
# Epoch duration =0.73s
# Cumulative duration =37.61s
#
# 52
# Epoch duration =0.72s
# Cumulative duration =38.33s
#
# 53
# Epoch duration =0.72s
# Cumulative duration =39.05s
#
# 54
# Epoch duration =0.72s
# Cumulative duration =39.77s
#
# 55
# Epoch duration =0.72s
# Cumulative duration =40.49s
#
# 56
# Epoch duration =0.73s
# Cumulative duration =41.23s
#
# 57
# Epoch duration =0.71s
# Cumulative duration =41.94s
#
# 58
# Epoch duration =0.72s
# Cumulative duration =42.65s
#
# 59
# Epoch duration =0.72s
# Cumulative duration =43.38s
#
# 60
# Epoch duration =0.71s
# Cumulative duration =44.09s
#
# 61
# Epoch duration =0.72s
# Cumulative duration =44.81s
#
# 62
# Epoch duration =0.72s
# Cumulative duration =45.53s
#
# 63
# Epoch duration =0.75s
# Cumulative duration =46.28s
#
# 64
# Epoch duration =0.73s
# Cumulative duration =47.01s
#
# 65
# Epoch duration =0.73s
# Cumulative duration =47.74s
#
# 66
# Epoch duration =0.72s
# Cumulative duration =48.46s
#
# 67
# Epoch duration =0.72s
# Cumulative duration =49.18s
#
# 68
# Epoch duration =0.71s
# Cumulative duration =49.9s
#
# 69
# Epoch duration =0.72s
# Cumulative duration =50.61s
#
# 70
# Epoch duration =0.73s
# Cumulative duration =51.35s
#
# 71
# Epoch duration =0.72s
# Cumulative duration =52.06s
#
# 72
# Epoch duration =0.72s
# Cumulative duration =52.78s
#
# 73
# Epoch duration =0.72s
# Cumulative duration =53.5s
#
# 74
# Epoch duration =0.73s
# Cumulative duration =54.23s
#
# 75
# Epoch duration =0.72s
# Cumulative duration =54.94s
#
# 76
# Epoch duration =0.71s
# Cumulative duration =55.65s
#
# 77
# Epoch duration =0.72s
# Cumulative duration =56.37s
#
# 78
# Epoch duration =0.71s
# Cumulative duration =57.09s
#
# 79
# Epoch duration =0.72s
# Cumulative duration =57.8s
#
# 80
# Epoch duration =0.72s
# Cumulative duration =58.52s
#
# 81
# Epoch duration =0.71s
# Cumulative duration =59.24s
#
# 82
# Epoch duration =0.73s
# Cumulative duration =59.97s
#
# 83
# Epoch duration =0.72s
# Cumulative duration =1min 0.6799999999999997s
#
# 84
# Epoch duration =0.72s
# Cumulative duration =1min 1.3999999999999986s
#
# 85
# Epoch duration =0.72s
# Cumulative duration =1min 2.1199999999999974s
#
# 86
# Epoch duration =0.72s
# Cumulative duration =1min 2.8400000000000034s
#
# 87
# Epoch duration =0.71s
# Cumulative duration =1min 3.5600000000000023s
#
# 88
# Epoch duration =0.72s
# Cumulative duration =1min 4.280000000000001s
#
# 89
# Epoch duration =0.72s
# Cumulative duration =1min 5.0s
#
# 90
# Epoch duration =0.71s
# Cumulative duration =1min 5.709999999999994s
#
# 91
# Epoch duration =0.72s
# Cumulative duration =1min 6.430000000000007s
#
# 92
# Epoch duration =0.72s
# Cumulative duration =1min 7.150000000000006s
#
# 93
# Epoch duration =0.71s
# Cumulative duration =1min 7.859999999999999s
#
# 94
# Epoch duration =0.72s
# Cumulative duration =1min 8.579999999999998s
#
# 95
# Epoch duration =0.72s
# Cumulative duration =1min 9.299999999999997s
#
# 96
# Epoch duration =0.73s
# Cumulative duration =1min 10.030000000000001s
#
# 97
# Epoch duration =0.72s
# Cumulative duration =1min 10.75s
#
# 98
# Epoch duration =0.72s
# Cumulative duration =1min 11.469999999999999s
#
# 99
# Epoch duration =0.74s
# Cumulative duration =1min 12.209999999999994s
#
# 100
# Epoch duration =0.72s
# Cumulative duration =1min 12.939999999999998s
#
# 101
# Epoch duration =0.72s
# Cumulative duration =1min 13.650000000000006s
#
# 102
# Epoch duration =0.72s
# Cumulative duration =1min 14.379999999999995s
#
# 103
# Epoch duration =0.73s
# Cumulative duration =1min 15.099999999999994s
#
# 104
# Epoch duration =0.72s
# Cumulative duration =1min 15.819999999999993s
#
# 105
# Epoch duration =0.72s
# Cumulative duration =1min 16.549999999999997s
#
# 106
# Epoch duration =0.71s
# Cumulative duration =1min 17.260000000000005s
#
# 107
# Epoch duration =0.71s
# Cumulative duration =1min 17.97s
#
# 108
# Epoch duration =0.72s
# Cumulative duration =1min 18.689999999999998s
#
# 109
# Epoch duration =0.72s
# Cumulative duration =1min 19.409999999999997s
#
# 110
# Epoch duration =0.73s
# Cumulative duration =1min 20.129999999999995s
#
# 111
# Epoch duration =0.72s
# Cumulative duration =1min 20.849999999999994s
#
# 112
# Epoch duration =0.72s
# Cumulative duration =1min 21.569999999999993s
#
# 113
# Epoch duration =0.71s
# Cumulative duration =1min 22.290000000000006s
#
# 114
# Epoch duration =0.72s
# Cumulative duration =1min 23.010000000000005s
#
# 115
# Epoch duration =0.72s
# Cumulative duration =1min 23.72s
#
# 116
# Epoch duration =0.72s
# Cumulative duration =1min 24.439999999999998s
#
# 117
# Epoch duration =0.72s
# Cumulative duration =1min 25.159999999999997s
#
# 118
# Epoch duration =0.72s
# Cumulative duration =1min 25.870000000000005s
#
# 119
# Epoch duration =0.72s
# Cumulative duration =1min 26.590000000000003s
#
# 120
# Epoch duration =0.71s
# Cumulative duration =1min 27.310000000000002s
#
# 121
# Epoch duration =0.72s
# Cumulative duration =1min 28.03s
#
# 122
# Epoch duration =0.72s
# Cumulative duration =1min 28.75s
#
# 123
# Epoch duration =0.72s
# Cumulative duration =1min 29.47s
#
# 124
# Epoch duration =0.73s
# Cumulative duration =1min 30.200000000000003s
#
# 125
# Epoch duration =0.74s
# Cumulative duration =1min 30.939999999999998s
#
# 126
# Epoch duration =0.71s
# Cumulative duration =1min 31.650000000000006s
#
# 127
# Epoch duration =0.72s
# Cumulative duration =1min 32.370000000000005s
#
# 128
# Epoch duration =0.72s
# Cumulative duration =1min 33.08s
#
# 129
# Epoch duration =0.75s
# Cumulative duration =1min 33.84s
#
# 130
# Epoch duration =0.72s
# Cumulative duration =1min 34.56s
#
# 131
# Epoch duration =0.71s
# Cumulative duration =1min 35.269999999999996s
#
# 132
# Epoch duration =0.72s
# Cumulative duration =1min 35.989999999999995s
#
# 133
# Epoch duration =0.72s
# Cumulative duration =1min 36.709999999999994s
#
# 134
# Epoch duration =0.72s
# Cumulative duration =1min 37.43000000000001s
#
# 135
# Epoch duration =0.73s
# Cumulative duration =1min 38.16s
#
# 136
# Epoch duration =0.72s
# Cumulative duration =1min 38.879999999999995s
#
# 137
# Epoch duration =0.75s
# Cumulative duration =1min 39.64s
#
# 138
# Epoch duration =0.72s
# Cumulative duration =1min 40.349999999999994s
#
# 139
# Epoch duration =0.72s
# Cumulative duration =1min 41.06999999999999s
#
# 140
# Epoch duration =0.72s
# Cumulative duration =1min 41.790000000000006s
#
# 141
# Epoch duration =0.72s
# Cumulative duration =1min 42.510000000000005s
#
# 142
# Epoch duration =0.72s
# Cumulative duration =1min 43.230000000000004s
#
# 143
# Epoch duration =0.71s
# Cumulative duration =1min 43.94s
#
# 144
# Epoch duration =0.72s
# Cumulative duration =1min 44.66s
#
# 145
# Epoch duration =0.71s
# Cumulative duration =1min 45.370000000000005s
#
# 146
# Epoch duration =0.71s
# Cumulative duration =1min 46.09s
#
# 147
# Epoch duration =0.72s
# Cumulative duration =1min 46.8s
#
# 148
# Epoch duration =0.71s
# Cumulative duration =1min 47.519999999999996s
#
# 149
# Epoch duration =0.72s
# Cumulative duration =1min 48.239999999999995s
#
# 150
# Epoch duration =0.72s
# Cumulative duration =1min 48.959999999999994s
#
# 151
# Epoch duration =0.71s
# Cumulative duration =1min 49.68000000000001s
#
# 152
# Epoch duration =0.72s
# Cumulative duration =1min 50.39s
#
# 153
# Epoch duration =0.71s
# Cumulative duration =1min 51.11s
#
# 154
# Epoch duration =0.72s
# Cumulative duration =1min 51.83s
#
# 155
# Epoch duration =0.72s
# Cumulative duration =1min 52.540000000000006s
#
# 156
# Epoch duration =0.72s
# Cumulative duration =1min 53.260000000000005s
#
# 157
# Epoch duration =0.72s
# Cumulative duration =1min 53.980000000000004s
#
# 158
# Epoch duration =0.72s
# Cumulative duration =1min 54.7s
#
# 159
# Epoch duration =0.72s
# Cumulative duration =1min 55.41s
#
# 160
# Epoch duration =0.71s
# Cumulative duration =1min 56.129999999999995s
#
# 161
# Epoch duration =0.74s
# Cumulative duration =1min 56.870000000000005s
#
# 162
# Epoch duration =0.71s
# Cumulative duration =1min 57.59s
#
# 163
# Epoch duration =0.72s
# Cumulative duration =1min 58.31s
#
# 164
# Epoch duration =0.72s
# Cumulative duration =1min 59.03s
#
# 165
# Epoch duration =0.72s
# Cumulative duration =1min 59.739999999999995s
#
# 166
# Epoch duration =0.72s
# Cumulative duration =2min 0.45999999999999375s
#
# 167
# Epoch duration =0.71s
# Cumulative duration =2min 1.1800000000000068s
#
# 168
# Epoch duration =0.72s
# Cumulative duration =2min 1.8900000000000006s
#
# 169
# Epoch duration =0.72s
# Cumulative duration =2min 2.6099999999999994s
#
# 170
# Epoch duration =0.72s
# Cumulative duration =2min 3.3299999999999983s
#
# 171
# Epoch duration =0.73s
# Cumulative duration =2min 4.060000000000002s
#
# 172
# Epoch duration =0.72s
# Cumulative duration =2min 4.769999999999996s
#
# 173
# Epoch duration =0.71s
# Cumulative duration =2min 5.489999999999995s
#
# 174
# Epoch duration =0.71s
# Cumulative duration =2min 6.200000000000003s
#
# 175
# Epoch duration =0.72s
# Cumulative duration =2min 6.920000000000002s
#
# 176
# Epoch duration =0.72s
# Cumulative duration =2min 7.640000000000001s
#
# 177
# Epoch duration =0.72s
# Cumulative duration =2min 8.360000000000014s
#
# 178
# Epoch duration =0.72s
# Cumulative duration =2min 9.080000000000013s
#
# 179
# Epoch duration =0.72s
# Cumulative duration =2min 9.800000000000011s
#
# 180
# Epoch duration =0.74s
# Cumulative duration =2min 10.539999999999992s
#
# 181
# Epoch duration =0.72s
# Cumulative duration =2min 11.259999999999991s
#
# 182
# Epoch duration =0.72s
# Cumulative duration =2min 11.969999999999999s
#
# 183
# Epoch duration =0.72s
# Cumulative duration =2min 12.689999999999998s
#
# 184
# Epoch duration =0.73s
# Cumulative duration =2min 13.419999999999987s
#
# 185
# Epoch duration =0.73s
# Cumulative duration =2min 14.150000000000006s
#
# 186
# Epoch duration =0.73s
# Cumulative duration =2min 14.879999999999995s
#
# 187
# Epoch duration =0.72s
# Cumulative duration =2min 15.599999999999994s
#
# 188
# Epoch duration =0.71s
# Cumulative duration =2min 16.319999999999993s
#
# 189
# Epoch duration =0.72s
# Cumulative duration =2min 17.039999999999992s
#
# 190
# Epoch duration =0.72s
# Cumulative duration =2min 17.75s
#
# 191
# Epoch duration =0.72s
# Cumulative duration =2min 18.47s
#
# 192
# Epoch duration =0.72s
# Cumulative duration =2min 19.19999999999999s
#
# 193
# Epoch duration =0.72s
# Cumulative duration =2min 19.909999999999997s
#
# 194
# Epoch duration =0.72s
# Cumulative duration =2min 20.629999999999995s
#
# 195
# Epoch duration =0.72s
# Cumulative duration =2min 21.349999999999994s
#
# 196
# Epoch duration =0.71s
# Cumulative duration =2min 22.060000000000002s
#
# 197
# Epoch duration =0.72s
# Cumulative duration =2min 22.78s
#
# 198
# Epoch duration =0.71s
# Cumulative duration =2min 23.5s
#
# 199
# Epoch duration =0.72s
# Cumulative duration =2min 24.210000000000008s
#
# 200
# Epoch duration =0.72s
# Cumulative duration =2min 24.939999999999998s
#
# 201
# Epoch duration =0.74s
# Cumulative duration =2min 25.680000000000007s
#
# 202
# Epoch duration =0.72s
# Cumulative duration =2min 26.400000000000006s
#
# 203
# Epoch duration =0.72s
# Cumulative duration =2min 27.120000000000005s
#
# 204
# Epoch duration =0.71s
# Cumulative duration =2min 27.830000000000013s
#
# 205
# Epoch duration =0.72s
# Cumulative duration =2min 28.560000000000002s
#
# 206
# Epoch duration =0.72s
# Cumulative duration =2min 29.27000000000001s
#
# 207
# Epoch duration =0.72s
# Cumulative duration =2min 30.0s
#
# 208
# Epoch duration =0.71s
# Cumulative duration =2min 30.710000000000008s
#
# 209
# Epoch duration =0.72s
# Cumulative duration =2min 31.430000000000007s
#
# 210
# Epoch duration =0.71s
# Cumulative duration =2min 32.139999999999986s
#
# 211
# Epoch duration =0.72s
# Cumulative duration =2min 32.860000000000014s
#
# 212
# Epoch duration =0.72s
# Cumulative duration =2min 33.58000000000001s
#
# 213
# Epoch duration =0.71s
# Cumulative duration =2min 34.28999999999999s
#
# 214
# Epoch duration =0.72s
# Cumulative duration =2min 35.02000000000001s
#
# 215
# Epoch duration =0.72s
# Cumulative duration =2min 35.74000000000001s
#
# 216
# Epoch duration =0.72s
# Cumulative duration =2min 36.46000000000001s
#
# 217
# Epoch duration =0.72s
# Cumulative duration =2min 37.18000000000001s
#
# 218
# Epoch duration =0.72s
# Cumulative duration =2min 37.889999999999986s
#
# 219
# Epoch duration =0.74s
# Cumulative duration =2min 38.639999999999986s
#
# 220
# Epoch duration =0.72s
# Cumulative duration =2min 39.360000000000014s
#
# 221
# Epoch duration =0.72s
# Cumulative duration =2min 40.08000000000001s
#
# 222
# Epoch duration =0.71s
# Cumulative duration =2min 40.78999999999999s
#
# 223
# Epoch duration =0.72s
# Cumulative duration =2min 41.50999999999999s
#
# 224
# Epoch duration =0.71s
# Cumulative duration =2min 42.22s
#
# 225
# Epoch duration =0.72s
# Cumulative duration =2min 42.94999999999999s
#
# 226
# Epoch duration =0.73s
# Cumulative duration =2min 43.68000000000001s
#
# 227
# Epoch duration =0.72s
# Cumulative duration =2min 44.400000000000006s
#
# 228
# Epoch duration =0.74s
# Cumulative duration =2min 45.139999999999986s
#
# 229
# Epoch duration =0.72s
# Cumulative duration =2min 45.860000000000014s
#
# 230
# Epoch duration =0.72s
# Cumulative duration =2min 46.58000000000001s
#
# 231
# Epoch duration =0.72s
# Cumulative duration =2min 47.30000000000001s
#
# 232
# Epoch duration =0.73s
# Cumulative duration =2min 48.03s
#
# 233
# Epoch duration =0.73s
# Cumulative duration =2min 48.75999999999999s
#
# 234
# Epoch duration =0.72s
# Cumulative duration =2min 49.49000000000001s
#
# 235
# Epoch duration =0.73s
# Cumulative duration =2min 50.21000000000001s
#
# 236
# Epoch duration =0.72s
# Cumulative duration =2min 50.93000000000001s
#
# 237
# Epoch duration =0.72s
# Cumulative duration =2min 51.650000000000006s
#
# 238
# Epoch duration =0.72s
# Cumulative duration =2min 52.370000000000005s
#
# 239
# Epoch duration =0.72s
# Cumulative duration =2min 53.09s
#
# 240
# Epoch duration =0.72s
# Cumulative duration =2min 53.81s
#
# 241
# Epoch duration =0.74s
# Cumulative duration =2min 54.55000000000001s
#
# 242
# Epoch duration =0.72s
# Cumulative duration =2min 55.27000000000001s
#
# 243
# Epoch duration =0.72s
# Cumulative duration =2min 55.99000000000001s
#
# 244
# Epoch duration =0.72s
# Cumulative duration =2min 56.71000000000001s
#
# 245
# Epoch duration =0.72s
# Cumulative duration =2min 57.43000000000001s
#
# 246
# Epoch duration =0.71s
# Cumulative duration =2min 58.139999999999986s
#
# 247
# Epoch duration =0.72s
# Cumulative duration =2min 58.860000000000014s
#
# 248
# Epoch duration =0.72s
# Cumulative duration =2min 59.58000000000001s
#
# 249
# Epoch duration =0.71s
# Cumulative duration =3min 0.28999999999999204s
#
# 250
# Epoch duration =0.72s
# Cumulative duration =3min 1.009999999999991s
#
# 251
# Epoch duration =0.72s
# Cumulative duration =3min 1.7299999999999898s
#
# 252
# Epoch duration =0.72s
# Cumulative duration =3min 2.4499999999999886s
#
# 253
# Epoch duration =0.72s
# Cumulative duration =3min 3.1699999999999875s
#
# 254
# Epoch duration =0.72s
# Cumulative duration =3min 3.8899999999999864s
#
# 255
# Epoch duration =0.75s
# Cumulative duration =3min 4.639999999999986s
#
# 256
# Epoch duration =0.72s
# Cumulative duration =3min 5.360000000000014s
#
# 257
# Epoch duration =0.72s
# Cumulative duration =3min 6.0800000000000125s
#
# 258
# Epoch duration =0.72s
# Cumulative duration =3min 6.800000000000011s
#
# 259
# Epoch duration =0.71s
# Cumulative duration =3min 7.509999999999991s
#
# 260
# Epoch duration =0.71s
# Cumulative duration =3min 8.219999999999999s
#
# 261
# Epoch duration =0.72s
# Cumulative duration =3min 8.939999999999998s
#
# 262
# Epoch duration =0.72s
# Cumulative duration =3min 9.659999999999997s
#
# 263
# Epoch duration =0.72s
# Cumulative duration =3min 10.379999999999995s
#
# 264
# Epoch duration =0.75s
# Cumulative duration =3min 11.129999999999995s
#
# 265
# Epoch duration =0.72s
# Cumulative duration =3min 11.840000000000003s
#
# 266
# Epoch duration =0.72s
# Cumulative duration =3min 12.560000000000002s
#
# 267
# Epoch duration =0.72s
# Cumulative duration =3min 13.280000000000001s
#
# 268
# Epoch duration =0.72s
# Cumulative duration =3min 14.0s
#
# 269
# Epoch duration =0.74s
# Cumulative duration =3min 14.740000000000009s
#
# 270
# Epoch duration =0.72s
# Cumulative duration =3min 15.460000000000008s
#
# 271
# Epoch duration =0.71s
# Cumulative duration =3min 16.169999999999987s
#
# 272
# Epoch duration =0.72s
# Cumulative duration =3min 16.889999999999986s
#
# 273
# Epoch duration =0.72s
# Cumulative duration =3min 17.610000000000014s
#
# 274
# Epoch duration =0.71s
# Cumulative duration =3min 18.330000000000013s
#
# 275
# Epoch duration =0.73s
# Cumulative duration =3min 19.060000000000002s
#
# 276
# Epoch duration =0.73s
# Cumulative duration =3min 19.789999999999992s
#
# 277
# Epoch duration =0.72s
# Cumulative duration =3min 20.50999999999999s
#
# 278
# Epoch duration =0.72s
# Cumulative duration =3min 21.22999999999999s
#
# 279
# Epoch duration =0.72s
# Cumulative duration =3min 21.94999999999999s
#
# 280
# Epoch duration =0.72s
# Cumulative duration =3min 22.669999999999987s
#
# 281
# Epoch duration =0.72s
# Cumulative duration =3min 23.389999999999986s
#
# 282
# Epoch duration =0.72s
# Cumulative duration =3min 24.110000000000014s
#
# 283
# Epoch duration =0.72s
# Cumulative duration =3min 24.830000000000013s
#
# 284
# Epoch duration =0.72s
# Cumulative duration =3min 25.55000000000001s
#
# 285
# Epoch duration =0.72s
# Cumulative duration =3min 26.27000000000001s
#
# 286
# Epoch duration =0.76s
# Cumulative duration =3min 27.02000000000001s
#
# 287
# Epoch duration =0.73s
# Cumulative duration =3min 27.75s
#
# 288
# Epoch duration =0.72s
# Cumulative duration =3min 28.47s
#
# 289
# Epoch duration =0.72s
# Cumulative duration =3min 29.19999999999999s
#
# 290
# Epoch duration =0.71s
# Cumulative duration =3min 29.909999999999997s
#
# 291
# Epoch duration =0.72s
# Cumulative duration =3min 30.629999999999995s
#
# 292
# Epoch duration =0.71s
# Cumulative duration =3min 31.349999999999994s
#
# 293
# Epoch duration =0.71s
# Cumulative duration =3min 32.06s
#
# 294
# Epoch duration =0.72s
# Cumulative duration =3min 32.78s
#
# 295
# Epoch duration =0.72s
# Cumulative duration =3min 33.5s
#
# 296
# Epoch duration =0.72s
# Cumulative duration =3min 34.22s
#
# 297
# Epoch duration =0.75s
# Cumulative duration =3min 34.97s
#
# 298
# Epoch duration =0.72s
# Cumulative duration =3min 35.69s
#
# 299
# Epoch duration =0.73s
# Cumulative duration =3min 36.41s
#
# 300
# Epoch duration =0.73s
# Cumulative duration =3min 37.150000000000006s
#
# 301
# Epoch duration =0.73s
# Cumulative duration =3min 37.870000000000005s
#
# 302
# Epoch duration =0.72s
# Cumulative duration =3min 38.59s
#
# 303
# Epoch duration =0.73s
# Cumulative duration =3min 39.31999999999999s
#
# 304
# Epoch duration =0.72s
# Cumulative duration =3min 40.03999999999999s
#
# 305
# Epoch duration =0.72s
# Cumulative duration =3min 40.75999999999999s
#
# 306
# Epoch duration =0.72s
# Cumulative duration =3min 41.47999999999999s
#
# 307
# Epoch duration =0.72s
# Cumulative duration =3min 42.19999999999999s
#
# 308
# Epoch duration =0.72s
# Cumulative duration =3min 42.91999999999999s
#
# 309
# Epoch duration =0.72s
# Cumulative duration =3min 43.639999999999986s
#
# 310
# Epoch duration =0.72s
# Cumulative duration =3min 44.360000000000014s
#
# 311
# Epoch duration =0.72s
# Cumulative duration =3min 45.08000000000001s
#
# 312
# Epoch duration =0.72s
# Cumulative duration =3min 45.80000000000001s
#
# 313
# Epoch duration =0.72s
# Cumulative duration =3min 46.50999999999999s
#
# 314
# Epoch duration =0.72s
# Cumulative duration =3min 47.22999999999999s
#
# 315
# Epoch duration =0.71s
# Cumulative duration =3min 47.94999999999999s
#
# 316
# Epoch duration =0.72s
# Cumulative duration =3min 48.66999999999999s
#
# 317
# Epoch duration =0.72s
# Cumulative duration =3min 49.379999999999995s
#
# 318
# Epoch duration =0.72s
# Cumulative duration =3min 50.110000000000014s
#
# 319
# Epoch duration =0.72s
# Cumulative duration =3min 50.83000000000001s
#
# 320
# Epoch duration =0.72s
# Cumulative duration =3min 51.55000000000001s
#
# 321
# Epoch duration =0.72s
# Cumulative duration =3min 52.27000000000001s
#
# 322
# Epoch duration =0.72s
# Cumulative duration =3min 52.99000000000001s
#
# 323
# Epoch duration =0.73s
# Cumulative duration =3min 53.71000000000001s
#
# 324
# Epoch duration =0.75s
# Cumulative duration =3min 54.46000000000001s
#
# 325
# Epoch duration =0.72s
# Cumulative duration =3min 55.18000000000001s
#
# 326
# Epoch duration =0.71s
# Cumulative duration =3min 55.889999999999986s
#
# 327
# Epoch duration =0.73s
# Cumulative duration =3min 56.620000000000005s
#
# 328
# Epoch duration =0.72s
# Cumulative duration =3min 57.34s
#
# 329
# Epoch duration =0.72s
# Cumulative duration =3min 58.06s
#
# 330
# Epoch duration =0.72s
# Cumulative duration =3min 58.78999999999999s
#
# 331
# Epoch duration =0.71s
# Cumulative duration =3min 59.5s
#
# 332
# Epoch duration =0.72s
# Cumulative duration =4min 0.21999999999999886s
#
# 333
# Epoch duration =0.72s
# Cumulative duration =4min 0.9399999999999977s
#
# 334
# Epoch duration =0.73s
# Cumulative duration =4min 1.6800000000000068s
#
# 335
# Epoch duration =0.72s
# Cumulative duration =4min 2.3899999999999864s
#
# 336
# Epoch duration =0.72s
# Cumulative duration =4min 3.1200000000000045s
#
# 337
# Epoch duration =0.72s
# Cumulative duration =4min 3.8300000000000125s
#
# 338
# Epoch duration =0.74s
# Cumulative duration =4min 4.5800000000000125s
#
# 339
# Epoch duration =0.74s
# Cumulative duration =4min 5.310000000000002s
#
# 340
# Epoch duration =0.72s
# Cumulative duration =4min 6.030000000000001s
#
# 341
# Epoch duration =0.73s
# Cumulative duration =4min 6.77000000000001s
#
# 342
# Epoch duration =0.72s
# Cumulative duration =4min 7.47999999999999s
#
# 343
# Epoch duration =0.72s
# Cumulative duration =4min 8.199999999999989s
#
# 344
# Epoch duration =0.72s
# Cumulative duration =4min 8.919999999999987s
#
# 345
# Epoch duration =0.72s
# Cumulative duration =4min 9.629999999999995s
#
# 346
# Epoch duration =0.72s
# Cumulative duration =4min 10.360000000000014s
#
# 347
# Epoch duration =0.72s
# Cumulative duration =4min 11.080000000000013s
#
# 348
# Epoch duration =0.71s
# Cumulative duration =4min 11.789999999999992s
#
# 349
# Epoch duration =0.72s
# Cumulative duration =4min 12.509999999999991s
#
# 350
# Epoch duration =0.74s
# Cumulative duration =4min 13.25s
#
# 351
# Epoch duration =0.72s
# Cumulative duration =4min 13.960000000000008s
#
# 352
# Epoch duration =0.73s
# Cumulative duration =4min 14.689999999999998s
#
# 353
# Epoch duration =0.73s
# Cumulative duration =4min 15.419999999999987s
#
# 354
# Epoch duration =0.72s
# Cumulative duration =4min 16.139999999999986s
#
# 355
# Epoch duration =0.73s
# Cumulative duration =4min 16.870000000000005s
#
# 356
# Epoch duration =0.72s
# Cumulative duration =4min 17.589999999999975s
#
# 357
# Epoch duration =0.74s
# Cumulative duration =4min 18.329999999999984s
#
# 358
# Epoch duration =0.72s
# Cumulative duration =4min 19.05000000000001s
#
# 359
# Epoch duration =0.73s
# Cumulative duration =4min 19.779999999999973s
#
# 360
# Epoch duration =0.72s
# Cumulative duration =4min 20.5s
#
# 361
# Epoch duration =0.73s
# Cumulative duration =4min 21.230000000000018s
#
# 362
# Epoch duration =0.72s
# Cumulative duration =4min 21.94999999999999s
#
# 363
# Epoch duration =0.72s
# Cumulative duration =4min 22.670000000000016s
#
# 364
# Epoch duration =0.72s
# Cumulative duration =4min 23.389999999999986s
#
# 365
# Epoch duration =0.75s
# Cumulative duration =4min 24.129999999999995s
#
# 366
# Epoch duration =0.72s
# Cumulative duration =4min 24.860000000000014s
#
# 367
# Epoch duration =0.72s
# Cumulative duration =4min 25.569999999999993s
#
# 368
# Epoch duration =0.72s
# Cumulative duration =4min 26.29000000000002s
#
# 369
# Epoch duration =0.72s
# Cumulative duration =4min 27.019999999999982s
#
# 370
# Epoch duration =0.72s
# Cumulative duration =4min 27.730000000000018s
#
# 371
# Epoch duration =0.72s
# Cumulative duration =4min 28.44999999999999s
#
# 372
# Epoch duration =0.72s
# Cumulative duration =4min 29.170000000000016s
#
# 373
# Epoch duration =0.72s
# Cumulative duration =4min 29.889999999999986s
#
# 374
# Epoch duration =0.72s
# Cumulative duration =4min 30.610000000000014s
#
# 375
# Epoch duration =0.73s
# Cumulative duration =4min 31.339999999999975s
#
# 376
# Epoch duration =0.73s
# Cumulative duration =4min 32.06999999999999s
#
# 377
# Epoch duration =0.72s
# Cumulative duration =4min 32.77999999999997s
#
# 378
# Epoch duration =0.72s
# Cumulative duration =4min 33.50999999999999s
#
# 379
# Epoch duration =0.73s
# Cumulative duration =4min 34.23000000000002s
#
# 380
# Epoch duration =0.72s
# Cumulative duration =4min 34.95999999999998s
#
# 381
# Epoch duration =0.72s
# Cumulative duration =4min 35.68000000000001s
#
# 382
# Epoch duration =0.76s
# Cumulative duration =4min 36.43000000000001s
#
# 383
# Epoch duration =0.72s
# Cumulative duration =4min 37.14999999999998s
#
# 384
# Epoch duration =0.72s
# Cumulative duration =4min 37.870000000000005s
#
# 385
# Epoch duration =0.73s
# Cumulative duration =4min 38.60000000000002s
#
# 386
# Epoch duration =0.72s
# Cumulative duration =4min 39.31999999999999s
#
# 387
# Epoch duration =0.72s
# Cumulative duration =4min 40.04000000000002s
#
# 388
# Epoch duration =0.72s
# Cumulative duration =4min 40.75999999999999s
#
# 389
# Epoch duration =0.72s
# Cumulative duration =4min 41.48000000000002s
#
# 390
# Epoch duration =0.72s
# Cumulative duration =4min 42.19999999999999s
#
# 391
# Epoch duration =0.72s
# Cumulative duration =4min 42.920000000000016s
#
# 392
# Epoch duration =0.71s
# Cumulative duration =4min 43.629999999999995s
#
# 393
# Epoch duration =0.73s
# Cumulative duration =4min 44.360000000000014s
#
# 394
# Epoch duration =0.72s
# Cumulative duration =4min 45.079999999999984s
#
# 395
# Epoch duration =0.74s
# Cumulative duration =4min 45.829999999999984s
#
# 396
# Epoch duration =0.72s
# Cumulative duration =4min 46.54000000000002s
#
# 397
# Epoch duration =0.72s
# Cumulative duration =4min 47.26999999999998s
#
# 398
# Epoch duration =0.72s
# Cumulative duration =4min 47.98000000000002s
#
# 399
# Epoch duration =0.72s
# Cumulative duration =4min 48.69999999999999s
#
# 400
# Epoch duration =0.72s
# Cumulative duration =4min 49.420000000000016s
#
# 401
# Epoch duration =0.72s
# Cumulative duration =4min 50.14999999999998s
#
# 402
# Epoch duration =0.72s
# Cumulative duration =4min 50.870000000000005s
#
# 403
# Epoch duration =0.72s
# Cumulative duration =4min 51.589999999999975s
#
# 404
# Epoch duration =0.72s
# Cumulative duration =4min 52.31999999999999s
#
# 405
# Epoch duration =0.72s
# Cumulative duration =4min 53.04000000000002s
#
# 406
# Epoch duration =0.73s
# Cumulative duration =4min 53.76999999999998s
#
# 407
# Epoch duration =0.72s
# Cumulative duration =4min 54.49000000000001s
#
# 408
# Epoch duration =0.74s
# Cumulative duration =4min 55.23000000000002s
#
# 409
# Epoch duration =0.72s
# Cumulative duration =4min 55.94999999999999s
#
# 410
# Epoch duration =0.74s
# Cumulative duration =4min 56.69s
#
# 411
# Epoch duration =0.71s
# Cumulative duration =4min 57.39999999999998s
#
# 412
# Epoch duration =0.72s
# Cumulative duration =4min 58.120000000000005s
#
# 413
# Epoch duration =0.72s
# Cumulative duration =4min 58.839999999999975s
#
# 414
# Epoch duration =0.74s
# Cumulative duration =4min 59.579999999999984s
#
# 415
# Epoch duration =0.72s
# Cumulative duration =5min 0.30000000000001137s
#
# 416
# Epoch duration =0.74s
# Cumulative duration =5min 1.0299999999999727s
#
# 417
# Epoch duration =0.72s
# Cumulative duration =5min 1.759999999999991s
#
# 418
# Epoch duration =0.73s
# Cumulative duration =5min 2.490000000000009s
#
# 419
# Epoch duration =0.73s
# Cumulative duration =5min 3.2200000000000273s
#
# 420
# Epoch duration =0.72s
# Cumulative duration =5min 3.9399999999999977s
#
# 421
# Epoch duration =0.72s
# Cumulative duration =5min 4.649999999999977s
#
# 422
# Epoch duration =0.71s
# Cumulative duration =5min 5.3700000000000045s
#
# 423
# Epoch duration =0.75s
# Cumulative duration =5min 6.1200000000000045s
#
# 424
# Epoch duration =0.72s
# Cumulative duration =5min 6.839999999999975s
#
# 425
# Epoch duration =0.72s
# Cumulative duration =5min 7.560000000000002s
#
# 426
# Epoch duration =0.72s
# Cumulative duration =5min 8.279999999999973s
#
# 427
# Epoch duration =0.72s
# Cumulative duration =5min 9.0s
#
# 428
# Epoch duration =0.72s
# Cumulative duration =5min 9.720000000000027s
#
# 429
# Epoch duration =0.72s
# Cumulative duration =5min 10.439999999999998s
#
# 430
# Epoch duration =0.72s
# Cumulative duration =5min 11.160000000000025s
#
# 431
# Epoch duration =0.73s
# Cumulative duration =5min 11.889999999999986s
#
# 432
# Epoch duration =0.72s
# Cumulative duration =5min 12.600000000000023s
#
# 433
# Epoch duration =0.72s
# Cumulative duration =5min 13.319999999999993s
#
# 434
# Epoch duration =0.72s
# Cumulative duration =5min 14.04000000000002s
#
# 435
# Epoch duration =0.72s
# Cumulative duration =5min 14.759999999999991s
#
# 436
# Epoch duration =0.72s
# Cumulative duration =5min 15.480000000000018s
#
# 437
# Epoch duration =0.72s
# Cumulative duration =5min 16.19999999999999s
#
# 438
# Epoch duration =0.72s
# Cumulative duration =5min 16.920000000000016s
#
# 439
# Epoch duration =0.72s
# Cumulative duration =5min 17.639999999999986s
#
# 440
# Epoch duration =0.72s
# Cumulative duration =5min 18.360000000000014s
#
# 441
# Epoch duration =0.71s
# Cumulative duration =5min 19.069999999999993s
#
# 442
# Epoch duration =0.75s
# Cumulative duration =5min 19.819999999999993s
#
# 443
# Epoch duration =0.72s
# Cumulative duration =5min 20.54000000000002s
#
# 444
# Epoch duration =0.72s
# Cumulative duration =5min 21.25999999999999s
#
# 445
# Epoch duration =0.72s
# Cumulative duration =5min 21.980000000000018s
#
# 446
# Epoch duration =0.72s
# Cumulative duration =5min 22.689999999999998s
#
# 447
# Epoch duration =0.73s
# Cumulative duration =5min 23.420000000000016s
#
# 448
# Epoch duration =0.72s
# Cumulative duration =5min 24.139999999999986s
#
# 449
# Epoch duration =0.72s
# Cumulative duration =5min 24.850000000000023s
#
# 450
# Epoch duration =0.72s
# Cumulative duration =5min 25.569999999999993s
#
# 451
# Epoch duration =0.72s
# Cumulative duration =5min 26.29000000000002s
#
# 452
# Epoch duration =0.75s
# Cumulative duration =5min 27.04000000000002s
#
# 453
# Epoch duration =0.72s
# Cumulative duration =5min 27.75999999999999s
#
# 454
# Epoch duration =0.73s
# Cumulative duration =5min 28.5s
#
# 455
# Epoch duration =0.71s
# Cumulative duration =5min 29.20999999999998s
#
# 456
# Epoch duration =0.72s
# Cumulative duration =5min 29.930000000000007s
#
# 457
# Epoch duration =0.72s
# Cumulative duration =5min 30.649999999999977s
#
# 458
# Epoch duration =0.72s
# Cumulative duration =5min 31.370000000000005s
#
# 459
# Epoch duration =0.72s
# Cumulative duration =5min 32.089999999999975s
#
# 460
# Epoch duration =0.72s
# Cumulative duration =5min 32.81999999999999s
#
# 461
# Epoch duration =0.72s
# Cumulative duration =5min 33.54000000000002s
#
# 462
# Epoch duration =0.72s
# Cumulative duration =5min 34.25999999999999s
#
# 463
# Epoch duration =0.74s
# Cumulative duration =5min 35.0s
#
# 464
# Epoch duration =0.72s
# Cumulative duration =5min 35.72000000000003s
#
# 465
# Epoch duration =0.72s
# Cumulative duration =5min 36.44s
#
# 466
# Epoch duration =0.72s
# Cumulative duration =5min 37.160000000000025s
#
# 467
# Epoch duration =0.72s
# Cumulative duration =5min 37.879999999999995s
#
# 468
# Epoch duration =0.71s
# Cumulative duration =5min 38.589999999999975s
#
# 469
# Epoch duration =0.72s
# Cumulative duration =5min 39.31s
#
# 470
# Epoch duration =0.72s
# Cumulative duration =5min 40.04000000000002s
#
# 471
# Epoch duration =0.73s
# Cumulative duration =5min 40.75999999999999s
#
# 472
# Epoch duration =0.72s
# Cumulative duration =5min 41.48000000000002s
#
# 473
# Epoch duration =0.72s
# Cumulative duration =5min 42.20999999999998s
#
# 474
# Epoch duration =0.72s
# Cumulative duration =5min 42.920000000000016s
#
# 475
# Epoch duration =0.72s
# Cumulative duration =5min 43.639999999999986s
#
# 476
# Epoch duration =0.72s
# Cumulative duration =5min 44.360000000000014s
#
# 477
# Epoch duration =0.72s
# Cumulative duration =5min 45.079999999999984s
#
# 478
# Epoch duration =0.72s
# Cumulative duration =5min 45.80000000000001s
#
# 479
# Epoch duration =0.72s
# Cumulative duration =5min 46.51999999999998s
#
# 480
# Epoch duration =0.72s
# Cumulative duration =5min 47.24000000000001s
#
# 481
# Epoch duration =0.75s
# Cumulative duration =5min 47.99000000000001s
#
# 482
# Epoch duration =0.72s
# Cumulative duration =5min 48.72000000000003s
#
# 483
# Epoch duration =0.73s
# Cumulative duration =5min 49.44999999999999s
#
# 484
# Epoch duration =0.72s
# Cumulative duration =5min 50.170000000000016s
#
# 485
# Epoch duration =0.72s
# Cumulative duration =5min 50.89999999999998s
#
# 486
# Epoch duration =0.72s
# Cumulative duration =5min 51.620000000000005s
#
# 487
# Epoch duration =0.75s
# Cumulative duration =5min 52.360000000000014s
#
# 488
# Epoch duration =0.73s
# Cumulative duration =5min 53.089999999999975s
#
# 489
# Epoch duration =0.75s
# Cumulative duration =5min 53.839999999999975s
#
# 490
# Epoch duration =0.72s
# Cumulative duration =5min 54.56s
#
# 491
# Epoch duration =0.72s
# Cumulative duration =5min 55.27999999999997s
#
# 492
# Epoch duration =0.72s
# Cumulative duration =5min 56.0s
#
# 493
# Epoch duration =0.72s
# Cumulative duration =5min 56.72000000000003s
#
# 494
# Epoch duration =0.73s
# Cumulative duration =5min 57.44999999999999s
#
# 495
# Epoch duration =0.72s
# Cumulative duration =5min 58.170000000000016s
#
# 496
# Epoch duration =0.71s
# Cumulative duration =5min 58.879999999999995s
#
# 497
# Epoch duration =0.73s
# Cumulative duration =5min 59.610000000000014s
#
# 498
# Epoch duration =0.73s
# Cumulative duration =6min 0.339999999999975s
#
# 499
# Epoch duration =0.72s
# Cumulative duration =6min 1.0600000000000023s
#
# 500
# Epoch duration =0.73s
# Cumulative duration =6min 1.7900000000000205s
#
# 501
# Epoch duration =0.72s
# Cumulative duration =6min 2.509999999999991s
#
# 502
# Epoch duration =0.72s
# Cumulative duration =6min 3.230000000000018s
#
# 503
# Epoch duration =0.72s
# Cumulative duration =6min 3.9399999999999977s
#
# 504
# Epoch duration =0.72s
# Cumulative duration =6min 4.670000000000016s
#
# 505
# Epoch duration =0.72s
# Cumulative duration =6min 5.389999999999986s
#
# 506
# Epoch duration =0.72s
# Cumulative duration =6min 6.110000000000014s
#
# 507
# Epoch duration =0.71s
# Cumulative duration =6min 6.819999999999993s
#
# 508
# Epoch duration =0.73s
# Cumulative duration =6min 7.560000000000002s
#
# 509
# Epoch duration =0.73s
# Cumulative duration =6min 8.279999999999973s
#
# 510
# Epoch duration =0.72s
# Cumulative duration =6min 9.0s
#
# 511
# Epoch duration =0.72s
# Cumulative duration =6min 9.730000000000018s
#
# 512
# Epoch duration =0.74s
# Cumulative duration =6min 10.45999999999998s
#
# 513
# Epoch duration =0.72s
# Cumulative duration =6min 11.189999999999998s
#
# 514
# Epoch duration =0.72s
# Cumulative duration =6min 11.899999999999977s
#
# 515
# Epoch duration =0.73s
# Cumulative duration =6min 12.629999999999995s
#
# 516
# Epoch duration =0.74s
# Cumulative duration =6min 13.370000000000005s
#
# 517
# Epoch duration =0.72s
# Cumulative duration =6min 14.089999999999975s
#
# 518
# Epoch duration =0.71s
# Cumulative duration =6min 14.810000000000002s
#
# 519
# Epoch duration =0.73s
# Cumulative duration =6min 15.54000000000002s
#
# 520
# Epoch duration =0.72s
# Cumulative duration =6min 16.25999999999999s
#
# 521
# Epoch duration =0.72s
# Cumulative duration =6min 16.980000000000018s
#
# 522
# Epoch duration =0.72s
# Cumulative duration =6min 17.689999999999998s
#
# 523
# Epoch duration =0.72s
# Cumulative duration =6min 18.410000000000025s
#
# 524
# Epoch duration =0.72s
# Cumulative duration =6min 19.139999999999986s
#
# 525
# Epoch duration =0.72s
# Cumulative duration =6min 19.860000000000014s
#
# 526
# Epoch duration =0.72s
# Cumulative duration =6min 20.579999999999984s
#
# 527
# Epoch duration =0.72s
# Cumulative duration =6min 21.30000000000001s
#
# 528
# Epoch duration =0.72s
# Cumulative duration =6min 22.019999999999982s
#
# 529
# Epoch duration =0.71s
# Cumulative duration =6min 22.74000000000001s
#
# 530
# Epoch duration =0.73s
# Cumulative duration =6min 23.470000000000027s
#
# 531
# Epoch duration =0.72s
# Cumulative duration =6min 24.180000000000007s
#
# 532
# Epoch duration =0.73s
# Cumulative duration =6min 24.910000000000025s
#
# 533
# Epoch duration =0.72s
# Cumulative duration =6min 25.629999999999995s
#
# 534
# Epoch duration =0.73s
# Cumulative duration =6min 26.360000000000014s
#
# 535
# Epoch duration =0.72s
# Cumulative duration =6min 27.079999999999984s
#
# 536
# Epoch duration =0.72s
# Cumulative duration =6min 27.810000000000002s
#
# 537
# Epoch duration =0.72s
# Cumulative duration =6min 28.529999999999973s
#
# 538
# Epoch duration =0.72s
# Cumulative duration =6min 29.25s
#
# 539
# Epoch duration =0.72s
# Cumulative duration =6min 29.970000000000027s
#
# 540
# Epoch duration =0.71s
# Cumulative duration =6min 30.680000000000007s
#
# 541
# Epoch duration =0.72s
# Cumulative duration =6min 31.399999999999977s
#
# 542
# Epoch duration =0.72s
# Cumulative duration =6min 32.120000000000005s
#
# 543
# Epoch duration =0.72s
# Cumulative duration =6min 32.839999999999975s
#
# 544
# Epoch duration =0.73s
# Cumulative duration =6min 33.56999999999999s
#
# 545
# Epoch duration =0.72s
# Cumulative duration =6min 34.29000000000002s
#
# 546
# Epoch duration =0.72s
# Cumulative duration =6min 35.00999999999999s
#
# 547
# Epoch duration =0.73s
# Cumulative duration =6min 35.73000000000002s
#
# 548
# Epoch duration =0.72s
# Cumulative duration =6min 36.44999999999999s
#
# 549
# Epoch duration =0.75s
# Cumulative duration =6min 37.19999999999999s
#
# 550
# Epoch duration =0.72s
# Cumulative duration =6min 37.920000000000016s
#
# 551
# Epoch duration =0.72s
# Cumulative duration =6min 38.629999999999995s
#
# 552
# Epoch duration =0.72s
# Cumulative duration =6min 39.360000000000014s
#
# 553
# Epoch duration =0.72s
# Cumulative duration =6min 40.079999999999984s
#
# 554
# Epoch duration =0.72s
# Cumulative duration =6min 40.80000000000001s
#
# 555
# Epoch duration =0.72s
# Cumulative duration =6min 41.52999999999997s
#
# 556
# Epoch duration =0.72s
# Cumulative duration =6min 42.24000000000001s
#
# 557
# Epoch duration =0.72s
# Cumulative duration =6min 42.95999999999998s
#
# 558
# Epoch duration =0.74s
# Cumulative duration =6min 43.70999999999998s
#
# 559
# Epoch duration =0.72s
# Cumulative duration =6min 44.420000000000016s
#
# 560
# Epoch duration =0.72s
# Cumulative duration =6min 45.139999999999986s
#
# 561
# Epoch duration =0.72s
# Cumulative duration =6min 45.860000000000014s
#
# 562
# Epoch duration =0.72s
# Cumulative duration =6min 46.579999999999984s
#
# 563
# Epoch duration =0.72s
# Cumulative duration =6min 47.30000000000001s
#
# 564
# Epoch duration =0.72s
# Cumulative duration =6min 48.02999999999997s
#
# 565
# Epoch duration =0.72s
# Cumulative duration =6min 48.75s
#
# 566
# Epoch duration =0.72s
# Cumulative duration =6min 49.47000000000003s
#
# 567
# Epoch duration =0.72s
# Cumulative duration =6min 50.18000000000001s
#
# 568
# Epoch duration =0.72s
# Cumulative duration =6min 50.89999999999998s
#
# 569
# Epoch duration =0.72s
# Cumulative duration =6min 51.629999999999995s
#
# 570
# Epoch duration =0.72s
# Cumulative duration =6min 52.35000000000002s
#
# 571
# Epoch duration =0.74s
# Cumulative duration =6min 53.089999999999975s
#
# 572
# Epoch duration =0.72s
# Cumulative duration =6min 53.81999999999999s
#
# 573
# Epoch duration =0.72s
# Cumulative duration =6min 54.54000000000002s
#
# 574
# Epoch duration =0.73s
# Cumulative duration =6min 55.26999999999998s
#
# 575
# Epoch duration =0.73s
# Cumulative duration =6min 56.0s
#
# 576
# Epoch duration =0.72s
# Cumulative duration =6min 56.72000000000003s
#
# 577
# Epoch duration =0.72s
# Cumulative duration =6min 57.44s
#
# 578
# Epoch duration =0.72s
# Cumulative duration =6min 58.160000000000025s
#
# 579
# Epoch duration =0.72s
# Cumulative duration =6min 58.879999999999995s
#
# 580
# Epoch duration =0.72s
# Cumulative duration =6min 59.60000000000002s
#
# 581
# Epoch duration =0.72s
# Cumulative duration =7min 0.3199999999999932s
#
# 582
# Epoch duration =0.73s
# Cumulative duration =7min 1.0500000000000114s
#
# 583
# Epoch duration =0.72s
# Cumulative duration =7min 1.7699999999999818s
#
# 584
# Epoch duration =0.72s
# Cumulative duration =7min 2.490000000000009s
#
# 585
# Epoch duration =0.72s
# Cumulative duration =7min 3.2099999999999795s
#
# 586
# Epoch duration =0.72s
# Cumulative duration =7min 3.930000000000007s
#
# 587
# Epoch duration =0.72s
# Cumulative duration =7min 4.649999999999977s
#
# 588
# Epoch duration =0.72s
# Cumulative duration =7min 5.3700000000000045s
#
# 589
# Epoch duration =0.72s
# Cumulative duration =7min 6.089999999999975s
#
# 590
# Epoch duration =0.75s
# Cumulative duration =7min 6.839999999999975s
#
# 591
# Epoch duration =0.73s
# Cumulative duration =7min 7.569999999999993s
#
# 592
# Epoch duration =0.71s
# Cumulative duration =7min 8.279999999999973s
#
# 593
# Epoch duration =0.72s
# Cumulative duration =7min 9.0s
#
# 594
# Epoch duration =0.72s
# Cumulative duration =7min 9.720000000000027s
#
# 595
# Epoch duration =0.74s
# Cumulative duration =7min 10.45999999999998s
#
# 596
# Epoch duration =0.72s
# Cumulative duration =7min 11.180000000000007s
#
# 597
# Epoch duration =0.72s
# Cumulative duration =7min 11.899999999999977s
#
# 598
# Epoch duration =0.72s
# Cumulative duration =7min 12.620000000000005s
#
# 599
# Epoch duration =0.72s
# Cumulative duration =7min 13.339999999999975s
#
# 600
# Epoch duration =0.72s
# Cumulative duration =7min 14.060000000000002s
#
# 601
# Epoch duration =0.72s
# Cumulative duration =7min 14.779999999999973s
#
# 602
# Epoch duration =0.72s
# Cumulative duration =7min 15.5s
#
# 603
# Epoch duration =0.72s
# Cumulative duration =7min 16.20999999999998s
#
# 604
# Epoch duration =0.73s
# Cumulative duration =7min 16.939999999999998s
#
# 605
# Epoch duration =0.72s
# Cumulative duration =7min 17.660000000000025s
#
# 606
# Epoch duration =0.71s
# Cumulative duration =7min 18.370000000000005s
#
# 607
# Epoch duration =0.72s
# Cumulative duration =7min 19.089999999999975s
#
# 608
# Epoch duration =0.72s
# Cumulative duration =7min 19.810000000000002s
#
# 609
# Epoch duration =0.72s
# Cumulative duration =7min 20.529999999999973s
#
# 610
# Epoch duration =0.72s
# Cumulative duration =7min 21.25s
#
# 611
# Epoch duration =0.72s
# Cumulative duration =7min 21.970000000000027s
#
# 612
# Epoch duration =0.72s
# Cumulative duration =7min 22.680000000000007s
#
# 613
# Epoch duration =0.72s
# Cumulative duration =7min 23.399999999999977s
#
# 614
# Epoch duration =0.72s
# Cumulative duration =7min 24.120000000000005s
#
# 615
# Epoch duration =0.72s
# Cumulative duration =7min 24.839999999999975s
#
# 616
# Epoch duration =0.72s
# Cumulative duration =7min 25.560000000000002s
#
# 617
# Epoch duration =0.72s
# Cumulative duration =7min 26.279999999999973s
#
# 618
# Epoch duration =0.73s
# Cumulative duration =7min 27.00999999999999s
#
# 619
# Epoch duration =0.74s
# Cumulative duration =7min 27.75s
#
# 620
# Epoch duration =0.72s
# Cumulative duration =7min 28.470000000000027s
#
# 621
# Epoch duration =0.72s
# Cumulative duration =7min 29.189999999999998s
#
# 622
# Epoch duration =0.72s
# Cumulative duration =7min 29.910000000000025s
#
# 623
# Epoch duration =0.72s
# Cumulative duration =7min 30.629999999999995s
#
# 624
# Epoch duration =0.74s
# Cumulative duration =7min 31.370000000000005s
#
# 625
# Epoch duration =0.72s
# Cumulative duration =7min 32.089999999999975s
#
# 626
# Epoch duration =0.72s
# Cumulative duration =7min 32.81s
#
# 627
# Epoch duration =0.72s
# Cumulative duration =7min 33.52999999999997s
#
# 628
# Epoch duration =0.74s
# Cumulative duration =7min 34.26999999999998s
#
# 629
# Epoch duration =0.74s
# Cumulative duration =7min 35.00999999999999s
#
# 630
# Epoch duration =0.72s
# Cumulative duration =7min 35.72000000000003s
#
# 631
# Epoch duration =0.72s
# Cumulative duration =7min 36.44s
#
# 632
# Epoch duration =0.72s
# Cumulative duration =7min 37.160000000000025s
#
# 633
# Epoch duration =0.73s
# Cumulative duration =7min 37.889999999999986s
#
# 634
# Epoch duration =0.72s
# Cumulative duration =7min 38.610000000000014s
#
# 635
# Epoch duration =0.72s
# Cumulative duration =7min 39.339999999999975s
#
# 636
# Epoch duration =0.72s
# Cumulative duration =7min 40.05000000000001s
#
# 637
# Epoch duration =0.72s
# Cumulative duration =7min 40.76999999999998s
#
# 638
# Epoch duration =0.72s
# Cumulative duration =7min 41.49000000000001s
#
# 639
# Epoch duration =0.72s
# Cumulative duration =7min 42.19999999999999s
#
# 640
# Epoch duration =0.72s
# Cumulative duration =7min 42.920000000000016s
#
# 641
# Epoch duration =0.72s
# Cumulative duration =7min 43.639999999999986s
#
# 642
# Epoch duration =0.71s
# Cumulative duration =7min 44.35000000000002s
#
# 643
# Epoch duration =0.72s
# Cumulative duration =7min 45.06999999999999s
#
# 644
# Epoch duration =0.72s
# Cumulative duration =7min 45.79000000000002s
#
# 645
# Epoch duration =0.72s
# Cumulative duration =7min 46.50999999999999s
#
# 646
# Epoch duration =0.73s
# Cumulative duration =7min 47.23000000000002s
#
# 647
# Epoch duration =0.73s
# Cumulative duration =7min 47.95999999999998s
#
# 648
# Epoch duration =0.72s
# Cumulative duration =7min 48.68000000000001s
#
# 649
# Epoch duration =0.72s
# Cumulative duration =7min 49.39999999999998s
#
# 650
# Epoch duration =0.72s
# Cumulative duration =7min 50.110000000000014s
#
# 651
# Epoch duration =0.72s
# Cumulative duration =7min 50.839999999999975s
#
# 652
# Epoch duration =0.73s
# Cumulative duration =7min 51.56999999999999s
#
# 653
# Epoch duration =0.72s
# Cumulative duration =7min 52.29000000000002s
#
# 654
# Epoch duration =0.72s
# Cumulative duration =7min 53.0s
#
# 655
# Epoch duration =0.72s
# Cumulative duration =7min 53.72000000000003s
#
# 656
# Epoch duration =0.74s
# Cumulative duration =7min 54.45999999999998s
#
# 657
# Epoch duration =0.72s
# Cumulative duration =7min 55.18000000000001s
#
# 658
# Epoch duration =0.72s
# Cumulative duration =7min 55.89999999999998s
#
# 659
# Epoch duration =0.72s
# Cumulative duration =7min 56.629999999999995s
#
# 660
# Epoch duration =0.72s
# Cumulative duration =7min 57.35000000000002s
#
# 661
# Epoch duration =0.72s
# Cumulative duration =7min 58.06s
#
# 662
# Epoch duration =0.73s
# Cumulative duration =7min 58.79000000000002s
#
# 663
# Epoch duration =0.72s
# Cumulative duration =7min 59.5s
#
# 664
# Epoch duration =0.73s
# Cumulative duration =8min 0.2400000000000091s
#
# 665
# Epoch duration =0.72s
# Cumulative duration =8min 0.9599999999999795s
#
# 666
# Epoch duration =0.72s
# Cumulative duration =8min 1.6800000000000068s
#
# 667
# Epoch duration =0.72s
# Cumulative duration =8min 2.3999999999999773s
#
# 668
# Epoch duration =0.72s
# Cumulative duration =8min 3.1200000000000045s
#
# 669
# Epoch duration =0.72s
# Cumulative duration =8min 3.829999999999984s
#
# 670
# Epoch duration =0.72s
# Cumulative duration =8min 4.550000000000011s
#
# 671
# Epoch duration =0.72s
# Cumulative duration =8min 5.279999999999973s
#
# 672
# Epoch duration =0.72s
# Cumulative duration =8min 5.990000000000009s
#
# 673
# Epoch duration =0.72s
# Cumulative duration =8min 6.7099999999999795s
#
# 674
# Epoch duration =0.71s
# Cumulative duration =8min 7.430000000000007s
#
# 675
# Epoch duration =0.72s
# Cumulative duration =8min 8.149999999999977s
#
# 676
# Epoch duration =0.72s
# Cumulative duration =8min 8.870000000000005s
#
# 677
# Epoch duration =0.72s
# Cumulative duration =8min 9.579999999999984s
#
# 678
# Epoch duration =0.72s
# Cumulative duration =8min 10.300000000000011s
#
# 679
# Epoch duration =0.73s
# Cumulative duration =8min 11.029999999999973s
#
# 680
# Epoch duration =0.72s
# Cumulative duration =8min 11.75s
#
# 681
# Epoch duration =0.72s
# Cumulative duration =8min 12.45999999999998s
#
# 682
# Epoch duration =0.74s
# Cumulative duration =8min 13.199999999999989s
#
# 683
# Epoch duration =0.72s
# Cumulative duration =8min 13.920000000000016s
#
# 684
# Epoch duration =0.72s
# Cumulative duration =8min 14.639999999999986s
#
# 685
# Epoch duration =0.75s
# Cumulative duration =8min 15.389999999999986s
#
# 686
# Epoch duration =0.72s
# Cumulative duration =8min 16.110000000000014s
#
# 687
# Epoch duration =0.72s
# Cumulative duration =8min 16.829999999999984s
#
# 688
# Epoch duration =0.72s
# Cumulative duration =8min 17.55000000000001s
#
# 689
# Epoch duration =0.72s
# Cumulative duration =8min 18.269999999999982s
#
# 690
# Epoch duration =0.72s
# Cumulative duration =8min 18.99000000000001s
#
# 691
# Epoch duration =0.72s
# Cumulative duration =8min 19.70999999999998s
#
# 692
# Epoch duration =0.72s
# Cumulative duration =8min 20.420000000000016s
#
# 693
# Epoch duration =0.72s
# ...
# Cumulative duration =21min 30.1099999999999s
#
# 1785
# Epoch duration =0.72s
# Cumulative duration =21min 30.839999999999918s
#
# 1786
# Epoch duration =0.73s
# Cumulative duration =21min 31.559999999999945s
#
# 1787
# Epoch duration =0.72s
# Cumulative duration =21min 32.289999999999964s
#
# 1788
# Epoch duration =0.72s
# Cumulative duration =21min 33.00999999999999s
#
# 1789
# Epoch duration =0.72s
# Cumulative duration =21min 33.74000000000001s
#
# 1790
# Epoch duration =0.73s
# Cumulative duration =21min 34.460000000000036s
#
# 1791
# Epoch duration =0.72s
# Cumulative duration =21min 35.190000000000055s
#
# 1792
# Epoch duration =0.72s
# Cumulative duration =21min 35.90000000000009s
#
# 1793
# Epoch duration =0.73s
# Cumulative duration =21min 36.63000000000011s
#
# 1794
# Epoch duration =0.73s
# Cumulative duration =21min 37.3599999999999s
#
# 1795
# Epoch duration =0.72s
# Cumulative duration =21min 38.07999999999993s
#
# 1796
# Epoch duration =0.72s
# Cumulative duration =21min 38.799999999999955s
#
# 1797
# Epoch duration =0.72s
# Cumulative duration =21min 39.51999999999998s
#
# 1798
# Epoch duration =0.72s
# Cumulative duration =21min 40.24000000000001s
#
# 1799
# Epoch duration =0.72s
# Cumulative duration =21min 40.97000000000003s
#
# 1800
# Epoch duration =0.72s
# Cumulative duration =21min 41.680000000000064s
#
# 1801
# Epoch duration =0.72s
# Cumulative duration =21min 42.40000000000009s
#
# 1802
# Epoch duration =0.72s
# Cumulative duration =21min 43.11999999999989s
#
# 1803
# Epoch duration =0.72s
# Cumulative duration =21min 43.84999999999991s
#
# 1804
# Epoch duration =0.72s
# Cumulative duration =21min 44.569999999999936s
#
# 1805
# Epoch duration =0.72s
# Cumulative duration =21min 45.289999999999964s
#
# 1806
# Epoch duration =0.72s
# Cumulative duration =21min 46.00999999999999s
#
# 1807
# Epoch duration =0.72s
# Cumulative duration =21min 46.73000000000002s
#
# 1808
# Epoch duration =0.72s
# Cumulative duration =21min 47.450000000000045s
#
# 1809
# Epoch duration =0.73s
# Cumulative duration =21min 48.190000000000055s
#
# 1810
# Epoch duration =0.72s
# Cumulative duration =21min 48.91000000000008s
#
# 1811
# Epoch duration =0.72s
# Cumulative duration =21min 49.63000000000011s
#
# 1812
# Epoch duration =0.72s
# Cumulative duration =21min 50.34999999999991s
#
# 1813
# Epoch duration =0.72s
# Cumulative duration =21min 51.07999999999993s
#
# 1814
# Epoch duration =0.72s
# Cumulative duration =21min 51.799999999999955s
#
# 1815
# Epoch duration =0.72s
# Cumulative duration =21min 52.51999999999998s
#
# 1816
# Epoch duration =0.73s
# Cumulative duration =21min 53.25s
#
# 1817
# Epoch duration =0.72s
# Cumulative duration =21min 53.960000000000036s
#
# 1818
# Epoch duration =0.72s
# Cumulative duration =21min 54.680000000000064s
#
# 1819
# Epoch duration =0.73s
# Cumulative duration =21min 55.42000000000007s
#
# 1820
# Epoch duration =0.72s
# Cumulative duration =21min 56.13000000000011s
#
# 1821
# Epoch duration =0.72s
# Cumulative duration =21min 56.8599999999999s
#
# 1822
# Epoch duration =0.72s
# Cumulative duration =21min 57.57999999999993s
#
# 1823
# Epoch duration =0.73s
# Cumulative duration =21min 58.299999999999955s
#
# 1824
# Epoch duration =0.72s
# Cumulative duration =21min 59.01999999999998s
#
# 1825
# Epoch duration =0.72s
# Cumulative duration =21min 59.74000000000001s
#
# 1826
# Epoch duration =0.72s
# Cumulative duration =22min 0.4600000000000364s
#
# 1827
# Epoch duration =0.72s
# Cumulative duration =22min 1.1800000000000637s
#
# 1828
# Epoch duration =0.72s
# Cumulative duration =22min 1.8900000000001s
#
# 1829
# Epoch duration =0.72s
# Cumulative duration =22min 2.619999999999891s
#
# 1830
# Epoch duration =0.72s
# Cumulative duration =22min 3.339999999999918s
#
# 1831
# Epoch duration =0.72s
# Cumulative duration =22min 4.059999999999945s
#
# 1832
# Epoch duration =0.72s
# Cumulative duration =22min 4.779999999999973s
#
# 1833
# Epoch duration =0.72s
# Cumulative duration =22min 5.5s
#
# 1834
# Epoch duration =0.72s
# Cumulative duration =22min 6.220000000000027s
#
# 1835
# Epoch duration =0.72s
# Cumulative duration =22min 6.940000000000055s
#
# 1836
# Epoch duration =0.72s
# Cumulative duration =22min 7.660000000000082s
#
# 1837
# Epoch duration =0.73s
# Cumulative duration =22min 8.400000000000091s
#
# 1838
# Epoch duration =0.72s
# Cumulative duration =22min 9.11999999999989s
#
# 1839
# Epoch duration =0.72s
# Cumulative duration =22min 9.839999999999918s
#
# 1840
# Epoch duration =0.74s
# Cumulative duration =22min 10.579999999999927s
#
# 1841
# Epoch duration =0.72s
# Cumulative duration =22min 11.299999999999955s
#
# 1842
# Epoch duration =0.72s
# Cumulative duration =22min 12.029999999999973s
#
# 1843
# Epoch duration =0.72s
# Cumulative duration =22min 12.740000000000009s
#
# 1844
# Epoch duration =0.76s
# Cumulative duration =22min 13.5s
#
# 1845
# Epoch duration =0.72s
# Cumulative duration =22min 14.230000000000018s
#
# 1846
# Epoch duration =0.73s
# Cumulative duration =22min 14.950000000000045s
#
# 1847
# Epoch duration =0.73s
# Cumulative duration =22min 15.680000000000064s
#
# 1848
# Epoch duration =0.75s
# Cumulative duration =22min 16.430000000000064s
#
# 1849
# Epoch duration =0.73s
# Cumulative duration =22min 17.160000000000082s
#
# 1850
# Epoch duration =0.71s
# Cumulative duration =22min 17.88000000000011s
#
# 1851
# Epoch duration =0.72s
# Cumulative duration =22min 18.589999999999918s
#
# 1852
# Epoch duration =0.71s
# Cumulative duration =22min 19.309999999999945s
#
# 1853
# Epoch duration =0.74s
# Cumulative duration =22min 20.039999999999964s
#
# 1854
# Epoch duration =0.72s
# Cumulative duration =22min 20.75999999999999s
#
# 1855
# Epoch duration =0.73s
# Cumulative duration =22min 21.49000000000001s
#
# 1856
# Epoch duration =0.72s
# Cumulative duration =22min 22.220000000000027s
#
# 1857
# Epoch duration =0.72s
# Cumulative duration =22min 22.930000000000064s
#
# 1858
# Epoch duration =0.72s
# Cumulative duration =22min 23.660000000000082s
#
# 1859
# Epoch duration =0.75s
# Cumulative duration =22min 24.40000000000009s
#
# 1860
# Epoch duration =0.72s
# Cumulative duration =22min 25.11999999999989s
#
# 1861
# Epoch duration =0.74s
# Cumulative duration =22min 25.8599999999999s
#
# 1862
# Epoch duration =0.72s
# Cumulative duration =22min 26.579999999999927s
#
# 1863
# Epoch duration =0.72s
# Cumulative duration =22min 27.299999999999955s
#
# 1864
# Epoch duration =0.73s
# Cumulative duration =22min 28.019999999999982s
#
# 1865
# Epoch duration =0.72s
# Cumulative duration =22min 28.74000000000001s
#
# 1866
# Epoch duration =0.73s
# Cumulative duration =22min 29.470000000000027s
#
# 1867
# Epoch duration =0.73s
# Cumulative duration =22min 30.200000000000045s
#
# 1868
# Epoch duration =0.72s
# Cumulative duration =22min 30.920000000000073s
#
# 1869
# Epoch duration =0.73s
# Cumulative duration =22min 31.65000000000009s
#
# 1870
# Epoch duration =0.72s
# Cumulative duration =22min 32.36999999999989s
#
# 1871
# Epoch duration =0.73s
# Cumulative duration =22min 33.08999999999992s
#
# 1872
# Epoch duration =0.72s
# Cumulative duration =22min 33.809999999999945s
#
# 1873
# Epoch duration =0.73s
# Cumulative duration =22min 34.549999999999955s
#
# 1874
# Epoch duration =0.72s
# Cumulative duration =22min 35.25999999999999s
#
# 1875
# Epoch duration =0.72s
# Cumulative duration =22min 35.98000000000002s
#
# 1876
# Epoch duration =0.72s
# Cumulative duration =22min 36.700000000000045s
#
# 1877
# Epoch duration =0.72s
# Cumulative duration =22min 37.42000000000007s
#
# 1878
# Epoch duration =0.72s
# Cumulative duration =22min 38.1400000000001s
#
# 1879
# Epoch duration =0.72s
# Cumulative duration =22min 38.8599999999999s
#
# 1880
# Epoch duration =0.72s
# Cumulative duration =22min 39.58999999999992s
#
# 1881
# Epoch duration =0.72s
# Cumulative duration =22min 40.309999999999945s
#
# 1882
# Epoch duration =0.72s
# Cumulative duration =22min 41.02999999999997s
#
# 1883
# Epoch duration =0.72s
# Cumulative duration =22min 41.75s
#
# 1884
# Epoch duration =0.72s
# Cumulative duration =22min 42.47000000000003s
#
# 1885
# Epoch duration =0.72s
# Cumulative duration =22min 43.190000000000055s
#
# 1886
# Epoch duration =0.72s
# Cumulative duration =22min 43.91000000000008s
#
# 1887
# Epoch duration =0.73s
# Cumulative duration =22min 44.6400000000001s
#
# 1888
# Epoch duration =0.71s
# Cumulative duration =22min 45.3599999999999s
#
# 1889
# Epoch duration =0.72s
# Cumulative duration =22min 46.07999999999993s
#
# 1890
# Epoch duration =0.73s
# Cumulative duration =22min 46.809999999999945s
#
# 1891
# Epoch duration =0.73s
# Cumulative duration =22min 47.539999999999964s
#
# 1892
# Epoch duration =0.72s
# Cumulative duration =22min 48.25999999999999s
#
# 1893
# Epoch duration =0.72s
# Cumulative duration =22min 48.98000000000002s
#
# 1894
# Epoch duration =0.72s
# Cumulative duration =22min 49.700000000000045s
#
# 1895
# Epoch duration =0.72s
# Cumulative duration =22min 50.430000000000064s
#
# 1896
# Epoch duration =0.72s
# Cumulative duration =22min 51.15000000000009s
#
# 1897
# Epoch duration =0.72s
# Cumulative duration =22min 51.86999999999989s
#
# 1898
# Epoch duration =0.72s
# Cumulative duration =22min 52.58999999999992s
#
# 1899
# Epoch duration =0.72s
# Cumulative duration =22min 53.309999999999945s
#
# 1900
# Epoch duration =0.76s
# Cumulative duration =22min 54.07999999999993s
#
# 1901
# Epoch duration =0.72s
# Cumulative duration =22min 54.789999999999964s
#
# 1902
# Epoch duration =0.72s
# Cumulative duration =22min 55.50999999999999s
#
# 1903
# Epoch duration =0.72s
# Cumulative duration =22min 56.24000000000001s
#
# 1904
# Epoch duration =0.72s
# Cumulative duration =22min 56.960000000000036s
#
# 1905
# Epoch duration =0.72s
# Cumulative duration =22min 57.680000000000064s
#
# 1906
# Epoch duration =0.72s
# Cumulative duration =22min 58.40000000000009s
#
# 1907
# Epoch duration =0.72s
# Cumulative duration =22min 59.11999999999989s
#
# 1908
# Epoch duration =0.72s
# Cumulative duration =22min 59.84999999999991s
#
# 1909
# Epoch duration =0.72s
# Cumulative duration =23min 0.5699999999999363s
#
# 1910
# Epoch duration =0.72s
# Cumulative duration =23min 1.2899999999999636s
#
# 1911
# Epoch duration =0.73s
# Cumulative duration =23min 2.019999999999982s
#
# 1912
# Epoch duration =0.72s
# Cumulative duration =23min 2.740000000000009s
#
# 1913
# Epoch duration =0.75s
# Cumulative duration =23min 3.490000000000009s
#
# 1914
# Epoch duration =0.72s
# Cumulative duration =23min 4.210000000000036s
#
# 1915
# Epoch duration =0.71s
# Cumulative duration =23min 4.920000000000073s
#
# 1916
# Epoch duration =0.72s
# Cumulative duration =23min 5.6400000000001s
#
# 1917
# Epoch duration =0.71s
# Cumulative duration =23min 6.3599999999999s
#
# 1918
# Epoch duration =0.72s
# Cumulative duration =23min 7.079999999999927s
#
# 1919
# Epoch duration =0.72s
# Cumulative duration =23min 7.7999999999999545s
#
# 1920
# Epoch duration =0.74s
# Cumulative duration =23min 8.539999999999964s
#
# 1921
# Epoch duration =0.72s
# Cumulative duration =23min 9.259999999999991s
#
# 1922
# Epoch duration =0.72s
# Cumulative duration =23min 9.990000000000009s
#
# 1923
# Epoch duration =0.72s
# Cumulative duration =23min 10.710000000000036s
#
# 1924
# Epoch duration =0.73s
# Cumulative duration =23min 11.440000000000055s
#
# 1925
# Epoch duration =0.73s
# Cumulative duration =23min 12.170000000000073s
#
# 1926
# Epoch duration =0.72s
# Cumulative duration =23min 12.8900000000001s
#
# 1927
# Epoch duration =0.73s
# Cumulative duration =23min 13.6099999999999s
#
# 1928
# Epoch duration =0.73s
# Cumulative duration =23min 14.339999999999918s
#
# 1929
# Epoch duration =0.73s
# Cumulative duration =23min 15.069999999999936s
#
# 1930
# Epoch duration =0.72s
# Cumulative duration =23min 15.789999999999964s
#
# 1931
# Epoch duration =0.72s
# Cumulative duration =23min 16.50999999999999s
#
# 1932
# Epoch duration =0.72s
# Cumulative duration =23min 17.230000000000018s
#
# 1933
# Epoch duration =0.72s
# Cumulative duration =23min 17.950000000000045s
#
# 1934
# Epoch duration =0.72s
# Cumulative duration =23min 18.670000000000073s
#
# 1935
# Epoch duration =0.72s
# Cumulative duration =23min 19.3900000000001s
#
# 1936
# Epoch duration =0.73s
# Cumulative duration =23min 20.11999999999989s
#
# 1937
# Epoch duration =0.73s
# Cumulative duration =23min 20.84999999999991s
#
# 1938
# Epoch duration =0.72s
# Cumulative duration =23min 21.569999999999936s
#
# 1939
# Epoch duration =0.73s
# Cumulative duration =23min 22.299999999999955s
#
# 1940
# Epoch duration =0.72s
# Cumulative duration =23min 23.019999999999982s
#
# 1941
# Epoch duration =0.72s
# Cumulative duration =23min 23.74000000000001s
#
# 1942
# Epoch duration =0.73s
# Cumulative duration =23min 24.470000000000027s
#
# 1943
# Epoch duration =0.74s
# Cumulative duration =23min 25.210000000000036s
#
# 1944
# Epoch duration =0.72s
# Cumulative duration =23min 25.930000000000064s
#
# 1945
# Epoch duration =0.72s
# Cumulative duration =23min 26.6400000000001s
#
# 1946
# Epoch duration =0.72s
# Cumulative duration =23min 27.36999999999989s
#
# 1947
# Epoch duration =0.72s
# Cumulative duration =23min 28.089999999999918s
#
# 1948
# Epoch duration =0.72s
# Cumulative duration =23min 28.799999999999955s
#
# 1949
# Epoch duration =0.73s
# Cumulative duration =23min 29.529999999999973s
#
# 1950
# Epoch duration =0.72s
# Cumulative duration =23min 30.25999999999999s
#
# 1951
# Epoch duration =0.72s
# Cumulative duration =23min 30.980000000000018s
#
# 1952
# Epoch duration =0.72s
# Cumulative duration =23min 31.710000000000036s
#
# 1953
# Epoch duration =0.72s
# Cumulative duration =23min 32.42000000000007s
#
# 1954
# Epoch duration =0.72s
# Cumulative duration =23min 33.1400000000001s
#
# 1955
# Epoch duration =0.72s
# Cumulative duration =23min 33.8599999999999s
#
# 1956
# Epoch duration =0.72s
# Cumulative duration =23min 34.57999999999993s
#
# 1957
# Epoch duration =0.73s
# Cumulative duration =23min 35.309999999999945s
#
# 1958
# Epoch duration =0.72s
# Cumulative duration =23min 36.02999999999997s
#
# 1959
# Epoch duration =0.72s
# Cumulative duration =23min 36.75s
#
# 1960
# Epoch duration =0.72s
# Cumulative duration =23min 37.47000000000003s
#
# 1961
# Epoch duration =0.72s
# Cumulative duration =23min 38.190000000000055s
#
# 1962
# Epoch duration =0.72s
# Cumulative duration =23min 38.91000000000008s
#
# 1963
# Epoch duration =0.72s
# Cumulative duration =23min 39.63000000000011s
#
# 1964
# Epoch duration =0.72s
# Cumulative duration =23min 40.34999999999991s
#
# 1965
# Epoch duration =0.72s
# Cumulative duration =23min 41.069999999999936s
#
# 1966
# Epoch duration =0.72s
# Cumulative duration =23min 41.789999999999964s
#
# 1967
# Epoch duration =0.71s
# Cumulative duration =23min 42.50999999999999s
#
# 1968
# Epoch duration =0.72s
# Cumulative duration =23min 43.22000000000003s
#
# 1969
# Epoch duration =0.72s
# Cumulative duration =23min 43.950000000000045s
#
# 1970
# Epoch duration =0.72s
# Cumulative duration =23min 44.67000000000007s
#
# 1971
# Epoch duration =0.72s
# Cumulative duration =23min 45.3900000000001s
#
# 1972
# Epoch duration =0.72s
# Cumulative duration =23min 46.1099999999999s
#
# 1973
# Epoch duration =0.71s
# Cumulative duration =23min 46.819999999999936s
#
# 1974
# Epoch duration =0.73s
# Cumulative duration =23min 47.549999999999955s
#
# 1975
# Epoch duration =0.72s
# Cumulative duration =23min 48.26999999999998s
#
# 1976
# Epoch duration =0.73s
# Cumulative duration =23min 49.0s
#
# 1977
# Epoch duration =0.72s
# Cumulative duration =23min 49.72000000000003s
#
# 1978
# Epoch duration =0.72s
# Cumulative duration =23min 50.440000000000055s
#
# 1979
# Epoch duration =0.73s
# Cumulative duration =23min 51.17000000000007s
#
# 1980
# Epoch duration =0.74s
# Cumulative duration =23min 51.90000000000009s
#
# 1981
# Epoch duration =0.73s
# Cumulative duration =23min 52.63000000000011s
#
# 1982
# Epoch duration =0.72s
# Cumulative duration =23min 53.3599999999999s
#
# 1983
# Epoch duration =0.72s
# Cumulative duration =23min 54.07999999999993s
#
# 1984
# Epoch duration =0.72s
# Cumulative duration =23min 54.799999999999955s
#
# 1985
# Epoch duration =0.73s
# Cumulative duration =23min 55.51999999999998s
#
# 1986
# Epoch duration =0.72s
# Cumulative duration =23min 56.24000000000001s
#
# 1987
# Epoch duration =0.73s
# Cumulative duration =23min 56.97000000000003s
#
# 1988
# Epoch duration =0.72s
# Cumulative duration =23min 57.700000000000045s
#
# 1989
# Epoch duration =0.72s
# Cumulative duration =23min 58.42000000000007s
#
# 1990
# Epoch duration =0.72s
# Cumulative duration =23min 59.1400000000001s
#
# 1991
# Epoch duration =0.72s
# Cumulative duration =23min 59.8599999999999s
#
# 1992
# Epoch duration =0.72s
# Cumulative duration =24min 0.5799999999999272s
#
# 1993
# Epoch duration =0.72s
# Cumulative duration =24min 1.2999999999999545s
#
# 1994
# Epoch duration =0.72s
# Cumulative duration =24min 2.019999999999982s
#
# 1995
# Epoch duration =0.72s
# Cumulative duration =24min 2.740000000000009s
#
# 1996
# Epoch duration =0.73s
# Cumulative duration =24min 3.4700000000000273s
#
# 1997
# Epoch duration =0.72s
# Cumulative duration =24min 4.190000000000055s
#
# 1998
# Epoch duration =0.72s
# Cumulative duration =24min 4.920000000000073s
#
# 1999
# Epoch duration =0.73s
# Cumulative duration =24min 5.650000000000091s
#
# Saving scores to Arrays/toypk_resbindt2_so2k.npy

# %%
#Load the saved data
num_summary = 2000
arrayspath = 'Arrays/%s_%s%s_so%.0fk.npy'%(exp_folder, modelarch, trial, num_summary/1000)
mean_mut2 = np.load(arrayspath)

#average the values
#mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

#Normalize
normalize = False
if normalize:
    meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, nntrainer, sess, normfactor=1)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*0.
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = +1.

nofilter = np.ones((4,4))

C = (meanhol_mut2*bpfilter)
C = np.sum((C).reshape(seqlen,seqlen,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C,vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')

# %%
#mf.square_holplot(meanhol_mut2, num=6, alphabet='rna', start=(5,25), cbar=True, cmap='hot', limits=(np.log(0.25),0.))

# %%
blocklen = np.sqrt(np.product(meanhol_mut2.shape)).astype(int)
S = np.zeros((blocklen, blocklen))
i,j,k,l = meanhol_mut2.shape

for ii in range(i):
    for jj in range(j):
        for kk in range(k):
            for ll in range(l):
                S[(4*ii)+kk, (4*jj)+ll] = meanhol_mut2[ii,jj,kk,ll]

plt.figure(figsize=(15,15))
plt.imshow(S,  cmap='Reds', vmin=None)
plt.colorbar()
