# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
'''SAVE PATHS AND PARAMETERS'''
params_results = '../../../results'
exp_folder = 'toypk'

modelarch = 'resbind'
trial = 't1'
modelsavename = '%s_%s'%(modelarch, trial)

# %%
'''OPEN DATA'''

starttime = time.time()

#Open data from h5py

data_path = '../../../data_toypk/toypk_50_d1.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, dims = X_data.shape
X_data = np.expand_dims(X_data, axis=2)
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 0.31s

# %%
'''BUILD NEURAL NETWORK'''

def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = os.path.join(params_results, exp_folder)
param_path = os.path.join(save_path, modelsavename)
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# %%
'''TRAIN '''

# initialize session
sess = utils.initialize_session()

#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)


sess.close()
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.77s -- loss=0.69198 -- acc=58.710001%
#
#   valid loss:		0.52455
#   valid accuracy:	0.75700+/-0.00000
#   valid auc-roc:	0.85728+/-0.00000
#   valid auc-pr:		0.84556+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.50309 -- acc=75.380008%
#
#   valid loss:		0.27877
#   valid accuracy:	0.90700+/-0.00000
#   valid auc-roc:	0.96904+/-0.00000
#   valid auc-pr:		0.96267+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=4.42s -- loss=0.35115 -- acc=85.093339%
#
#   valid loss:		0.18642
#   valid accuracy:	0.93410+/-0.00000
#   valid auc-roc:	0.98894+/-0.00000
#   valid auc-pr:		0.98641+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=4.49s -- loss=0.28514 -- acc=88.538344%
#
#   valid loss:		0.14337
#   valid accuracy:	0.95040+/-0.00000
#   valid auc-roc:	0.99291+/-0.00000
#   valid auc-pr:		0.99105+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.45s -- loss=0.25405 -- acc=90.011671%
#
#   valid loss:		0.13632
#   valid accuracy:	0.95130+/-0.00000
#   valid auc-roc:	0.99487+/-0.00000
#   valid auc-pr:		0.99394+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.73s -- loss=0.23145 -- acc=91.168347%
#
#   valid loss:		0.13096
#   valid accuracy:	0.95360+/-0.00000
#   valid auc-roc:	0.99508+/-0.00000
#   valid auc-pr:		0.99404+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.64s -- loss=0.21855 -- acc=91.770007%
#
#   valid loss:		0.12116
#   valid accuracy:	0.95640+/-0.00000
#   valid auc-roc:	0.99640+/-0.00000
#   valid auc-pr:		0.99558+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=4.71s -- loss=0.20600 -- acc=92.306671%
#
#   valid loss:		0.11859
#   valid accuracy:	0.95760+/-0.00000
#   valid auc-roc:	0.99547+/-0.00000
#   valid auc-pr:		0.99398+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.85s -- loss=0.19594 -- acc=92.890009%
#
#   valid loss:		0.11824
#   valid accuracy:	0.95930+/-0.00000
#   valid auc-roc:	0.99557+/-0.00000
#   valid auc-pr:		0.99431+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.77s -- loss=0.18717 -- acc=93.190009%
#
#   valid loss:		0.12408
#   valid accuracy:	0.95670+/-0.00000
#   valid auc-roc:	0.99459+/-0.00000
#   valid auc-pr:		0.99273+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=4.82s -- loss=0.18186 -- acc=93.518342%
#
#   valid loss:		0.10432
#   valid accuracy:	0.96520+/-0.00000
#   valid auc-roc:	0.99646+/-0.00000
#   valid auc-pr:		0.99492+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=4.79s -- loss=0.17841 -- acc=93.668347%
#
#   valid loss:		0.10518
#   valid accuracy:	0.96520+/-0.00000
#   valid auc-roc:	0.99628+/-0.00000
#   valid auc-pr:		0.99505+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=4.77s -- loss=0.17440 -- acc=93.933343%
#
#   valid loss:		0.11235
#   valid accuracy:	0.96280+/-0.00000
#   valid auc-roc:	0.99553+/-0.00000
#   valid auc-pr:		0.99349+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.17080 -- acc=94.110001%
#
#   valid loss:		0.09865
#   valid accuracy:	0.96960+/-0.00000
#   valid auc-roc:	0.99634+/-0.00000
#   valid auc-pr:		0.99488+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=4.64s -- loss=0.16547 -- acc=94.408341%
#
#   valid loss:		0.10270
#   valid accuracy:	0.96650+/-0.00000
#   valid auc-roc:	0.99656+/-0.00000
#   valid auc-pr:		0.99529+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.16431 -- acc=94.438344%
#
#   valid loss:		0.10704
#   valid accuracy:	0.96480+/-0.00000
#   valid auc-roc:	0.99616+/-0.00000
#   valid auc-pr:		0.99487+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.16344 -- acc=94.461676%
#
#   valid loss:		0.09531
#   valid accuracy:	0.97140+/-0.00000
#   valid auc-roc:	0.99656+/-0.00000
#   valid auc-pr:		0.99485+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toypk/resbind_t1_best.ckpt
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.15794 -- acc=94.688349%
#
#   valid loss:		0.09957
#   valid accuracy:	0.96940+/-0.00000
#   valid auc-roc:	0.99619+/-0.00000
#   valid auc-pr:		0.99440+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.15751 -- acc=94.796670%
#
#   valid loss:		0.10087
#   valid accuracy:	0.96860+/-0.00000
#   valid auc-roc:	0.99577+/-0.00000
#   valid auc-pr:		0.99411+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.15696 -- acc=94.856676%
#
#   valid loss:		0.11024
#   valid accuracy:	0.96450+/-0.00000
#   valid auc-roc:	0.99607+/-0.00000
#   valid auc-pr:		0.99478+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.15530 -- acc=95.045005%
#
#   valid loss:		0.10267
#   valid accuracy:	0.96890+/-0.00000
#   valid auc-roc:	0.99602+/-0.00000
#   valid auc-pr:		0.99419+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.15330 -- acc=94.993349%
#
#   valid loss:		0.10453
#   valid accuracy:	0.96720+/-0.00000
#   valid auc-roc:	0.99642+/-0.00000
#   valid auc-pr:		0.99492+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=4.73s -- loss=0.15106 -- acc=95.086679%
#
#   valid loss:		0.11021
#   valid accuracy:	0.96500+/-0.00000
#   valid auc-roc:	0.99634+/-0.00000
#   valid auc-pr:		0.99544+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.14852 -- acc=95.208341%
#
#   valid loss:		0.10307
#   valid accuracy:	0.96850+/-0.00000
#   valid auc-roc:	0.99648+/-0.00000
#   valid auc-pr:		0.99503+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.15087 -- acc=95.295000%
#
#   valid loss:		0.10591
#   valid accuracy:	0.96680+/-0.00000
#   valid auc-roc:	0.99662+/-0.00000
#   valid auc-pr:		0.99531+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=4.70s -- loss=0.14948 -- acc=95.328343%
#
#   valid loss:		0.10827
#   valid accuracy:	0.96840+/-0.00000
#   valid auc-roc:	0.99548+/-0.00000
#   valid auc-pr:		0.99387+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.14570 -- acc=95.500000%
#
#   valid loss:		0.10079
#   valid accuracy:	0.96940+/-0.00000
#   valid auc-roc:	0.99649+/-0.00000
#   valid auc-pr:		0.99531+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.14740 -- acc=95.368347%
#
#   valid loss:		0.11490
#   valid accuracy:	0.96410+/-0.00000
#   valid auc-roc:	0.99572+/-0.00000
#   valid auc-pr:		0.99341+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.14505 -- acc=95.503340%
#
#   valid loss:		0.10825
#   valid accuracy:	0.96670+/-0.00000
#   valid auc-roc:	0.99594+/-0.00000
#   valid auc-pr:		0.99413+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.14542 -- acc=95.435004%
#
#   valid loss:		0.10355
#   valid accuracy:	0.96960+/-0.00000
#   valid auc-roc:	0.99668+/-0.00000
#   valid auc-pr:		0.99554+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=4.70s -- loss=0.14348 -- acc=95.498340%
#
#   valid loss:		0.12445
#   valid accuracy:	0.96190+/-0.00000
#   valid auc-roc:	0.99564+/-0.00000
#   valid auc-pr:		0.99391+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.14274 -- acc=95.673347%
#
#   valid loss:		0.10404
#   valid accuracy:	0.96910+/-0.00000
#   valid auc-roc:	0.99685+/-0.00000
#   valid auc-pr:		0.99598+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.14350 -- acc=95.595000%
#
#   valid loss:		0.10531
#   valid accuracy:	0.96940+/-0.00000
#   valid auc-roc:	0.99614+/-0.00000
#   valid auc-pr:		0.99426+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.14340 -- acc=95.613341%
#
#   valid loss:		0.10300
#   valid accuracy:	0.96990+/-0.00000
#   valid auc-roc:	0.99681+/-0.00000
#   valid auc-pr:		0.99569+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.14052 -- acc=95.766677%
#
#   valid loss:		0.10063
#   valid accuracy:	0.97050+/-0.00000
#   valid auc-roc:	0.99694+/-0.00000
#   valid auc-pr:		0.99601+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.13991 -- acc=95.710001%
#
#   valid loss:		0.10766
#   valid accuracy:	0.96810+/-0.00000
#   valid auc-roc:	0.99643+/-0.00000
#   valid auc-pr:		0.99532+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.14110 -- acc=95.733343%
#
#   valid loss:		0.10095
#   valid accuracy:	0.97070+/-0.00000
#   valid auc-roc:	0.99704+/-0.00000
#   valid auc-pr:		0.99614+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.14246 -- acc=95.695000%
#
#   valid loss:		0.09890
#   valid accuracy:	0.97370+/-0.00000
#   valid auc-roc:	0.99652+/-0.00000
#   valid auc-pr:		0.99529+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.13971 -- acc=95.830003%
#
#   valid loss:		0.10657
#   valid accuracy:	0.97010+/-0.00000
#   valid auc-roc:	0.99690+/-0.00000
#   valid auc-pr:		0.99558+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.14045 -- acc=95.790009%
#
#   valid loss:		0.10416
#   valid accuracy:	0.97070+/-0.00000
#   valid auc-roc:	0.99680+/-0.00000
#   valid auc-pr:		0.99538+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.14112 -- acc=95.785009%
#
#   valid loss:		0.10802
#   valid accuracy:	0.96930+/-0.00000
#   valid auc-roc:	0.99631+/-0.00000
#   valid auc-pr:		0.99476+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.14241 -- acc=95.751675%
#
#   valid loss:		0.10531
#   valid accuracy:	0.97120+/-0.00000
#   valid auc-roc:	0.99669+/-0.00000
#   valid auc-pr:		0.99544+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.14038 -- acc=95.726673%
#
#   valid loss:		0.10534
#   valid accuracy:	0.97010+/-0.00000
#   valid auc-roc:	0.99695+/-0.00000
#   valid auc-pr:		0.99633+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.14034 -- acc=95.800000%
#
#   valid loss:		0.10588
#   valid accuracy:	0.96980+/-0.00000
#   valid auc-roc:	0.99730+/-0.00000
#   valid auc-pr:		0.99662+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.13846 -- acc=95.871677%
#
#   valid loss:		0.10514
#   valid accuracy:	0.97140+/-0.00000
#   valid auc-roc:	0.99689+/-0.00000
#   valid auc-pr:		0.99581+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.13937 -- acc=95.928343%
#
#   valid loss:		0.10731
#   valid accuracy:	0.97010+/-0.00000
#   valid auc-roc:	0.99675+/-0.00000
#   valid auc-pr:		0.99513+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.13562 -- acc=95.951675%
#
#   valid loss:		0.11248
#   valid accuracy:	0.96940+/-0.00000
#   valid auc-roc:	0.99610+/-0.00000
#   valid auc-pr:		0.99479+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.13703 -- acc=95.943344%
#
#   valid loss:		0.11181
#   valid accuracy:	0.96840+/-0.00000
#   valid auc-roc:	0.99711+/-0.00000
#   valid auc-pr:		0.99605+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.13866 -- acc=95.888349%
#
#   valid loss:		0.10997
#   valid accuracy:	0.96950+/-0.00000
#   valid auc-roc:	0.99646+/-0.00000
#   valid auc-pr:		0.99491+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.13540 -- acc=96.038344%
#
#   valid loss:		0.10207
#   valid accuracy:	0.97270+/-0.00000
#   valid auc-roc:	0.99645+/-0.00000
#   valid auc-pr:		0.99418+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.13795 -- acc=95.951675%
#
#   valid loss:		0.10375
#   valid accuracy:	0.97280+/-0.00000
#   valid auc-roc:	0.99641+/-0.00000
#   valid auc-pr:		0.99448+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.13829 -- acc=95.901670%
#
#   valid loss:		0.11337
#   valid accuracy:	0.96800+/-0.00000
#   valid auc-roc:	0.99620+/-0.00000
#   valid auc-pr:		0.99447+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.13717 -- acc=96.061676%
#
#   valid loss:		0.10502
#   valid accuracy:	0.97220+/-0.00000
#   valid auc-roc:	0.99693+/-0.00000
#   valid auc-pr:		0.99558+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.13633 -- acc=96.033343%
#
#   valid loss:		0.10355
#   valid accuracy:	0.97140+/-0.00000
#   valid auc-roc:	0.99723+/-0.00000
#   valid auc-pr:		0.99587+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=4.64s -- loss=0.13691 -- acc=96.051675%
#
#   valid loss:		0.10326
#   valid accuracy:	0.97210+/-0.00000
#   valid auc-roc:	0.99668+/-0.00000
#   valid auc-pr:		0.99503+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=4.64s -- loss=0.13820 -- acc=96.088349%
#
#   valid loss:		0.11075
#   valid accuracy:	0.97070+/-0.00000
#   valid auc-roc:	0.99584+/-0.00000
#   valid auc-pr:		0.99376+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.13562 -- acc=96.108341%
#
#   valid loss:		0.10767
#   valid accuracy:	0.97170+/-0.00000
#   valid auc-roc:	0.99673+/-0.00000
#   valid auc-pr:		0.99551+/-0.00000
# Patience ran out... Early stopping.

# %%
'''TEST'''
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/toypk/resbind_t1_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/toypk/resbind_t1_best.ckpt
#   test  loss:		0.08183
#   test  accuracy:	0.97683+/-0.00000
#   test  auc-roc:	0.99809+/-0.00000
#   test  auc-pr:		0.99741+/-0.00000

# %%
'''SORT ACTIVATIONS'''

predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
'''FIRST ORDER MUTAGENESIS'''
#num_plots=np.linspace(0,20000,5).astype(int)
num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[10000+ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))

# %%
'''SECOND ORDER MUTAGENESIS'''

num_summary = 2000

arrayspath = 'Arrays/%s_%s_so%.0fk.npy'%(exp_folder, modelarch, num_summary/1000)
X = test['inputs'][plot_index[:num_summary]]

mean_mut2 = mf.som_average_ungapped_logodds(X, range(seqlen), arrayspath, nntrainer, sess, progress='on', 
                                           save=True, layer='dense_1_bias')
# Out:
# 0
# ../../../../mutagenesisfunctions.py:554: RuntimeWarning: invalid value encountered in log
#   mut2_scores = np.log(mut2_scores + 1e-7) - np.log(WT_score+1e-7)
# Epoch duration =0.63s
# Cumulative duration =0.63s
#
# 1
# Epoch duration =0.54s
# Cumulative duration =1.16s
#
# 2
# Epoch duration =0.54s
# Cumulative duration =1.7s
#
# 3
# Epoch duration =0.53s
# Cumulative duration =2.24s
#
# 4
# Epoch duration =0.54s
# Cumulative duration =2.78s
#
# 5
# Epoch duration =0.53s
# Cumulative duration =3.31s
#
# 6
# Epoch duration =0.54s
# Cumulative duration =3.85s
#
# 7
# Epoch duration =0.66s
# Cumulative duration =4.51s
#
# 8
# Epoch duration =0.53s
# Cumulative duration =5.04s
#
# 9
# Epoch duration =0.53s
# Cumulative duration =5.57s
#
# 10
# Epoch duration =0.53s
# Cumulative duration =6.1s
#
# 11
# Epoch duration =0.53s
# Cumulative duration =6.63s
#
# 12
# Epoch duration =0.54s
# Cumulative duration =7.17s
#
# 13
# Epoch duration =0.53s
# Cumulative duration =7.7s
#
# 14
# Epoch duration =0.53s
# Cumulative duration =8.23s
#
# 15
# Epoch duration =0.52s
# Cumulative duration =8.75s
#
# 16
# Epoch duration =0.52s
# Cumulative duration =9.27s
#
# 17
# Epoch duration =0.53s
# Cumulative duration =9.8s
#
# 18
# Epoch duration =0.52s
# Cumulative duration =10.33s
#
# 19
# Epoch duration =0.52s
# Cumulative duration =10.85s
#
# 20
# Epoch duration =0.53s
# Cumulative duration =11.38s
#
# 21
# Epoch duration =0.52s
# Cumulative duration =11.9s
#
# 22
# Epoch duration =0.52s
# Cumulative duration =12.42s
#
# 23
# Epoch duration =0.57s
# Cumulative duration =12.99s
#
# 24
# Epoch duration =0.53s
# Cumulative duration =13.52s
#
# 25
# Epoch duration =0.53s
# Cumulative duration =14.06s
#
# 26
# Epoch duration =0.53s
# Cumulative duration =14.59s
#
# 27
# Epoch duration =0.53s
# Cumulative duration =15.13s
#
# 28
# Epoch duration =0.52s
# Cumulative duration =15.64s
#
# 29
# Epoch duration =0.52s
# Cumulative duration =16.16s
#
# 30
# Epoch duration =0.52s
# Cumulative duration =16.68s
#
# 31
# Epoch duration =0.52s
# Cumulative duration =17.21s
#
# 32
# Epoch duration =0.52s
# Cumulative duration =17.73s
#
# 33
# Epoch duration =0.52s
# Cumulative duration =18.25s
#
# 34
# Epoch duration =0.52s
# Cumulative duration =18.77s
#
# 35
# Epoch duration =0.53s
# Cumulative duration =19.3s
#
# 36
# Epoch duration =0.53s
# Cumulative duration =19.83s
#
# 37
# Epoch duration =0.51s
# Cumulative duration =20.34s
#
# 38
# Epoch duration =0.52s
# Cumulative duration =20.87s
#
# 39
# Epoch duration =0.52s
# Cumulative duration =21.38s
#
# 40
# Epoch duration =0.52s
# Cumulative duration =21.9s
#
# 41
# Epoch duration =0.53s
# Cumulative duration =22.43s
#
# 42
# Epoch duration =0.55s
# Cumulative duration =22.97s
#
# 43
# Epoch duration =0.52s
# Cumulative duration =23.49s
#
# 44
# Epoch duration =0.52s
# Cumulative duration =24.02s
#
# 45
# Epoch duration =0.52s
# Cumulative duration =24.53s
#
# 46
# Epoch duration =0.53s
# Cumulative duration =25.06s
#
# 47
# Epoch duration =0.52s
# Cumulative duration =25.58s
#
# 48
# Epoch duration =0.52s
# Cumulative duration =26.09s
#
# 49
# Epoch duration =0.53s
# Cumulative duration =26.62s
#
# 50
# Epoch duration =0.54s
# Cumulative duration =27.15s
#
# 51
# Epoch duration =0.53s
# Cumulative duration =27.69s
#
# 52
# Epoch duration =0.53s
# Cumulative duration =28.21s
#
# 53
# Epoch duration =0.52s
# Cumulative duration =28.73s
#
# 54
# Epoch duration =0.52s
# Cumulative duration =29.25s
#
# 55
# Epoch duration =0.53s
# Cumulative duration =29.78s
#
# 56
# Epoch duration =0.52s
# Cumulative duration =30.29s
#
# 57
# Epoch duration =0.52s
# Cumulative duration =30.81s
#
# 58
# Epoch duration =0.53s
# Cumulative duration =31.34s
#
# 59
# Epoch duration =0.54s
# Cumulative duration =31.87s
#
# 60
# Epoch duration =0.53s
# Cumulative duration =32.4s
#
# 61
# Epoch duration =0.53s
# Cumulative duration =32.93s
#
# 62
# Epoch duration =0.55s
# Cumulative duration =33.48s
#
# 63
# Epoch duration =0.56s
# Cumulative duration =34.05s
#
# 64
# Epoch duration =0.56s
# Cumulative duration =34.61s
#
# 65
# Epoch duration =0.52s
# Cumulative duration =35.13s
#
# 66
# Epoch duration =0.52s
# Cumulative duration =35.65s
#
# 67
# Epoch duration =0.52s
# Cumulative duration =36.17s
#
# 68
# Epoch duration =0.52s
# Cumulative duration =36.69s
#
# 69
# Epoch duration =0.52s
# Cumulative duration =37.21s
#
# 70
# Epoch duration =0.52s
# Cumulative duration =37.73s
#
# 71
# Epoch duration =0.53s
# Cumulative duration =38.26s
#
# 72
# Epoch duration =0.57s
# Cumulative duration =38.84s
#
# 73
# Epoch duration =0.53s
# Cumulative duration =39.36s
#
# 74
# Epoch duration =0.54s
# Cumulative duration =39.9s
#
# 75
# Epoch duration =0.52s
# Cumulative duration =40.43s
#
# 76
# Epoch duration =0.53s
# Cumulative duration =40.96s
#
# 77
# Epoch duration =0.52s
# Cumulative duration =41.48s
#
# 78
# Epoch duration =0.53s
# Cumulative duration =42.02s
#
# 79
# Epoch duration =0.54s
# Cumulative duration =42.55s
#
# 80
# Epoch duration =0.53s
# Cumulative duration =43.08s
#
# 81
# Epoch duration =0.54s
# Cumulative duration =43.62s
#
# 82
# Epoch duration =0.53s
# Cumulative duration =44.15s
#
# 83
# Epoch duration =0.54s
# Cumulative duration =44.69s
#
# 84
# Epoch duration =0.52s
# Cumulative duration =45.21s
#
# 85
# Epoch duration =0.52s
# Cumulative duration =45.73s
#
# 86
# Epoch duration =0.52s
# Cumulative duration =46.25s
#
# 87
# Epoch duration =0.58s
# Cumulative duration =46.84s
#
# 88
# Epoch duration =0.63s
# Cumulative duration =47.47s
#
# 89
# Epoch duration =0.56s
# Cumulative duration =48.03s
#
# 90
# Epoch duration =0.53s
# Cumulative duration =48.56s
#
# 91
# Epoch duration =0.59s
# Cumulative duration =49.16s
#
# 92
# Epoch duration =0.62s
# Cumulative duration =49.78s
#
# 93
# Epoch duration =0.52s
# Cumulative duration =50.31s
#
# 94
# Epoch duration =0.51s
# Cumulative duration =50.82s
#
# 95
# Epoch duration =0.51s
# Cumulative duration =51.33s
#
# 96
# Epoch duration =0.52s
# Cumulative duration =51.85s
#
# 97
# Epoch duration =0.52s
# Cumulative duration =52.37s
#
# 98
# Epoch duration =0.52s
# Cumulative duration =52.89s
#
# 99
# Epoch duration =0.52s
# Cumulative duration =53.41s
#
# 100
# Epoch duration =0.52s
# Cumulative duration =53.92s
#
# 101
# Epoch duration =0.52s
# Cumulative duration =54.44s
#
# 102
# Epoch duration =0.52s
# Cumulative duration =54.95s
#
# 103
# Epoch duration =0.51s
# Cumulative duration =55.47s
#
# 104
# Epoch duration =0.52s
# Cumulative duration =55.99s
#
# 105
# Epoch duration =0.52s
# Cumulative duration =56.51s
#
# 106
# Epoch duration =0.52s
# Cumulative duration =57.03s
#
# 107
# Epoch duration =0.51s
# Cumulative duration =57.54s
#
# 108
# Epoch duration =0.53s
# Cumulative duration =58.08s
#
# 109
# Epoch duration =0.52s
# Cumulative duration =58.59s
#
# 110
# Epoch duration =0.52s
# Cumulative duration =59.11s
#
# 111
# Epoch duration =0.52s
# Cumulative duration =59.63s
#
# 112
# Epoch duration =0.52s
# Cumulative duration =1min 0.14999999999999858s
#
# 113
# Epoch duration =0.52s
# Cumulative duration =1min 0.6700000000000017s
#
# 114
# Epoch duration =0.52s
# Cumulative duration =1min 1.1899999999999977s
#
# 115
# Epoch duration =0.52s
# Cumulative duration =1min 1.7100000000000009s
#
# 116
# Epoch duration =0.52s
# Cumulative duration =1min 2.229999999999997s
#
# 117
# Epoch duration =0.52s
# Cumulative duration =1min 2.75s
#
# 118
# Epoch duration =0.51s
# Cumulative duration =1min 3.259999999999998s
#
# 119
# Epoch duration =0.52s
# Cumulative duration =1min 3.780000000000001s
#
# 120
# Epoch duration =0.52s
# Cumulative duration =1min 4.299999999999997s
#
# 121
# Epoch duration =0.52s
# Cumulative duration =1min 4.829999999999998s
#
# 122
# Epoch duration =0.57s
# Cumulative duration =1min 5.400000000000006s
#
# 123
# Epoch duration =0.54s
# Cumulative duration =1min 5.930000000000007s
#
# 124
# Epoch duration =0.55s
# Cumulative duration =1min 6.489999999999995s
#
# 125
# Epoch duration =0.6s
# Cumulative duration =1min 7.090000000000003s
#
# 126
# Epoch duration =0.52s
# Cumulative duration =1min 7.609999999999999s
#
# 127
# Epoch duration =0.56s
# Cumulative duration =1min 8.170000000000002s
#
# 128
# Epoch duration =0.53s
# Cumulative duration =1min 8.700000000000003s
#
# 129
# Epoch duration =0.52s
# Cumulative duration =1min 9.219999999999999s
#
# 130
# Epoch duration =0.53s
# Cumulative duration =1min 9.75s
#
# 131
# Epoch duration =0.52s
# Cumulative duration =1min 10.269999999999996s
#
# 132
# Epoch duration =0.52s
# Cumulative duration =1min 10.790000000000006s
#
# 133
# Epoch duration =0.52s
# Cumulative duration =1min 11.310000000000002s
#
# 134
# Epoch duration =0.53s
# Cumulative duration =1min 11.829999999999998s
#
# 135
# Epoch duration =0.52s
# Cumulative duration =1min 12.349999999999994s
#
# 136
# Epoch duration =0.52s
# Cumulative duration =1min 12.870000000000005s
#
# 137
# Epoch duration =0.52s
# Cumulative duration =1min 13.39s
#
# 138
# Epoch duration =0.52s
# Cumulative duration =1min 13.909999999999997s
#
# 139
# Epoch duration =0.51s
# Cumulative duration =1min 14.430000000000007s
#
# 140
# Epoch duration =0.52s
# Cumulative duration =1min 14.950000000000003s
#
# 141
# Epoch duration =0.52s
# Cumulative duration =1min 15.469999999999999s
#
# 142
# Epoch duration =0.52s
# Cumulative duration =1min 15.989999999999995s
#
# 143
# Epoch duration =0.52s
# Cumulative duration =1min 16.5s
#
# 144
# Epoch duration =0.51s
# Cumulative duration =1min 17.019999999999996s
#
# 145
# Epoch duration =0.52s
# Cumulative duration =1min 17.53s
#
# 146
# Epoch duration =0.52s
# Cumulative duration =1min 18.049999999999997s
#
# 147
# Epoch duration =0.53s
# Cumulative duration =1min 18.58s
#
# 148
# Epoch duration =0.52s
# Cumulative duration =1min 19.099999999999994s
#
# 149
# Epoch duration =0.52s
# Cumulative duration =1min 19.620000000000005s
#
# 150
# Epoch duration =0.52s
# Cumulative duration =1min 20.129999999999995s
#
# 151
# Epoch duration =0.54s
# Cumulative duration =1min 20.67s
#
# 152
# Epoch duration =0.51s
# Cumulative duration =1min 21.189999999999998s
#
# 153
# Epoch duration =0.52s
# Cumulative duration =1min 21.700000000000003s
#
# 154
# Epoch duration =0.52s
# Cumulative duration =1min 22.22s
#
# 155
# Epoch duration =0.53s
# Cumulative duration =1min 22.760000000000005s
#
# 156
# Epoch duration =0.52s
# Cumulative duration =1min 23.28s
#
# 157
# Epoch duration =0.53s
# Cumulative duration =1min 23.799999999999997s
#
# 158
# Epoch duration =0.51s
# Cumulative duration =1min 24.319999999999993s
#
# 159
# Epoch duration =0.52s
# Cumulative duration =1min 24.83s
#
# 160
# Epoch duration =0.52s
# Cumulative duration =1min 25.349999999999994s
#
# 161
# Epoch duration =0.52s
# Cumulative duration =1min 25.870000000000005s
#
# 162
# Epoch duration =0.53s
# Cumulative duration =1min 26.400000000000006s
#
# 163
# Epoch duration =0.52s
# Cumulative duration =1min 26.909999999999997s
#
# 164
# Epoch duration =0.51s
# Cumulative duration =1min 27.430000000000007s
#
# 165
# Epoch duration =0.52s
# Cumulative duration =1min 27.950000000000003s
#
# 166
# Epoch duration =0.52s
# Cumulative duration =1min 28.47s
#
# 167
# Epoch duration =0.52s
# Cumulative duration =1min 28.989999999999995s
#
# 168
# Epoch duration =0.52s
# Cumulative duration =1min 29.519999999999996s
#
# 169
# Epoch duration =0.51s
# Cumulative duration =1min 30.03s
#
# 170
# Epoch duration =0.52s
# Cumulative duration =1min 30.549999999999997s
#
# 171
# Epoch duration =0.52s
# Cumulative duration =1min 31.069999999999993s
#
# 172
# Epoch duration =0.53s
# Cumulative duration =1min 31.599999999999994s
#
# 173
# Epoch duration =0.52s
# Cumulative duration =1min 32.11s
#
# 174
# Epoch duration =0.52s
# Cumulative duration =1min 32.629999999999995s
#
# 175
# Epoch duration =0.51s
# Cumulative duration =1min 33.14s
#
# 176
# Epoch duration =0.52s
# Cumulative duration =1min 33.66s
#
# 177
# Epoch duration =0.52s
# Cumulative duration =1min 34.18000000000001s
#
# 178
# Epoch duration =0.52s
# Cumulative duration =1min 34.69s
#
# 179
# Epoch duration =0.53s
# Cumulative duration =1min 35.22s
#
# 180
# Epoch duration =0.52s
# Cumulative duration =1min 35.739999999999995s
#
# 181
# Epoch duration =0.52s
# Cumulative duration =1min 36.260000000000005s
#
# 182
# Epoch duration =0.53s
# Cumulative duration =1min 36.790000000000006s
#
# 183
# Epoch duration =0.53s
# Cumulative duration =1min 37.31999999999999s
#
# 184
# Epoch duration =0.52s
# Cumulative duration =1min 37.83s
#
# 185
# Epoch duration =0.52s
# Cumulative duration =1min 38.349999999999994s
#
# 186
# Epoch duration =0.52s
# Cumulative duration =1min 38.870000000000005s
#
# 187
# Epoch duration =0.52s
# Cumulative duration =1min 39.39s
#
# 188
# Epoch duration =0.53s
# Cumulative duration =1min 39.92s
#
# 189
# Epoch duration =0.52s
# Cumulative duration =1min 40.44s
#
# 190
# Epoch duration =0.52s
# Cumulative duration =1min 40.959999999999994s
#
# 191
# Epoch duration =0.52s
# Cumulative duration =1min 41.47s
#
# 192
# Epoch duration =0.52s
# Cumulative duration =1min 41.989999999999995s
#
# 193
# Epoch duration =0.52s
# Cumulative duration =1min 42.519999999999996s
#
# 194
# Epoch duration =0.52s
# Cumulative duration =1min 43.03s
#
# 195
# Epoch duration =0.52s
# Cumulative duration =1min 43.55s
#
# 196
# Epoch duration =0.52s
# Cumulative duration =1min 44.06999999999999s
#
# 197
# Epoch duration =0.52s
# Cumulative duration =1min 44.59s
#
# 198
# Epoch duration =0.52s
# Cumulative duration =1min 45.11s
#
# 199
# Epoch duration =0.52s
# Cumulative duration =1min 45.620000000000005s
#
# 200
# Epoch duration =0.52s
# Cumulative duration =1min 46.14s
#
# 201
# Epoch duration =0.52s
# Cumulative duration =1min 46.66s
#
# 202
# Epoch duration =0.52s
# Cumulative duration =1min 47.18000000000001s
#
# 203
# Epoch duration =0.52s
# Cumulative duration =1min 47.7s
#
# 204
# Epoch duration =0.53s
# Cumulative duration =1min 48.230000000000004s
#
# 205
# Epoch duration =0.57s
# Cumulative duration =1min 48.8s
#
# 206
# Epoch duration =0.51s
# Cumulative duration =1min 49.31s
#
# 207
# Epoch duration =0.52s
# Cumulative duration =1min 49.83s
#
# 208
# Epoch duration =0.51s
# Cumulative duration =1min 50.349999999999994s
#
# 209
# Epoch duration =0.51s
# Cumulative duration =1min 50.86s
#
# 210
# Epoch duration =0.51s
# Cumulative duration =1min 51.379999999999995s
#
# 211
# Epoch duration =0.51s
# Cumulative duration =1min 51.89s
#
# 212
# Epoch duration =0.51s
# Cumulative duration =1min 52.400000000000006s
#
# 213
# Epoch duration =0.52s
# Cumulative duration =1min 52.92s
#
# 214
# Epoch duration =0.52s
# Cumulative duration =1min 53.44s
#
# 215
# Epoch duration =0.52s
# Cumulative duration =1min 53.959999999999994s
#
# 216
# Epoch duration =0.52s
# Cumulative duration =1min 54.480000000000004s
#
# 217
# Epoch duration =0.52s
# Cumulative duration =1min 55.0s
#
# 218
# Epoch duration =0.52s
# Cumulative duration =1min 55.510000000000005s
#
# 219
# Epoch duration =0.51s
# Cumulative duration =1min 56.03s
#
# 220
# Epoch duration =0.52s
# Cumulative duration =1min 56.540000000000006s
#
# 221
# Epoch duration =0.52s
# Cumulative duration =1min 57.06s
#
# 222
# Epoch duration =0.51s
# Cumulative duration =1min 57.56999999999999s
#
# 223
# Epoch duration =0.52s
# Cumulative duration =1min 58.09s
#
# 224
# Epoch duration =0.51s
# Cumulative duration =1min 58.599999999999994s
#
# 225
# Epoch duration =0.52s
# Cumulative duration =1min 59.120000000000005s
#
# 226
# Epoch duration =0.51s
# Cumulative duration =1min 59.64s
#
# 227
# Epoch duration =0.51s
# Cumulative duration =2min 0.15000000000000568s
#
# 228
# Epoch duration =0.52s
# Cumulative duration =2min 0.6700000000000017s
#
# 229
# Epoch duration =0.52s
# Cumulative duration =2min 1.1800000000000068s
#
# 230
# Epoch duration =0.52s
# Cumulative duration =2min 1.7000000000000028s
#
# 231
# Epoch duration =0.52s
# Cumulative duration =2min 2.219999999999999s
#
# 232
# Epoch duration =0.51s
# Cumulative duration =2min 2.730000000000004s
#
# 233
# Epoch duration =0.51s
# Cumulative duration =2min 3.25s
#
# 234
# Epoch duration =0.52s
# Cumulative duration =2min 3.760000000000005s
#
# 235
# Epoch duration =0.52s
# Cumulative duration =2min 4.280000000000001s
#
# 236
# Epoch duration =0.52s
# Cumulative duration =2min 4.799999999999997s
#
# 237
# Epoch duration =0.52s
# Cumulative duration =2min 5.319999999999993s
#
# 238
# Epoch duration =0.52s
# Cumulative duration =2min 5.840000000000003s
#
# 239
# Epoch duration =0.52s
# Cumulative duration =2min 6.349999999999994s
#
# 240
# Epoch duration =0.52s
# Cumulative duration =2min 6.8700000000000045s
#
# 241
# Epoch duration =0.52s
# Cumulative duration =2min 7.390000000000001s
#
# 242
# Epoch duration =0.51s
# Cumulative duration =2min 7.909999999999997s
#
# 243
# Epoch duration =0.52s
# Cumulative duration =2min 8.419999999999987s
#
# 244
# Epoch duration =0.52s
# Cumulative duration =2min 8.939999999999998s
#
# 245
# Epoch duration =0.52s
# Cumulative duration =2min 9.460000000000008s
#
# 246
# Epoch duration =0.52s
# Cumulative duration =2min 9.969999999999999s
#
# 247
# Epoch duration =0.51s
# Cumulative duration =2min 10.490000000000009s
#
# 248
# Epoch duration =0.53s
# Cumulative duration =2min 11.02000000000001s
#
# 249
# Epoch duration =0.52s
# Cumulative duration =2min 11.530000000000001s
#
# 250
# Epoch duration =0.52s
# Cumulative duration =2min 12.050000000000011s
#
# 251
# Epoch duration =0.51s
# Cumulative duration =2min 12.560000000000002s
#
# 252
# Epoch duration =0.52s
# Cumulative duration =2min 13.080000000000013s
#
# 253
# Epoch duration =0.51s
# Cumulative duration =2min 13.590000000000003s
#
# 254
# Epoch duration =0.51s
# Cumulative duration =2min 14.110000000000014s
#
# 255
# Epoch duration =0.51s
# Cumulative duration =2min 14.620000000000005s
#
# 256
# Epoch duration =0.52s
# Cumulative duration =2min 15.150000000000006s
#
# 257
# Epoch duration =0.52s
# Cumulative duration =2min 15.659999999999997s
#
# 258
# Epoch duration =0.52s
# Cumulative duration =2min 16.180000000000007s
#
# 259
# Epoch duration =0.52s
# Cumulative duration =2min 16.689999999999998s
#
# 260
# Epoch duration =0.51s
# Cumulative duration =2min 17.210000000000008s
#
# 261
# Epoch duration =0.52s
# Cumulative duration =2min 17.72s
#
# 262
# Epoch duration =0.52s
# Cumulative duration =2min 18.24000000000001s
#
# 263
# Epoch duration =0.52s
# Cumulative duration =2min 18.75999999999999s
#
# 264
# Epoch duration =0.53s
# Cumulative duration =2min 19.28s
#
# 265
# Epoch duration =0.52s
# Cumulative duration =2min 19.80000000000001s
#
# 266
# Epoch duration =0.51s
# Cumulative duration =2min 20.310000000000002s
#
# 267
# Epoch duration =0.51s
# Cumulative duration =2min 20.819999999999993s
#
# 268
# Epoch duration =0.51s
# Cumulative duration =2min 21.340000000000003s
#
# 269
# Epoch duration =0.52s
# Cumulative duration =2min 21.860000000000014s
#
# 270
# Epoch duration =0.51s
# Cumulative duration =2min 22.379999999999995s
#
# 271
# Epoch duration =0.54s
# Cumulative duration =2min 22.919999999999987s
#
# 272
# Epoch duration =0.52s
# Cumulative duration =2min 23.430000000000007s
#
# 273
# Epoch duration =0.52s
# Cumulative duration =2min 23.94999999999999s
#
# 274
# Epoch duration =0.51s
# Cumulative duration =2min 24.47s
#
# 275
# Epoch duration =0.52s
# Cumulative duration =2min 24.99000000000001s
#
# 276
# Epoch duration =0.51s
# Cumulative duration =2min 25.50999999999999s
#
# 277
# Epoch duration =0.51s
# Cumulative duration =2min 26.02000000000001s
#
# 278
# Epoch duration =0.51s
# Cumulative duration =2min 26.539999999999992s
#
# 279
# Epoch duration =0.52s
# Cumulative duration =2min 27.05000000000001s
#
# 280
# Epoch duration =0.52s
# Cumulative duration =2min 27.569999999999993s
#
# 281
# Epoch duration =0.52s
# Cumulative duration =2min 28.090000000000003s
#
# 282
# Epoch duration =0.52s
# Cumulative duration =2min 28.599999999999994s
#
# 283
# Epoch duration =0.51s
# Cumulative duration =2min 29.120000000000005s
#
# 284
# Epoch duration =0.53s
# Cumulative duration =2min 29.639999999999986s
#
# 285
# Epoch duration =0.51s
# Cumulative duration =2min 30.159999999999997s
#
# 286
# Epoch duration =0.52s
# Cumulative duration =2min 30.680000000000007s
#
# 287
# Epoch duration =0.52s
# Cumulative duration =2min 31.189999999999998s
#
# 288
# Epoch duration =0.52s
# Cumulative duration =2min 31.72s
#
# 289
# Epoch duration =0.52s
# Cumulative duration =2min 32.24000000000001s
#
# 290
# Epoch duration =0.51s
# Cumulative duration =2min 32.75s
#
# 291
# Epoch duration =0.51s
# Cumulative duration =2min 33.25999999999999s
#
# 292
# Epoch duration =0.51s
# Cumulative duration =2min 33.78s
#
# 293
# Epoch duration =0.52s
# Cumulative duration =2min 34.30000000000001s
#
# 294
# Epoch duration =0.51s
# Cumulative duration =2min 34.81s
#
# 295
# Epoch duration =0.51s
# Cumulative duration =2min 35.33000000000001s
#
# 296
# Epoch duration =0.52s
# Cumulative duration =2min 35.849999999999994s
#
# 297
# Epoch duration =0.52s
# Cumulative duration =2min 36.360000000000014s
#
# 298
# Epoch duration =0.52s
# Cumulative duration =2min 36.879999999999995s
#
# 299
# Epoch duration =0.51s
# Cumulative duration =2min 37.400000000000006s
#
# 300
# Epoch duration =0.51s
# Cumulative duration =2min 37.91s
#
# 301
# Epoch duration =0.52s
# Cumulative duration =2min 38.43000000000001s
#
# 302
# Epoch duration =0.51s
# Cumulative duration =2min 38.94999999999999s
#
# 303
# Epoch duration =0.51s
# Cumulative duration =2min 39.46000000000001s
#
# 304
# Epoch duration =0.51s
# Cumulative duration =2min 39.97999999999999s
#
# 305
# Epoch duration =0.51s
# Cumulative duration =2min 40.49000000000001s
#
# 306
# Epoch duration =0.52s
# Cumulative duration =2min 41.00999999999999s
#
# 307
# Epoch duration =0.52s
# Cumulative duration =2min 41.52000000000001s
#
# 308
# Epoch duration =0.52s
# Cumulative duration =2min 42.03999999999999s
#
# 309
# Epoch duration =0.52s
# Cumulative duration =2min 42.56s
#
# 310
# Epoch duration =0.52s
# Cumulative duration =2min 43.08000000000001s
#
# 311
# Epoch duration =0.51s
# Cumulative duration =2min 43.59s
#
# 312
# Epoch duration =0.52s
# Cumulative duration =2min 44.110000000000014s
#
# 313
# Epoch duration =0.51s
# Cumulative duration =2min 44.629999999999995s
#
# 314
# Epoch duration =0.52s
# Cumulative duration =2min 45.139999999999986s
#
# 315
# Epoch duration =0.51s
# Cumulative duration =2min 45.66s
#
# 316
# Epoch duration =0.51s
# Cumulative duration =2min 46.16999999999999s
#
# 317
# Epoch duration =0.51s
# Cumulative duration =2min 46.68000000000001s
#
# 318
# Epoch duration =0.51s
# Cumulative duration =2min 47.19999999999999s
#
# 319
# Epoch duration =0.52s
# Cumulative duration =2min 47.72s
#
# 320
# Epoch duration =0.52s
# Cumulative duration =2min 48.22999999999999s
#
# 321
# Epoch duration =0.52s
# Cumulative duration =2min 48.75s
#
# 322
# Epoch duration =0.51s
# Cumulative duration =2min 49.25999999999999s
#
# 323
# Epoch duration =0.53s
# Cumulative duration =2min 49.78999999999999s
#
# 324
# Epoch duration =0.51s
# Cumulative duration =2min 50.31s
#
# 325
# Epoch duration =0.51s
# Cumulative duration =2min 50.81999999999999s
#
# 326
# Epoch duration =0.51s
# Cumulative duration =2min 51.33000000000001s
#
# 327
# Epoch duration =0.52s
# Cumulative duration =2min 51.849999999999994s
#
# 328
# Epoch duration =0.52s
# Cumulative duration =2min 52.370000000000005s
#
# 329
# Epoch duration =0.51s
# Cumulative duration =2min 52.879999999999995s
#
# 330
# Epoch duration =0.52s
# Cumulative duration =2min 53.41s
#
# 331
# Epoch duration =0.52s
# Cumulative duration =2min 53.93000000000001s
#
# 332
# Epoch duration =0.51s
# Cumulative duration =2min 54.44s
#
# 333
# Epoch duration =0.51s
# Cumulative duration =2min 54.96000000000001s
#
# 334
# Epoch duration =0.51s
# Cumulative duration =2min 55.47s
#
# 335
# Epoch duration =0.51s
# Cumulative duration =2min 55.99000000000001s
#
# 336
# Epoch duration =0.51s
# Cumulative duration =2min 56.5s
#
# 337
# Epoch duration =0.51s
# Cumulative duration =2min 57.00999999999999s
#
# 338
# Epoch duration =0.52s
# Cumulative duration =2min 57.53s
#
# 339
# Epoch duration =0.52s
# Cumulative duration =2min 58.03999999999999s
#
# 340
# Epoch duration =0.52s
# Cumulative duration =2min 58.56999999999999s
#
# 341
# Epoch duration =0.53s
# Cumulative duration =2min 59.099999999999994s
#
# 342
# Epoch duration =0.52s
# Cumulative duration =2min 59.620000000000005s
#
# 343
# Epoch duration =0.51s
# Cumulative duration =3min 0.12999999999999545s
#
# 344
# Epoch duration =0.52s
# Cumulative duration =3min 0.6599999999999966s
#
# 345
# Epoch duration =0.52s
# Cumulative duration =3min 1.1800000000000068s
#
# 346
# Epoch duration =0.52s
# Cumulative duration =3min 1.6899999999999977s
#
# 347
# Epoch duration =0.52s
# Cumulative duration =3min 2.210000000000008s
#
# 348
# Epoch duration =0.52s
# Cumulative duration =3min 2.7299999999999898s
#
# 349
# Epoch duration =0.52s
# Cumulative duration =3min 3.25s
#
# 350
# Epoch duration =0.52s
# Cumulative duration =3min 3.7700000000000102s
#
# 351
# Epoch duration =0.51s
# Cumulative duration =3min 4.280000000000001s
#
# 352
# Epoch duration =0.52s
# Cumulative duration =3min 4.789999999999992s
#
# 353
# Epoch duration =0.51s
# Cumulative duration =3min 5.310000000000002s
#
# 354
# Epoch duration =0.52s
# Cumulative duration =3min 5.8300000000000125s
#
# 355
# Epoch duration =0.52s
# Cumulative duration =3min 6.349999999999994s
#
# 356
# Epoch duration =0.51s
# Cumulative duration =3min 6.860000000000014s
#
# 357
# Epoch duration =0.51s
# Cumulative duration =3min 7.3799999999999955s
#
# 358
# Epoch duration =0.51s
# Cumulative duration =3min 7.889999999999986s
#
# 359
# Epoch duration =0.51s
# Cumulative duration =3min 8.400000000000006s
#
# 360
# Epoch duration =0.52s
# Cumulative duration =3min 8.919999999999987s
#
# 361
# Epoch duration =0.51s
# Cumulative duration =3min 9.439999999999998s
#
# 362
# Epoch duration =0.52s
# Cumulative duration =3min 9.949999999999989s
#
# 363
# Epoch duration =0.52s
# Cumulative duration =3min 10.469999999999999s
#
# 364
# Epoch duration =0.51s
# Cumulative duration =3min 10.97999999999999s
#
# 365
# Epoch duration =0.52s
# Cumulative duration =3min 11.5s
#
# 366
# Epoch duration =0.53s
# Cumulative duration =3min 12.030000000000001s
#
# 367
# Epoch duration =0.51s
# Cumulative duration =3min 12.550000000000011s
#
# 368
# Epoch duration =0.51s
# Cumulative duration =3min 13.060000000000002s
#
# 369
# Epoch duration =0.51s
# Cumulative duration =3min 13.569999999999993s
#
# 370
# Epoch duration =0.51s
# Cumulative duration =3min 14.090000000000003s
#
# 371
# Epoch duration =0.52s
# Cumulative duration =3min 14.610000000000014s
#
# 372
# Epoch duration =0.53s
# Cumulative duration =3min 15.139999999999986s
#
# 373
# Epoch duration =0.59s
# Cumulative duration =3min 15.72999999999999s
#
# 374
# Epoch duration =0.6s
# Cumulative duration =3min 16.330000000000013s
#
# 375
# Epoch duration =0.59s
# Cumulative duration =3min 16.919999999999987s
#
# 376
# Epoch duration =0.56s
# Cumulative duration =3min 17.49000000000001s
#
# 377
# Epoch duration =0.55s
# Cumulative duration =3min 18.039999999999992s
#
# 378
# Epoch duration =0.56s
# Cumulative duration =3min 18.599999999999994s
#
# 379
# Epoch duration =0.58s
# Cumulative duration =3min 19.180000000000007s
#
# 380
# Epoch duration =0.6s
# Cumulative duration =3min 19.78s
#
# 381
# Epoch duration =0.61s
# Cumulative duration =3min 20.389999999999986s
#
# 382
# Epoch duration =0.52s
# Cumulative duration =3min 20.909999999999997s
#
# 383
# Epoch duration =0.52s
# Cumulative duration =3min 21.419999999999987s
#
# 384
# Epoch duration =0.51s
# Cumulative duration =3min 21.939999999999998s
#
# 385
# Epoch duration =0.52s
# Cumulative duration =3min 22.44999999999999s
#
# 386
# Epoch duration =0.52s
# Cumulative duration =3min 22.97999999999999s
#
# 387
# Epoch duration =0.52s
# Cumulative duration =3min 23.5s
#
# 388
# Epoch duration =0.51s
# Cumulative duration =3min 24.00999999999999s
#
# 389
# Epoch duration =0.52s
# Cumulative duration =3min 24.53s
#
# 390
# Epoch duration =0.51s
# Cumulative duration =3min 25.05000000000001s
#
# 391
# Epoch duration =0.51s
# Cumulative duration =3min 25.560000000000002s
#
# 392
# Epoch duration =0.52s
# Cumulative duration =3min 26.080000000000013s
#
# 393
# Epoch duration =0.52s
# Cumulative duration =3min 26.599999999999994s
#
# 394
# Epoch duration =0.52s
# Cumulative duration =3min 27.110000000000014s
#
# 395
# Epoch duration =0.51s
# Cumulative duration =3min 27.629999999999995s
#
# 396
# Epoch duration =0.52s
# Cumulative duration =3min 28.139999999999986s
#
# 397
# Epoch duration =0.53s
# Cumulative duration =3min 28.669999999999987s
#
# 398
# Epoch duration =0.52s
# Cumulative duration =3min 29.189999999999998s
#
# 399
# Epoch duration =0.52s
# Cumulative duration =3min 29.710000000000008s
#
# 400
# Epoch duration =0.51s
# Cumulative duration =3min 30.22s
#
# 401
# Epoch duration =0.51s
# Cumulative duration =3min 30.74000000000001s
#
# 402
# Epoch duration =0.53s
# Cumulative duration =3min 31.27000000000001s
#
# 403
# Epoch duration =0.52s
# Cumulative duration =3min 31.789999999999992s
#
# 404
# Epoch duration =0.51s
# Cumulative duration =3min 32.30000000000001s
#
# 405
# Epoch duration =0.51s
# Cumulative duration =3min 32.81999999999999s
#
# 406
# Epoch duration =0.52s
# Cumulative duration =3min 33.34s
#
# 407
# Epoch duration =0.51s
# Cumulative duration =3min 33.849999999999994s
#
# 408
# Epoch duration =0.52s
# Cumulative duration =3min 34.370000000000005s
#
# 409
# Epoch duration =0.52s
# Cumulative duration =3min 34.879999999999995s
#
# 410
# Epoch duration =0.52s
# Cumulative duration =3min 35.400000000000006s
#
# 411
# Epoch duration =0.52s
# Cumulative duration =3min 35.91999999999999s
#
# 412
# Epoch duration =0.52s
# Cumulative duration =3min 36.44s
#
# 413
# Epoch duration =0.52s
# Cumulative duration =3min 36.96000000000001s
#
# 414
# Epoch duration =0.52s
# Cumulative duration =3min 37.47999999999999s
#
# 415
# Epoch duration =0.52s
# Cumulative duration =3min 37.99000000000001s
#
# 416
# Epoch duration =0.51s
# Cumulative duration =3min 38.50999999999999s
#
# 417
# Epoch duration =0.52s
# Cumulative duration =3min 39.03s
#
# 418
# Epoch duration =0.52s
# Cumulative duration =3min 39.53999999999999s
#
# 419
# Epoch duration =0.51s
# Cumulative duration =3min 40.06s
#
# 420
# Epoch duration =0.54s
# Cumulative duration =3min 40.59s
#
# 421
# Epoch duration =0.52s
# Cumulative duration =3min 41.110000000000014s
#
# 422
# Epoch duration =0.51s
# Cumulative duration =3min 41.629999999999995s
#
# 423
# Epoch duration =0.51s
# Cumulative duration =3min 42.139999999999986s
#
# 424
# Epoch duration =0.52s
# Cumulative duration =3min 42.66s
#
# 425
# Epoch duration =0.52s
# Cumulative duration =3min 43.18000000000001s
#
# 426
# Epoch duration =0.52s
# Cumulative duration =3min 43.69s
#
# 427
# Epoch duration =0.52s
# Cumulative duration =3min 44.22s
#
# 428
# Epoch duration =0.52s
# Cumulative duration =3min 44.74000000000001s
#
# 429
# Epoch duration =0.52s
# Cumulative duration =3min 45.25s
#
# 430
# Epoch duration =0.51s
# Cumulative duration =3min 45.77000000000001s
#
# 431
# Epoch duration =0.53s
# Cumulative duration =3min 46.30000000000001s
#
# 432
# Epoch duration =0.52s
# Cumulative duration =3min 46.81999999999999s
#
# 433
# Epoch duration =0.53s
# Cumulative duration =3min 47.349999999999994s
#
# 434
# Epoch duration =0.51s
# Cumulative duration =3min 47.860000000000014s
#
# 435
# Epoch duration =0.52s
# Cumulative duration =3min 48.379999999999995s
#
# 436
# Epoch duration =0.52s
# Cumulative duration =3min 48.900000000000006s
#
# 437
# Epoch duration =0.52s
# Cumulative duration =3min 49.41s
#
# 438
# Epoch duration =0.52s
# Cumulative duration =3min 49.93000000000001s
#
# 439
# Epoch duration =0.52s
# Cumulative duration =3min 50.44999999999999s
#
# 440
# Epoch duration =0.52s
# Cumulative duration =3min 50.97s
#
# 441
# Epoch duration =0.51s
# Cumulative duration =3min 51.47999999999999s
#
# 442
# Epoch duration =0.52s
# Cumulative duration =3min 52.0s
#
# 443
# Epoch duration =0.52s
# Cumulative duration =3min 52.52000000000001s
#
# 444
# Epoch duration =0.52s
# Cumulative duration =3min 53.03999999999999s
#
# 445
# Epoch duration =0.53s
# Cumulative duration =3min 53.56999999999999s
#
# 446
# Epoch duration =0.52s
# Cumulative duration =3min 54.09s
#
# 447
# Epoch duration =0.52s
# Cumulative duration =3min 54.610000000000014s
#
# 448
# Epoch duration =0.51s
# Cumulative duration =3min 55.120000000000005s
#
# 449
# Epoch duration =0.52s
# Cumulative duration =3min 55.639999999999986s
#
# 450
# Epoch duration =0.53s
# Cumulative duration =3min 56.16999999999999s
#
# 451
# Epoch duration =0.52s
# Cumulative duration =3min 56.69s
#
# 452
# Epoch duration =0.51s
# Cumulative duration =3min 57.19999999999999s
#
# 453
# Epoch duration =0.51s
# Cumulative duration =3min 57.71000000000001s
#
# 454
# Epoch duration =0.52s
# Cumulative duration =3min 58.22999999999999s
#
# 455
# Epoch duration =0.52s
# Cumulative duration =3min 58.75s
#
# 456
# Epoch duration =0.52s
# Cumulative duration =3min 59.27000000000001s
#
# 457
# Epoch duration =0.52s
# Cumulative duration =3min 59.78999999999999s
#
# 458
# Epoch duration =0.52s
# Cumulative duration =4min 0.30000000000001137s
#
# 459
# Epoch duration =0.52s
# Cumulative duration =4min 0.8300000000000125s
#
# 460
# Epoch duration =0.52s
# Cumulative duration =4min 1.3400000000000034s
#
# 461
# Epoch duration =0.52s
# Cumulative duration =4min 1.8700000000000045s
#
# 462
# Epoch duration =0.52s
# Cumulative duration =4min 2.3899999999999864s
#
# 463
# Epoch duration =0.52s
# Cumulative duration =4min 2.9000000000000057s
#
# 464
# Epoch duration =0.52s
# Cumulative duration =4min 3.4199999999999875s
#
# 465
# Epoch duration =0.51s
# Cumulative duration =4min 3.9399999999999977s
#
# 466
# Epoch duration =0.52s
# Cumulative duration =4min 4.449999999999989s
#
# 467
# Epoch duration =0.51s
# Cumulative duration =4min 4.969999999999999s
#
# 468
# Epoch duration =0.53s
# Cumulative duration =4min 5.490000000000009s
#
# 469
# Epoch duration =0.52s
# Cumulative duration =4min 6.009999999999991s
#
# 470
# Epoch duration =0.51s
# Cumulative duration =4min 6.52000000000001s
#
# 471
# Epoch duration =0.53s
# Cumulative duration =4min 7.060000000000002s
#
# 472
# Epoch duration =0.51s
# Cumulative duration =4min 7.569999999999993s
#
# 473
# Epoch duration =0.52s
# Cumulative duration =4min 8.090000000000003s
#
# 474
# Epoch duration =0.52s
# Cumulative duration =4min 8.599999999999994s
#
# 475
# Epoch duration =0.52s
# Cumulative duration =4min 9.120000000000005s
#
# 476
# Epoch duration =0.53s
# Cumulative duration =4min 9.650000000000006s
#
# 477
# Epoch duration =0.52s
# Cumulative duration =4min 10.169999999999987s
#
# 478
# Epoch duration =0.51s
# Cumulative duration =4min 10.680000000000007s
#
# 479
# Epoch duration =0.51s
# Cumulative duration =4min 11.199999999999989s
#
# 480
# Epoch duration =0.52s
# Cumulative duration =4min 11.710000000000008s
#
# 481
# Epoch duration =0.51s
# Cumulative duration =4min 12.22999999999999s
#
# 482
# Epoch duration =0.52s
# Cumulative duration =4min 12.740000000000009s
#
# 483
# Epoch duration =0.51s
# Cumulative duration =4min 13.259999999999991s
#
# 484
# Epoch duration =0.52s
# Cumulative duration =4min 13.77000000000001s
#
# 485
# Epoch duration =0.52s
# Cumulative duration =4min 14.289999999999992s
#
# 486
# Epoch duration =0.52s
# Cumulative duration =4min 14.810000000000002s
#
# 487
# Epoch duration =0.51s
# Cumulative duration =4min 15.330000000000013s
#
# 488
# Epoch duration =0.51s
# Cumulative duration =4min 15.840000000000003s
#
# 489
# Epoch duration =0.52s
# Cumulative duration =4min 16.360000000000014s
#
# 490
# Epoch duration =0.52s
# Cumulative duration =4min 16.870000000000005s
#
# 491
# Epoch duration =0.52s
# Cumulative duration =4min 17.389999999999986s
#
# 492
# Epoch duration =0.52s
# Cumulative duration =4min 17.920000000000016s
#
# 493
# Epoch duration =0.52s
# Cumulative duration =4min 18.430000000000007s
#
# 494
# Epoch duration =0.52s
# Cumulative duration =4min 18.94999999999999s
#
# 495
# Epoch duration =0.52s
# Cumulative duration =4min 19.45999999999998s
#
# 496
# Epoch duration =0.52s
# Cumulative duration =4min 19.980000000000018s
#
# 497
# Epoch duration =0.51s
# Cumulative duration =4min 20.5s
#
# 498
# Epoch duration =0.52s
# Cumulative duration =4min 21.00999999999999s
#
# 499
# Epoch duration =0.52s
# Cumulative duration =4min 21.529999999999973s
#
# 500
# Epoch duration =0.52s
# Cumulative duration =4min 22.04000000000002s
#
# 501
# Epoch duration =0.52s
# Cumulative duration =4min 22.560000000000002s
#
# 502
# Epoch duration =0.53s
# Cumulative duration =4min 23.089999999999975s
#
# 503
# Epoch duration =0.52s
# Cumulative duration =4min 23.620000000000005s
#
# 504
# Epoch duration =0.52s
# Cumulative duration =4min 24.129999999999995s
#
# 505
# Epoch duration =0.52s
# Cumulative duration =4min 24.660000000000025s
#
# 506
# Epoch duration =0.52s
# Cumulative duration =4min 25.180000000000007s
#
# 507
# Epoch duration =0.51s
# Cumulative duration =4min 25.689999999999998s
#
# 508
# Epoch duration =0.51s
# Cumulative duration =4min 26.19999999999999s
#
# 509
# Epoch duration =0.52s
# Cumulative duration =4min 26.720000000000027s
#
# 510
# Epoch duration =0.52s
# Cumulative duration =4min 27.24000000000001s
#
# 511
# Epoch duration =0.52s
# Cumulative duration =4min 27.75999999999999s
#
# 512
# Epoch duration =0.51s
# Cumulative duration =4min 28.269999999999982s
#
# 513
# Epoch duration =0.52s
# Cumulative duration =4min 28.80000000000001s
#
# 514
# Epoch duration =0.51s
# Cumulative duration =4min 29.310000000000002s
#
# 515
# Epoch duration =0.51s
# Cumulative duration =4min 29.829999999999984s
#
# 516
# Epoch duration =0.51s
# Cumulative duration =4min 30.339999999999975s
#
# 517
# Epoch duration =0.52s
# Cumulative duration =4min 30.860000000000014s
#
# 518
# Epoch duration =0.52s
# Cumulative duration =4min 31.370000000000005s
#
# 519
# Epoch duration =0.53s
# Cumulative duration =4min 31.910000000000025s
#
# 520
# Epoch duration =0.52s
# Cumulative duration =4min 32.43000000000001s
#
# 521
# Epoch duration =0.51s
# Cumulative duration =4min 32.94999999999999s
#
# 522
# Epoch duration =0.52s
# Cumulative duration =4min 33.45999999999998s
#
# 523
# Epoch duration =0.52s
# Cumulative duration =4min 33.98000000000002s
#
# 524
# Epoch duration =0.53s
# Cumulative duration =4min 34.50999999999999s
#
# 525
# Epoch duration =0.52s
# Cumulative duration =4min 35.02999999999997s
#
# 526
# Epoch duration =0.53s
# Cumulative duration =4min 35.56999999999999s
#
# 527
# Epoch duration =0.52s
# Cumulative duration =4min 36.089999999999975s
#
# 528
# Epoch duration =0.52s
# Cumulative duration =4min 36.60000000000002s
#
# 529
# Epoch duration =0.52s
# Cumulative duration =4min 37.120000000000005s
#
# 530
# Epoch duration =0.52s
# Cumulative duration =4min 37.639999999999986s
#
# 531
# Epoch duration =0.54s
# Cumulative duration =4min 38.18000000000001s
#
# 532
# Epoch duration =0.53s
# Cumulative duration =4min 38.70999999999998s
#
# 533
# Epoch duration =0.52s
# Cumulative duration =4min 39.22000000000003s
#
# 534
# Epoch duration =0.52s
# Cumulative duration =4min 39.74000000000001s
#
# 535
# Epoch duration =0.51s
# Cumulative duration =4min 40.25s
#
# 536
# Epoch duration =0.52s
# Cumulative duration =4min 40.77999999999997s
#
# 537
# Epoch duration =0.52s
# Cumulative duration =4min 41.29000000000002s
#
# 538
# Epoch duration =0.53s
# Cumulative duration =4min 41.81999999999999s
#
# 539
# Epoch duration =0.52s
# Cumulative duration =4min 42.339999999999975s
#
# 540
# Epoch duration =0.52s
# Cumulative duration =4min 42.860000000000014s
#
# 541
# Epoch duration =0.52s
# Cumulative duration =4min 43.370000000000005s
#
# 542
# Epoch duration =0.52s
# Cumulative duration =4min 43.889999999999986s
#
# 543
# Epoch duration =0.52s
# Cumulative duration =4min 44.410000000000025s
#
# 544
# Epoch duration =0.53s
# Cumulative duration =4min 44.94999999999999s
#
# 545
# Epoch duration =0.52s
# Cumulative duration =4min 45.45999999999998s
#
# 546
# Epoch duration =0.52s
# Cumulative duration =4min 45.98000000000002s
#
# 547
# Epoch duration =0.53s
# Cumulative duration =4min 46.50999999999999s
#
# 548
# Epoch duration =0.52s
# Cumulative duration =4min 47.02999999999997s
#
# 549
# Epoch duration =0.52s
# Cumulative duration =4min 47.55000000000001s
#
# 550
# Epoch duration =0.53s
# Cumulative duration =4min 48.079999999999984s
#
# 551
# Epoch duration =0.52s
# Cumulative duration =4min 48.60000000000002s
#
# 552
# Epoch duration =0.52s
# Cumulative duration =4min 49.120000000000005s
#
# 553
# Epoch duration =0.51s
# Cumulative duration =4min 49.629999999999995s
#
# 554
# Epoch duration =0.51s
# Cumulative duration =4min 50.14999999999998s
#
# 555
# Epoch duration =0.52s
# Cumulative duration =4min 50.660000000000025s
#
# 556
# Epoch duration =0.52s
# Cumulative duration =4min 51.18000000000001s
#
# 557
# Epoch duration =0.52s
# Cumulative duration =4min 51.69999999999999s
#
# 558
# Epoch duration =0.52s
# Cumulative duration =4min 52.22000000000003s
#
# 559
# Epoch duration =0.52s
# Cumulative duration =4min 52.74000000000001s
#
# 560
# Epoch duration =0.52s
# Cumulative duration =4min 53.25999999999999s
#
# 561
# Epoch duration =0.52s
# Cumulative duration =4min 53.77999999999997s
#
# 562
# Epoch duration =0.51s
# Cumulative duration =4min 54.29000000000002s
#
# 563
# Epoch duration =0.54s
# Cumulative duration =4min 54.829999999999984s
#
# 564
# Epoch duration =0.52s
# Cumulative duration =4min 55.35000000000002s
#
# 565
# Epoch duration =0.53s
# Cumulative duration =4min 55.870000000000005s
#
# 566
# Epoch duration =0.52s
# Cumulative duration =4min 56.39999999999998s
#
# 567
# Epoch duration =0.52s
# Cumulative duration =4min 56.920000000000016s
#
# 568
# Epoch duration =0.52s
# Cumulative duration =4min 57.44s
#
# 569
# Epoch duration =0.52s
# Cumulative duration =4min 57.95999999999998s
#
# 570
# Epoch duration =0.52s
# Cumulative duration =4min 58.48000000000002s
#
# 571
# Epoch duration =0.52s
# Cumulative duration =4min 58.99000000000001s
#
# 572
# Epoch duration =0.52s
# Cumulative duration =4min 59.50999999999999s
#
# 573
# Epoch duration =0.52s
# Cumulative duration =5min 0.029999999999972715s
#
# 574
# Epoch duration =0.52s
# Cumulative duration =5min 0.5500000000000114s
#
# 575
# Epoch duration =0.6s
# Cumulative duration =5min 1.1499999999999773s
#
# 576
# Epoch duration =0.61s
# Cumulative duration =5min 1.759999999999991s
#
# 577
# Epoch duration =0.64s
# Cumulative duration =5min 2.3999999999999773s
#
# 578
# Epoch duration =0.6s
# Cumulative duration =5min 3.009999999999991s
#
# 579
# Epoch duration =0.58s
# Cumulative duration =5min 3.579999999999984s
#
# 580
# Epoch duration =0.59s
# Cumulative duration =5min 4.170000000000016s
#
# 581
# Epoch duration =0.62s
# Cumulative duration =5min 4.800000000000011s
#
# 582
# Epoch duration =0.61s
# Cumulative duration =5min 5.410000000000025s
#
# 583
# Epoch duration =0.64s
# Cumulative duration =5min 6.050000000000011s
#
# 584
# Epoch duration =0.71s
# Cumulative duration =5min 6.759999999999991s
#
# 585
# Epoch duration =0.62s
# Cumulative duration =5min 7.3799999999999955s
#
# 586
# Epoch duration =0.55s
# Cumulative duration =5min 7.930000000000007s
#
# 587
# Epoch duration =0.56s
# Cumulative duration =5min 8.490000000000009s
#
# 588
# Epoch duration =0.58s
# Cumulative duration =5min 9.069999999999993s
#
# 589
# Epoch duration =0.53s
# Cumulative duration =5min 9.600000000000023s
#
# 590
# Epoch duration =0.53s
# Cumulative duration =5min 10.129999999999995s
#
# 591
# Epoch duration =0.52s
# Cumulative duration =5min 10.639999999999986s
#
# 592
# Epoch duration =0.52s
# Cumulative duration =5min 11.160000000000025s
#
# 593
# Epoch duration =0.52s
# Cumulative duration =5min 11.680000000000007s
#
# 594
# Epoch duration =0.52s
# Cumulative duration =5min 12.199999999999989s
#
# 595
# Epoch duration =0.52s
# Cumulative duration =5min 12.720000000000027s
#
# 596
# Epoch duration =0.53s
# Cumulative duration =5min 13.25s
#
# 597
# Epoch duration =0.52s
# Cumulative duration =5min 13.769999999999982s
#
# 598
# Epoch duration =0.52s
# Cumulative duration =5min 14.29000000000002s
#
# 599
# Epoch duration =0.53s
# Cumulative duration =5min 14.819999999999993s
#
# 600
# Epoch duration =0.52s
# Cumulative duration =5min 15.339999999999975s
#
# 601
# Epoch duration =0.53s
# Cumulative duration =5min 15.870000000000005s
#
# 602
# Epoch duration =0.52s
# Cumulative duration =5min 16.389999999999986s
#
# 603
# Epoch duration =0.53s
# Cumulative duration =5min 16.930000000000007s
#
# 604
# Epoch duration =0.54s
# Cumulative duration =5min 17.45999999999998s
#
# 605
# Epoch duration =0.53s
# Cumulative duration =5min 17.99000000000001s
#
# 606
# Epoch duration =0.59s
# Cumulative duration =5min 18.579999999999984s
#
# 607
# Epoch duration =0.57s
# Cumulative duration =5min 19.149999999999977s
#
# 608
# Epoch duration =0.53s
# Cumulative duration =5min 19.680000000000007s
#
# 609
# Epoch duration =0.59s
# Cumulative duration =5min 20.269999999999982s
#
# 610
# Epoch duration =0.55s
# Cumulative duration =5min 20.819999999999993s
#
# 611
# Epoch duration =0.53s
# Cumulative duration =5min 21.350000000000023s
#
# 612
# Epoch duration =0.54s
# Cumulative duration =5min 21.889999999999986s
#
# 613
# Epoch duration =0.54s
# Cumulative duration =5min 22.430000000000007s
#
# 614
# Epoch duration =0.52s
# Cumulative duration =5min 22.95999999999998s
#
# 615
# Epoch duration =0.52s
# Cumulative duration =5min 23.470000000000027s
#
# 616
# Epoch duration =0.52s
# Cumulative duration =5min 23.99000000000001s
#
# 617
# Epoch duration =0.53s
# Cumulative duration =5min 24.519999999999982s
#
# 618
# Epoch duration =0.53s
# Cumulative duration =5min 25.05000000000001s
#
# 619
# Epoch duration =0.52s
# Cumulative duration =5min 25.569999999999993s
#
# 620
# Epoch duration =0.52s
# Cumulative duration =5min 26.089999999999975s
#
# 621
# Epoch duration =0.52s
# Cumulative duration =5min 26.610000000000014s
#
# 622
# Epoch duration =0.52s
# Cumulative duration =5min 27.129999999999995s
#
# 623
# Epoch duration =0.54s
# Cumulative duration =5min 27.670000000000016s
#
# 624
# Epoch duration =0.52s
# Cumulative duration =5min 28.189999999999998s
#
# 625
# Epoch duration =0.52s
# Cumulative duration =5min 28.70999999999998s
#
# 626
# Epoch duration =0.52s
# Cumulative duration =5min 29.230000000000018s
#
# 627
# Epoch duration =0.53s
# Cumulative duration =5min 29.75s
#
# 628
# Epoch duration =0.52s
# Cumulative duration =5min 30.269999999999982s
#
# 629
# Epoch duration =0.52s
# Cumulative duration =5min 30.80000000000001s
#
# 630
# Epoch duration =0.52s
# Cumulative duration =5min 31.319999999999993s
#
# 631
# Epoch duration =0.52s
# Cumulative duration =5min 31.829999999999984s
#
# 632
# Epoch duration =0.51s
# Cumulative duration =5min 32.35000000000002s
#
# 633
# Epoch duration =0.53s
# Cumulative duration =5min 32.870000000000005s
#
# 634
# Epoch duration =0.52s
# Cumulative duration =5min 33.389999999999986s
#
# 635
# Epoch duration =0.52s
# Cumulative duration =5min 33.910000000000025s
#
# 636
# Epoch duration =0.53s
# Cumulative duration =5min 34.44s
#
# 637
# Epoch duration =0.52s
# Cumulative duration =5min 34.95999999999998s
#
# 638
# Epoch duration =0.51s
# Cumulative duration =5min 35.47000000000003s
#
# 639
# Epoch duration =0.52s
# Cumulative duration =5min 35.99000000000001s
#
# 640
# Epoch duration =0.52s
# Cumulative duration =5min 36.5s
#
# 641
# Epoch duration =0.51s
# Cumulative duration =5min 37.01999999999998s
#
# 642
# Epoch duration =0.52s
# Cumulative duration =5min 37.54000000000002s
#
# 643
# Epoch duration =0.51s
# Cumulative duration =5min 38.05000000000001s
#
# 644
# Epoch duration =0.52s
# Cumulative duration =5min 38.56999999999999s
#
# 645
# Epoch duration =0.52s
# Cumulative duration =5min 39.10000000000002s
#
# 646
# Epoch duration =0.52s
# Cumulative duration =5min 39.620000000000005s
#
# 647
# Epoch duration =0.52s
# Cumulative duration =5min 40.129999999999995s
#
# 648
# Epoch duration =0.52s
# Cumulative duration =5min 40.64999999999998s
#
# 649
# Epoch duration =0.51s
# Cumulative duration =5min 41.160000000000025s
#
# 650
# Epoch duration =0.52s
# Cumulative duration =5min 41.68000000000001s
#
# 651
# Epoch duration =0.52s
# Cumulative duration =5min 42.19999999999999s
#
# 652
# Epoch duration =0.53s
# Cumulative duration =5min 42.73000000000002s
#
# 653
# Epoch duration =0.52s
# Cumulative duration =5min 43.24000000000001s
#
# 654
# Epoch duration =0.51s
# Cumulative duration =5min 43.75999999999999s
#
# 655
# Epoch duration =0.51s
# Cumulative duration =5min 44.26999999999998s
#
# 656
# Epoch duration =0.52s
# Cumulative duration =5min 44.79000000000002s
#
# 657
# Epoch duration =0.52s
# Cumulative duration =5min 45.31s
#
# 658
# Epoch duration =0.52s
# Cumulative duration =5min 45.829999999999984s
#
# 659
# Epoch duration =0.52s
# Cumulative duration =5min 46.35000000000002s
#
# 660
# Epoch duration =0.52s
# Cumulative duration =5min 46.870000000000005s
#
# 661
# Epoch duration =0.52s
# Cumulative duration =5min 47.389999999999986s
#
# 662
# Epoch duration =0.52s
# Cumulative duration =5min 47.910000000000025s
#
# 663
# Epoch duration =0.52s
# Cumulative duration =5min 48.420000000000016s
#
# 664
# Epoch duration =0.51s
# Cumulative duration =5min 48.94s
#
# 665
# Epoch duration =0.52s
# Cumulative duration =5min 49.44999999999999s
#
# 666
# Epoch duration =0.52s
# Cumulative duration =5min 49.97000000000003s
#
# 667
# Epoch duration =0.52s
# Cumulative duration =5min 50.5s
#
# 668
# Epoch duration =0.51s
# Cumulative duration =5min 51.00999999999999s
#
# 669
# Epoch duration =0.52s
# Cumulative duration =5min 51.52999999999997s
#
# 670
# Epoch duration =0.51s
# Cumulative duration =5min 52.04000000000002s
#
# 671
# Epoch duration =0.52s
# Cumulative duration =5min 52.56s
#
# 672
# Epoch duration =0.51s
# Cumulative duration =5min 53.079999999999984s
#
# 673
# Epoch duration =0.52s
# Cumulative duration =5min 53.589999999999975s
#
# 674
# Epoch duration =0.52s
# Cumulative duration =5min 54.110000000000014s
#
# 675
# Epoch duration =0.51s
# Cumulative duration =5min 54.629999999999995s
#
# 676
# Epoch duration =0.52s
# Cumulative duration =5min 55.139999999999986s
#
# 677
# Epoch duration =0.52s
# Cumulative duration =5min 55.660000000000025s
#
# 678
# Epoch duration =0.52s
# Cumulative duration =5min 56.170000000000016s
#
# 679
# Epoch duration =0.52s
# Cumulative duration =5min 56.69s
#
# 680
# Epoch duration =0.51s
# Cumulative duration =5min 57.20999999999998s
#
# 681
# Epoch duration =0.52s
# Cumulative duration =5min 57.72000000000003s
#
# 682
# Epoch duration =0.51s
# Cumulative duration =5min 58.24000000000001s
#
# 683
# Epoch duration =0.52s
# Cumulative duration =5min 58.75s
#
# 684
# Epoch duration =0.52s
# Cumulative duration =5min 59.26999999999998s
#
# 685
# Epoch duration =0.51s
# Cumulative duration =5min 59.77999999999997s
#
# 686
# Epoch duration =0.52s
# Cumulative duration =6min 0.30000000000001137s
#
# 687
# Epoch duration =0.52s
# Cumulative duration =6min 0.8199999999999932s
#
# 688
# Epoch duration =0.51s
# Cumulative duration =6min 1.329999999999984s
#
# 689
# Epoch duration =0.52s
# Cumulative duration =6min 1.8500000000000227s
#
# 690
# Epoch duration =0.52s
# Cumulative duration =6min 2.3700000000000045s
#
# 691
# Epoch duration =0.53s
# Cumulative duration =6min 2.8999999999999773s
#
# 692
# Epoch duration =0.51s
# Cumulative duration =6min 3.420000000000016s
#
# 693
# Epoch duration =0.52s
# Cumulative duration =6min 3.9399999999999977s
#
# 694
# Epoch duration =0.52s
# Cumulative duration =6min 4.449999999999989s
#
# 695
# Epoch duration =0.51s
# Cumulative duration =6min 4.970000000000027s
#
# 696
# Epoch duration =0.52s
# Cumulative duration =6min 5.490000000000009s
#
# 697
# Epoch duration =0.52s
# Cumulative duration =6min 6.0s
#
# 698
# Epoch duration =0.51s
# Cumulative duration =6min 6.519999999999982s
#
# 699
# Epoch duration =0.52s
# Cumulative duration =6min 7.029999999999973s
#
# 700
# Epoch duration =0.52s
# Cumulative duration =6min 7.550000000000011s
#
# 701
# Epoch duration =0.52s
# Cumulative duration =6min 8.069999999999993s
#
# 702
# Epoch duration =0.52s
# Cumulative duration =6min 8.589999999999975s
#
# 703
# Epoch duration =0.51s
# Cumulative duration =6min 9.100000000000023s
#
# 704
# Epoch duration =0.52s
# Cumulative duration =6min 9.620000000000005s
#
# 705
# ...
#
# 1784
# Epoch duration =0.52s
# Cumulative duration =15min 36.120000000000005s
#
# 1785
# Epoch duration =0.52s
# Cumulative duration =15min 36.639999999999986s
#
# 1786
# Epoch duration =0.52s
# Cumulative duration =15min 37.15999999999997s
#
# 1787
# Epoch duration =0.52s
# Cumulative duration =15min 37.67999999999995s
#
# 1788
# Epoch duration =0.52s
# Cumulative duration =15min 38.190000000000055s
#
# 1789
# Epoch duration =0.52s
# Cumulative duration =15min 38.72000000000003s
#
# 1790
# Epoch duration =0.52s
# Cumulative duration =15min 39.24000000000001s
#
# 1791
# Epoch duration =0.52s
# Cumulative duration =15min 39.75999999999999s
#
# 1792
# Epoch duration =0.52s
# Cumulative duration =15min 40.26999999999998s
#
# 1793
# Epoch duration =0.52s
# Cumulative duration =15min 40.799999999999955s
#
# 1794
# Epoch duration =0.52s
# Cumulative duration =15min 41.309999999999945s
#
# 1795
# Epoch duration =0.53s
# Cumulative duration =15min 41.84000000000003s
#
# 1796
# Epoch duration =0.53s
# Cumulative duration =15min 42.360000000000014s
#
# 1797
# Epoch duration =0.52s
# Cumulative duration =15min 42.889999999999986s
#
# 1798
# Epoch duration =0.52s
# Cumulative duration =15min 43.40999999999997s
#
# 1799
# Epoch duration =0.52s
# Cumulative duration =15min 43.92999999999995s
#
# 1800
# Epoch duration =0.52s
# Cumulative duration =15min 44.450000000000045s
#
# 1801
# Epoch duration =0.52s
# Cumulative duration =15min 44.97000000000003s
#
# 1802
# Epoch duration =0.53s
# Cumulative duration =15min 45.5s
#
# 1803
# Epoch duration =0.53s
# Cumulative duration =15min 46.01999999999998s
#
# 1804
# Epoch duration =0.52s
# Cumulative duration =15min 46.539999999999964s
#
# 1805
# Epoch duration =0.52s
# Cumulative duration =15min 47.07000000000005s
#
# 1806
# Epoch duration =0.52s
# Cumulative duration =15min 47.59000000000003s
#
# 1807
# Epoch duration =0.52s
# Cumulative duration =15min 48.10000000000002s
#
# 1808
# Epoch duration =0.52s
# Cumulative duration =15min 48.620000000000005s
#
# 1809
# Epoch duration =0.52s
# Cumulative duration =15min 49.14999999999998s
#
# 1810
# Epoch duration =0.53s
# Cumulative duration =15min 49.67999999999995s
#
# 1811
# Epoch duration =0.52s
# Cumulative duration =15min 50.200000000000045s
#
# 1812
# Epoch duration =0.52s
# Cumulative duration =15min 50.72000000000003s
#
# 1813
# Epoch duration =0.52s
# Cumulative duration =15min 51.25s
#
# 1814
# Epoch duration =0.52s
# Cumulative duration =15min 51.76999999999998s
#
# 1815
# Epoch duration =0.52s
# Cumulative duration =15min 52.289999999999964s
#
# 1816
# Epoch duration =0.52s
# Cumulative duration =15min 52.809999999999945s
#
# 1817
# Epoch duration =0.52s
# Cumulative duration =15min 53.33000000000004s
#
# 1818
# Epoch duration =0.52s
# Cumulative duration =15min 53.85000000000002s
#
# 1819
# Epoch duration =0.52s
# Cumulative duration =15min 54.370000000000005s
#
# 1820
# Epoch duration =0.52s
# Cumulative duration =15min 54.89999999999998s
#
# 1821
# Epoch duration =0.52s
# Cumulative duration =15min 55.41999999999996s
#
# 1822
# Epoch duration =0.52s
# Cumulative duration =15min 55.940000000000055s
#
# 1823
# Epoch duration =0.52s
# Cumulative duration =15min 56.460000000000036s
#
# 1824
# Epoch duration =0.52s
# Cumulative duration =15min 56.98000000000002s
#
# 1825
# Epoch duration =0.52s
# Cumulative duration =15min 57.50999999999999s
#
# 1826
# Epoch duration =0.52s
# Cumulative duration =15min 58.01999999999998s
#
# 1827
# Epoch duration =0.52s
# Cumulative duration =15min 58.539999999999964s
#
# 1828
# Epoch duration =0.52s
# Cumulative duration =15min 59.059999999999945s
#
# 1829
# Epoch duration =0.54s
# Cumulative duration =15min 59.60000000000002s
#
# 1830
# Epoch duration =0.53s
# Cumulative duration =16min 0.12999999999999545s
#
# 1831
# Epoch duration =0.54s
# Cumulative duration =16min 0.6699999999999591s
#
# 1832
# Epoch duration =0.53s
# Cumulative duration =16min 1.2000000000000455s
#
# 1833
# Epoch duration =0.52s
# Cumulative duration =16min 1.7100000000000364s
#
# 1834
# Epoch duration =0.53s
# Cumulative duration =16min 2.240000000000009s
#
# 1835
# Epoch duration =0.52s
# Cumulative duration =16min 2.759999999999991s
#
# 1836
# Epoch duration =0.52s
# Cumulative duration =16min 3.269999999999982s
#
# 1837
# Epoch duration =0.52s
# Cumulative duration =16min 3.7899999999999636s
#
# 1838
# Epoch duration =0.52s
# Cumulative duration =16min 4.309999999999945s
#
# 1839
# Epoch duration =0.52s
# Cumulative duration =16min 4.830000000000041s
#
# 1840
# Epoch duration =0.52s
# Cumulative duration =16min 5.350000000000023s
#
# 1841
# Epoch duration =0.53s
# Cumulative duration =16min 5.8799999999999955s
#
# 1842
# Epoch duration =0.52s
# Cumulative duration =16min 6.399999999999977s
#
# 1843
# Epoch duration =0.53s
# Cumulative duration =16min 6.940000000000055s
#
# 1844
# Epoch duration =0.52s
# Cumulative duration =16min 7.460000000000036s
#
# 1845
# Epoch duration =0.52s
# Cumulative duration =16min 7.980000000000018s
#
# 1846
# Epoch duration =0.52s
# Cumulative duration =16min 8.5s
#
# 1847
# Epoch duration =0.52s
# Cumulative duration =16min 9.019999999999982s
#
# 1848
# Epoch duration =0.52s
# Cumulative duration =16min 9.539999999999964s
#
# 1849
# Epoch duration =0.52s
# Cumulative duration =16min 10.059999999999945s
#
# 1850
# Epoch duration =0.52s
# Cumulative duration =16min 10.590000000000032s
#
# 1851
# Epoch duration =0.52s
# Cumulative duration =16min 11.110000000000014s
#
# 1852
# Epoch duration =0.53s
# Cumulative duration =16min 11.629999999999995s
#
# 1853
# Epoch duration =0.53s
# Cumulative duration =16min 12.159999999999968s
#
# 1854
# Epoch duration =0.53s
# Cumulative duration =16min 12.690000000000055s
#
# 1855
# Epoch duration =0.52s
# Cumulative duration =16min 13.210000000000036s
#
# 1856
# Epoch duration =0.52s
# Cumulative duration =16min 13.740000000000009s
#
# 1857
# Epoch duration =0.52s
# Cumulative duration =16min 14.259999999999991s
#
# 1858
# Epoch duration =0.53s
# Cumulative duration =16min 14.789999999999964s
#
# 1859
# Epoch duration =0.52s
# Cumulative duration =16min 15.309999999999945s
#
# 1860
# Epoch duration =0.52s
# Cumulative duration =16min 15.830000000000041s
#
# 1861
# Epoch duration =0.52s
# Cumulative duration =16min 16.350000000000023s
#
# 1862
# Epoch duration =0.52s
# Cumulative duration =16min 16.870000000000005s
#
# 1863
# Epoch duration =0.53s
# Cumulative duration =16min 17.389999999999986s
#
# 1864
# Epoch duration =0.52s
# Cumulative duration =16min 17.909999999999968s
#
# 1865
# Epoch duration =0.52s
# Cumulative duration =16min 18.440000000000055s
#
# 1866
# Epoch duration =0.52s
# Cumulative duration =16min 18.960000000000036s
#
# 1867
# Epoch duration =0.52s
# Cumulative duration =16min 19.480000000000018s
#
# 1868
# Epoch duration =0.54s
# Cumulative duration =16min 20.00999999999999s
#
# 1869
# Epoch duration =0.52s
# Cumulative duration =16min 20.529999999999973s
#
# 1870
# Epoch duration =0.52s
# Cumulative duration =16min 21.049999999999955s
#
# 1871
# Epoch duration =0.53s
# Cumulative duration =16min 21.58000000000004s
#
# 1872
# Epoch duration =0.52s
# Cumulative duration =16min 22.100000000000023s
#
# 1873
# Epoch duration =0.52s
# Cumulative duration =16min 22.620000000000005s
#
# 1874
# Epoch duration =0.54s
# Cumulative duration =16min 23.159999999999968s
#
# 1875
# Epoch duration =0.52s
# Cumulative duration =16min 23.67999999999995s
#
# 1876
# Epoch duration =0.52s
# Cumulative duration =16min 24.200000000000045s
#
# 1877
# Epoch duration =0.53s
# Cumulative duration =16min 24.730000000000018s
#
# 1878
# Epoch duration =0.53s
# Cumulative duration =16min 25.25999999999999s
#
# 1879
# Epoch duration =0.52s
# Cumulative duration =16min 25.779999999999973s
#
# 1880
# Epoch duration =0.53s
# Cumulative duration =16min 26.309999999999945s
#
# 1881
# Epoch duration =0.52s
# Cumulative duration =16min 26.83000000000004s
#
# 1882
# Epoch duration =0.52s
# Cumulative duration =16min 27.350000000000023s
#
# 1883
# Epoch duration =0.53s
# Cumulative duration =16min 27.879999999999995s
#
# 1884
# Epoch duration =0.52s
# Cumulative duration =16min 28.399999999999977s
#
# 1885
# Epoch duration =0.52s
# Cumulative duration =16min 28.909999999999968s
#
# 1886
# Epoch duration =0.53s
# Cumulative duration =16min 29.440000000000055s
#
# 1887
# Epoch duration =0.52s
# Cumulative duration =16min 29.960000000000036s
#
# 1888
# Epoch duration =0.52s
# Cumulative duration =16min 30.480000000000018s
#
# 1889
# Epoch duration =0.52s
# Cumulative duration =16min 31.0s
#
# 1890
# Epoch duration =0.52s
# Cumulative duration =16min 31.519999999999982s
#
# 1891
# Epoch duration =0.53s
# Cumulative duration =16min 32.049999999999955s
#
# 1892
# Epoch duration =0.52s
# Cumulative duration =16min 32.57000000000005s
#
# 1893
# Epoch duration =0.52s
# Cumulative duration =16min 33.09000000000003s
#
# 1894
# Epoch duration =0.52s
# Cumulative duration =16min 33.610000000000014s
#
# 1895
# Epoch duration =0.52s
# Cumulative duration =16min 34.129999999999995s
#
# 1896
# Epoch duration =0.53s
# Cumulative duration =16min 34.65999999999997s
#
# 1897
# Epoch duration =0.52s
# Cumulative duration =16min 35.16999999999996s
#
# 1898
# Epoch duration =0.52s
# Cumulative duration =16min 35.690000000000055s
#
# 1899
# Epoch duration =0.53s
# Cumulative duration =16min 36.22000000000003s
#
# 1900
# Epoch duration =0.52s
# Cumulative duration =16min 36.74000000000001s
#
# 1901
# Epoch duration =0.52s
# Cumulative duration =16min 37.25999999999999s
#
# 1902
# Epoch duration =0.52s
# Cumulative duration =16min 37.77999999999997s
#
# 1903
# Epoch duration =0.52s
# Cumulative duration =16min 38.289999999999964s
#
# 1904
# Epoch duration =0.53s
# Cumulative duration =16min 38.82000000000005s
#
# 1905
# Epoch duration =0.62s
# Cumulative duration =16min 39.440000000000055s
#
# 1906
# Epoch duration =0.59s
# Cumulative duration =16min 40.039999999999964s
#
# 1907
# Epoch duration =0.58s
# Cumulative duration =16min 40.610000000000014s
#
# 1908
# Epoch duration =0.55s
# Cumulative duration =16min 41.16999999999996s
#
# 1909
# Epoch duration =0.58s
# Cumulative duration =16min 41.75s
#
# 1910
# Epoch duration =0.63s
# Cumulative duration =16min 42.379999999999995s
#
# 1911
# Epoch duration =0.61s
# Cumulative duration =16min 42.99000000000001s
#
# 1912
# Epoch duration =0.65s
# Cumulative duration =16min 43.639999999999986s
#
# 1913
# Epoch duration =0.52s
# Cumulative duration =16min 44.15999999999997s
#
# 1914
# Epoch duration =0.52s
# Cumulative duration =16min 44.690000000000055s
#
# 1915
# Epoch duration =0.52s
# Cumulative duration =16min 45.200000000000045s
#
# 1916
# Epoch duration =0.52s
# Cumulative duration =16min 45.72000000000003s
#
# 1917
# Epoch duration =0.52s
# Cumulative duration =16min 46.24000000000001s
#
# 1918
# Epoch duration =0.52s
# Cumulative duration =16min 46.76999999999998s
#
# 1919
# Epoch duration =0.53s
# Cumulative duration =16min 47.289999999999964s
#
# 1920
# Epoch duration =0.52s
# Cumulative duration =16min 47.82000000000005s
#
# 1921
# Epoch duration =0.52s
# Cumulative duration =16min 48.34000000000003s
#
# 1922
# Epoch duration =0.52s
# Cumulative duration =16min 48.860000000000014s
#
# 1923
# Epoch duration =0.52s
# Cumulative duration =16min 49.379999999999995s
#
# 1924
# Epoch duration =0.52s
# Cumulative duration =16min 49.90999999999997s
#
# 1925
# Epoch duration =0.52s
# Cumulative duration =16min 50.42999999999995s
#
# 1926
# Epoch duration =0.52s
# Cumulative duration =16min 50.950000000000045s
#
# 1927
# Epoch duration =0.52s
# Cumulative duration =16min 51.47000000000003s
#
# 1928
# Epoch duration =0.52s
# Cumulative duration =16min 51.99000000000001s
#
# 1929
# Epoch duration =0.52s
# Cumulative duration =16min 52.50999999999999s
#
# 1930
# Epoch duration =0.52s
# Cumulative duration =16min 53.02999999999997s
#
# 1931
# Epoch duration =0.51s
# Cumulative duration =16min 53.539999999999964s
#
# 1932
# Epoch duration =0.52s
# Cumulative duration =16min 54.059999999999945s
#
# 1933
# Epoch duration =0.52s
# Cumulative duration =16min 54.58000000000004s
#
# 1934
# Epoch duration =0.52s
# Cumulative duration =16min 55.110000000000014s
#
# 1935
# Epoch duration =0.53s
# Cumulative duration =16min 55.629999999999995s
#
# 1936
# Epoch duration =0.54s
# Cumulative duration =16min 56.16999999999996s
#
# 1937
# Epoch duration =0.52s
# Cumulative duration =16min 56.690000000000055s
#
# 1938
# Epoch duration =0.52s
# Cumulative duration =16min 57.210000000000036s
#
# 1939
# Epoch duration =0.52s
# Cumulative duration =16min 57.73000000000002s
#
# 1940
# Epoch duration =0.53s
# Cumulative duration =16min 58.25s
#
# 1941
# Epoch duration =0.52s
# Cumulative duration =16min 58.76999999999998s
#
# 1942
# Epoch duration =0.52s
# Cumulative duration =16min 59.289999999999964s
#
# 1943
# Epoch duration =0.52s
# Cumulative duration =16min 59.809999999999945s
#
# 1944
# Epoch duration =0.52s
# Cumulative duration =17min 0.3300000000000409s
#
# 1945
# Epoch duration =0.52s
# Cumulative duration =17min 0.8500000000000227s
#
# 1946
# Epoch duration =0.52s
# Cumulative duration =17min 1.3700000000000045s
#
# 1947
# Epoch duration =0.52s
# Cumulative duration =17min 1.8899999999999864s
#
# 1948
# Epoch duration =0.52s
# Cumulative duration =17min 2.409999999999968s
#
# 1949
# Epoch duration =0.53s
# Cumulative duration =17min 2.9400000000000546s
#
# 1950
# Epoch duration =0.52s
# Cumulative duration =17min 3.4600000000000364s
#
# 1951
# Epoch duration =0.52s
# Cumulative duration =17min 3.980000000000018s
#
# 1952
# Epoch duration =0.52s
# Cumulative duration =17min 4.5s
#
# 1953
# Epoch duration =0.53s
# Cumulative duration =17min 5.019999999999982s
#
# 1954
# Epoch duration =0.53s
# Cumulative duration =17min 5.5499999999999545s
#
# 1955
# Epoch duration =0.54s
# Cumulative duration =17min 6.089999999999918s
#
# 1956
# Epoch duration =0.58s
# Cumulative duration =17min 6.670000000000073s
#
# 1957
# Epoch duration =0.58s
# Cumulative duration =17min 7.25s
#
# 1958
# Epoch duration =0.55s
# Cumulative duration =17min 7.7999999999999545s
#
# 1959
# Epoch duration =0.6s
# Cumulative duration =17min 8.400000000000091s
#
# 1960
# Epoch duration =0.61s
# Cumulative duration =17min 9.0s
#
# 1961
# Epoch duration =0.64s
# Cumulative duration =17min 9.6400000000001s
#
# 1962
# Epoch duration =0.54s
# Cumulative duration =17min 10.180000000000064s
#
# 1963
# Epoch duration =0.52s
# Cumulative duration =17min 10.700000000000045s
#
# 1964
# Epoch duration =0.52s
# Cumulative duration =17min 11.220000000000027s
#
# 1965
# Epoch duration =0.52s
# Cumulative duration =17min 11.740000000000009s
#
# 1966
# Epoch duration =0.52s
# Cumulative duration =17min 12.259999999999991s
#
# 1967
# Epoch duration =0.52s
# Cumulative duration =17min 12.779999999999973s
#
# 1968
# Epoch duration =0.52s
# Cumulative duration =17min 13.299999999999955s
#
# 1969
# Epoch duration =0.52s
# Cumulative duration =17min 13.819999999999936s
#
# 1970
# Epoch duration =0.52s
# Cumulative duration =17min 14.339999999999918s
#
# 1971
# Epoch duration =0.52s
# Cumulative duration =17min 14.8599999999999s
#
# 1972
# Epoch duration =0.52s
# Cumulative duration =17min 15.38000000000011s
#
# 1973
# Epoch duration =0.53s
# Cumulative duration =17min 15.920000000000073s
#
# 1974
# Epoch duration =0.52s
# Cumulative duration =17min 16.430000000000064s
#
# 1975
# Epoch duration =0.52s
# Cumulative duration =17min 16.950000000000045s
#
# 1976
# Epoch duration =0.52s
# Cumulative duration =17min 17.480000000000018s
#
# 1977
# Epoch duration =0.53s
# Cumulative duration =17min 18.0s
#
# 1978
# Epoch duration =0.52s
# Cumulative duration =17min 18.519999999999982s
#
# 1979
# Epoch duration =0.52s
# Cumulative duration =17min 19.039999999999964s
#
# 1980
# Epoch duration =0.52s
# Cumulative duration =17min 19.569999999999936s
#
# 1981
# Epoch duration =0.52s
# Cumulative duration =17min 20.089999999999918s
#
# 1982
# Epoch duration =0.52s
# Cumulative duration =17min 20.6099999999999s
#
# 1983
# Epoch duration =0.52s
# Cumulative duration =17min 21.13000000000011s
#
# 1984
# Epoch duration =0.52s
# Cumulative duration =17min 21.65000000000009s
#
# 1985
# Epoch duration =0.54s
# Cumulative duration =17min 22.190000000000055s
#
# 1986
# Epoch duration =0.53s
# Cumulative duration =17min 22.720000000000027s
#
# 1987
# Epoch duration =0.52s
# Cumulative duration =17min 23.230000000000018s
#
# 1988
# Epoch duration =0.52s
# Cumulative duration =17min 23.75s
#
# 1989
# Epoch duration =0.53s
# Cumulative duration =17min 24.279999999999973s
#
# 1990
# Epoch duration =0.52s
# Cumulative duration =17min 24.809999999999945s
#
# 1991
# Epoch duration =0.52s
# Cumulative duration =17min 25.329999999999927s
#
# 1992
# Epoch duration =0.52s
# Cumulative duration =17min 25.84999999999991s
#
# 1993
# Epoch duration =0.52s
# Cumulative duration =17min 26.3599999999999s
#
# 1994
# Epoch duration =0.52s
# Cumulative duration =17min 26.88000000000011s
#
# 1995
# Epoch duration =0.52s
# Cumulative duration =17min 27.40000000000009s
#
# 1996
# Epoch duration =0.53s
# Cumulative duration =17min 27.930000000000064s
#
# 1997
# Epoch duration =0.52s
# Cumulative duration =17min 28.450000000000045s
#
# 1998
# Epoch duration =0.52s
# Cumulative duration =17min 28.980000000000018s
#
# 1999
# Epoch duration =0.53s
# Cumulative duration =17min 29.5s
#
# Saving scores to Arrays/toypk_resbind_so2k.npy

# %%
#Load the saved data
num_summary = 2000
arrayspath = 'Arrays/%s_%s_so%.0fk.npy'%(exp_folder, modelarch, num_summary/1000)
mean_mut2 = np.load(arrayspath)

#average the values
#mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(seqlen,seqlen,4,4)

#Normalize
normalize = True
if normalize:
    meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, nntrainer, sess, normfactor=1)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((meanhol_mut2*bpfilter).reshape(seqlen,seqlen,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C,vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')

# %%
mf.square_holplot(meanhol_mut2, num=6, alphabet='rna', start=(5,25), cbar=True, cmap='hot', limits=(np.log(0.25),0.))

# %%
blocklen = np.sqrt(np.product(meanhol_mut2.shape)).astype(int)
S = np.zeros((blocklen, blocklen))
i,j,k,l = meanhol_mut2.shape

for ii in range(i):
    for jj in range(j):
        for kk in range(k):
            for ll in range(l):
                S[(4*ii)+kk, (4*jj)+ll] = meanhol_mut2[ii,jj,kk,ll]

plt.figure(figsize=(15,15))
plt.imshow(S,  cmap='RdPu')
plt.colorbar()
