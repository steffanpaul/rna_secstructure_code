# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import mutagenesis_functions as mf
import time as time

# %%
# load hairpin data
data_path = '../data_peter/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected_1_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=15, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_44_best.ckpt
#   test  loss:		0.00374
#   test  accuracy:	1.00000+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %% [markdown]
# ## First order mutagenesis saliency

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
numplots=5

for ii in range(numplots): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='output', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Second Order Mutagenesis

# %%
savepath = 'Arrays/toyhairpin_FC_1_44_sumoutputs5k.npy'

num_summary = 5000
X = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average(X, savepath, nntrainer, sess, progress='on')
# Out:
# 0
# Epoch duration =0.15s
# Cumulative duration =0.15s
#
# 1
# Epoch duration =0.14s
# Cumulative duration =0.29s
#
# 2
# Epoch duration =0.13s
# Cumulative duration =0.42s
#
# 3
# Epoch duration =0.14s
# Cumulative duration =0.56s
#
# 4
# Epoch duration =0.13s
# Cumulative duration =0.69s
#
# 5
# Epoch duration =0.14s
# Cumulative duration =0.83s
#
# 6
# Epoch duration =0.14s
# Cumulative duration =0.97s
#
# 7
# Epoch duration =0.13s
# Cumulative duration =1.1s
#
# 8
# Epoch duration =0.14s
# Cumulative duration =1.24s
#
# 9
# Epoch duration =0.14s
# Cumulative duration =1.38s
#
# 10
# Epoch duration =0.13s
# Cumulative duration =1.51s
#
# 11
# Epoch duration =0.13s
# Cumulative duration =1.64s
#
# 12
# Epoch duration =0.13s
# Cumulative duration =1.77s
#
# 13
# Epoch duration =0.14s
# Cumulative duration =1.91s
#
# 14
# Epoch duration =0.13s
# Cumulative duration =2.04s
#
# 15
# Epoch duration =0.14s
# Cumulative duration =2.18s
#
# 16
# Epoch duration =0.13s
# Cumulative duration =2.31s
#
# 17
# Epoch duration =0.14s
# Cumulative duration =2.45s
#
# 18
# Epoch duration =0.14s
# Cumulative duration =2.59s
#
# 19
# Epoch duration =0.19s
# Cumulative duration =2.78s
#
# 20
# Epoch duration =0.18s
# Cumulative duration =2.96s
#
# 21
# Epoch duration =0.18s
# Cumulative duration =3.14s
#
# 22
# Epoch duration =0.15s
# Cumulative duration =3.29s
#
# 23
# Epoch duration =0.14s
# Cumulative duration =3.42s
#
# 24
# Epoch duration =0.13s
# Cumulative duration =3.56s
#
# 25
# Epoch duration =0.14s
# Cumulative duration =3.69s
#
# 26
# Epoch duration =0.13s
# Cumulative duration =3.83s
#
# 27
# Epoch duration =0.14s
# Cumulative duration =3.97s
#
# 28
# Epoch duration =0.13s
# Cumulative duration =4.1s
#
# 29
# Epoch duration =0.14s
# Cumulative duration =4.24s
#
# 30
# Epoch duration =0.14s
# Cumulative duration =4.38s
#
# 31
# Epoch duration =0.14s
# Cumulative duration =4.52s
#
# 32
# Epoch duration =0.13s
# Cumulative duration =4.65s
#
# 33
# Epoch duration =0.14s
# Cumulative duration =4.79s
#
# 34
# Epoch duration =0.13s
# Cumulative duration =4.92s
#
# 35
# Epoch duration =0.13s
# Cumulative duration =5.05s
#
# 36
# Epoch duration =0.13s
# Cumulative duration =5.18s
#
# 37
# Epoch duration =0.13s
# Cumulative duration =5.31s
#
# 38
# Epoch duration =0.13s
# Cumulative duration =5.44s
#
# 39
# Epoch duration =0.13s
# Cumulative duration =5.57s
#
# 40
# Epoch duration =0.13s
# Cumulative duration =5.7s
#
# 41
# Epoch duration =0.13s
# Cumulative duration =5.84s
#
# 42
# Epoch duration =0.13s
# Cumulative duration =5.97s
#
# 43
# Epoch duration =0.13s
# Cumulative duration =6.11s
#
# 44
# Epoch duration =0.13s
# Cumulative duration =6.23s
#
# 45
# Epoch duration =0.13s
# Cumulative duration =6.37s
#
# 46
# Epoch duration =0.13s
# Cumulative duration =6.5s
#
# 47
# Epoch duration =0.13s
# Cumulative duration =6.63s
#
# 48
# Epoch duration =0.13s
# Cumulative duration =6.76s
#
# 49
# Epoch duration =0.14s
# Cumulative duration =6.9s
#
# 50
# Epoch duration =0.13s
# Cumulative duration =7.04s
#
# 51
# Epoch duration =0.13s
# Cumulative duration =7.17s
#
# 52
# Epoch duration =0.13s
# Cumulative duration =7.3s
#
# 53
# Epoch duration =0.13s
# Cumulative duration =7.43s
#
# 54
# Epoch duration =0.13s
# Cumulative duration =7.56s
#
# 55
# Epoch duration =0.13s
# Cumulative duration =7.69s
#
# 56
# Epoch duration =0.13s
# Cumulative duration =7.83s
#
# 57
# Epoch duration =0.13s
# Cumulative duration =7.96s
#
# 58
# Epoch duration =0.13s
# Cumulative duration =8.09s
#
# 59
# Epoch duration =0.15s
# Cumulative duration =8.24s
#
# 60
# Epoch duration =0.13s
# Cumulative duration =8.37s
#
# 61
# Epoch duration =0.14s
# Cumulative duration =8.51s
#
# 62
# Epoch duration =0.14s
# Cumulative duration =8.65s
#
# 63
# Epoch duration =0.17s
# Cumulative duration =8.82s
#
# 64
# Epoch duration =0.15s
# Cumulative duration =8.96s
#
# 65
# Epoch duration =0.16s
# Cumulative duration =9.12s
#
# 66
# Epoch duration =0.16s
# Cumulative duration =9.28s
#
# 67
# Epoch duration =0.16s
# Cumulative duration =9.44s
#
# 68
# Epoch duration =0.15s
# Cumulative duration =9.6s
#
# 69
# Epoch duration =0.14s
# Cumulative duration =9.73s
#
# 70
# Epoch duration =0.13s
# Cumulative duration =9.86s
#
# 71
# Epoch duration =0.14s
# Cumulative duration =10.01s
#
# 72
# Epoch duration =0.17s
# Cumulative duration =10.18s
#
# 73
# Epoch duration =0.14s
# Cumulative duration =10.31s
#
# 74
# Epoch duration =0.13s
# Cumulative duration =10.44s
#
# 75
# Epoch duration =0.13s
# Cumulative duration =10.58s
#
# 76
# Epoch duration =0.13s
# Cumulative duration =10.71s
#
# 77
# Epoch duration =0.13s
# Cumulative duration =10.84s
#
# 78
# Epoch duration =0.14s
# Cumulative duration =10.99s
#
# 79
# Epoch duration =0.14s
# Cumulative duration =11.13s
#
# 80
# Epoch duration =0.13s
# Cumulative duration =11.26s
#
# 81
# Epoch duration =0.14s
# Cumulative duration =11.4s
#
# 82
# Epoch duration =0.13s
# Cumulative duration =11.53s
#
# 83
# Epoch duration =0.14s
# Cumulative duration =11.68s
#
# 84
# Epoch duration =0.13s
# Cumulative duration =11.8s
#
# 85
# Epoch duration =0.13s
# Cumulative duration =11.93s
#
# 86
# Epoch duration =0.13s
# Cumulative duration =12.07s
#
# 87
# Epoch duration =0.13s
# Cumulative duration =12.2s
#
# 88
# Epoch duration =0.13s
# Cumulative duration =12.33s
#
# 89
# Epoch duration =0.13s
# Cumulative duration =12.46s
#
# 90
# Epoch duration =0.13s
# Cumulative duration =12.59s
#
# 91
# Epoch duration =0.13s
# Cumulative duration =12.72s
#
# 92
# Epoch duration =0.13s
# Cumulative duration =12.86s
#
# 93
# Epoch duration =0.14s
# Cumulative duration =12.99s
#
# 94
# Epoch duration =0.13s
# Cumulative duration =13.13s
#
# 95
# Epoch duration =0.17s
# Cumulative duration =13.3s
#
# 96
# Epoch duration =0.13s
# Cumulative duration =13.43s
#
# 97
# Epoch duration =0.14s
# Cumulative duration =13.57s
#
# 98
# Epoch duration =0.13s
# Cumulative duration =13.7s
#
# 99
# Epoch duration =0.13s
# Cumulative duration =13.83s
#
# 100
# Epoch duration =0.13s
# Cumulative duration =13.96s
#
# 101
# Epoch duration =0.13s
# Cumulative duration =14.1s
#
# 102
# Epoch duration =0.13s
# Cumulative duration =14.23s
#
# 103
# Epoch duration =0.14s
# Cumulative duration =14.36s
#
# 104
# Epoch duration =0.15s
# Cumulative duration =14.51s
#
# 105
# Epoch duration =0.14s
# Cumulative duration =14.65s
#
# 106
# Epoch duration =0.13s
# Cumulative duration =14.78s
#
# 107
# Epoch duration =0.13s
# Cumulative duration =14.91s
#
# 108
# Epoch duration =0.13s
# Cumulative duration =15.04s
#
# 109
# Epoch duration =0.14s
# Cumulative duration =15.18s
#
# 110
# Epoch duration =0.13s
# Cumulative duration =15.32s
#
# 111
# Epoch duration =0.14s
# Cumulative duration =15.46s
#
# 112
# Epoch duration =0.13s
# Cumulative duration =15.59s
#
# 113
# Epoch duration =0.13s
# Cumulative duration =15.72s
#
# 114
# Epoch duration =0.14s
# Cumulative duration =15.86s
#
# 115
# Epoch duration =0.13s
# Cumulative duration =15.99s
#
# 116
# Epoch duration =0.13s
# Cumulative duration =16.12s
#
# 117
# Epoch duration =0.13s
# Cumulative duration =16.26s
#
# 118
# Epoch duration =0.13s
# Cumulative duration =16.39s
#
# 119
# Epoch duration =0.14s
# Cumulative duration =16.53s
#
# 120
# Epoch duration =0.13s
# Cumulative duration =16.66s
#
# 121
# Epoch duration =0.13s
# Cumulative duration =16.79s
#
# 122
# Epoch duration =0.13s
# Cumulative duration =16.93s
#
# 123
# Epoch duration =0.14s
# Cumulative duration =17.06s
#
# 124
# Epoch duration =0.14s
# Cumulative duration =17.21s
#
# 125
# Epoch duration =0.15s
# Cumulative duration =17.35s
#
# 126
# Epoch duration =0.14s
# Cumulative duration =17.49s
#
# 127
# Epoch duration =0.15s
# Cumulative duration =17.64s
#
# 128
# Epoch duration =0.13s
# Cumulative duration =17.77s
#
# 129
# Epoch duration =0.14s
# Cumulative duration =17.91s
#
# 130
# Epoch duration =0.14s
# Cumulative duration =18.05s
#
# 131
# Epoch duration =0.14s
# Cumulative duration =18.19s
#
# 132
# Epoch duration =0.13s
# Cumulative duration =18.32s
#
# 133
# Epoch duration =0.13s
# Cumulative duration =18.45s
#
# 134
# Epoch duration =0.13s
# Cumulative duration =18.59s
#
# 135
# Epoch duration =0.14s
# Cumulative duration =18.72s
#
# 136
# Epoch duration =0.13s
# Cumulative duration =18.86s
#
# 137
# Epoch duration =0.13s
# Cumulative duration =18.99s
#
# 138
# Epoch duration =0.13s
# Cumulative duration =19.12s
#
# 139
# Epoch duration =0.14s
# Cumulative duration =19.26s
#
# 140
# Epoch duration =0.13s
# Cumulative duration =19.38s
#
# 141
# Epoch duration =0.14s
# Cumulative duration =19.53s
#
# 142
# Epoch duration =0.13s
# Cumulative duration =19.66s
#
# 143
# Epoch duration =0.14s
# Cumulative duration =19.79s
#
# 144
# Epoch duration =0.13s
# Cumulative duration =19.92s
#
# 145
# Epoch duration =0.13s
# Cumulative duration =20.06s
#
# 146
# Epoch duration =0.13s
# Cumulative duration =20.19s
#
# 147
# Epoch duration =0.13s
# Cumulative duration =20.32s
#
# 148
# Epoch duration =0.13s
# Cumulative duration =20.45s
#
# 149
# Epoch duration =0.14s
# Cumulative duration =20.59s
#
# 150
# Epoch duration =0.13s
# Cumulative duration =20.72s
#
# 151
# Epoch duration =0.13s
# Cumulative duration =20.85s
#
# 152
# Epoch duration =0.14s
# Cumulative duration =20.98s
#
# 153
# Epoch duration =0.13s
# Cumulative duration =21.11s
#
# 154
# Epoch duration =0.13s
# Cumulative duration =21.25s
#
# 155
# Epoch duration =0.13s
# Cumulative duration =21.38s
#
# 156
# Epoch duration =0.13s
# Cumulative duration =21.52s
#
# 157
# Epoch duration =0.13s
# Cumulative duration =21.65s
#
# 158
# Epoch duration =0.13s
# Cumulative duration =21.78s
#
# 159
# Epoch duration =0.13s
# Cumulative duration =21.92s
#
# 160
# Epoch duration =0.16s
# Cumulative duration =22.07s
#
# 161
# Epoch duration =0.13s
# Cumulative duration =22.2s
#
# 162
# Epoch duration =0.13s
# Cumulative duration =22.33s
#
# 163
# Epoch duration =0.14s
# Cumulative duration =22.47s
#
# 164
# Epoch duration =0.13s
# Cumulative duration =22.6s
#
# 165
# Epoch duration =0.13s
# Cumulative duration =22.74s
#
# 166
# Epoch duration =0.14s
# Cumulative duration =22.88s
#
# 167
# Epoch duration =0.13s
# Cumulative duration =23.01s
#
# 168
# Epoch duration =0.13s
# Cumulative duration =23.14s
#
# 169
# Epoch duration =0.13s
# Cumulative duration =23.27s
#
# 170
# Epoch duration =0.13s
# Cumulative duration =23.41s
#
# 171
# Epoch duration =0.13s
# Cumulative duration =23.54s
#
# 172
# Epoch duration =0.14s
# Cumulative duration =23.68s
#
# 173
# Epoch duration =0.13s
# Cumulative duration =23.81s
#
# 174
# Epoch duration =0.14s
# Cumulative duration =23.95s
#
# 175
# Epoch duration =0.14s
# Cumulative duration =24.09s
#
# 176
# Epoch duration =0.13s
# Cumulative duration =24.22s
#
# 177
# Epoch duration =0.13s
# Cumulative duration =24.35s
#
# 178
# Epoch duration =0.14s
# Cumulative duration =24.49s
#
# 179
# Epoch duration =0.14s
# Cumulative duration =24.62s
#
# 180
# Epoch duration =0.13s
# Cumulative duration =24.76s
#
# 181
# Epoch duration =0.19s
# Cumulative duration =24.95s
#
# 182
# Epoch duration =0.13s
# Cumulative duration =25.08s
#
# 183
# Epoch duration =0.14s
# Cumulative duration =25.22s
#
# 184
# Epoch duration =0.13s
# Cumulative duration =25.35s
#
# 185
# Epoch duration =0.13s
# Cumulative duration =25.48s
#
# 186
# Epoch duration =0.13s
# Cumulative duration =25.61s
#
# 187
# Epoch duration =0.13s
# Cumulative duration =25.75s
#
# 188
# Epoch duration =0.14s
# Cumulative duration =25.88s
#
# 189
# Epoch duration =0.13s
# Cumulative duration =26.02s
#
# 190
# Epoch duration =0.16s
# Cumulative duration =26.18s
#
# 191
# Epoch duration =0.14s
# Cumulative duration =26.33s
#
# 192
# Epoch duration =0.15s
# Cumulative duration =26.47s
#
# 193
# Epoch duration =0.14s
# Cumulative duration =26.61s
#
# 194
# Epoch duration =0.13s
# Cumulative duration =26.74s
#
# 195
# Epoch duration =0.13s
# Cumulative duration =26.87s
#
# 196
# Epoch duration =0.13s
# Cumulative duration =27.0s
#
# 197
# Epoch duration =0.14s
# Cumulative duration =27.14s
#
# 198
# Epoch duration =0.14s
# Cumulative duration =27.28s
#
# 199
# Epoch duration =0.13s
# Cumulative duration =27.41s
#
# 200
# Epoch duration =0.14s
# Cumulative duration =27.55s
#
# 201
# Epoch duration =0.13s
# Cumulative duration =27.68s
#
# 202
# Epoch duration =0.13s
# Cumulative duration =27.81s
#
# 203
# Epoch duration =0.13s
# Cumulative duration =27.94s
#
# 204
# Epoch duration =0.15s
# Cumulative duration =28.09s
#
# 205
# Epoch duration =0.14s
# Cumulative duration =28.24s
#
# 206
# Epoch duration =0.14s
# Cumulative duration =28.37s
#
# 207
# Epoch duration =0.13s
# Cumulative duration =28.51s
#
# 208
# Epoch duration =0.13s
# Cumulative duration =28.64s
#
# 209
# Epoch duration =0.13s
# Cumulative duration =28.77s
#
# 210
# Epoch duration =0.14s
# Cumulative duration =28.91s
#
# 211
# Epoch duration =0.14s
# Cumulative duration =29.05s
#
# 212
# Epoch duration =0.13s
# Cumulative duration =29.17s
#
# 213
# Epoch duration =0.13s
# Cumulative duration =29.31s
#
# 214
# Epoch duration =0.17s
# Cumulative duration =29.47s
#
# 215
# Epoch duration =0.14s
# Cumulative duration =29.61s
#
# 216
# Epoch duration =0.13s
# Cumulative duration =29.75s
#
# 217
# Epoch duration =0.14s
# Cumulative duration =29.89s
#
# 218
# Epoch duration =0.14s
# Cumulative duration =30.03s
#
# 219
# Epoch duration =0.15s
# Cumulative duration =30.18s
#
# 220
# Epoch duration =0.13s
# Cumulative duration =30.31s
#
# 221
# Epoch duration =0.14s
# Cumulative duration =30.45s
#
# 222
# Epoch duration =0.13s
# Cumulative duration =30.58s
#
# 223
# Epoch duration =0.14s
# Cumulative duration =30.72s
#
# 224
# Epoch duration =0.14s
# Cumulative duration =30.86s
#
# 225
# Epoch duration =0.15s
# Cumulative duration =31.01s
#
# 226
# Epoch duration =0.14s
# Cumulative duration =31.15s
#
# 227
# Epoch duration =0.15s
# Cumulative duration =31.3s
#
# 228
# Epoch duration =0.17s
# Cumulative duration =31.47s
#
# 229
# Epoch duration =0.14s
# Cumulative duration =31.61s
#
# 230
# Epoch duration =0.13s
# Cumulative duration =31.74s
#
# 231
# Epoch duration =0.13s
# Cumulative duration =31.87s
#
# 232
# Epoch duration =0.13s
# Cumulative duration =32.0s
#
# 233
# Epoch duration =0.14s
# Cumulative duration =32.14s
#
# 234
# Epoch duration =0.15s
# Cumulative duration =32.29s
#
# 235
# Epoch duration =0.14s
# Cumulative duration =32.43s
#
# 236
# Epoch duration =0.13s
# Cumulative duration =32.57s
#
# 237
# Epoch duration =0.13s
# Cumulative duration =32.7s
#
# 238
# Epoch duration =0.13s
# Cumulative duration =32.83s
#
# 239
# Epoch duration =0.14s
# Cumulative duration =32.97s
#
# 240
# Epoch duration =0.14s
# Cumulative duration =33.11s
#
# 241
# Epoch duration =0.13s
# Cumulative duration =33.24s
#
# 242
# Epoch duration =0.13s
# Cumulative duration =33.37s
#
# 243
# Epoch duration =0.14s
# Cumulative duration =33.51s
#
# 244
# Epoch duration =0.13s
# Cumulative duration =33.65s
#
# 245
# Epoch duration =0.13s
# Cumulative duration =33.78s
#
# 246
# Epoch duration =0.13s
# Cumulative duration =33.91s
#
# 247
# Epoch duration =0.14s
# Cumulative duration =34.05s
#
# 248
# Epoch duration =0.13s
# Cumulative duration =34.18s
#
# 249
# Epoch duration =0.13s
# Cumulative duration =34.31s
#
# 250
# Epoch duration =0.13s
# Cumulative duration =34.44s
#
# 251
# Epoch duration =0.13s
# Cumulative duration =34.58s
#
# 252
# Epoch duration =0.13s
# Cumulative duration =34.71s
#
# 253
# Epoch duration =0.13s
# Cumulative duration =34.84s
#
# 254
# Epoch duration =0.14s
# Cumulative duration =34.99s
#
# 255
# Epoch duration =0.13s
# Cumulative duration =35.12s
#
# 256
# Epoch duration =0.14s
# Cumulative duration =35.26s
#
# 257
# Epoch duration =0.14s
# Cumulative duration =35.4s
#
# 258
# Epoch duration =0.13s
# Cumulative duration =35.53s
#
# 259
# Epoch duration =0.13s
# Cumulative duration =35.66s
#
# 260
# Epoch duration =0.13s
# Cumulative duration =35.79s
#
# 261
# Epoch duration =0.14s
# Cumulative duration =35.93s
#
# 262
# Epoch duration =0.15s
# Cumulative duration =36.08s
#
# 263
# Epoch duration =0.14s
# Cumulative duration =36.22s
#
# 264
# Epoch duration =0.14s
# Cumulative duration =36.36s
#
# 265
# Epoch duration =0.15s
# Cumulative duration =36.51s
#
# 266
# Epoch duration =0.13s
# Cumulative duration =36.64s
#
# 267
# Epoch duration =0.13s
# Cumulative duration =36.77s
#
# 268
# Epoch duration =0.13s
# Cumulative duration =36.9s
#
# 269
# Epoch duration =0.13s
# Cumulative duration =37.04s
#
# 270
# Epoch duration =0.14s
# Cumulative duration =37.18s
#
# 271
# Epoch duration =0.13s
# Cumulative duration =37.31s
#
# 272
# Epoch duration =0.13s
# Cumulative duration =37.44s
#
# 273
# Epoch duration =0.14s
# Cumulative duration =37.58s
#
# 274
# Epoch duration =0.13s
# Cumulative duration =37.72s
#
# 275
# Epoch duration =0.14s
# Cumulative duration =37.86s
#
# 276
# Epoch duration =0.14s
# Cumulative duration =37.99s
#
# 277
# Epoch duration =0.13s
# Cumulative duration =38.13s
#
# 278
# Epoch duration =0.14s
# Cumulative duration =38.27s
#
# 279
# Epoch duration =0.13s
# Cumulative duration =38.39s
#
# 280
# Epoch duration =0.13s
# Cumulative duration =38.53s
#
# 281
# Epoch duration =0.13s
# Cumulative duration =38.66s
#
# 282
# Epoch duration =0.13s
# Cumulative duration =38.79s
#
# 283
# Epoch duration =0.13s
# Cumulative duration =38.92s
#
# 284
# Epoch duration =0.14s
# Cumulative duration =39.06s
#
# 285
# Epoch duration =0.13s
# Cumulative duration =39.2s
#
# 286
# Epoch duration =0.13s
# Cumulative duration =39.33s
#
# 287
# Epoch duration =0.15s
# Cumulative duration =39.48s
#
# 288
# Epoch duration =0.14s
# Cumulative duration =39.61s
#
# 289
# Epoch duration =0.13s
# Cumulative duration =39.74s
#
# 290
# Epoch duration =0.13s
# Cumulative duration =39.87s
#
# 291
# Epoch duration =0.14s
# Cumulative duration =40.02s
#
# 292
# Epoch duration =0.13s
# Cumulative duration =40.15s
#
# 293
# Epoch duration =0.14s
# Cumulative duration =40.3s
#
# 294
# Epoch duration =0.13s
# Cumulative duration =40.43s
#
# 295
# Epoch duration =0.13s
# Cumulative duration =40.56s
#
# 296
# Epoch duration =0.13s
# Cumulative duration =40.7s
#
# 297
# Epoch duration =0.14s
# Cumulative duration =40.84s
#
# 298
# Epoch duration =0.14s
# Cumulative duration =40.98s
#
# 299
# Epoch duration =0.14s
# Cumulative duration =41.11s
#
# 300
# Epoch duration =0.14s
# Cumulative duration =41.25s
#
# 301
# Epoch duration =0.15s
# Cumulative duration =41.4s
#
# 302
# Epoch duration =0.14s
# Cumulative duration =41.53s
#
# 303
# Epoch duration =0.14s
# Cumulative duration =41.67s
#
# 304
# Epoch duration =0.13s
# Cumulative duration =41.8s
#
# 305
# Epoch duration =0.14s
# Cumulative duration =41.94s
#
# 306
# Epoch duration =0.15s
# Cumulative duration =42.09s
#
# 307
# Epoch duration =0.15s
# Cumulative duration =42.24s
#
# 308
# Epoch duration =0.14s
# Cumulative duration =42.37s
#
# 309
# Epoch duration =0.14s
# Cumulative duration =42.51s
#
# 310
# Epoch duration =0.13s
# Cumulative duration =42.64s
#
# 311
# Epoch duration =0.13s
# Cumulative duration =42.77s
#
# 312
# Epoch duration =0.13s
# Cumulative duration =42.9s
#
# 313
# Epoch duration =0.13s
# Cumulative duration =43.04s
#
# 314
# Epoch duration =0.14s
# Cumulative duration =43.18s
#
# 315
# Epoch duration =0.14s
# Cumulative duration =43.31s
#
# 316
# Epoch duration =0.14s
# Cumulative duration =43.46s
#
# 317
# Epoch duration =0.14s
# Cumulative duration =43.6s
#
# 318
# Epoch duration =0.17s
# Cumulative duration =43.77s
#
# 319
# Epoch duration =0.15s
# Cumulative duration =43.92s
#
# 320
# Epoch duration =0.13s
# Cumulative duration =44.05s
#
# 321
# Epoch duration =0.14s
# Cumulative duration =44.19s
#
# 322
# Epoch duration =0.14s
# Cumulative duration =44.33s
#
# 323
# Epoch duration =0.15s
# Cumulative duration =44.48s
#
# 324
# Epoch duration =0.13s
# Cumulative duration =44.62s
#
# 325
# Epoch duration =0.13s
# Cumulative duration =44.75s
#
# 326
# Epoch duration =0.13s
# Cumulative duration =44.87s
#
# 327
# Epoch duration =0.13s
# Cumulative duration =45.01s
#
# 328
# Epoch duration =0.14s
# Cumulative duration =45.15s
#
# 329
# Epoch duration =0.14s
# Cumulative duration =45.28s
#
# 330
# Epoch duration =0.13s
# Cumulative duration =45.42s
#
# 331
# Epoch duration =0.14s
# Cumulative duration =45.56s
#
# 332
# Epoch duration =0.13s
# Cumulative duration =45.69s
#
# 333
# Epoch duration =0.13s
# Cumulative duration =45.82s
#
# 334
# Epoch duration =0.14s
# Cumulative duration =45.96s
#
# 335
# Epoch duration =0.13s
# Cumulative duration =46.09s
#
# 336
# Epoch duration =0.13s
# Cumulative duration =46.22s
#
# 337
# Epoch duration =0.14s
# Cumulative duration =46.36s
#
# 338
# Epoch duration =0.15s
# Cumulative duration =46.51s
#
# 339
# Epoch duration =0.13s
# Cumulative duration =46.64s
#
# 340
# Epoch duration =0.13s
# Cumulative duration =46.78s
#
# 341
# Epoch duration =0.13s
# Cumulative duration =46.91s
#
# 342
# Epoch duration =0.14s
# Cumulative duration =47.05s
#
# 343
# Epoch duration =0.14s
# Cumulative duration =47.19s
#
# 344
# Epoch duration =0.13s
# Cumulative duration =47.32s
#
# 345
# Epoch duration =0.13s
# Cumulative duration =47.45s
#
# 346
# Epoch duration =0.13s
# Cumulative duration =47.59s
#
# 347
# Epoch duration =0.15s
# Cumulative duration =47.73s
#
# 348
# Epoch duration =0.16s
# Cumulative duration =47.89s
#
# 349
# Epoch duration =0.14s
# Cumulative duration =48.03s
#
# 350
# Epoch duration =0.13s
# Cumulative duration =48.17s
#
# 351
# Epoch duration =0.13s
# Cumulative duration =48.3s
#
# 352
# Epoch duration =0.13s
# Cumulative duration =48.43s
#
# 353
# Epoch duration =0.13s
# Cumulative duration =48.56s
#
# 354
# Epoch duration =0.16s
# Cumulative duration =48.72s
#
# 355
# Epoch duration =0.14s
# Cumulative duration =48.86s
#
# 356
# Epoch duration =0.13s
# Cumulative duration =48.99s
#
# 357
# Epoch duration =0.13s
# Cumulative duration =49.12s
#
# 358
# Epoch duration =0.13s
# Cumulative duration =49.26s
#
# 359
# Epoch duration =0.13s
# Cumulative duration =49.39s
#
# 360
# Epoch duration =0.13s
# Cumulative duration =49.52s
#
# 361
# Epoch duration =0.13s
# Cumulative duration =49.64s
#
# 362
# Epoch duration =0.13s
# Cumulative duration =49.77s
#
# 363
# Epoch duration =0.13s
# Cumulative duration =49.91s
#
# 364
# Epoch duration =0.13s
# Cumulative duration =50.04s
#
# 365
# Epoch duration =0.13s
# Cumulative duration =50.17s
#
# 366
# Epoch duration =0.13s
# Cumulative duration =50.3s
#
# 367
# Epoch duration =0.13s
# Cumulative duration =50.43s
#
# 368
# Epoch duration =0.13s
# Cumulative duration =50.56s
#
# 369
# Epoch duration =0.13s
# Cumulative duration =50.69s
#
# 370
# Epoch duration =0.14s
# Cumulative duration =50.83s
#
# 371
# Epoch duration =0.13s
# Cumulative duration =50.96s
#
# 372
# Epoch duration =0.13s
# Cumulative duration =51.09s
#
# 373
# Epoch duration =0.13s
# Cumulative duration =51.22s
#
# 374
# Epoch duration =0.13s
# Cumulative duration =51.36s
#
# 375
# Epoch duration =0.13s
# Cumulative duration =51.49s
#
# 376
# Epoch duration =0.13s
# Cumulative duration =51.62s
#
# 377
# Epoch duration =0.13s
# Cumulative duration =51.75s
#
# 378
# Epoch duration =0.13s
# Cumulative duration =51.88s
#
# 379
# Epoch duration =0.13s
# Cumulative duration =52.01s
#
# 380
# Epoch duration =0.13s
# Cumulative duration =52.14s
#
# 381
# Epoch duration =0.13s
# Cumulative duration =52.28s
#
# 382
# Epoch duration =0.13s
# Cumulative duration =52.41s
#
# 383
# Epoch duration =0.13s
# Cumulative duration =52.54s
#
# 384
# Epoch duration =0.13s
# Cumulative duration =52.67s
#
# 385
# Epoch duration =0.13s
# Cumulative duration =52.8s
#
# 386
# Epoch duration =0.13s
# Cumulative duration =52.94s
#
# 387
# Epoch duration =0.14s
# Cumulative duration =53.07s
#
# 388
# Epoch duration =0.13s
# Cumulative duration =53.2s
#
# 389
# Epoch duration =0.13s
# Cumulative duration =53.33s
#
# 390
# Epoch duration =0.13s
# Cumulative duration =53.47s
#
# 391
# Epoch duration =0.15s
# Cumulative duration =53.61s
#
# 392
# Epoch duration =0.13s
# Cumulative duration =53.75s
#
# 393
# Epoch duration =0.13s
# Cumulative duration =53.87s
#
# 394
# Epoch duration =0.13s
# Cumulative duration =54.0s
#
# 395
# Epoch duration =0.13s
# Cumulative duration =54.14s
#
# 396
# Epoch duration =0.13s
# Cumulative duration =54.27s
#
# 397
# Epoch duration =0.13s
# Cumulative duration =54.4s
#
# 398
# Epoch duration =0.13s
# Cumulative duration =54.53s
#
# 399
# Epoch duration =0.13s
# Cumulative duration =54.66s
#
# 400
# Epoch duration =0.14s
# Cumulative duration =54.8s
#
# 401
# Epoch duration =0.13s
# Cumulative duration =54.93s
#
# 402
# Epoch duration =0.13s
# Cumulative duration =55.06s
#
# 403
# Epoch duration =0.13s
# Cumulative duration =55.19s
#
# 404
# Epoch duration =0.13s
# Cumulative duration =55.32s
#
# 405
# Epoch duration =0.13s
# Cumulative duration =55.45s
#
# 406
# Epoch duration =0.14s
# Cumulative duration =55.59s
#
# 407
# Epoch duration =0.13s
# Cumulative duration =55.72s
#
# 408
# Epoch duration =0.13s
# Cumulative duration =55.86s
#
# 409
# Epoch duration =0.13s
# Cumulative duration =55.99s
#
# 410
# Epoch duration =0.14s
# Cumulative duration =56.13s
#
# 411
# Epoch duration =0.13s
# Cumulative duration =56.26s
#
# 412
# Epoch duration =0.13s
# Cumulative duration =56.39s
#
# 413
# Epoch duration =0.16s
# Cumulative duration =56.55s
#
# 414
# Epoch duration =0.13s
# Cumulative duration =56.68s
#
# 415
# Epoch duration =0.13s
# Cumulative duration =56.81s
#
# 416
# Epoch duration =0.13s
# Cumulative duration =56.94s
#
# 417
# Epoch duration =0.13s
# Cumulative duration =57.08s
#
# 418
# Epoch duration =0.13s
# Cumulative duration =57.21s
#
# 419
# Epoch duration =0.13s
# Cumulative duration =57.34s
#
# 420
# Epoch duration =0.13s
# Cumulative duration =57.47s
#
# 421
# Epoch duration =0.13s
# Cumulative duration =57.6s
#
# 422
# Epoch duration =0.13s
# Cumulative duration =57.74s
#
# 423
# Epoch duration =0.15s
# Cumulative duration =57.88s
#
# 424
# Epoch duration =0.14s
# Cumulative duration =58.02s
#
# 425
# Epoch duration =0.17s
# Cumulative duration =58.19s
#
# 426
# Epoch duration =0.15s
# Cumulative duration =58.34s
#
# 427
# Epoch duration =0.14s
# Cumulative duration =58.48s
#
# 428
# Epoch duration =0.14s
# Cumulative duration =58.61s
#
# 429
# Epoch duration =0.15s
# Cumulative duration =58.76s
#
# 430
# Epoch duration =0.13s
# Cumulative duration =58.89s
#
# 431
# Epoch duration =0.13s
# Cumulative duration =59.03s
#
# 432
# Epoch duration =0.13s
# Cumulative duration =59.16s
#
# 433
# Epoch duration =0.14s
# Cumulative duration =59.3s
#
# 434
# Epoch duration =0.13s
# Cumulative duration =59.43s
#
# 435
# Epoch duration =0.21s
# Cumulative duration =59.65s
#
# 436
# Epoch duration =0.13s
# Cumulative duration =59.78s
#
# 437
# Epoch duration =0.13s
# Cumulative duration =59.91s
#
# 438
# Epoch duration =0.14s
# Cumulative duration =1min 0.05s
#
# 439
# Epoch duration =0.13s
# Cumulative duration =1min 0.18s
#
# 440
# Epoch duration =0.13s
# Cumulative duration =1min 0.31s
#
# 441
# Epoch duration =0.16s
# Cumulative duration =1min 0.47s
#
# 442
# Epoch duration =0.14s
# Cumulative duration =1min 0.61s
#
# 443
# Epoch duration =0.13s
# Cumulative duration =1min 0.74s
#
# 444
# Epoch duration =0.14s
# Cumulative duration =1min 0.88s
#
# 445
# Epoch duration =0.14s
# Cumulative duration =1min 1.02s
#
# 446
# Epoch duration =0.13s
# Cumulative duration =1min 1.15s
#
# 447
# Epoch duration =0.15s
# Cumulative duration =1min 1.3s
#
# 448
# Epoch duration =0.16s
# Cumulative duration =1min 1.45s
#
# 449
# Epoch duration =0.16s
# Cumulative duration =1min 1.61s
#
# 450
# Epoch duration =0.14s
# Cumulative duration =1min 1.75s
#
# 451
# Epoch duration =0.14s
# Cumulative duration =1min 1.89s
#
# 452
# Epoch duration =0.13s
# Cumulative duration =1min 2.02s
#
# 453
# Epoch duration =0.13s
# Cumulative duration =1min 2.15s
#
# 454
# Epoch duration =0.13s
# Cumulative duration =1min 2.29s
#
# 455
# Epoch duration =0.13s
# Cumulative duration =1min 2.42s
#
# 456
# Epoch duration =0.13s
# Cumulative duration =1min 2.55s
#
# 457
# Epoch duration =0.13s
# Cumulative duration =1min 2.68s
#
# 458
# Epoch duration =0.13s
# Cumulative duration =1min 2.81s
#
# 459
# Epoch duration =0.14s
# Cumulative duration =1min 2.95s
#
# 460
# Epoch duration =0.13s
# Cumulative duration =1min 3.08s
#
# 461
# Epoch duration =0.13s
# Cumulative duration =1min 3.21s
#
# 462
# Epoch duration =0.13s
# Cumulative duration =1min 3.34s
#
# 463
# Epoch duration =0.14s
# Cumulative duration =1min 3.48s
#
# 464
# Epoch duration =0.17s
# Cumulative duration =1min 3.65s
#
# 465
# Epoch duration =0.13s
# Cumulative duration =1min 3.78s
#
# 466
# Epoch duration =0.13s
# Cumulative duration =1min 3.92s
#
# 467
# Epoch duration =0.13s
# Cumulative duration =1min 4.04s
#
# 468
# Epoch duration =0.13s
# Cumulative duration =1min 4.17s
#
# 469
# Epoch duration =0.14s
# Cumulative duration =1min 4.31s
#
# 470
# Epoch duration =0.14s
# Cumulative duration =1min 4.45s
#
# 471
# Epoch duration =0.14s
# Cumulative duration =1min 4.59s
#
# 472
# Epoch duration =0.13s
# Cumulative duration =1min 4.72s
#
# 473
# Epoch duration =0.17s
# Cumulative duration =1min 4.89s
#
# 474
# Epoch duration =0.14s
# Cumulative duration =1min 5.03s
#
# 475
# Epoch duration =0.15s
# Cumulative duration =1min 5.18s
#
# 476
# Epoch duration =0.13s
# Cumulative duration =1min 5.31s
#
# 477
# Epoch duration =0.14s
# Cumulative duration =1min 5.46s
#
# 478
# Epoch duration =0.13s
# Cumulative duration =1min 5.59s
#
# 479
# Epoch duration =0.13s
# Cumulative duration =1min 5.73s
#
# 480
# Epoch duration =0.13s
# Cumulative duration =1min 5.86s
#
# 481
# Epoch duration =0.13s
# Cumulative duration =1min 5.99s
#
# 482
# Epoch duration =0.13s
# Cumulative duration =1min 6.12s
#
# 483
# Epoch duration =0.14s
# Cumulative duration =1min 6.26s
#
# 484
# Epoch duration =0.14s
# Cumulative duration =1min 6.4s
#
# 485
# Epoch duration =0.13s
# Cumulative duration =1min 6.53s
#
# 486
# Epoch duration =0.13s
# Cumulative duration =1min 6.66s
#
# 487
# Epoch duration =0.13s
# Cumulative duration =1min 6.79s
#
# 488
# Epoch duration =0.14s
# Cumulative duration =1min 6.93s
#
# 489
# Epoch duration =0.14s
# Cumulative duration =1min 7.07s
#
# 490
# Epoch duration =0.13s
# Cumulative duration =1min 7.2s
#
# 491
# Epoch duration =0.13s
# Cumulative duration =1min 7.33s
#
# 492
# Epoch duration =0.14s
# Cumulative duration =1min 7.47s
#
# 493
# Epoch duration =0.13s
# Cumulative duration =1min 7.6s
#
# 494
# Epoch duration =0.13s
# Cumulative duration =1min 7.73s
#
# 495
# Epoch duration =0.13s
# Cumulative duration =1min 7.86s
#
# 496
# Epoch duration =0.13s
# Cumulative duration =1min 7.99s
#
# 497
# Epoch duration =0.13s
# Cumulative duration =1min 8.12s
#
# 498
# Epoch duration =0.13s
# Cumulative duration =1min 8.25s
#
# 499
# Epoch duration =0.13s
# Cumulative duration =1min 8.39s
#
# 500
# Epoch duration =0.13s
# Cumulative duration =1min 8.52s
#
# 501
# Epoch duration =0.14s
# Cumulative duration =1min 8.66s
#
# 502
# Epoch duration =0.13s
# Cumulative duration =1min 8.79s
#
# 503
# Epoch duration =0.13s
# Cumulative duration =1min 8.92s
#
# 504
# Epoch duration =0.13s
# Cumulative duration =1min 9.05s
#
# 505
# Epoch duration =0.13s
# Cumulative duration =1min 9.18s
#
# 506
# Epoch duration =0.13s
# Cumulative duration =1min 9.31s
#
# 507
# Epoch duration =0.13s
# Cumulative duration =1min 9.44s
#
# 508
# Epoch duration =0.13s
# Cumulative duration =1min 9.57s
#
# 509
# Epoch duration =0.13s
# Cumulative duration =1min 9.7s
#
# 510
# Epoch duration =0.13s
# Cumulative duration =1min 9.83s
#
# 511
# Epoch duration =0.13s
# Cumulative duration =1min 9.96s
#
# 512
# Epoch duration =0.13s
# Cumulative duration =1min 10.1s
#
# 513
# Epoch duration =0.13s
# Cumulative duration =1min 10.23s
#
# 514
# Epoch duration =0.14s
# Cumulative duration =1min 10.36s
#
# 515
# Epoch duration =0.15s
# Cumulative duration =1min 10.51s
#
# 516
# Epoch duration =0.13s
# Cumulative duration =1min 10.64s
#
# 517
# Epoch duration =0.14s
# Cumulative duration =1min 10.78s
#
# 518
# Epoch duration =0.13s
# Cumulative duration =1min 10.92s
#
# 519
# Epoch duration =0.13s
# Cumulative duration =1min 11.05s
#
# 520
# Epoch duration =0.14s
# Cumulative duration =1min 11.19s
#
# 521
# Epoch duration =0.13s
# Cumulative duration =1min 11.32s
#
# 522
# Epoch duration =0.13s
# Cumulative duration =1min 11.45s
#
# 523
# Epoch duration =0.13s
# Cumulative duration =1min 11.58s
#
# 524
# Epoch duration =0.13s
# Cumulative duration =1min 11.71s
#
# 525
# Epoch duration =0.13s
# Cumulative duration =1min 11.84s
#
# 526
# Epoch duration =0.13s
# Cumulative duration =1min 11.97s
#
# 527
# Epoch duration =0.14s
# Cumulative duration =1min 12.11s
#
# 528
# Epoch duration =0.13s
# Cumulative duration =1min 12.24s
#
# 529
# Epoch duration =0.14s
# Cumulative duration =1min 12.39s
#
# 530
# Epoch duration =0.13s
# Cumulative duration =1min 12.52s
#
# 531
# Epoch duration =0.13s
# Cumulative duration =1min 12.65s
#
# 532
# Epoch duration =0.13s
# Cumulative duration =1min 12.78s
#
# 533
# Epoch duration =0.13s
# Cumulative duration =1min 12.91s
#
# 534
# Epoch duration =0.13s
# Cumulative duration =1min 13.05s
#
# 535
# Epoch duration =0.13s
# Cumulative duration =1min 13.18s
#
# 536
# Epoch duration =0.13s
# Cumulative duration =1min 13.31s
#
# 537
# Epoch duration =0.13s
# Cumulative duration =1min 13.45s
#
# 538
# Epoch duration =0.14s
# Cumulative duration =1min 13.58s
#
# 539
# Epoch duration =0.13s
# Cumulative duration =1min 13.72s
#
# 540
# Epoch duration =0.13s
# Cumulative duration =1min 13.85s
#
# 541
# Epoch duration =0.13s
# Cumulative duration =1min 13.98s
#
# 542
# Epoch duration =0.13s
# Cumulative duration =1min 14.11s
#
# 543
# Epoch duration =0.13s
# Cumulative duration =1min 14.24s
#
# 544
# Epoch duration =0.13s
# Cumulative duration =1min 14.37s
#
# 545
# Epoch duration =0.14s
# Cumulative duration =1min 14.51s
#
# 546
# Epoch duration =0.14s
# Cumulative duration =1min 14.65s
#
# 547
# Epoch duration =0.14s
# Cumulative duration =1min 14.79s
#
# 548
# Epoch duration =0.13s
# Cumulative duration =1min 14.92s
#
# 549
# Epoch duration =0.14s
# Cumulative duration =1min 15.06s
#
# 550
# Epoch duration =0.14s
# Cumulative duration =1min 15.19s
#
# 551
# Epoch duration =0.14s
# Cumulative duration =1min 15.33s
#
# 552
# Epoch duration =0.13s
# Cumulative duration =1min 15.46s
#
# 553
# Epoch duration =0.13s
# Cumulative duration =1min 15.6s
#
# 554
# Epoch duration =0.13s
# Cumulative duration =1min 15.73s
#
# 555
# Epoch duration =0.14s
# Cumulative duration =1min 15.87s
#
# 556
# Epoch duration =0.13s
# Cumulative duration =1min 16.0s
#
# 557
# Epoch duration =0.13s
# Cumulative duration =1min 16.14s
#
# 558
# Epoch duration =0.14s
# Cumulative duration =1min 16.28s
#
# 559
# Epoch duration =0.13s
# Cumulative duration =1min 16.41s
#
# 560
# Epoch duration =0.13s
# Cumulative duration =1min 16.54s
#
# 561
# Epoch duration =0.13s
# Cumulative duration =1min 16.67s
#
# 562
# Epoch duration =0.13s
# Cumulative duration =1min 16.81s
#
# 563
# Epoch duration =0.15s
# Cumulative duration =1min 16.95s
#
# 564
# Epoch duration =0.13s
# Cumulative duration =1min 17.08s
#
# 565
# Epoch duration =0.13s
# Cumulative duration =1min 17.22s
#
# 566
# Epoch duration =0.13s
# Cumulative duration =1min 17.35s
#
# 567
# Epoch duration =0.13s
# Cumulative duration =1min 17.48s
#
# 568
# Epoch duration =0.13s
# Cumulative duration =1min 17.61s
#
# 569
# Epoch duration =0.13s
# Cumulative duration =1min 17.74s
#
# 570
# Epoch duration =0.14s
# Cumulative duration =1min 17.88s
#
# 571
# Epoch duration =0.13s
# Cumulative duration =1min 18.01s
#
# 572
# Epoch duration =0.14s
# Cumulative duration =1min 18.15s
#
# 573
# Epoch duration =0.13s
# Cumulative duration =1min 18.28s
#
# 574
# Epoch duration =0.13s
# Cumulative duration =1min 18.41s
#
# 575
# Epoch duration =0.13s
# Cumulative duration =1min 18.55s
#
# 576
# Epoch duration =0.13s
# Cumulative duration =1min 18.68s
#
# 577
# Epoch duration =0.13s
# Cumulative duration =1min 18.81s
#
# 578
# Epoch duration =0.13s
# Cumulative duration =1min 18.94s
#
# 579
# Epoch duration =0.13s
# Cumulative duration =1min 19.07s
#
# 580
# Epoch duration =0.13s
# Cumulative duration =1min 19.2s
#
# 581
# Epoch duration =0.13s
# Cumulative duration =1min 19.33s
#
# 582
# Epoch duration =0.13s
# Cumulative duration =1min 19.47s
#
# 583
# Epoch duration =0.13s
# Cumulative duration =1min 19.6s
#
# 584
# Epoch duration =0.13s
# Cumulative duration =1min 19.73s
#
# 585
# Epoch duration =0.13s
# Cumulative duration =1min 19.86s
#
# 586
# Epoch duration =0.13s
# Cumulative duration =1min 19.99s
#
# 587
# Epoch duration =0.15s
# Cumulative duration =1min 20.14s
#
# 588
# Epoch duration =0.13s
# Cumulative duration =1min 20.27s
#
# 589
# Epoch duration =0.13s
# Cumulative duration =1min 20.4s
#
# 590
# Epoch duration =0.14s
# Cumulative duration =1min 20.54s
#
# 591
# Epoch duration =0.13s
# Cumulative duration =1min 20.67s
#
# 592
# Epoch duration =0.13s
# Cumulative duration =1min 20.8s
#
# 593
# Epoch duration =0.13s
# Cumulative duration =1min 20.93s
#
# 594
# Epoch duration =0.14s
# Cumulative duration =1min 21.07s
#
# 595
# Epoch duration =0.13s
# Cumulative duration =1min 21.2s
#
# 596
# Epoch duration =0.13s
# Cumulative duration =1min 21.33s
#
# 597
# Epoch duration =0.13s
# Cumulative duration =1min 21.46s
#
# 598
# Epoch duration =0.13s
# Cumulative duration =1min 21.59s
#
# 599
# Epoch duration =0.13s
# Cumulative duration =1min 21.73s
#
# 600
# Epoch duration =0.13s
# Cumulative duration =1min 21.85s
#
# 601
# Epoch duration =0.15s
# Cumulative duration =1min 22.01s
#
# 602
# Epoch duration =0.13s
# Cumulative duration =1min 22.14s
#
# 603
# Epoch duration =0.13s
# Cumulative duration =1min 22.27s
#
# 604
# Epoch duration =0.13s
# Cumulative duration =1min 22.4s
#
# 605
# Epoch duration =0.13s
# Cumulative duration =1min 22.54s
#
# 606
# Epoch duration =0.13s
# Cumulative duration =1min 22.67s
#
# 607
# Epoch duration =0.14s
# Cumulative duration =1min 22.8s
#
# 608
# Epoch duration =0.14s
# Cumulative duration =1min 22.94s
#
# 609
# Epoch duration =0.14s
# Cumulative duration =1min 23.08s
#
# 610
# Epoch duration =0.14s
# Cumulative duration =1min 23.23s
#
# 611
# Epoch duration =0.13s
# Cumulative duration =1min 23.36s
#
# 612
# Epoch duration =0.15s
# Cumulative duration =1min 23.51s
#
# 613
# Epoch duration =0.15s
# Cumulative duration =1min 23.65s
#
# 614
# Epoch duration =0.14s
# Cumulative duration =1min 23.79s
#
# 615
# Epoch duration =0.16s
# Cumulative duration =1min 23.95s
#
# 616
# Epoch duration =0.13s
# Cumulative duration =1min 24.08s
#
# 617
# Epoch duration =0.14s
# Cumulative duration =1min 24.22s
#
# 618
# Epoch duration =0.13s
# Cumulative duration =1min 24.35s
#
# 619
# Epoch duration =0.13s
# Cumulative duration =1min 24.48s
#
# 620
# Epoch duration =0.13s
# Cumulative duration =1min 24.61s
#
# 621
# Epoch duration =0.14s
# Cumulative duration =1min 24.75s
#
# 622
# Epoch duration =0.13s
# Cumulative duration =1min 24.88s
#
# 623
# Epoch duration =0.13s
# Cumulative duration =1min 25.01s
#
# 624
# Epoch duration =0.14s
# Cumulative duration =1min 25.16s
#
# 625
# Epoch duration =0.15s
# Cumulative duration =1min 25.31s
#
# 626
# Epoch duration =0.14s
# Cumulative duration =1min 25.45s
#
# 627
# Epoch duration =0.14s
# Cumulative duration =1min 25.59s
#
# 628
# Epoch duration =0.13s
# Cumulative duration =1min 25.72s
#
# 629
# Epoch duration =0.14s
# Cumulative duration =1min 25.86s
#
# 630
# Epoch duration =0.14s
# Cumulative duration =1min 25.99s
#
# 631
# Epoch duration =0.14s
# Cumulative duration =1min 26.13s
#
# 632
# Epoch duration =0.13s
# Cumulative duration =1min 26.26s
#
# 633
# Epoch duration =0.13s
# Cumulative duration =1min 26.39s
#
# 634
# Epoch duration =0.13s
# Cumulative duration =1min 26.53s
#
# 635
# Epoch duration =0.16s
# Cumulative duration =1min 26.68s
#
# 636
# Epoch duration =0.13s
# Cumulative duration =1min 26.81s
#
# 637
# Epoch duration =0.13s
# Cumulative duration =1min 26.95s
#
# 638
# Epoch duration =0.13s
# Cumulative duration =1min 27.08s
#
# 639
# Epoch duration =0.13s
# Cumulative duration =1min 27.21s
#
# 640
# Epoch duration =0.13s
# Cumulative duration =1min 27.34s
#
# 641
# Epoch duration =0.14s
# Cumulative duration =1min 27.48s
#
# 642
# Epoch duration =0.13s
# Cumulative duration =1min 27.61s
#
# 643
# Epoch duration =0.15s
# Cumulative duration =1min 27.77s
#
# 644
# Epoch duration =0.13s
# Cumulative duration =1min 27.89s
#
# 645
# Epoch duration =0.14s
# Cumulative duration =1min 28.03s
#
# 646
# Epoch duration =0.14s
# Cumulative duration =1min 28.16s
#
# 647
# Epoch duration =0.13s
# Cumulative duration =1min 28.3s
#
# 648
# Epoch duration =0.13s
# Cumulative duration =1min 28.43s
#
# 649
# Epoch duration =0.13s
# Cumulative duration =1min 28.56s
#
# 650
# Epoch duration =0.13s
# Cumulative duration =1min 28.69s
#
# 651
# Epoch duration =0.13s
# Cumulative duration =1min 28.82s
#
# 652
# Epoch duration =0.13s
# Cumulative duration =1min 28.95s
#
# 653
# Epoch duration =0.14s
# Cumulative duration =1min 29.09s
#
# 654
# Epoch duration =0.13s
# Cumulative duration =1min 29.22s
#
# 655
# Epoch duration =0.15s
# Cumulative duration =1min 29.38s
#
# 656
# Epoch duration =0.13s
# Cumulative duration =1min 29.51s
#
# 657
# Epoch duration =0.15s
# Cumulative duration =1min 29.66s
#
# 658
# Epoch duration =0.13s
# Cumulative duration =1min 29.78s
#
# 659
# Epoch duration =0.14s
# Cumulative duration =1min 29.92s
#
# 660
# Epoch duration =0.13s
# Cumulative duration =1min 30.05s
#
# 661
# Epoch duration =0.14s
# Cumulative duration =1min 30.19s
#
# 662
# Epoch duration =0.13s
# Cumulative duration =1min 30.32s
#
# 663
# Epoch duration =0.14s
# Cumulative duration =1min 30.46s
#
# 664
# Epoch duration =0.13s
# Cumulative duration =1min 30.59s
#
# 665
# Epoch duration =0.13s
# Cumulative duration =1min 30.72s
#
# 666
# Epoch duration =0.13s
# Cumulative duration =1min 30.85s
#
# 667
# Epoch duration =0.13s
# Cumulative duration =1min 30.98s
#
# 668
# Epoch duration =0.13s
# Cumulative duration =1min 31.11s
#
# 669
# Epoch duration =0.14s
# Cumulative duration =1min 31.25s
#
# 670
# Epoch duration =0.13s
# Cumulative duration =1min 31.38s
#
# 671
# Epoch duration =0.13s
# Cumulative duration =1min 31.51s
#
# 672
# Epoch duration =0.13s
# Cumulative duration =1min 31.65s
#
# 673
# Epoch duration =0.14s
# Cumulative duration =1min 31.78s
#
# 674
# Epoch duration =0.13s
# Cumulative duration =1min 31.92s
#
# 675
# Epoch duration =0.15s
# Cumulative duration =1min 32.07s
#
# 676
# Epoch duration =0.13s
# Cumulative duration =1min 32.21s
#
# 677
# Epoch duration =0.13s
# Cumulative duration =1min 32.34s
#
# 678
# Epoch duration =0.13s
# Cumulative duration =1min 32.47s
#
# 679
# Epoch duration =0.15s
# Cumulative duration =1min 32.62s
#
# 680
# Epoch duration =0.13s
# Cumulative duration =1min 32.75s
#
# 681
# Epoch duration =0.13s
# Cumulative duration =1min 32.89s
#
# 682
# Epoch duration =0.13s
# Cumulative duration =1min 33.02s
#
# 683
# Epoch duration =0.13s
# Cumulative duration =1min 33.15s
#
# 684
# Epoch duration =0.13s
# Cumulative duration =1min 33.28s
#
# 685
# Epoch duration =0.15s
# Cumulative duration =1min 33.43s
#
# 686
# Epoch duration =0.13s
# Cumulative duration =1min 33.56s
#
# 687
# Epoch duration =0.14s
# Cumulative duration =1min 33.7s
#
# 688
# Epoch duration =0.13s
# Cumulative duration =1min 33.83s
#
# 689
# Epoch duration =0.13s
# Cumulative duration =1min 33.97s
#
# 690
# Epoch duration =0.13s
# Cumulative duration =1min 34.1s
#
# 691
# Epoch duration =0.15s
# Cumulative duration =1min 34.25s
#
# 692
# Epoch duration =0.13s
# Cumulative duration =1min 34.38s
#
# 693
# Epoch duration =0.13s
# Cumulative duration =1min 34.51s
#
# 694
# Epoch duration =0.13s
# Cumulative duration =1min 34.64s
#
# 695
# Epoch duration =0.13s
# Cumulative duration =1min 34.77s
#
# 696
# Epoch duration =0.13s
# Cumulative duration =1min 34.9s
#
# 697
# Epoch duration =0.14s
# Cumulative duration =1min 35.04s
#
# 698
# Epoch duration =0.13s
# Cumulative duration =1min 35.18s
#
# 699
# Epoch duration =0.13s
# Cumulative duration =1min 35.31s
#
# 700
# Epoch duration =0.13s
# Cumulative duration =1min 35.44s
#
# 701
# Epoch duration =0.13s
# Cumulative duration =1min 35.57s
#
# 702
# Epoch duration =0.13s
# Cumulative duration =1min 35.71s
#
# 703
# Epoch duration =0.14s
# Cumulative duration =1min 35.84s
#
# 704
# Epoch duration =0.13s
# Cumulative duration =1min 35.97s
#
# 705
# Epoch duration =0.13s
# Cumulative duration =1min 36.1s
#
# 706
# Epoch duration =0.13s
# Cumulative duration =1min 36.23s
#
# 707
# Epoch duration =0.14s
# Cumulative duration =1min 36.37s
#
# 708
# Epoch duration =0.13s
# Cumulative duration =1min 36.5s
#
# 709
# Epoch duration =0.13s
# Cumulative duration =1min 36.63s
#
# 710
# Epoch duration =0.13s
# Cumulative duration =1min 36.76s
#
# 711
# Epoch duration =0.13s
# Cumulative duration =1min 36.89s
#
# 712
# Epoch duration =0.14s
# Cumulative duration =1min 37.03s
#
# 713
# Epoch duration =0.13s
# Cumulative duration =1min 37.16s
#
# 714
# Epoch duration =0.13s
# Cumulative duration =1min 37.29s
#
# 715
# Epoch duration =0.14s
# Cumulative duration =1min 37.43s
#
# 716
# Epoch duration =0.14s
# Cumulative duration =1min 37.57s
#
# 717
# Epoch duration =0.13s
# Cumulative duration =1min 37.7s
#
# 718
# Epoch duration =0.13s
# Cumulative duration =1min 37.83s
#
# 719
# Epoch duration =0.15s
# Cumulative duration =1min 37.98s
#
# 720
# Epoch duration =0.13s
# Cumulative duration =1min 38.11s
#
# 721
# Epoch duration =0.13s
# Cumulative duration =1min 38.24s
#
# 722
# Epoch duration =0.14s
# Cumulative duration =1min 38.38s
#
# 723
# Epoch duration =0.13s
# Cumulative duration =1min 38.51s
#
# 724
# Epoch duration =0.13s
# Cumulative duration =1min 38.64s
#
# 725
# Epoch duration =0.14s
# Cumulative duration =1min 38.78s
#
# 726
# Epoch duration =0.13s
# Cumulative duration =1min 38.91s
#
# 727
# Epoch duration =0.14s
# Cumulative duration =1min 39.05s
#
# 728
# Epoch duration =0.13s
# Cumulative duration =1min 39.18s
#
# 729
# Epoch duration =0.15s
# Cumulative duration =1min 39.33s
#
# 730
# Epoch duration =0.13s
# Cumulative duration =1min 39.46s
#
# 731
# Epoch duration =0.14s
# Cumulative duration =1min 39.6s
#
# 732
# Epoch duration =0.13s
# Cumulative duration =1min 39.73s
#
# 733
# Epoch duration =0.13s
# Cumulative duration =1min 39.86s
#
# 734
# Epoch duration =0.13s
# Cumulative duration =1min 40.0s
#
# 735
# Epoch duration =0.14s
# Cumulative duration =1min 40.14s
#
# 736
# Epoch duration =0.13s
# Cumulative duration =1min 40.26s
#
# 737
# Epoch duration =0.13s
# Cumulative duration =1min 40.4s
#
# 738
# Epoch duration =0.15s
# Cumulative duration =1min 40.55s
#
# 739
# Epoch duration =0.15s
# Cumulative duration =1min 40.7s
#
# 740
# Epoch duration =0.13s
# Cumulative duration =1min 40.83s
#
# 741
# Epoch duration =0.13s
# Cumulative duration =1min 40.97s
#
# 742
# Epoch duration =0.13s
# Cumulative duration =1min 41.1s
#
# 743
# Epoch duration =0.13s
# Cumulative duration =1min 41.23s
#
# 744
# Epoch duration =0.13s
# Cumulative duration =1min 41.36s
#
# 745
# Epoch duration =0.13s
# Cumulative duration =1min 41.5s
#
# 746
# Epoch duration =0.13s
# Cumulative duration =1min 41.63s
#
# 747
# Epoch duration =0.13s
# Cumulative duration =1min 41.76s
#
# 748
# Epoch duration =0.13s
# Cumulative duration =1min 41.89s
#
# 749
# Epoch duration =0.13s
# Cumulative duration =1min 42.03s
#
# 750
# Epoch duration =0.13s
# Cumulative duration =1min 42.16s
#
# 751
# Epoch duration =0.16s
# Cumulative duration =1min 42.32s
#
# 752
# Epoch duration =0.13s
# Cumulative duration =1min 42.45s
#
# 753
# Epoch duration =0.13s
# Cumulative duration =1min 42.58s
#
# 754
# Epoch duration =0.13s
# Cumulative duration =1min 42.71s
#
# 755
# Epoch duration =0.14s
# Cumulative duration =1min 42.85s
#
# 756
# Epoch duration =0.13s
# Cumulative duration =1min 42.98s
#
# 757
# Epoch duration =0.14s
# Cumulative duration =1min 43.12s
#
# 758
# Epoch duration =0.13s
# Cumulative duration =1min 43.25s
#
# 759
# Epoch duration =0.13s
# Cumulative duration =1min 43.39s
#
# 760
# Epoch duration =0.13s
# Cumulative duration =1min 43.52s
#
# 761
# Epoch duration =0.13s
# Cumulative duration =1min 43.65s
#
# 762
# Epoch duration =0.13s
# Cumulative duration =1min 43.79s
#
# 763
# Epoch duration =0.15s
# Cumulative duration =1min 43.94s
#
# 764
# Epoch duration =0.13s
# Cumulative duration =1min 44.07s
#
# 765
# Epoch duration =0.14s
# Cumulative duration =1min 44.2s
#
# 766
# Epoch duration =0.13s
# Cumulative duration =1min 44.33s
#
# 767
# Epoch duration =0.14s
# Cumulative duration =1min 44.47s
#
# 768
# Epoch duration =0.13s
# Cumulative duration =1min 44.6s
#
# 769
# Epoch duration =0.14s
# Cumulative duration =1min 44.74s
#
# 770
# Epoch duration =0.13s
# Cumulative duration =1min 44.87s
#
# 771
# Epoch duration =0.14s
# Cumulative duration =1min 45.0s
#
# 772
# Epoch duration =0.14s
# Cumulative duration =1min 45.14s
#
# 773
# Epoch duration =0.13s
# Cumulative duration =1min 45.27s
#
# 774
# Epoch duration =0.13s
# Cumulative duration =1min 45.41s
#
# 775
# Epoch duration =0.13s
# Cumulative duration =1min 45.54s
#
# 776
# Epoch duration =0.13s
# Cumulative duration =1min 45.67s
#
# 777
# Epoch duration =0.14s
# Cumulative duration =1min 45.82s
#
# 778
# Epoch duration =0.13s
# Cumulative duration =1min 45.95s
#
# 779
# Epoch duration =0.15s
# Cumulative duration =1min 46.1s
#
# 780
# Epoch duration =0.13s
# Cumulative duration =1min 46.23s
#
# 781
# Epoch duration =0.14s
# Cumulative duration =1min 46.37s
#
# 782
# Epoch duration =0.13s
# Cumulative duration =1min 46.5s
#
# 783
# Epoch duration =0.13s
# Cumulative duration =1min 46.63s
#
# 784
# Epoch duration =0.13s
# Cumulative duration =1min 46.76s
#
# 785
# Epoch duration =0.13s
# Cumulative duration =1min 46.9s
#
# 786
# Epoch duration =0.13s
# Cumulative duration =1min 47.03s
#
# 787
# Epoch duration =0.14s
# Cumulative duration =1min 47.16s
#
# 788
# Epoch duration =0.13s
# Cumulative duration =1min 47.3s
#
# 789
# Epoch duration =0.13s
# Cumulative duration =1min 47.43s
#
# 790
# Epoch duration =0.13s
# Cumulative duration =1min 47.56s
#
# 791
# Epoch duration =0.13s
# Cumulative duration =1min 47.7s
#
# 792
# Epoch duration =0.14s
# Cumulative duration =1min 47.84s
#
# 793
# Epoch duration =0.13s
# Cumulative duration =1min 47.97s
#
# 794
# Epoch duration =0.13s
# Cumulative duration =1min 48.1s
#
# 795
# Epoch duration =0.14s
# Cumulative duration =1min 48.23s
#
# 796
# Epoch duration =0.13s
# Cumulative duration =1min 48.37s
#
# 797
# Epoch duration =0.16s
# Cumulative duration =1min 48.52s
#
# 798
# Epoch duration =0.13s
# Cumulative duration =1min 48.65s
#
# 799
# Epoch duration =0.13s
# Cumulative duration =1min 48.78s
#
# 800
# Epoch duration =0.14s
# Cumulative duration =1min 48.92s
#
# 801
# Epoch duration =0.14s
# Cumulative duration =1min 49.06s
#
# 802
# Epoch duration =0.13s
# Cumulative duration =1min 49.2s
#
# 803
# Epoch duration =0.14s
# Cumulative duration =1min 49.33s
#
# 804
# Epoch duration =0.13s
# Cumulative duration =1min 49.46s
#
# 805
# Epoch duration =0.13s
# Cumulative duration =1min 49.6s
#
# 806
# Epoch duration =0.13s
# Cumulative duration =1min 49.73s
#
# 807
# Epoch duration =0.13s
# Cumulative duration =1min 49.86s
#
# 808
# Epoch duration =0.13s
# Cumulative duration =1min 49.99s
#
# 809
# Epoch duration =0.14s
# Cumulative duration =1min 50.13s
#
# 810
# Epoch duration =0.13s
# Cumulative duration =1min 50.26s
#
# 811
# Epoch duration =0.16s
# Cumulative duration =1min 50.42s
#
# 812
# Epoch duration =0.13s
# Cumulative duration =1min 50.55s
#
# 813
# Epoch duration =0.13s
# Cumulative duration =1min 50.69s
#
# 814
# Epoch duration =0.14s
# Cumulative duration =1min 50.82s
#
# 815
# Epoch duration =0.13s
# Cumulative duration =1min 50.96s
#
# 816
# Epoch duration =0.13s
# Cumulative duration =1min 51.09s
#
# 817
# Epoch duration =0.13s
# Cumulative duration =1min 51.22s
#
# 818
# Epoch duration =0.13s
# Cumulative duration =1min 51.35s
#
# 819
# Epoch duration =0.14s
# Cumulative duration =1min 51.49s
#
# 820
# Epoch duration =0.13s
# Cumulative duration =1min 51.62s
#
# 821
# Epoch duration =0.14s
# Cumulative duration =1min 51.76s
#
# 822
# Epoch duration =0.13s
# Cumulative duration =1min 51.88s
#
# 823
# Epoch duration =0.14s
# Cumulative duration =1min 52.02s
#
# 824
# Epoch duration =0.13s
# Cumulative duration =1min 52.15s
#
# 825
# Epoch duration =0.13s
# Cumulative duration =1min 52.28s
#
# 826
# Epoch duration =0.13s
# Cumulative duration =1min 52.41s
#
# 827
# Epoch duration =0.14s
# Cumulative duration =1min 52.55s
#
# 828
# Epoch duration =0.14s
# Cumulative duration =1min 52.69s
#
# 829
# Epoch duration =0.13s
# Cumulative duration =1min 52.82s
#
# 830
# Epoch duration =0.13s
# Cumulative duration =1min 52.95s
#
# 831
# Epoch duration =0.14s
# Cumulative duration =1min 53.09s
#
# 832
# Epoch duration =0.13s
# Cumulative duration =1min 53.23s
#
# 833
# Epoch duration =0.16s
# Cumulative duration =1min 53.38s
#
# 834
# Epoch duration =0.13s
# Cumulative duration =1min 53.51s
#
# 835
# Epoch duration =0.14s
# Cumulative duration =1min 53.65s
#
# 836
# Epoch duration =0.13s
# Cumulative duration =1min 53.78s
#
# 837
# Epoch duration =0.13s
# Cumulative duration =1min 53.91s
#
# 838
# Epoch duration =0.13s
# Cumulative duration =1min 54.04s
#
# 839
# Epoch duration =0.13s
# Cumulative duration =1min 54.17s
#
# 840
# Epoch duration =0.13s
# Cumulative duration =1min 54.3s
#
# 841
# Epoch duration =0.13s
# Cumulative duration =1min 54.44s
#
# ...
# Cumulative duration =10min 57.06s
#
# 4742
# Epoch duration =0.13s
# Cumulative duration =10min 57.19s
#
# 4743
# Epoch duration =0.13s
# Cumulative duration =10min 57.32s
#
# 4744
# Epoch duration =0.14s
# Cumulative duration =10min 57.46s
#
# 4745
# Epoch duration =0.13s
# Cumulative duration =10min 57.59s
#
# 4746
# Epoch duration =0.14s
# Cumulative duration =10min 57.73s
#
# 4747
# Epoch duration =0.14s
# Cumulative duration =10min 57.87s
#
# 4748
# Epoch duration =0.14s
# Cumulative duration =10min 58.01s
#
# 4749
# Epoch duration =0.17s
# Cumulative duration =10min 58.18s
#
# 4750
# Epoch duration =0.14s
# Cumulative duration =10min 58.32s
#
# 4751
# Epoch duration =0.14s
# Cumulative duration =10min 58.46s
#
# 4752
# Epoch duration =0.14s
# Cumulative duration =10min 58.59s
#
# 4753
# Epoch duration =0.14s
# Cumulative duration =10min 58.73s
#
# 4754
# Epoch duration =0.14s
# Cumulative duration =10min 58.87s
#
# 4755
# Epoch duration =0.13s
# Cumulative duration =10min 59.0s
#
# 4756
# Epoch duration =0.14s
# Cumulative duration =10min 59.14s
#
# 4757
# Epoch duration =0.15s
# Cumulative duration =10min 59.29s
#
# 4758
# Epoch duration =0.13s
# Cumulative duration =10min 59.42s
#
# 4759
# Epoch duration =0.13s
# Cumulative duration =10min 59.56s
#
# 4760
# Epoch duration =0.13s
# Cumulative duration =10min 59.68s
#
# 4761
# Epoch duration =0.14s
# Cumulative duration =10min 59.83s
#
# 4762
# Epoch duration =0.14s
# Cumulative duration =10min 59.96s
#
# 4763
# Epoch duration =0.14s
# Cumulative duration =11min 0.1s
#
# 4764
# Epoch duration =0.13s
# Cumulative duration =11min 0.23s
#
# 4765
# Epoch duration =0.13s
# Cumulative duration =11min 0.36s
#
# 4766
# Epoch duration =0.14s
# Cumulative duration =11min 0.5s
#
# 4767
# Epoch duration =0.16s
# Cumulative duration =11min 0.67s
#
# 4768
# Epoch duration =0.13s
# Cumulative duration =11min 0.8s
#
# 4769
# Epoch duration =0.16s
# Cumulative duration =11min 0.96s
#
# 4770
# Epoch duration =0.13s
# Cumulative duration =11min 1.09s
#
# 4771
# Epoch duration =0.14s
# Cumulative duration =11min 1.23s
#
# 4772
# Epoch duration =0.13s
# Cumulative duration =11min 1.36s
#
# 4773
# Epoch duration =0.14s
# Cumulative duration =11min 1.5s
#
# 4774
# Epoch duration =0.14s
# Cumulative duration =11min 1.64s
#
# 4775
# Epoch duration =0.13s
# Cumulative duration =11min 1.77s
#
# 4776
# Epoch duration =0.14s
# Cumulative duration =11min 1.91s
#
# 4777
# Epoch duration =0.13s
# Cumulative duration =11min 2.05s
#
# 4778
# Epoch duration =0.14s
# Cumulative duration =11min 2.19s
#
# 4779
# Epoch duration =0.19s
# Cumulative duration =11min 2.37s
#
# 4780
# Epoch duration =0.14s
# Cumulative duration =11min 2.51s
#
# 4781
# Epoch duration =0.14s
# Cumulative duration =11min 2.65s
#
# 4782
# Epoch duration =0.14s
# Cumulative duration =11min 2.79s
#
# 4783
# Epoch duration =0.17s
# Cumulative duration =11min 2.96s
#
# 4784
# Epoch duration =0.17s
# Cumulative duration =11min 3.13s
#
# 4785
# Epoch duration =0.16s
# Cumulative duration =11min 3.29s
#
# 4786
# Epoch duration =0.14s
# Cumulative duration =11min 3.43s
#
# 4787
# Epoch duration =0.17s
# Cumulative duration =11min 3.6s
#
# 4788
# Epoch duration =0.16s
# Cumulative duration =11min 3.76s
#
# 4789
# Epoch duration =0.13s
# Cumulative duration =11min 3.89s
#
# 4790
# Epoch duration =0.14s
# Cumulative duration =11min 4.02s
#
# 4791
# Epoch duration =0.14s
# Cumulative duration =11min 4.16s
#
# 4792
# Epoch duration =0.13s
# Cumulative duration =11min 4.29s
#
# 4793
# Epoch duration =0.13s
# Cumulative duration =11min 4.43s
#
# 4794
# Epoch duration =0.14s
# Cumulative duration =11min 4.56s
#
# 4795
# Epoch duration =0.15s
# Cumulative duration =11min 4.72s
#
# 4796
# Epoch duration =0.13s
# Cumulative duration =11min 4.85s
#
# 4797
# Epoch duration =0.13s
# Cumulative duration =11min 4.98s
#
# 4798
# Epoch duration =0.16s
# Cumulative duration =11min 5.14s
#
# 4799
# Epoch duration =0.19s
# Cumulative duration =11min 5.33s
#
# 4800
# Epoch duration =0.14s
# Cumulative duration =11min 5.46s
#
# 4801
# Epoch duration =0.13s
# Cumulative duration =11min 5.59s
#
# 4802
# Epoch duration =0.14s
# Cumulative duration =11min 5.73s
#
# 4803
# Epoch duration =0.15s
# Cumulative duration =11min 5.88s
#
# 4804
# Epoch duration =0.13s
# Cumulative duration =11min 6.02s
#
# 4805
# Epoch duration =0.13s
# Cumulative duration =11min 6.15s
#
# 4806
# Epoch duration =0.13s
# Cumulative duration =11min 6.28s
#
# 4807
# Epoch duration =0.13s
# Cumulative duration =11min 6.41s
#
# 4808
# Epoch duration =0.13s
# Cumulative duration =11min 6.54s
#
# 4809
# Epoch duration =0.13s
# Cumulative duration =11min 6.68s
#
# 4810
# Epoch duration =0.14s
# Cumulative duration =11min 6.82s
#
# 4811
# Epoch duration =0.15s
# Cumulative duration =11min 6.97s
#
# 4812
# Epoch duration =0.14s
# Cumulative duration =11min 7.1s
#
# 4813
# Epoch duration =0.14s
# Cumulative duration =11min 7.24s
#
# 4814
# Epoch duration =0.15s
# Cumulative duration =11min 7.39s
#
# 4815
# Epoch duration =0.13s
# Cumulative duration =11min 7.52s
#
# 4816
# Epoch duration =0.14s
# Cumulative duration =11min 7.66s
#
# 4817
# Epoch duration =0.18s
# Cumulative duration =11min 7.84s
#
# 4818
# Epoch duration =0.13s
# Cumulative duration =11min 7.97s
#
# 4819
# Epoch duration =0.13s
# Cumulative duration =11min 8.1s
#
# 4820
# Epoch duration =0.16s
# Cumulative duration =11min 8.26s
#
# 4821
# Epoch duration =0.13s
# Cumulative duration =11min 8.4s
#
# 4822
# Epoch duration =0.13s
# Cumulative duration =11min 8.53s
#
# 4823
# Epoch duration =0.14s
# Cumulative duration =11min 8.67s
#
# 4824
# Epoch duration =0.15s
# Cumulative duration =11min 8.81s
#
# 4825
# Epoch duration =0.13s
# Cumulative duration =11min 8.94s
#
# 4826
# Epoch duration =0.13s
# Cumulative duration =11min 9.07s
#
# 4827
# Epoch duration =0.13s
# Cumulative duration =11min 9.2s
#
# 4828
# Epoch duration =0.15s
# Cumulative duration =11min 9.35s
#
# 4829
# Epoch duration =0.14s
# Cumulative duration =11min 9.49s
#
# 4830
# Epoch duration =0.15s
# Cumulative duration =11min 9.64s
#
# 4831
# Epoch duration =0.18s
# Cumulative duration =11min 9.82s
#
# 4832
# Epoch duration =0.14s
# Cumulative duration =11min 9.95s
#
# 4833
# Epoch duration =0.14s
# Cumulative duration =11min 10.1s
#
# 4834
# Epoch duration =0.14s
# Cumulative duration =11min 10.23s
#
# 4835
# Epoch duration =0.18s
# Cumulative duration =11min 10.41s
#
# 4836
# Epoch duration =0.14s
# Cumulative duration =11min 10.55s
#
# 4837
# Epoch duration =0.13s
# Cumulative duration =11min 10.68s
#
# 4838
# Epoch duration =0.14s
# Cumulative duration =11min 10.82s
#
# 4839
# Epoch duration =0.17s
# Cumulative duration =11min 10.99s
#
# 4840
# Epoch duration =0.13s
# Cumulative duration =11min 11.12s
#
# 4841
# Epoch duration =0.13s
# Cumulative duration =11min 11.26s
#
# 4842
# Epoch duration =0.14s
# Cumulative duration =11min 11.4s
#
# 4843
# Epoch duration =0.17s
# Cumulative duration =11min 11.56s
#
# 4844
# Epoch duration =0.14s
# Cumulative duration =11min 11.7s
#
# 4845
# Epoch duration =0.16s
# Cumulative duration =11min 11.87s
#
# 4846
# Epoch duration =0.13s
# Cumulative duration =11min 12.0s
#
# 4847
# Epoch duration =0.13s
# Cumulative duration =11min 12.13s
#
# 4848
# Epoch duration =0.14s
# Cumulative duration =11min 12.27s
#
# 4849
# Epoch duration =0.17s
# Cumulative duration =11min 12.43s
#
# 4850
# Epoch duration =0.13s
# Cumulative duration =11min 12.57s
#
# 4851
# Epoch duration =0.13s
# Cumulative duration =11min 12.7s
#
# 4852
# Epoch duration =0.14s
# Cumulative duration =11min 12.84s
#
# 4853
# Epoch duration =0.13s
# Cumulative duration =11min 12.97s
#
# 4854
# Epoch duration =0.13s
# Cumulative duration =11min 13.1s
#
# 4855
# Epoch duration =0.13s
# Cumulative duration =11min 13.23s
#
# 4856
# Epoch duration =0.14s
# Cumulative duration =11min 13.37s
#
# 4857
# Epoch duration =0.13s
# Cumulative duration =11min 13.5s
#
# 4858
# Epoch duration =0.16s
# Cumulative duration =11min 13.66s
#
# 4859
# Epoch duration =0.18s
# Cumulative duration =11min 13.83s
#
# 4860
# Epoch duration =0.13s
# Cumulative duration =11min 13.97s
#
# 4861
# Epoch duration =0.13s
# Cumulative duration =11min 14.1s
#
# 4862
# Epoch duration =0.14s
# Cumulative duration =11min 14.24s
#
# 4863
# Epoch duration =0.15s
# Cumulative duration =11min 14.39s
#
# 4864
# Epoch duration =0.13s
# Cumulative duration =11min 14.52s
#
# 4865
# Epoch duration =0.13s
# Cumulative duration =11min 14.65s
#
# 4866
# Epoch duration =0.13s
# Cumulative duration =11min 14.78s
#
# 4867
# Epoch duration =0.13s
# Cumulative duration =11min 14.92s
#
# 4868
# Epoch duration =0.14s
# Cumulative duration =11min 15.06s
#
# 4869
# Epoch duration =0.2s
# Cumulative duration =11min 15.27s
#
# 4870
# Epoch duration =0.16s
# Cumulative duration =11min 15.42s
#
# 4871
# Epoch duration =0.13s
# Cumulative duration =11min 15.56s
#
# 4872
# Epoch duration =0.14s
# Cumulative duration =11min 15.7s
#
# 4873
# Epoch duration =0.13s
# Cumulative duration =11min 15.83s
#
# 4874
# Epoch duration =0.13s
# Cumulative duration =11min 15.96s
#
# 4875
# Epoch duration =0.14s
# Cumulative duration =11min 16.1s
#
# 4876
# Epoch duration =0.13s
# Cumulative duration =11min 16.23s
#
# 4877
# Epoch duration =0.16s
# Cumulative duration =11min 16.39s
#
# 4878
# Epoch duration =0.18s
# Cumulative duration =11min 16.57s
#
# 4879
# Epoch duration =0.14s
# Cumulative duration =11min 16.7s
#
# 4880
# Epoch duration =0.15s
# Cumulative duration =11min 16.86s
#
# 4881
# Epoch duration =0.13s
# Cumulative duration =11min 16.99s
#
# 4882
# Epoch duration =0.13s
# Cumulative duration =11min 17.12s
#
# 4883
# Epoch duration =0.13s
# Cumulative duration =11min 17.25s
#
# 4884
# Epoch duration =0.13s
# Cumulative duration =11min 17.39s
#
# 4885
# Epoch duration =0.14s
# Cumulative duration =11min 17.53s
#
# 4886
# Epoch duration =0.13s
# Cumulative duration =11min 17.66s
#
# 4887
# Epoch duration =0.14s
# Cumulative duration =11min 17.8s
#
# 4888
# Epoch duration =0.19s
# Cumulative duration =11min 17.99s
#
# 4889
# Epoch duration =0.13s
# Cumulative duration =11min 18.12s
#
# 4890
# Epoch duration =0.13s
# Cumulative duration =11min 18.26s
#
# 4891
# Epoch duration =0.13s
# Cumulative duration =11min 18.39s
#
# 4892
# Epoch duration =0.13s
# Cumulative duration =11min 18.52s
#
# 4893
# Epoch duration =0.15s
# Cumulative duration =11min 18.67s
#
# 4894
# Epoch duration =0.13s
# Cumulative duration =11min 18.8s
#
# 4895
# Epoch duration =0.14s
# Cumulative duration =11min 18.94s
#
# 4896
# Epoch duration =0.19s
# Cumulative duration =11min 19.13s
#
# 4897
# Epoch duration =0.14s
# Cumulative duration =11min 19.27s
#
# 4898
# Epoch duration =0.14s
# Cumulative duration =11min 19.41s
#
# 4899
# Epoch duration =0.13s
# Cumulative duration =11min 19.53s
#
# 4900
# Epoch duration =0.13s
# Cumulative duration =11min 19.67s
#
# 4901
# Epoch duration =0.13s
# Cumulative duration =11min 19.8s
#
# 4902
# Epoch duration =0.13s
# Cumulative duration =11min 19.93s
#
# 4903
# Epoch duration =0.13s
# Cumulative duration =11min 20.06s
#
# 4904
# Epoch duration =0.13s
# Cumulative duration =11min 20.19s
#
# 4905
# Epoch duration =0.14s
# Cumulative duration =11min 20.33s
#
# 4906
# Epoch duration =0.13s
# Cumulative duration =11min 20.46s
#
# 4907
# Epoch duration =0.13s
# Cumulative duration =11min 20.6s
#
# 4908
# Epoch duration =0.16s
# Cumulative duration =11min 20.76s
#
# 4909
# Epoch duration =0.13s
# Cumulative duration =11min 20.89s
#
# 4910
# Epoch duration =0.14s
# Cumulative duration =11min 21.03s
#
# 4911
# Epoch duration =0.13s
# Cumulative duration =11min 21.16s
#
# 4912
# Epoch duration =0.2s
# Cumulative duration =11min 21.36s
#
# 4913
# Epoch duration =0.14s
# Cumulative duration =11min 21.5s
#
# 4914
# Epoch duration =0.14s
# Cumulative duration =11min 21.64s
#
# 4915
# Epoch duration =0.13s
# Cumulative duration =11min 21.77s
#
# 4916
# Epoch duration =0.13s
# Cumulative duration =11min 21.9s
#
# 4917
# Epoch duration =0.13s
# Cumulative duration =11min 22.03s
#
# 4918
# Epoch duration =0.13s
# Cumulative duration =11min 22.17s
#
# 4919
# Epoch duration =0.14s
# Cumulative duration =11min 22.3s
#
# 4920
# Epoch duration =0.15s
# Cumulative duration =11min 22.45s
#
# 4921
# Epoch duration =0.13s
# Cumulative duration =11min 22.58s
#
# 4922
# Epoch duration =0.14s
# Cumulative duration =11min 22.72s
#
# 4923
# Epoch duration =0.14s
# Cumulative duration =11min 22.86s
#
# 4924
# Epoch duration =0.13s
# Cumulative duration =11min 22.99s
#
# 4925
# Epoch duration =0.13s
# Cumulative duration =11min 23.12s
#
# 4926
# Epoch duration =0.13s
# Cumulative duration =11min 23.25s
#
# 4927
# Epoch duration =0.14s
# Cumulative duration =11min 23.39s
#
# 4928
# Epoch duration =0.13s
# Cumulative duration =11min 23.52s
#
# 4929
# Epoch duration =0.15s
# Cumulative duration =11min 23.67s
#
# 4930
# Epoch duration =0.13s
# Cumulative duration =11min 23.8s
#
# 4931
# Epoch duration =0.13s
# Cumulative duration =11min 23.94s
#
# 4932
# Epoch duration =0.13s
# Cumulative duration =11min 24.06s
#
# 4933
# Epoch duration =0.13s
# Cumulative duration =11min 24.2s
#
# 4934
# Epoch duration =0.14s
# Cumulative duration =11min 24.33s
#
# 4935
# Epoch duration =0.13s
# Cumulative duration =11min 24.47s
#
# 4936
# Epoch duration =0.13s
# Cumulative duration =11min 24.6s
#
# 4937
# Epoch duration =0.16s
# Cumulative duration =11min 24.76s
#
# 4938
# Epoch duration =0.18s
# Cumulative duration =11min 24.94s
#
# 4939
# Epoch duration =0.14s
# Cumulative duration =11min 25.08s
#
# 4940
# Epoch duration =0.14s
# Cumulative duration =11min 25.22s
#
# 4941
# Epoch duration =0.16s
# Cumulative duration =11min 25.38s
#
# 4942
# Epoch duration =0.19s
# Cumulative duration =11min 25.57s
#
# 4943
# Epoch duration =0.14s
# Cumulative duration =11min 25.71s
#
# 4944
# Epoch duration =0.13s
# Cumulative duration =11min 25.85s
#
# 4945
# Epoch duration =0.14s
# Cumulative duration =11min 25.99s
#
# 4946
# Epoch duration =0.13s
# Cumulative duration =11min 26.12s
#
# 4947
# Epoch duration =0.15s
# Cumulative duration =11min 26.27s
#
# 4948
# Epoch duration =0.15s
# Cumulative duration =11min 26.41s
#
# 4949
# Epoch duration =0.14s
# Cumulative duration =11min 26.55s
#
# 4950
# Epoch duration =0.16s
# Cumulative duration =11min 26.72s
#
# 4951
# Epoch duration =0.16s
# Cumulative duration =11min 26.87s
#
# 4952
# Epoch duration =0.17s
# Cumulative duration =11min 27.05s
#
# 4953
# Epoch duration =0.14s
# Cumulative duration =11min 27.18s
#
# 4954
# Epoch duration =0.15s
# Cumulative duration =11min 27.34s
#
# 4955
# Epoch duration =0.14s
# Cumulative duration =11min 27.47s
#
# 4956
# Epoch duration =0.18s
# Cumulative duration =11min 27.66s
#
# 4957
# Epoch duration =0.17s
# Cumulative duration =11min 27.83s
#
# 4958
# Epoch duration =0.14s
# Cumulative duration =11min 27.97s
#
# 4959
# Epoch duration =0.14s
# Cumulative duration =11min 28.1s
#
# 4960
# Epoch duration =0.13s
# Cumulative duration =11min 28.24s
#
# 4961
# Epoch duration =0.14s
# Cumulative duration =11min 28.37s
#
# 4962
# Epoch duration =0.14s
# Cumulative duration =11min 28.51s
#
# 4963
# Epoch duration =0.13s
# Cumulative duration =11min 28.64s
#
# 4964
# Epoch duration =0.13s
# Cumulative duration =11min 28.77s
#
# 4965
# Epoch duration =0.14s
# Cumulative duration =11min 28.91s
#
# 4966
# Epoch duration =0.13s
# Cumulative duration =11min 29.04s
#
# 4967
# Epoch duration =0.13s
# Cumulative duration =11min 29.17s
#
# 4968
# Epoch duration =0.13s
# Cumulative duration =11min 29.31s
#
# 4969
# Epoch duration =0.13s
# Cumulative duration =11min 29.44s
#
# 4970
# Epoch duration =0.13s
# Cumulative duration =11min 29.57s
#
# 4971
# Epoch duration =0.13s
# Cumulative duration =11min 29.7s
#
# 4972
# Epoch duration =0.13s
# Cumulative duration =11min 29.83s
#
# 4973
# Epoch duration =0.14s
# Cumulative duration =11min 29.97s
#
# 4974
# Epoch duration =0.16s
# Cumulative duration =11min 30.14s
#
# 4975
# Epoch duration =0.15s
# Cumulative duration =11min 30.29s
#
# 4976
# Epoch duration =0.13s
# Cumulative duration =11min 30.42s
#
# 4977
# Epoch duration =0.14s
# Cumulative duration =11min 30.56s
#
# 4978
# Epoch duration =0.15s
# Cumulative duration =11min 30.71s
#
# 4979
# Epoch duration =0.13s
# Cumulative duration =11min 30.84s
#
# 4980
# Epoch duration =0.13s
# Cumulative duration =11min 30.97s
#
# 4981
# Epoch duration =0.15s
# Cumulative duration =11min 31.13s
#
# 4982
# Epoch duration =0.13s
# Cumulative duration =11min 31.26s
#
# 4983
# Epoch duration =0.15s
# Cumulative duration =11min 31.41s
#
# 4984
# Epoch duration =0.13s
# Cumulative duration =11min 31.54s
#
# 4985
# Epoch duration =0.14s
# Cumulative duration =11min 31.68s
#
# 4986
# Epoch duration =0.15s
# Cumulative duration =11min 31.83s
#
# 4987
# Epoch duration =0.14s
# Cumulative duration =11min 31.97s
#
# 4988
# Epoch duration =0.17s
# Cumulative duration =11min 32.15s
#
# 4989
# Epoch duration =0.13s
# Cumulative duration =11min 32.28s
#
# 4990
# Epoch duration =0.13s
# Cumulative duration =11min 32.41s
#
# 4991
# Epoch duration =0.13s
# Cumulative duration =11min 32.54s
#
# 4992
# Epoch duration =0.13s
# Cumulative duration =11min 32.67s
#
# 4993
# Epoch duration =0.13s
# Cumulative duration =11min 32.8s
#
# 4994
# Epoch duration =0.13s
# Cumulative duration =11min 32.93s
#
# 4995
# Epoch duration =0.14s
# Cumulative duration =11min 33.07s
#
# 4996
# Epoch duration =0.15s
# Cumulative duration =11min 33.23s
#
# 4997
# Epoch duration =0.14s
# Cumulative duration =11min 33.36s
#
# 4998
# Epoch duration =0.14s
# Cumulative duration =11min 33.5s
#
# 4999
# Epoch duration =0.14s
# Cumulative duration =11min 33.64s
#
# Saving scores to Arrays/toyhairpin_FC_1_44_sumoutputs5k.npy

# %%
#Load the saved data
savepath = 'Arrays/toyhairpin_FC_1_44_sumoutputs5k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 5000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

# %%
mf.symlinear_holplot(meanhol_mut2, figplot=(4,5), alphabet='rna')

# %%
mf.square_holplot(meanhol_mut2, num=15, alphabet='rna')
