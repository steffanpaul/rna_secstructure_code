# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import mutagenesis_functions as mf
import time as time

# %%
# load hairpin data
data_path = '../data_peter/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../results/toyhairpin'
param_path = os.path.join(save_path, 'resbindx')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=20, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=14.31s -- loss=0.29182 -- acc=86.95990%
#
#   valid loss:		0.10080
#   valid accuracy:	0.96596+/-0.00000
#   valid auc-roc:	0.99501+/-0.00000
#   valid auc-pr:		0.98626+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=13.68s -- loss=0.17016 -- acc=93.64271%
#
#   valid loss:		0.11597
#   valid accuracy:	0.95642+/-0.00000
#   valid auc-roc:	0.99521+/-0.00000
#   valid auc-pr:		0.98575+/-0.00000
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=13.64s -- loss=0.15327 -- acc=94.49427%
#
#   valid loss:		0.09547
#   valid accuracy:	0.96590+/-0.00000
#   valid auc-roc:	0.99669+/-0.00000
#   valid auc-pr:		0.98963+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=13.69s -- loss=0.14645 -- acc=94.85886%
#
#   valid loss:		0.10135
#   valid accuracy:	0.96410+/-0.00000
#   valid auc-roc:	0.99649+/-0.00000
#   valid auc-pr:		0.98840+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=13.68s -- loss=0.13917 -- acc=95.22500%
#
#   valid loss:		0.09979
#   valid accuracy:	0.96546+/-0.00000
#   valid auc-roc:	0.99648+/-0.00000
#   valid auc-pr:		0.98869+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=13.72s -- loss=0.13404 -- acc=95.49532%
#
#   valid loss:		0.09657
#   valid accuracy:	0.96652+/-0.00000
#   valid auc-roc:	0.99746+/-0.00000
#   valid auc-pr:		0.99162+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=13.68s -- loss=0.13023 -- acc=95.75104%
#
#   valid loss:		0.08307
#   valid accuracy:	0.97306+/-0.00000
#   valid auc-roc:	0.99823+/-0.00000
#   valid auc-pr:		0.99404+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=13.74s -- loss=0.12250 -- acc=96.07188%
#
#   valid loss:		0.08460
#   valid accuracy:	0.97219+/-0.00000
#   valid auc-roc:	0.99841+/-0.00000
#   valid auc-pr:		0.99501+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=13.79s -- loss=0.11861 -- acc=96.26979%
#
#   valid loss:		0.07789
#   valid accuracy:	0.97619+/-0.00000
#   valid auc-roc:	0.99865+/-0.00000
#   valid auc-pr:		0.99554+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=13.75s -- loss=0.11464 -- acc=96.50834%
#
#   valid loss:		0.08332
#   valid accuracy:	0.97408+/-0.00000
#   valid auc-roc:	0.99845+/-0.00000
#   valid auc-pr:		0.99499+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=13.83s -- loss=0.10973 -- acc=96.69740%
#
#   valid loss:		0.07700
#   valid accuracy:	0.97696+/-0.00000
#   valid auc-roc:	0.99884+/-0.00000
#   valid auc-pr:		0.99632+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=13.89s -- loss=0.10541 -- acc=96.94531%
#
#   valid loss:		0.06822
#   valid accuracy:	0.98098+/-0.00000
#   valid auc-roc:	0.99905+/-0.00000
#   valid auc-pr:		0.99672+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=13.94s -- loss=0.10389 -- acc=97.03854%
#
#   valid loss:		0.07253
#   valid accuracy:	0.97969+/-0.00000
#   valid auc-roc:	0.99891+/-0.00000
#   valid auc-pr:		0.99647+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=14.07s -- loss=0.10220 -- acc=97.07240%
#
#   valid loss:		0.06651
#   valid accuracy:	0.98198+/-0.00000
#   valid auc-roc:	0.99919+/-0.00000
#   valid auc-pr:		0.99746+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=14.01s -- loss=0.09995 -- acc=97.21198%
#
#   valid loss:		0.06675
#   valid accuracy:	0.98237+/-0.00000
#   valid auc-roc:	0.99925+/-0.00000
#   valid auc-pr:		0.99746+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.09932 -- acc=97.25886%
#
#   valid loss:		0.06985
#   valid accuracy:	0.98129+/-0.00000
#   valid auc-roc:	0.99918+/-0.00000
#   valid auc-pr:		0.99736+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=13.88s -- loss=0.09649 -- acc=97.40990%
#
#   valid loss:		0.06371
#   valid accuracy:	0.98460+/-0.00000
#   valid auc-roc:	0.99920+/-0.00000
#   valid auc-pr:		0.99759+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=14.84s -- loss=0.09565 -- acc=97.40261%
#
#   valid loss:		0.06556
#   valid accuracy:	0.98390+/-0.00000
#   valid auc-roc:	0.99919+/-0.00000
#   valid auc-pr:		0.99758+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=13.88s -- loss=0.09428 -- acc=97.49323%
#
#   valid loss:		0.06900
#   valid accuracy:	0.98235+/-0.00000
#   valid auc-roc:	0.99924+/-0.00000
#   valid auc-pr:		0.99721+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=14.34s -- loss=0.09315 -- acc=97.53646%
#
#   valid loss:		0.06802
#   valid accuracy:	0.98290+/-0.00000
#   valid auc-roc:	0.99923+/-0.00000
#   valid auc-pr:		0.99713+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=13.92s -- loss=0.09050 -- acc=97.65417%
#
#   valid loss:		0.05984
#   valid accuracy:	0.98610+/-0.00000
#   valid auc-roc:	0.99953+/-0.00000
#   valid auc-pr:		0.99853+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=13.94s -- loss=0.09071 -- acc=97.65104%
#
#   valid loss:		0.06749
#   valid accuracy:	0.98342+/-0.00000
#   valid auc-roc:	0.99935+/-0.00000
#   valid auc-pr:		0.99773+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=14.02s -- loss=0.08724 -- acc=97.78854%
#
#   valid loss:		0.06381
#   valid accuracy:	0.98485+/-0.00000
#   valid auc-roc:	0.99946+/-0.00000
#   valid auc-pr:		0.99843+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=14.09s -- loss=0.08892 -- acc=97.74688%
#
#   valid loss:		0.05823
#   valid accuracy:	0.98708+/-0.00000
#   valid auc-roc:	0.99946+/-0.00000
#   valid auc-pr:		0.99829+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=14.01s -- loss=0.08624 -- acc=97.85261%
#
#   valid loss:		0.06150
#   valid accuracy:	0.98610+/-0.00000
#   valid auc-roc:	0.99941+/-0.00000
#   valid auc-pr:		0.99803+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=13.96s -- loss=0.08766 -- acc=97.79323%
#
#   valid loss:		0.05643
#   valid accuracy:	0.98800+/-0.00000
#   valid auc-roc:	0.99945+/-0.00000
#   valid auc-pr:		0.99838+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=14.36s -- loss=0.08415 -- acc=97.92604%
#
#   valid loss:		0.05907
#   valid accuracy:	0.98679+/-0.00000
#   valid auc-roc:	0.99945+/-0.00000
#   valid auc-pr:		0.99822+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=13.96s -- loss=0.08485 -- acc=97.93906%
#
#   valid loss:		0.05695
#   valid accuracy:	0.98783+/-0.00000
#   valid auc-roc:	0.99946+/-0.00000
#   valid auc-pr:		0.99795+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=14.01s -- loss=0.08319 -- acc=97.98125%
#
#   valid loss:		0.05780
#   valid accuracy:	0.98769+/-0.00000
#   valid auc-roc:	0.99941+/-0.00000
#   valid auc-pr:		0.99798+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.08200 -- acc=98.03438%
#
#   valid loss:		0.06276
#   valid accuracy:	0.98621+/-0.00000
#   valid auc-roc:	0.99937+/-0.00000
#   valid auc-pr:		0.99798+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.08280 -- acc=98.04271%
#
#   valid loss:		0.05567
#   valid accuracy:	0.98862+/-0.00000
#   valid auc-roc:	0.99955+/-0.00000
#   valid auc-pr:		0.99871+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=14.37s -- loss=0.08163 -- acc=98.02604%
#
#   valid loss:		0.05505
#   valid accuracy:	0.98871+/-0.00000
#   valid auc-roc:	0.99950+/-0.00000
#   valid auc-pr:		0.99832+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=14.24s -- loss=0.08103 -- acc=98.05313%
#
#   valid loss:		0.05738
#   valid accuracy:	0.98802+/-0.00000
#   valid auc-roc:	0.99948+/-0.00000
#   valid auc-pr:		0.99836+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=14.12s -- loss=0.07957 -- acc=98.14167%
#
#   valid loss:		0.05613
#   valid accuracy:	0.98846+/-0.00000
#   valid auc-roc:	0.99944+/-0.00000
#   valid auc-pr:		0.99813+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=14.03s -- loss=0.08007 -- acc=98.09219%
#
#   valid loss:		0.05170
#   valid accuracy:	0.99015+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99895+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=14.48s -- loss=0.07861 -- acc=98.17552%
#
#   valid loss:		0.05865
#   valid accuracy:	0.98777+/-0.00000
#   valid auc-roc:	0.99942+/-0.00000
#   valid auc-pr:		0.99837+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=13.99s -- loss=0.07935 -- acc=98.13542%
#
#   valid loss:		0.05388
#   valid accuracy:	0.98927+/-0.00000
#   valid auc-roc:	0.99956+/-0.00000
#   valid auc-pr:		0.99874+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=14.22s -- loss=0.07837 -- acc=98.16042%
#
#   valid loss:		0.05541
#   valid accuracy:	0.98879+/-0.00000
#   valid auc-roc:	0.99954+/-0.00000
#   valid auc-pr:		0.99848+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=14.32s -- loss=0.07758 -- acc=98.23073%
#
#   valid loss:		0.05695
#   valid accuracy:	0.98829+/-0.00000
#   valid auc-roc:	0.99953+/-0.00000
#   valid auc-pr:		0.99858+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=14.00s -- loss=0.07639 -- acc=98.24688%
#
#   valid loss:		0.05293
#   valid accuracy:	0.98987+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99844+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=14.07s -- loss=0.07673 -- acc=98.20625%
#
#   valid loss:		0.05668
#   valid accuracy:	0.98850+/-0.00000
#   valid auc-roc:	0.99948+/-0.00000
#   valid auc-pr:		0.99824+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=14.29s -- loss=0.07626 -- acc=98.22604%
#
#   valid loss:		0.05616
#   valid accuracy:	0.98825+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99853+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=14.26s -- loss=0.07671 -- acc=98.25052%
#
#   valid loss:		0.05375
#   valid accuracy:	0.98960+/-0.00000
#   valid auc-roc:	0.99954+/-0.00000
#   valid auc-pr:		0.99868+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=14.23s -- loss=0.07602 -- acc=98.26250%
#
#   valid loss:		0.05232
#   valid accuracy:	0.99004+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99866+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=14.38s -- loss=0.07676 -- acc=98.24688%
#
#   valid loss:		0.05502
#   valid accuracy:	0.98931+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99878+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=14.28s -- loss=0.07661 -- acc=98.23958%
#
#   valid loss:		0.05399
#   valid accuracy:	0.98962+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99896+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=14.29s -- loss=0.07561 -- acc=98.30208%
#
#   valid loss:		0.05315
#   valid accuracy:	0.98979+/-0.00000
#   valid auc-roc:	0.99958+/-0.00000
#   valid auc-pr:		0.99869+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=14.30s -- loss=0.07619 -- acc=98.22552%
#
#   valid loss:		0.05381
#   valid accuracy:	0.98948+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99871+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=14.40s -- loss=0.07402 -- acc=98.32448%
#
#   valid loss:		0.05363
#   valid accuracy:	0.98960+/-0.00000
#   valid auc-roc:	0.99949+/-0.00000
#   valid auc-pr:		0.99831+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=14.31s -- loss=0.07319 -- acc=98.35677%
#
#   valid loss:		0.04878
#   valid accuracy:	0.99129+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99900+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=14.26s -- loss=0.07419 -- acc=98.30677%
#
#   valid loss:		0.05368
#   valid accuracy:	0.99015+/-0.00000
#   valid auc-roc:	0.99942+/-0.00000
#   valid auc-pr:		0.99822+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=14.41s -- loss=0.07346 -- acc=98.33854%
#
#   valid loss:		0.05325
#   valid accuracy:	0.98994+/-0.00000
#   valid auc-roc:	0.99952+/-0.00000
#   valid auc-pr:		0.99854+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=14.00s -- loss=0.07329 -- acc=98.33906%
#
#   valid loss:		0.05694
#   valid accuracy:	0.98858+/-0.00000
#   valid auc-roc:	0.99952+/-0.00000
#   valid auc-pr:		0.99840+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=14.48s -- loss=0.07402 -- acc=98.34688%
#
#   valid loss:		0.05687
#   valid accuracy:	0.98827+/-0.00000
#   valid auc-roc:	0.99950+/-0.00000
#   valid auc-pr:		0.99828+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=14.29s -- loss=0.07327 -- acc=98.31511%
#
#   valid loss:		0.05404
#   valid accuracy:	0.98958+/-0.00000
#   valid auc-roc:	0.99949+/-0.00000
#   valid auc-pr:		0.99813+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=14.09s -- loss=0.07341 -- acc=98.35990%
#
#   valid loss:		0.05447
#   valid accuracy:	0.98967+/-0.00000
#   valid auc-roc:	0.99953+/-0.00000
#   valid auc-pr:		0.99844+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=14.50s -- loss=0.07474 -- acc=98.31094%
#
#   valid loss:		0.04812
#   valid accuracy:	0.99185+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99872+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=14.08s -- loss=0.07367 -- acc=98.34063%
#
#   valid loss:		0.04953
#   valid accuracy:	0.99146+/-0.00000
#   valid auc-roc:	0.99956+/-0.00000
#   valid auc-pr:		0.99862+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=14.01s -- loss=0.07229 -- acc=98.38177%
#
#   valid loss:		0.05553
#   valid accuracy:	0.98875+/-0.00000
#   valid auc-roc:	0.99955+/-0.00000
#   valid auc-pr:		0.99828+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=14.25s -- loss=0.07248 -- acc=98.41354%
#
#   valid loss:		0.04759
#   valid accuracy:	0.99204+/-0.00000
#   valid auc-roc:	0.99955+/-0.00000
#   valid auc-pr:		0.99816+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.07137 -- acc=98.41771%
#
#   valid loss:		0.05053
#   valid accuracy:	0.99069+/-0.00000
#   valid auc-roc:	0.99961+/-0.00000
#   valid auc-pr:		0.99866+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=14.47s -- loss=0.07267 -- acc=98.39427%
#
#   valid loss:		0.05102
#   valid accuracy:	0.99008+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99898+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=14.30s -- loss=0.06994 -- acc=98.45469%
#
#   valid loss:		0.05151
#   valid accuracy:	0.99031+/-0.00000
#   valid auc-roc:	0.99956+/-0.00000
#   valid auc-pr:		0.99857+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=14.28s -- loss=0.07096 -- acc=98.42448%
#
#   valid loss:		0.04866
#   valid accuracy:	0.99162+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99880+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=14.31s -- loss=0.07118 -- acc=98.40573%
#
#   valid loss:		0.05128
#   valid accuracy:	0.99040+/-0.00000
#   valid auc-roc:	0.99959+/-0.00000
#   valid auc-pr:		0.99878+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=14.50s -- loss=0.07068 -- acc=98.43229%
#
#   valid loss:		0.04910
#   valid accuracy:	0.99119+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99901+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=14.28s -- loss=0.07012 -- acc=98.45990%
#
#   valid loss:		0.05421
#   valid accuracy:	0.98925+/-0.00000
#   valid auc-roc:	0.99954+/-0.00000
#   valid auc-pr:		0.99863+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=14.23s -- loss=0.07035 -- acc=98.44427%
#
#   valid loss:		0.04849
#   valid accuracy:	0.99156+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99912+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=14.25s -- loss=0.07101 -- acc=98.42292%
#
#   valid loss:		0.04902
#   valid accuracy:	0.99133+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99906+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=14.60s -- loss=0.07038 -- acc=98.44479%
#
#   valid loss:		0.05129
#   valid accuracy:	0.99027+/-0.00000
#   valid auc-roc:	0.99954+/-0.00000
#   valid auc-pr:		0.99817+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=14.50s -- loss=0.06983 -- acc=98.46094%
#
#   valid loss:		0.04820
#   valid accuracy:	0.99160+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99885+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=14.51s -- loss=0.07081 -- acc=98.43333%
#
#   valid loss:		0.04549
#   valid accuracy:	0.99287+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99872+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=14.21s -- loss=0.07056 -- acc=98.42708%
#
#   valid loss:		0.04830
#   valid accuracy:	0.99144+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99886+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=14.07s -- loss=0.07018 -- acc=98.47136%
#
#   valid loss:		0.04858
#   valid accuracy:	0.99135+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99876+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=14.68s -- loss=0.06973 -- acc=98.46146%
#
#   valid loss:		0.04739
#   valid accuracy:	0.99210+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99861+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.06868 -- acc=98.48021%
#
#   valid loss:		0.04629
#   valid accuracy:	0.99225+/-0.00000
#   valid auc-roc:	0.99959+/-0.00000
#   valid auc-pr:		0.99847+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.06937 -- acc=98.48281%
#
#   valid loss:		0.05000
#   valid accuracy:	0.99110+/-0.00000
#   valid auc-roc:	0.99951+/-0.00000
#   valid auc-pr:		0.99841+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=14.28s -- loss=0.06840 -- acc=98.50990%
#
#   valid loss:		0.04591
#   valid accuracy:	0.99235+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99882+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=14.25s -- loss=0.06909 -- acc=98.49011%
#
#   valid loss:		0.04614
#   valid accuracy:	0.99210+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99888+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=14.08s -- loss=0.06810 -- acc=98.52500%
#
#   valid loss:		0.04523
#   valid accuracy:	0.99215+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99873+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=14.07s -- loss=0.06710 -- acc=98.54479%
#
#   valid loss:		0.04443
#   valid accuracy:	0.99265+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99930+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.06857 -- acc=98.51146%
#
#   valid loss:		0.04615
#   valid accuracy:	0.99215+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99901+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=14.29s -- loss=0.06787 -- acc=98.52500%
#
#   valid loss:		0.04738
#   valid accuracy:	0.99167+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99886+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=14.47s -- loss=0.06764 -- acc=98.54740%
#
#   valid loss:		0.05022
#   valid accuracy:	0.99085+/-0.00000
#   valid auc-roc:	0.99950+/-0.00000
#   valid auc-pr:		0.99840+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=14.56s -- loss=0.06900 -- acc=98.50417%
#
#   valid loss:		0.04687
#   valid accuracy:	0.99187+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99867+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=14.38s -- loss=0.06704 -- acc=98.54375%
#
#   valid loss:		0.04812
#   valid accuracy:	0.99135+/-0.00000
#   valid auc-roc:	0.99958+/-0.00000
#   valid auc-pr:		0.99863+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.06717 -- acc=98.53802%
#
#   valid loss:		0.04745
#   valid accuracy:	0.99162+/-0.00000
#   valid auc-roc:	0.99958+/-0.00000
#   valid auc-pr:		0.99868+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=14.67s -- loss=0.06939 -- acc=98.47969%
#
#   valid loss:		0.04686
#   valid accuracy:	0.99196+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99914+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=14.50s -- loss=0.06677 -- acc=98.53594%
#
#   valid loss:		0.04824
#   valid accuracy:	0.99140+/-0.00000
#   valid auc-roc:	0.99973+/-0.00000
#   valid auc-pr:		0.99904+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=14.58s -- loss=0.06608 -- acc=98.58906%
#
#   valid loss:		0.04585
#   valid accuracy:	0.99227+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99888+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=14.75s -- loss=0.06767 -- acc=98.55104%
#
#   valid loss:		0.04673
#   valid accuracy:	0.99181+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99939+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=14.56s -- loss=0.06872 -- acc=98.52604%
#
#   valid loss:		0.04760
#   valid accuracy:	0.99187+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99892+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=14.52s -- loss=0.06751 -- acc=98.52761%
#
#   valid loss:		0.04523
#   valid accuracy:	0.99267+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99899+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=14.50s -- loss=0.06910 -- acc=98.48802%
#
#   valid loss:		0.04711
#   valid accuracy:	0.99192+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99872+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=14.48s -- loss=0.06506 -- acc=98.62448%
#
#   valid loss:		0.04402
#   valid accuracy:	0.99277+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99926+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/resbindx_best.ckpt
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=14.24s -- loss=0.06710 -- acc=98.54011%
#
#   valid loss:		0.04852
#   valid accuracy:	0.99123+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99893+/-0.00000
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=14.39s -- loss=0.06848 -- acc=98.52240%
#
#   valid loss:		0.04415
#   valid accuracy:	0.99238+/-0.00000
#   valid auc-roc:	0.99973+/-0.00000
#   valid auc-pr:		0.99906+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=14.53s -- loss=0.06690 -- acc=98.55573%
#
#   valid loss:		0.04559
#   valid accuracy:	0.99244+/-0.00000
#   valid auc-roc:	0.99972+/-0.00000
#   valid auc-pr:		0.99901+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=14.31s -- loss=0.06692 -- acc=98.58281%
#
#   valid loss:		0.04655
#   valid accuracy:	0.99192+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99894+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=14.32s -- loss=0.06602 -- acc=98.58646%
#
#   valid loss:		0.04508
#   valid accuracy:	0.99246+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99913+/-0.00000
