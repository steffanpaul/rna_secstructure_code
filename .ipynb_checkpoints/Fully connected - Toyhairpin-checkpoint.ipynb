# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import mutagenesis_functions as mf
import time as time

# %%
# load hairpin data
data_path = '../data_peter/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 196,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# %%
# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 196)
# layer3: dense_0_batch
# (?, 196)
# layer4: dense_0_active
# (?, 196)
# layer5: dense_0_dropout
# (?, 196)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

# fit model
data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=10, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.45s -- loss=0.11626 -- acc=95.39740
#
#   valid loss:		0.00348
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.00613 -- acc=99.95521
#
#   valid loss:		0.00255
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=4.81s -- loss=0.00520 -- acc=99.94896
#
#   valid loss:		0.00262
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=4.76s -- loss=0.00486 -- acc=99.95260
#
#   valid loss:		0.00295
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.76s -- loss=0.00427 -- acc=99.97396
#
#   valid loss:		0.00306
#   valid accuracy:	0.99996+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.96s -- loss=0.00496 -- acc=99.95833
#
#   valid loss:		0.00336
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.84s -- loss=0.00435 -- acc=99.97708
#
#   valid loss:		0.00338
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=5.29s -- loss=0.00491 -- acc=99.96719
#
#   valid loss:		0.00356
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.92s -- loss=0.00490 -- acc=99.96250
#
#   valid loss:		0.00381
#   valid accuracy:	0.99996+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.74s -- loss=0.00484 -- acc=99.97135
#
#   valid loss:		0.00381
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=5.03s -- loss=0.00481 -- acc=99.97500
#
#   valid loss:		0.00384
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=5.36s -- loss=0.00497 -- acc=99.97344
#
#   valid loss:		0.00396
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Patience ran out... Early stopping.

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_best.ckpt
#   test  loss:		0.00256
#   test  accuracy:	0.99998+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
#Get Predictions

# calculate activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
predictionslogits = nntrainer.get_activations(sess, test, layer='dense_1_bias')

# %% [markdown]
# ## Run a First Order Mutagenesis analysis

# %%
# sort activations
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

X = np.expand_dims(test['inputs'][plot_index[0]], axis=0)

X_mut = mf.mutate(X, X.shape[1], X.shape[3])
mutations = {'inputs': X_mut, 'targets': Y_test[:X_mut.shape[0]]}

# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

#Get output activations for the mutations
mut_predictionslogits = nntrainer.get_activations(sess, mutations, layer='dense_1_bias')
mut_predictionsoutput= nntrainer.get_activations(sess, mutations, layer='output')

#shape the predictions of the mutations into the shape of a heatmap
heat_mut = mut_predictionslogits.reshape(X.shape[1],4).T

#normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
norm_heat_mut = heat_mut - predictionslogits[plot_index[0]]
norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

plt.figure(figsize=(15,2))
visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                        norm_heat_mut, 
                                        alphabet='rna', 
                                        nt_width=400)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_best.ckpt
# /home/peter/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Look at the highest predicted sequences

# %%
num_plots = 5
for index in plot_index[:num_plots]:

    X = np.expand_dims(test['inputs'][index], axis=0)
    
    plt.figure(figsize=(15,1))
    visualize.plot_pos_saliency(np.squeeze(X).T, norm_factor=0, nt_width=400)

# %% [markdown]
# # Average the second order mutagenesis scores for 1000 different sequences
#
# Since each mutagenesis produces 41*41*16 = 26896 sequences, getting scores for 1000 is gonna take a long time...

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_summary = 1000

sum_mut2_predictoutputs = np.zeros((41*41*16, 1))
starttime = time.time()

for ii in range(num_summary):
    print (ii)
    epoch_starttime = time.time()
    
    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    #mutate the sequence
    X_mutsecorder = mf.double_mutate(X, X.shape[1], X.shape[3])

    #reshape the 6D tensor into a 4D tensor that the model can test
    X_mutsecorder_reshape = np.reshape(X_mutsecorder, (X.shape[1]*X.shape[1]*16, X.shape[1], 1, 4))
    
    mutations = {'inputs': X_mutsecorder_reshape, 'targets': Y_test[:X_mutsecorder_reshape.shape[0]]}
    
    #Get output activations for the mutations
    mut2_predictoutputs= nntrainer.get_activations(sess, mutations, layer='output')
    
    #Sum all the scores into a single matrix
    sum_mut2_predictoutputs += mut2_predictoutputs
    
    epoch_endtime = time.time()
    
    print ('Epoch duration =' + str(np.around((epoch_endtime -epoch_starttime), 2)) + 's')
    print ('Cumulative duration =' + str(np.around((epoch_endtime - starttime), 2)) + 's')
    print ()
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_best.ckpt
# 0
# Epoch duration =0.21s
# Cumulative duration =0.21s
#
# 1
# Epoch duration =0.2s
# Cumulative duration =0.41s
#
# 2
# Epoch duration =0.19s
# Cumulative duration =0.6s
#
# 3
# Epoch duration =0.19s
# Cumulative duration =0.79s
#
# 4
# Epoch duration =0.2s
# Cumulative duration =0.99s
#
# 5
# Epoch duration =0.19s
# Cumulative duration =1.18s
#
# 6
# Epoch duration =0.21s
# Cumulative duration =1.39s
#
# 7
# Epoch duration =0.27s
# Cumulative duration =1.66s
#
# 8
# Epoch duration =0.2s
# Cumulative duration =1.85s
#
# 9
# Epoch duration =0.19s
# Cumulative duration =2.05s
#
# 10
# Epoch duration =0.26s
# Cumulative duration =2.31s
#
# 11
# Epoch duration =0.22s
# Cumulative duration =2.53s
#
# 12
# Epoch duration =0.19s
# Cumulative duration =2.72s
#
# 13
# Epoch duration =0.19s
# Cumulative duration =2.92s
#
# 14
# Epoch duration =0.19s
# Cumulative duration =3.1s
#
# 15
# Epoch duration =0.19s
# Cumulative duration =3.3s
#
# 16
# Epoch duration =0.19s
# Cumulative duration =3.49s
#
# 17
# Epoch duration =0.2s
# Cumulative duration =3.68s
#
# 18
# Epoch duration =0.19s
# Cumulative duration =3.88s
#
# 19
# Epoch duration =0.21s
# Cumulative duration =4.09s
#
# 20
# Epoch duration =0.19s
# Cumulative duration =4.28s
#
# 21
# Epoch duration =0.19s
# Cumulative duration =4.47s
#
# 22
# Epoch duration =0.19s
# Cumulative duration =4.66s
#
# 23
# Epoch duration =0.19s
# Cumulative duration =4.85s
#
# 24
# Epoch duration =0.19s
# Cumulative duration =5.05s
#
# 25
# Epoch duration =0.19s
# Cumulative duration =5.24s
#
# 26
# Epoch duration =0.21s
# Cumulative duration =5.45s
#
# 27
# Epoch duration =0.21s
# Cumulative duration =5.66s
#
# 28
# Epoch duration =0.23s
# Cumulative duration =5.89s
#
# 29
# Epoch duration =0.23s
# Cumulative duration =6.12s
#
# 30
# Epoch duration =0.22s
# Cumulative duration =6.33s
#
# 31
# Epoch duration =0.21s
# Cumulative duration =6.54s
#
# 32
# Epoch duration =0.21s
# Cumulative duration =6.75s
#
# 33
# Epoch duration =0.21s
# Cumulative duration =6.97s
#
# 34
# Epoch duration =0.25s
# Cumulative duration =7.22s
#
# 35
# Epoch duration =0.19s
# Cumulative duration =7.41s
#
# 36
# Epoch duration =0.19s
# Cumulative duration =7.6s
#
# 37
# Epoch duration =0.19s
# Cumulative duration =7.8s
#
# 38
# Epoch duration =0.2s
# Cumulative duration =8.0s
#
# 39
# Epoch duration =0.2s
# Cumulative duration =8.2s
#
# 40
# Epoch duration =0.2s
# Cumulative duration =8.4s
#
# 41
# Epoch duration =0.2s
# Cumulative duration =8.6s
#
# 42
# Epoch duration =0.23s
# Cumulative duration =8.83s
#
# 43
# Epoch duration =0.21s
# Cumulative duration =9.03s
#
# 44
# Epoch duration =0.2s
# Cumulative duration =9.23s
#
# 45
# Epoch duration =0.23s
# Cumulative duration =9.47s
#
# 46
# Epoch duration =0.19s
# Cumulative duration =9.66s
#
# 47
# Epoch duration =0.22s
# Cumulative duration =9.89s
#
# 48
# Epoch duration =0.2s
# Cumulative duration =10.08s
#
# 49
# Epoch duration =0.22s
# Cumulative duration =10.31s
#
# 50
# Epoch duration =0.19s
# Cumulative duration =10.5s
#
# 51
# Epoch duration =0.19s
# Cumulative duration =10.7s
#
# 52
# Epoch duration =0.19s
# Cumulative duration =10.88s
#
# 53
# Epoch duration =0.19s
# Cumulative duration =11.07s
#
# 54
# Epoch duration =0.19s
# Cumulative duration =11.27s
#
# 55
# Epoch duration =0.19s
# Cumulative duration =11.46s
#
# 56
# Epoch duration =0.19s
# Cumulative duration =11.65s
#
# 57
# Epoch duration =0.19s
# Cumulative duration =11.84s
#
# 58
# Epoch duration =0.19s
# Cumulative duration =12.03s
#
# 59
# Epoch duration =0.19s
# Cumulative duration =12.22s
#
# 60
# Epoch duration =0.19s
# Cumulative duration =12.41s
#
# 61
# Epoch duration =0.19s
# Cumulative duration =12.6s
#
# 62
# Epoch duration =0.2s
# Cumulative duration =12.8s
#
# 63
# Epoch duration =0.19s
# Cumulative duration =12.99s
#
# 64
# Epoch duration =0.19s
# Cumulative duration =13.18s
#
# 65
# Epoch duration =0.19s
# Cumulative duration =13.37s
#
# 66
# Epoch duration =0.19s
# Cumulative duration =13.56s
#
# 67
# Epoch duration =0.19s
# Cumulative duration =13.75s
#
# 68
# Epoch duration =0.19s
# Cumulative duration =13.94s
#
# 69
# Epoch duration =0.19s
# Cumulative duration =14.14s
#
# 70
# Epoch duration =0.19s
# Cumulative duration =14.33s
#
# 71
# Epoch duration =0.19s
# Cumulative duration =14.52s
#
# 72
# Epoch duration =0.19s
# Cumulative duration =14.72s
#
# 73
# Epoch duration =0.19s
# Cumulative duration =14.91s
#
# 74
# Epoch duration =0.19s
# Cumulative duration =15.1s
#
# 75
# Epoch duration =0.19s
# Cumulative duration =15.29s
#
# 76
# Epoch duration =0.19s
# Cumulative duration =15.49s
#
# 77
# Epoch duration =0.19s
# Cumulative duration =15.68s
#
# 78
# Epoch duration =0.19s
# Cumulative duration =15.87s
#
# 79
# Epoch duration =0.2s
# Cumulative duration =16.07s
#
# 80
# Epoch duration =0.21s
# Cumulative duration =16.28s
#
# 81
# Epoch duration =0.21s
# Cumulative duration =16.49s
#
# 82
# Epoch duration =0.19s
# Cumulative duration =16.68s
#
# 83
# Epoch duration =0.2s
# Cumulative duration =16.88s
#
# 84
# Epoch duration =0.19s
# Cumulative duration =17.07s
#
# 85
# Epoch duration =0.2s
# Cumulative duration =17.27s
#
# 86
# Epoch duration =0.2s
# Cumulative duration =17.47s
#
# 87
# Epoch duration =0.19s
# Cumulative duration =17.66s
#
# 88
# Epoch duration =0.19s
# Cumulative duration =17.85s
#
# 89
# Epoch duration =0.19s
# Cumulative duration =18.04s
#
# 90
# Epoch duration =0.19s
# Cumulative duration =18.23s
#
# 91
# Epoch duration =0.2s
# Cumulative duration =18.42s
#
# 92
# Epoch duration =0.2s
# Cumulative duration =18.62s
#
# 93
# Epoch duration =0.2s
# Cumulative duration =18.82s
#
# 94
# Epoch duration =0.19s
# Cumulative duration =19.01s
#
# 95
# Epoch duration =0.19s
# Cumulative duration =19.2s
#
# 96
# Epoch duration =0.19s
# Cumulative duration =19.39s
#
# 97
# Epoch duration =0.19s
# Cumulative duration =19.58s
#
# 98
# Epoch duration =0.19s
# Cumulative duration =19.78s
#
# 99
# Epoch duration =0.19s
# Cumulative duration =19.96s
#
# 100
# Epoch duration =0.19s
# Cumulative duration =20.15s
#
# 101
# Epoch duration =0.19s
# Cumulative duration =20.34s
#
# 102
# Epoch duration =0.19s
# Cumulative duration =20.53s
#
# 103
# Epoch duration =0.19s
# Cumulative duration =20.72s
#
# 104
# Epoch duration =0.19s
# Cumulative duration =20.92s
#
# 105
# Epoch duration =0.19s
# Cumulative duration =21.11s
#
# 106
# Epoch duration =0.19s
# Cumulative duration =21.3s
#
# 107
# Epoch duration =0.19s
# Cumulative duration =21.48s
#
# 108
# Epoch duration =0.19s
# Cumulative duration =21.67s
#
# 109
# Epoch duration =0.2s
# Cumulative duration =21.88s
#
# 110
# Epoch duration =0.19s
# Cumulative duration =22.07s
#
# 111
# Epoch duration =0.2s
# Cumulative duration =22.27s
#
# 112
# Epoch duration =0.19s
# Cumulative duration =22.46s
#
# 113
# Epoch duration =0.19s
# Cumulative duration =22.65s
#
# 114
# Epoch duration =0.19s
# Cumulative duration =22.84s
#
# 115
# Epoch duration =0.19s
# Cumulative duration =23.03s
#
# 116
# Epoch duration =0.19s
# Cumulative duration =23.22s
#
# 117
# Epoch duration =0.19s
# Cumulative duration =23.42s
#
# 118
# Epoch duration =0.19s
# Cumulative duration =23.61s
#
# 119
# Epoch duration =0.19s
# Cumulative duration =23.8s
#
# 120
# Epoch duration =0.19s
# Cumulative duration =23.99s
#
# 121
# Epoch duration =0.2s
# Cumulative duration =24.19s
#
# 122
# Epoch duration =0.2s
# Cumulative duration =24.39s
#
# 123
# Epoch duration =0.2s
# Cumulative duration =24.59s
#
# 124
# Epoch duration =0.19s
# Cumulative duration =24.78s
#
# 125
# Epoch duration =0.19s
# Cumulative duration =24.98s
#
# 126
# Epoch duration =0.19s
# Cumulative duration =25.16s
#
# 127
# Epoch duration =0.2s
# Cumulative duration =25.37s
#
# 128
# Epoch duration =0.2s
# Cumulative duration =25.56s
#
# 129
# Epoch duration =0.2s
# Cumulative duration =25.76s
#
# 130
# Epoch duration =0.19s
# Cumulative duration =25.95s
#
# 131
# Epoch duration =0.21s
# Cumulative duration =26.16s
#
# 132
# Epoch duration =0.2s
# Cumulative duration =26.35s
#
# 133
# Epoch duration =0.19s
# Cumulative duration =26.54s
#
# 134
# Epoch duration =0.19s
# Cumulative duration =26.73s
#
# 135
# Epoch duration =0.2s
# Cumulative duration =26.92s
#
# 136
# Epoch duration =0.19s
# Cumulative duration =27.11s
#
# 137
# Epoch duration =0.19s
# Cumulative duration =27.3s
#
# 138
# Epoch duration =0.19s
# Cumulative duration =27.49s
#
# 139
# Epoch duration =0.19s
# Cumulative duration =27.68s
#
# 140
# Epoch duration =0.19s
# Cumulative duration =27.87s
#
# 141
# Epoch duration =0.2s
# Cumulative duration =28.07s
#
# 142
# Epoch duration =0.19s
# Cumulative duration =28.26s
#
# 143
# Epoch duration =0.2s
# Cumulative duration =28.45s
#
# 144
# Epoch duration =0.19s
# Cumulative duration =28.64s
#
# 145
# Epoch duration =0.2s
# Cumulative duration =28.84s
#
# 146
# Epoch duration =0.19s
# Cumulative duration =29.03s
#
# 147
# Epoch duration =0.19s
# Cumulative duration =29.22s
#
# 148
# Epoch duration =0.19s
# Cumulative duration =29.41s
#
# 149
# Epoch duration =0.2s
# Cumulative duration =29.61s
#
# 150
# Epoch duration =0.19s
# Cumulative duration =29.8s
#
# 151
# Epoch duration =0.19s
# Cumulative duration =29.99s
#
# 152
# Epoch duration =0.2s
# Cumulative duration =30.19s
#
# 153
# Epoch duration =0.2s
# Cumulative duration =30.38s
#
# 154
# Epoch duration =0.19s
# Cumulative duration =30.57s
#
# 155
# Epoch duration =0.19s
# Cumulative duration =30.76s
#
# 156
# Epoch duration =0.19s
# Cumulative duration =30.96s
#
# 157
# Epoch duration =0.19s
# Cumulative duration =31.14s
#
# 158
# Epoch duration =0.2s
# Cumulative duration =31.34s
#
# 159
# Epoch duration =0.2s
# Cumulative duration =31.54s
#
# 160
# Epoch duration =0.19s
# Cumulative duration =31.73s
#
# 161
# Epoch duration =0.19s
# Cumulative duration =31.92s
#
# 162
# Epoch duration =0.2s
# Cumulative duration =32.12s
#
# 163
# Epoch duration =0.2s
# Cumulative duration =32.32s
#
# 164
# Epoch duration =0.2s
# Cumulative duration =32.51s
#
# 165
# Epoch duration =0.19s
# Cumulative duration =32.7s
#
# 166
# Epoch duration =0.2s
# Cumulative duration =32.9s
#
# 167
# Epoch duration =0.19s
# Cumulative duration =33.09s
#
# 168
# Epoch duration =0.19s
# Cumulative duration =33.28s
#
# 169
# Epoch duration =0.19s
# Cumulative duration =33.46s
#
# 170
# Epoch duration =0.19s
# Cumulative duration =33.65s
#
# 171
# Epoch duration =0.19s
# Cumulative duration =33.84s
#
# 172
# Epoch duration =0.19s
# Cumulative duration =34.04s
#
# 173
# Epoch duration =0.19s
# Cumulative duration =34.22s
#
# 174
# Epoch duration =0.19s
# Cumulative duration =34.41s
#
# 175
# Epoch duration =0.19s
# Cumulative duration =34.6s
#
# 176
# Epoch duration =0.19s
# Cumulative duration =34.8s
#
# 177
# Epoch duration =0.19s
# Cumulative duration =34.99s
#
# 178
# Epoch duration =0.19s
# Cumulative duration =35.18s
#
# 179
# Epoch duration =0.19s
# Cumulative duration =35.37s
#
# 180
# Epoch duration =0.19s
# Cumulative duration =35.56s
#
# 181
# Epoch duration =0.19s
# Cumulative duration =35.75s
#
# 182
# Epoch duration =0.19s
# Cumulative duration =35.94s
#
# 183
# Epoch duration =0.19s
# Cumulative duration =36.13s
#
# 184
# Epoch duration =0.19s
# Cumulative duration =36.32s
#
# 185
# Epoch duration =0.19s
# Cumulative duration =36.51s
#
# 186
# Epoch duration =0.19s
# Cumulative duration =36.7s
#
# 187
# Epoch duration =0.19s
# Cumulative duration =36.89s
#
# 188
# Epoch duration =0.2s
# Cumulative duration =37.09s
#
# 189
# Epoch duration =0.21s
# Cumulative duration =37.29s
#
# 190
# Epoch duration =0.19s
# Cumulative duration =37.49s
#
# 191
# Epoch duration =0.19s
# Cumulative duration =37.68s
#
# 192
# Epoch duration =0.19s
# Cumulative duration =37.87s
#
# 193
# Epoch duration =0.2s
# Cumulative duration =38.07s
#
# 194
# Epoch duration =0.19s
# Cumulative duration =38.26s
#
# 195
# Epoch duration =0.2s
# Cumulative duration =38.46s
#
# 196
# Epoch duration =0.19s
# Cumulative duration =38.66s
#
# 197
# Epoch duration =0.19s
# Cumulative duration =38.85s
#
# 198
# Epoch duration =0.19s
# Cumulative duration =39.04s
#
# 199
# Epoch duration =0.2s
# Cumulative duration =39.24s
#
# 200
# Epoch duration =0.19s
# Cumulative duration =39.43s
#
# 201
# Epoch duration =0.19s
# Cumulative duration =39.62s
#
# 202
# Epoch duration =0.21s
# Cumulative duration =39.83s
#
# 203
# Epoch duration =0.2s
# Cumulative duration =40.04s
#
# 204
# Epoch duration =0.19s
# Cumulative duration =40.23s
#
# 205
# Epoch duration =0.2s
# Cumulative duration =40.42s
#
# 206
# Epoch duration =0.19s
# Cumulative duration =40.61s
#
# 207
# Epoch duration =0.19s
# Cumulative duration =40.8s
#
# 208
# Epoch duration =0.19s
# Cumulative duration =40.99s
#
# 209
# Epoch duration =0.2s
# Cumulative duration =41.19s
#
# 210
# Epoch duration =0.19s
# Cumulative duration =41.38s
#
# 211
# Epoch duration =0.2s
# Cumulative duration =41.58s
#
# 212
# Epoch duration =0.19s
# Cumulative duration =41.76s
#
# 213
# Epoch duration =0.2s
# Cumulative duration =41.96s
#
# 214
# Epoch duration =0.19s
# Cumulative duration =42.16s
#
# 215
# Epoch duration =0.19s
# Cumulative duration =42.35s
#
# 216
# Epoch duration =0.19s
# Cumulative duration =42.54s
#
# 217
# Epoch duration =0.19s
# Cumulative duration =42.73s
#
# 218
# Epoch duration =0.19s
# Cumulative duration =42.93s
#
# 219
# Epoch duration =0.2s
# Cumulative duration =43.12s
#
# 220
# Epoch duration =0.19s
# Cumulative duration =43.31s
#
# 221
# Epoch duration =0.19s
# Cumulative duration =43.51s
#
# 222
# Epoch duration =0.19s
# Cumulative duration =43.7s
#
# 223
# Epoch duration =0.2s
# Cumulative duration =43.9s
#
# 224
# Epoch duration =0.19s
# Cumulative duration =44.09s
#
# 225
# Epoch duration =0.19s
# Cumulative duration =44.28s
#
# 226
# Epoch duration =0.19s
# Cumulative duration =44.47s
#
# 227
# Epoch duration =0.19s
# Cumulative duration =44.67s
#
# 228
# Epoch duration =0.19s
# Cumulative duration =44.85s
#
# 229
# Epoch duration =0.19s
# Cumulative duration =45.04s
#
# 230
# Epoch duration =0.19s
# Cumulative duration =45.23s
#
# 231
# Epoch duration =0.2s
# Cumulative duration =45.43s
#
# 232
# Epoch duration =0.2s
# Cumulative duration =45.63s
#
# 233
# Epoch duration =0.19s
# Cumulative duration =45.82s
#
# 234
# Epoch duration =0.2s
# Cumulative duration =46.03s
#
# 235
# Epoch duration =0.19s
# Cumulative duration =46.22s
#
# 236
# Epoch duration =0.21s
# Cumulative duration =46.43s
#
# 237
# Epoch duration =0.19s
# Cumulative duration =46.62s
#
# 238
# Epoch duration =0.19s
# Cumulative duration =46.81s
#
# 239
# Epoch duration =0.22s
# Cumulative duration =47.03s
#
# 240
# Epoch duration =0.19s
# Cumulative duration =47.22s
#
# 241
# Epoch duration =0.2s
# Cumulative duration =47.42s
#
# 242
# Epoch duration =0.2s
# Cumulative duration =47.62s
#
# 243
# Epoch duration =0.2s
# Cumulative duration =47.83s
#
# 244
# Epoch duration =0.2s
# Cumulative duration =48.02s
#
# 245
# Epoch duration =0.2s
# Cumulative duration =48.22s
#
# 246
# Epoch duration =0.19s
# Cumulative duration =48.41s
#
# 247
# Epoch duration =0.19s
# Cumulative duration =48.6s
#
# 248
# Epoch duration =0.19s
# Cumulative duration =48.79s
#
# 249
# Epoch duration =0.2s
# Cumulative duration =48.99s
#
# 250
# Epoch duration =0.19s
# Cumulative duration =49.18s
#
# 251
# Epoch duration =0.19s
# Cumulative duration =49.37s
#
# 252
# Epoch duration =0.2s
# Cumulative duration =49.57s
#
# 253
# Epoch duration =0.19s
# Cumulative duration =49.76s
#
# 254
# Epoch duration =0.19s
# Cumulative duration =49.95s
#
# 255
# Epoch duration =0.19s
# Cumulative duration =50.14s
#
# 256
# Epoch duration =0.19s
# Cumulative duration =50.33s
#
# 257
# Epoch duration =0.2s
# Cumulative duration =50.54s
#
# 258
# Epoch duration =0.19s
# Cumulative duration =50.72s
#
# 259
# Epoch duration =0.19s
# Cumulative duration =50.91s
#
# 260
# Epoch duration =0.19s
# Cumulative duration =51.1s
#
# 261
# Epoch duration =0.19s
# Cumulative duration =51.3s
#
# 262
# Epoch duration =0.19s
# Cumulative duration =51.49s
#
# 263
# Epoch duration =0.19s
# Cumulative duration =51.67s
#
# 264
# Epoch duration =0.19s
# Cumulative duration =51.86s
#
# 265
# Epoch duration =0.19s
# Cumulative duration =52.05s
#
# 266
# Epoch duration =0.19s
# Cumulative duration =52.24s
#
# 267
# Epoch duration =0.19s
# Cumulative duration =52.43s
#
# 268
# Epoch duration =0.19s
# Cumulative duration =52.62s
#
# 269
# Epoch duration =0.2s
# Cumulative duration =52.82s
#
# 270
# Epoch duration =0.19s
# Cumulative duration =53.01s
#
# 271
# Epoch duration =0.19s
# Cumulative duration =53.19s
#
# 272
# Epoch duration =0.19s
# Cumulative duration =53.38s
#
# 273
# Epoch duration =0.19s
# Cumulative duration =53.57s
#
# 274
# Epoch duration =0.19s
# Cumulative duration =53.76s
#
# 275
# Epoch duration =0.2s
# Cumulative duration =53.97s
#
# 276
# Epoch duration =0.19s
# Cumulative duration =54.16s
#
# 277
# Epoch duration =0.19s
# Cumulative duration =54.35s
#
# 278
# Epoch duration =0.19s
# Cumulative duration =54.54s
#
# 279
# Epoch duration =0.2s
# Cumulative duration =54.74s
#
# 280
# Epoch duration =0.19s
# Cumulative duration =54.94s
#
# 281
# Epoch duration =0.2s
# Cumulative duration =55.14s
#
# 282
# Epoch duration =0.19s
# Cumulative duration =55.33s
#
# 283
# Epoch duration =0.19s
# Cumulative duration =55.52s
#
# 284
# Epoch duration =0.19s
# Cumulative duration =55.71s
#
# 285
# Epoch duration =0.2s
# Cumulative duration =55.91s
#
# 286
# Epoch duration =0.19s
# Cumulative duration =56.1s
#
# 287
# Epoch duration =0.19s
# Cumulative duration =56.29s
#
# 288
# Epoch duration =0.19s
# Cumulative duration =56.48s
#
# 289
# Epoch duration =0.2s
# Cumulative duration =56.68s
#
# 290
# Epoch duration =0.19s
# Cumulative duration =56.87s
#
# 291
# Epoch duration =0.2s
# Cumulative duration =57.07s
#
# 292
# Epoch duration =0.19s
# Cumulative duration =57.25s
#
# 293
# Epoch duration =0.21s
# Cumulative duration =57.46s
#
# 294
# Epoch duration =0.19s
# Cumulative duration =57.65s
#
# 295
# Epoch duration =0.21s
# Cumulative duration =57.86s
#
# 296
# Epoch duration =0.19s
# Cumulative duration =58.05s
#
# 297
# Epoch duration =0.19s
# Cumulative duration =58.24s
#
# 298
# Epoch duration =0.2s
# Cumulative duration =58.44s
#
# 299
# Epoch duration =0.2s
# Cumulative duration =58.63s
#
# 300
# Epoch duration =0.2s
# Cumulative duration =58.83s
#
# 301
# Epoch duration =0.2s
# Cumulative duration =59.03s
#
# 302
# Epoch duration =0.19s
# Cumulative duration =59.22s
#
# 303
# Epoch duration =0.19s
# Cumulative duration =59.42s
#
# 304
# Epoch duration =0.19s
# Cumulative duration =59.61s
#
# 305
# Epoch duration =0.2s
# Cumulative duration =59.81s
#
# 306
# Epoch duration =0.19s
# Cumulative duration =60.0s
#
# 307
# Epoch duration =0.2s
# Cumulative duration =60.2s
#
# 308
# Epoch duration =0.19s
# Cumulative duration =60.39s
#
# 309
# Epoch duration =0.19s
# Cumulative duration =60.59s
#
# 310
# Epoch duration =0.19s
# Cumulative duration =60.77s
#
# 311
# Epoch duration =0.2s
# Cumulative duration =60.97s
#
# 312
# Epoch duration =0.21s
# Cumulative duration =61.18s
#
# 313
# Epoch duration =0.2s
# Cumulative duration =61.37s
#
# 314
# Epoch duration =0.2s
# Cumulative duration =61.57s
#
# 315
# Epoch duration =0.19s
# Cumulative duration =61.76s
#
# 316
# Epoch duration =0.2s
# Cumulative duration =61.96s
#
# 317
# Epoch duration =0.21s
# Cumulative duration =62.17s
#
# 318
# Epoch duration =0.2s
# Cumulative duration =62.37s
#
# 319
# Epoch duration =0.2s
# Cumulative duration =62.57s
#
# 320
# Epoch duration =0.19s
# Cumulative duration =62.76s
#
# 321
# Epoch duration =0.2s
# Cumulative duration =62.97s
#
# 322
# Epoch duration =0.22s
# Cumulative duration =63.18s
#
# 323
# Epoch duration =0.22s
# Cumulative duration =63.4s
#
# 324
# Epoch duration =0.19s
# Cumulative duration =63.59s
#
# 325
# Epoch duration =0.2s
# Cumulative duration =63.79s
#
# 326
# Epoch duration =0.19s
# Cumulative duration =63.98s
#
# 327
# Epoch duration =0.19s
# Cumulative duration =64.17s
#
# 328
# Epoch duration =0.19s
# Cumulative duration =64.36s
#
# 329
# Epoch duration =0.19s
# Cumulative duration =64.56s
#
# 330
# Epoch duration =0.2s
# Cumulative duration =64.75s
#
# 331
# Epoch duration =0.2s
# Cumulative duration =64.95s
#
# 332
# Epoch duration =0.19s
# Cumulative duration =65.14s
#
# 333
# Epoch duration =0.19s
# Cumulative duration =65.34s
#
# 334
# Epoch duration =0.19s
# Cumulative duration =65.53s
#
# 335
# Epoch duration =0.19s
# Cumulative duration =65.71s
#
# 336
# Epoch duration =0.19s
# Cumulative duration =65.91s
#
# 337
# Epoch duration =0.19s
# Cumulative duration =66.1s
#
# 338
# Epoch duration =0.2s
# Cumulative duration =66.3s
#
# 339
# Epoch duration =0.2s
# Cumulative duration =66.49s
#
# 340
# Epoch duration =0.19s
# Cumulative duration =66.68s
#
# 341
# Epoch duration =0.19s
# Cumulative duration =66.88s
#
# 342
# Epoch duration =0.19s
# Cumulative duration =67.06s
#
# 343
# Epoch duration =0.19s
# Cumulative duration =67.25s
#
# 344
# Epoch duration =0.2s
# Cumulative duration =67.45s
#
# 345
# Epoch duration =0.19s
# Cumulative duration =67.64s
#
# 346
# Epoch duration =0.19s
# Cumulative duration =67.82s
#
# 347
# Epoch duration =0.19s
# Cumulative duration =68.01s
#
# 348
# Epoch duration =0.19s
# Cumulative duration =68.2s
#
# 349
# Epoch duration =0.19s
# Cumulative duration =68.39s
#
# 350
# Epoch duration =0.19s
# Cumulative duration =68.57s
#
# 351
# Epoch duration =0.19s
# Cumulative duration =68.76s
#
# 352
# Epoch duration =0.19s
# Cumulative duration =68.95s
#
# 353
# Epoch duration =0.19s
# Cumulative duration =69.15s
#
# 354
# Epoch duration =0.19s
# Cumulative duration =69.33s
#
# 355
# Epoch duration =0.2s
# Cumulative duration =69.53s
#
# 356
# Epoch duration =0.19s
# Cumulative duration =69.72s
#
# 357
# Epoch duration =0.19s
# Cumulative duration =69.91s
#
# 358
# Epoch duration =0.19s
# Cumulative duration =70.1s
#
# 359
# Epoch duration =0.19s
# Cumulative duration =70.29s
#
# 360
# Epoch duration =0.19s
# Cumulative duration =70.48s
#
# 361
# Epoch duration =0.19s
# Cumulative duration =70.67s
#
# 362
# Epoch duration =0.2s
# Cumulative duration =70.87s
#
# 363
# Epoch duration =0.19s
# Cumulative duration =71.06s
#
# 364
# Epoch duration =0.19s
# Cumulative duration =71.24s
#
# 365
# Epoch duration =0.2s
# Cumulative duration =71.44s
#
# 366
# Epoch duration =0.19s
# Cumulative duration =71.63s
#
# 367
# Epoch duration =0.19s
# Cumulative duration =71.82s
#
# 368
# Epoch duration =0.19s
# Cumulative duration =72.01s
#
# 369
# Epoch duration =0.21s
# Cumulative duration =72.22s
#
# 370
# Epoch duration =0.2s
# Cumulative duration =72.42s
#
# 371
# Epoch duration =0.2s
# Cumulative duration =72.62s
#
# 372
# Epoch duration =0.24s
# Cumulative duration =72.86s
#
# 373
# Epoch duration =0.2s
# Cumulative duration =73.06s
#
# 374
# Epoch duration =0.2s
# Cumulative duration =73.26s
#
# 375
# Epoch duration =0.19s
# Cumulative duration =73.45s
#
# 376
# Epoch duration =0.2s
# Cumulative duration =73.65s
#
# 377
# Epoch duration =0.19s
# Cumulative duration =73.84s
#
# 378
# Epoch duration =0.19s
# Cumulative duration =74.03s
#
# 379
# Epoch duration =0.19s
# Cumulative duration =74.22s
#
# 380
# Epoch duration =0.2s
# Cumulative duration =74.42s
#
# 381
# Epoch duration =0.19s
# Cumulative duration =74.61s
#
# 382
# Epoch duration =0.21s
# Cumulative duration =74.82s
#
# 383
# Epoch duration =0.19s
# Cumulative duration =75.01s
#
# 384
# Epoch duration =0.2s
# Cumulative duration =75.21s
#
# 385
# Epoch duration =0.19s
# Cumulative duration =75.4s
#
# 386
# Epoch duration =0.2s
# Cumulative duration =75.61s
#
# 387
# Epoch duration =0.18s
# Cumulative duration =75.79s
#
# 388
# Epoch duration =0.2s
# Cumulative duration =75.99s
#
# 389
# Epoch duration =0.19s
# Cumulative duration =76.18s
#
# 390
# Epoch duration =0.21s
# Cumulative duration =76.39s
#
# 391
# Epoch duration =0.19s
# Cumulative duration =76.58s
#
# 392
# Epoch duration =0.19s
# Cumulative duration =76.77s
#
# 393
# Epoch duration =0.2s
# Cumulative duration =76.97s
#
# 394
# Epoch duration =0.19s
# Cumulative duration =77.16s
#
# 395
# Epoch duration =0.2s
# Cumulative duration =77.35s
#
# 396
# Epoch duration =0.2s
# Cumulative duration =77.56s
#
# 397
# Epoch duration =0.19s
# Cumulative duration =77.74s
#
# 398
# Epoch duration =0.19s
# Cumulative duration =77.94s
#
# 399
# Epoch duration =0.19s
# Cumulative duration =78.12s
#
# 400
# Epoch duration =0.19s
# Cumulative duration =78.32s
#
# 401
# Epoch duration =0.19s
# Cumulative duration =78.5s
#
# 402
# Epoch duration =0.2s
# Cumulative duration =78.7s
#
# 403
# Epoch duration =0.19s
# Cumulative duration =78.89s
#
# 404
# Epoch duration =0.19s
# Cumulative duration =79.08s
#
# 405
# Epoch duration =0.18s
# Cumulative duration =79.27s
#
# 406
# Epoch duration =0.2s
# Cumulative duration =79.46s
#
# 407
# Epoch duration =0.19s
# Cumulative duration =79.65s
#
# 408
# Epoch duration =0.2s
# Cumulative duration =79.85s
#
# 409
# Epoch duration =0.19s
# Cumulative duration =80.04s
#
# 410
# Epoch duration =0.19s
# Cumulative duration =80.23s
#
# 411
# Epoch duration =0.19s
# Cumulative duration =80.42s
#
# 412
# Epoch duration =0.19s
# Cumulative duration =80.61s
#
# 413
# Epoch duration =0.19s
# Cumulative duration =80.8s
#
# 414
# Epoch duration =0.19s
# Cumulative duration =80.99s
#
# 415
# Epoch duration =0.19s
# Cumulative duration =81.17s
#
# 416
# Epoch duration =0.19s
# Cumulative duration =81.37s
#
# 417
# Epoch duration =0.19s
# Cumulative duration =81.56s
#
# 418
# Epoch duration =0.19s
# Cumulative duration =81.75s
#
# 419
# Epoch duration =0.19s
# Cumulative duration =81.94s
#
# 420
# Epoch duration =0.19s
# Cumulative duration =82.13s
#
# 421
# Epoch duration =0.19s
# Cumulative duration =82.32s
#
# 422
# Epoch duration =0.19s
# Cumulative duration =82.52s
#
# 423
# Epoch duration =0.19s
# Cumulative duration =82.7s
#
# 424
# Epoch duration =0.2s
# Cumulative duration =82.9s
#
# 425
# Epoch duration =0.19s
# Cumulative duration =83.09s
#
# 426
# Epoch duration =0.19s
# Cumulative duration =83.28s
#
# 427
# Epoch duration =0.2s
# Cumulative duration =83.48s
#
# 428
# Epoch duration =0.21s
# Cumulative duration =83.69s
#
# 429
# Epoch duration =0.19s
# Cumulative duration =83.88s
#
# 430
# Epoch duration =0.19s
# Cumulative duration =84.07s
#
# 431
# Epoch duration =0.2s
# Cumulative duration =84.27s
#
# 432
# Epoch duration =0.2s
# Cumulative duration =84.47s
#
# 433
# Epoch duration =0.21s
# Cumulative duration =84.68s
#
# 434
# Epoch duration =0.2s
# Cumulative duration =84.88s
#
# 435
# Epoch duration =0.2s
# Cumulative duration =85.08s
#
# 436
# Epoch duration =0.19s
# Cumulative duration =85.27s
#
# 437
# Epoch duration =0.19s
# Cumulative duration =85.46s
#
# 438
# Epoch duration =0.19s
# Cumulative duration =85.66s
#
# 439
# Epoch duration =0.19s
# Cumulative duration =85.85s
#
# 440
# Epoch duration =0.19s
# Cumulative duration =86.04s
#
# 441
# Epoch duration =0.2s
# Cumulative duration =86.24s
#
# 442
# Epoch duration =0.19s
# Cumulative duration =86.44s
#
# 443
# Epoch duration =0.2s
# Cumulative duration =86.64s
#
# 444
# Epoch duration =0.19s
# Cumulative duration =86.83s
#
# 445
# Epoch duration =0.19s
# Cumulative duration =87.02s
#
# 446
# Epoch duration =0.19s
# Cumulative duration =87.21s
#
# 447
# Epoch duration =0.19s
# Cumulative duration =87.4s
#
# 448
# Epoch duration =0.19s
# Cumulative duration =87.59s
#
# 449
# Epoch duration =0.19s
# Cumulative duration =87.77s
#
# 450
# Epoch duration =0.19s
# Cumulative duration =87.97s
#
# 451
# Epoch duration =0.19s
# Cumulative duration =88.16s
#
# 452
# Epoch duration =0.19s
# Cumulative duration =88.35s
#
# 453
# Epoch duration =0.19s
# Cumulative duration =88.55s
#
# 454
# Epoch duration =0.19s
# Cumulative duration =88.74s
#
# 455
# Epoch duration =0.2s
# Cumulative duration =88.94s
#
# 456
# Epoch duration =0.19s
# Cumulative duration =89.12s
#
# 457
# Epoch duration =0.19s
# Cumulative duration =89.31s
#
# 458
# Epoch duration =0.19s
# Cumulative duration =89.5s
#
# 459
# Epoch duration =0.21s
# Cumulative duration =89.71s
#
# 460
# Epoch duration =0.19s
# Cumulative duration =89.9s
#
# 461
# Epoch duration =0.19s
# Cumulative duration =90.09s
#
# 462
# Epoch duration =0.2s
# Cumulative duration =90.29s
#
# 463
# Epoch duration =0.19s
# Cumulative duration =90.48s
#
# 464
# Epoch duration =0.19s
# Cumulative duration =90.68s
#
# 465
# Epoch duration =0.19s
# Cumulative duration =90.86s
#
# 466
# Epoch duration =0.19s
# Cumulative duration =91.06s
#
# 467
# Epoch duration =0.18s
# Cumulative duration =91.24s
#
# 468
# Epoch duration =0.19s
# Cumulative duration =91.44s
#
# 469
# Epoch duration =0.19s
# Cumulative duration =91.63s
#
# 470
# Epoch duration =0.19s
# Cumulative duration =91.82s
#
# 471
# Epoch duration =0.19s
# Cumulative duration =92.01s
#
# 472
# Epoch duration =0.19s
# Cumulative duration =92.2s
#
# 473
# Epoch duration =0.19s
# Cumulative duration =92.39s
#
# 474
# Epoch duration =0.19s
# Cumulative duration =92.58s
#
# 475
# Epoch duration =0.19s
# Cumulative duration =92.77s
#
# 476
# Epoch duration =0.2s
# Cumulative duration =92.97s
#
# 477
# Epoch duration =0.2s
# Cumulative duration =93.17s
#
# 478
# Epoch duration =0.19s
# Cumulative duration =93.36s
#
# 479
# Epoch duration =0.21s
# Cumulative duration =93.57s
#
# 480
# Epoch duration =0.19s
# Cumulative duration =93.76s
#
# 481
# Epoch duration =0.2s
# Cumulative duration =93.96s
#
# 482
# Epoch duration =0.2s
# Cumulative duration =94.16s
#
# 483
# Epoch duration =0.19s
# Cumulative duration =94.35s
#
# 484
# Epoch duration =0.19s
# Cumulative duration =94.54s
#
# 485
# Epoch duration =0.19s
# Cumulative duration =94.73s
#
# 486
# Epoch duration =0.19s
# Cumulative duration =94.92s
#
# 487
# Epoch duration =0.19s
# Cumulative duration =95.11s
#
# 488
# Epoch duration =0.2s
# Cumulative duration =95.31s
#
# 489
# Epoch duration =0.19s
# Cumulative duration =95.5s
#
# 490
# Epoch duration =0.19s
# Cumulative duration =95.69s
#
# 491
# Epoch duration =0.19s
# Cumulative duration =95.88s
#
# 492
# Epoch duration =0.19s
# Cumulative duration =96.07s
#
# 493
# Epoch duration =0.2s
# Cumulative duration =96.27s
#
# 494
# Epoch duration =0.19s
# Cumulative duration =96.46s
#
# 495
# Epoch duration =0.19s
# Cumulative duration =96.65s
#
# 496
# Epoch duration =0.19s
# Cumulative duration =96.84s
#
# 497
# Epoch duration =0.19s
# Cumulative duration =97.03s
#
# 498
# Epoch duration =0.19s
# Cumulative duration =97.22s
#
# 499
# Epoch duration =0.19s
# Cumulative duration =97.41s
#
# 500
# Epoch duration =0.19s
# Cumulative duration =97.6s
#
# 501
# Epoch duration =0.21s
# Cumulative duration =97.81s
#
# 502
# Epoch duration =0.19s
# Cumulative duration =98.0s
#
# 503
# Epoch duration =0.19s
# Cumulative duration =98.19s
#
# 504
# Epoch duration =0.19s
# Cumulative duration =98.38s
#
# 505
# Epoch duration =0.19s
# Cumulative duration =98.57s
#
# 506
# Epoch duration =0.19s
# Cumulative duration =98.76s
#
# 507
# Epoch duration =0.21s
# Cumulative duration =98.97s
#
# 508
# Epoch duration =0.2s
# Cumulative duration =99.17s
#
# 509
# Epoch duration =0.19s
# Cumulative duration =99.36s
#
# 510
# Epoch duration =0.19s
# Cumulative duration =99.55s
#
# 511
# Epoch duration =0.2s
# Cumulative duration =99.74s
#
# 512
# Epoch duration =0.19s
# Cumulative duration =99.94s
#
# 513
# Epoch duration =0.19s
# Cumulative duration =100.13s
#
# 514
# Epoch duration =0.19s
# Cumulative duration =100.33s
#
# 515
# Epoch duration =0.2s
# Cumulative duration =100.52s
#
# 516
# Epoch duration =0.19s
# Cumulative duration =100.71s
#
# 517
# Epoch duration =0.19s
# Cumulative duration =100.9s
#
# 518
# Epoch duration =0.19s
# Cumulative duration =101.09s
#
# 519
# Epoch duration =0.2s
# Cumulative duration =101.29s
#
# 520
# Epoch duration =0.19s
# Cumulative duration =101.48s
#
# 521
# Epoch duration =0.19s
# Cumulative duration =101.67s
#
# 522
# Epoch duration =0.19s
# Cumulative duration =101.87s
#
# 523
# Epoch duration =0.2s
# Cumulative duration =102.07s
#
# 524
# Epoch duration =0.19s
# Cumulative duration =102.26s
#
# 525
# Epoch duration =0.2s
# Cumulative duration =102.46s
#
# 526
# Epoch duration =0.19s
# Cumulative duration =102.65s
#
# 527
# Epoch duration =0.19s
# Cumulative duration =102.84s
#
# 528
# Epoch duration =0.2s
# Cumulative duration =103.04s
#
# 529
# Epoch duration =0.19s
# Cumulative duration =103.23s
#
# 530
# Epoch duration =0.19s
# Cumulative duration =103.42s
#
# 531
# Epoch duration =0.19s
# Cumulative duration =103.61s
#
# 532
# Epoch duration =0.19s
# Cumulative duration =103.8s
#
# 533
# Epoch duration =0.19s
# Cumulative duration =103.99s
#
# 534
# Epoch duration =0.19s
# Cumulative duration =104.18s
#
# 535
# Epoch duration =0.19s
# Cumulative duration =104.38s
#
# 536
# Epoch duration =0.2s
# Cumulative duration =104.58s
#
# 537
# Epoch duration =0.2s
# Cumulative duration =104.78s
#
# 538
# Epoch duration =0.21s
# Cumulative duration =104.98s
#
# 539
# Epoch duration =0.2s
# Cumulative duration =105.18s
#
# 540
# Epoch duration =0.19s
# Cumulative duration =105.38s
#
# 541
# Epoch duration =0.2s
# Cumulative duration =105.58s
#
# 542
# Epoch duration =0.19s
# Cumulative duration =105.77s
#
# 543
# Epoch duration =0.19s
# Cumulative duration =105.96s
#
# 544
# Epoch duration =0.19s
# Cumulative duration =106.15s
#
# 545
# Epoch duration =0.19s
# Cumulative duration =106.34s
#
# 546
# Epoch duration =0.19s
# Cumulative duration =106.54s
#
# 547
# Epoch duration =0.2s
# Cumulative duration =106.74s
#
# 548
# Epoch duration =0.21s
# Cumulative duration =106.95s
#
# 549
# Epoch duration =0.2s
# Cumulative duration =107.15s
#
# 550
# Epoch duration =0.19s
# Cumulative duration =107.34s
#
# 551
# Epoch duration =0.2s
# Cumulative duration =107.53s
#
# 552
# Epoch duration =0.2s
# Cumulative duration =107.73s
#
# 553
# Epoch duration =0.21s
# Cumulative duration =107.94s
#
# 554
# Epoch duration =0.2s
# Cumulative duration =108.14s
#
# 555
# Epoch duration =0.19s
# Cumulative duration =108.33s
#
# 556
# Epoch duration =0.21s
# Cumulative duration =108.54s
#
# 557
# Epoch duration =0.19s
# Cumulative duration =108.73s
#
# 558
# Epoch duration =0.21s
# Cumulative duration =108.94s
#
# 559
# Epoch duration =0.19s
# Cumulative duration =109.13s
#
# 560
# Epoch duration =0.19s
# Cumulative duration =109.31s
#
# 561
# Epoch duration =0.2s
# Cumulative duration =109.51s
#
# 562
# Epoch duration =0.21s
# Cumulative duration =109.72s
#
# 563
# Epoch duration =0.19s
# Cumulative duration =109.91s
#
# 564
# Epoch duration =0.19s
# Cumulative duration =110.1s
#
# 565
# Epoch duration =0.19s
# Cumulative duration =110.29s
#
# 566
# Epoch duration =0.19s
# Cumulative duration =110.48s
#
# 567
# Epoch duration =0.19s
# Cumulative duration =110.67s
#
# 568
# Epoch duration =0.19s
# Cumulative duration =110.86s
#
# 569
# Epoch duration =0.2s
# Cumulative duration =111.06s
#
# 570
# Epoch duration =0.19s
# Cumulative duration =111.25s
#
# 571
# Epoch duration =0.2s
# Cumulative duration =111.45s
#
# 572
# Epoch duration =0.19s
# Cumulative duration =111.64s
#
# 573
# Epoch duration =0.19s
# Cumulative duration =111.83s
#
# 574
# Epoch duration =0.19s
# Cumulative duration =112.02s
#
# 575
# Epoch duration =0.21s
# Cumulative duration =112.22s
#
# 576
# Epoch duration =0.19s
# Cumulative duration =112.41s
#
# 577
# Epoch duration =0.2s
# Cumulative duration =112.62s
#
# 578
# Epoch duration =0.19s
# Cumulative duration =112.81s
#
# 579
# Epoch duration =0.2s
# Cumulative duration =113.01s
#
# 580
# Epoch duration =0.2s
# Cumulative duration =113.21s
#
# 581
# Epoch duration =0.19s
# Cumulative duration =113.4s
#
# 582
# Epoch duration =0.2s
# Cumulative duration =113.6s
#
# 583
# Epoch duration =0.2s
# Cumulative duration =113.8s
#
# 584
# Epoch duration =0.21s
# Cumulative duration =114.01s
#
# 585
# Epoch duration =0.19s
# Cumulative duration =114.2s
#
# 586
# Epoch duration =0.21s
# Cumulative duration =114.41s
#
# 587
# Epoch duration =0.19s
# Cumulative duration =114.6s
#
# 588
# Epoch duration =0.19s
# Cumulative duration =114.79s
#
# 589
# Epoch duration =0.19s
# Cumulative duration =114.98s
#
# 590
# Epoch duration =0.19s
# Cumulative duration =115.18s
#
# 591
# Epoch duration =0.19s
# Cumulative duration =115.36s
#
# 592
# Epoch duration =0.19s
# Cumulative duration =115.56s
#
# 593
# Epoch duration =0.19s
# Cumulative duration =115.75s
#
# 594
# Epoch duration =0.2s
# Cumulative duration =115.95s
#
# 595
# Epoch duration =0.19s
# Cumulative duration =116.14s
#
# 596
# Epoch duration =0.2s
# Cumulative duration =116.33s
#
# 597
# Epoch duration =0.19s
# Cumulative duration =116.52s
#
# 598
# Epoch duration =0.2s
# Cumulative duration =116.72s
#
# 599
# Epoch duration =0.19s
# Cumulative duration =116.91s
#
# 600
# Epoch duration =0.19s
# Cumulative duration =117.1s
#
# 601
# Epoch duration =0.19s
# Cumulative duration =117.29s
#
# 602
# Epoch duration =0.19s
# Cumulative duration =117.48s
#
# 603
# Epoch duration =0.19s
# Cumulative duration =117.67s
#
# 604
# Epoch duration =0.19s
# Cumulative duration =117.87s
#
# 605
# Epoch duration =0.19s
# Cumulative duration =118.05s
#
# 606
# Epoch duration =0.21s
# Cumulative duration =118.26s
#
# 607
# Epoch duration =0.2s
# Cumulative duration =118.46s
#
# 608
# Epoch duration =0.2s
# Cumulative duration =118.66s
#
# 609
# Epoch duration =0.19s
# Cumulative duration =118.85s
#
# 610
# Epoch duration =0.2s
# Cumulative duration =119.05s
#
# 611
# Epoch duration =0.19s
# Cumulative duration =119.24s
#
# 612
# Epoch duration =0.21s
# Cumulative duration =119.45s
#
# 613
# Epoch duration =0.19s
# Cumulative duration =119.65s
#
# 614
# Epoch duration =0.19s
# Cumulative duration =119.84s
#
# 615
# Epoch duration =0.2s
# Cumulative duration =120.04s
#
# 616
# Epoch duration =0.19s
# Cumulative duration =120.23s
#
# 617
# Epoch duration =0.19s
# Cumulative duration =120.42s
#
# 618
# Epoch duration =0.19s
# Cumulative duration =120.61s
#
# 619
# Epoch duration =0.19s
# Cumulative duration =120.8s
#
# 620
# Epoch duration =0.2s
# Cumulative duration =121.0s
#
# 621
# Epoch duration =0.19s
# Cumulative duration =121.19s
#
# 622
# Epoch duration =0.19s
# Cumulative duration =121.39s
#
# 623
# Epoch duration =0.2s
# Cumulative duration =121.58s
#
# 624
# Epoch duration =0.19s
# Cumulative duration =121.77s
#
# 625
# Epoch duration =0.19s
# Cumulative duration =121.96s
#
# 626
# Epoch duration =0.21s
# Cumulative duration =122.17s
#
# 627
# Epoch duration =0.2s
# Cumulative duration =122.37s
#
# 628
# Epoch duration =0.21s
# Cumulative duration =122.58s
#
# 629
# Epoch duration =0.19s
# Cumulative duration =122.77s
#
# 630
# Epoch duration =0.19s
# Cumulative duration =122.96s
#
# 631
# Epoch duration =0.19s
# Cumulative duration =123.15s
#
# 632
# Epoch duration =0.2s
# Cumulative duration =123.35s
#
# 633
# Epoch duration =0.19s
# Cumulative duration =123.54s
#
# 634
# Epoch duration =0.2s
# Cumulative duration =123.75s
#
# 635
# Epoch duration =0.2s
# Cumulative duration =123.94s
#
# 636
# Epoch duration =0.19s
# Cumulative duration =124.14s
#
# 637
# Epoch duration =0.19s
# Cumulative duration =124.33s
#
# 638
# Epoch duration =0.21s
# Cumulative duration =124.53s
#
# 639
# Epoch duration =0.19s
# Cumulative duration =124.72s
#
# 640
# Epoch duration =0.19s
# Cumulative duration =124.91s
#
# 641
# Epoch duration =0.2s
# Cumulative duration =125.11s
#
# 642
# Epoch duration =0.19s
# Cumulative duration =125.3s
#
# 643
# Epoch duration =0.2s
# Cumulative duration =125.5s
#
# 644
# Epoch duration =0.19s
# Cumulative duration =125.69s
#
# 645
# Epoch duration =0.21s
# Cumulative duration =125.91s
#
# 646
# Epoch duration =0.2s
# Cumulative duration =126.1s
#
# 647
# Epoch duration =0.19s
# Cumulative duration =126.29s
#
# 648
# Epoch duration =0.19s
# Cumulative duration =126.48s
#
# 649
# Epoch duration =0.19s
# Cumulative duration =126.67s
#
# 650
# Epoch duration =0.19s
# Cumulative duration =126.86s
#
# 651
# Epoch duration =0.19s
# Cumulative duration =127.05s
#
# 652
# Epoch duration =0.19s
# Cumulative duration =127.24s
#
# 653
# Epoch duration =0.19s
# Cumulative duration =127.44s
#
# 654
# Epoch duration =0.19s
# Cumulative duration =127.62s
#
# 655
# Epoch duration =0.19s
# Cumulative duration =127.81s
#
# 656
# Epoch duration =0.19s
# Cumulative duration =128.01s
#
# 657
# Epoch duration =0.19s
# Cumulative duration =128.2s
#
# 658
# Epoch duration =0.26s
# Cumulative duration =128.46s
#
# 659
# Epoch duration =0.19s
# Cumulative duration =128.65s
#
# 660
# Epoch duration =0.22s
# Cumulative duration =128.88s
#
# 661
# Epoch duration =0.24s
# Cumulative duration =129.12s
#
# 662
# Epoch duration =0.2s
# Cumulative duration =129.31s
#
# 663
# Epoch duration =0.2s
# Cumulative duration =129.51s
#
# 664
# Epoch duration =0.19s
# Cumulative duration =129.7s
#
# 665
# Epoch duration =0.19s
# Cumulative duration =129.89s
#
# 666
# Epoch duration =0.2s
# Cumulative duration =130.09s
#
# 667
# Epoch duration =0.19s
# Cumulative duration =130.28s
#
# 668
# Epoch duration =0.2s
# Cumulative duration =130.48s
#
# 669
# Epoch duration =0.2s
# Cumulative duration =130.68s
#
# 670
# Epoch duration =0.2s
# Cumulative duration =130.87s
#
# 671
# Epoch duration =0.2s
# Cumulative duration =131.07s
#
# 672
# Epoch duration =0.19s
# Cumulative duration =131.26s
#
# 673
# Epoch duration =0.22s
# Cumulative duration =131.48s
#
# 674
# Epoch duration =0.19s
# Cumulative duration =131.67s
#
# 675
# Epoch duration =0.2s
# Cumulative duration =131.87s
#
# 676
# Epoch duration =0.19s
# Cumulative duration =132.06s
#
# 677
# Epoch duration =0.22s
# Cumulative duration =132.28s
#
# 678
# Epoch duration =0.2s
# Cumulative duration =132.48s
#
# 679
# Epoch duration =0.19s
# Cumulative duration =132.68s
#
# 680
# Epoch duration =0.22s
# Cumulative duration =132.89s
#
# 681
# Epoch duration =0.21s
# Cumulative duration =133.1s
#
# 682
# Epoch duration =0.19s
# Cumulative duration =133.29s
#
# 683
# Epoch duration =0.2s
# Cumulative duration =133.48s
#
# 684
# Epoch duration =0.2s
# Cumulative duration =133.69s
#
# 685
# Epoch duration =0.19s
# Cumulative duration =133.88s
#
# 686
# Epoch duration =0.24s
# Cumulative duration =134.13s
#
# 687
# Epoch duration =0.18s
# Cumulative duration =134.31s
#
# 688
# Epoch duration =0.22s
# Cumulative duration =134.53s
#
# 689
# Epoch duration =0.2s
# Cumulative duration =134.73s
#
# 690
# Epoch duration =0.21s
# Cumulative duration =134.94s
#
# 691
# Epoch duration =0.19s
# Cumulative duration =135.13s
#
# 692
# Epoch duration =0.19s
# Cumulative duration =135.32s
#
# 693
# Epoch duration =0.19s
# Cumulative duration =135.51s
#
# 694
# Epoch duration =0.19s
# Cumulative duration =135.71s
#
# 695
# Epoch duration =0.19s
# Cumulative duration =135.89s
#
# 696
# Epoch duration =0.21s
# Cumulative duration =136.11s
#
# 697
# Epoch duration =0.19s
# Cumulative duration =136.3s
#
# 698
# Epoch duration =0.2s
# Cumulative duration =136.5s
#
# 699
# Epoch duration =0.19s
# Cumulative duration =136.68s
#
# 700
# Epoch duration =0.19s
# Cumulative duration =136.87s
#
# 701
# Epoch duration =0.19s
# Cumulative duration =137.06s
#
# 702
# Epoch duration =0.19s
# Cumulative duration =137.26s
#
# 703
# Epoch duration =0.19s
# Cumulative duration =137.44s
#
# 704
# Epoch duration =0.19s
# Cumulative duration =137.64s
#
# 705
# Epoch duration =0.19s
# Cumulative duration =137.83s
#
# 706
# Epoch duration =0.2s
# Cumulative duration =138.03s
#
# 707
# Epoch duration =0.21s
# Cumulative duration =138.24s
#
# 708
# Epoch duration =0.22s
# Cumulative duration =138.46s
#
# 709
# Epoch duration =0.2s
# Cumulative duration =138.66s
#
# 710
# Epoch duration =0.19s
# Cumulative duration =138.85s
#
# 711
# Epoch duration =0.21s
# Cumulative duration =139.06s
#
# 712
# Epoch duration =0.2s
# Cumulative duration =139.26s
#
# 713
# Epoch duration =0.19s
# Cumulative duration =139.45s
#
# 714
# Epoch duration =0.2s
# Cumulative duration =139.65s
#
# 715
# Epoch duration =0.19s
# Cumulative duration =139.84s
#
# 716
# Epoch duration =0.19s
# Cumulative duration =140.03s
#
# 717
# Epoch duration =0.19s
# Cumulative duration =140.22s
#
# 718
# Epoch duration =0.19s
# Cumulative duration =140.41s
#
# 719
# Epoch duration =0.2s
# Cumulative duration =140.61s
#
# 720
# Epoch duration =0.22s
# Cumulative duration =140.82s
#
# 721
# Epoch duration =0.2s
# Cumulative duration =141.03s
#
# 722
# Epoch duration =0.19s
# Cumulative duration =141.22s
#
# 723
# Epoch duration =0.2s
# Cumulative duration =141.41s
#
# 724
# Epoch duration =0.19s
# Cumulative duration =141.61s
#
# 725
# Epoch duration =0.19s
# Cumulative duration =141.8s
#
# 726
# Epoch duration =0.19s
# Cumulative duration =141.99s
#
# 727
# Epoch duration =0.19s
# Cumulative duration =142.18s
#
# 728
# Epoch duration =0.19s
# Cumulative duration =142.37s
#
# 729
# Epoch duration =0.2s
# Cumulative duration =142.57s
#
# 730
# Epoch duration =0.19s
# Cumulative duration =142.76s
#
# 731
# Epoch duration =0.19s
# Cumulative duration =142.95s
#
# 732
# Epoch duration =0.2s
# Cumulative duration =143.15s
#
# 733
# Epoch duration =0.21s
# Cumulative duration =143.36s
#
# 734
# Epoch duration =0.19s
# Cumulative duration =143.56s
#
# 735
# Epoch duration =0.2s
# Cumulative duration =143.75s
#
# 736
# Epoch duration =0.2s
# Cumulative duration =143.95s
#
# 737
# Epoch duration =0.21s
# Cumulative duration =144.16s
#
# 738
# Epoch duration =0.19s
# Cumulative duration =144.35s
#
# 739
# Epoch duration =0.19s
# Cumulative duration =144.54s
#
# 740
# Epoch duration =0.19s
# Cumulative duration =144.73s
#
# 741
# Epoch duration =0.19s
# Cumulative duration =144.92s
#
# 742
# Epoch duration =0.2s
# Cumulative duration =145.12s
#
# 743
# Epoch duration =0.19s
# Cumulative duration =145.31s
#
# 744
# Epoch duration =0.19s
# Cumulative duration =145.5s
#
# 745
# Epoch duration =0.19s
# Cumulative duration =145.69s
#
# 746
# Epoch duration =0.19s
# Cumulative duration =145.88s
#
# 747
# Epoch duration =0.19s
# Cumulative duration =146.07s
#
# 748
# Epoch duration =0.19s
# Cumulative duration =146.26s
#
# 749
# Epoch duration =0.19s
# Cumulative duration =146.46s
#
# 750
# Epoch duration =0.19s
# Cumulative duration =146.65s
#
# 751
# Epoch duration =0.2s
# Cumulative duration =146.84s
#
# 752
# Epoch duration =0.2s
# Cumulative duration =147.04s
#
# 753
# Epoch duration =0.19s
# Cumulative duration =147.23s
#
# 754
# Epoch duration =0.19s
# Cumulative duration =147.42s
#
# 755
# Epoch duration =0.21s
# Cumulative duration =147.63s
#
# 756
# Epoch duration =0.19s
# Cumulative duration =147.82s
#
# 757
# Epoch duration =0.19s
# Cumulative duration =148.01s
#
# 758
# Epoch duration =0.19s
# Cumulative duration =148.2s
#
# 759
# Epoch duration =0.19s
# Cumulative duration =148.39s
#
# 760
# Epoch duration =0.19s
# Cumulative duration =148.57s
#
# 761
# Epoch duration =0.19s
# Cumulative duration =148.76s
#
# 762
# Epoch duration =0.19s
# Cumulative duration =148.96s
#
# 763
# Epoch duration =0.2s
# Cumulative duration =149.16s
#
# 764
# Epoch duration =0.2s
# Cumulative duration =149.36s
#
# 765
# Epoch duration =0.19s
# Cumulative duration =149.55s
#
# 766
# Epoch duration =0.2s
# Cumulative duration =149.75s
#
# 767
# Epoch duration =0.2s
# Cumulative duration =149.95s
#
# 768
# Epoch duration =0.21s
# Cumulative duration =150.16s
#
# 769
# Epoch duration =0.19s
# Cumulative duration =150.35s
#
# 770
# Epoch duration =0.22s
# Cumulative duration =150.56s
#
# 771
# Epoch duration =0.19s
# Cumulative duration =150.75s
#
# 772
# Epoch duration =0.19s
# Cumulative duration =150.94s
#
# 773
# Epoch duration =0.19s
# Cumulative duration =151.13s
#
# 774
# Epoch duration =0.2s
# Cumulative duration =151.33s
#
# 775
# Epoch duration =0.19s
# Cumulative duration =151.52s
#
# 776
# Epoch duration =0.19s
# Cumulative duration =151.71s
#
# 777
# Epoch duration =0.18s
# Cumulative duration =151.9s
#
# 778
# Epoch duration =0.2s
# Cumulative duration =152.09s
#
# 779
# Epoch duration =0.18s
# Cumulative duration =152.28s
#
# 780
# Epoch duration =0.19s
# Cumulative duration =152.47s
#
# 781
# Epoch duration =0.19s
# Cumulative duration =152.66s
#
# 782
# Epoch duration =0.19s
# Cumulative duration =152.85s
#
# 783
# Epoch duration =0.19s
# Cumulative duration =153.04s
#
# 784
# Epoch duration =0.19s
# Cumulative duration =153.23s
#
# 785
# Epoch duration =0.18s
# Cumulative duration =153.42s
#
# 786
# Epoch duration =0.2s
# Cumulative duration =153.61s
#
# 787
# Epoch duration =0.19s
# Cumulative duration =153.8s
#
# 788
# Epoch duration =0.2s
# Cumulative duration =154.0s
#
# 789
# Epoch duration =0.19s
# Cumulative duration =154.19s
#
# 790
# Epoch duration =0.19s
# Cumulative duration =154.37s
#
# 791
# Epoch duration =0.19s
# Cumulative duration =154.56s
#
# 792
# Epoch duration =0.19s
# Cumulative duration =154.75s
#
# 793
# Epoch duration =0.19s
# Cumulative duration =154.94s
#
# 794
# Epoch duration =0.19s
# Cumulative duration =155.13s
#
# 795
# Epoch duration =0.19s
# Cumulative duration =155.32s
#
# 796
# Epoch duration =0.2s
# Cumulative duration =155.52s
#
# 797
# Epoch duration =0.19s
# Cumulative duration =155.7s
#
# 798
# Epoch duration =0.19s
# Cumulative duration =155.89s
#
# 799
# Epoch duration =0.19s
# Cumulative duration =156.08s
#
# 800
# Epoch duration =0.19s
# Cumulative duration =156.28s
#
# 801
# Epoch duration =0.19s
# Cumulative duration =156.47s
#
# 802
# Epoch duration =0.19s
# Cumulative duration =156.66s
#
# 803
# Epoch duration =0.19s
# Cumulative duration =156.85s
#
# 804
# Epoch duration =0.19s
# Cumulative duration =157.04s
#
# 805
# Epoch duration =0.19s
# Cumulative duration =157.24s
#
# 806
# Epoch duration =0.19s
# Cumulative duration =157.43s
#
# 807
# Epoch duration =0.19s
# Cumulative duration =157.62s
#
# 808
# Epoch duration =0.19s
# Cumulative duration =157.81s
#
# 809
# Epoch duration =0.19s
# Cumulative duration =158.0s
#
# 810
# Epoch duration =0.2s
# Cumulative duration =158.2s
#
# 811
# Epoch duration =0.19s
# Cumulative duration =158.39s
#
# 812
# Epoch duration =0.19s
# Cumulative duration =158.58s
#
# 813
# Epoch duration =0.19s
# Cumulative duration =158.77s
#
# 814
# Epoch duration =0.19s
# Cumulative duration =158.96s
#
# 815
# Epoch duration =0.19s
# Cumulative duration =159.15s
#
# 816
# Epoch duration =0.19s
# Cumulative duration =159.34s
#
# 817
# Epoch duration =0.2s
# Cumulative duration =159.54s
#
# 818
# Epoch duration =0.19s
# Cumulative duration =159.73s
#
# 819
# Epoch duration =0.19s
# Cumulative duration =159.92s
#
# 820
# Epoch duration =0.2s
# Cumulative duration =160.12s
#
# 821
# Epoch duration =0.19s
# Cumulative duration =160.31s
#
# 822
# Epoch duration =0.19s
# Cumulative duration =160.5s
#
# 823
# Epoch duration =0.19s
# Cumulative duration =160.69s
#
# 824
# Epoch duration =0.2s
# Cumulative duration =160.89s
#
# 825
# Epoch duration =0.2s
# Cumulative duration =161.09s
#
# 826
# Epoch duration =0.2s
# Cumulative duration =161.29s
#
# 827
# Epoch duration =0.19s
# Cumulative duration =161.48s
#
# 828
# Epoch duration =0.2s
# Cumulative duration =161.67s
#
# 829
# Epoch duration =0.18s
# Cumulative duration =161.86s
#
# 830
# Epoch duration =0.22s
# Cumulative duration =162.07s
#
# 831
# Epoch duration =0.19s
# Cumulative duration =162.26s
#
# 832
# Epoch duration =0.21s
# Cumulative duration =162.48s
#
# 833
# Epoch duration =0.19s
# Cumulative duration =162.67s
#
# 834
# Epoch duration =0.19s
# Cumulative duration =162.86s
#
# 835
# Epoch duration =0.19s
# Cumulative duration =163.05s
#
# 836
# Epoch duration =0.2s
# Cumulative duration =163.25s
#
# 837
# Epoch duration =0.19s
# Cumulative duration =163.44s
#
# 838
# Epoch duration =0.19s
# Cumulative duration =163.63s
#
# 839
# Epoch duration =0.19s
# Cumulative duration =163.82s
#
# 840
# Epoch duration =0.19s
# Cumulative duration =164.01s
#
# 841
# Epoch duration =0.19s
# Cumulative duration =164.2s
#
# 842
# Epoch duration =0.19s
# Cumulative duration =164.39s
#
# 843
# Epoch duration =0.19s
# Cumulative duration =164.57s
#
# 844
# Epoch duration =0.21s
# Cumulative duration =164.79s
#
# 845
# Epoch duration =0.19s
# Cumulative duration =164.97s
#
# 846
# Epoch duration =0.19s
# Cumulative duration =165.17s
#
# 847
# Epoch duration =0.19s
# Cumulative duration =165.35s
#
# 848
# Epoch duration =0.19s
# Cumulative duration =165.55s
#
# 849
# Epoch duration =0.19s
# Cumulative duration =165.74s
#
# 850
# Epoch duration =0.19s
# Cumulative duration =165.93s
#
# 851
# Epoch duration =0.19s
# Cumulative duration =166.13s
#
# 852
# Epoch duration =0.19s
# Cumulative duration =166.31s
#
# 853
# Epoch duration =0.19s
# Cumulative duration =166.5s
#
# 854
# Epoch duration =0.2s
# Cumulative duration =166.7s
#
# 855
# Epoch duration =0.19s
# Cumulative duration =166.89s
#
# 856
# Epoch duration =0.2s
# Cumulative duration =167.08s
#
# 857
# Epoch duration =0.19s
# Cumulative duration =167.27s
#
# 858
# Epoch duration =0.19s
# Cumulative duration =167.46s
#
# 859
# Epoch duration =0.19s
# Cumulative duration =167.65s
#
# 860
# Epoch duration =0.19s
# Cumulative duration =167.84s
#
# 861
# Epoch duration =0.19s
# Cumulative duration =168.03s
#
# 862
# Epoch duration =0.19s
# Cumulative duration =168.22s
#
# 863
# Epoch duration =0.19s
# Cumulative duration =168.41s
#
# 864
# Epoch duration =0.2s
# Cumulative duration =168.61s
#
# 865
# Epoch duration =0.19s
# Cumulative duration =168.8s
#
# 866
# Epoch duration =0.2s
# Cumulative duration =169.0s
#
# 867
# Epoch duration =0.19s
# Cumulative duration =169.19s
#
# 868
# Epoch duration =0.19s
# Cumulative duration =169.39s
#
# 869
# Epoch duration =0.19s
# Cumulative duration =169.58s
#
# 870
# Epoch duration =0.2s
# Cumulative duration =169.78s
#
# 871
# Epoch duration =0.19s
# Cumulative duration =169.97s
#
# 872
# Epoch duration =0.19s
# Cumulative duration =170.16s
#
# 873
# Epoch duration =0.19s
# Cumulative duration =170.36s
#
# 874
# Epoch duration =0.2s
# Cumulative duration =170.55s
#
# 875
# Epoch duration =0.19s
# Cumulative duration =170.74s
#
# 876
# Epoch duration =0.19s
# Cumulative duration =170.93s
#
# 877
# Epoch duration =0.19s
# Cumulative duration =171.12s
#
# 878
# Epoch duration =0.19s
# Cumulative duration =171.31s
#
# 879
# Epoch duration =0.19s
# Cumulative duration =171.5s
#
# 880
# Epoch duration =0.2s
# Cumulative duration =171.7s
#
# 881
# Epoch duration =0.19s
# Cumulative duration =171.89s
#
# 882
# Epoch duration =0.2s
# Cumulative duration =172.09s
#
# 883
# Epoch duration =0.19s
# Cumulative duration =172.27s
#
# 884
# Epoch duration =0.19s
# Cumulative duration =172.46s
#
# 885
# Epoch duration =0.19s
# Cumulative duration =172.65s
#
# 886
# Epoch duration =0.19s
# Cumulative duration =172.85s
#
# 887
# Epoch duration =0.19s
# Cumulative duration =173.04s
#
# 888
# Epoch duration =0.19s
# Cumulative duration =173.23s
#
# 889
# Epoch duration =0.19s
# Cumulative duration =173.41s
#
# 890
# Epoch duration =0.19s
# Cumulative duration =173.6s
#
# 891
# Epoch duration =0.19s
# Cumulative duration =173.79s
#
# 892
# Epoch duration =0.19s
# Cumulative duration =173.98s
#
# 893
# Epoch duration =0.19s
# Cumulative duration =174.17s
#
# 894
# Epoch duration =0.19s
# Cumulative duration =174.36s
#
# 895
# Epoch duration =0.19s
# Cumulative duration =174.55s
#
# 896
# Epoch duration =0.2s
# Cumulative duration =174.75s
#
# 897
# Epoch duration =0.19s
# Cumulative duration =174.94s
#
# 898
# Epoch duration =0.19s
# Cumulative duration =175.13s
#
# 899
# Epoch duration =0.19s
# Cumulative duration =175.32s
#
# 900
# Epoch duration =0.19s
# Cumulative duration =175.51s
#
# 901
# Epoch duration =0.19s
# Cumulative duration =175.7s
#
# 902
# Epoch duration =0.19s
# Cumulative duration =175.9s
#
# 903
# Epoch duration =0.19s
# Cumulative duration =176.09s
#
# 904
# Epoch duration =0.2s
# Cumulative duration =176.28s
#
# 905
# Epoch duration =0.19s
# Cumulative duration =176.47s
#
# 906
# Epoch duration =0.19s
# Cumulative duration =176.66s
#
# 907
# Epoch duration =0.19s
# Cumulative duration =176.86s
#
# 908
# Epoch duration =0.19s
# Cumulative duration =177.05s
#
# 909
# Epoch duration =0.19s
# Cumulative duration =177.24s
#
# 910
# Epoch duration =0.19s
# Cumulative duration =177.43s
#
# 911
# Epoch duration =0.19s
# Cumulative duration =177.61s
#
# 912
# Epoch duration =0.2s
# Cumulative duration =177.82s
#
# 913
# Epoch duration =0.19s
# Cumulative duration =178.01s
#
# 914
# Epoch duration =0.19s
# Cumulative duration =178.2s
#
# 915
# Epoch duration =0.19s
# Cumulative duration =178.4s
#
# 916
# Epoch duration =0.2s
# Cumulative duration =178.59s
#
# 917
# Epoch duration =0.19s
# Cumulative duration =178.78s
#
# 918
# Epoch duration =0.2s
# Cumulative duration =178.98s
#
# 919
# Epoch duration =0.19s
# Cumulative duration =179.17s
#
# 920
# Epoch duration =0.19s
# Cumulative duration =179.36s
#
# 921
# Epoch duration =0.19s
# Cumulative duration =179.56s
#
# 922
# Epoch duration =0.2s
# Cumulative duration =179.75s
#
# 923
# Epoch duration =0.19s
# Cumulative duration =179.94s
#
# 924
# Epoch duration =0.2s
# Cumulative duration =180.14s
#
# 925
# Epoch duration =0.19s
# Cumulative duration =180.33s
#
# 926
# Epoch duration =0.19s
# Cumulative duration =180.52s
#
# 927
# Epoch duration =0.19s
# Cumulative duration =180.71s
#
# 928
# Epoch duration =0.2s
# Cumulative duration =180.91s
#
# 929
# Epoch duration =0.19s
# Cumulative duration =181.1s
#
# 930
# Epoch duration =0.2s
# Cumulative duration =181.3s
#
# 931
# Epoch duration =0.2s
# Cumulative duration =181.5s
#
# 932
# Epoch duration =0.2s
# Cumulative duration =181.7s
#
# 933
# Epoch duration =0.19s
# Cumulative duration =181.89s
#
# 934
# Epoch duration =0.21s
# Cumulative duration =182.1s
#
# 935
# Epoch duration =0.21s
# Cumulative duration =182.3s
#
# 936
# Epoch duration =0.21s
# Cumulative duration =182.51s
#
# 937
# Epoch duration =0.24s
# Cumulative duration =182.75s
#
# 938
# Epoch duration =0.23s
# Cumulative duration =182.98s
#
# 939
# Epoch duration =0.26s
# Cumulative duration =183.24s
#
# 940
# Epoch duration =0.23s
# Cumulative duration =183.47s
#
# 941
# Epoch duration =0.23s
# Cumulative duration =183.7s
#
# 942
# Epoch duration =0.22s
# Cumulative duration =183.92s
#
# 943
# Epoch duration =0.23s
# Cumulative duration =184.15s
#
# 944
# Epoch duration =0.22s
# Cumulative duration =184.38s
#
# 945
# Epoch duration =0.24s
# Cumulative duration =184.61s
#
# 946
# Epoch duration =0.25s
# Cumulative duration =184.86s
#
# 947
# Epoch duration =0.25s
# Cumulative duration =185.11s
#
# 948
# Epoch duration =0.21s
# Cumulative duration =185.33s
#
# 949
# Epoch duration =0.22s
# Cumulative duration =185.54s
#
# 950
# Epoch duration =0.21s
# Cumulative duration =185.76s
#
# 951
# Epoch duration =0.22s
# Cumulative duration =185.98s
#
# 952
# Epoch duration =0.22s
# Cumulative duration =186.2s
#
# 953
# Epoch duration =0.22s
# Cumulative duration =186.42s
#
# 954
# Epoch duration =0.21s
# Cumulative duration =186.62s
#
# 955
# Epoch duration =0.19s
# Cumulative duration =186.81s
#
# 956
# Epoch duration =0.19s
# Cumulative duration =187.01s
#
# 957
# Epoch duration =0.19s
# Cumulative duration =187.2s
#
# 958
# Epoch duration =0.19s
# Cumulative duration =187.39s
#
# 959
# Epoch duration =0.19s
# Cumulative duration =187.58s
#
# 960
# Epoch duration =0.2s
# Cumulative duration =187.77s
#
# 961
# Epoch duration =0.19s
# Cumulative duration =187.96s
#
# 962
# Epoch duration =0.19s
# Cumulative duration =188.16s
#
# 963
# Epoch duration =0.19s
# Cumulative duration =188.34s
#
# 964
# Epoch duration =0.19s
# Cumulative duration =188.53s
#
# 965
# Epoch duration =0.19s
# Cumulative duration =188.72s
#
# 966
# Epoch duration =0.19s
# Cumulative duration =188.91s
#
# 967
# Epoch duration =0.19s
# Cumulative duration =189.1s
#
# 968
# Epoch duration =0.2s
# Cumulative duration =189.3s
#
# 969
# Epoch duration =0.19s
# Cumulative duration =189.48s
#
# 970
# Epoch duration =0.19s
# Cumulative duration =189.68s
#
# 971
# Epoch duration =0.19s
# Cumulative duration =189.86s
#
# 972
# Epoch duration =0.19s
# Cumulative duration =190.05s
#
# 973
# Epoch duration =0.19s
# Cumulative duration =190.24s
#
# 974
# Epoch duration =0.21s
# Cumulative duration =190.45s
#
# 975
# Epoch duration =0.19s
# Cumulative duration =190.64s
#
# 976
# Epoch duration =0.19s
# Cumulative duration =190.83s
#
# 977
# Epoch duration =0.19s
# Cumulative duration =191.02s
#
# 978
# Epoch duration =0.19s
# Cumulative duration =191.21s
#
# 979
# Epoch duration =0.19s
# Cumulative duration =191.4s
#
# 980
# Epoch duration =0.19s
# Cumulative duration =191.59s
#
# 981
# Epoch duration =0.19s
# Cumulative duration =191.78s
#
# 982
# Epoch duration =0.19s
# Cumulative duration =191.97s
#
# 983
# Epoch duration =0.19s
# Cumulative duration =192.16s
#
# 984
# Epoch duration =0.19s
# Cumulative duration =192.35s
#
# 985
# Epoch duration =0.19s
# Cumulative duration =192.54s
#
# 986
# Epoch duration =0.19s
# Cumulative duration =192.73s
#
# 987
# Epoch duration =0.19s
# Cumulative duration =192.92s
#
# 988
# Epoch duration =0.19s
# Cumulative duration =193.11s
#
# 989
# Epoch duration =0.19s
# Cumulative duration =193.3s
#
# 990
# Epoch duration =0.19s
# Cumulative duration =193.49s
#
# 991
# Epoch duration =0.2s
# Cumulative duration =193.69s
#
# 992
# Epoch duration =0.19s
# Cumulative duration =193.88s
#
# 993
# Epoch duration =0.19s
# Cumulative duration =194.07s
#
# 994
# Epoch duration =0.2s
# Cumulative duration =194.27s
#
# 995
# Epoch duration =0.19s
# Cumulative duration =194.45s
#
# 996
# Epoch duration =0.19s
# Cumulative duration =194.65s
#
# 997
# Epoch duration =0.19s
# Cumulative duration =194.83s
#
# 998
# Epoch duration =0.19s
# Cumulative duration =195.02s
#
# 999
# Epoch duration =0.19s
# Cumulative duration =195.21s

# %%
# Save the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_sumoutputs1000.npy'
np.save(npy_save_path, sum_mut2_predictoutputs)

# %%
#Load the saved data
sum_mut2_predictoutputs = np.load('Arrays/toyhairpin_FC_sumoutputs1000.npy')

# %%
#average the values
num_summary = 1000
mean_mut2_predictoutputs = sum_mut2_predictoutputs/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_predictoutputs_hol = mean_mut2_predictoutputs.reshape(X.shape[1],X.shape[1],4,4)

# %% [markdown]
# ## Signatures

# %% [markdown]
# ### First 20

# %%
nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(10,7))

num = 20

for ii in range(num):
    ax = fig4.add_subplot(4,5,ii+1)
    ax.set_title(str(ii)+','+str(40-ii))
    ax = sb.heatmap(mean_mut2_predictoutputs_hol[ii, 40-ii], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc)

# %% [markdown]
# ### All bases Paired (editted visuals)

# %%
nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(15,14))

num = 11

for one in range(num):
    for two in range(num):
        ax = fig4.add_subplot(num, num, ((one*num)+two)+1)
        
        #plot the 0th column with row labels and the num_th most row with column labels
        if two == 0:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc, cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=nuc, cbar=False)
        else:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=[], cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=[], cbar=False)

# %% [markdown]
# ## Test averages of larger amounts of the data

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_summary = 3000

sum_mut2_predictoutputs = np.zeros((41*41*16, 1))
starttime = time.time()

for ii in range(num_summary):
    print (ii)
    epoch_starttime = time.time()
    
    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    #mutate the sequence
    X_mutsecorder = mf.double_mutate(X, X.shape[1], X.shape[3])

    #reshape the 6D tensor into a 4D tensor that the model can test
    X_mutsecorder_reshape = np.reshape(X_mutsecorder, (X.shape[1]*X.shape[1]*16, X.shape[1], 1, 4))
    
    mutations = {'inputs': X_mutsecorder_reshape, 'targets': Y_test[:X_mutsecorder_reshape.shape[0]]}
    
    #Get output activations for the mutations
    mut2_predictoutputs= nntrainer.get_activations(sess, mutations, layer='output')
    
    #Sum all the scores into a single matrix
    sum_mut2_predictoutputs += mut2_predictoutputs
    
    epoch_endtime = time.time()
    
    print ('Epoch duration =' + str(np.around((epoch_endtime -epoch_starttime), 2)) + 's')
    print ('Cumulative duration =' + str(np.around((epoch_endtime - starttime), 2)) + 's')
    print ()

# Save the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_sumoutputs3000.npy'
np.save(npy_save_path, sum_mut2_predictoutputs)
    
#average the values
mean_mut2_predictoutputs = sum_mut2_predictoutputs/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_predictoutputs_hol = mean_mut2_predictoutputs.reshape(X.shape[1],X.shape[1],4,4)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_best.ckpt
# 0
# Epoch duration =0.2s
# Cumulative duration =0.2s
#
# 1
# Epoch duration =0.19s
# Cumulative duration =0.39s
#
# 2
# Epoch duration =0.19s
# Cumulative duration =0.58s
#
# 3
# Epoch duration =0.19s
# Cumulative duration =0.77s
#
# 4
# Epoch duration =0.26s
# Cumulative duration =1.03s
#
# 5
# Epoch duration =0.24s
# Cumulative duration =1.27s
#
# 6
# Epoch duration =0.19s
# Cumulative duration =1.46s
#
# 7
# Epoch duration =0.19s
# Cumulative duration =1.65s
#
# 8
# Epoch duration =0.19s
# Cumulative duration =1.84s
#
# 9
# Epoch duration =0.2s
# Cumulative duration =2.04s
#
# 10
# Epoch duration =0.19s
# Cumulative duration =2.23s
#
# 11
# Epoch duration =0.2s
# Cumulative duration =2.43s
#
# 12
# Epoch duration =0.21s
# Cumulative duration =2.64s
#
# 13
# Epoch duration =0.2s
# Cumulative duration =2.84s
#
# 14
# Epoch duration =0.2s
# Cumulative duration =3.04s
#
# 15
# Epoch duration =0.19s
# Cumulative duration =3.23s
#
# 16
# Epoch duration =0.2s
# Cumulative duration =3.43s
#
# 17
# Epoch duration =0.19s
# Cumulative duration =3.62s
#
# 18
# Epoch duration =0.29s
# Cumulative duration =3.9s
#
# 19
# Epoch duration =0.28s
# Cumulative duration =4.18s
#
# 20
# Epoch duration =0.2s
# Cumulative duration =4.38s
#
# 21
# Epoch duration =0.31s
# Cumulative duration =4.69s
#
# 22
# Epoch duration =0.19s
# Cumulative duration =4.88s
#
# 23
# Epoch duration =0.19s
# Cumulative duration =5.07s
#
# 24
# Epoch duration =0.19s
# Cumulative duration =5.26s
#
# 25
# Epoch duration =0.28s
# Cumulative duration =5.54s
#
# 26
# Epoch duration =0.22s
# Cumulative duration =5.76s
#
# 27
# Epoch duration =0.19s
# Cumulative duration =5.96s
#
# 28
# Epoch duration =0.2s
# Cumulative duration =6.15s
#
# 29
# Epoch duration =0.19s
# Cumulative duration =6.34s
#
# 30
# Epoch duration =0.19s
# Cumulative duration =6.53s
#
# 31
# Epoch duration =0.19s
# Cumulative duration =6.73s
#
# 32
# Epoch duration =0.21s
# Cumulative duration =6.93s
#
# 33
# Epoch duration =0.21s
# Cumulative duration =7.15s
#
# 34
# Epoch duration =0.21s
# Cumulative duration =7.35s
#
# 35
# Epoch duration =0.19s
# Cumulative duration =7.55s
#
# 36
# Epoch duration =0.2s
# Cumulative duration =7.74s
#
# 37
# Epoch duration =0.2s
# Cumulative duration =7.94s
#
# 38
# Epoch duration =0.2s
# Cumulative duration =8.15s
#
# 39
# Epoch duration =0.2s
# Cumulative duration =8.34s
#
# 40
# Epoch duration =0.21s
# Cumulative duration =8.56s
#
# 41
# Epoch duration =0.19s
# Cumulative duration =8.75s
#
# 42
# Epoch duration =0.2s
# Cumulative duration =8.94s
#
# 43
# Epoch duration =0.19s
# Cumulative duration =9.14s
#
# 44
# Epoch duration =0.19s
# Cumulative duration =9.33s
#
# 45
# Epoch duration =0.19s
# Cumulative duration =9.52s
#
# 46
# Epoch duration =0.23s
# Cumulative duration =9.75s
#
# 47
# Epoch duration =0.29s
# Cumulative duration =10.04s
#
# 48
# Epoch duration =0.19s
# Cumulative duration =10.23s
#
# 49
# Epoch duration =0.2s
# Cumulative duration =10.43s
#
# 50
# Epoch duration =0.23s
# Cumulative duration =10.65s
#
# 51
# Epoch duration =0.27s
# Cumulative duration =10.92s
#
# 52
# Epoch duration =0.25s
# Cumulative duration =11.18s
#
# 53
# Epoch duration =0.22s
# Cumulative duration =11.4s
#
# 54
# Epoch duration =0.19s
# Cumulative duration =11.59s
#
# 55
# Epoch duration =0.27s
# Cumulative duration =11.85s
#
# 56
# Epoch duration =0.24s
# Cumulative duration =12.1s
#
# 57
# Epoch duration =0.25s
# Cumulative duration =12.35s
#
# 58
# Epoch duration =0.21s
# Cumulative duration =12.56s
#
# 59
# Epoch duration =0.26s
# Cumulative duration =12.82s
#
# 60
# Epoch duration =0.23s
# Cumulative duration =13.05s
#
# 61
# Epoch duration =0.19s
# Cumulative duration =13.24s
#
# 62
# Epoch duration =0.27s
# Cumulative duration =13.51s
#
# 63
# Epoch duration =0.23s
# Cumulative duration =13.74s
#
# 64
# Epoch duration =0.19s
# Cumulative duration =13.93s
#
# 65
# Epoch duration =0.19s
# Cumulative duration =14.12s
#
# 66
# Epoch duration =0.2s
# Cumulative duration =14.32s
#
# 67
# Epoch duration =0.2s
# Cumulative duration =14.53s
#
# 68
# Epoch duration =0.19s
# Cumulative duration =14.71s
#
# 69
# Epoch duration =0.2s
# Cumulative duration =14.91s
#
# 70
# Epoch duration =0.19s
# Cumulative duration =15.1s
#
# 71
# Epoch duration =0.19s
# Cumulative duration =15.29s
#
# 72
# Epoch duration =0.19s
# Cumulative duration =15.48s
#
# 73
# Epoch duration =0.2s
# Cumulative duration =15.68s
#
# 74
# Epoch duration =0.19s
# Cumulative duration =15.87s
#
# 75
# Epoch duration =0.19s
# Cumulative duration =16.06s
#
# 76
# Epoch duration =0.19s
# Cumulative duration =16.25s
#
# 77
# Epoch duration =0.2s
# Cumulative duration =16.45s
#
# 78
# Epoch duration =0.2s
# Cumulative duration =16.65s
#
# 79
# Epoch duration =0.28s
# Cumulative duration =16.93s
#
# 80
# Epoch duration =0.2s
# Cumulative duration =17.13s
#
# 81
# Epoch duration =0.19s
# Cumulative duration =17.32s
#
# 82
# Epoch duration =0.19s
# Cumulative duration =17.5s
#
# 83
# Epoch duration =0.19s
# Cumulative duration =17.7s
#
# 84
# Epoch duration =0.28s
# Cumulative duration =17.97s
#
# 85
# Epoch duration =0.24s
# Cumulative duration =18.21s
#
# 86
# Epoch duration =0.24s
# Cumulative duration =18.45s
#
# 87
# Epoch duration =0.3s
# Cumulative duration =18.76s
#
# 88
# Epoch duration =0.19s
# Cumulative duration =18.95s
#
# 89
# Epoch duration =0.2s
# Cumulative duration =19.15s
#
# 90
# Epoch duration =0.19s
# Cumulative duration =19.34s
#
# 91
# Epoch duration =0.19s
# Cumulative duration =19.53s
#
# 92
# Epoch duration =0.2s
# Cumulative duration =19.73s
#
# 93
# Epoch duration =0.19s
# Cumulative duration =19.92s
#
# 94
# Epoch duration =0.19s
# Cumulative duration =20.11s
#
# 95
# Epoch duration =0.2s
# Cumulative duration =20.31s
#
# 96
# Epoch duration =0.19s
# Cumulative duration =20.5s
#
# 97
# Epoch duration =0.19s
# Cumulative duration =20.69s
#
# 98
# Epoch duration =0.19s
# Cumulative duration =20.88s
#
# 99
# Epoch duration =0.2s
# Cumulative duration =21.08s
#
# 100
# Epoch duration =0.19s
# Cumulative duration =21.27s
#
# 101
# Epoch duration =0.2s
# Cumulative duration =21.47s
#
# 102
# Epoch duration =0.19s
# Cumulative duration =21.66s
#
# 103
# Epoch duration =0.2s
# Cumulative duration =21.86s
#
# 104
# Epoch duration =0.21s
# Cumulative duration =22.07s
#
# 105
# Epoch duration =0.21s
# Cumulative duration =22.28s
#
# 106
# Epoch duration =0.19s
# Cumulative duration =22.47s
#
# 107
# Epoch duration =0.2s
# Cumulative duration =22.66s
#
# 108
# Epoch duration =0.19s
# Cumulative duration =22.85s
#
# 109
# Epoch duration =0.21s
# Cumulative duration =23.06s
#
# 110
# Epoch duration =0.19s
# Cumulative duration =23.25s
#
# 111
# Epoch duration =0.21s
# Cumulative duration =23.46s
#
# 112
# Epoch duration =0.21s
# Cumulative duration =23.66s
#
# 113
# Epoch duration =0.19s
# Cumulative duration =23.86s
#
# 114
# Epoch duration =0.2s
# Cumulative duration =24.05s
#
# 115
# Epoch duration =0.2s
# Cumulative duration =24.25s
#
# 116
# Epoch duration =0.2s
# Cumulative duration =24.45s
#
# 117
# Epoch duration =0.21s
# Cumulative duration =24.66s
#
# 118
# Epoch duration =0.2s
# Cumulative duration =24.85s
#
# 119
# Epoch duration =0.2s
# Cumulative duration =25.06s
#
# 120
# Epoch duration =0.19s
# Cumulative duration =25.24s
#
# 121
# Epoch duration =0.19s
# Cumulative duration =25.44s
#
# 122
# Epoch duration =0.19s
# Cumulative duration =25.62s
#
# 123
# Epoch duration =0.19s
# Cumulative duration =25.82s
#
# 124
# Epoch duration =0.19s
# Cumulative duration =26.01s
#
# 125
# Epoch duration =0.2s
# Cumulative duration =26.21s
#
# 126
# Epoch duration =0.19s
# Cumulative duration =26.4s
#
# 127
# Epoch duration =0.2s
# Cumulative duration =26.59s
#
# 128
# Epoch duration =0.19s
# Cumulative duration =26.78s
#
# 129
# Epoch duration =0.19s
# Cumulative duration =26.98s
#
# 130
# Epoch duration =0.19s
# Cumulative duration =27.17s
#
# 131
# Epoch duration =0.19s
# Cumulative duration =27.36s
#
# 132
# Epoch duration =0.19s
# Cumulative duration =27.55s
#
# 133
# Epoch duration =0.2s
# Cumulative duration =27.75s
#
# 134
# Epoch duration =0.19s
# Cumulative duration =27.94s
#
# 135
# Epoch duration =0.19s
# Cumulative duration =28.13s
#
# 136
# Epoch duration =0.19s
# Cumulative duration =28.32s
#
# 137
# Epoch duration =0.19s
# Cumulative duration =28.51s
#
# 138
# Epoch duration =0.19s
# Cumulative duration =28.7s
#
# 139
# Epoch duration =0.19s
# Cumulative duration =28.89s
#
# 140
# Epoch duration =0.19s
# Cumulative duration =29.08s
#
# 141
# Epoch duration =0.19s
# Cumulative duration =29.27s
#
# 142
# Epoch duration =0.19s
# Cumulative duration =29.46s
#
# 143
# Epoch duration =0.21s
# Cumulative duration =29.67s
#
# 144
# Epoch duration =0.19s
# Cumulative duration =29.86s
#
# 145
# Epoch duration =0.19s
# Cumulative duration =30.05s
#
# 146
# Epoch duration =0.19s
# Cumulative duration =30.24s
#
# 147
# Epoch duration =0.19s
# Cumulative duration =30.44s
#
# 148
# Epoch duration =0.2s
# Cumulative duration =30.64s
#
# 149
# Epoch duration =0.19s
# Cumulative duration =30.83s
#
# 150
# Epoch duration =0.19s
# Cumulative duration =31.02s
#
# 151
# Epoch duration =0.2s
# Cumulative duration =31.22s
#
# 152
# Epoch duration =0.2s
# Cumulative duration =31.42s
#
# 153
# Epoch duration =0.2s
# Cumulative duration =31.62s
#
# 154
# Epoch duration =0.2s
# Cumulative duration =31.82s
#
# 155
# Epoch duration =0.21s
# Cumulative duration =32.03s
#
# 156
# Epoch duration =0.19s
# Cumulative duration =32.22s
#
# 157
# Epoch duration =0.19s
# Cumulative duration =32.42s
#
# 158
# Epoch duration =0.2s
# Cumulative duration =32.62s
#
# 159
# Epoch duration =0.21s
# Cumulative duration =32.83s
#
# 160
# Epoch duration =0.19s
# Cumulative duration =33.02s
#
# 161
# Epoch duration =0.2s
# Cumulative duration =33.22s
#
# 162
# Epoch duration =0.19s
# Cumulative duration =33.4s
#
# 163
# Epoch duration =0.19s
# Cumulative duration =33.6s
#
# 164
# Epoch duration =0.19s
# Cumulative duration =33.79s
#
# 165
# Epoch duration =0.2s
# Cumulative duration =33.99s
#
# 166
# Epoch duration =0.19s
# Cumulative duration =34.18s
#
# 167
# Epoch duration =0.2s
# Cumulative duration =34.38s
#
# 168
# Epoch duration =0.19s
# Cumulative duration =34.57s
#
# 169
# Epoch duration =0.2s
# Cumulative duration =34.77s
#
# 170
# Epoch duration =0.19s
# Cumulative duration =34.96s
#
# 171
# Epoch duration =0.2s
# Cumulative duration =35.16s
#
# 172
# Epoch duration =0.19s
# Cumulative duration =35.35s
#
# 173
# Epoch duration =0.19s
# Cumulative duration =35.54s
#
# 174
# Epoch duration =0.19s
# Cumulative duration =35.73s
#
# 175
# Epoch duration =0.19s
# Cumulative duration =35.93s
#
# 176
# Epoch duration =0.19s
# Cumulative duration =36.12s
#
# 177
# Epoch duration =0.19s
# Cumulative duration =36.31s
#
# 178
# Epoch duration =0.19s
# Cumulative duration =36.5s
#
# 179
# Epoch duration =0.19s
# Cumulative duration =36.69s
#
# 180
# Epoch duration =0.18s
# Cumulative duration =36.88s
#
# 181
# Epoch duration =0.2s
# Cumulative duration =37.07s
#
# 182
# Epoch duration =0.19s
# Cumulative duration =37.26s
#
# 183
# Epoch duration =0.19s
# Cumulative duration =37.45s
#
# 184
# Epoch duration =0.19s
# Cumulative duration =37.64s
#
# 185
# Epoch duration =0.19s
# Cumulative duration =37.83s
#
# 186
# Epoch duration =0.18s
# Cumulative duration =38.02s
#
# 187
# Epoch duration =0.2s
# Cumulative duration =38.21s
#
# 188
# Epoch duration =0.19s
# Cumulative duration =38.4s
#
# 189
# Epoch duration =0.2s
# Cumulative duration =38.6s
#
# 190
# Epoch duration =0.19s
# Cumulative duration =38.79s
#
# 191
# Epoch duration =0.19s
# Cumulative duration =38.98s
#
# 192
# Epoch duration =0.19s
# Cumulative duration =39.17s
#
# 193
# Epoch duration =0.2s
# Cumulative duration =39.38s
#
# 194
# Epoch duration =0.19s
# Cumulative duration =39.57s
#
# 195
# Epoch duration =0.2s
# Cumulative duration =39.76s
#
# 196
# Epoch duration =0.19s
# Cumulative duration =39.95s
#
# 197
# Epoch duration =0.22s
# Cumulative duration =40.17s
#
# 198
# Epoch duration =0.2s
# Cumulative duration =40.37s
#
# 199
# Epoch duration =0.21s
# Cumulative duration =40.58s
#
# 200
# Epoch duration =0.21s
# Cumulative duration =40.79s
#
# 201
# Epoch duration =0.22s
# Cumulative duration =41.0s
#
# 202
# Epoch duration =0.2s
# Cumulative duration =41.2s
#
# 203
# Epoch duration =0.2s
# Cumulative duration =41.4s
#
# 204
# Epoch duration =0.19s
# Cumulative duration =41.6s
#
# 205
# Epoch duration =0.19s
# Cumulative duration =41.79s
#
# 206
# Epoch duration =0.2s
# Cumulative duration =41.99s
#
# 207
# Epoch duration =0.29s
# Cumulative duration =42.28s
#
# 208
# Epoch duration =0.23s
# Cumulative duration =42.51s
#
# 209
# Epoch duration =0.22s
# Cumulative duration =42.73s
#
# 210
# Epoch duration =0.2s
# Cumulative duration =42.93s
#
# 211
# Epoch duration =0.22s
# Cumulative duration =43.15s
#
# 212
# Epoch duration =0.19s
# Cumulative duration =43.34s
#
# 213
# Epoch duration =0.19s
# Cumulative duration =43.54s
#
# 214
# Epoch duration =0.2s
# Cumulative duration =43.74s
#
# 215
# Epoch duration =0.2s
# Cumulative duration =43.94s
#
# 216
# Epoch duration =0.19s
# Cumulative duration =44.14s
#
# 217
# Epoch duration =0.2s
# Cumulative duration =44.34s
#
# 218
# Epoch duration =0.19s
# Cumulative duration =44.53s
#
# 219
# Epoch duration =0.2s
# Cumulative duration =44.72s
#
# 220
# Epoch duration =0.18s
# Cumulative duration =44.91s
#
# 221
# Epoch duration =0.2s
# Cumulative duration =45.11s
#
# 222
# Epoch duration =0.22s
# Cumulative duration =45.32s
#
# 223
# Epoch duration =0.21s
# Cumulative duration =45.54s
#
# 224
# Epoch duration =0.2s
# Cumulative duration =45.73s
#
# 225
# Epoch duration =0.21s
# Cumulative duration =45.94s
#
# 226
# Epoch duration =0.2s
# Cumulative duration =46.14s
#
# 227
# Epoch duration =0.2s
# Cumulative duration =46.34s
#
# 228
# Epoch duration =0.19s
# Cumulative duration =46.53s
#
# 229
# Epoch duration =0.2s
# Cumulative duration =46.73s
#
# 230
# Epoch duration =0.19s
# Cumulative duration =46.92s
#
# 231
# Epoch duration =0.2s
# Cumulative duration =47.11s
#
# 232
# Epoch duration =0.2s
# Cumulative duration =47.31s
#
# 233
# Epoch duration =0.21s
# Cumulative duration =47.52s
#
# 234
# Epoch duration =0.19s
# Cumulative duration =47.71s
#
# 235
# Epoch duration =0.19s
# Cumulative duration =47.91s
#
# 236
# Epoch duration =0.23s
# Cumulative duration =48.14s
#
# 237
# Epoch duration =0.19s
# Cumulative duration =48.33s
#
# 238
# Epoch duration =0.19s
# Cumulative duration =48.53s
#
# 239
# Epoch duration =0.19s
# Cumulative duration =48.72s
#
# 240
# Epoch duration =0.24s
# Cumulative duration =48.97s
#
# 241
# Epoch duration =0.24s
# Cumulative duration =49.21s
#
# 242
# Epoch duration =0.22s
# Cumulative duration =49.43s
#
# 243
# Epoch duration =0.27s
# Cumulative duration =49.7s
#
# 244
# Epoch duration =0.24s
# Cumulative duration =49.94s
#
# 245
# Epoch duration =0.2s
# Cumulative duration =50.14s
#
# 246
# Epoch duration =0.2s
# Cumulative duration =50.34s
#
# 247
# Epoch duration =0.22s
# Cumulative duration =50.56s
#
# 248
# Epoch duration =0.29s
# Cumulative duration =50.85s
#
# 249
# Epoch duration =0.22s
# Cumulative duration =51.07s
#
# 250
# Epoch duration =0.19s
# Cumulative duration =51.26s
#
# 251
# Epoch duration =0.26s
# Cumulative duration =51.52s
#
# 252
# Epoch duration =0.22s
# Cumulative duration =51.74s
#
# 253
# Epoch duration =0.2s
# Cumulative duration =51.94s
#
# 254
# Epoch duration =0.2s
# Cumulative duration =52.14s
#
# 255
# Epoch duration =0.2s
# Cumulative duration =52.34s
#
# 256
# Epoch duration =0.2s
# Cumulative duration =52.55s
#
# 257
# Epoch duration =0.21s
# Cumulative duration =52.76s
#
# 258
# Epoch duration =0.2s
# Cumulative duration =52.96s
#
# 259
# Epoch duration =0.21s
# Cumulative duration =53.17s
#
# 260
# Epoch duration =0.19s
# Cumulative duration =53.36s
#
# 261
# Epoch duration =0.31s
# Cumulative duration =53.67s
#
# 262
# Epoch duration =0.21s
# Cumulative duration =53.88s
#
# 263
# Epoch duration =0.19s
# Cumulative duration =54.07s
#
# 264
# Epoch duration =0.21s
# Cumulative duration =54.28s
#
# 265
# Epoch duration =0.29s
# Cumulative duration =54.57s
#
# 266
# Epoch duration =0.28s
# Cumulative duration =54.85s
#
# 267
# Epoch duration =0.21s
# Cumulative duration =55.06s
#
# 268
# Epoch duration =0.31s
# Cumulative duration =55.38s
#
# 269
# Epoch duration =0.27s
# Cumulative duration =55.65s
#
# 270
# Epoch duration =0.19s
# Cumulative duration =55.85s
#
# 271
# Epoch duration =0.27s
# Cumulative duration =56.11s
#
# 272
# Epoch duration =0.23s
# Cumulative duration =56.34s
#
# 273
# Epoch duration =0.22s
# Cumulative duration =56.56s
#
# 274
# Epoch duration =0.22s
# Cumulative duration =56.78s
#
# 275
# Epoch duration =0.2s
# Cumulative duration =56.99s
#
# 276
# Epoch duration =0.23s
# Cumulative duration =57.22s
#
# 277
# Epoch duration =0.2s
# Cumulative duration =57.41s
#
# 278
# Epoch duration =0.21s
# Cumulative duration =57.62s
#
# 279
# Epoch duration =0.2s
# Cumulative duration =57.83s
#
# 280
# Epoch duration =0.19s
# Cumulative duration =58.02s
#
# 281
# Epoch duration =0.2s
# Cumulative duration =58.22s
#
# 282
# Epoch duration =0.2s
# Cumulative duration =58.41s
#
# 283
# Epoch duration =0.19s
# Cumulative duration =58.6s
#
# 284
# Epoch duration =0.19s
# Cumulative duration =58.79s
#
# 285
# Epoch duration =0.2s
# Cumulative duration =58.99s
#
# 286
# Epoch duration =0.2s
# Cumulative duration =59.19s
#
# 287
# Epoch duration =0.2s
# Cumulative duration =59.38s
#
# 288
# Epoch duration =0.21s
# Cumulative duration =59.59s
#
# 289
# Epoch duration =0.2s
# Cumulative duration =59.78s
#
# 290
# Epoch duration =0.19s
# Cumulative duration =59.98s
#
# 291
# Epoch duration =0.19s
# Cumulative duration =60.17s
#
# 292
# Epoch duration =0.19s
# Cumulative duration =60.36s
#
# 293
# Epoch duration =0.26s
# Cumulative duration =60.62s
#
# 294
# Epoch duration =0.19s
# Cumulative duration =60.81s
#
# 295
# Epoch duration =0.27s
# Cumulative duration =61.08s
#
# 296
# Epoch duration =0.28s
# Cumulative duration =61.36s
#
# 297
# Epoch duration =0.2s
# Cumulative duration =61.56s
#
# 298
# Epoch duration =0.2s
# Cumulative duration =61.76s
#
# 299
# Epoch duration =0.19s
# Cumulative duration =61.95s
#
# 300
# Epoch duration =0.2s
# Cumulative duration =62.15s
#
# 301
# Epoch duration =0.26s
# Cumulative duration =62.4s
#
# 302
# Epoch duration =0.32s
# Cumulative duration =62.72s
#
# 303
# Epoch duration =0.21s
# Cumulative duration =62.93s
#
# 304
# Epoch duration =0.19s
# Cumulative duration =63.12s
#
# 305
# Epoch duration =0.19s
# Cumulative duration =63.31s
#
# 306
# Epoch duration =0.19s
# Cumulative duration =63.51s
#
# 307
# Epoch duration =0.2s
# Cumulative duration =63.71s
#
# 308
# Epoch duration =0.2s
# Cumulative duration =63.9s
#
# 309
# Epoch duration =0.26s
# Cumulative duration =64.16s
#
# 310
# Epoch duration =0.19s
# Cumulative duration =64.36s
#
# 311
# Epoch duration =0.2s
# Cumulative duration =64.56s
#
# 312
# Epoch duration =0.19s
# Cumulative duration =64.75s
#
# 313
# Epoch duration =0.19s
# Cumulative duration =64.94s
#
# 314
# Epoch duration =0.21s
# Cumulative duration =65.15s
#
# 315
# Epoch duration =0.19s
# Cumulative duration =65.34s
#
# 316
# Epoch duration =0.19s
# Cumulative duration =65.53s
#
# 317
# Epoch duration =0.19s
# Cumulative duration =65.72s
#
# 318
# Epoch duration =0.2s
# Cumulative duration =65.93s
#
# 319
# Epoch duration =0.19s
# Cumulative duration =66.12s
#
# 320
# Epoch duration =0.19s
# Cumulative duration =66.32s
#
# 321
# Epoch duration =0.22s
# Cumulative duration =66.54s
#
# 322
# Epoch duration =0.27s
# Cumulative duration =66.81s
#
# 323
# Epoch duration =0.19s
# Cumulative duration =67.0s
#
# 324
# Epoch duration =0.21s
# Cumulative duration =67.21s
#
# 325
# Epoch duration =0.2s
# Cumulative duration =67.41s
#
# 326
# Epoch duration =0.2s
# Cumulative duration =67.61s
#
# 327
# Epoch duration =0.19s
# Cumulative duration =67.8s
#
# 328
# Epoch duration =0.19s
# Cumulative duration =67.99s
#
# 329
# Epoch duration =0.19s
# Cumulative duration =68.18s
#
# 330
# Epoch duration =0.19s
# Cumulative duration =68.37s
#
# 331
# Epoch duration =0.34s
# Cumulative duration =68.71s
#
# 332
# Epoch duration =0.31s
# Cumulative duration =69.02s
#
# 333
# Epoch duration =0.33s
# Cumulative duration =69.35s
#
# 334
# Epoch duration =0.19s
# Cumulative duration =69.54s
#
# 335
# Epoch duration =0.19s
# Cumulative duration =69.74s
#
# 336
# Epoch duration =0.19s
# Cumulative duration =69.93s
#
# 337
# Epoch duration =0.2s
# Cumulative duration =70.13s
#
# 338
# Epoch duration =0.19s
# Cumulative duration =70.33s
#
# 339
# Epoch duration =0.21s
# Cumulative duration =70.54s
#
# 340
# Epoch duration =0.19s
# Cumulative duration =70.72s
#
# 341
# Epoch duration =0.2s
# Cumulative duration =70.92s
#
# 342
# Epoch duration =0.2s
# Cumulative duration =71.12s
#
# 343
# Epoch duration =0.2s
# Cumulative duration =71.31s
#
# 344
# Epoch duration =0.19s
# Cumulative duration =71.5s
#
# 345
# Epoch duration =0.19s
# Cumulative duration =71.7s
#
# 346
# Epoch duration =0.19s
# Cumulative duration =71.88s
#
# 347
# Epoch duration =0.19s
# Cumulative duration =72.08s
#
# 348
# Epoch duration =0.2s
# Cumulative duration =72.27s
#
# 349
# Epoch duration =0.2s
# Cumulative duration =72.47s
#
# 350
# Epoch duration =0.19s
# Cumulative duration =72.66s
#
# 351
# Epoch duration =0.19s
# Cumulative duration =72.85s
#
# 352
# Epoch duration =0.19s
# Cumulative duration =73.04s
#
# 353
# Epoch duration =0.19s
# Cumulative duration =73.23s
#
# 354
# Epoch duration =0.19s
# Cumulative duration =73.42s
#
# 355
# Epoch duration =0.19s
# Cumulative duration =73.62s
#
# 356
# Epoch duration =0.19s
# Cumulative duration =73.81s
#
# 357
# Epoch duration =0.19s
# Cumulative duration =74.0s
#
# 358
# Epoch duration =0.19s
# Cumulative duration =74.19s
#
# 359
# Epoch duration =0.19s
# Cumulative duration =74.38s
#
# 360
# Epoch duration =0.19s
# Cumulative duration =74.57s
#
# 361
# Epoch duration =0.19s
# Cumulative duration =74.76s
#
# 362
# Epoch duration =0.19s
# Cumulative duration =74.95s
#
# 363
# Epoch duration =0.19s
# Cumulative duration =75.14s
#
# 364
# Epoch duration =0.19s
# Cumulative duration =75.33s
#
# 365
# Epoch duration =0.19s
# Cumulative duration =75.52s
#
# 366
# Epoch duration =0.19s
# Cumulative duration =75.71s
#
# 367
# Epoch duration =0.2s
# Cumulative duration =75.91s
#
# 368
# Epoch duration =0.19s
# Cumulative duration =76.1s
#
# 369
# Epoch duration =0.2s
# Cumulative duration =76.29s
#
# 370
# Epoch duration =0.19s
# Cumulative duration =76.48s
#
# 371
# Epoch duration =0.2s
# Cumulative duration =76.68s
#
# 372
# Epoch duration =0.19s
# Cumulative duration =76.87s
#
# 373
# Epoch duration =0.2s
# Cumulative duration =77.07s
#
# 374
# Epoch duration =0.19s
# Cumulative duration =77.27s
#
# 375
# Epoch duration =0.19s
# Cumulative duration =77.46s
#
# 376
# Epoch duration =0.19s
# Cumulative duration =77.65s
#
# 377
# Epoch duration =0.22s
# Cumulative duration =77.87s
#
# 378
# Epoch duration =0.2s
# Cumulative duration =78.07s
#
# 379
# Epoch duration =0.19s
# Cumulative duration =78.26s
#
# 380
# Epoch duration =0.19s
# Cumulative duration =78.46s
#
# 381
# Epoch duration =0.22s
# Cumulative duration =78.67s
#
# 382
# Epoch duration =0.2s
# Cumulative duration =78.87s
#
# 383
# Epoch duration =0.19s
# Cumulative duration =79.06s
#
# 384
# Epoch duration =0.2s
# Cumulative duration =79.26s
#
# 385
# Epoch duration =0.19s
# Cumulative duration =79.45s
#
# 386
# Epoch duration =0.21s
# Cumulative duration =79.66s
#
# 387
# Epoch duration =0.19s
# Cumulative duration =79.85s
#
# 388
# Epoch duration =0.2s
# Cumulative duration =80.05s
#
# 389
# Epoch duration =0.21s
# Cumulative duration =80.26s
#
# 390
# Epoch duration =0.19s
# Cumulative duration =80.45s
#
# 391
# Epoch duration =0.2s
# Cumulative duration =80.65s
#
# 392
# Epoch duration =0.24s
# Cumulative duration =80.89s
#
# 393
# Epoch duration =0.19s
# Cumulative duration =81.08s
#
# 394
# Epoch duration =0.2s
# Cumulative duration =81.28s
#
# 395
# Epoch duration =0.21s
# Cumulative duration =81.49s
#
# 396
# Epoch duration =0.2s
# Cumulative duration =81.68s
#
# 397
# Epoch duration =0.2s
# Cumulative duration =81.89s
#
# 398
# Epoch duration =0.2s
# Cumulative duration =82.08s
#
# 399
# Epoch duration =0.19s
# Cumulative duration =82.28s
#
# 400
# Epoch duration =0.21s
# Cumulative duration =82.49s
#
# 401
# Epoch duration =0.3s
# Cumulative duration =82.79s
#
# 402
# Epoch duration =0.19s
# Cumulative duration =82.98s
#
# 403
# Epoch duration =0.23s
# Cumulative duration =83.21s
#
# 404
# Epoch duration =0.19s
# Cumulative duration =83.4s
#
# 405
# Epoch duration =0.2s
# Cumulative duration =83.6s
#
# 406
# Epoch duration =0.19s
# Cumulative duration =83.79s
#
# 407
# Epoch duration =0.19s
# Cumulative duration =83.98s
#
# 408
# Epoch duration =0.24s
# Cumulative duration =84.22s
#
# 409
# Epoch duration =0.23s
# Cumulative duration =84.45s
#
# 410
# Epoch duration =0.19s
# Cumulative duration =84.64s
#
# 411
# Epoch duration =0.19s
# Cumulative duration =84.83s
#
# 412
# Epoch duration =0.19s
# Cumulative duration =85.02s
#
# 413
# Epoch duration =0.19s
# Cumulative duration =85.22s
#
# 414
# Epoch duration =0.19s
# Cumulative duration =85.41s
#
# 415
# Epoch duration =0.24s
# Cumulative duration =85.64s
#
# 416
# Epoch duration =0.19s
# Cumulative duration =85.83s
#
# 417
# Epoch duration =0.22s
# Cumulative duration =86.05s
#
# 418
# Epoch duration =0.22s
# Cumulative duration =86.28s
#
# 419
# Epoch duration =0.23s
# Cumulative duration =86.5s
#
# 420
# Epoch duration =0.22s
# Cumulative duration =86.72s
#
# 421
# Epoch duration =0.24s
# Cumulative duration =86.96s
#
# 422
# Epoch duration =0.19s
# Cumulative duration =87.16s
#
# 423
# Epoch duration =0.22s
# Cumulative duration =87.37s
#
# 424
# Epoch duration =0.23s
# Cumulative duration =87.6s
#
# 425
# Epoch duration =0.21s
# Cumulative duration =87.81s
#
# 426
# Epoch duration =0.23s
# Cumulative duration =88.04s
#
# 427
# Epoch duration =0.24s
# Cumulative duration =88.28s
#
# 428
# Epoch duration =0.22s
# Cumulative duration =88.5s
#
# 429
# Epoch duration =0.29s
# Cumulative duration =88.79s
#
# 430
# Epoch duration =0.23s
# Cumulative duration =89.02s
#
# 431
# Epoch duration =0.25s
# Cumulative duration =89.27s
#
# 432
# Epoch duration =0.25s
# Cumulative duration =89.52s
#
# 433
# Epoch duration =0.21s
# Cumulative duration =89.73s
#
# 434
# Epoch duration =0.26s
# Cumulative duration =89.99s
#
# 435
# Epoch duration =0.25s
# Cumulative duration =90.24s
#
# 436
# Epoch duration =0.28s
# Cumulative duration =90.52s
#
# 437
# Epoch duration =0.32s
# Cumulative duration =90.83s
#
# 438
# Epoch duration =0.23s
# Cumulative duration =91.07s
#
# 439
# Epoch duration =0.28s
# Cumulative duration =91.35s
#
# 440
# Epoch duration =0.28s
# Cumulative duration =91.63s
#
# 441
# Epoch duration =0.23s
# Cumulative duration =91.86s
#
# 442
# Epoch duration =0.26s
# Cumulative duration =92.12s
#
# 443
# Epoch duration =0.25s
# Cumulative duration =92.38s
#
# 444
# Epoch duration =0.26s
# Cumulative duration =92.63s
#
# 445
# Epoch duration =0.23s
# Cumulative duration =92.86s
#
# 446
# Epoch duration =0.28s
# Cumulative duration =93.14s
#
# 447
# Epoch duration =0.24s
# Cumulative duration =93.38s
#
# 448
# Epoch duration =0.27s
# Cumulative duration =93.65s
#
# 449
# Epoch duration =0.24s
# Cumulative duration =93.89s
#
# 450
# Epoch duration =0.26s
# Cumulative duration =94.15s
#
# 451
# Epoch duration =0.22s
# Cumulative duration =94.37s
#
# 452
# Epoch duration =0.23s
# Cumulative duration =94.6s
#
# 453
# Epoch duration =0.21s
# Cumulative duration =94.81s
#
# 454
# Epoch duration =0.19s
# Cumulative duration =95.0s
#
# 455
# Epoch duration =0.21s
# Cumulative duration =95.21s
#
# 456
# Epoch duration =0.19s
# Cumulative duration =95.4s
#
# 457
# Epoch duration =0.2s
# Cumulative duration =95.6s
#
# 458
# Epoch duration =0.19s
# Cumulative duration =95.8s
#
# 459
# Epoch duration =0.19s
# Cumulative duration =95.99s
#
# 460
# Epoch duration =0.2s
# Cumulative duration =96.19s
#
# 461
# Epoch duration =0.2s
# Cumulative duration =96.39s
#
# 462
# Epoch duration =0.2s
# Cumulative duration =96.58s
#
# 463
# Epoch duration =0.19s
# Cumulative duration =96.77s
#
# 464
# Epoch duration =0.19s
# Cumulative duration =96.97s
#
# 465
# Epoch duration =0.2s
# Cumulative duration =97.17s
#
# 466
# Epoch duration =0.19s
# Cumulative duration =97.36s
#
# 467
# Epoch duration =0.2s
# Cumulative duration =97.56s
#
# 468
# Epoch duration =0.2s
# Cumulative duration =97.76s
#
# 469
# Epoch duration =0.2s
# Cumulative duration =97.95s
#
# 470
# Epoch duration =0.19s
# Cumulative duration =98.15s
#
# 471
# Epoch duration =0.2s
# Cumulative duration =98.35s
#
# 472
# Epoch duration =0.19s
# Cumulative duration =98.54s
#
# 473
# Epoch duration =0.2s
# Cumulative duration =98.74s
#
# 474
# Epoch duration =0.22s
# Cumulative duration =98.96s
#
# 475
# Epoch duration =0.2s
# Cumulative duration =99.15s
#
# 476
# Epoch duration =0.2s
# Cumulative duration =99.35s
#
# 477
# Epoch duration =0.19s
# Cumulative duration =99.54s
#
# 478
# Epoch duration =0.2s
# Cumulative duration =99.74s
#
# 479
# Epoch duration =0.31s
# Cumulative duration =100.05s
#
# 480
# Epoch duration =0.24s
# Cumulative duration =100.29s
#
# 481
# Epoch duration =0.21s
# Cumulative duration =100.5s
#
# 482
# Epoch duration =0.2s
# Cumulative duration =100.69s
#
# 483
# Epoch duration =0.2s
# Cumulative duration =100.9s
#
# 484
# Epoch duration =0.2s
# Cumulative duration =101.09s
#
# 485
# Epoch duration =0.19s
# Cumulative duration =101.28s
#
# 486
# Epoch duration =0.19s
# Cumulative duration =101.47s
#
# 487
# Epoch duration =0.21s
# Cumulative duration =101.68s
#
# 488
# Epoch duration =0.19s
# Cumulative duration =101.87s
#
# 489
# Epoch duration =0.19s
# Cumulative duration =102.06s
#
# 490
# Epoch duration =0.19s
# Cumulative duration =102.25s
#
# 491
# Epoch duration =0.19s
# Cumulative duration =102.44s
#
# 492
# Epoch duration =0.19s
# Cumulative duration =102.63s
#
# 493
# Epoch duration =0.19s
# Cumulative duration =102.82s
#
# 494
# Epoch duration =0.19s
# Cumulative duration =103.01s
#
# 495
# Epoch duration =0.19s
# Cumulative duration =103.2s
#
# 496
# Epoch duration =0.19s
# Cumulative duration =103.39s
#
# 497
# Epoch duration =0.2s
# Cumulative duration =103.59s
#
# 498
# Epoch duration =0.2s
# Cumulative duration =103.79s
#
# 499
# Epoch duration =0.2s
# Cumulative duration =103.98s
#
# 500
# Epoch duration =0.19s
# Cumulative duration =104.18s
#
# 501
# Epoch duration =0.19s
# Cumulative duration =104.37s
#
# 502
# Epoch duration =0.19s
# Cumulative duration =104.56s
#
# 503
# Epoch duration =0.21s
# Cumulative duration =104.76s
#
# 504
# Epoch duration =0.19s
# Cumulative duration =104.95s
#
# 505
# Epoch duration =0.2s
# Cumulative duration =105.15s
#
# 506
# Epoch duration =0.19s
# Cumulative duration =105.34s
#
# 507
# Epoch duration =0.2s
# Cumulative duration =105.54s
#
# 508
# Epoch duration =0.3s
# Cumulative duration =105.84s
#
# 509
# Epoch duration =0.28s
# Cumulative duration =106.12s
#
# 510
# Epoch duration =0.23s
# Cumulative duration =106.35s
#
# 511
# Epoch duration =0.19s
# Cumulative duration =106.54s
#
# 512
# Epoch duration =0.2s
# Cumulative duration =106.75s
#
# 513
# Epoch duration =0.29s
# Cumulative duration =107.03s
#
# 514
# Epoch duration =0.22s
# Cumulative duration =107.26s
#
# 515
# Epoch duration =0.2s
# Cumulative duration =107.45s
#
# 516
# Epoch duration =0.21s
# Cumulative duration =107.66s
#
# 517
# Epoch duration =0.21s
# Cumulative duration =107.87s
#
# 518
# Epoch duration =0.19s
# Cumulative duration =108.07s
#
# 519
# Epoch duration =0.22s
# Cumulative duration =108.28s
#
# 520
# Epoch duration =0.2s
# Cumulative duration =108.48s
#
# 521
# Epoch duration =0.2s
# Cumulative duration =108.67s
#
# 522
# Epoch duration =0.19s
# Cumulative duration =108.87s
#
# 523
# Epoch duration =0.2s
# Cumulative duration =109.06s
#
# 524
# Epoch duration =0.2s
# Cumulative duration =109.26s
#
# 525
# Epoch duration =0.19s
# Cumulative duration =109.46s
#
# 526
# Epoch duration =0.21s
# Cumulative duration =109.66s
#
# 527
# Epoch duration =0.21s
# Cumulative duration =109.87s
#
# 528
# Epoch duration =0.19s
# Cumulative duration =110.07s
#
# 529
# Epoch duration =0.22s
# Cumulative duration =110.29s
#
# 530
# Epoch duration =0.19s
# Cumulative duration =110.47s
#
# 531
# Epoch duration =0.19s
# Cumulative duration =110.67s
#
# 532
# Epoch duration =0.2s
# Cumulative duration =110.86s
#
# 533
# Epoch duration =0.21s
# Cumulative duration =111.08s
#
# 534
# Epoch duration =0.21s
# Cumulative duration =111.29s
#
# 535
# Epoch duration =0.21s
# Cumulative duration =111.5s
#
# 536
# Epoch duration =0.19s
# Cumulative duration =111.69s
#
# 537
# Epoch duration =0.2s
# Cumulative duration =111.89s
#
# 538
# Epoch duration =0.21s
# Cumulative duration =112.1s
#
# 539
# Epoch duration =0.2s
# Cumulative duration =112.29s
#
# 540
# Epoch duration =0.22s
# Cumulative duration =112.51s
#
# 541
# Epoch duration =0.2s
# Cumulative duration =112.71s
#
# 542
# Epoch duration =0.2s
# Cumulative duration =112.91s
#
# 543
# Epoch duration =0.2s
# Cumulative duration =113.11s
#
# 544
# Epoch duration =0.2s
# Cumulative duration =113.31s
#
# 545
# Epoch duration =0.21s
# Cumulative duration =113.51s
#
# 546
# Epoch duration =0.21s
# Cumulative duration =113.72s
#
# 547
# Epoch duration =0.19s
# Cumulative duration =113.91s
#
# 548
# Epoch duration =0.2s
# Cumulative duration =114.11s
#
# 549
# Epoch duration =0.21s
# Cumulative duration =114.32s
#
# 550
# Epoch duration =0.19s
# Cumulative duration =114.51s
#
# 551
# Epoch duration =0.19s
# Cumulative duration =114.7s
#
# 552
# Epoch duration =0.19s
# Cumulative duration =114.89s
#
# 553
# Epoch duration =0.19s
# Cumulative duration =115.08s
#
# 554
# Epoch duration =0.19s
# Cumulative duration =115.27s
#
# 555
# Epoch duration =0.19s
# Cumulative duration =115.46s
#
# 556
# Epoch duration =0.19s
# Cumulative duration =115.66s
#
# 557
# Epoch duration =0.21s
# Cumulative duration =115.87s
#
# 558
# Epoch duration =0.2s
# Cumulative duration =116.06s
#
# 559
# Epoch duration =0.19s
# Cumulative duration =116.25s
#
# 560
# Epoch duration =0.19s
# Cumulative duration =116.44s
#
# 561
# Epoch duration =0.19s
# Cumulative duration =116.64s
#
# 562
# Epoch duration =0.2s
# Cumulative duration =116.84s
#
# 563
# Epoch duration =0.2s
# Cumulative duration =117.04s
#
# 564
# Epoch duration =0.19s
# Cumulative duration =117.23s
#
# 565
# Epoch duration =0.2s
# Cumulative duration =117.43s
#
# 566
# Epoch duration =0.19s
# Cumulative duration =117.62s
#
# 567
# Epoch duration =0.19s
# Cumulative duration =117.81s
#
# 568
# Epoch duration =0.19s
# Cumulative duration =118.01s
#
# 569
# Epoch duration =0.19s
# Cumulative duration =118.2s
#
# 570
# Epoch duration =0.19s
# Cumulative duration =118.39s
#
# 571
# Epoch duration =0.19s
# Cumulative duration =118.58s
#
# 572
# Epoch duration =0.19s
# Cumulative duration =118.77s
#
# 573
# Epoch duration =0.19s
# Cumulative duration =118.96s
#
# 574
# Epoch duration =0.19s
# Cumulative duration =119.15s
#
# 575
# Epoch duration =0.19s
# Cumulative duration =119.34s
#
# 576
# Epoch duration =0.19s
# Cumulative duration =119.53s
#
# 577
# Epoch duration =0.19s
# Cumulative duration =119.72s
#
# 578
# Epoch duration =0.19s
# Cumulative duration =119.9s
#
# 579
# Epoch duration =0.21s
# Cumulative duration =120.11s
#
# 580
# Epoch duration =0.19s
# Cumulative duration =120.31s
#
# 581
# Epoch duration =0.19s
# Cumulative duration =120.5s
#
# 582
# Epoch duration =0.19s
# Cumulative duration =120.69s
#
# 583
# Epoch duration =0.2s
# Cumulative duration =120.89s
#
# 584
# Epoch duration =0.19s
# Cumulative duration =121.07s
#
# 585
# Epoch duration =0.19s
# Cumulative duration =121.26s
#
# 586
# Epoch duration =0.2s
# Cumulative duration =121.47s
#
# 587
# Epoch duration =0.19s
# Cumulative duration =121.66s
#
# 588
# Epoch duration =0.2s
# Cumulative duration =121.86s
#
# 589
# Epoch duration =0.2s
# Cumulative duration =122.06s
#
# 590
# Epoch duration =0.2s
# Cumulative duration =122.26s
#
# 591
# Epoch duration =0.2s
# Cumulative duration =122.46s
#
# 592
# Epoch duration =0.2s
# Cumulative duration =122.65s
#
# 593
# Epoch duration =0.2s
# Cumulative duration =122.85s
#
# 594
# Epoch duration =0.2s
# Cumulative duration =123.05s
#
# 595
# Epoch duration =0.19s
# Cumulative duration =123.25s
#
# 596
# Epoch duration =0.21s
# Cumulative duration =123.45s
#
# 597
# Epoch duration =0.2s
# Cumulative duration =123.65s
#
# 598
# Epoch duration =0.2s
# Cumulative duration =123.86s
#
# 599
# Epoch duration =0.19s
# Cumulative duration =124.04s
#
# 600
# Epoch duration =0.25s
# Cumulative duration =124.29s
#
# 601
# Epoch duration =0.21s
# Cumulative duration =124.5s
#
# 602
# Epoch duration =0.19s
# Cumulative duration =124.7s
#
# 603
# Epoch duration =0.2s
# Cumulative duration =124.9s
#
# 604
# Epoch duration =0.2s
# Cumulative duration =125.1s
#
# 605
# Epoch duration =0.2s
# Cumulative duration =125.3s
#
# 606
# Epoch duration =0.19s
# Cumulative duration =125.49s
#
# 607
# Epoch duration =0.19s
# Cumulative duration =125.68s
#
# 608
# Epoch duration =0.2s
# Cumulative duration =125.88s
#
# 609
# Epoch duration =0.2s
# Cumulative duration =126.07s
#
# 610
# Epoch duration =0.19s
# Cumulative duration =126.26s
#
# 611
# Epoch duration =0.21s
# Cumulative duration =126.47s
#
# 612
# Epoch duration =0.21s
# Cumulative duration =126.68s
#
# 613
# Epoch duration =0.2s
# Cumulative duration =126.88s
#
# 614
# Epoch duration =0.19s
# Cumulative duration =127.08s
#
# 615
# Epoch duration =0.2s
# Cumulative duration =127.27s
#
# 616
# Epoch duration =0.19s
# Cumulative duration =127.46s
#
# 617
# Epoch duration =0.2s
# Cumulative duration =127.66s
#
# 618
# Epoch duration =0.2s
# Cumulative duration =127.86s
#
# 619
# Epoch duration =0.2s
# Cumulative duration =128.05s
#
# 620
# Epoch duration =0.19s
# Cumulative duration =128.25s
#
# 621
# Epoch duration =0.19s
# Cumulative duration =128.44s
#
# 622
# Epoch duration =0.19s
# Cumulative duration =128.63s
#
# 623
# Epoch duration =0.2s
# Cumulative duration =128.83s
#
# 624
# Epoch duration =0.19s
# Cumulative duration =129.02s
#
# 625
# Epoch duration =0.21s
# Cumulative duration =129.23s
#
# 626
# Epoch duration =0.19s
# Cumulative duration =129.42s
#
# 627
# Epoch duration =0.2s
# Cumulative duration =129.62s
#
# 628
# Epoch duration =0.19s
# Cumulative duration =129.81s
#
# 629
# Epoch duration =0.19s
# Cumulative duration =130.0s
#
# 630
# Epoch duration =0.19s
# Cumulative duration =130.19s
#
# 631
# Epoch duration =0.2s
# Cumulative duration =130.39s
#
# 632
# Epoch duration =0.19s
# Cumulative duration =130.58s
#
# 633
# Epoch duration =0.2s
# Cumulative duration =130.78s
#
# 634
# Epoch duration =0.19s
# Cumulative duration =130.96s
#
# 635
# Epoch duration =0.19s
# Cumulative duration =131.15s
#
# 636
# Epoch duration =0.2s
# Cumulative duration =131.35s
#
# 637
# Epoch duration =0.21s
# Cumulative duration =131.56s
#
# 638
# Epoch duration =0.19s
# Cumulative duration =131.76s
#
# 639
# Epoch duration =0.19s
# Cumulative duration =131.95s
#
# 640
# Epoch duration =0.19s
# Cumulative duration =132.13s
#
# 641
# Epoch duration =0.2s
# Cumulative duration =132.33s
#
# 642
# Epoch duration =0.2s
# Cumulative duration =132.53s
#
# 643
# Epoch duration =0.19s
# Cumulative duration =132.72s
#
# 644
# Epoch duration =0.19s
# Cumulative duration =132.92s
#
# 645
# Epoch duration =0.19s
# Cumulative duration =133.11s
#
# 646
# Epoch duration =0.22s
# Cumulative duration =133.32s
#
# 647
# Epoch duration =0.19s
# Cumulative duration =133.51s
#
# 648
# Epoch duration =0.19s
# Cumulative duration =133.7s
#
# 649
# Epoch duration =0.19s
# Cumulative duration =133.89s
#
# 650
# Epoch duration =0.19s
# Cumulative duration =134.09s
#
# 651
# Epoch duration =0.19s
# Cumulative duration =134.28s
#
# 652
# Epoch duration =0.2s
# Cumulative duration =134.48s
#
# 653
# Epoch duration =0.19s
# Cumulative duration =134.67s
#
# 654
# Epoch duration =0.2s
# Cumulative duration =134.87s
#
# 655
# Epoch duration =0.2s
# Cumulative duration =135.07s
#
# 656
# Epoch duration =0.21s
# Cumulative duration =135.29s
#
# 657
# Epoch duration =0.22s
# Cumulative duration =135.5s
#
# 658
# Epoch duration =0.21s
# Cumulative duration =135.72s
#
# 659
# Epoch duration =0.19s
# Cumulative duration =135.91s
#
# 660
# Epoch duration =0.19s
# Cumulative duration =136.11s
#
# 661
# Epoch duration =0.19s
# Cumulative duration =136.3s
#
# 662
# Epoch duration =0.2s
# Cumulative duration =136.5s
#
# 663
# Epoch duration =0.19s
# Cumulative duration =136.69s
#
# 664
# Epoch duration =0.19s
# Cumulative duration =136.88s
#
# 665
# Epoch duration =0.19s
# Cumulative duration =137.07s
#
# 666
# Epoch duration =0.2s
# Cumulative duration =137.27s
#
# 667
# Epoch duration =0.19s
# Cumulative duration =137.46s
#
# 668
# Epoch duration =0.19s
# Cumulative duration =137.65s
#
# 669
# Epoch duration =0.2s
# Cumulative duration =137.85s
#
# 670
# Epoch duration =0.21s
# Cumulative duration =138.05s
#
# 671
# Epoch duration =0.19s
# Cumulative duration =138.24s
#
# 672
# Epoch duration =0.2s
# Cumulative duration =138.44s
#
# 673
# Epoch duration =0.21s
# Cumulative duration =138.65s
#
# 674
# Epoch duration =0.19s
# Cumulative duration =138.84s
#
# 675
# Epoch duration =0.21s
# Cumulative duration =139.06s
#
# 676
# Epoch duration =0.29s
# Cumulative duration =139.35s
#
# 677
# Epoch duration =0.22s
# Cumulative duration =139.57s
#
# 678
# Epoch duration =0.25s
# Cumulative duration =139.82s
#
# 679
# Epoch duration =0.22s
# Cumulative duration =140.04s
#
# 680
# Epoch duration =0.24s
# Cumulative duration =140.28s
#
# 681
# Epoch duration =0.19s
# Cumulative duration =140.47s
#
# 682
# Epoch duration =0.19s
# Cumulative duration =140.67s
#
# 683
# Epoch duration =0.2s
# Cumulative duration =140.86s
#
# 684
# Epoch duration =0.22s
# Cumulative duration =141.08s
#
# 685
# Epoch duration =0.21s
# Cumulative duration =141.3s
#
# 686
# Epoch duration =0.19s
# Cumulative duration =141.49s
#
# 687
# Epoch duration =0.21s
# Cumulative duration =141.7s
#
# 688
# Epoch duration =0.28s
# Cumulative duration =141.98s
#
# 689
# Epoch duration =0.22s
# Cumulative duration =142.2s
#
# 690
# Epoch duration =0.27s
# Cumulative duration =142.47s
#
# 691
# Epoch duration =0.22s
# Cumulative duration =142.7s
#
# 692
# Epoch duration =0.26s
# Cumulative duration =142.95s
#
# 693
# Epoch duration =0.19s
# Cumulative duration =143.14s
#
# 694
# Epoch duration =0.2s
# Cumulative duration =143.34s
#
# 695
# Epoch duration =0.2s
# Cumulative duration =143.54s
#
# 696
# Epoch duration =0.27s
# Cumulative duration =143.81s
#
# 697
# Epoch duration =0.21s
# Cumulative duration =144.02s
#
# 698
# Epoch duration =0.2s
# Cumulative duration =144.22s
#
# 699
# Epoch duration =0.29s
# Cumulative duration =144.51s
#
# 700
# Epoch duration =0.31s
# Cumulative duration =144.82s
#
# 701
# Epoch duration =0.25s
# Cumulative duration =145.07s
#
# 702
# Epoch duration =0.3s
# Cumulative duration =145.37s
#
# 703
# Epoch duration =0.24s
# Cumulative duration =145.61s
#
# 704
# Epoch duration =0.29s
# Cumulative duration =145.9s
#
# 705
# Epoch duration =0.3s
# Cumulative duration =146.21s
#
# 706
# Epoch duration =0.36s
# Cumulative duration =146.57s
#
# 707
# Epoch duration =0.33s
# Cumulative duration =146.91s
#
# 708
# Epoch duration =0.29s
# Cumulative duration =147.2s
#
# 709
# Epoch duration =0.31s
# Cumulative duration =147.51s
#
# 710
# Epoch duration =0.34s
# Cumulative duration =147.85s
#
# 711
# Epoch duration =0.32s
# Cumulative duration =148.16s
#
# 712
# Epoch duration =0.3s
# Cumulative duration =148.47s
#
# 713
# Epoch duration =0.24s
# Cumulative duration =148.71s
#
# 714
# Epoch duration =0.21s
# Cumulative duration =148.92s
#
# 715
# Epoch duration =0.31s
# Cumulative duration =149.24s
#
# 716
# Epoch duration =0.3s
# Cumulative duration =149.54s
#
# 717
# Epoch duration =0.22s
# Cumulative duration =149.75s
#
# 718
# Epoch duration =0.27s
# Cumulative duration =150.02s
#
# 719
# Epoch duration =0.3s
# Cumulative duration =150.33s
#
# 720
# Epoch duration =0.19s
# Cumulative duration =150.51s
#
# 721
# Epoch duration =0.19s
# Cumulative duration =150.71s
#
# 722
# Epoch duration =0.19s
# Cumulative duration =150.89s
#
# 723
# Epoch duration =0.19s
# Cumulative duration =151.09s
#
# 724
# Epoch duration =0.19s
# Cumulative duration =151.28s
#
# 725
# Epoch duration =0.25s
# Cumulative duration =151.53s
#
# 726
# Epoch duration =0.19s
# Cumulative duration =151.72s
#
# 727
# Epoch duration =0.2s
# Cumulative duration =151.91s
#
# 728
# Epoch duration =0.26s
# Cumulative duration =152.17s
#
# 729
# Epoch duration =0.19s
# Cumulative duration =152.37s
#
# 730
# Epoch duration =0.19s
# Cumulative duration =152.55s
#
# 731
# Epoch duration =0.19s
# Cumulative duration =152.74s
#
# 732
# Epoch duration =0.2s
# Cumulative duration =152.94s
#
# 733
# Epoch duration =0.19s
# Cumulative duration =153.12s
#
# 734
# Epoch duration =0.2s
# Cumulative duration =153.32s
#
# 735
# Epoch duration =0.19s
# Cumulative duration =153.51s
#
# 736
# Epoch duration =0.19s
# Cumulative duration =153.7s
#
# 737
# Epoch duration =0.19s
# Cumulative duration =153.89s
#
# 738
# Epoch duration =0.19s
# Cumulative duration =154.08s
#
# 739
# Epoch duration =0.19s
# Cumulative duration =154.27s
#
# 740
# Epoch duration =0.19s
# Cumulative duration =154.46s
#
# 741
# Epoch duration =0.19s
# Cumulative duration =154.65s
#
# 742
# Epoch duration =0.19s
# Cumulative duration =154.84s
#
# 743
# Epoch duration =0.19s
# Cumulative duration =155.03s
#
# 744
# Epoch duration =0.21s
# Cumulative duration =155.24s
#
# 745
# Epoch duration =0.25s
# Cumulative duration =155.49s
#
# 746
# Epoch duration =0.2s
# Cumulative duration =155.69s
#
# 747
# Epoch duration =0.2s
# Cumulative duration =155.89s
#
# 748
# Epoch duration =0.19s
# Cumulative duration =156.08s
#
# 749
# Epoch duration =0.19s
# Cumulative duration =156.27s
#
# 750
# Epoch duration =0.2s
# Cumulative duration =156.47s
#
# 751
# Epoch duration =0.19s
# Cumulative duration =156.65s
#
# 752
# Epoch duration =0.19s
# Cumulative duration =156.85s
#
# 753
# Epoch duration =0.19s
# Cumulative duration =157.04s
#
# 754
# Epoch duration =0.2s
# Cumulative duration =157.24s
#
# 755
# Epoch duration =0.2s
# Cumulative duration =157.44s
#
# 756
# Epoch duration =0.21s
# Cumulative duration =157.65s
#
# 757
# Epoch duration =0.21s
# Cumulative duration =157.85s
#
# 758
# Epoch duration =0.2s
# Cumulative duration =158.06s
#
# 759
# Epoch duration =0.19s
# Cumulative duration =158.25s
#
# 760
# Epoch duration =0.2s
# Cumulative duration =158.45s
#
# 761
# Epoch duration =0.19s
# Cumulative duration =158.64s
#
# 762
# Epoch duration =0.2s
# Cumulative duration =158.84s
#
# 763
# Epoch duration =0.2s
# Cumulative duration =159.04s
#
# 764
# Epoch duration =0.19s
# Cumulative duration =159.24s
#
# 765
# Epoch duration =0.2s
# Cumulative duration =159.43s
#
# 766
# Epoch duration =0.2s
# Cumulative duration =159.63s
#
# 767
# Epoch duration =0.19s
# Cumulative duration =159.83s
#
# 768
# Epoch duration =0.19s
# Cumulative duration =160.02s
#
# 769
# Epoch duration =0.19s
# Cumulative duration =160.2s
#
# 770
# Epoch duration =0.2s
# Cumulative duration =160.4s
#
# 771
# Epoch duration =0.19s
# Cumulative duration =160.59s
#
# 772
# Epoch duration =0.19s
# Cumulative duration =160.78s
#
# 773
# Epoch duration =0.19s
# Cumulative duration =160.96s
#
# 774
# Epoch duration =0.19s
# Cumulative duration =161.16s
#
# 775
# Epoch duration =0.21s
# Cumulative duration =161.36s
#
# 776
# Epoch duration =0.19s
# Cumulative duration =161.55s
#
# 777
# Epoch duration =0.2s
# Cumulative duration =161.75s
#
# 778
# Epoch duration =0.19s
# Cumulative duration =161.94s
#
# 779
# Epoch duration =0.19s
# Cumulative duration =162.13s
#
# 780
# Epoch duration =0.19s
# Cumulative duration =162.32s
#
# 781
# Epoch duration =0.19s
# Cumulative duration =162.51s
#
# 782
# Epoch duration =0.19s
# Cumulative duration =162.69s
#
# 783
# Epoch duration =0.2s
# Cumulative duration =162.89s
#
# 784
# Epoch duration =0.19s
# Cumulative duration =163.08s
#
# 785
# Epoch duration =0.19s
# Cumulative duration =163.27s
#
# 786
# Epoch duration =0.19s
# Cumulative duration =163.46s
#
# 787
# Epoch duration =0.19s
# Cumulative duration =163.66s
#
# 788
# Epoch duration =0.2s
# Cumulative duration =163.85s
#
# 789
# Epoch duration =0.28s
# Cumulative duration =164.13s
#
# 790
# Epoch duration =0.22s
# Cumulative duration =164.35s
#
# 791
# Epoch duration =0.19s
# Cumulative duration =164.54s
#
# 792
# Epoch duration =0.19s
# Cumulative duration =164.73s
#
# 793
# Epoch duration =0.2s
# Cumulative duration =164.93s
#
# 794
# Epoch duration =0.19s
# Cumulative duration =165.12s
#
# 795
# Epoch duration =0.19s
# Cumulative duration =165.31s
#
# 796
# Epoch duration =0.2s
# Cumulative duration =165.51s
#
# 797
# Epoch duration =0.19s
# Cumulative duration =165.71s
#
# 798
# Epoch duration =0.2s
# Cumulative duration =165.9s
#
# 799
# Epoch duration =0.19s
# Cumulative duration =166.09s
#
# 800
# Epoch duration =0.21s
# Cumulative duration =166.3s
#
# 801
# Epoch duration =0.2s
# Cumulative duration =166.5s
#
# 802
# Epoch duration =0.2s
# Cumulative duration =166.7s
#
# 803
# Epoch duration =0.2s
# Cumulative duration =166.9s
#
# 804
# Epoch duration =0.19s
# Cumulative duration =167.1s
#
# 805
# Epoch duration =0.19s
# Cumulative duration =167.29s
#
# 806
# Epoch duration =0.21s
# Cumulative duration =167.5s
#
# 807
# Epoch duration =0.21s
# Cumulative duration =167.71s
#
# 808
# Epoch duration =0.19s
# Cumulative duration =167.89s
#
# 809
# Epoch duration =0.2s
# Cumulative duration =168.09s
#
# 810
# Epoch duration =0.2s
# Cumulative duration =168.3s
#
# 811
# Epoch duration =0.19s
# Cumulative duration =168.49s
#
# 812
# Epoch duration =0.19s
# Cumulative duration =168.68s
#
# 813
# Epoch duration =0.2s
# Cumulative duration =168.88s
#
# 814
# Epoch duration =0.21s
# Cumulative duration =169.09s
#
# 815
# Epoch duration =0.2s
# Cumulative duration =169.29s
#
# 816
# Epoch duration =0.2s
# Cumulative duration =169.49s
#
# 817
# Epoch duration =0.2s
# Cumulative duration =169.69s
#
# 818
# Epoch duration =0.19s
# Cumulative duration =169.88s
#
# 819
# Epoch duration =0.2s
# Cumulative duration =170.08s
#
# 820
# Epoch duration =0.26s
# Cumulative duration =170.34s
#
# 821
# Epoch duration =0.2s
# Cumulative duration =170.53s
#
# 822
# Epoch duration =0.2s
# Cumulative duration =170.73s
#
# 823
# Epoch duration =0.19s
# Cumulative duration =170.92s
#
# 824
# Epoch duration =0.19s
# Cumulative duration =171.12s
#
# 825
# Epoch duration =0.19s
# Cumulative duration =171.31s
#
# 826
# Epoch duration =0.19s
# Cumulative duration =171.5s
#
# 827
# Epoch duration =0.19s
# Cumulative duration =171.69s
#
# 828
# Epoch duration =0.19s
# Cumulative duration =171.88s
#
# 829
# Epoch duration =0.2s
# Cumulative duration =172.08s
#
# 830
# Epoch duration =0.19s
# Cumulative duration =172.27s
#
# 831
# Epoch duration =0.19s
# Cumulative duration =172.46s
#
# 832
# Epoch duration =0.19s
# Cumulative duration =172.65s
#
# 833
# Epoch duration =0.19s
# Cumulative duration =172.84s
#
# 834
# Epoch duration =0.19s
# Cumulative duration =173.03s
#
# 835
# Epoch duration =0.19s
# Cumulative duration =173.22s
#
# 836
# Epoch duration =0.2s
# Cumulative duration =173.42s
#
# 837
# Epoch duration =0.19s
# Cumulative duration =173.61s
#
# 838
# Epoch duration =0.27s
# Cumulative duration =173.88s
#
# 839
# Epoch duration =0.28s
# Cumulative duration =174.16s
#
# 840
# Epoch duration =0.22s
# Cumulative duration =174.38s
#
# 841
# Epoch duration =0.31s
# Cumulative duration =174.69s
#
# 842
# Epoch duration =0.21s
# Cumulative duration =174.9s
#
# 843
# Epoch duration =0.19s
# Cumulative duration =175.09s
#
# 844
# Epoch duration =0.19s
# Cumulative duration =175.29s
#
# 845
# Epoch duration =0.2s
# Cumulative duration =175.49s
#
# 846
# Epoch duration =0.21s
# Cumulative duration =175.7s
#
# 847
# Epoch duration =0.19s
# Cumulative duration =175.89s
#
# 848
# Epoch duration =0.2s
# Cumulative duration =176.09s
#
# 849
# Epoch duration =0.19s
# Cumulative duration =176.27s
#
# 850
# Epoch duration =0.2s
# Cumulative duration =176.47s
#
# 851
# Epoch duration =0.25s
# Cumulative duration =176.73s
#
# 852
# Epoch duration =0.25s
# Cumulative duration =176.98s
#
# 853
# Epoch duration =0.26s
# Cumulative duration =177.24s
#
# 854
# Epoch duration =0.2s
# Cumulative duration =177.44s
#
# 855
# Epoch duration =0.19s
# Cumulative duration =177.64s
#
# 856
# Epoch duration =0.35s
# Cumulative duration =177.99s
#
# 857
# Epoch duration =0.19s
# Cumulative duration =178.18s
#
# 858
# Epoch duration =0.28s
# Cumulative duration =178.46s
#
# 859
# Epoch duration =0.3s
# Cumulative duration =178.76s
#
# 860
# Epoch duration =0.28s
# Cumulative duration =179.04s
#
# 861
# Epoch duration =0.3s
# Cumulative duration =179.34s
#
# 862
# Epoch duration =0.2s
# Cumulative duration =179.55s
#
# 863
# Epoch duration =0.26s
# Cumulative duration =179.8s
#
# 864
# Epoch duration =0.26s
# Cumulative duration =180.07s
#
# 865
# Epoch duration =0.21s
# Cumulative duration =180.28s
#
# 866
# Epoch duration =0.21s
# Cumulative duration =180.49s
#
# 867
# Epoch duration =0.19s
# Cumulative duration =180.68s
#
# 868
# Epoch duration =0.31s
# Cumulative duration =180.98s
#
# 869
# Epoch duration =0.29s
# Cumulative duration =181.27s
#
# 870
# Epoch duration =0.23s
# Cumulative duration =181.5s
#
# 871
# Epoch duration =0.24s
# Cumulative duration =181.74s
#
# 872
# Epoch duration =0.2s
# Cumulative duration =181.94s
#
# ...
# Cumulative duration =574.43s
#
# 2718
# Epoch duration =0.23s
# Cumulative duration =574.65s
#
# 2719
# Epoch duration =0.21s
# Cumulative duration =574.86s
#
# 2720
# Epoch duration =0.19s
# Cumulative duration =575.06s
#
# 2721
# Epoch duration =0.21s
# Cumulative duration =575.26s
#
# 2722
# Epoch duration =0.34s
# Cumulative duration =575.61s
#
# 2723
# Epoch duration =0.22s
# Cumulative duration =575.82s
#
# 2724
# Epoch duration =0.3s
# Cumulative duration =576.12s
#
# 2725
# Epoch duration =0.25s
# Cumulative duration =576.37s
#
# 2726
# Epoch duration =0.19s
# Cumulative duration =576.56s
#
# 2727
# Epoch duration =0.19s
# Cumulative duration =576.76s
#
# 2728
# Epoch duration =0.19s
# Cumulative duration =576.95s
#
# 2729
# Epoch duration =0.2s
# Cumulative duration =577.15s
#
# 2730
# Epoch duration =0.21s
# Cumulative duration =577.36s
#
# 2731
# Epoch duration =0.19s
# Cumulative duration =577.55s
#
# 2732
# Epoch duration =0.22s
# Cumulative duration =577.77s
#
# 2733
# Epoch duration =0.19s
# Cumulative duration =577.96s
#
# 2734
# Epoch duration =0.22s
# Cumulative duration =578.18s
#
# 2735
# Epoch duration =0.22s
# Cumulative duration =578.4s
#
# 2736
# Epoch duration =0.22s
# Cumulative duration =578.62s
#
# 2737
# Epoch duration =0.21s
# Cumulative duration =578.83s
#
# 2738
# Epoch duration =0.23s
# Cumulative duration =579.06s
#
# 2739
# Epoch duration =0.21s
# Cumulative duration =579.26s
#
# 2740
# Epoch duration =0.21s
# Cumulative duration =579.48s
#
# 2741
# Epoch duration =0.24s
# Cumulative duration =579.71s
#
# 2742
# Epoch duration =0.21s
# Cumulative duration =579.92s
#
# 2743
# Epoch duration =0.25s
# Cumulative duration =580.18s
#
# 2744
# Epoch duration =0.22s
# Cumulative duration =580.39s
#
# 2745
# Epoch duration =0.23s
# Cumulative duration =580.63s
#
# 2746
# Epoch duration =0.24s
# Cumulative duration =580.87s
#
# 2747
# Epoch duration =0.21s
# Cumulative duration =581.08s
#
# 2748
# Epoch duration =0.25s
# Cumulative duration =581.33s
#
# 2749
# Epoch duration =0.23s
# Cumulative duration =581.56s
#
# 2750
# Epoch duration =0.23s
# Cumulative duration =581.78s
#
# 2751
# Epoch duration =0.21s
# Cumulative duration =582.0s
#
# 2752
# Epoch duration =0.22s
# Cumulative duration =582.22s
#
# 2753
# Epoch duration =0.21s
# Cumulative duration =582.43s
#
# 2754
# Epoch duration =0.23s
# Cumulative duration =582.66s
#
# 2755
# Epoch duration =0.2s
# Cumulative duration =582.86s
#
# 2756
# Epoch duration =0.21s
# Cumulative duration =583.07s
#
# 2757
# Epoch duration =0.2s
# Cumulative duration =583.28s
#
# 2758
# Epoch duration =0.23s
# Cumulative duration =583.51s
#
# 2759
# Epoch duration =0.23s
# Cumulative duration =583.73s
#
# 2760
# Epoch duration =0.2s
# Cumulative duration =583.94s
#
# 2761
# Epoch duration =0.2s
# Cumulative duration =584.14s
#
# 2762
# Epoch duration =0.19s
# Cumulative duration =584.33s
#
# 2763
# Epoch duration =0.21s
# Cumulative duration =584.54s
#
# 2764
# Epoch duration =0.21s
# Cumulative duration =584.76s
#
# 2765
# Epoch duration =0.22s
# Cumulative duration =584.98s
#
# 2766
# Epoch duration =0.2s
# Cumulative duration =585.17s
#
# 2767
# Epoch duration =0.19s
# Cumulative duration =585.37s
#
# 2768
# Epoch duration =0.19s
# Cumulative duration =585.55s
#
# 2769
# Epoch duration =0.19s
# Cumulative duration =585.75s
#
# 2770
# Epoch duration =0.19s
# Cumulative duration =585.94s
#
# 2771
# Epoch duration =0.2s
# Cumulative duration =586.13s
#
# 2772
# Epoch duration =0.19s
# Cumulative duration =586.32s
#
# 2773
# Epoch duration =0.22s
# Cumulative duration =586.54s
#
# 2774
# Epoch duration =0.2s
# Cumulative duration =586.74s
#
# 2775
# Epoch duration =0.2s
# Cumulative duration =586.94s
#
# 2776
# Epoch duration =0.2s
# Cumulative duration =587.14s
#
# 2777
# Epoch duration =0.2s
# Cumulative duration =587.34s
#
# 2778
# Epoch duration =0.23s
# Cumulative duration =587.57s
#
# 2779
# Epoch duration =0.2s
# Cumulative duration =587.77s
#
# 2780
# Epoch duration =0.22s
# Cumulative duration =587.99s
#
# 2781
# Epoch duration =0.25s
# Cumulative duration =588.25s
#
# 2782
# Epoch duration =0.23s
# Cumulative duration =588.48s
#
# 2783
# Epoch duration =0.26s
# Cumulative duration =588.74s
#
# 2784
# Epoch duration =0.19s
# Cumulative duration =588.93s
#
# 2785
# Epoch duration =0.2s
# Cumulative duration =589.13s
#
# 2786
# Epoch duration =0.19s
# Cumulative duration =589.32s
#
# 2787
# Epoch duration =0.2s
# Cumulative duration =589.51s
#
# 2788
# Epoch duration =0.19s
# Cumulative duration =589.71s
#
# 2789
# Epoch duration =0.19s
# Cumulative duration =589.9s
#
# 2790
# Epoch duration =0.2s
# Cumulative duration =590.1s
#
# 2791
# Epoch duration =0.2s
# Cumulative duration =590.3s
#
# 2792
# Epoch duration =0.2s
# Cumulative duration =590.49s
#
# 2793
# Epoch duration =0.23s
# Cumulative duration =590.72s
#
# 2794
# Epoch duration =0.21s
# Cumulative duration =590.93s
#
# 2795
# Epoch duration =0.22s
# Cumulative duration =591.15s
#
# 2796
# Epoch duration =0.24s
# Cumulative duration =591.38s
#
# 2797
# Epoch duration =0.2s
# Cumulative duration =591.59s
#
# 2798
# Epoch duration =0.32s
# Cumulative duration =591.9s
#
# 2799
# Epoch duration =0.29s
# Cumulative duration =592.19s
#
# 2800
# Epoch duration =0.22s
# Cumulative duration =592.41s
#
# 2801
# Epoch duration =0.24s
# Cumulative duration =592.65s
#
# 2802
# Epoch duration =0.22s
# Cumulative duration =592.87s
#
# 2803
# Epoch duration =0.24s
# Cumulative duration =593.11s
#
# 2804
# Epoch duration =0.19s
# Cumulative duration =593.31s
#
# 2805
# Epoch duration =0.2s
# Cumulative duration =593.5s
#
# 2806
# Epoch duration =0.19s
# Cumulative duration =593.7s
#
# 2807
# Epoch duration =0.19s
# Cumulative duration =593.89s
#
# 2808
# Epoch duration =0.19s
# Cumulative duration =594.08s
#
# 2809
# Epoch duration =0.2s
# Cumulative duration =594.28s
#
# 2810
# Epoch duration =0.2s
# Cumulative duration =594.48s
#
# 2811
# Epoch duration =0.2s
# Cumulative duration =594.68s
#
# 2812
# Epoch duration =0.2s
# Cumulative duration =594.88s
#
# 2813
# Epoch duration =0.2s
# Cumulative duration =595.08s
#
# 2814
# Epoch duration =0.2s
# Cumulative duration =595.28s
#
# 2815
# Epoch duration =0.25s
# Cumulative duration =595.53s
#
# 2816
# Epoch duration =0.19s
# Cumulative duration =595.72s
#
# 2817
# Epoch duration =0.2s
# Cumulative duration =595.91s
#
# 2818
# Epoch duration =0.2s
# Cumulative duration =596.11s
#
# 2819
# Epoch duration =0.19s
# Cumulative duration =596.3s
#
# 2820
# Epoch duration =0.2s
# Cumulative duration =596.5s
#
# 2821
# Epoch duration =0.2s
# Cumulative duration =596.7s
#
# 2822
# Epoch duration =0.19s
# Cumulative duration =596.89s
#
# 2823
# Epoch duration =0.2s
# Cumulative duration =597.09s
#
# 2824
# Epoch duration =0.19s
# Cumulative duration =597.28s
#
# 2825
# Epoch duration =0.19s
# Cumulative duration =597.47s
#
# 2826
# Epoch duration =0.19s
# Cumulative duration =597.66s
#
# 2827
# Epoch duration =0.19s
# Cumulative duration =597.86s
#
# 2828
# Epoch duration =0.21s
# Cumulative duration =598.07s
#
# 2829
# Epoch duration =0.19s
# Cumulative duration =598.26s
#
# 2830
# Epoch duration =0.19s
# Cumulative duration =598.45s
#
# 2831
# Epoch duration =0.19s
# Cumulative duration =598.64s
#
# 2832
# Epoch duration =0.24s
# Cumulative duration =598.87s
#
# 2833
# Epoch duration =0.19s
# Cumulative duration =599.06s
#
# 2834
# Epoch duration =0.19s
# Cumulative duration =599.25s
#
# 2835
# Epoch duration =0.2s
# Cumulative duration =599.45s
#
# 2836
# Epoch duration =0.19s
# Cumulative duration =599.64s
#
# 2837
# Epoch duration =0.2s
# Cumulative duration =599.84s
#
# 2838
# Epoch duration =0.25s
# Cumulative duration =600.08s
#
# 2839
# Epoch duration =0.19s
# Cumulative duration =600.28s
#
# 2840
# Epoch duration =0.2s
# Cumulative duration =600.47s
#
# 2841
# Epoch duration =0.2s
# Cumulative duration =600.67s
#
# 2842
# Epoch duration =0.25s
# Cumulative duration =600.92s
#
# 2843
# Epoch duration =0.19s
# Cumulative duration =601.12s
#
# 2844
# Epoch duration =0.19s
# Cumulative duration =601.31s
#
# 2845
# Epoch duration =0.2s
# Cumulative duration =601.51s
#
# 2846
# Epoch duration =0.2s
# Cumulative duration =601.7s
#
# 2847
# Epoch duration =0.2s
# Cumulative duration =601.9s
#
# 2848
# Epoch duration =0.2s
# Cumulative duration =602.1s
#
# 2849
# Epoch duration =0.21s
# Cumulative duration =602.31s
#
# 2850
# Epoch duration =0.2s
# Cumulative duration =602.51s
#
# 2851
# Epoch duration =0.2s
# Cumulative duration =602.71s
#
# 2852
# Epoch duration =0.22s
# Cumulative duration =602.93s
#
# 2853
# Epoch duration =0.27s
# Cumulative duration =603.2s
#
# 2854
# Epoch duration =0.23s
# Cumulative duration =603.43s
#
# 2855
# Epoch duration =0.2s
# Cumulative duration =603.63s
#
# 2856
# Epoch duration =0.21s
# Cumulative duration =603.84s
#
# 2857
# Epoch duration =0.22s
# Cumulative duration =604.05s
#
# 2858
# Epoch duration =0.22s
# Cumulative duration =604.28s
#
# 2859
# Epoch duration =0.19s
# Cumulative duration =604.47s
#
# 2860
# Epoch duration =0.19s
# Cumulative duration =604.66s
#
# 2861
# Epoch duration =0.28s
# Cumulative duration =604.94s
#
# 2862
# Epoch duration =0.32s
# Cumulative duration =605.27s
#
# 2863
# Epoch duration =0.3s
# Cumulative duration =605.56s
#
# 2864
# Epoch duration =0.2s
# Cumulative duration =605.76s
#
# 2865
# Epoch duration =0.3s
# Cumulative duration =606.06s
#
# 2866
# Epoch duration =0.31s
# Cumulative duration =606.38s
#
# 2867
# Epoch duration =0.34s
# Cumulative duration =606.72s
#
# 2868
# Epoch duration =0.2s
# Cumulative duration =606.92s
#
# 2869
# Epoch duration =0.23s
# Cumulative duration =607.15s
#
# 2870
# Epoch duration =0.2s
# Cumulative duration =607.34s
#
# 2871
# Epoch duration =0.2s
# Cumulative duration =607.54s
#
# 2872
# Epoch duration =0.21s
# Cumulative duration =607.75s
#
# 2873
# Epoch duration =0.19s
# Cumulative duration =607.95s
#
# 2874
# Epoch duration =0.19s
# Cumulative duration =608.14s
#
# 2875
# Epoch duration =0.19s
# Cumulative duration =608.33s
#
# 2876
# Epoch duration =0.19s
# Cumulative duration =608.53s
#
# 2877
# Epoch duration =0.2s
# Cumulative duration =608.73s
#
# 2878
# Epoch duration =0.2s
# Cumulative duration =608.93s
#
# 2879
# Epoch duration =0.2s
# Cumulative duration =609.12s
#
# 2880
# Epoch duration =0.21s
# Cumulative duration =609.33s
#
# 2881
# Epoch duration =0.2s
# Cumulative duration =609.52s
#
# 2882
# Epoch duration =0.19s
# Cumulative duration =609.72s
#
# 2883
# Epoch duration =0.2s
# Cumulative duration =609.92s
#
# 2884
# Epoch duration =0.19s
# Cumulative duration =610.1s
#
# 2885
# Epoch duration =0.23s
# Cumulative duration =610.33s
#
# 2886
# Epoch duration =0.2s
# Cumulative duration =610.53s
#
# 2887
# Epoch duration =0.19s
# Cumulative duration =610.72s
#
# 2888
# Epoch duration =0.19s
# Cumulative duration =610.91s
#
# 2889
# Epoch duration =0.2s
# Cumulative duration =611.11s
#
# 2890
# Epoch duration =0.19s
# Cumulative duration =611.31s
#
# 2891
# Epoch duration =0.2s
# Cumulative duration =611.5s
#
# 2892
# Epoch duration =0.19s
# Cumulative duration =611.69s
#
# 2893
# Epoch duration =0.2s
# Cumulative duration =611.89s
#
# 2894
# Epoch duration =0.21s
# Cumulative duration =612.1s
#
# 2895
# Epoch duration =0.2s
# Cumulative duration =612.3s
#
# 2896
# Epoch duration =0.37s
# Cumulative duration =612.67s
#
# 2897
# Epoch duration =0.25s
# Cumulative duration =612.92s
#
# 2898
# Epoch duration =0.2s
# Cumulative duration =613.12s
#
# 2899
# Epoch duration =0.21s
# Cumulative duration =613.32s
#
# 2900
# Epoch duration =0.21s
# Cumulative duration =613.53s
#
# 2901
# Epoch duration =0.23s
# Cumulative duration =613.76s
#
# 2902
# Epoch duration =0.24s
# Cumulative duration =614.0s
#
# 2903
# Epoch duration =0.19s
# Cumulative duration =614.2s
#
# 2904
# Epoch duration =0.2s
# Cumulative duration =614.4s
#
# 2905
# Epoch duration =0.2s
# Cumulative duration =614.6s
#
# 2906
# Epoch duration =0.21s
# Cumulative duration =614.8s
#
# 2907
# Epoch duration =0.19s
# Cumulative duration =615.0s
#
# 2908
# Epoch duration =0.2s
# Cumulative duration =615.2s
#
# 2909
# Epoch duration =0.19s
# Cumulative duration =615.39s
#
# 2910
# Epoch duration =0.2s
# Cumulative duration =615.59s
#
# 2911
# Epoch duration =0.2s
# Cumulative duration =615.79s
#
# 2912
# Epoch duration =0.2s
# Cumulative duration =615.99s
#
# 2913
# Epoch duration =0.2s
# Cumulative duration =616.19s
#
# 2914
# Epoch duration =0.2s
# Cumulative duration =616.38s
#
# 2915
# Epoch duration =0.19s
# Cumulative duration =616.58s
#
# 2916
# Epoch duration =0.21s
# Cumulative duration =616.78s
#
# 2917
# Epoch duration =0.2s
# Cumulative duration =616.99s
#
# 2918
# Epoch duration =0.19s
# Cumulative duration =617.18s
#
# 2919
# Epoch duration =0.2s
# Cumulative duration =617.38s
#
# 2920
# Epoch duration =0.22s
# Cumulative duration =617.6s
#
# 2921
# Epoch duration =0.19s
# Cumulative duration =617.79s
#
# 2922
# Epoch duration =0.19s
# Cumulative duration =617.98s
#
# 2923
# Epoch duration =0.2s
# Cumulative duration =618.18s
#
# 2924
# Epoch duration =0.19s
# Cumulative duration =618.37s
#
# 2925
# Epoch duration =0.19s
# Cumulative duration =618.56s
#
# 2926
# Epoch duration =0.19s
# Cumulative duration =618.75s
#
# 2927
# Epoch duration =0.19s
# Cumulative duration =618.94s
#
# 2928
# Epoch duration =0.19s
# Cumulative duration =619.13s
#
# 2929
# Epoch duration =0.19s
# Cumulative duration =619.32s
#
# 2930
# Epoch duration =0.19s
# Cumulative duration =619.51s
#
# 2931
# Epoch duration =0.19s
# Cumulative duration =619.7s
#
# 2932
# Epoch duration =0.19s
# Cumulative duration =619.89s
#
# 2933
# Epoch duration =0.19s
# Cumulative duration =620.09s
#
# 2934
# Epoch duration =0.19s
# Cumulative duration =620.28s
#
# 2935
# Epoch duration =0.19s
# Cumulative duration =620.47s
#
# 2936
# Epoch duration =0.19s
# Cumulative duration =620.66s
#
# 2937
# Epoch duration =0.19s
# Cumulative duration =620.85s
#
# 2938
# Epoch duration =0.19s
# Cumulative duration =621.05s
#
# 2939
# Epoch duration =0.2s
# Cumulative duration =621.24s
#
# 2940
# Epoch duration =0.19s
# Cumulative duration =621.44s
#
# 2941
# Epoch duration =0.2s
# Cumulative duration =621.64s
#
# 2942
# Epoch duration =0.2s
# Cumulative duration =621.83s
#
# 2943
# Epoch duration =0.19s
# Cumulative duration =622.03s
#
# 2944
# Epoch duration =0.19s
# Cumulative duration =622.22s
#
# 2945
# Epoch duration =0.22s
# Cumulative duration =622.44s
#
# 2946
# Epoch duration =0.33s
# Cumulative duration =622.77s
#
# 2947
# Epoch duration =0.23s
# Cumulative duration =623.01s
#
# 2948
# Epoch duration =0.22s
# Cumulative duration =623.22s
#
# 2949
# Epoch duration =0.23s
# Cumulative duration =623.46s
#
# 2950
# Epoch duration =0.26s
# Cumulative duration =623.71s
#
# 2951
# Epoch duration =0.26s
# Cumulative duration =623.98s
#
# 2952
# Epoch duration =0.27s
# Cumulative duration =624.24s
#
# 2953
# Epoch duration =0.2s
# Cumulative duration =624.45s
#
# 2954
# Epoch duration =0.19s
# Cumulative duration =624.64s
#
# 2955
# Epoch duration =0.22s
# Cumulative duration =624.86s
#
# 2956
# Epoch duration =0.19s
# Cumulative duration =625.05s
#
# 2957
# Epoch duration =0.2s
# Cumulative duration =625.25s
#
# 2958
# Epoch duration =0.19s
# Cumulative duration =625.44s
#
# 2959
# Epoch duration =0.2s
# Cumulative duration =625.64s
#
# 2960
# Epoch duration =0.22s
# Cumulative duration =625.86s
#
# 2961
# Epoch duration =0.21s
# Cumulative duration =626.06s
#
# 2962
# Epoch duration =0.2s
# Cumulative duration =626.26s
#
# 2963
# Epoch duration =0.21s
# Cumulative duration =626.47s
#
# 2964
# Epoch duration =0.19s
# Cumulative duration =626.66s
#
# 2965
# Epoch duration =0.2s
# Cumulative duration =626.85s
#
# 2966
# Epoch duration =0.19s
# Cumulative duration =627.04s
#
# 2967
# Epoch duration =0.19s
# Cumulative duration =627.23s
#
# 2968
# Epoch duration =0.19s
# Cumulative duration =627.42s
#
# 2969
# Epoch duration =0.19s
# Cumulative duration =627.61s
#
# 2970
# Epoch duration =0.19s
# Cumulative duration =627.8s
#
# 2971
# Epoch duration =0.19s
# Cumulative duration =628.0s
#
# 2972
# Epoch duration =0.19s
# Cumulative duration =628.19s
#
# 2973
# Epoch duration =0.21s
# Cumulative duration =628.4s
#
# 2974
# Epoch duration =0.2s
# Cumulative duration =628.6s
#
# 2975
# Epoch duration =0.21s
# Cumulative duration =628.8s
#
# 2976
# Epoch duration =0.21s
# Cumulative duration =629.01s
#
# 2977
# Epoch duration =0.22s
# Cumulative duration =629.23s
#
# 2978
# Epoch duration =0.2s
# Cumulative duration =629.43s
#
# 2979
# Epoch duration =0.19s
# Cumulative duration =629.62s
#
# 2980
# Epoch duration =0.29s
# Cumulative duration =629.91s
#
# 2981
# Epoch duration =0.3s
# Cumulative duration =630.22s
#
# 2982
# Epoch duration =0.24s
# Cumulative duration =630.45s
#
# 2983
# Epoch duration =0.19s
# Cumulative duration =630.64s
#
# 2984
# Epoch duration =0.2s
# Cumulative duration =630.85s
#
# 2985
# Epoch duration =0.19s
# Cumulative duration =631.04s
#
# 2986
# Epoch duration =0.27s
# Cumulative duration =631.31s
#
# 2987
# Epoch duration =0.2s
# Cumulative duration =631.51s
#
# 2988
# Epoch duration =0.2s
# Cumulative duration =631.71s
#
# 2989
# Epoch duration =0.19s
# Cumulative duration =631.89s
#
# 2990
# Epoch duration =0.2s
# Cumulative duration =632.09s
#
# 2991
# Epoch duration =0.2s
# Cumulative duration =632.29s
#
# 2992
# Epoch duration =0.2s
# Cumulative duration =632.49s
#
# 2993
# Epoch duration =0.19s
# Cumulative duration =632.68s
#
# 2994
# Epoch duration =0.19s
# Cumulative duration =632.88s
#
# 2995
# Epoch duration =0.19s
# Cumulative duration =633.07s
#
# 2996
# Epoch duration =0.19s
# Cumulative duration =633.26s
#
# 2997
# Epoch duration =0.19s
# Cumulative duration =633.45s
#
# 2998
# Epoch duration =0.19s
# Cumulative duration =633.63s
#
# 2999
# Epoch duration =0.2s
# Cumulative duration =633.83s

# %%
#Load the saved data
sum_mut2_predictoutputs = np.load('Arrays/toyhairpin_FC_sumoutputs3000.npy')

num_summary = 3000
#average the values
mean_mut2_predictoutputs = sum_mut2_predictoutputs/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_predictoutputs_hol = mean_mut2_predictoutputs.reshape(X.shape[1],X.shape[1],4,4)

# %%
nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(10,7))

num = 20

for ii in range(num):
    ax = fig4.add_subplot(4,5,ii+1)
    ax.set_title(str(ii)+','+str(40-ii))
    ax = sb.heatmap(mean_mut2_predictoutputs_hol[ii, 40-ii], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc)

# %%
nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(15,14))

num = 20

for one in range(num):
    for two in range(num):
        ax = fig4.add_subplot(num, num, ((one*num)+two)+1)
        
        #plot the 0th column with row labels and the num_th most row with column labels
        if two == 0:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+5, two+15], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc, cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+5, two+15], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=nuc, cbar=False)
        else:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+5, two+15], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=[], cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+5, two+15], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=[], cbar=False)

# %% [markdown]
# ## What is the model learning and how - Look at hidden layers

# %% [markdown]
# ### The final Dense layer parameters
#
# These give us an idea of the most important neurons for the model. In the final layer, the higher weights correspond to neurons the model wants to highlight in the output.

# %%
W = nnmodel.get_parameters(sess, layer='dense_1')[0]
W.shape
top_neurons=np.argsort(np.squeeze(W))[::-1]
top_neurons
# Out:
# array([172, 154,  83,  51,  41,  74, 128,  12,  65,  76, 132,  47, 177,
#         89,  35, 138,  75, 135,  27, 136, 173,   3, 183,  46, 143, 163,
#        114,  57,   9,  30,   5,  19, 193, 131, 120,  90, 103,   8,  10,
#        100, 137, 139, 109, 181,   2, 104,  42, 124, 180,  79,  54, 129,
#        112, 105,   6, 192, 151, 178,  82,  97,  52, 117, 126, 158,  31,
#         61, 191,  80,  18,  48, 152,  29, 175,  49, 149, 161, 155, 179,
#        190, 108,  45,  66,  78, 189,  96, 127, 159, 106, 113,  98, 118,
#         17, 147,  94, 170, 148,  85, 166,  36, 144,  58, 194,  20, 115,
#         37,  86, 121,  64, 168,  70,  72, 160,  55, 101, 156,  21, 133,
#        174, 167, 169,  28,  40,  13, 153,  11,  23,  63,  43, 119, 141,
#         93, 107,  62, 184, 125,  22,  91,  32,  81, 102, 150, 165, 186,
#         88,  16, 130,  14,  69, 171,  73, 195,  87,  95,  34,  68, 176,
#        110,  15,  56,  39, 111,  26,  71,  99,   1,  60,  50, 116,  33,
#        146, 134,  67,  25, 162,  38, 182,  53, 188,  44,   0, 187,  84,
#        145, 185, 122, 142,  92,  24,  59, 140,   4,  77, 164,   7, 123, 157])

# %% [markdown]
# ### The Dense activation layer
#
# The value of each neurons scoring of each sequence

# %%
dense = nntrainer.get_activations(sess, test, layer='dense_0_active')
dense.shape
# Out:
# (60000, 196)

# %%
np.max(dense)
# Out:
# 9.733304

# %%
#plot which neurons got activated by the highest predicted sequence (from the outputs)
plt.plot(range(dense.shape[1]), dense[plot_index[0]])
plt.show()

''' An example of how a single sequence can excite various different neurons'''

top_neurons = np.argsort(dense[plot_index[0]])[::-1]

# %% [markdown]
# ### For a given neuron, evaluate the saliency of its highest scored sequences

# %%
neuron = top_neurons[0]

# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

#sort
top_indices = np.argsort(dense[:,neuron])[::-1]

num_plots=5

plotrange = range(0,num_plots) + range(dense.shape[1]-num_plots, dense.shape[1])

for ii in plotrange:

    X = np.expand_dims(test['inputs'][top_indices[ii]], axis=0)

    X_mut = mf.mutate(X, X.shape[1], X.shape[3])
    mutations = {'inputs': X_mut, 'targets': Y_test[:X_mut.shape[0]]}

    #Get output activations for the mutations
    mut_predictions = nntrainer.get_activations(sess, mutations, layer='dense_0_active')[:,neuron]

    #shape the predictions of the mutations into the shape of a heatmap
    heat_mut = mut_predictions.reshape(X.shape[1],4).T

    #normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
    norm_heat_mut = heat_mut - dense[top_indices[ii], neuron]
    norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

    plt.figure(figsize=(15,2))
    if ii == 0:
        plt.title('Saliencies of this neurons highest predicted sequences')
    if ii == dense.shape[1]-num_plots:
        plt.title('Saliencies of this neurons lowest predicted sequences')
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            norm_heat_mut, 
                                            alphabet='rna', 
                                            nt_width=400)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_best.ckpt

# %% [markdown]
# This suggests that a single neuron is looking for the same pattern no matter what the sequence.

# %% [markdown]
# ### Evaluate what the most import neurons are learning - show the saliency of each neurons highest scored sequence

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_plots = 5
plotrange = np.concatenate((top_neurons[0:num_plots],top_neurons[-num_plots:]))

for neuron in plotrange:

    top_indices = np.argsort(dense[:,neuron])[::-1]

    ii=0

    X = np.expand_dims(test['inputs'][top_indices[ii]], axis=0)

    X_mut = mf.mutate(X, X.shape[1], X.shape[3])
    mutations = {'inputs': X_mut, 'targets': Y_test[:X_mut.shape[0]]}

    #Get output activations for the mutations
    mut_predictions = nntrainer.get_activations(sess, mutations, layer='dense_0_active')[:,neuron]

    #shape the predictions of the mutations into the shape of a heatmap
    heat_mut = mut_predictions.reshape(X.shape[1],4).T

    #normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
    norm_heat_mut = heat_mut - dense[top_indices[ii], neuron]
    norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

    plt.figure(figsize=(15,2))
    if neuron == plotrange[0]:
        plt.title('The neurons of greatest importance')
    if neuron == plotrange[num_plots]:
        plt.title('The neurons of least importance')
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            norm_heat_mut, 
                                            alphabet='rna', 
                                            nt_width=400)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_best.ckpt

# %% [markdown]
# ### Repeat the above test but plot the saliencies from the same sequence
#
# Doesn't matter much because the saliencies identify the same patterns in any sequence

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_plots = 10

ii=0

X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)

X_mut = mf.mutate(X, X.shape[1], X.shape[3])
mutations = {'inputs': X_mut, 'targets': Y_test[:X_mut.shape[0]]}

#Get output activations for the mutations
mut_predictions = nntrainer.get_activations(sess, mutations, layer='dense_0_active')

for neuron in top_neurons[:num_plots]:

    #shape the predictions of the mutations into the shape of a heatmap
    heat_mut = mut_predictions[:,neuron].reshape(X.shape[1],4).T

    #normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
    norm_heat_mut = heat_mut - dense[plot_index[ii], neuron]
    norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

    plt.figure(figsize=(15,2))
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            norm_heat_mut, 
                                            alphabet='rna', 
                                            nt_width=400)

# %% [markdown]
# ## Perform Second Order Mutagenesis but based on a neurons output

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_summary = 1000

sum_mut2_scores = np.zeros((41*41*16, dense.shape[1]))
starttime = time.time()

for ii in range(num_summary):
    print (ii)
    epoch_starttime = time.time()
    
    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    #mutate the sequence
    X_mutsecorder = mf.double_mutate(X, X.shape[1], X.shape[3])

    #reshape the 6D tensor into a 4D tensor that the model can test
    X_mutsecorder_reshape = np.reshape(X_mutsecorder, (X.shape[1]*X.shape[1]*16, X.shape[1], 1, 4))
    
    mutations = {'inputs': X_mutsecorder_reshape, 'targets': Y_test[:X_mutsecorder_reshape.shape[0]]}
    
    #Get the neuron's scores for the mutations
    mut2_scores= nntrainer.get_activations(sess, mutations, layer='dense_0_active')
    
    #Sum all the scores into a single matrix
    sum_mut2_scores += mut2_scores
    
    epoch_endtime = time.time()
    
    print ('Epoch duration =' + str(np.around((epoch_endtime -epoch_starttime), 2)) + 's')
    print ('Cumulative duration =' + str(np.around((epoch_endtime - starttime), 2)) + 's')
    print ()

# Save the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_sumneuronscores1000.npy'
np.save(npy_save_path, sum_mut2_scores)

#average the values
mean_mut2_scores = sum_mut2_scores/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_scores_hol = mean_mut2_scores.reshape(X.shape[1],X.shape[1],4,4,dense.shape[1])
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_best.ckpt
# 0
# Epoch duration =0.18s
# Cumulative duration =0.18s
#
# 1
# Epoch duration =0.18s
# Cumulative duration =0.36s
#
# 2
# Epoch duration =0.15s
# Cumulative duration =0.51s
#
# 3
# Epoch duration =0.18s
# Cumulative duration =0.7s
#
# 4
# Epoch duration =0.16s
# Cumulative duration =0.86s
#
# 5
# Epoch duration =0.17s
# Cumulative duration =1.03s
#
# 6
# Epoch duration =0.15s
# Cumulative duration =1.17s
#
# 7
# Epoch duration =0.15s
# Cumulative duration =1.32s
#
# 8
# Epoch duration =0.17s
# Cumulative duration =1.49s
#
# 9
# Epoch duration =0.14s
# Cumulative duration =1.63s
#
# 10
# Epoch duration =0.14s
# Cumulative duration =1.77s
#
# 11
# Epoch duration =0.15s
# Cumulative duration =1.92s
#
# 12
# Epoch duration =0.15s
# Cumulative duration =2.06s
#
# 13
# Epoch duration =0.15s
# Cumulative duration =2.21s
#
# 14
# Epoch duration =0.14s
# Cumulative duration =2.36s
#
# 15
# Epoch duration =0.14s
# Cumulative duration =2.5s
#
# 16
# Epoch duration =0.15s
# Cumulative duration =2.64s
#
# 17
# Epoch duration =0.15s
# Cumulative duration =2.8s
#
# 18
# Epoch duration =0.14s
# Cumulative duration =2.94s
#
# 19
# Epoch duration =0.15s
# Cumulative duration =3.09s
#
# 20
# Epoch duration =0.16s
# Cumulative duration =3.25s
#
# 21
# Epoch duration =0.14s
# Cumulative duration =3.4s
#
# 22
# Epoch duration =0.15s
# Cumulative duration =3.54s
#
# 23
# Epoch duration =0.17s
# Cumulative duration =3.71s
#
# 24
# Epoch duration =0.15s
# Cumulative duration =3.86s
#
# 25
# Epoch duration =0.14s
# Cumulative duration =4.0s
#
# 26
# Epoch duration =0.14s
# Cumulative duration =4.14s
#
# 27
# Epoch duration =0.14s
# Cumulative duration =4.29s
#
# 28
# Epoch duration =0.14s
# Cumulative duration =4.43s
#
# 29
# Epoch duration =0.14s
# Cumulative duration =4.57s
#
# 30
# Epoch duration =0.14s
# Cumulative duration =4.71s
#
# 31
# Epoch duration =0.14s
# Cumulative duration =4.86s
#
# 32
# Epoch duration =0.14s
# Cumulative duration =5.0s
#
# 33
# Epoch duration =0.14s
# Cumulative duration =5.14s
#
# 34
# Epoch duration =0.14s
# Cumulative duration =5.29s
#
# 35
# Epoch duration =0.15s
# Cumulative duration =5.44s
#
# 36
# Epoch duration =0.15s
# Cumulative duration =5.59s
#
# 37
# Epoch duration =0.16s
# Cumulative duration =5.75s
#
# 38
# Epoch duration =0.15s
# Cumulative duration =5.91s
#
# 39
# Epoch duration =0.15s
# Cumulative duration =6.06s
#
# 40
# Epoch duration =0.15s
# Cumulative duration =6.22s
#
# 41
# Epoch duration =0.14s
# Cumulative duration =6.36s
#
# 42
# Epoch duration =0.14s
# Cumulative duration =6.5s
#
# 43
# Epoch duration =0.14s
# Cumulative duration =6.65s
#
# 44
# Epoch duration =0.15s
# Cumulative duration =6.79s
#
# 45
# Epoch duration =0.14s
# Cumulative duration =6.94s
#
# 46
# Epoch duration =0.14s
# Cumulative duration =7.08s
#
# 47
# Epoch duration =0.15s
# Cumulative duration =7.23s
#
# 48
# Epoch duration =0.14s
# Cumulative duration =7.37s
#
# 49
# Epoch duration =0.15s
# Cumulative duration =7.51s
#
# 50
# Epoch duration =0.16s
# Cumulative duration =7.68s
#
# 51
# Epoch duration =0.14s
# Cumulative duration =7.82s
#
# 52
# Epoch duration =0.14s
# Cumulative duration =7.96s
#
# 53
# Epoch duration =0.14s
# Cumulative duration =8.1s
#
# 54
# Epoch duration =0.15s
# Cumulative duration =8.25s
#
# 55
# Epoch duration =0.14s
# Cumulative duration =8.39s
#
# 56
# Epoch duration =0.15s
# Cumulative duration =8.54s
#
# 57
# Epoch duration =0.14s
# Cumulative duration =8.68s
#
# 58
# Epoch duration =0.15s
# Cumulative duration =8.83s
#
# 59
# Epoch duration =0.14s
# Cumulative duration =8.97s
#
# 60
# Epoch duration =0.15s
# Cumulative duration =9.12s
#
# 61
# Epoch duration =0.14s
# Cumulative duration =9.26s
#
# 62
# Epoch duration =0.15s
# Cumulative duration =9.41s
#
# 63
# Epoch duration =0.14s
# Cumulative duration =9.56s
#
# 64
# Epoch duration =0.15s
# Cumulative duration =9.7s
#
# 65
# Epoch duration =0.14s
# Cumulative duration =9.85s
#
# 66
# Epoch duration =0.15s
# Cumulative duration =10.0s
#
# 67
# Epoch duration =0.14s
# Cumulative duration =10.14s
#
# 68
# Epoch duration =0.14s
# Cumulative duration =10.28s
#
# 69
# Epoch duration =0.15s
# Cumulative duration =10.43s
#
# 70
# Epoch duration =0.19s
# Cumulative duration =10.62s
#
# 71
# Epoch duration =0.14s
# Cumulative duration =10.76s
#
# 72
# Epoch duration =0.17s
# Cumulative duration =10.93s
#
# 73
# Epoch duration =0.14s
# Cumulative duration =11.07s
#
# 74
# Epoch duration =0.14s
# Cumulative duration =11.22s
#
# 75
# Epoch duration =0.15s
# Cumulative duration =11.36s
#
# 76
# Epoch duration =0.14s
# Cumulative duration =11.51s
#
# 77
# Epoch duration =0.14s
# Cumulative duration =11.65s
#
# 78
# Epoch duration =0.14s
# Cumulative duration =11.79s
#
# 79
# Epoch duration =0.16s
# Cumulative duration =11.95s
#
# 80
# Epoch duration =0.15s
# Cumulative duration =12.1s
#
# 81
# Epoch duration =0.14s
# Cumulative duration =12.25s
#
# 82
# Epoch duration =0.14s
# Cumulative duration =12.39s
#
# 83
# Epoch duration =0.14s
# Cumulative duration =12.53s
#
# 84
# Epoch duration =0.15s
# Cumulative duration =12.68s
#
# 85
# Epoch duration =0.14s
# Cumulative duration =12.82s
#
# 86
# Epoch duration =0.14s
# Cumulative duration =12.96s
#
# 87
# Epoch duration =0.14s
# Cumulative duration =13.1s
#
# 88
# Epoch duration =0.14s
# Cumulative duration =13.25s
#
# 89
# Epoch duration =0.14s
# Cumulative duration =13.39s
#
# 90
# Epoch duration =0.14s
# Cumulative duration =13.53s
#
# 91
# Epoch duration =0.14s
# Cumulative duration =13.67s
#
# 92
# Epoch duration =0.16s
# Cumulative duration =13.83s
#
# 93
# Epoch duration =0.14s
# Cumulative duration =13.98s
#
# 94
# Epoch duration =0.14s
# Cumulative duration =14.12s
#
# 95
# Epoch duration =0.14s
# Cumulative duration =14.26s
#
# 96
# Epoch duration =0.16s
# Cumulative duration =14.42s
#
# 97
# Epoch duration =0.19s
# Cumulative duration =14.6s
#
# 98
# Epoch duration =0.15s
# Cumulative duration =14.75s
#
# 99
# Epoch duration =0.14s
# Cumulative duration =14.9s
#
# 100
# Epoch duration =0.14s
# Cumulative duration =15.04s
#
# 101
# Epoch duration =0.14s
# Cumulative duration =15.18s
#
# 102
# Epoch duration =0.14s
# Cumulative duration =15.32s
#
# 103
# Epoch duration =0.14s
# Cumulative duration =15.47s
#
# 104
# Epoch duration =0.15s
# Cumulative duration =15.61s
#
# 105
# Epoch duration =0.14s
# Cumulative duration =15.76s
#
# 106
# Epoch duration =0.14s
# Cumulative duration =15.9s
#
# 107
# Epoch duration =0.14s
# Cumulative duration =16.04s
#
# 108
# Epoch duration =0.14s
# Cumulative duration =16.19s
#
# 109
# Epoch duration =0.14s
# Cumulative duration =16.33s
#
# 110
# Epoch duration =0.15s
# Cumulative duration =16.48s
#
# 111
# Epoch duration =0.15s
# Cumulative duration =16.63s
#
# 112
# Epoch duration =0.14s
# Cumulative duration =16.77s
#
# 113
# Epoch duration =0.14s
# Cumulative duration =16.91s
#
# 114
# Epoch duration =0.15s
# Cumulative duration =17.06s
#
# 115
# Epoch duration =0.14s
# Cumulative duration =17.21s
#
# 116
# Epoch duration =0.14s
# Cumulative duration =17.35s
#
# 117
# Epoch duration =0.15s
# Cumulative duration =17.5s
#
# 118
# Epoch duration =0.21s
# Cumulative duration =17.71s
#
# 119
# Epoch duration =0.16s
# Cumulative duration =17.87s
#
# 120
# Epoch duration =0.19s
# Cumulative duration =18.06s
#
# 121
# Epoch duration =0.17s
# Cumulative duration =18.23s
#
# 122
# Epoch duration =0.15s
# Cumulative duration =18.38s
#
# 123
# Epoch duration =0.14s
# Cumulative duration =18.52s
#
# 124
# Epoch duration =0.14s
# Cumulative duration =18.67s
#
# 125
# Epoch duration =0.15s
# Cumulative duration =18.81s
#
# 126
# Epoch duration =0.19s
# Cumulative duration =19.0s
#
# 127
# Epoch duration =0.14s
# Cumulative duration =19.14s
#
# 128
# Epoch duration =0.14s
# Cumulative duration =19.29s
#
# 129
# Epoch duration =0.14s
# Cumulative duration =19.43s
#
# 130
# Epoch duration =0.14s
# Cumulative duration =19.57s
#
# 131
# Epoch duration =0.14s
# Cumulative duration =19.72s
#
# 132
# Epoch duration =0.14s
# Cumulative duration =19.86s
#
# 133
# Epoch duration =0.19s
# Cumulative duration =20.05s
#
# 134
# Epoch duration =0.17s
# Cumulative duration =20.23s
#
# 135
# Epoch duration =0.17s
# Cumulative duration =20.4s
#
# 136
# Epoch duration =0.14s
# Cumulative duration =20.54s
#
# 137
# Epoch duration =0.14s
# Cumulative duration =20.68s
#
# 138
# Epoch duration =0.15s
# Cumulative duration =20.83s
#
# 139
# Epoch duration =0.14s
# Cumulative duration =20.97s
#
# 140
# Epoch duration =0.14s
# Cumulative duration =21.11s
#
# 141
# Epoch duration =0.14s
# Cumulative duration =21.26s
#
# 142
# Epoch duration =0.14s
# Cumulative duration =21.4s
#
# 143
# Epoch duration =0.14s
# Cumulative duration =21.54s
#
# 144
# Epoch duration =0.15s
# Cumulative duration =21.69s
#
# 145
# Epoch duration =0.15s
# Cumulative duration =21.83s
#
# 146
# Epoch duration =0.14s
# Cumulative duration =21.98s
#
# 147
# Epoch duration =0.14s
# Cumulative duration =22.12s
#
# 148
# Epoch duration =0.14s
# Cumulative duration =22.26s
#
# 149
# Epoch duration =0.14s
# Cumulative duration =22.41s
#
# 150
# Epoch duration =0.14s
# Cumulative duration =22.55s
#
# 151
# Epoch duration =0.14s
# Cumulative duration =22.69s
#
# 152
# Epoch duration =0.14s
# Cumulative duration =22.83s
#
# 153
# Epoch duration =0.14s
# Cumulative duration =22.97s
#
# 154
# Epoch duration =0.14s
# Cumulative duration =23.11s
#
# 155
# Epoch duration =0.14s
# Cumulative duration =23.25s
#
# 156
# Epoch duration =0.15s
# Cumulative duration =23.4s
#
# 157
# Epoch duration =0.14s
# Cumulative duration =23.54s
#
# 158
# Epoch duration =0.14s
# Cumulative duration =23.68s
#
# 159
# Epoch duration =0.14s
# Cumulative duration =23.83s
#
# 160
# Epoch duration =0.14s
# Cumulative duration =23.97s
#
# 161
# Epoch duration =0.14s
# Cumulative duration =24.11s
#
# 162
# Epoch duration =0.15s
# Cumulative duration =24.26s
#
# 163
# Epoch duration =0.14s
# Cumulative duration =24.4s
#
# 164
# Epoch duration =0.14s
# Cumulative duration =24.54s
#
# 165
# Epoch duration =0.14s
# Cumulative duration =24.68s
#
# 166
# Epoch duration =0.14s
# Cumulative duration =24.83s
#
# 167
# Epoch duration =0.14s
# Cumulative duration =24.97s
#
# 168
# Epoch duration =0.14s
# Cumulative duration =25.11s
#
# 169
# Epoch duration =0.15s
# Cumulative duration =25.25s
#
# 170
# Epoch duration =0.14s
# Cumulative duration =25.4s
#
# 171
# Epoch duration =0.17s
# Cumulative duration =25.57s
#
# 172
# Epoch duration =0.14s
# Cumulative duration =25.71s
#
# 173
# Epoch duration =0.14s
# Cumulative duration =25.85s
#
# 174
# Epoch duration =0.14s
# Cumulative duration =25.99s
#
# 175
# Epoch duration =0.14s
# Cumulative duration =26.14s
#
# 176
# Epoch duration =0.15s
# Cumulative duration =26.28s
#
# 177
# Epoch duration =0.15s
# Cumulative duration =26.43s
#
# 178
# Epoch duration =0.14s
# Cumulative duration =26.58s
#
# 179
# Epoch duration =0.14s
# Cumulative duration =26.72s
#
# 180
# Epoch duration =0.17s
# Cumulative duration =26.89s
#
# 181
# Epoch duration =0.14s
# Cumulative duration =27.03s
#
# 182
# Epoch duration =0.15s
# Cumulative duration =27.18s
#
# 183
# Epoch duration =0.16s
# Cumulative duration =27.34s
#
# 184
# Epoch duration =0.15s
# Cumulative duration =27.49s
#
# 185
# Epoch duration =0.2s
# Cumulative duration =27.69s
#
# 186
# Epoch duration =0.15s
# Cumulative duration =27.84s
#
# 187
# Epoch duration =0.15s
# Cumulative duration =27.99s
#
# 188
# Epoch duration =0.14s
# Cumulative duration =28.13s
#
# 189
# Epoch duration =0.14s
# Cumulative duration =28.27s
#
# 190
# Epoch duration =0.15s
# Cumulative duration =28.42s
#
# 191
# Epoch duration =0.18s
# Cumulative duration =28.6s
#
# 192
# Epoch duration =0.15s
# Cumulative duration =28.75s
#
# 193
# Epoch duration =0.16s
# Cumulative duration =28.91s
#
# 194
# Epoch duration =0.15s
# Cumulative duration =29.06s
#
# 195
# Epoch duration =0.24s
# Cumulative duration =29.29s
#
# 196
# Epoch duration =0.14s
# Cumulative duration =29.44s
#
# 197
# Epoch duration =0.15s
# Cumulative duration =29.59s
#
# 198
# Epoch duration =0.14s
# Cumulative duration =29.73s
#
# 199
# Epoch duration =0.14s
# Cumulative duration =29.87s
#
# 200
# Epoch duration =0.14s
# Cumulative duration =30.01s
#
# 201
# Epoch duration =0.14s
# Cumulative duration =30.15s
#
# 202
# Epoch duration =0.14s
# Cumulative duration =30.29s
#
# 203
# Epoch duration =0.14s
# Cumulative duration =30.43s
#
# 204
# Epoch duration =0.15s
# Cumulative duration =30.58s
#
# 205
# Epoch duration =0.14s
# Cumulative duration =30.72s
#
# 206
# Epoch duration =0.14s
# Cumulative duration =30.87s
#
# 207
# Epoch duration =0.14s
# Cumulative duration =31.01s
#
# 208
# Epoch duration =0.14s
# Cumulative duration =31.15s
#
# 209
# Epoch duration =0.14s
# Cumulative duration =31.29s
#
# 210
# Epoch duration =0.14s
# Cumulative duration =31.43s
#
# 211
# Epoch duration =0.15s
# Cumulative duration =31.59s
#
# 212
# Epoch duration =0.14s
# Cumulative duration =31.73s
#
# 213
# Epoch duration =0.15s
# Cumulative duration =31.88s
#
# 214
# Epoch duration =0.17s
# Cumulative duration =32.05s
#
# 215
# Epoch duration =0.15s
# Cumulative duration =32.2s
#
# 216
# Epoch duration =0.14s
# Cumulative duration =32.34s
#
# 217
# Epoch duration =0.14s
# Cumulative duration =32.48s
#
# 218
# Epoch duration =0.14s
# Cumulative duration =32.62s
#
# 219
# Epoch duration =0.14s
# Cumulative duration =32.77s
#
# 220
# Epoch duration =0.14s
# Cumulative duration =32.91s
#
# 221
# Epoch duration =0.14s
# Cumulative duration =33.05s
#
# 222
# Epoch duration =0.14s
# Cumulative duration =33.19s
#
# 223
# Epoch duration =0.14s
# Cumulative duration =33.33s
#
# 224
# Epoch duration =0.14s
# Cumulative duration =33.47s
#
# 225
# Epoch duration =0.14s
# Cumulative duration =33.61s
#
# 226
# Epoch duration =0.14s
# Cumulative duration =33.76s
#
# 227
# Epoch duration =0.14s
# Cumulative duration =33.9s
#
# 228
# Epoch duration =0.14s
# Cumulative duration =34.05s
#
# 229
# Epoch duration =0.15s
# Cumulative duration =34.19s
#
# 230
# Epoch duration =0.14s
# Cumulative duration =34.34s
#
# 231
# Epoch duration =0.14s
# Cumulative duration =34.48s
#
# 232
# Epoch duration =0.14s
# Cumulative duration =34.62s
#
# 233
# Epoch duration =0.14s
# Cumulative duration =34.76s
#
# 234
# Epoch duration =0.14s
# Cumulative duration =34.91s
#
# 235
# Epoch duration =0.14s
# Cumulative duration =35.05s
#
# 236
# Epoch duration =0.15s
# Cumulative duration =35.19s
#
# 237
# Epoch duration =0.15s
# Cumulative duration =35.34s
#
# 238
# Epoch duration =0.14s
# Cumulative duration =35.49s
#
# 239
# Epoch duration =0.14s
# Cumulative duration =35.63s
#
# 240
# Epoch duration =0.14s
# Cumulative duration =35.77s
#
# 241
# Epoch duration =0.15s
# Cumulative duration =35.92s
#
# 242
# Epoch duration =0.18s
# Cumulative duration =36.11s
#
# 243
# Epoch duration =0.16s
# Cumulative duration =36.26s
#
# 244
# Epoch duration =0.14s
# Cumulative duration =36.4s
#
# 245
# Epoch duration =0.14s
# Cumulative duration =36.55s
#
# 246
# Epoch duration =0.14s
# Cumulative duration =36.69s
#
# 247
# Epoch duration =0.15s
# Cumulative duration =36.83s
#
# 248
# Epoch duration =0.16s
# Cumulative duration =37.0s
#
# 249
# Epoch duration =0.14s
# Cumulative duration =37.14s
#
# 250
# Epoch duration =0.15s
# Cumulative duration =37.29s
#
# 251
# Epoch duration =0.17s
# Cumulative duration =37.45s
#
# 252
# Epoch duration =0.14s
# Cumulative duration =37.6s
#
# 253
# Epoch duration =0.14s
# Cumulative duration =37.74s
#
# 254
# Epoch duration =0.14s
# Cumulative duration =37.88s
#
# 255
# Epoch duration =0.15s
# Cumulative duration =38.03s
#
# 256
# Epoch duration =0.14s
# Cumulative duration =38.18s
#
# 257
# Epoch duration =0.14s
# Cumulative duration =38.32s
#
# 258
# Epoch duration =0.15s
# Cumulative duration =38.47s
#
# 259
# Epoch duration =0.14s
# Cumulative duration =38.62s
#
# 260
# Epoch duration =0.15s
# Cumulative duration =38.77s
#
# 261
# Epoch duration =0.15s
# Cumulative duration =38.92s
#
# 262
# Epoch duration =0.14s
# Cumulative duration =39.06s
#
# 263
# Epoch duration =0.14s
# Cumulative duration =39.2s
#
# 264
# Epoch duration =0.14s
# Cumulative duration =39.35s
#
# 265
# Epoch duration =0.17s
# Cumulative duration =39.51s
#
# 266
# Epoch duration =0.14s
# Cumulative duration =39.66s
#
# 267
# Epoch duration =0.15s
# Cumulative duration =39.81s
#
# 268
# Epoch duration =0.14s
# Cumulative duration =39.95s
#
# 269
# Epoch duration =0.14s
# Cumulative duration =40.09s
#
# 270
# Epoch duration =0.15s
# Cumulative duration =40.24s
#
# 271
# Epoch duration =0.14s
# Cumulative duration =40.38s
#
# 272
# Epoch duration =0.14s
# Cumulative duration =40.52s
#
# 273
# Epoch duration =0.15s
# Cumulative duration =40.68s
#
# 274
# Epoch duration =0.14s
# Cumulative duration =40.82s
#
# 275
# Epoch duration =0.14s
# Cumulative duration =40.96s
#
# 276
# Epoch duration =0.14s
# Cumulative duration =41.1s
#
# 277
# Epoch duration =0.16s
# Cumulative duration =41.26s
#
# 278
# Epoch duration =0.14s
# Cumulative duration =41.4s
#
# 279
# Epoch duration =0.15s
# Cumulative duration =41.54s
#
# 280
# Epoch duration =0.18s
# Cumulative duration =41.72s
#
# 281
# Epoch duration =0.15s
# Cumulative duration =41.87s
#
# 282
# Epoch duration =0.14s
# Cumulative duration =42.01s
#
# 283
# Epoch duration =0.15s
# Cumulative duration =42.16s
#
# 284
# Epoch duration =0.14s
# Cumulative duration =42.3s
#
# 285
# Epoch duration =0.15s
# Cumulative duration =42.45s
#
# 286
# Epoch duration =0.14s
# Cumulative duration =42.6s
#
# 287
# Epoch duration =0.15s
# Cumulative duration =42.75s
#
# 288
# Epoch duration =0.14s
# Cumulative duration =42.89s
#
# 289
# Epoch duration =0.14s
# Cumulative duration =43.04s
#
# 290
# Epoch duration =0.14s
# Cumulative duration =43.18s
#
# 291
# Epoch duration =0.14s
# Cumulative duration =43.32s
#
# 292
# Epoch duration =0.16s
# Cumulative duration =43.48s
#
# 293
# Epoch duration =0.14s
# Cumulative duration =43.62s
#
# 294
# Epoch duration =0.14s
# Cumulative duration =43.77s
#
# 295
# Epoch duration =0.14s
# Cumulative duration =43.91s
#
# 296
# Epoch duration =0.14s
# Cumulative duration =44.05s
#
# 297
# Epoch duration =0.15s
# Cumulative duration =44.2s
#
# 298
# Epoch duration =0.14s
# Cumulative duration =44.34s
#
# 299
# Epoch duration =0.15s
# Cumulative duration =44.49s
#
# 300
# Epoch duration =0.14s
# Cumulative duration =44.64s
#
# 301
# Epoch duration =0.15s
# Cumulative duration =44.79s
#
# 302
# Epoch duration =0.14s
# Cumulative duration =44.93s
#
# 303
# Epoch duration =0.14s
# Cumulative duration =45.07s
#
# 304
# Epoch duration =0.14s
# Cumulative duration =45.21s
#
# 305
# Epoch duration =0.14s
# Cumulative duration =45.36s
#
# 306
# Epoch duration =0.14s
# Cumulative duration =45.5s
#
# 307
# Epoch duration =0.14s
# Cumulative duration =45.64s
#
# 308
# Epoch duration =0.14s
# Cumulative duration =45.78s
#
# 309
# Epoch duration =0.14s
# Cumulative duration =45.93s
#
# 310
# Epoch duration =0.14s
# Cumulative duration =46.07s
#
# 311
# Epoch duration =0.14s
# Cumulative duration =46.21s
#
# 312
# Epoch duration =0.14s
# Cumulative duration =46.35s
#
# 313
# Epoch duration =0.14s
# Cumulative duration =46.49s
#
# 314
# Epoch duration =0.14s
# Cumulative duration =46.63s
#
# 315
# Epoch duration =0.15s
# Cumulative duration =46.78s
#
# 316
# Epoch duration =0.14s
# Cumulative duration =46.93s
#
# 317
# Epoch duration =0.14s
# Cumulative duration =47.07s
#
# 318
# Epoch duration =0.14s
# Cumulative duration =47.21s
#
# 319
# Epoch duration =0.14s
# Cumulative duration =47.35s
#
# 320
# Epoch duration =0.14s
# Cumulative duration =47.49s
#
# 321
# Epoch duration =0.15s
# Cumulative duration =47.64s
#
# 322
# Epoch duration =0.14s
# Cumulative duration =47.79s
#
# 323
# Epoch duration =0.14s
# Cumulative duration =47.93s
#
# 324
# Epoch duration =0.14s
# Cumulative duration =48.07s
#
# 325
# Epoch duration =0.15s
# Cumulative duration =48.21s
#
# 326
# Epoch duration =0.14s
# Cumulative duration =48.36s
#
# 327
# Epoch duration =0.14s
# Cumulative duration =48.5s
#
# 328
# Epoch duration =0.14s
# Cumulative duration =48.64s
#
# 329
# Epoch duration =0.16s
# Cumulative duration =48.8s
#
# 330
# Epoch duration =0.14s
# Cumulative duration =48.94s
#
# 331
# Epoch duration =0.14s
# Cumulative duration =49.08s
#
# 332
# Epoch duration =0.14s
# Cumulative duration =49.23s
#
# 333
# Epoch duration =0.16s
# Cumulative duration =49.38s
#
# 334
# Epoch duration =0.18s
# Cumulative duration =49.57s
#
# 335
# Epoch duration =0.15s
# Cumulative duration =49.71s
#
# 336
# Epoch duration =0.14s
# Cumulative duration =49.86s
#
# 337
# Epoch duration =0.14s
# Cumulative duration =50.0s
#
# 338
# Epoch duration =0.15s
# Cumulative duration =50.14s
#
# 339
# Epoch duration =0.14s
# Cumulative duration =50.28s
#
# 340
# Epoch duration =0.14s
# Cumulative duration =50.42s
#
# 341
# Epoch duration =0.15s
# Cumulative duration =50.57s
#
# 342
# Epoch duration =0.14s
# Cumulative duration =50.72s
#
# 343
# Epoch duration =0.16s
# Cumulative duration =50.87s
#
# 344
# Epoch duration =0.14s
# Cumulative duration =51.01s
#
# 345
# Epoch duration =0.14s
# Cumulative duration =51.15s
#
# 346
# Epoch duration =0.14s
# Cumulative duration =51.3s
#
# 347
# Epoch duration =0.14s
# Cumulative duration =51.44s
#
# 348
# Epoch duration =0.14s
# Cumulative duration =51.58s
#
# 349
# Epoch duration =0.14s
# Cumulative duration =51.73s
#
# 350
# Epoch duration =0.14s
# Cumulative duration =51.87s
#
# 351
# Epoch duration =0.14s
# Cumulative duration =52.01s
#
# 352
# Epoch duration =0.14s
# Cumulative duration =52.15s
#
# 353
# Epoch duration =0.15s
# Cumulative duration =52.31s
#
# 354
# Epoch duration =0.14s
# Cumulative duration =52.45s
#
# 355
# Epoch duration =0.14s
# Cumulative duration =52.59s
#
# 356
# Epoch duration =0.14s
# Cumulative duration =52.73s
#
# 357
# Epoch duration =0.15s
# Cumulative duration =52.88s
#
# 358
# Epoch duration =0.14s
# Cumulative duration =53.02s
#
# 359
# Epoch duration =0.15s
# Cumulative duration =53.18s
#
# 360
# Epoch duration =0.14s
# Cumulative duration =53.32s
#
# 361
# Epoch duration =0.14s
# Cumulative duration =53.46s
#
# 362
# Epoch duration =0.14s
# Cumulative duration =53.61s
#
# 363
# Epoch duration =0.14s
# Cumulative duration =53.75s
#
# 364
# Epoch duration =0.14s
# Cumulative duration =53.89s
#
# 365
# Epoch duration =0.14s
# Cumulative duration =54.03s
#
# 366
# Epoch duration =0.14s
# Cumulative duration =54.18s
#
# 367
# Epoch duration =0.14s
# Cumulative duration =54.32s
#
# 368
# Epoch duration =0.14s
# Cumulative duration =54.46s
#
# 369
# Epoch duration =0.14s
# Cumulative duration =54.6s
#
# 370
# Epoch duration =0.14s
# Cumulative duration =54.74s
#
# 371
# Epoch duration =0.14s
# Cumulative duration =54.89s
#
# 372
# Epoch duration =0.14s
# Cumulative duration =55.03s
#
# 373
# Epoch duration =0.14s
# Cumulative duration =55.17s
#
# 374
# Epoch duration =0.14s
# Cumulative duration =55.31s
#
# 375
# Epoch duration =0.14s
# Cumulative duration =55.46s
#
# 376
# Epoch duration =0.14s
# Cumulative duration =55.6s
#
# 377
# Epoch duration =0.16s
# Cumulative duration =55.75s
#
# 378
# Epoch duration =0.14s
# Cumulative duration =55.9s
#
# 379
# Epoch duration =0.14s
# Cumulative duration =56.04s
#
# 380
# Epoch duration =0.14s
# Cumulative duration =56.18s
#
# 381
# Epoch duration =0.16s
# Cumulative duration =56.33s
#
# 382
# Epoch duration =0.14s
# Cumulative duration =56.48s
#
# 383
# Epoch duration =0.16s
# Cumulative duration =56.64s
#
# 384
# Epoch duration =0.17s
# Cumulative duration =56.8s
#
# 385
# Epoch duration =0.18s
# Cumulative duration =56.98s
#
# 386
# Epoch duration =0.14s
# Cumulative duration =57.13s
#
# 387
# Epoch duration =0.17s
# Cumulative duration =57.3s
#
# 388
# Epoch duration =0.15s
# Cumulative duration =57.45s
#
# 389
# Epoch duration =0.16s
# Cumulative duration =57.61s
#
# 390
# Epoch duration =0.14s
# Cumulative duration =57.75s
#
# 391
# Epoch duration =0.14s
# Cumulative duration =57.89s
#
# 392
# Epoch duration =0.14s
# Cumulative duration =58.04s
#
# 393
# Epoch duration =0.14s
# Cumulative duration =58.18s
#
# 394
# Epoch duration =0.15s
# Cumulative duration =58.33s
#
# 395
# Epoch duration =0.14s
# Cumulative duration =58.47s
#
# 396
# Epoch duration =0.14s
# Cumulative duration =58.61s
#
# 397
# Epoch duration =0.14s
# Cumulative duration =58.75s
#
# 398
# Epoch duration =0.14s
# Cumulative duration =58.89s
#
# 399
# Epoch duration =0.14s
# Cumulative duration =59.03s
#
# 400
# Epoch duration =0.14s
# Cumulative duration =59.18s
#
# 401
# Epoch duration =0.14s
# Cumulative duration =59.32s
#
# 402
# Epoch duration =0.14s
# Cumulative duration =59.46s
#
# 403
# Epoch duration =0.14s
# Cumulative duration =59.6s
#
# 404
# Epoch duration =0.16s
# Cumulative duration =59.77s
#
# 405
# Epoch duration =0.14s
# Cumulative duration =59.91s
#
# 406
# Epoch duration =0.14s
# Cumulative duration =60.05s
#
# 407
# Epoch duration =0.14s
# Cumulative duration =60.19s
#
# 408
# Epoch duration =0.14s
# Cumulative duration =60.33s
#
# 409
# Epoch duration =0.14s
# Cumulative duration =60.47s
#
# 410
# Epoch duration =0.14s
# Cumulative duration =60.62s
#
# 411
# Epoch duration =0.14s
# Cumulative duration =60.76s
#
# 412
# Epoch duration =0.14s
# Cumulative duration =60.9s
#
# 413
# Epoch duration =0.14s
# Cumulative duration =61.05s
#
# 414
# Epoch duration =0.14s
# Cumulative duration =61.19s
#
# 415
# Epoch duration =0.15s
# Cumulative duration =61.34s
#
# 416
# Epoch duration =0.14s
# Cumulative duration =61.48s
#
# 417
# Epoch duration =0.14s
# Cumulative duration =61.62s
#
# 418
# Epoch duration =0.14s
# Cumulative duration =61.77s
#
# 419
# Epoch duration =0.14s
# Cumulative duration =61.91s
#
# 420
# Epoch duration =0.14s
# Cumulative duration =62.05s
#
# 421
# Epoch duration =0.14s
# Cumulative duration =62.19s
#
# 422
# Epoch duration =0.15s
# Cumulative duration =62.34s
#
# 423
# Epoch duration =0.15s
# Cumulative duration =62.49s
#
# 424
# Epoch duration =0.14s
# Cumulative duration =62.64s
#
# 425
# Epoch duration =0.16s
# Cumulative duration =62.79s
#
# 426
# Epoch duration =0.14s
# Cumulative duration =62.93s
#
# 427
# Epoch duration =0.16s
# Cumulative duration =63.09s
#
# 428
# Epoch duration =0.14s
# Cumulative duration =63.23s
#
# 429
# Epoch duration =0.14s
# Cumulative duration =63.38s
#
# 430
# Epoch duration =0.14s
# Cumulative duration =63.52s
#
# 431
# Epoch duration =0.16s
# Cumulative duration =63.68s
#
# 432
# Epoch duration =0.14s
# Cumulative duration =63.82s
#
# 433
# Epoch duration =0.14s
# Cumulative duration =63.96s
#
# 434
# Epoch duration =0.17s
# Cumulative duration =64.13s
#
# 435
# Epoch duration =0.14s
# Cumulative duration =64.28s
#
# 436
# Epoch duration =0.14s
# Cumulative duration =64.42s
#
# 437
# Epoch duration =0.14s
# Cumulative duration =64.56s
#
# 438
# Epoch duration =0.18s
# Cumulative duration =64.74s
#
# 439
# Epoch duration =0.14s
# Cumulative duration =64.89s
#
# 440
# Epoch duration =0.14s
# Cumulative duration =65.03s
#
# 441
# Epoch duration =0.14s
# Cumulative duration =65.17s
#
# 442
# Epoch duration =0.14s
# Cumulative duration =65.31s
#
# 443
# Epoch duration =0.14s
# Cumulative duration =65.45s
#
# 444
# Epoch duration =0.14s
# Cumulative duration =65.59s
#
# 445
# Epoch duration =0.16s
# Cumulative duration =65.75s
#
# 446
# Epoch duration =0.14s
# Cumulative duration =65.89s
#
# 447
# Epoch duration =0.14s
# Cumulative duration =66.03s
#
# 448
# Epoch duration =0.14s
# Cumulative duration =66.17s
#
# 449
# Epoch duration =0.16s
# Cumulative duration =66.34s
#
# 450
# Epoch duration =0.14s
# Cumulative duration =66.48s
#
# 451
# Epoch duration =0.14s
# Cumulative duration =66.62s
#
# 452
# Epoch duration =0.14s
# Cumulative duration =66.76s
#
# 453
# Epoch duration =0.14s
# Cumulative duration =66.91s
#
# 454
# Epoch duration =0.14s
# Cumulative duration =67.05s
#
# 455
# Epoch duration =0.14s
# Cumulative duration =67.19s
#
# 456
# Epoch duration =0.14s
# Cumulative duration =67.34s
#
# 457
# Epoch duration =0.17s
# Cumulative duration =67.51s
#
# 458
# Epoch duration =0.14s
# Cumulative duration =67.65s
#
# 459
# Epoch duration =0.14s
# Cumulative duration =67.79s
#
# 460
# Epoch duration =0.14s
# Cumulative duration =67.93s
#
# 461
# Epoch duration =0.14s
# Cumulative duration =68.07s
#
# 462
# Epoch duration =0.15s
# Cumulative duration =68.22s
#
# 463
# Epoch duration =0.18s
# Cumulative duration =68.4s
#
# 464
# Epoch duration =0.14s
# Cumulative duration =68.54s
#
# 465
# Epoch duration =0.14s
# Cumulative duration =68.68s
#
# 466
# Epoch duration =0.15s
# Cumulative duration =68.83s
#
# 467
# Epoch duration =0.14s
# Cumulative duration =68.97s
#
# 468
# Epoch duration =0.14s
# Cumulative duration =69.12s
#
# 469
# Epoch duration =0.14s
# Cumulative duration =69.26s
#
# 470
# Epoch duration =0.14s
# Cumulative duration =69.4s
#
# 471
# Epoch duration =0.14s
# Cumulative duration =69.54s
#
# 472
# Epoch duration =0.14s
# Cumulative duration =69.69s
#
# 473
# Epoch duration =0.14s
# Cumulative duration =69.83s
#
# 474
# Epoch duration =0.14s
# Cumulative duration =69.97s
#
# 475
# Epoch duration =0.14s
# Cumulative duration =70.11s
#
# 476
# Epoch duration =0.14s
# Cumulative duration =70.25s
#
# 477
# Epoch duration =0.14s
# Cumulative duration =70.4s
#
# 478
# Epoch duration =0.14s
# Cumulative duration =70.54s
#
# 479
# Epoch duration =0.14s
# Cumulative duration =70.68s
#
# 480
# Epoch duration =0.14s
# Cumulative duration =70.83s
#
# 481
# Epoch duration =0.14s
# Cumulative duration =70.97s
#
# 482
# Epoch duration =0.14s
# Cumulative duration =71.11s
#
# 483
# Epoch duration =0.14s
# Cumulative duration =71.25s
#
# 484
# Epoch duration =0.14s
# Cumulative duration =71.39s
#
# 485
# Epoch duration =0.14s
# Cumulative duration =71.54s
#
# 486
# Epoch duration =0.14s
# Cumulative duration =71.68s
#
# 487
# Epoch duration =0.14s
# Cumulative duration =71.82s
#
# 488
# Epoch duration =0.14s
# Cumulative duration =71.96s
#
# 489
# Epoch duration =0.14s
# Cumulative duration =72.1s
#
# 490
# Epoch duration =0.14s
# Cumulative duration =72.24s
#
# 491
# Epoch duration =0.14s
# Cumulative duration =72.39s
#
# 492
# Epoch duration =0.14s
# Cumulative duration =72.53s
#
# 493
# Epoch duration =0.16s
# Cumulative duration =72.69s
#
# 494
# Epoch duration =0.14s
# Cumulative duration =72.83s
#
# 495
# Epoch duration =0.16s
# Cumulative duration =72.99s
#
# 496
# Epoch duration =0.14s
# Cumulative duration =73.13s
#
# 497
# Epoch duration =0.14s
# Cumulative duration =73.28s
#
# 498
# Epoch duration =0.14s
# Cumulative duration =73.42s
#
# 499
# Epoch duration =0.14s
# Cumulative duration =73.56s
#
# 500
# Epoch duration =0.14s
# Cumulative duration =73.7s
#
# 501
# Epoch duration =0.15s
# Cumulative duration =73.85s
#
# 502
# Epoch duration =0.14s
# Cumulative duration =74.0s
#
# 503
# Epoch duration =0.16s
# Cumulative duration =74.15s
#
# 504
# Epoch duration =0.14s
# Cumulative duration =74.3s
#
# 505
# Epoch duration =0.14s
# Cumulative duration =74.44s
#
# 506
# Epoch duration =0.14s
# Cumulative duration =74.58s
#
# 507
# Epoch duration =0.14s
# Cumulative duration =74.72s
#
# 508
# Epoch duration =0.14s
# Cumulative duration =74.87s
#
# 509
# Epoch duration =0.14s
# Cumulative duration =75.01s
#
# 510
# Epoch duration =0.14s
# Cumulative duration =75.15s
#
# 511
# Epoch duration =0.15s
# Cumulative duration =75.3s
#
# 512
# Epoch duration =0.14s
# Cumulative duration =75.44s
#
# 513
# Epoch duration =0.14s
# Cumulative duration =75.59s
#
# 514
# Epoch duration =0.14s
# Cumulative duration =75.73s
#
# 515
# Epoch duration =0.14s
# Cumulative duration =75.87s
#
# 516
# Epoch duration =0.14s
# Cumulative duration =76.01s
#
# 517
# Epoch duration =0.15s
# Cumulative duration =76.16s
#
# 518
# Epoch duration =0.15s
# Cumulative duration =76.31s
#
# 519
# Epoch duration =0.15s
# Cumulative duration =76.46s
#
# 520
# Epoch duration =0.14s
# Cumulative duration =76.6s
#
# 521
# Epoch duration =0.15s
# Cumulative duration =76.75s
#
# 522
# Epoch duration =0.15s
# Cumulative duration =76.89s
#
# 523
# Epoch duration =0.14s
# Cumulative duration =77.04s
#
# 524
# Epoch duration =0.14s
# Cumulative duration =77.18s
#
# 525
# Epoch duration =0.15s
# Cumulative duration =77.33s
#
# 526
# Epoch duration =0.14s
# Cumulative duration =77.47s
#
# 527
# Epoch duration =0.14s
# Cumulative duration =77.61s
#
# 528
# Epoch duration =0.14s
# Cumulative duration =77.75s
#
# 529
# Epoch duration =0.14s
# Cumulative duration =77.89s
#
# 530
# Epoch duration =0.14s
# Cumulative duration =78.04s
#
# 531
# Epoch duration =0.14s
# Cumulative duration =78.18s
#
# 532
# Epoch duration =0.14s
# Cumulative duration =78.32s
#
# 533
# Epoch duration =0.14s
# Cumulative duration =78.46s
#
# 534
# Epoch duration =0.14s
# Cumulative duration =78.6s
#
# 535
# Epoch duration =0.14s
# Cumulative duration =78.74s
#
# 536
# Epoch duration =0.14s
# Cumulative duration =78.88s
#
# 537
# Epoch duration =0.14s
# Cumulative duration =79.03s
#
# 538
# Epoch duration =0.14s
# Cumulative duration =79.17s
#
# 539
# Epoch duration =0.15s
# Cumulative duration =79.32s
#
# 540
# Epoch duration =0.14s
# Cumulative duration =79.46s
#
# 541
# Epoch duration =0.14s
# Cumulative duration =79.6s
#
# 542
# Epoch duration =0.14s
# Cumulative duration =79.74s
#
# 543
# Epoch duration =0.15s
# Cumulative duration =79.89s
#
# 544
# Epoch duration =0.14s
# Cumulative duration =80.03s
#
# 545
# Epoch duration =0.16s
# Cumulative duration =80.19s
#
# 546
# Epoch duration =0.15s
# Cumulative duration =80.33s
#
# 547
# Epoch duration =0.16s
# Cumulative duration =80.49s
#
# 548
# Epoch duration =0.14s
# Cumulative duration =80.63s
#
# 549
# Epoch duration =0.15s
# Cumulative duration =80.78s
#
# 550
# Epoch duration =0.14s
# Cumulative duration =80.92s
#
# 551
# Epoch duration =0.15s
# Cumulative duration =81.06s
#
# 552
# Epoch duration =0.14s
# Cumulative duration =81.21s
#
# 553
# Epoch duration =0.15s
# Cumulative duration =81.35s
#
# 554
# Epoch duration =0.14s
# Cumulative duration =81.5s
#
# 555
# Epoch duration =0.14s
# Cumulative duration =81.64s
#
# 556
# Epoch duration =0.14s
# Cumulative duration =81.78s
#
# 557
# Epoch duration =0.14s
# Cumulative duration =81.92s
#
# 558
# Epoch duration =0.14s
# Cumulative duration =82.07s
#
# 559
# Epoch duration =0.16s
# Cumulative duration =82.23s
#
# 560
# Epoch duration =0.14s
# Cumulative duration =82.37s
#
# 561
# Epoch duration =0.14s
# Cumulative duration =82.51s
#
# 562
# Epoch duration =0.14s
# Cumulative duration =82.65s
#
# 563
# Epoch duration =0.14s
# Cumulative duration =82.79s
#
# 564
# Epoch duration =0.14s
# Cumulative duration =82.94s
#
# 565
# Epoch duration =0.14s
# Cumulative duration =83.08s
#
# 566
# Epoch duration =0.15s
# Cumulative duration =83.23s
#
# 567
# Epoch duration =0.16s
# Cumulative duration =83.39s
#
# 568
# Epoch duration =0.14s
# Cumulative duration =83.54s
#
# 569
# Epoch duration =0.14s
# Cumulative duration =83.68s
#
# 570
# Epoch duration =0.14s
# Cumulative duration =83.82s
#
# 571
# Epoch duration =0.14s
# Cumulative duration =83.96s
#
# 572
# Epoch duration =0.14s
# Cumulative duration =84.1s
#
# 573
# Epoch duration =0.14s
# Cumulative duration =84.24s
#
# 574
# Epoch duration =0.14s
# Cumulative duration =84.39s
#
# 575
# Epoch duration =0.14s
# Cumulative duration =84.53s
#
# 576
# Epoch duration =0.14s
# Cumulative duration =84.68s
#
# 577
# Epoch duration =0.15s
# Cumulative duration =84.82s
#
# 578
# Epoch duration =0.14s
# Cumulative duration =84.97s
#
# 579
# Epoch duration =0.14s
# Cumulative duration =85.11s
#
# 580
# Epoch duration =0.14s
# Cumulative duration =85.25s
#
# 581
# Epoch duration =0.16s
# Cumulative duration =85.41s
#
# 582
# Epoch duration =0.14s
# Cumulative duration =85.55s
#
# 583
# Epoch duration =0.14s
# Cumulative duration =85.69s
#
# 584
# Epoch duration =0.14s
# Cumulative duration =85.84s
#
# 585
# Epoch duration =0.14s
# Cumulative duration =85.98s
#
# 586
# Epoch duration =0.14s
# Cumulative duration =86.12s
#
# 587
# Epoch duration =0.14s
# Cumulative duration =86.26s
#
# 588
# Epoch duration =0.14s
# Cumulative duration =86.41s
#
# 589
# Epoch duration =0.15s
# Cumulative duration =86.55s
#
# 590
# Epoch duration =0.16s
# Cumulative duration =86.71s
#
# 591
# Epoch duration =0.14s
# Cumulative duration =86.86s
#
# 592
# Epoch duration =0.14s
# Cumulative duration =86.99s
#
# 593
# Epoch duration =0.15s
# Cumulative duration =87.14s
#
# 594
# Epoch duration =0.14s
# Cumulative duration =87.28s
#
# 595
# Epoch duration =0.14s
# Cumulative duration =87.42s
#
# 596
# Epoch duration =0.14s
# Cumulative duration =87.57s
#
# 597
# Epoch duration =0.14s
# Cumulative duration =87.71s
#
# 598
# Epoch duration =0.14s
# Cumulative duration =87.85s
#
# 599
# Epoch duration =0.14s
# Cumulative duration =88.0s
#
# 600
# Epoch duration =0.14s
# Cumulative duration =88.14s
#
# 601
# Epoch duration =0.14s
# Cumulative duration =88.28s
#
# 602
# Epoch duration =0.14s
# Cumulative duration =88.42s
#
# 603
# Epoch duration =0.14s
# Cumulative duration =88.56s
#
# 604
# Epoch duration =0.14s
# Cumulative duration =88.71s
#
# 605
# Epoch duration =0.14s
# Cumulative duration =88.85s
#
# 606
# Epoch duration =0.14s
# Cumulative duration =88.99s
#
# 607
# Epoch duration =0.14s
# Cumulative duration =89.13s
#
# 608
# Epoch duration =0.14s
# Cumulative duration =89.27s
#
# 609
# Epoch duration =0.14s
# Cumulative duration =89.42s
#
# 610
# Epoch duration =0.14s
# Cumulative duration =89.56s
#
# 611
# Epoch duration =0.14s
# Cumulative duration =89.7s
#
# 612
# Epoch duration =0.14s
# Cumulative duration =89.84s
#
# 613
# Epoch duration =0.14s
# Cumulative duration =89.98s
#
# 614
# Epoch duration =0.14s
# Cumulative duration =90.12s
#
# 615
# Epoch duration =0.14s
# Cumulative duration =90.26s
#
# 616
# Epoch duration =0.14s
# Cumulative duration =90.41s
#
# 617
# Epoch duration =0.18s
# Cumulative duration =90.58s
#
# 618
# Epoch duration =0.15s
# Cumulative duration =90.74s
#
# 619
# Epoch duration =0.14s
# Cumulative duration =90.88s
#
# 620
# Epoch duration =0.15s
# Cumulative duration =91.04s
#
# 621
# Epoch duration =0.16s
# Cumulative duration =91.2s
#
# 622
# Epoch duration =0.14s
# Cumulative duration =91.34s
#
# 623
# Epoch duration =0.14s
# Cumulative duration =91.49s
#
# 624
# Epoch duration =0.14s
# Cumulative duration =91.63s
#
# 625
# Epoch duration =0.14s
# Cumulative duration =91.77s
#
# 626
# Epoch duration =0.14s
# Cumulative duration =91.91s
#
# 627
# Epoch duration =0.14s
# Cumulative duration =92.05s
#
# 628
# Epoch duration =0.14s
# Cumulative duration =92.19s
#
# 629
# Epoch duration =0.14s
# Cumulative duration =92.34s
#
# 630
# Epoch duration =0.14s
# Cumulative duration =92.48s
#
# 631
# Epoch duration =0.15s
# Cumulative duration =92.63s
#
# 632
# Epoch duration =0.14s
# Cumulative duration =92.77s
#
# 633
# Epoch duration =0.15s
# Cumulative duration =92.92s
#
# 634
# Epoch duration =0.14s
# Cumulative duration =93.06s
#
# 635
# Epoch duration =0.14s
# Cumulative duration =93.2s
#
# 636
# Epoch duration =0.14s
# Cumulative duration =93.34s
#
# 637
# Epoch duration =0.14s
# Cumulative duration =93.48s
#
# 638
# Epoch duration =0.14s
# Cumulative duration =93.63s
#
# 639
# Epoch duration =0.14s
# Cumulative duration =93.77s
#
# 640
# Epoch duration =0.15s
# Cumulative duration =93.92s
#
# 641
# Epoch duration =0.14s
# Cumulative duration =94.06s
#
# 642
# Epoch duration =0.14s
# Cumulative duration =94.2s
#
# 643
# Epoch duration =0.14s
# Cumulative duration =94.34s
#
# 644
# Epoch duration =0.14s
# Cumulative duration =94.48s
#
# 645
# Epoch duration =0.14s
# Cumulative duration =94.63s
#
# 646
# Epoch duration =0.15s
# Cumulative duration =94.77s
#
# 647
# Epoch duration =0.15s
# Cumulative duration =94.93s
#
# 648
# Epoch duration =0.17s
# Cumulative duration =95.1s
#
# 649
# Epoch duration =0.15s
# Cumulative duration =95.24s
#
# 650
# Epoch duration =0.14s
# Cumulative duration =95.38s
#
# 651
# Epoch duration =0.14s
# Cumulative duration =95.52s
#
# 652
# Epoch duration =0.14s
# Cumulative duration =95.67s
#
# 653
# Epoch duration =0.14s
# Cumulative duration =95.81s
#
# 654
# Epoch duration =0.14s
# Cumulative duration =95.95s
#
# 655
# Epoch duration =0.14s
# Cumulative duration =96.09s
#
# 656
# Epoch duration =0.14s
# Cumulative duration =96.23s
#
# 657
# Epoch duration =0.15s
# Cumulative duration =96.38s
#
# 658
# Epoch duration =0.14s
# Cumulative duration =96.52s
#
# 659
# Epoch duration =0.14s
# Cumulative duration =96.67s
#
# 660
# Epoch duration =0.15s
# Cumulative duration =96.81s
#
# 661
# Epoch duration =0.14s
# Cumulative duration =96.96s
#
# 662
# Epoch duration =0.14s
# Cumulative duration =97.1s
#
# 663
# Epoch duration =0.14s
# Cumulative duration =97.24s
#
# 664
# Epoch duration =0.14s
# Cumulative duration =97.38s
#
# 665
# Epoch duration =0.15s
# Cumulative duration =97.52s
#
# 666
# Epoch duration =0.14s
# Cumulative duration =97.66s
#
# 667
# Epoch duration =0.14s
# Cumulative duration =97.81s
#
# 668
# Epoch duration =0.14s
# Cumulative duration =97.95s
#
# 669
# Epoch duration =0.14s
# Cumulative duration =98.09s
#
# 670
# Epoch duration =0.14s
# Cumulative duration =98.23s
#
# 671
# Epoch duration =0.14s
# Cumulative duration =98.38s
#
# 672
# Epoch duration =0.14s
# Cumulative duration =98.52s
#
# 673
# Epoch duration =0.14s
# Cumulative duration =98.66s
#
# 674
# Epoch duration =0.14s
# Cumulative duration =98.8s
#
# 675
# Epoch duration =0.14s
# Cumulative duration =98.94s
#
# 676
# Epoch duration =0.14s
# Cumulative duration =99.08s
#
# 677
# Epoch duration =0.14s
# Cumulative duration =99.23s
#
# 678
# Epoch duration =0.16s
# Cumulative duration =99.39s
#
# 679
# Epoch duration =0.16s
# Cumulative duration =99.55s
#
# 680
# Epoch duration =0.14s
# Cumulative duration =99.69s
#
# 681
# Epoch duration =0.14s
# Cumulative duration =99.84s
#
# 682
# Epoch duration =0.14s
# Cumulative duration =99.98s
#
# 683
# Epoch duration =0.17s
# Cumulative duration =100.15s
#
# 684
# Epoch duration =0.14s
# Cumulative duration =100.29s
#
# 685
# Epoch duration =0.14s
# Cumulative duration =100.44s
#
# 686
# Epoch duration =0.14s
# Cumulative duration =100.58s
#
# 687
# Epoch duration =0.17s
# Cumulative duration =100.75s
#
# 688
# Epoch duration =0.14s
# Cumulative duration =100.89s
#
# 689
# Epoch duration =0.14s
# Cumulative duration =101.03s
#
# 690
# Epoch duration =0.14s
# Cumulative duration =101.17s
#
# 691
# Epoch duration =0.14s
# Cumulative duration =101.31s
#
# 692
# Epoch duration =0.14s
# Cumulative duration =101.46s
#
# 693
# Epoch duration =0.14s
# Cumulative duration =101.6s
#
# 694
# Epoch duration =0.14s
# Cumulative duration =101.74s
#
# 695
# Epoch duration =0.14s
# Cumulative duration =101.88s
#
# 696
# Epoch duration =0.14s
# Cumulative duration =102.02s
#
# 697
# Epoch duration =0.15s
# Cumulative duration =102.18s
#
# 698
# Epoch duration =0.14s
# Cumulative duration =102.32s
#
# 699
# Epoch duration =0.14s
# Cumulative duration =102.46s
#
# 700
# Epoch duration =0.14s
# Cumulative duration =102.6s
#
# 701
# Epoch duration =0.15s
# Cumulative duration =102.75s
#
# 702
# Epoch duration =0.14s
# Cumulative duration =102.88s
#
# 703
# Epoch duration =0.16s
# Cumulative duration =103.05s
#
# 704
# Epoch duration =0.14s
# Cumulative duration =103.19s
#
# 705
# Epoch duration =0.14s
# Cumulative duration =103.33s
#
# 706
# Epoch duration =0.14s
# Cumulative duration =103.47s
#
# 707
# Epoch duration =0.15s
# Cumulative duration =103.62s
#
# 708
# Epoch duration =0.14s
# Cumulative duration =103.76s
#
# 709
# Epoch duration =0.14s
# Cumulative duration =103.9s
#
# 710
# Epoch duration =0.14s
# Cumulative duration =104.04s
#
# 711
# Epoch duration =0.14s
# Cumulative duration =104.18s
#
# 712
# Epoch duration =0.14s
# Cumulative duration =104.33s
#
# 713
# Epoch duration =0.15s
# Cumulative duration =104.47s
#
# 714
# Epoch duration =0.14s
# Cumulative duration =104.61s
#
# 715
# Epoch duration =0.14s
# Cumulative duration =104.75s
#
# 716
# Epoch duration =0.14s
# Cumulative duration =104.89s
#
# 717
# Epoch duration =0.14s
# Cumulative duration =105.04s
#
# 718
# Epoch duration =0.14s
# Cumulative duration =105.18s
#
# 719
# Epoch duration =0.14s
# Cumulative duration =105.32s
#
# 720
# Epoch duration =0.14s
# Cumulative duration =105.46s
#
# 721
# Epoch duration =0.14s
# Cumulative duration =105.6s
#
# 722
# Epoch duration =0.14s
# Cumulative duration =105.75s
#
# 723
# Epoch duration =0.14s
# Cumulative duration =105.89s
#
# 724
# Epoch duration =0.16s
# Cumulative duration =106.04s
#
# 725
# Epoch duration =0.14s
# Cumulative duration =106.18s
#
# 726
# Epoch duration =0.14s
# Cumulative duration =106.33s
#
# 727
# Epoch duration =0.14s
# Cumulative duration =106.47s
#
# 728
# Epoch duration =0.14s
# Cumulative duration =106.61s
#
# 729
# Epoch duration =0.14s
# Cumulative duration =106.75s
#
# 730
# Epoch duration =0.14s
# Cumulative duration =106.9s
#
# 731
# Epoch duration =0.14s
# Cumulative duration =107.04s
#
# 732
# Epoch duration =0.14s
# Cumulative duration =107.18s
#
# 733
# Epoch duration =0.16s
# Cumulative duration =107.34s
#
# 734
# Epoch duration =0.14s
# Cumulative duration =107.48s
#
# 735
# Epoch duration =0.14s
# Cumulative duration =107.62s
#
# 736
# Epoch duration =0.15s
# Cumulative duration =107.77s
#
# 737
# Epoch duration =0.15s
# Cumulative duration =107.92s
#
# 738
# Epoch duration =0.14s
# Cumulative duration =108.06s
#
# 739
# Epoch duration =0.15s
# Cumulative duration =108.22s
#
# 740
# Epoch duration =0.14s
# Cumulative duration =108.36s
#
# 741
# Epoch duration =0.14s
# Cumulative duration =108.5s
#
# 742
# Epoch duration =0.14s
# Cumulative duration =108.64s
#
# 743
# Epoch duration =0.14s
# Cumulative duration =108.78s
#
# 744
# Epoch duration =0.14s
# Cumulative duration =108.92s
#
# 745
# Epoch duration =0.14s
# Cumulative duration =109.07s
#
# 746
# Epoch duration =0.14s
# Cumulative duration =109.21s
#
# 747
# Epoch duration =0.15s
# Cumulative duration =109.36s
#
# 748
# Epoch duration =0.14s
# Cumulative duration =109.5s
#
# 749
# Epoch duration =0.15s
# Cumulative duration =109.65s
#
# 750
# Epoch duration =0.16s
# Cumulative duration =109.81s
#
# 751
# Epoch duration =0.14s
# Cumulative duration =109.95s
#
# 752
# Epoch duration =0.14s
# Cumulative duration =110.1s
#
# 753
# Epoch duration =0.16s
# Cumulative duration =110.26s
#
# 754
# Epoch duration =0.15s
# Cumulative duration =110.4s
#
# 755
# Epoch duration =0.16s
# Cumulative duration =110.56s
#
# 756
# Epoch duration =0.15s
# Cumulative duration =110.71s
#
# 757
# Epoch duration =0.15s
# Cumulative duration =110.86s
#
# 758
# Epoch duration =0.14s
# Cumulative duration =111.0s
#
# 759
# Epoch duration =0.14s
# Cumulative duration =111.14s
#
# 760
# Epoch duration =0.14s
# Cumulative duration =111.29s
#
# 761
# Epoch duration =0.14s
# Cumulative duration =111.43s
#
# 762
# Epoch duration =0.14s
# Cumulative duration =111.57s
#
# 763
# Epoch duration =0.14s
# Cumulative duration =111.71s
#
# 764
# Epoch duration =0.15s
# Cumulative duration =111.86s
#
# 765
# Epoch duration =0.15s
# Cumulative duration =112.0s
#
# 766
# Epoch duration =0.14s
# Cumulative duration =112.14s
#
# 767
# Epoch duration =0.14s
# Cumulative duration =112.28s
#
# 768
# Epoch duration =0.14s
# Cumulative duration =112.43s
#
# 769
# Epoch duration =0.14s
# Cumulative duration =112.57s
#
# 770
# Epoch duration =0.14s
# Cumulative duration =112.71s
#
# 771
# Epoch duration =0.16s
# Cumulative duration =112.87s
#
# 772
# Epoch duration =0.14s
# Cumulative duration =113.01s
#
# 773
# Epoch duration =0.14s
# Cumulative duration =113.16s
#
# 774
# Epoch duration =0.14s
# Cumulative duration =113.3s
#
# 775
# Epoch duration =0.17s
# Cumulative duration =113.47s
#
# 776
# Epoch duration =0.17s
# Cumulative duration =113.63s
#
# 777
# Epoch duration =0.14s
# Cumulative duration =113.78s
#
# 778
# Epoch duration =0.14s
# Cumulative duration =113.92s
#
# 779
# Epoch duration =0.14s
# Cumulative duration =114.06s
#
# 780
# Epoch duration =0.14s
# Cumulative duration =114.2s
#
# 781
# Epoch duration =0.14s
# Cumulative duration =114.34s
#
# 782
# Epoch duration =0.19s
# Cumulative duration =114.53s
#
# 783
# Epoch duration =0.14s
# Cumulative duration =114.68s
#
# 784
# Epoch duration =0.14s
# Cumulative duration =114.82s
#
# 785
# Epoch duration =0.15s
# Cumulative duration =114.97s
#
# 786
# Epoch duration =0.16s
# Cumulative duration =115.13s
#
# 787
# Epoch duration =0.14s
# Cumulative duration =115.27s
#
# 788
# Epoch duration =0.14s
# Cumulative duration =115.41s
#
# 789
# Epoch duration =0.14s
# Cumulative duration =115.56s
#
# 790
# Epoch duration =0.14s
# Cumulative duration =115.7s
#
# 791
# Epoch duration =0.14s
# Cumulative duration =115.85s
#
# 792
# Epoch duration =0.14s
# Cumulative duration =115.99s
#
# 793
# Epoch duration =0.15s
# Cumulative duration =116.13s
#
# 794
# Epoch duration =0.14s
# Cumulative duration =116.27s
#
# 795
# Epoch duration =0.15s
# Cumulative duration =116.42s
#
# 796
# Epoch duration =0.17s
# Cumulative duration =116.59s
#
# 797
# Epoch duration =0.17s
# Cumulative duration =116.76s
#
# 798
# Epoch duration =0.14s
# Cumulative duration =116.9s
#
# 799
# Epoch duration =0.14s
# Cumulative duration =117.04s
#
# 800
# Epoch duration =0.14s
# Cumulative duration =117.18s
#
# 801
# Epoch duration =0.14s
# Cumulative duration =117.32s
#
# 802
# Epoch duration =0.14s
# Cumulative duration =117.46s
#
# 803
# Epoch duration =0.14s
# Cumulative duration =117.61s
#
# 804
# Epoch duration =0.14s
# Cumulative duration =117.75s
#
# 805
# Epoch duration =0.14s
# Cumulative duration =117.89s
#
# 806
# Epoch duration =0.14s
# Cumulative duration =118.03s
#
# 807
# Epoch duration =0.14s
# Cumulative duration =118.17s
#
# 808
# Epoch duration =0.14s
# Cumulative duration =118.32s
#
# 809
# Epoch duration =0.15s
# Cumulative duration =118.47s
#
# 810
# Epoch duration =0.14s
# Cumulative duration =118.61s
#
# 811
# Epoch duration =0.16s
# Cumulative duration =118.77s
#
# 812
# Epoch duration =0.14s
# Cumulative duration =118.91s
#
# 813
# Epoch duration =0.14s
# Cumulative duration =119.06s
#
# 814
# Epoch duration =0.14s
# Cumulative duration =119.2s
#
# 815
# Epoch duration =0.15s
# Cumulative duration =119.35s
#
# 816
# Epoch duration =0.15s
# Cumulative duration =119.5s
#
# 817
# Epoch duration =0.15s
# Cumulative duration =119.65s
#
# 818
# Epoch duration =0.14s
# Cumulative duration =119.79s
#
# 819
# Epoch duration =0.16s
# Cumulative duration =119.96s
#
# 820
# Epoch duration =0.14s
# Cumulative duration =120.1s
#
# 821
# Epoch duration =0.14s
# Cumulative duration =120.24s
#
# 822
# Epoch duration =0.15s
# Cumulative duration =120.39s
#
# 823
# Epoch duration =0.14s
# Cumulative duration =120.53s
#
# 824
# Epoch duration =0.14s
# Cumulative duration =120.67s
#
# 825
# Epoch duration =0.14s
# Cumulative duration =120.82s
#
# 826
# Epoch duration =0.14s
# Cumulative duration =120.96s
#
# 827
# Epoch duration =0.14s
# Cumulative duration =121.1s
#
# 828
# Epoch duration =0.14s
# Cumulative duration =121.24s
#
# 829
# Epoch duration =0.14s
# Cumulative duration =121.38s
#
# 830
# Epoch duration =0.15s
# Cumulative duration =121.53s
#
# 831
# Epoch duration =0.15s
# Cumulative duration =121.67s
#
# 832
# Epoch duration =0.14s
# Cumulative duration =121.81s
#
# 833
# Epoch duration =0.14s
# Cumulative duration =121.96s
#
# 834
# Epoch duration =0.14s
# Cumulative duration =122.1s
#
# 835
# Epoch duration =0.14s
# Cumulative duration =122.24s
#
# 836
# Epoch duration =0.14s
# Cumulative duration =122.38s
#
# 837
# Epoch duration =0.14s
# Cumulative duration =122.52s
#
# 838
# Epoch duration =0.14s
# Cumulative duration =122.66s
#
# 839
# Epoch duration =0.14s
# Cumulative duration =122.81s
#
# 840
# Epoch duration =0.14s
# Cumulative duration =122.94s
#
# 841
# Epoch duration =0.15s
# Cumulative duration =123.09s
#
# 842
# Epoch duration =0.14s
# Cumulative duration =123.23s
#
# 843
# Epoch duration =0.14s
# Cumulative duration =123.37s
#
# 844
# Epoch duration =0.14s
# Cumulative duration =123.51s
#
# 845
# Epoch duration =0.14s
# Cumulative duration =123.66s
#
# 846
# Epoch duration =0.14s
# Cumulative duration =123.8s
#
# 847
# Epoch duration =0.15s
# Cumulative duration =123.95s
#
# 848
# Epoch duration =0.14s
# Cumulative duration =124.09s
#
# 849
# Epoch duration =0.14s
# Cumulative duration =124.23s
#
# 850
# Epoch duration =0.15s
# Cumulative duration =124.38s
#
# 851
# Epoch duration =0.14s
# Cumulative duration =124.52s
#
# 852
# Epoch duration =0.14s
# Cumulative duration =124.66s
#
# 853
# Epoch duration =0.14s
# Cumulative duration =124.8s
#
# 854
# Epoch duration =0.14s
# Cumulative duration =124.94s
#
# 855
# Epoch duration =0.14s
# Cumulative duration =125.09s
#
# 856
# Epoch duration =0.14s
# Cumulative duration =125.23s
#
# 857
# Epoch duration =0.17s
# Cumulative duration =125.39s
#
# 858
# Epoch duration =0.14s
# Cumulative duration =125.54s
#
# 859
# Epoch duration =0.14s
# Cumulative duration =125.68s
#
# 860
# Epoch duration =0.14s
# Cumulative duration =125.82s
#
# 861
# Epoch duration =0.17s
# Cumulative duration =125.98s
#
# 862
# Epoch duration =0.14s
# Cumulative duration =126.12s
#
# 863
# Epoch duration =0.15s
# Cumulative duration =126.27s
#
# 864
# Epoch duration =0.15s
# Cumulative duration =126.42s
#
# 865
# Epoch duration =0.16s
# Cumulative duration =126.59s
#
# 866
# Epoch duration =0.16s
# Cumulative duration =126.74s
#
# 867
# Epoch duration =0.16s
# Cumulative duration =126.9s
#
# 868
# Epoch duration =0.14s
# Cumulative duration =127.05s
#
# 869
# Epoch duration =0.17s
# Cumulative duration =127.21s
#
# 870
# Epoch duration =0.14s
# Cumulative duration =127.35s
#
# 871
# Epoch duration =0.14s
# Cumulative duration =127.5s
#
# 872
# Epoch duration =0.17s
# Cumulative duration =127.66s
#
# 873
# Epoch duration =0.14s
# Cumulative duration =127.81s
#
# 874
# Epoch duration =0.14s
# Cumulative duration =127.95s
#
# 875
# Epoch duration =0.15s
# Cumulative duration =128.09s
#
# 876
# Epoch duration =0.15s
# Cumulative duration =128.24s
#
# 877
# Epoch duration =0.15s
# Cumulative duration =128.39s
#
# 878
# Epoch duration =0.14s
# Cumulative duration =128.53s
#
# 879
# Epoch duration =0.15s
# Cumulative duration =128.67s
#
# 880
# Epoch duration =0.14s
# Cumulative duration =128.82s
#
# 881
# Epoch duration =0.14s
# Cumulative duration =128.96s
#
# 882
# Epoch duration =0.14s
# Cumulative duration =129.1s
#
# 883
# Epoch duration =0.17s
# Cumulative duration =129.27s
#
# 884
# Epoch duration =0.14s
# Cumulative duration =129.41s
#
# 885
# Epoch duration =0.16s
# Cumulative duration =129.57s
#
# 886
# Epoch duration =0.14s
# Cumulative duration =129.71s
#
# 887
# Epoch duration =0.14s
# Cumulative duration =129.86s
#
# 888
# Epoch duration =0.14s
# Cumulative duration =130.0s
#
# 889
# Epoch duration =0.15s
# Cumulative duration =130.15s
#
# 890
# Epoch duration =0.14s
# Cumulative duration =130.29s
#
# 891
# Epoch duration =0.14s
# Cumulative duration =130.43s
#
# 892
# Epoch duration =0.15s
# Cumulative duration =130.57s
#
# 893
# Epoch duration =0.17s
# Cumulative duration =130.74s
#
# 894
# Epoch duration =0.14s
# Cumulative duration =130.88s
#
# 895
# Epoch duration =0.15s
# Cumulative duration =131.03s
#
# 896
# Epoch duration =0.14s
# Cumulative duration =131.17s
#
# 897
# Epoch duration =0.14s
# Cumulative duration =131.31s
#
# 898
# Epoch duration =0.14s
# Cumulative duration =131.46s
#
# 899
# Epoch duration =0.15s
# Cumulative duration =131.61s
#
# 900
# Epoch duration =0.15s
# Cumulative duration =131.76s
#
# 901
# Epoch duration =0.15s
# Cumulative duration =131.91s
#
# 902
# Epoch duration =0.14s
# Cumulative duration =132.05s
#
# 903
# Epoch duration =0.14s
# Cumulative duration =132.2s
#
# 904
# Epoch duration =0.15s
# Cumulative duration =132.35s
#
# 905
# Epoch duration =0.15s
# Cumulative duration =132.49s
#
# 906
# Epoch duration =0.15s
# Cumulative duration =132.64s
#
# 907
# Epoch duration =0.14s
# Cumulative duration =132.78s
#
# 908
# Epoch duration =0.14s
# Cumulative duration =132.92s
#
# 909
# Epoch duration =0.17s
# Cumulative duration =133.1s
#
# 910
# Epoch duration =0.14s
# Cumulative duration =133.23s
#
# 911
# Epoch duration =0.14s
# Cumulative duration =133.38s
#
# 912
# Epoch duration =0.14s
# Cumulative duration =133.52s
#
# 913
# Epoch duration =0.14s
# Cumulative duration =133.66s
#
# 914
# Epoch duration =0.14s
# Cumulative duration =133.8s
#
# 915
# Epoch duration =0.14s
# Cumulative duration =133.94s
#
# 916
# Epoch duration =0.14s
# Cumulative duration =134.09s
#
# 917
# Epoch duration =0.14s
# Cumulative duration =134.23s
#
# 918
# Epoch duration =0.14s
# Cumulative duration =134.37s
#
# 919
# Epoch duration =0.14s
# Cumulative duration =134.51s
#
# 920
# Epoch duration =0.14s
# Cumulative duration =134.65s
#
# 921
# Epoch duration =0.14s
# Cumulative duration =134.8s
#
# 922
# Epoch duration =0.14s
# Cumulative duration =134.94s
#
# 923
# Epoch duration =0.17s
# Cumulative duration =135.11s
#
# 924
# Epoch duration =0.14s
# Cumulative duration =135.25s
#
# 925
# Epoch duration =0.14s
# Cumulative duration =135.4s
#
# 926
# Epoch duration =0.14s
# Cumulative duration =135.54s
#
# 927
# Epoch duration =0.15s
# Cumulative duration =135.68s
#
# 928
# Epoch duration =0.14s
# Cumulative duration =135.82s
#
# 929
# Epoch duration =0.14s
# Cumulative duration =135.97s
#
# 930
# Epoch duration =0.14s
# Cumulative duration =136.11s
#
# 931
# Epoch duration =0.14s
# Cumulative duration =136.25s
#
# 932
# Epoch duration =0.14s
# Cumulative duration =136.4s
#
# 933
# Epoch duration =0.14s
# Cumulative duration =136.54s
#
# 934
# Epoch duration =0.15s
# Cumulative duration =136.69s
#
# 935
# Epoch duration =0.16s
# Cumulative duration =136.84s
#
# 936
# Epoch duration =0.15s
# Cumulative duration =136.99s
#
# 937
# Epoch duration =0.17s
# Cumulative duration =137.16s
#
# 938
# Epoch duration =0.14s
# Cumulative duration =137.3s
#
# 939
# Epoch duration =0.16s
# Cumulative duration =137.46s
#
# 940
# Epoch duration =0.16s
# Cumulative duration =137.62s
#
# 941
# Epoch duration =0.17s
# Cumulative duration =137.79s
#
# 942
# Epoch duration =0.14s
# Cumulative duration =137.94s
#
# 943
# Epoch duration =0.14s
# Cumulative duration =138.08s
#
# 944
# Epoch duration =0.14s
# Cumulative duration =138.22s
#
# 945
# Epoch duration =0.16s
# Cumulative duration =138.38s
#
# 946
# Epoch duration =0.14s
# Cumulative duration =138.52s
#
# 947
# Epoch duration =0.14s
# Cumulative duration =138.66s
#
# 948
# Epoch duration =0.14s
# Cumulative duration =138.8s
#
# 949
# Epoch duration =0.14s
# Cumulative duration =138.94s
#
# 950
# Epoch duration =0.14s
# Cumulative duration =139.09s
#
# 951
# Epoch duration =0.14s
# Cumulative duration =139.23s
#
# 952
# Epoch duration =0.14s
# Cumulative duration =139.37s
#
# 953
# Epoch duration =0.15s
# Cumulative duration =139.52s
#
# 954
# Epoch duration =0.14s
# Cumulative duration =139.66s
#
# 955
# Epoch duration =0.16s
# Cumulative duration =139.82s
#
# 956
# Epoch duration =0.14s
# Cumulative duration =139.96s
#
# 957
# Epoch duration =0.14s
# Cumulative duration =140.1s
#
# 958
# Epoch duration =0.14s
# Cumulative duration =140.25s
#
# 959
# Epoch duration =0.14s
# Cumulative duration =140.39s
#
# 960
# Epoch duration =0.14s
# Cumulative duration =140.53s
#
# 961
# Epoch duration =0.14s
# Cumulative duration =140.67s
#
# 962
# Epoch duration =0.14s
# Cumulative duration =140.82s
#
# 963
# Epoch duration =0.14s
# Cumulative duration =140.96s
#
# 964
# Epoch duration =0.14s
# Cumulative duration =141.1s
#
# 965
# Epoch duration =0.15s
# Cumulative duration =141.25s
#
# 966
# Epoch duration =0.14s
# Cumulative duration =141.39s
#
# 967
# Epoch duration =0.14s
# Cumulative duration =141.53s
#
# 968
# Epoch duration =0.14s
# Cumulative duration =141.67s
#
# 969
# Epoch duration =0.14s
# Cumulative duration =141.82s
#
# 970
# Epoch duration =0.14s
# Cumulative duration =141.96s
#
# 971
# Epoch duration =0.14s
# Cumulative duration =142.1s
#
# 972
# Epoch duration =0.15s
# Cumulative duration =142.25s
#
# 973
# Epoch duration =0.14s
# Cumulative duration =142.39s
#
# 974
# Epoch duration =0.14s
# Cumulative duration =142.53s
#
# 975
# Epoch duration =0.14s
# Cumulative duration =142.68s
#
# 976
# Epoch duration =0.14s
# Cumulative duration =142.82s
#
# 977
# Epoch duration =0.15s
# Cumulative duration =142.97s
#
# 978
# Epoch duration =0.14s
# Cumulative duration =143.11s
#
# 979
# Epoch duration =0.14s
# Cumulative duration =143.26s
#
# 980
# Epoch duration =0.14s
# Cumulative duration =143.4s
#
# 981
# Epoch duration =0.14s
# Cumulative duration =143.54s
#
# 982
# Epoch duration =0.14s
# Cumulative duration =143.68s
#
# 983
# Epoch duration =0.14s
# Cumulative duration =143.83s
#
# 984
# Epoch duration =0.14s
# Cumulative duration =143.97s
#
# 985
# Epoch duration =0.14s
# Cumulative duration =144.11s
#
# 986
# Epoch duration =0.14s
# Cumulative duration =144.25s
#
# 987
# Epoch duration =0.14s
# Cumulative duration =144.4s
#
# 988
# Epoch duration =0.14s
# Cumulative duration =144.54s
#
# 989
# Epoch duration =0.14s
# Cumulative duration =144.68s
#
# 990
# Epoch duration =0.14s
# Cumulative duration =144.82s
#
# 991
# Epoch duration =0.14s
# Cumulative duration =144.97s
#
# 992
# Epoch duration =0.14s
# Cumulative duration =145.11s
#
# 993
# Epoch duration =0.14s
# Cumulative duration =145.25s
#
# 994
# Epoch duration =0.14s
# Cumulative duration =145.39s
#
# 995
# Epoch duration =0.15s
# Cumulative duration =145.53s
#
# 996
# Epoch duration =0.14s
# Cumulative duration =145.68s
#
# 997
# Epoch duration =0.19s
# Cumulative duration =145.86s
#
# 998
# Epoch duration =0.15s
# Cumulative duration =146.01s
#
# 999
# Epoch duration =0.15s
# Cumulative duration =146.16s

# %%
# Load the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_sumneuronscores1000.npy'
sum_mut2_scores = np.load(npy_save_path)

num_summary = 1000
#average the values
mean_mut2_scores = sum_mut2_scores/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_scores_hol = mean_mut2_scores.reshape(X.shape[1],X.shape[1],4,4,dense.shape[1])

# %%
#select neuron
neuron = top_neurons[0]
#select mutation information for that neuron
mean_mut2_predictoutputs_hol = mean_mut2_scores_hol[:, :, :, :, neuron]


nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(15,14))

num = 11

for one in range(num):
    for two in range(num):
        ax = fig4.add_subplot(num, num, ((one*num)+two)+1)
        
        #plot the 0th column with row labels and the num_th most row with column labels
        if two == 0:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc, cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=nuc, cbar=False)
        else:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=[], cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=[], cbar=False)

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

#select neuron
neuron = top_neurons[0]
#sort
top_indices = np.argsort(dense[:,neuron])[::-1]

num_summary = 1000

sum_mut2_scores = np.zeros((41*41*16,))
starttime = time.time()


for ii in range(num_summary):
    print (ii)
    epoch_starttime = time.time()
    
    X = np.expand_dims(test['inputs'][top_indices[ii]], axis=0)
    
    #mutate the sequence
    X_mutsecorder = mf.double_mutate(X, X.shape[1], X.shape[3])

    #reshape the 6D tensor into a 4D tensor that the model can test
    X_mutsecorder_reshape = np.reshape(X_mutsecorder, (X.shape[1]*X.shape[1]*16, X.shape[1], 1, 4))
    
    mutations = {'inputs': X_mutsecorder_reshape, 'targets': Y_test[:X_mutsecorder_reshape.shape[0]]}
    
    #Get the neuron's scores for the mutations
    mut2_scores= nntrainer.get_activations(sess, mutations, layer='dense_0_active')[:,neuron]
    
    #Sum all the scores into a single matrix
    sum_mut2_scores += mut2_scores
    
    epoch_endtime = time.time()
    
    print ('Epoch duration =' + str(np.around((epoch_endtime -epoch_starttime), 2)) + 's')
    print ('Cumulative duration =' + str(np.around((epoch_endtime - starttime), 2)) + 's')
    print ()

#average the values
mean_mut2_scores = sum_mut2_scores/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_scores_hol = mean_mut2_scores.reshape(X.shape[1],X.shape[1],4,4)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_best.ckpt
# 0
# Epoch duration =0.15s
# Cumulative duration =0.15s
#
# 1
# Epoch duration =0.15s
# Cumulative duration =0.3s
#
# 2
# Epoch duration =0.14s
# Cumulative duration =0.44s
#
# 3
# Epoch duration =0.14s
# Cumulative duration =0.58s
#
# 4
# Epoch duration =0.14s
# Cumulative duration =0.72s
#
# 5
# Epoch duration =0.15s
# Cumulative duration =0.87s
#
# 6
# Epoch duration =0.15s
# Cumulative duration =1.01s
#
# 7
# Epoch duration =0.14s
# Cumulative duration =1.16s
#
# 8
# Epoch duration =0.14s
# Cumulative duration =1.3s
#
# 9
# Epoch duration =0.14s
# Cumulative duration =1.44s
#
# 10
# Epoch duration =0.14s
# Cumulative duration =1.59s
#
# 11
# Epoch duration =0.14s
# Cumulative duration =1.73s
#
# 12
# Epoch duration =0.14s
# Cumulative duration =1.87s
#
# 13
# Epoch duration =0.14s
# Cumulative duration =2.01s
#
# 14
# Epoch duration =0.14s
# Cumulative duration =2.15s
#
# 15
# Epoch duration =0.14s
# Cumulative duration =2.3s
#
# 16
# Epoch duration =0.14s
# Cumulative duration =2.44s
#
# 17
# Epoch duration =0.14s
# Cumulative duration =2.58s
#
# 18
# Epoch duration =0.14s
# Cumulative duration =2.72s
#
# 19
# Epoch duration =0.14s
# Cumulative duration =2.86s
#
# 20
# Epoch duration =0.15s
# Cumulative duration =3.01s
#
# 21
# Epoch duration =0.14s
# Cumulative duration =3.15s
#
# 22
# Epoch duration =0.15s
# Cumulative duration =3.29s
#
# 23
# Epoch duration =0.14s
# Cumulative duration =3.44s
#
# 24
# Epoch duration =0.14s
# Cumulative duration =3.58s
#
# 25
# Epoch duration =0.15s
# Cumulative duration =3.72s
#
# 26
# Epoch duration =0.14s
# Cumulative duration =3.87s
#
# 27
# Epoch duration =0.15s
# Cumulative duration =4.01s
#
# 28
# Epoch duration =0.14s
# Cumulative duration =4.15s
#
# 29
# Epoch duration =0.15s
# Cumulative duration =4.3s
#
# 30
# Epoch duration =0.14s
# Cumulative duration =4.44s
#
# 31
# Epoch duration =0.14s
# Cumulative duration =4.59s
#
# 32
# Epoch duration =0.14s
# Cumulative duration =4.73s
#
# 33
# Epoch duration =0.14s
# Cumulative duration =4.87s
#
# 34
# Epoch duration =0.14s
# Cumulative duration =5.02s
#
# 35
# Epoch duration =0.14s
# Cumulative duration =5.16s
#
# 36
# Epoch duration =0.15s
# Cumulative duration =5.31s
#
# 37
# Epoch duration =0.14s
# Cumulative duration =5.45s
#
# 38
# Epoch duration =0.14s
# Cumulative duration =5.59s
#
# 39
# Epoch duration =0.15s
# Cumulative duration =5.74s
#
# 40
# Epoch duration =0.15s
# Cumulative duration =5.89s
#
# 41
# Epoch duration =0.15s
# Cumulative duration =6.04s
#
# 42
# Epoch duration =0.14s
# Cumulative duration =6.19s
#
# 43
# Epoch duration =0.14s
# Cumulative duration =6.33s
#
# 44
# Epoch duration =0.14s
# Cumulative duration =6.47s
#
# 45
# Epoch duration =0.14s
# Cumulative duration =6.61s
#
# 46
# Epoch duration =0.14s
# Cumulative duration =6.75s
#
# 47
# Epoch duration =0.15s
# Cumulative duration =6.89s
#
# 48
# Epoch duration =0.14s
# Cumulative duration =7.04s
#
# 49
# Epoch duration =0.15s
# Cumulative duration =7.18s
#
# 50
# Epoch duration =0.14s
# Cumulative duration =7.32s
#
# 51
# Epoch duration =0.14s
# Cumulative duration =7.46s
#
# 52
# Epoch duration =0.14s
# Cumulative duration =7.61s
#
# 53
# Epoch duration =0.14s
# Cumulative duration =7.75s
#
# 54
# Epoch duration =0.15s
# Cumulative duration =7.89s
#
# 55
# Epoch duration =0.15s
# Cumulative duration =8.04s
#
# 56
# Epoch duration =0.14s
# Cumulative duration =8.18s
#
# 57
# Epoch duration =0.15s
# Cumulative duration =8.33s
#
# 58
# Epoch duration =0.14s
# Cumulative duration =8.48s
#
# 59
# Epoch duration =0.14s
# Cumulative duration =8.62s
#
# 60
# Epoch duration =0.14s
# Cumulative duration =8.76s
#
# 61
# Epoch duration =0.15s
# Cumulative duration =8.91s
#
# 62
# Epoch duration =0.15s
# Cumulative duration =9.06s
#
# 63
# Epoch duration =0.15s
# Cumulative duration =9.21s
#
# 64
# Epoch duration =0.15s
# Cumulative duration =9.35s
#
# 65
# Epoch duration =0.14s
# Cumulative duration =9.5s
#
# 66
# Epoch duration =0.15s
# Cumulative duration =9.64s
#
# 67
# Epoch duration =0.14s
# Cumulative duration =9.79s
#
# 68
# Epoch duration =0.15s
# Cumulative duration =9.93s
#
# 69
# Epoch duration =0.15s
# Cumulative duration =10.08s
#
# 70
# Epoch duration =0.16s
# Cumulative duration =10.24s
#
# 71
# Epoch duration =0.14s
# Cumulative duration =10.39s
#
# 72
# Epoch duration =0.15s
# Cumulative duration =10.53s
#
# 73
# Epoch duration =0.15s
# Cumulative duration =10.68s
#
# 74
# Epoch duration =0.14s
# Cumulative duration =10.82s
#
# 75
# Epoch duration =0.14s
# Cumulative duration =10.96s
#
# 76
# Epoch duration =0.14s
# Cumulative duration =11.11s
#
# 77
# Epoch duration =0.15s
# Cumulative duration =11.25s
#
# 78
# Epoch duration =0.14s
# Cumulative duration =11.39s
#
# 79
# Epoch duration =0.14s
# Cumulative duration =11.54s
#
# 80
# Epoch duration =0.15s
# Cumulative duration =11.68s
#
# 81
# Epoch duration =0.14s
# Cumulative duration =11.82s
#
# 82
# Epoch duration =0.14s
# Cumulative duration =11.97s
#
# 83
# Epoch duration =0.14s
# Cumulative duration =12.11s
#
# 84
# Epoch duration =0.14s
# Cumulative duration =12.25s
#
# 85
# Epoch duration =0.14s
# Cumulative duration =12.39s
#
# 86
# Epoch duration =0.14s
# Cumulative duration =12.53s
#
# 87
# Epoch duration =0.14s
# Cumulative duration =12.68s
#
# 88
# Epoch duration =0.14s
# Cumulative duration =12.82s
#
# 89
# Epoch duration =0.14s
# Cumulative duration =12.96s
#
# 90
# Epoch duration =0.14s
# Cumulative duration =13.11s
#
# 91
# Epoch duration =0.14s
# Cumulative duration =13.25s
#
# 92
# Epoch duration =0.14s
# Cumulative duration =13.39s
#
# 93
# Epoch duration =0.14s
# Cumulative duration =13.53s
#
# 94
# Epoch duration =0.14s
# Cumulative duration =13.67s
#
# 95
# Epoch duration =0.14s
# Cumulative duration =13.82s
#
# 96
# Epoch duration =0.15s
# Cumulative duration =13.96s
#
# 97
# Epoch duration =0.14s
# Cumulative duration =14.1s
#
# 98
# Epoch duration =0.14s
# Cumulative duration =14.24s
#
# 99
# Epoch duration =0.14s
# Cumulative duration =14.38s
#
# 100
# Epoch duration =0.14s
# Cumulative duration =14.52s
#
# 101
# Epoch duration =0.15s
# Cumulative duration =14.67s
#
# 102
# Epoch duration =0.14s
# Cumulative duration =14.82s
#
# 103
# Epoch duration =0.15s
# Cumulative duration =14.96s
#
# 104
# Epoch duration =0.14s
# Cumulative duration =15.11s
#
# 105
# Epoch duration =0.14s
# Cumulative duration =15.25s
#
# 106
# Epoch duration =0.14s
# Cumulative duration =15.39s
#
# 107
# Epoch duration =0.14s
# Cumulative duration =15.54s
#
# 108
# Epoch duration =0.14s
# Cumulative duration =15.67s
#
# 109
# Epoch duration =0.15s
# Cumulative duration =15.82s
#
# 110
# Epoch duration =0.14s
# Cumulative duration =15.97s
#
# 111
# Epoch duration =0.15s
# Cumulative duration =16.12s
#
# 112
# Epoch duration =0.14s
# Cumulative duration =16.26s
#
# 113
# Epoch duration =0.14s
# Cumulative duration =16.4s
#
# 114
# Epoch duration =0.15s
# Cumulative duration =16.55s
#
# 115
# Epoch duration =0.14s
# Cumulative duration =16.69s
#
# 116
# Epoch duration =0.15s
# Cumulative duration =16.84s
#
# 117
# Epoch duration =0.15s
# Cumulative duration =16.99s
#
# 118
# Epoch duration =0.14s
# Cumulative duration =17.14s
#
# 119
# Epoch duration =0.15s
# Cumulative duration =17.28s
#
# 120
# Epoch duration =0.14s
# Cumulative duration =17.42s
#
# 121
# Epoch duration =0.15s
# Cumulative duration =17.57s
#
# 122
# Epoch duration =0.15s
# Cumulative duration =17.72s
#
# 123
# Epoch duration =0.14s
# Cumulative duration =17.86s
#
# 124
# Epoch duration =0.14s
# Cumulative duration =18.01s
#
# 125
# Epoch duration =0.15s
# Cumulative duration =18.15s
#
# 126
# Epoch duration =0.14s
# Cumulative duration =18.3s
#
# 127
# Epoch duration =0.14s
# Cumulative duration =18.44s
#
# 128
# Epoch duration =0.15s
# Cumulative duration =18.58s
#
# 129
# Epoch duration =0.14s
# Cumulative duration =18.72s
#
# 130
# Epoch duration =0.14s
# Cumulative duration =18.86s
#
# 131
# Epoch duration =0.14s
# Cumulative duration =19.0s
#
# 132
# Epoch duration =0.14s
# Cumulative duration =19.15s
#
# 133
# Epoch duration =0.14s
# Cumulative duration =19.29s
#
# 134
# Epoch duration =0.14s
# Cumulative duration =19.43s
#
# 135
# Epoch duration =0.14s
# Cumulative duration =19.57s
#
# 136
# Epoch duration =0.14s
# Cumulative duration =19.71s
#
# 137
# Epoch duration =0.15s
# Cumulative duration =19.86s
#
# 138
# Epoch duration =0.15s
# Cumulative duration =20.01s
#
# 139
# Epoch duration =0.14s
# Cumulative duration =20.15s
#
# 140
# Epoch duration =0.14s
# Cumulative duration =20.29s
#
# 141
# Epoch duration =0.16s
# Cumulative duration =20.45s
#
# 142
# Epoch duration =0.16s
# Cumulative duration =20.61s
#
# 143
# Epoch duration =0.15s
# Cumulative duration =20.76s
#
# 144
# Epoch duration =0.14s
# Cumulative duration =20.9s
#
# 145
# Epoch duration =0.14s
# Cumulative duration =21.04s
#
# 146
# Epoch duration =0.14s
# Cumulative duration =21.18s
#
# 147
# Epoch duration =0.14s
# Cumulative duration =21.32s
#
# 148
# Epoch duration =0.15s
# Cumulative duration =21.47s
#
# 149
# Epoch duration =0.17s
# Cumulative duration =21.64s
#
# 150
# Epoch duration =0.17s
# Cumulative duration =21.81s
#
# 151
# Epoch duration =0.15s
# Cumulative duration =21.96s
#
# 152
# Epoch duration =0.14s
# Cumulative duration =22.1s
#
# 153
# Epoch duration =0.14s
# Cumulative duration =22.25s
#
# 154
# Epoch duration =0.14s
# Cumulative duration =22.39s
#
# 155
# Epoch duration =0.14s
# Cumulative duration =22.53s
#
# 156
# Epoch duration =0.14s
# Cumulative duration =22.67s
#
# 157
# Epoch duration =0.15s
# Cumulative duration =22.82s
#
# 158
# Epoch duration =0.14s
# Cumulative duration =22.96s
#
# 159
# Epoch duration =0.17s
# Cumulative duration =23.13s
#
# 160
# Epoch duration =0.16s
# Cumulative duration =23.29s
#
# 161
# Epoch duration =0.14s
# Cumulative duration =23.43s
#
# 162
# Epoch duration =0.14s
# Cumulative duration =23.57s
#
# 163
# Epoch duration =0.14s
# Cumulative duration =23.71s
#
# 164
# Epoch duration =0.14s
# Cumulative duration =23.85s
#
# 165
# Epoch duration =0.14s
# Cumulative duration =23.99s
#
# 166
# Epoch duration =0.14s
# Cumulative duration =24.14s
#
# 167
# Epoch duration =0.14s
# Cumulative duration =24.28s
#
# 168
# Epoch duration =0.14s
# Cumulative duration =24.42s
#
# 169
# Epoch duration =0.14s
# Cumulative duration =24.56s
#
# 170
# Epoch duration =0.14s
# Cumulative duration =24.7s
#
# 171
# Epoch duration =0.14s
# Cumulative duration =24.85s
#
# 172
# Epoch duration =0.14s
# Cumulative duration =24.99s
#
# 173
# Epoch duration =0.15s
# Cumulative duration =25.14s
#
# 174
# Epoch duration =0.14s
# Cumulative duration =25.28s
#
# 175
# Epoch duration =0.14s
# Cumulative duration =25.42s
#
# 176
# Epoch duration =0.14s
# Cumulative duration =25.56s
#
# 177
# Epoch duration =0.14s
# Cumulative duration =25.7s
#
# 178
# Epoch duration =0.14s
# Cumulative duration =25.84s
#
# 179
# Epoch duration =0.14s
# Cumulative duration =25.98s
#
# 180
# Epoch duration =0.15s
# Cumulative duration =26.13s
#
# 181
# Epoch duration =0.14s
# Cumulative duration =26.27s
#
# 182
# Epoch duration =0.14s
# Cumulative duration =26.41s
#
# 183
# Epoch duration =0.15s
# Cumulative duration =26.56s
#
# 184
# Epoch duration =0.14s
# Cumulative duration =26.7s
#
# 185
# Epoch duration =0.14s
# Cumulative duration =26.84s
#
# 186
# Epoch duration =0.14s
# Cumulative duration =26.99s
#
# 187
# Epoch duration =0.14s
# Cumulative duration =27.13s
#
# 188
# Epoch duration =0.14s
# Cumulative duration =27.27s
#
# 189
# Epoch duration =0.14s
# Cumulative duration =27.41s
#
# 190
# Epoch duration =0.14s
# Cumulative duration =27.55s
#
# 191
# Epoch duration =0.15s
# Cumulative duration =27.69s
#
# 192
# Epoch duration =0.14s
# Cumulative duration =27.84s
#
# 193
# Epoch duration =0.14s
# Cumulative duration =27.98s
#
# 194
# Epoch duration =0.14s
# Cumulative duration =28.12s
#
# 195
# Epoch duration =0.15s
# Cumulative duration =28.27s
#
# 196
# Epoch duration =0.14s
# Cumulative duration =28.41s
#
# 197
# Epoch duration =0.14s
# Cumulative duration =28.55s
#
# 198
# Epoch duration =0.15s
# Cumulative duration =28.7s
#
# 199
# Epoch duration =0.15s
# Cumulative duration =28.84s
#
# 200
# Epoch duration =0.14s
# Cumulative duration =28.99s
#
# 201
# Epoch duration =0.14s
# Cumulative duration =29.13s
#
# 202
# Epoch duration =0.15s
# Cumulative duration =29.28s
#
# 203
# Epoch duration =0.14s
# Cumulative duration =29.42s
#
# 204
# Epoch duration =0.14s
# Cumulative duration =29.56s
#
# 205
# Epoch duration =0.17s
# Cumulative duration =29.73s
#
# 206
# Epoch duration =0.15s
# Cumulative duration =29.88s
#
# 207
# Epoch duration =0.14s
# Cumulative duration =30.03s
#
# 208
# Epoch duration =0.14s
# Cumulative duration =30.17s
#
# 209
# Epoch duration =0.14s
# Cumulative duration =30.31s
#
# 210
# Epoch duration =0.14s
# Cumulative duration =30.45s
#
# 211
# Epoch duration =0.15s
# Cumulative duration =30.6s
#
# 212
# Epoch duration =0.14s
# Cumulative duration =30.74s
#
# 213
# Epoch duration =0.14s
# Cumulative duration =30.88s
#
# 214
# Epoch duration =0.16s
# Cumulative duration =31.05s
#
# 215
# Epoch duration =0.14s
# Cumulative duration =31.19s
#
# 216
# Epoch duration =0.14s
# Cumulative duration =31.33s
#
# 217
# Epoch duration =0.15s
# Cumulative duration =31.48s
#
# 218
# Epoch duration =0.14s
# Cumulative duration =31.62s
#
# 219
# Epoch duration =0.14s
# Cumulative duration =31.76s
#
# 220
# Epoch duration =0.14s
# Cumulative duration =31.9s
#
# 221
# Epoch duration =0.14s
# Cumulative duration =32.04s
#
# 222
# Epoch duration =0.14s
# Cumulative duration =32.18s
#
# 223
# Epoch duration =0.14s
# Cumulative duration =32.32s
#
# 224
# Epoch duration =0.14s
# Cumulative duration =32.47s
#
# 225
# Epoch duration =0.15s
# Cumulative duration =32.61s
#
# 226
# Epoch duration =0.15s
# Cumulative duration =32.76s
#
# 227
# Epoch duration =0.15s
# Cumulative duration =32.91s
#
# 228
# Epoch duration =0.15s
# Cumulative duration =33.06s
#
# 229
# Epoch duration =0.14s
# Cumulative duration =33.2s
#
# 230
# Epoch duration =0.14s
# Cumulative duration =33.34s
#
# 231
# Epoch duration =0.14s
# Cumulative duration =33.49s
#
# 232
# Epoch duration =0.14s
# Cumulative duration =33.63s
#
# 233
# Epoch duration =0.15s
# Cumulative duration =33.77s
#
# 234
# Epoch duration =0.14s
# Cumulative duration =33.91s
#
# 235
# Epoch duration =0.14s
# Cumulative duration =34.05s
#
# 236
# Epoch duration =0.15s
# Cumulative duration =34.2s
#
# 237
# Epoch duration =0.14s
# Cumulative duration =34.34s
#
# 238
# Epoch duration =0.14s
# Cumulative duration =34.49s
#
# 239
# Epoch duration =0.15s
# Cumulative duration =34.63s
#
# 240
# Epoch duration =0.14s
# Cumulative duration =34.78s
#
# 241
# Epoch duration =0.15s
# Cumulative duration =34.92s
#
# 242
# Epoch duration =0.14s
# Cumulative duration =35.07s
#
# 243
# Epoch duration =0.14s
# Cumulative duration =35.21s
#
# 244
# Epoch duration =0.14s
# Cumulative duration =35.35s
#
# 245
# Epoch duration =0.14s
# Cumulative duration =35.49s
#
# 246
# Epoch duration =0.14s
# Cumulative duration =35.64s
#
# 247
# Epoch duration =0.15s
# Cumulative duration =35.79s
#
# 248
# Epoch duration =0.14s
# Cumulative duration =35.93s
#
# 249
# Epoch duration =0.16s
# Cumulative duration =36.08s
#
# 250
# Epoch duration =0.14s
# Cumulative duration =36.23s
#
# 251
# Epoch duration =0.15s
# Cumulative duration =36.37s
#
# 252
# Epoch duration =0.15s
# Cumulative duration =36.52s
#
# 253
# Epoch duration =0.16s
# Cumulative duration =36.68s
#
# 254
# Epoch duration =0.14s
# Cumulative duration =36.82s
#
# 255
# Epoch duration =0.15s
# Cumulative duration =36.97s
#
# 256
# Epoch duration =0.15s
# Cumulative duration =37.11s
#
# 257
# Epoch duration =0.14s
# Cumulative duration =37.25s
#
# 258
# Epoch duration =0.19s
# Cumulative duration =37.45s
#
# 259
# Epoch duration =0.16s
# Cumulative duration =37.61s
#
# 260
# Epoch duration =0.2s
# Cumulative duration =37.81s
#
# 261
# Epoch duration =0.18s
# Cumulative duration =37.98s
#
# 262
# Epoch duration =0.18s
# Cumulative duration =38.17s
#
# 263
# Epoch duration =0.18s
# Cumulative duration =38.35s
#
# 264
# Epoch duration =0.21s
# Cumulative duration =38.56s
#
# 265
# Epoch duration =0.16s
# Cumulative duration =38.72s
#
# 266
# Epoch duration =0.2s
# Cumulative duration =38.92s
#
# 267
# Epoch duration =0.17s
# Cumulative duration =39.09s
#
# 268
# Epoch duration =0.19s
# Cumulative duration =39.28s
#
# 269
# Epoch duration =0.19s
# Cumulative duration =39.47s
#
# 270
# Epoch duration =0.19s
# Cumulative duration =39.66s
#
# 271
# Epoch duration =0.16s
# Cumulative duration =39.82s
#
# 272
# Epoch duration =0.19s
# Cumulative duration =40.01s
#
# 273
# Epoch duration =0.17s
# Cumulative duration =40.18s
#
# 274
# Epoch duration =0.14s
# Cumulative duration =40.33s
#
# 275
# Epoch duration =0.14s
# Cumulative duration =40.46s
#
# 276
# Epoch duration =0.14s
# Cumulative duration =40.61s
#
# 277
# Epoch duration =0.14s
# Cumulative duration =40.75s
#
# 278
# Epoch duration =0.16s
# Cumulative duration =40.91s
#
# 279
# Epoch duration =0.15s
# Cumulative duration =41.06s
#
# 280
# Epoch duration =0.18s
# Cumulative duration =41.24s
#
# 281
# Epoch duration =0.19s
# Cumulative duration =41.43s
#
# 282
# Epoch duration =0.15s
# Cumulative duration =41.57s
#
# 283
# Epoch duration =0.18s
# Cumulative duration =41.75s
#
# 284
# Epoch duration =0.2s
# Cumulative duration =41.95s
#
# 285
# Epoch duration =0.16s
# Cumulative duration =42.11s
#
# 286
# Epoch duration =0.14s
# Cumulative duration =42.25s
#
# 287
# Epoch duration =0.14s
# Cumulative duration =42.39s
#
# 288
# Epoch duration =0.18s
# Cumulative duration =42.58s
#
# 289
# Epoch duration =0.2s
# Cumulative duration =42.77s
#
# 290
# Epoch duration =0.14s
# Cumulative duration =42.92s
#
# 291
# Epoch duration =0.2s
# Cumulative duration =43.11s
#
# 292
# Epoch duration =0.21s
# Cumulative duration =43.33s
#
# 293
# Epoch duration =0.14s
# Cumulative duration =43.47s
#
# 294
# Epoch duration =0.14s
# Cumulative duration =43.61s
#
# 295
# Epoch duration =0.15s
# Cumulative duration =43.76s
#
# 296
# Epoch duration =0.14s
# Cumulative duration =43.9s
#
# 297
# Epoch duration =0.19s
# Cumulative duration =44.09s
#
# 298
# Epoch duration =0.19s
# Cumulative duration =44.28s
#
# 299
# Epoch duration =0.25s
# Cumulative duration =44.52s
#
# 300
# Epoch duration =0.15s
# Cumulative duration =44.68s
#
# 301
# Epoch duration =0.14s
# Cumulative duration =44.82s
#
# 302
# Epoch duration =0.14s
# Cumulative duration =44.96s
#
# 303
# Epoch duration =0.17s
# Cumulative duration =45.13s
#
# 304
# Epoch duration =0.21s
# Cumulative duration =45.34s
#
# 305
# Epoch duration =0.14s
# Cumulative duration =45.48s
#
# 306
# Epoch duration =0.14s
# Cumulative duration =45.63s
#
# 307
# Epoch duration =0.14s
# Cumulative duration =45.76s
#
# 308
# Epoch duration =0.14s
# Cumulative duration =45.91s
#
# 309
# Epoch duration =0.14s
# Cumulative duration =46.05s
#
# 310
# Epoch duration =0.15s
# Cumulative duration =46.19s
#
# 311
# Epoch duration =0.14s
# Cumulative duration =46.33s
#
# 312
# Epoch duration =0.17s
# Cumulative duration =46.51s
#
# 313
# Epoch duration =0.21s
# Cumulative duration =46.72s
#
# 314
# Epoch duration =0.15s
# Cumulative duration =46.86s
#
# 315
# Epoch duration =0.2s
# Cumulative duration =47.07s
#
# 316
# Epoch duration =0.15s
# Cumulative duration =47.22s
#
# 317
# Epoch duration =0.2s
# Cumulative duration =47.42s
#
# 318
# Epoch duration =0.17s
# Cumulative duration =47.59s
#
# 319
# Epoch duration =0.19s
# Cumulative duration =47.78s
#
# 320
# Epoch duration =0.2s
# Cumulative duration =47.98s
#
# 321
# Epoch duration =0.15s
# Cumulative duration =48.12s
#
# 322
# Epoch duration =0.14s
# Cumulative duration =48.27s
#
# 323
# Epoch duration =0.14s
# Cumulative duration =48.41s
#
# 324
# Epoch duration =0.15s
# Cumulative duration =48.56s
#
# 325
# Epoch duration =0.15s
# Cumulative duration =48.71s
#
# 326
# Epoch duration =0.15s
# Cumulative duration =48.85s
#
# 327
# Epoch duration =0.15s
# Cumulative duration =49.0s
#
# 328
# Epoch duration =0.15s
# Cumulative duration =49.15s
#
# 329
# Epoch duration =0.15s
# Cumulative duration =49.29s
#
# 330
# Epoch duration =0.15s
# Cumulative duration =49.44s
#
# 331
# Epoch duration =0.14s
# Cumulative duration =49.58s
#
# 332
# Epoch duration =0.14s
# Cumulative duration =49.72s
#
# 333
# Epoch duration =0.14s
# Cumulative duration =49.86s
#
# 334
# Epoch duration =0.14s
# Cumulative duration =50.01s
#
# 335
# Epoch duration =0.14s
# Cumulative duration =50.15s
#
# 336
# Epoch duration =0.14s
# Cumulative duration =50.29s
#
# 337
# Epoch duration =0.14s
# Cumulative duration =50.44s
#
# 338
# Epoch duration =0.14s
# Cumulative duration =50.58s
#
# 339
# Epoch duration =0.14s
# Cumulative duration =50.72s
#
# 340
# Epoch duration =0.14s
# Cumulative duration =50.86s
#
# 341
# Epoch duration =0.14s
# Cumulative duration =51.0s
#
# 342
# Epoch duration =0.14s
# Cumulative duration =51.15s
#
# 343
# Epoch duration =0.14s
# Cumulative duration =51.29s
#
# 344
# Epoch duration =0.14s
# Cumulative duration =51.43s
#
# 345
# Epoch duration =0.15s
# Cumulative duration =51.58s
#
# 346
# Epoch duration =0.15s
# Cumulative duration =51.73s
#
# 347
# Epoch duration =0.14s
# Cumulative duration =51.88s
#
# 348
# Epoch duration =0.15s
# Cumulative duration =52.02s
#
# 349
# Epoch duration =0.16s
# Cumulative duration =52.18s
#
# 350
# Epoch duration =0.14s
# Cumulative duration =52.32s
#
# 351
# Epoch duration =0.14s
# Cumulative duration =52.46s
#
# 352
# Epoch duration =0.15s
# Cumulative duration =52.61s
#
# 353
# Epoch duration =0.15s
# Cumulative duration =52.76s
#
# 354
# Epoch duration =0.14s
# Cumulative duration =52.9s
#
# 355
# Epoch duration =0.14s
# Cumulative duration =53.04s
#
# 356
# Epoch duration =0.14s
# Cumulative duration =53.19s
#
# 357
# Epoch duration =0.14s
# Cumulative duration =53.33s
#
# 358
# Epoch duration =0.14s
# Cumulative duration =53.47s
#
# 359
# Epoch duration =0.14s
# Cumulative duration =53.62s
#
# 360
# Epoch duration =0.14s
# Cumulative duration =53.76s
#
# 361
# Epoch duration =0.14s
# Cumulative duration =53.9s
#
# 362
# Epoch duration =0.14s
# Cumulative duration =54.05s
#
# 363
# Epoch duration =0.14s
# Cumulative duration =54.19s
#
# 364
# Epoch duration =0.14s
# Cumulative duration =54.33s
#
# 365
# Epoch duration =0.14s
# Cumulative duration =54.47s
#
# 366
# Epoch duration =0.14s
# Cumulative duration =54.61s
#
# 367
# Epoch duration =0.14s
# Cumulative duration =54.76s
#
# 368
# Epoch duration =0.14s
# Cumulative duration =54.9s
#
# 369
# Epoch duration =0.14s
# Cumulative duration =55.04s
#
# 370
# Epoch duration =0.14s
# Cumulative duration =55.18s
#
# 371
# Epoch duration =0.14s
# Cumulative duration =55.32s
#
# 372
# Epoch duration =0.14s
# Cumulative duration =55.46s
#
# 373
# Epoch duration =0.15s
# Cumulative duration =55.61s
#
# 374
# Epoch duration =0.15s
# Cumulative duration =55.75s
#
# 375
# Epoch duration =0.15s
# Cumulative duration =55.9s
#
# 376
# Epoch duration =0.14s
# Cumulative duration =56.04s
#
# 377
# Epoch duration =0.14s
# Cumulative duration =56.18s
#
# 378
# Epoch duration =0.14s
# Cumulative duration =56.32s
#
# 379
# Epoch duration =0.14s
# Cumulative duration =56.46s
#
# 380
# Epoch duration =0.14s
# Cumulative duration =56.61s
#
# 381
# Epoch duration =0.15s
# Cumulative duration =56.75s
#
# 382
# Epoch duration =0.14s
# Cumulative duration =56.89s
#
# 383
# Epoch duration =0.15s
# Cumulative duration =57.04s
#
# 384
# Epoch duration =0.15s
# Cumulative duration =57.19s
#
# 385
# Epoch duration =0.14s
# Cumulative duration =57.33s
#
# 386
# Epoch duration =0.15s
# Cumulative duration =57.48s
#
# 387
# Epoch duration =0.14s
# Cumulative duration =57.62s
#
# 388
# Epoch duration =0.15s
# Cumulative duration =57.77s
#
# 389
# Epoch duration =0.14s
# Cumulative duration =57.91s
#
# 390
# Epoch duration =0.15s
# Cumulative duration =58.06s
#
# 391
# Epoch duration =0.14s
# Cumulative duration =58.2s
#
# 392
# Epoch duration =0.14s
# Cumulative duration =58.34s
#
# 393
# Epoch duration =0.14s
# Cumulative duration =58.48s
#
# 394
# Epoch duration =0.17s
# Cumulative duration =58.65s
#
# 395
# Epoch duration =0.16s
# Cumulative duration =58.81s
#
# 396
# Epoch duration =0.14s
# Cumulative duration =58.95s
#
# 397
# Epoch duration =0.15s
# Cumulative duration =59.1s
#
# 398
# Epoch duration =0.14s
# Cumulative duration =59.24s
#
# 399
# Epoch duration =0.16s
# Cumulative duration =59.4s
#
# 400
# Epoch duration =0.15s
# Cumulative duration =59.55s
#
# 401
# Epoch duration =0.16s
# Cumulative duration =59.71s
#
# 402
# Epoch duration =0.14s
# Cumulative duration =59.85s
#
# 403
# Epoch duration =0.15s
# Cumulative duration =60.0s
#
# 404
# Epoch duration =0.14s
# Cumulative duration =60.14s
#
# 405
# Epoch duration =0.14s
# Cumulative duration =60.28s
#
# 406
# Epoch duration =0.14s
# Cumulative duration =60.42s
#
# 407
# Epoch duration =0.14s
# Cumulative duration =60.57s
#
# 408
# Epoch duration =0.14s
# Cumulative duration =60.71s
#
# 409
# Epoch duration =0.15s
# Cumulative duration =60.86s
#
# 410
# Epoch duration =0.15s
# Cumulative duration =61.0s
#
# 411
# Epoch duration =0.15s
# Cumulative duration =61.15s
#
# 412
# Epoch duration =0.14s
# Cumulative duration =61.29s
#
# 413
# Epoch duration =0.16s
# Cumulative duration =61.45s
#
# 414
# Epoch duration =0.14s
# Cumulative duration =61.59s
#
# 415
# Epoch duration =0.14s
# Cumulative duration =61.74s
#
# 416
# Epoch duration =0.14s
# Cumulative duration =61.88s
#
# 417
# Epoch duration =0.14s
# Cumulative duration =62.02s
#
# 418
# Epoch duration =0.14s
# Cumulative duration =62.16s
#
# 419
# Epoch duration =0.14s
# Cumulative duration =62.3s
#
# 420
# Epoch duration =0.15s
# Cumulative duration =62.45s
#
# 421
# Epoch duration =0.14s
# Cumulative duration =62.59s
#
# 422
# Epoch duration =0.14s
# Cumulative duration =62.73s
#
# 423
# Epoch duration =0.15s
# Cumulative duration =62.89s
#
# 424
# Epoch duration =0.14s
# Cumulative duration =63.03s
#
# 425
# Epoch duration =0.15s
# Cumulative duration =63.17s
#
# 426
# Epoch duration =0.14s
# Cumulative duration =63.31s
#
# 427
# Epoch duration =0.14s
# Cumulative duration =63.46s
#
# 428
# Epoch duration =0.14s
# Cumulative duration =63.6s
#
# 429
# Epoch duration =0.15s
# Cumulative duration =63.74s
#
# 430
# Epoch duration =0.14s
# Cumulative duration =63.89s
#
# 431
# Epoch duration =0.14s
# Cumulative duration =64.03s
#
# 432
# Epoch duration =0.14s
# Cumulative duration =64.17s
#
# 433
# Epoch duration =0.14s
# Cumulative duration =64.32s
#
# 434
# Epoch duration =0.14s
# Cumulative duration =64.46s
#
# 435
# Epoch duration =0.14s
# Cumulative duration =64.6s
#
# 436
# Epoch duration =0.14s
# Cumulative duration =64.75s
#
# 437
# Epoch duration =0.15s
# Cumulative duration =64.9s
#
# 438
# Epoch duration =0.14s
# Cumulative duration =65.04s
#
# 439
# Epoch duration =0.16s
# Cumulative duration =65.2s
#
# 440
# Epoch duration =0.14s
# Cumulative duration =65.34s
#
# 441
# Epoch duration =0.16s
# Cumulative duration =65.5s
#
# 442
# Epoch duration =0.14s
# Cumulative duration =65.64s
#
# 443
# Epoch duration =0.14s
# Cumulative duration =65.78s
#
# 444
# Epoch duration =0.14s
# Cumulative duration =65.92s
#
# 445
# Epoch duration =0.14s
# Cumulative duration =66.06s
#
# 446
# Epoch duration =0.14s
# Cumulative duration =66.2s
#
# 447
# Epoch duration =0.14s
# Cumulative duration =66.35s
#
# 448
# Epoch duration =0.14s
# Cumulative duration =66.49s
#
# 449
# Epoch duration =0.14s
# Cumulative duration =66.63s
#
# 450
# Epoch duration =0.14s
# Cumulative duration =66.78s
#
# 451
# Epoch duration =0.14s
# Cumulative duration =66.91s
#
# 452
# Epoch duration =0.14s
# Cumulative duration =67.06s
#
# 453
# Epoch duration =0.15s
# Cumulative duration =67.21s
#
# 454
# Epoch duration =0.14s
# Cumulative duration =67.35s
#
# 455
# Epoch duration =0.14s
# Cumulative duration =67.49s
#
# 456
# Epoch duration =0.14s
# Cumulative duration =67.63s
#
# 457
# Epoch duration =0.14s
# Cumulative duration =67.77s
#
# 458
# Epoch duration =0.14s
# Cumulative duration =67.91s
#
# 459
# Epoch duration =0.14s
# Cumulative duration =68.06s
#
# 460
# Epoch duration =0.15s
# Cumulative duration =68.21s
#
# 461
# Epoch duration =0.15s
# Cumulative duration =68.35s
#
# 462
# Epoch duration =0.14s
# Cumulative duration =68.49s
#
# 463
# Epoch duration =0.14s
# Cumulative duration =68.64s
#
# 464
# Epoch duration =0.14s
# Cumulative duration =68.78s
#
# 465
# Epoch duration =0.14s
# Cumulative duration =68.92s
#
# 466
# Epoch duration =0.14s
# Cumulative duration =69.06s
#
# 467
# Epoch duration =0.14s
# Cumulative duration =69.2s
#
# 468
# Epoch duration =0.14s
# Cumulative duration =69.34s
#
# 469
# Epoch duration =0.14s
# Cumulative duration =69.48s
#
# 470
# Epoch duration =0.14s
# Cumulative duration =69.62s
#
# 471
# Epoch duration =0.14s
# Cumulative duration =69.77s
#
# 472
# Epoch duration =0.14s
# Cumulative duration =69.9s
#
# 473
# Epoch duration =0.14s
# Cumulative duration =70.05s
#
# 474
# Epoch duration =0.14s
# Cumulative duration =70.19s
#
# 475
# Epoch duration =0.14s
# Cumulative duration =70.32s
#
# 476
# Epoch duration =0.14s
# Cumulative duration =70.46s
#
# 477
# Epoch duration =0.14s
# Cumulative duration =70.61s
#
# 478
# Epoch duration =0.14s
# Cumulative duration =70.75s
#
# 479
# Epoch duration =0.15s
# Cumulative duration =70.9s
#
# 480
# Epoch duration =0.14s
# Cumulative duration =71.05s
#
# 481
# Epoch duration =0.14s
# Cumulative duration =71.18s
#
# 482
# Epoch duration =0.14s
# Cumulative duration =71.33s
#
# 483
# Epoch duration =0.16s
# Cumulative duration =71.48s
#
# 484
# Epoch duration =0.14s
# Cumulative duration =71.62s
#
# 485
# Epoch duration =0.14s
# Cumulative duration =71.77s
#
# 486
# Epoch duration =0.14s
# Cumulative duration =71.91s
#
# 487
# Epoch duration =0.14s
# Cumulative duration =72.05s
#
# 488
# Epoch duration =0.14s
# Cumulative duration =72.19s
#
# 489
# Epoch duration =0.14s
# Cumulative duration =72.33s
#
# 490
# Epoch duration =0.14s
# Cumulative duration =72.47s
#
# 491
# Epoch duration =0.14s
# Cumulative duration =72.62s
#
# 492
# Epoch duration =0.14s
# Cumulative duration =72.76s
#
# 493
# Epoch duration =0.14s
# Cumulative duration =72.9s
#
# 494
# Epoch duration =0.14s
# Cumulative duration =73.04s
#
# 495
# Epoch duration =0.14s
# Cumulative duration =73.18s
#
# 496
# Epoch duration =0.14s
# Cumulative duration =73.33s
#
# 497
# Epoch duration =0.14s
# Cumulative duration =73.46s
#
# 498
# Epoch duration =0.14s
# Cumulative duration =73.61s
#
# 499
# Epoch duration =0.14s
# Cumulative duration =73.75s
#
# 500
# Epoch duration =0.14s
# Cumulative duration =73.89s
#
# 501
# Epoch duration =0.14s
# Cumulative duration =74.03s
#
# 502
# Epoch duration =0.14s
# Cumulative duration =74.17s
#
# 503
# Epoch duration =0.14s
# Cumulative duration =74.32s
#
# 504
# Epoch duration =0.14s
# Cumulative duration =74.46s
#
# 505
# Epoch duration =0.14s
# Cumulative duration =74.6s
#
# 506
# Epoch duration =0.14s
# Cumulative duration =74.75s
#
# 507
# Epoch duration =0.15s
# Cumulative duration =74.9s
#
# 508
# Epoch duration =0.14s
# Cumulative duration =75.04s
#
# 509
# Epoch duration =0.15s
# Cumulative duration =75.19s
#
# 510
# Epoch duration =0.14s
# Cumulative duration =75.33s
#
# 511
# Epoch duration =0.14s
# Cumulative duration =75.47s
#
# 512
# Epoch duration =0.14s
# Cumulative duration =75.61s
#
# 513
# Epoch duration =0.14s
# Cumulative duration =75.75s
#
# 514
# Epoch duration =0.14s
# Cumulative duration =75.89s
#
# 515
# Epoch duration =0.14s
# Cumulative duration =76.03s
#
# 516
# Epoch duration =0.14s
# Cumulative duration =76.18s
#
# 517
# Epoch duration =0.14s
# Cumulative duration =76.31s
#
# 518
# Epoch duration =0.14s
# Cumulative duration =76.45s
#
# 519
# Epoch duration =0.14s
# Cumulative duration =76.6s
#
# 520
# Epoch duration =0.14s
# Cumulative duration =76.74s
#
# 521
# Epoch duration =0.14s
# Cumulative duration =76.88s
#
# 522
# Epoch duration =0.15s
# Cumulative duration =77.03s
#
# 523
# Epoch duration =0.14s
# Cumulative duration =77.17s
#
# 524
# Epoch duration =0.14s
# Cumulative duration =77.31s
#
# 525
# Epoch duration =0.14s
# Cumulative duration =77.45s
#
# 526
# Epoch duration =0.14s
# Cumulative duration =77.59s
#
# 527
# Epoch duration =0.14s
# Cumulative duration =77.73s
#
# 528
# Epoch duration =0.14s
# Cumulative duration =77.88s
#
# 529
# Epoch duration =0.14s
# Cumulative duration =78.02s
#
# 530
# Epoch duration =0.14s
# Cumulative duration =78.16s
#
# 531
# Epoch duration =0.14s
# Cumulative duration =78.3s
#
# 532
# Epoch duration =0.14s
# Cumulative duration =78.44s
#
# 533
# Epoch duration =0.14s
# Cumulative duration =78.58s
#
# 534
# Epoch duration =0.14s
# Cumulative duration =78.73s
#
# 535
# Epoch duration =0.14s
# Cumulative duration =78.87s
#
# 536
# Epoch duration =0.14s
# Cumulative duration =79.01s
#
# 537
# Epoch duration =0.16s
# Cumulative duration =79.17s
#
# 538
# Epoch duration =0.14s
# Cumulative duration =79.31s
#
# 539
# Epoch duration =0.14s
# Cumulative duration =79.45s
#
# 540
# Epoch duration =0.14s
# Cumulative duration =79.59s
#
# 541
# Epoch duration =0.14s
# Cumulative duration =79.74s
#
# 542
# Epoch duration =0.14s
# Cumulative duration =79.88s
#
# 543
# Epoch duration =0.14s
# Cumulative duration =80.02s
#
# 544
# Epoch duration =0.14s
# Cumulative duration =80.16s
#
# 545
# Epoch duration =0.15s
# Cumulative duration =80.31s
#
# 546
# Epoch duration =0.14s
# Cumulative duration =80.45s
#
# 547
# Epoch duration =0.14s
# Cumulative duration =80.59s
#
# 548
# Epoch duration =0.15s
# Cumulative duration =80.74s
#
# 549
# Epoch duration =0.14s
# Cumulative duration =80.88s
#
# 550
# Epoch duration =0.14s
# Cumulative duration =81.03s
#
# 551
# Epoch duration =0.14s
# Cumulative duration =81.17s
#
# 552
# Epoch duration =0.14s
# Cumulative duration =81.31s
#
# 553
# Epoch duration =0.15s
# Cumulative duration =81.45s
#
# 554
# Epoch duration =0.14s
# Cumulative duration =81.6s
#
# 555
# Epoch duration =0.14s
# Cumulative duration =81.74s
#
# 556
# Epoch duration =0.14s
# Cumulative duration =81.88s
#
# 557
# Epoch duration =0.14s
# Cumulative duration =82.02s
#
# 558
# Epoch duration =0.14s
# Cumulative duration =82.17s
#
# 559
# Epoch duration =0.14s
# Cumulative duration =82.31s
#
# 560
# Epoch duration =0.14s
# Cumulative duration =82.45s
#
# 561
# Epoch duration =0.14s
# Cumulative duration =82.59s
#
# 562
# Epoch duration =0.14s
# Cumulative duration =82.73s
#
# 563
# Epoch duration =0.15s
# Cumulative duration =82.89s
#
# 564
# Epoch duration =0.14s
# Cumulative duration =83.03s
#
# 565
# Epoch duration =0.14s
# Cumulative duration =83.17s
#
# 566
# Epoch duration =0.14s
# Cumulative duration =83.31s
#
# 567
# Epoch duration =0.15s
# Cumulative duration =83.46s
#
# 568
# Epoch duration =0.14s
# Cumulative duration =83.6s
#
# 569
# Epoch duration =0.14s
# Cumulative duration =83.74s
#
# 570
# Epoch duration =0.14s
# Cumulative duration =83.88s
#
# 571
# Epoch duration =0.14s
# Cumulative duration =84.03s
#
# 572
# Epoch duration =0.14s
# Cumulative duration =84.17s
#
# 573
# Epoch duration =0.14s
# Cumulative duration =84.31s
#
# 574
# Epoch duration =0.14s
# Cumulative duration =84.45s
#
# 575
# Epoch duration =0.14s
# Cumulative duration =84.59s
#
# 576
# Epoch duration =0.14s
# Cumulative duration =84.74s
#
# 577
# Epoch duration =0.14s
# Cumulative duration =84.88s
#
# 578
# Epoch duration =0.14s
# Cumulative duration =85.02s
#
# 579
# Epoch duration =0.14s
# Cumulative duration =85.17s
#
# 580
# Epoch duration =0.14s
# Cumulative duration =85.31s
#
# 581
# Epoch duration =0.14s
# Cumulative duration =85.45s
#
# 582
# Epoch duration =0.14s
# Cumulative duration =85.59s
#
# 583
# Epoch duration =0.16s
# Cumulative duration =85.75s
#
# 584
# Epoch duration =0.14s
# Cumulative duration =85.89s
#
# 585
# Epoch duration =0.14s
# Cumulative duration =86.03s
#
# 586
# Epoch duration =0.14s
# Cumulative duration =86.18s
#
# 587
# Epoch duration =0.14s
# Cumulative duration =86.32s
#
# 588
# Epoch duration =0.14s
# Cumulative duration =86.46s
#
# 589
# Epoch duration =0.14s
# Cumulative duration =86.6s
#
# 590
# Epoch duration =0.14s
# Cumulative duration =86.74s
#
# 591
# Epoch duration =0.14s
# Cumulative duration =86.88s
#
# 592
# Epoch duration =0.14s
# Cumulative duration =87.02s
#
# 593
# Epoch duration =0.14s
# Cumulative duration =87.17s
#
# 594
# Epoch duration =0.14s
# Cumulative duration =87.31s
#
# 595
# Epoch duration =0.14s
# Cumulative duration =87.44s
#
# 596
# Epoch duration =0.14s
# Cumulative duration =87.59s
#
# 597
# Epoch duration =0.16s
# Cumulative duration =87.75s
#
# 598
# Epoch duration =0.14s
# Cumulative duration =87.88s
#
# 599
# Epoch duration =0.14s
# Cumulative duration =88.03s
#
# 600
# Epoch duration =0.14s
# Cumulative duration =88.17s
#
# 601
# Epoch duration =0.14s
# Cumulative duration =88.31s
#
# 602
# Epoch duration =0.14s
# Cumulative duration =88.45s
#
# 603
# Epoch duration =0.14s
# Cumulative duration =88.59s
#
# 604
# Epoch duration =0.14s
# Cumulative duration =88.73s
#
# 605
# Epoch duration =0.14s
# Cumulative duration =88.87s
#
# 606
# Epoch duration =0.14s
# Cumulative duration =89.01s
#
# 607
# Epoch duration =0.14s
# Cumulative duration =89.16s
#
# 608
# Epoch duration =0.14s
# Cumulative duration =89.3s
#
# 609
# Epoch duration =0.14s
# Cumulative duration =89.44s
#
# 610
# Epoch duration =0.14s
# Cumulative duration =89.58s
#
# 611
# Epoch duration =0.15s
# Cumulative duration =89.72s
#
# 612
# Epoch duration =0.16s
# Cumulative duration =89.88s
#
# 613
# Epoch duration =0.15s
# Cumulative duration =90.03s
#
# 614
# Epoch duration =0.14s
# Cumulative duration =90.18s
#
# 615
# Epoch duration =0.15s
# Cumulative duration =90.32s
#
# 616
# Epoch duration =0.14s
# Cumulative duration =90.47s
#
# 617
# Epoch duration =0.15s
# Cumulative duration =90.62s
#
# 618
# Epoch duration =0.14s
# Cumulative duration =90.76s
#
# 619
# Epoch duration =0.14s
# Cumulative duration =90.9s
#
# 620
# Epoch duration =0.15s
# Cumulative duration =91.05s
#
# 621
# Epoch duration =0.15s
# Cumulative duration =91.2s
#
# 622
# Epoch duration =0.14s
# Cumulative duration =91.34s
#
# 623
# Epoch duration =0.14s
# Cumulative duration =91.48s
#
# 624
# Epoch duration =0.2s
# Cumulative duration =91.68s
#
# 625
# Epoch duration =0.16s
# Cumulative duration =91.84s
#
# 626
# Epoch duration =0.2s
# Cumulative duration =92.04s
#
# 627
# Epoch duration =0.15s
# Cumulative duration =92.19s
#
# 628
# Epoch duration =0.19s
# Cumulative duration =92.38s
#
# 629
# Epoch duration =0.16s
# Cumulative duration =92.54s
#
# 630
# Epoch duration =0.2s
# Cumulative duration =92.74s
#
# 631
# Epoch duration =0.16s
# Cumulative duration =92.9s
#
# 632
# Epoch duration =0.22s
# Cumulative duration =93.12s
#
# 633
# Epoch duration =0.15s
# Cumulative duration =93.27s
#
# 634
# Epoch duration =0.17s
# Cumulative duration =93.44s
#
# 635
# Epoch duration =0.14s
# Cumulative duration =93.58s
#
# 636
# Epoch duration =0.15s
# Cumulative duration =93.73s
#
# 637
# Epoch duration =0.21s
# Cumulative duration =93.94s
#
# 638
# Epoch duration =0.16s
# Cumulative duration =94.1s
#
# 639
# Epoch duration =0.2s
# Cumulative duration =94.3s
#
# 640
# Epoch duration =0.18s
# Cumulative duration =94.48s
#
# 641
# Epoch duration =0.17s
# Cumulative duration =94.65s
#
# 642
# Epoch duration =0.18s
# Cumulative duration =94.83s
#
# 643
# Epoch duration =0.17s
# Cumulative duration =95.0s
#
# 644
# Epoch duration =0.14s
# Cumulative duration =95.14s
#
# 645
# Epoch duration =0.15s
# Cumulative duration =95.29s
#
# 646
# Epoch duration =0.14s
# Cumulative duration =95.43s
#
# 647
# Epoch duration =0.16s
# Cumulative duration =95.6s
#
# 648
# Epoch duration =0.14s
# Cumulative duration =95.73s
#
# 649
# Epoch duration =0.15s
# Cumulative duration =95.88s
#
# 650
# Epoch duration =0.15s
# Cumulative duration =96.03s
#
# 651
# Epoch duration =0.15s
# Cumulative duration =96.19s
#
# 652
# Epoch duration =0.16s
# Cumulative duration =96.35s
#
# 653
# Epoch duration =0.15s
# Cumulative duration =96.49s
#
# 654
# Epoch duration =0.15s
# Cumulative duration =96.64s
#
# 655
# Epoch duration =0.14s
# Cumulative duration =96.78s
#
# 656
# Epoch duration =0.14s
# Cumulative duration =96.93s
#
# 657
# Epoch duration =0.14s
# Cumulative duration =97.07s
#
# 658
# Epoch duration =0.14s
# Cumulative duration =97.21s
#
# 659
# Epoch duration =0.16s
# Cumulative duration =97.37s
#
# 660
# Epoch duration =0.14s
# Cumulative duration =97.52s
#
# 661
# Epoch duration =0.14s
# Cumulative duration =97.66s
#
# 662
# Epoch duration =0.14s
# Cumulative duration =97.8s
#
# 663
# Epoch duration =0.15s
# Cumulative duration =97.95s
#
# 664
# Epoch duration =0.14s
# Cumulative duration =98.09s
#
# 665
# Epoch duration =0.14s
# Cumulative duration =98.23s
#
# 666
# Epoch duration =0.14s
# Cumulative duration =98.37s
#
# 667
# Epoch duration =0.17s
# Cumulative duration =98.54s
#
# 668
# Epoch duration =0.14s
# Cumulative duration =98.68s
#
# 669
# Epoch duration =0.14s
# Cumulative duration =98.82s
#
# 670
# Epoch duration =0.14s
# Cumulative duration =98.96s
#
# 671
# Epoch duration =0.14s
# Cumulative duration =99.1s
#
# 672
# Epoch duration =0.14s
# Cumulative duration =99.24s
#
# 673
# Epoch duration =0.14s
# Cumulative duration =99.39s
#
# 674
# Epoch duration =0.14s
# Cumulative duration =99.52s
#
# 675
# Epoch duration =0.16s
# Cumulative duration =99.68s
#
# 676
# Epoch duration =0.14s
# Cumulative duration =99.83s
#
# 677
# Epoch duration =0.14s
# Cumulative duration =99.97s
#
# 678
# Epoch duration =0.14s
# Cumulative duration =100.11s
#
# 679
# Epoch duration =0.16s
# Cumulative duration =100.27s
#
# 680
# Epoch duration =0.14s
# Cumulative duration =100.41s
#
# 681
# Epoch duration =0.14s
# Cumulative duration =100.56s
#
# 682
# Epoch duration =0.14s
# Cumulative duration =100.7s
#
# 683
# Epoch duration =0.14s
# Cumulative duration =100.84s
#
# 684
# Epoch duration =0.14s
# Cumulative duration =100.98s
#
# 685
# Epoch duration =0.15s
# Cumulative duration =101.13s
#
# 686
# Epoch duration =0.14s
# Cumulative duration =101.27s
#
# 687
# Epoch duration =0.14s
# Cumulative duration =101.41s
#
# 688
# Epoch duration =0.14s
# Cumulative duration =101.56s
#
# 689
# Epoch duration =0.14s
# Cumulative duration =101.7s
#
# 690
# Epoch duration =0.14s
# Cumulative duration =101.84s
#
# 691
# Epoch duration =0.15s
# Cumulative duration =102.0s
#
# 692
# Epoch duration =0.14s
# Cumulative duration =102.14s
#
# 693
# Epoch duration =0.14s
# Cumulative duration =102.28s
#
# 694
# Epoch duration =0.14s
# Cumulative duration =102.42s
#
# 695
# Epoch duration =0.14s
# Cumulative duration =102.56s
#
# 696
# Epoch duration =0.14s
# Cumulative duration =102.7s
#
# 697
# Epoch duration =0.14s
# Cumulative duration =102.84s
#
# 698
# Epoch duration =0.14s
# Cumulative duration =102.98s
#
# 699
# Epoch duration =0.14s
# Cumulative duration =103.12s
#
# 700
# Epoch duration =0.14s
# Cumulative duration =103.27s
#
# 701
# Epoch duration =0.14s
# Cumulative duration =103.41s
#
# 702
# Epoch duration =0.14s
# Cumulative duration =103.55s
#
# 703
# Epoch duration =0.14s
# Cumulative duration =103.69s
#
# 704
# Epoch duration =0.14s
# Cumulative duration =103.83s
#
# 705
# Epoch duration =0.14s
# Cumulative duration =103.98s
#
# 706
# Epoch duration =0.14s
# Cumulative duration =104.12s
#
# 707
# Epoch duration =0.15s
# Cumulative duration =104.27s
#
# 708
# Epoch duration =0.14s
# Cumulative duration =104.41s
#
# 709
# Epoch duration =0.14s
# Cumulative duration =104.55s
#
# 710
# Epoch duration =0.14s
# Cumulative duration =104.69s
#
# 711
# Epoch duration =0.14s
# Cumulative duration =104.83s
#
# 712
# Epoch duration =0.14s
# Cumulative duration =104.97s
#
# 713
# Epoch duration =0.14s
# Cumulative duration =105.12s
#
# 714
# Epoch duration =0.14s
# Cumulative duration =105.26s
#
# 715
# Epoch duration =0.14s
# Cumulative duration =105.4s
#
# 716
# Epoch duration =0.14s
# Cumulative duration =105.55s
#
# 717
# Epoch duration =0.15s
# Cumulative duration =105.69s
#
# 718
# Epoch duration =0.14s
# Cumulative duration =105.83s
#
# 719
# Epoch duration =0.14s
# Cumulative duration =105.97s
#
# 720
# Epoch duration =0.14s
# Cumulative duration =106.12s
#
# 721
# Epoch duration =0.14s
# Cumulative duration =106.26s
#
# 722
# Epoch duration =0.14s
# Cumulative duration =106.4s
#
# 723
# Epoch duration =0.14s
# Cumulative duration =106.54s
#
# 724
# Epoch duration =0.14s
# Cumulative duration =106.68s
#
# 725
# Epoch duration =0.14s
# Cumulative duration =106.83s
#
# 726
# Epoch duration =0.14s
# Cumulative duration =106.97s
#
# 727
# Epoch duration =0.14s
# Cumulative duration =107.11s
#
# 728
# Epoch duration =0.15s
# Cumulative duration =107.26s
#
# 729
# Epoch duration =0.14s
# Cumulative duration =107.4s
#
# 730
# Epoch duration =0.14s
# Cumulative duration =107.54s
#
# 731
# Epoch duration =0.14s
# Cumulative duration =107.68s
#
# 732
# Epoch duration =0.14s
# Cumulative duration =107.83s
#
# 733
# Epoch duration =0.14s
# Cumulative duration =107.97s
#
# 734
# Epoch duration =0.14s
# Cumulative duration =108.11s
#
# 735
# Epoch duration =0.14s
# Cumulative duration =108.25s
#
# 736
# Epoch duration =0.14s
# Cumulative duration =108.39s
#
# 737
# Epoch duration =0.14s
# Cumulative duration =108.54s
#
# 738
# Epoch duration =0.14s
# Cumulative duration =108.67s
#
# 739
# Epoch duration =0.14s
# Cumulative duration =108.82s
#
# 740
# Epoch duration =0.14s
# Cumulative duration =108.96s
#
# 741
# Epoch duration =0.14s
# Cumulative duration =109.1s
#
# 742
# Epoch duration =0.14s
# Cumulative duration =109.24s
#
# 743
# Epoch duration =0.14s
# Cumulative duration =109.38s
#
# 744
# Epoch duration =0.14s
# Cumulative duration =109.53s
#
# 745
# Epoch duration =0.14s
# Cumulative duration =109.67s
#
# 746
# Epoch duration =0.19s
# Cumulative duration =109.85s
#
# 747
# Epoch duration =0.2s
# Cumulative duration =110.06s
#
# 748
# Epoch duration =0.21s
# Cumulative duration =110.26s
#
# 749
# Epoch duration =0.15s
# Cumulative duration =110.41s
#
# 750
# Epoch duration =0.18s
# Cumulative duration =110.59s
#
# 751
# Epoch duration =0.18s
# Cumulative duration =110.76s
#
# 752
# Epoch duration =0.14s
# Cumulative duration =110.91s
#
# 753
# Epoch duration =0.21s
# Cumulative duration =111.12s
#
# 754
# Epoch duration =0.14s
# Cumulative duration =111.26s
#
# 755
# Epoch duration =0.19s
# Cumulative duration =111.45s
#
# 756
# Epoch duration =0.21s
# Cumulative duration =111.66s
#
# 757
# Epoch duration =0.19s
# Cumulative duration =111.85s
#
# 758
# Epoch duration =0.2s
# Cumulative duration =112.05s
#
# 759
# Epoch duration =0.17s
# Cumulative duration =112.21s
#
# 760
# Epoch duration =0.14s
# Cumulative duration =112.36s
#
# 761
# Epoch duration =0.14s
# Cumulative duration =112.5s
#
# 762
# Epoch duration =0.14s
# Cumulative duration =112.64s
#
# 763
# Epoch duration =0.14s
# Cumulative duration =112.79s
#
# 764
# Epoch duration =0.14s
# Cumulative duration =112.93s
#
# 765
# Epoch duration =0.15s
# Cumulative duration =113.07s
#
# 766
# Epoch duration =0.15s
# Cumulative duration =113.22s
#
# 767
# Epoch duration =0.14s
# Cumulative duration =113.36s
#
# 768
# Epoch duration =0.14s
# Cumulative duration =113.5s
#
# 769
# Epoch duration =0.14s
# Cumulative duration =113.64s
#
# 770
# Epoch duration =0.15s
# Cumulative duration =113.79s
#
# 771
# Epoch duration =0.14s
# Cumulative duration =113.93s
#
# 772
# Epoch duration =0.14s
# Cumulative duration =114.07s
#
# 773
# Epoch duration =0.14s
# Cumulative duration =114.22s
#
# 774
# Epoch duration =0.14s
# Cumulative duration =114.36s
#
# 775
# Epoch duration =0.14s
# Cumulative duration =114.5s
#
# 776
# Epoch duration =0.14s
# Cumulative duration =114.64s
#
# 777
# Epoch duration =0.14s
# Cumulative duration =114.78s
#
# 778
# Epoch duration =0.19s
# Cumulative duration =114.97s
#
# 779
# Epoch duration =0.16s
# Cumulative duration =115.14s
#
# 780
# Epoch duration =0.2s
# Cumulative duration =115.33s
#
# 781
# Epoch duration =0.18s
# Cumulative duration =115.52s
#
# 782
# Epoch duration =0.16s
# Cumulative duration =115.68s
#
# 783
# Epoch duration =0.14s
# Cumulative duration =115.82s
#
# 784
# Epoch duration =0.17s
# Cumulative duration =115.99s
#
# 785
# Epoch duration =0.14s
# Cumulative duration =116.13s
#
# 786
# Epoch duration =0.14s
# Cumulative duration =116.27s
#
# 787
# Epoch duration =0.14s
# Cumulative duration =116.41s
#
# 788
# Epoch duration =0.15s
# Cumulative duration =116.57s
#
# 789
# Epoch duration =0.15s
# Cumulative duration =116.71s
#
# 790
# Epoch duration =0.14s
# Cumulative duration =116.86s
#
# 791
# Epoch duration =0.14s
# Cumulative duration =117.0s
#
# 792
# Epoch duration =0.14s
# Cumulative duration =117.14s
#
# 793
# Epoch duration =0.15s
# Cumulative duration =117.29s
#
# 794
# Epoch duration =0.14s
# Cumulative duration =117.43s
#
# 795
# Epoch duration =0.14s
# Cumulative duration =117.57s
#
# 796
# Epoch duration =0.16s
# Cumulative duration =117.73s
#
# 797
# Epoch duration =0.15s
# Cumulative duration =117.88s
#
# 798
# Epoch duration =0.14s
# Cumulative duration =118.02s
#
# 799
# Epoch duration =0.14s
# Cumulative duration =118.16s
#
# 800
# Epoch duration =0.15s
# Cumulative duration =118.31s
#
# 801
# Epoch duration =0.14s
# Cumulative duration =118.45s
#
# 802
# Epoch duration =0.14s
# Cumulative duration =118.59s
#
# 803
# Epoch duration =0.14s
# Cumulative duration =118.73s
#
# 804
# Epoch duration =0.17s
# Cumulative duration =118.9s
#
# 805
# Epoch duration =0.14s
# Cumulative duration =119.04s
#
# 806
# Epoch duration =0.14s
# Cumulative duration =119.18s
#
# 807
# Epoch duration =0.14s
# Cumulative duration =119.33s
#
# 808
# Epoch duration =0.15s
# Cumulative duration =119.48s
#
# 809
# Epoch duration =0.14s
# Cumulative duration =119.62s
#
# 810
# Epoch duration =0.14s
# Cumulative duration =119.76s
#
# 811
# Epoch duration =0.14s
# Cumulative duration =119.9s
#
# 812
# Epoch duration =0.14s
# Cumulative duration =120.04s
#
# 813
# Epoch duration =0.18s
# Cumulative duration =120.23s
#
# 814
# Epoch duration =0.14s
# Cumulative duration =120.37s
#
# 815
# Epoch duration =0.14s
# Cumulative duration =120.51s
#
# 816
# Epoch duration =0.15s
# Cumulative duration =120.66s
#
# 817
# Epoch duration =0.15s
# Cumulative duration =120.8s
#
# 818
# Epoch duration =0.14s
# Cumulative duration =120.95s
#
# 819
# Epoch duration =0.14s
# Cumulative duration =121.09s
#
# 820
# Epoch duration =0.14s
# Cumulative duration =121.23s
#
# 821
# Epoch duration =0.14s
# Cumulative duration =121.37s
#
# 822
# Epoch duration =0.15s
# Cumulative duration =121.51s
#
# 823
# Epoch duration =0.14s
# Cumulative duration =121.66s
#
# 824
# Epoch duration =0.15s
# Cumulative duration =121.81s
#
# 825
# Epoch duration =0.14s
# Cumulative duration =121.95s
#
# 826
# Epoch duration =0.15s
# Cumulative duration =122.1s
#
# 827
# Epoch duration =0.14s
# Cumulative duration =122.24s
#
# 828
# Epoch duration =0.14s
# Cumulative duration =122.38s
#
# 829
# Epoch duration =0.14s
# Cumulative duration =122.53s
#
# 830
# Epoch duration =0.14s
# Cumulative duration =122.67s
#
# 831
# Epoch duration =0.14s
# Cumulative duration =122.81s
#
# 832
# Epoch duration =0.14s
# Cumulative duration =122.95s
#
# 833
# Epoch duration =0.14s
# Cumulative duration =123.1s
#
# 834
# Epoch duration =0.16s
# Cumulative duration =123.25s
#
# 835
# Epoch duration =0.14s
# Cumulative duration =123.39s
#
# 836
# Epoch duration =0.14s
# Cumulative duration =123.53s
#
# 837
# Epoch duration =0.15s
# Cumulative duration =123.68s
#
# 838
# Epoch duration =0.14s
# Cumulative duration =123.82s
#
# 839
# Epoch duration =0.14s
# Cumulative duration =123.96s
#
# 840
# Epoch duration =0.14s
# Cumulative duration =124.1s
#
# 841
# Epoch duration =0.14s
# Cumulative duration =124.24s
#
# 842
# Epoch duration =0.14s
# Cumulative duration =124.39s
#
# 843
# Epoch duration =0.14s
# Cumulative duration =124.53s
#
# 844
# Epoch duration =0.14s
# Cumulative duration =124.67s
#
# 845
# Epoch duration =0.14s
# Cumulative duration =124.81s
#
# 846
# Epoch duration =0.14s
# Cumulative duration =124.95s
#
# 847
# Epoch duration =0.14s
# Cumulative duration =125.09s
#
# 848
# Epoch duration =0.14s
# Cumulative duration =125.24s
#
# 849
# Epoch duration =0.14s
# Cumulative duration =125.38s
#
# 850
# Epoch duration =0.14s
# Cumulative duration =125.52s
#
# 851
# Epoch duration =0.14s
# Cumulative duration =125.66s
#
# 852
# Epoch duration =0.17s
# Cumulative duration =125.83s
#
# 853
# Epoch duration =0.14s
# Cumulative duration =125.97s
#
# 854
# Epoch duration =0.14s
# Cumulative duration =126.11s
#
# 855
# Epoch duration =0.14s
# Cumulative duration =126.25s
#
# 856
# Epoch duration =0.14s
# Cumulative duration =126.39s
#
# 857
# Epoch duration =0.14s
# Cumulative duration =126.54s
#
# 858
# Epoch duration =0.14s
# Cumulative duration =126.68s
#
# 859
# Epoch duration =0.14s
# Cumulative duration =126.82s
#
# 860
# Epoch duration =0.14s
# Cumulative duration =126.96s
#
# 861
# Epoch duration =0.14s
# Cumulative duration =127.1s
#
# 862
# Epoch duration =0.14s
# Cumulative duration =127.24s
#
# 863
# Epoch duration =0.14s
# Cumulative duration =127.38s
#
# 864
# Epoch duration =0.14s
# Cumulative duration =127.52s
#
# 865
# Epoch duration =0.14s
# Cumulative duration =127.67s
#
# 866
# Epoch duration =0.15s
# Cumulative duration =127.81s
#
# 867
# Epoch duration =0.14s
# Cumulative duration =127.95s
#
# 868
# Epoch duration =0.15s
# Cumulative duration =128.1s
#
# 869
# Epoch duration =0.14s
# Cumulative duration =128.24s
#
# 870
# Epoch duration =0.15s
# Cumulative duration =128.38s
#
# 871
# Epoch duration =0.14s
# Cumulative duration =128.53s
#
# 872
# Epoch duration =0.14s
# Cumulative duration =128.67s
#
# 873
# Epoch duration =0.14s
# Cumulative duration =128.81s
#
# 874
# Epoch duration =0.14s
# Cumulative duration =128.95s
#
# 875
# Epoch duration =0.14s
# Cumulative duration =129.09s
#
# 876
# Epoch duration =0.17s
# Cumulative duration =129.26s
#
# 877
# Epoch duration =0.14s
# Cumulative duration =129.41s
#
# 878
# Epoch duration =0.14s
# Cumulative duration =129.55s
#
# 879
# Epoch duration =0.14s
# Cumulative duration =129.69s
#
# 880
# Epoch duration =0.15s
# Cumulative duration =129.84s
#
# 881
# Epoch duration =0.14s
# Cumulative duration =129.98s
#
# 882
# Epoch duration =0.14s
# Cumulative duration =130.12s
#
# 883
# Epoch duration =0.14s
# Cumulative duration =130.26s
#
# 884
# Epoch duration =0.16s
# Cumulative duration =130.41s
#
# 885
# Epoch duration =0.14s
# Cumulative duration =130.55s
#
# 886
# Epoch duration =0.14s
# Cumulative duration =130.69s
#
# 887
# Epoch duration =0.14s
# Cumulative duration =130.84s
#
# 888
# Epoch duration =0.16s
# Cumulative duration =131.0s
#
# 889
# Epoch duration =0.14s
# Cumulative duration =131.14s
#
# 890
# Epoch duration =0.15s
# Cumulative duration =131.29s
#
# 891
# Epoch duration =0.14s
# Cumulative duration =131.43s
#
# 892
# Epoch duration =0.14s
# Cumulative duration =131.57s
#
# 893
# Epoch duration =0.14s
# Cumulative duration =131.71s
#
# 894
# Epoch duration =0.14s
# Cumulative duration =131.86s
#
# 895
# Epoch duration =0.14s
# Cumulative duration =132.0s
#
# 896
# Epoch duration =0.14s
# Cumulative duration =132.14s
#
# 897
# Epoch duration =0.14s
# Cumulative duration =132.28s
#
# 898
# Epoch duration =0.14s
# Cumulative duration =132.42s
#
# 899
# Epoch duration =0.14s
# Cumulative duration =132.56s
#
# 900
# Epoch duration =0.14s
# Cumulative duration =132.7s
#
# 901
# Epoch duration =0.15s
# Cumulative duration =132.86s
#
# 902
# Epoch duration =0.15s
# Cumulative duration =133.01s
#
# 903
# Epoch duration =0.14s
# Cumulative duration =133.15s
#
# 904
# Epoch duration =0.14s
# Cumulative duration =133.29s
#
# 905
# Epoch duration =0.14s
# Cumulative duration =133.43s
#
# 906
# Epoch duration =0.14s
# Cumulative duration =133.58s
#
# 907
# Epoch duration =0.14s
# Cumulative duration =133.72s
#
# 908
# Epoch duration =0.14s
# Cumulative duration =133.86s
#
# 909
# Epoch duration =0.14s
# Cumulative duration =134.0s
#
# 910
# Epoch duration =0.14s
# Cumulative duration =134.14s
#
# 911
# Epoch duration =0.14s
# Cumulative duration =134.29s
#
# 912
# Epoch duration =0.14s
# Cumulative duration =134.43s
#
# 913
# Epoch duration =0.14s
# Cumulative duration =134.57s
#
# 914
# Epoch duration =0.17s
# Cumulative duration =134.74s
#
# 915
# Epoch duration =0.14s
# Cumulative duration =134.88s
#
# 916
# Epoch duration =0.15s
# Cumulative duration =135.03s
#
# 917
# Epoch duration =0.14s
# Cumulative duration =135.17s
#
# 918
# Epoch duration =0.17s
# Cumulative duration =135.34s
#
# 919
# Epoch duration =0.14s
# Cumulative duration =135.47s
#
# 920
# Epoch duration =0.14s
# Cumulative duration =135.62s
#
# 921
# Epoch duration =0.15s
# Cumulative duration =135.76s
#
# 922
# Epoch duration =0.14s
# Cumulative duration =135.9s
#
# 923
# Epoch duration =0.14s
# Cumulative duration =136.05s
#
# 924
# Epoch duration =0.14s
# Cumulative duration =136.19s
#
# 925
# Epoch duration =0.15s
# Cumulative duration =136.34s
#
# 926
# Epoch duration =0.14s
# Cumulative duration =136.48s
#
# 927
# Epoch duration =0.14s
# Cumulative duration =136.62s
#
# 928
# Epoch duration =0.14s
# Cumulative duration =136.76s
#
# 929
# Epoch duration =0.14s
# Cumulative duration =136.9s
#
# 930
# Epoch duration =0.14s
# Cumulative duration =137.04s
#
# 931
# Epoch duration =0.14s
# Cumulative duration =137.19s
#
# 932
# Epoch duration =0.14s
# Cumulative duration =137.33s
#
# 933
# Epoch duration =0.14s
# Cumulative duration =137.47s
#
# 934
# Epoch duration =0.14s
# Cumulative duration =137.61s
#
# 935
# Epoch duration =0.14s
# Cumulative duration =137.75s
#
# 936
# Epoch duration =0.17s
# Cumulative duration =137.92s
#
# 937
# Epoch duration =0.14s
# Cumulative duration =138.06s
#
# 938
# Epoch duration =0.17s
# Cumulative duration =138.23s
#
# 939
# Epoch duration =0.17s
# Cumulative duration =138.4s
#
# 940
# Epoch duration =0.16s
# Cumulative duration =138.57s
#
# 941
# Epoch duration =0.15s
# Cumulative duration =138.72s
#
# 942
# Epoch duration =0.14s
# Cumulative duration =138.87s
#
# 943
# Epoch duration =0.16s
# Cumulative duration =139.03s
#
# 944
# Epoch duration =0.16s
# Cumulative duration =139.19s
#
# 945
# Epoch duration =0.14s
# Cumulative duration =139.33s
#
# 946
# Epoch duration =0.14s
# Cumulative duration =139.47s
#
# 947
# Epoch duration =0.14s
# Cumulative duration =139.61s
#
# 948
# Epoch duration =0.17s
# Cumulative duration =139.79s
#
# 949
# Epoch duration =0.14s
# Cumulative duration =139.93s
#
# 950
# Epoch duration =0.15s
# Cumulative duration =140.07s
#
# 951
# Epoch duration =0.14s
# Cumulative duration =140.22s
#
# 952
# Epoch duration =0.17s
# Cumulative duration =140.39s
#
# 953
# Epoch duration =0.15s
# Cumulative duration =140.54s
#
# 954
# Epoch duration =0.15s
# Cumulative duration =140.7s
#
# 955
# Epoch duration =0.16s
# Cumulative duration =140.85s
#
# 956
# Epoch duration =0.14s
# Cumulative duration =140.99s
#
# 957
# Epoch duration =0.14s
# Cumulative duration =141.14s
#
# 958
# Epoch duration =0.14s
# Cumulative duration =141.28s
#
# 959
# Epoch duration =0.14s
# Cumulative duration =141.42s
#
# 960
# Epoch duration =0.14s
# Cumulative duration =141.56s
#
# 961
# Epoch duration =0.14s
# Cumulative duration =141.7s
#
# 962
# Epoch duration =0.14s
# Cumulative duration =141.84s
#
# 963
# Epoch duration =0.14s
# Cumulative duration =141.98s
#
# 964
# Epoch duration =0.14s
# Cumulative duration =142.13s
#
# 965
# Epoch duration =0.14s
# Cumulative duration =142.27s
#
# 966
# Epoch duration =0.15s
# Cumulative duration =142.42s
#
# 967
# Epoch duration =0.14s
# Cumulative duration =142.56s
#
# 968
# Epoch duration =0.14s
# Cumulative duration =142.7s
#
# 969
# Epoch duration =0.14s
# Cumulative duration =142.84s
#
# 970
# Epoch duration =0.15s
# Cumulative duration =142.99s
#
# 971
# Epoch duration =0.14s
# Cumulative duration =143.14s
#
# 972
# Epoch duration =0.15s
# Cumulative duration =143.28s
#
# 973
# Epoch duration =0.14s
# Cumulative duration =143.43s
#
# 974
# Epoch duration =0.14s
# Cumulative duration =143.57s
#
# 975
# Epoch duration =0.14s
# Cumulative duration =143.71s
#
# 976
# Epoch duration =0.17s
# Cumulative duration =143.88s
#
# 977
# Epoch duration =0.14s
# Cumulative duration =144.02s
#
# 978
# Epoch duration =0.14s
# Cumulative duration =144.16s
#
# 979
# Epoch duration =0.15s
# Cumulative duration =144.31s
#
# 980
# Epoch duration =0.14s
# Cumulative duration =144.46s
#
# 981
# Epoch duration =0.14s
# Cumulative duration =144.6s
#
# 982
# Epoch duration =0.14s
# Cumulative duration =144.74s
#
# 983
# Epoch duration =0.14s
# Cumulative duration =144.89s
#
# 984
# Epoch duration =0.14s
# Cumulative duration =145.03s
#
# 985
# Epoch duration =0.14s
# Cumulative duration =145.17s
#
# 986
# Epoch duration =0.14s
# Cumulative duration =145.32s
#
# 987
# Epoch duration =0.14s
# Cumulative duration =145.46s
#
# 988
# Epoch duration =0.14s
# Cumulative duration =145.6s
#
# 989
# Epoch duration =0.14s
# Cumulative duration =145.74s
#
# 990
# Epoch duration =0.14s
# Cumulative duration =145.89s
#
# 991
# Epoch duration =0.14s
# Cumulative duration =146.03s
#
# 992
# Epoch duration =0.14s
# Cumulative duration =146.17s
#
# 993
# Epoch duration =0.14s
# Cumulative duration =146.31s
#
# 994
# Epoch duration =0.16s
# Cumulative duration =146.47s
#
# 995
# Epoch duration =0.14s
# Cumulative duration =146.61s
#
# 996
# Epoch duration =0.14s
# Cumulative duration =146.75s
#
# 997
# Epoch duration =0.14s
# Cumulative duration =146.89s
#
# 998
# Epoch duration =0.14s
# Cumulative duration =147.04s
#
# 999
# Epoch duration =0.14s
# Cumulative duration =147.18s

# %%
mean_mut2_scores
# Out:
# array([ 2.87159176,  2.44828665,  2.82368728, ...,  2.81453967,
#         2.71582651,  2.79476791])

# %% [markdown]
# ### Repeat the above but the sequences averaged were the highest scored sequences from that particular neuron

# %%
#select neuron
neuron = top_neurons[0]
#select mutation information for that neuron
mean_mut2_predictoutputs_hol = mean_mut2_scores_hol


nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(15,14))

num = 11

for one in range(num):
    for two in range(num):
        ax = fig4.add_subplot(num, num, ((one*num)+two)+1)
        
        #plot the 0th column with row labels and the num_th most row with column labels
        if two == 0:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc, cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=nuc, cbar=False)
        else:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=[], cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+6, two+24], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=[], cbar=False)

# %% [markdown]
# ## Look at the dense parameters

# %%
W = nnmodel.get_parameters(sess, layer='dense_0')[0]
W = W.reshape((41,4,196))
W = W.transpose(1,0,2)

# %%
for ii in top_neurons[:5]:
    plt.figure()
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            W[:,:,ii], 
                                            alphabet='rna', 
                                            nt_width=400)
