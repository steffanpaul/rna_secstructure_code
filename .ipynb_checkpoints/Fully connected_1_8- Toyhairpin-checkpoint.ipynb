# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import mutagenesis_functions as mf
import time as time

# %%
# load hairpin data
data_path = '../data_peter/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 8,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected_1_8')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 8)
# layer3: dense_0_batch
# (?, 8)
# layer4: dense_0_active
# (?, 8)
# layer5: dense_0_dropout
# (?, 8)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.51744 -- acc=66.668757%
#
#   valid loss:		0.22088
#   valid accuracy:	0.99808+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99875+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.35654 -- acc=80.409891%
#
#   valid loss:		0.15625
#   valid accuracy:	0.99813+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99907+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.33646 -- acc=81.031253%
#
#   valid loss:		0.14149
#   valid accuracy:	0.99819+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99898+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.32892 -- acc=81.264586%
#
#   valid loss:		0.13609
#   valid accuracy:	0.99842+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99911+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.59s -- loss=0.32682 -- acc=81.390109%
#
#   valid loss:		0.13494
#   valid accuracy:	0.99848+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99901+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.60s -- loss=0.32405 -- acc=81.621872%
#
#   valid loss:		0.13174
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99925+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.64s -- loss=0.32325 -- acc=81.647395%
#
#   valid loss:		0.12909
#   valid accuracy:	0.99844+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99919+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=4.61s -- loss=0.32409 -- acc=81.553125%
#
#   valid loss:		0.13137
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99928+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.32284 -- acc=81.757816%
#
#   valid loss:		0.12884
#   valid accuracy:	0.99838+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99905+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.60s -- loss=0.32299 -- acc=81.732293%
#
#   valid loss:		0.12742
#   valid accuracy:	0.99856+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99884+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.32135 -- acc=81.788549%
#
#   valid loss:		0.13249
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99876+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.32230 -- acc=81.800000%
#
#   valid loss:		0.13066
#   valid accuracy:	0.99852+/-0.00000
#   valid auc-roc:	0.99955+/-0.00000
#   valid auc-pr:		0.99838+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.32149 -- acc=81.768237%
#
#   valid loss:		0.13042
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99951+/-0.00000
#   valid auc-pr:		0.99831+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.31951 -- acc=81.988029%
#
#   valid loss:		0.12866
#   valid accuracy:	0.99831+/-0.00000
#   valid auc-roc:	0.99951+/-0.00000
#   valid auc-pr:		0.99844+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=4.86s -- loss=0.32083 -- acc=81.906251%
#
#   valid loss:		0.12769
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99953+/-0.00000
#   valid auc-pr:		0.99863+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.32030 -- acc=81.889069%
#
#   valid loss:		0.12809
#   valid accuracy:	0.99842+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99879+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=4.85s -- loss=0.31958 -- acc=81.981258%
#
#   valid loss:		0.12855
#   valid accuracy:	0.99833+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99869+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=4.59s -- loss=0.32046 -- acc=81.944274%
#
#   valid loss:		0.12979
#   valid accuracy:	0.99856+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99894+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=4.61s -- loss=0.31917 -- acc=82.094279%
#
#   valid loss:		0.12761
#   valid accuracy:	0.99838+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99899+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=4.59s -- loss=0.32174 -- acc=81.894799%
#
#   valid loss:		0.12765
#   valid accuracy:	0.99833+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99910+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.31901 -- acc=82.065107%
#
#   valid loss:		0.12945
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99920+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.32077 -- acc=81.891149%
#
#   valid loss:		0.12748
#   valid accuracy:	0.99833+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99893+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=4.64s -- loss=0.31995 -- acc=82.001040%
#
#   valid loss:		0.12858
#   valid accuracy:	0.99844+/-0.00000
#   valid auc-roc:	0.99961+/-0.00000
#   valid auc-pr:		0.99892+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.31912 -- acc=82.062506%
#
#   valid loss:		0.12650
#   valid accuracy:	0.99856+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99907+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=4.61s -- loss=0.31801 -- acc=82.188029%
#
#   valid loss:		0.12739
#   valid accuracy:	0.99867+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99883+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.31928 -- acc=82.117712%
#
#   valid loss:		0.12397
#   valid accuracy:	0.99852+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99905+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.31930 -- acc=82.022392%
#
#   valid loss:		0.12836
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	0.99972+/-0.00000
#   valid auc-pr:		0.99925+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.31715 -- acc=82.223962%
#
#   valid loss:		0.12428
#   valid accuracy:	0.99879+/-0.00000
#   valid auc-roc:	0.99973+/-0.00000
#   valid auc-pr:		0.99929+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=4.64s -- loss=0.31705 -- acc=82.316672%
#
#   valid loss:		0.12471
#   valid accuracy:	0.99852+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99904+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.31844 -- acc=82.131253%
#
#   valid loss:		0.12789
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99907+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.31912 -- acc=82.114581%
#
#   valid loss:		0.12571
#   valid accuracy:	0.99846+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99874+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.31723 -- acc=82.243754%
#
#   valid loss:		0.12699
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99900+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.31949 -- acc=82.079178%
#
#   valid loss:		0.12806
#   valid accuracy:	0.99856+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99896+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.31842 -- acc=82.111981%
#
#   valid loss:		0.12587
#   valid accuracy:	0.99844+/-0.00000
#   valid auc-roc:	0.99959+/-0.00000
#   valid auc-pr:		0.99890+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=5.15s -- loss=0.31690 -- acc=82.222392%
#
#   valid loss:		0.12802
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99899+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.31917 -- acc=82.029173%
#
#   valid loss:		0.12709
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99898+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.31824 -- acc=82.184898%
#
#   valid loss:		0.12825
#   valid accuracy:	0.99844+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99888+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=5.12s -- loss=0.31784 -- acc=82.187509%
#
#   valid loss:		0.12870
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99919+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.31598 -- acc=82.352605%
#
#   valid loss:		0.12474
#   valid accuracy:	0.99848+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99908+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.31747 -- acc=82.171357%
#
#   valid loss:		0.12562
#   valid accuracy:	0.99862+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99913+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=4.70s -- loss=0.31829 -- acc=82.136984%
#
#   valid loss:		0.12530
#   valid accuracy:	0.99823+/-0.00000
#   valid auc-roc:	0.99958+/-0.00000
#   valid auc-pr:		0.99868+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.31556 -- acc=82.396870%
#
#   valid loss:		0.13018
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99919+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=4.64s -- loss=0.31797 -- acc=82.163546%
#
#   valid loss:		0.12577
#   valid accuracy:	0.99856+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99915+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.31927 -- acc=82.050005%
#
#   valid loss:		0.12841
#   valid accuracy:	0.99842+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99926+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.31544 -- acc=82.404690%
#
#   valid loss:		0.12871
#   valid accuracy:	0.99858+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99923+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=4.73s -- loss=0.31899 -- acc=82.176568%
#
#   valid loss:		0.12687
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99944+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.31530 -- acc=82.468757%
#
#   valid loss:		0.12549
#   valid accuracy:	0.99881+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99909+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=5.18s -- loss=0.31724 -- acc=82.225523%
#
#   valid loss:		0.12718
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99878+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=4.73s -- loss=0.31487 -- acc=82.463546%
#
#   valid loss:		0.12389
#   valid accuracy:	0.99873+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99904+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=4.75s -- loss=0.31755 -- acc=82.272927%
#
#   valid loss:		0.12879
#   valid accuracy:	0.99844+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99915+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=4.93s -- loss=0.31584 -- acc=82.356256%
#
#   valid loss:		0.12348
#   valid accuracy:	0.99829+/-0.00000
#   valid auc-roc:	0.99955+/-0.00000
#   valid auc-pr:		0.99873+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=4.83s -- loss=0.31676 -- acc=82.313021%
#
#   valid loss:		0.12557
#   valid accuracy:	0.99848+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99899+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.31598 -- acc=82.380218%
#
#   valid loss:		0.12467
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99880+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.31499 -- acc=82.416672%
#
#   valid loss:		0.12563
#   valid accuracy:	0.99858+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99918+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=4.99s -- loss=0.31789 -- acc=82.230213%
#
#   valid loss:		0.12648
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99953+/-0.00000
#   valid auc-pr:		0.99839+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=4.76s -- loss=0.31423 -- acc=82.484898%
#
#   valid loss:		0.12280
#   valid accuracy:	0.99846+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99905+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=5.00s -- loss=0.31626 -- acc=82.280218%
#
#   valid loss:		0.12814
#   valid accuracy:	0.99829+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99907+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.31776 -- acc=82.257296%
#
#   valid loss:		0.12546
#   valid accuracy:	0.99821+/-0.00000
#   valid auc-roc:	0.99959+/-0.00000
#   valid auc-pr:		0.99869+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=4.73s -- loss=0.31900 -- acc=82.130733%
#
#   valid loss:		0.12511
#   valid accuracy:	0.99833+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99902+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=4.76s -- loss=0.31619 -- acc=82.332293%
#
#   valid loss:		0.12723
#   valid accuracy:	0.99838+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99919+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=5.35s -- loss=0.31711 -- acc=82.323962%
#
#   valid loss:		0.12807
#   valid accuracy:	0.99829+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99900+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=5.30s -- loss=0.31564 -- acc=82.474487%
#
#   valid loss:		0.12661
#   valid accuracy:	0.99819+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99877+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=4.82s -- loss=0.31581 -- acc=82.484898%
#
#   valid loss:		0.12794
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99956+/-0.00000
#   valid auc-pr:		0.99868+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=4.87s -- loss=0.31440 -- acc=82.416672%
#
#   valid loss:		0.12566
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99896+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=4.99s -- loss=0.31643 -- acc=82.344794%
#
#   valid loss:		0.12687
#   valid accuracy:	0.99808+/-0.00000
#   valid auc-roc:	0.99959+/-0.00000
#   valid auc-pr:		0.99888+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=4.71s -- loss=0.31570 -- acc=82.463026%
#
#   valid loss:		0.12603
#   valid accuracy:	0.99817+/-0.00000
#   valid auc-roc:	0.99955+/-0.00000
#   valid auc-pr:		0.99877+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=4.93s -- loss=0.31669 -- acc=82.361986%
#
#   valid loss:		0.12696
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99877+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=4.80s -- loss=0.31611 -- acc=82.344274%
#
#   valid loss:		0.12755
#   valid accuracy:	0.99808+/-0.00000
#   valid auc-roc:	0.99958+/-0.00000
#   valid auc-pr:		0.99886+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=4.74s -- loss=0.31626 -- acc=82.404170%
#
#   valid loss:		0.12582
#   valid accuracy:	0.99823+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99917+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=4.86s -- loss=0.31756 -- acc=82.316672%
#
#   valid loss:		0.12849
#   valid accuracy:	0.99831+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99878+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=4.88s -- loss=0.31786 -- acc=82.258856%
#
#   valid loss:		0.12717
#   valid accuracy:	0.99821+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99899+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=5.07s -- loss=0.31726 -- acc=82.318232%
#
#   valid loss:		0.12746
#   valid accuracy:	0.99858+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99911+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=4.92s -- loss=0.31519 -- acc=82.547925%
#
#   valid loss:		0.12520
#   valid accuracy:	0.99858+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99909+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=5.13s -- loss=0.31525 -- acc=82.481258%
#
#   valid loss:		0.12952
#   valid accuracy:	0.99881+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99922+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=4.80s -- loss=0.31498 -- acc=82.459376%
#
#   valid loss:		0.12758
#   valid accuracy:	0.99877+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99907+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=4.70s -- loss=0.31928 -- acc=82.254695%
#
#   valid loss:		0.12772
#   valid accuracy:	0.99842+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99900+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=4.93s -- loss=0.31656 -- acc=82.327083%
#
#   valid loss:		0.12924
#   valid accuracy:	0.99842+/-0.00000
#   valid auc-roc:	0.99959+/-0.00000
#   valid auc-pr:		0.99883+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=4.82s -- loss=0.31626 -- acc=82.414581%
#
#   valid loss:		0.12400
#   valid accuracy:	0.99842+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99883+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=4.80s -- loss=0.31796 -- acc=82.232293%
#
#   valid loss:		0.12640
#   valid accuracy:	0.99813+/-0.00000
#   valid auc-roc:	0.99955+/-0.00000
#   valid auc-pr:		0.99850+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=4.91s -- loss=0.31488 -- acc=82.515622%
#
#   valid loss:		0.12514
#   valid accuracy:	0.99817+/-0.00000
#   valid auc-roc:	0.99954+/-0.00000
#   valid auc-pr:		0.99869+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=4.86s -- loss=0.31741 -- acc=82.319792%
#
#   valid loss:		0.12594
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99956+/-0.00000
#   valid auc-pr:		0.99880+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=4.79s -- loss=0.31739 -- acc=82.339584%
#
#   valid loss:		0.12343
#   valid accuracy:	0.99808+/-0.00000
#   valid auc-roc:	0.99951+/-0.00000
#   valid auc-pr:		0.99855+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=4.96s -- loss=0.31589 -- acc=82.544794%
#
#   valid loss:		0.12766
#   valid accuracy:	0.99833+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99903+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=4.75s -- loss=0.31683 -- acc=82.290629%
#
#   valid loss:		0.12528
#   valid accuracy:	0.99846+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99876+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=5.03s -- loss=0.31488 -- acc=82.506771%
#
#   valid loss:		0.12406
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99961+/-0.00000
#   valid auc-pr:		0.99890+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=4.82s -- loss=0.31574 -- acc=82.453645%
#
#   valid loss:		0.12497
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99900+/-0.00000
# Patience ran out... Early stopping.

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_8_best.ckpt
# INFO:tensorflow:Restoring parameters from ../results/toyhairpin/fullyconnected_1_8_best.ckpt
#   test  loss:		0.12215
#   test  accuracy:	0.99798+/-0.00000
#   test  auc-roc:	0.99961+/-0.00000
#   test  auc-pr:		0.99902+/-0.00000

# %% [markdown]
# ## First order mutagenesis saliency

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
numplots=5

for ii in range(numplots): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='output', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Second Order Mutagenesis

# %%
savepath = 'Arrays/toyhairpin_FC_1_8_sumoutputs1k.npy'

num_summary = 1000
X = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average(X, savepath, nntrainer, sess, progress='off')
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/toyhairpin_FC_1_8_sumoutputs1k.npy

# %%
#Load the saved data
savepath = 'Arrays/toyhairpin_FC_1_8_sumoutputs1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

# %%
mf.symlinear_holplot(meanhol_mut2, figplot=(4,5), alphabet='rna')

# %%
mf.square_holplot(meanhol_mut2, num=15, alphabet='rna')

# %% [markdown]
# ## Look at Hidden Layers

# %%
W = nnmodel.get_parameters(sess, layer='dense_1')[0]
top_neurons=np.argsort(np.squeeze(W))[::-1]
top_neurons
# Out:
# array([7, 0, 6, 4, 1, 5, 2, 3])

# %%
top_weights=np.sort(np.squeeze(W))[::-1]
top_weights
# Out:
# array([ 0.97123396,  0.8057757 ,  0.65905607, -3.347049  , -3.3628347 ,
#        -3.450039  , -3.568007  , -3.9264615 ], dtype=float32)

# %%
dense = nntrainer.get_activations(sess, test, layer='dense_0_active')

#plot which neurons got activated by the highest predicted sequence (from the outputs)
plt.plot(range(dense.shape[1]), dense[plot_index[0]])
plt.show()

''' An example of how a single sequence can excite various different neurons'''
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# ' An example of how a single sequence can excite various different neurons'

# %%
num_plots = 5
for neuron in top_neurons[0:num_plots]:
    top_indices = np.argsort(dense[:,neuron])[::-1]
    X = np.expand_dims(test['inputs'][top_indices[0]], axis=0)
    
    mf.fom_neursal(X, layer='dense_0_active', alphabet='rna', neuron=neuron, nntrainer=nntrainer, sess=sess)

# %% [markdown]
# ## Look at the dense parameters

# %%
W = nnmodel.get_parameters(sess, layer='dense_0')[0]
W = W.reshape((41,4,8))
W = W.transpose(1,0,2)

for ii in top_neurons[:8]:
    plt.figure()
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            W[:,:,ii], 
                                            alphabet='rna', 
                                            nt_width=400)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-bbabc01cc2a7> in <module>()
#       8                                             W[:,:,ii],
#       9                                             alphabet='rna',
# ---> 10                                             nt_width=400)
#
# /home/peter/steffan/rna_secstructure/rna_secstructure_code/deepomics/visualize.pyc in plot_seq_pos_saliency(X, W, nt_width, alphabet, norm_factor, colormap)
#     287
#     288         # sequence logo
# --> 289         pwm_seq_logo = seq_logo(X[:,plot_index], height=nt_width, nt_width=nt_width, norm=0, alphabet=alphabet, colormap=colormap)
#     290
#     291         # sequence saliency logo
#
# /home/peter/steffan/rna_secstructure/rna_secstructure_code/deepomics/visualize.pyc in seq_logo(pwm, height, nt_width, norm, alphabet, colormap)
#     594
#     595         # get the heights of each nucleotide
# --> 596         heights = get_nt_height(pwm, height, norm)
#     597
#     598         # resize nucleotide images for each base of sequence and stack
#
# /home/peter/steffan/rna_secstructure/rna_secstructure_code/deepomics/visualize.pyc in get_nt_height(pwm, height, norm)
#     573                         return s
#     574
# --> 575                 num_nt, num_seq = pwm.shape
#     576                 heights = np.zeros((num_nt,num_seq));
#     577                 for i in range(num_seq):
#
# ValueError: too many values to unpack

# %% [markdown]
# ## Second order mutagenesis based on the neuron outputs

# %%
neuron = top_neurons[3]
top_indices = np.argsort(dense[:,neuron])[::-1]

num_summary = 1000

X = test['inputs'][top_indices[:num_summary]]
savepath = 'Arrays/toyhairpin_FC_1_8_sumneuron4_1k.npy'

sum_mut2 = mf.som_neuronaverage(X,'dense_0_active', neuron, savepath, nntrainer, sess, progress='off')
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/toyhairpin_FC_1_8_sumneuron4_1k.npy

# %%
#Load the saved data
savepath = 'Arrays/toyhairpin_FC_1_8_sumneuron4_1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

# %%
mf.symlinear_holplot(meanhol_mut2, figplot=(4,5), alphabet='rna', limits=False)

# %%
mf.square_holplot(meanhol_mut2, num=11, alphabet='rna', figsize=(7,7), start=(6,24))

# %%
M = mean_mut2.reshape(41,41,16)
Mstd = np.std(M, axis=2)
sb.heatmap(Mstd)
plt.show()
