# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import mutagenesis_functions as mf
import time as time

# %%
# load hairpin data
data_path = '../data_peter/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 196,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected_1_196')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# %%
# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 196)
# layer3: dense_0_batch
# (?, 196)
# layer4: dense_0_active
# (?, 196)
# layer5: dense_0_dropout
# (?, 196)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_196_best.ckpt
#   test  loss:		0.00255
#   test  accuracy:	0.99998+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
#Get Predictions

# calculate activations
#predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
#predictionslogits = nntrainer.get_activations(sess, test, layer='dense_0_bias')

# %%
import mutagenesis_functions as mf

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)



num_summary = 1000
X = test['inputs'][:num_summary]

sum_mut2_scores = mf.som_average(X, nntrainer, sess)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_196_best.ckpt
# 0
# Epoch duration =0hr 0min 0.2s
# Cumulative duration =0hr 0min 0.2s
#
# 1
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 0.34s
#
# 2
# Epoch duration =0hr 0min 0.2s
# Cumulative duration =0hr 0min 0.54s
#
# 3
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 0.69s
#
# 4
# Epoch duration =0hr 0min 0.17s
# Cumulative duration =0hr 0min 0.86s
#
# 5
# Epoch duration =0hr 0min 0.19s
# Cumulative duration =0hr 0min 1.05s
#
# 6
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 1.19s
#
# 7
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 1.33s
#
# 8
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 1.47s
#
# 9
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 1.61s
#
# 10
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 1.75s
#
# 11
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 1.88s
#
# 12
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 2.03s
#
# 13
# Epoch duration =0hr 0min 0.2s
# Cumulative duration =0hr 0min 2.23s
#
# 14
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 2.39s
#
# 15
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 2.53s
#
# 16
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 2.68s
#
# 17
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 2.82s
#
# 18
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 2.97s
#
# 19
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 3.11s
#
# 20
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 3.25s
#
# 21
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 3.39s
#
# 22
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 3.54s
#
# 23
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 3.67s
#
# 24
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 3.81s
#
# 25
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 3.95s
#
# 26
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 4.09s
#
# 27
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 4.23s
#
# 28
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 4.37s
#
# 29
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 4.5s
#
# 30
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 4.65s
#
# 31
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 4.8s
#
# 32
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 4.96s
#
# 33
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 5.11s
#
# 34
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 5.26s
#
# 35
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 5.41s
#
# 36
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 5.56s
#
# 37
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 5.72s
#
# 38
# Epoch duration =0hr 0min 0.17s
# Cumulative duration =0hr 0min 5.89s
#
# 39
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 6.03s
#
# 40
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 6.17s
#
# 41
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 6.31s
#
# 42
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 6.45s
#
# 43
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 6.58s
#
# 44
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 6.72s
#
# 45
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 6.85s
#
# 46
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 6.99s
#
# 47
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 7.13s
#
# 48
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 7.27s
#
# 49
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 7.4s
#
# 50
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 7.55s
#
# 51
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 7.68s
#
# 52
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 7.84s
#
# 53
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 7.97s
#
# 54
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 8.11s
#
# 55
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 8.27s
#
# 56
# Epoch duration =0hr 0min 0.17s
# Cumulative duration =0hr 0min 8.44s
#
# 57
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 8.58s
#
# 58
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 8.73s
#
# 59
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 8.89s
#
# 60
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 9.03s
#
# 61
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 9.17s
#
# 62
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 9.31s
#
# 63
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 9.46s
#
# 64
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 9.62s
#
# 65
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 9.77s
#
# 66
# Epoch duration =0hr 0min 0.17s
# Cumulative duration =0hr 0min 9.94s
#
# 67
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 10.07s
#
# 68
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 10.21s
#
# 69
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 10.35s
#
# 70
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 10.48s
#
# 71
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 10.62s
#
# 72
# Epoch duration =0hr 0min 0.17s
# Cumulative duration =0hr 0min 10.79s
#
# 73
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 10.93s
#
# 74
# Epoch duration =0hr 0min 0.18s
# Cumulative duration =0hr 0min 11.11s
#
# 75
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 11.27s
#
# 76
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 11.42s
#
# 77
# Epoch duration =0hr 0min 0.17s
# Cumulative duration =0hr 0min 11.59s
#
# 78
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 11.74s
#
# 79
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 11.9s
#
# 80
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 12.04s
#
# 81
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 12.18s
#
# 82
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 12.32s
#
# 83
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 12.46s
#
# 84
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 12.61s
#
# 85
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 12.77s
#
# 86
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 12.92s
#
# 87
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 13.07s
#
# 88
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 13.22s
#
# 89
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 13.35s
#
# 90
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 13.49s
#
# 91
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 13.63s
#
# 92
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 13.77s
#
# 93
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 13.91s
#
# 94
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 14.05s
#
# 95
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 14.21s
#
# 96
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 14.36s
#
# 97
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 14.5s
#
# 98
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 14.66s
#
# 99
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 14.81s
#
# 100
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 14.96s
#
# 101
# Epoch duration =0hr 0min 0.18s
# Cumulative duration =0hr 0min 15.13s
#
# 102
# Epoch duration =0hr 0min 0.17s
# Cumulative duration =0hr 0min 15.3s
#
# 103
# Epoch duration =0hr 0min 0.19s
# Cumulative duration =0hr 0min 15.49s
#
# 104
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 15.63s
#
# 105
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 15.77s
#
# 106
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 15.91s
#
# 107
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 16.05s
#
# 108
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 16.19s
#
# 109
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 16.34s
#
# 110
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 16.48s
#
# 111
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 16.61s
#
# 112
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 16.75s
#
# 113
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 16.91s
#
# 114
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 17.06s
#
# 115
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 17.2s
#
# 116
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 17.35s
#
# 117
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 17.51s
#
# 118
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 17.66s
#
# 119
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 17.8s
#
# 120
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 17.94s
#
# 121
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 18.08s
#
# 122
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 18.24s
#
# 123
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 18.39s
#
# 124
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 18.52s
#
# 125
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 18.68s
#
# 126
# Epoch duration =0hr 0min 0.18s
# Cumulative duration =0hr 0min 18.86s
#
# 127
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 19.0s
#
# 128
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 19.13s
#
# 129
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 19.27s
#
# 130
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 19.41s
#
# 131
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 19.55s
#
# 132
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 19.69s
#
# 133
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 19.82s
#
# 134
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 19.96s
#
# 135
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 20.1s
#
# 136
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 20.26s
#
# 137
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 20.41s
#
# 138
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 20.56s
#
# 139
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 20.71s
#
# 140
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 20.86s
#
# 141
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 21.0s
#
# 142
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 21.16s
#
# 143
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 21.3s
#
# 144
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 21.45s
#
# 145
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 21.58s
#
# 146
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 21.73s
#
# 147
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 21.86s
#
# 148
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 22.03s
#
# 149
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 22.17s
#
# 150
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 22.33s
#
# 151
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 22.49s
#
# 152
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 22.64s
#
# 153
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 22.79s
#
# 154
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 22.93s
#
# 155
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 23.08s
#
# 156
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 23.25s
#
# 157
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 23.38s
#
# 158
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 23.54s
#
# 159
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 23.69s
#
# 160
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 23.84s
#
# 161
# Epoch duration =0hr 0min 0.16s
# Cumulative duration =0hr 0min 24.0s
#
# 162
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 24.15s
#
# 163
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 24.3s
#
# 164
# Epoch duration =0hr 0min 0.15s
# Cumulative duration =0hr 0min 24.45s
#
# 165
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 24.58s
#
# 166
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 24.72s
#
# 167
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 24.86s
#
# 168
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 25.0s
#
# 169
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 25.14s
#
# 170
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 25.28s
#
# 171
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 25.41s
#
# 172
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 25.55s
#
# 173
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 25.69s
#
# 174
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 25.82s
#
# 175
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 25.96s
#
# 176
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 26.1s
#
# 177
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 26.24s
#
# 178
# Epoch duration =0hr 0min 0.14s
# Cumulative duration =0hr 0min 26.38s
#
# 179
# Epoch duration =0hr 0min 0.13s
# Cumulative duration =0hr 0min 26.51s
#
# 180
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-662b4db22416> in <module>()
#      10 X = test['inputs'][:num_summary]
#      11
# ---> 12 sum_mut2_scores = mf.som_average(X, nntrainer, sess)
#
# /home/peter/steffan/rna_secstructure/rna_secstructure_code/mutagenesis_functions.py in som_average(X, nntrainer, sess)
#     130
#     131         #Get output activations for the mutations
# --> 132         mut2_scores= nntrainer.get_activations(sess, mutations, layer='output')
#     133
#     134         #Sum all the scores into a single matrix
#
# /home/peter/steffan/rna_secstructure/rna_secstructure_code/deepomics/neuralnetwork.pyc in get_activations(self, sess, data, layer, batch_size)
#     538                 for i in range(batch_generator.get_num_batches()):
#     539                         self.test_feed = batch_generator.next_minibatch(data, self.test_feed, self.placeholders)
# --> 540                         activations.append(self.nnmodel.get_activations(sess, self.test_feed, layer))
#     541                 activations = np.vstack(activations)
#     542
#
# /home/peter/steffan/rna_secstructure/rna_secstructure_code/deepomics/neuralnetwork.pyc in get_activations(self, sess, feed_X, layer)
#     156                 """get the real-valued feature maps of a given convolutional layer"""
#     157
# --> 158                 return sess.run(self.network[layer].get_output(), feed_dict=feed_X)
#     159
#     160
#
# /home/peter/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/peter/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/peter/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/peter/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/peter/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
X[:1].shape

# %%
def sectotime(t):
    t = np.around(t, 2)
    if t>=3600.:
        s = t%60
        m = ((t)%3600)//60
        hr = t//3600
        output = str(int(hr)) + 'hr ' + str(int(m)) + 'min ' + str(s) + 's'
    else:
        if t>=60.:
            s = t%60
            m = t//60
            output = str(int(m)) + 'min ' + str(s) + 's'
        else:
            s = np.copy(t)
            output = str(s) + 's'
    return(output)

# %%
t = 129.3697

sectotime(t)
# Out:
# '2min 9.37s'
