# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import mutagenesis_functions as mf
import time as time

# %%
# load hairpin data
data_path = '../data_peter/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 15,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected_1_15')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 15)
# layer3: dense_0_batch
# (?, 15)
# layer4: dense_0_active
# (?, 15)
# layer5: dense_0_dropout
# (?, 15)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=10, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.44921 -- acc=77.39062
#
#   valid loss:		0.12524
#   valid accuracy:	0.99979+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.53s -- loss=0.24478 -- acc=90.33125
#
#   valid loss:		0.07831
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=4.70s -- loss=0.22412 -- acc=90.75052
#
#   valid loss:		0.06916
#   valid accuracy:	0.99996+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=4.88s -- loss=0.21401 -- acc=90.89271
#
#   valid loss:		0.06070
#   valid accuracy:	0.99992+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.79s -- loss=0.20855 -- acc=90.87292
#
#   valid loss:		0.05962
#   valid accuracy:	0.99994+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.39s -- loss=0.20427 -- acc=90.95469
#
#   valid loss:		0.05821
#   valid accuracy:	0.99994+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.20121 -- acc=91.00052
#
#   valid loss:		0.05437
#   valid accuracy:	0.99996+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=4.34s -- loss=0.19957 -- acc=91.08698
#
#   valid loss:		0.05365
#   valid accuracy:	0.99994+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.37s -- loss=0.19637 -- acc=91.20417
#
#   valid loss:		0.05298
#   valid accuracy:	0.99992+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.48s -- loss=0.19540 -- acc=91.17448
#
#   valid loss:		0.05216
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=4.27s -- loss=0.19395 -- acc=91.18073
#
#   valid loss:		0.04914
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=4.34s -- loss=0.19468 -- acc=91.13750
#
#   valid loss:		0.05089
#   valid accuracy:	0.99977+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=4.27s -- loss=0.19270 -- acc=91.27188
#
#   valid loss:		0.05364
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=4.43s -- loss=0.19275 -- acc=91.27084
#
#   valid loss:		0.05062
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=4.33s -- loss=0.19092 -- acc=91.38542
#
#   valid loss:		0.05003
#   valid accuracy:	0.99987+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=4.38s -- loss=0.19198 -- acc=91.23906
#
#   valid loss:		0.05029
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=4.31s -- loss=0.18906 -- acc=91.48698
#
#   valid loss:		0.04834
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=4.35s -- loss=0.19083 -- acc=91.38959
#
#   valid loss:		0.04822
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=4.31s -- loss=0.19120 -- acc=91.33646
#
#   valid loss:		0.05089
#   valid accuracy:	0.99983+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=4.37s -- loss=0.18856 -- acc=91.52552
#
#   valid loss:		0.04927
#   valid accuracy:	0.99983+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=4.41s -- loss=0.19146 -- acc=91.31146
#
#   valid loss:		0.04777
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=4.32s -- loss=0.18924 -- acc=91.45990
#
#   valid loss:		0.04848
#   valid accuracy:	0.99996+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=4.33s -- loss=0.19053 -- acc=91.35000
#
#   valid loss:		0.05073
#   valid accuracy:	0.99994+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=4.42s -- loss=0.19195 -- acc=91.22761
#
#   valid loss:		0.04944
#   valid accuracy:	0.99992+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=4.31s -- loss=0.19092 -- acc=91.41146
#
#   valid loss:		0.05036
#   valid accuracy:	0.99987+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=4.38s -- loss=0.19099 -- acc=91.39219
#
#   valid loss:		0.04762
#   valid accuracy:	0.99994+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.19013 -- acc=91.48959
#
#   valid loss:		0.04921
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=4.31s -- loss=0.18904 -- acc=91.46927
#
#   valid loss:		0.04889
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=4.44s -- loss=0.18948 -- acc=91.49115
#
#   valid loss:		0.04740
#   valid accuracy:	0.99987+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=4.46s -- loss=0.19158 -- acc=91.33959
#
#   valid loss:		0.04744
#   valid accuracy:	0.99992+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=4.32s -- loss=0.18932 -- acc=91.48281
#
#   valid loss:		0.04860
#   valid accuracy:	0.99998+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=4.36s -- loss=0.19119 -- acc=91.41511
#
#   valid loss:		0.04840
#   valid accuracy:	0.99998+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=4.45s -- loss=0.18797 -- acc=91.54844
#
#   valid loss:		0.04982
#   valid accuracy:	0.99998+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=4.35s -- loss=0.18911 -- acc=91.49844
#
#   valid loss:		0.04782
#   valid accuracy:	0.99996+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=4.34s -- loss=0.18946 -- acc=91.44740
#
#   valid loss:		0.04777
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 36 out of 100
# [=================             ] 57.6% -- remaining time=1s -- loss=0.18787 -- accuracy=91.55%

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_15_best.ckpt
#   test  loss:		0.04730
#   test  accuracy:	0.99998+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %% [markdown]
# ## First order mutagenesis saliency

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
numplots=5

for ii in range(numplots): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='output', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Second Order Mutagenesis

# %%
savepath = 'Arrays/toyhairpin_FC_1_15_sumoutputs1k.npy'

num_summary = 1000
X = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average(X, savepath, nntrainer, sess, progress='off')
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/toyhairpin_FC_1_15_sumoutputs1k.npy

# %%
#Load the saved data
savepath = 'Arrays/toyhairpin_FC_1_15_sumoutputs1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

# %%
mf.symlinear_holplot(meanhol_mut2, figplot=(4,5), alphabet='rna')

# %%
mf.square_holplot(meanhol_mut2, num=15, alphabet='rna')
