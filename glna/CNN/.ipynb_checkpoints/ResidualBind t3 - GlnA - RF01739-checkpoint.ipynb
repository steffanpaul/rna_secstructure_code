# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
#Save dictionaries into h5py files
hdf5path = '../../../data_RFAM/glnAsim_100k_t2.hdf5'
with h5py.File(hdf5path, 'w') as f:
    f.create_dataset('X_data', data=X_data)
    f.create_dataset('Y_data', data=Y_data)

# %%
##Make our post processed data - remove columns where x% is gapped

starttime = time.time()

#Open data
'''trial2 data - X data with 100k sequences with gaps (max size=893), Y data generated by p(gap|ungapped)=0.005 p(gap|gapped)=0.995'''

data_path = '../../../data_RFAM/glnAsim_100k_t2.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
num_data, seq_length, _, dims = X_data.shape
dims = dims-1
    
print (time.time() - starttime)
# Out:
# 1.91382908821

# %%
#extract the positive control
Xpos = X_data[:num_data//2]
Xmargin = np.sum(Xpos, axis=0)/(num_data/2)

#identify columns to be cut
indices = []
ranges = np.linspace(0., 1., 1000)
for cutoff in ranges:
    idx = np.where(Xmargin[:,:,4]>cutoff)
    indices.append(893-idx[0].shape[0])
    
plt.figure()
plt.plot(ranges, indices)
plt.xlabel('cutoff: greater than this indices will be cut')
plt.ylabel('number of indices: these many columns will be kept')
plt.show()

tolerance = 0.5
cut_indices = np.squeeze(np.where(Xmargin[:,:,4]<=tolerance)[0])

#remove these sequences from the full data
X_data = X_data[:, cut_indices, :, :]
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.2
valid_frac = 0.1
N = num_data
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'resbind_t3')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 61, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# ...

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=11.42s -- loss=0.01196 -- acc=99.72357%
#
#   valid loss:		0.00494
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t3_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=10.01s -- loss=0.00517 -- acc=99.95785%
#
#   valid loss:		0.00365
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t3_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=10.16s -- loss=0.00415 -- acc=99.96571%
#
#   valid loss:		0.00403
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 4 out of 100
# ...

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/resbind_t3_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t3_best.ckpt
#   test  loss:		0.00122
#   test  accuracy:	1.00000+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
numplots=5

for ii in range(numplots): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
seqstr
# Out:
# 'AUCGUUCAuCuccccuuuuuggggaGaCGGAAGUAGGcaauaaaugCCGAAGGAACGCguu'

# %%
# saliency parameters  <-- neccessary because we need to rebuild graph using different gradient ops
params = {'genome_model': cnn_model, 
          'input_shape': input_shape, 
          'output_shape': output_shape, 
          'optimization': optimization,
          'model_path': param_path+'_best.ckpt',
         }

num_plots = 5
for ii in range(num_plots):
    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    # guided backprop
    guided_saliency = saliency.guided_backprop(X, layer='output', class_index=None, params=params)

    # plot and save saliency
    fig = plt.figure(figsize=(10,7.5))
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                    np.squeeze(guided_saliency[0]).T, 
                                    alphabet='rna', 
                                    nt_width=400)
# Out:
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t3_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t3_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t3_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t3_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t3_best.ckpt

# %%
layer='output'

num_plots=np.linspace(0,20000,10).astype(int)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    gap_index = np.where(np.sum(X, axis=0)!=0)[0]
    
    norm_heat_mut = mf.fom_heatmap(X, layer='output', alphabet='rna', nntrainer=nntrainer, sess=sess, eps=1e-7)

    plt.figure(figsize=(10,1.5))
    sb.heatmap(norm_heat_mut, vmin=0, vmax=1)

# %%
num_plots[-1]
# Out:
# 20000

# %%
num_plots=np.linspace(0,20000,20).astype(int)
for ii in num_plots[:5]: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    plt.figure(figsize=(15,1))
    visualize.plot_pos_saliency(np.squeeze(X).T, alphabet='rna', norm_factor=0, nt_width=400)

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'
SC = ''
with open(simalign_file) as f1:
    for line in f1:
        if '#=GC RF' in line:
            line = line.strip()
            line = line.split()
            SC = SC + line[-1]
len(SC)
# Out:
# 893

# %%
seqstr = ''
for j in cut_indices:
    seqstr = seqstr + SC[j]
seqstr
# Out:
# 'AUCGUUCAuCuccccuuuuuggggaGaCGGAAGUAGGcaauaaaugCCGAAGGAACGCguu'

# %%
simalign_file = '../../../data_RFAM/seeds/RF01739.sto'
SCseed = ''
with open(simalign_file) as f1:
    for line in f1:
        if '#=GC RF' in line:
            line = line.strip()
            line = line.split()
            SCseed = SCseed + line[-1]
seqseedstr = ''
for j in SCseed:
    seqseedstr = seqseedstr + j
seqseedstr
# Out:
# 'AUCGUUCAuCucccc........................uuuuu......................................................................ggggaGaCGG.AAGUAGGca...................auaaa...................................................................................................ugCCGAAGGAACGCguu'

# %%
#second order mutagenesis

savepath = 'Arrays/glnA_Resbind_sumoutputs5k.npy'

num_summary = 1
X = np.expand_dims(test['inputs'][plot_index[num_plots[-1]]], axis=0)

sum_mut2 = mf.som_average(X, savepath, nntrainer, sess, progress='on', save=False, layer='dense_1_bias')
# Out:
# 0
# Epoch duration =0.97s
# Cumulative duration =0.97s

# %%
#Load the saved data
savepath = 'Arrays/glnA_Resbind_sumoutputs5k.npy'
#sum_mut2 = np.load(savepath)

#average the values
num_summary = 1
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],dims,dims)

# %%
mf.square_holplot(meanhol_mut2, num=9,alphabet='rna', start=(0,51), title=True, limits=False)

# %%
X.shape[1]
# Out:
# 61
