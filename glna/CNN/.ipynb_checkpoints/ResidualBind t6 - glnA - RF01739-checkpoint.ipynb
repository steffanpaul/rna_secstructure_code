# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/glnA_100k_t6.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 16.09s

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

bpSS
# Out:
# '(((((<<<<<<<>>>>>>><<<<>>>>)))))'

# %%
ugSS
# Out:
# '::(((((,<<<<<<<_____>>>>>>>,,,,,,,,<<<<_____>>>>,,,,)))))::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'resbind_t6')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 893, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=15.20s -- loss=0.00920 -- acc=99.84583%
#
#   valid loss:		0.00549
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=14.01s -- loss=0.00566 -- acc=99.95833%
#
#   valid loss:		0.00521
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=13.97s -- loss=0.00483 -- acc=99.96333%
#
#   valid loss:		0.00393
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=13.97s -- loss=0.00444 -- acc=99.96167%
#
#   valid loss:		0.00364
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=13.97s -- loss=0.00395 -- acc=99.97000%
#
#   valid loss:		0.00379
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=14.02s -- loss=0.00422 -- acc=99.96500%
#
#   valid loss:		0.00421
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=14.02s -- loss=0.00445 -- acc=99.96917%
#
#   valid loss:		0.00489
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=14.02s -- loss=0.00466 -- acc=99.97000%
#
#   valid loss:		0.00457
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=14.01s -- loss=0.00516 -- acc=99.95833%
#
#   valid loss:		0.00623
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=14.03s -- loss=0.00484 -- acc=99.97583%
#
#   valid loss:		0.00435
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=14.07s -- loss=0.00481 -- acc=99.97000%
#
#   valid loss:		0.00516
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=14.09s -- loss=0.00470 -- acc=99.97417%
#
#   valid loss:		0.00509
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=14.11s -- loss=0.00405 -- acc=99.98000%
#
#   valid loss:		0.00450
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00486 -- acc=99.96583%
#
#   valid loss:		0.00432
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=14.11s -- loss=0.00398 -- acc=99.98167%
#
#   valid loss:		0.00387
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=14.08s -- loss=0.00434 -- acc=99.97083%
#
#   valid loss:		0.00489
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=14.13s -- loss=0.00420 -- acc=99.98083%
#
#   valid loss:		0.00578
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00418 -- acc=99.98083%
#
#   valid loss:		0.00454
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00417 -- acc=99.97917%
#
#   valid loss:		0.00386
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.00368 -- acc=99.97917%
#
#   valid loss:		0.00380
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00334 -- acc=99.98583%
#
#   valid loss:		0.00374
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=14.13s -- loss=0.00385 -- acc=99.98000%
#
#   valid loss:		0.00353
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=14.13s -- loss=0.00364 -- acc=99.97833%
#
#   valid loss:		0.00382
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=14.11s -- loss=0.00272 -- acc=99.99000%
#
#   valid loss:		0.00344
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=14.20s -- loss=0.00328 -- acc=99.98000%
#
#   valid loss:		0.00764
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00345 -- acc=99.98250%
#
#   valid loss:		0.00550
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00351 -- acc=99.97333%
#
#   valid loss:		0.00475
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00323 -- acc=99.98917%
#
#   valid loss:		0.00356
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.00281 -- acc=99.98583%
#
#   valid loss:		0.00339
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.00296 -- acc=99.98583%
#
#   valid loss:		0.00398
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00333 -- acc=99.98083%
#
#   valid loss:		0.00420
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00300 -- acc=99.99083%
#
#   valid loss:		0.00402
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.00326 -- acc=99.98083%
#
#   valid loss:		0.00378
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00280 -- acc=99.98833%
#
#   valid loss:		0.00341
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00252 -- acc=99.98917%
#
#   valid loss:		0.00299
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00236 -- acc=99.99000%
#
#   valid loss:		0.00309
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.00257 -- acc=99.98500%
#
#   valid loss:		0.00386
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00283 -- acc=99.98667%
#
#   valid loss:		0.00292
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.00238 -- acc=99.99167%
#
#   valid loss:		0.00337
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00225 -- acc=99.99000%
#
#   valid loss:		0.00264
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00230 -- acc=99.98583%
#
#   valid loss:		0.00350
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00233 -- acc=99.98833%
#
#   valid loss:		0.00325
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00228 -- acc=99.99083%
#
#   valid loss:		0.00299
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00196 -- acc=99.99083%
#
#   valid loss:		0.00290
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00220 -- acc=99.99000%
#
#   valid loss:		0.00272
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.00239 -- acc=99.98833%
#
#   valid loss:		0.00377
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=14.13s -- loss=0.00236 -- acc=99.98583%
#
#   valid loss:		0.00317
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00234 -- acc=99.98583%
#
#   valid loss:		0.00352
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00224 -- acc=99.98917%
#
#   valid loss:		0.00313
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=14.15s -- loss=0.00248 -- acc=99.98667%
#
#   valid loss:		0.00265
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00167 -- acc=99.996670%
#
#   valid loss:		0.00376
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00275 -- acc=99.98417%
#
#   valid loss:		0.00296
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00194 -- acc=99.99167%
#
#   valid loss:		0.00290
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00189 -- acc=99.99250%
#
#   valid loss:		0.00300
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00231 -- acc=99.98500%
#
#   valid loss:		0.00297
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00214 -- acc=99.99000%
#
#   valid loss:		0.00255
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00210 -- acc=99.98667%
#
#   valid loss:		0.00313
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00201 -- acc=99.98833%
#
#   valid loss:		0.00282
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00224 -- acc=99.98083%
#
#   valid loss:		0.00298
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00208 -- acc=99.98833%
#
#   valid loss:		0.00285
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00214 -- acc=99.98583%
#
#   valid loss:		0.00286
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00184 -- acc=99.995830%
#
#   valid loss:		0.00237
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00189 -- acc=99.98667%
#
#   valid loss:		0.00271
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=14.16s -- loss=0.00216 -- acc=99.98500%
#
#   valid loss:		0.00251
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=14.21s -- loss=0.00164 -- acc=99.99500%
#
#   valid loss:		0.00240
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00212 -- acc=99.98417%
#
#   valid loss:		0.00236
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=14.21s -- loss=0.00203 -- acc=99.98583%
#
#   valid loss:		0.00247
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=14.20s -- loss=0.00199 -- acc=99.98833%
#
#   valid loss:		0.00244
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00194 -- acc=99.98833%
#
#   valid loss:		0.00261
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00195 -- acc=99.99083%
#
#   valid loss:		0.00236
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00197 -- acc=99.98583%
#
#   valid loss:		0.00279
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00168 -- acc=99.99333%
#
#   valid loss:		0.00261
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00202 -- acc=99.98750%
#
#   valid loss:		0.00320
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=14.20s -- loss=0.00178 -- acc=99.99000%
#
#   valid loss:		0.00225
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00203 -- acc=99.98750%
#
#   valid loss:		0.00261
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00176 -- acc=99.99083%
#
#   valid loss:		0.00310
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00191 -- acc=99.98750%
#
#   valid loss:		0.00250
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00195 -- acc=99.99000%
#
#   valid loss:		0.00248
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00169 -- acc=99.99167%
#
#   valid loss:		0.00255
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00253 -- acc=99.98167%
#
#   valid loss:		0.00332
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00219 -- acc=99.99000%
#
#   valid loss:		0.00265
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00174 -- acc=99.99417%
#
#   valid loss:		0.00255
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00193 -- acc=99.99083%
#
#   valid loss:		0.00247
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00195 -- acc=99.98667%
#
#   valid loss:		0.00303
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00188 -- acc=99.99167%
#
#   valid loss:		0.00291
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00178 -- acc=99.99083%
#
#   valid loss:		0.00276
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=14.21s -- loss=0.00201 -- acc=99.98750%
#
#   valid loss:		0.00290
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00175 -- acc=99.99500%
#
#   valid loss:		0.00243
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=14.21s -- loss=0.00193 -- acc=99.98417%
#
#   valid loss:		0.00276
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00189 -- acc=99.98917%
#
#   valid loss:		0.00268
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00204 -- acc=99.98917%
#
#   valid loss:		0.00257
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00209 -- acc=99.98833%
#
#   valid loss:		0.00252
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00181 -- acc=99.99083%
#
#   valid loss:		0.00289
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.00166 -- acc=99.99167%
#
#   valid loss:		0.00311
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00233 -- acc=99.98083%
#
#   valid loss:		0.00261
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.00183 -- acc=99.99333%
#
#   valid loss:		0.00282
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00159 -- acc=99.995830%
#
#   valid loss:		0.00274
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=14.28s -- loss=0.00151 -- acc=99.99500%
#
#   valid loss:		0.00213
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t6_best.ckpt
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00199 -- acc=99.98333%
#
#   valid loss:		0.00273
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00207 -- acc=99.98417%
#
#   valid loss:		0.00239
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/resbind_t6_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t6_best.ckpt
#   test  loss:		0.00126
#   test  accuracy:	1.00000+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

plt.figure()
plt.ylabel('Predicted score')
plt.xlabel('Sequences ordered by score')
plt.plot(range(len(plot_index)), predictionsoutput[plot_index])
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/glna_resbindt6_ug_so1k.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='off', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/glna_resbindt6_ug_so1k.npy

# %%
#load values
savepath = 'Arrays/glna_resbindt6_ug_so1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

def normalize_mut_hol(hol_mut, WTmean, nntrainer, sess, normfactor=None):
    norm_hol_mut = np.copy(hol_mut) - WTmean
    for one in range(hol_mut.shape[0]):
        for two in range(hol_mut.shape[0]):
            norm_hol_mut[one, two] = mf.normalize_hol(hol_mut[one, two], factor=normfactor)
    return norm_hol_mut

norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=None, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
bpugSQ = ['.' for i in range(len(ugidx))]
bpugidx = []
for i, ix in enumerate(ugidx):
    if ix in bpidx:
        bpugSQ[i] = SQ[ix]
        bpugidx.append(i)

# %%
C[bpugidx][:, bpugidx].shape
# Out:
# (32, 32)
