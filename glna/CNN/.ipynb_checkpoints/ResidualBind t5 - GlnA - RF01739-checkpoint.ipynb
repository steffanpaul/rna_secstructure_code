# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data
'''trial2 data - X data with 100k sequences with gaps (max size=893), Y data generated by p(gap|ungapped)=0.005 p(gap|gapped)=0.995'''

data_path = '../../../data_RFAM/glnAsim_100k_t2.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
num_data, seq_length, _, dims = X_data.shape
dims = dims-1
    
print ('Data extraction completed in: ' + str(time.time() - starttime) + 's')
# Out:
# Data extraction completed in: 14.515734911s

# %%
starttime = time.time()

#create a random dataset
Xneg_rand = mf.seq_generator(num_data//2, seq_length, dims+1, 274)
print ('Random sequence generation completed in: ' + str(time.time() - starttime) + 's')
# Out:
# Random sequence generation completed in: 31.1137320995s

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'
SS = mf.getSSconsensus(simalign_file)
bpchars = ['(',')','<','>','{','}']

nonbp_idx = []
for i,s in enumerate(SS):
    if s not in bpchars:
        nonbp_idx.append(i)

# %%
simalign_file = '../../../data_RFAM/seeds/RF01739.sto'
SS = mf.getSSconsensus(simalign_file)
_, ugSS, _ = mf.rm_consensus_gaps(X_data, SS)
ugSS
# Out:
# '::(((((,<<<<<<<_____>>>>>>>,,,,,,,,<<<<_____>>>>,,,,)))))::::'

# %%
starttime = time.time()
#extract the positive control
Xpos = X_data[:num_data//2]

#insert non base pair positive control things into negative control
for s in range(Xpos.shape[0]):
    Xneg_rand[s, nonbp_idx, :, :] = np.copy(Xpos[s, nonbp_idx, :, :])

print ('Making neg control w/o base pairs: ' + str(time.time() - starttime) + 's')
# Out:
# Making neg control w/o base pairs: 7.56334495544s

# %%
if Xneg_rand[:, nonbp_idx, :, :].all() == Xpos[:, nonbp_idx, :, :].all():
    print ('Success!')
# Out:
# Success!

# %%
#rejoin pos and neg controls
X_data = np.concatenate((Xpos, Xneg_rand), axis=0)

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.2
valid_frac = 0.1
N = num_data
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'resbind_t5')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 893, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/resbind_t5_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t5_best.ckpt
#   test  loss:		0.03149
#   test  accuracy:	0.99365+/-0.00000
#   test  auc-roc:	0.99978+/-0.00000
#   test  auc-pr:		0.99978+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
numplots=5

for ii in range(numplots): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    
    norm_heat_mut = mf.fom_heatmap(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, eps=1e-7)
    nucpos = np.zeros(shape=(1,seq_length))
    nucpos[:, nuc_index] = 1.
    norm_heat_mut = np.append(norm_heat_mut, nucpos, axis=0)
    
    
    plt.figure(figsize=(10,1.5))
    plt.title('Sequence score rank: %s' %ii)
    sb.heatmap(norm_heat_mut, vmin=0, vmax=1, yticklabels=['A', 'C', 'G', 'U', 'Gap'])

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

bpSS
# Out:
# '(((((<<<<<<<>>>>>>><<<<>>>>)))))'

# %%
savepath = 'Arrays/glna_resbindt5_ug_so2000.npy'

num_summary = 2000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =3.42s
# Cumulative duration =3.42s
#
# 1
# Epoch duration =3.12s
# Cumulative duration =6.54s
#
# 2
# Epoch duration =3.05s
# Cumulative duration =9.59s
#
# 3
# Epoch duration =2.35s
# Cumulative duration =11.94s
#
# 4
# Epoch duration =2.93s
# Cumulative duration =14.87s
#
# 5
# Epoch duration =2.33s
# Cumulative duration =17.21s
#
# 6
# Epoch duration =2.92s
# Cumulative duration =20.13s
#
# 7
# Epoch duration =2.32s
# Cumulative duration =22.45s
#
# 8
# Epoch duration =2.9s
# Cumulative duration =25.35s
#
# 9
# Epoch duration =2.32s
# Cumulative duration =27.68s
#
# 10
# Epoch duration =2.9s
# Cumulative duration =30.58s
#
# 11
# Epoch duration =2.33s
# Cumulative duration =32.91s
#
# 12
# Epoch duration =2.97s
# Cumulative duration =35.88s
#
# 13
# Epoch duration =2.34s
# Cumulative duration =38.22s
#
# 14
# Epoch duration =2.95s
# Cumulative duration =41.17s
#
# 15
# Epoch duration =2.34s
# Cumulative duration =43.51s
#
# 16
# Epoch duration =2.94s
# Cumulative duration =46.45s
#
# 17
# Epoch duration =2.35s
# Cumulative duration =48.8s
#
# 18
# Epoch duration =2.93s
# Cumulative duration =51.73s
#
# 19
# Epoch duration =2.34s
# Cumulative duration =54.07s
#
# 20
# Epoch duration =2.94s
# Cumulative duration =57.0s
#
# 21
# Epoch duration =2.36s
# Cumulative duration =59.36s
#
# 22
# Epoch duration =3.18s
# Cumulative duration =1min 2.539999999999999s
#
# 23
# Epoch duration =2.42s
# Cumulative duration =1min 4.969999999999999s
#
# 24
# Epoch duration =3.35s
# Cumulative duration =1min 8.319999999999993s
#
# 25
# Epoch duration =2.99s
# Cumulative duration =1min 11.310000000000002s
#
# 26
# Epoch duration =3.0s
# Cumulative duration =1min 14.299999999999997s
#
# 27
# Epoch duration =2.36s
# Cumulative duration =1min 16.67s
#
# 28
# Epoch duration =3.2s
# Cumulative duration =1min 19.870000000000005s
#
# 29
# Epoch duration =2.47s
# Cumulative duration =1min 22.340000000000003s
#
# 30
# Epoch duration =3.2s
# Cumulative duration =1min 25.540000000000006s
#
# 31
# Epoch duration =2.48s
# Cumulative duration =1min 28.019999999999996s
#
# 32
# Epoch duration =2.94s
# Cumulative duration =1min 30.959999999999994s
#
# 33
# Epoch duration =2.35s
# Cumulative duration =1min 33.31s
#
# 34
# Epoch duration =2.77s
# Cumulative duration =1min 36.08s
#
# 35
# Epoch duration =2.39s
# Cumulative duration =1min 38.47s
#
# 36
# Epoch duration =3.01s
# Cumulative duration =1min 41.480000000000004s
#
# 37
# Epoch duration =2.36s
# Cumulative duration =1min 43.84s
#
# 38
# Epoch duration =2.89s
# Cumulative duration =1min 46.730000000000004s
#
# 39
# Epoch duration =2.36s
# Cumulative duration =1min 49.099999999999994s
#
# 40
# Epoch duration =2.9s
# Cumulative duration =1min 51.989999999999995s
#
# 41
# Epoch duration =2.35s
# Cumulative duration =1min 54.34s
#
# 42
# Epoch duration =2.92s
# Cumulative duration =1min 57.260000000000005s
#
# 43
# Epoch duration =2.35s
# Cumulative duration =1min 59.599999999999994s
#
# 44
# Epoch duration =2.91s
# Cumulative duration =2min 2.519999999999996s
#
# 45
# Epoch duration =2.34s
# Cumulative duration =2min 4.859999999999999s
#
# 46
# Epoch duration =2.92s
# Cumulative duration =2min 7.790000000000006s
#
# 47
# Epoch duration =2.37s
# Cumulative duration =2min 10.159999999999997s
#
# 48
# Epoch duration =2.91s
# Cumulative duration =2min 13.069999999999993s
#
# 49
# Epoch duration =2.38s
# Cumulative duration =2min 15.449999999999989s
#
# 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-f4bd27f26563> in <module>()
#       6 sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer,
#       7                                 sess=sess, progress='on', save=True, layer='dense_1_bias',
# ----> 8                                normalize=False, normfactor=0)
#
# /home/peter/steffan/mutagenesisfunctions.pyc in som_average_ungapped(Xdict, ungapped_index, savepath, nntrainer, sess, progress, save, layer, normalize, normfactor, eps)
#     478         X = np.expand_dims(Xdict[ii], axis=0)
#     479
# --> 480         X_mutsecorder = double_mutate_ungapped(X, ungapped_index)
#     481
#     482         #reshape the 6D tensor into a 4D tensor that the model can test
#
# /home/peter/steffan/mutagenesisfunctions.pyc in double_mutate_ungapped(X, ungapped_index)
#     150                 for nuc2 in range(dims):
#     151
# --> 152                     mut_seq = np.copy(X)
#     153                     mut_seq[0, position1, 0, :] = np.zeros(dims)
#     154                     mut_seq[0, position1, 0, nuc1] = 1.0
#
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/numpy/lib/function_base.pyc in copy(a, order)
#    1503
#    1504     """
# -> 1505     return array(a, order=order, copy=True)
#    1506
#    1507 # Basic operations
#
# KeyboardInterrupt:

# %%
#load values
savepath = 'Arrays/glna_resbindt5_ug_so50.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 50
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
bpugSQ = ['.' for i in range(len(ugidx))]
bpugidx = []
for i, ix in enumerate(ugidx):
    if ix in bpidx:
        bpugSQ[i] = SQ[ix]
        bpugidx.append(i)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

def normalize_mut_hol(hol_mut, WTmean, nntrainer, sess, normfactor=None):
    norm_hol_mut = np.copy(hol_mut) - WTmean
    for one in range(hol_mut.shape[0]):
        for two in range(hol_mut.shape[0]):
            norm_hol_mut[one, two] = mf.normalize_hol(hol_mut[one, two], factor=normfactor)
    return norm_hol_mut

norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
#C = C - np.mean(C)
#C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
