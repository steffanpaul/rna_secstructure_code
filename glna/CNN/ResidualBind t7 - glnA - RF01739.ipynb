# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/glna_100k_d7.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 10.49s

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<<>>>>>>><<<<>>>>)))))'

# %%
ugSS
# Out:
# '::(((((,<<<<<<<_____>>>>>>>,,,,,,,,<<<<_____>>>>,,,,)))))::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'resbind_t7')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 893, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=15.30s -- loss=0.03752 -- acc=98.66083%
#
#   valid loss:		0.00740
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=13.96s -- loss=0.01112 -- acc=99.82583%
#
#   valid loss:		0.00748
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=13.44s -- loss=0.00867 -- acc=99.91250%
#
#   valid loss:		0.01070
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	0.99974+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=13.67s -- loss=0.01021 -- acc=99.88333%
#
#   valid loss:		0.00790
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=13.40s -- loss=0.00871 -- acc=99.92333%
#
#   valid loss:		0.00770
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=13.39s -- loss=0.00980 -- acc=99.90750%
#
#   valid loss:		0.00893
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=13.42s -- loss=0.01092 -- acc=99.90667%
#
#   valid loss:		0.00855
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=13.43s -- loss=0.00980 -- acc=99.92083%
#
#   valid loss:		0.00907
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=14.36s -- loss=0.00959 -- acc=99.92167%
#
#   valid loss:		0.00880
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=13.48s -- loss=0.01028 -- acc=99.92583%
#
#   valid loss:		0.00870
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=13.43s -- loss=0.01025 -- acc=99.93167%
#
#   valid loss:		0.00837
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=13.49s -- loss=0.00920 -- acc=99.94583%
#
#   valid loss:		0.00799
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.00988 -- acc=99.92583%
#
#   valid loss:		0.00869
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=13.49s -- loss=0.00948 -- acc=99.94167%
#
#   valid loss:		0.00952
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=13.50s -- loss=0.00962 -- acc=99.93333%
#
#   valid loss:		0.00752
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=13.53s -- loss=0.00943 -- acc=99.93000%
#
#   valid loss:		0.00867
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=13.51s -- loss=0.00914 -- acc=99.94000%
#
#   valid loss:		0.00823
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=13.50s -- loss=0.00929 -- acc=99.93833%
#
#   valid loss:		0.00860
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=13.74s -- loss=0.00889 -- acc=99.94833%
#
#   valid loss:		0.00746
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=13.53s -- loss=0.00839 -- acc=99.94833%
#
#   valid loss:		0.00739
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=13.47s -- loss=0.00805 -- acc=99.95250%
#
#   valid loss:		0.00697
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00933 -- acc=99.93833%
#
#   valid loss:		0.00769
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=13.51s -- loss=0.00845 -- acc=99.95000%
#
#   valid loss:		0.00679
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00862 -- acc=99.94917%
#
#   valid loss:		0.00818
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.00838 -- acc=99.95167%
#
#   valid loss:		0.00720
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.00878 -- acc=99.93167%
#
#   valid loss:		0.00849
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00808 -- acc=99.95583%
#
#   valid loss:		0.00737
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00782 -- acc=99.94667%
#
#   valid loss:		0.00752
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00787 -- acc=99.94583%
#
#   valid loss:		0.00677
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00820 -- acc=99.95750%
#
#   valid loss:		0.00691
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00714 -- acc=99.95833%
#
#   valid loss:		0.00646
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00727 -- acc=99.95583%
#
#   valid loss:		0.00672
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=13.65s -- loss=0.00733 -- acc=99.95750%
#
#   valid loss:		0.00619
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=13.67s -- loss=0.00786 -- acc=99.94167%
#
#   valid loss:		0.01062
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00731 -- acc=99.96000%
#
#   valid loss:		0.00696
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00722 -- acc=99.95000%
#
#   valid loss:		0.00583
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00732 -- acc=99.95583%
#
#   valid loss:		0.00611
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.00777 -- acc=99.93833%
#
#   valid loss:		0.00668
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00704 -- acc=99.95917%
#
#   valid loss:		0.00726
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00678 -- acc=99.96667%
#
#   valid loss:		0.00617
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=13.56s -- loss=0.00721 -- acc=99.95250%
#
#   valid loss:		0.00583
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=13.63s -- loss=0.00697 -- acc=99.95250%
#
#   valid loss:		0.00594
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00713 -- acc=99.95083%
#
#   valid loss:		0.00619
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=13.57s -- loss=0.00668 -- acc=99.96500%
#
#   valid loss:		0.00602
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=13.56s -- loss=0.00617 -- acc=99.96417%
#
#   valid loss:		0.00607
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=13.62s -- loss=0.00739 -- acc=99.94667%
#
#   valid loss:		0.00643
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=13.62s -- loss=0.00657 -- acc=99.96750%
#
#   valid loss:		0.00612
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.00612 -- acc=99.96500%
#
#   valid loss:		0.00569
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=14.42s -- loss=0.00646 -- acc=99.94833%
#
#   valid loss:		0.00553
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=14.66s -- loss=0.00671 -- acc=99.95167%
#
#   valid loss:		0.00514
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00649 -- acc=99.96167%
#
#   valid loss:		0.00593
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=13.97s -- loss=0.00644 -- acc=99.95250%
#
#   valid loss:		0.00603
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.00653 -- acc=99.95417%
#
#   valid loss:		0.00588
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.00595 -- acc=99.96667%
#
#   valid loss:		0.00593
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=13.93s -- loss=0.00657 -- acc=99.94583%
#
#   valid loss:		0.00628
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.00615 -- acc=99.96250%
#
#   valid loss:		0.00607
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=13.90s -- loss=0.00638 -- acc=99.95000%
#
#   valid loss:		0.00558
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.00601 -- acc=99.97333%
#
#   valid loss:		0.00584
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=13.89s -- loss=0.00646 -- acc=99.95000%
#
#   valid loss:		0.00664
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=13.94s -- loss=0.00623 -- acc=99.96083%
#
#   valid loss:		0.00524
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=13.90s -- loss=0.00596 -- acc=99.96333%
#
#   valid loss:		0.00511
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=13.92s -- loss=0.00591 -- acc=99.97083%
#
#   valid loss:		0.00522
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=13.90s -- loss=0.00589 -- acc=99.95667%
#
#   valid loss:		0.00510
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=13.89s -- loss=0.00640 -- acc=99.95083%
#
#   valid loss:		0.00555
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=13.90s -- loss=0.00636 -- acc=99.96417%
#
#   valid loss:		0.00580
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=13.87s -- loss=0.00612 -- acc=99.95667%
#
#   valid loss:		0.00558
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=13.87s -- loss=0.00599 -- acc=99.96583%
#
#   valid loss:		0.00523
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=13.94s -- loss=0.00600 -- acc=99.95833%
#
#   valid loss:		0.00528
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=13.91s -- loss=0.00598 -- acc=99.96667%
#
#   valid loss:		0.00525
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.00580 -- acc=99.96417%
#
#   valid loss:		0.00549
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=13.93s -- loss=0.00575 -- acc=99.95833%
#
#   valid loss:		0.00550
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=13.93s -- loss=0.00549 -- acc=99.96667%
#
#   valid loss:		0.00478
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=14.00s -- loss=0.00578 -- acc=99.96667%
#
#   valid loss:		0.00541
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=13.92s -- loss=0.00575 -- acc=99.96583%
#
#   valid loss:		0.00565
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=13.91s -- loss=0.00564 -- acc=99.96500%
#
#   valid loss:		0.00509
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=13.89s -- loss=0.00576 -- acc=99.96083%
#
#   valid loss:		0.00507
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=13.95s -- loss=0.00527 -- acc=99.97500%
#
#   valid loss:		0.00501
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=13.97s -- loss=0.00571 -- acc=99.95583%
#
#   valid loss:		0.00579
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=13.94s -- loss=0.00591 -- acc=99.95417%
#
#   valid loss:		0.00520
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=13.93s -- loss=0.00521 -- acc=99.97000%
#
#   valid loss:		0.00486
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=13.99s -- loss=0.00556 -- acc=99.96250%
#
#   valid loss:		0.00520
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=13.93s -- loss=0.00601 -- acc=99.95167%
#
#   valid loss:		0.00526
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=13.99s -- loss=0.00550 -- acc=99.96750%
#
#   valid loss:		0.00511
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=14.00s -- loss=0.00538 -- acc=99.96500%
#
#   valid loss:		0.00515
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=13.92s -- loss=0.00587 -- acc=99.95500%
#
#   valid loss:		0.00607
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=13.91s -- loss=0.00608 -- acc=99.96083%
#
#   valid loss:		0.00520
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=13.89s -- loss=0.00558 -- acc=99.97417%
#
#   valid loss:		0.00463
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=13.94s -- loss=0.00528 -- acc=99.96000%
#
#   valid loss:		0.00464
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=13.91s -- loss=0.00512 -- acc=99.97583%
#
#   valid loss:		0.00463
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=13.93s -- loss=0.00530 -- acc=99.96750%
#
#   valid loss:		0.00450
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=13.91s -- loss=0.00579 -- acc=99.96583%
#
#   valid loss:		0.00449
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=13.90s -- loss=0.00540 -- acc=99.96667%
#
#   valid loss:		0.00509
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=13.88s -- loss=0.00532 -- acc=99.96750%
#
#   valid loss:		0.00523
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=13.87s -- loss=0.00476 -- acc=99.97750%
#
#   valid loss:		0.00449
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=13.88s -- loss=0.00573 -- acc=99.96333%
#
#   valid loss:		0.00482
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=13.88s -- loss=0.00487 -- acc=99.97167%
#
#   valid loss:		0.00419
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t7_best.ckpt
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=13.83s -- loss=0.00527 -- acc=99.95167%
#
#   valid loss:		0.00681
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=13.88s -- loss=0.00533 -- acc=99.96500%
#
#   valid loss:		0.00482
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=13.98s -- loss=0.00494 -- acc=99.97833%
#
#   valid loss:		0.00451
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=13.87s -- loss=0.00544 -- acc=99.95750%
#
#   valid loss:		0.00638
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/resbind_t7_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t7_best.ckpt
#   test  loss:		0.00414
#   test  accuracy:	0.99992+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

plt.figure()
plt.ylabel('Predicted score')
plt.xlabel('Sequences ordered by score')
plt.plot(range(len(plot_index)), predictionsoutput[plot_index])
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/glna_resbindt7_ug_so1k.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='off', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/glna_resbindt7_ug_so1k.npy

# %%
#load values
savepath = 'Arrays/glna_resbindt7_ug_so1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

def normalize_mut_hol(hol_mut, WTmean, nntrainer, sess, normfactor=None):
    norm_hol_mut = np.copy(hol_mut) - WTmean
    for one in range(hol_mut.shape[0]):
        for two in range(hol_mut.shape[0]):
            norm_hol_mut[one, two] = mf.normalize_hol(hol_mut[one, two], factor=normfactor)
    return norm_hol_mut

norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
bpugSQ = ['.' for i in range(len(ugidx))]
bpugidx = []
for i, ix in enumerate(ugidx):
    if ix in bpidx:
        bpugSQ[i] = SQ[ix]
        bpugidx.append(i)

# %%
C[bpugidx][:, bpugidx].shape
# Out:
# (32, 32)
