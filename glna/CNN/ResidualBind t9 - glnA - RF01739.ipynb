# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/glna_100k_d9.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 10.6s

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<<>>>>>>><<<<>>>>)))))'

# %%
ugSS
# Out:
# '::(((((,<<<<<<<_____>>>>>>>,,,,,,,,<<<<_____>>>>,,,,)))))::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'resbind_t9')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 893, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=14.04s -- loss=0.03657 -- acc=98.66000%
#
#   valid loss:		0.00668
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=13.43s -- loss=0.01038 -- acc=99.82167%
#
#   valid loss:		0.00881
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=13.38s -- loss=0.00870 -- acc=99.88333%
#
#   valid loss:		0.00908
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=13.39s -- loss=0.00802 -- acc=99.91000%
#
#   valid loss:		0.00708
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=13.39s -- loss=0.00915 -- acc=99.89583%
#
#   valid loss:		0.00697
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=13.38s -- loss=0.00864 -- acc=99.92167%
#
#   valid loss:		0.00677
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=13.41s -- loss=0.00933 -- acc=99.92167%
#
#   valid loss:		0.00800
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=13.45s -- loss=0.01003 -- acc=99.90667%
#
#   valid loss:		0.00858
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=13.44s -- loss=0.00936 -- acc=99.92083%
#
#   valid loss:		0.00771
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=13.47s -- loss=0.00910 -- acc=99.93833%
#
#   valid loss:		0.00731
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=13.47s -- loss=0.00992 -- acc=99.92000%
#
#   valid loss:		0.00789
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=13.45s -- loss=0.00923 -- acc=99.92500%
#
#   valid loss:		0.00772
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=13.45s -- loss=0.00812 -- acc=99.96083%
#
#   valid loss:		0.00874
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=13.47s -- loss=0.00922 -- acc=99.93333%
#
#   valid loss:		0.00700
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=13.47s -- loss=0.00854 -- acc=99.94417%
#
#   valid loss:		0.00688
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=13.49s -- loss=0.00935 -- acc=99.92833%
#
#   valid loss:		0.00705
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=13.49s -- loss=0.00894 -- acc=99.94167%
#
#   valid loss:		0.00700
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=13.56s -- loss=0.00810 -- acc=99.94833%
#
#   valid loss:		0.00649
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=13.50s -- loss=0.00842 -- acc=99.93667%
#
#   valid loss:		0.00713
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=13.50s -- loss=0.00808 -- acc=99.94833%
#
#   valid loss:		0.00673
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.00821 -- acc=99.93500%
#
#   valid loss:		0.00710
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.00797 -- acc=99.95167%
#
#   valid loss:		0.00650
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=13.53s -- loss=0.00725 -- acc=99.96250%
#
#   valid loss:		0.00658
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=13.53s -- loss=0.00793 -- acc=99.94583%
#
#   valid loss:		0.00674
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00761 -- acc=99.94833%
#
#   valid loss:		0.00611
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00724 -- acc=99.95500%
#
#   valid loss:		0.00680
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=13.51s -- loss=0.00782 -- acc=99.93750%
#
#   valid loss:		0.00616
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=13.51s -- loss=0.00720 -- acc=99.95083%
#
#   valid loss:		0.00637
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=13.50s -- loss=0.00733 -- acc=99.94750%
#
#   valid loss:		0.00653
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=13.49s -- loss=0.00750 -- acc=99.94833%
#
#   valid loss:		0.00600
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.00686 -- acc=99.95917%
#
#   valid loss:		0.00597
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00697 -- acc=99.95000%
#
#   valid loss:		0.00577
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.00676 -- acc=99.95500%
#
#   valid loss:		0.00713
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=13.50s -- loss=0.00637 -- acc=99.96750%
#
#   valid loss:		0.00560
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00639 -- acc=99.96000%
#
#   valid loss:		0.00515
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=13.53s -- loss=0.00668 -- acc=99.94833%
#
#   valid loss:		0.00668
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00645 -- acc=99.96417%
#
#   valid loss:		0.00557
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=13.53s -- loss=0.00686 -- acc=99.94500%
#
#   valid loss:		0.00575
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00666 -- acc=99.95417%
#
#   valid loss:		0.00548
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00622 -- acc=99.96500%
#
#   valid loss:		0.00543
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=13.57s -- loss=0.00621 -- acc=99.96583%
#
#   valid loss:		0.00558
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00694 -- acc=99.93417%
#
#   valid loss:		0.00558
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=13.57s -- loss=0.00605 -- acc=99.97000%
#
#   valid loss:		0.00542
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=13.53s -- loss=0.00633 -- acc=99.96000%
#
#   valid loss:		0.00523
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00644 -- acc=99.95833%
#
#   valid loss:		0.00526
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=13.57s -- loss=0.00577 -- acc=99.97333%
#
#   valid loss:		0.00485
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00636 -- acc=99.94667%
#
#   valid loss:		0.00571
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00675 -- acc=99.95167%
#
#   valid loss:		0.00550
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=13.65s -- loss=0.00586 -- acc=99.96750%
#
#   valid loss:		0.00538
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00563 -- acc=99.97167%
#
#   valid loss:		0.00486
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00628 -- acc=99.95083%
#
#   valid loss:		0.00536
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=13.56s -- loss=0.00561 -- acc=99.96833%
#
#   valid loss:		0.00492
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00606 -- acc=99.96167%
#
#   valid loss:		0.00540
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00597 -- acc=99.95917%
#
#   valid loss:		0.00532
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=13.57s -- loss=0.00559 -- acc=99.97250%
#
#   valid loss:		0.00575
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=13.63s -- loss=0.00602 -- acc=99.95500%
#
#   valid loss:		0.00497
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.00559 -- acc=99.96417%
#
#   valid loss:		0.00519
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00579 -- acc=99.96500%
#
#   valid loss:		0.00555
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.00552 -- acc=99.97167%
#
#   valid loss:		0.00483
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00581 -- acc=99.95083%
#
#   valid loss:		0.00541
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00584 -- acc=99.96000%
#
#   valid loss:		0.00489
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=13.64s -- loss=0.00570 -- acc=99.96583%
#
#   valid loss:		0.00465
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=13.62s -- loss=0.00534 -- acc=99.96667%
#
#   valid loss:		0.00482
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00535 -- acc=99.96833%
#
#   valid loss:		0.00467
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00540 -- acc=99.95750%
#
#   valid loss:		0.00482
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00540 -- acc=99.97333%
#
#   valid loss:		0.00452
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00582 -- acc=99.95667%
#
#   valid loss:		0.00467
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.00549 -- acc=99.96000%
#
#   valid loss:		0.00495
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.00501 -- acc=99.97333%
#
#   valid loss:		0.00447
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=13.68s -- loss=0.00578 -- acc=99.95417%
#
#   valid loss:		0.00497
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=13.62s -- loss=0.00583 -- acc=99.95750%
#
#   valid loss:		0.00486
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00514 -- acc=99.97167%
#
#   valid loss:		0.00463
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00572 -- acc=99.95333%
#
#   valid loss:		0.00484
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=13.66s -- loss=0.00510 -- acc=99.97000%
#
#   valid loss:		0.00443
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=13.63s -- loss=0.00530 -- acc=99.96833%
#
#   valid loss:		0.00437
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00559 -- acc=99.95667%
#
#   valid loss:		0.00449
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00496 -- acc=99.97750%
#
#   valid loss:		0.00419
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=13.62s -- loss=0.00553 -- acc=99.95667%
#
#   valid loss:		0.00446
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00506 -- acc=99.96500%
#
#   valid loss:		0.00439
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00566 -- acc=99.95333%
#
#   valid loss:		0.00449
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00517 -- acc=99.96250%
#
#   valid loss:		0.00438
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00524 -- acc=99.96250%
#
#   valid loss:		0.00421
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=13.63s -- loss=0.00516 -- acc=99.96750%
#
#   valid loss:		0.00441
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00503 -- acc=99.96667%
#
#   valid loss:		0.00500
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00552 -- acc=99.95583%
#
#   valid loss:		0.00439
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=13.63s -- loss=0.00471 -- acc=99.97417%
#
#   valid loss:		0.00476
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.00491 -- acc=99.96750%
#
#   valid loss:		0.00469
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.00523 -- acc=99.95917%
#
#   valid loss:		0.00431
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00478 -- acc=99.97333%
#
#   valid loss:		0.00428
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.00503 -- acc=99.96667%
#
#   valid loss:		0.00404
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00531 -- acc=99.96250%
#
#   valid loss:		0.00412
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=13.62s -- loss=0.00514 -- acc=99.96000%
#
#   valid loss:		0.00429
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00493 -- acc=99.96583%
#
#   valid loss:		0.00418
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00517 -- acc=99.95750%
#
#   valid loss:		0.00421
#   valid accuracy:	0.99990+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00498 -- acc=99.96167%
#
#   valid loss:		0.00405
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.00553 -- acc=99.94667%
#
#   valid loss:		0.00421
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.00494 -- acc=99.97083%
#
#   valid loss:		0.00400
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00553 -- acc=99.95167%
#
#   valid loss:		0.00463
#   valid accuracy:	0.99985+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.00474 -- acc=99.97333%
#
#   valid loss:		0.00398
#   valid accuracy:	0.99995+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/resbind_t9_best.ckpt
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=13.62s -- loss=0.00502 -- acc=99.96167%
#
#   valid loss:		0.00450
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/resbind_t9_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/resbind_t9_best.ckpt
#   test  loss:		0.00406
#   test  accuracy:	0.99993+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

plt.figure()
plt.ylabel('Predicted score')
plt.xlabel('Sequences ordered by score')
plt.plot(range(len(plot_index)), predictionsoutput[plot_index])
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/glna_resbindt9_ug_so1klog.npy'

num_summary = 500
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped_logodds(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias')
# Out:
# 0
# Epoch duration =2.2s
# Cumulative duration =2.2s
#
# 1
# Epoch duration =2.14s
# Cumulative duration =4.34s
#
# 2
# Epoch duration =2.16s
# Cumulative duration =6.5s
#
# 3
# Epoch duration =2.21s
# Cumulative duration =8.72s
#
# 4
# Epoch duration =2.15s
# Cumulative duration =10.87s
#
# 5
# Epoch duration =2.15s
# Cumulative duration =13.01s
#
# 6
# Epoch duration =2.3s
# Cumulative duration =15.32s
#
# 7
# Epoch duration =2.47s
# Cumulative duration =17.79s
#
# 8
# Epoch duration =2.4s
# Cumulative duration =20.19s
#
# 9
# Epoch duration =2.14s
# Cumulative duration =22.33s
#
# 10
# Epoch duration =2.18s
# Cumulative duration =24.51s
#
# 11
# Epoch duration =2.17s
# Cumulative duration =26.68s
#
# 12
# Epoch duration =2.16s
# Cumulative duration =28.84s
#
# 13
# Epoch duration =2.14s
# Cumulative duration =30.98s
#
# 14
# Epoch duration =2.75s
# Cumulative duration =33.74s
#
# 15
# Epoch duration =2.29s
# Cumulative duration =36.02s
#
# 16
# Epoch duration =2.28s
# Cumulative duration =38.3s
#
# 17
# Epoch duration =2.24s
# Cumulative duration =40.55s
#
# 18
# Epoch duration =2.14s
# Cumulative duration =42.69s
#
# 19
# Epoch duration =2.16s
# Cumulative duration =44.85s
#
# 20
# Epoch duration =2.15s
# Cumulative duration =47.0s
#
# 21
# Epoch duration =2.15s
# Cumulative duration =49.16s
#
# 22
# Epoch duration =2.16s
# Cumulative duration =51.31s
#
# 23
# Epoch duration =2.17s
# Cumulative duration =53.48s
#
# 24
# Epoch duration =2.15s
# Cumulative duration =55.62s
#
# 25
# Epoch duration =2.14s
# Cumulative duration =57.77s
#
# 26
# Epoch duration =2.15s
# Cumulative duration =59.92s
#
# 27
# Epoch duration =2.25s
# Cumulative duration =1min 2.1700000000000017s
#
# 28
# Epoch duration =2.34s
# Cumulative duration =1min 4.519999999999996s
#
# 29
# Epoch duration =2.18s
# Cumulative duration =1min 6.700000000000003s
#
# 30
# Epoch duration =2.15s
# Cumulative duration =1min 8.849999999999994s
#
# 31
# Epoch duration =2.15s
# Cumulative duration =1min 11.0s
#
# 32
# Epoch duration =2.23s
# Cumulative duration =1min 13.230000000000004s
#
# 33
# Epoch duration =2.18s
# Cumulative duration =1min 15.409999999999997s
#
# 34
# Epoch duration =2.17s
# Cumulative duration =1min 17.58s
#
# 35
# Epoch duration =2.14s
# Cumulative duration =1min 19.72s
#
# 36
# Epoch duration =2.14s
# Cumulative duration =1min 21.86s
#
# 37
# Epoch duration =2.14s
# Cumulative duration =1min 24.0s
#
# 38
# Epoch duration =2.14s
# Cumulative duration =1min 26.150000000000006s
#
# 39
# Epoch duration =2.14s
# Cumulative duration =1min 28.290000000000006s
#
# 40
# Epoch duration =2.19s
# Cumulative duration =1min 30.480000000000004s
#
# 41
# Epoch duration =2.31s
# Cumulative duration =1min 32.790000000000006s
#
# 42
# Epoch duration =2.26s
# Cumulative duration =1min 35.05s
#
# 43
# Epoch duration =2.26s
# Cumulative duration =1min 37.3s
#
# 44
# Epoch duration =2.29s
# Cumulative duration =1min 39.599999999999994s
#
# 45
# Epoch duration =2.2s
# Cumulative duration =1min 41.8s
#
# 46
# Epoch duration =2.17s
# Cumulative duration =1min 43.97s
#
# 47
# Epoch duration =2.21s
# Cumulative duration =1min 46.18000000000001s
#
# 48
# Epoch duration =2.16s
# Cumulative duration =1min 48.34s
#
# 49
# Epoch duration =2.18s
# Cumulative duration =1min 50.519999999999996s
#
# 50
# Epoch duration =2.18s
# Cumulative duration =1min 52.7s
#
# 51
# Epoch duration =2.25s
# Cumulative duration =1min 54.95s
#
# 52
# Epoch duration =2.25s
# Cumulative duration =1min 57.2s
#
# 53
# Epoch duration =2.25s
# Cumulative duration =1min 59.45s
#
# 54
# Epoch duration =2.48s
# Cumulative duration =2min 1.9300000000000068s
#
# 55
# Epoch duration =2.31s
# Cumulative duration =2min 4.239999999999995s
#
# 56
# Epoch duration =2.22s
# Cumulative duration =2min 6.459999999999994s
#
# 57
# Epoch duration =2.21s
# Cumulative duration =2min 8.669999999999987s
#
# 58
# Epoch duration =2.22s
# Cumulative duration =2min 10.889999999999986s
#
# 59
# Epoch duration =2.21s
# Cumulative duration =2min 13.099999999999994s
#
# 60
# Epoch duration =2.21s
# Cumulative duration =2min 15.310000000000002s
#
# 61
# Epoch duration =2.21s
# Cumulative duration =2min 17.52000000000001s
#
# 62
# Epoch duration =2.24s
# Cumulative duration =2min 19.75999999999999s
#
# 63
# Epoch duration =2.25s
# Cumulative duration =2min 22.00999999999999s
#
# 64
# Epoch duration =2.22s
# Cumulative duration =2min 24.22s
#
# 65
# Epoch duration =2.22s
# Cumulative duration =2min 26.44999999999999s
#
# 66
# Epoch duration =2.16s
# Cumulative duration =2min 28.610000000000014s
#
# 67
# Epoch duration =2.14s
# Cumulative duration =2min 30.75s
#
# 68
# Epoch duration =2.16s
# Cumulative duration =2min 32.91s
#
# 69
# Epoch duration =2.14s
# Cumulative duration =2min 35.05000000000001s
#
# 70
# Epoch duration =2.17s
# Cumulative duration =2min 37.21000000000001s
#
# 71
# Epoch duration =2.15s
# Cumulative duration =2min 39.370000000000005s
#
# 72
# Epoch duration =2.17s
# Cumulative duration =2min 41.53999999999999s
#
# 73
# Epoch duration =2.16s
# Cumulative duration =2min 43.69999999999999s
#
# 74
# Epoch duration =2.15s
# Cumulative duration =2min 45.860000000000014s
#
# 75
# Epoch duration =2.14s
# Cumulative duration =2min 47.99000000000001s
#
# 76
# Epoch duration =2.15s
# Cumulative duration =2min 50.139999999999986s
#
# 77
# Epoch duration =2.15s
# Cumulative duration =2min 52.30000000000001s
#
# 78
# Epoch duration =2.14s
# Cumulative duration =2min 54.43000000000001s
#
# 79
# Epoch duration =2.16s
# Cumulative duration =2min 56.59s
#
# 80
# Epoch duration =2.14s
# Cumulative duration =2min 58.72999999999999s
#
# 81
# Epoch duration =2.16s
# Cumulative duration =3min 0.8899999999999864s
#
# 82
# Epoch duration =2.14s
# Cumulative duration =3min 3.030000000000001s
#
# 83
# Epoch duration =2.14s
# Cumulative duration =3min 5.180000000000007s
#
# 84
# Epoch duration =2.16s
# Cumulative duration =3min 7.340000000000003s
#
# 85
# Epoch duration =2.14s
# Cumulative duration =3min 9.47999999999999s
#
# 86
# Epoch duration =2.16s
# Cumulative duration =3min 11.629999999999995s
#
# 87
# Epoch duration =2.14s
# Cumulative duration =3min 13.77000000000001s
#
# 88
# Epoch duration =2.14s
# Cumulative duration =3min 15.909999999999997s
#
# 89
# Epoch duration =2.14s
# Cumulative duration =3min 18.039999999999992s
#
# 90
# Epoch duration =2.16s
# Cumulative duration =3min 20.210000000000008s
#
# 91
# Epoch duration =2.17s
# Cumulative duration =3min 22.370000000000005s
#
# 92
# Epoch duration =2.14s
# Cumulative duration =3min 24.52000000000001s
#
# 93
# Epoch duration =2.15s
# Cumulative duration =3min 26.669999999999987s
#
# 94
# Epoch duration =2.14s
# Cumulative duration =3min 28.810000000000002s
#
# 95
# Epoch duration =2.14s
# Cumulative duration =3min 30.94999999999999s
#
# 96
# Epoch duration =2.13s
# Cumulative duration =3min 33.08000000000001s
#
# 97
# Epoch duration =2.15s
# Cumulative duration =3min 35.22999999999999s
#
# 98
# Epoch duration =2.14s
# Cumulative duration =3min 37.370000000000005s
#
# 99
# Epoch duration =2.17s
# Cumulative duration =3min 39.53999999999999s
#
# 100
# Epoch duration =2.22s
# Cumulative duration =3min 41.75999999999999s
#
# 101
# Epoch duration =2.13s
# Cumulative duration =3min 43.889999999999986s
#
# 102
# Epoch duration =2.14s
# Cumulative duration =3min 46.03999999999999s
#
# 103
# Epoch duration =2.16s
# Cumulative duration =3min 48.19999999999999s
#
# 104
# Epoch duration =2.15s
# Cumulative duration =3min 50.349999999999994s
#
# 105
# Epoch duration =2.13s
# Cumulative duration =3min 52.47999999999999s
#
# 106
# Epoch duration =2.15s
# Cumulative duration =3min 54.639999999999986s
#
# 107
# Epoch duration =2.14s
# Cumulative duration =3min 56.78s
#
# 108
# Epoch duration =2.13s
# Cumulative duration =3min 58.91s
#
# 109
# Epoch duration =2.15s
# Cumulative duration =4min 1.0600000000000023s
#
# 110
# Epoch duration =2.14s
# Cumulative duration =4min 3.1999999999999886s
#
# 111
# Epoch duration =2.16s
# Cumulative duration =4min 5.360000000000014s
#
# 112
# Epoch duration =2.15s
# Cumulative duration =4min 7.509999999999991s
#
# 113
# Epoch duration =2.14s
# Cumulative duration =4min 9.650000000000006s
#
# 114
# Epoch duration =2.14s
# Cumulative duration =4min 11.789999999999992s
#
# 115
# Epoch duration =2.14s
# Cumulative duration =4min 13.939999999999998s
#
# 116
# Epoch duration =2.15s
# Cumulative duration =4min 16.089999999999975s
#
# 117
# Epoch duration =2.15s
# Cumulative duration =4min 18.24000000000001s
#
# 118
# Epoch duration =2.16s
# Cumulative duration =4min 20.389999999999986s
#
# 119
# Epoch duration =2.15s
# Cumulative duration =4min 22.54000000000002s
#
# 120
# Epoch duration =2.16s
# Cumulative duration =4min 24.69999999999999s
#
# 121
# Epoch duration =2.15s
# Cumulative duration =4min 26.850000000000023s
#
# 122
# Epoch duration =2.15s
# Cumulative duration =4min 28.99000000000001s
#
# 123
# Epoch duration =2.14s
# Cumulative duration =4min 31.129999999999995s
#
# 124
# Epoch duration =2.14s
# Cumulative duration =4min 33.26999999999998s
#
# 125
# Epoch duration =2.14s
# Cumulative duration =4min 35.410000000000025s
#
# 126
# Epoch duration =2.15s
# Cumulative duration =4min 37.56s
#
# 127
# Epoch duration =2.15s
# Cumulative duration =4min 39.69999999999999s
#
# 128
# Epoch duration =2.14s
# Cumulative duration =4min 41.85000000000002s
#
# 129
# Epoch duration =2.15s
# Cumulative duration =4min 43.99000000000001s
#
# 130
# Epoch duration =2.2s
# Cumulative duration =4min 46.19s
#
# 131
# Epoch duration =2.16s
# Cumulative duration =4min 48.35000000000002s
#
# 132
# Epoch duration =2.15s
# Cumulative duration =4min 50.50999999999999s
#
# 133
# Epoch duration =2.15s
# Cumulative duration =4min 52.660000000000025s
#
# 134
# Epoch duration =2.15s
# Cumulative duration =4min 54.80000000000001s
#
# 135
# Epoch duration =2.14s
# Cumulative duration =4min 56.94s
#
# 136
# Epoch duration =2.14s
# Cumulative duration =4min 59.079999999999984s
#
# 137
# Epoch duration =2.15s
# Cumulative duration =5min 1.2300000000000182s
#
# 138
# Epoch duration =2.14s
# Cumulative duration =5min 3.3700000000000045s
#
# 139
# Epoch duration =2.14s
# Cumulative duration =5min 5.509999999999991s
#
# 140
# Epoch duration =2.15s
# Cumulative duration =5min 7.670000000000016s
#
# 141
# Epoch duration =2.15s
# Cumulative duration =5min 9.819999999999993s
#
# 142
# Epoch duration =2.15s
# Cumulative duration =5min 11.970000000000027s
#
# 143
# Epoch duration =2.14s
# Cumulative duration =5min 14.100000000000023s
#
# 144
# Epoch duration =2.15s
# Cumulative duration =5min 16.25s
#
# 145
# Epoch duration =2.14s
# Cumulative duration =5min 18.389999999999986s
#
# 146
# Epoch duration =2.15s
# Cumulative duration =5min 20.54000000000002s
#
# 147
# Epoch duration =2.15s
# Cumulative duration =5min 22.689999999999998s
#
# 148
# Epoch duration =2.15s
# Cumulative duration =5min 24.839999999999975s
#
# 149
# Epoch duration =2.13s
# Cumulative duration =5min 26.95999999999998s
#
# 150
# Epoch duration =2.14s
# Cumulative duration =5min 29.100000000000023s
#
# 151
# Epoch duration =2.14s
# Cumulative duration =5min 31.25s
#
# 152
# Epoch duration =2.14s
# Cumulative duration =5min 33.389999999999986s
#
# 153
# Epoch duration =2.14s
# Cumulative duration =5min 35.52999999999997s
#
# 154
# Epoch duration =2.16s
# Cumulative duration =5min 37.69s
#
# 155
# Epoch duration =2.14s
# Cumulative duration =5min 39.829999999999984s
#
# 156
# Epoch duration =2.14s
# Cumulative duration =5min 41.97000000000003s
#
# 157
# Epoch duration =2.15s
# Cumulative duration =5min 44.129999999999995s
#
# 158
# Epoch duration =2.14s
# Cumulative duration =5min 46.26999999999998s
#
# 159
# Epoch duration =2.16s
# Cumulative duration =5min 48.44s
#
# 160
# Epoch duration =2.14s
# Cumulative duration =5min 50.579999999999984s
#
# 161
# Epoch duration =2.18s
# Cumulative duration =5min 52.75999999999999s
#
# 162
# Epoch duration =2.15s
# Cumulative duration =5min 54.910000000000025s
#
# 163
# Epoch duration =2.16s
# Cumulative duration =5min 57.06s
#
# 164
# Epoch duration =2.14s
# Cumulative duration =5min 59.20999999999998s
#
# 165
# Epoch duration =2.14s
# Cumulative duration =6min 1.3500000000000227s
#
# 166
# Epoch duration =2.14s
# Cumulative duration =6min 3.490000000000009s
#
# 167
# Epoch duration =2.14s
# Cumulative duration =6min 5.6200000000000045s
#
# 168
# Epoch duration =2.15s
# Cumulative duration =6min 7.779999999999973s
#
# 169
# Epoch duration =2.14s
# Cumulative duration =6min 9.920000000000016s
#
# 170
# Epoch duration =2.16s
# Cumulative duration =6min 12.079999999999984s
#
# 171
# Epoch duration =2.16s
# Cumulative duration =6min 14.240000000000009s
#
# 172
# Epoch duration =2.13s
# Cumulative duration =6min 16.370000000000005s
#
# 173
# Epoch duration =2.16s
# Cumulative duration =6min 18.529999999999973s
#
# 174
# Epoch duration =2.14s
# Cumulative duration =6min 20.670000000000016s
#
# 175
# Epoch duration =2.16s
# Cumulative duration =6min 22.829999999999984s
#
# 176
# Epoch duration =2.15s
# Cumulative duration =6min 24.980000000000018s
#
# 177
# Epoch duration =2.17s
# Cumulative duration =6min 27.149999999999977s
#
# 178
# Epoch duration =2.14s
# Cumulative duration =6min 29.29000000000002s
#
# 179
# Epoch duration =2.14s
# Cumulative duration =6min 31.439999999999998s
#
# 180
# Epoch duration =2.13s
# Cumulative duration =6min 33.56999999999999s
#
# 181
# Epoch duration =2.16s
# Cumulative duration =6min 35.73000000000002s
#
# 182
# Epoch duration =2.14s
# Cumulative duration =6min 37.870000000000005s
#
# 183
# Epoch duration =2.13s
# Cumulative duration =6min 40.0s
#
# 184
# Epoch duration =2.14s
# Cumulative duration =6min 42.139999999999986s
#
# 185
# Epoch duration =2.14s
# Cumulative duration =6min 44.27999999999997s
#
# 186
# Epoch duration =2.14s
# Cumulative duration =6min 46.420000000000016s
#
# 187
# Epoch duration =2.15s
# Cumulative duration =6min 48.56999999999999s
#
# 188
# Epoch duration =2.15s
# Cumulative duration =6min 50.72000000000003s
#
# 189
# Epoch duration =2.15s
# Cumulative duration =6min 52.879999999999995s
#
# 190
# Epoch duration =2.15s
# Cumulative duration =6min 55.01999999999998s
#
# 191
# Epoch duration =2.13s
# Cumulative duration =6min 57.14999999999998s
#
# 192
# Epoch duration =2.15s
# Cumulative duration =6min 59.31s
#
# 193
# Epoch duration =2.15s
# Cumulative duration =7min 1.4599999999999795s
#
# 194
# Epoch duration =2.14s
# Cumulative duration =7min 3.6000000000000227s
#
# 195
# Epoch duration =2.13s
# Cumulative duration =7min 5.720000000000027s
#
# 196
# Epoch duration =2.14s
# Cumulative duration =7min 7.8700000000000045s
#
# 197
# Epoch duration =2.14s
# Cumulative duration =7min 10.0s
#
# 198
# Epoch duration =2.14s
# Cumulative duration =7min 12.139999999999986s
#
# 199
# Epoch duration =2.14s
# Cumulative duration =7min 14.279999999999973s
#
# 200
# Epoch duration =2.14s
# Cumulative duration =7min 16.420000000000016s
#
# 201
# Epoch duration =2.28s
# Cumulative duration =7min 18.69999999999999s
#
# 202
# Epoch duration =2.28s
# Cumulative duration =7min 20.980000000000018s
#
# 203
# Epoch duration =2.29s
# Cumulative duration =7min 23.279999999999973s
#
# 204
# Epoch duration =2.5s
# Cumulative duration =7min 25.779999999999973s
#
# 205
# Epoch duration =2.25s
# Cumulative duration =7min 28.029999999999973s
#
# 206
# Epoch duration =2.13s
# Cumulative duration =7min 30.160000000000025s
#
# 207
# Epoch duration =2.13s
# Cumulative duration =7min 32.29000000000002s
#
# 208
# Epoch duration =2.18s
# Cumulative duration =7min 34.47000000000003s
#
# 209
# Epoch duration =2.15s
# Cumulative duration =7min 36.620000000000005s
#
# 210
# Epoch duration =2.14s
# Cumulative duration =7min 38.75999999999999s
#
# 211
# Epoch duration =2.15s
# Cumulative duration =7min 40.89999999999998s
#
# 212
# Epoch duration =2.15s
# Cumulative duration =7min 43.05000000000001s
#
# 213
# Epoch duration =2.18s
# Cumulative duration =7min 45.23000000000002s
#
# 214
# Epoch duration =2.16s
# Cumulative duration =7min 47.389999999999986s
#
# 215
# Epoch duration =2.16s
# Cumulative duration =7min 49.55000000000001s
#
# 216
# Epoch duration =2.15s
# Cumulative duration =7min 51.69999999999999s
#
# 217
# Epoch duration =2.21s
# Cumulative duration =7min 53.910000000000025s
#
# 218
# Epoch duration =2.14s
# Cumulative duration =7min 56.05000000000001s
#
# 219
# Epoch duration =2.14s
# Cumulative duration =7min 58.19s
#
# 220
# Epoch duration =2.13s
# Cumulative duration =8min 0.3199999999999932s
#
# 221
# Epoch duration =2.16s
# Cumulative duration =8min 2.480000000000018s
#
# 222
# Epoch duration =2.14s
# Cumulative duration =8min 4.6200000000000045s
#
# 223
# Epoch duration =2.14s
# Cumulative duration =8min 6.759999999999991s
#
# 224
# Epoch duration =2.16s
# Cumulative duration =8min 8.920000000000016s
#
# 225
# Epoch duration =2.14s
# Cumulative duration =8min 11.060000000000002s
#
# 226
# Epoch duration =2.14s
# Cumulative duration =8min 13.199999999999989s
#
# 227
# Epoch duration =2.16s
# Cumulative duration =8min 15.350000000000023s
#
# 228
# Epoch duration =2.16s
# Cumulative duration =8min 17.50999999999999s
#
# 229
# Epoch duration =2.16s
# Cumulative duration =8min 19.660000000000025s
#
# 230
# Epoch duration =2.18s
# Cumulative duration =8min 21.839999999999975s
#
# 231
# Epoch duration =2.17s
# Cumulative duration =8min 24.00999999999999s
#
# 232
# Epoch duration =2.16s
# Cumulative duration =8min 26.170000000000016s
#
# 233
# Epoch duration =2.16s
# Cumulative duration =8min 28.339999999999975s
#
# 234
# Epoch duration =2.14s
# Cumulative duration =8min 30.480000000000018s
#
# 235
# Epoch duration =2.14s
# Cumulative duration =8min 32.620000000000005s
#
# 236
# Epoch duration =2.15s
# Cumulative duration =8min 34.75999999999999s
#
# 237
# Epoch duration =2.14s
# Cumulative duration =8min 36.90999999999997s
#
# 238
# Epoch duration =2.15s
# Cumulative duration =8min 39.059999999999945s
#
# 239
# Epoch duration =2.15s
# Cumulative duration =8min 41.210000000000036s
#
# 240
# Epoch duration =2.16s
# Cumulative duration =8min 43.370000000000005s
#
# 241
# Epoch duration =2.15s
# Cumulative duration =8min 45.50999999999999s
#
# 242
# Epoch duration =2.15s
# Cumulative duration =8min 47.66999999999996s
#
# 243
# Epoch duration =2.14s
# Cumulative duration =8min 49.799999999999955s
#
# 244
# Epoch duration =2.16s
# Cumulative duration =8min 51.97000000000003s
#
# 245
# Epoch duration =2.15s
# Cumulative duration =8min 54.120000000000005s
#
# 246
# Epoch duration =2.14s
# Cumulative duration =8min 56.26999999999998s
#
# 247
# Epoch duration =2.14s
# Cumulative duration =8min 58.40999999999997s
#
# 248
# Epoch duration =2.14s
# Cumulative duration =9min 0.5499999999999545s
#
# 249
# Epoch duration =2.16s
# Cumulative duration =9min 2.7100000000000364s
#
# 250
# Epoch duration =2.15s
# Cumulative duration =9min 4.8700000000000045s
#
# 251
# Epoch duration =2.14s
# Cumulative duration =9min 7.009999999999991s
#
# 252
# Epoch duration =2.17s
# Cumulative duration =9min 9.169999999999959s
#
# 253
# Epoch duration =2.14s
# Cumulative duration =9min 11.309999999999945s
#
# 254
# Epoch duration =2.14s
# Cumulative duration =9min 13.450000000000045s
#
# 255
# Epoch duration =2.14s
# Cumulative duration =9min 15.590000000000032s
#
# 256
# Epoch duration =2.16s
# Cumulative duration =9min 17.74000000000001s
#
# 257
# Epoch duration =2.15s
# Cumulative duration =9min 19.889999999999986s
#
# 258
# Epoch duration =2.16s
# Cumulative duration =9min 22.049999999999955s
#
# 259
# Epoch duration =2.15s
# Cumulative duration =9min 24.200000000000045s
#
# 260
# Epoch duration =2.13s
# Cumulative duration =9min 26.340000000000032s
#
# 261
# Epoch duration =2.15s
# Cumulative duration =9min 28.480000000000018s
#
# 262
# Epoch duration =2.13s
# Cumulative duration =9min 30.620000000000005s
#
# 263
# Epoch duration =2.13s
# Cumulative duration =9min 32.75s
#
# 264
# Epoch duration =2.14s
# Cumulative duration =9min 34.89999999999998s
#
# 265
# Epoch duration =2.15s
# Cumulative duration =9min 37.049999999999955s
#
# 266
# Epoch duration =2.14s
# Cumulative duration =9min 39.190000000000055s
#
# 267
# Epoch duration =2.13s
# Cumulative duration =9min 41.32000000000005s
#
# 268
# Epoch duration =2.15s
# Cumulative duration =9min 43.47000000000003s
#
# 269
# Epoch duration =2.15s
# Cumulative duration =9min 45.620000000000005s
#
# 270
# Epoch duration =2.14s
# Cumulative duration =9min 47.75999999999999s
#
# 271
# Epoch duration =2.15s
# Cumulative duration =9min 49.90999999999997s
#
# 272
# Epoch duration =2.15s
# Cumulative duration =9min 52.059999999999945s
#
# 273
# Epoch duration =2.14s
# Cumulative duration =9min 54.200000000000045s
#
# 274
# Epoch duration =2.13s
# Cumulative duration =9min 56.33000000000004s
#
# 275
# Epoch duration =2.15s
# Cumulative duration =9min 58.48000000000002s
#
# 276
# Epoch duration =2.15s
# Cumulative duration =10min 0.6299999999999955s
#
# 277
# Epoch duration =2.14s
# Cumulative duration =10min 2.769999999999982s
#
# 278
# Epoch duration =2.15s
# Cumulative duration =10min 4.919999999999959s
#
# 279
# Epoch duration =2.15s
# Cumulative duration =10min 7.080000000000041s
#
# 280
# Epoch duration =2.14s
# Cumulative duration =10min 9.220000000000027s
#
# 281
# Epoch duration =2.14s
# Cumulative duration =10min 11.360000000000014s
#
# 282
# Epoch duration =2.17s
# Cumulative duration =10min 13.529999999999973s
#
# 283
# Epoch duration =2.15s
# Cumulative duration =10min 15.67999999999995s
#
# 284
# Epoch duration =2.16s
# Cumulative duration =10min 17.840000000000032s
#
# 285
# Epoch duration =2.15s
# Cumulative duration =10min 19.99000000000001s
#
# 286
# Epoch duration =2.15s
# Cumulative duration =10min 22.139999999999986s
#
# 287
# Epoch duration =2.15s
# Cumulative duration =10min 24.289999999999964s
#
# 288
# Epoch duration =2.17s
# Cumulative duration =10min 26.470000000000027s
#
# 289
# Epoch duration =2.16s
# Cumulative duration =10min 28.629999999999995s
#
# 290
# Epoch duration =2.14s
# Cumulative duration =10min 30.769999999999982s
#
# 291
# Epoch duration =2.14s
# Cumulative duration =10min 32.90999999999997s
#
# 292
# Epoch duration =2.15s
# Cumulative duration =10min 35.059999999999945s
#
# 293
# Epoch duration =2.16s
# Cumulative duration =10min 37.22000000000003s
#
# 294
# Epoch duration =2.13s
# Cumulative duration =10min 39.35000000000002s
#
# 295
# Epoch duration =2.16s
# Cumulative duration =10min 41.51999999999998s
#
# 296
# Epoch duration =2.15s
# Cumulative duration =10min 43.66999999999996s
#
# 297
# Epoch duration =2.15s
# Cumulative duration =10min 45.82000000000005s
#
# 298
# Epoch duration =2.13s
# Cumulative duration =10min 47.960000000000036s
#
# 299
# Epoch duration =2.14s
# Cumulative duration =10min 50.09000000000003s
#
# 300
# Epoch duration =2.15s
# Cumulative duration =10min 52.24000000000001s
#
# 301
# Epoch duration =2.15s
# Cumulative duration =10min 54.39999999999998s
#
# 302
# Epoch duration =2.15s
# Cumulative duration =10min 56.539999999999964s
#
# 303
# Epoch duration =2.14s
# Cumulative duration =10min 58.690000000000055s
#
# 304
# Epoch duration =2.15s
# Cumulative duration =11min 0.8400000000000318s
#
# 305
# Epoch duration =2.15s
# Cumulative duration =11min 2.990000000000009s
#
# 306
# Epoch duration =2.13s
# Cumulative duration =11min 5.1200000000000045s
#
# 307
# Epoch duration =2.15s
# Cumulative duration =11min 7.269999999999982s
#
# 308
# Epoch duration =2.16s
# Cumulative duration =11min 9.42999999999995s
#
# 309
# Epoch duration =2.14s
# Cumulative duration =11min 11.559999999999945s
#
# 310
# Epoch duration =2.15s
# Cumulative duration =11min 13.710000000000036s
#
# 311
# Epoch duration =2.13s
# Cumulative duration =11min 15.840000000000032s
#
# 312
# Epoch duration =2.14s
# Cumulative duration =11min 17.980000000000018s
#
# 313
# Epoch duration =2.14s
# Cumulative duration =11min 20.129999999999995s
#
# 314
# Epoch duration =2.14s
# Cumulative duration =11min 22.25999999999999s
#
# 315
# Epoch duration =2.15s
# Cumulative duration =11min 24.41999999999996s
#
# 316
# Epoch duration =2.15s
# Cumulative duration =11min 26.57000000000005s
#
# 317
# Epoch duration =2.16s
# Cumulative duration =11min 28.730000000000018s
#
# 318
# Epoch duration =2.16s
# Cumulative duration =11min 30.889999999999986s
#
# 319
# Epoch duration =2.15s
# Cumulative duration =11min 33.039999999999964s
#
# 320
# Epoch duration =2.13s
# Cumulative duration =11min 35.16999999999996s
#
# 321
# Epoch duration =2.14s
# Cumulative duration =11min 37.32000000000005s
#
# 322
# Epoch duration =2.14s
# Cumulative duration =11min 39.450000000000045s
#
# 323
# Epoch duration =2.13s
# Cumulative duration =11min 41.59000000000003s
#
# 324
# Epoch duration =2.16s
# Cumulative duration =11min 43.74000000000001s
#
# 325
# Epoch duration =2.14s
# Cumulative duration =11min 45.889999999999986s
#
# 326
# Epoch duration =2.14s
# Cumulative duration =11min 48.01999999999998s
#
# 327
# Epoch duration =2.16s
# Cumulative duration =11min 50.190000000000055s
#
# 328
# Epoch duration =2.17s
# Cumulative duration =11min 52.35000000000002s
#
# 329
# Epoch duration =2.16s
# Cumulative duration =11min 54.50999999999999s
#
# 330
# Epoch duration =2.16s
# Cumulative duration =11min 56.66999999999996s
#
# 331
# Epoch duration =2.14s
# Cumulative duration =11min 58.799999999999955s
#
# 332
# Epoch duration =2.16s
# Cumulative duration =12min 0.9700000000000273s
#
# 333
# Epoch duration =2.14s
# Cumulative duration =12min 3.1100000000000136s
#
# 334
# Epoch duration =2.13s
# Cumulative duration =12min 5.240000000000009s
#
# 335
# Epoch duration =2.14s
# Cumulative duration =12min 7.389999999999986s
#
# 336
# Epoch duration =2.15s
# Cumulative duration =12min 9.539999999999964s
#
# 337
# Epoch duration =2.18s
# Cumulative duration =12min 11.730000000000018s
#
# 338
# Epoch duration =2.15s
# Cumulative duration =12min 13.879999999999995s
#
# 339
# Epoch duration =2.15s
# Cumulative duration =12min 16.029999999999973s
#
# 340
# Epoch duration =2.17s
# Cumulative duration =12min 18.200000000000045s
#
# 341
# Epoch duration =2.15s
# Cumulative duration =12min 20.350000000000023s
#
# 342
# Epoch duration =2.16s
# Cumulative duration =12min 22.50999999999999s
#
# 343
# Epoch duration =2.14s
# Cumulative duration =12min 24.649999999999977s
#
# 344
# Epoch duration =2.14s
# Cumulative duration =12min 26.789999999999964s
#
# 345
# Epoch duration =2.16s
# Cumulative duration =12min 28.950000000000045s
#
# 346
# Epoch duration =2.14s
# Cumulative duration =12min 31.090000000000032s
#
# 347
# Epoch duration =2.15s
# Cumulative duration =12min 33.24000000000001s
#
# 348
# Epoch duration =2.17s
# Cumulative duration =12min 35.40999999999997s
#
# 349
# Epoch duration =2.19s
# Cumulative duration =12min 37.60000000000002s
#
# 350
# Epoch duration =2.16s
# Cumulative duration =12min 39.75999999999999s
#
# 351
# Epoch duration =2.16s
# Cumulative duration =12min 41.92999999999995s
#
# 352
# Epoch duration =2.15s
# Cumulative duration =12min 44.07000000000005s
#
# 353
# Epoch duration =2.17s
# Cumulative duration =12min 46.24000000000001s
#
# 354
# Epoch duration =2.14s
# Cumulative duration =12min 48.379999999999995s
#
# 355
# Epoch duration =2.14s
# Cumulative duration =12min 50.51999999999998s
#
# 356
# Epoch duration =2.17s
# Cumulative duration =12min 52.700000000000045s
#
# 357
# Epoch duration =2.16s
# Cumulative duration =12min 54.860000000000014s
#
# 358
# Epoch duration =2.14s
# Cumulative duration =12min 57.0s
#
# 359
# Epoch duration =2.17s
# Cumulative duration =12min 59.16999999999996s
#
# 360
# Epoch duration =2.14s
# Cumulative duration =13min 1.3099999999999454s
#
# 361
# Epoch duration =2.15s
# Cumulative duration =13min 3.4600000000000364s
#
# 362
# Epoch duration =2.13s
# Cumulative duration =13min 5.590000000000032s
#
# 363
# Epoch duration =2.15s
# Cumulative duration =13min 7.740000000000009s
#
# 364
# Epoch duration =2.14s
# Cumulative duration =13min 9.879999999999995s
#
# 365
# Epoch duration =2.15s
# Cumulative duration =13min 12.029999999999973s
#
# 366
# Epoch duration =2.14s
# Cumulative duration =13min 14.169999999999959s
#
# 367
# Epoch duration =2.14s
# Cumulative duration =13min 16.309999999999945s
#
# 368
# Epoch duration =2.14s
# Cumulative duration =13min 18.450000000000045s
#
# 369
# Epoch duration =2.15s
# Cumulative duration =13min 20.600000000000023s
#
# 370
# Epoch duration =2.18s
# Cumulative duration =13min 22.779999999999973s
#
# 371
# Epoch duration =2.15s
# Cumulative duration =13min 24.940000000000055s
#
# 372
# Epoch duration =2.14s
# Cumulative duration =13min 27.08000000000004s
#
# 373
# Epoch duration =2.18s
# Cumulative duration =13min 29.25999999999999s
#
# 374
# Epoch duration =2.14s
# Cumulative duration =13min 31.399999999999977s
#
# 375
# Epoch duration =2.17s
# Cumulative duration =13min 33.57000000000005s
#
# 376
# Epoch duration =2.18s
# Cumulative duration =13min 35.74000000000001s
#
# 377
# Epoch duration =2.17s
# Cumulative duration =13min 37.91999999999996s
#
# 378
# Epoch duration =2.15s
# Cumulative duration =13min 40.07000000000005s
#
# 379
# Epoch duration =2.23s
# Cumulative duration =13min 42.299999999999955s
#
# 380
# Epoch duration =2.18s
# Cumulative duration =13min 44.47000000000003s
#
# 381
# Epoch duration =2.17s
# Cumulative duration =13min 46.639999999999986s
#
# 382
# Epoch duration =2.14s
# Cumulative duration =13min 48.77999999999997s
#
# 383
# Epoch duration =2.17s
# Cumulative duration =13min 50.950000000000045s
#
# 384
# Epoch duration =2.17s
# Cumulative duration =13min 53.120000000000005s
#
# 385
# Epoch duration =2.18s
# Cumulative duration =13min 55.299999999999955s
#
# 386
# Epoch duration =2.14s
# Cumulative duration =13min 57.450000000000045s
#
# 387
# Epoch duration =2.14s
# Cumulative duration =13min 59.58000000000004s
#
# 388
# Epoch duration =2.15s
# Cumulative duration =14min 1.7300000000000182s
#
# 389
# Epoch duration =2.15s
# Cumulative duration =14min 3.8799999999999955s
#
# 390
# Epoch duration =2.14s
# Cumulative duration =14min 6.009999999999991s
#
# 391
# Epoch duration =2.14s
# Cumulative duration =14min 8.149999999999977s
#
# 392
# Epoch duration =2.18s
# Cumulative duration =14min 10.340000000000032s
#
# 393
# Epoch duration =2.16s
# Cumulative duration =14min 12.5s
#
# 394
# Epoch duration =2.14s
# Cumulative duration =14min 14.649999999999977s
#
# 395
# Epoch duration =2.14s
# Cumulative duration =14min 16.779999999999973s
#
# 396
# Epoch duration =2.15s
# Cumulative duration =14min 18.92999999999995s
#
# 397
# Epoch duration =2.15s
# Cumulative duration =14min 21.08000000000004s
#
# 398
# Epoch duration =2.15s
# Cumulative duration =14min 23.230000000000018s
#
# 399
# Epoch duration =2.14s
# Cumulative duration =14min 25.370000000000005s
#
# 400
# Epoch duration =2.15s
# Cumulative duration =14min 27.519999999999982s
#
# 401
# Epoch duration =2.15s
# Cumulative duration =14min 29.66999999999996s
#
# 402
# Epoch duration =2.14s
# Cumulative duration =14min 31.82000000000005s
#
# 403
# Epoch duration =2.15s
# Cumulative duration =14min 33.97000000000003s
#
# 404
# Epoch duration =2.18s
# Cumulative duration =14min 36.14999999999998s
#
# 405
# Epoch duration =2.15s
# Cumulative duration =14min 38.299999999999955s
#
# 406
# Epoch duration =2.14s
# Cumulative duration =14min 40.440000000000055s
#
# 407
# Epoch duration =2.15s
# Cumulative duration =14min 42.60000000000002s
#
# 408
# Epoch duration =2.45s
# Cumulative duration =14min 45.039999999999964s
#
# 409
# Epoch duration =2.43s
# Cumulative duration =14min 47.48000000000002s
#
# 410
# Epoch duration =2.18s
# Cumulative duration =14min 49.65999999999997s
#
# 411
# Epoch duration =2.18s
# Cumulative duration =14min 51.84000000000003s
#
# 412
# Epoch duration =2.32s
# Cumulative duration =14min 54.15999999999997s
#
# 413
# Epoch duration =2.16s
# Cumulative duration =14min 56.32000000000005s
#
# 414
# Epoch duration =2.19s
# Cumulative duration =14min 58.5s
#
# 415
# Epoch duration =2.42s
# Cumulative duration =15min 0.9199999999999591s
#
# 416
# Epoch duration =2.38s
# Cumulative duration =15min 3.2999999999999545s
#
# 417
# Epoch duration =2.31s
# Cumulative duration =15min 5.610000000000014s
#
# 418
# Epoch duration =2.27s
# Cumulative duration =15min 7.889999999999986s
#
# 419
# Epoch duration =2.32s
# Cumulative duration =15min 10.210000000000036s
#
# 420
# Epoch duration =2.41s
# Cumulative duration =15min 12.610000000000014s
#
# 421
# Epoch duration =2.17s
# Cumulative duration =15min 14.789999999999964s
#
# 422
# Epoch duration =2.14s
# Cumulative duration =15min 16.92999999999995s
#
# 423
# Epoch duration =2.15s
# Cumulative duration =15min 19.08000000000004s
#
# 424
# Epoch duration =2.19s
# Cumulative duration =15min 21.269999999999982s
#
# 425
# Epoch duration =2.15s
# Cumulative duration =15min 23.409999999999968s
#
# 426
# Epoch duration =2.17s
# Cumulative duration =15min 25.58000000000004s
#
# 427
# Epoch duration =2.14s
# Cumulative duration =15min 27.720000000000027s
#
# 428
# Epoch duration =2.14s
# Cumulative duration =15min 29.860000000000014s
#
# 429
# Epoch duration =2.15s
# Cumulative duration =15min 32.00999999999999s
#
# 430
# Epoch duration =2.15s
# Cumulative duration =15min 34.15999999999997s
#
# 431
# Epoch duration =2.14s
# Cumulative duration =15min 36.299999999999955s
#
# 432
# Epoch duration =2.17s
# Cumulative duration =15min 38.47000000000003s
#
# 433
# Epoch duration =2.15s
# Cumulative duration =15min 40.629999999999995s
#
# 434
# Epoch duration =2.15s
# Cumulative duration =15min 42.77999999999997s
#
# 435
# Epoch duration =2.15s
# Cumulative duration =15min 44.92999999999995s
#
# 436
# Epoch duration =2.18s
# Cumulative duration =15min 47.110000000000014s
#
# 437
# Epoch duration =2.15s
# Cumulative duration =15min 49.25999999999999s
#
# 438
# Epoch duration =2.13s
# Cumulative duration =15min 51.389999999999986s
#
# 439
# Epoch duration =2.14s
# Cumulative duration =15min 53.52999999999997s
#
# 440
# Epoch duration =2.14s
# Cumulative duration =15min 55.66999999999996s
#
# 441
# Epoch duration =2.16s
# Cumulative duration =15min 57.83000000000004s
#
# 442
# Epoch duration =2.13s
# Cumulative duration =15min 59.960000000000036s
#
# 443
# Epoch duration =2.13s
# Cumulative duration =16min 2.090000000000032s
#
# 444
# Epoch duration =2.14s
# Cumulative duration =16min 4.220000000000027s
#
# 445
# Epoch duration =2.15s
# Cumulative duration =16min 6.3700000000000045s
#
# 446
# Epoch duration =2.12s
# Cumulative duration =16min 8.490000000000009s
#
# 447
# Epoch duration =2.18s
# Cumulative duration =16min 10.669999999999959s
#
# 448
# Epoch duration =2.18s
# Cumulative duration =16min 12.850000000000023s
#
# 449
# Epoch duration =2.16s
# Cumulative duration =16min 15.009999999999991s
#
# 450
# Epoch duration =2.14s
# Cumulative duration =16min 17.149999999999977s
#
# 451
# Epoch duration =2.16s
# Cumulative duration =16min 19.309999999999945s
#
# 452
# Epoch duration =2.16s
# Cumulative duration =16min 21.470000000000027s
#
# 453
# Epoch duration =2.15s
# Cumulative duration =16min 23.620000000000005s
#
# 454
# Epoch duration =2.15s
# Cumulative duration =16min 25.75999999999999s
#
# 455
# Epoch duration =2.14s
# Cumulative duration =16min 27.909999999999968s
#
# 456
# Epoch duration =2.14s
# Cumulative duration =16min 30.049999999999955s
#
# 457
# Epoch duration =2.14s
# Cumulative duration =16min 32.190000000000055s
#
# 458
# Epoch duration =2.15s
# Cumulative duration =16min 34.34000000000003s
#
# 459
# Epoch duration =2.14s
# Cumulative duration =16min 36.47000000000003s
#
# 460
# Epoch duration =2.14s
# Cumulative duration =16min 38.620000000000005s
#
# 461
# Epoch duration =2.15s
# Cumulative duration =16min 40.76999999999998s
#
# 462
# Epoch duration =2.15s
# Cumulative duration =16min 42.90999999999997s
#
# 463
# Epoch duration =2.16s
# Cumulative duration =16min 45.07000000000005s
#
# 464
# Epoch duration =2.15s
# Cumulative duration =16min 47.23000000000002s
#
# 465
# Epoch duration =2.15s
# Cumulative duration =16min 49.379999999999995s
#
# 466
# Epoch duration =2.2s
# Cumulative duration =16min 51.58000000000004s
#
# 467
# Epoch duration =2.38s
# Cumulative duration =16min 53.960000000000036s
#
# 468
# Epoch duration =2.59s
# Cumulative duration =16min 56.549999999999955s
#
# 469
# Epoch duration =2.19s
# Cumulative duration =16min 58.74000000000001s
#
# 470
# Epoch duration =2.15s
# Cumulative duration =17min 0.8899999999999864s
#
# 471
# Epoch duration =2.16s
# Cumulative duration =17min 3.0499999999999545s
#
# 472
# Epoch duration =2.16s
# Cumulative duration =17min 5.210000000000036s
#
# 473
# Epoch duration =2.16s
# Cumulative duration =17min 7.380000000000109s
#
# 474
# Epoch duration =2.18s
# Cumulative duration =17min 9.549999999999955s
#
# 475
# Epoch duration =2.15s
# Cumulative duration =17min 11.700000000000045s
#
# 476
# Epoch duration =2.15s
# Cumulative duration =17min 13.849999999999909s
#
# 477
# Epoch duration =2.16s
# Cumulative duration =17min 16.00999999999999s
#
# 478
# Epoch duration =2.15s
# Cumulative duration =17min 18.160000000000082s
#
# 479
# Epoch duration =2.13s
# Cumulative duration =17min 20.289999999999964s
#
# 480
# Epoch duration =2.13s
# Cumulative duration =17min 22.430000000000064s
#
# 481
# Epoch duration =2.15s
# Cumulative duration =17min 24.569999999999936s
#
# 482
# Epoch duration =2.14s
# Cumulative duration =17min 26.710000000000036s
#
# 483
# Epoch duration =2.14s
# Cumulative duration =17min 28.84999999999991s
#
# 484
# Epoch duration =2.17s
# Cumulative duration =17min 31.019999999999982s
#
# 485
# Epoch duration =2.14s
# Cumulative duration =17min 33.16000000000008s
#
# 486
# Epoch duration =2.16s
# Cumulative duration =17min 35.309999999999945s
#
# 487
# Epoch duration =2.16s
# Cumulative duration =17min 37.47000000000003s
#
# 488
# Epoch duration =2.15s
# Cumulative duration =17min 39.61999999999989s
#
# 489
# Epoch duration =2.14s
# Cumulative duration =17min 41.76999999999998s
#
# 490
# Epoch duration =2.16s
# Cumulative duration =17min 43.92000000000007s
#
# 491
# Epoch duration =2.13s
# Cumulative duration =17min 46.059999999999945s
#
# 492
# Epoch duration =2.15s
# Cumulative duration =17min 48.210000000000036s
#
# 493
# Epoch duration =2.14s
# Cumulative duration =17min 50.34999999999991s
#
# 494
# Epoch duration =2.15s
# Cumulative duration =17min 52.5s
#
# 495
# Epoch duration =2.15s
# Cumulative duration =17min 54.65000000000009s
#
# 496
# Epoch duration =2.15s
# Cumulative duration =17min 56.799999999999955s
#
# 497
# Epoch duration =2.16s
# Cumulative duration =17min 58.960000000000036s
#
# 498
# Epoch duration =2.14s
# Cumulative duration =18min 1.0899999999999181s
#
# 499
# Epoch duration =2.13s
# Cumulative duration =18min 3.230000000000018s
#
# ----------------Summing complete----------------
# Saving scores to Arrays/glna_resbindt9_ug_so1klog.npy

# %%
#load values
savepath = 'Arrays/glna_resbindt9_ug_so1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

def normalize_mut_hol(hol_mut, WTmean, nntrainer, sess, normfactor=None):
    norm_hol_mut = np.copy(hol_mut) - WTmean
    for one in range(hol_mut.shape[0]):
        for two in range(hol_mut.shape[0]):
            norm_hol_mut[one, two] = mf.normalize_hol(hol_mut[one, two], factor=normfactor)
    return norm_hol_mut

norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess, normfactor=1)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
#C = C - np.mean(C)
#C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=-0.5, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=-0.5, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
