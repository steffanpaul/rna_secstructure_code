# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/glna_100k_d9.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 10.39s

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<<>>>>>>><<<<>>>>)))))'

# %%
ugSS
# Out:
# '::(((((,<<<<<<<_____>>>>>>>,,,,,,,,<<<<_____>>>>,,,,)))))::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'mlp_t3_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 893, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.26983 -- acc=89.207501%
#
#   valid loss:		0.03575
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t3_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.08437 -- acc=97.510001%
#
#   valid loss:		0.01798
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t3_44_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.55s -- loss=0.05920 -- acc=98.278338%
#
#   valid loss:		0.01182
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t3_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.04909 -- acc=98.611671%
#
#   valid loss:		0.00890
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t3_44_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.04166 -- acc=98.811671%
#
#   valid loss:		0.00802
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t3_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.03962 -- acc=98.904170%
#
#   valid loss:		0.00894
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.54s -- loss=0.03597 -- acc=98.995830%
#
#   valid loss:		0.00958
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.50s -- loss=0.03524 -- acc=99.055006%
#
#   valid loss:		0.00936
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.03384 -- acc=99.090839%
#
#   valid loss:		0.00978
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.03185 -- acc=99.150835%
#
#   valid loss:		0.00984
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.47s -- loss=0.03094 -- acc=99.180008%
#
#   valid loss:		0.00964
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.03082 -- acc=99.168337%
#
#   valid loss:		0.00883
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.03083 -- acc=99.200830%
#
#   valid loss:		0.00947
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.42s -- loss=0.02857 -- acc=99.257506%
#
#   valid loss:		0.01054
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.39s -- loss=0.03011 -- acc=99.240834%
#
#   valid loss:		0.00914
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.38s -- loss=0.02950 -- acc=99.267507%
#
#   valid loss:		0.00998
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.38s -- loss=0.03007 -- acc=99.248335%
#
#   valid loss:		0.00878
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.39s -- loss=0.02838 -- acc=99.313331%
#
#   valid loss:		0.00950
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.38s -- loss=0.02980 -- acc=99.266677%
#
#   valid loss:		0.00998
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.35s -- loss=0.02745 -- acc=99.351675%
#
#   valid loss:		0.01016
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.37s -- loss=0.02951 -- acc=99.291679%
#
#   valid loss:		0.00920
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.37s -- loss=0.02891 -- acc=99.310001%
#
#   valid loss:		0.00967
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.37s -- loss=0.02924 -- acc=99.290839%
#
#   valid loss:		0.01014
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.35s -- loss=0.02849 -- acc=99.318332%
#
#   valid loss:		0.01003
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.36s -- loss=0.02933 -- acc=99.320832%
#
#   valid loss:		0.01024
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.37s -- loss=0.02732 -- acc=99.385009%
#
#   valid loss:		0.00996
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.39s -- loss=0.02865 -- acc=99.350835%
#
#   valid loss:		0.01025
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.35s -- loss=0.03001 -- acc=99.279178%
#
#   valid loss:		0.01085
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.39s -- loss=0.02831 -- acc=99.326673%
#
#   valid loss:		0.00992
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.36s -- loss=0.02871 -- acc=99.355006%
#
#   valid loss:		0.01028
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.37s -- loss=0.02921 -- acc=99.354175%
#
#   valid loss:		0.01043
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.38s -- loss=0.02898 -- acc=99.345835%
#
#   valid loss:		0.01076
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.37s -- loss=0.02924 -- acc=99.370837%
#
#   valid loss:		0.01110
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.42s -- loss=0.02929 -- acc=99.338334%
#
#   valid loss:		0.01185
#   valid accuracy:	0.99895+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.38s -- loss=0.02910 -- acc=99.345835%
#
#   valid loss:		0.01166
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.02880 -- acc=99.387509%
#
#   valid loss:		0.01146
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.41s -- loss=0.02891 -- acc=99.352505%
#
#   valid loss:		0.01090
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.40s -- loss=0.02804 -- acc=99.378338%
#
#   valid loss:		0.01097
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.40s -- loss=0.02855 -- acc=99.374177%
#
#   valid loss:		0.01119
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.41s -- loss=0.02872 -- acc=99.370007%
#
#   valid loss:		0.01095
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.38s -- loss=0.02884 -- acc=99.379178%
#
#   valid loss:		0.01130
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.39s -- loss=0.02874 -- acc=99.355836%
#
#   valid loss:		0.01120
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.42s -- loss=0.02889 -- acc=99.361676%
#
#   valid loss:		0.01104
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.37s -- loss=0.02865 -- acc=99.374177%
#
#   valid loss:		0.01066
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.37s -- loss=0.02775 -- acc=99.406671%
#
#   valid loss:		0.01218
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/mlp_t3_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/mlp_t3_44_best.ckpt
#   test  loss:		0.00699
#   test  accuracy:	0.99972+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/glna_mlpt3_44_ug_so500.npy'

num_summary = 500
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =1.01s
# Cumulative duration =1.01s
#
# 1
# Epoch duration =0.96s
# Cumulative duration =1.98s
#
# 2
# Epoch duration =0.98s
# Cumulative duration =2.96s
#
# 3
# Epoch duration =0.97s
# Cumulative duration =3.92s
#
# 4
# Epoch duration =0.96s
# Cumulative duration =4.89s
#
# 5
# Epoch duration =0.97s
# Cumulative duration =5.86s
#
# 6
# Epoch duration =0.96s
# Cumulative duration =6.82s
#
# 7
# Epoch duration =0.99s
# Cumulative duration =7.81s
#
# 8
# Epoch duration =0.99s
# Cumulative duration =8.8s
#
# 9
# Epoch duration =0.98s
# Cumulative duration =9.77s
#
# 10
# Epoch duration =0.96s
# Cumulative duration =10.73s
#
# 11
# Epoch duration =0.96s
# Cumulative duration =11.69s
#
# 12
# Epoch duration =0.97s
# Cumulative duration =12.66s
#
# 13
# Epoch duration =1.0s
# Cumulative duration =13.66s
#
# 14
# Epoch duration =0.96s
# Cumulative duration =14.62s
#
# 15
# Epoch duration =0.98s
# Cumulative duration =15.61s
#
# 16
# Epoch duration =0.96s
# Cumulative duration =16.56s
#
# 17
# Epoch duration =0.97s
# Cumulative duration =17.53s
#
# 18
# Epoch duration =0.96s
# Cumulative duration =18.49s
#
# 19
# Epoch duration =0.96s
# Cumulative duration =19.45s
#
# 20
# Epoch duration =0.96s
# Cumulative duration =20.41s
#
# 21
# Epoch duration =0.96s
# Cumulative duration =21.37s
#
# 22
# Epoch duration =0.96s
# Cumulative duration =22.33s
#
# 23
# Epoch duration =0.97s
# Cumulative duration =23.3s
#
# 24
# Epoch duration =0.96s
# Cumulative duration =24.26s
#
# 25
# Epoch duration =0.96s
# Cumulative duration =25.22s
#
# 26
# Epoch duration =0.96s
# Cumulative duration =26.18s
#
# 27
# Epoch duration =0.96s
# Cumulative duration =27.14s
#
# 28
# Epoch duration =0.95s
# Cumulative duration =28.1s
#
# 29
# Epoch duration =0.96s
# Cumulative duration =29.06s
#
# 30
# Epoch duration =0.96s
# Cumulative duration =30.02s
#
# 31
# Epoch duration =0.96s
# Cumulative duration =30.98s
#
# 32
# Epoch duration =0.96s
# Cumulative duration =31.95s
#
# 33
# Epoch duration =1.0s
# Cumulative duration =32.94s
#
# 34
# Epoch duration =0.97s
# Cumulative duration =33.92s
#
# 35
# Epoch duration =0.97s
# Cumulative duration =34.89s
#
# 36
# Epoch duration =1.0s
# Cumulative duration =35.89s
#
# 37
# Epoch duration =0.96s
# Cumulative duration =36.85s
#
# 38
# Epoch duration =0.96s
# Cumulative duration =37.81s
#
# 39
# Epoch duration =0.99s
# Cumulative duration =38.8s
#
# 40
# Epoch duration =0.97s
# Cumulative duration =39.77s
#
# 41
# Epoch duration =0.96s
# Cumulative duration =40.74s
#
# 42
# Epoch duration =1.01s
# Cumulative duration =41.74s
#
# 43
# Epoch duration =0.96s
# Cumulative duration =42.7s
#
# 44
# Epoch duration =0.97s
# Cumulative duration =43.67s
#
# 45
# Epoch duration =0.97s
# Cumulative duration =44.64s
#
# 46
# Epoch duration =0.98s
# Cumulative duration =45.62s
#
# 47
# Epoch duration =0.96s
# Cumulative duration =46.58s
#
# 48
# Epoch duration =0.96s
# Cumulative duration =47.55s
#
# 49
# Epoch duration =0.96s
# Cumulative duration =48.51s
#
# 50
# Epoch duration =0.99s
# Cumulative duration =49.5s
#
# 51
# Epoch duration =0.96s
# Cumulative duration =50.46s
#
# 52
# Epoch duration =0.96s
# Cumulative duration =51.42s
#
# 53
# Epoch duration =0.96s
# Cumulative duration =52.39s
#
# 54
# Epoch duration =0.96s
# Cumulative duration =53.34s
#
# 55
# Epoch duration =0.96s
# Cumulative duration =54.3s
#
# 56
# Epoch duration =0.97s
# Cumulative duration =55.27s
#
# 57
# Epoch duration =0.96s
# Cumulative duration =56.23s
#
# 58
# Epoch duration =0.96s
# Cumulative duration =57.18s
#
# 59
# Epoch duration =0.97s
# Cumulative duration =58.16s
#
# 60
# Epoch duration =1.0s
# Cumulative duration =59.16s
#
# 61
# Epoch duration =0.98s
# Cumulative duration =1min 0.13000000000000256s
#
# 62
# Epoch duration =0.98s
# Cumulative duration =1min 1.1099999999999994s
#
# 63
# Epoch duration =0.98s
# Cumulative duration =1min 2.0900000000000034s
#
# 64
# Epoch duration =0.99s
# Cumulative duration =1min 3.0799999999999983s
#
# 65
# Epoch duration =0.98s
# Cumulative duration =1min 4.060000000000002s
#
# 66
# Epoch duration =0.96s
# Cumulative duration =1min 5.019999999999996s
#
# 67
# Epoch duration =0.96s
# Cumulative duration =1min 5.980000000000004s
#
# 68
# Epoch duration =0.95s
# Cumulative duration =1min 6.930000000000007s
#
# 69
# Epoch duration =0.97s
# Cumulative duration =1min 7.900000000000006s
#
# 70
# Epoch duration =0.96s
# Cumulative duration =1min 8.86s
#
# 71
# Epoch duration =0.96s
# Cumulative duration =1min 9.829999999999998s
#
# 72
# Epoch duration =0.96s
# Cumulative duration =1min 10.790000000000006s
#
# 73
# Epoch duration =0.96s
# Cumulative duration =1min 11.75s
#
# 74
# Epoch duration =0.97s
# Cumulative duration =1min 12.719999999999999s
#
# 75
# Epoch duration =0.95s
# Cumulative duration =1min 13.670000000000002s
#
# 76
# Epoch duration =0.96s
# Cumulative duration =1min 14.620000000000005s
#
# 77
# Epoch duration =0.96s
# Cumulative duration =1min 15.579999999999998s
#
# 78
# Epoch duration =0.97s
# Cumulative duration =1min 16.549999999999997s
#
# 79
# Epoch duration =0.98s
# Cumulative duration =1min 17.519999999999996s
#
# 80
# Epoch duration =1.06s
# Cumulative duration =1min 18.58s
#
# 81
# Epoch duration =1.16s
# Cumulative duration =1min 19.739999999999995s
#
# 82
# Epoch duration =1.0s
# Cumulative duration =1min 20.739999999999995s
#
# 83
# Epoch duration =1.07s
# Cumulative duration =1min 21.810000000000002s
#
# 84
# Epoch duration =1.08s
# Cumulative duration =1min 22.89s
#
# 85
# Epoch duration =0.98s
# Cumulative duration =1min 23.870000000000005s
#
# 86
# Epoch duration =1.05s
# Cumulative duration =1min 24.92s
#
# 87
# Epoch duration =1.23s
# Cumulative duration =1min 26.150000000000006s
#
# 88
# Epoch duration =1.19s
# Cumulative duration =1min 27.340000000000003s
#
# 89
# Epoch duration =1.08s
# Cumulative duration =1min 28.42s
#
# 90
# Epoch duration =1.01s
# Cumulative duration =1min 29.439999999999998s
#
# 91
# Epoch duration =1.01s
# Cumulative duration =1min 30.439999999999998s
#
# 92
# Epoch duration =0.98s
# Cumulative duration =1min 31.42s
#
# 93
# Epoch duration =1.15s
# Cumulative duration =1min 32.56999999999999s
#
# 94
# Epoch duration =1.0s
# Cumulative duration =1min 33.56999999999999s
#
# 95
# Epoch duration =1.14s
# Cumulative duration =1min 34.7s
#
# 96
# Epoch duration =1.22s
# Cumulative duration =1min 35.92s
#
# 97
# Epoch duration =1.02s
# Cumulative duration =1min 36.94s
#
# 98
# Epoch duration =1.16s
# Cumulative duration =1min 38.099999999999994s
#
# 99
# Epoch duration =1.05s
# Cumulative duration =1min 39.16s
#
# 100
# Epoch duration =1.0s
# Cumulative duration =1min 40.150000000000006s
#
# 101
# Epoch duration =0.96s
# Cumulative duration =1min 41.11s
#
# 102
# Epoch duration =0.96s
# Cumulative duration =1min 42.06999999999999s
#
# 103
# Epoch duration =1.0s
# Cumulative duration =1min 43.06s
#
# 104
# Epoch duration =0.97s
# Cumulative duration =1min 44.040000000000006s
#
# 105
# Epoch duration =0.96s
# Cumulative duration =1min 45.0s
#
# 106
# Epoch duration =0.96s
# Cumulative duration =1min 45.959999999999994s
#
# 107
# Epoch duration =1.0s
# Cumulative duration =1min 46.959999999999994s
#
# 108
# Epoch duration =0.99s
# Cumulative duration =1min 47.94s
#
# 109
# Epoch duration =0.96s
# Cumulative duration =1min 48.91s
#
# 110
# Epoch duration =1.05s
# Cumulative duration =1min 49.959999999999994s
#
# 111
# Epoch duration =1.14s
# Cumulative duration =1min 51.099999999999994s
#
# 112
# Epoch duration =1.24s
# Cumulative duration =1min 52.34s
#
# 113
# Epoch duration =1.02s
# Cumulative duration =1min 53.36s
#
# 114
# Epoch duration =0.97s
# Cumulative duration =1min 54.33s
#
# 115
# Epoch duration =0.96s
# Cumulative duration =1min 55.3s
#
# 116
# Epoch duration =1.1s
# Cumulative duration =1min 56.39s
#
# 117
# Epoch duration =1.22s
# Cumulative duration =1min 57.61s
#
# 118
# Epoch duration =1.08s
# Cumulative duration =1min 58.69s
#
# 119
# Epoch duration =1.05s
# Cumulative duration =1min 59.739999999999995s
#
# 120
# Epoch duration =0.99s
# Cumulative duration =2min 0.7399999999999949s
#
# 121
# Epoch duration =1.08s
# Cumulative duration =2min 1.8100000000000023s
#
# 122
# Epoch duration =0.97s
# Cumulative duration =2min 2.780000000000001s
#
# 123
# Epoch duration =0.97s
# Cumulative duration =2min 3.75s
#
# 124
# Epoch duration =0.97s
# Cumulative duration =2min 4.719999999999999s
#
# 125
# Epoch duration =0.97s
# Cumulative duration =2min 5.689999999999998s
#
# 126
# Epoch duration =0.99s
# Cumulative duration =2min 6.680000000000007s
#
# 127
# Epoch duration =0.98s
# Cumulative duration =2min 7.659999999999997s
#
# 128
# Epoch duration =0.97s
# Cumulative duration =2min 8.620000000000005s
#
# 129
# Epoch duration =0.97s
# Cumulative duration =2min 9.590000000000003s
#
# 130
# Epoch duration =0.97s
# Cumulative duration =2min 10.560000000000002s
#
# 131
# Epoch duration =0.96s
# Cumulative duration =2min 11.52000000000001s
#
# 132
# Epoch duration =0.97s
# Cumulative duration =2min 12.490000000000009s
#
# 133
# Epoch duration =0.99s
# Cumulative duration =2min 13.47999999999999s
#
# 134
# Epoch duration =0.96s
# Cumulative duration =2min 14.439999999999998s
#
# 135
# Epoch duration =0.98s
# Cumulative duration =2min 15.419999999999987s
#
# 136
# Epoch duration =0.97s
# Cumulative duration =2min 16.400000000000006s
#
# 137
# Epoch duration =0.98s
# Cumulative duration =2min 17.379999999999995s
#
# 138
# Epoch duration =0.96s
# Cumulative duration =2min 18.340000000000003s
#
# 139
# Epoch duration =0.97s
# Cumulative duration =2min 19.310000000000002s
#
# 140
# Epoch duration =0.98s
# Cumulative duration =2min 20.289999999999992s
#
# 141
# Epoch duration =0.97s
# Cumulative duration =2min 21.25999999999999s
#
# 142
# Epoch duration =0.98s
# Cumulative duration =2min 22.25s
#
# 143
# Epoch duration =0.96s
# Cumulative duration =2min 23.210000000000008s
#
# 144
# Epoch duration =0.96s
# Cumulative duration =2min 24.169999999999987s
#
# 145
# Epoch duration =0.98s
# Cumulative duration =2min 25.150000000000006s
#
# 146
# Epoch duration =0.96s
# Cumulative duration =2min 26.099999999999994s
#
# 147
# Epoch duration =0.96s
# Cumulative duration =2min 27.060000000000002s
#
# 148
# Epoch duration =0.96s
# Cumulative duration =2min 28.02000000000001s
#
# 149
# Epoch duration =0.97s
# Cumulative duration =2min 28.97999999999999s
#
# 150
# Epoch duration =0.98s
# Cumulative duration =2min 29.97s
#
# 151
# Epoch duration =0.97s
# Cumulative duration =2min 30.939999999999998s
#
# 152
# Epoch duration =0.96s
# Cumulative duration =2min 31.900000000000006s
#
# 153
# Epoch duration =0.97s
# Cumulative duration =2min 32.870000000000005s
#
# 154
# Epoch duration =0.99s
# Cumulative duration =2min 33.860000000000014s
#
# 155
# Epoch duration =0.96s
# Cumulative duration =2min 34.81999999999999s
#
# 156
# Epoch duration =0.96s
# Cumulative duration =2min 35.78s
#
# 157
# Epoch duration =0.96s
# Cumulative duration =2min 36.74000000000001s
#
# 158
# Epoch duration =0.98s
# Cumulative duration =2min 37.72s
#
# 159
# Epoch duration =0.96s
# Cumulative duration =2min 38.68000000000001s
#
# 160
# Epoch duration =0.95s
# Cumulative duration =2min 39.639999999999986s
#
# 161
# Epoch duration =0.97s
# Cumulative duration =2min 40.610000000000014s
#
# 162
# Epoch duration =0.97s
# Cumulative duration =2min 41.56999999999999s
#
# 163
# Epoch duration =0.96s
# Cumulative duration =2min 42.53s
#
# 164
# Epoch duration =0.96s
# Cumulative duration =2min 43.49000000000001s
#
# 165
# Epoch duration =0.97s
# Cumulative duration =2min 44.47s
#
# 166
# Epoch duration =0.97s
# Cumulative duration =2min 45.44s
#
# 167
# Epoch duration =0.98s
# Cumulative duration =2min 46.41999999999999s
#
# 168
# Epoch duration =0.97s
# Cumulative duration =2min 47.389999999999986s
#
# 169
# Epoch duration =0.97s
# Cumulative duration =2min 48.360000000000014s
#
# 170
# Epoch duration =0.97s
# Cumulative duration =2min 49.33000000000001s
#
# 171
# Epoch duration =0.99s
# Cumulative duration =2min 50.31s
#
# 172
# Epoch duration =0.97s
# Cumulative duration =2min 51.28999999999999s
#
# 173
# Epoch duration =0.96s
# Cumulative duration =2min 52.25s
#
# 174
# Epoch duration =0.98s
# Cumulative duration =2min 53.22999999999999s
#
# 175
# Epoch duration =0.95s
# Cumulative duration =2min 54.18000000000001s
#
# 176
# Epoch duration =0.97s
# Cumulative duration =2min 55.139999999999986s
#
# 177
# Epoch duration =0.96s
# Cumulative duration =2min 56.110000000000014s
#
# 178
# Epoch duration =0.95s
# Cumulative duration =2min 57.06s
#
# 179
# Epoch duration =0.96s
# Cumulative duration =2min 58.02000000000001s
#
# 180
# Epoch duration =0.97s
# Cumulative duration =2min 58.99000000000001s
#
# 181
# Epoch duration =0.96s
# Cumulative duration =2min 59.96000000000001s
#
# 182
# Epoch duration =0.96s
# Cumulative duration =3min 0.9199999999999875s
#
# 183
# Epoch duration =0.96s
# Cumulative duration =3min 1.8799999999999955s
#
# 184
# Epoch duration =0.95s
# Cumulative duration =3min 2.8400000000000034s
#
# 185
# Epoch duration =0.95s
# Cumulative duration =3min 3.789999999999992s
#
# 186
# Epoch duration =0.96s
# Cumulative duration =3min 4.75s
#
# 187
# Epoch duration =0.96s
# Cumulative duration =3min 5.710000000000008s
#
# 188
# Epoch duration =0.97s
# Cumulative duration =3min 6.680000000000007s
#
# 189
# Epoch duration =0.97s
# Cumulative duration =3min 7.650000000000006s
#
# 190
# Epoch duration =0.98s
# Cumulative duration =3min 8.629999999999995s
#
# 191
# Epoch duration =0.98s
# Cumulative duration =3min 9.610000000000014s
#
# 192
# Epoch duration =0.97s
# Cumulative duration =3min 10.580000000000013s
#
# 193
# Epoch duration =0.99s
# Cumulative duration =3min 11.569999999999993s
#
# 194
# Epoch duration =0.97s
# Cumulative duration =3min 12.539999999999992s
#
# 195
# Epoch duration =0.96s
# Cumulative duration =3min 13.5s
#
# 196
# Epoch duration =0.96s
# Cumulative duration =3min 14.460000000000008s
#
# 197
# Epoch duration =1.01s
# Cumulative duration =3min 15.469999999999999s
#
# 198
# Epoch duration =0.96s
# Cumulative duration =3min 16.439999999999998s
#
# 199
# Epoch duration =0.97s
# Cumulative duration =3min 17.409999999999997s
#
# 200
# Epoch duration =0.98s
# Cumulative duration =3min 18.389999999999986s
#
# 201
# Epoch duration =0.98s
# Cumulative duration =3min 19.360000000000014s
#
# 202
# Epoch duration =0.98s
# Cumulative duration =3min 20.340000000000003s
#
# 203
# Epoch duration =0.97s
# Cumulative duration =3min 21.310000000000002s
#
# 204
# Epoch duration =0.97s
# Cumulative duration =3min 22.28s
#
# 205
# Epoch duration =0.96s
# Cumulative duration =3min 23.22999999999999s
#
# 206
# Epoch duration =0.96s
# Cumulative duration =3min 24.189999999999998s
#
# 207
# Epoch duration =0.96s
# Cumulative duration =3min 25.150000000000006s
#
# 208
# Epoch duration =0.97s
# Cumulative duration =3min 26.120000000000005s
#
# 209
# Epoch duration =0.99s
# Cumulative duration =3min 27.110000000000014s
#
# 210
# Epoch duration =0.95s
# Cumulative duration =3min 28.060000000000002s
#
# 211
# Epoch duration =0.96s
# Cumulative duration =3min 29.02000000000001s
#
# 212
# Epoch duration =0.96s
# Cumulative duration =3min 29.97999999999999s
#
# 213
# Epoch duration =0.96s
# Cumulative duration =3min 30.939999999999998s
#
# 214
# Epoch duration =0.97s
# Cumulative duration =3min 31.909999999999997s
#
# 215
# Epoch duration =0.97s
# Cumulative duration =3min 32.879999999999995s
#
# 216
# Epoch duration =1.0s
# Cumulative duration =3min 33.879999999999995s
#
# 217
# Epoch duration =0.97s
# Cumulative duration =3min 34.860000000000014s
#
# 218
# Epoch duration =0.96s
# Cumulative duration =3min 35.81999999999999s
#
# 219
# Epoch duration =0.97s
# Cumulative duration =3min 36.78s
#
# 220
# Epoch duration =0.96s
# Cumulative duration =3min 37.74000000000001s
#
# 221
# Epoch duration =0.95s
# Cumulative duration =3min 38.69s
#
# 222
# Epoch duration =0.96s
# Cumulative duration =3min 39.650000000000006s
#
# 223
# Epoch duration =0.96s
# Cumulative duration =3min 40.610000000000014s
#
# 224
# Epoch duration =0.99s
# Cumulative duration =3min 41.599999999999994s
#
# 225
# Epoch duration =0.99s
# Cumulative duration =3min 42.59s
#
# 226
# Epoch duration =0.98s
# Cumulative duration =3min 43.56s
#
# 227
# Epoch duration =0.96s
# Cumulative duration =3min 44.53s
#
# 228
# Epoch duration =0.97s
# Cumulative duration =3min 45.5s
#
# 229
# Epoch duration =0.99s
# Cumulative duration =3min 46.49000000000001s
#
# 230
# Epoch duration =0.97s
# Cumulative duration =3min 47.46000000000001s
#
# 231
# Epoch duration =0.96s
# Cumulative duration =3min 48.41s
#
# 232
# Epoch duration =0.98s
# Cumulative duration =3min 49.400000000000006s
#
# 233
# Epoch duration =0.97s
# Cumulative duration =3min 50.360000000000014s
#
# 234
# Epoch duration =1.01s
# Cumulative duration =3min 51.379999999999995s
#
# 235
# Epoch duration =0.99s
# Cumulative duration =3min 52.360000000000014s
#
# 236
# Epoch duration =0.97s
# Cumulative duration =3min 53.33000000000001s
#
# 237
# Epoch duration =0.98s
# Cumulative duration =3min 54.31s
#
# 238
# Epoch duration =0.98s
# Cumulative duration =3min 55.28999999999999s
#
# 239
# Epoch duration =0.95s
# Cumulative duration =3min 56.24000000000001s
#
# 240
# Epoch duration =1.05s
# Cumulative duration =3min 57.30000000000001s
#
# 241
# Epoch duration =0.96s
# Cumulative duration =3min 58.25999999999999s
#
# 242
# Epoch duration =0.96s
# Cumulative duration =3min 59.22s
#
# 243
# Epoch duration =0.98s
# Cumulative duration =4min 0.19999999999998863s
#
# 244
# Epoch duration =0.99s
# Cumulative duration =4min 1.1899999999999977s
#
# 245
# Epoch duration =0.99s
# Cumulative duration =4min 2.1699999999999875s
#
# 246
# Epoch duration =0.97s
# Cumulative duration =4min 3.1500000000000057s
#
# 247
# Epoch duration =0.96s
# Cumulative duration =4min 4.110000000000014s
#
# 248
# Epoch duration =0.97s
# Cumulative duration =4min 5.090000000000003s
#
# 249
# Epoch duration =0.96s
# Cumulative duration =4min 6.050000000000011s
#
# 250
# Epoch duration =0.97s
# Cumulative duration =4min 7.02000000000001s
#
# 251
# Epoch duration =0.97s
# Cumulative duration =4min 7.990000000000009s
#
# 252
# Epoch duration =0.96s
# Cumulative duration =4min 8.949999999999989s
#
# 253
# Epoch duration =0.97s
# Cumulative duration =4min 9.919999999999987s
#
# 254
# Epoch duration =0.97s
# Cumulative duration =4min 10.889999999999986s
#
# 255
# Epoch duration =0.96s
# Cumulative duration =4min 11.849999999999994s
#
# 256
# Epoch duration =0.97s
# Cumulative duration =4min 12.810000000000002s
#
# 257
# Epoch duration =0.97s
# Cumulative duration =4min 13.780000000000001s
#
# 258
# Epoch duration =0.98s
# Cumulative duration =4min 14.759999999999991s
#
# 259
# Epoch duration =0.98s
# Cumulative duration =4min 15.75s
#
# 260
# Epoch duration =0.97s
# Cumulative duration =4min 16.720000000000027s
#
# 261
# Epoch duration =0.95s
# Cumulative duration =4min 17.680000000000007s
#
# 262
# Epoch duration =0.97s
# Cumulative duration =4min 18.649999999999977s
#
# 263
# Epoch duration =0.99s
# Cumulative duration =4min 19.639999999999986s
#
# 264
# Epoch duration =1.01s
# Cumulative duration =4min 20.649999999999977s
#
# 265
# Epoch duration =0.99s
# Cumulative duration =4min 21.639999999999986s
#
# 266
# Epoch duration =0.97s
# Cumulative duration =4min 22.610000000000014s
#
# 267
# Epoch duration =0.97s
# Cumulative duration =4min 23.589999999999975s
#
# 268
# Epoch duration =0.96s
# Cumulative duration =4min 24.54000000000002s
#
# 269
# Epoch duration =0.96s
# Cumulative duration =4min 25.5s
#
# 270
# Epoch duration =0.96s
# Cumulative duration =4min 26.45999999999998s
#
# 271
# Epoch duration =0.96s
# Cumulative duration =4min 27.420000000000016s
#
# 272
# Epoch duration =0.96s
# Cumulative duration =4min 28.379999999999995s
#
# 273
# Epoch duration =0.96s
# Cumulative duration =4min 29.339999999999975s
#
# 274
# Epoch duration =0.98s
# Cumulative duration =4min 30.329999999999984s
#
# 275
# Epoch duration =1.0s
# Cumulative duration =4min 31.319999999999993s
#
# 276
# Epoch duration =0.96s
# Cumulative duration =4min 32.29000000000002s
#
# 277
# Epoch duration =0.96s
# Cumulative duration =4min 33.25s
#
# 278
# Epoch duration =0.97s
# Cumulative duration =4min 34.22000000000003s
#
# 279
# Epoch duration =0.97s
# Cumulative duration =4min 35.19s
#
# 280
# Epoch duration =0.97s
# Cumulative duration =4min 36.160000000000025s
#
# 281
# Epoch duration =0.97s
# Cumulative duration =4min 37.129999999999995s
#
# 282
# Epoch duration =0.99s
# Cumulative duration =4min 38.120000000000005s
#
# 283
# Epoch duration =0.98s
# Cumulative duration =4min 39.10000000000002s
#
# 284
# Epoch duration =0.98s
# Cumulative duration =4min 40.079999999999984s
#
# 285
# Epoch duration =0.97s
# Cumulative duration =4min 41.05000000000001s
#
# 286
# Epoch duration =0.96s
# Cumulative duration =4min 42.00999999999999s
#
# 287
# Epoch duration =0.95s
# Cumulative duration =4min 42.95999999999998s
#
# 288
# Epoch duration =0.97s
# Cumulative duration =4min 43.93000000000001s
#
# 289
# Epoch duration =0.96s
# Cumulative duration =4min 44.889999999999986s
#
# 290
# Epoch duration =0.97s
# Cumulative duration =4min 45.860000000000014s
#
# 291
# Epoch duration =0.97s
# Cumulative duration =4min 46.829999999999984s
#
# 292
# Epoch duration =0.96s
# Cumulative duration =4min 47.79000000000002s
#
# 293
# Epoch duration =0.97s
# Cumulative duration =4min 48.75s
#
# 294
# Epoch duration =0.95s
# Cumulative duration =4min 49.70999999999998s
#
# 295
# Epoch duration =0.95s
# Cumulative duration =4min 50.64999999999998s
#
# 296
# Epoch duration =0.96s
# Cumulative duration =4min 51.620000000000005s
#
# 297
# Epoch duration =0.97s
# Cumulative duration =4min 52.589999999999975s
#
# 298
# Epoch duration =0.96s
# Cumulative duration =4min 53.55000000000001s
#
# 299
# Epoch duration =0.96s
# Cumulative duration =4min 54.50999999999999s
#
# 300
# Epoch duration =0.96s
# Cumulative duration =4min 55.47000000000003s
#
# 301
# Epoch duration =0.97s
# Cumulative duration =4min 56.44s
#
# 302
# Epoch duration =0.98s
# Cumulative duration =4min 57.420000000000016s
#
# 303
# Epoch duration =1.01s
# Cumulative duration =4min 58.44s
#
# 304
# Epoch duration =0.98s
# Cumulative duration =4min 59.410000000000025s
#
# 305
# Epoch duration =0.99s
# Cumulative duration =5min 0.39999999999997726s
#
# 306
# Epoch duration =0.98s
# Cumulative duration =5min 1.3799999999999955s
#
# 307
# Epoch duration =0.98s
# Cumulative duration =5min 2.3600000000000136s
#
# 308
# Epoch duration =0.96s
# Cumulative duration =5min 3.319999999999993s
#
# 309
# Epoch duration =0.97s
# Cumulative duration =5min 4.2900000000000205s
#
# 310
# Epoch duration =1.04s
# Cumulative duration =5min 5.339999999999975s
#
# 311
# Epoch duration =0.97s
# Cumulative duration =5min 6.310000000000002s
#
# 312
# Epoch duration =0.95s
# Cumulative duration =5min 7.259999999999991s
#
# 313
# Epoch duration =0.96s
# Cumulative duration =5min 8.220000000000027s
#
# 314
# Epoch duration =0.96s
# Cumulative duration =5min 9.180000000000007s
#
# 315
# Epoch duration =0.98s
# Cumulative duration =5min 10.149999999999977s
#
# 316
# Epoch duration =0.97s
# Cumulative duration =5min 11.120000000000005s
#
# 317
# Epoch duration =0.97s
# Cumulative duration =5min 12.089999999999975s
#
# 318
# Epoch duration =0.97s
# Cumulative duration =5min 13.060000000000002s
#
# 319
# Epoch duration =0.97s
# Cumulative duration =5min 14.029999999999973s
#
# 320
# Epoch duration =0.95s
# Cumulative duration =5min 14.990000000000009s
#
# 321
# Epoch duration =0.96s
# Cumulative duration =5min 15.949999999999989s
#
# 322
# Epoch duration =0.97s
# Cumulative duration =5min 16.920000000000016s
#
# 323
# Epoch duration =0.95s
# Cumulative duration =5min 17.870000000000005s
#
# 324
# Epoch duration =0.99s
# Cumulative duration =5min 18.860000000000014s
#
# 325
# Epoch duration =0.97s
# Cumulative duration =5min 19.829999999999984s
#
# 326
# Epoch duration =0.95s
# Cumulative duration =5min 20.79000000000002s
#
# 327
# Epoch duration =0.95s
# Cumulative duration =5min 21.74000000000001s
#
# 328
# Epoch duration =0.99s
# Cumulative duration =5min 22.730000000000018s
#
# 329
# Epoch duration =0.97s
# Cumulative duration =5min 23.70999999999998s
#
# 330
# Epoch duration =0.96s
# Cumulative duration =5min 24.670000000000016s
#
# 331
# Epoch duration =0.96s
# Cumulative duration =5min 25.620000000000005s
#
# 332
# Epoch duration =0.99s
# Cumulative duration =5min 26.610000000000014s
#
# 333
# Epoch duration =0.97s
# Cumulative duration =5min 27.579999999999984s
#
# 334
# Epoch duration =0.98s
# Cumulative duration =5min 28.560000000000002s
#
# 335
# Epoch duration =0.96s
# Cumulative duration =5min 29.529999999999973s
#
# 336
# Epoch duration =0.96s
# Cumulative duration =5min 30.480000000000018s
#
# 337
# Epoch duration =0.96s
# Cumulative duration =5min 31.44999999999999s
#
# 338
# Epoch duration =0.98s
# Cumulative duration =5min 32.420000000000016s
#
# 339
# Epoch duration =0.96s
# Cumulative duration =5min 33.389999999999986s
#
# 340
# Epoch duration =0.96s
# Cumulative duration =5min 34.35000000000002s
#
# 341
# Epoch duration =0.96s
# Cumulative duration =5min 35.31s
#
# 342
# Epoch duration =0.97s
# Cumulative duration =5min 36.29000000000002s
#
# 343
# Epoch duration =0.97s
# Cumulative duration =5min 37.25999999999999s
#
# 344
# Epoch duration =0.97s
# Cumulative duration =5min 38.23000000000002s
#
# 345
# Epoch duration =0.98s
# Cumulative duration =5min 39.20999999999998s
#
# 346
# Epoch duration =0.98s
# Cumulative duration =5min 40.19s
#
# 347
# Epoch duration =0.98s
# Cumulative duration =5min 41.170000000000016s
#
# 348
# Epoch duration =0.95s
# Cumulative duration =5min 42.120000000000005s
#
# 349
# Epoch duration =1.0s
# Cumulative duration =5min 43.120000000000005s
#
# 350
# Epoch duration =0.97s
# Cumulative duration =5min 44.079999999999984s
#
# 351
# Epoch duration =0.99s
# Cumulative duration =5min 45.06999999999999s
#
# 352
# Epoch duration =0.98s
# Cumulative duration =5min 46.05000000000001s
#
# 353
# Epoch duration =0.97s
# Cumulative duration =5min 47.01999999999998s
#
# 354
# Epoch duration =0.98s
# Cumulative duration =5min 48.0s
#
# 355
# Epoch duration =0.96s
# Cumulative duration =5min 48.95999999999998s
#
# 356
# Epoch duration =0.98s
# Cumulative duration =5min 49.94s
#
# 357
# Epoch duration =0.99s
# Cumulative duration =5min 50.93000000000001s
#
# 358
# Epoch duration =0.99s
# Cumulative duration =5min 51.920000000000016s
#
# 359
# Epoch duration =0.97s
# Cumulative duration =5min 52.889999999999986s
#
# 360
# Epoch duration =0.96s
# Cumulative duration =5min 53.85000000000002s
#
# 361
# Epoch duration =0.98s
# Cumulative duration =5min 54.839999999999975s
#
# 362
# Epoch duration =1.0s
# Cumulative duration =5min 55.839999999999975s
#
# 363
# Epoch duration =0.98s
# Cumulative duration =5min 56.829999999999984s
#
# 364
# Epoch duration =0.95s
# Cumulative duration =5min 57.77999999999997s
#
# 365
# Epoch duration =0.96s
# Cumulative duration =5min 58.74000000000001s
#
# 366
# Epoch duration =0.97s
# Cumulative duration =5min 59.70999999999998s
#
# 367
# Epoch duration =1.01s
# Cumulative duration =6min 0.7099999999999795s
#
# 368
# Epoch duration =0.97s
# Cumulative duration =6min 1.6899999999999977s
#
# 369
# Epoch duration =0.97s
# Cumulative duration =6min 2.6499999999999773s
#
# 370
# Epoch duration =0.99s
# Cumulative duration =6min 3.6499999999999773s
#
# 371
# Epoch duration =0.98s
# Cumulative duration =6min 4.6299999999999955s
#
# 372
# Epoch duration =0.95s
# Cumulative duration =6min 5.579999999999984s
#
# 373
# Epoch duration =0.97s
# Cumulative duration =6min 6.550000000000011s
#
# 374
# Epoch duration =0.97s
# Cumulative duration =6min 7.509999999999991s
#
# 375
# Epoch duration =0.98s
# Cumulative duration =6min 8.490000000000009s
#
# 376
# Epoch duration =0.98s
# Cumulative duration =6min 9.470000000000027s
#
# 377
# Epoch duration =0.97s
# Cumulative duration =6min 10.449999999999989s
#
# 378
# Epoch duration =0.99s
# Cumulative duration =6min 11.439999999999998s
#
# 379
# Epoch duration =0.97s
# Cumulative duration =6min 12.410000000000025s
#
# 380
# Epoch duration =0.97s
# Cumulative duration =6min 13.379999999999995s
#
# 381
# Epoch duration =0.96s
# Cumulative duration =6min 14.339999999999975s
#
# 382
# Epoch duration =0.96s
# Cumulative duration =6min 15.300000000000011s
#
# 383
# Epoch duration =0.97s
# Cumulative duration =6min 16.269999999999982s
#
# 384
# Epoch duration =0.97s
# Cumulative duration =6min 17.24000000000001s
#
# 385
# Epoch duration =0.96s
# Cumulative duration =6min 18.19999999999999s
#
# 386
# Epoch duration =0.96s
# Cumulative duration =6min 19.170000000000016s
#
# 387
# Epoch duration =0.96s
# Cumulative duration =6min 20.129999999999995s
#
# 388
# Epoch duration =0.96s
# Cumulative duration =6min 21.089999999999975s
#
# 389
# Epoch duration =0.96s
# Cumulative duration =6min 22.05000000000001s
#
# 390
# Epoch duration =0.97s
# Cumulative duration =6min 23.00999999999999s
#
# 391
# Epoch duration =0.97s
# Cumulative duration =6min 23.980000000000018s
#
# 392
# Epoch duration =0.97s
# Cumulative duration =6min 24.94999999999999s
#
# 393
# Epoch duration =0.96s
# Cumulative duration =6min 25.910000000000025s
#
# 394
# Epoch duration =0.98s
# Cumulative duration =6min 26.889999999999986s
#
# 395
# Epoch duration =0.96s
# Cumulative duration =6min 27.850000000000023s
#
# 396
# Epoch duration =0.97s
# Cumulative duration =6min 28.819999999999993s
#
# 397
# Epoch duration =0.98s
# Cumulative duration =6min 29.79000000000002s
#
# 398
# Epoch duration =1.01s
# Cumulative duration =6min 30.810000000000002s
#
# 399
# Epoch duration =1.02s
# Cumulative duration =6min 31.829999999999984s
#
# 400
# Epoch duration =0.97s
# Cumulative duration =6min 32.80000000000001s
#
# 401
# Epoch duration =0.98s
# Cumulative duration =6min 33.77999999999997s
#
# 402
# Epoch duration =1.0s
# Cumulative duration =6min 34.77999999999997s
#
# 403
# Epoch duration =0.96s
# Cumulative duration =6min 35.74000000000001s
#
# 404
# Epoch duration =0.96s
# Cumulative duration =6min 36.69999999999999s
#
# 405
# Epoch duration =1.05s
# Cumulative duration =6min 37.75s
#
# 406
# Epoch duration =0.98s
# Cumulative duration =6min 38.73000000000002s
#
# 407
# Epoch duration =0.97s
# Cumulative duration =6min 39.70999999999998s
#
# 408
# Epoch duration =0.97s
# Cumulative duration =6min 40.670000000000016s
#
# 409
# Epoch duration =0.98s
# Cumulative duration =6min 41.64999999999998s
#
# 410
# Epoch duration =0.97s
# Cumulative duration =6min 42.620000000000005s
#
# 411
# Epoch duration =0.96s
# Cumulative duration =6min 43.579999999999984s
#
# 412
# Epoch duration =0.96s
# Cumulative duration =6min 44.54000000000002s
#
# 413
# Epoch duration =0.97s
# Cumulative duration =6min 45.50999999999999s
#
# 414
# Epoch duration =0.95s
# Cumulative duration =6min 46.45999999999998s
#
# 415
# Epoch duration =0.97s
# Cumulative duration =6min 47.43000000000001s
#
# 416
# Epoch duration =1.0s
# Cumulative duration =6min 48.43000000000001s
#
# 417
# Epoch duration =1.01s
# Cumulative duration =6min 49.44s
#
# 418
# Epoch duration =0.96s
# Cumulative duration =6min 50.39999999999998s
#
# 419
# Epoch duration =0.96s
# Cumulative duration =6min 51.360000000000014s
#
# 420
# Epoch duration =0.97s
# Cumulative duration =6min 52.339999999999975s
#
# 421
# Epoch duration =0.99s
# Cumulative duration =6min 53.329999999999984s
#
# 422
# Epoch duration =1.02s
# Cumulative duration =6min 54.35000000000002s
#
# 423
# Epoch duration =0.99s
# Cumulative duration =6min 55.329999999999984s
#
# 424
# Epoch duration =0.98s
# Cumulative duration =6min 56.31s
#
# 425
# Epoch duration =0.98s
# Cumulative duration =6min 57.29000000000002s
#
# 426
# Epoch duration =0.97s
# Cumulative duration =6min 58.25999999999999s
#
# 427
# Epoch duration =0.99s
# Cumulative duration =6min 59.25s
#
# 428
# Epoch duration =0.97s
# Cumulative duration =7min 0.22000000000002728s
#
# 429
# Epoch duration =0.96s
# Cumulative duration =7min 1.1800000000000068s
#
# 430
# Epoch duration =0.96s
# Cumulative duration =7min 2.1399999999999864s
#
# 431
# Epoch duration =0.99s
# Cumulative duration =7min 3.1299999999999955s
#
# 432
# Epoch duration =0.95s
# Cumulative duration =7min 4.079999999999984s
#
# 433
# Epoch duration =0.97s
# Cumulative duration =7min 5.050000000000011s
#
# 434
# Epoch duration =0.97s
# Cumulative duration =7min 6.019999999999982s
#
# 435
# Epoch duration =0.97s
# Cumulative duration =7min 6.990000000000009s
#
# 436
# Epoch duration =0.97s
# Cumulative duration =7min 7.970000000000027s
#
# 437
# Epoch duration =1.03s
# Cumulative duration =7min 9.0s
#
# 438
# Epoch duration =0.97s
# Cumulative duration =7min 9.970000000000027s
#
# 439
# Epoch duration =0.96s
# Cumulative duration =7min 10.930000000000007s
#
# 440
# Epoch duration =0.95s
# Cumulative duration =7min 11.889999999999986s
#
# 441
# Epoch duration =1.0s
# Cumulative duration =7min 12.889999999999986s
#
# 442
# Epoch duration =1.0s
# Cumulative duration =7min 13.889999999999986s
#
# 443
# Epoch duration =0.97s
# Cumulative duration =7min 14.860000000000014s
#
# 444
# Epoch duration =0.97s
# Cumulative duration =7min 15.829999999999984s
#
# 445
# Epoch duration =0.96s
# Cumulative duration =7min 16.79000000000002s
#
# 446
# Epoch duration =0.97s
# Cumulative duration =7min 17.75999999999999s
#
# 447
# Epoch duration =0.95s
# Cumulative duration =7min 18.70999999999998s
#
# 448
# Epoch duration =0.98s
# Cumulative duration =7min 19.689999999999998s
#
# 449
# Epoch duration =0.98s
# Cumulative duration =7min 20.670000000000016s
#
# 450
# Epoch duration =0.98s
# Cumulative duration =7min 21.639999999999986s
#
# 451
# Epoch duration =0.97s
# Cumulative duration =7min 22.610000000000014s
#
# 452
# Epoch duration =0.98s
# Cumulative duration =7min 23.600000000000023s
#
# 453
# Epoch duration =0.97s
# Cumulative duration =7min 24.569999999999993s
#
# 454
# Epoch duration =0.96s
# Cumulative duration =7min 25.519999999999982s
#
# 455
# Epoch duration =0.95s
# Cumulative duration =7min 26.480000000000018s
#
# 456
# Epoch duration =0.97s
# Cumulative duration =7min 27.439999999999998s
#
# 457
# Epoch duration =1.03s
# Cumulative duration =7min 28.480000000000018s
#
# 458
# Epoch duration =0.98s
# Cumulative duration =7min 29.45999999999998s
#
# 459
# Epoch duration =0.99s
# Cumulative duration =7min 30.44999999999999s
#
# 460
# Epoch duration =0.98s
# Cumulative duration =7min 31.430000000000007s
#
# 461
# Epoch duration =0.99s
# Cumulative duration =7min 32.420000000000016s
#
# 462
# Epoch duration =0.98s
# Cumulative duration =7min 33.39999999999998s
#
# 463
# Epoch duration =0.97s
# Cumulative duration =7min 34.360000000000014s
#
# 464
# Epoch duration =0.97s
# Cumulative duration =7min 35.329999999999984s
#
# 465
# Epoch duration =0.96s
# Cumulative duration =7min 36.29000000000002s
#
# 466
# Epoch duration =0.96s
# Cumulative duration =7min 37.25s
#
# 467
# Epoch duration =0.96s
# Cumulative duration =7min 38.20999999999998s
#
# 468
# Epoch duration =0.98s
# Cumulative duration =7min 39.19s
#
# 469
# Epoch duration =0.96s
# Cumulative duration =7min 40.14999999999998s
#
# 470
# Epoch duration =0.96s
# Cumulative duration =7min 41.110000000000014s
#
# 471
# Epoch duration =0.96s
# Cumulative duration =7min 42.06999999999999s
#
# 472
# Epoch duration =0.96s
# Cumulative duration =7min 43.04000000000002s
#
# 473
# Epoch duration =0.97s
# Cumulative duration =7min 44.0s
#
# 474
# Epoch duration =1.02s
# Cumulative duration =7min 45.01999999999998s
#
# 475
# Epoch duration =0.97s
# Cumulative duration =7min 45.99000000000001s
#
# 476
# Epoch duration =0.97s
# Cumulative duration =7min 46.95999999999998s
#
# 477
# Epoch duration =0.98s
# Cumulative duration =7min 47.94s
#
# 478
# Epoch duration =0.97s
# Cumulative duration =7min 48.910000000000025s
#
# 479
# Epoch duration =0.97s
# Cumulative duration =7min 49.879999999999995s
#
# 480
# Epoch duration =0.97s
# Cumulative duration =7min 50.860000000000014s
#
# 481
# Epoch duration =0.99s
# Cumulative duration =7min 51.839999999999975s
#
# 482
# Epoch duration =0.96s
# Cumulative duration =7min 52.80000000000001s
#
# 483
# Epoch duration =0.95s
# Cumulative duration =7min 53.75999999999999s
#
# 484
# Epoch duration =0.96s
# Cumulative duration =7min 54.70999999999998s
#
# 485
# Epoch duration =1.0s
# Cumulative duration =7min 55.70999999999998s
#
# 486
# Epoch duration =0.96s
# Cumulative duration =7min 56.670000000000016s
#
# 487
# Epoch duration =0.99s
# Cumulative duration =7min 57.660000000000025s
#
# 488
# Epoch duration =0.99s
# Cumulative duration =7min 58.660000000000025s
#
# 489
# Epoch duration =0.98s
# Cumulative duration =7min 59.639999999999986s
#
# 490
# Epoch duration =0.96s
# Cumulative duration =8min 0.6000000000000227s
#
# 491
# Epoch duration =0.98s
# Cumulative duration =8min 1.579999999999984s
#
# 492
# Epoch duration =0.97s
# Cumulative duration =8min 2.5500000000000114s
#
# 493
# Epoch duration =0.95s
# Cumulative duration =8min 3.509999999999991s
#
# 494
# Epoch duration =0.97s
# Cumulative duration =8min 4.470000000000027s
#
# 495
# Epoch duration =0.99s
# Cumulative duration =8min 5.4599999999999795s
#
# 496
# Epoch duration =0.97s
# Cumulative duration =8min 6.430000000000007s
#
# 497
# Epoch duration =0.97s
# Cumulative duration =8min 7.399999999999977s
#
# 498
# Epoch duration =0.98s
# Cumulative duration =8min 8.379999999999995s
#
# 499
# Epoch duration =0.99s
# Cumulative duration =8min 9.370000000000005s
#
# Saving scores to Arrays/glna_mlpt3_44_ug_so500.npy

# %%
#load values
savepath = 'Arrays/glna_mlpt3_44_ug_so500.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 500
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
#C = C - np.mean(C)
#C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=None, cmap='Blues', linewidth=0.00)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=None, cmap='Blues', linewidth=0.0)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
