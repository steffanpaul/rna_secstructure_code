# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/glna_100k_d8.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 10.81s

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<<>>>>>>><<<<>>>>)))))'

# %%
ugSS
# Out:
# '::(((((,<<<<<<<_____>>>>>>>,,,,,,,,<<<<_____>>>>,,,,)))))::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'mlp_t2_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 893, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.25015 -- acc=89.950005%
#
#   valid loss:		0.04019
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.08435 -- acc=97.489179%
#
#   valid loss:		0.05122
#   valid accuracy:	0.98575+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.06119 -- acc=98.260006%
#
#   valid loss:		0.01362
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.05443 -- acc=98.512501%
#
#   valid loss:		0.01887
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.81s -- loss=0.04590 -- acc=98.792509%
#
#   valid loss:		0.01170
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.04448 -- acc=98.839174%
#
#   valid loss:		0.01268
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.04368 -- acc=98.925003%
#
#   valid loss:		0.01204
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.55s -- loss=0.04140 -- acc=98.999170%
#
#   valid loss:		0.01226
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.56s -- loss=0.03861 -- acc=99.080008%
#
#   valid loss:		0.01144
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.03732 -- acc=99.105831%
#
#   valid loss:		0.01223
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.03643 -- acc=99.136674%
#
#   valid loss:		0.01100
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.03674 -- acc=99.190839%
#
#   valid loss:		0.01096
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.03726 -- acc=99.153335%
#
#   valid loss:		0.01248
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.03469 -- acc=99.253335%
#
#   valid loss:		0.01441
#   valid accuracy:	0.99870+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.03703 -- acc=99.115832%
#
#   valid loss:		0.01486
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.03514 -- acc=99.232503%
#
#   valid loss:		0.01345
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.03478 -- acc=99.205001%
#
#   valid loss:		0.01310
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.03418 -- acc=99.260836%
#
#   valid loss:		0.01219
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.03388 -- acc=99.278338%
#
#   valid loss:		0.01580
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.03525 -- acc=99.240834%
#
#   valid loss:		0.01835
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03399 -- acc=99.305831%
#
#   valid loss:		0.01530
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03441 -- acc=99.261676%
#
#   valid loss:		0.01483
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03312 -- acc=99.320002%
#
#   valid loss:		0.01504
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03324 -- acc=99.305001%
#
#   valid loss:		0.01443
#   valid accuracy:	0.99895+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.85s -- loss=0.03314 -- acc=99.310831%
#
#   valid loss:		0.01293
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.03331 -- acc=99.320002%
#
#   valid loss:		0.01269
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.03301 -- acc=99.303330%
#
#   valid loss:		0.01347
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=4.08s -- loss=0.03415 -- acc=99.278338%
#
#   valid loss:		0.01297
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.03315 -- acc=99.341674%
#
#   valid loss:		0.01323
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.03273 -- acc=99.322502%
#
#   valid loss:		0.01259
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.03218 -- acc=99.330833%
#
#   valid loss:		0.01287
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.03303 -- acc=99.315832%
#
#   valid loss:		0.01350
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.03293 -- acc=99.326673%
#
#   valid loss:		0.01499
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.03354 -- acc=99.319172%
#
#   valid loss:		0.01264
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.03260 -- acc=99.343334%
#
#   valid loss:		0.01353
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.03251 -- acc=99.335834%
#
#   valid loss:		0.01418
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.03216 -- acc=99.367507%
#
#   valid loss:		0.01313
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.03339 -- acc=99.313331%
#
#   valid loss:		0.01739
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.03215 -- acc=99.395000%
#
#   valid loss:		0.01268
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03354 -- acc=99.322502%
#
#   valid loss:		0.01296
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.03262 -- acc=99.374177%
#
#   valid loss:		0.01309
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.03145 -- acc=99.389179%
#
#   valid loss:		0.01301
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.03314 -- acc=99.337504%
#
#   valid loss:		0.01335
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.03355 -- acc=99.309171%
#
#   valid loss:		0.01274
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.03314 -- acc=99.328333%
#
#   valid loss:		0.01487
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.03282 -- acc=99.338334%
#
#   valid loss:		0.01343
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.03280 -- acc=99.339174%
#
#   valid loss:		0.01340
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.03168 -- acc=99.390839%
#
#   valid loss:		0.01284
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.03132 -- acc=99.385839%
#
#   valid loss:		0.01248
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.03027 -- acc=99.403330%
#
#   valid loss:		0.01268
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=3.84s -- loss=0.03194 -- acc=99.392509%
#
#   valid loss:		0.01613
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=3.89s -- loss=0.03226 -- acc=99.375008%
#
#   valid loss:		0.01415
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/mlp_t2_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/mlp_t2_44_best.ckpt
#   test  loss:		0.01025
#   test  accuracy:	0.99970+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/glna_mlpt2_44_ug_so20.npy'

num_summary = 20
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='off', save=False, layer='dense_1_bias', 
                               normalize=False, normfactor=0)

# %%
savepath = 'Arrays/glna_mlpt2_44_ug_so20.npy'

num_summary = 500
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=False, layer='output', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =1.0s
# Cumulative duration =1.0s
#
# 1
# Epoch duration =0.98s
# Cumulative duration =1.99s
#
# 2
# Epoch duration =0.98s
# Cumulative duration =2.97s
#
# 3
# Epoch duration =0.98s
# Cumulative duration =3.95s
#
# 4
# Epoch duration =0.97s
# Cumulative duration =4.92s
#
# 5
# Epoch duration =0.97s
# Cumulative duration =5.89s
#
# 6
# Epoch duration =1.15s
# Cumulative duration =7.04s
#
# 7
# Epoch duration =0.96s
# Cumulative duration =7.99s
#
# 8
# Epoch duration =1.1s
# Cumulative duration =9.1s
#
# 9
# Epoch duration =0.98s
# Cumulative duration =10.08s
#
# 10
# Epoch duration =0.97s
# Cumulative duration =11.04s
#
# 11
# Epoch duration =0.97s
# Cumulative duration =12.01s
#
# 12
# Epoch duration =0.97s
# Cumulative duration =12.98s
#
# 13
# Epoch duration =0.96s
# Cumulative duration =13.94s
#
# 14
# Epoch duration =1.01s
# Cumulative duration =14.95s
#
# 15
# Epoch duration =0.98s
# Cumulative duration =15.93s
#
# 16
# Epoch duration =0.98s
# Cumulative duration =16.91s
#
# 17
# Epoch duration =0.97s
# Cumulative duration =17.88s
#
# 18
# Epoch duration =0.97s
# Cumulative duration =18.86s
#
# 19
# Epoch duration =0.98s
# Cumulative duration =19.83s
#
# 20
# Epoch duration =0.97s
# Cumulative duration =20.8s
#
# 21
# Epoch duration =0.97s
# Cumulative duration =21.77s
#
# 22
# Epoch duration =0.97s
# Cumulative duration =22.75s
#
# 23
# Epoch duration =0.98s
# Cumulative duration =23.73s
#
# 24
# Epoch duration =0.97s
# Cumulative duration =24.7s
#
# 25
# Epoch duration =0.96s
# Cumulative duration =25.66s
#
# 26
# Epoch duration =0.97s
# Cumulative duration =26.63s
#
# 27
# Epoch duration =0.97s
# Cumulative duration =27.6s
#
# 28
# Epoch duration =0.97s
# Cumulative duration =28.57s
#
# 29
# Epoch duration =0.98s
# Cumulative duration =29.55s
#
# 30
# Epoch duration =0.96s
# Cumulative duration =30.51s
#
# 31
# Epoch duration =0.99s
# Cumulative duration =31.5s
#
# 32
# Epoch duration =0.96s
# Cumulative duration =32.46s
#
# 33
# Epoch duration =0.97s
# Cumulative duration =33.43s
#
# 34
# Epoch duration =0.98s
# Cumulative duration =34.41s
#
# 35
# Epoch duration =0.96s
# Cumulative duration =35.37s
#
# 36
# Epoch duration =0.96s
# Cumulative duration =36.33s
#
# 37
# Epoch duration =0.97s
# Cumulative duration =37.3s
#
# 38
# Epoch duration =0.97s
# Cumulative duration =38.27s
#
# 39
# Epoch duration =0.97s
# Cumulative duration =39.24s
#
# 40
# Epoch duration =0.97s
# Cumulative duration =40.21s
#
# 41
# Epoch duration =0.96s
# Cumulative duration =41.17s
#
# 42
# Epoch duration =0.98s
# Cumulative duration =42.15s
#
# 43
# Epoch duration =0.96s
# Cumulative duration =43.11s
#
# 44
# Epoch duration =0.97s
# Cumulative duration =44.08s
#
# 45
# Epoch duration =0.97s
# Cumulative duration =45.05s
#
# 46
# Epoch duration =0.98s
# Cumulative duration =46.03s
#
# 47
# Epoch duration =0.97s
# Cumulative duration =47.0s
#
# 48
# Epoch duration =0.97s
# Cumulative duration =47.97s
#
# 49
# Epoch duration =0.96s
# Cumulative duration =48.92s
#
# 50
# Epoch duration =1.0s
# Cumulative duration =49.93s
#
# 51
# Epoch duration =0.98s
# Cumulative duration =50.9s
#
# 52
# Epoch duration =0.97s
# Cumulative duration =51.88s
#
# 53
# Epoch duration =0.98s
# Cumulative duration =52.85s
#
# 54
# Epoch duration =0.97s
# Cumulative duration =53.83s
#
# 55
# Epoch duration =0.96s
# Cumulative duration =54.79s
#
# 56
# Epoch duration =0.98s
# Cumulative duration =55.76s
#
# 57
# Epoch duration =0.98s
# Cumulative duration =56.74s
#
# 58
# Epoch duration =0.97s
# Cumulative duration =57.72s
#
# 59
# Epoch duration =0.97s
# Cumulative duration =58.69s
#
# 60
# Epoch duration =0.97s
# Cumulative duration =59.65s
#
# 61
# Epoch duration =0.96s
# Cumulative duration =1min 0.6099999999999994s
#
# 62
# Epoch duration =0.97s
# Cumulative duration =1min 1.5799999999999983s
#
# 63
# Epoch duration =0.97s
# Cumulative duration =1min 2.539999999999999s
#
# 64
# Epoch duration =0.97s
# Cumulative duration =1min 3.509999999999998s
#
# 65
# Epoch duration =0.97s
# Cumulative duration =1min 4.480000000000004s
#
# 66
# Epoch duration =1.06s
# Cumulative duration =1min 5.540000000000006s
#
# 67
# Epoch duration =0.96s
# Cumulative duration =1min 6.510000000000005s
#
# 68
# Epoch duration =0.98s
# Cumulative duration =1min 7.489999999999995s
#
# 69
# Epoch duration =0.97s
# Cumulative duration =1min 8.459999999999994s
#
# 70
# Epoch duration =0.97s
# Cumulative duration =1min 9.439999999999998s
#
# 71
# Epoch duration =0.98s
# Cumulative duration =1min 10.420000000000002s
#
# 72
# Epoch duration =0.97s
# Cumulative duration =1min 11.379999999999995s
#
# 73
# Epoch duration =0.97s
# Cumulative duration =1min 12.349999999999994s
#
# 74
# Epoch duration =0.98s
# Cumulative duration =1min 13.329999999999998s
#
# 75
# Epoch duration =0.97s
# Cumulative duration =1min 14.299999999999997s
#
# 76
# Epoch duration =0.96s
# Cumulative duration =1min 15.260000000000005s
#
# 77
# Epoch duration =0.97s
# Cumulative duration =1min 16.239999999999995s
#
# 78
# Epoch duration =0.97s
# Cumulative duration =1min 17.209999999999994s
#
# 79
# Epoch duration =0.98s
# Cumulative duration =1min 18.189999999999998s
#
# 80
# Epoch duration =0.96s
# Cumulative duration =1min 19.150000000000006s
#
# 81
# Epoch duration =0.97s
# Cumulative duration =1min 20.120000000000005s
#
# 82
# Epoch duration =0.98s
# Cumulative duration =1min 21.099999999999994s
#
# 83
# Epoch duration =0.97s
# Cumulative duration =1min 22.069999999999993s
#
# 84
# Epoch duration =0.98s
# Cumulative duration =1min 23.049999999999997s
#
# 85
# Epoch duration =0.96s
# Cumulative duration =1min 24.010000000000005s
#
# 86
# Epoch duration =0.97s
# Cumulative duration =1min 24.97s
#
# 87
# Epoch duration =0.98s
# Cumulative duration =1min 25.959999999999994s
#
# 88
# Epoch duration =0.97s
# Cumulative duration =1min 26.92s
#
# 89
# Epoch duration =0.97s
# Cumulative duration =1min 27.89s
#
# 90
# Epoch duration =0.96s
# Cumulative duration =1min 28.849999999999994s
#
# 91
# Epoch duration =0.96s
# Cumulative duration =1min 29.810000000000002s
#
# 92
# Epoch duration =0.96s
# Cumulative duration =1min 30.769999999999996s
#
# 93
# Epoch duration =0.97s
# Cumulative duration =1min 31.739999999999995s
#
# 94
# Epoch duration =0.98s
# Cumulative duration =1min 32.72s
#
# 95
# Epoch duration =0.97s
# Cumulative duration =1min 33.69s
#
# 96
# Epoch duration =0.96s
# Cumulative duration =1min 34.650000000000006s
#
# 97
# Epoch duration =0.98s
# Cumulative duration =1min 35.629999999999995s
#
# 98
# Epoch duration =0.97s
# Cumulative duration =1min 36.61s
#
# 99
# Epoch duration =0.96s
# Cumulative duration =1min 37.56s
#
# 100
# Epoch duration =0.97s
# Cumulative duration =1min 38.53s
#
# 101
# Epoch duration =0.97s
# Cumulative duration =1min 39.5s
#
# 102
# Epoch duration =0.97s
# Cumulative duration =1min 40.47s
#
# 103
# Epoch duration =0.99s
# Cumulative duration =1min 41.47s
#
# 104
# Epoch duration =0.96s
# Cumulative duration =1min 42.43000000000001s
#
# 105
# Epoch duration =0.97s
# Cumulative duration =1min 43.400000000000006s
#
# 106
# Epoch duration =0.99s
# Cumulative duration =1min 44.39s
#
# 107
# Epoch duration =0.96s
# Cumulative duration =1min 45.349999999999994s
#
# 108
# Epoch duration =0.98s
# Cumulative duration =1min 46.33s
#
# 109
# Epoch duration =0.98s
# Cumulative duration =1min 47.31999999999999s
#
# 110
# Epoch duration =0.96s
# Cumulative duration =1min 48.28s
#
# 111
# Epoch duration =0.97s
# Cumulative duration =1min 49.25s
#
# 112
# Epoch duration =0.97s
# Cumulative duration =1min 50.209999999999994s
#
# 113
# Epoch duration =1.01s
# Cumulative duration =1min 51.22s
#
# 114
# Epoch duration =0.97s
# Cumulative duration =1min 52.19s
#
# 115
# Epoch duration =0.97s
# Cumulative duration =1min 53.16s
#
# 116
# Epoch duration =0.96s
# Cumulative duration =1min 54.120000000000005s
#
# 117
# Epoch duration =0.97s
# Cumulative duration =1min 55.09s
#
# 118
# Epoch duration =0.98s
# Cumulative duration =1min 56.06999999999999s
#
# 119
# Epoch duration =0.96s
# Cumulative duration =1min 57.03s
#
# 120
# Epoch duration =0.97s
# Cumulative duration =1min 58.0s
#
# 121
# Epoch duration =0.96s
# Cumulative duration =1min 58.959999999999994s
#
# 122
# Epoch duration =0.97s
# Cumulative duration =1min 59.93000000000001s
#
# 123
# Epoch duration =0.98s
# Cumulative duration =2min 0.9000000000000057s
#
# 124
# Epoch duration =0.96s
# Cumulative duration =2min 1.8599999999999994s
#
# 125
# Epoch duration =0.96s
# Cumulative duration =2min 2.8299999999999983s
#
# 126
# Epoch duration =0.97s
# Cumulative duration =2min 3.799999999999997s
#
# 127
# Epoch duration =0.97s
# Cumulative duration =2min 4.769999999999996s
#
# 128
# Epoch duration =0.97s
# Cumulative duration =2min 5.739999999999995s
#
# 129
# Epoch duration =0.98s
# Cumulative duration =2min 6.709999999999994s
#
# 130
# Epoch duration =1.06s
# Cumulative duration =2min 7.780000000000001s
#
# 131
# Epoch duration =1.05s
# Cumulative duration =2min 8.830000000000013s
#
# 132
# Epoch duration =1.04s
# Cumulative duration =2min 9.870000000000005s
#
# 133
# Epoch duration =0.98s
# Cumulative duration =2min 10.840000000000003s
#
# 134
# Epoch duration =0.96s
# Cumulative duration =2min 11.810000000000002s
#
# 135
# Epoch duration =0.97s
# Cumulative duration =2min 12.780000000000001s
#
# 136
# Epoch duration =0.99s
# Cumulative duration =2min 13.77000000000001s
#
# 137
# Epoch duration =0.96s
# Cumulative duration =2min 14.72999999999999s
#
# 138
# Epoch duration =0.96s
# Cumulative duration =2min 15.689999999999998s
#
# 139
# Epoch duration =0.97s
# Cumulative duration =2min 16.659999999999997s
#
# 140
# Epoch duration =0.96s
# Cumulative duration =2min 17.620000000000005s
#
# 141
# Epoch duration =0.99s
# Cumulative duration =2min 18.610000000000014s
#
# 142
# Epoch duration =1.0s
# Cumulative duration =2min 19.620000000000005s
#
# 143
# Epoch duration =0.96s
# Cumulative duration =2min 20.580000000000013s
#
# 144
# Epoch duration =0.96s
# Cumulative duration =2min 21.539999999999992s
#
# 145
# Epoch duration =0.97s
# Cumulative duration =2min 22.50999999999999s
#
# 146
# Epoch duration =0.98s
# Cumulative duration =2min 23.49000000000001s
#
# 147
# Epoch duration =0.97s
# Cumulative duration =2min 24.460000000000008s
#
# 148
# Epoch duration =0.99s
# Cumulative duration =2min 25.44999999999999s
#
# 149
# Epoch duration =0.96s
# Cumulative duration =2min 26.409999999999997s
#
# 150
# Epoch duration =0.99s
# Cumulative duration =2min 27.400000000000006s
#
# 151
# Epoch duration =1.01s
# Cumulative duration =2min 28.409999999999997s
#
# 152
# Epoch duration =0.97s
# Cumulative duration =2min 29.379999999999995s
#
# 153
# Epoch duration =0.98s
# Cumulative duration =2min 30.360000000000014s
#
# 154
# Epoch duration =0.96s
# Cumulative duration =2min 31.319999999999993s
#
# 155
# Epoch duration =0.96s
# Cumulative duration =2min 32.28s
#
# 156
# Epoch duration =0.96s
# Cumulative duration =2min 33.25s
#
# 157
# Epoch duration =0.98s
# Cumulative duration =2min 34.22999999999999s
#
# 158
# Epoch duration =0.97s
# Cumulative duration =2min 35.19999999999999s
#
# 159
# Epoch duration =1.05s
# Cumulative duration =2min 36.25s
#
# 160
# Epoch duration =0.99s
# Cumulative duration =2min 37.24000000000001s
#
# 161
# Epoch duration =0.99s
# Cumulative duration =2min 38.22s
#
# 162
# Epoch duration =0.97s
# Cumulative duration =2min 39.19s
#
# 163
# Epoch duration =0.99s
# Cumulative duration =2min 40.18000000000001s
#
# 164
# Epoch duration =0.99s
# Cumulative duration =2min 41.16999999999999s
#
# 165
# Epoch duration =0.98s
# Cumulative duration =2min 42.150000000000006s
#
# 166
# Epoch duration =0.97s
# Cumulative duration =2min 43.129999999999995s
#
# 167
# Epoch duration =1.01s
# Cumulative duration =2min 44.129999999999995s
#
# 168
# Epoch duration =0.98s
# Cumulative duration =2min 45.110000000000014s
#
# 169
# Epoch duration =0.96s
# Cumulative duration =2min 46.06999999999999s
#
# 170
# Epoch duration =0.98s
# Cumulative duration =2min 47.05000000000001s
#
# 171
# Epoch duration =0.96s
# Cumulative duration =2min 48.00999999999999s
#
# 172
# Epoch duration =0.98s
# Cumulative duration =2min 48.97999999999999s
#
# 173
# Epoch duration =0.98s
# Cumulative duration =2min 49.97s
#
# 174
# Epoch duration =0.99s
# Cumulative duration =2min 50.94999999999999s
#
# 175
# Epoch duration =0.97s
# Cumulative duration =2min 51.91999999999999s
#
# 176
# Epoch duration =0.98s
# Cumulative duration =2min 52.900000000000006s
#
# 177
# Epoch duration =1.0s
# Cumulative duration =2min 53.900000000000006s
#
# 178
# Epoch duration =0.98s
# Cumulative duration =2min 54.879999999999995s
#
# 179
# Epoch duration =0.97s
# Cumulative duration =2min 55.849999999999994s
#
# 180
# Epoch duration =0.98s
# Cumulative duration =2min 56.83000000000001s
#
# 181
# Epoch duration =0.99s
# Cumulative duration =2min 57.81999999999999s
#
# 182
# Epoch duration =1.0s
# Cumulative duration =2min 58.83000000000001s
#
# 183
# Epoch duration =0.98s
# Cumulative duration =2min 59.81s
#
# 184
# Epoch duration =1.0s
# Cumulative duration =3min 0.8100000000000023s
#
# 185
# Epoch duration =0.98s
# Cumulative duration =3min 1.789999999999992s
#
# 186
# Epoch duration =0.97s
# Cumulative duration =3min 2.759999999999991s
#
# 187
# Epoch duration =0.98s
# Cumulative duration =3min 3.740000000000009s
#
# 188
# Epoch duration =0.97s
# Cumulative duration =3min 4.710000000000008s
#
# 189
# Epoch duration =0.97s
# Cumulative duration =3min 5.680000000000007s
#
# 190
# Epoch duration =0.96s
# Cumulative duration =3min 6.639999999999986s
#
# 191
# Epoch duration =0.98s
# Cumulative duration =3min 7.6299999999999955s
#
# 192
# Epoch duration =1.01s
# Cumulative duration =3min 8.639999999999986s
#
# 193
# Epoch duration =0.97s
# Cumulative duration =3min 9.599999999999994s
#
# 194
# Epoch duration =0.97s
# Cumulative duration =3min 10.569999999999993s
#
# 195
# Epoch duration =0.97s
# Cumulative duration =3min 11.539999999999992s
#
# 196
# Epoch duration =0.98s
# Cumulative duration =3min 12.52000000000001s
#
# 197
# Epoch duration =0.97s
# Cumulative duration =3min 13.490000000000009s
#
# 198
# Epoch duration =1.0s
# Cumulative duration =3min 14.490000000000009s
#
# 199
# Epoch duration =0.97s
# Cumulative duration =3min 15.460000000000008s
#
# 200
# Epoch duration =0.97s
# Cumulative duration =3min 16.430000000000007s
#
# 201
# Epoch duration =0.98s
# Cumulative duration =3min 17.409999999999997s
#
# 202
# Epoch duration =0.97s
# Cumulative duration =3min 18.370000000000005s
#
# 203
# Epoch duration =0.97s
# Cumulative duration =3min 19.340000000000003s
#
# 204
# Epoch duration =0.98s
# Cumulative duration =3min 20.310000000000002s
#
# 205
# Epoch duration =0.97s
# Cumulative duration =3min 21.28s
#
# 206
# Epoch duration =0.97s
# Cumulative duration =3min 22.25s
#
# 207
# Epoch duration =0.98s
# Cumulative duration =3min 23.22999999999999s
#
# 208
# Epoch duration =0.97s
# Cumulative duration =3min 24.19999999999999s
#
# 209
# Epoch duration =1.0s
# Cumulative duration =3min 25.19999999999999s
#
# 210
# Epoch duration =0.97s
# Cumulative duration =3min 26.159999999999997s
#
# 211
# Epoch duration =0.98s
# Cumulative duration =3min 27.139999999999986s
#
# 212
# Epoch duration =0.96s
# Cumulative duration =3min 28.110000000000014s
#
# 213
# Epoch duration =0.99s
# Cumulative duration =3min 29.099999999999994s
#
# 214
# Epoch duration =0.98s
# Cumulative duration =3min 30.069999999999993s
#
# 215
# Epoch duration =0.96s
# Cumulative duration =3min 31.03s
#
# 216
# Epoch duration =0.98s
# Cumulative duration =3min 32.00999999999999s
#
# 217
# Epoch duration =0.97s
# Cumulative duration =3min 32.97999999999999s
#
# 218
# Epoch duration =0.97s
# Cumulative duration =3min 33.94999999999999s
#
# 219
# Epoch duration =0.96s
# Cumulative duration =3min 34.91999999999999s
#
# 220
# Epoch duration =1.01s
# Cumulative duration =3min 35.93000000000001s
#
# 221
# Epoch duration =1.09s
# Cumulative duration =3min 37.03s
#
# 222
# Epoch duration =1.1s
# Cumulative duration =3min 38.120000000000005s
#
# 223
# Epoch duration =1.02s
# Cumulative duration =3min 39.139999999999986s
#
# 224
# Epoch duration =0.98s
# Cumulative duration =3min 40.120000000000005s
#
# 225
# Epoch duration =0.96s
# Cumulative duration =3min 41.08000000000001s
#
# 226
# Epoch duration =1.0s
# Cumulative duration =3min 42.08000000000001s
#
# 227
# Epoch duration =0.97s
# Cumulative duration =3min 43.05000000000001s
#
# 228
# Epoch duration =0.97s
# Cumulative duration =3min 44.02000000000001s
#
# 229
# Epoch duration =0.97s
# Cumulative duration =3min 44.99000000000001s
#
# 230
# Epoch duration =0.97s
# Cumulative duration =3min 45.96000000000001s
#
# 231
# Epoch duration =0.96s
# Cumulative duration =3min 46.93000000000001s
#
# 232
# Epoch duration =0.97s
# Cumulative duration =3min 47.900000000000006s
#
# 233
# Epoch duration =0.97s
# Cumulative duration =3min 48.870000000000005s
#
# 234
# Epoch duration =0.97s
# Cumulative duration =3min 49.84s
#
# 235
# Epoch duration =0.98s
# Cumulative duration =3min 50.81999999999999s
#
# 236
# Epoch duration =1.0s
# Cumulative duration =3min 51.83000000000001s
#
# 237
# Epoch duration =0.97s
# Cumulative duration =3min 52.80000000000001s
#
# 238
# Epoch duration =0.97s
# Cumulative duration =3min 53.75999999999999s
#
# 239
# Epoch duration =1.01s
# Cumulative duration =3min 54.77000000000001s
#
# 240
# Epoch duration =0.98s
# Cumulative duration =3min 55.75s
#
# 241
# Epoch duration =0.98s
# Cumulative duration =3min 56.72999999999999s
#
# 242
# Epoch duration =0.99s
# Cumulative duration =3min 57.72999999999999s
#
# 243
# Epoch duration =0.98s
# Cumulative duration =3min 58.69999999999999s
#
# 244
# Epoch duration =0.97s
# Cumulative duration =3min 59.68000000000001s
#
# 245
# Epoch duration =0.97s
# Cumulative duration =4min 0.6399999999999864s
#
# 246
# Epoch duration =0.97s
# Cumulative duration =4min 1.6100000000000136s
#
# 247
# Epoch duration =0.97s
# Cumulative duration =4min 2.5900000000000034s
#
# 248
# Epoch duration =0.98s
# Cumulative duration =4min 3.5600000000000023s
#
# 249
# Epoch duration =0.97s
# Cumulative duration =4min 4.530000000000001s
#
# 250
# Epoch duration =0.96s
# Cumulative duration =4min 5.490000000000009s
#
# 251
# Epoch duration =0.96s
# Cumulative duration =4min 6.449999999999989s
#
# 252
# Epoch duration =0.97s
# Cumulative duration =4min 7.4199999999999875s
#
# 253
# Epoch duration =0.95s
# Cumulative duration =4min 8.370000000000005s
#
# 254
# Epoch duration =0.98s
# Cumulative duration =4min 9.349999999999994s
#
# 255
# Epoch duration =0.96s
# Cumulative duration =4min 10.310000000000002s
#
# 256
# Epoch duration =0.97s
# Cumulative duration =4min 11.280000000000001s
#
# 257
# Epoch duration =0.96s
# Cumulative duration =4min 12.240000000000009s
#
# 258
# Epoch duration =0.99s
# Cumulative duration =4min 13.22999999999999s
#
# 259
# Epoch duration =0.96s
# Cumulative duration =4min 14.189999999999998s
#
# 260
# Epoch duration =0.98s
# Cumulative duration =4min 15.180000000000007s
#
# 261
# Epoch duration =0.98s
# Cumulative duration =4min 16.149999999999977s
#
# 262
# Epoch duration =0.96s
# Cumulative duration =4min 17.110000000000014s
#
# 263
# Epoch duration =0.97s
# Cumulative duration =4min 18.079999999999984s
#
# 264
# Epoch duration =0.99s
# Cumulative duration =4min 19.069999999999993s
#
# 265
# Epoch duration =0.97s
# Cumulative duration =4min 20.04000000000002s
#
# 266
# Epoch duration =0.97s
# Cumulative duration =4min 21.00999999999999s
#
# 267
# Epoch duration =0.99s
# Cumulative duration =4min 22.0s
#
# 268
# Epoch duration =1.01s
# Cumulative duration =4min 23.00999999999999s
#
# 269
# Epoch duration =0.96s
# Cumulative duration =4min 23.970000000000027s
#
# 270
# Epoch duration =0.97s
# Cumulative duration =4min 24.939999999999998s
#
# 271
# Epoch duration =0.96s
# Cumulative duration =4min 25.899999999999977s
#
# 272
# Epoch duration =0.97s
# Cumulative duration =4min 26.870000000000005s
#
# 273
# Epoch duration =0.99s
# Cumulative duration =4min 27.870000000000005s
#
# 274
# Epoch duration =0.97s
# Cumulative duration =4min 28.839999999999975s
#
# 275
# Epoch duration =0.98s
# Cumulative duration =4min 29.819999999999993s
#
# 276
# Epoch duration =0.98s
# Cumulative duration =4min 30.79000000000002s
#
# 277
# Epoch duration =0.99s
# Cumulative duration =4min 31.779999999999973s
#
# 278
# Epoch duration =0.98s
# Cumulative duration =4min 32.75999999999999s
#
# 279
# Epoch duration =0.97s
# Cumulative duration =4min 33.73000000000002s
#
# 280
# Epoch duration =0.97s
# Cumulative duration =4min 34.69999999999999s
#
# 281
# Epoch duration =0.96s
# Cumulative duration =4min 35.660000000000025s
#
# 282
# Epoch duration =0.97s
# Cumulative duration =4min 36.629999999999995s
#
# 283
# Epoch duration =0.99s
# Cumulative duration =4min 37.629999999999995s
#
# 284
# Epoch duration =0.98s
# Cumulative duration =4min 38.610000000000014s
#
# 285
# Epoch duration =0.97s
# Cumulative duration =4min 39.579999999999984s
#
# 286
# Epoch duration =0.98s
# Cumulative duration =4min 40.56s
#
# 287
# Epoch duration =1.01s
# Cumulative duration =4min 41.56999999999999s
#
# 288
# Epoch duration =0.99s
# Cumulative duration =4min 42.56s
#
# 289
# Epoch duration =0.99s
# Cumulative duration =4min 43.55000000000001s
#
# 290
# Epoch duration =0.99s
# Cumulative duration =4min 44.54000000000002s
#
# 291
# Epoch duration =0.97s
# Cumulative duration =4min 45.50999999999999s
#
# 292
# Epoch duration =0.97s
# Cumulative duration =4min 46.48000000000002s
#
# 293
# Epoch duration =0.97s
# Cumulative duration =4min 47.44999999999999s
#
# 294
# Epoch duration =0.98s
# Cumulative duration =4min 48.43000000000001s
#
# 295
# Epoch duration =0.98s
# Cumulative duration =4min 49.410000000000025s
#
# 296
# Epoch duration =0.97s
# Cumulative duration =4min 50.379999999999995s
#
# 297
# Epoch duration =0.97s
# Cumulative duration =4min 51.360000000000014s
#
# 298
# Epoch duration =0.96s
# Cumulative duration =4min 52.31999999999999s
#
# 299
# Epoch duration =0.97s
# Cumulative duration =4min 53.29000000000002s
#
# 300
# Epoch duration =0.99s
# Cumulative duration =4min 54.27999999999997s
#
# 301
# Epoch duration =1.0s
# Cumulative duration =4min 55.27999999999997s
#
# 302
# Epoch duration =0.96s
# Cumulative duration =4min 56.24000000000001s
#
# 303
# Epoch duration =1.02s
# Cumulative duration =4min 57.25999999999999s
#
# 304
# Epoch duration =0.98s
# Cumulative duration =4min 58.24000000000001s
#
# 305
# Epoch duration =0.99s
# Cumulative duration =4min 59.23000000000002s
#
# 306
# Epoch duration =0.97s
# Cumulative duration =5min 0.18999999999999773s
#
# 307
# Epoch duration =0.96s
# Cumulative duration =5min 1.1499999999999773s
#
# 308
# Epoch duration =0.98s
# Cumulative duration =5min 2.1399999999999864s
#
# 309
# Epoch duration =0.99s
# Cumulative duration =5min 3.1200000000000045s
#
# 310
# Epoch duration =0.98s
# Cumulative duration =5min 4.110000000000014s
#
# 311
# Epoch duration =0.99s
# Cumulative duration =5min 5.100000000000023s
#
# 312
# Epoch duration =1.0s
# Cumulative duration =5min 6.100000000000023s
#
# 313
# Epoch duration =1.0s
# Cumulative duration =5min 7.110000000000014s
#
# 314
# Epoch duration =0.98s
# Cumulative duration =5min 8.089999999999975s
#
# 315
# Epoch duration =0.98s
# Cumulative duration =5min 9.069999999999993s
#
# 316
# Epoch duration =0.98s
# Cumulative duration =5min 10.04000000000002s
#
# 317
# Epoch duration =0.96s
# Cumulative duration =5min 11.0s
#
# 318
# Epoch duration =0.97s
# Cumulative duration =5min 11.980000000000018s
#
# 319
# Epoch duration =0.98s
# Cumulative duration =5min 12.949999999999989s
#
# 320
# Epoch duration =0.96s
# Cumulative duration =5min 13.910000000000025s
#
# 321
# Epoch duration =1.15s
# Cumulative duration =5min 15.060000000000002s
#
# 322
# Epoch duration =1.13s
# Cumulative duration =5min 16.189999999999998s
#
# 323
# Epoch duration =1.04s
# Cumulative duration =5min 17.230000000000018s
#
# 324
# Epoch duration =1.11s
# Cumulative duration =5min 18.339999999999975s
#
# 325
# Epoch duration =1.01s
# Cumulative duration =5min 19.360000000000014s
#
# 326
# Epoch duration =0.98s
# Cumulative duration =5min 20.339999999999975s
#
# 327
# Epoch duration =0.98s
# Cumulative duration =5min 21.310000000000002s
#
# 328
# Epoch duration =0.98s
# Cumulative duration =5min 22.29000000000002s
#
# 329
# Epoch duration =0.97s
# Cumulative duration =5min 23.25999999999999s
#
# 330
# Epoch duration =0.98s
# Cumulative duration =5min 24.24000000000001s
#
# 331
# Epoch duration =0.97s
# Cumulative duration =5min 25.20999999999998s
#
# 332
# Epoch duration =0.96s
# Cumulative duration =5min 26.180000000000007s
#
# 333
# Epoch duration =0.98s
# Cumulative duration =5min 27.149999999999977s
#
# 334
# Epoch duration =0.96s
# Cumulative duration =5min 28.120000000000005s
#
# 335
# Epoch duration =0.98s
# Cumulative duration =5min 29.100000000000023s
#
# 336
# Epoch duration =0.96s
# Cumulative duration =5min 30.069999999999993s
#
# 337
# Epoch duration =0.97s
# Cumulative duration =5min 31.029999999999973s
#
# 338
# Epoch duration =0.98s
# Cumulative duration =5min 32.01999999999998s
#
# 339
# Epoch duration =0.98s
# Cumulative duration =5min 33.0s
#
# 340
# Epoch duration =0.96s
# Cumulative duration =5min 33.95999999999998s
#
# 341
# Epoch duration =0.96s
# Cumulative duration =5min 34.93000000000001s
#
# 342
# Epoch duration =0.96s
# Cumulative duration =5min 35.889999999999986s
#
# 343
# Epoch duration =1.01s
# Cumulative duration =5min 36.889999999999986s
#
# 344
# Epoch duration =0.99s
# Cumulative duration =5min 37.879999999999995s
#
# 345
# Epoch duration =0.99s
# Cumulative duration =5min 38.879999999999995s
#
# 346
# Epoch duration =0.97s
# Cumulative duration =5min 39.85000000000002s
#
# 347
# Epoch duration =0.97s
# Cumulative duration =5min 40.81s
#
# 348
# Epoch duration =0.98s
# Cumulative duration =5min 41.79000000000002s
#
# 349
# Epoch duration =0.98s
# Cumulative duration =5min 42.76999999999998s
#
# 350
# Epoch duration =0.96s
# Cumulative duration =5min 43.73000000000002s
#
# 351
# Epoch duration =0.97s
# Cumulative duration =5min 44.69999999999999s
#
# 352
# Epoch duration =0.96s
# Cumulative duration =5min 45.660000000000025s
#
# 353
# Epoch duration =0.96s
# Cumulative duration =5min 46.620000000000005s
#
# 354
# Epoch duration =0.99s
# Cumulative duration =5min 47.610000000000014s
#
# 355
# Epoch duration =1.0s
# Cumulative duration =5min 48.610000000000014s
#
# 356
# Epoch duration =0.99s
# Cumulative duration =5min 49.60000000000002s
#
# 357
# Epoch duration =0.97s
# Cumulative duration =5min 50.56999999999999s
#
# 358
# Epoch duration =0.96s
# Cumulative duration =5min 51.52999999999997s
#
# 359
# Epoch duration =0.97s
# Cumulative duration =5min 52.5s
#
# 360
# Epoch duration =0.97s
# Cumulative duration =5min 53.45999999999998s
#
# 361
# Epoch duration =0.97s
# Cumulative duration =5min 54.43000000000001s
#
# 362
# Epoch duration =0.97s
# Cumulative duration =5min 55.39999999999998s
#
# 363
# Epoch duration =0.97s
# Cumulative duration =5min 56.370000000000005s
#
# 364
# Epoch duration =0.95s
# Cumulative duration =5min 57.329999999999984s
#
# 365
# Epoch duration =0.96s
# Cumulative duration =5min 58.27999999999997s
#
# 366
# Epoch duration =0.97s
# Cumulative duration =5min 59.25s
#
# 367
# Epoch duration =0.98s
# Cumulative duration =6min 0.2300000000000182s
#
# 368
# Epoch duration =0.97s
# Cumulative duration =6min 1.1999999999999886s
#
# 369
# Epoch duration =0.97s
# Cumulative duration =6min 2.170000000000016s
#
# 370
# Epoch duration =0.97s
# Cumulative duration =6min 3.1399999999999864s
#
# 371
# Epoch duration =0.96s
# Cumulative duration =6min 4.100000000000023s
#
# 372
# Epoch duration =0.97s
# Cumulative duration =6min 5.079999999999984s
#
# 373
# Epoch duration =0.96s
# Cumulative duration =6min 6.029999999999973s
#
# 374
# Epoch duration =0.98s
# Cumulative duration =6min 7.009999999999991s
#
# 375
# Epoch duration =0.96s
# Cumulative duration =6min 7.970000000000027s
#
# 376
# Epoch duration =1.05s
# Cumulative duration =6min 9.029999999999973s
#
# 377
# Epoch duration =0.96s
# Cumulative duration =6min 9.990000000000009s
#
# 378
# Epoch duration =0.98s
# Cumulative duration =6min 10.95999999999998s
#
# 379
# Epoch duration =0.97s
# Cumulative duration =6min 11.930000000000007s
#
# 380
# Epoch duration =0.97s
# Cumulative duration =6min 12.899999999999977s
#
# 381
# Epoch duration =0.97s
# Cumulative duration =6min 13.870000000000005s
#
# 382
# Epoch duration =0.96s
# Cumulative duration =6min 14.829999999999984s
#
# 383
# Epoch duration =0.96s
# Cumulative duration =6min 15.79000000000002s
#
# 384
# Epoch duration =0.97s
# Cumulative duration =6min 16.75999999999999s
#
# 385
# Epoch duration =0.97s
# Cumulative duration =6min 17.730000000000018s
#
# 386
# Epoch duration =0.96s
# Cumulative duration =6min 18.680000000000007s
#
# 387
# Epoch duration =0.98s
# Cumulative duration =6min 19.660000000000025s
#
# 388
# Epoch duration =0.97s
# Cumulative duration =6min 20.629999999999995s
#
# 389
# Epoch duration =0.97s
# Cumulative duration =6min 21.600000000000023s
#
# 390
# Epoch duration =0.98s
# Cumulative duration =6min 22.579999999999984s
#
# 391
# Epoch duration =0.98s
# Cumulative duration =6min 23.560000000000002s
#
# 392
# Epoch duration =0.98s
# Cumulative duration =6min 24.54000000000002s
#
# 393
# Epoch duration =1.01s
# Cumulative duration =6min 25.55000000000001s
#
# 394
# Epoch duration =0.97s
# Cumulative duration =6min 26.519999999999982s
#
# 395
# Epoch duration =0.96s
# Cumulative duration =6min 27.480000000000018s
#
# 396
# Epoch duration =0.96s
# Cumulative duration =6min 28.439999999999998s
#
# 397
# Epoch duration =0.97s
# Cumulative duration =6min 29.399999999999977s
#
# 398
# Epoch duration =0.96s
# Cumulative duration =6min 30.360000000000014s
#
# 399
# Epoch duration =0.98s
# Cumulative duration =6min 31.339999999999975s
#
# 400
# Epoch duration =0.97s
# Cumulative duration =6min 32.31999999999999s
#
# 401
# Epoch duration =0.96s
# Cumulative duration =6min 33.27999999999997s
#
# 402
# Epoch duration =0.97s
# Cumulative duration =6min 34.25s
#
# 403
# Epoch duration =0.98s
# Cumulative duration =6min 35.23000000000002s
#
# 404
# Epoch duration =0.96s
# Cumulative duration =6min 36.19s
#
# 405
# Epoch duration =0.98s
# Cumulative duration =6min 37.170000000000016s
#
# 406
# Epoch duration =0.95s
# Cumulative duration =6min 38.120000000000005s
#
# 407
# Epoch duration =0.96s
# Cumulative duration =6min 39.079999999999984s
#
# 408
# Epoch duration =0.96s
# Cumulative duration =6min 40.04000000000002s
#
# 409
# Epoch duration =0.98s
# Cumulative duration =6min 41.01999999999998s
#
# 410
# Epoch duration =0.99s
# Cumulative duration =6min 42.01999999999998s
#
# 411
# Epoch duration =0.99s
# Cumulative duration =6min 43.0s
#
# 412
# Epoch duration =0.99s
# Cumulative duration =6min 43.99000000000001s
#
# 413
# Epoch duration =0.97s
# Cumulative duration =6min 44.97000000000003s
#
# 414
# Epoch duration =0.98s
# Cumulative duration =6min 45.94999999999999s
#
# 415
# Epoch duration =0.97s
# Cumulative duration =6min 46.920000000000016s
#
# 416
# Epoch duration =0.97s
# Cumulative duration =6min 47.889999999999986s
#
# 417
# Epoch duration =0.96s
# Cumulative duration =6min 48.85000000000002s
#
# 418
# Epoch duration =0.97s
# Cumulative duration =6min 49.81999999999999s
#
# 419
# Epoch duration =0.99s
# Cumulative duration =6min 50.81s
#
# 420
# Epoch duration =0.97s
# Cumulative duration =6min 51.77999999999997s
#
# 421
# Epoch duration =0.97s
# Cumulative duration =6min 52.75s
#
# 422
# Epoch duration =0.97s
# Cumulative duration =6min 53.72000000000003s
#
# 423
# Epoch duration =0.97s
# Cumulative duration =6min 54.69999999999999s
#
# 424
# Epoch duration =0.96s
# Cumulative duration =6min 55.660000000000025s
#
# 425
# Epoch duration =0.97s
# Cumulative duration =6min 56.629999999999995s
#
# 426
# Epoch duration =0.98s
# Cumulative duration =6min 57.610000000000014s
#
# 427
# Epoch duration =0.96s
# Cumulative duration =6min 58.56999999999999s
#
# 428
# Epoch duration =0.97s
# Cumulative duration =6min 59.54000000000002s
#
# 429
# Epoch duration =0.96s
# Cumulative duration =7min 0.5s
#
# 430
# Epoch duration =0.96s
# Cumulative duration =7min 1.4599999999999795s
#
# 431
# Epoch duration =0.99s
# Cumulative duration =7min 2.4499999999999886s
#
# 432
# Epoch duration =0.97s
# Cumulative duration =7min 3.410000000000025s
#
# 433
# Epoch duration =0.98s
# Cumulative duration =7min 4.389999999999986s
#
# 434
# Epoch duration =0.98s
# Cumulative duration =7min 5.3700000000000045s
#
# 435
# Epoch duration =0.96s
# Cumulative duration =7min 6.329999999999984s
#
# 436
# Epoch duration =0.96s
# Cumulative duration =7min 7.2900000000000205s
#
# 437
# Epoch duration =0.99s
# Cumulative duration =7min 8.279999999999973s
#
# 438
# Epoch duration =0.98s
# Cumulative duration =7min 9.259999999999991s
#
# 439
# Epoch duration =0.97s
# Cumulative duration =7min 10.230000000000018s
#
# 440
# Epoch duration =0.99s
# Cumulative duration =7min 11.220000000000027s
#
# 441
# Epoch duration =0.97s
# Cumulative duration =7min 12.189999999999998s
#
# 442
# Epoch duration =0.98s
# Cumulative duration =7min 13.170000000000016s
#
# 443
# Epoch duration =0.95s
# Cumulative duration =7min 14.120000000000005s
#
# 444
# Epoch duration =0.98s
# Cumulative duration =7min 15.100000000000023s
#
# 445
# Epoch duration =0.97s
# Cumulative duration =7min 16.069999999999993s
#
# 446
# Epoch duration =0.95s
# Cumulative duration =7min 17.019999999999982s
#
# 447
# Epoch duration =0.98s
# Cumulative duration =7min 18.0s
#
# 448
# Epoch duration =0.97s
# Cumulative duration =7min 18.980000000000018s
#
# 449
# Epoch duration =0.98s
# Cumulative duration =7min 19.95999999999998s
#
# 450
# Epoch duration =0.97s
# Cumulative duration =7min 20.920000000000016s
#
# 451
# Epoch duration =0.97s
# Cumulative duration =7min 21.889999999999986s
#
# 452
# Epoch duration =0.97s
# Cumulative duration =7min 22.860000000000014s
#
# 453
# Epoch duration =0.96s
# Cumulative duration =7min 23.819999999999993s
#
# 454
# Epoch duration =0.97s
# Cumulative duration =7min 24.79000000000002s
#
# 455
# Epoch duration =0.98s
# Cumulative duration =7min 25.769999999999982s
#
# 456
# Epoch duration =0.96s
# Cumulative duration =7min 26.730000000000018s
#
# 457
# Epoch duration =0.98s
# Cumulative duration =7min 27.70999999999998s
#
# 458
# Epoch duration =1.0s
# Cumulative duration =7min 28.70999999999998s
#
# 459
# Epoch duration =0.97s
# Cumulative duration =7min 29.680000000000007s
#
# 460
# Epoch duration =0.96s
# Cumulative duration =7min 30.649999999999977s
#
# 461
# Epoch duration =0.97s
# Cumulative duration =7min 31.610000000000014s
#
# 462
# Epoch duration =0.96s
# Cumulative duration =7min 32.56999999999999s
#
# 463
# Epoch duration =0.96s
# Cumulative duration =7min 33.54000000000002s
#
# 464
# Epoch duration =0.99s
# Cumulative duration =7min 34.51999999999998s
#
# 465
# Epoch duration =0.98s
# Cumulative duration =7min 35.50999999999999s
#
# 466
# Epoch duration =0.97s
# Cumulative duration =7min 36.47000000000003s
#
# 467
# Epoch duration =0.98s
# Cumulative duration =7min 37.44999999999999s
#
# 468
# Epoch duration =0.97s
# Cumulative duration =7min 38.420000000000016s
#
# 469
# Epoch duration =0.96s
# Cumulative duration =7min 39.389999999999986s
#
# 470
# Epoch duration =0.98s
# Cumulative duration =7min 40.360000000000014s
#
# 471
# Epoch duration =0.97s
# Cumulative duration =7min 41.339999999999975s
#
# 472
# Epoch duration =0.97s
# Cumulative duration =7min 42.31s
#
# 473
# Epoch duration =1.0s
# Cumulative duration =7min 43.31s
#
# 474
# Epoch duration =0.97s
# Cumulative duration =7min 44.27999999999997s
#
# 475
# Epoch duration =0.96s
# Cumulative duration =7min 45.24000000000001s
#
# 476
# Epoch duration =0.96s
# Cumulative duration =7min 46.19s
#
# 477
# Epoch duration =0.96s
# Cumulative duration =7min 47.160000000000025s
#
# 478
# Epoch duration =0.98s
# Cumulative duration =7min 48.129999999999995s
#
# 479
# Epoch duration =0.98s
# Cumulative duration =7min 49.110000000000014s
#
# 480
# Epoch duration =0.96s
# Cumulative duration =7min 50.079999999999984s
#
# 481
# Epoch duration =0.96s
# Cumulative duration =7min 51.02999999999997s
#
# 482
# Epoch duration =0.96s
# Cumulative duration =7min 52.0s
#
# 483
# Epoch duration =0.96s
# Cumulative duration =7min 52.94999999999999s
#
# 484
# Epoch duration =0.97s
# Cumulative duration =7min 53.93000000000001s
#
# 485
# Epoch duration =0.96s
# Cumulative duration =7min 54.879999999999995s
#
# 486
# Epoch duration =0.97s
# Cumulative duration =7min 55.85000000000002s
#
# 487
# Epoch duration =1.03s
# Cumulative duration =7min 56.879999999999995s
#
# 488
# Epoch duration =0.96s
# Cumulative duration =7min 57.839999999999975s
#
# 489
# Epoch duration =0.99s
# Cumulative duration =7min 58.829999999999984s
#
# 490
# Epoch duration =0.96s
# Cumulative duration =7min 59.80000000000001s
#
# 491
# Epoch duration =0.97s
# Cumulative duration =8min 0.7599999999999909s
#
# 492
# Epoch duration =0.97s
# Cumulative duration =8min 1.740000000000009s
#
# 493
# Epoch duration =0.96s
# Cumulative duration =8min 2.6999999999999886s
#
# 494
# Epoch duration =0.97s
# Cumulative duration =8min 3.660000000000025s
#
# 495
# Epoch duration =0.96s
# Cumulative duration =8min 4.6299999999999955s
#
# 496
# Epoch duration =0.97s
# Cumulative duration =8min 5.600000000000023s
#
# 497
# Epoch duration =0.96s
# Cumulative duration =8min 6.569999999999993s
#
# 498
# Epoch duration =0.97s
# Cumulative duration =8min 7.5400000000000205s
#
# 499
# Epoch duration =0.96s
# Cumulative duration =8min 8.5s

# %%
#load values
savepath = 'Arrays/glna_mlpt2_44_ug_so500.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 500
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:20]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess, normfactor=None)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=None, cmap='Reds', linewidth=0.)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
