# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/glna_100k_d7.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 11.06s

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<<>>>>>>><<<<>>>>)))))'

# %%
ugSS
# Out:
# '::(((((,<<<<<<<_____>>>>>>>,,,,,,,,<<<<_____>>>>,,,,)))))::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'mlp_t1_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 893, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.74s -- loss=0.22750 -- acc=90.626673%
#
#   valid loss:		0.05071
#   valid accuracy:	0.99215+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t1_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.43s -- loss=0.07251 -- acc=97.949175%
#
#   valid loss:		0.01828
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t1_44_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.05379 -- acc=98.532503%
#
#   valid loss:		0.01720
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t1_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.04561 -- acc=98.824172%
#
#   valid loss:		0.01605
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t1_44_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.03930 -- acc=99.056676%
#
#   valid loss:		0.01100
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t1_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.47s -- loss=0.03761 -- acc=99.100000%
#
#   valid loss:		0.01466
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.40s -- loss=0.03615 -- acc=99.148335%
#
#   valid loss:		0.01779
#   valid accuracy:	0.99705+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.42s -- loss=0.03470 -- acc=99.186679%
#
#   valid loss:		0.01262
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.03301 -- acc=99.245005%
#
#   valid loss:		0.01696
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.03198 -- acc=99.304170%
#
#   valid loss:		0.01537
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.03254 -- acc=99.295000%
#
#   valid loss:		0.01407
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.03048 -- acc=99.351675%
#
#   valid loss:		0.01333
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.45s -- loss=0.03024 -- acc=99.389179%
#
#   valid loss:		0.01434
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.41s -- loss=0.03189 -- acc=99.340004%
#
#   valid loss:		0.01724
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.03123 -- acc=99.388339%
#
#   valid loss:		0.01372
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.02962 -- acc=99.421672%
#
#   valid loss:		0.01298
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.03040 -- acc=99.397500%
#
#   valid loss:		0.01389
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.03009 -- acc=99.422502%
#
#   valid loss:		0.01405
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.02984 -- acc=99.407501%
#
#   valid loss:		0.01655
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.47s -- loss=0.02989 -- acc=99.420002%
#
#   valid loss:		0.01782
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.03065 -- acc=99.413331%
#
#   valid loss:		0.01478
#   valid accuracy:	0.99895+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.41s -- loss=0.02918 -- acc=99.460006%
#
#   valid loss:		0.01313
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.03014 -- acc=99.431673%
#
#   valid loss:		0.01722
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.47s -- loss=0.02891 -- acc=99.460006%
#
#   valid loss:		0.01344
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.02981 -- acc=99.440004%
#
#   valid loss:		0.01426
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.50s -- loss=0.02950 -- acc=99.468337%
#
#   valid loss:		0.01349
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.02969 -- acc=99.448335%
#
#   valid loss:		0.01520
#   valid accuracy:	0.99895+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.03086 -- acc=99.441674%
#
#   valid loss:		0.01314
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.50s -- loss=0.02865 -- acc=99.479178%
#
#   valid loss:		0.01773
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.02994 -- acc=99.455836%
#
#   valid loss:		0.01390
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.02933 -- acc=99.445835%
#
#   valid loss:		0.01442
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.03015 -- acc=99.483338%
#
#   valid loss:		0.01617
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.45s -- loss=0.02963 -- acc=99.467507%
#
#   valid loss:		0.01471
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.03040 -- acc=99.445835%
#
#   valid loss:		0.01460
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.02962 -- acc=99.463336%
#
#   valid loss:		0.01504
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.02951 -- acc=99.475838%
#
#   valid loss:		0.01506
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.03053 -- acc=99.461676%
#
#   valid loss:		0.01380
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.50s -- loss=0.02990 -- acc=99.488339%
#
#   valid loss:		0.01364
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.45s -- loss=0.03008 -- acc=99.503330%
#
#   valid loss:		0.01486
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.02973 -- acc=99.498330%
#
#   valid loss:		0.01443
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.02957 -- acc=99.499170%
#
#   valid loss:		0.01659
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.03052 -- acc=99.464176%
#
#   valid loss:		0.01443
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.47s -- loss=0.02923 -- acc=99.512501%
#
#   valid loss:		0.01543
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.02926 -- acc=99.508331%
#
#   valid loss:		0.01517
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.50s -- loss=0.02771 -- acc=99.540834%
#
#   valid loss:		0.01563
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/mlp_t1_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/mlp_t1_44_best.ckpt
#   test  loss:		0.01184
#   test  accuracy:	0.99892+/-0.00000
#   test  auc-roc:	0.99997+/-0.00000
#   test  auc-pr:		0.99997+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/glna_mlpt1_44_ug_so500.npy'

num_summary = 500
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =0.95s
# Cumulative duration =0.95s
#
# 1
# Epoch duration =0.97s
# Cumulative duration =1.92s
#
# 2
# Epoch duration =0.96s
# Cumulative duration =2.88s
#
# 3
# Epoch duration =0.96s
# Cumulative duration =3.84s
#
# 4
# Epoch duration =0.96s
# Cumulative duration =4.81s
#
# 5
# Epoch duration =0.96s
# Cumulative duration =5.76s
#
# 6
# Epoch duration =0.96s
# Cumulative duration =6.72s
#
# 7
# Epoch duration =0.95s
# Cumulative duration =7.68s
#
# 8
# Epoch duration =0.95s
# Cumulative duration =8.62s
#
# 9
# Epoch duration =0.95s
# Cumulative duration =9.58s
#
# 10
# Epoch duration =0.97s
# Cumulative duration =10.55s
#
# 11
# Epoch duration =0.97s
# Cumulative duration =11.52s
#
# 12
# Epoch duration =0.95s
# Cumulative duration =12.47s
#
# 13
# Epoch duration =0.95s
# Cumulative duration =13.42s
#
# 14
# Epoch duration =0.95s
# Cumulative duration =14.37s
#
# 15
# Epoch duration =0.97s
# Cumulative duration =15.34s
#
# 16
# Epoch duration =0.95s
# Cumulative duration =16.29s
#
# 17
# Epoch duration =0.96s
# Cumulative duration =17.25s
#
# 18
# Epoch duration =0.96s
# Cumulative duration =18.2s
#
# 19
# Epoch duration =0.95s
# Cumulative duration =19.15s
#
# 20
# Epoch duration =0.94s
# Cumulative duration =20.1s
#
# 21
# Epoch duration =0.95s
# Cumulative duration =21.04s
#
# 22
# Epoch duration =0.96s
# Cumulative duration =22.0s
#
# 23
# Epoch duration =0.96s
# Cumulative duration =22.96s
#
# 24
# Epoch duration =0.96s
# Cumulative duration =23.91s
#
# 25
# Epoch duration =0.96s
# Cumulative duration =24.88s
#
# 26
# Epoch duration =0.96s
# Cumulative duration =25.84s
#
# 27
# Epoch duration =0.96s
# Cumulative duration =26.8s
#
# 28
# Epoch duration =0.96s
# Cumulative duration =27.75s
#
# 29
# Epoch duration =0.98s
# Cumulative duration =28.74s
#
# 30
# Epoch duration =0.98s
# Cumulative duration =29.72s
#
# 31
# Epoch duration =0.95s
# Cumulative duration =30.67s
#
# 32
# Epoch duration =0.97s
# Cumulative duration =31.63s
#
# 33
# Epoch duration =0.96s
# Cumulative duration =32.59s
#
# 34
# Epoch duration =0.94s
# Cumulative duration =33.54s
#
# 35
# Epoch duration =0.98s
# Cumulative duration =34.52s
#
# 36
# Epoch duration =0.96s
# Cumulative duration =35.48s
#
# 37
# Epoch duration =0.97s
# Cumulative duration =36.45s
#
# 38
# Epoch duration =0.96s
# Cumulative duration =37.41s
#
# 39
# Epoch duration =0.95s
# Cumulative duration =38.36s
#
# 40
# Epoch duration =0.95s
# Cumulative duration =39.31s
#
# 41
# Epoch duration =0.96s
# Cumulative duration =40.26s
#
# 42
# Epoch duration =0.95s
# Cumulative duration =41.22s
#
# 43
# Epoch duration =0.95s
# Cumulative duration =42.16s
#
# 44
# Epoch duration =0.95s
# Cumulative duration =43.11s
#
# 45
# Epoch duration =0.95s
# Cumulative duration =44.07s
#
# 46
# Epoch duration =0.95s
# Cumulative duration =45.01s
#
# 47
# Epoch duration =0.95s
# Cumulative duration =45.97s
#
# 48
# Epoch duration =0.96s
# Cumulative duration =46.93s
#
# 49
# Epoch duration =0.96s
# Cumulative duration =47.89s
#
# 50
# Epoch duration =0.95s
# Cumulative duration =48.83s
#
# 51
# Epoch duration =0.95s
# Cumulative duration =49.78s
#
# 52
# Epoch duration =0.95s
# Cumulative duration =50.73s
#
# 53
# Epoch duration =0.96s
# Cumulative duration =51.69s
#
# 54
# Epoch duration =0.97s
# Cumulative duration =52.67s
#
# 55
# Epoch duration =0.96s
# Cumulative duration =53.63s
#
# 56
# Epoch duration =0.95s
# Cumulative duration =54.57s
#
# 57
# Epoch duration =0.95s
# Cumulative duration =55.53s
#
# 58
# Epoch duration =0.97s
# Cumulative duration =56.5s
#
# 59
# Epoch duration =0.95s
# Cumulative duration =57.45s
#
# 60
# Epoch duration =0.96s
# Cumulative duration =58.41s
#
# 61
# Epoch duration =0.94s
# Cumulative duration =59.35s
#
# 62
# Epoch duration =0.95s
# Cumulative duration =1min 0.29999999999999716s
#
# 63
# Epoch duration =0.96s
# Cumulative duration =1min 1.259999999999998s
#
# 64
# Epoch duration =0.95s
# Cumulative duration =1min 2.210000000000001s
#
# 65
# Epoch duration =0.95s
# Cumulative duration =1min 3.1599999999999966s
#
# 66
# Epoch duration =0.94s
# Cumulative duration =1min 4.099999999999994s
#
# 67
# Epoch duration =0.95s
# Cumulative duration =1min 5.049999999999997s
#
# 68
# Epoch duration =0.96s
# Cumulative duration =1min 6.010000000000005s
#
# 69
# Epoch duration =0.96s
# Cumulative duration =1min 6.969999999999999s
#
# 70
# Epoch duration =0.96s
# Cumulative duration =1min 7.930000000000007s
#
# 71
# Epoch duration =0.95s
# Cumulative duration =1min 8.89s
#
# 72
# Epoch duration =0.95s
# Cumulative duration =1min 9.840000000000003s
#
# 73
# Epoch duration =0.95s
# Cumulative duration =1min 10.790000000000006s
#
# 74
# Epoch duration =0.95s
# Cumulative duration =1min 11.75s
#
# 75
# Epoch duration =0.96s
# Cumulative duration =1min 12.709999999999994s
#
# 76
# Epoch duration =0.96s
# Cumulative duration =1min 13.670000000000002s
#
# 77
# Epoch duration =0.95s
# Cumulative duration =1min 14.61s
#
# 78
# Epoch duration =0.95s
# Cumulative duration =1min 15.560000000000002s
#
# 79
# Epoch duration =0.95s
# Cumulative duration =1min 16.510000000000005s
#
# 80
# Epoch duration =0.95s
# Cumulative duration =1min 17.459999999999994s
#
# 81
# Epoch duration =0.94s
# Cumulative duration =1min 18.400000000000006s
#
# 82
# Epoch duration =0.95s
# Cumulative duration =1min 19.349999999999994s
#
# 83
# Epoch duration =0.95s
# Cumulative duration =1min 20.299999999999997s
#
# 84
# Epoch duration =0.95s
# Cumulative duration =1min 21.260000000000005s
#
# 85
# Epoch duration =0.95s
# Cumulative duration =1min 22.209999999999994s
#
# 86
# Epoch duration =0.95s
# Cumulative duration =1min 23.150000000000006s
#
# 87
# Epoch duration =0.95s
# Cumulative duration =1min 24.099999999999994s
#
# 88
# Epoch duration =0.95s
# Cumulative duration =1min 25.060000000000002s
#
# 89
# Epoch duration =0.95s
# Cumulative duration =1min 26.010000000000005s
#
# 90
# Epoch duration =0.98s
# Cumulative duration =1min 26.989999999999995s
#
# 91
# Epoch duration =0.96s
# Cumulative duration =1min 27.950000000000003s
#
# 92
# Epoch duration =0.95s
# Cumulative duration =1min 28.900000000000006s
#
# 93
# Epoch duration =0.94s
# Cumulative duration =1min 29.840000000000003s
#
# 94
# Epoch duration =0.95s
# Cumulative duration =1min 30.790000000000006s
#
# 95
# Epoch duration =0.97s
# Cumulative duration =1min 31.760000000000005s
#
# 96
# Epoch duration =0.95s
# Cumulative duration =1min 32.72s
#
# 97
# Epoch duration =0.96s
# Cumulative duration =1min 33.68000000000001s
#
# 98
# Epoch duration =0.96s
# Cumulative duration =1min 34.64s
#
# 99
# Epoch duration =0.95s
# Cumulative duration =1min 35.59s
#
# 100
# Epoch duration =0.96s
# Cumulative duration =1min 36.55s
#
# 101
# Epoch duration =0.95s
# Cumulative duration =1min 37.510000000000005s
#
# 102
# Epoch duration =0.96s
# Cumulative duration =1min 38.47s
#
# 103
# Epoch duration =0.98s
# Cumulative duration =1min 39.45s
#
# 104
# Epoch duration =0.95s
# Cumulative duration =1min 40.400000000000006s
#
# 105
# Epoch duration =0.95s
# Cumulative duration =1min 41.349999999999994s
#
# 106
# Epoch duration =0.95s
# Cumulative duration =1min 42.31s
#
# 107
# Epoch duration =0.95s
# Cumulative duration =1min 43.260000000000005s
#
# 108
# Epoch duration =0.94s
# Cumulative duration =1min 44.2s
#
# 109
# Epoch duration =0.95s
# Cumulative duration =1min 45.150000000000006s
#
# 110
# Epoch duration =0.98s
# Cumulative duration =1min 46.129999999999995s
#
# 111
# Epoch duration =0.95s
# Cumulative duration =1min 47.09s
#
# 112
# Epoch duration =0.95s
# Cumulative duration =1min 48.040000000000006s
#
# 113
# Epoch duration =0.95s
# Cumulative duration =1min 49.0s
#
# 114
# Epoch duration =0.95s
# Cumulative duration =1min 49.95s
#
# 115
# Epoch duration =0.96s
# Cumulative duration =1min 50.91s
#
# 116
# Epoch duration =0.96s
# Cumulative duration =1min 51.870000000000005s
#
# 117
# Epoch duration =1.01s
# Cumulative duration =1min 52.879999999999995s
#
# 118
# Epoch duration =0.96s
# Cumulative duration =1min 53.84s
#
# 119
# Epoch duration =0.96s
# Cumulative duration =1min 54.8s
#
# 120
# Epoch duration =0.96s
# Cumulative duration =1min 55.75s
#
# 121
# Epoch duration =0.95s
# Cumulative duration =1min 56.709999999999994s
#
# 122
# Epoch duration =0.94s
# Cumulative duration =1min 57.650000000000006s
#
# 123
# Epoch duration =0.96s
# Cumulative duration =1min 58.61s
#
# 124
# Epoch duration =0.95s
# Cumulative duration =1min 59.56s
#
# 125
# Epoch duration =0.95s
# Cumulative duration =2min 0.519999999999996s
#
# 126
# Epoch duration =0.95s
# Cumulative duration =2min 1.4699999999999989s
#
# 127
# Epoch duration =0.97s
# Cumulative duration =2min 2.4399999999999977s
#
# 128
# Epoch duration =0.95s
# Cumulative duration =2min 3.3900000000000006s
#
# 129
# Epoch duration =0.95s
# Cumulative duration =2min 4.340000000000003s
#
# 130
# Epoch duration =0.96s
# Cumulative duration =2min 5.299999999999997s
#
# 131
# Epoch duration =0.96s
# Cumulative duration =2min 6.260000000000005s
#
# 132
# Epoch duration =0.95s
# Cumulative duration =2min 7.209999999999994s
#
# 133
# Epoch duration =0.97s
# Cumulative duration =2min 8.180000000000007s
#
# 134
# Epoch duration =0.95s
# Cumulative duration =2min 9.139999999999986s
#
# 135
# Epoch duration =0.98s
# Cumulative duration =2min 10.120000000000005s
#
# 136
# Epoch duration =0.96s
# Cumulative duration =2min 11.080000000000013s
#
# 137
# Epoch duration =0.95s
# Cumulative duration =2min 12.030000000000001s
#
# 138
# Epoch duration =0.95s
# Cumulative duration =2min 12.97999999999999s
#
# 139
# Epoch duration =0.96s
# Cumulative duration =2min 13.949999999999989s
#
# 140
# Epoch duration =0.95s
# Cumulative duration =2min 14.889999999999986s
#
# 141
# Epoch duration =0.95s
# Cumulative duration =2min 15.849999999999994s
#
# 142
# Epoch duration =0.96s
# Cumulative duration =2min 16.80000000000001s
#
# 143
# Epoch duration =0.96s
# Cumulative duration =2min 17.75999999999999s
#
# 144
# Epoch duration =0.97s
# Cumulative duration =2min 18.72999999999999s
#
# 145
# Epoch duration =0.96s
# Cumulative duration =2min 19.689999999999998s
#
# 146
# Epoch duration =0.95s
# Cumulative duration =2min 20.639999999999986s
#
# 147
# Epoch duration =0.96s
# Cumulative duration =2min 21.599999999999994s
#
# 148
# Epoch duration =0.99s
# Cumulative duration =2min 22.590000000000003s
#
# 149
# Epoch duration =0.95s
# Cumulative duration =2min 23.539999999999992s
#
# 150
# Epoch duration =0.96s
# Cumulative duration =2min 24.5s
#
# 151
# Epoch duration =0.98s
# Cumulative duration =2min 25.47999999999999s
#
# 152
# Epoch duration =0.96s
# Cumulative duration =2min 26.439999999999998s
#
# 153
# Epoch duration =0.95s
# Cumulative duration =2min 27.389999999999986s
#
# 154
# Epoch duration =0.94s
# Cumulative duration =2min 28.340000000000003s
#
# 155
# Epoch duration =0.95s
# Cumulative duration =2min 29.289999999999992s
#
# 156
# Epoch duration =0.95s
# Cumulative duration =2min 30.24000000000001s
#
# 157
# Epoch duration =0.96s
# Cumulative duration =2min 31.19999999999999s
#
# 158
# Epoch duration =0.95s
# Cumulative duration =2min 32.150000000000006s
#
# 159
# Epoch duration =0.95s
# Cumulative duration =2min 33.09s
#
# 160
# Epoch duration =0.95s
# Cumulative duration =2min 34.03999999999999s
#
# 161
# Epoch duration =0.97s
# Cumulative duration =2min 35.00999999999999s
#
# 162
# Epoch duration =0.96s
# Cumulative duration =2min 35.97s
#
# 163
# Epoch duration =0.95s
# Cumulative duration =2min 36.91999999999999s
#
# 164
# Epoch duration =0.95s
# Cumulative duration =2min 37.870000000000005s
#
# 165
# Epoch duration =0.96s
# Cumulative duration =2min 38.83000000000001s
#
# 166
# Epoch duration =0.96s
# Cumulative duration =2min 39.78999999999999s
#
# 167
# Epoch duration =0.96s
# Cumulative duration =2min 40.75s
#
# 168
# Epoch duration =0.96s
# Cumulative duration =2min 41.71000000000001s
#
# 169
# Epoch duration =0.95s
# Cumulative duration =2min 42.66s
#
# 170
# Epoch duration =0.95s
# Cumulative duration =2min 43.610000000000014s
#
# 171
# Epoch duration =0.96s
# Cumulative duration =2min 44.56s
#
# 172
# Epoch duration =0.95s
# Cumulative duration =2min 45.50999999999999s
#
# 173
# Epoch duration =0.96s
# Cumulative duration =2min 46.47s
#
# 174
# Epoch duration =0.95s
# Cumulative duration =2min 47.41999999999999s
#
# 175
# Epoch duration =0.95s
# Cumulative duration =2min 48.370000000000005s
#
# 176
# Epoch duration =0.95s
# Cumulative duration =2min 49.31999999999999s
#
# 177
# Epoch duration =0.96s
# Cumulative duration =2min 50.28s
#
# 178
# Epoch duration =0.95s
# Cumulative duration =2min 51.22999999999999s
#
# 179
# Epoch duration =0.96s
# Cumulative duration =2min 52.19s
#
# 180
# Epoch duration =0.98s
# Cumulative duration =2min 53.16999999999999s
#
# 181
# Epoch duration =0.97s
# Cumulative duration =2min 54.129999999999995s
#
# 182
# Epoch duration =0.98s
# Cumulative duration =2min 55.110000000000014s
#
# 183
# Epoch duration =0.96s
# Cumulative duration =2min 56.06999999999999s
#
# 184
# Epoch duration =0.95s
# Cumulative duration =2min 57.02000000000001s
#
# 185
# Epoch duration =0.96s
# Cumulative duration =2min 57.97999999999999s
#
# 186
# Epoch duration =0.95s
# Cumulative duration =2min 58.93000000000001s
#
# 187
# Epoch duration =0.95s
# Cumulative duration =2min 59.879999999999995s
#
# 188
# Epoch duration =0.96s
# Cumulative duration =3min 0.8400000000000034s
#
# 189
# Epoch duration =0.95s
# Cumulative duration =3min 1.789999999999992s
#
# 190
# Epoch duration =0.96s
# Cumulative duration =3min 2.740000000000009s
#
# 191
# Epoch duration =0.96s
# Cumulative duration =3min 3.6999999999999886s
#
# 192
# Epoch duration =0.94s
# Cumulative duration =3min 4.650000000000006s
#
# 193
# Epoch duration =0.97s
# Cumulative duration =3min 5.6200000000000045s
#
# 194
# Epoch duration =0.95s
# Cumulative duration =3min 6.569999999999993s
#
# 195
# Epoch duration =0.95s
# Cumulative duration =3min 7.52000000000001s
#
# 196
# Epoch duration =0.95s
# Cumulative duration =3min 8.469999999999999s
#
# 197
# Epoch duration =0.96s
# Cumulative duration =3min 9.430000000000007s
#
# 198
# Epoch duration =0.95s
# Cumulative duration =3min 10.379999999999995s
#
# 199
# Epoch duration =1.0s
# Cumulative duration =3min 11.379999999999995s
#
# 200
# Epoch duration =0.98s
# Cumulative duration =3min 12.360000000000014s
#
# 201
# Epoch duration =0.95s
# Cumulative duration =3min 13.310000000000002s
#
# 202
# Epoch duration =0.95s
# Cumulative duration =3min 14.259999999999991s
#
# 203
# Epoch duration =0.98s
# Cumulative duration =3min 15.22999999999999s
#
# 204
# Epoch duration =0.96s
# Cumulative duration =3min 16.189999999999998s
#
# 205
# Epoch duration =0.95s
# Cumulative duration =3min 17.139999999999986s
#
# 206
# Epoch duration =0.95s
# Cumulative duration =3min 18.090000000000003s
#
# 207
# Epoch duration =0.95s
# Cumulative duration =3min 19.039999999999992s
#
# 208
# Epoch duration =0.97s
# Cumulative duration =3min 20.00999999999999s
#
# 209
# Epoch duration =0.95s
# Cumulative duration =3min 20.94999999999999s
#
# 210
# Epoch duration =0.96s
# Cumulative duration =3min 21.919999999999987s
#
# 211
# Epoch duration =1.0s
# Cumulative duration =3min 22.909999999999997s
#
# 212
# Epoch duration =0.96s
# Cumulative duration =3min 23.870000000000005s
#
# 213
# Epoch duration =0.97s
# Cumulative duration =3min 24.840000000000003s
#
# 214
# Epoch duration =0.95s
# Cumulative duration =3min 25.789999999999992s
#
# 215
# Epoch duration =0.95s
# Cumulative duration =3min 26.75s
#
# 216
# Epoch duration =0.96s
# Cumulative duration =3min 27.710000000000008s
#
# 217
# Epoch duration =0.95s
# Cumulative duration =3min 28.659999999999997s
#
# 218
# Epoch duration =0.95s
# Cumulative duration =3min 29.610000000000014s
#
# 219
# Epoch duration =0.95s
# Cumulative duration =3min 30.560000000000002s
#
# 220
# Epoch duration =0.97s
# Cumulative duration =3min 31.52000000000001s
#
# 221
# Epoch duration =0.96s
# Cumulative duration =3min 32.49000000000001s
#
# 222
# Epoch duration =0.98s
# Cumulative duration =3min 33.47s
#
# 223
# Epoch duration =0.98s
# Cumulative duration =3min 34.44999999999999s
#
# 224
# Epoch duration =0.95s
# Cumulative duration =3min 35.400000000000006s
#
# 225
# Epoch duration =0.95s
# Cumulative duration =3min 36.349999999999994s
#
# 226
# Epoch duration =0.95s
# Cumulative duration =3min 37.30000000000001s
#
# 227
# Epoch duration =0.95s
# Cumulative duration =3min 38.25s
#
# 228
# Epoch duration =0.95s
# Cumulative duration =3min 39.19s
#
# 229
# Epoch duration =0.95s
# Cumulative duration =3min 40.139999999999986s
#
# 230
# Epoch duration =0.96s
# Cumulative duration =3min 41.099999999999994s
#
# 231
# Epoch duration =0.97s
# Cumulative duration =3min 42.06999999999999s
#
# 232
# Epoch duration =0.96s
# Cumulative duration =3min 43.03999999999999s
#
# 233
# Epoch duration =0.97s
# Cumulative duration =3min 44.0s
#
# 234
# Epoch duration =0.95s
# Cumulative duration =3min 44.96000000000001s
#
# 235
# Epoch duration =0.96s
# Cumulative duration =3min 45.91999999999999s
#
# 236
# Epoch duration =0.96s
# Cumulative duration =3min 46.870000000000005s
#
# 237
# Epoch duration =0.95s
# Cumulative duration =3min 47.81999999999999s
#
# 238
# Epoch duration =0.95s
# Cumulative duration =3min 48.77000000000001s
#
# 239
# Epoch duration =0.99s
# Cumulative duration =3min 49.77000000000001s
#
# 240
# Epoch duration =0.95s
# Cumulative duration =3min 50.72s
#
# 241
# Epoch duration =0.96s
# Cumulative duration =3min 51.68000000000001s
#
# 242
# Epoch duration =0.95s
# Cumulative duration =3min 52.629999999999995s
#
# 243
# Epoch duration =0.95s
# Cumulative duration =3min 53.58000000000001s
#
# 244
# Epoch duration =0.97s
# Cumulative duration =3min 54.55000000000001s
#
# 245
# Epoch duration =0.97s
# Cumulative duration =3min 55.52000000000001s
#
# 246
# Epoch duration =0.96s
# Cumulative duration =3min 56.47999999999999s
#
# 247
# Epoch duration =0.95s
# Cumulative duration =3min 57.43000000000001s
#
# 248
# Epoch duration =0.96s
# Cumulative duration =3min 58.389999999999986s
#
# 249
# Epoch duration =0.95s
# Cumulative duration =3min 59.34s
#
# 250
# Epoch duration =0.96s
# Cumulative duration =4min 0.30000000000001137s
#
# 251
# Epoch duration =0.95s
# Cumulative duration =4min 1.25s
#
# 252
# Epoch duration =0.95s
# Cumulative duration =4min 2.1999999999999886s
#
# 253
# Epoch duration =0.97s
# Cumulative duration =4min 3.1699999999999875s
#
# 254
# Epoch duration =0.96s
# Cumulative duration =4min 4.1299999999999955s
#
# 255
# Epoch duration =0.96s
# Cumulative duration =4min 5.090000000000003s
#
# 256
# Epoch duration =0.95s
# Cumulative duration =4min 6.039999999999992s
#
# 257
# Epoch duration =0.96s
# Cumulative duration =4min 7.0s
#
# 258
# Epoch duration =0.97s
# Cumulative duration =4min 7.960000000000008s
#
# 259
# Epoch duration =0.95s
# Cumulative duration =4min 8.919999999999987s
#
# 260
# Epoch duration =0.98s
# Cumulative duration =4min 9.889999999999986s
#
# 261
# Epoch duration =0.96s
# Cumulative duration =4min 10.849999999999994s
#
# 262
# Epoch duration =0.96s
# Cumulative duration =4min 11.810000000000002s
#
# 263
# Epoch duration =0.97s
# Cumulative duration =4min 12.780000000000001s
#
# 264
# Epoch duration =0.95s
# Cumulative duration =4min 13.72999999999999s
#
# 265
# Epoch duration =0.95s
# Cumulative duration =4min 14.680000000000007s
#
# 266
# Epoch duration =0.95s
# Cumulative duration =4min 15.629999999999995s
#
# 267
# Epoch duration =0.96s
# Cumulative duration =4min 16.589999999999975s
#
# 268
# Epoch duration =0.95s
# Cumulative duration =4min 17.55000000000001s
#
# 269
# Epoch duration =0.96s
# Cumulative duration =4min 18.5s
#
# 270
# Epoch duration =0.95s
# Cumulative duration =4min 19.45999999999998s
#
# 271
# Epoch duration =0.96s
# Cumulative duration =4min 20.420000000000016s
#
# 272
# Epoch duration =0.97s
# Cumulative duration =4min 21.379999999999995s
#
# 273
# Epoch duration =0.96s
# Cumulative duration =4min 22.339999999999975s
#
# 274
# Epoch duration =0.95s
# Cumulative duration =4min 23.29000000000002s
#
# 275
# Epoch duration =0.96s
# Cumulative duration =4min 24.25999999999999s
#
# 276
# Epoch duration =0.95s
# Cumulative duration =4min 25.19999999999999s
#
# 277
# Epoch duration =1.01s
# Cumulative duration =4min 26.20999999999998s
#
# 278
# Epoch duration =0.96s
# Cumulative duration =4min 27.170000000000016s
#
# 279
# Epoch duration =0.95s
# Cumulative duration =4min 28.120000000000005s
#
# 280
# Epoch duration =0.95s
# Cumulative duration =4min 29.069999999999993s
#
# 281
# Epoch duration =0.95s
# Cumulative duration =4min 30.019999999999982s
#
# 282
# Epoch duration =0.96s
# Cumulative duration =4min 30.99000000000001s
#
# 283
# Epoch duration =0.96s
# Cumulative duration =4min 31.939999999999998s
#
# 284
# Epoch duration =0.96s
# Cumulative duration =4min 32.910000000000025s
#
# 285
# Epoch duration =0.96s
# Cumulative duration =4min 33.870000000000005s
#
# 286
# Epoch duration =1.01s
# Cumulative duration =4min 34.879999999999995s
#
# 287
# Epoch duration =0.96s
# Cumulative duration =4min 35.829999999999984s
#
# 288
# Epoch duration =0.96s
# Cumulative duration =4min 36.80000000000001s
#
# 289
# Epoch duration =0.96s
# Cumulative duration =4min 37.75999999999999s
#
# 290
# Epoch duration =0.95s
# Cumulative duration =4min 38.70999999999998s
#
# 291
# Epoch duration =0.95s
# Cumulative duration =4min 39.660000000000025s
#
# 292
# Epoch duration =0.95s
# Cumulative duration =4min 40.610000000000014s
#
# 293
# Epoch duration =0.95s
# Cumulative duration =4min 41.56999999999999s
#
# 294
# Epoch duration =0.96s
# Cumulative duration =4min 42.51999999999998s
#
# 295
# Epoch duration =0.97s
# Cumulative duration =4min 43.49000000000001s
#
# 296
# Epoch duration =0.95s
# Cumulative duration =4min 44.44s
#
# 297
# Epoch duration =0.95s
# Cumulative duration =4min 45.389999999999986s
#
# 298
# Epoch duration =0.96s
# Cumulative duration =4min 46.35000000000002s
#
# 299
# Epoch duration =0.98s
# Cumulative duration =4min 47.31999999999999s
#
# 300
# Epoch duration =0.95s
# Cumulative duration =4min 48.26999999999998s
#
# 301
# Epoch duration =0.97s
# Cumulative duration =4min 49.24000000000001s
#
# 302
# Epoch duration =0.96s
# Cumulative duration =4min 50.19999999999999s
#
# 303
# Epoch duration =0.97s
# Cumulative duration =4min 51.170000000000016s
#
# 304
# Epoch duration =0.96s
# Cumulative duration =4min 52.139999999999986s
#
# 305
# Epoch duration =0.97s
# Cumulative duration =4min 53.110000000000014s
#
# 306
# Epoch duration =0.95s
# Cumulative duration =4min 54.06s
#
# 307
# Epoch duration =0.96s
# Cumulative duration =4min 55.01999999999998s
#
# 308
# Epoch duration =0.97s
# Cumulative duration =4min 55.98000000000002s
#
# 309
# Epoch duration =0.96s
# Cumulative duration =4min 56.94999999999999s
#
# 310
# Epoch duration =0.98s
# Cumulative duration =4min 57.920000000000016s
#
# 311
# Epoch duration =0.95s
# Cumulative duration =4min 58.879999999999995s
#
# 312
# Epoch duration =0.95s
# Cumulative duration =4min 59.829999999999984s
#
# 313
# Epoch duration =0.95s
# Cumulative duration =5min 0.7799999999999727s
#
# 314
# Epoch duration =0.96s
# Cumulative duration =5min 1.740000000000009s
#
# 315
# Epoch duration =0.95s
# Cumulative duration =5min 2.6899999999999977s
#
# 316
# Epoch duration =0.96s
# Cumulative duration =5min 3.6499999999999773s
#
# 317
# Epoch duration =0.94s
# Cumulative duration =5min 4.589999999999975s
#
# 318
# Epoch duration =0.96s
# Cumulative duration =5min 5.550000000000011s
#
# 319
# Epoch duration =0.96s
# Cumulative duration =5min 6.509999999999991s
#
# 320
# Epoch duration =0.98s
# Cumulative duration =5min 7.490000000000009s
#
# 321
# Epoch duration =0.98s
# Cumulative duration =5min 8.470000000000027s
#
# 322
# Epoch duration =0.95s
# Cumulative duration =5min 9.420000000000016s
#
# 323
# Epoch duration =0.96s
# Cumulative duration =5min 10.379999999999995s
#
# 324
# Epoch duration =0.96s
# Cumulative duration =5min 11.339999999999975s
#
# 325
# Epoch duration =0.96s
# Cumulative duration =5min 12.300000000000011s
#
# 326
# Epoch duration =0.96s
# Cumulative duration =5min 13.259999999999991s
#
# 327
# Epoch duration =0.96s
# Cumulative duration =5min 14.220000000000027s
#
# 328
# Epoch duration =0.97s
# Cumulative duration =5min 15.189999999999998s
#
# 329
# Epoch duration =0.96s
# Cumulative duration =5min 16.149999999999977s
#
# 330
# Epoch duration =0.96s
# Cumulative duration =5min 17.110000000000014s
#
# 331
# Epoch duration =0.95s
# Cumulative duration =5min 18.069999999999993s
#
# 332
# Epoch duration =0.96s
# Cumulative duration =5min 19.019999999999982s
#
# 333
# Epoch duration =0.95s
# Cumulative duration =5min 19.980000000000018s
#
# 334
# Epoch duration =0.95s
# Cumulative duration =5min 20.930000000000007s
#
# 335
# Epoch duration =0.96s
# Cumulative duration =5min 21.879999999999995s
#
# 336
# Epoch duration =0.96s
# Cumulative duration =5min 22.839999999999975s
#
# 337
# Epoch duration =0.95s
# Cumulative duration =5min 23.79000000000002s
#
# 338
# Epoch duration =0.95s
# Cumulative duration =5min 24.74000000000001s
#
# 339
# Epoch duration =0.96s
# Cumulative duration =5min 25.69999999999999s
#
# 340
# Epoch duration =0.95s
# Cumulative duration =5min 26.649999999999977s
#
# 341
# Epoch duration =0.96s
# Cumulative duration =5min 27.610000000000014s
#
# 342
# Epoch duration =0.95s
# Cumulative duration =5min 28.560000000000002s
#
# 343
# Epoch duration =0.95s
# Cumulative duration =5min 29.50999999999999s
#
# 344
# Epoch duration =0.95s
# Cumulative duration =5min 30.45999999999998s
#
# 345
# Epoch duration =0.96s
# Cumulative duration =5min 31.420000000000016s
#
# 346
# Epoch duration =0.95s
# Cumulative duration =5min 32.370000000000005s
#
# 347
# Epoch duration =0.98s
# Cumulative duration =5min 33.35000000000002s
#
# 348
# Epoch duration =0.96s
# Cumulative duration =5min 34.30000000000001s
#
# 349
# Epoch duration =0.97s
# Cumulative duration =5min 35.26999999999998s
#
# 350
# Epoch duration =0.97s
# Cumulative duration =5min 36.24000000000001s
#
# 351
# Epoch duration =0.95s
# Cumulative duration =5min 37.19s
#
# 352
# Epoch duration =0.96s
# Cumulative duration =5min 38.14999999999998s
#
# 353
# Epoch duration =0.96s
# Cumulative duration =5min 39.120000000000005s
#
# 354
# Epoch duration =0.96s
# Cumulative duration =5min 40.079999999999984s
#
# 355
# Epoch duration =0.95s
# Cumulative duration =5min 41.04000000000002s
#
# 356
# Epoch duration =0.95s
# Cumulative duration =5min 41.99000000000001s
#
# 357
# Epoch duration =0.95s
# Cumulative duration =5min 42.94s
#
# 358
# Epoch duration =0.96s
# Cumulative duration =5min 43.89999999999998s
#
# 359
# Epoch duration =0.95s
# Cumulative duration =5min 44.85000000000002s
#
# 360
# Epoch duration =0.96s
# Cumulative duration =5min 45.81s
#
# 361
# Epoch duration =0.95s
# Cumulative duration =5min 46.75999999999999s
#
# 362
# Epoch duration =0.95s
# Cumulative duration =5min 47.70999999999998s
#
# 363
# Epoch duration =0.97s
# Cumulative duration =5min 48.68000000000001s
#
# 364
# Epoch duration =0.95s
# Cumulative duration =5min 49.629999999999995s
#
# 365
# Epoch duration =0.95s
# Cumulative duration =5min 50.579999999999984s
#
# 366
# Epoch duration =0.96s
# Cumulative duration =5min 51.55000000000001s
#
# 367
# Epoch duration =0.97s
# Cumulative duration =5min 52.51999999999998s
#
# 368
# Epoch duration =0.95s
# Cumulative duration =5min 53.47000000000003s
#
# 369
# Epoch duration =0.95s
# Cumulative duration =5min 54.43000000000001s
#
# 370
# Epoch duration =0.95s
# Cumulative duration =5min 55.370000000000005s
#
# 371
# Epoch duration =0.95s
# Cumulative duration =5min 56.329999999999984s
#
# 372
# Epoch duration =0.96s
# Cumulative duration =5min 57.29000000000002s
#
# 373
# Epoch duration =0.95s
# Cumulative duration =5min 58.25s
#
# 374
# Epoch duration =0.97s
# Cumulative duration =5min 59.20999999999998s
#
# 375
# Epoch duration =0.98s
# Cumulative duration =6min 0.18999999999999773s
#
# 376
# Epoch duration =0.95s
# Cumulative duration =6min 1.1399999999999864s
#
# 377
# Epoch duration =0.95s
# Cumulative duration =6min 2.089999999999975s
#
# 378
# Epoch duration =0.94s
# Cumulative duration =6min 3.0299999999999727s
#
# 379
# Epoch duration =0.95s
# Cumulative duration =6min 3.980000000000018s
#
# 380
# Epoch duration =0.95s
# Cumulative duration =6min 4.939999999999998s
#
# 381
# Epoch duration =0.95s
# Cumulative duration =6min 5.889999999999986s
#
# 382
# Epoch duration =0.96s
# Cumulative duration =6min 6.850000000000023s
#
# 383
# Epoch duration =0.95s
# Cumulative duration =6min 7.800000000000011s
#
# 384
# Epoch duration =0.96s
# Cumulative duration =6min 8.759999999999991s
#
# 385
# Epoch duration =0.95s
# Cumulative duration =6min 9.70999999999998s
#
# 386
# Epoch duration =0.95s
# Cumulative duration =6min 10.660000000000025s
#
# 387
# Epoch duration =0.94s
# Cumulative duration =6min 11.600000000000023s
#
# 388
# Epoch duration =0.97s
# Cumulative duration =6min 12.569999999999993s
#
# 389
# Epoch duration =0.95s
# Cumulative duration =6min 13.529999999999973s
#
# 390
# Epoch duration =0.95s
# Cumulative duration =6min 14.470000000000027s
#
# 391
# Epoch duration =0.95s
# Cumulative duration =6min 15.420000000000016s
#
# 392
# Epoch duration =0.95s
# Cumulative duration =6min 16.370000000000005s
#
# 393
# Epoch duration =1.0s
# Cumulative duration =6min 17.360000000000014s
#
# 394
# Epoch duration =0.96s
# Cumulative duration =6min 18.319999999999993s
#
# 395
# Epoch duration =1.0s
# Cumulative duration =6min 19.319999999999993s
#
# 396
# Epoch duration =0.95s
# Cumulative duration =6min 20.269999999999982s
#
# 397
# Epoch duration =0.95s
# Cumulative duration =6min 21.230000000000018s
#
# 398
# Epoch duration =0.95s
# Cumulative duration =6min 22.180000000000007s
#
# 399
# Epoch duration =0.96s
# Cumulative duration =6min 23.139999999999986s
#
# 400
# Epoch duration =0.96s
# Cumulative duration =6min 24.100000000000023s
#
# 401
# Epoch duration =0.97s
# Cumulative duration =6min 25.069999999999993s
#
# 402
# Epoch duration =0.95s
# Cumulative duration =6min 26.019999999999982s
#
# 403
# Epoch duration =0.95s
# Cumulative duration =6min 26.980000000000018s
#
# 404
# Epoch duration =0.97s
# Cumulative duration =6min 27.939999999999998s
#
# 405
# Epoch duration =0.96s
# Cumulative duration =6min 28.899999999999977s
#
# 406
# Epoch duration =0.95s
# Cumulative duration =6min 29.850000000000023s
#
# 407
# Epoch duration =0.95s
# Cumulative duration =6min 30.80000000000001s
#
# 408
# Epoch duration =0.95s
# Cumulative duration =6min 31.74000000000001s
#
# 409
# Epoch duration =0.94s
# Cumulative duration =6min 32.68000000000001s
#
# 410
# Epoch duration =0.96s
# Cumulative duration =6min 33.639999999999986s
#
# 411
# Epoch duration =0.94s
# Cumulative duration =6min 34.589999999999975s
#
# 412
# Epoch duration =0.97s
# Cumulative duration =6min 35.56s
#
# 413
# Epoch duration =0.96s
# Cumulative duration =6min 36.51999999999998s
#
# 414
# Epoch duration =0.94s
# Cumulative duration =6min 37.45999999999998s
#
# 415
# Epoch duration =0.96s
# Cumulative duration =6min 38.420000000000016s
#
# 416
# Epoch duration =0.97s
# Cumulative duration =6min 39.389999999999986s
#
# 417
# Epoch duration =0.97s
# Cumulative duration =6min 40.360000000000014s
#
# 418
# Epoch duration =0.98s
# Cumulative duration =6min 41.339999999999975s
#
# 419
# Epoch duration =0.96s
# Cumulative duration =6min 42.31s
#
# 420
# Epoch duration =0.95s
# Cumulative duration =6min 43.25999999999999s
#
# 421
# Epoch duration =0.97s
# Cumulative duration =6min 44.23000000000002s
#
# 422
# Epoch duration =0.95s
# Cumulative duration =6min 45.18000000000001s
#
# 423
# Epoch duration =0.96s
# Cumulative duration =6min 46.139999999999986s
#
# 424
# Epoch duration =0.95s
# Cumulative duration =6min 47.089999999999975s
#
# 425
# Epoch duration =0.96s
# Cumulative duration =6min 48.06s
#
# 426
# Epoch duration =0.94s
# Cumulative duration =6min 49.0s
#
# 427
# Epoch duration =0.95s
# Cumulative duration =6min 49.94999999999999s
#
# 428
# Epoch duration =0.95s
# Cumulative duration =6min 50.89999999999998s
#
# 429
# Epoch duration =0.95s
# Cumulative duration =6min 51.85000000000002s
#
# 430
# Epoch duration =0.97s
# Cumulative duration =6min 52.81999999999999s
#
# 431
# Epoch duration =0.98s
# Cumulative duration =6min 53.80000000000001s
#
# 432
# Epoch duration =0.96s
# Cumulative duration =6min 54.75999999999999s
#
# 433
# Epoch duration =0.96s
# Cumulative duration =6min 55.72000000000003s
#
# 434
# Epoch duration =0.96s
# Cumulative duration =6min 56.68000000000001s
#
# 435
# Epoch duration =0.97s
# Cumulative duration =6min 57.64999999999998s
#
# 436
# Epoch duration =0.95s
# Cumulative duration =6min 58.60000000000002s
#
# 437
# Epoch duration =0.95s
# Cumulative duration =6min 59.54000000000002s
#
# 438
# Epoch duration =0.95s
# Cumulative duration =7min 0.5s
#
# 439
# Epoch duration =0.96s
# Cumulative duration =7min 1.4599999999999795s
#
# 440
# Epoch duration =0.97s
# Cumulative duration =7min 2.430000000000007s
#
# 441
# Epoch duration =1.0s
# Cumulative duration =7min 3.430000000000007s
#
# 442
# Epoch duration =0.96s
# Cumulative duration =7min 4.389999999999986s
#
# 443
# Epoch duration =0.98s
# Cumulative duration =7min 5.3700000000000045s
#
# 444
# Epoch duration =0.95s
# Cumulative duration =7min 6.310000000000002s
#
# 445
# Epoch duration =0.99s
# Cumulative duration =7min 7.300000000000011s
#
# 446
# Epoch duration =0.95s
# Cumulative duration =7min 8.25s
#
# 447
# Epoch duration =0.94s
# Cumulative duration =7min 9.189999999999998s
#
# 448
# Epoch duration =0.94s
# Cumulative duration =7min 10.139999999999986s
#
# 449
# Epoch duration =0.97s
# Cumulative duration =7min 11.110000000000014s
#
# 450
# Epoch duration =0.96s
# Cumulative duration =7min 12.069999999999993s
#
# 451
# Epoch duration =0.95s
# Cumulative duration =7min 13.029999999999973s
#
# 452
# Epoch duration =0.94s
# Cumulative duration =7min 13.970000000000027s
#
# 453
# Epoch duration =0.95s
# Cumulative duration =7min 14.920000000000016s
#
# 454
# Epoch duration =0.95s
# Cumulative duration =7min 15.879999999999995s
#
# 455
# Epoch duration =0.95s
# Cumulative duration =7min 16.829999999999984s
#
# 456
# Epoch duration =0.95s
# Cumulative duration =7min 17.769999999999982s
#
# 457
# Epoch duration =0.96s
# Cumulative duration =7min 18.730000000000018s
#
# 458
# Epoch duration =0.95s
# Cumulative duration =7min 19.680000000000007s
#
# 459
# Epoch duration =0.95s
# Cumulative duration =7min 20.639999999999986s
#
# 460
# Epoch duration =0.96s
# Cumulative duration =7min 21.600000000000023s
#
# 461
# Epoch duration =0.96s
# Cumulative duration =7min 22.560000000000002s
#
# 462
# Epoch duration =1.0s
# Cumulative duration =7min 23.560000000000002s
#
# 463
# Epoch duration =0.95s
# Cumulative duration =7min 24.50999999999999s
#
# 464
# Epoch duration =0.96s
# Cumulative duration =7min 25.470000000000027s
#
# 465
# Epoch duration =0.95s
# Cumulative duration =7min 26.420000000000016s
#
# 466
# Epoch duration =0.95s
# Cumulative duration =7min 27.370000000000005s
#
# 467
# Epoch duration =0.95s
# Cumulative duration =7min 28.319999999999993s
#
# 468
# Epoch duration =0.98s
# Cumulative duration =7min 29.30000000000001s
#
# 469
# Epoch duration =0.96s
# Cumulative duration =7min 30.25999999999999s
#
# 470
# Epoch duration =0.98s
# Cumulative duration =7min 31.230000000000018s
#
# 471
# Epoch duration =0.95s
# Cumulative duration =7min 32.18000000000001s
#
# 472
# Epoch duration =0.96s
# Cumulative duration =7min 33.139999999999986s
#
# 473
# Epoch duration =0.95s
# Cumulative duration =7min 34.089999999999975s
#
# 474
# Epoch duration =0.99s
# Cumulative duration =7min 35.079999999999984s
#
# 475
# Epoch duration =1.0s
# Cumulative duration =7min 36.079999999999984s
#
# 476
# Epoch duration =0.95s
# Cumulative duration =7min 37.01999999999998s
#
# 477
# Epoch duration =0.98s
# Cumulative duration =7min 38.0s
#
# 478
# Epoch duration =0.96s
# Cumulative duration =7min 38.95999999999998s
#
# 479
# Epoch duration =0.95s
# Cumulative duration =7min 39.89999999999998s
#
# 480
# Epoch duration =0.95s
# Cumulative duration =7min 40.85000000000002s
#
# 481
# Epoch duration =0.95s
# Cumulative duration =7min 41.80000000000001s
#
# 482
# Epoch duration =0.95s
# Cumulative duration =7min 42.75s
#
# 483
# Epoch duration =0.95s
# Cumulative duration =7min 43.69999999999999s
#
# 484
# Epoch duration =0.97s
# Cumulative duration =7min 44.670000000000016s
#
# 485
# Epoch duration =0.98s
# Cumulative duration =7min 45.64999999999998s
#
# 486
# Epoch duration =0.96s
# Cumulative duration =7min 46.610000000000014s
#
# 487
# Epoch duration =0.95s
# Cumulative duration =7min 47.56s
#
# 488
# Epoch duration =0.96s
# Cumulative duration =7min 48.50999999999999s
#
# 489
# Epoch duration =0.96s
# Cumulative duration =7min 49.47000000000003s
#
# 490
# Epoch duration =0.96s
# Cumulative duration =7min 50.43000000000001s
#
# 491
# Epoch duration =0.95s
# Cumulative duration =7min 51.389999999999986s
#
# 492
# Epoch duration =0.95s
# Cumulative duration =7min 52.329999999999984s
#
# 493
# Epoch duration =0.95s
# Cumulative duration =7min 53.29000000000002s
#
# 494
# Epoch duration =0.95s
# Cumulative duration =7min 54.23000000000002s
#
# 495
# Epoch duration =0.98s
# Cumulative duration =7min 55.20999999999998s
#
# 496
# Epoch duration =0.96s
# Cumulative duration =7min 56.170000000000016s
#
# 497
# Epoch duration =0.97s
# Cumulative duration =7min 57.139999999999986s
#
# 498
# Epoch duration =0.95s
# Cumulative duration =7min 58.089999999999975s
#
# 499
# Epoch duration =0.97s
# Cumulative duration =7min 59.05000000000001s
#
# Saving scores to Arrays/glna_mlpt1_44_ug_so500.npy

# %%
#load values
savepath = 'Arrays/glna_mlpt1_44_ug_so500.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 500
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, vmax=1.0, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
