# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/glna_100k_d8.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 10.83s

# %%
simalign_file = '../../../data_RFAM/glnAsim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<<>>>>>>><<<<>>>>)))))'

# %%
ugSS
# Out:
# '::(((((,<<<<<<<_____>>>>>>>,,,,,,,,<<<<_____>>>>,,,,)))))::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/glnA'
param_path = os.path.join(save_path, 'mlp_t2_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 893, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.25015 -- acc=89.950005%
#
#   valid loss:		0.04019
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.08435 -- acc=97.489179%
#
#   valid loss:		0.05122
#   valid accuracy:	0.98575+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.06119 -- acc=98.260006%
#
#   valid loss:		0.01362
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.05443 -- acc=98.512501%
#
#   valid loss:		0.01887
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.81s -- loss=0.04590 -- acc=98.792509%
#
#   valid loss:		0.01170
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.04448 -- acc=98.839174%
#
#   valid loss:		0.01268
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.04368 -- acc=98.925003%
#
#   valid loss:		0.01204
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.55s -- loss=0.04140 -- acc=98.999170%
#
#   valid loss:		0.01226
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.56s -- loss=0.03861 -- acc=99.080008%
#
#   valid loss:		0.01144
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.03732 -- acc=99.105831%
#
#   valid loss:		0.01223
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.03643 -- acc=99.136674%
#
#   valid loss:		0.01100
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.03674 -- acc=99.190839%
#
#   valid loss:		0.01096
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/glnA/mlp_t2_44_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.03726 -- acc=99.153335%
#
#   valid loss:		0.01248
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.03469 -- acc=99.253335%
#
#   valid loss:		0.01441
#   valid accuracy:	0.99870+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.03703 -- acc=99.115832%
#
#   valid loss:		0.01486
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.03514 -- acc=99.232503%
#
#   valid loss:		0.01345
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.03478 -- acc=99.205001%
#
#   valid loss:		0.01310
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.03418 -- acc=99.260836%
#
#   valid loss:		0.01219
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.03388 -- acc=99.278338%
#
#   valid loss:		0.01580
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.03525 -- acc=99.240834%
#
#   valid loss:		0.01835
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03399 -- acc=99.305831%
#
#   valid loss:		0.01530
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03441 -- acc=99.261676%
#
#   valid loss:		0.01483
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03312 -- acc=99.320002%
#
#   valid loss:		0.01504
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03324 -- acc=99.305001%
#
#   valid loss:		0.01443
#   valid accuracy:	0.99895+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.85s -- loss=0.03314 -- acc=99.310831%
#
#   valid loss:		0.01293
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.03331 -- acc=99.320002%
#
#   valid loss:		0.01269
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.03301 -- acc=99.303330%
#
#   valid loss:		0.01347
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=4.08s -- loss=0.03415 -- acc=99.278338%
#
#   valid loss:		0.01297
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.03315 -- acc=99.341674%
#
#   valid loss:		0.01323
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.03273 -- acc=99.322502%
#
#   valid loss:		0.01259
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.03218 -- acc=99.330833%
#
#   valid loss:		0.01287
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.03303 -- acc=99.315832%
#
#   valid loss:		0.01350
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.03293 -- acc=99.326673%
#
#   valid loss:		0.01499
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.03354 -- acc=99.319172%
#
#   valid loss:		0.01264
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.03260 -- acc=99.343334%
#
#   valid loss:		0.01353
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.03251 -- acc=99.335834%
#
#   valid loss:		0.01418
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.03216 -- acc=99.367507%
#
#   valid loss:		0.01313
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.03339 -- acc=99.313331%
#
#   valid loss:		0.01739
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.03215 -- acc=99.395000%
#
#   valid loss:		0.01268
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.03354 -- acc=99.322502%
#
#   valid loss:		0.01296
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.03262 -- acc=99.374177%
#
#   valid loss:		0.01309
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.03145 -- acc=99.389179%
#
#   valid loss:		0.01301
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.03314 -- acc=99.337504%
#
#   valid loss:		0.01335
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.03355 -- acc=99.309171%
#
#   valid loss:		0.01274
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.03314 -- acc=99.328333%
#
#   valid loss:		0.01487
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.03282 -- acc=99.338334%
#
#   valid loss:		0.01343
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.03280 -- acc=99.339174%
#
#   valid loss:		0.01340
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.03168 -- acc=99.390839%
#
#   valid loss:		0.01284
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.03132 -- acc=99.385839%
#
#   valid loss:		0.01248
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.03027 -- acc=99.403330%
#
#   valid loss:		0.01268
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=3.84s -- loss=0.03194 -- acc=99.392509%
#
#   valid loss:		0.01613
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=3.89s -- loss=0.03226 -- acc=99.375008%
#
#   valid loss:		0.01415
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/glnA/mlp_t2_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/glnA/mlp_t2_44_best.ckpt
#   test  loss:		0.01050
#   test  accuracy:	0.99973+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/glna_mlpt2_44_ug_so500.npy'

num_summary = 500
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='off', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =1.04s
# Cumulative duration =1.04s
#
# 1
# Epoch duration =1.05s
# Cumulative duration =2.09s
#
# 2
# Epoch duration =1.06s
# Cumulative duration =3.15s
#
# 3
# Epoch duration =1.07s
# Cumulative duration =4.23s
#
# 4
# Epoch duration =1.06s
# Cumulative duration =5.29s
#
# 5
# Epoch duration =1.03s
# Cumulative duration =6.31s
#
# 6
# Epoch duration =1.03s
# Cumulative duration =7.35s
#
# 7
# Epoch duration =1.03s
# Cumulative duration =8.38s
#
# 8
# Epoch duration =1.03s
# Cumulative duration =9.41s
#
# 9
# Epoch duration =1.03s
# Cumulative duration =10.44s
#
# 10
# Epoch duration =1.04s
# Cumulative duration =11.48s
#
# 11
# Epoch duration =1.03s
# Cumulative duration =12.51s
#
# 12
# Epoch duration =1.03s
# Cumulative duration =13.54s
#
# 13
# Epoch duration =1.04s
# Cumulative duration =14.58s
#
# 14
# Epoch duration =1.06s
# Cumulative duration =15.64s
#
# 15
# Epoch duration =1.03s
# Cumulative duration =16.67s
#
# 16
# Epoch duration =1.04s
# Cumulative duration =17.71s
#
# 17
# Epoch duration =1.04s
# Cumulative duration =18.74s
#
# 18
# Epoch duration =1.03s
# Cumulative duration =19.77s
#
# 19
# Epoch duration =1.03s
# Cumulative duration =20.8s
#
# 20
# Epoch duration =1.02s
# Cumulative duration =21.83s
#
# 21
# Epoch duration =1.04s
# Cumulative duration =22.86s
#
# 22
# Epoch duration =1.04s
# Cumulative duration =23.91s
#
# 23
# Epoch duration =1.03s
# Cumulative duration =24.94s
#
# 24
# Epoch duration =1.04s
# Cumulative duration =25.98s
#
# 25
# Epoch duration =1.02s
# Cumulative duration =27.0s
#
# 26
# Epoch duration =1.04s
# Cumulative duration =28.04s
#
# 27
# Epoch duration =1.04s
# Cumulative duration =29.08s
#
# 28
# Epoch duration =1.04s
# Cumulative duration =30.12s
#
# 29
# Epoch duration =1.03s
# Cumulative duration =31.15s
#
# 30
# Epoch duration =1.03s
# Cumulative duration =32.19s
#
# 31
# Epoch duration =1.03s
# Cumulative duration =33.22s
#
# 32
# Epoch duration =1.03s
# Cumulative duration =34.25s
#
# 33
# Epoch duration =1.02s
# Cumulative duration =35.27s
#
# 34
# Epoch duration =1.03s
# Cumulative duration =36.31s
#
# 35
# Epoch duration =1.03s
# Cumulative duration =37.34s
#
# 36
# Epoch duration =1.03s
# Cumulative duration =38.37s
#
# 37
# Epoch duration =1.03s
# Cumulative duration =39.39s
#
# 38
# Epoch duration =1.04s
# Cumulative duration =40.43s
#
# 39
# Epoch duration =1.07s
# Cumulative duration =41.5s
#
# 40
# Epoch duration =1.03s
# Cumulative duration =42.53s
#
# 41
# Epoch duration =1.03s
# Cumulative duration =43.56s
#
# 42
# Epoch duration =1.07s
# Cumulative duration =44.63s
#
# 43
# Epoch duration =1.03s
# Cumulative duration =45.66s
#
# 44
# Epoch duration =1.03s
# Cumulative duration =46.69s
#
# 45
# Epoch duration =1.07s
# Cumulative duration =47.76s
#
# 46
# Epoch duration =1.03s
# Cumulative duration =48.79s
#
# 47
# Epoch duration =1.03s
# Cumulative duration =49.83s
#
# 48
# Epoch duration =1.04s
# Cumulative duration =50.87s
#
# 49
# Epoch duration =1.03s
# Cumulative duration =51.9s
#
# 50
# Epoch duration =1.07s
# Cumulative duration =52.97s
#
# 51
# Epoch duration =1.03s
# Cumulative duration =54.0s
#
# 52
# Epoch duration =1.02s
# Cumulative duration =55.02s
#
# 53
# Epoch duration =1.03s
# Cumulative duration =56.05s
#
# 54
# Epoch duration =1.04s
# Cumulative duration =57.09s
#
# 55
# Epoch duration =1.04s
# Cumulative duration =58.13s
#
# 56
# Epoch duration =1.13s
# Cumulative duration =59.27s
#
# 57
# Epoch duration =1.15s
# Cumulative duration =1min 0.4200000000000017s
#
# 58
# Epoch duration =0.99s
# Cumulative duration =1min 1.4099999999999966s
#
# 59
# Epoch duration =0.99s
# Cumulative duration =1min 2.3999999999999986s
#
# 60
# Epoch duration =0.98s
# Cumulative duration =1min 3.3800000000000026s
#
# 61
# Epoch duration =0.99s
# Cumulative duration =1min 4.359999999999999s
#
# 62
# Epoch duration =1.0s
# Cumulative duration =1min 5.3700000000000045s
#
# 63
# Epoch duration =1.0s
# Cumulative duration =1min 6.3700000000000045s
#
# 64
# Epoch duration =0.99s
# Cumulative duration =1min 7.349999999999994s
#
# 65
# Epoch duration =0.99s
# Cumulative duration =1min 8.340000000000003s
#
# 66
# Epoch duration =1.05s
# Cumulative duration =1min 9.39s
#
# 67
# Epoch duration =0.99s
# Cumulative duration =1min 10.379999999999995s
#
# 68
# Epoch duration =1.01s
# Cumulative duration =1min 11.39s
#
# 69
# Epoch duration =1.0s
# Cumulative duration =1min 12.39s
#
# 70
# Epoch duration =0.99s
# Cumulative duration =1min 13.379999999999995s
#
# 71
# Epoch duration =1.0s
# Cumulative duration =1min 14.370000000000005s
#
# 72
# Epoch duration =1.0s
# Cumulative duration =1min 15.379999999999995s
#
# 73
# Epoch duration =0.99s
# Cumulative duration =1min 16.36s
#
# 74
# Epoch duration =0.98s
# Cumulative duration =1min 17.340000000000003s
#
# 75
# Epoch duration =0.99s
# Cumulative duration =1min 18.340000000000003s
#
# 76
# Epoch duration =1.01s
# Cumulative duration =1min 19.349999999999994s
#
# 77
# Epoch duration =0.99s
# Cumulative duration =1min 20.340000000000003s
#
# 78
# Epoch duration =1.0s
# Cumulative duration =1min 21.340000000000003s
#
# 79
# Epoch duration =0.99s
# Cumulative duration =1min 22.33s
#
# 80
# Epoch duration =0.99s
# Cumulative duration =1min 23.319999999999993s
#
# 81
# Epoch duration =0.99s
# Cumulative duration =1min 24.310000000000002s
#
# 82
# Epoch duration =0.99s
# Cumulative duration =1min 25.299999999999997s
#
# 83
# Epoch duration =1.0s
# Cumulative duration =1min 26.299999999999997s
#
# 84
# Epoch duration =0.99s
# Cumulative duration =1min 27.290000000000006s
#
# 85
# Epoch duration =1.0s
# Cumulative duration =1min 28.28s
#
# 86
# Epoch duration =0.99s
# Cumulative duration =1min 29.28s
#
# 87
# Epoch duration =0.99s
# Cumulative duration =1min 30.269999999999996s
#
# 88
# Epoch duration =0.99s
# Cumulative duration =1min 31.260000000000005s
#
# 89
# Epoch duration =1.07s
# Cumulative duration =1min 32.33s
#
# 90
# Epoch duration =1.09s
# Cumulative duration =1min 33.42s
#
# 91
# Epoch duration =1.03s
# Cumulative duration =1min 34.45s
#
# 92
# Epoch duration =1.09s
# Cumulative duration =1min 35.540000000000006s
#
# 93
# Epoch duration =1.14s
# Cumulative duration =1min 36.69s
#
# 94
# Epoch duration =1.05s
# Cumulative duration =1min 37.739999999999995s
#
# 95
# Epoch duration =1.05s
# Cumulative duration =1min 38.790000000000006s
#
# 96
# Epoch duration =1.04s
# Cumulative duration =1min 39.83s
#
# 97
# Epoch duration =1.07s
# Cumulative duration =1min 40.900000000000006s
#
# 98
# Epoch duration =1.03s
# Cumulative duration =1min 41.93000000000001s
#
# 99
# Epoch duration =1.05s
# Cumulative duration =1min 42.989999999999995s
#
# 100
# Epoch duration =1.1s
# Cumulative duration =1min 44.08s
#
# 101
# Epoch duration =1.16s
# Cumulative duration =1min 45.239999999999995s
#
# 102
# Epoch duration =1.18s
# Cumulative duration =1min 46.42s
#
# 103
# Epoch duration =1.22s
# Cumulative duration =1min 47.64s
#
# 104
# Epoch duration =1.17s
# Cumulative duration =1min 48.81s
#
# 105
# Epoch duration =1.05s
# Cumulative duration =1min 49.86s
#
# 106
# Epoch duration =1.05s
# Cumulative duration =1min 50.91s
#
# 107
# Epoch duration =1.17s
# Cumulative duration =1min 52.06999999999999s
#
# 108
# Epoch duration =1.15s
# Cumulative duration =1min 53.230000000000004s
#
# 109
# Epoch duration =1.06s
# Cumulative duration =1min 54.28s
#
# 110
# Epoch duration =1.06s
# Cumulative duration =1min 55.34s
#
# 111
# Epoch duration =1.04s
# Cumulative duration =1min 56.379999999999995s
#
# 112
# Epoch duration =1.03s
# Cumulative duration =1min 57.41s
#
# 113
# Epoch duration =1.05s
# Cumulative duration =1min 58.459999999999994s
#
# 114
# Epoch duration =1.03s
# Cumulative duration =1min 59.489999999999995s
#
# 115
# Epoch duration =1.04s
# Cumulative duration =2min 0.5300000000000011s
#
# 116
# Epoch duration =1.04s
# Cumulative duration =2min 1.5699999999999932s
#
# 117
# Epoch duration =1.05s
# Cumulative duration =2min 2.6200000000000045s
#
# 118
# Epoch duration =1.04s
# Cumulative duration =2min 3.6599999999999966s
#
# 119
# Epoch duration =1.05s
# Cumulative duration =2min 4.700000000000003s
#
# 120
# Epoch duration =1.03s
# Cumulative duration =2min 5.730000000000004s
#
# 121
# Epoch duration =1.03s
# Cumulative duration =2min 6.769999999999996s
#
# 122
# Epoch duration =1.07s
# Cumulative duration =2min 7.840000000000003s
#
# 123
# Epoch duration =1.04s
# Cumulative duration =2min 8.879999999999995s
#
# 124
# Epoch duration =1.03s
# Cumulative duration =2min 9.909999999999997s
#
# 125
# Epoch duration =1.03s
# Cumulative duration =2min 10.939999999999998s
#
# 126
# Epoch duration =1.04s
# Cumulative duration =2min 11.97999999999999s
#
# 127
# Epoch duration =1.08s
# Cumulative duration =2min 13.060000000000002s
#
# 128
# Epoch duration =1.03s
# Cumulative duration =2min 14.090000000000003s
#
# 129
# Epoch duration =1.03s
# Cumulative duration =2min 15.120000000000005s
#
# 130
# Epoch duration =1.03s
# Cumulative duration =2min 16.150000000000006s
#
# 131
# Epoch duration =1.04s
# Cumulative duration =2min 17.189999999999998s
#
# 132
# Epoch duration =1.03s
# Cumulative duration =2min 18.210000000000008s
#
# 133
# Epoch duration =1.03s
# Cumulative duration =2min 19.24000000000001s
#
# 134
# Epoch duration =1.04s
# Cumulative duration =2min 20.28s
#
# 135
# Epoch duration =1.07s
# Cumulative duration =2min 21.349999999999994s
#
# 136
# Epoch duration =1.05s
# Cumulative duration =2min 22.409999999999997s
#
# 137
# Epoch duration =1.05s
# Cumulative duration =2min 23.460000000000008s
#
# 138
# Epoch duration =1.04s
# Cumulative duration =2min 24.5s
#
# 139
# Epoch duration =1.07s
# Cumulative duration =2min 25.580000000000013s
#
# 140
# Epoch duration =1.06s
# Cumulative duration =2min 26.639999999999986s
#
# 141
# Epoch duration =1.05s
# Cumulative duration =2min 27.689999999999998s
#
# 142
# Epoch duration =1.04s
# Cumulative duration =2min 28.72999999999999s
#
# 143
# Epoch duration =1.08s
# Cumulative duration =2min 29.810000000000002s
#
# 144
# Epoch duration =1.04s
# Cumulative duration =2min 30.860000000000014s
#
# 145
# Epoch duration =1.03s
# Cumulative duration =2min 31.889999999999986s
#
# 146
# Epoch duration =1.03s
# Cumulative duration =2min 32.93000000000001s
#
# 147
# Epoch duration =1.03s
# Cumulative duration =2min 33.96000000000001s
#
# 148
# Epoch duration =1.04s
# Cumulative duration =2min 35.0s
#
# 149
# Epoch duration =1.1s
# Cumulative duration =2min 36.099999999999994s
#
# 150
# Epoch duration =1.03s
# Cumulative duration =2min 37.129999999999995s
#
# 151
# Epoch duration =1.03s
# Cumulative duration =2min 38.16s
#
# 152
# Epoch duration =1.03s
# Cumulative duration =2min 39.19999999999999s
#
# 153
# Epoch duration =1.03s
# Cumulative duration =2min 40.22999999999999s
#
# 154
# Epoch duration =1.03s
# Cumulative duration =2min 41.25999999999999s
#
# 155
# Epoch duration =1.04s
# Cumulative duration =2min 42.30000000000001s
#
# 156
# Epoch duration =1.03s
# Cumulative duration =2min 43.33000000000001s
#
# 157
# Epoch duration =1.05s
# Cumulative duration =2min 44.379999999999995s
#
# 158
# Epoch duration =1.02s
# Cumulative duration =2min 45.400000000000006s
#
# 159
# Epoch duration =1.1s
# Cumulative duration =2min 46.5s
#
# 160
# Epoch duration =1.04s
# Cumulative duration =2min 47.53999999999999s
#
# 161
# Epoch duration =1.03s
# Cumulative duration =2min 48.56s
#
# 162
# Epoch duration =1.03s
# Cumulative duration =2min 49.599999999999994s
#
# 163
# Epoch duration =1.03s
# Cumulative duration =2min 50.629999999999995s
#
# 164
# Epoch duration =1.03s
# Cumulative duration =2min 51.650000000000006s
#
# 165
# Epoch duration =1.03s
# Cumulative duration =2min 52.69s
#
# 166
# Epoch duration =1.03s
# Cumulative duration =2min 53.71000000000001s
#
# 167
# Epoch duration =1.03s
# Cumulative duration =2min 54.74000000000001s
#
# 168
# Epoch duration =1.02s
# Cumulative duration =2min 55.77000000000001s
#
# 169
# Epoch duration =1.04s
# Cumulative duration =2min 56.80000000000001s
#
# 170
# Epoch duration =1.04s
# Cumulative duration =2min 57.84s
#
# 171
# Epoch duration =1.04s
# Cumulative duration =2min 58.879999999999995s
#
# 172
# Epoch duration =1.05s
# Cumulative duration =2min 59.94s
#
# 173
# Epoch duration =1.04s
# Cumulative duration =3min 0.9799999999999898s
#
# 174
# Epoch duration =1.03s
# Cumulative duration =3min 2.009999999999991s
#
# 175
# Epoch duration =1.02s
# Cumulative duration =3min 3.030000000000001s
#
# 176
# Epoch duration =1.03s
# Cumulative duration =3min 4.060000000000002s
#
# 177
# Epoch duration =1.02s
# Cumulative duration =3min 5.090000000000003s
#
# 178
# Epoch duration =1.02s
# Cumulative duration =3min 6.110000000000014s
#
# 179
# Epoch duration =1.04s
# Cumulative duration =3min 7.150000000000006s
#
# 180
# Epoch duration =1.03s
# Cumulative duration =3min 8.180000000000007s
#
# 181
# Epoch duration =1.03s
# Cumulative duration =3min 9.210000000000008s
#
# 182
# Epoch duration =1.03s
# Cumulative duration =3min 10.25s
#
# 183
# Epoch duration =1.04s
# Cumulative duration =3min 11.289999999999992s
#
# 184
# Epoch duration =1.04s
# Cumulative duration =3min 12.330000000000013s
#
# 185
# Epoch duration =1.02s
# Cumulative duration =3min 13.349999999999994s
#
# 186
# Epoch duration =1.03s
# Cumulative duration =3min 14.379999999999995s
#
# 187
# Epoch duration =1.03s
# Cumulative duration =3min 15.409999999999997s
#
# 188
# Epoch duration =1.03s
# Cumulative duration =3min 16.439999999999998s
#
# 189
# Epoch duration =1.04s
# Cumulative duration =3min 17.47999999999999s
#
# 190
# Epoch duration =1.06s
# Cumulative duration =3min 18.539999999999992s
#
# 191
# Epoch duration =1.03s
# Cumulative duration =3min 19.569999999999993s
#
# 192
# Epoch duration =1.03s
# Cumulative duration =3min 20.599999999999994s
#
# 193
# Epoch duration =1.03s
# Cumulative duration =3min 21.629999999999995s
#
# 194
# Epoch duration =1.04s
# Cumulative duration =3min 22.659999999999997s
#
# 195
# Epoch duration =1.04s
# Cumulative duration =3min 23.69999999999999s
#
# 196
# Epoch duration =1.03s
# Cumulative duration =3min 24.74000000000001s
#
# 197
# Epoch duration =1.03s
# Cumulative duration =3min 25.77000000000001s
#
# 198
# Epoch duration =1.04s
# Cumulative duration =3min 26.80000000000001s
#
# 199
# Epoch duration =1.12s
# Cumulative duration =3min 27.919999999999987s

# %%
#load values
savepath = 'Arrays/glna_mlpt2_44_ug_so500.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 500
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, vmax=1.0, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
