# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
import time as time

# %%
# load hairpin data
data_path = '../../../data_toyhairpin/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 8,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected_1_8')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 8)
# layer3: dense_0_batch
# (?, 8)
# layer4: dense_0_active
# (?, 8)
# layer5: dense_0_dropout
# (?, 8)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.91s -- loss=0.52217 -- acc=66.426563%
#
#   valid loss:		0.22263
#   valid accuracy:	0.99758+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99897+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.78s -- loss=0.36099 -- acc=80.126563%
#
#   valid loss:		0.16467
#   valid accuracy:	0.99856+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99942+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=4.90s -- loss=0.34130 -- acc=81.171877%
#
#   valid loss:		0.13865
#   valid accuracy:	0.99821+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99941+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.32954 -- acc=81.377608%
#
#   valid loss:		0.13627
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99875+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.47s -- loss=0.32645 -- acc=81.498960%
#
#   valid loss:		0.13040
#   valid accuracy:	0.99831+/-0.00000
#   valid auc-roc:	0.99956+/-0.00000
#   valid auc-pr:		0.99869+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.36s -- loss=0.32485 -- acc=81.643754%
#
#   valid loss:		0.13212
#   valid accuracy:	0.99856+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99916+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.45s -- loss=0.32626 -- acc=81.512501%
#
#   valid loss:		0.12848
#   valid accuracy:	0.99829+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99905+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.32429 -- acc=81.629693%
#
#   valid loss:		0.12945
#   valid accuracy:	0.99848+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99922+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.53s -- loss=0.32421 -- acc=81.681258%
#
#   valid loss:		0.12613
#   valid accuracy:	0.99838+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99915+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.45s -- loss=0.32206 -- acc=81.838544%
#
#   valid loss:		0.12807
#   valid accuracy:	0.99852+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99924+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=4.37s -- loss=0.32225 -- acc=81.742714%
#
#   valid loss:		0.12789
#   valid accuracy:	0.99846+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99900+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=4.46s -- loss=0.32245 -- acc=81.851565%
#
#   valid loss:		0.12590
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99954+/-0.00000
#   valid auc-pr:		0.99865+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=4.51s -- loss=0.32323 -- acc=81.710421%
#
#   valid loss:		0.12785
#   valid accuracy:	0.99821+/-0.00000
#   valid auc-roc:	0.99953+/-0.00000
#   valid auc-pr:		0.99869+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=4.57s -- loss=0.32067 -- acc=81.955216%
#
#   valid loss:		0.12631
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99889+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.31999 -- acc=81.951045%
#
#   valid loss:		0.12624
#   valid accuracy:	0.99844+/-0.00000
#   valid auc-roc:	0.99958+/-0.00000
#   valid auc-pr:		0.99885+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=4.42s -- loss=0.32266 -- acc=81.798440%
#
#   valid loss:		0.13181
#   valid accuracy:	0.99846+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99896+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.32177 -- acc=81.913541%
#
#   valid loss:		0.12419
#   valid accuracy:	0.99852+/-0.00000
#   valid auc-roc:	0.99974+/-0.00000
#   valid auc-pr:		0.99934+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=4.56s -- loss=0.32134 -- acc=81.901560%
#
#   valid loss:		0.12890
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99972+/-0.00000
#   valid auc-pr:		0.99930+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=4.46s -- loss=0.32031 -- acc=81.998440%
#
#   valid loss:		0.12423
#   valid accuracy:	0.99844+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99913+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=4.42s -- loss=0.32090 -- acc=81.914061%
#
#   valid loss:		0.12832
#   valid accuracy:	0.99848+/-0.00000
#   valid auc-roc:	0.99958+/-0.00000
#   valid auc-pr:		0.99892+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=4.51s -- loss=0.32054 -- acc=81.889589%
#
#   valid loss:		0.12739
#   valid accuracy:	0.99838+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99917+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.32156 -- acc=81.816672%
#
#   valid loss:		0.12407
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99918+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=4.57s -- loss=0.32196 -- acc=81.890109%
#
#   valid loss:		0.12740
#   valid accuracy:	0.99846+/-0.00000
#   valid auc-roc:	0.99965+/-0.00000
#   valid auc-pr:		0.99912+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=4.70s -- loss=0.32053 -- acc=82.015102%
#
#   valid loss:		0.12441
#   valid accuracy:	0.99838+/-0.00000
#   valid auc-roc:	0.99957+/-0.00000
#   valid auc-pr:		0.99889+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=4.55s -- loss=0.32003 -- acc=82.056776%
#
#   valid loss:		0.12549
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99923+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.31998 -- acc=82.055216%
#
#   valid loss:		0.12434
#   valid accuracy:	0.99848+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99903+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=4.57s -- loss=0.32027 -- acc=82.015622%
#
#   valid loss:		0.12593
#   valid accuracy:	0.99873+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99927+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=4.54s -- loss=0.31686 -- acc=82.275528%
#
#   valid loss:		0.12264
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99907+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=4.77s -- loss=0.32024 -- acc=82.086989%
#
#   valid loss:		0.12803
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99922+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=4.91s -- loss=0.32075 -- acc=81.979178%
#
#   valid loss:		0.12914
#   valid accuracy:	0.99852+/-0.00000
#   valid auc-roc:	0.99961+/-0.00000
#   valid auc-pr:		0.99903+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=4.48s -- loss=0.31892 -- acc=82.169797%
#
#   valid loss:		0.12770
#   valid accuracy:	0.99846+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99927+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.31865 -- acc=82.165627%
#
#   valid loss:		0.12503
#   valid accuracy:	0.99871+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99897+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.31881 -- acc=82.169797%
#
#   valid loss:		0.12536
#   valid accuracy:	0.99887+/-0.00000
#   valid auc-roc:	0.99972+/-0.00000
#   valid auc-pr:		0.99911+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=4.87s -- loss=0.31869 -- acc=82.193239%
#
#   valid loss:		0.12409
#   valid accuracy:	0.99887+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99940+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=4.77s -- loss=0.31923 -- acc=82.137504%
#
#   valid loss:		0.12489
#   valid accuracy:	0.99887+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99954+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.31702 -- acc=82.311461%
#
#   valid loss:		0.12305
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99928+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.31921 -- acc=82.159896%
#
#   valid loss:		0.12378
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99943+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=4.80s -- loss=0.31867 -- acc=82.113021%
#
#   valid loss:		0.12467
#   valid accuracy:	0.99867+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99953+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.31961 -- acc=82.141674%
#
#   valid loss:		0.12407
#   valid accuracy:	0.99862+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99948+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=5.12s -- loss=0.31633 -- acc=82.344274%
#
#   valid loss:		0.12367
#   valid accuracy:	0.99881+/-0.00000
#   valid auc-roc:	0.99972+/-0.00000
#   valid auc-pr:		0.99909+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=4.53s -- loss=0.31923 -- acc=82.134893%
#
#   valid loss:		0.12619
#   valid accuracy:	0.99871+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99941+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=4.87s -- loss=0.31915 -- acc=82.084898%
#
#   valid loss:		0.12523
#   valid accuracy:	0.99869+/-0.00000
#   valid auc-roc:	0.99973+/-0.00000
#   valid auc-pr:		0.99911+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=4.78s -- loss=0.31778 -- acc=82.248965%
#
#   valid loss:		0.12095
#   valid accuracy:	0.99898+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99932+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=5.12s -- loss=0.31793 -- acc=82.240624%
#
#   valid loss:		0.12289
#   valid accuracy:	0.99892+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99939+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=4.53s -- loss=0.31988 -- acc=82.091149%
#
#   valid loss:		0.12592
#   valid accuracy:	0.99881+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99950+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=4.55s -- loss=0.31822 -- acc=82.216672%
#
#   valid loss:		0.12322
#   valid accuracy:	0.99904+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99962+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=5.09s -- loss=0.31984 -- acc=82.068237%
#
#   valid loss:		0.12700
#   valid accuracy:	0.99898+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99944+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.31971 -- acc=82.120832%
#
#   valid loss:		0.12753
#   valid accuracy:	0.99894+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99927+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=5.00s -- loss=0.31889 -- acc=82.160426%
#
#   valid loss:		0.12748
#   valid accuracy:	0.99867+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99942+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=4.75s -- loss=0.31871 -- acc=82.125002%
#
#   valid loss:		0.12703
#   valid accuracy:	0.99862+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99935+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=4.57s -- loss=0.31740 -- acc=82.229693%
#
#   valid loss:		0.12275
#   valid accuracy:	0.99862+/-0.00000
#   valid auc-roc:	0.99974+/-0.00000
#   valid auc-pr:		0.99930+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=4.92s -- loss=0.31745 -- acc=82.278128%
#
#   valid loss:		0.12595
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99947+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=4.80s -- loss=0.31618 -- acc=82.412501%
#
#   valid loss:		0.12360
#   valid accuracy:	0.99862+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99913+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.31886 -- acc=82.225523%
#
#   valid loss:		0.12248
#   valid accuracy:	0.99854+/-0.00000
#   valid auc-roc:	0.99962+/-0.00000
#   valid auc-pr:		0.99889+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=4.53s -- loss=0.31750 -- acc=82.234373%
#
#   valid loss:		0.12569
#   valid accuracy:	0.99881+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99900+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=4.99s -- loss=0.31619 -- acc=82.340624%
#
#   valid loss:		0.12158
#   valid accuracy:	0.99852+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99881+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=4.76s -- loss=0.31740 -- acc=82.308331%
#
#   valid loss:		0.12467
#   valid accuracy:	0.99887+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99916+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=4.61s -- loss=0.31630 -- acc=82.273447%
#
#   valid loss:		0.12545
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99913+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=5.03s -- loss=0.31972 -- acc=82.094279%
#
#   valid loss:		0.12769
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	0.99972+/-0.00000
#   valid auc-pr:		0.99921+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.31843 -- acc=82.266677%
#
#   valid loss:		0.12481
#   valid accuracy:	0.99877+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99912+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=5.18s -- loss=0.31798 -- acc=82.276048%
#
#   valid loss:		0.12438
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99914+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.31877 -- acc=82.268237%
#
#   valid loss:		0.12471
#   valid accuracy:	0.99858+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99899+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=4.49s -- loss=0.31491 -- acc=82.432293%
#
#   valid loss:		0.12592
#   valid accuracy:	0.99881+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99908+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=5.28s -- loss=0.31650 -- acc=82.400000%
#
#   valid loss:		0.12884
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99932+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=4.78s -- loss=0.31745 -- acc=82.236984%
#
#   valid loss:		0.12500
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99911+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=4.87s -- loss=0.31686 -- acc=82.253125%
#
#   valid loss:		0.12736
#   valid accuracy:	0.99869+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99916+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=4.68s -- loss=0.31764 -- acc=82.283338%
#
#   valid loss:		0.12155
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99919+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=4.97s -- loss=0.31799 -- acc=82.234893%
#
#   valid loss:		0.12227
#   valid accuracy:	0.99869+/-0.00000
#   valid auc-roc:	0.99973+/-0.00000
#   valid auc-pr:		0.99931+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.31847 -- acc=82.281258%
#
#   valid loss:		0.12651
#   valid accuracy:	0.99871+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99895+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.31696 -- acc=82.412501%
#
#   valid loss:		0.12221
#   valid accuracy:	0.99881+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99907+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=4.62s -- loss=0.31691 -- acc=82.371357%
#
#   valid loss:		0.12783
#   valid accuracy:	0.99873+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99914+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.31898 -- acc=82.205211%
#
#   valid loss:		0.12634
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99961+/-0.00000
#   valid auc-pr:		0.99891+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=4.97s -- loss=0.31630 -- acc=82.400000%
#
#   valid loss:		0.12311
#   valid accuracy:	0.99856+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99910+/-0.00000
# Patience ran out... Early stopping.

# %%
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/toyhairpin/fullyconnected_1_8_best.ckpt
#   test  loss:		0.12082
#   test  accuracy:	0.99887+/-0.00000
#   test  auc-roc:	0.99972+/-0.00000
#   test  auc-pr:		0.99914+/-0.00000

# %% [markdown]
# ## First order mutagenesis saliency

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
numplots=5

for ii in range(numplots): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='output', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))

# %% [markdown]
# ## Second Order Mutagenesis

# %%
savepath = 'Arrays/toyhairpin_FC_1_8_sumoutputs1k.npy'

num_summary = 1000
X = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average(X, savepath, nntrainer, sess, progress='off')
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/toyhairpin_FC_1_8_sumoutputs1k.npy

# %%
#Load the saved data
savepath = 'Arrays/toyhairpin_FC_1_8_sumoutputs1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

# %%
mf.symlinear_holplot(meanhol_mut2, figplot=(4,5), alphabet='rna')

# %%
mf.square_holplot(meanhol_mut2, num=15, alphabet='rna')

# %% [markdown]
# ## Look at Hidden Layers

# %%
W = nnmodel.get_parameters(sess, layer='dense_1')[0]
top_neurons=np.argsort(np.squeeze(W))[::-1]
top_neurons
# Out:
# array([6, 0, 7, 4, 1, 5, 2, 3])

# %%
top_weights=np.sort(np.squeeze(W))[::-1]
top_weights
# Out:
# array([ 0.9895722,  0.8487142,  0.6894215, -3.3191054, -3.3996234,
#        -3.534822 , -3.5944262, -3.8194234], dtype=float32)

# %%
dense = nntrainer.get_activations(sess, test, layer='dense_0_active')

#plot which neurons got activated by the highest predicted sequence (from the outputs)
plt.plot(range(dense.shape[1]), dense[plot_index[0]])
plt.show()

''' An example of how a single sequence can excite various different neurons'''
# Out:
# ' An example of how a single sequence can excite various different neurons'

# %% [markdown]
# ## Look at the dense parameters

# %%
W = nnmodel.get_parameters(sess, layer='dense_0')[0]
W = W.reshape((41,4,dense.shape[1]))
W = np.expand_dims(W, axis=1)

num_plots = 8

Wplot = W[:,:,:,top_neurons[:num_plots]]

fig = visualize.plot_filter_logos(Wplot, figsize=(100,100), height=50,
                                 nt_width=10, norm=0, alphabet='rna', num_rows=num_plots//2)

# %% [markdown]
# ## Second order mutagenesis based on the neuron outputs

# %%
neuron = top_neurons[1]
top_indices = np.argsort(dense[:,neuron])[::-1]

num_summary = 500

X = test['inputs'][top_indices[:num_summary]]
savepath = 'Arrays/toyhairpin_FC_1_8_sumneuron0_500.npy'

sum_mut2 = mf.som_neruonaverage(X,'dense_0_active', neuron, savepath, nntrainer, sess, progress='off')
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/toyhairpin_FC_1_8_sumneuron0_500.npy

# %%
#Load the saved data
savepath = 'Arrays/toyhairpin_FC_1_8_sumneuron0_500.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 500
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

# %%
mf.symlinear_holplot(meanhol_mut2, figplot=(4,5), alphabet='rna', limits=False)

# %%
mf.square_holplot(meanhol_mut2, num=11, alphabet='rna', figsize=(7,6), start=(6,24))
