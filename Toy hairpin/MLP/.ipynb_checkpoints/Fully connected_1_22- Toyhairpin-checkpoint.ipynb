# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
import time as time

# %%
# load hairpin data
data_path = '../../../data_toyhairpin/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 22,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected_1_22')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 22)
# layer3: dense_0_batch
# (?, 22)
# layer4: dense_0_active
# (?, 22)
# layer5: dense_0_dropout
# (?, 22)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=20, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=5.76s -- loss=0.33061 -- acc=85.940624%
#
#   valid loss:		0.05497
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.83s -- loss=0.12179 -- acc=96.647925%
#
#   valid loss:		0.02785
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=5.07s -- loss=0.09884 -- acc=97.108851%
#
#   valid loss:		0.02031
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=5.11s -- loss=0.09095 -- acc=97.273447%
#
#   valid loss:		0.01830
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.08661 -- acc=97.411461%
#
#   valid loss:		0.01631
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.75s -- loss=0.08318 -- acc=97.509371%
#
#   valid loss:		0.01492
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.08262 -- acc=97.511461%
#
#   valid loss:		0.01602
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=4.67s -- loss=0.08146 -- acc=97.567187%
#
#   valid loss:		0.01438
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.85s -- loss=0.08163 -- acc=97.515622%
#
#   valid loss:		0.01389
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.52s -- loss=0.08114 -- acc=97.547915%
#
#   valid loss:		0.01468
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=4.65s -- loss=0.08052 -- acc=97.531773%
#
#   valid loss:		0.01398
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=4.82s -- loss=0.07831 -- acc=97.648435%
#
#   valid loss:		0.01417
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=4.59s -- loss=0.07938 -- acc=97.595830%
#
#   valid loss:		0.01311
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=4.93s -- loss=0.07909 -- acc=97.600520%
#
#   valid loss:		0.01406
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=4.66s -- loss=0.07928 -- acc=97.577088%
#
#   valid loss:		0.01405
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=4.82s -- loss=0.07889 -- acc=97.633853%
#
#   valid loss:		0.01391
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=4.79s -- loss=0.07785 -- acc=97.651565%
#
#   valid loss:		0.01344
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.07879 -- acc=97.609891%
#
#   valid loss:		0.01417
#   valid accuracy:	0.99998+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=4.75s -- loss=0.07850 -- acc=97.604160%
#
#   valid loss:		0.01410
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=5.19s -- loss=0.07831 -- acc=97.628643%
#
#   valid loss:		0.01349
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=4.96s -- loss=0.07748 -- acc=97.657816%
#
#   valid loss:		0.01454
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=4.73s -- loss=0.07645 -- acc=97.725002%
#
#   valid loss:		0.01351
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=4.74s -- loss=0.07652 -- acc=97.721872%
#
#   valid loss:		0.01346
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=4.76s -- loss=0.07581 -- acc=97.746875%
#
#   valid loss:		0.01369
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=4.69s -- loss=0.07716 -- acc=97.677088%
#
#   valid loss:		0.01348
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=5.19s -- loss=0.07565 -- acc=97.791149%
#
#   valid loss:		0.01401
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=5.41s -- loss=0.07687 -- acc=97.711461%
#
#   valid loss:		0.01394
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=4.83s -- loss=0.07615 -- acc=97.743234%
#
#   valid loss:		0.01398
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=4.77s -- loss=0.07656 -- acc=97.734373%
#
#   valid loss:		0.01399
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=4.83s -- loss=0.07680 -- acc=97.725002%
#
#   valid loss:		0.01397
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=4.80s -- loss=0.07856 -- acc=97.640624%
#
#   valid loss:		0.01495
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=4.84s -- loss=0.07568 -- acc=97.787509%
#
#   valid loss:		0.01459
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=4.77s -- loss=0.07698 -- acc=97.714581%
#
#   valid loss:		0.01435
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Patience ran out... Early stopping.

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/toyhairpin/fullyconnected_1_22_best.ckpt
#   test  loss:		0.01323
#   test  accuracy:	1.00000+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %% [markdown]
# ## First order mutagenesis saliency

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
numplots=5

for ii in range(numplots): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='output', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Second Order Mutagenesis

# %%
savepath = 'Arrays/toyhairpin_FC_1_22_sumoutputs1k.npy'

num_summary = 1000
X = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average(X, savepath, nntrainer, sess, progress='off')
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/toyhairpin_FC_1_22_sumoutputs1k.npy

# %%
X = test['inputs'][plot_index[:num_summary]]

#Load the saved data
savepath = 'Arrays/toyhairpin_FC_1_22_sumoutputs1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

# %%
mf.symlinear_holplot(meanhol_mut2, figplot=(4,5), alphabet='rna')

# %%
mf.square_holplot(meanhol_mut2, num=15, alphabet='rna')

# %% [markdown]
# ## Look at Hidden Layers

# %%
W = nnmodel.get_parameters(sess, layer='dense_1')[0]
W.shape
top_neurons=np.argsort(np.squeeze(W))[::-1]
top_neurons
# Out:
# array([19,  6,  7,  0, 17, 21,  1,  8, 15,  4, 20, 13, 11, 18, 14,  2,  5,
#         9, 12,  3, 10, 16])

# %%
dense = nntrainer.get_activations(sess, test, layer='dense_0_active')

#plot which neurons got activated by the highest predicted sequence (from the outputs)
plt.plot(range(dense.shape[1]), dense[plot_index[0]])
plt.show()

''' An example of how a single sequence can excite various different neurons'''
# Out:
# ' An example of how a single sequence can excite various different neurons'

# %%
num_plots = 5
for neuron in top_neurons[0:num_plots]:
    top_indices = np.argsort(dense[:,neuron])[::-1]
    X = np.expand_dims(test['inputs'][top_indices[0]], axis=0)
    
    mf.fom_neursal(X, layer='dense_0_active', alphabet='rna', neuron=neuron, nntrainer=nntrainer, sess=sess)

# %% [markdown]
# ## Look at the dense parameters

# %%
W = nnmodel.get_parameters(sess, layer='dense_0')[0]
W = W.reshape((41,4,dense.shape[1]))
W = np.expand_dims(W, axis=1)

num_plots = 22

Wplot = W[:,:,:,top_neurons[:num_plots]]

fig = visualize.plot_filter_logos(Wplot, figsize=(100,200), height=50,
                                 nt_width=10, norm=0, alphabet='rna', num_rows=num_plots//2)
