# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import mutagenesis_functions as mf
import time as time

# %%
# load hairpin data
data_path = '../data_peter/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 64,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected_1_64')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# %%
# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 64)
# layer3: dense_0_batch
# (?, 64)
# layer4: dense_0_active
# (?, 64)
# layer5: dense_0_dropout
# (?, 64)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

# fit model
data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=10, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.71s -- loss=0.19913 -- acc=91.93958
#
#   valid loss:		0.00970
#   valid accuracy:	0.99998+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.74s -- loss=0.02445 -- acc=99.56510
#
#   valid loss:		0.00384
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=4.96s -- loss=0.01502 -- acc=99.72083
#
#   valid loss:		0.00288
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=4.97s -- loss=0.01148 -- acc=99.77135
#
#   valid loss:		0.00276
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.78s -- loss=0.01002 -- acc=99.81250
#
#   valid loss:		0.00280
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.51s -- loss=0.00900 -- acc=99.84479
#
#   valid loss:		0.00286
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.51s -- loss=0.00914 -- acc=99.84843
#
#   valid loss:		0.00310
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.00899 -- acc=99.85468
#
#   valid loss:		0.00321
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.55s -- loss=0.00796 -- acc=99.88437
#
#   valid loss:		0.00325
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.63s -- loss=0.00810 -- acc=99.88020
#
#   valid loss:		0.00337
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=4.37s -- loss=0.00856 -- acc=99.86198
#
#   valid loss:		0.00354
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=4.39s -- loss=0.00846 -- acc=99.86875
#
#   valid loss:		0.00358
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=4.77s -- loss=0.00849 -- acc=99.87291
#
#   valid loss:		0.00375
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=4.39s -- loss=0.00803 -- acc=99.88906
#
#   valid loss:		0.00380
#   valid accuracy:	1.00000+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Patience ran out... Early stopping.

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
#   test  loss:		0.00275
#   test  accuracy:	1.00000+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
#Get Predictions

# calculate activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
predictionslogits = nntrainer.get_activations(sess, test, layer='dense_1_bias')

# %% [markdown]
# ## Run a First Order Mutagenesis analysis

# %%
# sort activations
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

X = np.expand_dims(test['inputs'][plot_index[0]], axis=0)

X_mut = mf.mutate(X, X.shape[1], X.shape[3])
mutations = {'inputs': X_mut, 'targets': Y_test[:X_mut.shape[0]]}

# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

#Get output activations for the mutations
mut_predictionslogits = nntrainer.get_activations(sess, mutations, layer='dense_1_bias')
mut_predictionsoutput= nntrainer.get_activations(sess, mutations, layer='output')

#shape the predictions of the mutations into the shape of a heatmap
heat_mut = mut_predictionslogits.reshape(X.shape[1],4).T

#normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
norm_heat_mut = heat_mut - predictionslogits[plot_index[0]]
norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

plt.figure(figsize=(15,2))
visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                        norm_heat_mut, 
                                        alphabet='rna', 
                                        nt_width=400)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
# /home/peter/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Look at the highest predicted sequences

# %%
num_plots = 5
for index in plot_index[:num_plots]:

    X = np.expand_dims(test['inputs'][index], axis=0)
    
    plt.figure(figsize=(15,1))
    visualize.plot_pos_saliency(np.squeeze(X).T, norm_factor=0, nt_width=400)

# %% [markdown]
# # Average the second order mutagenesis scores for 1000 different sequences
#
# Since each mutagenesis produces 41*41*16 = 26896 sequences, getting scores for 1000 is gonna take a long time...

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_summary = 1000

sum_mut2_predictoutputs = np.zeros((41*41*16, 1))
starttime = time.time()

for ii in range(num_summary):
    print (ii)
    epoch_starttime = time.time()
    
    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    #mutate the sequence
    X_mutsecorder = mf.double_mutate(X, X.shape[1], X.shape[3])

    #reshape the 6D tensor into a 4D tensor that the model can test
    X_mutsecorder_reshape = np.reshape(X_mutsecorder, (X.shape[1]*X.shape[1]*16, X.shape[1], 1, 4))
    
    mutations = {'inputs': X_mutsecorder_reshape, 'targets': Y_test[:X_mutsecorder_reshape.shape[0]]}
    
    #Get output activations for the mutations
    mut2_predictoutputs= nntrainer.get_activations(sess, mutations, layer='output')
    
    #Sum all the scores into a single matrix
    sum_mut2_predictoutputs += mut2_predictoutputs
    
    epoch_endtime = time.time()
    
    print ('Epoch duration =' + str(np.around((epoch_endtime -epoch_starttime), 2)) + 's')
    print ('Cumulative duration =' + str(np.around((epoch_endtime - starttime), 2)) + 's')
    print ()
    
# Save the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_1_64_sumoutputs1000.npy'
np.save(npy_save_path, sum_mut2_predictoutputs)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
# 0
# Epoch duration =0.15s
# Cumulative duration =0.15s
#
# 1
# Epoch duration =0.14s
# Cumulative duration =0.28s
#
# 2
# Epoch duration =0.14s
# Cumulative duration =0.42s
#
# 3
# Epoch duration =0.14s
# Cumulative duration =0.56s
#
# 4
# Epoch duration =0.14s
# Cumulative duration =0.7s
#
# 5
# Epoch duration =0.14s
# Cumulative duration =0.83s
#
# 6
# Epoch duration =0.14s
# Cumulative duration =0.97s
#
# 7
# Epoch duration =0.14s
# Cumulative duration =1.11s
#
# 8
# Epoch duration =0.14s
# Cumulative duration =1.25s
#
# 9
# Epoch duration =0.14s
# Cumulative duration =1.38s
#
# 10
# Epoch duration =0.14s
# Cumulative duration =1.52s
#
# 11
# Epoch duration =0.13s
# Cumulative duration =1.66s
#
# 12
# Epoch duration =0.14s
# Cumulative duration =1.79s
#
# 13
# Epoch duration =0.13s
# Cumulative duration =1.93s
#
# 14
# Epoch duration =0.13s
# Cumulative duration =2.06s
#
# 15
# Epoch duration =0.14s
# Cumulative duration =2.2s
#
# 16
# Epoch duration =0.14s
# Cumulative duration =2.34s
#
# 17
# Epoch duration =0.14s
# Cumulative duration =2.47s
#
# 18
# Epoch duration =0.14s
# Cumulative duration =2.61s
#
# 19
# Epoch duration =0.13s
# Cumulative duration =2.75s
#
# 20
# Epoch duration =0.13s
# Cumulative duration =2.88s
#
# 21
# Epoch duration =0.13s
# Cumulative duration =3.01s
#
# 22
# Epoch duration =0.14s
# Cumulative duration =3.15s
#
# 23
# Epoch duration =0.14s
# Cumulative duration =3.3s
#
# 24
# Epoch duration =0.14s
# Cumulative duration =3.43s
#
# 25
# Epoch duration =0.14s
# Cumulative duration =3.57s
#
# 26
# Epoch duration =0.14s
# Cumulative duration =3.71s
#
# 27
# Epoch duration =0.13s
# Cumulative duration =3.84s
#
# 28
# Epoch duration =0.14s
# Cumulative duration =3.98s
#
# 29
# Epoch duration =0.14s
# Cumulative duration =4.12s
#
# 30
# Epoch duration =0.14s
# Cumulative duration =4.26s
#
# 31
# Epoch duration =0.13s
# Cumulative duration =4.39s
#
# 32
# Epoch duration =0.14s
# Cumulative duration =4.53s
#
# 33
# Epoch duration =0.14s
# Cumulative duration =4.66s
#
# 34
# Epoch duration =0.14s
# Cumulative duration =4.8s
#
# 35
# Epoch duration =0.14s
# Cumulative duration =4.94s
#
# 36
# Epoch duration =0.14s
# Cumulative duration =5.08s
#
# 37
# Epoch duration =0.14s
# Cumulative duration =5.21s
#
# 38
# Epoch duration =0.16s
# Cumulative duration =5.37s
#
# 39
# Epoch duration =0.13s
# Cumulative duration =5.5s
#
# 40
# Epoch duration =0.14s
# Cumulative duration =5.64s
#
# 41
# Epoch duration =0.13s
# Cumulative duration =5.77s
#
# 42
# Epoch duration =0.14s
# Cumulative duration =5.91s
#
# 43
# Epoch duration =0.14s
# Cumulative duration =6.05s
#
# 44
# Epoch duration =0.14s
# Cumulative duration =6.18s
#
# 45
# Epoch duration =0.13s
# Cumulative duration =6.32s
#
# 46
# Epoch duration =0.14s
# Cumulative duration =6.46s
#
# 47
# Epoch duration =0.13s
# Cumulative duration =6.59s
#
# 48
# Epoch duration =0.14s
# Cumulative duration =6.73s
#
# 49
# Epoch duration =0.13s
# Cumulative duration =6.86s
#
# 50
# Epoch duration =0.14s
# Cumulative duration =7.0s
#
# 51
# Epoch duration =0.13s
# Cumulative duration =7.13s
#
# 52
# Epoch duration =0.16s
# Cumulative duration =7.29s
#
# 53
# Epoch duration =0.15s
# Cumulative duration =7.44s
#
# 54
# Epoch duration =0.14s
# Cumulative duration =7.58s
#
# 55
# Epoch duration =0.13s
# Cumulative duration =7.71s
#
# 56
# Epoch duration =0.14s
# Cumulative duration =7.85s
#
# 57
# Epoch duration =0.13s
# Cumulative duration =7.98s
#
# 58
# Epoch duration =0.14s
# Cumulative duration =8.12s
#
# 59
# Epoch duration =0.14s
# Cumulative duration =8.26s
#
# 60
# Epoch duration =0.14s
# Cumulative duration =8.39s
#
# 61
# Epoch duration =0.13s
# Cumulative duration =8.53s
#
# 62
# Epoch duration =0.14s
# Cumulative duration =8.66s
#
# 63
# Epoch duration =0.13s
# Cumulative duration =8.8s
#
# 64
# Epoch duration =0.14s
# Cumulative duration =8.94s
#
# 65
# Epoch duration =0.13s
# Cumulative duration =9.07s
#
# 66
# Epoch duration =0.13s
# Cumulative duration =9.2s
#
# 67
# Epoch duration =0.13s
# Cumulative duration =9.34s
#
# 68
# Epoch duration =0.14s
# Cumulative duration =9.47s
#
# 69
# Epoch duration =0.13s
# Cumulative duration =9.61s
#
# 70
# Epoch duration =0.14s
# Cumulative duration =9.75s
#
# 71
# Epoch duration =0.14s
# Cumulative duration =9.88s
#
# 72
# Epoch duration =0.13s
# Cumulative duration =10.01s
#
# 73
# Epoch duration =0.14s
# Cumulative duration =10.16s
#
# 74
# Epoch duration =0.14s
# Cumulative duration =10.29s
#
# 75
# Epoch duration =0.13s
# Cumulative duration =10.43s
#
# 76
# Epoch duration =0.14s
# Cumulative duration =10.57s
#
# 77
# Epoch duration =0.14s
# Cumulative duration =10.7s
#
# 78
# Epoch duration =0.14s
# Cumulative duration =10.84s
#
# 79
# Epoch duration =0.14s
# Cumulative duration =10.98s
#
# 80
# Epoch duration =0.14s
# Cumulative duration =11.12s
#
# 81
# Epoch duration =0.13s
# Cumulative duration =11.26s
#
# 82
# Epoch duration =0.14s
# Cumulative duration =11.39s
#
# 83
# Epoch duration =0.14s
# Cumulative duration =11.53s
#
# 84
# Epoch duration =0.14s
# Cumulative duration =11.67s
#
# 85
# Epoch duration =0.14s
# Cumulative duration =11.81s
#
# 86
# Epoch duration =0.13s
# Cumulative duration =11.94s
#
# 87
# Epoch duration =0.14s
# Cumulative duration =12.08s
#
# 88
# Epoch duration =0.14s
# Cumulative duration =12.22s
#
# 89
# Epoch duration =0.13s
# Cumulative duration =12.35s
#
# 90
# Epoch duration =0.13s
# Cumulative duration =12.48s
#
# 91
# Epoch duration =0.14s
# Cumulative duration =12.62s
#
# 92
# Epoch duration =0.14s
# Cumulative duration =12.76s
#
# 93
# Epoch duration =0.14s
# Cumulative duration =12.9s
#
# 94
# Epoch duration =0.14s
# Cumulative duration =13.04s
#
# 95
# Epoch duration =0.14s
# Cumulative duration =13.17s
#
# 96
# Epoch duration =0.13s
# Cumulative duration =13.31s
#
# 97
# Epoch duration =0.13s
# Cumulative duration =13.44s
#
# 98
# Epoch duration =0.14s
# Cumulative duration =13.58s
#
# 99
# Epoch duration =0.14s
# Cumulative duration =13.72s
#
# 100
# Epoch duration =0.13s
# Cumulative duration =13.85s
#
# 101
# Epoch duration =0.13s
# Cumulative duration =13.99s
#
# 102
# Epoch duration =0.14s
# Cumulative duration =14.13s
#
# 103
# Epoch duration =0.14s
# Cumulative duration =14.26s
#
# 104
# Epoch duration =0.14s
# Cumulative duration =14.4s
#
# 105
# Epoch duration =0.15s
# Cumulative duration =14.55s
#
# 106
# Epoch duration =0.14s
# Cumulative duration =14.68s
#
# 107
# Epoch duration =0.14s
# Cumulative duration =14.82s
#
# 108
# Epoch duration =0.14s
# Cumulative duration =14.96s
#
# 109
# Epoch duration =0.13s
# Cumulative duration =15.09s
#
# 110
# Epoch duration =0.14s
# Cumulative duration =15.23s
#
# 111
# Epoch duration =0.14s
# Cumulative duration =15.37s
#
# 112
# Epoch duration =0.14s
# Cumulative duration =15.51s
#
# 113
# Epoch duration =0.13s
# Cumulative duration =15.64s
#
# 114
# Epoch duration =0.14s
# Cumulative duration =15.79s
#
# 115
# Epoch duration =0.14s
# Cumulative duration =15.93s
#
# 116
# Epoch duration =0.14s
# Cumulative duration =16.07s
#
# 117
# Epoch duration =0.14s
# Cumulative duration =16.2s
#
# 118
# Epoch duration =0.13s
# Cumulative duration =16.34s
#
# 119
# Epoch duration =0.13s
# Cumulative duration =16.47s
#
# 120
# Epoch duration =0.15s
# Cumulative duration =16.62s
#
# 121
# Epoch duration =0.15s
# Cumulative duration =16.77s
#
# 122
# Epoch duration =0.14s
# Cumulative duration =16.91s
#
# 123
# Epoch duration =0.14s
# Cumulative duration =17.04s
#
# 124
# Epoch duration =0.14s
# Cumulative duration =17.18s
#
# 125
# Epoch duration =0.14s
# Cumulative duration =17.32s
#
# 126
# Epoch duration =0.14s
# Cumulative duration =17.46s
#
# 127
# Epoch duration =0.13s
# Cumulative duration =17.6s
#
# 128
# Epoch duration =0.14s
# Cumulative duration =17.74s
#
# 129
# Epoch duration =0.14s
# Cumulative duration =17.88s
#
# 130
# Epoch duration =0.14s
# Cumulative duration =18.01s
#
# 131
# Epoch duration =0.14s
# Cumulative duration =18.15s
#
# 132
# Epoch duration =0.14s
# Cumulative duration =18.29s
#
# 133
# Epoch duration =0.13s
# Cumulative duration =18.42s
#
# 134
# Epoch duration =0.14s
# Cumulative duration =18.56s
#
# 135
# Epoch duration =0.14s
# Cumulative duration =18.69s
#
# 136
# Epoch duration =0.14s
# Cumulative duration =18.83s
#
# 137
# Epoch duration =0.14s
# Cumulative duration =18.97s
#
# 138
# Epoch duration =0.14s
# Cumulative duration =19.11s
#
# 139
# Epoch duration =0.13s
# Cumulative duration =19.24s
#
# 140
# Epoch duration =0.14s
# Cumulative duration =19.38s
#
# 141
# Epoch duration =0.13s
# Cumulative duration =19.52s
#
# 142
# Epoch duration =0.14s
# Cumulative duration =19.65s
#
# 143
# Epoch duration =0.14s
# Cumulative duration =19.79s
#
# 144
# Epoch duration =0.16s
# Cumulative duration =19.95s
#
# 145
# Epoch duration =0.13s
# Cumulative duration =20.08s
#
# 146
# Epoch duration =0.14s
# Cumulative duration =20.22s
#
# 147
# Epoch duration =0.13s
# Cumulative duration =20.36s
#
# 148
# Epoch duration =0.14s
# Cumulative duration =20.5s
#
# 149
# Epoch duration =0.13s
# Cumulative duration =20.63s
#
# 150
# Epoch duration =0.14s
# Cumulative duration =20.77s
#
# 151
# Epoch duration =0.16s
# Cumulative duration =20.93s
#
# 152
# Epoch duration =0.14s
# Cumulative duration =21.07s
#
# 153
# Epoch duration =0.14s
# Cumulative duration =21.21s
#
# 154
# Epoch duration =0.14s
# Cumulative duration =21.34s
#
# 155
# Epoch duration =0.14s
# Cumulative duration =21.48s
#
# 156
# Epoch duration =0.14s
# Cumulative duration =21.62s
#
# 157
# Epoch duration =0.15s
# Cumulative duration =21.77s
#
# 158
# Epoch duration =0.14s
# Cumulative duration =21.9s
#
# 159
# Epoch duration =0.14s
# Cumulative duration =22.05s
#
# 160
# Epoch duration =0.14s
# Cumulative duration =22.19s
#
# 161
# Epoch duration =0.13s
# Cumulative duration =22.32s
#
# 162
# Epoch duration =0.14s
# Cumulative duration =22.46s
#
# 163
# Epoch duration =0.14s
# Cumulative duration =22.6s
#
# 164
# Epoch duration =0.14s
# Cumulative duration =22.73s
#
# 165
# Epoch duration =0.13s
# Cumulative duration =22.87s
#
# 166
# Epoch duration =0.14s
# Cumulative duration =23.01s
#
# 167
# Epoch duration =0.15s
# Cumulative duration =23.16s
#
# 168
# Epoch duration =0.14s
# Cumulative duration =23.3s
#
# 169
# Epoch duration =0.14s
# Cumulative duration =23.43s
#
# 170
# Epoch duration =0.14s
# Cumulative duration =23.57s
#
# 171
# Epoch duration =0.14s
# Cumulative duration =23.71s
#
# 172
# Epoch duration =0.14s
# Cumulative duration =23.85s
#
# 173
# Epoch duration =0.13s
# Cumulative duration =23.98s
#
# 174
# Epoch duration =0.14s
# Cumulative duration =24.12s
#
# 175
# Epoch duration =0.14s
# Cumulative duration =24.26s
#
# 176
# Epoch duration =0.13s
# Cumulative duration =24.39s
#
# 177
# Epoch duration =0.13s
# Cumulative duration =24.53s
#
# 178
# Epoch duration =0.14s
# Cumulative duration =24.66s
#
# 179
# Epoch duration =0.14s
# Cumulative duration =24.8s
#
# 180
# Epoch duration =0.14s
# Cumulative duration =24.94s
#
# 181
# Epoch duration =0.14s
# Cumulative duration =25.08s
#
# 182
# Epoch duration =0.14s
# Cumulative duration =25.22s
#
# 183
# Epoch duration =0.14s
# Cumulative duration =25.35s
#
# 184
# Epoch duration =0.14s
# Cumulative duration =25.49s
#
# 185
# Epoch duration =0.14s
# Cumulative duration =25.63s
#
# 186
# Epoch duration =0.13s
# Cumulative duration =25.77s
#
# 187
# Epoch duration =0.14s
# Cumulative duration =25.9s
#
# 188
# Epoch duration =0.14s
# Cumulative duration =26.05s
#
# 189
# Epoch duration =0.15s
# Cumulative duration =26.19s
#
# 190
# Epoch duration =0.13s
# Cumulative duration =26.33s
#
# 191
# Epoch duration =0.13s
# Cumulative duration =26.46s
#
# 192
# Epoch duration =0.14s
# Cumulative duration =26.6s
#
# 193
# Epoch duration =0.14s
# Cumulative duration =26.74s
#
# 194
# Epoch duration =0.14s
# Cumulative duration =26.88s
#
# 195
# Epoch duration =0.14s
# Cumulative duration =27.01s
#
# 196
# Epoch duration =0.13s
# Cumulative duration =27.15s
#
# 197
# Epoch duration =0.14s
# Cumulative duration =27.29s
#
# 198
# Epoch duration =0.14s
# Cumulative duration =27.43s
#
# 199
# Epoch duration =0.13s
# Cumulative duration =27.56s
#
# 200
# Epoch duration =0.14s
# Cumulative duration =27.71s
#
# 201
# Epoch duration =0.14s
# Cumulative duration =27.84s
#
# 202
# Epoch duration =0.13s
# Cumulative duration =27.98s
#
# 203
# Epoch duration =0.14s
# Cumulative duration =28.11s
#
# 204
# Epoch duration =0.14s
# Cumulative duration =28.25s
#
# 205
# Epoch duration =0.14s
# Cumulative duration =28.38s
#
# 206
# Epoch duration =0.13s
# Cumulative duration =28.52s
#
# 207
# Epoch duration =0.13s
# Cumulative duration =28.65s
#
# 208
# Epoch duration =0.14s
# Cumulative duration =28.79s
#
# 209
# Epoch duration =0.14s
# Cumulative duration =28.93s
#
# 210
# Epoch duration =0.14s
# Cumulative duration =29.07s
#
# 211
# Epoch duration =0.14s
# Cumulative duration =29.21s
#
# 212
# Epoch duration =0.15s
# Cumulative duration =29.36s
#
# 213
# Epoch duration =0.13s
# Cumulative duration =29.49s
#
# 214
# Epoch duration =0.14s
# Cumulative duration =29.63s
#
# 215
# Epoch duration =0.15s
# Cumulative duration =29.78s
#
# 216
# Epoch duration =0.14s
# Cumulative duration =29.92s
#
# 217
# Epoch duration =0.13s
# Cumulative duration =30.05s
#
# 218
# Epoch duration =0.14s
# Cumulative duration =30.19s
#
# 219
# Epoch duration =0.13s
# Cumulative duration =30.32s
#
# 220
# Epoch duration =0.14s
# Cumulative duration =30.46s
#
# 221
# Epoch duration =0.14s
# Cumulative duration =30.59s
#
# 222
# Epoch duration =0.14s
# Cumulative duration =30.73s
#
# 223
# Epoch duration =0.13s
# Cumulative duration =30.86s
#
# 224
# Epoch duration =0.14s
# Cumulative duration =31.0s
#
# 225
# Epoch duration =0.14s
# Cumulative duration =31.14s
#
# 226
# Epoch duration =0.14s
# Cumulative duration =31.27s
#
# 227
# Epoch duration =0.13s
# Cumulative duration =31.41s
#
# 228
# Epoch duration =0.14s
# Cumulative duration =31.55s
#
# 229
# Epoch duration =0.15s
# Cumulative duration =31.7s
#
# 230
# Epoch duration =0.14s
# Cumulative duration =31.83s
#
# 231
# Epoch duration =0.14s
# Cumulative duration =31.97s
#
# 232
# Epoch duration =0.14s
# Cumulative duration =32.11s
#
# 233
# Epoch duration =0.14s
# Cumulative duration =32.25s
#
# 234
# Epoch duration =0.13s
# Cumulative duration =32.38s
#
# 235
# Epoch duration =0.14s
# Cumulative duration =32.52s
#
# 236
# Epoch duration =0.14s
# Cumulative duration =32.66s
#
# 237
# Epoch duration =0.14s
# Cumulative duration =32.8s
#
# 238
# Epoch duration =0.14s
# Cumulative duration =32.93s
#
# 239
# Epoch duration =0.13s
# Cumulative duration =33.07s
#
# 240
# Epoch duration =0.16s
# Cumulative duration =33.23s
#
# 241
# Epoch duration =0.16s
# Cumulative duration =33.39s
#
# 242
# Epoch duration =0.14s
# Cumulative duration =33.52s
#
# 243
# Epoch duration =0.13s
# Cumulative duration =33.66s
#
# 244
# Epoch duration =0.14s
# Cumulative duration =33.8s
#
# 245
# Epoch duration =0.13s
# Cumulative duration =33.93s
#
# 246
# Epoch duration =0.14s
# Cumulative duration =34.07s
#
# 247
# Epoch duration =0.14s
# Cumulative duration =34.21s
#
# 248
# Epoch duration =0.14s
# Cumulative duration =34.35s
#
# 249
# Epoch duration =0.13s
# Cumulative duration =34.48s
#
# 250
# Epoch duration =0.15s
# Cumulative duration =34.63s
#
# 251
# Epoch duration =0.14s
# Cumulative duration =34.77s
#
# 252
# Epoch duration =0.14s
# Cumulative duration =34.91s
#
# 253
# Epoch duration =0.14s
# Cumulative duration =35.04s
#
# 254
# Epoch duration =0.14s
# Cumulative duration =35.18s
#
# 255
# Epoch duration =0.14s
# Cumulative duration =35.32s
#
# 256
# Epoch duration =0.15s
# Cumulative duration =35.47s
#
# 257
# Epoch duration =0.14s
# Cumulative duration =35.61s
#
# 258
# Epoch duration =0.14s
# Cumulative duration =35.75s
#
# 259
# Epoch duration =0.13s
# Cumulative duration =35.88s
#
# 260
# Epoch duration =0.14s
# Cumulative duration =36.02s
#
# 261
# Epoch duration =0.14s
# Cumulative duration =36.15s
#
# 262
# Epoch duration =0.14s
# Cumulative duration =36.3s
#
# 263
# Epoch duration =0.14s
# Cumulative duration =36.43s
#
# 264
# Epoch duration =0.14s
# Cumulative duration =36.57s
#
# 265
# Epoch duration =0.14s
# Cumulative duration =36.71s
#
# 266
# Epoch duration =0.14s
# Cumulative duration =36.85s
#
# 267
# Epoch duration =0.14s
# Cumulative duration =36.99s
#
# 268
# Epoch duration =0.14s
# Cumulative duration =37.13s
#
# 269
# Epoch duration =0.14s
# Cumulative duration =37.27s
#
# 270
# Epoch duration =0.14s
# Cumulative duration =37.4s
#
# 271
# Epoch duration =0.13s
# Cumulative duration =37.54s
#
# 272
# Epoch duration =0.14s
# Cumulative duration =37.67s
#
# 273
# Epoch duration =0.13s
# Cumulative duration =37.81s
#
# 274
# Epoch duration =0.15s
# Cumulative duration =37.96s
#
# 275
# Epoch duration =0.14s
# Cumulative duration =38.1s
#
# 276
# Epoch duration =0.14s
# Cumulative duration =38.24s
#
# 277
# Epoch duration =0.13s
# Cumulative duration =38.37s
#
# 278
# Epoch duration =0.13s
# Cumulative duration =38.51s
#
# 279
# Epoch duration =0.15s
# Cumulative duration =38.65s
#
# 280
# Epoch duration =0.15s
# Cumulative duration =38.8s
#
# 281
# Epoch duration =0.13s
# Cumulative duration =38.93s
#
# 282
# Epoch duration =0.14s
# Cumulative duration =39.07s
#
# 283
# Epoch duration =0.13s
# Cumulative duration =39.2s
#
# 284
# Epoch duration =0.13s
# Cumulative duration =39.34s
#
# 285
# Epoch duration =0.14s
# Cumulative duration =39.47s
#
# 286
# Epoch duration =0.14s
# Cumulative duration =39.61s
#
# 287
# Epoch duration =0.14s
# Cumulative duration =39.75s
#
# 288
# Epoch duration =0.13s
# Cumulative duration =39.89s
#
# 289
# Epoch duration =0.14s
# Cumulative duration =40.02s
#
# 290
# Epoch duration =0.17s
# Cumulative duration =40.19s
#
# 291
# Epoch duration =0.13s
# Cumulative duration =40.32s
#
# 292
# Epoch duration =0.14s
# Cumulative duration =40.46s
#
# 293
# Epoch duration =0.14s
# Cumulative duration =40.6s
#
# 294
# Epoch duration =0.14s
# Cumulative duration =40.74s
#
# 295
# Epoch duration =0.17s
# Cumulative duration =40.91s
#
# 296
# Epoch duration =0.14s
# Cumulative duration =41.05s
#
# 297
# Epoch duration =0.13s
# Cumulative duration =41.18s
#
# 298
# Epoch duration =0.15s
# Cumulative duration =41.32s
#
# 299
# Epoch duration =0.14s
# Cumulative duration =41.46s
#
# 300
# Epoch duration =0.14s
# Cumulative duration =41.6s
#
# 301
# Epoch duration =0.16s
# Cumulative duration =41.75s
#
# 302
# Epoch duration =0.14s
# Cumulative duration =41.89s
#
# 303
# Epoch duration =0.14s
# Cumulative duration =42.03s
#
# 304
# Epoch duration =0.15s
# Cumulative duration =42.18s
#
# 305
# Epoch duration =0.14s
# Cumulative duration =42.31s
#
# 306
# Epoch duration =0.14s
# Cumulative duration =42.45s
#
# 307
# Epoch duration =0.14s
# Cumulative duration =42.59s
#
# 308
# Epoch duration =0.14s
# Cumulative duration =42.73s
#
# 309
# Epoch duration =0.13s
# Cumulative duration =42.86s
#
# 310
# Epoch duration =0.15s
# Cumulative duration =43.01s
#
# 311
# Epoch duration =0.13s
# Cumulative duration =43.14s
#
# 312
# Epoch duration =0.14s
# Cumulative duration =43.28s
#
# 313
# Epoch duration =0.14s
# Cumulative duration =43.42s
#
# 314
# Epoch duration =0.14s
# Cumulative duration =43.55s
#
# 315
# Epoch duration =0.14s
# Cumulative duration =43.69s
#
# 316
# Epoch duration =0.13s
# Cumulative duration =43.82s
#
# 317
# Epoch duration =0.13s
# Cumulative duration =43.96s
#
# 318
# Epoch duration =0.14s
# Cumulative duration =44.09s
#
# 319
# Epoch duration =0.16s
# Cumulative duration =44.26s
#
# 320
# Epoch duration =0.15s
# Cumulative duration =44.41s
#
# 321
# Epoch duration =0.16s
# Cumulative duration =44.57s
#
# 322
# Epoch duration =0.14s
# Cumulative duration =44.71s
#
# 323
# Epoch duration =0.14s
# Cumulative duration =44.85s
#
# 324
# Epoch duration =0.14s
# Cumulative duration =44.99s
#
# 325
# Epoch duration =0.13s
# Cumulative duration =45.12s
#
# 326
# Epoch duration =0.13s
# Cumulative duration =45.26s
#
# 327
# Epoch duration =0.13s
# Cumulative duration =45.39s
#
# 328
# Epoch duration =0.15s
# Cumulative duration =45.54s
#
# 329
# Epoch duration =0.14s
# Cumulative duration =45.67s
#
# 330
# Epoch duration =0.14s
# Cumulative duration =45.81s
#
# 331
# Epoch duration =0.14s
# Cumulative duration =45.95s
#
# 332
# Epoch duration =0.14s
# Cumulative duration =46.09s
#
# 333
# Epoch duration =0.14s
# Cumulative duration =46.22s
#
# 334
# Epoch duration =0.15s
# Cumulative duration =46.37s
#
# 335
# Epoch duration =0.14s
# Cumulative duration =46.51s
#
# 336
# Epoch duration =0.14s
# Cumulative duration =46.64s
#
# 337
# Epoch duration =0.14s
# Cumulative duration =46.78s
#
# 338
# Epoch duration =0.14s
# Cumulative duration =46.92s
#
# 339
# Epoch duration =0.14s
# Cumulative duration =47.05s
#
# 340
# Epoch duration =0.14s
# Cumulative duration =47.2s
#
# 341
# Epoch duration =0.14s
# Cumulative duration =47.33s
#
# 342
# Epoch duration =0.14s
# Cumulative duration =47.47s
#
# 343
# Epoch duration =0.17s
# Cumulative duration =47.64s
#
# 344
# Epoch duration =0.14s
# Cumulative duration =47.77s
#
# 345
# Epoch duration =0.13s
# Cumulative duration =47.91s
#
# 346
# Epoch duration =0.14s
# Cumulative duration =48.05s
#
# 347
# Epoch duration =0.14s
# Cumulative duration =48.18s
#
# 348
# Epoch duration =0.15s
# Cumulative duration =48.33s
#
# 349
# Epoch duration =0.15s
# Cumulative duration =48.48s
#
# 350
# Epoch duration =0.16s
# Cumulative duration =48.64s
#
# 351
# Epoch duration =0.13s
# Cumulative duration =48.77s
#
# 352
# Epoch duration =0.13s
# Cumulative duration =48.91s
#
# 353
# Epoch duration =0.13s
# Cumulative duration =49.04s
#
# 354
# Epoch duration =0.14s
# Cumulative duration =49.18s
#
# 355
# Epoch duration =0.16s
# Cumulative duration =49.34s
#
# 356
# Epoch duration =0.13s
# Cumulative duration =49.47s
#
# 357
# Epoch duration =0.14s
# Cumulative duration =49.61s
#
# 358
# Epoch duration =0.14s
# Cumulative duration =49.75s
#
# 359
# Epoch duration =0.14s
# Cumulative duration =49.88s
#
# 360
# Epoch duration =0.14s
# Cumulative duration =50.02s
#
# 361
# Epoch duration =0.14s
# Cumulative duration =50.15s
#
# 362
# Epoch duration =0.13s
# Cumulative duration =50.29s
#
# 363
# Epoch duration =0.13s
# Cumulative duration =50.42s
#
# 364
# Epoch duration =0.14s
# Cumulative duration =50.56s
#
# 365
# Epoch duration =0.13s
# Cumulative duration =50.69s
#
# 366
# Epoch duration =0.14s
# Cumulative duration =50.84s
#
# 367
# Epoch duration =0.14s
# Cumulative duration =50.97s
#
# 368
# Epoch duration =0.14s
# Cumulative duration =51.11s
#
# 369
# Epoch duration =0.14s
# Cumulative duration =51.24s
#
# 370
# Epoch duration =0.14s
# Cumulative duration =51.38s
#
# 371
# Epoch duration =0.13s
# Cumulative duration =51.51s
#
# 372
# Epoch duration =0.14s
# Cumulative duration =51.65s
#
# 373
# Epoch duration =0.14s
# Cumulative duration =51.79s
#
# 374
# Epoch duration =0.13s
# Cumulative duration =51.92s
#
# 375
# Epoch duration =0.13s
# Cumulative duration =52.05s
#
# 376
# Epoch duration =0.14s
# Cumulative duration =52.19s
#
# 377
# Epoch duration =0.14s
# Cumulative duration =52.33s
#
# 378
# Epoch duration =0.13s
# Cumulative duration =52.46s
#
# 379
# Epoch duration =0.13s
# Cumulative duration =52.59s
#
# 380
# Epoch duration =0.13s
# Cumulative duration =52.73s
#
# 381
# Epoch duration =0.15s
# Cumulative duration =52.88s
#
# 382
# Epoch duration =0.14s
# Cumulative duration =53.01s
#
# 383
# Epoch duration =0.14s
# Cumulative duration =53.15s
#
# 384
# Epoch duration =0.15s
# Cumulative duration =53.3s
#
# 385
# Epoch duration =0.13s
# Cumulative duration =53.43s
#
# 386
# Epoch duration =0.14s
# Cumulative duration =53.57s
#
# 387
# Epoch duration =0.13s
# Cumulative duration =53.7s
#
# 388
# Epoch duration =0.13s
# Cumulative duration =53.84s
#
# 389
# Epoch duration =0.13s
# Cumulative duration =53.97s
#
# 390
# Epoch duration =0.14s
# Cumulative duration =54.12s
#
# 391
# Epoch duration =0.14s
# Cumulative duration =54.25s
#
# 392
# Epoch duration =0.14s
# Cumulative duration =54.39s
#
# 393
# Epoch duration =0.14s
# Cumulative duration =54.53s
#
# 394
# Epoch duration =0.17s
# Cumulative duration =54.7s
#
# 395
# Epoch duration =0.16s
# Cumulative duration =54.86s
#
# 396
# Epoch duration =0.18s
# Cumulative duration =55.03s
#
# 397
# Epoch duration =0.17s
# Cumulative duration =55.21s
#
# 398
# Epoch duration =0.14s
# Cumulative duration =55.34s
#
# 399
# Epoch duration =0.14s
# Cumulative duration =55.48s
#
# 400
# Epoch duration =0.14s
# Cumulative duration =55.62s
#
# 401
# Epoch duration =0.14s
# Cumulative duration =55.76s
#
# 402
# Epoch duration =0.15s
# Cumulative duration =55.91s
#
# 403
# Epoch duration =0.13s
# Cumulative duration =56.04s
#
# 404
# Epoch duration =0.15s
# Cumulative duration =56.19s
#
# 405
# Epoch duration =0.14s
# Cumulative duration =56.33s
#
# 406
# Epoch duration =0.15s
# Cumulative duration =56.48s
#
# 407
# Epoch duration =0.14s
# Cumulative duration =56.63s
#
# 408
# Epoch duration =0.14s
# Cumulative duration =56.76s
#
# 409
# Epoch duration =0.16s
# Cumulative duration =56.92s
#
# 410
# Epoch duration =0.19s
# Cumulative duration =57.11s
#
# 411
# Epoch duration =0.16s
# Cumulative duration =57.27s
#
# 412
# Epoch duration =0.14s
# Cumulative duration =57.41s
#
# 413
# Epoch duration =0.13s
# Cumulative duration =57.54s
#
# 414
# Epoch duration =0.14s
# Cumulative duration =57.68s
#
# 415
# Epoch duration =0.14s
# Cumulative duration =57.82s
#
# 416
# Epoch duration =0.14s
# Cumulative duration =57.96s
#
# 417
# Epoch duration =0.14s
# Cumulative duration =58.09s
#
# 418
# Epoch duration =0.14s
# Cumulative duration =58.23s
#
# 419
# Epoch duration =0.14s
# Cumulative duration =58.37s
#
# 420
# Epoch duration =0.15s
# Cumulative duration =58.52s
#
# 421
# Epoch duration =0.15s
# Cumulative duration =58.67s
#
# 422
# Epoch duration =0.17s
# Cumulative duration =58.83s
#
# 423
# Epoch duration =0.16s
# Cumulative duration =58.99s
#
# 424
# Epoch duration =0.14s
# Cumulative duration =59.13s
#
# 425
# Epoch duration =0.14s
# Cumulative duration =59.26s
#
# 426
# Epoch duration =0.14s
# Cumulative duration =59.4s
#
# 427
# Epoch duration =0.14s
# Cumulative duration =59.54s
#
# 428
# Epoch duration =0.14s
# Cumulative duration =59.68s
#
# 429
# Epoch duration =0.14s
# Cumulative duration =59.81s
#
# 430
# Epoch duration =0.14s
# Cumulative duration =59.95s
#
# 431
# Epoch duration =0.13s
# Cumulative duration =60.09s
#
# 432
# Epoch duration =0.13s
# Cumulative duration =60.22s
#
# 433
# Epoch duration =0.17s
# Cumulative duration =60.39s
#
# 434
# Epoch duration =0.16s
# Cumulative duration =60.55s
#
# 435
# Epoch duration =0.13s
# Cumulative duration =60.69s
#
# 436
# Epoch duration =0.14s
# Cumulative duration =60.82s
#
# 437
# Epoch duration =0.14s
# Cumulative duration =60.96s
#
# 438
# Epoch duration =0.13s
# Cumulative duration =61.09s
#
# 439
# Epoch duration =0.13s
# Cumulative duration =61.22s
#
# 440
# Epoch duration =0.14s
# Cumulative duration =61.36s
#
# 441
# Epoch duration =0.13s
# Cumulative duration =61.49s
#
# 442
# Epoch duration =0.14s
# Cumulative duration =61.63s
#
# 443
# Epoch duration =0.14s
# Cumulative duration =61.77s
#
# 444
# Epoch duration =0.15s
# Cumulative duration =61.92s
#
# 445
# Epoch duration =0.14s
# Cumulative duration =62.06s
#
# 446
# Epoch duration =0.13s
# Cumulative duration =62.2s
#
# 447
# Epoch duration =0.13s
# Cumulative duration =62.33s
#
# 448
# Epoch duration =0.14s
# Cumulative duration =62.47s
#
# 449
# Epoch duration =0.14s
# Cumulative duration =62.61s
#
# 450
# Epoch duration =0.14s
# Cumulative duration =62.75s
#
# 451
# Epoch duration =0.14s
# Cumulative duration =62.88s
#
# 452
# Epoch duration =0.14s
# Cumulative duration =63.02s
#
# 453
# Epoch duration =0.13s
# Cumulative duration =63.16s
#
# 454
# Epoch duration =0.14s
# Cumulative duration =63.29s
#
# 455
# Epoch duration =0.13s
# Cumulative duration =63.42s
#
# 456
# Epoch duration =0.15s
# Cumulative duration =63.57s
#
# 457
# Epoch duration =0.14s
# Cumulative duration =63.72s
#
# 458
# Epoch duration =0.17s
# Cumulative duration =63.89s
#
# 459
# Epoch duration =0.13s
# Cumulative duration =64.02s
#
# 460
# Epoch duration =0.14s
# Cumulative duration =64.16s
#
# 461
# Epoch duration =0.13s
# Cumulative duration =64.3s
#
# 462
# Epoch duration =0.14s
# Cumulative duration =64.43s
#
# 463
# Epoch duration =0.19s
# Cumulative duration =64.62s
#
# 464
# Epoch duration =0.14s
# Cumulative duration =64.76s
#
# 465
# Epoch duration =0.13s
# Cumulative duration =64.89s
#
# 466
# Epoch duration =0.15s
# Cumulative duration =65.04s
#
# 467
# Epoch duration =0.15s
# Cumulative duration =65.19s
#
# 468
# Epoch duration =0.14s
# Cumulative duration =65.33s
#
# 469
# Epoch duration =0.13s
# Cumulative duration =65.46s
#
# 470
# Epoch duration =0.15s
# Cumulative duration =65.62s
#
# 471
# Epoch duration =0.13s
# Cumulative duration =65.75s
#
# 472
# Epoch duration =0.14s
# Cumulative duration =65.89s
#
# 473
# Epoch duration =0.13s
# Cumulative duration =66.02s
#
# 474
# Epoch duration =0.14s
# Cumulative duration =66.16s
#
# 475
# Epoch duration =0.14s
# Cumulative duration =66.3s
#
# 476
# Epoch duration =0.15s
# Cumulative duration =66.45s
#
# 477
# Epoch duration =0.14s
# Cumulative duration =66.59s
#
# 478
# Epoch duration =0.14s
# Cumulative duration =66.73s
#
# 479
# Epoch duration =0.14s
# Cumulative duration =66.87s
#
# 480
# Epoch duration =0.14s
# Cumulative duration =67.01s
#
# 481
# Epoch duration =0.14s
# Cumulative duration =67.15s
#
# 482
# Epoch duration =0.14s
# Cumulative duration =67.29s
#
# 483
# Epoch duration =0.15s
# Cumulative duration =67.44s
#
# 484
# Epoch duration =0.16s
# Cumulative duration =67.6s
#
# 485
# Epoch duration =0.16s
# Cumulative duration =67.75s
#
# 486
# Epoch duration =0.14s
# Cumulative duration =67.89s
#
# 487
# Epoch duration =0.15s
# Cumulative duration =68.05s
#
# 488
# Epoch duration =0.14s
# Cumulative duration =68.19s
#
# 489
# Epoch duration =0.13s
# Cumulative duration =68.32s
#
# 490
# Epoch duration =0.13s
# Cumulative duration =68.46s
#
# 491
# Epoch duration =0.13s
# Cumulative duration =68.59s
#
# 492
# Epoch duration =0.14s
# Cumulative duration =68.73s
#
# 493
# Epoch duration =0.14s
# Cumulative duration =68.87s
#
# 494
# Epoch duration =0.14s
# Cumulative duration =69.01s
#
# 495
# Epoch duration =0.13s
# Cumulative duration =69.14s
#
# 496
# Epoch duration =0.14s
# Cumulative duration =69.28s
#
# 497
# Epoch duration =0.13s
# Cumulative duration =69.41s
#
# 498
# Epoch duration =0.14s
# Cumulative duration =69.55s
#
# 499
# Epoch duration =0.13s
# Cumulative duration =69.68s
#
# 500
# Epoch duration =0.13s
# Cumulative duration =69.82s
#
# 501
# Epoch duration =0.13s
# Cumulative duration =69.95s
#
# 502
# Epoch duration =0.14s
# Cumulative duration =70.09s
#
# 503
# Epoch duration =0.13s
# Cumulative duration =70.23s
#
# 504
# Epoch duration =0.14s
# Cumulative duration =70.36s
#
# 505
# Epoch duration =0.14s
# Cumulative duration =70.5s
#
# 506
# Epoch duration =0.13s
# Cumulative duration =70.64s
#
# 507
# Epoch duration =0.14s
# Cumulative duration =70.77s
#
# 508
# Epoch duration =0.14s
# Cumulative duration =70.91s
#
# 509
# Epoch duration =0.14s
# Cumulative duration =71.05s
#
# 510
# Epoch duration =0.15s
# Cumulative duration =71.21s
#
# 511
# Epoch duration =0.17s
# Cumulative duration =71.38s
#
# 512
# Epoch duration =0.14s
# Cumulative duration =71.51s
#
# 513
# Epoch duration =0.14s
# Cumulative duration =71.65s
#
# 514
# Epoch duration =0.14s
# Cumulative duration =71.79s
#
# 515
# Epoch duration =0.14s
# Cumulative duration =71.93s
#
# 516
# Epoch duration =0.13s
# Cumulative duration =72.06s
#
# 517
# Epoch duration =0.13s
# Cumulative duration =72.2s
#
# 518
# Epoch duration =0.15s
# Cumulative duration =72.35s
#
# 519
# Epoch duration =0.14s
# Cumulative duration =72.49s
#
# 520
# Epoch duration =0.14s
# Cumulative duration =72.62s
#
# 521
# Epoch duration =0.14s
# Cumulative duration =72.76s
#
# 522
# Epoch duration =0.14s
# Cumulative duration =72.9s
#
# 523
# Epoch duration =0.13s
# Cumulative duration =73.03s
#
# 524
# Epoch duration =0.13s
# Cumulative duration =73.16s
#
# 525
# Epoch duration =0.14s
# Cumulative duration =73.3s
#
# 526
# Epoch duration =0.14s
# Cumulative duration =73.43s
#
# 527
# Epoch duration =0.14s
# Cumulative duration =73.57s
#
# 528
# Epoch duration =0.14s
# Cumulative duration =73.71s
#
# 529
# Epoch duration =0.14s
# Cumulative duration =73.85s
#
# 530
# Epoch duration =0.15s
# Cumulative duration =74.0s
#
# 531
# Epoch duration =0.14s
# Cumulative duration =74.14s
#
# 532
# Epoch duration =0.14s
# Cumulative duration =74.27s
#
# 533
# Epoch duration =0.13s
# Cumulative duration =74.41s
#
# 534
# Epoch duration =0.13s
# Cumulative duration =74.54s
#
# 535
# Epoch duration =0.14s
# Cumulative duration =74.68s
#
# 536
# Epoch duration =0.14s
# Cumulative duration =74.82s
#
# 537
# Epoch duration =0.13s
# Cumulative duration =74.95s
#
# 538
# Epoch duration =0.13s
# Cumulative duration =75.09s
#
# 539
# Epoch duration =0.14s
# Cumulative duration =75.22s
#
# 540
# Epoch duration =0.15s
# Cumulative duration =75.38s
#
# 541
# Epoch duration =0.14s
# Cumulative duration =75.51s
#
# 542
# Epoch duration =0.15s
# Cumulative duration =75.67s
#
# 543
# Epoch duration =0.13s
# Cumulative duration =75.8s
#
# 544
# Epoch duration =0.14s
# Cumulative duration =75.94s
#
# 545
# Epoch duration =0.17s
# Cumulative duration =76.11s
#
# 546
# Epoch duration =0.14s
# Cumulative duration =76.25s
#
# 547
# Epoch duration =0.15s
# Cumulative duration =76.4s
#
# 548
# Epoch duration =0.14s
# Cumulative duration =76.53s
#
# 549
# Epoch duration =0.14s
# Cumulative duration =76.67s
#
# 550
# Epoch duration =0.15s
# Cumulative duration =76.82s
#
# 551
# Epoch duration =0.13s
# Cumulative duration =76.95s
#
# 552
# Epoch duration =0.14s
# Cumulative duration =77.1s
#
# 553
# Epoch duration =0.13s
# Cumulative duration =77.23s
#
# 554
# Epoch duration =0.13s
# Cumulative duration =77.36s
#
# 555
# Epoch duration =0.13s
# Cumulative duration =77.5s
#
# 556
# Epoch duration =0.14s
# Cumulative duration =77.63s
#
# 557
# Epoch duration =0.14s
# Cumulative duration =77.77s
#
# 558
# Epoch duration =0.14s
# Cumulative duration =77.9s
#
# 559
# Epoch duration =0.14s
# Cumulative duration =78.04s
#
# 560
# Epoch duration =0.14s
# Cumulative duration =78.18s
#
# 561
# Epoch duration =0.14s
# Cumulative duration =78.32s
#
# 562
# Epoch duration =0.14s
# Cumulative duration =78.45s
#
# 563
# Epoch duration =0.16s
# Cumulative duration =78.62s
#
# 564
# Epoch duration =0.14s
# Cumulative duration =78.76s
#
# 565
# Epoch duration =0.15s
# Cumulative duration =78.91s
#
# 566
# Epoch duration =0.14s
# Cumulative duration =79.05s
#
# 567
# Epoch duration =0.14s
# Cumulative duration =79.19s
#
# 568
# Epoch duration =0.15s
# Cumulative duration =79.34s
#
# 569
# Epoch duration =0.13s
# Cumulative duration =79.48s
#
# 570
# Epoch duration =0.15s
# Cumulative duration =79.63s
#
# 571
# Epoch duration =0.14s
# Cumulative duration =79.77s
#
# 572
# Epoch duration =0.18s
# Cumulative duration =79.95s
#
# 573
# Epoch duration =0.14s
# Cumulative duration =80.09s
#
# 574
# Epoch duration =0.14s
# Cumulative duration =80.23s
#
# 575
# Epoch duration =0.13s
# Cumulative duration =80.36s
#
# 576
# Epoch duration =0.14s
# Cumulative duration =80.5s
#
# 577
# Epoch duration =0.14s
# Cumulative duration =80.64s
#
# 578
# Epoch duration =0.15s
# Cumulative duration =80.79s
#
# 579
# Epoch duration =0.14s
# Cumulative duration =80.93s
#
# 580
# Epoch duration =0.15s
# Cumulative duration =81.08s
#
# 581
# Epoch duration =0.13s
# Cumulative duration =81.22s
#
# 582
# Epoch duration =0.14s
# Cumulative duration =81.35s
#
# 583
# Epoch duration =0.14s
# Cumulative duration =81.49s
#
# 584
# Epoch duration =0.13s
# Cumulative duration =81.62s
#
# 585
# Epoch duration =0.14s
# Cumulative duration =81.76s
#
# 586
# Epoch duration =0.14s
# Cumulative duration =81.9s
#
# 587
# Epoch duration =0.13s
# Cumulative duration =82.03s
#
# 588
# Epoch duration =0.14s
# Cumulative duration =82.17s
#
# 589
# Epoch duration =0.14s
# Cumulative duration =82.32s
#
# 590
# Epoch duration =0.17s
# Cumulative duration =82.48s
#
# 591
# Epoch duration =0.14s
# Cumulative duration =82.62s
#
# 592
# Epoch duration =0.14s
# Cumulative duration =82.76s
#
# 593
# Epoch duration =0.14s
# Cumulative duration =82.9s
#
# 594
# Epoch duration =0.15s
# Cumulative duration =83.06s
#
# 595
# Epoch duration =0.14s
# Cumulative duration =83.2s
#
# 596
# Epoch duration =0.14s
# Cumulative duration =83.34s
#
# 597
# Epoch duration =0.14s
# Cumulative duration =83.48s
#
# 598
# Epoch duration =0.14s
# Cumulative duration =83.61s
#
# 599
# Epoch duration =0.13s
# Cumulative duration =83.75s
#
# 600
# Epoch duration =0.14s
# Cumulative duration =83.88s
#
# 601
# Epoch duration =0.13s
# Cumulative duration =84.02s
#
# 602
# Epoch duration =0.14s
# Cumulative duration =84.15s
#
# 603
# Epoch duration =0.14s
# Cumulative duration =84.29s
#
# 604
# Epoch duration =0.14s
# Cumulative duration =84.43s
#
# 605
# Epoch duration =0.13s
# Cumulative duration =84.57s
#
# 606
# Epoch duration =0.14s
# Cumulative duration =84.71s
#
# 607
# Epoch duration =0.13s
# Cumulative duration =84.84s
#
# 608
# Epoch duration =0.15s
# Cumulative duration =84.99s
#
# 609
# Epoch duration =0.14s
# Cumulative duration =85.13s
#
# 610
# Epoch duration =0.14s
# Cumulative duration =85.27s
#
# 611
# Epoch duration =0.13s
# Cumulative duration =85.4s
#
# 612
# Epoch duration =0.16s
# Cumulative duration =85.56s
#
# 613
# Epoch duration =0.14s
# Cumulative duration =85.7s
#
# 614
# Epoch duration =0.14s
# Cumulative duration =85.84s
#
# 615
# Epoch duration =0.14s
# Cumulative duration =85.98s
#
# 616
# Epoch duration =0.14s
# Cumulative duration =86.11s
#
# 617
# Epoch duration =0.14s
# Cumulative duration =86.25s
#
# 618
# Epoch duration =0.17s
# Cumulative duration =86.43s
#
# 619
# Epoch duration =0.15s
# Cumulative duration =86.58s
#
# 620
# Epoch duration =0.14s
# Cumulative duration =86.71s
#
# 621
# Epoch duration =0.14s
# Cumulative duration =86.85s
#
# 622
# Epoch duration =0.18s
# Cumulative duration =87.03s
#
# 623
# Epoch duration =0.13s
# Cumulative duration =87.16s
#
# 624
# Epoch duration =0.15s
# Cumulative duration =87.31s
#
# 625
# Epoch duration =0.13s
# Cumulative duration =87.44s
#
# 626
# Epoch duration =0.14s
# Cumulative duration =87.58s
#
# 627
# Epoch duration =0.14s
# Cumulative duration =87.72s
#
# 628
# Epoch duration =0.14s
# Cumulative duration =87.86s
#
# 629
# Epoch duration =0.14s
# Cumulative duration =87.99s
#
# 630
# Epoch duration =0.14s
# Cumulative duration =88.14s
#
# 631
# Epoch duration =0.14s
# Cumulative duration =88.27s
#
# 632
# Epoch duration =0.14s
# Cumulative duration =88.41s
#
# 633
# Epoch duration =0.14s
# Cumulative duration =88.55s
#
# 634
# Epoch duration =0.14s
# Cumulative duration =88.69s
#
# 635
# Epoch duration =0.14s
# Cumulative duration =88.82s
#
# 636
# Epoch duration =0.14s
# Cumulative duration =88.96s
#
# 637
# Epoch duration =0.14s
# Cumulative duration =89.1s
#
# 638
# Epoch duration =0.16s
# Cumulative duration =89.27s
#
# 639
# Epoch duration =0.18s
# Cumulative duration =89.45s
#
# 640
# Epoch duration =0.17s
# Cumulative duration =89.62s
#
# 641
# Epoch duration =0.18s
# Cumulative duration =89.8s
#
# 642
# Epoch duration =0.17s
# Cumulative duration =89.97s
#
# 643
# Epoch duration =0.21s
# Cumulative duration =90.18s
#
# 644
# Epoch duration =0.2s
# Cumulative duration =90.38s
#
# 645
# Epoch duration =0.17s
# Cumulative duration =90.55s
#
# 646
# Epoch duration =0.15s
# Cumulative duration =90.7s
#
# 647
# Epoch duration =0.13s
# Cumulative duration =90.84s
#
# 648
# Epoch duration =0.14s
# Cumulative duration =90.97s
#
# 649
# Epoch duration =0.13s
# Cumulative duration =91.11s
#
# 650
# Epoch duration =0.14s
# Cumulative duration =91.25s
#
# 651
# Epoch duration =0.13s
# Cumulative duration =91.38s
#
# 652
# Epoch duration =0.15s
# Cumulative duration =91.53s
#
# 653
# Epoch duration =0.14s
# Cumulative duration =91.67s
#
# 654
# Epoch duration =0.14s
# Cumulative duration =91.82s
#
# 655
# Epoch duration =0.18s
# Cumulative duration =91.99s
#
# 656
# Epoch duration =0.14s
# Cumulative duration =92.13s
#
# 657
# Epoch duration =0.14s
# Cumulative duration =92.26s
#
# 658
# Epoch duration =0.14s
# Cumulative duration =92.4s
#
# 659
# Epoch duration =0.13s
# Cumulative duration =92.54s
#
# 660
# Epoch duration =0.16s
# Cumulative duration =92.7s
#
# 661
# Epoch duration =0.14s
# Cumulative duration =92.84s
#
# 662
# Epoch duration =0.16s
# Cumulative duration =93.0s
#
# 663
# Epoch duration =0.13s
# Cumulative duration =93.13s
#
# 664
# Epoch duration =0.14s
# Cumulative duration =93.27s
#
# 665
# Epoch duration =0.13s
# Cumulative duration =93.4s
#
# 666
# Epoch duration =0.14s
# Cumulative duration =93.54s
#
# 667
# Epoch duration =0.13s
# Cumulative duration =93.68s
#
# 668
# Epoch duration =0.14s
# Cumulative duration =93.82s
#
# 669
# Epoch duration =0.13s
# Cumulative duration =93.95s
#
# 670
# Epoch duration =0.14s
# Cumulative duration =94.09s
#
# 671
# Epoch duration =0.14s
# Cumulative duration =94.23s
#
# 672
# Epoch duration =0.15s
# Cumulative duration =94.39s
#
# 673
# Epoch duration =0.13s
# Cumulative duration =94.52s
#
# 674
# Epoch duration =0.13s
# Cumulative duration =94.66s
#
# 675
# Epoch duration =0.14s
# Cumulative duration =94.79s
#
# 676
# Epoch duration =0.13s
# Cumulative duration =94.93s
#
# 677
# Epoch duration =0.14s
# Cumulative duration =95.06s
#
# 678
# Epoch duration =0.15s
# Cumulative duration =95.22s
#
# 679
# Epoch duration =0.13s
# Cumulative duration =95.35s
#
# 680
# Epoch duration =0.14s
# Cumulative duration =95.49s
#
# 681
# Epoch duration =0.13s
# Cumulative duration =95.62s
#
# 682
# Epoch duration =0.14s
# Cumulative duration =95.76s
#
# 683
# Epoch duration =0.14s
# Cumulative duration =95.9s
#
# 684
# Epoch duration =0.14s
# Cumulative duration =96.04s
#
# 685
# Epoch duration =0.14s
# Cumulative duration =96.18s
#
# 686
# Epoch duration =0.14s
# Cumulative duration =96.31s
#
# 687
# Epoch duration =0.14s
# Cumulative duration =96.46s
#
# 688
# Epoch duration =0.14s
# Cumulative duration =96.59s
#
# 689
# Epoch duration =0.14s
# Cumulative duration =96.73s
#
# 690
# Epoch duration =0.14s
# Cumulative duration =96.87s
#
# 691
# Epoch duration =0.13s
# Cumulative duration =97.01s
#
# 692
# Epoch duration =0.13s
# Cumulative duration =97.14s
#
# 693
# Epoch duration =0.13s
# Cumulative duration =97.28s
#
# 694
# Epoch duration =0.14s
# Cumulative duration =97.41s
#
# 695
# Epoch duration =0.13s
# Cumulative duration =97.55s
#
# 696
# Epoch duration =0.15s
# Cumulative duration =97.7s
#
# 697
# Epoch duration =0.15s
# Cumulative duration =97.86s
#
# 698
# Epoch duration =0.14s
# Cumulative duration =97.99s
#
# 699
# Epoch duration =0.15s
# Cumulative duration =98.14s
#
# 700
# Epoch duration =0.14s
# Cumulative duration =98.28s
#
# 701
# Epoch duration =0.13s
# Cumulative duration =98.41s
#
# 702
# Epoch duration =0.14s
# Cumulative duration =98.55s
#
# 703
# Epoch duration =0.14s
# Cumulative duration =98.69s
#
# 704
# Epoch duration =0.14s
# Cumulative duration =98.83s
#
# 705
# Epoch duration =0.14s
# Cumulative duration =98.97s
#
# 706
# Epoch duration =0.13s
# Cumulative duration =99.1s
#
# 707
# Epoch duration =0.14s
# Cumulative duration =99.24s
#
# 708
# Epoch duration =0.14s
# Cumulative duration =99.38s
#
# 709
# Epoch duration =0.13s
# Cumulative duration =99.51s
#
# 710
# Epoch duration =0.14s
# Cumulative duration =99.65s
#
# 711
# Epoch duration =0.14s
# Cumulative duration =99.79s
#
# 712
# Epoch duration =0.14s
# Cumulative duration =99.93s
#
# 713
# Epoch duration =0.14s
# Cumulative duration =100.07s
#
# 714
# Epoch duration =0.13s
# Cumulative duration =100.2s
#
# 715
# Epoch duration =0.14s
# Cumulative duration =100.34s
#
# 716
# Epoch duration =0.16s
# Cumulative duration =100.5s
#
# 717
# Epoch duration =0.13s
# Cumulative duration =100.63s
#
# 718
# Epoch duration =0.14s
# Cumulative duration =100.77s
#
# 719
# Epoch duration =0.14s
# Cumulative duration =100.91s
#
# 720
# Epoch duration =0.14s
# Cumulative duration =101.04s
#
# 721
# Epoch duration =0.14s
# Cumulative duration =101.18s
#
# 722
# Epoch duration =0.14s
# Cumulative duration =101.32s
#
# 723
# Epoch duration =0.13s
# Cumulative duration =101.45s
#
# 724
# Epoch duration =0.14s
# Cumulative duration =101.59s
#
# 725
# Epoch duration =0.13s
# Cumulative duration =101.73s
#
# 726
# Epoch duration =0.14s
# Cumulative duration =101.87s
#
# 727
# Epoch duration =0.13s
# Cumulative duration =102.0s
#
# 728
# Epoch duration =0.14s
# Cumulative duration =102.14s
#
# 729
# Epoch duration =0.14s
# Cumulative duration =102.28s
#
# 730
# Epoch duration =0.14s
# Cumulative duration =102.42s
#
# 731
# Epoch duration =0.14s
# Cumulative duration =102.56s
#
# 732
# Epoch duration =0.14s
# Cumulative duration =102.7s
#
# 733
# Epoch duration =0.13s
# Cumulative duration =102.83s
#
# 734
# Epoch duration =0.14s
# Cumulative duration =102.97s
#
# 735
# Epoch duration =0.13s
# Cumulative duration =103.11s
#
# 736
# Epoch duration =0.14s
# Cumulative duration =103.24s
#
# 737
# Epoch duration =0.14s
# Cumulative duration =103.38s
#
# 738
# Epoch duration =0.14s
# Cumulative duration =103.52s
#
# 739
# Epoch duration =0.17s
# Cumulative duration =103.69s
#
# 740
# Epoch duration =0.15s
# Cumulative duration =103.84s
#
# 741
# Epoch duration =0.15s
# Cumulative duration =103.98s
#
# 742
# Epoch duration =0.14s
# Cumulative duration =104.12s
#
# 743
# Epoch duration =0.16s
# Cumulative duration =104.28s
#
# 744
# Epoch duration =0.14s
# Cumulative duration =104.42s
#
# 745
# Epoch duration =0.14s
# Cumulative duration =104.56s
#
# 746
# Epoch duration =0.14s
# Cumulative duration =104.69s
#
# 747
# Epoch duration =0.13s
# Cumulative duration =104.82s
#
# 748
# Epoch duration =0.16s
# Cumulative duration =104.98s
#
# 749
# Epoch duration =0.13s
# Cumulative duration =105.11s
#
# 750
# Epoch duration =0.14s
# Cumulative duration =105.25s
#
# 751
# Epoch duration =0.13s
# Cumulative duration =105.38s
#
# 752
# Epoch duration =0.14s
# Cumulative duration =105.52s
#
# 753
# Epoch duration =0.13s
# Cumulative duration =105.65s
#
# 754
# Epoch duration =0.13s
# Cumulative duration =105.79s
#
# 755
# Epoch duration =0.14s
# Cumulative duration =105.93s
#
# 756
# Epoch duration =0.14s
# Cumulative duration =106.06s
#
# 757
# Epoch duration =0.14s
# Cumulative duration =106.2s
#
# 758
# Epoch duration =0.15s
# Cumulative duration =106.35s
#
# 759
# Epoch duration =0.19s
# Cumulative duration =106.54s
#
# 760
# Epoch duration =0.2s
# Cumulative duration =106.73s
#
# 761
# Epoch duration =0.14s
# Cumulative duration =106.88s
#
# 762
# Epoch duration =0.14s
# Cumulative duration =107.02s
#
# 763
# Epoch duration =0.14s
# Cumulative duration =107.16s
#
# 764
# Epoch duration =0.14s
# Cumulative duration =107.29s
#
# 765
# Epoch duration =0.13s
# Cumulative duration =107.43s
#
# 766
# Epoch duration =0.14s
# Cumulative duration =107.57s
#
# 767
# Epoch duration =0.14s
# Cumulative duration =107.7s
#
# 768
# Epoch duration =0.16s
# Cumulative duration =107.86s
#
# 769
# Epoch duration =0.14s
# Cumulative duration =108.0s
#
# 770
# Epoch duration =0.15s
# Cumulative duration =108.15s
#
# 771
# Epoch duration =0.13s
# Cumulative duration =108.28s
#
# 772
# Epoch duration =0.14s
# Cumulative duration =108.42s
#
# 773
# Epoch duration =0.13s
# Cumulative duration =108.55s
#
# 774
# Epoch duration =0.14s
# Cumulative duration =108.69s
#
# 775
# Epoch duration =0.15s
# Cumulative duration =108.83s
#
# 776
# Epoch duration =0.15s
# Cumulative duration =108.98s
#
# 777
# Epoch duration =0.14s
# Cumulative duration =109.12s
#
# 778
# Epoch duration =0.14s
# Cumulative duration =109.26s
#
# 779
# Epoch duration =0.14s
# Cumulative duration =109.4s
#
# 780
# Epoch duration =0.13s
# Cumulative duration =109.53s
#
# 781
# Epoch duration =0.14s
# Cumulative duration =109.67s
#
# 782
# Epoch duration =0.14s
# Cumulative duration =109.81s
#
# 783
# Epoch duration =0.13s
# Cumulative duration =109.94s
#
# 784
# Epoch duration =0.14s
# Cumulative duration =110.08s
#
# 785
# Epoch duration =0.14s
# Cumulative duration =110.23s
#
# 786
# Epoch duration =0.14s
# Cumulative duration =110.36s
#
# 787
# Epoch duration =0.14s
# Cumulative duration =110.5s
#
# 788
# Epoch duration =0.14s
# Cumulative duration =110.64s
#
# 789
# Epoch duration =0.14s
# Cumulative duration =110.78s
#
# 790
# Epoch duration =0.15s
# Cumulative duration =110.93s
#
# 791
# Epoch duration =0.13s
# Cumulative duration =111.06s
#
# 792
# Epoch duration =0.15s
# Cumulative duration =111.21s
#
# 793
# Epoch duration =0.15s
# Cumulative duration =111.36s
#
# 794
# Epoch duration =0.16s
# Cumulative duration =111.52s
#
# 795
# Epoch duration =0.16s
# Cumulative duration =111.68s
#
# 796
# Epoch duration =0.15s
# Cumulative duration =111.83s
#
# 797
# Epoch duration =0.13s
# Cumulative duration =111.96s
#
# 798
# Epoch duration =0.13s
# Cumulative duration =112.1s
#
# 799
# Epoch duration =0.13s
# Cumulative duration =112.23s
#
# 800
# Epoch duration =0.14s
# Cumulative duration =112.37s
#
# 801
# Epoch duration =0.15s
# Cumulative duration =112.52s
#
# 802
# Epoch duration =0.14s
# Cumulative duration =112.66s
#
# 803
# Epoch duration =0.13s
# Cumulative duration =112.8s
#
# 804
# Epoch duration =0.14s
# Cumulative duration =112.94s
#
# 805
# Epoch duration =0.14s
# Cumulative duration =113.07s
#
# 806
# Epoch duration =0.14s
# Cumulative duration =113.21s
#
# 807
# Epoch duration =0.14s
# Cumulative duration =113.34s
#
# 808
# Epoch duration =0.14s
# Cumulative duration =113.48s
#
# 809
# Epoch duration =0.14s
# Cumulative duration =113.62s
#
# 810
# Epoch duration =0.14s
# Cumulative duration =113.75s
#
# 811
# Epoch duration =0.13s
# Cumulative duration =113.89s
#
# 812
# Epoch duration =0.14s
# Cumulative duration =114.03s
#
# 813
# Epoch duration =0.14s
# Cumulative duration =114.17s
#
# 814
# Epoch duration =0.14s
# Cumulative duration =114.31s
#
# 815
# Epoch duration =0.13s
# Cumulative duration =114.44s
#
# 816
# Epoch duration =0.13s
# Cumulative duration =114.58s
#
# 817
# Epoch duration =0.13s
# Cumulative duration =114.71s
#
# 818
# Epoch duration =0.14s
# Cumulative duration =114.85s
#
# 819
# Epoch duration =0.14s
# Cumulative duration =114.99s
#
# 820
# Epoch duration =0.13s
# Cumulative duration =115.13s
#
# 821
# Epoch duration =0.14s
# Cumulative duration =115.27s
#
# 822
# Epoch duration =0.14s
# Cumulative duration =115.41s
#
# 823
# Epoch duration =0.13s
# Cumulative duration =115.54s
#
# 824
# Epoch duration =0.14s
# Cumulative duration =115.68s
#
# 825
# Epoch duration =0.13s
# Cumulative duration =115.82s
#
# 826
# Epoch duration =0.16s
# Cumulative duration =115.98s
#
# 827
# Epoch duration =0.13s
# Cumulative duration =116.11s
#
# 828
# Epoch duration =0.14s
# Cumulative duration =116.25s
#
# 829
# Epoch duration =0.13s
# Cumulative duration =116.38s
#
# 830
# Epoch duration =0.16s
# Cumulative duration =116.54s
#
# 831
# Epoch duration =0.13s
# Cumulative duration =116.68s
#
# 832
# Epoch duration =0.14s
# Cumulative duration =116.81s
#
# 833
# Epoch duration =0.14s
# Cumulative duration =116.96s
#
# 834
# Epoch duration =0.14s
# Cumulative duration =117.09s
#
# 835
# Epoch duration =0.14s
# Cumulative duration =117.23s
#
# 836
# Epoch duration =0.14s
# Cumulative duration =117.37s
#
# 837
# Epoch duration =0.16s
# Cumulative duration =117.53s
#
# 838
# Epoch duration =0.14s
# Cumulative duration =117.67s
#
# 839
# Epoch duration =0.14s
# Cumulative duration =117.81s
#
# 840
# Epoch duration =0.15s
# Cumulative duration =117.96s
#
# 841
# Epoch duration =0.13s
# Cumulative duration =118.09s
#
# 842
# Epoch duration =0.14s
# Cumulative duration =118.23s
#
# 843
# Epoch duration =0.16s
# Cumulative duration =118.39s
#
# 844
# Epoch duration =0.14s
# Cumulative duration =118.53s
#
# 845
# Epoch duration =0.13s
# Cumulative duration =118.66s
#
# 846
# Epoch duration =0.14s
# Cumulative duration =118.81s
#
# 847
# Epoch duration =0.15s
# Cumulative duration =118.96s
#
# 848
# Epoch duration =0.16s
# Cumulative duration =119.12s
#
# 849
# Epoch duration =0.13s
# Cumulative duration =119.25s
#
# 850
# Epoch duration =0.15s
# Cumulative duration =119.4s
#
# 851
# Epoch duration =0.14s
# Cumulative duration =119.54s
#
# 852
# Epoch duration =0.14s
# Cumulative duration =119.68s
#
# 853
# Epoch duration =0.15s
# Cumulative duration =119.83s
#
# 854
# Epoch duration =0.14s
# Cumulative duration =119.97s
#
# 855
# Epoch duration =0.13s
# Cumulative duration =120.1s
#
# 856
# Epoch duration =0.14s
# Cumulative duration =120.24s
#
# 857
# Epoch duration =0.14s
# Cumulative duration =120.37s
#
# 858
# Epoch duration =0.14s
# Cumulative duration =120.51s
#
# 859
# Epoch duration =0.14s
# Cumulative duration =120.65s
#
# 860
# Epoch duration =0.14s
# Cumulative duration =120.78s
#
# 861
# Epoch duration =0.13s
# Cumulative duration =120.92s
#
# 862
# Epoch duration =0.14s
# Cumulative duration =121.06s
#
# 863
# Epoch duration =0.13s
# Cumulative duration =121.19s
#
# 864
# Epoch duration =0.14s
# Cumulative duration =121.33s
#
# 865
# Epoch duration =0.14s
# Cumulative duration =121.47s
#
# 866
# Epoch duration =0.14s
# Cumulative duration =121.61s
#
# 867
# Epoch duration =0.13s
# Cumulative duration =121.74s
#
# 868
# Epoch duration =0.14s
# Cumulative duration =121.88s
#
# 869
# Epoch duration =0.14s
# Cumulative duration =122.01s
#
# 870
# Epoch duration =0.15s
# Cumulative duration =122.16s
#
# 871
# Epoch duration =0.13s
# Cumulative duration =122.3s
#
# 872
# Epoch duration =0.14s
# Cumulative duration =122.43s
#
# 873
# Epoch duration =0.13s
# Cumulative duration =122.57s
#
# 874
# Epoch duration =0.14s
# Cumulative duration =122.71s
#
# 875
# Epoch duration =0.13s
# Cumulative duration =122.84s
#
# 876
# Epoch duration =0.14s
# Cumulative duration =122.99s
#
# 877
# Epoch duration =0.13s
# Cumulative duration =123.12s
#
# 878
# Epoch duration =0.14s
# Cumulative duration =123.26s
#
# 879
# Epoch duration =0.14s
# Cumulative duration =123.39s
#
# 880
# Epoch duration =0.14s
# Cumulative duration =123.53s
#
# 881
# Epoch duration =0.13s
# Cumulative duration =123.67s
#
# 882
# Epoch duration =0.14s
# Cumulative duration =123.8s
#
# 883
# Epoch duration =0.14s
# Cumulative duration =123.94s
#
# 884
# Epoch duration =0.14s
# Cumulative duration =124.08s
#
# 885
# Epoch duration =0.14s
# Cumulative duration =124.22s
#
# 886
# Epoch duration =0.14s
# Cumulative duration =124.36s
#
# 887
# Epoch duration =0.13s
# Cumulative duration =124.49s
#
# 888
# Epoch duration =0.14s
# Cumulative duration =124.63s
#
# 889
# Epoch duration =0.13s
# Cumulative duration =124.76s
#
# 890
# Epoch duration =0.14s
# Cumulative duration =124.9s
#
# 891
# Epoch duration =0.13s
# Cumulative duration =125.04s
#
# 892
# Epoch duration =0.14s
# Cumulative duration =125.17s
#
# 893
# Epoch duration =0.13s
# Cumulative duration =125.3s
#
# 894
# Epoch duration =0.14s
# Cumulative duration =125.45s
#
# 895
# Epoch duration =0.13s
# Cumulative duration =125.58s
#
# 896
# Epoch duration =0.14s
# Cumulative duration =125.72s
#
# 897
# Epoch duration =0.13s
# Cumulative duration =125.85s
#
# 898
# Epoch duration =0.14s
# Cumulative duration =125.99s
#
# 899
# Epoch duration =0.13s
# Cumulative duration =126.12s
#
# 900
# Epoch duration =0.14s
# Cumulative duration =126.26s
#
# 901
# Epoch duration =0.14s
# Cumulative duration =126.4s
#
# 902
# Epoch duration =0.16s
# Cumulative duration =126.55s
#
# 903
# Epoch duration =0.16s
# Cumulative duration =126.72s
#
# 904
# Epoch duration =0.16s
# Cumulative duration =126.88s
#
# 905
# Epoch duration =0.13s
# Cumulative duration =127.01s
#
# 906
# Epoch duration =0.14s
# Cumulative duration =127.15s
#
# 907
# Epoch duration =0.14s
# Cumulative duration =127.29s
#
# 908
# Epoch duration =0.14s
# Cumulative duration =127.43s
#
# 909
# Epoch duration =0.14s
# Cumulative duration =127.57s
#
# 910
# Epoch duration =0.14s
# Cumulative duration =127.7s
#
# 911
# Epoch duration =0.13s
# Cumulative duration =127.83s
#
# 912
# Epoch duration =0.15s
# Cumulative duration =127.98s
#
# 913
# Epoch duration =0.13s
# Cumulative duration =128.11s
#
# 914
# Epoch duration =0.14s
# Cumulative duration =128.25s
#
# 915
# Epoch duration =0.14s
# Cumulative duration =128.39s
#
# 916
# Epoch duration =0.14s
# Cumulative duration =128.53s
#
# 917
# Epoch duration =0.14s
# Cumulative duration =128.66s
#
# 918
# Epoch duration =0.14s
# Cumulative duration =128.8s
#
# 919
# Epoch duration =0.14s
# Cumulative duration =128.94s
#
# 920
# Epoch duration =0.14s
# Cumulative duration =129.07s
#
# 921
# Epoch duration =0.13s
# Cumulative duration =129.21s
#
# 922
# Epoch duration =0.14s
# Cumulative duration =129.35s
#
# 923
# Epoch duration =0.14s
# Cumulative duration =129.48s
#
# 924
# Epoch duration =0.15s
# Cumulative duration =129.63s
#
# 925
# Epoch duration =0.14s
# Cumulative duration =129.77s
#
# 926
# Epoch duration =0.15s
# Cumulative duration =129.92s
#
# 927
# Epoch duration =0.15s
# Cumulative duration =130.07s
#
# 928
# Epoch duration =0.14s
# Cumulative duration =130.21s
#
# 929
# Epoch duration =0.14s
# Cumulative duration =130.34s
#
# 930
# Epoch duration =0.14s
# Cumulative duration =130.48s
#
# 931
# Epoch duration =0.16s
# Cumulative duration =130.64s
#
# 932
# Epoch duration =0.14s
# Cumulative duration =130.78s
#
# 933
# Epoch duration =0.15s
# Cumulative duration =130.93s
#
# 934
# Epoch duration =0.17s
# Cumulative duration =131.1s
#
# 935
# Epoch duration =0.15s
# Cumulative duration =131.26s
#
# 936
# Epoch duration =0.16s
# Cumulative duration =131.42s
#
# 937
# Epoch duration =0.13s
# Cumulative duration =131.55s
#
# 938
# Epoch duration =0.15s
# Cumulative duration =131.7s
#
# 939
# Epoch duration =0.17s
# Cumulative duration =131.87s
#
# 940
# Epoch duration =0.14s
# Cumulative duration =132.01s
#
# 941
# Epoch duration =0.14s
# Cumulative duration =132.15s
#
# 942
# Epoch duration =0.14s
# Cumulative duration =132.29s
#
# 943
# Epoch duration =0.14s
# Cumulative duration =132.43s
#
# 944
# Epoch duration =0.14s
# Cumulative duration =132.57s
#
# 945
# Epoch duration =0.14s
# Cumulative duration =132.71s
#
# 946
# Epoch duration =0.14s
# Cumulative duration =132.85s
#
# 947
# Epoch duration =0.15s
# Cumulative duration =132.99s
#
# 948
# Epoch duration =0.14s
# Cumulative duration =133.13s
#
# 949
# Epoch duration =0.14s
# Cumulative duration =133.27s
#
# 950
# Epoch duration =0.16s
# Cumulative duration =133.43s
#
# 951
# Epoch duration =0.14s
# Cumulative duration =133.56s
#
# 952
# Epoch duration =0.16s
# Cumulative duration =133.72s
#
# 953
# Epoch duration =0.13s
# Cumulative duration =133.86s
#
# 954
# Epoch duration =0.14s
# Cumulative duration =134.0s
#
# 955
# Epoch duration =0.22s
# Cumulative duration =134.21s
#
# 956
# Epoch duration =0.14s
# Cumulative duration =134.35s
#
# 957
# Epoch duration =0.14s
# Cumulative duration =134.49s
#
# 958
# Epoch duration =0.14s
# Cumulative duration =134.63s
#
# 959
# Epoch duration =0.16s
# Cumulative duration =134.79s
#
# 960
# Epoch duration =0.14s
# Cumulative duration =134.93s
#
# 961
# Epoch duration =0.14s
# Cumulative duration =135.07s
#
# 962
# Epoch duration =0.14s
# Cumulative duration =135.21s
#
# 963
# Epoch duration =0.14s
# Cumulative duration =135.34s
#
# 964
# Epoch duration =0.15s
# Cumulative duration =135.5s
#
# 965
# Epoch duration =0.14s
# Cumulative duration =135.63s
#
# 966
# Epoch duration =0.14s
# Cumulative duration =135.77s
#
# 967
# Epoch duration =0.14s
# Cumulative duration =135.9s
#
# 968
# Epoch duration =0.13s
# Cumulative duration =136.04s
#
# 969
# Epoch duration =0.14s
# Cumulative duration =136.18s
#
# 970
# Epoch duration =0.14s
# Cumulative duration =136.32s
#
# 971
# Epoch duration =0.16s
# Cumulative duration =136.48s
#
# 972
# Epoch duration =0.14s
# Cumulative duration =136.62s
#
# 973
# Epoch duration =0.15s
# Cumulative duration =136.77s
#
# 974
# Epoch duration =0.14s
# Cumulative duration =136.91s
#
# 975
# Epoch duration =0.14s
# Cumulative duration =137.05s
#
# 976
# Epoch duration =0.13s
# Cumulative duration =137.18s
#
# 977
# Epoch duration =0.14s
# Cumulative duration =137.32s
#
# 978
# Epoch duration =0.14s
# Cumulative duration =137.45s
#
# 979
# Epoch duration =0.14s
# Cumulative duration =137.59s
#
# 980
# Epoch duration =0.14s
# Cumulative duration =137.73s
#
# 981
# Epoch duration =0.14s
# Cumulative duration =137.87s
#
# 982
# Epoch duration =0.14s
# Cumulative duration =138.01s
#
# 983
# Epoch duration =0.16s
# Cumulative duration =138.17s
#
# 984
# Epoch duration =0.13s
# Cumulative duration =138.3s
#
# 985
# Epoch duration =0.14s
# Cumulative duration =138.44s
#
# 986
# Epoch duration =0.13s
# Cumulative duration =138.58s
#
# 987
# Epoch duration =0.14s
# Cumulative duration =138.72s
#
# 988
# Epoch duration =0.13s
# Cumulative duration =138.85s
#
# 989
# Epoch duration =0.14s
# Cumulative duration =138.99s
#
# 990
# Epoch duration =0.14s
# Cumulative duration =139.13s
#
# 991
# Epoch duration =0.14s
# Cumulative duration =139.27s
#
# 992
# Epoch duration =0.14s
# Cumulative duration =139.4s
#
# 993
# Epoch duration =0.14s
# Cumulative duration =139.54s
#
# 994
# Epoch duration =0.13s
# Cumulative duration =139.68s
#
# 995
# Epoch duration =0.14s
# Cumulative duration =139.82s
#
# 996
# Epoch duration =0.14s
# Cumulative duration =139.95s
#
# 997
# Epoch duration =0.14s
# Cumulative duration =140.09s
#
# 998
# Epoch duration =0.13s
# Cumulative duration =140.23s
#
# 999
# Epoch duration =0.14s
# Cumulative duration =140.37s

# %%
#Load the saved data
sum_mut2_predictoutputs = np.load('Arrays/toyhairpin_FC_1_64_sumoutputs1000.npy')

#average the values
num_summary = 1000
mean_mut2_predictoutputs = sum_mut2_predictoutputs/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_predictoutputs_hol = mean_mut2_predictoutputs.reshape(X.shape[1],X.shape[1],4,4)

# %% [markdown]
# ## Signatures

# %% [markdown]
# ### First 20

# %%
nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(10,7))

num = 20

for ii in range(num):
    ax = fig4.add_subplot(4,5,ii+1)
    ax.set_title(str(ii)+','+str(40-ii))
    ax = sb.heatmap(mean_mut2_predictoutputs_hol[ii, 40-ii], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc)

# %% [markdown]
# ### All bases Paired (editted visuals)

# %%
nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(15,14))

num = 15

for one in range(num):
    for two in range(num):
        ax = fig4.add_subplot(num, num, ((one*num)+two)+1)
        
        #plot the 0th column with row labels and the num_th most row with column labels
        if two == 0:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc, cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=nuc, cbar=False)
        else:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=[], cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=[], cbar=False)

# %% [markdown]
# ## Test averages of larger amounts of the data

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_summary = 3000

sum_mut2_predictoutputs = np.zeros((41*41*16, 1))
starttime = time.time()

for ii in range(num_summary):
    print (ii)
    epoch_starttime = time.time()
    
    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    #mutate the sequence
    X_mutsecorder = mf.double_mutate(X, X.shape[1], X.shape[3])

    #reshape the 6D tensor into a 4D tensor that the model can test
    X_mutsecorder_reshape = np.reshape(X_mutsecorder, (X.shape[1]*X.shape[1]*16, X.shape[1], 1, 4))
    
    mutations = {'inputs': X_mutsecorder_reshape, 'targets': Y_test[:X_mutsecorder_reshape.shape[0]]}
    
    #Get output activations for the mutations
    mut2_predictoutputs= nntrainer.get_activations(sess, mutations, layer='output')
    
    #Sum all the scores into a single matrix
    sum_mut2_predictoutputs += mut2_predictoutputs
    
    epoch_endtime = time.time()
    
    print ('Epoch duration =' + str(np.around((epoch_endtime -epoch_starttime), 2)) + 's')
    print ('Cumulative duration =' + str(np.around((epoch_endtime - starttime), 2)) + 's')
    print ()
    
# Save the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_1_64_sumoutputs3000.npy'
np.save(npy_save_path, sum_mut2_predictoutputs)

# %%
#Load the saved data
sum_mut2_predictoutputs = np.load('Arrays/toyhairpin_FC_1_64_sumoutputs3000.npy')

num_summary = 3000
#average the values
mean_mut2_predictoutputs = sum_mut2_predictoutputs/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_predictoutputs_hol = mean_mut2_predictoutputs.reshape(X.shape[1],X.shape[1],4,4)

# %%
nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(10,7))

num = 20

for ii in range(num):
    ax = fig4.add_subplot(4,5,ii+1)
    ax.set_title(str(ii)+','+str(40-ii))
    ax = sb.heatmap(mean_mut2_predictoutputs_hol[ii, 40-ii], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc)

# %%
nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(15,14))

num = 15

for one in range(num):
    for two in range(num):
        ax = fig4.add_subplot(num, num, ((one*num)+two)+1)
        
        #plot the 0th column with row labels and the num_th most row with column labels
        if two == 0:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc, cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=nuc, cbar=False)
        else:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=[], cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], vmin=0., vmax=1., cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=[], cbar=False)

# %% [markdown]
# ## What is the model learning and how - Look at hidden layers

# %% [markdown]
# ### The final Dense layer parameters
#
# These give us an idea of the most important neurons for the model. In the final layer, the higher weights correspond to neurons the model wants to highlight in the output.

# %%
W = nnmodel.get_parameters(sess, layer='dense_1')[0]
W.shape
top_neurons=np.argsort(np.squeeze(W))[::-1]
top_neurons
# Out:
# array([12, 47, 57, 51, 42,  6, 52,  3,  9, 35, 48, 27, 18,  2, 54, 46, 19,
#        29, 41, 61,  8, 30, 49, 45, 10,  5, 17, 16, 15, 21, 50, 31, 38, 34,
#        63,  1, 24, 62, 44, 36, 26, 28,  0, 56, 39, 58, 25, 20, 53, 13, 33,
#         7, 59, 55, 40, 14, 23, 37, 32, 22, 60, 11, 43,  4])

# %% [markdown]
# ### The Dense activation layer
#
# The value of each neurons scoring of each sequence

# %%
dense = nntrainer.get_activations(sess, test, layer='dense_0_active')
dense.shape
# Out:
# (60000, 64)

# %%
np.max(dense)
# Out:
# 12.803059

# %%
#plot which neurons got activated by the highest predicted sequence (from the outputs)
plt.plot(range(dense.shape[1]), dense[plot_index[0]])
plt.show()

''' An example of how a single sequence can excite various different neurons'''

top_neurons = np.argsort(dense[plot_index[0]])[::-1]

# %% [markdown]
# ### For a given neuron, evaluate the saliency of its highest scored sequences

# %%
neuron = top_neurons[0]

# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

#sort
top_indices = np.argsort(dense[:,neuron])[::-1]

num_plots=5

plotrange = range(0,num_plots) + range(dense.shape[1]-num_plots, dense.shape[1])

for ii in plotrange:

    X = np.expand_dims(test['inputs'][top_indices[ii]], axis=0)

    X_mut = mf.mutate(X, X.shape[1], X.shape[3])
    mutations = {'inputs': X_mut, 'targets': Y_test[:X_mut.shape[0]]}

    #Get output activations for the mutations
    mut_predictions = nntrainer.get_activations(sess, mutations, layer='dense_0_active')[:,neuron]

    #shape the predictions of the mutations into the shape of a heatmap
    heat_mut = mut_predictions.reshape(X.shape[1],4).T

    #normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
    norm_heat_mut = heat_mut - dense[top_indices[ii], neuron]
    norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

    plt.figure(figsize=(15,2))
    if ii == 0:
        plt.title('Saliencies of this neurons highest predicted sequences')
    if ii == dense.shape[1]-num_plots:
        plt.title('Saliencies of this neurons lowest predicted sequences')
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            norm_heat_mut, 
                                            alphabet='rna', 
                                            nt_width=400)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt

# %% [markdown]
# This suggests that a single neuron is looking for the same pattern no matter what the sequence.

# %% [markdown]
# ### Evaluate what the most import neurons are learning - show the saliency of each neurons highest scored sequence

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_plots = 5
plotrange = np.concatenate((top_neurons[0:num_plots],top_neurons[-num_plots:]))

for neuron in plotrange:

    top_indices = np.argsort(dense[:,neuron])[::-1]

    ii=0

    X = np.expand_dims(test['inputs'][top_indices[ii]], axis=0)

    X_mut = mf.mutate(X, X.shape[1], X.shape[3])
    mutations = {'inputs': X_mut, 'targets': Y_test[:X_mut.shape[0]]}

    #Get output activations for the mutations
    mut_predictions = nntrainer.get_activations(sess, mutations, layer='dense_0_active')[:,neuron]

    #shape the predictions of the mutations into the shape of a heatmap
    heat_mut = mut_predictions.reshape(X.shape[1],4).T

    #normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
    norm_heat_mut = heat_mut - dense[top_indices[ii], neuron]
    norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

    plt.figure(figsize=(15,2))
    if neuron == plotrange[0]:
        plt.title('The neurons of greatest importance')
    if neuron == plotrange[num_plots]:
        plt.title('The neurons of least importance')
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            norm_heat_mut, 
                                            alphabet='rna', 
                                            nt_width=400)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt

# %% [markdown]
# ### Repeat the above test but plot the saliencies from the same sequence
#
# Doesn't matter much because the saliencies identify the same patterns in any sequence

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_plots = 10

ii=0

X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)

X_mut = mf.mutate(X, X.shape[1], X.shape[3])
mutations = {'inputs': X_mut, 'targets': Y_test[:X_mut.shape[0]]}

#Get output activations for the mutations
mut_predictions = nntrainer.get_activations(sess, mutations, layer='dense_0_active')

for neuron in top_neurons[:num_plots]:

    #shape the predictions of the mutations into the shape of a heatmap
    heat_mut = mut_predictions[:,neuron].reshape(X.shape[1],4).T

    #normalize the heat map rearrangement by minusing it by the true prediction score of that test sequence
    norm_heat_mut = heat_mut - dense[plot_index[ii], neuron]
    norm_heat_mut = utils.normalize_pwm(norm_heat_mut, factor=4)

    plt.figure(figsize=(15,2))
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            norm_heat_mut, 
                                            alphabet='rna', 
                                            nt_width=400)

# %% [markdown]
# ## Perform Second Order Mutagenesis but based on a neurons output

# %% [markdown]
# #### Top scored sequences by output

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

num_summary = 1000

sum_mut2_scores = np.zeros((41*41*16, dense.shape[1]))
starttime = time.time()

for ii in range(num_summary):
    print (ii)
    epoch_starttime = time.time()
    
    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    #mutate the sequence
    X_mutsecorder = mf.double_mutate(X, X.shape[1], X.shape[3])

    #reshape the 6D tensor into a 4D tensor that the model can test
    X_mutsecorder_reshape = np.reshape(X_mutsecorder, (X.shape[1]*X.shape[1]*16, X.shape[1], 1, 4))
    
    mutations = {'inputs': X_mutsecorder_reshape, 'targets': Y_test[:X_mutsecorder_reshape.shape[0]]}
    
    #Get the neuron's scores for the mutations
    mut2_scores= nntrainer.get_activations(sess, mutations, layer='dense_0_active')
    
    #Sum all the scores into a single matrix
    sum_mut2_scores += mut2_scores
    
    epoch_endtime = time.time()
    
    print ('Epoch duration =' + str(np.around((epoch_endtime -epoch_starttime), 2)) + 's')
    print ('Cumulative duration =' + str(np.around((epoch_endtime - starttime), 2)) + 's')
    print ()

# Save the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_1_64_sumneuron_0_1000.npy'
np.save(npy_save_path, sum_mut2_scores)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
# 0
# Epoch duration =0.18s
# Cumulative duration =0.18s
#
# 1
# Epoch duration =0.14s
# Cumulative duration =0.32s
#
# 2
# Epoch duration =0.15s
# Cumulative duration =0.47s
#
# 3
# Epoch duration =0.14s
# Cumulative duration =0.62s
#
# 4
# Epoch duration =0.14s
# Cumulative duration =0.75s
#
# 5
# Epoch duration =0.16s
# Cumulative duration =0.91s
#
# 6
# Epoch duration =0.14s
# Cumulative duration =1.05s
#
# 7
# Epoch duration =0.14s
# Cumulative duration =1.19s
#
# 8
# Epoch duration =0.14s
# Cumulative duration =1.33s
#
# 9
# Epoch duration =0.14s
# Cumulative duration =1.47s
#
# 10
# Epoch duration =0.14s
# Cumulative duration =1.61s
#
# 11
# Epoch duration =0.14s
# Cumulative duration =1.74s
#
# 12
# Epoch duration =0.14s
# Cumulative duration =1.89s
#
# 13
# Epoch duration =0.14s
# Cumulative duration =2.02s
#
# 14
# Epoch duration =0.14s
# Cumulative duration =2.16s
#
# 15
# Epoch duration =0.14s
# Cumulative duration =2.3s
#
# 16
# Epoch duration =0.14s
# Cumulative duration =2.44s
#
# 17
# Epoch duration =0.14s
# Cumulative duration =2.58s
#
# 18
# Epoch duration =0.14s
# Cumulative duration =2.72s
#
# 19
# Epoch duration =0.14s
# Cumulative duration =2.86s
#
# 20
# Epoch duration =0.14s
# Cumulative duration =3.0s
#
# 21
# Epoch duration =0.18s
# Cumulative duration =3.19s
#
# 22
# Epoch duration =0.16s
# Cumulative duration =3.35s
#
# 23
# Epoch duration =0.15s
# Cumulative duration =3.5s
#
# 24
# Epoch duration =0.18s
# Cumulative duration =3.68s
#
# 25
# Epoch duration =0.16s
# Cumulative duration =3.84s
#
# 26
# Epoch duration =0.17s
# Cumulative duration =4.01s
#
# 27
# Epoch duration =0.16s
# Cumulative duration =4.17s
#
# 28
# Epoch duration =0.14s
# Cumulative duration =4.32s
#
# 29
# Epoch duration =0.14s
# Cumulative duration =4.46s
#
# 30
# Epoch duration =0.14s
# Cumulative duration =4.6s
#
# 31
# Epoch duration =0.14s
# Cumulative duration =4.74s
#
# 32
# Epoch duration =0.14s
# Cumulative duration =4.87s
#
# 33
# Epoch duration =0.14s
# Cumulative duration =5.01s
#
# 34
# Epoch duration =0.13s
# Cumulative duration =5.15s
#
# 35
# Epoch duration =0.14s
# Cumulative duration =5.28s
#
# 36
# Epoch duration =0.17s
# Cumulative duration =5.45s
#
# 37
# Epoch duration =0.19s
# Cumulative duration =5.64s
#
# 38
# Epoch duration =0.14s
# Cumulative duration =5.78s
#
# 39
# Epoch duration =0.19s
# Cumulative duration =5.96s
#
# 40
# Epoch duration =0.16s
# Cumulative duration =6.12s
#
# 41
# Epoch duration =0.2s
# Cumulative duration =6.32s
#
# 42
# Epoch duration =0.16s
# Cumulative duration =6.49s
#
# 43
# Epoch duration =0.14s
# Cumulative duration =6.62s
#
# 44
# Epoch duration =0.14s
# Cumulative duration =6.76s
#
# 45
# Epoch duration =0.14s
# Cumulative duration =6.9s
#
# 46
# Epoch duration =0.14s
# Cumulative duration =7.03s
#
# 47
# Epoch duration =0.14s
# Cumulative duration =7.18s
#
# 48
# Epoch duration =0.14s
# Cumulative duration =7.31s
#
# 49
# Epoch duration =0.14s
# Cumulative duration =7.45s
#
# 50
# Epoch duration =0.14s
# Cumulative duration =7.59s
#
# 51
# Epoch duration =0.14s
# Cumulative duration =7.73s
#
# 52
# Epoch duration =0.14s
# Cumulative duration =7.87s
#
# 53
# Epoch duration =0.14s
# Cumulative duration =8.01s
#
# 54
# Epoch duration =0.14s
# Cumulative duration =8.15s
#
# 55
# Epoch duration =0.14s
# Cumulative duration =8.28s
#
# 56
# Epoch duration =0.14s
# Cumulative duration =8.43s
#
# 57
# Epoch duration =0.14s
# Cumulative duration =8.56s
#
# 58
# Epoch duration =0.14s
# Cumulative duration =8.7s
#
# 59
# Epoch duration =0.15s
# Cumulative duration =8.85s
#
# 60
# Epoch duration =0.14s
# Cumulative duration =8.99s
#
# 61
# Epoch duration =0.14s
# Cumulative duration =9.12s
#
# 62
# Epoch duration =0.14s
# Cumulative duration =9.27s
#
# 63
# Epoch duration =0.14s
# Cumulative duration =9.41s
#
# 64
# Epoch duration =0.14s
# Cumulative duration =9.55s
#
# 65
# Epoch duration =0.14s
# Cumulative duration =9.69s
#
# 66
# Epoch duration =0.14s
# Cumulative duration =9.83s
#
# 67
# Epoch duration =0.16s
# Cumulative duration =9.99s
#
# 68
# Epoch duration =0.14s
# Cumulative duration =10.13s
#
# 69
# Epoch duration =0.14s
# Cumulative duration =10.26s
#
# 70
# Epoch duration =0.14s
# Cumulative duration =10.4s
#
# 71
# Epoch duration =0.14s
# Cumulative duration =10.54s
#
# 72
# Epoch duration =0.14s
# Cumulative duration =10.69s
#
# 73
# Epoch duration =0.14s
# Cumulative duration =10.83s
#
# 74
# Epoch duration =0.15s
# Cumulative duration =10.98s
#
# 75
# Epoch duration =0.14s
# Cumulative duration =11.12s
#
# 76
# Epoch duration =0.14s
# Cumulative duration =11.26s
#
# 77
# Epoch duration =0.13s
# Cumulative duration =11.39s
#
# 78
# Epoch duration =0.14s
# Cumulative duration =11.53s
#
# 79
# Epoch duration =0.14s
# Cumulative duration =11.67s
#
# 80
# Epoch duration =0.14s
# Cumulative duration =11.81s
#
# 81
# Epoch duration =0.14s
# Cumulative duration =11.95s
#
# 82
# Epoch duration =0.14s
# Cumulative duration =12.09s
#
# 83
# Epoch duration =0.14s
# Cumulative duration =12.22s
#
# 84
# Epoch duration =0.14s
# Cumulative duration =12.36s
#
# 85
# Epoch duration =0.14s
# Cumulative duration =12.5s
#
# 86
# Epoch duration =0.15s
# Cumulative duration =12.65s
#
# 87
# Epoch duration =0.14s
# Cumulative duration =12.78s
#
# 88
# Epoch duration =0.13s
# Cumulative duration =12.92s
#
# 89
# Epoch duration =0.13s
# Cumulative duration =13.05s
#
# 90
# Epoch duration =0.14s
# Cumulative duration =13.19s
#
# 91
# Epoch duration =0.14s
# Cumulative duration =13.33s
#
# 92
# Epoch duration =0.14s
# Cumulative duration =13.47s
#
# 93
# Epoch duration =0.14s
# Cumulative duration =13.61s
#
# 94
# Epoch duration =0.15s
# Cumulative duration =13.75s
#
# 95
# Epoch duration =0.14s
# Cumulative duration =13.89s
#
# 96
# Epoch duration =0.14s
# Cumulative duration =14.03s
#
# 97
# Epoch duration =0.14s
# Cumulative duration =14.16s
#
# 98
# Epoch duration =0.14s
# Cumulative duration =14.3s
#
# 99
# Epoch duration =0.15s
# Cumulative duration =14.45s
#
# 100
# Epoch duration =0.14s
# Cumulative duration =14.59s
#
# 101
# Epoch duration =0.14s
# Cumulative duration =14.72s
#
# 102
# Epoch duration =0.14s
# Cumulative duration =14.86s
#
# 103
# Epoch duration =0.14s
# Cumulative duration =15.0s
#
# 104
# Epoch duration =0.14s
# Cumulative duration =15.14s
#
# 105
# Epoch duration =0.14s
# Cumulative duration =15.29s
#
# 106
# Epoch duration =0.15s
# Cumulative duration =15.43s
#
# 107
# Epoch duration =0.14s
# Cumulative duration =15.57s
#
# 108
# Epoch duration =0.14s
# Cumulative duration =15.71s
#
# 109
# Epoch duration =0.13s
# Cumulative duration =15.84s
#
# 110
# Epoch duration =0.14s
# Cumulative duration =15.98s
#
# 111
# Epoch duration =0.14s
# Cumulative duration =16.12s
#
# 112
# Epoch duration =0.14s
# Cumulative duration =16.26s
#
# 113
# Epoch duration =0.14s
# Cumulative duration =16.4s
#
# 114
# Epoch duration =0.14s
# Cumulative duration =16.53s
#
# 115
# Epoch duration =0.14s
# Cumulative duration =16.67s
#
# 116
# Epoch duration =0.14s
# Cumulative duration =16.81s
#
# 117
# Epoch duration =0.14s
# Cumulative duration =16.95s
#
# 118
# Epoch duration =0.14s
# Cumulative duration =17.09s
#
# 119
# Epoch duration =0.15s
# Cumulative duration =17.23s
#
# 120
# Epoch duration =0.14s
# Cumulative duration =17.37s
#
# 121
# Epoch duration =0.14s
# Cumulative duration =17.51s
#
# 122
# Epoch duration =0.14s
# Cumulative duration =17.65s
#
# 123
# Epoch duration =0.14s
# Cumulative duration =17.79s
#
# 124
# Epoch duration =0.14s
# Cumulative duration =17.93s
#
# 125
# Epoch duration =0.14s
# Cumulative duration =18.07s
#
# 126
# Epoch duration =0.14s
# Cumulative duration =18.21s
#
# 127
# Epoch duration =0.14s
# Cumulative duration =18.35s
#
# 128
# Epoch duration =0.14s
# Cumulative duration =18.49s
#
# 129
# Epoch duration =0.14s
# Cumulative duration =18.62s
#
# 130
# Epoch duration =0.14s
# Cumulative duration =18.76s
#
# 131
# Epoch duration =0.14s
# Cumulative duration =18.9s
#
# 132
# Epoch duration =0.14s
# Cumulative duration =19.04s
#
# 133
# Epoch duration =0.14s
# Cumulative duration =19.18s
#
# 134
# Epoch duration =0.14s
# Cumulative duration =19.32s
#
# 135
# Epoch duration =0.15s
# Cumulative duration =19.48s
#
# 136
# Epoch duration =0.14s
# Cumulative duration =19.62s
#
# 137
# Epoch duration =0.13s
# Cumulative duration =19.75s
#
# 138
# Epoch duration =0.14s
# Cumulative duration =19.89s
#
# 139
# Epoch duration =0.14s
# Cumulative duration =20.03s
#
# 140
# Epoch duration =0.15s
# Cumulative duration =20.18s
#
# 141
# Epoch duration =0.19s
# Cumulative duration =20.37s
#
# 142
# Epoch duration =0.16s
# Cumulative duration =20.53s
#
# 143
# Epoch duration =0.18s
# Cumulative duration =20.71s
#
# 144
# Epoch duration =0.16s
# Cumulative duration =20.88s
#
# 145
# Epoch duration =0.14s
# Cumulative duration =21.02s
#
# 146
# Epoch duration =0.19s
# Cumulative duration =21.21s
#
# 147
# Epoch duration =0.14s
# Cumulative duration =21.35s
#
# 148
# Epoch duration =0.14s
# Cumulative duration =21.49s
#
# 149
# Epoch duration =0.14s
# Cumulative duration =21.63s
#
# 150
# Epoch duration =0.14s
# Cumulative duration =21.78s
#
# 151
# Epoch duration =0.14s
# Cumulative duration =21.92s
#
# 152
# Epoch duration =0.17s
# Cumulative duration =22.09s
#
# 153
# Epoch duration =0.14s
# Cumulative duration =22.23s
#
# 154
# Epoch duration =0.14s
# Cumulative duration =22.37s
#
# 155
# Epoch duration =0.13s
# Cumulative duration =22.5s
#
# 156
# Epoch duration =0.14s
# Cumulative duration =22.64s
#
# 157
# Epoch duration =0.14s
# Cumulative duration =22.77s
#
# 158
# Epoch duration =0.14s
# Cumulative duration =22.92s
#
# 159
# Epoch duration =0.13s
# Cumulative duration =23.05s
#
# 160
# Epoch duration =0.14s
# Cumulative duration =23.19s
#
# 161
# Epoch duration =0.14s
# Cumulative duration =23.33s
#
# 162
# Epoch duration =0.14s
# Cumulative duration =23.47s
#
# 163
# Epoch duration =0.16s
# Cumulative duration =23.63s
#
# 164
# Epoch duration =0.14s
# Cumulative duration =23.77s
#
# 165
# Epoch duration =0.14s
# Cumulative duration =23.91s
#
# 166
# Epoch duration =0.14s
# Cumulative duration =24.05s
#
# 167
# Epoch duration =0.14s
# Cumulative duration =24.19s
#
# 168
# Epoch duration =0.15s
# Cumulative duration =24.34s
#
# 169
# Epoch duration =0.14s
# Cumulative duration =24.47s
#
# 170
# Epoch duration =0.14s
# Cumulative duration =24.61s
#
# 171
# Epoch duration =0.14s
# Cumulative duration =24.75s
#
# 172
# Epoch duration =0.14s
# Cumulative duration =24.89s
#
# 173
# Epoch duration =0.13s
# Cumulative duration =25.02s
#
# 174
# Epoch duration =0.14s
# Cumulative duration =25.16s
#
# 175
# Epoch duration =0.14s
# Cumulative duration =25.29s
#
# 176
# Epoch duration =0.14s
# Cumulative duration =25.43s
#
# 177
# Epoch duration =0.16s
# Cumulative duration =25.6s
#
# 178
# Epoch duration =0.14s
# Cumulative duration =25.74s
#
# 179
# Epoch duration =0.14s
# Cumulative duration =25.87s
#
# 180
# Epoch duration =0.14s
# Cumulative duration =26.01s
#
# 181
# Epoch duration =0.13s
# Cumulative duration =26.15s
#
# 182
# Epoch duration =0.14s
# Cumulative duration =26.29s
#
# 183
# Epoch duration =0.14s
# Cumulative duration =26.42s
#
# 184
# Epoch duration =0.14s
# Cumulative duration =26.56s
#
# 185
# Epoch duration =0.14s
# Cumulative duration =26.7s
#
# 186
# Epoch duration =0.14s
# Cumulative duration =26.84s
#
# 187
# Epoch duration =0.14s
# Cumulative duration =26.98s
#
# 188
# Epoch duration =0.15s
# Cumulative duration =27.12s
#
# 189
# Epoch duration =0.15s
# Cumulative duration =27.28s
#
# 190
# Epoch duration =0.16s
# Cumulative duration =27.44s
#
# 191
# Epoch duration =0.14s
# Cumulative duration =27.57s
#
# 192
# Epoch duration =0.14s
# Cumulative duration =27.71s
#
# 193
# Epoch duration =0.14s
# Cumulative duration =27.85s
#
# 194
# Epoch duration =0.14s
# Cumulative duration =27.99s
#
# 195
# Epoch duration =0.14s
# Cumulative duration =28.13s
#
# 196
# Epoch duration =0.14s
# Cumulative duration =28.27s
#
# 197
# Epoch duration =0.14s
# Cumulative duration =28.4s
#
# 198
# Epoch duration =0.15s
# Cumulative duration =28.55s
#
# 199
# Epoch duration =0.14s
# Cumulative duration =28.69s
#
# 200
# Epoch duration =0.14s
# Cumulative duration =28.83s
#
# 201
# Epoch duration =0.13s
# Cumulative duration =28.96s
#
# 202
# Epoch duration =0.14s
# Cumulative duration =29.1s
#
# 203
# Epoch duration =0.14s
# Cumulative duration =29.24s
#
# 204
# Epoch duration =0.14s
# Cumulative duration =29.38s
#
# 205
# Epoch duration =0.14s
# Cumulative duration =29.52s
#
# 206
# Epoch duration =0.14s
# Cumulative duration =29.66s
#
# 207
# Epoch duration =0.14s
# Cumulative duration =29.8s
#
# 208
# Epoch duration =0.14s
# Cumulative duration =29.94s
#
# 209
# Epoch duration =0.14s
# Cumulative duration =30.07s
#
# 210
# Epoch duration =0.14s
# Cumulative duration =30.21s
#
# 211
# Epoch duration =0.14s
# Cumulative duration =30.35s
#
# 212
# Epoch duration =0.14s
# Cumulative duration =30.49s
#
# 213
# Epoch duration =0.14s
# Cumulative duration =30.63s
#
# 214
# Epoch duration =0.14s
# Cumulative duration =30.77s
#
# 215
# Epoch duration =0.14s
# Cumulative duration =30.91s
#
# 216
# Epoch duration =0.14s
# Cumulative duration =31.05s
#
# 217
# Epoch duration =0.14s
# Cumulative duration =31.19s
#
# 218
# Epoch duration =0.14s
# Cumulative duration =31.33s
#
# 219
# Epoch duration =0.14s
# Cumulative duration =31.47s
#
# 220
# Epoch duration =0.14s
# Cumulative duration =31.6s
#
# 221
# Epoch duration =0.14s
# Cumulative duration =31.74s
#
# 222
# Epoch duration =0.14s
# Cumulative duration =31.88s
#
# 223
# Epoch duration =0.14s
# Cumulative duration =32.02s
#
# 224
# Epoch duration =0.14s
# Cumulative duration =32.16s
#
# 225
# Epoch duration =0.13s
# Cumulative duration =32.29s
#
# 226
# Epoch duration =0.15s
# Cumulative duration =32.44s
#
# 227
# Epoch duration =0.13s
# Cumulative duration =32.57s
#
# 228
# Epoch duration =0.14s
# Cumulative duration =32.71s
#
# 229
# Epoch duration =0.13s
# Cumulative duration =32.84s
#
# 230
# Epoch duration =0.14s
# Cumulative duration =32.99s
#
# 231
# Epoch duration =0.14s
# Cumulative duration =33.13s
#
# 232
# Epoch duration =0.15s
# Cumulative duration =33.28s
#
# 233
# Epoch duration =0.14s
# Cumulative duration =33.41s
#
# 234
# Epoch duration =0.14s
# Cumulative duration =33.55s
#
# 235
# Epoch duration =0.14s
# Cumulative duration =33.69s
#
# 236
# Epoch duration =0.14s
# Cumulative duration =33.83s
#
# 237
# Epoch duration =0.14s
# Cumulative duration =33.96s
#
# 238
# Epoch duration =0.15s
# Cumulative duration =34.11s
#
# 239
# Epoch duration =0.14s
# Cumulative duration =34.25s
#
# 240
# Epoch duration =0.14s
# Cumulative duration =34.38s
#
# 241
# Epoch duration =0.14s
# Cumulative duration =34.52s
#
# 242
# Epoch duration =0.14s
# Cumulative duration =34.66s
#
# 243
# Epoch duration =0.14s
# Cumulative duration =34.8s
#
# 244
# Epoch duration =0.14s
# Cumulative duration =34.93s
#
# 245
# Epoch duration =0.13s
# Cumulative duration =35.07s
#
# 246
# Epoch duration =0.14s
# Cumulative duration =35.21s
#
# 247
# Epoch duration =0.14s
# Cumulative duration =35.35s
#
# 248
# Epoch duration =0.15s
# Cumulative duration =35.5s
#
# 249
# Epoch duration =0.16s
# Cumulative duration =35.66s
#
# 250
# Epoch duration =0.14s
# Cumulative duration =35.8s
#
# 251
# Epoch duration =0.15s
# Cumulative duration =35.95s
#
# 252
# Epoch duration =0.14s
# Cumulative duration =36.09s
#
# 253
# Epoch duration =0.14s
# Cumulative duration =36.23s
#
# 254
# Epoch duration =0.14s
# Cumulative duration =36.37s
#
# 255
# Epoch duration =0.16s
# Cumulative duration =36.53s
#
# 256
# Epoch duration =0.15s
# Cumulative duration =36.68s
#
# 257
# Epoch duration =0.14s
# Cumulative duration =36.82s
#
# 258
# Epoch duration =0.15s
# Cumulative duration =36.97s
#
# 259
# Epoch duration =0.14s
# Cumulative duration =37.11s
#
# 260
# Epoch duration =0.14s
# Cumulative duration =37.24s
#
# 261
# Epoch duration =0.14s
# Cumulative duration =37.38s
#
# 262
# Epoch duration =0.14s
# Cumulative duration =37.52s
#
# 263
# Epoch duration =0.13s
# Cumulative duration =37.65s
#
# 264
# Epoch duration =0.14s
# Cumulative duration =37.79s
#
# 265
# Epoch duration =0.14s
# Cumulative duration =37.93s
#
# 266
# Epoch duration =0.14s
# Cumulative duration =38.07s
#
# 267
# Epoch duration =0.14s
# Cumulative duration =38.21s
#
# 268
# Epoch duration =0.14s
# Cumulative duration =38.36s
#
# 269
# Epoch duration =0.14s
# Cumulative duration =38.5s
#
# 270
# Epoch duration =0.14s
# Cumulative duration =38.64s
#
# 271
# Epoch duration =0.14s
# Cumulative duration =38.78s
#
# 272
# Epoch duration =0.14s
# Cumulative duration =38.91s
#
# 273
# Epoch duration =0.14s
# Cumulative duration =39.05s
#
# 274
# Epoch duration =0.16s
# Cumulative duration =39.21s
#
# 275
# Epoch duration =0.14s
# Cumulative duration =39.35s
#
# 276
# Epoch duration =0.14s
# Cumulative duration =39.49s
#
# 277
# Epoch duration =0.14s
# Cumulative duration =39.63s
#
# 278
# Epoch duration =0.14s
# Cumulative duration =39.77s
#
# 279
# Epoch duration =0.14s
# Cumulative duration =39.91s
#
# 280
# Epoch duration =0.14s
# Cumulative duration =40.05s
#
# 281
# Epoch duration =0.14s
# Cumulative duration =40.19s
#
# 282
# Epoch duration =0.14s
# Cumulative duration =40.32s
#
# 283
# Epoch duration =0.14s
# Cumulative duration =40.46s
#
# 284
# Epoch duration =0.15s
# Cumulative duration =40.61s
#
# 285
# Epoch duration =0.14s
# Cumulative duration =40.74s
#
# 286
# Epoch duration =0.14s
# Cumulative duration =40.88s
#
# 287
# Epoch duration =0.14s
# Cumulative duration =41.02s
#
# 288
# Epoch duration =0.14s
# Cumulative duration =41.16s
#
# 289
# Epoch duration =0.14s
# Cumulative duration =41.3s
#
# 290
# Epoch duration =0.14s
# Cumulative duration =41.43s
#
# 291
# Epoch duration =0.14s
# Cumulative duration =41.57s
#
# 292
# Epoch duration =0.13s
# Cumulative duration =41.7s
#
# 293
# Epoch duration =0.14s
# Cumulative duration =41.84s
#
# 294
# Epoch duration =0.14s
# Cumulative duration =41.98s
#
# 295
# Epoch duration =0.14s
# Cumulative duration =42.11s
#
# 296
# Epoch duration =0.14s
# Cumulative duration =42.25s
#
# 297
# Epoch duration =0.14s
# Cumulative duration =42.39s
#
# 298
# Epoch duration =0.14s
# Cumulative duration =42.53s
#
# 299
# Epoch duration =0.13s
# Cumulative duration =42.66s
#
# 300
# Epoch duration =0.14s
# Cumulative duration =42.8s
#
# 301
# Epoch duration =0.14s
# Cumulative duration =42.94s
#
# 302
# Epoch duration =0.14s
# Cumulative duration =43.08s
#
# 303
# Epoch duration =0.15s
# Cumulative duration =43.23s
#
# 304
# Epoch duration =0.14s
# Cumulative duration =43.36s
#
# 305
# Epoch duration =0.15s
# Cumulative duration =43.51s
#
# 306
# Epoch duration =0.14s
# Cumulative duration =43.65s
#
# 307
# Epoch duration =0.14s
# Cumulative duration =43.79s
#
# 308
# Epoch duration =0.15s
# Cumulative duration =43.94s
#
# 309
# Epoch duration =0.14s
# Cumulative duration =44.08s
#
# 310
# Epoch duration =0.15s
# Cumulative duration =44.23s
#
# 311
# Epoch duration =0.16s
# Cumulative duration =44.39s
#
# 312
# Epoch duration =0.14s
# Cumulative duration =44.53s
#
# 313
# Epoch duration =0.14s
# Cumulative duration =44.67s
#
# 314
# Epoch duration =0.13s
# Cumulative duration =44.8s
#
# 315
# Epoch duration =0.14s
# Cumulative duration =44.94s
#
# 316
# Epoch duration =0.14s
# Cumulative duration =45.07s
#
# 317
# Epoch duration =0.14s
# Cumulative duration =45.21s
#
# 318
# Epoch duration =0.14s
# Cumulative duration =45.35s
#
# 319
# Epoch duration =0.15s
# Cumulative duration =45.5s
#
# 320
# Epoch duration =0.16s
# Cumulative duration =45.67s
#
# 321
# Epoch duration =0.14s
# Cumulative duration =45.8s
#
# 322
# Epoch duration =0.15s
# Cumulative duration =45.95s
#
# 323
# Epoch duration =0.14s
# Cumulative duration =46.08s
#
# 324
# Epoch duration =0.13s
# Cumulative duration =46.22s
#
# 325
# Epoch duration =0.14s
# Cumulative duration =46.36s
#
# 326
# Epoch duration =0.14s
# Cumulative duration =46.49s
#
# 327
# Epoch duration =0.14s
# Cumulative duration =46.63s
#
# 328
# Epoch duration =0.14s
# Cumulative duration =46.77s
#
# 329
# Epoch duration =0.14s
# Cumulative duration =46.91s
#
# 330
# Epoch duration =0.13s
# Cumulative duration =47.04s
#
# 331
# Epoch duration =0.14s
# Cumulative duration =47.18s
#
# 332
# Epoch duration =0.13s
# Cumulative duration =47.32s
#
# 333
# Epoch duration =0.14s
# Cumulative duration =47.45s
#
# 334
# Epoch duration =0.14s
# Cumulative duration =47.59s
#
# 335
# Epoch duration =0.14s
# Cumulative duration =47.73s
#
# 336
# Epoch duration =0.15s
# Cumulative duration =47.88s
#
# 337
# Epoch duration =0.14s
# Cumulative duration =48.02s
#
# 338
# Epoch duration =0.14s
# Cumulative duration =48.15s
#
# 339
# Epoch duration =0.14s
# Cumulative duration =48.29s
#
# 340
# Epoch duration =0.14s
# Cumulative duration =48.44s
#
# 341
# Epoch duration =0.14s
# Cumulative duration =48.57s
#
# 342
# Epoch duration =0.13s
# Cumulative duration =48.71s
#
# 343
# Epoch duration =0.16s
# Cumulative duration =48.86s
#
# 344
# Epoch duration =0.15s
# Cumulative duration =49.01s
#
# 345
# Epoch duration =0.14s
# Cumulative duration =49.14s
#
# 346
# Epoch duration =0.14s
# Cumulative duration =49.29s
#
# 347
# Epoch duration =0.16s
# Cumulative duration =49.44s
#
# 348
# Epoch duration =0.14s
# Cumulative duration =49.58s
#
# 349
# Epoch duration =0.13s
# Cumulative duration =49.71s
#
# 350
# Epoch duration =0.14s
# Cumulative duration =49.85s
#
# 351
# Epoch duration =0.14s
# Cumulative duration =49.99s
#
# 352
# Epoch duration =0.14s
# Cumulative duration =50.13s
#
# 353
# Epoch duration =0.14s
# Cumulative duration =50.27s
#
# 354
# Epoch duration =0.14s
# Cumulative duration =50.41s
#
# 355
# Epoch duration =0.14s
# Cumulative duration =50.54s
#
# 356
# Epoch duration =0.14s
# Cumulative duration =50.68s
#
# 357
# Epoch duration =0.15s
# Cumulative duration =50.83s
#
# 358
# Epoch duration =0.16s
# Cumulative duration =50.99s
#
# 359
# Epoch duration =0.14s
# Cumulative duration =51.13s
#
# 360
# Epoch duration =0.16s
# Cumulative duration =51.28s
#
# 361
# Epoch duration =0.14s
# Cumulative duration =51.42s
#
# 362
# Epoch duration =0.17s
# Cumulative duration =51.59s
#
# 363
# Epoch duration =0.14s
# Cumulative duration =51.74s
#
# 364
# Epoch duration =0.15s
# Cumulative duration =51.89s
#
# 365
# Epoch duration =0.16s
# Cumulative duration =52.05s
#
# 366
# Epoch duration =0.13s
# Cumulative duration =52.18s
#
# 367
# Epoch duration =0.14s
# Cumulative duration =52.32s
#
# 368
# Epoch duration =0.15s
# Cumulative duration =52.48s
#
# 369
# Epoch duration =0.14s
# Cumulative duration =52.61s
#
# 370
# Epoch duration =0.14s
# Cumulative duration =52.75s
#
# 371
# Epoch duration =0.14s
# Cumulative duration =52.89s
#
# 372
# Epoch duration =0.14s
# Cumulative duration =53.02s
#
# 373
# Epoch duration =0.15s
# Cumulative duration =53.17s
#
# 374
# Epoch duration =0.14s
# Cumulative duration =53.31s
#
# 375
# Epoch duration =0.14s
# Cumulative duration =53.45s
#
# 376
# Epoch duration =0.2s
# Cumulative duration =53.66s
#
# 377
# Epoch duration =0.15s
# Cumulative duration =53.81s
#
# 378
# Epoch duration =0.14s
# Cumulative duration =53.95s
#
# 379
# Epoch duration =0.14s
# Cumulative duration =54.09s
#
# 380
# Epoch duration =0.14s
# Cumulative duration =54.23s
#
# 381
# Epoch duration =0.16s
# Cumulative duration =54.4s
#
# 382
# Epoch duration =0.14s
# Cumulative duration =54.53s
#
# 383
# Epoch duration =0.14s
# Cumulative duration =54.67s
#
# 384
# Epoch duration =0.13s
# Cumulative duration =54.8s
#
# 385
# Epoch duration =0.14s
# Cumulative duration =54.94s
#
# 386
# Epoch duration =0.14s
# Cumulative duration =55.08s
#
# 387
# Epoch duration =0.14s
# Cumulative duration =55.22s
#
# 388
# Epoch duration =0.14s
# Cumulative duration =55.35s
#
# 389
# Epoch duration =0.13s
# Cumulative duration =55.49s
#
# 390
# Epoch duration =0.14s
# Cumulative duration =55.63s
#
# 391
# Epoch duration =0.14s
# Cumulative duration =55.77s
#
# 392
# Epoch duration =0.14s
# Cumulative duration =55.9s
#
# 393
# Epoch duration =0.14s
# Cumulative duration =56.04s
#
# 394
# Epoch duration =0.14s
# Cumulative duration =56.17s
#
# 395
# Epoch duration =0.13s
# Cumulative duration =56.31s
#
# 396
# Epoch duration =0.14s
# Cumulative duration =56.45s
#
# 397
# Epoch duration =0.14s
# Cumulative duration =56.58s
#
# 398
# Epoch duration =0.14s
# Cumulative duration =56.72s
#
# 399
# Epoch duration =0.14s
# Cumulative duration =56.85s
#
# 400
# Epoch duration =0.14s
# Cumulative duration =56.99s
#
# 401
# Epoch duration =0.14s
# Cumulative duration =57.13s
#
# 402
# Epoch duration =0.13s
# Cumulative duration =57.27s
#
# 403
# Epoch duration =0.14s
# Cumulative duration =57.41s
#
# 404
# Epoch duration =0.14s
# Cumulative duration =57.55s
#
# 405
# Epoch duration =0.14s
# Cumulative duration =57.68s
#
# 406
# Epoch duration =0.15s
# Cumulative duration =57.84s
#
# 407
# Epoch duration =0.14s
# Cumulative duration =57.97s
#
# 408
# Epoch duration =0.14s
# Cumulative duration =58.11s
#
# 409
# Epoch duration =0.14s
# Cumulative duration =58.25s
#
# 410
# Epoch duration =0.14s
# Cumulative duration =58.39s
#
# 411
# Epoch duration =0.14s
# Cumulative duration =58.53s
#
# 412
# Epoch duration =0.14s
# Cumulative duration =58.67s
#
# 413
# Epoch duration =0.14s
# Cumulative duration =58.81s
#
# 414
# Epoch duration =0.14s
# Cumulative duration =58.94s
#
# 415
# Epoch duration =0.14s
# Cumulative duration =59.08s
#
# 416
# Epoch duration =0.15s
# Cumulative duration =59.23s
#
# 417
# Epoch duration =0.14s
# Cumulative duration =59.37s
#
# 418
# Epoch duration =0.13s
# Cumulative duration =59.5s
#
# 419
# Epoch duration =0.14s
# Cumulative duration =59.64s
#
# 420
# Epoch duration =0.14s
# Cumulative duration =59.77s
#
# 421
# Epoch duration =0.14s
# Cumulative duration =59.92s
#
# 422
# Epoch duration =0.15s
# Cumulative duration =60.06s
#
# 423
# Epoch duration =0.14s
# Cumulative duration =60.2s
#
# 424
# Epoch duration =0.14s
# Cumulative duration =60.34s
#
# 425
# Epoch duration =0.15s
# Cumulative duration =60.5s
#
# 426
# Epoch duration =0.15s
# Cumulative duration =60.65s
#
# 427
# Epoch duration =0.14s
# Cumulative duration =60.78s
#
# 428
# Epoch duration =0.14s
# Cumulative duration =60.93s
#
# 429
# Epoch duration =0.14s
# Cumulative duration =61.07s
#
# 430
# Epoch duration =0.15s
# Cumulative duration =61.22s
#
# 431
# Epoch duration =0.14s
# Cumulative duration =61.36s
#
# 432
# Epoch duration =0.14s
# Cumulative duration =61.5s
#
# 433
# Epoch duration =0.18s
# Cumulative duration =61.68s
#
# 434
# Epoch duration =0.14s
# Cumulative duration =61.81s
#
# 435
# Epoch duration =0.14s
# Cumulative duration =61.95s
#
# 436
# Epoch duration =0.14s
# Cumulative duration =62.09s
#
# 437
# Epoch duration =0.14s
# Cumulative duration =62.23s
#
# 438
# Epoch duration =0.14s
# Cumulative duration =62.37s
#
# 439
# Epoch duration =0.14s
# Cumulative duration =62.51s
#
# 440
# Epoch duration =0.14s
# Cumulative duration =62.65s
#
# 441
# Epoch duration =0.14s
# Cumulative duration =62.79s
#
# 442
# Epoch duration =0.14s
# Cumulative duration =62.93s
#
# 443
# Epoch duration =0.14s
# Cumulative duration =63.07s
#
# 444
# Epoch duration =0.14s
# Cumulative duration =63.21s
#
# 445
# Epoch duration =0.14s
# Cumulative duration =63.35s
#
# 446
# Epoch duration =0.14s
# Cumulative duration =63.49s
#
# 447
# Epoch duration =0.14s
# Cumulative duration =63.62s
#
# 448
# Epoch duration =0.14s
# Cumulative duration =63.76s
#
# 449
# Epoch duration =0.14s
# Cumulative duration =63.9s
#
# 450
# Epoch duration =0.14s
# Cumulative duration =64.04s
#
# 451
# Epoch duration =0.14s
# Cumulative duration =64.18s
#
# 452
# Epoch duration =0.13s
# Cumulative duration =64.31s
#
# 453
# Epoch duration =0.13s
# Cumulative duration =64.44s
#
# 454
# Epoch duration =0.14s
# Cumulative duration =64.58s
#
# 455
# Epoch duration =0.14s
# Cumulative duration =64.72s
#
# 456
# Epoch duration =0.18s
# Cumulative duration =64.9s
#
# 457
# Epoch duration =0.14s
# Cumulative duration =65.04s
#
# 458
# Epoch duration =0.14s
# Cumulative duration =65.18s
#
# 459
# Epoch duration =0.13s
# Cumulative duration =65.32s
#
# 460
# Epoch duration =0.14s
# Cumulative duration =65.45s
#
# 461
# Epoch duration =0.16s
# Cumulative duration =65.61s
#
# 462
# Epoch duration =0.16s
# Cumulative duration =65.77s
#
# 463
# Epoch duration =0.14s
# Cumulative duration =65.91s
#
# 464
# Epoch duration =0.14s
# Cumulative duration =66.05s
#
# 465
# Epoch duration =0.15s
# Cumulative duration =66.2s
#
# 466
# Epoch duration =0.14s
# Cumulative duration =66.34s
#
# 467
# Epoch duration =0.14s
# Cumulative duration =66.47s
#
# 468
# Epoch duration =0.15s
# Cumulative duration =66.62s
#
# 469
# Epoch duration =0.14s
# Cumulative duration =66.76s
#
# 470
# Epoch duration =0.14s
# Cumulative duration =66.9s
#
# 471
# Epoch duration =0.17s
# Cumulative duration =67.07s
#
# 472
# Epoch duration =0.13s
# Cumulative duration =67.2s
#
# 473
# Epoch duration =0.13s
# Cumulative duration =67.34s
#
# 474
# Epoch duration =0.13s
# Cumulative duration =67.47s
#
# 475
# Epoch duration =0.14s
# Cumulative duration =67.6s
#
# 476
# Epoch duration =0.13s
# Cumulative duration =67.74s
#
# 477
# Epoch duration =0.14s
# Cumulative duration =67.88s
#
# 478
# Epoch duration =0.15s
# Cumulative duration =68.03s
#
# 479
# Epoch duration =0.14s
# Cumulative duration =68.17s
#
# 480
# Epoch duration =0.14s
# Cumulative duration =68.31s
#
# 481
# Epoch duration =0.14s
# Cumulative duration =68.45s
#
# 482
# Epoch duration =0.14s
# Cumulative duration =68.58s
#
# 483
# Epoch duration =0.14s
# Cumulative duration =68.72s
#
# 484
# Epoch duration =0.14s
# Cumulative duration =68.86s
#
# 485
# Epoch duration =0.13s
# Cumulative duration =68.99s
#
# 486
# Epoch duration =0.14s
# Cumulative duration =69.13s
#
# 487
# Epoch duration =0.14s
# Cumulative duration =69.27s
#
# 488
# Epoch duration =0.14s
# Cumulative duration =69.41s
#
# 489
# Epoch duration =0.14s
# Cumulative duration =69.55s
#
# 490
# Epoch duration =0.15s
# Cumulative duration =69.7s
#
# 491
# Epoch duration =0.14s
# Cumulative duration =69.84s
#
# 492
# Epoch duration =0.14s
# Cumulative duration =69.98s
#
# 493
# Epoch duration =0.14s
# Cumulative duration =70.12s
#
# 494
# Epoch duration =0.14s
# Cumulative duration =70.26s
#
# 495
# Epoch duration =0.14s
# Cumulative duration =70.4s
#
# 496
# Epoch duration =0.14s
# Cumulative duration =70.54s
#
# 497
# Epoch duration =0.14s
# Cumulative duration =70.67s
#
# 498
# Epoch duration =0.14s
# Cumulative duration =70.81s
#
# 499
# Epoch duration =0.14s
# Cumulative duration =70.95s
#
# 500
# Epoch duration =0.14s
# Cumulative duration =71.09s
#
# 501
# Epoch duration =0.18s
# Cumulative duration =71.26s
#
# 502
# Epoch duration =0.14s
# Cumulative duration =71.4s
#
# 503
# Epoch duration =0.14s
# Cumulative duration =71.54s
#
# 504
# Epoch duration =0.14s
# Cumulative duration =71.68s
#
# 505
# Epoch duration =0.14s
# Cumulative duration =71.82s
#
# 506
# Epoch duration =0.14s
# Cumulative duration =71.96s
#
# 507
# Epoch duration =0.14s
# Cumulative duration =72.1s
#
# 508
# Epoch duration =0.13s
# Cumulative duration =72.24s
#
# 509
# Epoch duration =0.18s
# Cumulative duration =72.42s
#
# 510
# Epoch duration =0.14s
# Cumulative duration =72.56s
#
# 511
# Epoch duration =0.14s
# Cumulative duration =72.7s
#
# 512
# Epoch duration =0.13s
# Cumulative duration =72.83s
#
# 513
# Epoch duration =0.14s
# Cumulative duration =72.97s
#
# 514
# Epoch duration =0.14s
# Cumulative duration =73.11s
#
# 515
# Epoch duration =0.14s
# Cumulative duration =73.25s
#
# 516
# Epoch duration =0.14s
# Cumulative duration =73.39s
#
# 517
# Epoch duration =0.14s
# Cumulative duration =73.53s
#
# 518
# Epoch duration =0.15s
# Cumulative duration =73.68s
#
# 519
# Epoch duration =0.14s
# Cumulative duration =73.82s
#
# 520
# Epoch duration =0.14s
# Cumulative duration =73.96s
#
# 521
# Epoch duration =0.14s
# Cumulative duration =74.1s
#
# 522
# Epoch duration =0.14s
# Cumulative duration =74.24s
#
# 523
# Epoch duration =0.14s
# Cumulative duration =74.38s
#
# 524
# Epoch duration =0.14s
# Cumulative duration =74.52s
#
# 525
# Epoch duration =0.13s
# Cumulative duration =74.65s
#
# 526
# Epoch duration =0.14s
# Cumulative duration =74.79s
#
# 527
# Epoch duration =0.14s
# Cumulative duration =74.92s
#
# 528
# Epoch duration =0.15s
# Cumulative duration =75.07s
#
# 529
# Epoch duration =0.14s
# Cumulative duration =75.21s
#
# 530
# Epoch duration =0.14s
# Cumulative duration =75.35s
#
# 531
# Epoch duration =0.14s
# Cumulative duration =75.48s
#
# 532
# Epoch duration =0.13s
# Cumulative duration =75.62s
#
# 533
# Epoch duration =0.14s
# Cumulative duration =75.76s
#
# 534
# Epoch duration =0.15s
# Cumulative duration =75.9s
#
# 535
# Epoch duration =0.14s
# Cumulative duration =76.05s
#
# 536
# Epoch duration =0.14s
# Cumulative duration =76.18s
#
# 537
# Epoch duration =0.14s
# Cumulative duration =76.32s
#
# 538
# Epoch duration =0.14s
# Cumulative duration =76.46s
#
# 539
# Epoch duration =0.13s
# Cumulative duration =76.59s
#
# 540
# Epoch duration =0.14s
# Cumulative duration =76.73s
#
# 541
# Epoch duration =0.16s
# Cumulative duration =76.88s
#
# 542
# Epoch duration =0.14s
# Cumulative duration =77.02s
#
# 543
# Epoch duration =0.14s
# Cumulative duration =77.16s
#
# 544
# Epoch duration =0.14s
# Cumulative duration =77.3s
#
# 545
# Epoch duration =0.14s
# Cumulative duration =77.44s
#
# 546
# Epoch duration =0.14s
# Cumulative duration =77.58s
#
# 547
# Epoch duration =0.13s
# Cumulative duration =77.71s
#
# 548
# Epoch duration =0.14s
# Cumulative duration =77.85s
#
# 549
# Epoch duration =0.16s
# Cumulative duration =78.01s
#
# 550
# Epoch duration =0.14s
# Cumulative duration =78.14s
#
# 551
# Epoch duration =0.14s
# Cumulative duration =78.28s
#
# 552
# Epoch duration =0.14s
# Cumulative duration =78.42s
#
# 553
# Epoch duration =0.14s
# Cumulative duration =78.56s
#
# 554
# Epoch duration =0.14s
# Cumulative duration =78.69s
#
# 555
# Epoch duration =0.14s
# Cumulative duration =78.83s
#
# 556
# Epoch duration =0.14s
# Cumulative duration =78.97s
#
# 557
# Epoch duration =0.14s
# Cumulative duration =79.1s
#
# 558
# Epoch duration =0.14s
# Cumulative duration =79.24s
#
# 559
# Epoch duration =0.13s
# Cumulative duration =79.38s
#
# 560
# Epoch duration =0.14s
# Cumulative duration =79.52s
#
# 561
# Epoch duration =0.13s
# Cumulative duration =79.65s
#
# 562
# Epoch duration =0.13s
# Cumulative duration =79.78s
#
# 563
# Epoch duration =0.13s
# Cumulative duration =79.92s
#
# 564
# Epoch duration =0.14s
# Cumulative duration =80.06s
#
# 565
# Epoch duration =0.14s
# Cumulative duration =80.2s
#
# 566
# Epoch duration =0.14s
# Cumulative duration =80.34s
#
# 567
# Epoch duration =0.14s
# Cumulative duration =80.47s
#
# 568
# Epoch duration =0.14s
# Cumulative duration =80.61s
#
# 569
# Epoch duration =0.15s
# Cumulative duration =80.76s
#
# 570
# Epoch duration =0.16s
# Cumulative duration =80.92s
#
# 571
# Epoch duration =0.14s
# Cumulative duration =81.05s
#
# 572
# Epoch duration =0.14s
# Cumulative duration =81.19s
#
# 573
# Epoch duration =0.14s
# Cumulative duration =81.33s
#
# 574
# Epoch duration =0.14s
# Cumulative duration =81.46s
#
# 575
# Epoch duration =0.14s
# Cumulative duration =81.6s
#
# 576
# Epoch duration =0.14s
# Cumulative duration =81.74s
#
# 577
# Epoch duration =0.14s
# Cumulative duration =81.88s
#
# 578
# Epoch duration =0.15s
# Cumulative duration =82.03s
#
# 579
# Epoch duration =0.14s
# Cumulative duration =82.17s
#
# 580
# Epoch duration =0.14s
# Cumulative duration =82.31s
#
# 581
# Epoch duration =0.14s
# Cumulative duration =82.44s
#
# 582
# Epoch duration =0.14s
# Cumulative duration =82.58s
#
# 583
# Epoch duration =0.14s
# Cumulative duration =82.72s
#
# 584
# Epoch duration =0.14s
# Cumulative duration =82.86s
#
# 585
# Epoch duration =0.14s
# Cumulative duration =82.99s
#
# 586
# Epoch duration =0.15s
# Cumulative duration =83.14s
#
# 587
# Epoch duration =0.14s
# Cumulative duration =83.28s
#
# 588
# Epoch duration =0.14s
# Cumulative duration =83.42s
#
# 589
# Epoch duration =0.14s
# Cumulative duration =83.57s
#
# 590
# Epoch duration =0.14s
# Cumulative duration =83.71s
#
# 591
# Epoch duration =0.14s
# Cumulative duration =83.85s
#
# 592
# Epoch duration =0.13s
# Cumulative duration =83.99s
#
# 593
# Epoch duration =0.13s
# Cumulative duration =84.12s
#
# 594
# Epoch duration =0.13s
# Cumulative duration =84.25s
#
# 595
# Epoch duration =0.14s
# Cumulative duration =84.39s
#
# 596
# Epoch duration =0.14s
# Cumulative duration =84.53s
#
# 597
# Epoch duration =0.14s
# Cumulative duration =84.67s
#
# 598
# Epoch duration =0.15s
# Cumulative duration =84.82s
#
# 599
# Epoch duration =0.14s
# Cumulative duration =84.96s
#
# 600
# Epoch duration =0.14s
# Cumulative duration =85.1s
#
# 601
# Epoch duration =0.15s
# Cumulative duration =85.24s
#
# 602
# Epoch duration =0.18s
# Cumulative duration =85.42s
#
# 603
# Epoch duration =0.15s
# Cumulative duration =85.57s
#
# 604
# Epoch duration =0.19s
# Cumulative duration =85.76s
#
# 605
# Epoch duration =0.16s
# Cumulative duration =85.92s
#
# 606
# Epoch duration =0.14s
# Cumulative duration =86.06s
#
# 607
# Epoch duration =0.14s
# Cumulative duration =86.2s
#
# 608
# Epoch duration =0.14s
# Cumulative duration =86.34s
#
# 609
# Epoch duration =0.14s
# Cumulative duration =86.48s
#
# 610
# Epoch duration =0.14s
# Cumulative duration =86.62s
#
# 611
# Epoch duration =0.14s
# Cumulative duration =86.76s
#
# 612
# Epoch duration =0.19s
# Cumulative duration =86.95s
#
# 613
# Epoch duration =0.17s
# Cumulative duration =87.11s
#
# 614
# Epoch duration =0.14s
# Cumulative duration =87.26s
#
# 615
# Epoch duration =0.14s
# Cumulative duration =87.4s
#
# 616
# Epoch duration =0.15s
# Cumulative duration =87.55s
#
# 617
# Epoch duration =0.14s
# Cumulative duration =87.69s
#
# 618
# Epoch duration =0.14s
# Cumulative duration =87.83s
#
# 619
# Epoch duration =0.15s
# Cumulative duration =87.99s
#
# 620
# Epoch duration =0.15s
# Cumulative duration =88.14s
#
# 621
# Epoch duration =0.16s
# Cumulative duration =88.3s
#
# 622
# Epoch duration =0.15s
# Cumulative duration =88.44s
#
# 623
# Epoch duration =0.17s
# Cumulative duration =88.61s
#
# 624
# Epoch duration =0.14s
# Cumulative duration =88.75s
#
# 625
# Epoch duration =0.14s
# Cumulative duration =88.89s
#
# 626
# Epoch duration =0.14s
# Cumulative duration =89.03s
#
# 627
# Epoch duration =0.13s
# Cumulative duration =89.17s
#
# 628
# Epoch duration =0.15s
# Cumulative duration =89.32s
#
# 629
# Epoch duration =0.22s
# Cumulative duration =89.54s
#
# 630
# Epoch duration =0.15s
# Cumulative duration =89.69s
#
# 631
# Epoch duration =0.16s
# Cumulative duration =89.85s
#
# 632
# Epoch duration =0.14s
# Cumulative duration =89.99s
#
# 633
# Epoch duration =0.14s
# Cumulative duration =90.13s
#
# 634
# Epoch duration =0.13s
# Cumulative duration =90.27s
#
# 635
# Epoch duration =0.14s
# Cumulative duration =90.4s
#
# 636
# Epoch duration =0.14s
# Cumulative duration =90.55s
#
# 637
# Epoch duration =0.14s
# Cumulative duration =90.69s
#
# 638
# Epoch duration =0.2s
# Cumulative duration =90.89s
#
# 639
# Epoch duration =0.16s
# Cumulative duration =91.05s
#
# 640
# Epoch duration =0.13s
# Cumulative duration =91.19s
#
# 641
# Epoch duration =0.14s
# Cumulative duration =91.33s
#
# 642
# Epoch duration =0.14s
# Cumulative duration =91.47s
#
# 643
# Epoch duration =0.16s
# Cumulative duration =91.62s
#
# 644
# Epoch duration =0.13s
# Cumulative duration =91.76s
#
# 645
# Epoch duration =0.14s
# Cumulative duration =91.9s
#
# 646
# Epoch duration =0.14s
# Cumulative duration =92.04s
#
# 647
# Epoch duration =0.16s
# Cumulative duration =92.2s
#
# 648
# Epoch duration =0.15s
# Cumulative duration =92.35s
#
# 649
# Epoch duration =0.16s
# Cumulative duration =92.51s
#
# 650
# Epoch duration =0.13s
# Cumulative duration =92.65s
#
# 651
# Epoch duration =0.14s
# Cumulative duration =92.78s
#
# 652
# Epoch duration =0.14s
# Cumulative duration =92.92s
#
# 653
# Epoch duration =0.14s
# Cumulative duration =93.06s
#
# 654
# Epoch duration =0.14s
# Cumulative duration =93.2s
#
# 655
# Epoch duration =0.14s
# Cumulative duration =93.34s
#
# 656
# Epoch duration =0.15s
# Cumulative duration =93.49s
#
# 657
# Epoch duration =0.14s
# Cumulative duration =93.63s
#
# 658
# Epoch duration =0.14s
# Cumulative duration =93.77s
#
# 659
# Epoch duration =0.14s
# Cumulative duration =93.92s
#
# 660
# Epoch duration =0.14s
# Cumulative duration =94.06s
#
# 661
# Epoch duration =0.14s
# Cumulative duration =94.2s
#
# 662
# Epoch duration =0.14s
# Cumulative duration =94.34s
#
# 663
# Epoch duration =0.14s
# Cumulative duration =94.48s
#
# 664
# Epoch duration =0.17s
# Cumulative duration =94.64s
#
# 665
# Epoch duration =0.14s
# Cumulative duration =94.78s
#
# 666
# Epoch duration =0.14s
# Cumulative duration =94.92s
#
# 667
# Epoch duration =0.14s
# Cumulative duration =95.06s
#
# 668
# Epoch duration =0.14s
# Cumulative duration =95.2s
#
# 669
# Epoch duration =0.14s
# Cumulative duration =95.34s
#
# 670
# Epoch duration =0.15s
# Cumulative duration =95.48s
#
# 671
# Epoch duration =0.14s
# Cumulative duration =95.62s
#
# 672
# Epoch duration =0.13s
# Cumulative duration =95.76s
#
# 673
# Epoch duration =0.14s
# Cumulative duration =95.89s
#
# 674
# Epoch duration =0.14s
# Cumulative duration =96.03s
#
# 675
# Epoch duration =0.14s
# Cumulative duration =96.17s
#
# 676
# Epoch duration =0.13s
# Cumulative duration =96.3s
#
# 677
# Epoch duration =0.16s
# Cumulative duration =96.46s
#
# 678
# Epoch duration =0.15s
# Cumulative duration =96.61s
#
# 679
# Epoch duration =0.14s
# Cumulative duration =96.74s
#
# 680
# Epoch duration =0.14s
# Cumulative duration =96.88s
#
# 681
# Epoch duration =0.14s
# Cumulative duration =97.02s
#
# 682
# Epoch duration =0.14s
# Cumulative duration =97.15s
#
# 683
# Epoch duration =0.14s
# Cumulative duration =97.29s
#
# 684
# Epoch duration =0.14s
# Cumulative duration =97.43s
#
# 685
# Epoch duration =0.14s
# Cumulative duration =97.57s
#
# 686
# Epoch duration =0.14s
# Cumulative duration =97.7s
#
# 687
# Epoch duration =0.14s
# Cumulative duration =97.85s
#
# 688
# Epoch duration =0.13s
# Cumulative duration =97.98s
#
# 689
# Epoch duration =0.14s
# Cumulative duration =98.12s
#
# 690
# Epoch duration =0.15s
# Cumulative duration =98.26s
#
# 691
# Epoch duration =0.14s
# Cumulative duration =98.41s
#
# 692
# Epoch duration =0.14s
# Cumulative duration =98.54s
#
# 693
# Epoch duration =0.14s
# Cumulative duration =98.69s
#
# 694
# Epoch duration =0.14s
# Cumulative duration =98.83s
#
# 695
# Epoch duration =0.14s
# Cumulative duration =98.97s
#
# 696
# Epoch duration =0.14s
# Cumulative duration =99.1s
#
# 697
# Epoch duration =0.14s
# Cumulative duration =99.24s
#
# 698
# Epoch duration =0.14s
# Cumulative duration =99.38s
#
# 699
# Epoch duration =0.14s
# Cumulative duration =99.52s
#
# 700
# Epoch duration =0.13s
# Cumulative duration =99.66s
#
# 701
# Epoch duration =0.16s
# Cumulative duration =99.81s
#
# 702
# Epoch duration =0.14s
# Cumulative duration =99.96s
#
# 703
# Epoch duration =0.16s
# Cumulative duration =100.12s
#
# 704
# Epoch duration =0.14s
# Cumulative duration =100.25s
#
# 705
# Epoch duration =0.14s
# Cumulative duration =100.39s
#
# 706
# Epoch duration =0.14s
# Cumulative duration =100.53s
#
# 707
# Epoch duration =0.14s
# Cumulative duration =100.67s
#
# 708
# Epoch duration =0.13s
# Cumulative duration =100.8s
#
# 709
# Epoch duration =0.14s
# Cumulative duration =100.94s
#
# 710
# Epoch duration =0.14s
# Cumulative duration =101.08s
#
# 711
# Epoch duration =0.14s
# Cumulative duration =101.22s
#
# 712
# Epoch duration =0.13s
# Cumulative duration =101.35s
#
# 713
# Epoch duration =0.14s
# Cumulative duration =101.49s
#
# 714
# Epoch duration =0.15s
# Cumulative duration =101.64s
#
# 715
# Epoch duration =0.14s
# Cumulative duration =101.77s
#
# 716
# Epoch duration =0.14s
# Cumulative duration =101.91s
#
# 717
# Epoch duration =0.14s
# Cumulative duration =102.05s
#
# 718
# Epoch duration =0.15s
# Cumulative duration =102.2s
#
# 719
# Epoch duration =0.14s
# Cumulative duration =102.34s
#
# 720
# Epoch duration =0.14s
# Cumulative duration =102.47s
#
# 721
# Epoch duration =0.14s
# Cumulative duration =102.62s
#
# 722
# Epoch duration =0.14s
# Cumulative duration =102.75s
#
# 723
# Epoch duration =0.14s
# Cumulative duration =102.89s
#
# 724
# Epoch duration =0.14s
# Cumulative duration =103.03s
#
# 725
# Epoch duration =0.14s
# Cumulative duration =103.17s
#
# 726
# Epoch duration =0.14s
# Cumulative duration =103.31s
#
# 727
# Epoch duration =0.16s
# Cumulative duration =103.47s
#
# 728
# Epoch duration =0.13s
# Cumulative duration =103.61s
#
# 729
# Epoch duration =0.14s
# Cumulative duration =103.75s
#
# 730
# Epoch duration =0.16s
# Cumulative duration =103.9s
#
# 731
# Epoch duration =0.14s
# Cumulative duration =104.04s
#
# 732
# Epoch duration =0.13s
# Cumulative duration =104.18s
#
# 733
# Epoch duration =0.14s
# Cumulative duration =104.32s
#
# 734
# Epoch duration =0.14s
# Cumulative duration =104.46s
#
# 735
# Epoch duration =0.14s
# Cumulative duration =104.6s
#
# 736
# Epoch duration =0.13s
# Cumulative duration =104.73s
#
# 737
# Epoch duration =0.14s
# Cumulative duration =104.87s
#
# 738
# Epoch duration =0.13s
# Cumulative duration =105.01s
#
# 739
# Epoch duration =0.16s
# Cumulative duration =105.17s
#
# 740
# Epoch duration =0.17s
# Cumulative duration =105.34s
#
# 741
# Epoch duration =0.14s
# Cumulative duration =105.48s
#
# 742
# Epoch duration =0.14s
# Cumulative duration =105.61s
#
# 743
# Epoch duration =0.14s
# Cumulative duration =105.75s
#
# 744
# Epoch duration =0.16s
# Cumulative duration =105.91s
#
# 745
# Epoch duration =0.14s
# Cumulative duration =106.05s
#
# 746
# Epoch duration =0.14s
# Cumulative duration =106.19s
#
# 747
# Epoch duration =0.14s
# Cumulative duration =106.33s
#
# 748
# Epoch duration =0.14s
# Cumulative duration =106.47s
#
# 749
# Epoch duration =0.14s
# Cumulative duration =106.61s
#
# 750
# Epoch duration =0.2s
# Cumulative duration =106.81s
#
# 751
# Epoch duration =0.16s
# Cumulative duration =106.97s
#
# 752
# Epoch duration =0.15s
# Cumulative duration =107.12s
#
# 753
# Epoch duration =0.14s
# Cumulative duration =107.25s
#
# 754
# Epoch duration =0.14s
# Cumulative duration =107.39s
#
# 755
# Epoch duration =0.14s
# Cumulative duration =107.53s
#
# 756
# Epoch duration =0.13s
# Cumulative duration =107.66s
#
# 757
# Epoch duration =0.14s
# Cumulative duration =107.8s
#
# 758
# Epoch duration =0.14s
# Cumulative duration =107.94s
#
# 759
# Epoch duration =0.14s
# Cumulative duration =108.08s
#
# 760
# Epoch duration =0.13s
# Cumulative duration =108.21s
#
# 761
# Epoch duration =0.15s
# Cumulative duration =108.36s
#
# 762
# Epoch duration =0.14s
# Cumulative duration =108.5s
#
# 763
# Epoch duration =0.15s
# Cumulative duration =108.65s
#
# 764
# Epoch duration =0.14s
# Cumulative duration =108.79s
#
# 765
# Epoch duration =0.14s
# Cumulative duration =108.93s
#
# 766
# Epoch duration =0.14s
# Cumulative duration =109.07s
#
# 767
# Epoch duration =0.15s
# Cumulative duration =109.22s
#
# 768
# Epoch duration =0.14s
# Cumulative duration =109.36s
#
# 769
# Epoch duration =0.16s
# Cumulative duration =109.52s
#
# 770
# Epoch duration =0.13s
# Cumulative duration =109.66s
#
# 771
# Epoch duration =0.14s
# Cumulative duration =109.8s
#
# 772
# Epoch duration =0.14s
# Cumulative duration =109.94s
#
# 773
# Epoch duration =0.14s
# Cumulative duration =110.08s
#
# 774
# Epoch duration =0.16s
# Cumulative duration =110.24s
#
# 775
# Epoch duration =0.15s
# Cumulative duration =110.39s
#
# 776
# Epoch duration =0.15s
# Cumulative duration =110.54s
#
# 777
# Epoch duration =0.16s
# Cumulative duration =110.7s
#
# 778
# Epoch duration =0.14s
# Cumulative duration =110.84s
#
# 779
# Epoch duration =0.14s
# Cumulative duration =110.98s
#
# 780
# Epoch duration =0.19s
# Cumulative duration =111.17s
#
# 781
# Epoch duration =0.14s
# Cumulative duration =111.31s
#
# 782
# Epoch duration =0.14s
# Cumulative duration =111.46s
#
# 783
# Epoch duration =0.14s
# Cumulative duration =111.59s
#
# 784
# Epoch duration =0.14s
# Cumulative duration =111.73s
#
# 785
# Epoch duration =0.14s
# Cumulative duration =111.87s
#
# 786
# Epoch duration =0.14s
# Cumulative duration =112.0s
#
# 787
# Epoch duration =0.15s
# Cumulative duration =112.15s
#
# 788
# Epoch duration =0.18s
# Cumulative duration =112.33s
#
# 789
# Epoch duration =0.16s
# Cumulative duration =112.49s
#
# 790
# Epoch duration =0.13s
# Cumulative duration =112.62s
#
# 791
# Epoch duration =0.14s
# Cumulative duration =112.76s
#
# 792
# Epoch duration =0.14s
# Cumulative duration =112.9s
#
# 793
# Epoch duration =0.14s
# Cumulative duration =113.04s
#
# 794
# Epoch duration =0.14s
# Cumulative duration =113.18s
#
# 795
# Epoch duration =0.15s
# Cumulative duration =113.33s
#
# 796
# Epoch duration =0.14s
# Cumulative duration =113.47s
#
# 797
# Epoch duration =0.16s
# Cumulative duration =113.63s
#
# 798
# Epoch duration =0.14s
# Cumulative duration =113.77s
#
# 799
# Epoch duration =0.14s
# Cumulative duration =113.91s
#
# 800
# Epoch duration =0.14s
# Cumulative duration =114.04s
#
# 801
# Epoch duration =0.14s
# Cumulative duration =114.18s
#
# 802
# Epoch duration =0.14s
# Cumulative duration =114.32s
#
# 803
# Epoch duration =0.14s
# Cumulative duration =114.47s
#
# 804
# Epoch duration =0.14s
# Cumulative duration =114.6s
#
# 805
# Epoch duration =0.14s
# Cumulative duration =114.74s
#
# 806
# Epoch duration =0.14s
# Cumulative duration =114.88s
#
# 807
# Epoch duration =0.14s
# Cumulative duration =115.03s
#
# 808
# Epoch duration =0.14s
# Cumulative duration =115.16s
#
# 809
# Epoch duration =0.14s
# Cumulative duration =115.3s
#
# 810
# Epoch duration =0.14s
# Cumulative duration =115.44s
#
# 811
# Epoch duration =0.14s
# Cumulative duration =115.58s
#
# 812
# Epoch duration =0.14s
# Cumulative duration =115.72s
#
# 813
# Epoch duration =0.14s
# Cumulative duration =115.86s
#
# 814
# Epoch duration =0.14s
# Cumulative duration =116.0s
#
# 815
# Epoch duration =0.14s
# Cumulative duration =116.13s
#
# 816
# Epoch duration =0.14s
# Cumulative duration =116.27s
#
# 817
# Epoch duration =0.14s
# Cumulative duration =116.41s
#
# 818
# Epoch duration =0.14s
# Cumulative duration =116.55s
#
# 819
# Epoch duration =0.17s
# Cumulative duration =116.72s
#
# 820
# Epoch duration =0.14s
# Cumulative duration =116.86s
#
# 821
# Epoch duration =0.17s
# Cumulative duration =117.03s
#
# 822
# Epoch duration =0.14s
# Cumulative duration =117.17s
#
# 823
# Epoch duration =0.14s
# Cumulative duration =117.31s
#
# 824
# Epoch duration =0.14s
# Cumulative duration =117.45s
#
# 825
# Epoch duration =0.16s
# Cumulative duration =117.61s
#
# 826
# Epoch duration =0.14s
# Cumulative duration =117.75s
#
# 827
# Epoch duration =0.14s
# Cumulative duration =117.89s
#
# 828
# Epoch duration =0.14s
# Cumulative duration =118.03s
#
# 829
# Epoch duration =0.16s
# Cumulative duration =118.19s
#
# 830
# Epoch duration =0.14s
# Cumulative duration =118.33s
#
# 831
# Epoch duration =0.14s
# Cumulative duration =118.46s
#
# 832
# Epoch duration =0.14s
# Cumulative duration =118.6s
#
# 833
# Epoch duration =0.14s
# Cumulative duration =118.74s
#
# 834
# Epoch duration =0.14s
# Cumulative duration =118.88s
#
# 835
# Epoch duration =0.14s
# Cumulative duration =119.01s
#
# 836
# Epoch duration =0.16s
# Cumulative duration =119.17s
#
# 837
# Epoch duration =0.14s
# Cumulative duration =119.31s
#
# 838
# Epoch duration =0.13s
# Cumulative duration =119.45s
#
# 839
# Epoch duration =0.14s
# Cumulative duration =119.59s
#
# 840
# Epoch duration =0.14s
# Cumulative duration =119.73s
#
# 841
# Epoch duration =0.14s
# Cumulative duration =119.87s
#
# 842
# Epoch duration =0.14s
# Cumulative duration =120.01s
#
# 843
# Epoch duration =0.14s
# Cumulative duration =120.15s
#
# 844
# Epoch duration =0.14s
# Cumulative duration =120.29s
#
# 845
# Epoch duration =0.16s
# Cumulative duration =120.45s
#
# 846
# Epoch duration =0.14s
# Cumulative duration =120.59s
#
# 847
# Epoch duration =0.14s
# Cumulative duration =120.73s
#
# 848
# Epoch duration =0.14s
# Cumulative duration =120.88s
#
# 849
# Epoch duration =0.14s
# Cumulative duration =121.01s
#
# 850
# Epoch duration =0.17s
# Cumulative duration =121.18s
#
# 851
# Epoch duration =0.16s
# Cumulative duration =121.34s
#
# 852
# Epoch duration =0.14s
# Cumulative duration =121.48s
#
# 853
# Epoch duration =0.14s
# Cumulative duration =121.62s
#
# 854
# Epoch duration =0.13s
# Cumulative duration =121.75s
#
# 855
# Epoch duration =0.14s
# Cumulative duration =121.9s
#
# 856
# Epoch duration =0.14s
# Cumulative duration =122.03s
#
# 857
# Epoch duration =0.14s
# Cumulative duration =122.17s
#
# 858
# Epoch duration =0.14s
# Cumulative duration =122.31s
#
# 859
# Epoch duration =0.14s
# Cumulative duration =122.46s
#
# 860
# Epoch duration =0.13s
# Cumulative duration =122.59s
#
# 861
# Epoch duration =0.14s
# Cumulative duration =122.73s
#
# 862
# Epoch duration =0.14s
# Cumulative duration =122.86s
#
# 863
# Epoch duration =0.15s
# Cumulative duration =123.01s
#
# 864
# Epoch duration =0.14s
# Cumulative duration =123.15s
#
# 865
# Epoch duration =0.16s
# Cumulative duration =123.32s
#
# 866
# Epoch duration =0.14s
# Cumulative duration =123.46s
#
# 867
# Epoch duration =0.14s
# Cumulative duration =123.6s
#
# 868
# Epoch duration =0.13s
# Cumulative duration =123.73s
#
# 869
# Epoch duration =0.14s
# Cumulative duration =123.87s
#
# 870
# Epoch duration =0.14s
# Cumulative duration =124.01s
#
# 871
# Epoch duration =0.14s
# Cumulative duration =124.15s
#
# 872
# Epoch duration =0.14s
# Cumulative duration =124.29s
#
# 873
# Epoch duration =0.14s
# Cumulative duration =124.43s
#
# 874
# Epoch duration =0.14s
# Cumulative duration =124.57s
#
# 875
# Epoch duration =0.14s
# Cumulative duration =124.71s
#
# 876
# Epoch duration =0.14s
# Cumulative duration =124.85s
#
# 877
# Epoch duration =0.14s
# Cumulative duration =124.98s
#
# 878
# Epoch duration =0.15s
# Cumulative duration =125.13s
#
# 879
# Epoch duration =0.18s
# Cumulative duration =125.32s
#
# 880
# Epoch duration =0.14s
# Cumulative duration =125.46s
#
# 881
# Epoch duration =0.14s
# Cumulative duration =125.6s
#
# 882
# Epoch duration =0.14s
# Cumulative duration =125.73s
#
# 883
# Epoch duration =0.16s
# Cumulative duration =125.89s
#
# 884
# Epoch duration =0.13s
# Cumulative duration =126.03s
#
# 885
# Epoch duration =0.14s
# Cumulative duration =126.16s
#
# 886
# Epoch duration =0.14s
# Cumulative duration =126.3s
#
# 887
# Epoch duration =0.16s
# Cumulative duration =126.46s
#
# 888
# Epoch duration =0.14s
# Cumulative duration =126.6s
#
# 889
# Epoch duration =0.14s
# Cumulative duration =126.74s
#
# 890
# Epoch duration =0.14s
# Cumulative duration =126.88s
#
# 891
# Epoch duration =0.14s
# Cumulative duration =127.01s
#
# 892
# Epoch duration =0.13s
# Cumulative duration =127.15s
#
# 893
# Epoch duration =0.14s
# Cumulative duration =127.29s
#
# 894
# Epoch duration =0.14s
# Cumulative duration =127.43s
#
# 895
# Epoch duration =0.14s
# Cumulative duration =127.57s
#
# 896
# Epoch duration =0.14s
# Cumulative duration =127.71s
#
# 897
# Epoch duration =0.14s
# Cumulative duration =127.85s
#
# 898
# Epoch duration =0.14s
# Cumulative duration =127.99s
#
# 899
# Epoch duration =0.14s
# Cumulative duration =128.13s
#
# 900
# Epoch duration =0.14s
# Cumulative duration =128.27s
#
# 901
# Epoch duration =0.14s
# Cumulative duration =128.41s
#
# 902
# Epoch duration =0.13s
# Cumulative duration =128.54s
#
# 903
# Epoch duration =0.15s
# Cumulative duration =128.7s
#
# 904
# Epoch duration =0.14s
# Cumulative duration =128.84s
#
# 905
# Epoch duration =0.14s
# Cumulative duration =128.97s
#
# 906
# Epoch duration =0.14s
# Cumulative duration =129.11s
#
# 907
# Epoch duration =0.14s
# Cumulative duration =129.25s
#
# 908
# Epoch duration =0.13s
# Cumulative duration =129.38s
#
# 909
# Epoch duration =0.14s
# Cumulative duration =129.52s
#
# 910
# Epoch duration =0.13s
# Cumulative duration =129.65s
#
# 911
# Epoch duration =0.17s
# Cumulative duration =129.83s
#
# 912
# Epoch duration =0.14s
# Cumulative duration =129.96s
#
# 913
# Epoch duration =0.16s
# Cumulative duration =130.12s
#
# 914
# Epoch duration =0.13s
# Cumulative duration =130.26s
#
# 915
# Epoch duration =0.14s
# Cumulative duration =130.4s
#
# 916
# Epoch duration =0.14s
# Cumulative duration =130.53s
#
# 917
# Epoch duration =0.14s
# Cumulative duration =130.67s
#
# 918
# Epoch duration =0.14s
# Cumulative duration =130.81s
#
# 919
# Epoch duration =0.17s
# Cumulative duration =130.98s
#
# 920
# Epoch duration =0.13s
# Cumulative duration =131.11s
#
# 921
# Epoch duration =0.14s
# Cumulative duration =131.25s
#
# 922
# Epoch duration =0.13s
# Cumulative duration =131.39s
#
# 923
# Epoch duration =0.14s
# Cumulative duration =131.53s
#
# 924
# Epoch duration =0.14s
# Cumulative duration =131.67s
#
# 925
# Epoch duration =0.15s
# Cumulative duration =131.82s
#
# 926
# Epoch duration =0.14s
# Cumulative duration =131.95s
#
# 927
# Epoch duration =0.14s
# Cumulative duration =132.09s
#
# 928
# Epoch duration =0.15s
# Cumulative duration =132.24s
#
# 929
# Epoch duration =0.14s
# Cumulative duration =132.38s
#
# 930
# Epoch duration =0.16s
# Cumulative duration =132.54s
#
# 931
# Epoch duration =0.14s
# Cumulative duration =132.68s
#
# 932
# Epoch duration =0.14s
# Cumulative duration =132.82s
#
# 933
# Epoch duration =0.14s
# Cumulative duration =132.96s
#
# 934
# Epoch duration =0.14s
# Cumulative duration =133.09s
#
# 935
# Epoch duration =0.14s
# Cumulative duration =133.24s
#
# 936
# Epoch duration =0.14s
# Cumulative duration =133.37s
#
# 937
# Epoch duration =0.15s
# Cumulative duration =133.53s
#
# 938
# Epoch duration =0.13s
# Cumulative duration =133.66s
#
# 939
# Epoch duration =0.14s
# Cumulative duration =133.8s
#
# 940
# Epoch duration =0.14s
# Cumulative duration =133.94s
#
# 941
# Epoch duration =0.14s
# Cumulative duration =134.08s
#
# 942
# Epoch duration =0.14s
# Cumulative duration =134.22s
#
# 943
# Epoch duration =0.14s
# Cumulative duration =134.36s
#
# 944
# Epoch duration =0.14s
# Cumulative duration =134.49s
#
# 945
# Epoch duration =0.14s
# Cumulative duration =134.63s
#
# 946
# Epoch duration =0.13s
# Cumulative duration =134.76s
#
# 947
# Epoch duration =0.16s
# Cumulative duration =134.92s
#
# 948
# Epoch duration =0.14s
# Cumulative duration =135.06s
#
# 949
# Epoch duration =0.14s
# Cumulative duration =135.2s
#
# 950
# Epoch duration =0.14s
# Cumulative duration =135.34s
#
# 951
# Epoch duration =0.14s
# Cumulative duration =135.48s
#
# 952
# Epoch duration =0.15s
# Cumulative duration =135.63s
#
# 953
# Epoch duration =0.18s
# Cumulative duration =135.81s
#
# 954
# Epoch duration =0.14s
# Cumulative duration =135.94s
#
# 955
# Epoch duration =0.14s
# Cumulative duration =136.08s
#
# 956
# Epoch duration =0.14s
# Cumulative duration =136.22s
#
# 957
# Epoch duration =0.14s
# Cumulative duration =136.36s
#
# 958
# Epoch duration =0.14s
# Cumulative duration =136.5s
#
# 959
# Epoch duration =0.14s
# Cumulative duration =136.63s
#
# 960
# Epoch duration =0.14s
# Cumulative duration =136.77s
#
# 961
# Epoch duration =0.14s
# Cumulative duration =136.91s
#
# 962
# Epoch duration =0.14s
# Cumulative duration =137.05s
#
# 963
# Epoch duration =0.14s
# Cumulative duration =137.19s
#
# 964
# Epoch duration =0.13s
# Cumulative duration =137.32s
#
# 965
# Epoch duration =0.14s
# Cumulative duration =137.46s
#
# 966
# Epoch duration =0.13s
# Cumulative duration =137.59s
#
# 967
# Epoch duration =0.15s
# Cumulative duration =137.74s
#
# 968
# Epoch duration =0.14s
# Cumulative duration =137.89s
#
# 969
# Epoch duration =0.16s
# Cumulative duration =138.05s
#
# 970
# Epoch duration =0.14s
# Cumulative duration =138.18s
#
# 971
# Epoch duration =0.16s
# Cumulative duration =138.35s
#
# 972
# Epoch duration =0.14s
# Cumulative duration =138.49s
#
# 973
# Epoch duration =0.14s
# Cumulative duration =138.63s
#
# 974
# Epoch duration =0.14s
# Cumulative duration =138.76s
#
# 975
# Epoch duration =0.14s
# Cumulative duration =138.9s
#
# 976
# Epoch duration =0.14s
# Cumulative duration =139.04s
#
# 977
# Epoch duration =0.14s
# Cumulative duration =139.18s
#
# 978
# Epoch duration =0.14s
# Cumulative duration =139.32s
#
# 979
# Epoch duration =0.16s
# Cumulative duration =139.48s
#
# 980
# Epoch duration =0.14s
# Cumulative duration =139.62s
#
# 981
# Epoch duration =0.14s
# Cumulative duration =139.76s
#
# 982
# Epoch duration =0.14s
# Cumulative duration =139.89s
#
# 983
# Epoch duration =0.15s
# Cumulative duration =140.04s
#
# 984
# Epoch duration =0.14s
# Cumulative duration =140.18s
#
# 985
# Epoch duration =0.14s
# Cumulative duration =140.32s
#
# 986
# Epoch duration =0.14s
# Cumulative duration =140.46s
#
# 987
# Epoch duration =0.14s
# Cumulative duration =140.6s
#
# 988
# Epoch duration =0.14s
# Cumulative duration =140.74s
#
# 989
# Epoch duration =0.16s
# Cumulative duration =140.9s
#
# 990
# Epoch duration =0.14s
# Cumulative duration =141.04s
#
# 991
# Epoch duration =0.15s
# Cumulative duration =141.19s
#
# 992
# Epoch duration =0.14s
# Cumulative duration =141.33s
#
# 993
# Epoch duration =0.15s
# Cumulative duration =141.48s
#
# 994
# Epoch duration =0.15s
# Cumulative duration =141.63s
#
# 995
# Epoch duration =0.18s
# Cumulative duration =141.81s
#
# 996
# Epoch duration =0.14s
# Cumulative duration =141.95s
#
# 997
# Epoch duration =0.14s
# Cumulative duration =142.08s
#
# 998
# Epoch duration =0.14s
# Cumulative duration =142.22s
#
# 999
# Epoch duration =0.16s
# Cumulative duration =142.38s

# %%
# Load the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_1_64_sumneuron_0_1000.npy'
sum_mut2_scores = np.load(npy_save_path)

num_summary = 1000
#average the values
mean_mut2_scores = sum_mut2_scores/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_scores_hol = mean_mut2_scores.reshape(X.shape[1],X.shape[1],4,4,dense.shape[1])

# %%
#select neuron
neuron = top_neurons[0]
#select mutation information for that neuron
mean_mut2_predictoutputs_hol = mean_mut2_scores_hol[:, :, :, :, neuron]


nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(15,14))

num = 15

for one in range(num):
    for two in range(num):
        ax = fig4.add_subplot(num, num, ((one*num)+two)+1)
        
        #plot the 0th column with row labels and the num_th most row with column labels
        if two == 0:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc, cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=nuc, cbar=False)
        else:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=[], cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=[], cbar=False)

# %% [markdown]
# #### Top scored sequences by neuron's score

# %%
# initialize session
sess = utils.initialize_session()

# set best parameters
nntrainer.set_best_parameters(sess)

#select neuron
neuron = top_neurons[0]
#sort
top_indices = np.argsort(dense[:,neuron])[::-1]

num_summary = 1000

sum_mut2_scores = np.zeros((41*41*16,))
starttime = time.time()


for ii in range(num_summary):
    print (ii)
    epoch_starttime = time.time()
    
    X = np.expand_dims(test['inputs'][top_indices[ii]], axis=0)
    
    #mutate the sequence
    X_mutsecorder = mf.double_mutate(X, X.shape[1], X.shape[3])

    #reshape the 6D tensor into a 4D tensor that the model can test
    X_mutsecorder_reshape = np.reshape(X_mutsecorder, (X.shape[1]*X.shape[1]*16, X.shape[1], 1, 4))
    
    mutations = {'inputs': X_mutsecorder_reshape, 'targets': Y_test[:X_mutsecorder_reshape.shape[0]]}
    
    #Get the neuron's scores for the mutations
    mut2_scores= nntrainer.get_activations(sess, mutations, layer='dense_0_active')[:,neuron]
    
    #Sum all the scores into a single matrix
    sum_mut2_scores += mut2_scores
    
    epoch_endtime = time.time()
    
    print ('Epoch duration =' + str(np.around((epoch_endtime -epoch_starttime), 2)) + 's')
    print ('Cumulative duration =' + str(np.around((epoch_endtime - starttime), 2)) + 's')
    print ()

# Save the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_1_64_sumneuron_1_1000.npy'
np.save(npy_save_path, sum_mut2_scores)
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_64_best.ckpt
# 0
# Epoch duration =0.16s
# Cumulative duration =0.16s
#
# 1
# Epoch duration =0.14s
# Cumulative duration =0.3s
#
# 2
# Epoch duration =0.14s
# Cumulative duration =0.43s
#
# 3
# Epoch duration =0.15s
# Cumulative duration =0.58s
#
# 4
# Epoch duration =0.14s
# Cumulative duration =0.73s
#
# 5
# Epoch duration =0.14s
# Cumulative duration =0.86s
#
# 6
# Epoch duration =0.14s
# Cumulative duration =1.0s
#
# 7
# Epoch duration =0.14s
# Cumulative duration =1.14s
#
# 8
# Epoch duration =0.14s
# Cumulative duration =1.28s
#
# 9
# Epoch duration =0.15s
# Cumulative duration =1.42s
#
# 10
# Epoch duration =0.15s
# Cumulative duration =1.58s
#
# 11
# Epoch duration =0.14s
# Cumulative duration =1.72s
#
# 12
# Epoch duration =0.14s
# Cumulative duration =1.86s
#
# 13
# Epoch duration =0.15s
# Cumulative duration =2.01s
#
# 14
# Epoch duration =0.15s
# Cumulative duration =2.16s
#
# 15
# Epoch duration =0.13s
# Cumulative duration =2.3s
#
# 16
# Epoch duration =0.14s
# Cumulative duration =2.43s
#
# 17
# Epoch duration =0.17s
# Cumulative duration =2.6s
#
# 18
# Epoch duration =0.17s
# Cumulative duration =2.77s
#
# 19
# Epoch duration =0.14s
# Cumulative duration =2.91s
#
# 20
# Epoch duration =0.13s
# Cumulative duration =3.05s
#
# 21
# Epoch duration =0.14s
# Cumulative duration =3.18s
#
# 22
# Epoch duration =0.15s
# Cumulative duration =3.33s
#
# 23
# Epoch duration =0.14s
# Cumulative duration =3.47s
#
# 24
# Epoch duration =0.15s
# Cumulative duration =3.61s
#
# 25
# Epoch duration =0.14s
# Cumulative duration =3.75s
#
# 26
# Epoch duration =0.14s
# Cumulative duration =3.88s
#
# 27
# Epoch duration =0.13s
# Cumulative duration =4.02s
#
# 28
# Epoch duration =0.15s
# Cumulative duration =4.17s
#
# 29
# Epoch duration =0.16s
# Cumulative duration =4.33s
#
# 30
# Epoch duration =0.14s
# Cumulative duration =4.47s
#
# 31
# Epoch duration =0.14s
# Cumulative duration =4.61s
#
# 32
# Epoch duration =0.15s
# Cumulative duration =4.76s
#
# 33
# Epoch duration =0.14s
# Cumulative duration =4.9s
#
# 34
# Epoch duration =0.14s
# Cumulative duration =5.04s
#
# 35
# Epoch duration =0.14s
# Cumulative duration =5.18s
#
# 36
# Epoch duration =0.14s
# Cumulative duration =5.32s
#
# 37
# Epoch duration =0.14s
# Cumulative duration =5.45s
#
# 38
# Epoch duration =0.14s
# Cumulative duration =5.59s
#
# 39
# Epoch duration =0.14s
# Cumulative duration =5.72s
#
# 40
# Epoch duration =0.14s
# Cumulative duration =5.86s
#
# 41
# Epoch duration =0.13s
# Cumulative duration =5.99s
#
# 42
# Epoch duration =0.15s
# Cumulative duration =6.14s
#
# 43
# Epoch duration =0.14s
# Cumulative duration =6.28s
#
# 44
# Epoch duration =0.14s
# Cumulative duration =6.42s
#
# 45
# Epoch duration =0.13s
# Cumulative duration =6.55s
#
# 46
# Epoch duration =0.14s
# Cumulative duration =6.69s
#
# 47
# Epoch duration =0.13s
# Cumulative duration =6.83s
#
# 48
# Epoch duration =0.14s
# Cumulative duration =6.97s
#
# 49
# Epoch duration =0.14s
# Cumulative duration =7.11s
#
# 50
# Epoch duration =0.14s
# Cumulative duration =7.24s
#
# 51
# Epoch duration =0.16s
# Cumulative duration =7.4s
#
# 52
# Epoch duration =0.14s
# Cumulative duration =7.54s
#
# 53
# Epoch duration =0.14s
# Cumulative duration =7.68s
#
# 54
# Epoch duration =0.13s
# Cumulative duration =7.81s
#
# 55
# Epoch duration =0.13s
# Cumulative duration =7.95s
#
# 56
# Epoch duration =0.14s
# Cumulative duration =8.08s
#
# 57
# Epoch duration =0.13s
# Cumulative duration =8.22s
#
# 58
# Epoch duration =0.15s
# Cumulative duration =8.37s
#
# 59
# Epoch duration =0.13s
# Cumulative duration =8.5s
#
# 60
# Epoch duration =0.14s
# Cumulative duration =8.64s
#
# 61
# Epoch duration =0.13s
# Cumulative duration =8.77s
#
# 62
# Epoch duration =0.14s
# Cumulative duration =8.91s
#
# 63
# Epoch duration =0.16s
# Cumulative duration =9.07s
#
# 64
# Epoch duration =0.14s
# Cumulative duration =9.21s
#
# 65
# Epoch duration =0.14s
# Cumulative duration =9.35s
#
# 66
# Epoch duration =0.19s
# Cumulative duration =9.54s
#
# 67
# Epoch duration =0.14s
# Cumulative duration =9.68s
#
# 68
# Epoch duration =0.14s
# Cumulative duration =9.82s
#
# 69
# Epoch duration =0.13s
# Cumulative duration =9.96s
#
# 70
# Epoch duration =0.14s
# Cumulative duration =10.1s
#
# 71
# Epoch duration =0.15s
# Cumulative duration =10.25s
#
# 72
# Epoch duration =0.14s
# Cumulative duration =10.38s
#
# 73
# Epoch duration =0.14s
# Cumulative duration =10.52s
#
# 74
# Epoch duration =0.13s
# Cumulative duration =10.65s
#
# 75
# Epoch duration =0.13s
# Cumulative duration =10.79s
#
# 76
# Epoch duration =0.14s
# Cumulative duration =10.92s
#
# 77
# Epoch duration =0.15s
# Cumulative duration =11.08s
#
# 78
# Epoch duration =0.16s
# Cumulative duration =11.24s
#
# 79
# Epoch duration =0.14s
# Cumulative duration =11.37s
#
# 80
# Epoch duration =0.13s
# Cumulative duration =11.51s
#
# 81
# Epoch duration =0.14s
# Cumulative duration =11.65s
#
# 82
# Epoch duration =0.14s
# Cumulative duration =11.79s
#
# 83
# Epoch duration =0.13s
# Cumulative duration =11.92s
#
# 84
# Epoch duration =0.13s
# Cumulative duration =12.05s
#
# 85
# Epoch duration =0.13s
# Cumulative duration =12.19s
#
# 86
# Epoch duration =0.14s
# Cumulative duration =12.33s
#
# 87
# Epoch duration =0.13s
# Cumulative duration =12.46s
#
# 88
# Epoch duration =0.14s
# Cumulative duration =12.6s
#
# 89
# Epoch duration =0.14s
# Cumulative duration =12.73s
#
# 90
# Epoch duration =0.13s
# Cumulative duration =12.86s
#
# 91
# Epoch duration =0.14s
# Cumulative duration =13.01s
#
# 92
# Epoch duration =0.14s
# Cumulative duration =13.15s
#
# 93
# Epoch duration =0.13s
# Cumulative duration =13.28s
#
# 94
# Epoch duration =0.13s
# Cumulative duration =13.42s
#
# 95
# Epoch duration =0.13s
# Cumulative duration =13.55s
#
# 96
# Epoch duration =0.14s
# Cumulative duration =13.7s
#
# 97
# Epoch duration =0.13s
# Cumulative duration =13.83s
#
# 98
# Epoch duration =0.14s
# Cumulative duration =13.97s
#
# 99
# Epoch duration =0.13s
# Cumulative duration =14.1s
#
# 100
# Epoch duration =0.14s
# Cumulative duration =14.25s
#
# 101
# Epoch duration =0.14s
# Cumulative duration =14.38s
#
# 102
# Epoch duration =0.14s
# Cumulative duration =14.52s
#
# 103
# Epoch duration =0.14s
# Cumulative duration =14.66s
#
# 104
# Epoch duration =0.14s
# Cumulative duration =14.8s
#
# 105
# Epoch duration =0.14s
# Cumulative duration =14.94s
#
# 106
# Epoch duration =0.14s
# Cumulative duration =15.07s
#
# 107
# Epoch duration =0.13s
# Cumulative duration =15.21s
#
# 108
# Epoch duration =0.14s
# Cumulative duration =15.34s
#
# 109
# Epoch duration =0.14s
# Cumulative duration =15.48s
#
# 110
# Epoch duration =0.13s
# Cumulative duration =15.61s
#
# 111
# Epoch duration =0.13s
# Cumulative duration =15.74s
#
# 112
# Epoch duration =0.13s
# Cumulative duration =15.88s
#
# 113
# Epoch duration =0.14s
# Cumulative duration =16.02s
#
# 114
# Epoch duration =0.14s
# Cumulative duration =16.15s
#
# 115
# Epoch duration =0.13s
# Cumulative duration =16.29s
#
# 116
# Epoch duration =0.14s
# Cumulative duration =16.42s
#
# 117
# Epoch duration =0.14s
# Cumulative duration =16.56s
#
# 118
# Epoch duration =0.14s
# Cumulative duration =16.71s
#
# 119
# Epoch duration =0.14s
# Cumulative duration =16.84s
#
# 120
# Epoch duration =0.14s
# Cumulative duration =16.99s
#
# 121
# Epoch duration =0.14s
# Cumulative duration =17.12s
#
# 122
# Epoch duration =0.13s
# Cumulative duration =17.25s
#
# 123
# Epoch duration =0.13s
# Cumulative duration =17.39s
#
# 124
# Epoch duration =0.13s
# Cumulative duration =17.52s
#
# 125
# Epoch duration =0.14s
# Cumulative duration =17.66s
#
# 126
# Epoch duration =0.13s
# Cumulative duration =17.79s
#
# 127
# Epoch duration =0.13s
# Cumulative duration =17.92s
#
# 128
# Epoch duration =0.13s
# Cumulative duration =18.06s
#
# 129
# Epoch duration =0.14s
# Cumulative duration =18.19s
#
# 130
# Epoch duration =0.13s
# Cumulative duration =18.33s
#
# 131
# Epoch duration =0.14s
# Cumulative duration =18.47s
#
# 132
# Epoch duration =0.14s
# Cumulative duration =18.61s
#
# 133
# Epoch duration =0.14s
# Cumulative duration =18.74s
#
# 134
# Epoch duration =0.14s
# Cumulative duration =18.88s
#
# 135
# Epoch duration =0.13s
# Cumulative duration =19.01s
#
# 136
# Epoch duration =0.14s
# Cumulative duration =19.15s
#
# 137
# Epoch duration =0.14s
# Cumulative duration =19.29s
#
# 138
# Epoch duration =0.14s
# Cumulative duration =19.43s
#
# 139
# Epoch duration =0.13s
# Cumulative duration =19.56s
#
# 140
# Epoch duration =0.14s
# Cumulative duration =19.7s
#
# 141
# Epoch duration =0.13s
# Cumulative duration =19.83s
#
# 142
# Epoch duration =0.13s
# Cumulative duration =19.97s
#
# 143
# Epoch duration =0.14s
# Cumulative duration =20.11s
#
# 144
# Epoch duration =0.14s
# Cumulative duration =20.25s
#
# 145
# Epoch duration =0.13s
# Cumulative duration =20.38s
#
# 146
# Epoch duration =0.13s
# Cumulative duration =20.52s
#
# 147
# Epoch duration =0.14s
# Cumulative duration =20.65s
#
# 148
# Epoch duration =0.19s
# Cumulative duration =20.84s
#
# 149
# Epoch duration =0.18s
# Cumulative duration =21.02s
#
# 150
# Epoch duration =0.14s
# Cumulative duration =21.16s
#
# 151
# Epoch duration =0.15s
# Cumulative duration =21.31s
#
# 152
# Epoch duration =0.14s
# Cumulative duration =21.46s
#
# 153
# Epoch duration =0.13s
# Cumulative duration =21.59s
#
# 154
# Epoch duration =0.14s
# Cumulative duration =21.73s
#
# 155
# Epoch duration =0.14s
# Cumulative duration =21.88s
#
# 156
# Epoch duration =0.13s
# Cumulative duration =22.01s
#
# 157
# Epoch duration =0.14s
# Cumulative duration =22.15s
#
# 158
# Epoch duration =0.13s
# Cumulative duration =22.28s
#
# 159
# Epoch duration =0.13s
# Cumulative duration =22.42s
#
# 160
# Epoch duration =0.14s
# Cumulative duration =22.56s
#
# 161
# Epoch duration =0.14s
# Cumulative duration =22.69s
#
# 162
# Epoch duration =0.14s
# Cumulative duration =22.83s
#
# 163
# Epoch duration =0.15s
# Cumulative duration =22.98s
#
# 164
# Epoch duration =0.14s
# Cumulative duration =23.12s
#
# 165
# Epoch duration =0.21s
# Cumulative duration =23.33s
#
# 166
# Epoch duration =0.16s
# Cumulative duration =23.49s
#
# 167
# Epoch duration =0.13s
# Cumulative duration =23.63s
#
# 168
# Epoch duration =0.14s
# Cumulative duration =23.76s
#
# 169
# Epoch duration =0.13s
# Cumulative duration =23.9s
#
# 170
# Epoch duration =0.2s
# Cumulative duration =24.1s
#
# 171
# Epoch duration =0.14s
# Cumulative duration =24.23s
#
# 172
# Epoch duration =0.15s
# Cumulative duration =24.38s
#
# 173
# Epoch duration =0.14s
# Cumulative duration =24.52s
#
# 174
# Epoch duration =0.18s
# Cumulative duration =24.7s
#
# 175
# Epoch duration =0.14s
# Cumulative duration =24.83s
#
# 176
# Epoch duration =0.13s
# Cumulative duration =24.97s
#
# 177
# Epoch duration =0.14s
# Cumulative duration =25.11s
#
# 178
# Epoch duration =0.15s
# Cumulative duration =25.26s
#
# 179
# Epoch duration =0.14s
# Cumulative duration =25.4s
#
# 180
# Epoch duration =0.14s
# Cumulative duration =25.53s
#
# 181
# Epoch duration =0.14s
# Cumulative duration =25.67s
#
# 182
# Epoch duration =0.13s
# Cumulative duration =25.8s
#
# 183
# Epoch duration =0.14s
# Cumulative duration =25.94s
#
# 184
# Epoch duration =0.14s
# Cumulative duration =26.08s
#
# 185
# Epoch duration =0.14s
# Cumulative duration =26.22s
#
# 186
# Epoch duration =0.13s
# Cumulative duration =26.35s
#
# 187
# Epoch duration =0.14s
# Cumulative duration =26.49s
#
# 188
# Epoch duration =0.14s
# Cumulative duration =26.63s
#
# 189
# Epoch duration =0.14s
# Cumulative duration =26.77s
#
# 190
# Epoch duration =0.13s
# Cumulative duration =26.9s
#
# 191
# Epoch duration =0.14s
# Cumulative duration =27.04s
#
# 192
# Epoch duration =0.15s
# Cumulative duration =27.19s
#
# 193
# Epoch duration =0.14s
# Cumulative duration =27.34s
#
# 194
# Epoch duration =0.16s
# Cumulative duration =27.5s
#
# 195
# Epoch duration =0.14s
# Cumulative duration =27.64s
#
# 196
# Epoch duration =0.13s
# Cumulative duration =27.78s
#
# 197
# Epoch duration =0.14s
# Cumulative duration =27.92s
#
# 198
# Epoch duration =0.15s
# Cumulative duration =28.07s
#
# 199
# Epoch duration =0.14s
# Cumulative duration =28.21s
#
# 200
# Epoch duration =0.17s
# Cumulative duration =28.38s
#
# 201
# Epoch duration =0.14s
# Cumulative duration =28.52s
#
# 202
# Epoch duration =0.14s
# Cumulative duration =28.66s
#
# 203
# Epoch duration =0.14s
# Cumulative duration =28.8s
#
# 204
# Epoch duration =0.14s
# Cumulative duration =28.94s
#
# 205
# Epoch duration =0.15s
# Cumulative duration =29.09s
#
# 206
# Epoch duration =0.14s
# Cumulative duration =29.22s
#
# 207
# Epoch duration =0.14s
# Cumulative duration =29.36s
#
# 208
# Epoch duration =0.15s
# Cumulative duration =29.51s
#
# 209
# Epoch duration =0.14s
# Cumulative duration =29.65s
#
# 210
# Epoch duration =0.14s
# Cumulative duration =29.79s
#
# 211
# Epoch duration =0.14s
# Cumulative duration =29.93s
#
# 212
# Epoch duration =0.13s
# Cumulative duration =30.06s
#
# 213
# Epoch duration =0.13s
# Cumulative duration =30.19s
#
# 214
# Epoch duration =0.13s
# Cumulative duration =30.33s
#
# 215
# Epoch duration =0.14s
# Cumulative duration =30.46s
#
# 216
# Epoch duration =0.13s
# Cumulative duration =30.6s
#
# 217
# Epoch duration =0.15s
# Cumulative duration =30.74s
#
# 218
# Epoch duration =0.13s
# Cumulative duration =30.87s
#
# 219
# Epoch duration =0.13s
# Cumulative duration =31.01s
#
# 220
# Epoch duration =0.13s
# Cumulative duration =31.14s
#
# 221
# Epoch duration =0.14s
# Cumulative duration =31.28s
#
# 222
# Epoch duration =0.14s
# Cumulative duration =31.42s
#
# 223
# Epoch duration =0.14s
# Cumulative duration =31.56s
#
# 224
# Epoch duration =0.14s
# Cumulative duration =31.7s
#
# 225
# Epoch duration =0.14s
# Cumulative duration =31.83s
#
# 226
# Epoch duration =0.14s
# Cumulative duration =31.97s
#
# 227
# Epoch duration =0.14s
# Cumulative duration =32.11s
#
# 228
# Epoch duration =0.13s
# Cumulative duration =32.24s
#
# 229
# Epoch duration =0.14s
# Cumulative duration =32.38s
#
# 230
# Epoch duration =0.14s
# Cumulative duration =32.52s
#
# 231
# Epoch duration =0.14s
# Cumulative duration =32.66s
#
# 232
# Epoch duration =0.13s
# Cumulative duration =32.79s
#
# 233
# Epoch duration =0.14s
# Cumulative duration =32.92s
#
# 234
# Epoch duration =0.15s
# Cumulative duration =33.07s
#
# 235
# Epoch duration =0.14s
# Cumulative duration =33.21s
#
# 236
# Epoch duration =0.13s
# Cumulative duration =33.35s
#
# 237
# Epoch duration =0.14s
# Cumulative duration =33.48s
#
# 238
# Epoch duration =0.13s
# Cumulative duration =33.62s
#
# 239
# Epoch duration =0.14s
# Cumulative duration =33.75s
#
# 240
# Epoch duration =0.13s
# Cumulative duration =33.89s
#
# 241
# Epoch duration =0.14s
# Cumulative duration =34.03s
#
# 242
# Epoch duration =0.13s
# Cumulative duration =34.16s
#
# 243
# Epoch duration =0.14s
# Cumulative duration =34.3s
#
# 244
# Epoch duration =0.13s
# Cumulative duration =34.43s
#
# 245
# Epoch duration =0.15s
# Cumulative duration =34.58s
#
# 246
# Epoch duration =0.14s
# Cumulative duration =34.71s
#
# 247
# Epoch duration =0.13s
# Cumulative duration =34.85s
#
# 248
# Epoch duration =0.13s
# Cumulative duration =34.98s
#
# 249
# Epoch duration =0.14s
# Cumulative duration =35.12s
#
# 250
# Epoch duration =0.14s
# Cumulative duration =35.26s
#
# 251
# Epoch duration =0.14s
# Cumulative duration =35.39s
#
# 252
# Epoch duration =0.13s
# Cumulative duration =35.52s
#
# 253
# Epoch duration =0.14s
# Cumulative duration =35.67s
#
# 254
# Epoch duration =0.18s
# Cumulative duration =35.84s
#
# 255
# Epoch duration =0.14s
# Cumulative duration =35.98s
#
# 256
# Epoch duration =0.14s
# Cumulative duration =36.12s
#
# 257
# Epoch duration =0.14s
# Cumulative duration =36.26s
#
# 258
# Epoch duration =0.13s
# Cumulative duration =36.4s
#
# 259
# Epoch duration =0.13s
# Cumulative duration =36.53s
#
# 260
# Epoch duration =0.14s
# Cumulative duration =36.67s
#
# 261
# Epoch duration =0.13s
# Cumulative duration =36.81s
#
# 262
# Epoch duration =0.14s
# Cumulative duration =36.95s
#
# 263
# Epoch duration =0.14s
# Cumulative duration =37.08s
#
# 264
# Epoch duration =0.14s
# Cumulative duration =37.22s
#
# 265
# Epoch duration =0.15s
# Cumulative duration =37.37s
#
# 266
# Epoch duration =0.13s
# Cumulative duration =37.5s
#
# 267
# Epoch duration =0.14s
# Cumulative duration =37.64s
#
# 268
# Epoch duration =0.14s
# Cumulative duration =37.78s
#
# 269
# Epoch duration =0.17s
# Cumulative duration =37.95s
#
# 270
# Epoch duration =0.13s
# Cumulative duration =38.08s
#
# 271
# Epoch duration =0.14s
# Cumulative duration =38.23s
#
# 272
# Epoch duration =0.14s
# Cumulative duration =38.37s
#
# 273
# Epoch duration =0.18s
# Cumulative duration =38.55s
#
# 274
# Epoch duration =0.13s
# Cumulative duration =38.68s
#
# 275
# Epoch duration =0.16s
# Cumulative duration =38.84s
#
# 276
# Epoch duration =0.13s
# Cumulative duration =38.97s
#
# 277
# Epoch duration =0.16s
# Cumulative duration =39.13s
#
# 278
# Epoch duration =0.13s
# Cumulative duration =39.27s
#
# 279
# Epoch duration =0.15s
# Cumulative duration =39.41s
#
# 280
# Epoch duration =0.13s
# Cumulative duration =39.54s
#
# 281
# Epoch duration =0.14s
# Cumulative duration =39.69s
#
# 282
# Epoch duration =0.15s
# Cumulative duration =39.83s
#
# 283
# Epoch duration =0.13s
# Cumulative duration =39.97s
#
# 284
# Epoch duration =0.13s
# Cumulative duration =40.1s
#
# 285
# Epoch duration =0.14s
# Cumulative duration =40.24s
#
# 286
# Epoch duration =0.14s
# Cumulative duration =40.38s
#
# 287
# Epoch duration =0.14s
# Cumulative duration =40.52s
#
# 288
# Epoch duration =0.14s
# Cumulative duration =40.65s
#
# 289
# Epoch duration =0.14s
# Cumulative duration =40.8s
#
# 290
# Epoch duration =0.16s
# Cumulative duration =40.95s
#
# 291
# Epoch duration =0.14s
# Cumulative duration =41.09s
#
# 292
# Epoch duration =0.15s
# Cumulative duration =41.24s
#
# 293
# Epoch duration =0.15s
# Cumulative duration =41.39s
#
# 294
# Epoch duration =0.15s
# Cumulative duration =41.54s
#
# 295
# Epoch duration =0.14s
# Cumulative duration =41.68s
#
# 296
# Epoch duration =0.13s
# Cumulative duration =41.81s
#
# 297
# Epoch duration =0.14s
# Cumulative duration =41.95s
#
# 298
# Epoch duration =0.13s
# Cumulative duration =42.08s
#
# 299
# Epoch duration =0.13s
# Cumulative duration =42.21s
#
# 300
# Epoch duration =0.14s
# Cumulative duration =42.35s
#
# 301
# Epoch duration =0.14s
# Cumulative duration =42.49s
#
# 302
# Epoch duration =0.14s
# Cumulative duration =42.62s
#
# 303
# Epoch duration =0.14s
# Cumulative duration =42.77s
#
# 304
# Epoch duration =0.14s
# Cumulative duration =42.9s
#
# 305
# Epoch duration =0.13s
# Cumulative duration =43.04s
#
# 306
# Epoch duration =0.14s
# Cumulative duration =43.18s
#
# 307
# Epoch duration =0.14s
# Cumulative duration =43.31s
#
# 308
# Epoch duration =0.13s
# Cumulative duration =43.44s
#
# 309
# Epoch duration =0.14s
# Cumulative duration =43.58s
#
# 310
# Epoch duration =0.14s
# Cumulative duration =43.72s
#
# 311
# Epoch duration =0.14s
# Cumulative duration =43.86s
#
# 312
# Epoch duration =0.14s
# Cumulative duration =44.0s
#
# 313
# Epoch duration =0.14s
# Cumulative duration =44.14s
#
# 314
# Epoch duration =0.13s
# Cumulative duration =44.27s
#
# 315
# Epoch duration =0.14s
# Cumulative duration =44.41s
#
# 316
# Epoch duration =0.13s
# Cumulative duration =44.54s
#
# 317
# Epoch duration =0.15s
# Cumulative duration =44.69s
#
# 318
# Epoch duration =0.13s
# Cumulative duration =44.82s
#
# 319
# Epoch duration =0.14s
# Cumulative duration =44.96s
#
# 320
# Epoch duration =0.14s
# Cumulative duration =45.1s
#
# 321
# Epoch duration =0.14s
# Cumulative duration =45.24s
#
# 322
# Epoch duration =0.2s
# Cumulative duration =45.43s
#
# 323
# Epoch duration =0.14s
# Cumulative duration =45.57s
#
# 324
# Epoch duration =0.14s
# Cumulative duration =45.71s
#
# 325
# Epoch duration =0.13s
# Cumulative duration =45.85s
#
# 326
# Epoch duration =0.14s
# Cumulative duration =45.98s
#
# 327
# Epoch duration =0.14s
# Cumulative duration =46.12s
#
# 328
# Epoch duration =0.13s
# Cumulative duration =46.25s
#
# 329
# Epoch duration =0.14s
# Cumulative duration =46.39s
#
# 330
# Epoch duration =0.14s
# Cumulative duration =46.53s
#
# 331
# Epoch duration =0.14s
# Cumulative duration =46.67s
#
# 332
# Epoch duration =0.14s
# Cumulative duration =46.8s
#
# 333
# Epoch duration =0.13s
# Cumulative duration =46.94s
#
# 334
# Epoch duration =0.13s
# Cumulative duration =47.07s
#
# 335
# Epoch duration =0.14s
# Cumulative duration =47.21s
#
# 336
# Epoch duration =0.13s
# Cumulative duration =47.34s
#
# 337
# Epoch duration =0.15s
# Cumulative duration =47.49s
#
# 338
# Epoch duration =0.14s
# Cumulative duration =47.63s
#
# 339
# Epoch duration =0.14s
# Cumulative duration =47.77s
#
# 340
# Epoch duration =0.13s
# Cumulative duration =47.9s
#
# 341
# Epoch duration =0.15s
# Cumulative duration =48.05s
#
# 342
# Epoch duration =0.14s
# Cumulative duration =48.19s
#
# 343
# Epoch duration =0.14s
# Cumulative duration =48.33s
#
# 344
# Epoch duration =0.13s
# Cumulative duration =48.47s
#
# 345
# Epoch duration =0.14s
# Cumulative duration =48.6s
#
# 346
# Epoch duration =0.13s
# Cumulative duration =48.74s
#
# 347
# Epoch duration =0.14s
# Cumulative duration =48.87s
#
# 348
# Epoch duration =0.14s
# Cumulative duration =49.01s
#
# 349
# Epoch duration =0.15s
# Cumulative duration =49.16s
#
# 350
# Epoch duration =0.13s
# Cumulative duration =49.29s
#
# 351
# Epoch duration =0.14s
# Cumulative duration =49.43s
#
# 352
# Epoch duration =0.16s
# Cumulative duration =49.6s
#
# 353
# Epoch duration =0.14s
# Cumulative duration =49.73s
#
# 354
# Epoch duration =0.14s
# Cumulative duration =49.87s
#
# 355
# Epoch duration =0.13s
# Cumulative duration =50.0s
#
# 356
# Epoch duration =0.14s
# Cumulative duration =50.15s
#
# 357
# Epoch duration =0.16s
# Cumulative duration =50.31s
#
# 358
# Epoch duration =0.13s
# Cumulative duration =50.44s
#
# 359
# Epoch duration =0.14s
# Cumulative duration =50.58s
#
# 360
# Epoch duration =0.13s
# Cumulative duration =50.71s
#
# 361
# Epoch duration =0.14s
# Cumulative duration =50.85s
#
# 362
# Epoch duration =0.13s
# Cumulative duration =50.98s
#
# 363
# Epoch duration =0.13s
# Cumulative duration =51.12s
#
# 364
# Epoch duration =0.14s
# Cumulative duration =51.26s
#
# 365
# Epoch duration =0.14s
# Cumulative duration =51.4s
#
# 366
# Epoch duration =0.18s
# Cumulative duration =51.57s
#
# 367
# Epoch duration =0.14s
# Cumulative duration =51.71s
#
# 368
# Epoch duration =0.14s
# Cumulative duration =51.85s
#
# 369
# Epoch duration =0.14s
# Cumulative duration =51.99s
#
# 370
# Epoch duration =0.13s
# Cumulative duration =52.12s
#
# 371
# Epoch duration =0.15s
# Cumulative duration =52.27s
#
# 372
# Epoch duration =0.14s
# Cumulative duration =52.41s
#
# 373
# Epoch duration =0.14s
# Cumulative duration =52.55s
#
# 374
# Epoch duration =0.15s
# Cumulative duration =52.7s
#
# 375
# Epoch duration =0.15s
# Cumulative duration =52.85s
#
# 376
# Epoch duration =0.14s
# Cumulative duration =52.99s
#
# 377
# Epoch duration =0.15s
# Cumulative duration =53.14s
#
# 378
# Epoch duration =0.13s
# Cumulative duration =53.27s
#
# 379
# Epoch duration =0.15s
# Cumulative duration =53.42s
#
# 380
# Epoch duration =0.13s
# Cumulative duration =53.55s
#
# 381
# Epoch duration =0.14s
# Cumulative duration =53.69s
#
# 382
# Epoch duration =0.13s
# Cumulative duration =53.82s
#
# 383
# Epoch duration =0.14s
# Cumulative duration =53.96s
#
# 384
# Epoch duration =0.13s
# Cumulative duration =54.09s
#
# 385
# Epoch duration =0.14s
# Cumulative duration =54.23s
#
# 386
# Epoch duration =0.14s
# Cumulative duration =54.36s
#
# 387
# Epoch duration =0.14s
# Cumulative duration =54.5s
#
# 388
# Epoch duration =0.13s
# Cumulative duration =54.63s
#
# 389
# Epoch duration =0.14s
# Cumulative duration =54.77s
#
# 390
# Epoch duration =0.13s
# Cumulative duration =54.91s
#
# 391
# Epoch duration =0.14s
# Cumulative duration =55.05s
#
# 392
# Epoch duration =0.13s
# Cumulative duration =55.18s
#
# 393
# Epoch duration =0.14s
# Cumulative duration =55.32s
#
# 394
# Epoch duration =0.14s
# Cumulative duration =55.46s
#
# 395
# Epoch duration =0.14s
# Cumulative duration =55.6s
#
# 396
# Epoch duration =0.13s
# Cumulative duration =55.73s
#
# 397
# Epoch duration =0.13s
# Cumulative duration =55.86s
#
# 398
# Epoch duration =0.14s
# Cumulative duration =56.0s
#
# 399
# Epoch duration =0.15s
# Cumulative duration =56.15s
#
# 400
# Epoch duration =0.14s
# Cumulative duration =56.28s
#
# 401
# Epoch duration =0.14s
# Cumulative duration =56.42s
#
# 402
# Epoch duration =0.14s
# Cumulative duration =56.56s
#
# 403
# Epoch duration =0.14s
# Cumulative duration =56.7s
#
# 404
# Epoch duration =0.13s
# Cumulative duration =56.83s
#
# 405
# Epoch duration =0.15s
# Cumulative duration =56.98s
#
# 406
# Epoch duration =0.13s
# Cumulative duration =57.11s
#
# 407
# Epoch duration =0.13s
# Cumulative duration =57.25s
#
# 408
# Epoch duration =0.14s
# Cumulative duration =57.38s
#
# 409
# Epoch duration =0.13s
# Cumulative duration =57.52s
#
# 410
# Epoch duration =0.13s
# Cumulative duration =57.65s
#
# 411
# Epoch duration =0.14s
# Cumulative duration =57.79s
#
# 412
# Epoch duration =0.13s
# Cumulative duration =57.92s
#
# 413
# Epoch duration =0.14s
# Cumulative duration =58.06s
#
# 414
# Epoch duration =0.13s
# Cumulative duration =58.19s
#
# 415
# Epoch duration =0.13s
# Cumulative duration =58.32s
#
# 416
# Epoch duration =0.13s
# Cumulative duration =58.46s
#
# 417
# Epoch duration =0.13s
# Cumulative duration =58.59s
#
# 418
# Epoch duration =0.13s
# Cumulative duration =58.72s
#
# 419
# Epoch duration =0.14s
# Cumulative duration =58.86s
#
# 420
# Epoch duration =0.13s
# Cumulative duration =58.99s
#
# 421
# Epoch duration =0.13s
# Cumulative duration =59.12s
#
# 422
# Epoch duration =0.14s
# Cumulative duration =59.27s
#
# 423
# Epoch duration =0.14s
# Cumulative duration =59.4s
#
# 424
# Epoch duration =0.14s
# Cumulative duration =59.54s
#
# 425
# Epoch duration =0.13s
# Cumulative duration =59.68s
#
# 426
# Epoch duration =0.14s
# Cumulative duration =59.81s
#
# 427
# Epoch duration =0.13s
# Cumulative duration =59.95s
#
# 428
# Epoch duration =0.13s
# Cumulative duration =60.08s
#
# 429
# Epoch duration =0.15s
# Cumulative duration =60.23s
#
# 430
# Epoch duration =0.15s
# Cumulative duration =60.38s
#
# 431
# Epoch duration =0.14s
# Cumulative duration =60.51s
#
# 432
# Epoch duration =0.14s
# Cumulative duration =60.65s
#
# 433
# Epoch duration =0.15s
# Cumulative duration =60.8s
#
# 434
# Epoch duration =0.14s
# Cumulative duration =60.94s
#
# 435
# Epoch duration =0.13s
# Cumulative duration =61.08s
#
# 436
# Epoch duration =0.13s
# Cumulative duration =61.21s
#
# 437
# Epoch duration =0.14s
# Cumulative duration =61.35s
#
# 438
# Epoch duration =0.14s
# Cumulative duration =61.48s
#
# 439
# Epoch duration =0.14s
# Cumulative duration =61.62s
#
# 440
# Epoch duration =0.13s
# Cumulative duration =61.75s
#
# 441
# Epoch duration =0.14s
# Cumulative duration =61.89s
#
# 442
# Epoch duration =0.14s
# Cumulative duration =62.02s
#
# 443
# Epoch duration =0.14s
# Cumulative duration =62.16s
#
# 444
# Epoch duration =0.14s
# Cumulative duration =62.3s
#
# 445
# Epoch duration =0.14s
# Cumulative duration =62.44s
#
# 446
# Epoch duration =0.13s
# Cumulative duration =62.57s
#
# 447
# Epoch duration =0.14s
# Cumulative duration =62.71s
#
# 448
# Epoch duration =0.14s
# Cumulative duration =62.85s
#
# 449
# Epoch duration =0.14s
# Cumulative duration =62.98s
#
# 450
# Epoch duration =0.13s
# Cumulative duration =63.12s
#
# 451
# Epoch duration =0.13s
# Cumulative duration =63.25s
#
# 452
# Epoch duration =0.13s
# Cumulative duration =63.39s
#
# 453
# Epoch duration =0.16s
# Cumulative duration =63.55s
#
# 454
# Epoch duration =0.13s
# Cumulative duration =63.68s
#
# 455
# Epoch duration =0.14s
# Cumulative duration =63.82s
#
# 456
# Epoch duration =0.13s
# Cumulative duration =63.95s
#
# 457
# Epoch duration =0.14s
# Cumulative duration =64.09s
#
# 458
# Epoch duration =0.14s
# Cumulative duration =64.23s
#
# 459
# Epoch duration =0.14s
# Cumulative duration =64.37s
#
# 460
# Epoch duration =0.13s
# Cumulative duration =64.5s
#
# 461
# Epoch duration =0.19s
# Cumulative duration =64.69s
#
# 462
# Epoch duration =0.13s
# Cumulative duration =64.82s
#
# 463
# Epoch duration =0.14s
# Cumulative duration =64.96s
#
# 464
# Epoch duration =0.13s
# Cumulative duration =65.1s
#
# 465
# Epoch duration =0.14s
# Cumulative duration =65.23s
#
# 466
# Epoch duration =0.13s
# Cumulative duration =65.37s
#
# 467
# Epoch duration =0.14s
# Cumulative duration =65.51s
#
# 468
# Epoch duration =0.14s
# Cumulative duration =65.65s
#
# 469
# Epoch duration =0.15s
# Cumulative duration =65.8s
#
# 470
# Epoch duration =0.14s
# Cumulative duration =65.93s
#
# 471
# Epoch duration =0.14s
# Cumulative duration =66.07s
#
# 472
# Epoch duration =0.14s
# Cumulative duration =66.21s
#
# 473
# Epoch duration =0.14s
# Cumulative duration =66.34s
#
# 474
# Epoch duration =0.14s
# Cumulative duration =66.48s
#
# 475
# Epoch duration =0.15s
# Cumulative duration =66.63s
#
# 476
# Epoch duration =0.15s
# Cumulative duration =66.78s
#
# 477
# Epoch duration =0.15s
# Cumulative duration =66.92s
#
# 478
# Epoch duration =0.13s
# Cumulative duration =67.06s
#
# 479
# Epoch duration =0.13s
# Cumulative duration =67.19s
#
# 480
# Epoch duration =0.13s
# Cumulative duration =67.33s
#
# 481
# Epoch duration =0.14s
# Cumulative duration =67.46s
#
# 482
# Epoch duration =0.14s
# Cumulative duration =67.6s
#
# 483
# Epoch duration =0.18s
# Cumulative duration =67.78s
#
# 484
# Epoch duration =0.13s
# Cumulative duration =67.91s
#
# 485
# Epoch duration =0.15s
# Cumulative duration =68.06s
#
# 486
# Epoch duration =0.14s
# Cumulative duration =68.2s
#
# 487
# Epoch duration =0.14s
# Cumulative duration =68.34s
#
# 488
# Epoch duration =0.17s
# Cumulative duration =68.51s
#
# 489
# Epoch duration =0.14s
# Cumulative duration =68.65s
#
# 490
# Epoch duration =0.16s
# Cumulative duration =68.8s
#
# 491
# Epoch duration =0.14s
# Cumulative duration =68.94s
#
# 492
# Epoch duration =0.14s
# Cumulative duration =69.09s
#
# 493
# Epoch duration =0.13s
# Cumulative duration =69.22s
#
# 494
# Epoch duration =0.14s
# Cumulative duration =69.36s
#
# 495
# Epoch duration =0.14s
# Cumulative duration =69.49s
#
# 496
# Epoch duration =0.14s
# Cumulative duration =69.64s
#
# 497
# Epoch duration =0.14s
# Cumulative duration =69.77s
#
# 498
# Epoch duration =0.14s
# Cumulative duration =69.91s
#
# 499
# Epoch duration =0.14s
# Cumulative duration =70.05s
#
# 500
# Epoch duration =0.13s
# Cumulative duration =70.19s
#
# 501
# Epoch duration =0.14s
# Cumulative duration =70.32s
#
# 502
# Epoch duration =0.14s
# Cumulative duration =70.46s
#
# 503
# Epoch duration =0.14s
# Cumulative duration =70.6s
#
# 504
# Epoch duration =0.13s
# Cumulative duration =70.73s
#
# 505
# Epoch duration =0.14s
# Cumulative duration =70.86s
#
# 506
# Epoch duration =0.13s
# Cumulative duration =71.0s
#
# 507
# Epoch duration =0.17s
# Cumulative duration =71.17s
#
# 508
# Epoch duration =0.15s
# Cumulative duration =71.32s
#
# 509
# Epoch duration =0.15s
# Cumulative duration =71.47s
#
# 510
# Epoch duration =0.16s
# Cumulative duration =71.62s
#
# 511
# Epoch duration =0.16s
# Cumulative duration =71.78s
#
# 512
# Epoch duration =0.14s
# Cumulative duration =71.93s
#
# 513
# Epoch duration =0.14s
# Cumulative duration =72.06s
#
# 514
# Epoch duration =0.14s
# Cumulative duration =72.2s
#
# 515
# Epoch duration =0.13s
# Cumulative duration =72.33s
#
# 516
# Epoch duration =0.14s
# Cumulative duration =72.47s
#
# 517
# Epoch duration =0.14s
# Cumulative duration =72.61s
#
# 518
# Epoch duration =0.17s
# Cumulative duration =72.78s
#
# 519
# Epoch duration =0.2s
# Cumulative duration =72.98s
#
# 520
# Epoch duration =0.14s
# Cumulative duration =73.12s
#
# 521
# Epoch duration =0.14s
# Cumulative duration =73.26s
#
# 522
# Epoch duration =0.13s
# Cumulative duration =73.4s
#
# 523
# Epoch duration =0.14s
# Cumulative duration =73.53s
#
# 524
# Epoch duration =0.17s
# Cumulative duration =73.71s
#
# 525
# Epoch duration =0.19s
# Cumulative duration =73.89s
#
# 526
# Epoch duration =0.13s
# Cumulative duration =74.03s
#
# 527
# Epoch duration =0.14s
# Cumulative duration =74.16s
#
# 528
# Epoch duration =0.15s
# Cumulative duration =74.31s
#
# 529
# Epoch duration =0.14s
# Cumulative duration =74.45s
#
# 530
# Epoch duration =0.13s
# Cumulative duration =74.58s
#
# 531
# Epoch duration =0.19s
# Cumulative duration =74.77s
#
# 532
# Epoch duration =0.16s
# Cumulative duration =74.93s
#
# 533
# Epoch duration =0.14s
# Cumulative duration =75.06s
#
# 534
# Epoch duration =0.14s
# Cumulative duration =75.2s
#
# 535
# Epoch duration =0.14s
# Cumulative duration =75.34s
#
# 536
# Epoch duration =0.13s
# Cumulative duration =75.48s
#
# 537
# Epoch duration =0.14s
# Cumulative duration =75.62s
#
# 538
# Epoch duration =0.13s
# Cumulative duration =75.75s
#
# 539
# Epoch duration =0.15s
# Cumulative duration =75.9s
#
# 540
# Epoch duration =0.13s
# Cumulative duration =76.04s
#
# 541
# Epoch duration =0.14s
# Cumulative duration =76.18s
#
# 542
# Epoch duration =0.14s
# Cumulative duration =76.31s
#
# 543
# Epoch duration =0.13s
# Cumulative duration =76.45s
#
# 544
# Epoch duration =0.13s
# Cumulative duration =76.58s
#
# 545
# Epoch duration =0.13s
# Cumulative duration =76.72s
#
# 546
# Epoch duration =0.14s
# Cumulative duration =76.85s
#
# 547
# Epoch duration =0.14s
# Cumulative duration =76.99s
#
# 548
# Epoch duration =0.14s
# Cumulative duration =77.13s
#
# 549
# Epoch duration =0.15s
# Cumulative duration =77.29s
#
# 550
# Epoch duration =0.15s
# Cumulative duration =77.44s
#
# 551
# Epoch duration =0.14s
# Cumulative duration =77.58s
#
# 552
# Epoch duration =0.13s
# Cumulative duration =77.71s
#
# 553
# Epoch duration =0.14s
# Cumulative duration =77.86s
#
# 554
# Epoch duration =0.14s
# Cumulative duration =78.0s
#
# 555
# Epoch duration =0.14s
# Cumulative duration =78.13s
#
# 556
# Epoch duration =0.14s
# Cumulative duration =78.27s
#
# 557
# Epoch duration =0.14s
# Cumulative duration =78.41s
#
# 558
# Epoch duration =0.13s
# Cumulative duration =78.54s
#
# 559
# Epoch duration =0.14s
# Cumulative duration =78.68s
#
# 560
# Epoch duration =0.14s
# Cumulative duration =78.82s
#
# 561
# Epoch duration =0.15s
# Cumulative duration =78.97s
#
# 562
# Epoch duration =0.13s
# Cumulative duration =79.1s
#
# 563
# Epoch duration =0.14s
# Cumulative duration =79.24s
#
# 564
# Epoch duration =0.13s
# Cumulative duration =79.37s
#
# 565
# Epoch duration =0.15s
# Cumulative duration =79.53s
#
# 566
# Epoch duration =0.13s
# Cumulative duration =79.66s
#
# 567
# Epoch duration =0.14s
# Cumulative duration =79.79s
#
# 568
# Epoch duration =0.13s
# Cumulative duration =79.93s
#
# 569
# Epoch duration =0.14s
# Cumulative duration =80.06s
#
# 570
# Epoch duration =0.14s
# Cumulative duration =80.2s
#
# 571
# Epoch duration =0.14s
# Cumulative duration =80.34s
#
# 572
# Epoch duration =0.14s
# Cumulative duration =80.48s
#
# 573
# Epoch duration =0.13s
# Cumulative duration =80.61s
#
# 574
# Epoch duration =0.14s
# Cumulative duration =80.75s
#
# 575
# Epoch duration =0.16s
# Cumulative duration =80.91s
#
# 576
# Epoch duration =0.15s
# Cumulative duration =81.05s
#
# 577
# Epoch duration =0.15s
# Cumulative duration =81.21s
#
# 578
# Epoch duration =0.15s
# Cumulative duration =81.36s
#
# 579
# Epoch duration =0.14s
# Cumulative duration =81.5s
#
# 580
# Epoch duration =0.14s
# Cumulative duration =81.64s
#
# 581
# Epoch duration =0.14s
# Cumulative duration =81.78s
#
# 582
# Epoch duration =0.14s
# Cumulative duration =81.91s
#
# 583
# Epoch duration =0.14s
# Cumulative duration =82.05s
#
# 584
# Epoch duration =0.14s
# Cumulative duration =82.19s
#
# 585
# Epoch duration =0.15s
# Cumulative duration =82.34s
#
# 586
# Epoch duration =0.18s
# Cumulative duration =82.52s
#
# 587
# Epoch duration =0.13s
# Cumulative duration =82.65s
#
# 588
# Epoch duration =0.14s
# Cumulative duration =82.79s
#
# 589
# Epoch duration =0.14s
# Cumulative duration =82.92s
#
# 590
# Epoch duration =0.13s
# Cumulative duration =83.06s
#
# 591
# Epoch duration =0.14s
# Cumulative duration =83.19s
#
# 592
# Epoch duration =0.14s
# Cumulative duration =83.34s
#
# 593
# Epoch duration =0.14s
# Cumulative duration =83.48s
#
# 594
# Epoch duration =0.15s
# Cumulative duration =83.63s
#
# 595
# Epoch duration =0.14s
# Cumulative duration =83.76s
#
# 596
# Epoch duration =0.13s
# Cumulative duration =83.9s
#
# 597
# Epoch duration =0.15s
# Cumulative duration =84.05s
#
# 598
# Epoch duration =0.15s
# Cumulative duration =84.2s
#
# 599
# Epoch duration =0.14s
# Cumulative duration =84.34s
#
# 600
# Epoch duration =0.14s
# Cumulative duration =84.48s
#
# 601
# Epoch duration =0.14s
# Cumulative duration =84.62s
#
# 602
# Epoch duration =0.14s
# Cumulative duration =84.76s
#
# 603
# Epoch duration =0.16s
# Cumulative duration =84.92s
#
# 604
# Epoch duration =0.14s
# Cumulative duration =85.06s
#
# 605
# Epoch duration =0.14s
# Cumulative duration =85.2s
#
# 606
# Epoch duration =0.15s
# Cumulative duration =85.34s
#
# 607
# Epoch duration =0.15s
# Cumulative duration =85.5s
#
# 608
# Epoch duration =0.13s
# Cumulative duration =85.63s
#
# 609
# Epoch duration =0.14s
# Cumulative duration =85.77s
#
# 610
# Epoch duration =0.14s
# Cumulative duration =85.91s
#
# 611
# Epoch duration =0.14s
# Cumulative duration =86.05s
#
# 612
# Epoch duration =0.13s
# Cumulative duration =86.19s
#
# 613
# Epoch duration =0.14s
# Cumulative duration =86.32s
#
# 614
# Epoch duration =0.14s
# Cumulative duration =86.46s
#
# 615
# Epoch duration =0.14s
# Cumulative duration =86.59s
#
# 616
# Epoch duration =0.13s
# Cumulative duration =86.72s
#
# 617
# Epoch duration =0.14s
# Cumulative duration =86.87s
#
# 618
# Epoch duration =0.13s
# Cumulative duration =87.0s
#
# 619
# Epoch duration =0.13s
# Cumulative duration =87.14s
#
# 620
# Epoch duration =0.14s
# Cumulative duration =87.28s
#
# 621
# Epoch duration =0.13s
# Cumulative duration =87.41s
#
# 622
# Epoch duration =0.14s
# Cumulative duration =87.55s
#
# 623
# Epoch duration =0.14s
# Cumulative duration =87.68s
#
# 624
# Epoch duration =0.13s
# Cumulative duration =87.82s
#
# 625
# Epoch duration =0.14s
# Cumulative duration =87.95s
#
# 626
# Epoch duration =0.13s
# Cumulative duration =88.09s
#
# 627
# Epoch duration =0.14s
# Cumulative duration =88.22s
#
# 628
# Epoch duration =0.13s
# Cumulative duration =88.36s
#
# 629
# Epoch duration =0.15s
# Cumulative duration =88.51s
#
# 630
# Epoch duration =0.14s
# Cumulative duration =88.65s
#
# 631
# Epoch duration =0.15s
# Cumulative duration =88.81s
#
# 632
# Epoch duration =0.14s
# Cumulative duration =88.95s
#
# 633
# Epoch duration =0.14s
# Cumulative duration =89.08s
#
# 634
# Epoch duration =0.13s
# Cumulative duration =89.22s
#
# 635
# Epoch duration =0.14s
# Cumulative duration =89.35s
#
# 636
# Epoch duration =0.13s
# Cumulative duration =89.49s
#
# 637
# Epoch duration =0.14s
# Cumulative duration =89.63s
#
# 638
# Epoch duration =0.14s
# Cumulative duration =89.76s
#
# 639
# Epoch duration =0.14s
# Cumulative duration =89.9s
#
# 640
# Epoch duration =0.14s
# Cumulative duration =90.04s
#
# 641
# Epoch duration =0.14s
# Cumulative duration =90.17s
#
# 642
# Epoch duration =0.13s
# Cumulative duration =90.31s
#
# 643
# Epoch duration =0.18s
# Cumulative duration =90.48s
#
# 644
# Epoch duration =0.15s
# Cumulative duration =90.63s
#
# 645
# Epoch duration =0.15s
# Cumulative duration =90.78s
#
# 646
# Epoch duration =0.14s
# Cumulative duration =90.91s
#
# 647
# Epoch duration =0.14s
# Cumulative duration =91.05s
#
# 648
# Epoch duration =0.14s
# Cumulative duration =91.18s
#
# 649
# Epoch duration =0.15s
# Cumulative duration =91.34s
#
# 650
# Epoch duration =0.13s
# Cumulative duration =91.47s
#
# 651
# Epoch duration =0.14s
# Cumulative duration =91.61s
#
# 652
# Epoch duration =0.14s
# Cumulative duration =91.75s
#
# 653
# Epoch duration =0.13s
# Cumulative duration =91.88s
#
# 654
# Epoch duration =0.13s
# Cumulative duration =92.01s
#
# 655
# Epoch duration =0.14s
# Cumulative duration =92.15s
#
# 656
# Epoch duration =0.14s
# Cumulative duration =92.28s
#
# 657
# Epoch duration =0.14s
# Cumulative duration =92.42s
#
# 658
# Epoch duration =0.14s
# Cumulative duration =92.56s
#
# 659
# Epoch duration =0.14s
# Cumulative duration =92.7s
#
# 660
# Epoch duration =0.13s
# Cumulative duration =92.83s
#
# 661
# Epoch duration =0.14s
# Cumulative duration =92.97s
#
# 662
# Epoch duration =0.13s
# Cumulative duration =93.1s
#
# 663
# Epoch duration =0.16s
# Cumulative duration =93.26s
#
# 664
# Epoch duration =0.14s
# Cumulative duration =93.4s
#
# 665
# Epoch duration =0.14s
# Cumulative duration =93.54s
#
# 666
# Epoch duration =0.13s
# Cumulative duration =93.67s
#
# 667
# Epoch duration =0.14s
# Cumulative duration =93.81s
#
# 668
# Epoch duration =0.14s
# Cumulative duration =93.94s
#
# 669
# Epoch duration =0.14s
# Cumulative duration =94.08s
#
# 670
# Epoch duration =0.13s
# Cumulative duration =94.21s
#
# 671
# Epoch duration =0.14s
# Cumulative duration =94.35s
#
# 672
# Epoch duration =0.13s
# Cumulative duration =94.49s
#
# 673
# Epoch duration =0.14s
# Cumulative duration =94.62s
#
# 674
# Epoch duration =0.16s
# Cumulative duration =94.79s
#
# 675
# Epoch duration =0.14s
# Cumulative duration =94.92s
#
# 676
# Epoch duration =0.14s
# Cumulative duration =95.06s
#
# 677
# Epoch duration =0.16s
# Cumulative duration =95.22s
#
# 678
# Epoch duration =0.14s
# Cumulative duration =95.35s
#
# 679
# Epoch duration =0.14s
# Cumulative duration =95.49s
#
# 680
# Epoch duration =0.14s
# Cumulative duration =95.63s
#
# 681
# Epoch duration =0.14s
# Cumulative duration =95.77s
#
# 682
# Epoch duration =0.14s
# Cumulative duration =95.9s
#
# 683
# Epoch duration =0.13s
# Cumulative duration =96.03s
#
# 684
# Epoch duration =0.13s
# Cumulative duration =96.17s
#
# 685
# Epoch duration =0.14s
# Cumulative duration =96.31s
#
# 686
# Epoch duration =0.13s
# Cumulative duration =96.44s
#
# 687
# Epoch duration =0.14s
# Cumulative duration =96.58s
#
# 688
# Epoch duration =0.13s
# Cumulative duration =96.71s
#
# 689
# Epoch duration =0.14s
# Cumulative duration =96.85s
#
# 690
# Epoch duration =0.14s
# Cumulative duration =96.99s
#
# 691
# Epoch duration =0.14s
# Cumulative duration =97.13s
#
# 692
# Epoch duration =0.13s
# Cumulative duration =97.26s
#
# 693
# Epoch duration =0.16s
# Cumulative duration =97.42s
#
# 694
# Epoch duration =0.14s
# Cumulative duration =97.56s
#
# 695
# Epoch duration =0.14s
# Cumulative duration =97.69s
#
# 696
# Epoch duration =0.13s
# Cumulative duration =97.83s
#
# 697
# Epoch duration =0.14s
# Cumulative duration =97.96s
#
# 698
# Epoch duration =0.14s
# Cumulative duration =98.1s
#
# 699
# Epoch duration =0.15s
# Cumulative duration =98.25s
#
# 700
# Epoch duration =0.13s
# Cumulative duration =98.39s
#
# 701
# Epoch duration =0.14s
# Cumulative duration =98.53s
#
# 702
# Epoch duration =0.13s
# Cumulative duration =98.66s
#
# 703
# Epoch duration =0.14s
# Cumulative duration =98.79s
#
# 704
# Epoch duration =0.14s
# Cumulative duration =98.93s
#
# 705
# Epoch duration =0.16s
# Cumulative duration =99.09s
#
# 706
# Epoch duration =0.13s
# Cumulative duration =99.22s
#
# 707
# Epoch duration =0.14s
# Cumulative duration =99.36s
#
# 708
# Epoch duration =0.14s
# Cumulative duration =99.5s
#
# 709
# Epoch duration =0.14s
# Cumulative duration =99.64s
#
# 710
# Epoch duration =0.13s
# Cumulative duration =99.77s
#
# 711
# Epoch duration =0.14s
# Cumulative duration =99.92s
#
# 712
# Epoch duration =0.15s
# Cumulative duration =100.06s
#
# 713
# Epoch duration =0.14s
# Cumulative duration =100.2s
#
# 714
# Epoch duration =0.18s
# Cumulative duration =100.38s
#
# 715
# Epoch duration =0.14s
# Cumulative duration =100.51s
#
# 716
# Epoch duration =0.15s
# Cumulative duration =100.67s
#
# 717
# Epoch duration =0.14s
# Cumulative duration =100.81s
#
# 718
# Epoch duration =0.13s
# Cumulative duration =100.94s
#
# 719
# Epoch duration =0.16s
# Cumulative duration =101.1s
#
# 720
# Epoch duration =0.15s
# Cumulative duration =101.25s
#
# 721
# Epoch duration =0.16s
# Cumulative duration =101.41s
#
# 722
# Epoch duration =0.14s
# Cumulative duration =101.55s
#
# 723
# Epoch duration =0.15s
# Cumulative duration =101.69s
#
# 724
# Epoch duration =0.17s
# Cumulative duration =101.86s
#
# 725
# Epoch duration =0.13s
# Cumulative duration =101.99s
#
# 726
# Epoch duration =0.14s
# Cumulative duration =102.13s
#
# 727
# Epoch duration =0.13s
# Cumulative duration =102.27s
#
# 728
# Epoch duration =0.14s
# Cumulative duration =102.41s
#
# 729
# Epoch duration =0.16s
# Cumulative duration =102.56s
#
# 730
# Epoch duration =0.16s
# Cumulative duration =102.72s
#
# 731
# Epoch duration =0.15s
# Cumulative duration =102.87s
#
# 732
# Epoch duration =0.14s
# Cumulative duration =103.01s
#
# 733
# Epoch duration =0.16s
# Cumulative duration =103.17s
#
# 734
# Epoch duration =0.14s
# Cumulative duration =103.31s
#
# 735
# Epoch duration =0.14s
# Cumulative duration =103.44s
#
# 736
# Epoch duration =0.14s
# Cumulative duration =103.58s
#
# 737
# Epoch duration =0.14s
# Cumulative duration =103.72s
#
# 738
# Epoch duration =0.14s
# Cumulative duration =103.86s
#
# 739
# Epoch duration =0.15s
# Cumulative duration =104.02s
#
# 740
# Epoch duration =0.14s
# Cumulative duration =104.15s
#
# 741
# Epoch duration =0.14s
# Cumulative duration =104.3s
#
# 742
# Epoch duration =0.13s
# Cumulative duration =104.43s
#
# 743
# Epoch duration =0.14s
# Cumulative duration =104.57s
#
# 744
# Epoch duration =0.13s
# Cumulative duration =104.7s
#
# 745
# Epoch duration =0.14s
# Cumulative duration =104.84s
#
# 746
# Epoch duration =0.14s
# Cumulative duration =104.98s
#
# 747
# Epoch duration =0.15s
# Cumulative duration =105.13s
#
# 748
# Epoch duration =0.14s
# Cumulative duration =105.27s
#
# 749
# Epoch duration =0.14s
# Cumulative duration =105.41s
#
# 750
# Epoch duration =0.14s
# Cumulative duration =105.54s
#
# 751
# Epoch duration =0.13s
# Cumulative duration =105.68s
#
# 752
# Epoch duration =0.13s
# Cumulative duration =105.81s
#
# 753
# Epoch duration =0.14s
# Cumulative duration =105.95s
#
# 754
# Epoch duration =0.14s
# Cumulative duration =106.08s
#
# 755
# Epoch duration =0.13s
# Cumulative duration =106.22s
#
# 756
# Epoch duration =0.13s
# Cumulative duration =106.35s
#
# 757
# Epoch duration =0.14s
# Cumulative duration =106.49s
#
# 758
# Epoch duration =0.13s
# Cumulative duration =106.62s
#
# 759
# Epoch duration =0.13s
# Cumulative duration =106.75s
#
# 760
# Epoch duration =0.14s
# Cumulative duration =106.89s
#
# 761
# Epoch duration =0.15s
# Cumulative duration =107.04s
#
# 762
# Epoch duration =0.16s
# Cumulative duration =107.2s
#
# 763
# Epoch duration =0.13s
# Cumulative duration =107.33s
#
# 764
# Epoch duration =0.13s
# Cumulative duration =107.47s
#
# 765
# Epoch duration =0.16s
# Cumulative duration =107.62s
#
# 766
# Epoch duration =0.13s
# Cumulative duration =107.76s
#
# 767
# Epoch duration =0.14s
# Cumulative duration =107.9s
#
# 768
# Epoch duration =0.14s
# Cumulative duration =108.04s
#
# 769
# Epoch duration =0.14s
# Cumulative duration =108.17s
#
# 770
# Epoch duration =0.14s
# Cumulative duration =108.31s
#
# 771
# Epoch duration =0.14s
# Cumulative duration =108.45s
#
# 772
# Epoch duration =0.14s
# Cumulative duration =108.58s
#
# 773
# Epoch duration =0.13s
# Cumulative duration =108.72s
#
# 774
# Epoch duration =0.14s
# Cumulative duration =108.86s
#
# 775
# Epoch duration =0.13s
# Cumulative duration =108.99s
#
# 776
# Epoch duration =0.14s
# Cumulative duration =109.13s
#
# 777
# Epoch duration =0.14s
# Cumulative duration =109.27s
#
# 778
# Epoch duration =0.14s
# Cumulative duration =109.4s
#
# 779
# Epoch duration =0.14s
# Cumulative duration =109.54s
#
# 780
# Epoch duration =0.14s
# Cumulative duration =109.68s
#
# 781
# Epoch duration =0.13s
# Cumulative duration =109.81s
#
# 782
# Epoch duration =0.14s
# Cumulative duration =109.95s
#
# 783
# Epoch duration =0.13s
# Cumulative duration =110.09s
#
# 784
# Epoch duration =0.13s
# Cumulative duration =110.22s
#
# 785
# Epoch duration =0.14s
# Cumulative duration =110.35s
#
# 786
# Epoch duration =0.13s
# Cumulative duration =110.49s
#
# 787
# Epoch duration =0.14s
# Cumulative duration =110.63s
#
# 788
# Epoch duration =0.13s
# Cumulative duration =110.76s
#
# 789
# Epoch duration =0.14s
# Cumulative duration =110.9s
#
# 790
# Epoch duration =0.13s
# Cumulative duration =111.03s
#
# 791
# Epoch duration =0.14s
# Cumulative duration =111.17s
#
# 792
# Epoch duration =0.14s
# Cumulative duration =111.32s
#
# 793
# Epoch duration =0.14s
# Cumulative duration =111.46s
#
# 794
# Epoch duration =0.14s
# Cumulative duration =111.6s
#
# 795
# Epoch duration =0.16s
# Cumulative duration =111.76s
#
# 796
# Epoch duration =0.14s
# Cumulative duration =111.9s
#
# 797
# Epoch duration =0.13s
# Cumulative duration =112.03s
#
# 798
# Epoch duration =0.13s
# Cumulative duration =112.17s
#
# 799
# Epoch duration =0.14s
# Cumulative duration =112.3s
#
# 800
# Epoch duration =0.13s
# Cumulative duration =112.44s
#
# 801
# Epoch duration =0.13s
# Cumulative duration =112.57s
#
# 802
# Epoch duration =0.14s
# Cumulative duration =112.71s
#
# 803
# Epoch duration =0.14s
# Cumulative duration =112.85s
#
# 804
# Epoch duration =0.14s
# Cumulative duration =112.99s
#
# 805
# Epoch duration =0.13s
# Cumulative duration =113.12s
#
# 806
# Epoch duration =0.14s
# Cumulative duration =113.27s
#
# 807
# Epoch duration =0.14s
# Cumulative duration =113.4s
#
# 808
# Epoch duration =0.14s
# Cumulative duration =113.54s
#
# 809
# Epoch duration =0.13s
# Cumulative duration =113.67s
#
# 810
# Epoch duration =0.14s
# Cumulative duration =113.81s
#
# 811
# Epoch duration =0.14s
# Cumulative duration =113.95s
#
# 812
# Epoch duration =0.13s
# Cumulative duration =114.08s
#
# 813
# Epoch duration =0.14s
# Cumulative duration =114.22s
#
# 814
# Epoch duration =0.14s
# Cumulative duration =114.36s
#
# 815
# Epoch duration =0.14s
# Cumulative duration =114.49s
#
# 816
# Epoch duration =0.13s
# Cumulative duration =114.63s
#
# 817
# Epoch duration =0.14s
# Cumulative duration =114.76s
#
# 818
# Epoch duration =0.14s
# Cumulative duration =114.9s
#
# 819
# Epoch duration =0.14s
# Cumulative duration =115.04s
#
# 820
# Epoch duration =0.13s
# Cumulative duration =115.17s
#
# 821
# Epoch duration =0.14s
# Cumulative duration =115.31s
#
# 822
# Epoch duration =0.13s
# Cumulative duration =115.45s
#
# 823
# Epoch duration =0.13s
# Cumulative duration =115.58s
#
# 824
# Epoch duration =0.13s
# Cumulative duration =115.71s
#
# 825
# Epoch duration =0.13s
# Cumulative duration =115.85s
#
# 826
# Epoch duration =0.14s
# Cumulative duration =115.98s
#
# 827
# Epoch duration =0.14s
# Cumulative duration =116.12s
#
# 828
# Epoch duration =0.17s
# Cumulative duration =116.29s
#
# 829
# Epoch duration =0.15s
# Cumulative duration =116.44s
#
# 830
# Epoch duration =0.13s
# Cumulative duration =116.58s
#
# 831
# Epoch duration =0.14s
# Cumulative duration =116.72s
#
# 832
# Epoch duration =0.13s
# Cumulative duration =116.85s
#
# 833
# Epoch duration =0.14s
# Cumulative duration =116.99s
#
# 834
# Epoch duration =0.13s
# Cumulative duration =117.12s
#
# 835
# Epoch duration =0.14s
# Cumulative duration =117.26s
#
# 836
# Epoch duration =0.13s
# Cumulative duration =117.39s
#
# 837
# Epoch duration =0.14s
# Cumulative duration =117.53s
#
# 838
# Epoch duration =0.14s
# Cumulative duration =117.67s
#
# 839
# Epoch duration =0.14s
# Cumulative duration =117.81s
#
# 840
# Epoch duration =0.13s
# Cumulative duration =117.94s
#
# 841
# Epoch duration =0.14s
# Cumulative duration =118.08s
#
# 842
# Epoch duration =0.13s
# Cumulative duration =118.21s
#
# 843
# Epoch duration =0.14s
# Cumulative duration =118.35s
#
# 844
# Epoch duration =0.15s
# Cumulative duration =118.49s
#
# 845
# Epoch duration =0.14s
# Cumulative duration =118.63s
#
# 846
# Epoch duration =0.14s
# Cumulative duration =118.78s
#
# 847
# Epoch duration =0.15s
# Cumulative duration =118.93s
#
# 848
# Epoch duration =0.13s
# Cumulative duration =119.06s
#
# 849
# Epoch duration =0.14s
# Cumulative duration =119.21s
#
# 850
# Epoch duration =0.14s
# Cumulative duration =119.35s
#
# 851
# Epoch duration =0.14s
# Cumulative duration =119.49s
#
# 852
# Epoch duration =0.14s
# Cumulative duration =119.62s
#
# 853
# Epoch duration =0.14s
# Cumulative duration =119.76s
#
# 854
# Epoch duration =0.14s
# Cumulative duration =119.9s
#
# 855
# Epoch duration =0.14s
# Cumulative duration =120.04s
#
# 856
# Epoch duration =0.16s
# Cumulative duration =120.2s
#
# 857
# Epoch duration =0.16s
# Cumulative duration =120.36s
#
# 858
# Epoch duration =0.13s
# Cumulative duration =120.49s
#
# 859
# Epoch duration =0.14s
# Cumulative duration =120.63s
#
# 860
# Epoch duration =0.14s
# Cumulative duration =120.77s
#
# 861
# Epoch duration =0.14s
# Cumulative duration =120.91s
#
# 862
# Epoch duration =0.14s
# Cumulative duration =121.04s
#
# 863
# Epoch duration =0.13s
# Cumulative duration =121.18s
#
# 864
# Epoch duration =0.13s
# Cumulative duration =121.31s
#
# 865
# Epoch duration =0.14s
# Cumulative duration =121.45s
#
# 866
# Epoch duration =0.13s
# Cumulative duration =121.58s
#
# 867
# Epoch duration =0.14s
# Cumulative duration =121.72s
#
# 868
# Epoch duration =0.14s
# Cumulative duration =121.85s
#
# 869
# Epoch duration =0.13s
# Cumulative duration =121.99s
#
# 870
# Epoch duration =0.14s
# Cumulative duration =122.12s
#
# 871
# Epoch duration =0.13s
# Cumulative duration =122.26s
#
# 872
# Epoch duration =0.13s
# Cumulative duration =122.39s
#
# 873
# Epoch duration =0.14s
# Cumulative duration =122.53s
#
# 874
# Epoch duration =0.13s
# Cumulative duration =122.66s
#
# 875
# Epoch duration =0.13s
# Cumulative duration =122.8s
#
# 876
# Epoch duration =0.13s
# Cumulative duration =122.93s
#
# 877
# Epoch duration =0.13s
# Cumulative duration =123.07s
#
# 878
# Epoch duration =0.14s
# Cumulative duration =123.2s
#
# 879
# Epoch duration =0.14s
# Cumulative duration =123.34s
#
# 880
# Epoch duration =0.14s
# Cumulative duration =123.49s
#
# 881
# Epoch duration =0.14s
# Cumulative duration =123.62s
#
# 882
# Epoch duration =0.13s
# Cumulative duration =123.76s
#
# 883
# Epoch duration =0.14s
# Cumulative duration =123.9s
#
# 884
# Epoch duration =0.14s
# Cumulative duration =124.04s
#
# 885
# Epoch duration =0.14s
# Cumulative duration =124.17s
#
# 886
# Epoch duration =0.15s
# Cumulative duration =124.33s
#
# 887
# Epoch duration =0.14s
# Cumulative duration =124.46s
#
# 888
# Epoch duration =0.13s
# Cumulative duration =124.59s
#
# 889
# Epoch duration =0.14s
# Cumulative duration =124.74s
#
# 890
# Epoch duration =0.14s
# Cumulative duration =124.88s
#
# 891
# Epoch duration =0.15s
# Cumulative duration =125.02s
#
# 892
# Epoch duration =0.14s
# Cumulative duration =125.16s
#
# 893
# Epoch duration =0.14s
# Cumulative duration =125.3s
#
# 894
# Epoch duration =0.14s
# Cumulative duration =125.44s
#
# 895
# Epoch duration =0.14s
# Cumulative duration =125.58s
#
# 896
# Epoch duration =0.13s
# Cumulative duration =125.71s
#
# 897
# Epoch duration =0.14s
# Cumulative duration =125.85s
#
# 898
# Epoch duration =0.14s
# Cumulative duration =125.99s
#
# 899
# Epoch duration =0.14s
# Cumulative duration =126.13s
#
# 900
# Epoch duration =0.13s
# Cumulative duration =126.26s
#
# 901
# Epoch duration =0.14s
# Cumulative duration =126.39s
#
# 902
# Epoch duration =0.13s
# Cumulative duration =126.53s
#
# 903
# Epoch duration =0.18s
# Cumulative duration =126.71s
#
# 904
# Epoch duration =0.14s
# Cumulative duration =126.84s
#
# 905
# Epoch duration =0.14s
# Cumulative duration =126.98s
#
# 906
# Epoch duration =0.14s
# Cumulative duration =127.12s
#
# 907
# Epoch duration =0.17s
# Cumulative duration =127.28s
#
# 908
# Epoch duration =0.16s
# Cumulative duration =127.44s
#
# 909
# Epoch duration =0.14s
# Cumulative duration =127.58s
#
# 910
# Epoch duration =0.15s
# Cumulative duration =127.73s
#
# 911
# Epoch duration =0.14s
# Cumulative duration =127.87s
#
# 912
# Epoch duration =0.14s
# Cumulative duration =128.01s
#
# 913
# Epoch duration =0.14s
# Cumulative duration =128.14s
#
# 914
# Epoch duration =0.13s
# Cumulative duration =128.28s
#
# 915
# Epoch duration =0.14s
# Cumulative duration =128.41s
#
# 916
# Epoch duration =0.14s
# Cumulative duration =128.55s
#
# 917
# Epoch duration =0.14s
# Cumulative duration =128.69s
#
# 918
# Epoch duration =0.14s
# Cumulative duration =128.83s
#
# 919
# Epoch duration =0.13s
# Cumulative duration =128.96s
#
# 920
# Epoch duration =0.14s
# Cumulative duration =129.1s
#
# 921
# Epoch duration =0.16s
# Cumulative duration =129.26s
#
# 922
# Epoch duration =0.14s
# Cumulative duration =129.4s
#
# 923
# Epoch duration =0.14s
# Cumulative duration =129.53s
#
# 924
# Epoch duration =0.14s
# Cumulative duration =129.67s
#
# 925
# Epoch duration =0.16s
# Cumulative duration =129.83s
#
# 926
# Epoch duration =0.14s
# Cumulative duration =129.97s
#
# 927
# Epoch duration =0.14s
# Cumulative duration =130.11s
#
# 928
# Epoch duration =0.13s
# Cumulative duration =130.24s
#
# 929
# Epoch duration =0.14s
# Cumulative duration =130.39s
#
# 930
# Epoch duration =0.15s
# Cumulative duration =130.54s
#
# 931
# Epoch duration =0.14s
# Cumulative duration =130.67s
#
# 932
# Epoch duration =0.14s
# Cumulative duration =130.81s
#
# 933
# Epoch duration =0.14s
# Cumulative duration =130.95s
#
# 934
# Epoch duration =0.14s
# Cumulative duration =131.09s
#
# 935
# Epoch duration =0.14s
# Cumulative duration =131.22s
#
# 936
# Epoch duration =0.13s
# Cumulative duration =131.35s
#
# 937
# Epoch duration =0.14s
# Cumulative duration =131.49s
#
# 938
# Epoch duration =0.13s
# Cumulative duration =131.62s
#
# 939
# Epoch duration =0.14s
# Cumulative duration =131.76s
#
# 940
# Epoch duration =0.13s
# Cumulative duration =131.89s
#
# 941
# Epoch duration =0.14s
# Cumulative duration =132.03s
#
# 942
# Epoch duration =0.14s
# Cumulative duration =132.17s
#
# 943
# Epoch duration =0.14s
# Cumulative duration =132.31s
#
# 944
# Epoch duration =0.13s
# Cumulative duration =132.44s
#
# 945
# Epoch duration =0.16s
# Cumulative duration =132.6s
#
# 946
# Epoch duration =0.13s
# Cumulative duration =132.73s
#
# 947
# Epoch duration =0.17s
# Cumulative duration =132.9s
#
# 948
# Epoch duration =0.15s
# Cumulative duration =133.05s
#
# 949
# Epoch duration =0.14s
# Cumulative duration =133.19s
#
# 950
# Epoch duration =0.13s
# Cumulative duration =133.32s
#
# 951
# Epoch duration =0.14s
# Cumulative duration =133.46s
#
# 952
# Epoch duration =0.14s
# Cumulative duration =133.6s
#
# 953
# Epoch duration =0.14s
# Cumulative duration =133.74s
#
# 954
# Epoch duration =0.16s
# Cumulative duration =133.89s
#
# 955
# Epoch duration =0.14s
# Cumulative duration =134.03s
#
# 956
# Epoch duration =0.14s
# Cumulative duration =134.17s
#
# 957
# Epoch duration =0.14s
# Cumulative duration =134.31s
#
# 958
# Epoch duration =0.14s
# Cumulative duration =134.45s
#
# 959
# Epoch duration =0.14s
# Cumulative duration =134.59s
#
# 960
# Epoch duration =0.14s
# Cumulative duration =134.73s
#
# 961
# Epoch duration =0.14s
# Cumulative duration =134.87s
#
# 962
# Epoch duration =0.13s
# Cumulative duration =135.0s
#
# 963
# Epoch duration =0.14s
# Cumulative duration =135.14s
#
# 964
# Epoch duration =0.13s
# Cumulative duration =135.27s
#
# 965
# Epoch duration =0.15s
# Cumulative duration =135.42s
#
# 966
# Epoch duration =0.15s
# Cumulative duration =135.57s
#
# 967
# Epoch duration =0.14s
# Cumulative duration =135.71s
#
# 968
# Epoch duration =0.14s
# Cumulative duration =135.85s
#
# 969
# Epoch duration =0.15s
# Cumulative duration =136.0s
#
# 970
# Epoch duration =0.13s
# Cumulative duration =136.13s
#
# 971
# Epoch duration =0.15s
# Cumulative duration =136.28s
#
# 972
# Epoch duration =0.14s
# Cumulative duration =136.42s
#
# 973
# Epoch duration =0.16s
# Cumulative duration =136.59s
#
# 974
# Epoch duration =0.13s
# Cumulative duration =136.72s
#
# 975
# Epoch duration =0.15s
# Cumulative duration =136.87s
#
# 976
# Epoch duration =0.14s
# Cumulative duration =137.01s
#
# 977
# Epoch duration =0.14s
# Cumulative duration =137.15s
#
# 978
# Epoch duration =0.14s
# Cumulative duration =137.29s
#
# 979
# Epoch duration =0.14s
# Cumulative duration =137.43s
#
# 980
# Epoch duration =0.14s
# Cumulative duration =137.57s
#
# 981
# Epoch duration =0.14s
# Cumulative duration =137.71s
#
# 982
# Epoch duration =0.14s
# Cumulative duration =137.84s
#
# 983
# Epoch duration =0.14s
# Cumulative duration =137.98s
#
# 984
# Epoch duration =0.13s
# Cumulative duration =138.11s
#
# 985
# Epoch duration =0.14s
# Cumulative duration =138.26s
#
# 986
# Epoch duration =0.13s
# Cumulative duration =138.39s
#
# 987
# Epoch duration =0.14s
# Cumulative duration =138.52s
#
# 988
# Epoch duration =0.13s
# Cumulative duration =138.66s
#
# 989
# Epoch duration =0.14s
# Cumulative duration =138.79s
#
# 990
# Epoch duration =0.14s
# Cumulative duration =138.93s
#
# 991
# Epoch duration =0.16s
# Cumulative duration =139.09s
#
# 992
# Epoch duration =0.13s
# Cumulative duration =139.22s
#
# 993
# Epoch duration =0.16s
# Cumulative duration =139.39s
#
# 994
# Epoch duration =0.14s
# Cumulative duration =139.52s
#
# 995
# Epoch duration =0.15s
# Cumulative duration =139.67s
#
# 996
# Epoch duration =0.13s
# Cumulative duration =139.81s
#
# 997
# Epoch duration =0.14s
# Cumulative duration =139.95s
#
# 998
# Epoch duration =0.14s
# Cumulative duration =140.08s
#
# 999
# Epoch duration =0.14s
# Cumulative duration =140.22s

# %%
# Load the summed array for future use
npy_save_path = 'Arrays/toyhairpin_FC_1_64_sumneuron_1_1000.npy'
sum_mut2_scores = np.load(npy_save_path)

num_summary = 1000
#average the values
mean_mut2_scores = sum_mut2_scores/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
mean_mut2_scores_hol = mean_mut2_scores.reshape(X.shape[1],X.shape[1],4,4)

# %%
mean_mut2_predictoutputs_hol = mean_mut2_scores_hol


nuc = ['A', 'C', 'G', 'U']

fig4 = plt.figure(figsize=(15,14))

num = 15

for one in range(num):
    for two in range(num):
        ax = fig4.add_subplot(num, num, ((one*num)+two)+1)
        
        #plot the 0th column with row labels and the num_th most row with column labels
        if two == 0:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=nuc, cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=nuc, cbar=False)
        else:
            if one == (num-1):
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=nuc, yticklabels=[], cbar=False)
            else:
                ax = sb.heatmap(mean_mut2_predictoutputs_hol[one+4, two+22], cmap='Blues', linewidths=0.1, linecolor='black', xticklabels=[], yticklabels=[], cbar=False)

# %%
def square_holplot(mutations, num, alphabet, cmap ='Blues', figsize=(15,14), lines=True, start=(4,22)):

    if alphabet == 'rna':
        nuc = ['A', 'C', 'G', 'U']
    if alphabet == 'dna':
        nuc = ['A', 'C', 'G', 'T']

    if lines == True:
        linewidths = 0.1
    else:
        linewidths = 0.

    start_1, start_2 = start

    fig = plt.figure(figsize=(15,14))

    for one in range(num):
        for two in range(num):
            ax = fig.add_subplot(num, num, ((one*num)+two)+1)

            #plot the 0th column with row labels and the num_th most row with column labels
            if two == 0:
                if one == (num-1):
                    xtick=nuc
                    ytick=nuc
                else:
                    xtick=[]
                    ytick=nuc
            else:
                if one == (num-1):
                    xtick=nuc
                    ytick=[]
                else:
                    xtick=[]
                    ytick=[]

            ax = sb.heatmap(mutations[one+start_1, two+start_2], cmap=cmap, linewidths=linewidths, linecolor='black', xticklabels=xtick, yticklabels=ytick, cbar=False)

# %%
square_holplot(mean_mut2_predictoutputs_hol, num=4, alphabet='rna')

# %% [markdown]
# ## Look at the dense parameters

# %%
W = nnmodel.get_parameters(sess, layer='dense_0')[0]
W = W.reshape((41,4,64))
W = W.transpose(1,0,2)

# %%
for ii in top_neurons[:5]:
    plt.figure()
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            W[:,:,ii], 
                                            alphabet='rna', 
                                            nt_width=400)
