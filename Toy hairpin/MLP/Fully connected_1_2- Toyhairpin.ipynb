# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency

import mutagenesis_functions as mf
import time as time

# %%
# load hairpin data
data_path = '../data_peter/random_sequences_with_custom_hl.hdf5'
with h5py.File(data_path) as dataset:
    X_train_seq = np.expand_dims(np.array(dataset['train_seq']).transpose([0, 2, 1]), axis=2)
    X_train_struct = np.expand_dims(np.array(dataset['train_structures']).transpose([0, 2, 1]), axis=2)
    Y_train = np.expand_dims(np.array(dataset['train_targets']), axis=1)
    X_test_seq = np.expand_dims(np.array(dataset['test_seq']).transpose([0, 2, 1]), axis=2)
    X_test_struct = np.expand_dims(np.array(dataset['test_structures']).transpose([0, 2, 1]), axis=2)
    Y_test = np.expand_dims(np.array(dataset['test_targets']), axis=1)

num_data, seq_length, _, num_alphabet = X_train_seq.shape

# get validation set from training set
valid_frac = 0.2
N = len(X_train_seq)
split_index = int(N*valid_frac)
shuffle = np.random.permutation(N)

# put in a dictionary for deepomics
train = {'inputs': X_train_seq[shuffle[split_index:]], 
         'targets': Y_train[shuffle[split_index:]]}
valid = {'inputs': X_train_seq[shuffle[:split_index]], 
         'targets': Y_train[shuffle[:split_index]]}
test = {'inputs': X_test_seq, 'targets': Y_test}

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 2,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../results/toyhairpin'
param_path = os.path.join(save_path, 'fullyconnected_1_2')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 41, 1, 4)
# layer2: dense_0
# (?, 2)
# layer3: dense_0_batch
# (?, 2)
# layer4: dense_0_active
# (?, 2)
# layer5: dense_0_dropout
# (?, 2)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=10, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.70s -- loss=0.60078 -- acc=57.76094
#
#   valid loss:		0.42234
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.92874+/-0.00000
#   valid auc-pr:		0.88292+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.51770 -- acc=66.55416
#
#   valid loss:		0.37448
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.94517+/-0.00000
#   valid auc-pr:		0.90809+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=5.20s -- loss=0.51099 -- acc=66.55416
#
#   valid loss:		0.36041
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.94185+/-0.00000
#   valid auc-pr:		0.90330+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=5.00s -- loss=0.50896 -- acc=66.55416
#
#   valid loss:		0.35360
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93861+/-0.00000
#   valid auc-pr:		0.89980+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=4.88s -- loss=0.50803 -- acc=66.55416
#
#   valid loss:		0.35268
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93658+/-0.00000
#   valid auc-pr:		0.89703+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=4.48s -- loss=0.50594 -- acc=66.55416
#
#   valid loss:		0.34705
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93642+/-0.00000
#   valid auc-pr:		0.89710+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=4.45s -- loss=0.50690 -- acc=66.55416
#
#   valid loss:		0.34306
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93852+/-0.00000
#   valid auc-pr:		0.89980+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=4.57s -- loss=0.50784 -- acc=66.55416
#
#   valid loss:		0.34828
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93459+/-0.00000
#   valid auc-pr:		0.89477+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=4.35s -- loss=0.50515 -- acc=66.55416
#
#   valid loss:		0.34237
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93581+/-0.00000
#   valid auc-pr:		0.89631+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.50606 -- acc=66.55416
#
#   valid loss:		0.34555
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93254+/-0.00000
#   valid auc-pr:		0.89218+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=4.50s -- loss=0.50547 -- acc=66.55416
#
#   valid loss:		0.34367
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93126+/-0.00000
#   valid auc-pr:		0.89057+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=4.29s -- loss=0.50681 -- acc=66.55416
#
#   valid loss:		0.34194
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93439+/-0.00000
#   valid auc-pr:		0.89448+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=4.27s -- loss=0.50442 -- acc=66.55416
#
#   valid loss:		0.34106
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93278+/-0.00000
#   valid auc-pr:		0.89247+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.50542 -- acc=66.55416
#
#   valid loss:		0.34238
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93246+/-0.00000
#   valid auc-pr:		0.89207+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=4.40s -- loss=0.50559 -- acc=66.55416
#
#   valid loss:		0.33723
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93549+/-0.00000
#   valid auc-pr:		0.89592+/-0.00000
#   lower cross-validation found
#   saving model to:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=4.59s -- loss=0.50490 -- acc=66.55416
#
#   valid loss:		0.34035
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93229+/-0.00000
#   valid auc-pr:		0.89184+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=4.37s -- loss=0.50550 -- acc=66.55416
#
#   valid loss:		0.34104
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93051+/-0.00000
#   valid auc-pr:		0.88964+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=4.36s -- loss=0.50317 -- acc=66.55416
#
#   valid loss:		0.33756
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93382+/-0.00000
#   valid auc-pr:		0.89375+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=4.58s -- loss=0.50540 -- acc=66.55416
#
#   valid loss:		0.34008
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93296+/-0.00000
#   valid auc-pr:		0.89271+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=4.35s -- loss=0.50611 -- acc=66.55416
#
#   valid loss:		0.34343
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93045+/-0.00000
#   valid auc-pr:		0.88957+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=4.34s -- loss=0.50553 -- acc=66.55416
#
#   valid loss:		0.34068
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93150+/-0.00000
#   valid auc-pr:		0.89088+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=4.45s -- loss=0.50489 -- acc=66.55416
#
#   valid loss:		0.33885
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93186+/-0.00000
#   valid auc-pr:		0.89131+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=4.52s -- loss=0.50525 -- acc=66.55416
#
#   valid loss:		0.33921
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93174+/-0.00000
#   valid auc-pr:		0.89117+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=5.04s -- loss=0.50465 -- acc=66.55416
#
#   valid loss:		0.33941
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93048+/-0.00000
#   valid auc-pr:		0.88961+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=4.28s -- loss=0.50558 -- acc=66.55416
#
#   valid loss:		0.33900
#   valid accuracy:	0.67081+/-0.00000
#   valid auc-roc:	0.93060+/-0.00000
#   valid auc-pr:		0.88976+/-0.00000
# Patience ran out... Early stopping.

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../results/toyhairpin/fullyconnected_1_2_best.ckpt
#   test  loss:		0.33956
#   test  accuracy:	0.66695+/-0.00000
#   test  auc-roc:	0.93467+/-0.00000
#   test  auc-pr:		0.89630+/-0.00000

# %% [markdown]
# ## First order mutagenesis saliency

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
numplots=5

for ii in range(numplots): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='output', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Second Order Mutagenesis

# %%
savepath = 'Arrays/toyhairpin_FC_1_2_sumoutputs1k.npy'

num_summary = 1000
X = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average(X, savepath, nntrainer, sess, progress='off')
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/toyhairpin_FC_1_2_sumoutputs1k.npy

# %%
#Load the saved data
savepath = 'Arrays/toyhairpin_FC_1_2_sumoutputs1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4
meanhol_mut2 = mean_mut2.reshape(X.shape[1],X.shape[1],4,4)

# %%
mf.symlinear_holplot(meanhol_mut2, figplot=(4,5), alphabet='rna')

# %%
mf.square_holplot(meanhol_mut2, num=15, alphabet='rna')

# %% [markdown]
# ## Look at Hidden Layers

# %%
W = nnmodel.get_parameters(sess, layer='dense_1')[0]
W.shape
top_neurons=np.argsort(np.squeeze(W))[::-1]
top_neurons
# Out:
# array([ 8,  6, 12,  9,  3,  5,  2, 10,  1, 13,  7,  0, 14, 11,  4])

# %%
dense = nntrainer.get_activations(sess, test, layer='dense_0_active')

#plot which neurons got activated by the highest predicted sequence (from the outputs)
plt.plot(range(dense.shape[1]), dense[plot_index[0]])
plt.show()

''' An example of how a single sequence can excite various different neurons'''
# Out:
# /home/peter/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
# ' An example of how a single sequence can excite various different neurons'

# %%
num_plots = 5
for neuron in top_neurons[0:num_plots]:
    top_indices = np.argsort(dense[:,neuron])[::-1]
    X = np.expand_dims(test['inputs'][top_indices[0]], axis=0)
    
    mf.fom_neursal(X, layer='dense_0_active', alphabet='rna', neuron=neuron, nntrainer=nntrainer, sess=sess)

# %% [markdown]
# ## Look at the dense parameters

# %%
W = nnmodel.get_parameters(sess, layer='dense_0')[0]
W = W.reshape((41,4,44))
W = W.transpose(1,0,2)

for ii in top_neurons[:5]:
    plt.figure()
    visualize.plot_seq_pos_saliency(np.squeeze(X).T, 
                                            W[:,:,ii], 
                                            alphabet='rna', 
                                            nt_width=400)
