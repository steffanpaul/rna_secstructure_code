# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/trna_100k_d3.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 1.92s

# %%
simalign_file = '../../../data_RFAM/trnasim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((((<<<<>>>><<<<<>>>>><<<<<>>>>>)))))))'

# %%
ugSS
# Out:
# '(((((((,,<<<<_______>>>>,<<<<<_______>>>>>,,,,<<<<<_______>>>>>))))))):'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/trna'
param_path = os.path.join(save_path, 'resbind_t3')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 513, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=11.78s -- loss=0.17199 -- acc=92.80500%
#
#   valid loss:		0.08112
#   valid accuracy:	0.97030+/-0.00000
#   valid auc-roc:	0.99920+/-0.00000
#   valid auc-pr:		0.99909+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t3_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=10.96s -- loss=0.04418 -- acc=98.73417%
#
#   valid loss:		0.01969
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t3_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=11.36s -- loss=0.03111 -- acc=99.20417%
#
#   valid loss:		0.02527
#   valid accuracy:	0.99405+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=11.28s -- loss=0.02644 -- acc=99.37750%
#
#   valid loss:		0.01826
#   valid accuracy:	0.99660+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t3_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=11.31s -- loss=0.02494 -- acc=99.44583%
#
#   valid loss:		0.01630
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t3_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=11.36s -- loss=0.02483 -- acc=99.49750%
#
#   valid loss:		0.02454
#   valid accuracy:	0.99515+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=11.27s -- loss=0.02276 -- acc=99.59167%
#
#   valid loss:		0.02031
#   valid accuracy:	0.99700+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=11.47s -- loss=0.02262 -- acc=99.59917%
#
#   valid loss:		0.02453
#   valid accuracy:	0.99555+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=11.32s -- loss=0.02305 -- acc=99.62750%
#
#   valid loss:		0.01753
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=11.29s -- loss=0.02201 -- acc=99.68333%
#
#   valid loss:		0.02199
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=11.36s -- loss=0.02234 -- acc=99.69083%
#
#   valid loss:		0.01793
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=11.41s -- loss=0.02208 -- acc=99.69833%
#
#   valid loss:		0.01851
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=11.32s -- loss=0.02219 -- acc=99.70417%
#
#   valid loss:		0.02209
#   valid accuracy:	0.99695+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=11.28s -- loss=0.02188 -- acc=99.72083%
#
#   valid loss:		0.02144
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=11.36s -- loss=0.02215 -- acc=99.74250%
#
#   valid loss:		0.02005
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=11.35s -- loss=0.02136 -- acc=99.75417%
#
#   valid loss:		0.02555
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=11.36s -- loss=0.02148 -- acc=99.75083%
#
#   valid loss:		0.02532
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=11.31s -- loss=0.02128 -- acc=99.76833%
#
#   valid loss:		0.01814
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=11.38s -- loss=0.02031 -- acc=99.79750%
#
#   valid loss:		0.02243
#   valid accuracy:	0.99685+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=11.44s -- loss=0.02081 -- acc=99.79083%
#
#   valid loss:		0.01788
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=11.41s -- loss=0.02031 -- acc=99.79583%
#
#   valid loss:		0.02003
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=11.48s -- loss=0.02069 -- acc=99.78250%
#
#   valid loss:		0.01804
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=11.41s -- loss=0.02112 -- acc=99.78083%
#
#   valid loss:		0.02206
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=11.47s -- loss=0.02042 -- acc=99.77417%
#
#   valid loss:		0.01869
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=11.48s -- loss=0.02073 -- acc=99.78833%
#
#   valid loss:		0.02278
#   valid accuracy:	0.99705+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=11.41s -- loss=0.02075 -- acc=99.78917%
#
#   valid loss:		0.01874
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=11.45s -- loss=0.01993 -- acc=99.82250%
#
#   valid loss:		0.01997
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=11.50s -- loss=0.01969 -- acc=99.82333%
#
#   valid loss:		0.01781
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=11.43s -- loss=0.02000 -- acc=99.81667%
#
#   valid loss:		0.02028
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=11.40s -- loss=0.01951 -- acc=99.81333%
#
#   valid loss:		0.01814
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=11.37s -- loss=0.01981 -- acc=99.79833%
#
#   valid loss:		0.01831
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=11.41s -- loss=0.02027 -- acc=99.80250%
#
#   valid loss:		0.01727
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=11.47s -- loss=0.01937 -- acc=99.83250%
#
#   valid loss:		0.01867
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=11.38s -- loss=0.01927 -- acc=99.82917%
#
#   valid loss:		0.02121
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=11.40s -- loss=0.01980 -- acc=99.80583%
#
#   valid loss:		0.01877
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=11.43s -- loss=0.01874 -- acc=99.83417%
#
#   valid loss:		0.02396
#   valid accuracy:	0.99695+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=11.40s -- loss=0.01845 -- acc=99.85333%
#
#   valid loss:		0.01760
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=11.42s -- loss=0.01959 -- acc=99.82833%
#
#   valid loss:		0.01855
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=11.42s -- loss=0.01892 -- acc=99.82833%
#
#   valid loss:		0.02146
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=11.43s -- loss=0.01819 -- acc=99.85500%
#
#   valid loss:		0.01816
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=11.41s -- loss=0.01934 -- acc=99.80917%
#
#   valid loss:		0.01809
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=11.47s -- loss=0.01869 -- acc=99.83833%
#
#   valid loss:		0.01716
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=11.44s -- loss=0.01866 -- acc=99.83750%
#
#   valid loss:		0.01708
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=11.50s -- loss=0.01890 -- acc=99.81667%
#
#   valid loss:		0.01936
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=11.41s -- loss=0.01826 -- acc=99.85750%
#
#   valid loss:		0.01809
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/trna/resbind_t3_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/trna/resbind_t3_best.ckpt
#   test  loss:		0.01877
#   test  accuracy:	0.99702+/-0.00000
#   test  auc-roc:	0.99993+/-0.00000
#   test  auc-pr:		0.99993+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/trna_resbindt3_ug_so1000.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =2.03s
# Cumulative duration =2.03s
#
# 1
# Epoch duration =2.0s
# Cumulative duration =4.03s
#
# 2
# Epoch duration =2.0s
# Cumulative duration =6.04s
#
# 3
# Epoch duration =2.0s
# Cumulative duration =8.04s
#
# 4
# Epoch duration =1.99s
# Cumulative duration =10.03s
#
# 5
# Epoch duration =1.99s
# Cumulative duration =12.03s
#
# 6
# Epoch duration =2.0s
# Cumulative duration =14.02s
#
# 7
# Epoch duration =2.0s
# Cumulative duration =16.03s
#
# 8
# Epoch duration =2.0s
# Cumulative duration =18.03s
#
# 9
# Epoch duration =2.0s
# Cumulative duration =20.02s
#
# 10
# Epoch duration =2.0s
# Cumulative duration =22.02s
#
# 11
# Epoch duration =1.99s
# Cumulative duration =24.01s
#
# 12
# Epoch duration =2.07s
# Cumulative duration =26.08s
#
# 13
# Epoch duration =1.99s
# Cumulative duration =28.08s
#
# 14
# Epoch duration =1.99s
# Cumulative duration =30.06s
#
# 15
# Epoch duration =1.99s
# Cumulative duration =32.05s
#
# 16
# Epoch duration =2.0s
# Cumulative duration =34.05s
#
# 17
# Epoch duration =2.0s
# Cumulative duration =36.06s
#
# 18
# Epoch duration =1.99s
# Cumulative duration =38.04s
#
# 19
# Epoch duration =2.02s
# Cumulative duration =40.06s
#
# 20
# Epoch duration =2.0s
# Cumulative duration =42.05s
#
# 21
# Epoch duration =1.99s
# Cumulative duration =44.05s
#
# 22
# Epoch duration =2.0s
# Cumulative duration =46.05s
#
# 23
# Epoch duration =1.99s
# Cumulative duration =48.05s
#
# 24
# Epoch duration =1.99s
# Cumulative duration =50.04s
#
# 25
# Epoch duration =1.99s
# Cumulative duration =52.03s
#
# 26
# Epoch duration =1.99s
# Cumulative duration =54.02s
#
# 27
# Epoch duration =1.99s
# Cumulative duration =56.01s
#
# 28
# Epoch duration =2.0s
# Cumulative duration =58.01s
#
# 29
# Epoch duration =2.0s
# Cumulative duration =1min 0.0s
#
# 30
# Epoch duration =2.01s
# Cumulative duration =1min 2.009999999999998s
#
# 31
# Epoch duration =2.0s
# Cumulative duration =1min 4.010000000000005s
#
# 32
# Epoch duration =2.0s
# Cumulative duration =1min 6.019999999999996s
#
# 33
# Epoch duration =2.0s
# Cumulative duration =1min 8.019999999999996s
#
# 34
# Epoch duration =1.99s
# Cumulative duration =1min 10.010000000000005s
#
# 35
# Epoch duration =2.01s
# Cumulative duration =1min 12.019999999999996s
#
# 36
# Epoch duration =2.0s
# Cumulative duration =1min 14.019999999999996s
#
# 37
# Epoch duration =1.98s
# Cumulative duration =1min 16.010000000000005s
#
# 38
# Epoch duration =1.99s
# Cumulative duration =1min 18.0s
#
# 39
# Epoch duration =2.01s
# Cumulative duration =1min 20.0s
#
# 40
# Epoch duration =1.99s
# Cumulative duration =1min 22.0s
#
# 41
# Epoch duration =2.0s
# Cumulative duration =1min 24.0s
#
# 42
# Epoch duration =2.02s
# Cumulative duration =1min 26.019999999999996s
#
# 43
# Epoch duration =2.0s
# Cumulative duration =1min 28.019999999999996s
#
# 44
# Epoch duration =2.01s
# Cumulative duration =1min 30.019999999999996s
#
# 45
# Epoch duration =2.0s
# Cumulative duration =1min 32.019999999999996s
#
# 46
# Epoch duration =1.98s
# Cumulative duration =1min 34.0s
#
# 47
# Epoch duration =2.0s
# Cumulative duration =1min 36.0s
#
# 48
# Epoch duration =2.0s
# Cumulative duration =1min 38.0s
#
# 49
# Epoch duration =2.0s
# Cumulative duration =1min 40.0s
#
# 50
# Epoch duration =2.0s
# Cumulative duration =1min 42.0s
#
# 51
# Epoch duration =1.99s
# Cumulative duration =1min 43.989999999999995s
#
# 52
# Epoch duration =1.99s
# Cumulative duration =1min 45.989999999999995s
#
# 53
# Epoch duration =1.99s
# Cumulative duration =1min 47.989999999999995s
#
# 54
# Epoch duration =1.99s
# Cumulative duration =1min 49.980000000000004s
#
# 55
# Epoch duration =2.0s
# Cumulative duration =1min 51.980000000000004s
#
# 56
# Epoch duration =2.0s
# Cumulative duration =1min 53.980000000000004s
#
# 57
# Epoch duration =2.0s
# Cumulative duration =1min 55.980000000000004s
#
# 58
# Epoch duration =2.01s
# Cumulative duration =1min 57.989999999999995s
#
# 59
# Epoch duration =2.0s
# Cumulative duration =1min 59.980000000000004s
#
# 60
# Epoch duration =2.0s
# Cumulative duration =2min 1.980000000000004s
#
# 61
# Epoch duration =2.0s
# Cumulative duration =2min 3.980000000000004s
#
# 62
# Epoch duration =2.01s
# Cumulative duration =2min 5.989999999999995s
#
# 63
# Epoch duration =2.01s
# Cumulative duration =2min 8.0s
#
# 64
# Epoch duration =2.0s
# Cumulative duration =2min 10.0s
#
# 65
# Epoch duration =2.0s
# Cumulative duration =2min 12.0s
#
# 66
# Epoch duration =2.0s
# Cumulative duration =2min 14.0s
#
# 67
# Epoch duration =2.01s
# Cumulative duration =2min 16.00999999999999s
#
# 68
# Epoch duration =2.0s
# Cumulative duration =2min 18.0s
#
# 69
# Epoch duration =2.01s
# Cumulative duration =2min 20.00999999999999s
#
# 70
# Epoch duration =2.0s
# Cumulative duration =2min 22.00999999999999s
#
# 71
# Epoch duration =2.0s
# Cumulative duration =2min 24.00999999999999s
#
# 72
# Epoch duration =2.0s
# Cumulative duration =2min 26.00999999999999s
#
# 73
# Epoch duration =1.99s
# Cumulative duration =2min 28.0s
#
# 74
# Epoch duration =2.02s
# Cumulative duration =2min 30.02000000000001s
#
# 75
# Epoch duration =2.0s
# Cumulative duration =2min 32.02000000000001s
#
# 76
# Epoch duration =2.0s
# Cumulative duration =2min 34.02000000000001s
#
# 77
# Epoch duration =1.99s
# Cumulative duration =2min 36.00999999999999s
#
# 78
# Epoch duration =1.99s
# Cumulative duration =2min 38.00999999999999s
#
# 79
# Epoch duration =2.01s
# Cumulative duration =2min 40.00999999999999s
#
# 80
# Epoch duration =2.0s
# Cumulative duration =2min 42.02000000000001s
#
# 81
# Epoch duration =2.0s
# Cumulative duration =2min 44.02000000000001s
#
# 82
# Epoch duration =2.0s
# Cumulative duration =2min 46.00999999999999s
#
# 83
# Epoch duration =2.01s
# Cumulative duration =2min 48.02000000000001s
#
# 84
# Epoch duration =2.05s
# Cumulative duration =2min 50.08000000000001s
#
# 85
# Epoch duration =2.0s
# Cumulative duration =2min 52.08000000000001s
#
# 86
# Epoch duration =1.99s
# Cumulative duration =2min 54.06999999999999s
#
# 87
# Epoch duration =2.01s
# Cumulative duration =2min 56.08000000000001s
#
# 88
# Epoch duration =1.99s
# Cumulative duration =2min 58.06999999999999s
#
# 89
# Epoch duration =2.0s
# Cumulative duration =3min 0.06999999999999318s
#
# 90
# Epoch duration =1.99s
# Cumulative duration =3min 2.0600000000000023s
#
# 91
# Epoch duration =1.99s
# Cumulative duration =3min 4.050000000000011s
#
# 92
# Epoch duration =2.0s
# Cumulative duration =3min 6.039999999999992s
#
# 93
# Epoch duration =1.99s
# Cumulative duration =3min 8.039999999999992s
#
# 94
# Epoch duration =1.99s
# Cumulative duration =3min 10.030000000000001s
#
# 95
# Epoch duration =2.01s
# Cumulative duration =3min 12.039999999999992s
#
# 96
# Epoch duration =2.0s
# Cumulative duration =3min 14.039999999999992s
#
# 97
# Epoch duration =2.01s
# Cumulative duration =3min 16.060000000000002s
#
# 98
# Epoch duration =2.02s
# Cumulative duration =3min 18.080000000000013s
#
# 99
# Epoch duration =2.0s
# Cumulative duration =3min 20.080000000000013s
#
# 100
# Epoch duration =2.0s
# Cumulative duration =3min 22.080000000000013s
#
# 101
# Epoch duration =2.0s
# Cumulative duration =3min 24.080000000000013s
#
# 102
# Epoch duration =2.01s
# Cumulative duration =3min 26.090000000000003s
#
# 103
# Epoch duration =2.0s
# Cumulative duration =3min 28.090000000000003s
#
# 104
# Epoch duration =2.0s
# Cumulative duration =3min 30.090000000000003s
#
# 105
# Epoch duration =2.0s
# Cumulative duration =3min 32.099999999999994s
#
# 106
# Epoch duration =2.0s
# Cumulative duration =3min 34.09s
#
# 107
# Epoch duration =2.0s
# Cumulative duration =3min 36.099999999999994s
#
# 108
# Epoch duration =2.0s
# Cumulative duration =3min 38.09s
#
# 109
# Epoch duration =2.0s
# Cumulative duration =3min 40.099999999999994s
#
# 110
# Epoch duration =2.0s
# Cumulative duration =3min 42.099999999999994s
#
# 111
# Epoch duration =2.0s
# Cumulative duration =3min 44.099999999999994s
#
# 112
# Epoch duration =2.0s
# Cumulative duration =3min 46.099999999999994s
#
# 113
# Epoch duration =2.03s
# Cumulative duration =3min 48.129999999999995s
#
# 114
# Epoch duration =2.0s
# Cumulative duration =3min 50.139999999999986s
#
# 115
# Epoch duration =2.0s
# Cumulative duration =3min 52.139999999999986s
#
# 116
# Epoch duration =2.0s
# Cumulative duration =3min 54.139999999999986s
#
# 117
# Epoch duration =2.0s
# Cumulative duration =3min 56.139999999999986s
#
# 118
# Epoch duration =2.0s
# Cumulative duration =3min 58.150000000000006s
#
# 119
# Epoch duration =2.0s
# Cumulative duration =4min 0.15000000000000568s
#
# 120
# Epoch duration =1.99s
# Cumulative duration =4min 2.1399999999999864s
#
# 121
# Epoch duration =1.99s
# Cumulative duration =4min 4.139999999999986s
#
# 122
# Epoch duration =2.04s
# Cumulative duration =4min 6.180000000000007s
#
# 123
# Epoch duration =2.0s
# Cumulative duration =4min 8.180000000000007s
#
# 124
# Epoch duration =2.01s
# Cumulative duration =4min 10.189999999999998s
#
# 125
# Epoch duration =1.99s
# Cumulative duration =4min 12.180000000000007s
#
# 126
# Epoch duration =1.99s
# Cumulative duration =4min 14.180000000000007s
#
# 127
# Epoch duration =2.0s
# Cumulative duration =4min 16.180000000000007s
#
# 128
# Epoch duration =2.0s
# Cumulative duration =4min 18.180000000000007s
#
# 129
# Epoch duration =2.01s
# Cumulative duration =4min 20.189999999999998s
#
# 130
# Epoch duration =2.0s
# Cumulative duration =4min 22.189999999999998s
#
# 131
# Epoch duration =2.0s
# Cumulative duration =4min 24.189999999999998s
#
# 132
# Epoch duration =2.0s
# Cumulative duration =4min 26.189999999999998s
#
# 133
# Epoch duration =2.0s
# Cumulative duration =4min 28.189999999999998s
#
# 134
# Epoch duration =1.99s
# Cumulative duration =4min 30.180000000000007s
#
# 135
# Epoch duration =2.0s
# Cumulative duration =4min 32.19s
#
# 136
# Epoch duration =2.01s
# Cumulative duration =4min 34.19999999999999s
#
# 137
# Epoch duration =1.99s
# Cumulative duration =4min 36.19s
#
# 138
# Epoch duration =2.0s
# Cumulative duration =4min 38.19s
#
# 139
# Epoch duration =2.0s
# Cumulative duration =4min 40.19s
#
# 140
# Epoch duration =2.0s
# Cumulative duration =4min 42.19s
#
# 141
# Epoch duration =2.0s
# Cumulative duration =4min 44.19s
#
# 142
# Epoch duration =2.0s
# Cumulative duration =4min 46.19s
#
# 143
# Epoch duration =2.03s
# Cumulative duration =4min 48.20999999999998s
#
# 144
# Epoch duration =2.01s
# Cumulative duration =4min 50.23000000000002s
#
# 145
# Epoch duration =1.99s
# Cumulative duration =4min 52.22000000000003s
#
# 146
# Epoch duration =2.0s
# Cumulative duration =4min 54.22000000000003s
#
# 147
# Epoch duration =2.01s
# Cumulative duration =4min 56.23000000000002s
#
# 148
# Epoch duration =2.01s
# Cumulative duration =4min 58.24000000000001s
#
# 149
# Epoch duration =2.0s
# Cumulative duration =5min 0.2400000000000091s
#
# 150
# Epoch duration =1.99s
# Cumulative duration =5min 2.230000000000018s
#
# 151
# Epoch duration =2.0s
# Cumulative duration =5min 4.230000000000018s
#
# 152
# Epoch duration =2.01s
# Cumulative duration =5min 6.230000000000018s
#
# 153
# Epoch duration =2.0s
# Cumulative duration =5min 8.240000000000009s
#
# 154
# Epoch duration =2.0s
# Cumulative duration =5min 10.240000000000009s
#
# 155
# Epoch duration =1.99s
# Cumulative duration =5min 12.230000000000018s
#
# 156
# Epoch duration =2.0s
# Cumulative duration =5min 14.220000000000027s
#
# 157
# Epoch duration =1.99s
# Cumulative duration =5min 16.20999999999998s
#
# 158
# Epoch duration =2.01s
# Cumulative duration =5min 18.20999999999998s
#
# 159
# Epoch duration =2.0s
# Cumulative duration =5min 20.20999999999998s
#
# 160
# Epoch duration =1.99s
# Cumulative duration =5min 22.20999999999998s
#
# 161
# Epoch duration =2.01s
# Cumulative duration =5min 24.20999999999998s
#
# 162
# Epoch duration =2.01s
# Cumulative duration =5min 26.220000000000027s
#
# 163
# Epoch duration =2.01s
# Cumulative duration =5min 28.230000000000018s
#
# 164
# Epoch duration =1.99s
# Cumulative duration =5min 30.230000000000018s
#
# 165
# Epoch duration =2.01s
# Cumulative duration =5min 32.24000000000001s
#
# 166
# Epoch duration =2.0s
# Cumulative duration =5min 34.24000000000001s
#
# 167
# Epoch duration =2.0s
# Cumulative duration =5min 36.24000000000001s
#
# 168
# Epoch duration =1.99s
# Cumulative duration =5min 38.23000000000002s
#
# 169
# Epoch duration =2.01s
# Cumulative duration =5min 40.24000000000001s
#
# 170
# Epoch duration =1.99s
# Cumulative duration =5min 42.23000000000002s
#
# 171
# Epoch duration =1.99s
# Cumulative duration =5min 44.23000000000002s
#
# 172
# Epoch duration =2.01s
# Cumulative duration =5min 46.24000000000001s
#
# 173
# Epoch duration =1.99s
# Cumulative duration =5min 48.23000000000002s
#
# 174
# Epoch duration =2.0s
# Cumulative duration =5min 50.24000000000001s
#
# 175
# Epoch duration =1.99s
# Cumulative duration =5min 52.23000000000002s
#
# 176
# Epoch duration =2.01s
# Cumulative duration =5min 54.24000000000001s
#
# 177
# Epoch duration =2.0s
# Cumulative duration =5min 56.24000000000001s
#
# 178
# Epoch duration =2.0s
# Cumulative duration =5min 58.24000000000001s
#
# 179
# Epoch duration =2.01s
# Cumulative duration =6min 0.2400000000000091s
#
# 180
# Epoch duration =2.03s
# Cumulative duration =6min 2.269999999999982s
#
# 181
# Epoch duration =2.01s
# Cumulative duration =6min 4.279999999999973s
#
# 182
# Epoch duration =1.99s
# Cumulative duration =6min 6.269999999999982s
#
# 183
# Epoch duration =2.0s
# Cumulative duration =6min 8.279999999999973s
#
# 184
# Epoch duration =2.0s
# Cumulative duration =6min 10.279999999999973s
#
# 185
# Epoch duration =2.01s
# Cumulative duration =6min 12.29000000000002s
#
# 186
# Epoch duration =2.0s
# Cumulative duration =6min 14.29000000000002s
#
# 187
# Epoch duration =2.0s
# Cumulative duration =6min 16.29000000000002s
#
# 188
# Epoch duration =2.0s
# Cumulative duration =6min 18.29000000000002s
#
# 189
# Epoch duration =2.0s
# Cumulative duration =6min 20.30000000000001s
#
# 190
# Epoch duration =2.02s
# Cumulative duration =6min 22.319999999999993s
#
# 191
# Epoch duration =2.0s
# Cumulative duration =6min 24.319999999999993s
#
# 192
# Epoch duration =1.99s
# Cumulative duration =6min 26.310000000000002s
#
# 193
# Epoch duration =2.0s
# Cumulative duration =6min 28.319999999999993s
#
# 194
# Epoch duration =1.99s
# Cumulative duration =6min 30.310000000000002s
#
# 195
# Epoch duration =2.0s
# Cumulative duration =6min 32.30000000000001s
#
# 196
# Epoch duration =2.01s
# Cumulative duration =6min 34.31s
#
# 197
# Epoch duration =1.99s
# Cumulative duration =6min 36.30000000000001s
#
# 198
# Epoch duration =2.0s
# Cumulative duration =6min 38.30000000000001s
#
# 199
# Epoch duration =2.03s
# Cumulative duration =6min 40.329999999999984s
#
# 200
# Epoch duration =2.0s
# Cumulative duration =6min 42.329999999999984s
#
# 201
# Epoch duration =2.0s
# Cumulative duration =6min 44.31999999999999s
#
# 202
# Epoch duration =2.0s
# Cumulative duration =6min 46.329999999999984s
#
# 203
# Epoch duration =2.02s
# Cumulative duration =6min 48.35000000000002s
#
# 204
# Epoch duration =2.01s
# Cumulative duration =6min 50.360000000000014s
#
# 205
# Epoch duration =2.03s
# Cumulative duration =6min 52.389999999999986s
#
# 206
# Epoch duration =2.02s
# Cumulative duration =6min 54.410000000000025s
#
# 207
# Epoch duration =1.99s
# Cumulative duration =6min 56.39999999999998s
#
# 208
# Epoch duration =2.0s
# Cumulative duration =6min 58.39999999999998s
#
# 209
# Epoch duration =2.0s
# Cumulative duration =7min 0.39999999999997726s
#
# 210
# Epoch duration =2.0s
# Cumulative duration =7min 2.3999999999999773s
#
# 211
# Epoch duration =2.0s
# Cumulative duration =7min 4.399999999999977s
#
# 212
# Epoch duration =2.0s
# Cumulative duration =7min 6.399999999999977s
#
# 213
# Epoch duration =2.01s
# Cumulative duration =7min 8.410000000000025s
#
# 214
# Epoch duration =2.02s
# Cumulative duration =7min 10.420000000000016s
#
# 215
# Epoch duration =2.0s
# Cumulative duration =7min 12.430000000000007s
#
# 216
# Epoch duration =2.02s
# Cumulative duration =7min 14.449999999999989s
#
# 217
# Epoch duration =2.0s
# Cumulative duration =7min 16.44999999999999s
#
# 218
# Epoch duration =2.02s
# Cumulative duration =7min 18.470000000000027s
#
# 219
# Epoch duration =2.01s
# Cumulative duration =7min 20.470000000000027s
#
# 220
# Epoch duration =2.0s
# Cumulative duration =7min 22.470000000000027s
#
# 221
# Epoch duration =2.0s
# Cumulative duration =7min 24.480000000000018s
#
# 222
# Epoch duration =2.01s
# Cumulative duration =7min 26.49000000000001s
#
# 223
# Epoch duration =2.01s
# Cumulative duration =7min 28.50999999999999s
#
# 224
# Epoch duration =2.01s
# Cumulative duration =7min 30.519999999999982s
#
# 225
# Epoch duration =2.02s
# Cumulative duration =7min 32.52999999999997s
#
# 226
# Epoch duration =2.0s
# Cumulative duration =7min 34.52999999999997s
#
# 227
# Epoch duration =2.01s
# Cumulative duration =7min 36.54000000000002s
#
# 228
# Epoch duration =1.99s
# Cumulative duration =7min 38.54000000000002s
#
# 229
# Epoch duration =2.0s
# Cumulative duration =7min 40.54000000000002s
#
# 230
# Epoch duration =2.01s
# Cumulative duration =7min 42.56s
#
# 231
# Epoch duration =2.01s
# Cumulative duration =7min 44.56999999999999s
#
# 232
# Epoch duration =2.0s
# Cumulative duration =7min 46.56s
#
# 233
# Epoch duration =2.0s
# Cumulative duration =7min 48.56s
#
# 234
# Epoch duration =1.99s
# Cumulative duration =7min 50.56s
#
# 235
# Epoch duration =2.01s
# Cumulative duration =7min 52.56999999999999s
#
# 236
# Epoch duration =2.01s
# Cumulative duration =7min 54.579999999999984s
#
# 237
# Epoch duration =2.0s
# Cumulative duration =7min 56.579999999999984s
#
# 238
# Epoch duration =2.01s
# Cumulative duration =7min 58.589999999999975s
#
# 239
# Epoch duration =2.01s
# Cumulative duration =8min 0.6000000000000227s
#
# 240
# Epoch duration =2.0s
# Cumulative duration =8min 2.6000000000000227s
#
# 241
# Epoch duration =2.0s
# Cumulative duration =8min 4.600000000000023s
#
# 242
# Epoch duration =2.0s
# Cumulative duration =8min 6.600000000000023s
#
# 243
# Epoch duration =2.0s
# Cumulative duration =8min 8.600000000000023s
#
# 244
# Epoch duration =2.02s
# Cumulative duration =8min 10.620000000000005s
#
# 245
# Epoch duration =1.99s
# Cumulative duration =8min 12.610000000000014s
#
# 246
# Epoch duration =1.99s
# Cumulative duration =8min 14.600000000000023s
#
# 247
# Epoch duration =2.0s
# Cumulative duration =8min 16.600000000000023s
#
# 248
# Epoch duration =1.99s
# Cumulative duration =8min 18.589999999999975s
#
# 249
# Epoch duration =2.01s
# Cumulative duration =8min 20.600000000000023s
#
# 250
# Epoch duration =2.01s
# Cumulative duration =8min 22.620000000000005s
#
# 251
# Epoch duration =2.01s
# Cumulative duration =8min 24.629999999999995s
#
# 252
# Epoch duration =2.0s
# Cumulative duration =8min 26.629999999999995s
#
# 253
# Epoch duration =1.99s
# Cumulative duration =8min 28.620000000000005s
#
# 254
# Epoch duration =2.0s
# Cumulative duration =8min 30.620000000000005s
#
# 255
# Epoch duration =2.02s
# Cumulative duration =8min 32.629999999999995s
#
# 256
# Epoch duration =2.0s
# Cumulative duration =8min 34.629999999999995s
#
# 257
# Epoch duration =2.0s
# Cumulative duration =8min 36.629999999999995s
#
# 258
# Epoch duration =2.0s
# Cumulative duration =8min 38.629999999999995s
#
# 259
# Epoch duration =2.06s
# Cumulative duration =8min 40.700000000000045s
#
# 260
# Epoch duration =2.01s
# Cumulative duration =8min 42.700000000000045s
#
# 261
# Epoch duration =2.04s
# Cumulative duration =8min 44.74000000000001s
#
# 262
# Epoch duration =2.01s
# Cumulative duration =8min 46.75999999999999s
#
# 263
# Epoch duration =2.01s
# Cumulative duration =8min 48.76999999999998s
#
# 264
# Epoch duration =1.99s
# Cumulative duration =8min 50.75999999999999s
#
# 265
# Epoch duration =1.99s
# Cumulative duration =8min 52.75s
#
# 266
# Epoch duration =1.99s
# Cumulative duration =8min 54.75s
#
# 267
# Epoch duration =2.01s
# Cumulative duration =8min 56.75999999999999s
#
# 268
# Epoch duration =2.01s
# Cumulative duration =8min 58.76999999999998s
#
# 269
# Epoch duration =2.01s
# Cumulative duration =9min 0.7799999999999727s
#
# 270
# Epoch duration =2.0s
# Cumulative duration =9min 2.769999999999982s
#
# 271
# Epoch duration =2.01s
# Cumulative duration =9min 4.779999999999973s
#
# 272
# Epoch duration =2.01s
# Cumulative duration =9min 6.789999999999964s
#
# 273
# Epoch duration =2.0s
# Cumulative duration =9min 8.789999999999964s
#
# 274
# Epoch duration =2.0s
# Cumulative duration =9min 10.789999999999964s
#
# 275
# Epoch duration =2.02s
# Cumulative duration =9min 12.809999999999945s
#
# 276
# Epoch duration =2.0s
# Cumulative duration =9min 14.82000000000005s
#
# 277
# Epoch duration =2.01s
# Cumulative duration =9min 16.83000000000004s
#
# 278
# Epoch duration =2.0s
# Cumulative duration =9min 18.83000000000004s
#
# 279
# Epoch duration =2.01s
# Cumulative duration =9min 20.840000000000032s
#
# 280
# Epoch duration =2.01s
# Cumulative duration =9min 22.850000000000023s
#
# 281
# Epoch duration =2.02s
# Cumulative duration =9min 24.870000000000005s
#
# 282
# Epoch duration =2.01s
# Cumulative duration =9min 26.879999999999995s
#
# 283
# Epoch duration =2.01s
# Cumulative duration =9min 28.899999999999977s
#
# 284
# Epoch duration =1.99s
# Cumulative duration =9min 30.889999999999986s
#
# 285
# Epoch duration =2.03s
# Cumulative duration =9min 32.91999999999996s
#
# 286
# Epoch duration =2.02s
# Cumulative duration =9min 34.940000000000055s
#
# 287
# Epoch duration =2.01s
# Cumulative duration =9min 36.950000000000045s
#
# 288
# Epoch duration =2.0s
# Cumulative duration =9min 38.950000000000045s
#
# 289
# Epoch duration =2.0s
# Cumulative duration =9min 40.950000000000045s
#
# 290
# Epoch duration =1.99s
# Cumulative duration =9min 42.940000000000055s
#
# 291
# Epoch duration =2.0s
# Cumulative duration =9min 44.940000000000055s
#
# 292
# Epoch duration =2.0s
# Cumulative duration =9min 46.940000000000055s
#
# 293
# Epoch duration =1.99s
# Cumulative duration =9min 48.92999999999995s
#
# 294
# Epoch duration =1.99s
# Cumulative duration =9min 50.91999999999996s
#
# 295
# Epoch duration =2.01s
# Cumulative duration =9min 52.92999999999995s
#
# 296
# Epoch duration =2.0s
# Cumulative duration =9min 54.92999999999995s
#
# 297
# Epoch duration =1.99s
# Cumulative duration =9min 56.91999999999996s
#
# 298
# Epoch duration =2.01s
# Cumulative duration =9min 58.92999999999995s
#
# 299
# Epoch duration =2.03s
# Cumulative duration =10min 0.9600000000000364s
#
# 300
# Epoch duration =2.0s
# Cumulative duration =10min 2.9600000000000364s
#
# 301
# Epoch duration =1.99s
# Cumulative duration =10min 4.960000000000036s
#
# 302
# Epoch duration =1.99s
# Cumulative duration =10min 6.9500000000000455s
#
# 303
# Epoch duration =2.0s
# Cumulative duration =10min 8.950000000000045s
#
# 304
# Epoch duration =1.99s
# Cumulative duration =10min 10.950000000000045s
#
# 305
# Epoch duration =1.99s
# Cumulative duration =10min 12.940000000000055s
#
# 306
# Epoch duration =2.0s
# Cumulative duration =10min 14.92999999999995s
#
# 307
# Epoch duration =2.0s
# Cumulative duration =10min 16.92999999999995s
#
# 308
# Epoch duration =2.02s
# Cumulative duration =10min 18.950000000000045s
#
# 309
# Epoch duration =1.99s
# Cumulative duration =10min 20.950000000000045s
#
# 310
# Epoch duration =2.0s
# Cumulative duration =10min 22.950000000000045s
#
# 311
# Epoch duration =1.99s
# Cumulative duration =10min 24.940000000000055s
#
# 312
# Epoch duration =1.99s
# Cumulative duration =10min 26.940000000000055s
#
# 313
# Epoch duration =1.99s
# Cumulative duration =10min 28.92999999999995s
#
# 314
# Epoch duration =2.0s
# Cumulative duration =10min 30.92999999999995s
#
# 315
# Epoch duration =2.01s
# Cumulative duration =10min 32.940000000000055s
#
# 316
# Epoch duration =2.01s
# Cumulative duration =10min 34.940000000000055s
#
# 317
# Epoch duration =2.03s
# Cumulative duration =10min 36.98000000000002s
#
# 318
# Epoch duration =2.01s
# Cumulative duration =10min 38.99000000000001s
#
# 319
# Epoch duration =2.01s
# Cumulative duration =10min 41.0s
#
# 320
# Epoch duration =2.0s
# Cumulative duration =10min 43.0s
#
# 321
# Epoch duration =2.02s
# Cumulative duration =10min 45.01999999999998s
#
# 322
# Epoch duration =2.0s
# Cumulative duration =10min 47.00999999999999s
#
# 323
# Epoch duration =2.0s
# Cumulative duration =10min 49.01999999999998s
#
# 324
# Epoch duration =2.0s
# Cumulative duration =10min 51.01999999999998s
#
# 325
# Epoch duration =2.0s
# Cumulative duration =10min 53.01999999999998s
#
# 326
# Epoch duration =2.0s
# Cumulative duration =10min 55.01999999999998s
#
# 327
# Epoch duration =2.0s
# Cumulative duration =10min 57.01999999999998s
#
# 328
# Epoch duration =2.0s
# Cumulative duration =10min 59.01999999999998s
#
# 329
# Epoch duration =1.99s
# Cumulative duration =11min 1.0199999999999818s
#
# 330
# Epoch duration =2.0s
# Cumulative duration =11min 3.019999999999982s
#
# 331
# Epoch duration =2.02s
# Cumulative duration =11min 5.039999999999964s
#
# 332
# Epoch duration =2.04s
# Cumulative duration =11min 7.07000000000005s
#
# 333
# Epoch duration =1.99s
# Cumulative duration =11min 9.07000000000005s
#
# 334
# Epoch duration =2.0s
# Cumulative duration =11min 11.07000000000005s
#
# 335
# Epoch duration =1.99s
# Cumulative duration =11min 13.07000000000005s
#
# 336
# Epoch duration =2.0s
# Cumulative duration =11min 15.07000000000005s
#
# 337
# Epoch duration =2.0s
# Cumulative duration =11min 17.07000000000005s
#
# 338
# Epoch duration =2.03s
# Cumulative duration =11min 19.100000000000023s
#
# 339
# Epoch duration =2.03s
# Cumulative duration =11min 21.129999999999995s
#
# 340
# Epoch duration =2.01s
# Cumulative duration =11min 23.139999999999986s
#
# 341
# Epoch duration =2.02s
# Cumulative duration =11min 25.159999999999968s
#
# 342
# Epoch duration =1.99s
# Cumulative duration =11min 27.159999999999968s
#
# 343
# Epoch duration =2.0s
# Cumulative duration =11min 29.159999999999968s
#
# 344
# Epoch duration =2.0s
# Cumulative duration =11min 31.159999999999968s
#
# 345
# Epoch duration =1.99s
# Cumulative duration =11min 33.14999999999998s
#
# 346
# Epoch duration =2.0s
# Cumulative duration =11min 35.14999999999998s
#
# 347
# Epoch duration =2.01s
# Cumulative duration =11min 37.15999999999997s
#
# 348
# Epoch duration =2.0s
# Cumulative duration =11min 39.15999999999997s
#
# 349
# Epoch duration =1.99s
# Cumulative duration =11min 41.14999999999998s
#
# 350
# Epoch duration =2.01s
# Cumulative duration =11min 43.15999999999997s
#
# 351
# Epoch duration =2.02s
# Cumulative duration =11min 45.17999999999995s
#
# 352
# Epoch duration =2.02s
# Cumulative duration =11min 47.210000000000036s
#
# 353
# Epoch duration =2.0s
# Cumulative duration =11min 49.200000000000045s
#
# 354
# Epoch duration =2.0s
# Cumulative duration =11min 51.200000000000045s
#
# 355
# Epoch duration =2.0s
# Cumulative duration =11min 53.210000000000036s
#
# 356
# Epoch duration =2.0s
# Cumulative duration =11min 55.210000000000036s
#
# 357
# Epoch duration =2.0s
# Cumulative duration =11min 57.210000000000036s
#
# 358
# Epoch duration =2.01s
# Cumulative duration =11min 59.210000000000036s
#
# 359
# Epoch duration =2.0s
# Cumulative duration =12min 1.2200000000000273s
#
# 360
# Epoch duration =2.01s
# Cumulative duration =12min 3.230000000000018s
#
# 361
# Epoch duration =2.0s
# Cumulative duration =12min 5.220000000000027s
#
# 362
# Epoch duration =2.0s
# Cumulative duration =12min 7.220000000000027s
#
# 363
# Epoch duration =2.01s
# Cumulative duration =12min 9.220000000000027s
#
# 364
# Epoch duration =1.99s
# Cumulative duration =12min 11.220000000000027s
#
# 365
# Epoch duration =2.01s
# Cumulative duration =12min 13.230000000000018s
#
# 366
# Epoch duration =2.03s
# Cumulative duration =12min 15.269999999999982s
#
# 367
# Epoch duration =2.02s
# Cumulative duration =12min 17.279999999999973s
#
# 368
# Epoch duration =2.0s
# Cumulative duration =12min 19.279999999999973s
#
# 369
# Epoch duration =2.0s
# Cumulative duration =12min 21.279999999999973s
#
# 370
# Epoch duration =2.02s
# Cumulative duration =12min 23.299999999999955s
#
# 371
# Epoch duration =2.0s
# Cumulative duration =12min 25.299999999999955s
#
# 372
# Epoch duration =1.99s
# Cumulative duration =12min 27.289999999999964s
#
# 373
# Epoch duration =2.0s
# Cumulative duration =12min 29.289999999999964s
#
# 374
# Epoch duration =2.0s
# Cumulative duration =12min 31.289999999999964s
#
# 375
# Epoch duration =2.0s
# Cumulative duration =12min 33.289999999999964s
#
# 376
# Epoch duration =1.99s
# Cumulative duration =12min 35.289999999999964s
#
# 377
# Epoch duration =2.03s
# Cumulative duration =12min 37.309999999999945s
#
# 378
# Epoch duration =1.99s
# Cumulative duration =12min 39.309999999999945s
#
# 379
# Epoch duration =2.01s
# Cumulative duration =12min 41.32000000000005s
#
# 380
# Epoch duration =1.99s
# Cumulative duration =12min 43.309999999999945s
#
# 381
# Epoch duration =2.0s
# Cumulative duration =12min 45.309999999999945s
#
# 382
# Epoch duration =1.99s
# Cumulative duration =12min 47.309999999999945s
#
# 383
# Epoch duration =2.02s
# Cumulative duration =12min 49.33000000000004s
#
# 384
# Epoch duration =1.99s
# Cumulative duration =12min 51.32000000000005s
#
# 385
# Epoch duration =1.99s
# Cumulative duration =12min 53.32000000000005s
#
# 386
# Epoch duration =2.01s
# Cumulative duration =12min 55.33000000000004s
#
# 387
# Epoch duration =2.0s
# Cumulative duration =12min 57.33000000000004s
#
# 388
# Epoch duration =2.0s
# Cumulative duration =12min 59.33000000000004s
#
# 389
# Epoch duration =1.99s
# Cumulative duration =13min 1.32000000000005s
#
# 390
# Epoch duration =2.01s
# Cumulative duration =13min 3.32000000000005s
#
# 391
# Epoch duration =1.99s
# Cumulative duration =13min 5.309999999999945s
#
# 392
# Epoch duration =2.0s
# Cumulative duration =13min 7.309999999999945s
#
# 393
# Epoch duration =1.99s
# Cumulative duration =13min 9.299999999999955s
#
# 394
# Epoch duration =1.99s
# Cumulative duration =13min 11.289999999999964s
#
# 395
# Epoch duration =2.01s
# Cumulative duration =13min 13.299999999999955s
#
# 396
# Epoch duration =2.0s
# Cumulative duration =13min 15.299999999999955s
#
# 397
# Epoch duration =2.01s
# Cumulative duration =13min 17.309999999999945s
#
# 398
# Epoch duration =2.01s
# Cumulative duration =13min 19.32000000000005s
#
# 399
# Epoch duration =2.01s
# Cumulative duration =13min 21.33000000000004s
#
# 400
# Epoch duration =1.99s
# Cumulative duration =13min 23.33000000000004s
#
# 401
# Epoch duration =2.0s
# Cumulative duration =13min 25.33000000000004s
#
# 402
# Epoch duration =2.01s
# Cumulative duration =13min 27.33000000000004s
#
# 403
# Epoch duration =2.01s
# Cumulative duration =13min 29.340000000000032s
#
# 404
# Epoch duration =1.99s
# Cumulative duration =13min 31.33000000000004s
#
# 405
# Epoch duration =2.0s
# Cumulative duration =13min 33.34000000000003s
#
# 406
# Epoch duration =2.0s
# Cumulative duration =13min 35.33000000000004s
#
# 407
# Epoch duration =2.01s
# Cumulative duration =13min 37.34000000000003s
#
# 408
# Epoch duration =2.0s
# Cumulative duration =13min 39.34000000000003s
#
# 409
# Epoch duration =1.98s
# Cumulative duration =13min 41.33000000000004s
#
# 410
# Epoch duration =2.01s
# Cumulative duration =13min 43.33000000000004s
#
# 411
# Epoch duration =2.01s
# Cumulative duration =13min 45.34000000000003s
#
# 412
# Epoch duration =2.0s
# Cumulative duration =13min 47.34000000000003s
#
# 413
# Epoch duration =2.0s
# Cumulative duration =13min 49.34000000000003s
#
# 414
# Epoch duration =1.99s
# Cumulative duration =13min 51.32000000000005s
#
# 415
# Epoch duration =2.0s
# Cumulative duration =13min 53.32000000000005s
#
# 416
# Epoch duration =2.0s
# Cumulative duration =13min 55.32000000000005s
#
# 417
# Epoch duration =1.99s
# Cumulative duration =13min 57.309999999999945s
#
# 418
# Epoch duration =2.0s
# Cumulative duration =13min 59.309999999999945s
#
# 419
# Epoch duration =1.99s
# Cumulative duration =14min 1.3099999999999454s
#
# 420
# Epoch duration =2.0s
# Cumulative duration =14min 3.3099999999999454s
#
# 421
# Epoch duration =2.0s
# Cumulative duration =14min 5.309999999999945s
#
# 422
# Epoch duration =1.99s
# Cumulative duration =14min 7.2999999999999545s
#
# 423
# Epoch duration =2.01s
# Cumulative duration =14min 9.309999999999945s
#
# 424
# Epoch duration =2.03s
# Cumulative duration =14min 11.340000000000032s
#
# 425
# Epoch duration =2.0s
# Cumulative duration =14min 13.340000000000032s
#
# 426
# Epoch duration =2.02s
# Cumulative duration =14min 15.370000000000005s
#
# 427
# Epoch duration =2.01s
# Cumulative duration =14min 17.370000000000005s
#
# 428
# Epoch duration =2.0s
# Cumulative duration =14min 19.370000000000005s
#
# 429
# Epoch duration =2.0s
# Cumulative duration =14min 21.370000000000005s
#
# 430
# Epoch duration =2.0s
# Cumulative duration =14min 23.370000000000005s
#
# 431
# Epoch duration =2.01s
# Cumulative duration =14min 25.379999999999995s
#
# 432
# Epoch duration =2.0s
# Cumulative duration =14min 27.389999999999986s
#
# 433
# Epoch duration =1.99s
# Cumulative duration =14min 29.379999999999995s
#
# 434
# Epoch duration =1.99s
# Cumulative duration =14min 31.370000000000005s
#
# 435
# Epoch duration =2.0s
# Cumulative duration =14min 33.370000000000005s
#
# 436
# Epoch duration =1.99s
# Cumulative duration =14min 35.360000000000014s
#
# 437
# Epoch duration =1.99s
# Cumulative duration =14min 37.35000000000002s
#
# 438
# Epoch duration =2.0s
# Cumulative duration =14min 39.35000000000002s
#
# 439
# Epoch duration =2.04s
# Cumulative duration =14min 41.379999999999995s
#
# 440
# Epoch duration =2.01s
# Cumulative duration =14min 43.389999999999986s
#
# 441
# Epoch duration =2.0s
# Cumulative duration =14min 45.39999999999998s
#
# 442
# Epoch duration =2.0s
# Cumulative duration =14min 47.39999999999998s
#
# 443
# Epoch duration =2.01s
# Cumulative duration =14min 49.40999999999997s
#
# 444
# Epoch duration =1.99s
# Cumulative duration =14min 51.40999999999997s
#
# 445
# Epoch duration =2.0s
# Cumulative duration =14min 53.40999999999997s
#
# 446
# Epoch duration =2.0s
# Cumulative duration =14min 55.40999999999997s
#
# 447
# Epoch duration =2.01s
# Cumulative duration =14min 57.41999999999996s
#
# 448
# Epoch duration =2.0s
# Cumulative duration =14min 59.41999999999996s
#
# 449
# Epoch duration =2.0s
# Cumulative duration =15min 1.419999999999959s
#
# 450
# Epoch duration =2.01s
# Cumulative duration =15min 3.42999999999995s
#
# 451
# Epoch duration =2.0s
# Cumulative duration =15min 5.42999999999995s
#
# 452
# Epoch duration =2.0s
# Cumulative duration =15min 7.42999999999995s
#
# 453
# Epoch duration =2.06s
# Cumulative duration =15min 9.490000000000009s
#
# 454
# Epoch duration =2.02s
# Cumulative duration =15min 11.519999999999982s
#
# 455
# Epoch duration =2.01s
# Cumulative duration =15min 13.529999999999973s
#
# 456
# Epoch duration =1.99s
# Cumulative duration =15min 15.519999999999982s
#
# 457
# Epoch duration =2.0s
# Cumulative duration =15min 17.519999999999982s
#
# 458
# Epoch duration =2.0s
# Cumulative duration =15min 19.519999999999982s
#
# 459
# Epoch duration =2.02s
# Cumulative duration =15min 21.539999999999964s
#
# 460
# Epoch duration =2.01s
# Cumulative duration =15min 23.549999999999955s
#
# 461
# Epoch duration =2.0s
# Cumulative duration =15min 25.549999999999955s
#
# 462
# Epoch duration =2.0s
# Cumulative duration =15min 27.549999999999955s
#
# 463
# Epoch duration =2.01s
# Cumulative duration =15min 29.549999999999955s
#
# 464
# Epoch duration =2.0s
# Cumulative duration =15min 31.549999999999955s
#
# 465
# Epoch duration =2.02s
# Cumulative duration =15min 33.57000000000005s
#
# 466
# Epoch duration =2.02s
# Cumulative duration =15min 35.59000000000003s
#
# 467
# Epoch duration =2.0s
# Cumulative duration =15min 37.60000000000002s
#
# 468
# Epoch duration =2.0s
# Cumulative duration =15min 39.60000000000002s
#
# 469
# Epoch duration =2.0s
# Cumulative duration =15min 41.60000000000002s
#
# 470
# Epoch duration =2.0s
# Cumulative duration =15min 43.60000000000002s
#
# 471
# Epoch duration =2.01s
# Cumulative duration =15min 45.610000000000014s
#
# 472
# Epoch duration =2.0s
# Cumulative duration =15min 47.610000000000014s
#
# 473
# Epoch duration =2.01s
# Cumulative duration =15min 49.629999999999995s
#
# 474
# Epoch duration =2.03s
# Cumulative duration =15min 51.65999999999997s
#
# 475
# Epoch duration =2.0s
# Cumulative duration =15min 53.65999999999997s
#
# 476
# Epoch duration =2.01s
# Cumulative duration =15min 55.66999999999996s
#
# 477
# Epoch duration =2.0s
# Cumulative duration =15min 57.65999999999997s
#
# 478
# Epoch duration =2.0s
# Cumulative duration =15min 59.65999999999997s
#
# 479
# Epoch duration =2.01s
# Cumulative duration =16min 1.669999999999959s
#
# 480
# Epoch duration =2.0s
# Cumulative duration =16min 3.669999999999959s
#
# 481
# Epoch duration =2.0s
# Cumulative duration =16min 5.669999999999959s
#
# 482
# Epoch duration =2.01s
# Cumulative duration =16min 7.67999999999995s
#
# 483
# Epoch duration =2.02s
# Cumulative duration =16min 9.700000000000045s
#
# 484
# Epoch duration =2.01s
# Cumulative duration =16min 11.710000000000036s
#
# 485
# Epoch duration =2.0s
# Cumulative duration =16min 13.700000000000045s
#
# 486
# Epoch duration =2.01s
# Cumulative duration =16min 15.710000000000036s
#
# 487
# Epoch duration =2.03s
# Cumulative duration =16min 17.74000000000001s
#
# 488
# Epoch duration =2.0s
# Cumulative duration =16min 19.730000000000018s
#
# 489
# Epoch duration =2.01s
# Cumulative duration =16min 21.74000000000001s
#
# 490
# Epoch duration =2.01s
# Cumulative duration =16min 23.75s
#
# 491
# Epoch duration =2.0s
# Cumulative duration =16min 25.75s
#
# 492
# Epoch duration =2.0s
# Cumulative duration =16min 27.75s
#
# 493
# Epoch duration =2.01s
# Cumulative duration =16min 29.75999999999999s
#
# 494
# Epoch duration =2.01s
# Cumulative duration =16min 31.769999999999982s
#
# 495
# Epoch duration =2.02s
# Cumulative duration =16min 33.799999999999955s
#
# 496
# Epoch duration =2.01s
# Cumulative duration =16min 35.809999999999945s
#
# 497
# Epoch duration =2.0s
# Cumulative duration =16min 37.809999999999945s
#
# 498
# Epoch duration =2.0s
# Cumulative duration =16min 39.809999999999945s
#
# 499
# Epoch duration =2.01s
# Cumulative duration =16min 41.82000000000005s
#
# 500
# Epoch duration =2.01s
# Cumulative duration =16min 43.83000000000004s
#
# 501
# Epoch duration =2.02s
# Cumulative duration =16min 45.85000000000002s
#
# 502
# Epoch duration =2.01s
# Cumulative duration =16min 47.85000000000002s
#
# 503
# Epoch duration =2.0s
# Cumulative duration =16min 49.860000000000014s
#
# 504
# Epoch duration =2.0s
# Cumulative duration =16min 51.860000000000014s
#
# 505
# Epoch duration =2.0s
# Cumulative duration =16min 53.85000000000002s
#
# 506
# Epoch duration =2.02s
# Cumulative duration =16min 55.870000000000005s
#
# 507
# Epoch duration =2.01s
# Cumulative duration =16min 57.879999999999995s
#
# 508
# Epoch duration =2.02s
# Cumulative duration =16min 59.90999999999997s
#
# 509
# Epoch duration =2.0s
# Cumulative duration =17min 1.8999999999999773s
#
# 510
# Epoch duration =1.99s
# Cumulative duration =17min 3.8899999999999864s
#
# 511
# Epoch duration =2.01s
# Cumulative duration =17min 5.900000000000091s
#
# 512
# Epoch duration =2.02s
# Cumulative duration =17min 7.920000000000073s
#
# 513
# Epoch duration =2.0s
# Cumulative duration =17min 9.920000000000073s
#
# 514
# Epoch duration =2.0s
# Cumulative duration =17min 11.920000000000073s
#
# 515
# Epoch duration =2.0s
# Cumulative duration =17min 13.920000000000073s
#
# 516
# Epoch duration =2.0s
# Cumulative duration =17min 15.920000000000073s
#
# 517
# Epoch duration =2.0s
# Cumulative duration =17min 17.920000000000073s
#
# 518
# Epoch duration =1.99s
# Cumulative duration =17min 19.910000000000082s
#
# 519
# Epoch duration =2.01s
# Cumulative duration =17min 21.920000000000073s
#
# 520
# Epoch duration =2.01s
# Cumulative duration =17min 23.930000000000064s
#
# 521
# Epoch duration =2.03s
# Cumulative duration =17min 25.960000000000036s
#
# 522
# Epoch duration =2.05s
# Cumulative duration =17min 28.00999999999999s
#
# 523
# Epoch duration =1.99s
# Cumulative duration =17min 30.0s
#
# 524
# Epoch duration =2.0s
# Cumulative duration =17min 32.00999999999999s
#
# 525
# Epoch duration =2.01s
# Cumulative duration =17min 34.01999999999998s
#
# 526
# Epoch duration =2.0s
# Cumulative duration =17min 36.01999999999998s
#
# 527
# Epoch duration =2.02s
# Cumulative duration =17min 38.039999999999964s
#
# 528
# Epoch duration =2.02s
# Cumulative duration =17min 40.059999999999945s
#
# 529
# Epoch duration =2.0s
# Cumulative duration =17min 42.059999999999945s
#
# 530
# Epoch duration =2.05s
# Cumulative duration =17min 44.1099999999999s
#
# 531
# Epoch duration =2.01s
# Cumulative duration =17min 46.11999999999989s
#
# 532
# Epoch duration =2.01s
# Cumulative duration =17min 48.13000000000011s
#
# 533
# Epoch duration =2.0s
# Cumulative duration =17min 50.13000000000011s
#
# 534
# Epoch duration =1.98s
# Cumulative duration =17min 52.1099999999999s
#
# 535
# Epoch duration =2.02s
# Cumulative duration =17min 54.13000000000011s
#
# 536
# Epoch duration =2.01s
# Cumulative duration =17min 56.1400000000001s
#
# 537
# Epoch duration =2.01s
# Cumulative duration =17min 58.1400000000001s
#
# 538
# Epoch duration =2.02s
# Cumulative duration =18min 0.16000000000008185s
#
# 539
# Epoch duration =2.0s
# Cumulative duration =18min 2.160000000000082s
#
# 540
# Epoch duration =1.99s
# Cumulative duration =18min 4.160000000000082s
#
# 541
# Epoch duration =2.0s
# Cumulative duration =18min 6.160000000000082s
#
# 542
# Epoch duration =2.0s
# Cumulative duration =18min 8.160000000000082s
#
# 543
# Epoch duration =2.0s
# Cumulative duration =18min 10.160000000000082s
#
# 544
# Epoch duration =1.99s
# Cumulative duration =18min 12.150000000000091s
#
# 545
# Epoch duration =2.0s
# Cumulative duration =18min 14.160000000000082s
#
# 546
# Epoch duration =2.01s
# Cumulative duration =18min 16.170000000000073s
#
# 547
# Epoch duration =2.0s
# Cumulative duration =18min 18.170000000000073s
#
# 548
# Epoch duration =2.01s
# Cumulative duration =18min 20.180000000000064s
#
# 549
# Epoch duration =2.0s
# Cumulative duration =18min 22.170000000000073s
#
# 550
# Epoch duration =2.0s
# Cumulative duration =18min 24.170000000000073s
#
# 551
# Epoch duration =2.01s
# Cumulative duration =18min 26.180000000000064s
#
# 552
# Epoch duration =2.0s
# Cumulative duration =18min 28.180000000000064s
#
# 553
# Epoch duration =2.01s
# Cumulative duration =18min 30.190000000000055s
#
# 554
# Epoch duration =2.0s
# Cumulative duration =18min 32.190000000000055s
#
# 555
# Epoch duration =2.02s
# Cumulative duration =18min 34.210000000000036s
#
# 556
# Epoch duration =2.03s
# Cumulative duration =18min 36.24000000000001s
#
# 557
# Epoch duration =2.0s
# Cumulative duration =18min 38.24000000000001s
#
# 558
# Epoch duration =2.01s
# Cumulative duration =18min 40.25s
#
# 559
# Epoch duration =2.01s
# Cumulative duration =18min 42.25999999999999s
#
# 560
# Epoch duration =2.01s
# Cumulative duration =18min 44.27999999999997s
#
# 561
# Epoch duration =2.03s
# Cumulative duration =18min 46.309999999999945s
#
# 562
# Epoch duration =2.01s
# Cumulative duration =18min 48.309999999999945s
#
# 563
# Epoch duration =2.01s
# Cumulative duration =18min 50.32999999999993s
#
# 564
# Epoch duration =2.0s
# Cumulative duration =18min 52.32999999999993s
#
# 565
# Epoch duration =2.0s
# Cumulative duration =18min 54.32999999999993s
#
# 566
# Epoch duration =2.01s
# Cumulative duration =18min 56.33999999999992s
#
# 567
# Epoch duration =2.03s
# Cumulative duration =18min 58.3599999999999s
#
# 568
# Epoch duration =2.01s
# Cumulative duration =19min 0.38000000000010914s
#
# 569
# Epoch duration =2.01s
# Cumulative duration =19min 2.3900000000001s
#
# 570
# Epoch duration =2.0s
# Cumulative duration =19min 4.3900000000001s
#
# 571
# Epoch duration =2.0s
# Cumulative duration =19min 6.3900000000001s
#
# 572
# Epoch duration =2.0s
# Cumulative duration =19min 8.3900000000001s
#
# 573
# Epoch duration =2.0s
# Cumulative duration =19min 10.3900000000001s
#
# 574
# Epoch duration =2.0s
# Cumulative duration =19min 12.3900000000001s
#
# 575
# Epoch duration =2.01s
# Cumulative duration =19min 14.3900000000001s
#
# 576
# Epoch duration =1.99s
# Cumulative duration =19min 16.3900000000001s
#
# 577
# Epoch duration =2.0s
# Cumulative duration =19min 18.3900000000001s
#
# 578
# Epoch duration =2.03s
# Cumulative duration =19min 20.420000000000073s
#
# 579
# Epoch duration =2.01s
# Cumulative duration =19min 22.440000000000055s
#
# 580
# Epoch duration =2.0s
# Cumulative duration =19min 24.440000000000055s
#
# 581
# Epoch duration =2.01s
# Cumulative duration =19min 26.450000000000045s
#
# 582
# Epoch duration =2.0s
# Cumulative duration =19min 28.450000000000045s
#
# 583
# Epoch duration =2.0s
# Cumulative duration =19min 30.450000000000045s
#
# 584
# Epoch duration =2.01s
# Cumulative duration =19min 32.460000000000036s
#
# 585
# Epoch duration =2.0s
# Cumulative duration =19min 34.450000000000045s
#
# 586
# Epoch duration =2.0s
# Cumulative duration =19min 36.460000000000036s
#
# 587
# Epoch duration =2.0s
# Cumulative duration =19min 38.450000000000045s
#
# 588
# Epoch duration =2.01s
# Cumulative duration =19min 40.460000000000036s
#
# 589
# Epoch duration =2.03s
# Cumulative duration =19min 42.49000000000001s
#
# 590
# Epoch duration =2.04s
# Cumulative duration =19min 44.52999999999997s
#
# 591
# Epoch duration =2.05s
# Cumulative duration =19min 46.57999999999993s
#
# 592
# Epoch duration =2.0s
# Cumulative duration =19min 48.57999999999993s
#
# 593
# Epoch duration =2.08s
# Cumulative duration =19min 50.65000000000009s
#
# 594
# Epoch duration =2.0s
# Cumulative duration =19min 52.66000000000008s
#
# 595
# Epoch duration =2.0s
# Cumulative duration =19min 54.66000000000008s
#
# 596
# Epoch duration =1.99s
# Cumulative duration =19min 56.65000000000009s
#
# 597
# Epoch duration =2.01s
# Cumulative duration =19min 58.66000000000008s
#
# 598
# Epoch duration =2.01s
# Cumulative duration =20min 0.6700000000000728s
#
# 599
# Epoch duration =2.0s
# Cumulative duration =20min 2.660000000000082s
#
# 600
# Epoch duration =2.0s
# Cumulative duration =20min 4.660000000000082s
#
# 601
# Epoch duration =1.99s
# Cumulative duration =20min 6.660000000000082s
#
# 602
# Epoch duration =1.99s
# Cumulative duration =20min 8.6400000000001s
#
# 603
# Epoch duration =2.0s
# Cumulative duration =20min 10.6400000000001s
#
# 604
# Epoch duration =2.0s
# Cumulative duration =20min 12.6400000000001s
#
# 605
# Epoch duration =2.0s
# Cumulative duration =20min 14.6400000000001s
#
# 606
# Epoch duration =2.01s
# Cumulative duration =20min 16.65000000000009s
#
# 607
# Epoch duration =2.0s
# Cumulative duration =20min 18.65000000000009s
#
# 608
# Epoch duration =2.0s
# Cumulative duration =20min 20.65000000000009s
#
# 609
# Epoch duration =2.01s
# Cumulative duration =20min 22.660000000000082s
#
# 610
# Epoch duration =2.03s
# Cumulative duration =20min 24.690000000000055s
#
# 611
# Epoch duration =2.01s
# Cumulative duration =20min 26.710000000000036s
#
# 612
# Epoch duration =2.02s
# Cumulative duration =20min 28.720000000000027s
#
# 613
# Epoch duration =2.02s
# Cumulative duration =20min 30.74000000000001s
#
# 614
# Epoch duration =2.01s
# Cumulative duration =20min 32.75s
#
# 615
# Epoch duration =2.01s
# Cumulative duration =20min 34.75999999999999s
#
# 616
# Epoch duration =2.0s
# Cumulative duration =20min 36.75999999999999s
#
# 617
# Epoch duration =2.0s
# Cumulative duration =20min 38.75999999999999s
#
# 618
# Epoch duration =2.0s
# Cumulative duration =20min 40.75999999999999s
#
# 619
# Epoch duration =2.04s
# Cumulative duration =20min 42.799999999999955s
#
# 620
# Epoch duration =2.02s
# Cumulative duration =20min 44.819999999999936s
#
# 621
# Epoch duration =1.99s
# Cumulative duration =20min 46.809999999999945s
#
# 622
# Epoch duration =1.99s
# Cumulative duration =20min 48.809999999999945s
#
# 623
# Epoch duration =2.0s
# Cumulative duration =20min 50.799999999999955s
#
# 624
# Epoch duration =1.99s
# Cumulative duration =20min 52.789999999999964s
#
# 625
# Epoch duration =1.99s
# Cumulative duration =20min 54.789999999999964s
#
# 626
# Epoch duration =2.0s
# Cumulative duration =20min 56.789999999999964s
#
# 627
# Epoch duration =2.0s
# Cumulative duration =20min 58.789999999999964s
#
# 628
# Epoch duration =2.01s
# Cumulative duration =21min 0.7999999999999545s
#
# 629
# Epoch duration =2.0s
# Cumulative duration =21min 2.7999999999999545s
#
# 630
# Epoch duration =2.0s
# Cumulative duration =21min 4.789999999999964s
#
# 631
# Epoch duration =2.02s
# Cumulative duration =21min 6.819999999999936s
#
# 632
# Epoch duration =2.0s
# Cumulative duration =21min 8.809999999999945s
#
# 633
# Epoch duration =2.0s
# Cumulative duration =21min 10.809999999999945s
#
# 634
# Epoch duration =2.0s
# Cumulative duration =21min 12.809999999999945s
#
# 635
# Epoch duration =2.03s
# Cumulative duration =21min 14.839999999999918s
#
# 636
# Epoch duration =2.0s
# Cumulative duration =21min 16.829999999999927s
#
# 637
# Epoch duration =2.02s
# Cumulative duration =21min 18.84999999999991s
#
# 638
# Epoch duration =2.01s
# Cumulative duration =21min 20.8599999999999s
#
# 639
# Epoch duration =2.0s
# Cumulative duration =21min 22.8599999999999s
#
# 640
# Epoch duration =2.01s
# Cumulative duration =21min 24.86999999999989s
#
# 641
# Epoch duration =2.0s
# Cumulative duration =21min 26.86999999999989s
#
# 642
# Epoch duration =1.99s
# Cumulative duration =21min 28.8599999999999s
#
# 643
# Epoch duration =2.01s
# Cumulative duration =21min 30.86999999999989s
#
# 644
# Epoch duration =1.99s
# Cumulative duration =21min 32.86999999999989s
#
# 645
# Epoch duration =1.99s
# Cumulative duration =21min 34.8599999999999s
#
# 646
# Epoch duration =1.99s
# Cumulative duration =21min 36.84999999999991s
#
# 647
# Epoch duration =2.04s
# Cumulative duration =21min 38.88000000000011s
#
# 648
# Epoch duration =2.0s
# Cumulative duration =21min 40.88000000000011s
#
# 649
# Epoch duration =2.0s
# Cumulative duration =21min 42.88000000000011s
#
# 650
# Epoch duration =2.0s
# Cumulative duration =21min 44.88000000000011s
#
# 651
# Epoch duration =1.99s
# Cumulative duration =21min 46.86999999999989s
#
# 652
# Epoch duration =2.0s
# Cumulative duration =21min 48.86999999999989s
#
# 653
# Epoch duration =2.01s
# Cumulative duration =21min 50.88000000000011s
#
# 654
# Epoch duration =1.99s
# Cumulative duration =21min 52.86999999999989s
#
# 655
# Epoch duration =2.0s
# Cumulative duration =21min 54.86999999999989s
#
# 656
# Epoch duration =2.01s
# Cumulative duration =21min 56.88000000000011s
#
# 657
# Epoch duration =1.99s
# Cumulative duration =21min 58.86999999999989s
#
# 658
# Epoch duration =2.01s
# Cumulative duration =22min 0.8800000000001091s
#
# 659
# Epoch duration =2.04s
# Cumulative duration =22min 2.9200000000000728s
#
# 660
# Epoch duration =2.01s
# Cumulative duration =22min 4.930000000000064s
#
# 661
# Epoch duration =2.01s
# Cumulative duration =22min 6.940000000000055s
#
# 662
# Epoch duration =2.03s
# Cumulative duration =22min 8.970000000000027s
#
# 663
# Epoch duration =2.0s
# Cumulative duration =22min 10.970000000000027s
#
# 664
# Epoch duration =1.99s
# Cumulative duration =22min 12.960000000000036s
#
# 665
# Epoch duration =2.0s
# Cumulative duration =22min 14.970000000000027s
#
# 666
# Epoch duration =2.01s
# Cumulative duration =22min 16.970000000000027s
#
# 667
# Epoch duration =2.0s
# Cumulative duration =22min 18.970000000000027s
#
# 668
# Epoch duration =2.0s
# Cumulative duration =22min 20.980000000000018s
#
# 669
# Epoch duration =2.0s
# Cumulative duration =22min 22.980000000000018s
#
# 670
# Epoch duration =2.0s
# Cumulative duration =22min 24.980000000000018s
#
# 671
# Epoch duration =2.03s
# Cumulative duration =22min 27.0s
#
# 672
# Epoch duration =2.0s
# Cumulative duration =22min 29.0s
#
# 673
# Epoch duration =2.05s
# Cumulative duration =22min 31.049999999999955s
#
# 674
# Epoch duration =2.01s
# Cumulative duration =22min 33.059999999999945s
#
# 675
# Epoch duration =2.0s
# Cumulative duration =22min 35.059999999999945s
#
# 676
# Epoch duration =2.0s
# Cumulative duration =22min 37.059999999999945s
#
# 677
# Epoch duration =2.0s
# ...
#
# 781
# Epoch duration =2.01s
# Cumulative duration =26min 8.25s
#
# 782
# Epoch duration =2.0s
# Cumulative duration =26min 10.240000000000009s
#
# 783
# Epoch duration =2.01s
# Cumulative duration =26min 12.259999999999991s
#
# 784
# Epoch duration =2.02s
# Cumulative duration =26min 14.279999999999973s
#
# 785
# Epoch duration =2.0s
# Cumulative duration =26min 16.279999999999973s
#
# 786
# Epoch duration =2.0s
# Cumulative duration =26min 18.279999999999973s
#
# 787
# Epoch duration =2.0s
# Cumulative duration =26min 20.279999999999973s
#
# 788
# Epoch duration =1.99s
# Cumulative duration =26min 22.269999999999982s
#
# 789
# Epoch duration =2.01s
# Cumulative duration =26min 24.289999999999964s
#
# 790
# Epoch duration =2.0s
# Cumulative duration =26min 26.289999999999964s
#
# 791
# Epoch duration =2.0s
# Cumulative duration =26min 28.289999999999964s
#
# 792
# Epoch duration =2.0s
# Cumulative duration =26min 30.289999999999964s
#
# 793
# Epoch duration =2.03s
# Cumulative duration =26min 32.319999999999936s
#
# 794
# Epoch duration =1.99s
# Cumulative duration =26min 34.319999999999936s
#
# 795
# Epoch duration =2.0s
# Cumulative duration =26min 36.309999999999945s
#
# 796
# Epoch duration =1.99s
# Cumulative duration =26min 38.299999999999955s
#
# 797
# Epoch duration =2.01s
# Cumulative duration =26min 40.319999999999936s
#
# 798
# Epoch duration =1.99s
# Cumulative duration =26min 42.309999999999945s
#
# 799
# Epoch duration =1.99s
# Cumulative duration =26min 44.299999999999955s
#
# 800
# Epoch duration =2.01s
# Cumulative duration =26min 46.299999999999955s
#
# 801
# Epoch duration =2.0s
# Cumulative duration =26min 48.299999999999955s
#
# 802
# Epoch duration =2.0s
# Cumulative duration =26min 50.299999999999955s
#
# 803
# Epoch duration =2.02s
# Cumulative duration =26min 52.32999999999993s
#
# 804
# Epoch duration =2.0s
# Cumulative duration =26min 54.32999999999993s
#
# 805
# Epoch duration =2.0s
# Cumulative duration =26min 56.32999999999993s
#
# 806
# Epoch duration =2.01s
# Cumulative duration =26min 58.33999999999992s
#
# 807
# Epoch duration =2.0s
# Cumulative duration =27min 0.34999999999990905s
#
# 808
# Epoch duration =1.99s
# Cumulative duration =27min 2.339999999999918s
#
# 809
# Epoch duration =2.01s
# Cumulative duration =27min 4.349999999999909s
#
# 810
# Epoch duration =2.03s
# Cumulative duration =27min 6.380000000000109s
#
# 811
# Epoch duration =2.01s
# Cumulative duration =27min 8.3900000000001s
#
# 812
# Epoch duration =2.01s
# Cumulative duration =27min 10.400000000000091s
#
# 813
# Epoch duration =2.02s
# Cumulative duration =27min 12.420000000000073s
#
# 814
# Epoch duration =2.01s
# Cumulative duration =27min 14.430000000000064s
#
# 815
# Epoch duration =2.0s
# Cumulative duration =27min 16.430000000000064s
#
# 816
# Epoch duration =2.0s
# Cumulative duration =27min 18.430000000000064s
#
# 817
# Epoch duration =2.0s
# Cumulative duration =27min 20.430000000000064s
#
# 818
# Epoch duration =2.01s
# Cumulative duration =27min 22.440000000000055s
#
# 819
# Epoch duration =2.03s
# Cumulative duration =27min 24.470000000000027s
#
# 820
# Epoch duration =2.0s
# Cumulative duration =27min 26.470000000000027s
#
# 821
# Epoch duration =2.0s
# Cumulative duration =27min 28.480000000000018s
#
# 822
# Epoch duration =2.01s
# Cumulative duration =27min 30.49000000000001s
#
# 823
# Epoch duration =2.0s
# Cumulative duration =27min 32.49000000000001s
#
# 824
# Epoch duration =1.99s
# Cumulative duration =27min 34.48000000000002s
#
# 825
# Epoch duration =2.0s
# Cumulative duration =27min 36.49000000000001s
#
# 826
# Epoch duration =2.01s
# Cumulative duration =27min 38.49000000000001s
#
# 827
# Epoch duration =2.01s
# Cumulative duration =27min 40.50999999999999s
#
# 828
# Epoch duration =2.01s
# Cumulative duration =27min 42.51999999999998s
#
# 829
# Epoch duration =2.0s
# Cumulative duration =27min 44.51999999999998s
#
# 830
# Epoch duration =2.0s
# Cumulative duration =27min 46.51999999999998s
#
# 831
# Epoch duration =2.01s
# Cumulative duration =27min 48.52999999999997s
#
# 832
# Epoch duration =1.99s
# Cumulative duration =27min 50.51999999999998s
#
# 833
# Epoch duration =2.0s
# Cumulative duration =27min 52.51999999999998s
#
# 834
# Epoch duration =2.02s
# Cumulative duration =27min 54.539999999999964s
#
# 835
# Epoch duration =2.0s
# Cumulative duration =27min 56.549999999999955s
#
# 836
# Epoch duration =2.0s
# Cumulative duration =27min 58.539999999999964s
#
# 837
# Epoch duration =1.99s
# Cumulative duration =28min 0.5299999999999727s
#
# 838
# Epoch duration =2.01s
# Cumulative duration =28min 2.5399999999999636s
#
# 839
# Epoch duration =2.0s
# Cumulative duration =28min 4.5499999999999545s
#
# 840
# Epoch duration =2.0s
# Cumulative duration =28min 6.5499999999999545s
#
# 841
# Epoch duration =1.99s
# Cumulative duration =28min 8.539999999999964s
#
# 842
# Epoch duration =2.01s
# Cumulative duration =28min 10.539999999999964s
#
# 843
# Epoch duration =2.01s
# Cumulative duration =28min 12.549999999999955s
#
# 844
# Epoch duration =2.0s
# Cumulative duration =28min 14.549999999999955s
#
# 845
# Epoch duration =2.0s
# Cumulative duration =28min 16.559999999999945s
#
# 846
# Epoch duration =2.0s
# Cumulative duration =28min 18.559999999999945s
#
# 847
# Epoch duration =2.01s
# Cumulative duration =28min 20.559999999999945s
#
# 848
# Epoch duration =1.99s
# Cumulative duration =28min 22.549999999999955s
#
# 849
# Epoch duration =2.03s
# Cumulative duration =28min 24.589999999999918s
#
# 850
# Epoch duration =2.01s
# Cumulative duration =28min 26.589999999999918s
#
# 851
# Epoch duration =2.0s
# Cumulative duration =28min 28.59999999999991s
#
# 852
# Epoch duration =2.0s
# Cumulative duration =28min 30.59999999999991s
#
# 853
# Epoch duration =2.0s
# Cumulative duration =28min 32.59999999999991s
#
# 854
# Epoch duration =2.0s
# Cumulative duration =28min 34.59999999999991s
#
# 855
# Epoch duration =2.0s
# Cumulative duration =28min 36.59999999999991s
#
# 856
# Epoch duration =1.99s
# Cumulative duration =28min 38.58999999999992s
#
# 857
# Epoch duration =1.99s
# Cumulative duration =28min 40.58999999999992s
#
# 858
# Epoch duration =2.02s
# Cumulative duration =28min 42.6099999999999s
#
# 859
# Epoch duration =2.06s
# Cumulative duration =28min 44.67000000000007s
#
# 860
# Epoch duration =2.0s
# Cumulative duration =28min 46.67000000000007s
#
# 861
# Epoch duration =2.0s
# Cumulative duration =28min 48.67000000000007s
#
# 862
# Epoch duration =2.0s
# Cumulative duration =28min 50.67000000000007s
#
# 863
# Epoch duration =2.02s
# Cumulative duration =28min 52.690000000000055s
#
# 864
# Epoch duration =2.02s
# Cumulative duration =28min 54.710000000000036s
#
# 865
# Epoch duration =2.02s
# Cumulative duration =28min 56.74000000000001s
#
# 866
# Epoch duration =2.0s
# Cumulative duration =28min 58.74000000000001s
#
# 867
# Epoch duration =1.99s
# Cumulative duration =29min 0.7400000000000091s
#
# 868
# Epoch duration =2.0s
# Cumulative duration =29min 2.730000000000018s
#
# 869
# Epoch duration =2.0s
# Cumulative duration =29min 4.730000000000018s
#
# 870
# Epoch duration =2.0s
# Cumulative duration =29min 6.730000000000018s
#
# 871
# Epoch duration =2.01s
# Cumulative duration =29min 8.740000000000009s
#
# 872
# Epoch duration =2.05s
# Cumulative duration =29min 10.789999999999964s
#
# 873
# Epoch duration =2.01s
# Cumulative duration =29min 12.799999999999955s
#
# 874
# Epoch duration =2.0s
# Cumulative duration =29min 14.799999999999955s
#
# 875
# Epoch duration =2.0s
# Cumulative duration =29min 16.799999999999955s
#
# 876
# Epoch duration =2.03s
# Cumulative duration =29min 18.839999999999918s
#
# 877
# Epoch duration =2.0s
# Cumulative duration =29min 20.839999999999918s
#
# 878
# Epoch duration =2.02s
# Cumulative duration =29min 22.8599999999999s
#
# 879
# Epoch duration =2.01s
# Cumulative duration =29min 24.86999999999989s
#
# 880
# Epoch duration =2.01s
# Cumulative duration =29min 26.88000000000011s
#
# 881
# Epoch duration =2.01s
# Cumulative duration =29min 28.8900000000001s
#
# 882
# Epoch duration =2.05s
# Cumulative duration =29min 30.930000000000064s
#
# 883
# Epoch duration =1.99s
# Cumulative duration =29min 32.92000000000007s
#
# 884
# Epoch duration =1.99s
# Cumulative duration =29min 34.91000000000008s
#
# 885
# Epoch duration =2.0s
# Cumulative duration =29min 36.91000000000008s
#
# 886
# Epoch duration =2.0s
# Cumulative duration =29min 38.91000000000008s
#
# 887
# Epoch duration =2.0s
# Cumulative duration =29min 40.91000000000008s
#
# 888
# Epoch duration =2.0s
# Cumulative duration =29min 42.91000000000008s
#
# 889
# Epoch duration =2.03s
# Cumulative duration =29min 44.940000000000055s
#
# 890
# Epoch duration =2.01s
# Cumulative duration =29min 46.950000000000045s
#
# 891
# Epoch duration =1.99s
# Cumulative duration =29min 48.950000000000045s
#
# 892
# Epoch duration =2.0s
# Cumulative duration =29min 50.940000000000055s
#
# 893
# Epoch duration =1.99s
# Cumulative duration =29min 52.940000000000055s
#
# 894
# Epoch duration =2.0s
# Cumulative duration =29min 54.930000000000064s
#
# 895
# Epoch duration =2.0s
# Cumulative duration =29min 56.930000000000064s
#
# 896
# Epoch duration =2.0s
# Cumulative duration =29min 58.930000000000064s
#
# 897
# Epoch duration =2.01s
# Cumulative duration =30min 0.9400000000000546s
#
# 898
# Epoch duration =2.01s
# Cumulative duration =30min 2.9500000000000455s
#
# 899
# Epoch duration =2.04s
# Cumulative duration =30min 4.990000000000009s
#
# 900
# Epoch duration =2.01s
# Cumulative duration =30min 7.0s
#
# 901
# Epoch duration =2.03s
# Cumulative duration =30min 9.029999999999973s
#
# 902
# Epoch duration =2.0s
# Cumulative duration =30min 11.019999999999982s
#
# 903
# Epoch duration =1.99s
# Cumulative duration =30min 13.019999999999982s
#
# 904
# Epoch duration =1.99s
# Cumulative duration =30min 15.009999999999991s
#
# 905
# Epoch duration =2.07s
# Cumulative duration =30min 17.079999999999927s
#
# 906
# Epoch duration =2.02s
# Cumulative duration =30min 19.09999999999991s
#
# 907
# Epoch duration =2.0s
# Cumulative duration =30min 21.089999999999918s
#
# 908
# Epoch duration =2.01s
# Cumulative duration =30min 23.09999999999991s
#
# 909
# Epoch duration =2.04s
# Cumulative duration =30min 25.1400000000001s
#
# 910
# Epoch duration =2.0s
# Cumulative duration =30min 27.1400000000001s
#
# 911
# Epoch duration =2.0s
# Cumulative duration =30min 29.13000000000011s
#
# 912
# Epoch duration =1.99s
# Cumulative duration =30min 31.11999999999989s
#
# 913
# Epoch duration =2.05s
# Cumulative duration =30min 33.180000000000064s
#
# 914
# Epoch duration =2.01s
# Cumulative duration =30min 35.190000000000055s
#
# 915
# Epoch duration =2.0s
# Cumulative duration =30min 37.190000000000055s
#
# 916
# Epoch duration =2.0s
# Cumulative duration =30min 39.180000000000064s
#
# 917
# Epoch duration =2.0s
# Cumulative duration =30min 41.180000000000064s
#
# 918
# Epoch duration =2.05s
# Cumulative duration =30min 43.23000000000002s
#
# 919
# Epoch duration =2.01s
# Cumulative duration =30min 45.24000000000001s
#
# 920
# Epoch duration =2.01s
# Cumulative duration =30min 47.24000000000001s
#
# 921
# Epoch duration =2.0s
# Cumulative duration =30min 49.24000000000001s
#
# 922
# Epoch duration =2.01s
# Cumulative duration =30min 51.25s
#
# 923
# Epoch duration =2.0s
# Cumulative duration =30min 53.25999999999999s
#
# 924
# Epoch duration =2.0s
# Cumulative duration =30min 55.25s
#
# 925
# Epoch duration =2.0s
# Cumulative duration =30min 57.25999999999999s
#
# 926
# Epoch duration =2.01s
# Cumulative duration =30min 59.26999999999998s
#
# 927
# Epoch duration =2.0s
# Cumulative duration =31min 1.2699999999999818s
#
# 928
# Epoch duration =2.0s
# Cumulative duration =31min 3.269999999999982s
#
# 929
# Epoch duration =2.0s
# Cumulative duration =31min 5.269999999999982s
#
# 930
# Epoch duration =2.01s
# Cumulative duration =31min 7.279999999999973s
#
# 931
# Epoch duration =2.01s
# Cumulative duration =31min 9.289999999999964s
#
# 932
# Epoch duration =2.02s
# Cumulative duration =31min 11.309999999999945s
#
# 933
# Epoch duration =1.99s
# Cumulative duration =31min 13.309999999999945s
#
# 934
# Epoch duration =2.0s
# Cumulative duration =31min 15.299999999999955s
#
# 935
# Epoch duration =1.99s
# Cumulative duration =31min 17.289999999999964s
#
# 936
# Epoch duration =1.99s
# Cumulative duration =31min 19.279999999999973s
#
# 937
# Epoch duration =2.02s
# Cumulative duration =31min 21.309999999999945s
#
# 938
# Epoch duration =2.01s
# Cumulative duration =31min 23.319999999999936s
#
# 939
# Epoch duration =2.0s
# Cumulative duration =31min 25.319999999999936s
#
# 940
# Epoch duration =2.04s
# Cumulative duration =31min 27.3599999999999s
#
# 941
# Epoch duration =2.0s
# Cumulative duration =31min 29.3599999999999s
#
# 942
# Epoch duration =2.0s
# Cumulative duration =31min 31.3599999999999s
#
# 943
# Epoch duration =1.99s
# Cumulative duration =31min 33.34999999999991s
#
# 944
# Epoch duration =2.0s
# Cumulative duration =31min 35.34999999999991s
#
# 945
# Epoch duration =1.99s
# Cumulative duration =31min 37.33999999999992s
#
# 946
# Epoch duration =2.02s
# Cumulative duration =31min 39.3599999999999s
#
# 947
# Epoch duration =2.0s
# Cumulative duration =31min 41.3599999999999s
#
# 948
# Epoch duration =2.0s
# Cumulative duration =31min 43.3599999999999s
#
# 949
# Epoch duration =2.01s
# Cumulative duration =31min 45.38000000000011s
#
# 950
# Epoch duration =2.01s
# Cumulative duration =31min 47.38000000000011s
#
# 951
# Epoch duration =2.0s
# Cumulative duration =31min 49.38000000000011s
#
# 952
# Epoch duration =1.99s
# Cumulative duration =31min 51.38000000000011s
#
# 953
# Epoch duration =1.99s
# Cumulative duration =31min 53.36999999999989s
#
# 954
# Epoch duration =2.01s
# Cumulative duration =31min 55.38000000000011s
#
# 955
# Epoch duration =2.06s
# Cumulative duration =31min 57.450000000000045s
#
# 956
# Epoch duration =2.0s
# Cumulative duration =31min 59.440000000000055s
#
# 957
# Epoch duration =2.0s
# Cumulative duration =32min 1.4400000000000546s
#
# 958
# Epoch duration =2.0s
# Cumulative duration =32min 3.4400000000000546s
#
# 959
# Epoch duration =2.01s
# Cumulative duration =32min 5.4500000000000455s
#
# 960
# Epoch duration =2.0s
# Cumulative duration =32min 7.460000000000036s
#
# 961
# Epoch duration =2.03s
# Cumulative duration =32min 9.490000000000009s
#
# 962
# Epoch duration =2.0s
# Cumulative duration =32min 11.490000000000009s
#
# 963
# Epoch duration =2.03s
# Cumulative duration =32min 13.519999999999982s
#
# 964
# Epoch duration =2.02s
# Cumulative duration =32min 15.539999999999964s
#
# 965
# Epoch duration =2.0s
# Cumulative duration =32min 17.539999999999964s
#
# 966
# Epoch duration =2.0s
# Cumulative duration =32min 19.539999999999964s
#
# 967
# Epoch duration =2.01s
# Cumulative duration =32min 21.549999999999955s
#
# 968
# Epoch duration =1.99s
# Cumulative duration =32min 23.539999999999964s
#
# 969
# Epoch duration =2.01s
# Cumulative duration =32min 25.549999999999955s
#
# 970
# Epoch duration =2.01s
# Cumulative duration =32min 27.559999999999945s
#
# 971
# Epoch duration =2.01s
# Cumulative duration =32min 29.559999999999945s
#
# 972
# Epoch duration =2.04s
# Cumulative duration =32min 31.59999999999991s
#
# 973
# Epoch duration =1.99s
# Cumulative duration =32min 33.58999999999992s
#
# 974
# Epoch duration =2.0s
# Cumulative duration =32min 35.58999999999992s
#
# 975
# Epoch duration =2.02s
# Cumulative duration =32min 37.6099999999999s
#
# 976
# Epoch duration =2.0s
# Cumulative duration =32min 39.59999999999991s
#
# 977
# Epoch duration =2.02s
# Cumulative duration =32min 41.63000000000011s
#
# 978
# Epoch duration =2.01s
# Cumulative duration =32min 43.6400000000001s
#
# 979
# Epoch duration =2.0s
# Cumulative duration =32min 45.6400000000001s
#
# 980
# Epoch duration =2.0s
# Cumulative duration =32min 47.6400000000001s
#
# 981
# Epoch duration =2.0s
# Cumulative duration =32min 49.6400000000001s
#
# 982
# Epoch duration =2.01s
# Cumulative duration =32min 51.65000000000009s
#
# 983
# Epoch duration =2.04s
# Cumulative duration =32min 53.690000000000055s
#
# 984
# Epoch duration =2.03s
# Cumulative duration =32min 55.72000000000003s
#
# 985
# Epoch duration =2.03s
# Cumulative duration =32min 57.75s
#
# 986
# Epoch duration =2.01s
# Cumulative duration =32min 59.75999999999999s
#
# 987
# Epoch duration =1.99s
# Cumulative duration =33min 1.759999999999991s
#
# 988
# Epoch duration =1.99s
# Cumulative duration =33min 3.75s
#
# 989
# Epoch duration =2.0s
# Cumulative duration =33min 5.75s
#
# 990
# Epoch duration =2.01s
# Cumulative duration =33min 7.759999999999991s
#
# 991
# Epoch duration =2.02s
# Cumulative duration =33min 9.779999999999973s
#
# 992
# Epoch duration =2.0s
# Cumulative duration =33min 11.779999999999973s
#
# 993
# Epoch duration =2.01s
# Cumulative duration =33min 13.789999999999964s
#
# 994
# Epoch duration =2.0s
# Cumulative duration =33min 15.789999999999964s
#
# 995
# Epoch duration =2.01s
# Cumulative duration =33min 17.799999999999955s
#
# 996
# Epoch duration =2.01s
# Cumulative duration =33min 19.809999999999945s
#
# 997
# Epoch duration =2.03s
# Cumulative duration =33min 21.839999999999918s
#
# 998
# Epoch duration =2.01s
# Cumulative duration =33min 23.839999999999918s
#
# 999
# Epoch duration =2.03s
# Cumulative duration =33min 25.86999999999989s
#
# Saving scores to Arrays/trna_resbindt3_ug_so1000.npy

# %%
#load values
savepath = 'Arrays/trna_resbindt3_ug_so1000.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='RdPu', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, cmap='RdPu', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
