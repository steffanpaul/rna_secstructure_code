# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/trna_100k_t2.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 1.9s

# %%
simalign_file = '../../../data_RFAM/trnasim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the nested information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((((<<<<>>>><<<<<>>>>><<<<<>>>>>)))))))'

# %%
ugSS
# Out:
# '(((((((,,<<<<_______>>>>,<<<<<_______>>>>>,,,,<<<<<_______>>>>>))))))):'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/trna'
param_path = os.path.join(save_path, 'resbind_t2')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 513, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=11.78s -- loss=0.01281 -- acc=99.72583%
#
#   valid loss:		0.00832
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t2_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=10.98s -- loss=0.00778 -- acc=99.88250%
#
#   valid loss:		0.00727
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t2_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=11.16s -- loss=0.00675 -- acc=99.89583%
#
#   valid loss:		0.00821
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=11.06s -- loss=0.00663 -- acc=99.89833%
#
#   valid loss:		0.00622
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t2_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=10.79s -- loss=0.00641 -- acc=99.91167%
#
#   valid loss:		0.00693
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=10.75s -- loss=0.00669 -- acc=99.92417%
#
#   valid loss:		0.00811
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=10.75s -- loss=0.00662 -- acc=99.93167%
#
#   valid loss:		0.00867
#   valid accuracy:	0.99870+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=10.79s -- loss=0.00658 -- acc=99.93083%
#
#   valid loss:		0.00846
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=10.79s -- loss=0.00713 -- acc=99.93750%
#
#   valid loss:		0.00792
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=10.79s -- loss=0.00679 -- acc=99.95167%
#
#   valid loss:		0.00812
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=10.76s -- loss=0.00679 -- acc=99.94083%
#
#   valid loss:		0.00925
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=10.75s -- loss=0.00697 -- acc=99.94583%
#
#   valid loss:		0.00786
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=10.78s -- loss=0.00689 -- acc=99.94000%
#
#   valid loss:		0.00865
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=10.77s -- loss=0.00653 -- acc=99.95083%
#
#   valid loss:		0.00807
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=10.80s -- loss=0.00652 -- acc=99.95000%
#
#   valid loss:		0.00767
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=10.79s -- loss=0.00581 -- acc=99.97167%
#
#   valid loss:		0.00768
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=10.78s -- loss=0.00592 -- acc=99.96250%
#
#   valid loss:		0.00829
#   valid accuracy:	0.99900+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=10.80s -- loss=0.00625 -- acc=99.95750%
#
#   valid loss:		0.00787
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=10.79s -- loss=0.00568 -- acc=99.96917%
#
#   valid loss:		0.00792
#   valid accuracy:	0.99890+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=10.77s -- loss=0.00595 -- acc=99.95667%
#
#   valid loss:		0.00731
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=10.80s -- loss=0.00556 -- acc=99.96417%
#
#   valid loss:		0.00707
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=10.82s -- loss=0.00537 -- acc=99.96583%
#
#   valid loss:		0.00728
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=10.76s -- loss=0.00544 -- acc=99.96250%
#
#   valid loss:		0.00687
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=10.78s -- loss=0.00517 -- acc=99.96500%
#
#   valid loss:		0.00753
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=10.85s -- loss=0.00530 -- acc=99.96250%
#
#   valid loss:		0.00796
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=10.81s -- loss=0.00538 -- acc=99.96333%
#
#   valid loss:		0.00714
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=10.85s -- loss=0.00499 -- acc=99.97333%
#
#   valid loss:		0.00678
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=10.86s -- loss=0.00545 -- acc=99.95750%
#
#   valid loss:		0.00808
#   valid accuracy:	0.99905+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=10.85s -- loss=0.00490 -- acc=99.97750%
#
#   valid loss:		0.00815
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=10.89s -- loss=0.00539 -- acc=99.96083%
#
#   valid loss:		0.00661
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=10.82s -- loss=0.00470 -- acc=99.97750%
#
#   valid loss:		0.00657
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.00428 -- acc=99.98417%
#
#   valid loss:		0.00659
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=10.89s -- loss=0.00493 -- acc=99.95917%
#
#   valid loss:		0.00786
#   valid accuracy:	0.99920+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=11.03s -- loss=0.00442 -- acc=99.97750%
#
#   valid loss:		0.00716
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/trna/resbind_t2_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/trna/resbind_t2_best.ckpt
#   test  loss:		0.00579
#   test  accuracy:	0.99937+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

plt.figure()
plt.ylabel('Predicted score')
plt.xlabel('Sequences ordered by score')
plt.plot(range(len(plot_index)), predictionsoutput[plot_index])
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/trna_resbindt2_ug_so500.npy'

num_summary = 500
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =2.04s
# Cumulative duration =2.04s
#
# 1
# Epoch duration =2.01s
# Cumulative duration =4.06s
#
# 2
# Epoch duration =2.0s
# Cumulative duration =6.05s
#
# 3
# Epoch duration =1.99s
# Cumulative duration =8.05s
#
# 4
# Epoch duration =2.01s
# Cumulative duration =10.06s
#
# 5
# Epoch duration =2.03s
# Cumulative duration =12.09s
#
# 6
# Epoch duration =2.01s
# Cumulative duration =14.09s
#
# 7
# Epoch duration =2.0s
# Cumulative duration =16.09s
#
# 8
# Epoch duration =1.99s
# Cumulative duration =18.09s
#
# 9
# Epoch duration =2.0s
# Cumulative duration =20.09s
#
# 10
# Epoch duration =1.99s
# Cumulative duration =22.08s
#
# 11
# Epoch duration =2.0s
# Cumulative duration =24.08s
#
# 12
# Epoch duration =2.01s
# Cumulative duration =26.09s
#
# 13
# Epoch duration =2.01s
# Cumulative duration =28.1s
#
# 14
# Epoch duration =2.0s
# Cumulative duration =30.11s
#
# 15
# Epoch duration =2.0s
# Cumulative duration =32.11s
#
# 16
# Epoch duration =2.07s
# Cumulative duration =34.18s
#
# 17
# Epoch duration =2.02s
# Cumulative duration =36.2s
#
# 18
# Epoch duration =2.01s
# Cumulative duration =38.21s
#
# 19
# Epoch duration =2.0s
# Cumulative duration =40.21s
#
# 20
# Epoch duration =1.99s
# Cumulative duration =42.2s
#
# 21
# Epoch duration =2.02s
# Cumulative duration =44.22s
#
# 22
# Epoch duration =2.0s
# Cumulative duration =46.22s
#
# 23
# Epoch duration =2.0s
# Cumulative duration =48.22s
#
# 24
# Epoch duration =2.01s
# Cumulative duration =50.24s
#
# 25
# Epoch duration =2.01s
# Cumulative duration =52.25s
#
# 26
# Epoch duration =2.03s
# Cumulative duration =54.28s
#
# 27
# Epoch duration =2.01s
# Cumulative duration =56.29s
#
# 28
# Epoch duration =2.03s
# Cumulative duration =58.32s
#
# 29
# Epoch duration =2.02s
# Cumulative duration =1min 0.3400000000000034s
#
# 30
# Epoch duration =2.0s
# Cumulative duration =1min 2.3400000000000034s
#
# 31
# Epoch duration =2.01s
# Cumulative duration =1min 4.349999999999994s
#
# 32
# Epoch duration =2.01s
# Cumulative duration =1min 6.349999999999994s
#
# 33
# Epoch duration =2.01s
# Cumulative duration =1min 8.370000000000005s
#
# 34
# Epoch duration =2.06s
# Cumulative duration =1min 10.430000000000007s
#
# 35
# Epoch duration =2.01s
# Cumulative duration =1min 12.439999999999998s
#
# 36
# Epoch duration =2.02s
# Cumulative duration =1min 14.459999999999994s
#
# 37
# Epoch duration =2.01s
# Cumulative duration =1min 16.47s
#
# 38
# Epoch duration =2.01s
# Cumulative duration =1min 18.47s
#
# 39
# Epoch duration =2.03s
# Cumulative duration =1min 20.510000000000005s
#
# 40
# Epoch duration =2.01s
# Cumulative duration =1min 22.519999999999996s
#
# 41
# Epoch duration =2.01s
# Cumulative duration =1min 24.53s
#
# 42
# Epoch duration =2.0s
# Cumulative duration =1min 26.53s
#
# 43
# Epoch duration =2.0s
# Cumulative duration =1min 28.53s
#
# 44
# Epoch duration =2.01s
# Cumulative duration =1min 30.549999999999997s
#
# 45
# Epoch duration =2.02s
# Cumulative duration =1min 32.56999999999999s
#
# 46
# Epoch duration =2.01s
# Cumulative duration =1min 34.58s
#
# 47
# Epoch duration =2.0s
# Cumulative duration =1min 36.58s
#
# 48
# Epoch duration =2.01s
# Cumulative duration =1min 38.599999999999994s
#
# 49
# Epoch duration =2.01s
# Cumulative duration =1min 40.599999999999994s
#
# 50
# Epoch duration =2.02s
# Cumulative duration =1min 42.620000000000005s
#
# 51
# Epoch duration =2.01s
# Cumulative duration =1min 44.629999999999995s
#
# 52
# Epoch duration =2.01s
# Cumulative duration =1min 46.650000000000006s
#
# 53
# Epoch duration =2.01s
# Cumulative duration =1min 48.66s
#
# 54
# Epoch duration =2.01s
# Cumulative duration =1min 50.67s
#
# 55
# Epoch duration =2.01s
# Cumulative duration =1min 52.67s
#
# 56
# Epoch duration =1.99s
# Cumulative duration =1min 54.67s
#
# 57
# Epoch duration =2.02s
# Cumulative duration =1min 56.68000000000001s
#
# 58
# Epoch duration =2.01s
# Cumulative duration =1min 58.69s
#
# 59
# Epoch duration =2.01s
# Cumulative duration =2min 0.7000000000000028s
#
# 60
# Epoch duration =2.02s
# Cumulative duration =2min 2.719999999999999s
#
# 61
# Epoch duration =2.02s
# Cumulative duration =2min 4.739999999999995s
#
# 62
# Epoch duration =2.03s
# Cumulative duration =2min 6.769999999999996s
#
# 63
# Epoch duration =2.0s
# Cumulative duration =2min 8.780000000000001s
#
# 64
# Epoch duration =2.0s
# Cumulative duration =2min 10.780000000000001s
#
# 65
# Epoch duration =2.01s
# Cumulative duration =2min 12.789999999999992s
#
# 66
# Epoch duration =2.0s
# Cumulative duration =2min 14.780000000000001s
#
# 67
# Epoch duration =2.0s
# Cumulative duration =2min 16.789999999999992s
#
# 68
# Epoch duration =2.01s
# Cumulative duration =2min 18.80000000000001s
#
# 69
# Epoch duration =2.02s
# Cumulative duration =2min 20.819999999999993s
#
# 70
# Epoch duration =2.01s
# Cumulative duration =2min 22.830000000000013s
#
# 71
# Epoch duration =1.99s
# Cumulative duration =2min 24.819999999999993s
#
# 72
# Epoch duration =2.01s
# Cumulative duration =2min 26.830000000000013s
#
# 73
# Epoch duration =2.01s
# Cumulative duration =2min 28.840000000000003s
#
# 74
# Epoch duration =2.01s
# Cumulative duration =2min 30.840000000000003s
#
# 75
# Epoch duration =2.01s
# Cumulative duration =2min 32.860000000000014s
#
# 76
# Epoch duration =2.01s
# Cumulative duration =2min 34.870000000000005s
#
# 77
# Epoch duration =2.03s
# Cumulative duration =2min 36.900000000000006s
#
# 78
# Epoch duration =2.01s
# Cumulative duration =2min 38.91s
#
# 79
# Epoch duration =2.01s
# Cumulative duration =2min 40.91999999999999s
#
# 80
# Epoch duration =2.0s
# Cumulative duration =2min 42.91999999999999s
#
# 81
# Epoch duration =2.01s
# Cumulative duration =2min 44.94s
#
# 82
# Epoch duration =2.0s
# Cumulative duration =2min 46.94s
#
# 83
# Epoch duration =2.01s
# Cumulative duration =2min 48.94999999999999s
#
# 84
# Epoch duration =2.02s
# Cumulative duration =2min 50.97s
#
# 85
# Epoch duration =2.01s
# Cumulative duration =2min 52.99000000000001s
#
# 86
# Epoch duration =2.0s
# Cumulative duration =2min 54.97999999999999s
#
# 87
# Epoch duration =2.02s
# Cumulative duration =2min 57.0s
#
# 88
# Epoch duration =2.01s
# Cumulative duration =2min 59.00999999999999s
#
# 89
# Epoch duration =2.01s
# Cumulative duration =3min 1.0200000000000102s
#
# 90
# Epoch duration =2.0s
# Cumulative duration =3min 3.0200000000000102s
#
# 91
# Epoch duration =2.0s
# Cumulative duration =3min 5.030000000000001s
#
# 92
# Epoch duration =2.0s
# Cumulative duration =3min 7.030000000000001s
#
# 93
# Epoch duration =2.01s
# Cumulative duration =3min 9.030000000000001s
#
# 94
# Epoch duration =2.0s
# Cumulative duration =3min 11.030000000000001s
#
# 95
# Epoch duration =2.0s
# Cumulative duration =3min 13.030000000000001s
#
# 96
# Epoch duration =2.03s
# Cumulative duration =3min 15.060000000000002s
#
# 97
# Epoch duration =2.01s
# Cumulative duration =3min 17.060000000000002s
#
# 98
# Epoch duration =2.02s
# Cumulative duration =3min 19.080000000000013s
#
# 99
# Epoch duration =1.99s
# Cumulative duration =3min 21.080000000000013s
#
# 100
# Epoch duration =2.0s
# Cumulative duration =3min 23.080000000000013s
#
# 101
# Epoch duration =2.02s
# Cumulative duration =3min 25.099999999999994s
#
# 102
# Epoch duration =2.01s
# Cumulative duration =3min 27.099999999999994s
#
# 103
# Epoch duration =2.0s
# Cumulative duration =3min 29.099999999999994s
#
# 104
# Epoch duration =2.0s
# Cumulative duration =3min 31.099999999999994s
#
# 105
# Epoch duration =2.01s
# Cumulative duration =3min 33.110000000000014s
#
# 106
# Epoch duration =2.01s
# Cumulative duration =3min 35.120000000000005s
#
# 107
# Epoch duration =2.02s
# Cumulative duration =3min 37.139999999999986s
#
# 108
# Epoch duration =2.01s
# Cumulative duration =3min 39.150000000000006s
#
# 109
# Epoch duration =2.01s
# Cumulative duration =3min 41.16s
#
# 110
# Epoch duration =2.01s
# Cumulative duration =3min 43.18000000000001s
#
# 111
# Epoch duration =2.01s
# Cumulative duration =3min 45.19s
#
# 112
# Epoch duration =2.02s
# Cumulative duration =3min 47.21000000000001s
#
# 113
# Epoch duration =2.01s
# Cumulative duration =3min 49.22s
#
# 114
# Epoch duration =2.0s
# Cumulative duration =3min 51.22s
#
# 115
# Epoch duration =2.01s
# Cumulative duration =3min 53.22999999999999s
#
# 116
# Epoch duration =2.0s
# Cumulative duration =3min 55.22999999999999s
#
# 117
# Epoch duration =2.01s
# Cumulative duration =3min 57.24000000000001s
#
# 118
# Epoch duration =2.02s
# Cumulative duration =3min 59.27000000000001s
#
# 119
# Epoch duration =2.02s
# Cumulative duration =4min 1.289999999999992s
#
# 120
# Epoch duration =2.01s
# Cumulative duration =4min 3.3000000000000114s
#
# 121
# Epoch duration =2.01s
# Cumulative duration =4min 5.300000000000011s
#
# 122
# Epoch duration =2.0s
# Cumulative duration =4min 7.300000000000011s
#
# 123
# Epoch duration =2.0s
# Cumulative duration =4min 9.310000000000002s
#
# 124
# Epoch duration =2.01s
# Cumulative duration =4min 11.319999999999993s
#
# 125
# Epoch duration =2.01s
# Cumulative duration =4min 13.340000000000003s
#
# 126
# Epoch duration =2.01s
# Cumulative duration =4min 15.340000000000003s
#
# 127
# Epoch duration =2.01s
# Cumulative duration =4min 17.350000000000023s
#
# 128
# Epoch duration =2.02s
# Cumulative duration =4min 19.360000000000014s
#
# 129
# Epoch duration =2.03s
# Cumulative duration =4min 21.389999999999986s
#
# 130
# Epoch duration =2.04s
# Cumulative duration =4min 23.430000000000007s
#
# 131
# Epoch duration =2.02s
# Cumulative duration =4min 25.44999999999999s
#
# 132
# Epoch duration =2.01s
# Cumulative duration =4min 27.45999999999998s
#
# 133
# Epoch duration =2.02s
# Cumulative duration =4min 29.480000000000018s
#
# 134
# Epoch duration =2.01s
# Cumulative duration =4min 31.49000000000001s
#
# 135
# Epoch duration =2.02s
# Cumulative duration =4min 33.51999999999998s
#
# 136
# Epoch duration =2.01s
# Cumulative duration =4min 35.51999999999998s
#
# 137
# Epoch duration =2.02s
# Cumulative duration =4min 37.54000000000002s
#
# 138
# Epoch duration =2.01s
# Cumulative duration =4min 39.56s
#
# 139
# Epoch duration =2.01s
# Cumulative duration =4min 41.56999999999999s
#
# 140
# Epoch duration =2.0s
# Cumulative duration =4min 43.56999999999999s
#
# 141
# Epoch duration =2.01s
# Cumulative duration =4min 45.579999999999984s
#
# 142
# Epoch duration =2.01s
# Cumulative duration =4min 47.589999999999975s
#
# 143
# Epoch duration =2.01s
# Cumulative duration =4min 49.60000000000002s
#
# 144
# Epoch duration =2.02s
# Cumulative duration =4min 51.620000000000005s
#
# 145
# Epoch duration =2.02s
# Cumulative duration =4min 53.639999999999986s
#
# 146
# Epoch duration =2.01s
# Cumulative duration =4min 55.64999999999998s
#
# 147
# Epoch duration =2.02s
# Cumulative duration =4min 57.670000000000016s
#
# 148
# Epoch duration =2.01s
# Cumulative duration =4min 59.68000000000001s
#
# 149
# Epoch duration =2.01s
# Cumulative duration =5min 1.6899999999999977s
#
# 150
# Epoch duration =2.0s
# Cumulative duration =5min 3.6899999999999977s
#
# 151
# Epoch duration =2.03s
# Cumulative duration =5min 5.720000000000027s
#
# 152
# Epoch duration =2.01s
# Cumulative duration =5min 7.730000000000018s
#
# 153
# Epoch duration =2.01s
# Cumulative duration =5min 9.740000000000009s
#
# 154
# Epoch duration =2.01s
# Cumulative duration =5min 11.75s
#
# 155
# Epoch duration =2.0s
# Cumulative duration =5min 13.75s
#
# 156
# Epoch duration =2.02s
# Cumulative duration =5min 15.769999999999982s
#
# 157
# Epoch duration =2.02s
# Cumulative duration =5min 17.779999999999973s
#
# 158
# Epoch duration =2.01s
# Cumulative duration =5min 19.79000000000002s
#
# 159
# Epoch duration =2.01s
# Cumulative duration =5min 21.80000000000001s
#
# 160
# Epoch duration =2.01s
# Cumulative duration =5min 23.819999999999993s
#
# 161
# Epoch duration =2.0s
# Cumulative duration =5min 25.819999999999993s
#
# 162
# Epoch duration =2.0s
# Cumulative duration =5min 27.819999999999993s
#
# 163
# Epoch duration =2.01s
# Cumulative duration =5min 29.829999999999984s
#
# 164
# Epoch duration =2.02s
# Cumulative duration =5min 31.850000000000023s
#
# 165
# Epoch duration =2.02s
# Cumulative duration =5min 33.870000000000005s
#
# 166
# Epoch duration =2.01s
# Cumulative duration =5min 35.879999999999995s
#
# 167
# Epoch duration =2.0s
# Cumulative duration =5min 37.879999999999995s
#
# 168
# Epoch duration =2.02s
# Cumulative duration =5min 39.910000000000025s
#
# 169
# Epoch duration =2.02s
# Cumulative duration =5min 41.920000000000016s
#
# 170
# Epoch duration =2.0s
# Cumulative duration =5min 43.920000000000016s
#
# 171
# Epoch duration =2.0s
# Cumulative duration =5min 45.920000000000016s
#
# 172
# Epoch duration =2.01s
# Cumulative duration =5min 47.93000000000001s
#
# 173
# Epoch duration =2.01s
# Cumulative duration =5min 49.94s
#
# 174
# Epoch duration =2.02s
# Cumulative duration =5min 51.95999999999998s
#
# 175
# Epoch duration =2.01s
# Cumulative duration =5min 53.97000000000003s
#
# 176
# Epoch duration =2.03s
# Cumulative duration =5min 56.0s
#
# 177
# Epoch duration =2.02s
# Cumulative duration =5min 58.01999999999998s
#
# 178
# Epoch duration =2.05s
# Cumulative duration =6min 0.06999999999999318s
#
# 179
# Epoch duration =2.0s
# Cumulative duration =6min 2.079999999999984s
#
# 180
# Epoch duration =2.02s
# Cumulative duration =6min 4.089999999999975s
#
# 181
# Epoch duration =2.0s
# Cumulative duration =6min 6.089999999999975s
#
# 182
# Epoch duration =2.02s
# Cumulative duration =6min 8.110000000000014s
#
# 183
# Epoch duration =2.0s
# Cumulative duration =6min 10.110000000000014s
#
# 184
# Epoch duration =2.01s
# Cumulative duration =6min 12.120000000000005s
#
# 185
# Epoch duration =2.04s
# Cumulative duration =6min 14.160000000000025s
#
# 186
# Epoch duration =2.0s
# Cumulative duration =6min 16.170000000000016s
#
# 187
# Epoch duration =2.01s
# Cumulative duration =6min 18.170000000000016s
#
# 188
# Epoch duration =2.01s
# Cumulative duration =6min 20.180000000000007s
#
# 189
# Epoch duration =2.0s
# Cumulative duration =6min 22.180000000000007s
#
# 190
# Epoch duration =2.01s
# Cumulative duration =6min 24.19999999999999s
#
# 191
# Epoch duration =2.0s
# Cumulative duration =6min 26.19999999999999s
#
# 192
# Epoch duration =2.01s
# Cumulative duration =6min 28.19999999999999s
#
# 193
# Epoch duration =2.01s
# Cumulative duration =6min 30.220000000000027s
#
# 194
# Epoch duration =2.01s
# Cumulative duration =6min 32.22000000000003s
#
# 195
# Epoch duration =2.02s
# Cumulative duration =6min 34.25s
#
# 196
# Epoch duration =2.0s
# Cumulative duration =6min 36.25s
#
# 197
# Epoch duration =2.02s
# Cumulative duration =6min 38.26999999999998s
#
# 198
# Epoch duration =2.0s
# Cumulative duration =6min 40.27999999999997s
#
# 199
# Epoch duration =2.0s
# Cumulative duration =6min 42.26999999999998s
#
# 200
# Epoch duration =2.0s
# Cumulative duration =6min 44.26999999999998s
#
# 201
# Epoch duration =2.04s
# Cumulative duration =6min 46.31s
#
# 202
# Epoch duration =2.0s
# Cumulative duration =6min 48.31999999999999s
#
# 203
# Epoch duration =2.01s
# Cumulative duration =6min 50.329999999999984s
#
# 204
# Epoch duration =2.02s
# Cumulative duration =6min 52.35000000000002s
#
# 205
# Epoch duration =2.0s
# Cumulative duration =6min 54.35000000000002s
#
# 206
# Epoch duration =2.03s
# Cumulative duration =6min 56.379999999999995s
#
# 207
# Epoch duration =2.0s
# Cumulative duration =6min 58.379999999999995s
#
# 208
# Epoch duration =2.02s
# Cumulative duration =7min 0.39999999999997726s
#
# 209
# Epoch duration =2.01s
# Cumulative duration =7min 2.410000000000025s
#
# 210
# Epoch duration =2.02s
# Cumulative duration =7min 4.430000000000007s
#
# 211
# Epoch duration =2.0s
# Cumulative duration =7min 6.430000000000007s
#
# 212
# Epoch duration =2.01s
# Cumulative duration =7min 8.439999999999998s
#
# 213
# Epoch duration =2.02s
# Cumulative duration =7min 10.45999999999998s
#
# 214
# Epoch duration =2.01s
# Cumulative duration =7min 12.470000000000027s
#
# 215
# Epoch duration =2.0s
# Cumulative duration =7min 14.470000000000027s
#
# 216
# Epoch duration =2.01s
# Cumulative duration =7min 16.480000000000018s
#
# 217
# Epoch duration =2.02s
# Cumulative duration =7min 18.5s
#
# 218
# Epoch duration =2.0s
# Cumulative duration =7min 20.5s
#
# 219
# Epoch duration =2.01s
# Cumulative duration =7min 22.50999999999999s
#
# 220
# Epoch duration =2.01s
# Cumulative duration =7min 24.519999999999982s
#
# 221
# Epoch duration =2.06s
# Cumulative duration =7min 26.569999999999993s
#
# 222
# Epoch duration =2.01s
# Cumulative duration =7min 28.579999999999984s
#
# 223
# Epoch duration =2.02s
# Cumulative duration =7min 30.600000000000023s
#
# 224
# Epoch duration =2.01s
# Cumulative duration =7min 32.620000000000005s
#
# 225
# Epoch duration =2.01s
# Cumulative duration =7min 34.620000000000005s
#
# 226
# Epoch duration =2.02s
# Cumulative duration =7min 36.639999999999986s
#
# 227
# Epoch duration =2.01s
# Cumulative duration =7min 38.64999999999998s
#
# 228
# Epoch duration =2.03s
# Cumulative duration =7min 40.68000000000001s
#
# 229
# Epoch duration =2.02s
# Cumulative duration =7min 42.69999999999999s
#
# 230
# Epoch duration =2.01s
# Cumulative duration =7min 44.70999999999998s
#
# 231
# Epoch duration =2.01s
# Cumulative duration =7min 46.72000000000003s
#
# 232
# Epoch duration =2.01s
# Cumulative duration =7min 48.73000000000002s
#
# 233
# Epoch duration =2.02s
# Cumulative duration =7min 50.75s
#
# 234
# Epoch duration =2.03s
# Cumulative duration =7min 52.77999999999997s
#
# 235
# Epoch duration =1.99s
# Cumulative duration =7min 54.77999999999997s
#
# 236
# Epoch duration =2.02s
# Cumulative duration =7min 56.79000000000002s
#
# 237
# Epoch duration =2.03s
# Cumulative duration =7min 58.829999999999984s
#
# 238
# Epoch duration =2.02s
# Cumulative duration =8min 0.8500000000000227s
#
# 239
# Epoch duration =2.02s
# Cumulative duration =8min 2.8600000000000136s
#
# 240
# Epoch duration =2.01s
# Cumulative duration =8min 4.8700000000000045s
#
# 241
# Epoch duration =2.02s
# Cumulative duration =8min 6.899999999999977s
#
# 242
# Epoch duration =2.0s
# Cumulative duration =8min 8.899999999999977s
#
# 243
# Epoch duration =2.0s
# Cumulative duration =8min 10.899999999999977s
#
# 244
# Epoch duration =2.01s
# Cumulative duration =8min 12.910000000000025s
#
# 245
# Epoch duration =2.0s
# Cumulative duration =8min 14.910000000000025s
#
# 246
# Epoch duration =1.99s
# Cumulative duration =8min 16.899999999999977s
#
# 247
# Epoch duration =2.0s
# Cumulative duration =8min 18.899999999999977s
#
# 248
# Epoch duration =2.01s
# Cumulative duration =8min 20.910000000000025s
#
# 249
# Epoch duration =2.0s
# Cumulative duration =8min 22.910000000000025s
#
# 250
# Epoch duration =2.0s
# Cumulative duration =8min 24.910000000000025s
#
# 251
# Epoch duration =2.0s
# Cumulative duration =8min 26.910000000000025s
#
# 252
# Epoch duration =2.0s
# Cumulative duration =8min 28.920000000000016s
#
# 253
# Epoch duration =2.01s
# Cumulative duration =8min 30.920000000000016s
#
# 254
# Epoch duration =2.01s
# Cumulative duration =8min 32.92999999999995s
#
# 255
# Epoch duration =2.0s
# Cumulative duration =8min 34.940000000000055s
#
# 256
# Epoch duration =2.0s
# Cumulative duration =8min 36.940000000000055s
#
# 257
# Epoch duration =2.02s
# Cumulative duration =8min 38.960000000000036s
#
# 258
# Epoch duration =2.0s
# Cumulative duration =8min 40.960000000000036s
#
# 259
# Epoch duration =2.01s
# Cumulative duration =8min 42.97000000000003s
#
# 260
# Epoch duration =2.0s
# Cumulative duration =8min 44.97000000000003s
#
# 261
# Epoch duration =2.03s
# Cumulative duration =8min 47.0s
#
# 262
# Epoch duration =2.01s
# Cumulative duration =8min 49.00999999999999s
#
# 263
# Epoch duration =2.02s
# Cumulative duration =8min 51.039999999999964s
#
# 264
# Epoch duration =2.02s
# Cumulative duration =8min 53.049999999999955s
#
# 265
# Epoch duration =2.0s
# Cumulative duration =8min 55.059999999999945s
#
# 266
# Epoch duration =2.01s
# Cumulative duration =8min 57.07000000000005s
#
# 267
# Epoch duration =2.03s
# Cumulative duration =8min 59.110000000000014s
#
# 268
# Epoch duration =2.02s
# Cumulative duration =9min 1.1200000000000045s
#
# 269
# Epoch duration =2.01s
# Cumulative duration =9min 3.1399999999999864s
#
# 270
# Epoch duration =2.01s
# Cumulative duration =9min 5.149999999999977s
#
# 271
# Epoch duration =2.0s
# Cumulative duration =9min 7.149999999999977s
#
# 272
# Epoch duration =2.01s
# Cumulative duration =9min 9.159999999999968s
#
# 273
# Epoch duration =2.02s
# Cumulative duration =9min 11.169999999999959s
#
# 274
# Epoch duration =2.01s
# Cumulative duration =9min 13.17999999999995s
#
# 275
# Epoch duration =2.02s
# Cumulative duration =9min 15.200000000000045s
#
# 276
# Epoch duration =2.01s
# Cumulative duration =9min 17.210000000000036s
#
# 277
# Epoch duration =2.01s
# Cumulative duration =9min 19.220000000000027s
#
# 278
# Epoch duration =2.03s
# Cumulative duration =9min 21.25s
#
# 279
# Epoch duration =2.01s
# Cumulative duration =9min 23.269999999999982s
#
# 280
# Epoch duration =2.01s
# Cumulative duration =9min 25.279999999999973s
#
# 281
# Epoch duration =2.01s
# Cumulative duration =9min 27.289999999999964s
#
# 282
# Epoch duration =2.01s
# Cumulative duration =9min 29.299999999999955s
#
# 283
# Epoch duration =2.01s
# Cumulative duration =9min 31.309999999999945s
#
# 284
# Epoch duration =2.01s
# Cumulative duration =9min 33.32000000000005s
#
# 285
# Epoch duration =2.03s
# Cumulative duration =9min 35.35000000000002s
#
# 286
# Epoch duration =2.01s
# Cumulative duration =9min 37.35000000000002s
#
# 287
# Epoch duration =2.01s
# Cumulative duration =9min 39.360000000000014s
#
# 288
# Epoch duration =2.01s
# Cumulative duration =9min 41.370000000000005s
#
# 289
# Epoch duration =2.02s
# Cumulative duration =9min 43.389999999999986s
#
# 290
# Epoch duration =2.0s
# Cumulative duration =9min 45.389999999999986s
#
# 291
# Epoch duration =2.01s
# Cumulative duration =9min 47.39999999999998s
#
# 292
# Epoch duration =2.01s
# Cumulative duration =9min 49.41999999999996s
#
# 293
# Epoch duration =2.0s
# Cumulative duration =9min 51.41999999999996s
#
# 294
# Epoch duration =2.0s
# Cumulative duration =9min 53.41999999999996s
#
# 295
# Epoch duration =2.0s
# Cumulative duration =9min 55.41999999999996s
#
# 296
# Epoch duration =2.03s
# Cumulative duration =9min 57.440000000000055s
#
# 297
# Epoch duration =2.02s
# Cumulative duration =9min 59.460000000000036s
#
# 298
# Epoch duration =2.01s
# Cumulative duration =10min 1.4700000000000273s
#
# 299
# Epoch duration =2.01s
# Cumulative duration =10min 3.480000000000018s
#
# 300
# Epoch duration =2.02s
# Cumulative duration =10min 5.5s
#
# 301
# Epoch duration =2.02s
# Cumulative duration =10min 7.519999999999982s
#
# 302
# Epoch duration =2.0s
# Cumulative duration =10min 9.529999999999973s
#
# 303
# Epoch duration =2.0s
# Cumulative duration =10min 11.529999999999973s
#
# 304
# Epoch duration =2.0s
# Cumulative duration =10min 13.519999999999982s
#
# 305
# Epoch duration =2.01s
# Cumulative duration =10min 15.529999999999973s
#
# 306
# Epoch duration =2.0s
# Cumulative duration =10min 17.529999999999973s
#
# 307
# Epoch duration =2.0s
# Cumulative duration =10min 19.529999999999973s
#
# 308
# Epoch duration =2.0s
# Cumulative duration =10min 21.539999999999964s
#
# 309
# Epoch duration =2.02s
# Cumulative duration =10min 23.559999999999945s
#
# 310
# Epoch duration =2.01s
# Cumulative duration =10min 25.57000000000005s
#
# 311
# Epoch duration =2.01s
# Cumulative duration =10min 27.58000000000004s
#
# 312
# Epoch duration =2.02s
# Cumulative duration =10min 29.600000000000023s
#
# 313
# Epoch duration =2.05s
# Cumulative duration =10min 31.649999999999977s
#
# 314
# Epoch duration =2.01s
# Cumulative duration =10min 33.65999999999997s
#
# 315
# Epoch duration =2.0s
# Cumulative duration =10min 35.65999999999997s
#
# 316
# Epoch duration =2.02s
# Cumulative duration =10min 37.67999999999995s
#
# 317
# Epoch duration =2.02s
# Cumulative duration =10min 39.700000000000045s
#
# 318
# Epoch duration =2.0s
# Cumulative duration =10min 41.700000000000045s
#
# 319
# Epoch duration =2.01s
# Cumulative duration =10min 43.72000000000003s
#
# 320
# Epoch duration =2.02s
# Cumulative duration =10min 45.74000000000001s
#
# 321
# Epoch duration =2.02s
# Cumulative duration =10min 47.75999999999999s
#
# 322
# Epoch duration =2.0s
# Cumulative duration =10min 49.75s
#
# 323
# Epoch duration =2.03s
# Cumulative duration =10min 51.77999999999997s
#
# 324
# Epoch duration =2.01s
# Cumulative duration =10min 53.799999999999955s
#
# 325
# Epoch duration =2.03s
# Cumulative duration =10min 55.82000000000005s
#
# 326
# Epoch duration =2.0s
# Cumulative duration =10min 57.82000000000005s
#
# 327
# Epoch duration =2.0s
# Cumulative duration =10min 59.82000000000005s
#
# 328
# Epoch duration =2.0s
# Cumulative duration =11min 1.830000000000041s
#
# 329
# Epoch duration =2.02s
# Cumulative duration =11min 3.840000000000032s
#
# 330
# Epoch duration =2.02s
# Cumulative duration =11min 5.860000000000014s
#
# 331
# Epoch duration =2.0s
# Cumulative duration =11min 7.860000000000014s
#
# 332
# Epoch duration =2.01s
# Cumulative duration =11min 9.879999999999995s
#
# 333
# Epoch duration =2.01s
# Cumulative duration =11min 11.879999999999995s
#
# 334
# Epoch duration =2.01s
# Cumulative duration =11min 13.899999999999977s
#
# 335
# Epoch duration =2.02s
# Cumulative duration =11min 15.919999999999959s
#
# 336
# Epoch duration =2.02s
# Cumulative duration =11min 17.940000000000055s
#
# 337
# Epoch duration =2.02s
# Cumulative duration =11min 19.960000000000036s
#
# 338
# Epoch duration =1.99s
# Cumulative duration =11min 21.950000000000045s
#
# 339
# Epoch duration =2.0s
# Cumulative duration =11min 23.950000000000045s
#
# 340
# Epoch duration =2.02s
# Cumulative duration =11min 25.970000000000027s
#
# 341
# Epoch duration =2.01s
# Cumulative duration =11min 27.980000000000018s
#
# 342
# Epoch duration =2.01s
# Cumulative duration =11min 29.99000000000001s
#
# 343
# Epoch duration =2.03s
# Cumulative duration =11min 32.00999999999999s
#
# 344
# Epoch duration =2.02s
# Cumulative duration =11min 34.02999999999997s
#
# 345
# Epoch duration =2.02s
# Cumulative duration =11min 36.049999999999955s
#
# 346
# Epoch duration =2.0s
# Cumulative duration =11min 38.049999999999955s
#
# 347
# Epoch duration =2.01s
# Cumulative duration =11min 40.059999999999945s
#
# 348
# Epoch duration =2.01s
# Cumulative duration =11min 42.07000000000005s
#
# 349
# Epoch duration =2.01s
# Cumulative duration =11min 44.08000000000004s
#
# 350
# Epoch duration =2.02s
# Cumulative duration =11min 46.09000000000003s
#
# 351
# Epoch duration =2.01s
# Cumulative duration =11min 48.10000000000002s
#
# 352
# Epoch duration =2.03s
# Cumulative duration =11min 50.129999999999995s
#
# 353
# Epoch duration =2.01s
# Cumulative duration =11min 52.14999999999998s
#
# 354
# Epoch duration =2.0s
# Cumulative duration =11min 54.14999999999998s
#
# 355
# Epoch duration =2.0s
# Cumulative duration =11min 56.14999999999998s
#
# 356
# Epoch duration =2.03s
# Cumulative duration =11min 58.190000000000055s
#
# 357
# Epoch duration =2.03s
# Cumulative duration =12min 0.22000000000002728s
#
# 358
# Epoch duration =2.02s
# Cumulative duration =12min 2.230000000000018s
#
# 359
# Epoch duration =2.02s
# Cumulative duration =12min 4.25s
#
# 360
# Epoch duration =2.0s
# Cumulative duration =12min 6.259999999999991s
#
# 361
# Epoch duration =2.01s
# Cumulative duration =12min 8.269999999999982s
#
# 362
# Epoch duration =2.01s
# Cumulative duration =12min 10.279999999999973s
#
# 363
# Epoch duration =2.0s
# Cumulative duration =12min 12.279999999999973s
#
# 364
# Epoch duration =2.01s
# Cumulative duration =12min 14.289999999999964s
#
# 365
# Epoch duration =2.03s
# Cumulative duration =12min 16.32000000000005s
#
# 366
# Epoch duration =2.01s
# Cumulative duration =12min 18.33000000000004s
#
# 367
# Epoch duration =2.03s
# Cumulative duration =12min 20.350000000000023s
#
# 368
# Epoch duration =2.01s
# Cumulative duration =12min 22.360000000000014s
#
# 369
# Epoch duration =2.0s
# Cumulative duration =12min 24.360000000000014s
#
# 370
# Epoch duration =1.99s
# Cumulative duration =12min 26.360000000000014s
#
# 371
# Epoch duration =2.01s
# Cumulative duration =12min 28.370000000000005s
#
# 372
# Epoch duration =2.02s
# Cumulative duration =12min 30.389999999999986s
#
# 373
# Epoch duration =2.01s
# Cumulative duration =12min 32.39999999999998s
#
# 374
# Epoch duration =2.0s
# Cumulative duration =12min 34.39999999999998s
#
# 375
# Epoch duration =2.01s
# Cumulative duration =12min 36.40999999999997s
#
# 376
# Epoch duration =2.01s
# Cumulative duration =12min 38.41999999999996s
#
# 377
# Epoch duration =2.01s
# Cumulative duration =12min 40.42999999999995s
#
# 378
# Epoch duration =2.01s
# Cumulative duration =12min 42.42999999999995s
#
# 379
# Epoch duration =2.01s
# Cumulative duration =12min 44.440000000000055s
#
# 380
# Epoch duration =2.03s
# Cumulative duration =12min 46.47000000000003s
#
# 381
# Epoch duration =2.01s
# Cumulative duration =12min 48.48000000000002s
#
# 382
# Epoch duration =2.02s
# Cumulative duration =12min 50.5s
#
# 383
# Epoch duration =2.02s
# Cumulative duration =12min 52.51999999999998s
#
# 384
# Epoch duration =2.01s
# Cumulative duration =12min 54.52999999999997s
#
# 385
# Epoch duration =2.01s
# Cumulative duration =12min 56.539999999999964s
#
# 386
# Epoch duration =2.0s
# Cumulative duration =12min 58.52999999999997s
#
# 387
# Epoch duration =2.0s
# Cumulative duration =13min 0.5399999999999636s
#
# 388
# Epoch duration =2.02s
# Cumulative duration =13min 2.5599999999999454s
#
# 389
# Epoch duration =2.01s
# Cumulative duration =13min 4.57000000000005s
#
# 390
# Epoch duration =2.02s
# Cumulative duration =13min 6.590000000000032s
#
# 391
# Epoch duration =2.07s
# Cumulative duration =13min 8.659999999999968s
#
# 392
# Epoch duration =2.04s
# Cumulative duration =13min 10.700000000000045s
#
# 393
# Epoch duration =2.02s
# Cumulative duration =13min 12.710000000000036s
#
# 394
# Epoch duration =2.02s
# Cumulative duration =13min 14.730000000000018s
#
# 395
# Epoch duration =2.01s
# Cumulative duration =13min 16.74000000000001s
#
# 396
# Epoch duration =2.0s
# Cumulative duration =13min 18.74000000000001s
#
# 397
# Epoch duration =2.01s
# Cumulative duration =13min 20.75s
#
# 398
# Epoch duration =2.01s
# Cumulative duration =13min 22.75s
#
# 399
# Epoch duration =2.01s
# Cumulative duration =13min 24.769999999999982s
#
# 400
# Epoch duration =2.0s
# Cumulative duration =13min 26.769999999999982s
#
# 401
# Epoch duration =2.02s
# Cumulative duration =13min 28.789999999999964s
#
# 402
# Epoch duration =2.0s
# Cumulative duration =13min 30.789999999999964s
#
# 403
# Epoch duration =2.03s
# Cumulative duration =13min 32.82000000000005s
#
# 404
# Epoch duration =2.02s
# Cumulative duration =13min 34.84000000000003s
#
# 405
# Epoch duration =2.02s
# Cumulative duration =13min 36.860000000000014s
#
# 406
# Epoch duration =2.01s
# Cumulative duration =13min 38.870000000000005s
#
# 407
# Epoch duration =2.02s
# Cumulative duration =13min 40.889999999999986s
#
# 408
# Epoch duration =2.0s
# Cumulative duration =13min 42.889999999999986s
#
# 409
# Epoch duration =2.01s
# Cumulative duration =13min 44.89999999999998s
#
# 410
# Epoch duration =2.02s
# Cumulative duration =13min 46.90999999999997s
#
# 411
# Epoch duration =2.02s
# Cumulative duration =13min 48.92999999999995s
#
# 412
# Epoch duration =2.02s
# Cumulative duration =13min 50.950000000000045s
#
# 413
# Epoch duration =2.0s
# Cumulative duration =13min 52.950000000000045s
#
# 414
# Epoch duration =2.01s
# Cumulative duration =13min 54.97000000000003s
#
# 415
# Epoch duration =2.02s
# Cumulative duration =13min 56.99000000000001s
#
# 416
# Epoch duration =2.0s
# Cumulative duration =13min 58.99000000000001s
#
# 417
# Epoch duration =2.0s
# Cumulative duration =14min 1.0s
#
# 418
# Epoch duration =1.99s
# Cumulative duration =14min 2.990000000000009s
#
# 419
# Epoch duration =2.01s
# Cumulative duration =14min 5.0s
#
# 420
# Epoch duration =2.0s
# Cumulative duration =14min 6.990000000000009s
#
# 421
# Epoch duration =2.02s
# Cumulative duration =14min 9.019999999999982s
#
# 422
# Epoch duration =1.99s
# Cumulative duration =14min 11.009999999999991s
#
# 423
# Epoch duration =2.01s
# Cumulative duration =14min 13.019999999999982s
#
# 424
# Epoch duration =1.99s
# Cumulative duration =14min 15.009999999999991s
#
# 425
# Epoch duration =2.03s
# Cumulative duration =14min 17.039999999999964s
#
# 426
# Epoch duration =2.01s
# Cumulative duration =14min 19.049999999999955s
#
# 427
# Epoch duration =2.01s
# Cumulative duration =14min 21.049999999999955s
#
# 428
# Epoch duration =2.01s
# Cumulative duration =14min 23.059999999999945s
#
# 429
# Epoch duration =2.01s
# Cumulative duration =14min 25.07000000000005s
#
# 430
# Epoch duration =2.02s
# Cumulative duration =14min 27.090000000000032s
#
# 431
# Epoch duration =2.04s
# Cumulative duration =14min 29.129999999999995s
#
# 432
# Epoch duration =2.0s
# Cumulative duration =14min 31.129999999999995s
#
# 433
# Epoch duration =2.01s
# Cumulative duration =14min 33.139999999999986s
#
# 434
# Epoch duration =2.0s
# Cumulative duration =14min 35.139999999999986s
#
# 435
# Epoch duration =2.04s
# Cumulative duration =14min 37.17999999999995s
#
# 436
# Epoch duration =2.03s
# Cumulative duration =14min 39.210000000000036s
#
# 437
# Epoch duration =2.0s
# Cumulative duration =14min 41.210000000000036s
#
# 438
# Epoch duration =1.99s
# Cumulative duration =14min 43.200000000000045s
#
# 439
# Epoch duration =2.0s
# Cumulative duration =14min 45.200000000000045s
#
# 440
# Epoch duration =2.0s
# Cumulative duration =14min 47.200000000000045s
#
# 441
# Epoch duration =2.06s
# Cumulative duration =14min 49.25999999999999s
#
# 442
# Epoch duration =2.02s
# Cumulative duration =14min 51.27999999999997s
#
# 443
# Epoch duration =2.0s
# Cumulative duration =14min 53.289999999999964s
#
# 444
# Epoch duration =2.02s
# Cumulative duration =14min 55.309999999999945s
#
# 445
# Epoch duration =2.02s
# Cumulative duration =14min 57.33000000000004s
#
# 446
# Epoch duration =2.01s
# Cumulative duration =14min 59.34000000000003s
#
# 447
# Epoch duration =2.0s
# Cumulative duration =15min 1.3500000000000227s
#
# 448
# Epoch duration =2.01s
# Cumulative duration =15min 3.3500000000000227s
#
# 449
# Epoch duration =2.01s
# Cumulative duration =15min 5.360000000000014s
#
# 450
# Epoch duration =2.02s
# Cumulative duration =15min 7.3799999999999955s
#
# 451
# Epoch duration =2.01s
# Cumulative duration =15min 9.379999999999995s
#
# 452
# Epoch duration =2.0s
# Cumulative duration =15min 11.389999999999986s
#
# 453
# Epoch duration =2.01s
# Cumulative duration =15min 13.389999999999986s
#
# 454
# Epoch duration =2.0s
# Cumulative duration =15min 15.399999999999977s
#
# 455
# Epoch duration =2.03s
# Cumulative duration =15min 17.42999999999995s
#
# 456
# Epoch duration =2.01s
# Cumulative duration =15min 19.440000000000055s
#
# 457
# Epoch duration =2.01s
# Cumulative duration =15min 21.450000000000045s
#
# 458
# Epoch duration =2.01s
# Cumulative duration =15min 23.460000000000036s
#
# 459
# Epoch duration =2.01s
# Cumulative duration =15min 25.480000000000018s
#
# 460
# Epoch duration =2.02s
# Cumulative duration =15min 27.5s
#
# 461
# Epoch duration =2.02s
# Cumulative duration =15min 29.519999999999982s
#
# 462
# Epoch duration =2.01s
# Cumulative duration =15min 31.529999999999973s
#
# 463
# Epoch duration =2.01s
# Cumulative duration =15min 33.539999999999964s
#
# 464
# Epoch duration =2.01s
# Cumulative duration =15min 35.549999999999955s
#
# 465
# Epoch duration =2.01s
# Cumulative duration =15min 37.559999999999945s
#
# 466
# Epoch duration =2.0s
# Cumulative duration =15min 39.549999999999955s
#
# 467
# Epoch duration =2.0s
# Cumulative duration =15min 41.559999999999945s
#
# 468
# Epoch duration =2.03s
# Cumulative duration =15min 43.59000000000003s
#
# 469
# Epoch duration =2.04s
# Cumulative duration =15min 45.629999999999995s
#
# 470
# Epoch duration =2.01s
# Cumulative duration =15min 47.629999999999995s
#
# 471
# Epoch duration =2.02s
# Cumulative duration =15min 49.65999999999997s
#
# 472
# Epoch duration =2.0s
# Cumulative duration =15min 51.65999999999997s
#
# 473
# Epoch duration =2.02s
# Cumulative duration =15min 53.67999999999995s
#
# 474
# Epoch duration =2.01s
# Cumulative duration =15min 55.690000000000055s
#
# 475
# Epoch duration =2.02s
# Cumulative duration =15min 57.72000000000003s
#
# 476
# Epoch duration =2.0s
# Cumulative duration =15min 59.72000000000003s
#
# 477
# Epoch duration =2.01s
# Cumulative duration =16min 1.7300000000000182s
#
# 478
# Epoch duration =2.0s
# Cumulative duration =16min 3.730000000000018s
#
# 479
# Epoch duration =1.99s
# Cumulative duration =16min 5.720000000000027s
#
# 480
# Epoch duration =2.01s
# Cumulative duration =16min 7.730000000000018s
#
# 481
# Epoch duration =2.01s
# Cumulative duration =16min 9.740000000000009s
#
# 482
# Epoch duration =2.01s
# Cumulative duration =16min 11.75s
#
# 483
# Epoch duration =2.0s
# Cumulative duration =16min 13.75s
#
# 484
# Epoch duration =2.01s
# Cumulative duration =16min 15.75s
#
# 485
# Epoch duration =2.0s
# Cumulative duration =16min 17.75999999999999s
#
# 486
# Epoch duration =2.03s
# Cumulative duration =16min 19.789999999999964s
#
# 487
# Epoch duration =2.0s
# Cumulative duration =16min 21.789999999999964s
#
# 488
# Epoch duration =2.04s
# Cumulative duration =16min 23.840000000000032s
#
# 489
# Epoch duration =2.01s
# Cumulative duration =16min 25.850000000000023s
#
# 490
# Epoch duration =2.0s
# Cumulative duration =16min 27.850000000000023s
#
# 491
# Epoch duration =2.0s
# Cumulative duration =16min 29.860000000000014s
#
# 492
# Epoch duration =2.02s
# Cumulative duration =16min 31.879999999999995s
#
# 493
# Epoch duration =2.0s
# Cumulative duration =16min 33.879999999999995s
#
# 494
# Epoch duration =2.0s
# Cumulative duration =16min 35.879999999999995s
#
# 495
# Epoch duration =2.0s
# Cumulative duration =16min 37.879999999999995s
#
# 496
# Epoch duration =2.0s
# Cumulative duration =16min 39.879999999999995s
#
# 497
# Epoch duration =2.01s
# Cumulative duration =16min 41.889999999999986s
#
# 498
# Epoch duration =2.0s
# Cumulative duration =16min 43.889999999999986s
#
# 499
# Epoch duration =2.02s
# Cumulative duration =16min 45.90999999999997s
#
# Saving scores to Arrays/trna_resbindt2_ug_so500.npy

# %%
#load values
savepath = 'Arrays/trna_resbindt2_ug_so500.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 500
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
bpugSQ = ['.' for i in range(len(ugidx))]
bpugidx = []
for i, ix in enumerate(ugidx):
    if ix in bpidx:
        bpugSQ[i] = SQ[ix]
        bpugidx.append(i)

# %%
C[bpugidx][:, bpugidx].shape
# Out:
# (32, 32)
