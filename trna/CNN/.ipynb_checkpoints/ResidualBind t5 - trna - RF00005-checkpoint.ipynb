# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/trna_100k_d5.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 6.32s

# %%
simalign_file = '../../../data_RFAM/trnasim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((((<<<<>>>><<<<<>>>>><<<<<>>>>>)))))))'

# %%
ugSS
# Out:
# '(((((((,,<<<<_______>>>>,<<<<<_______>>>>>,,,,<<<<<_______>>>>>))))))):'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/trna'
param_path = os.path.join(save_path, 'resbind_t5')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 513, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=10.88s -- loss=0.15681 -- acc=93.80500%
#
#   valid loss:		0.05196
#   valid accuracy:	0.98420+/-0.00000
#   valid auc-roc:	0.99875+/-0.00000
#   valid auc-pr:		0.99854+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=10.49s -- loss=0.04326 -- acc=98.75917%
#
#   valid loss:		0.02473
#   valid accuracy:	0.99460+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99960+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=10.50s -- loss=0.02995 -- acc=99.22917%
#
#   valid loss:		0.02398
#   valid accuracy:	0.99525+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99951+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=10.46s -- loss=0.02656 -- acc=99.40333%
#
#   valid loss:		0.02185
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99966+/-0.00000
#   valid auc-pr:		0.99961+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=10.35s -- loss=0.02466 -- acc=99.47917%
#
#   valid loss:		0.02316
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99970+/-0.00000
#   valid auc-pr:		0.99969+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=10.44s -- loss=0.02304 -- acc=99.57917%
#
#   valid loss:		0.02532
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99962+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=10.43s -- loss=0.02299 -- acc=99.59167%
#
#   valid loss:		0.02254
#   valid accuracy:	0.99705+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99954+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=10.47s -- loss=0.02311 -- acc=99.64333%
#
#   valid loss:		0.02353
#   valid accuracy:	0.99695+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99966+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=10.45s -- loss=0.02234 -- acc=99.68583%
#
#   valid loss:		0.02657
#   valid accuracy:	0.99635+/-0.00000
#   valid auc-roc:	0.99960+/-0.00000
#   valid auc-pr:		0.99949+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=10.44s -- loss=0.02287 -- acc=99.68000%
#
#   valid loss:		0.02785
#   valid accuracy:	0.99660+/-0.00000
#   valid auc-roc:	0.99940+/-0.00000
#   valid auc-pr:		0.99896+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=10.42s -- loss=0.02192 -- acc=99.72083%
#
#   valid loss:		0.02351
#   valid accuracy:	0.99740+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99954+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=10.49s -- loss=0.02169 -- acc=99.72500%
#
#   valid loss:		0.02290
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99967+/-0.00000
#   valid auc-pr:		0.99953+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=10.49s -- loss=0.02201 -- acc=99.71583%
#
#   valid loss:		0.02528
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99967+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=10.46s -- loss=0.02184 -- acc=99.73750%
#
#   valid loss:		0.02319
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=10.50s -- loss=0.02110 -- acc=99.77917%
#
#   valid loss:		0.02336
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99973+/-0.00000
#   valid auc-pr:		0.99968+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=10.47s -- loss=0.02156 -- acc=99.76667%
#
#   valid loss:		0.02459
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=10.44s -- loss=0.02171 -- acc=99.78000%
#
#   valid loss:		0.02908
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99974+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=10.46s -- loss=0.02184 -- acc=99.76250%
#
#   valid loss:		0.02382
#   valid accuracy:	0.99740+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=10.45s -- loss=0.02112 -- acc=99.80083%
#
#   valid loss:		0.02276
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=10.50s -- loss=0.02174 -- acc=99.76417%
#
#   valid loss:		0.02512
#   valid accuracy:	0.99715+/-0.00000
#   valid auc-roc:	0.99968+/-0.00000
#   valid auc-pr:		0.99934+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=10.54s -- loss=0.02073 -- acc=99.81250%
#
#   valid loss:		0.02430
#   valid accuracy:	0.99740+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99956+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=10.55s -- loss=0.02030 -- acc=99.82917%
#
#   valid loss:		0.02427
#   valid accuracy:	0.99755+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99963+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=10.57s -- loss=0.02178 -- acc=99.77000%
#
#   valid loss:		0.02330
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99946+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=10.59s -- loss=0.02077 -- acc=99.82667%
#
#   valid loss:		0.02320
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=10.55s -- loss=0.02172 -- acc=99.77500%
#
#   valid loss:		0.02168
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=10.63s -- loss=0.02044 -- acc=99.81417%
#
#   valid loss:		0.02183
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=10.69s -- loss=0.02064 -- acc=99.82250%
#
#   valid loss:		0.02581
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=10.58s -- loss=0.02076 -- acc=99.81000%
#
#   valid loss:		0.02319
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=10.58s -- loss=0.02066 -- acc=99.80917%
#
#   valid loss:		0.02319
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=10.57s -- loss=0.02011 -- acc=99.83083%
#
#   valid loss:		0.02401
#   valid accuracy:	0.99750+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99976+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=10.64s -- loss=0.02003 -- acc=99.82583%
#
#   valid loss:		0.02374
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=10.60s -- loss=0.02043 -- acc=99.82750%
#
#   valid loss:		0.02335
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99962+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=10.60s -- loss=0.01959 -- acc=99.83917%
#
#   valid loss:		0.02476
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=10.62s -- loss=0.02107 -- acc=99.80417%
#
#   valid loss:		0.02179
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=10.60s -- loss=0.01970 -- acc=99.82417%
#
#   valid loss:		0.02372
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=10.63s -- loss=0.01960 -- acc=99.82833%
#
#   valid loss:		0.02174
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=10.64s -- loss=0.02022 -- acc=99.81417%
#
#   valid loss:		0.02118
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99972+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=10.58s -- loss=0.01934 -- acc=99.84583%
#
#   valid loss:		0.02497
#   valid accuracy:	0.99755+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99965+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=10.58s -- loss=0.01952 -- acc=99.83167%
#
#   valid loss:		0.02183
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=10.58s -- loss=0.01896 -- acc=99.85250%
#
#   valid loss:		0.02282
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=10.58s -- loss=0.01965 -- acc=99.82250%
#
#   valid loss:		0.02325
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=10.60s -- loss=0.01927 -- acc=99.83417%
#
#   valid loss:		0.02295
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=10.62s -- loss=0.01944 -- acc=99.83250%
#
#   valid loss:		0.02182
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99976+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=10.61s -- loss=0.01932 -- acc=99.82583%
#
#   valid loss:		0.02247
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=10.58s -- loss=0.01823 -- acc=99.86500%
#
#   valid loss:		0.02052
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=10.61s -- loss=0.01875 -- acc=99.82583%
#
#   valid loss:		0.02258
#   valid accuracy:	0.99740+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=10.60s -- loss=0.01859 -- acc=99.85083%
#
#   valid loss:		0.02277
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=10.59s -- loss=0.01905 -- acc=99.84250%
#
#   valid loss:		0.02066
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=10.59s -- loss=0.01848 -- acc=99.83833%
#
#   valid loss:		0.01997
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99969+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=10.61s -- loss=0.01848 -- acc=99.84417%
#
#   valid loss:		0.02149
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=10.62s -- loss=0.01872 -- acc=99.85250%
#
#   valid loss:		0.02140
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=10.61s -- loss=0.01864 -- acc=99.84000%
#
#   valid loss:		0.02088
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99966+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=10.57s -- loss=0.01813 -- acc=99.85333%
#
#   valid loss:		0.02318
#   valid accuracy:	0.99750+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99968+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=10.58s -- loss=0.01806 -- acc=99.86333%
#
#   valid loss:		0.02054
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=10.69s -- loss=0.01834 -- acc=99.82917%
#
#   valid loss:		0.02156
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=10.64s -- loss=0.01722 -- acc=99.87167%
#
#   valid loss:		0.02060
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99972+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=10.68s -- loss=0.01732 -- acc=99.88250%
#
#   valid loss:		0.02024
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=10.65s -- loss=0.01854 -- acc=99.83333%
#
#   valid loss:		0.02085
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99969+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=10.66s -- loss=0.01803 -- acc=99.85667%
#
#   valid loss:		0.01995
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=10.68s -- loss=0.01755 -- acc=99.85333%
#
#   valid loss:		0.02172
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=10.65s -- loss=0.01743 -- acc=99.85083%
#
#   valid loss:		0.02114
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99968+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=10.67s -- loss=0.01801 -- acc=99.86750%
#
#   valid loss:		0.02010
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=10.69s -- loss=0.01762 -- acc=99.87000%
#
#   valid loss:		0.02042
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99967+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=10.65s -- loss=0.01760 -- acc=99.86417%
#
#   valid loss:		0.01992
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99955+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=10.62s -- loss=0.01720 -- acc=99.87167%
#
#   valid loss:		0.02021
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=10.61s -- loss=0.01751 -- acc=99.85583%
#
#   valid loss:		0.02186
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99965+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=10.68s -- loss=0.01684 -- acc=99.87083%
#
#   valid loss:		0.02213
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=10.65s -- loss=0.01721 -- acc=99.87083%
#
#   valid loss:		0.02167
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=10.69s -- loss=0.01761 -- acc=99.85000%
#
#   valid loss:		0.02069
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=10.74s -- loss=0.01712 -- acc=99.86583%
#
#   valid loss:		0.01924
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=10.64s -- loss=0.01721 -- acc=99.87167%
#
#   valid loss:		0.01994
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=10.73s -- loss=0.01729 -- acc=99.85583%
#
#   valid loss:		0.02068
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=10.63s -- loss=0.01691 -- acc=99.89000%
#
#   valid loss:		0.02098
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99974+/-0.00000
#   valid auc-pr:		0.99955+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=10.65s -- loss=0.01750 -- acc=99.85583%
#
#   valid loss:		0.01937
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=10.60s -- loss=0.01661 -- acc=99.88250%
#
#   valid loss:		0.02158
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99969+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=10.65s -- loss=0.01714 -- acc=99.86333%
#
#   valid loss:		0.01997
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99966+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=10.63s -- loss=0.01699 -- acc=99.87750%
#
#   valid loss:		0.02018
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=10.70s -- loss=0.01701 -- acc=99.86083%
#
#   valid loss:		0.02030
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99972+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=10.67s -- loss=0.01675 -- acc=99.86917%
#
#   valid loss:		0.01992
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99966+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=10.72s -- loss=0.01671 -- acc=99.86333%
#
#   valid loss:		0.02020
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=10.70s -- loss=0.01619 -- acc=99.88000%
#
#   valid loss:		0.01868
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99976+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=10.67s -- loss=0.01616 -- acc=99.87917%
#
#   valid loss:		0.01906
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99976+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=10.67s -- loss=0.01644 -- acc=99.87667%
#
#   valid loss:		0.01962
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99971+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=10.74s -- loss=0.01683 -- acc=99.87333%
#
#   valid loss:		0.01987
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=10.65s -- loss=0.01659 -- acc=99.88167%
#
#   valid loss:		0.01882
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=10.63s -- loss=0.01662 -- acc=99.87250%
#
#   valid loss:		0.01902
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=10.59s -- loss=0.01600 -- acc=99.89417%
#
#   valid loss:		0.01892
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99969+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=10.72s -- loss=0.01676 -- acc=99.86333%
#
#   valid loss:		0.01918
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=10.66s -- loss=0.01649 -- acc=99.88250%
#
#   valid loss:		0.01897
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99965+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=10.67s -- loss=0.01631 -- acc=99.88083%
#
#   valid loss:		0.01978
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99969+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=10.73s -- loss=0.01651 -- acc=99.86000%
#
#   valid loss:		0.02010
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=10.70s -- loss=0.01590 -- acc=99.90417%
#
#   valid loss:		0.01882
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=10.67s -- loss=0.01614 -- acc=99.87417%
#
#   valid loss:		0.01886
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=10.68s -- loss=0.01668 -- acc=99.86667%
#
#   valid loss:		0.01914
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=10.65s -- loss=0.01619 -- acc=99.86750%
#
#   valid loss:		0.01763
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=10.63s -- loss=0.01623 -- acc=99.86833%
#
#   valid loss:		0.01923
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99971+/-0.00000
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=10.66s -- loss=0.01599 -- acc=99.88333%
#
#   valid loss:		0.01904
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=10.75s -- loss=0.01596 -- acc=99.87917%
#
#   valid loss:		0.01949
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99967+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=10.66s -- loss=0.01604 -- acc=99.87333%
#
#   valid loss:		0.01878
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=10.62s -- loss=0.01595 -- acc=99.87583%
#
#   valid loss:		0.01747
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t5_best.ckpt

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/trna/resbind_t5_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/trna/resbind_t5_best.ckpt
#   test  loss:		0.01578
#   test  accuracy:	0.99882+/-0.00000
#   test  auc-roc:	0.99999+/-0.00000
#   test  auc-pr:		0.99999+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/trna_resbindt5_ug_so1000.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =2.02s
# Cumulative duration =2.02s
#
# 1
# Epoch duration =1.98s
# Cumulative duration =4.0s
#
# 2
# Epoch duration =1.98s
# Cumulative duration =5.98s
#
# 3
# Epoch duration =1.97s
# Cumulative duration =7.95s
#
# 4
# Epoch duration =1.98s
# Cumulative duration =9.93s
#
# 5
# Epoch duration =1.99s
# Cumulative duration =11.92s
#
# 6
# Epoch duration =1.98s
# Cumulative duration =13.9s
#
# 7
# Epoch duration =1.99s
# Cumulative duration =15.89s
#
# 8
# Epoch duration =1.98s
# Cumulative duration =17.87s
#
# 9
# Epoch duration =1.97s
# Cumulative duration =19.85s
#
# 10
# Epoch duration =1.98s
# Cumulative duration =21.82s
#
# 11
# Epoch duration =1.97s
# Cumulative duration =23.79s
#
# 12
# Epoch duration =1.99s
# Cumulative duration =25.77s
#
# 13
# Epoch duration =1.97s
# Cumulative duration =27.75s
#
# 14
# Epoch duration =1.99s
# Cumulative duration =29.74s
#
# 15
# Epoch duration =1.98s
# Cumulative duration =31.72s
#
# 16
# Epoch duration =1.99s
# Cumulative duration =33.71s
#
# 17
# Epoch duration =1.98s
# Cumulative duration =35.69s
#
# 18
# Epoch duration =1.98s
# Cumulative duration =37.67s
#
# 19
# Epoch duration =1.98s
# Cumulative duration =39.65s
#
# 20
# Epoch duration =1.99s
# Cumulative duration =41.64s
#
# 21
# Epoch duration =1.98s
# Cumulative duration =43.62s
#
# 22
# Epoch duration =1.99s
# Cumulative duration =45.61s
#
# 23
# Epoch duration =1.98s
# Cumulative duration =47.6s
#
# 24
# Epoch duration =1.98s
# Cumulative duration =49.58s
#
# 25
# Epoch duration =1.99s
# Cumulative duration =51.57s
#
# 26
# Epoch duration =2.01s
# Cumulative duration =53.57s
#
# 27
# Epoch duration =1.99s
# Cumulative duration =55.56s
#
# 28
# Epoch duration =1.99s
# Cumulative duration =57.56s
#
# 29
# Epoch duration =1.98s
# Cumulative duration =59.54s
#
# 30
# Epoch duration =1.99s
# Cumulative duration =1min 1.5300000000000011s
#
# 31
# Epoch duration =1.99s
# Cumulative duration =1min 3.520000000000003s
#
# 32
# Epoch duration =1.99s
# Cumulative duration =1min 5.510000000000005s
#
# 33
# Epoch duration =1.99s
# Cumulative duration =1min 7.5s
#
# 34
# Epoch duration =1.99s
# Cumulative duration =1min 9.5s
#
# 35
# Epoch duration =1.99s
# Cumulative duration =1min 11.489999999999995s
#
# 36
# Epoch duration =1.99s
# Cumulative duration =1min 13.480000000000004s
#
# 37
# Epoch duration =1.98s
# Cumulative duration =1min 15.459999999999994s
#
# 38
# Epoch duration =1.99s
# Cumulative duration =1min 17.439999999999998s
#
# 39
# Epoch duration =2.01s
# Cumulative duration =1min 19.450000000000003s
#
# 40
# Epoch duration =2.0s
# Cumulative duration =1min 21.450000000000003s
#
# 41
# Epoch duration =2.0s
# Cumulative duration =1min 23.450000000000003s
#
# 42
# Epoch duration =2.02s
# Cumulative duration =1min 25.459999999999994s
#
# 43
# Epoch duration =1.99s
# Cumulative duration =1min 27.450000000000003s
#
# 44
# Epoch duration =1.98s
# Cumulative duration =1min 29.430000000000007s
#
# 45
# Epoch duration =1.98s
# Cumulative duration =1min 31.409999999999997s
#
# 46
# Epoch duration =1.99s
# Cumulative duration =1min 33.400000000000006s
#
# 47
# Epoch duration =1.98s
# Cumulative duration =1min 35.379999999999995s
#
# 48
# Epoch duration =1.98s
# Cumulative duration =1min 37.370000000000005s
#
# 49
# Epoch duration =2.0s
# Cumulative duration =1min 39.370000000000005s
#
# 50
# Epoch duration =1.99s
# Cumulative duration =1min 41.36s
#
# 51
# Epoch duration =1.98s
# Cumulative duration =1min 43.34s
#
# 52
# Epoch duration =2.04s
# Cumulative duration =1min 45.379999999999995s
#
# 53
# Epoch duration =1.98s
# Cumulative duration =1min 47.36s
#
# 54
# Epoch duration =1.99s
# Cumulative duration =1min 49.36s
#
# 55
# Epoch duration =2.0s
# Cumulative duration =1min 51.36s
#
# 56
# Epoch duration =1.98s
# Cumulative duration =1min 53.34s
#
# 57
# Epoch duration =2.0s
# Cumulative duration =1min 55.34s
#
# 58
# Epoch duration =1.98s
# Cumulative duration =1min 57.33s
#
# 59
# Epoch duration =2.0s
# Cumulative duration =1min 59.31999999999999s
#
# 60
# Epoch duration =2.01s
# Cumulative duration =2min 1.3299999999999983s
#
# 61
# Epoch duration =1.99s
# Cumulative duration =2min 3.319999999999993s
#
# 62
# Epoch duration =1.99s
# Cumulative duration =2min 5.310000000000002s
#
# 63
# Epoch duration =1.99s
# Cumulative duration =2min 7.299999999999997s
#
# 64
# Epoch duration =1.99s
# Cumulative duration =2min 9.289999999999992s
#
# 65
# Epoch duration =2.01s
# Cumulative duration =2min 11.310000000000002s
#
# 66
# Epoch duration =1.99s
# Cumulative duration =2min 13.300000000000011s
#
# 67
# Epoch duration =2.0s
# Cumulative duration =2min 15.300000000000011s
#
# 68
# Epoch duration =1.99s
# Cumulative duration =2min 17.28s
#
# 69
# Epoch duration =1.99s
# Cumulative duration =2min 19.28s
#
# 70
# Epoch duration =1.99s
# Cumulative duration =2min 21.27000000000001s
#
# 71
# Epoch duration =1.98s
# Cumulative duration =2min 23.25s
#
# 72
# Epoch duration =1.97s
# Cumulative duration =2min 25.22s
#
# 73
# Epoch duration =1.98s
# Cumulative duration =2min 27.210000000000008s
#
# 74
# Epoch duration =1.99s
# Cumulative duration =2min 29.189999999999998s
#
# 75
# Epoch duration =1.99s
# Cumulative duration =2min 31.180000000000007s
#
# 76
# Epoch duration =1.98s
# Cumulative duration =2min 33.16s
#
# 77
# Epoch duration =1.99s
# Cumulative duration =2min 35.150000000000006s
#
# 78
# Epoch duration =1.99s
# Cumulative duration =2min 37.139999999999986s
#
# 79
# Epoch duration =1.98s
# Cumulative duration =2min 39.120000000000005s
#
# 80
# Epoch duration =2.0s
# Cumulative duration =2min 41.120000000000005s
#
# 81
# Epoch duration =1.99s
# Cumulative duration =2min 43.110000000000014s
#
# 82
# Epoch duration =1.99s
# Cumulative duration =2min 45.099999999999994s
#
# 83
# Epoch duration =2.0s
# Cumulative duration =2min 47.110000000000014s
#
# 84
# Epoch duration =2.01s
# Cumulative duration =2min 49.110000000000014s
#
# 85
# Epoch duration =2.0s
# Cumulative duration =2min 51.120000000000005s
#
# 86
# Epoch duration =1.99s
# Cumulative duration =2min 53.110000000000014s
#
# 87
# Epoch duration =1.99s
# Cumulative duration =2min 55.099999999999994s
#
# 88
# Epoch duration =2.0s
# Cumulative duration =2min 57.09s
#
# 89
# Epoch duration =1.99s
# Cumulative duration =2min 59.08000000000001s
#
# 90
# Epoch duration =2.01s
# Cumulative duration =3min 1.0900000000000034s
#
# 91
# Epoch duration =1.99s
# Cumulative duration =3min 3.0900000000000034s
#
# 92
# Epoch duration =1.98s
# Cumulative duration =3min 5.069999999999993s
#
# 93
# Epoch duration =1.97s
# Cumulative duration =3min 7.039999999999992s
#
# 94
# Epoch duration =1.99s
# Cumulative duration =3min 9.030000000000001s
#
# 95
# Epoch duration =1.98s
# Cumulative duration =3min 11.009999999999991s
#
# 96
# Epoch duration =1.97s
# Cumulative duration =3min 12.97999999999999s
#
# 97
# Epoch duration =1.99s
# Cumulative duration =3min 14.969999999999999s
#
# 98
# Epoch duration =1.99s
# Cumulative duration =3min 16.960000000000008s
#
# 99
# Epoch duration =2.01s
# Cumulative duration =3min 18.97s
#
# 100
# Epoch duration =1.98s
# Cumulative duration =3min 20.94999999999999s
#
# 101
# Epoch duration =1.98s
# Cumulative duration =3min 22.930000000000007s
#
# 102
# Epoch duration =1.99s
# Cumulative duration =3min 24.919999999999987s
#
# 103
# Epoch duration =1.98s
# Cumulative duration =3min 26.900000000000006s
#
# 104
# Epoch duration =1.98s
# Cumulative duration =3min 28.879999999999995s
#
# 105
# Epoch duration =2.07s
# Cumulative duration =3min 30.94999999999999s
#
# 106
# Epoch duration =2.01s
# Cumulative duration =3min 32.94999999999999s
#
# 107
# Epoch duration =1.99s
# Cumulative duration =3min 34.94s
#
# 108
# Epoch duration =1.99s
# Cumulative duration =3min 36.91999999999999s
#
# 109
# Epoch duration =1.99s
# Cumulative duration =3min 38.91s
#
# 110
# Epoch duration =1.98s
# Cumulative duration =3min 40.889999999999986s
#
# 111
# Epoch duration =1.97s
# Cumulative duration =3min 42.860000000000014s
#
# 112
# Epoch duration =1.97s
# Cumulative duration =3min 44.84s
#
# 113
# Epoch duration =2.0s
# Cumulative duration =3min 46.84s
#
# 114
# Epoch duration =1.98s
# Cumulative duration =3min 48.81999999999999s
#
# 115
# Epoch duration =1.98s
# Cumulative duration =3min 50.80000000000001s
#
# 116
# Epoch duration =1.99s
# Cumulative duration =3min 52.78999999999999s
#
# 117
# Epoch duration =1.99s
# Cumulative duration =3min 54.78s
#
# 118
# Epoch duration =2.01s
# Cumulative duration =3min 56.78999999999999s
#
# 119
# Epoch duration =1.99s
# Cumulative duration =3min 58.78999999999999s
#
# 120
# Epoch duration =1.99s
# Cumulative duration =4min 0.7800000000000011s
#
# 121
# Epoch duration =2.0s
# Cumulative duration =4min 2.780000000000001s
#
# 122
# Epoch duration =1.97s
# Cumulative duration =4min 4.75s
#
# 123
# Epoch duration =1.99s
# Cumulative duration =4min 6.740000000000009s
#
# 124
# Epoch duration =1.99s
# Cumulative duration =4min 8.72999999999999s
#
# 125
# Epoch duration =1.98s
# Cumulative duration =4min 10.719999999999999s
#
# 126
# Epoch duration =1.98s
# Cumulative duration =4min 12.699999999999989s
#
# 127
# Epoch duration =2.01s
# Cumulative duration =4min 14.710000000000008s
#
# 128
# Epoch duration =1.99s
# Cumulative duration =4min 16.689999999999998s
#
# 129
# Epoch duration =1.99s
# Cumulative duration =4min 18.689999999999998s
#
# 130
# Epoch duration =1.99s
# Cumulative duration =4min 20.680000000000007s
#
# 131
# Epoch duration =1.98s
# Cumulative duration =4min 22.649999999999977s
#
# 132
# Epoch duration =1.98s
# Cumulative duration =4min 24.629999999999995s
#
# 133
# Epoch duration =1.98s
# Cumulative duration =4min 26.620000000000005s
#
# 134
# Epoch duration =1.98s
# Cumulative duration =4min 28.600000000000023s
#
# 135
# Epoch duration =1.98s
# Cumulative duration =4min 30.569999999999993s
#
# 136
# Epoch duration =1.99s
# Cumulative duration =4min 32.56s
#
# 137
# Epoch duration =1.99s
# Cumulative duration =4min 34.56s
#
# 138
# Epoch duration =1.98s
# Cumulative duration =4min 36.52999999999997s
#
# 139
# Epoch duration =1.99s
# Cumulative duration =4min 38.51999999999998s
#
# 140
# Epoch duration =1.99s
# Cumulative duration =4min 40.50999999999999s
#
# 141
# Epoch duration =2.0s
# Cumulative duration =4min 42.50999999999999s
#
# 142
# Epoch duration =1.98s
# Cumulative duration =4min 44.49000000000001s
#
# 143
# Epoch duration =2.04s
# Cumulative duration =4min 46.52999999999997s
#
# 144
# Epoch duration =2.02s
# Cumulative duration =4min 48.55000000000001s
#
# 145
# Epoch duration =1.98s
# Cumulative duration =4min 50.54000000000002s
#
# 146
# Epoch duration =2.0s
# Cumulative duration =4min 52.54000000000002s
#
# 147
# Epoch duration =1.98s
# Cumulative duration =4min 54.51999999999998s
#
# 148
# Epoch duration =2.06s
# Cumulative duration =4min 56.579999999999984s
#
# 149
# Epoch duration =1.99s
# Cumulative duration =4min 58.579999999999984s
#
# 150
# Epoch duration =2.01s
# Cumulative duration =5min 0.5799999999999841s
#
# 151
# Epoch duration =1.99s
# Cumulative duration =5min 2.579999999999984s
#
# 152
# Epoch duration =1.99s
# Cumulative duration =5min 4.569999999999993s
#
# 153
# Epoch duration =1.98s
# Cumulative duration =5min 6.550000000000011s
#
# 154
# Epoch duration =1.98s
# Cumulative duration =5min 8.529999999999973s
#
# 155
# Epoch duration =1.99s
# Cumulative duration =5min 10.519999999999982s
#
# 156
# Epoch duration =1.99s
# Cumulative duration =5min 12.509999999999991s
#
# 157
# Epoch duration =2.01s
# Cumulative duration =5min 14.519999999999982s
#
# 158
# Epoch duration =2.0s
# Cumulative duration =5min 16.519999999999982s
#
# 159
# Epoch duration =1.99s
# Cumulative duration =5min 18.50999999999999s
#
# 160
# Epoch duration =1.99s
# Cumulative duration =5min 20.5s
#
# 161
# Epoch duration =1.99s
# Cumulative duration =5min 22.49000000000001s
#
# 162
# Epoch duration =2.0s
# Cumulative duration =5min 24.480000000000018s
#
# 163
# Epoch duration =1.98s
# Cumulative duration =5min 26.45999999999998s
#
# 164
# Epoch duration =1.99s
# Cumulative duration =5min 28.44999999999999s
#
# 165
# Epoch duration =1.99s
# Cumulative duration =5min 30.439999999999998s
#
# 166
# Epoch duration =1.98s
# Cumulative duration =5min 32.420000000000016s
#
# 167
# Epoch duration =1.99s
# Cumulative duration =5min 34.420000000000016s
#
# 168
# Epoch duration =1.98s
# Cumulative duration =5min 36.39999999999998s
#
# 169
# Epoch duration =1.99s
# Cumulative duration =5min 38.389999999999986s
#
# 170
# Epoch duration =1.98s
# Cumulative duration =5min 40.370000000000005s
#
# 171
# Epoch duration =1.99s
# Cumulative duration =5min 42.360000000000014s
#
# 172
# Epoch duration =1.98s
# Cumulative duration =5min 44.339999999999975s
#
# 173
# Epoch duration =2.0s
# Cumulative duration =5min 46.339999999999975s
#
# 174
# Epoch duration =2.0s
# Cumulative duration =5min 48.339999999999975s
#
# 175
# Epoch duration =2.0s
# Cumulative duration =5min 50.35000000000002s
#
# 176
# Epoch duration =2.0s
# Cumulative duration =5min 52.339999999999975s
#
# 177
# Epoch duration =2.0s
# Cumulative duration =5min 54.35000000000002s
#
# 178
# Epoch duration =1.98s
# Cumulative duration =5min 56.329999999999984s
#
# 179
# Epoch duration =1.97s
# Cumulative duration =5min 58.30000000000001s
#
# 180
# Epoch duration =1.98s
# Cumulative duration =6min 0.2799999999999727s
#
# 181
# Epoch duration =1.98s
# Cumulative duration =6min 2.259999999999991s
#
# 182
# Epoch duration =1.99s
# Cumulative duration =6min 4.25s
#
# 183
# Epoch duration =1.99s
# Cumulative duration =6min 6.230000000000018s
#
# 184
# Epoch duration =2.04s
# Cumulative duration =6min 8.279999999999973s
#
# 185
# Epoch duration =1.98s
# Cumulative duration =6min 10.25s
#
# 186
# Epoch duration =1.97s
# Cumulative duration =6min 12.220000000000027s
#
# 187
# Epoch duration =1.99s
# Cumulative duration =6min 14.20999999999998s
#
# 188
# Epoch duration =1.98s
# Cumulative duration =6min 16.189999999999998s
#
# 189
# Epoch duration =1.99s
# Cumulative duration =6min 18.180000000000007s
#
# 190
# Epoch duration =1.99s
# Cumulative duration =6min 20.170000000000016s
#
# 191
# Epoch duration =1.99s
# Cumulative duration =6min 22.160000000000025s
#
# 192
# Epoch duration =1.99s
# Cumulative duration =6min 24.149999999999977s
#
# 193
# Epoch duration =1.99s
# Cumulative duration =6min 26.139999999999986s
#
# 194
# Epoch duration =1.99s
# Cumulative duration =6min 28.120000000000005s
#
# 195
# Epoch duration =2.02s
# Cumulative duration =6min 30.149999999999977s
#
# 196
# Epoch duration =1.98s
# Cumulative duration =6min 32.129999999999995s
#
# 197
# Epoch duration =1.98s
# Cumulative duration =6min 34.110000000000014s
#
# 198
# Epoch duration =2.0s
# Cumulative duration =6min 36.110000000000014s
#
# 199
# Epoch duration =1.99s
# Cumulative duration =6min 38.10000000000002s
#
# 200
# Epoch duration =2.01s
# Cumulative duration =6min 40.10000000000002s
#
# 201
# Epoch duration =1.98s
# Cumulative duration =6min 42.079999999999984s
#
# 202
# Epoch duration =1.98s
# Cumulative duration =6min 44.06999999999999s
#
# 203
# Epoch duration =1.98s
# Cumulative duration =6min 46.05000000000001s
#
# 204
# Epoch duration =2.01s
# Cumulative duration =6min 48.05000000000001s
#
# 205
# Epoch duration =2.0s
# Cumulative duration =6min 50.05000000000001s
#
# 206
# Epoch duration =2.02s
# Cumulative duration =6min 52.06999999999999s
#
# 207
# Epoch duration =2.0s
# Cumulative duration =6min 54.06999999999999s
#
# 208
# Epoch duration =1.98s
# Cumulative duration =6min 56.05000000000001s
#
# 209
# Epoch duration =2.01s
# Cumulative duration =6min 58.06s
#
# 210
# Epoch duration =1.99s
# Cumulative duration =7min 0.05000000000001137s
#
# 211
# Epoch duration =1.98s
# Cumulative duration =7min 2.0299999999999727s
#
# 212
# Epoch duration =1.99s
# Cumulative duration =7min 4.019999999999982s
#
# 213
# Epoch duration =1.99s
# Cumulative duration =7min 6.009999999999991s
#
# 214
# Epoch duration =1.99s
# Cumulative duration =7min 8.0s
#
# 215
# Epoch duration =1.99s
# Cumulative duration =7min 9.990000000000009s
#
# 216
# Epoch duration =1.99s
# Cumulative duration =7min 11.980000000000018s
#
# 217
# Epoch duration =1.99s
# Cumulative duration =7min 13.970000000000027s
#
# 218
# Epoch duration =1.99s
# Cumulative duration =7min 15.949999999999989s
#
# 219
# Epoch duration =1.98s
# Cumulative duration =7min 17.939999999999998s
#
# 220
# Epoch duration =1.98s
# Cumulative duration =7min 19.920000000000016s
#
# 221
# Epoch duration =1.99s
# Cumulative duration =7min 21.899999999999977s
#
# 222
# Epoch duration =1.99s
# Cumulative duration =7min 23.899999999999977s
#
# 223
# Epoch duration =2.0s
# Cumulative duration =7min 25.899999999999977s
#
# 224
# Epoch duration =1.98s
# Cumulative duration =7min 27.879999999999995s
#
# 225
# Epoch duration =1.98s
# Cumulative duration =7min 29.860000000000014s
#
# 226
# Epoch duration =1.99s
# Cumulative duration =7min 31.850000000000023s
#
# 227
# Epoch duration =1.98s
# Cumulative duration =7min 33.829999999999984s
#
# 228
# Epoch duration =1.99s
# Cumulative duration =7min 35.81999999999999s
#
# 229
# Epoch duration =1.98s
# Cumulative duration =7min 37.80000000000001s
#
# 230
# Epoch duration =1.99s
# Cumulative duration =7min 39.79000000000002s
#
# 231
# Epoch duration =1.98s
# Cumulative duration =7min 41.76999999999998s
#
# 232
# Epoch duration =1.98s
# Cumulative duration =7min 43.75999999999999s
#
# 233
# Epoch duration =1.99s
# Cumulative duration =7min 45.74000000000001s
#
# 234
# Epoch duration =2.0s
# Cumulative duration =7min 47.74000000000001s
#
# 235
# Epoch duration =1.98s
# Cumulative duration =7min 49.73000000000002s
#
# 236
# Epoch duration =1.99s
# Cumulative duration =7min 51.70999999999998s
#
# 237
# Epoch duration =1.99s
# Cumulative duration =7min 53.69999999999999s
#
# 238
# Epoch duration =1.99s
# Cumulative duration =7min 55.69s
#
# 239
# Epoch duration =1.98s
# Cumulative duration =7min 57.670000000000016s
#
# 240
# Epoch duration =2.06s
# Cumulative duration =7min 59.74000000000001s
#
# 241
# Epoch duration =1.99s
# Cumulative duration =8min 1.7200000000000273s
#
# 242
# Epoch duration =1.98s
# Cumulative duration =8min 3.6999999999999886s
#
# 243
# Epoch duration =1.98s
# Cumulative duration =8min 5.680000000000007s
#
# 244
# Epoch duration =1.99s
# Cumulative duration =8min 7.670000000000016s
#
# 245
# Epoch duration =2.0s
# Cumulative duration =8min 9.670000000000016s
#
# 246
# Epoch duration =1.98s
# Cumulative duration =8min 11.649999999999977s
#
# 247
# Epoch duration =1.98s
# Cumulative duration =8min 13.629999999999995s
#
# 248
# Epoch duration =2.01s
# Cumulative duration =8min 15.639999999999986s
#
# 249
# Epoch duration =1.99s
# Cumulative duration =8min 17.629999999999995s
#
# 250
# Epoch duration =1.99s
# Cumulative duration =8min 19.620000000000005s
#
# 251
# Epoch duration =2.06s
# Cumulative duration =8min 21.680000000000007s
#
# 252
# Epoch duration =1.99s
# Cumulative duration =8min 23.680000000000007s
#
# 253
# Epoch duration =2.0s
# Cumulative duration =8min 25.670000000000016s
#
# 254
# Epoch duration =1.99s
# Cumulative duration =8min 27.670000000000016s
#
# 255
# Epoch duration =1.99s
# Cumulative duration =8min 29.649999999999977s
#
# 256
# Epoch duration =2.0s
# Cumulative duration =8min 31.649999999999977s
#
# 257
# Epoch duration =1.98s
# Cumulative duration =8min 33.629999999999995s
#
# 258
# Epoch duration =1.99s
# Cumulative duration =8min 35.620000000000005s
#
# 259
# Epoch duration =1.99s
# Cumulative duration =8min 37.60000000000002s
#
# 260
# Epoch duration =1.99s
# Cumulative duration =8min 39.59000000000003s
#
# 261
# Epoch duration =2.0s
# Cumulative duration =8min 41.60000000000002s
#
# 262
# Epoch duration =1.98s
# Cumulative duration =8min 43.58000000000004s
#
# 263
# Epoch duration =1.98s
# Cumulative duration =8min 45.559999999999945s
#
# 264
# Epoch duration =2.0s
# Cumulative duration =8min 47.559999999999945s
#
# 265
# Epoch duration =2.0s
# Cumulative duration =8min 49.559999999999945s
#
# 266
# Epoch duration =1.99s
# Cumulative duration =8min 51.549999999999955s
#
# 267
# Epoch duration =1.99s
# Cumulative duration =8min 53.539999999999964s
#
# 268
# Epoch duration =1.98s
# Cumulative duration =8min 55.51999999999998s
#
# 269
# Epoch duration =1.98s
# Cumulative duration =8min 57.5s
#
# 270
# Epoch duration =1.98s
# Cumulative duration =8min 59.48000000000002s
#
# 271
# Epoch duration =1.98s
# Cumulative duration =9min 1.4600000000000364s
#
# 272
# Epoch duration =1.98s
# Cumulative duration =9min 3.4400000000000546s
#
# 273
# Epoch duration =1.99s
# Cumulative duration =9min 5.419999999999959s
#
# 274
# Epoch duration =2.0s
# Cumulative duration =9min 7.42999999999995s
#
# 275
# Epoch duration =1.98s
# Cumulative duration =9min 9.409999999999968s
#
# 276
# Epoch duration =1.99s
# Cumulative duration =9min 11.399999999999977s
#
# 277
# Epoch duration =1.99s
# Cumulative duration =9min 13.389999999999986s
#
# 278
# Epoch duration =1.98s
# Cumulative duration =9min 15.370000000000005s
#
# 279
# Epoch duration =1.98s
# Cumulative duration =9min 17.350000000000023s
#
# 280
# Epoch duration =2.0s
# Cumulative duration =9min 19.350000000000023s
#
# 281
# Epoch duration =1.99s
# Cumulative duration =9min 21.340000000000032s
#
# 282
# Epoch duration =1.99s
# Cumulative duration =9min 23.32000000000005s
#
# 283
# Epoch duration =1.98s
# Cumulative duration =9min 25.299999999999955s
#
# 284
# Epoch duration =1.98s
# Cumulative duration =9min 27.289999999999964s
#
# 285
# Epoch duration =1.98s
# Cumulative duration =9min 29.25999999999999s
#
# 286
# Epoch duration =1.99s
# Cumulative duration =9min 31.25s
#
# 287
# Epoch duration =1.98s
# Cumulative duration =9min 33.23000000000002s
#
# 288
# Epoch duration =1.99s
# Cumulative duration =9min 35.22000000000003s
#
# 289
# Epoch duration =1.98s
# Cumulative duration =9min 37.210000000000036s
#
# 290
# Epoch duration =1.98s
# Cumulative duration =9min 39.190000000000055s
#
# 291
# Epoch duration =1.99s
# Cumulative duration =9min 41.17999999999995s
#
# 292
# Epoch duration =1.98s
# Cumulative duration =9min 43.15999999999997s
#
# 293
# Epoch duration =2.0s
# Cumulative duration =9min 45.15999999999997s
#
# 294
# Epoch duration =1.98s
# Cumulative duration =9min 47.139999999999986s
#
# 295
# Epoch duration =1.97s
# Cumulative duration =9min 49.120000000000005s
#
# 296
# Epoch duration =2.0s
# Cumulative duration =9min 51.120000000000005s
#
# 297
# Epoch duration =1.98s
# Cumulative duration =9min 53.10000000000002s
#
# 298
# Epoch duration =1.99s
# Cumulative duration =9min 55.09000000000003s
#
# 299
# Epoch duration =1.99s
# Cumulative duration =9min 57.08000000000004s
#
# 300
# Epoch duration =1.98s
# Cumulative duration =9min 59.059999999999945s
#
# 301
# Epoch duration =1.99s
# Cumulative duration =10min 1.0599999999999454s
#
# 302
# Epoch duration =1.99s
# Cumulative duration =10min 3.0499999999999545s
#
# 303
# Epoch duration =1.98s
# Cumulative duration =10min 5.029999999999973s
#
# 304
# Epoch duration =2.01s
# Cumulative duration =10min 7.039999999999964s
#
# 305
# Epoch duration =1.98s
# Cumulative duration =10min 9.019999999999982s
#
# 306
# Epoch duration =2.0s
# Cumulative duration =10min 11.019999999999982s
#
# 307
# Epoch duration =1.99s
# Cumulative duration =10min 13.009999999999991s
#
# 308
# Epoch duration =1.99s
# Cumulative duration =10min 15.0s
#
# 309
# Epoch duration =1.98s
# Cumulative duration =10min 16.980000000000018s
#
# 310
# Epoch duration =2.0s
# Cumulative duration =10min 18.980000000000018s
#
# 311
# Epoch duration =2.0s
# Cumulative duration =10min 20.980000000000018s
#
# 312
# Epoch duration =1.99s
# Cumulative duration =10min 22.970000000000027s
#
# 313
# Epoch duration =1.98s
# Cumulative duration =10min 24.950000000000045s
#
# 314
# Epoch duration =1.98s
# Cumulative duration =10min 26.92999999999995s
#
# 315
# Epoch duration =2.01s
# Cumulative duration =10min 28.92999999999995s
#
# 316
# Epoch duration =1.99s
# Cumulative duration =10min 30.91999999999996s
#
# 317
# Epoch duration =1.99s
# Cumulative duration =10min 32.90999999999997s
#
# 318
# Epoch duration =1.99s
# Cumulative duration =10min 34.89999999999998s
#
# 319
# Epoch duration =1.98s
# Cumulative duration =10min 36.879999999999995s
#
# 320
# Epoch duration =1.99s
# Cumulative duration =10min 38.879999999999995s
#
# 321
# Epoch duration =1.99s
# Cumulative duration =10min 40.870000000000005s
#
# 322
# Epoch duration =1.99s
# Cumulative duration =10min 42.860000000000014s
#
# 323
# Epoch duration =1.99s
# Cumulative duration =10min 44.84000000000003s
#
# 324
# Epoch duration =2.01s
# Cumulative duration =10min 46.860000000000014s
#
# 325
# Epoch duration =1.99s
# Cumulative duration =10min 48.85000000000002s
#
# 326
# Epoch duration =1.99s
# Cumulative duration =10min 50.84000000000003s
#
# 327
# Epoch duration =1.99s
# Cumulative duration =10min 52.83000000000004s
#
# 328
# Epoch duration =2.0s
# Cumulative duration =10min 54.82000000000005s
#
# 329
# Epoch duration =2.0s
# Cumulative duration =10min 56.82000000000005s
#
# 330
# Epoch duration =1.98s
# Cumulative duration =10min 58.799999999999955s
#
# 331
# Epoch duration =1.99s
# Cumulative duration =11min 0.7899999999999636s
#
# 332
# Epoch duration =2.0s
# Cumulative duration =11min 2.7799999999999727s
#
# 333
# Epoch duration =1.98s
# Cumulative duration =11min 4.769999999999982s
#
# 334
# Epoch duration =2.0s
# Cumulative duration =11min 6.769999999999982s
#
# 335
# Epoch duration =1.99s
# Cumulative duration =11min 8.769999999999982s
#
# 336
# Epoch duration =2.05s
# Cumulative duration =11min 10.82000000000005s
#
# 337
# Epoch duration =1.99s
# Cumulative duration =11min 12.809999999999945s
#
# 338
# Epoch duration =1.99s
# Cumulative duration =11min 14.799999999999955s
#
# 339
# Epoch duration =1.99s
# Cumulative duration =11min 16.779999999999973s
#
# 340
# Epoch duration =1.99s
# Cumulative duration =11min 18.769999999999982s
#
# 341
# Epoch duration =1.99s
# Cumulative duration =11min 20.75999999999999s
#
# 342
# Epoch duration =1.99s
# Cumulative duration =11min 22.74000000000001s
#
# 343
# Epoch duration =1.98s
# Cumulative duration =11min 24.730000000000018s
#
# 344
# Epoch duration =1.98s
# Cumulative duration =11min 26.710000000000036s
#
# 345
# Epoch duration =1.98s
# Cumulative duration =11min 28.690000000000055s
#
# 346
# Epoch duration =1.98s
# Cumulative duration =11min 30.66999999999996s
#
# 347
# Epoch duration =1.99s
# Cumulative duration =11min 32.66999999999996s
#
# 348
# Epoch duration =2.01s
# Cumulative duration =11min 34.67999999999995s
#
# 349
# Epoch duration =2.01s
# Cumulative duration =11min 36.690000000000055s
#
# 350
# Epoch duration =1.98s
# Cumulative duration =11min 38.66999999999996s
#
# 351
# Epoch duration =2.0s
# Cumulative duration =11min 40.66999999999996s
#
# 352
# Epoch duration =2.0s
# Cumulative duration =11min 42.66999999999996s
#
# 353
# Epoch duration =2.0s
# Cumulative duration =11min 44.67999999999995s
#
# 354
# Epoch duration =1.98s
# Cumulative duration =11min 46.65999999999997s
#
# 355
# Epoch duration =2.0s
# Cumulative duration =11min 48.66999999999996s
#
# 356
# Epoch duration =1.99s
# Cumulative duration =11min 50.64999999999998s
#
# 357
# Epoch duration =1.99s
# Cumulative duration =11min 52.639999999999986s
#
# 358
# Epoch duration =1.99s
# Cumulative duration =11min 54.629999999999995s
#
# 359
# Epoch duration =1.99s
# Cumulative duration =11min 56.629999999999995s
#
# 360
# Epoch duration =2.0s
# Cumulative duration =11min 58.620000000000005s
#
# 361
# Epoch duration =2.0s
# Cumulative duration =12min 0.6200000000000045s
#
# 362
# Epoch duration =1.99s
# Cumulative duration =12min 2.6100000000000136s
#
# 363
# Epoch duration =2.0s
# Cumulative duration =12min 4.610000000000014s
#
# 364
# Epoch duration =1.99s
# Cumulative duration =12min 6.600000000000023s
#
# 365
# Epoch duration =1.99s
# Cumulative duration =12min 8.590000000000032s
#
# 366
# Epoch duration =2.02s
# Cumulative duration =12min 10.610000000000014s
#
# 367
# Epoch duration =1.98s
# Cumulative duration =12min 12.600000000000023s
#
# 368
# Epoch duration =2.08s
# Cumulative duration =12min 14.67999999999995s
#
# 369
# Epoch duration =1.99s
# Cumulative duration =12min 16.659999999999968s
#
# 370
# Epoch duration =1.98s
# Cumulative duration =12min 18.649999999999977s
#
# 371
# Epoch duration =1.98s
# Cumulative duration =12min 20.629999999999995s
#
# 372
# Epoch duration =1.98s
# Cumulative duration =12min 22.620000000000005s
#
# 373
# Epoch duration =1.99s
# Cumulative duration =12min 24.610000000000014s
#
# 374
# Epoch duration =1.98s
# Cumulative duration =12min 26.590000000000032s
#
# 375
# Epoch duration =2.0s
# Cumulative duration =12min 28.590000000000032s
#
# 376
# Epoch duration =1.98s
# Cumulative duration =12min 30.57000000000005s
#
# 377
# Epoch duration =1.98s
# Cumulative duration =12min 32.549999999999955s
#
# 378
# Epoch duration =1.98s
# Cumulative duration =12min 34.52999999999997s
#
# 379
# Epoch duration =2.0s
# Cumulative duration =12min 36.52999999999997s
#
# 380
# Epoch duration =1.98s
# Cumulative duration =12min 38.50999999999999s
#
# 381
# Epoch duration =1.99s
# Cumulative duration =12min 40.5s
#
# 382
# Epoch duration =1.98s
# Cumulative duration =12min 42.48000000000002s
#
# 383
# Epoch duration =1.99s
# Cumulative duration =12min 44.460000000000036s
#
# 384
# Epoch duration =1.98s
# Cumulative duration =12min 46.450000000000045s
#
# 385
# Epoch duration =1.99s
# Cumulative duration =12min 48.440000000000055s
#
# 386
# Epoch duration =1.98s
# Cumulative duration =12min 50.41999999999996s
#
# 387
# Epoch duration =2.0s
# Cumulative duration =12min 52.41999999999996s
#
# 388
# Epoch duration =2.0s
# Cumulative duration =12min 54.40999999999997s
#
# 389
# Epoch duration =1.98s
# Cumulative duration =12min 56.39999999999998s
#
# 390
# Epoch duration =1.98s
# Cumulative duration =12min 58.379999999999995s
#
# 391
# Epoch duration =2.01s
# Cumulative duration =13min 0.38999999999998636s
#
# 392
# Epoch duration =1.99s
# Cumulative duration =13min 2.3899999999999864s
#
# 393
# Epoch duration =2.0s
# Cumulative duration =13min 4.3799999999999955s
#
# 394
# Epoch duration =1.98s
# Cumulative duration =13min 6.360000000000014s
#
# 395
# Epoch duration =1.98s
# Cumulative duration =13min 8.340000000000032s
#
# 396
# Epoch duration =1.98s
# Cumulative duration =13min 10.32000000000005s
#
# 397
# Epoch duration =1.99s
# Cumulative duration =13min 12.309999999999945s
#
# 398
# Epoch duration =2.0s
# Cumulative duration =13min 14.309999999999945s
#
# 399
# Epoch duration =2.01s
# Cumulative duration =13min 16.32000000000005s
#
# 400
# Epoch duration =2.0s
# Cumulative duration =13min 18.309999999999945s
#
# 401
# Epoch duration =1.99s
# Cumulative duration =13min 20.299999999999955s
#
# 402
# Epoch duration =1.98s
# Cumulative duration =13min 22.279999999999973s
#
# 403
# Epoch duration =2.02s
# Cumulative duration =13min 24.299999999999955s
#
# 404
# Epoch duration =1.98s
# Cumulative duration =13min 26.279999999999973s
#
# 405
# Epoch duration =1.98s
# Cumulative duration =13min 28.25999999999999s
#
# 406
# Epoch duration =1.98s
# Cumulative duration =13min 30.24000000000001s
#
# 407
# Epoch duration =1.99s
# Cumulative duration =13min 32.23000000000002s
#
# 408
# Epoch duration =1.99s
# Cumulative duration =13min 34.22000000000003s
#
# 409
# Epoch duration =1.99s
# Cumulative duration =13min 36.200000000000045s
#
# 410
# Epoch duration =1.98s
# Cumulative duration =13min 38.190000000000055s
#
# 411
# Epoch duration =1.98s
# Cumulative duration =13min 40.15999999999997s
#
# 412
# Epoch duration =2.0s
# Cumulative duration =13min 42.15999999999997s
#
# 413
# Epoch duration =1.98s
# Cumulative duration =13min 44.139999999999986s
#
# 414
# Epoch duration =1.98s
# Cumulative duration =13min 46.129999999999995s
#
# 415
# Epoch duration =1.99s
# Cumulative duration =13min 48.110000000000014s
#
# 416
# Epoch duration =2.01s
# Cumulative duration =13min 50.120000000000005s
#
# 417
# Epoch duration =1.98s
# Cumulative duration =13min 52.10000000000002s
#
# 418
# Epoch duration =1.99s
# Cumulative duration =13min 54.09000000000003s
#
# 419
# Epoch duration =1.99s
# Cumulative duration =13min 56.09000000000003s
#
# 420
# Epoch duration =1.99s
# Cumulative duration =13min 58.07000000000005s
#
# 421
# Epoch duration =1.98s
# Cumulative duration =14min 0.05999999999994543s
#
# 422
# Epoch duration =2.01s
# Cumulative duration =14min 2.0599999999999454s
#
# 423
# Epoch duration =1.99s
# Cumulative duration =14min 4.0499999999999545s
#
# 424
# Epoch duration =1.99s
# Cumulative duration =14min 6.039999999999964s
#
# 425
# Epoch duration =2.01s
# Cumulative duration =14min 8.049999999999955s
#
# 426
# Epoch duration =1.99s
# Cumulative duration =14min 10.039999999999964s
#
# 427
# Epoch duration =2.0s
# Cumulative duration =14min 12.039999999999964s
#
# 428
# Epoch duration =2.0s
# Cumulative duration =14min 14.049999999999955s
#
# 429
# Epoch duration =2.0s
# Cumulative duration =14min 16.049999999999955s
#
# 430
# Epoch duration =1.99s
# Cumulative duration =14min 18.039999999999964s
#
# 431
# Epoch duration =2.02s
# Cumulative duration =14min 20.059999999999945s
#
# 432
# Epoch duration =2.0s
# Cumulative duration =14min 22.059999999999945s
#
# 433
# Epoch duration =1.99s
# Cumulative duration =14min 24.039999999999964s
#
# 434
# Epoch duration =2.0s
# Cumulative duration =14min 26.049999999999955s
#
# 435
# Epoch duration =2.0s
# Cumulative duration =14min 28.039999999999964s
#
# 436
# Epoch duration =1.99s
# Cumulative duration =14min 30.029999999999973s
#
# 437
# Epoch duration =1.98s
# Cumulative duration =14min 32.00999999999999s
#
# 438
# Epoch duration =1.99s
# Cumulative duration =14min 34.0s
#
# 439
# Epoch duration =2.0s
# Cumulative duration =14min 36.00999999999999s
#
# 440
# Epoch duration =1.99s
# Cumulative duration =14min 38.0s
#
# 441
# Epoch duration =1.97s
# Cumulative duration =14min 39.97000000000003s
#
# 442
# Epoch duration =1.98s
# Cumulative duration =14min 41.940000000000055s
#
# 443
# Epoch duration =1.98s
# Cumulative duration =14min 43.92999999999995s
#
# 444
# Epoch duration =1.98s
# Cumulative duration =14min 45.90999999999997s
#
# 445
# Epoch duration =1.98s
# Cumulative duration =14min 47.889999999999986s
#
# 446
# Epoch duration =2.01s
# Cumulative duration =14min 49.89999999999998s
#
# 447
# Epoch duration =2.03s
# Cumulative duration =14min 51.92999999999995s
#
# 448
# Epoch duration =1.99s
# Cumulative duration =14min 53.91999999999996s
#
# 449
# Epoch duration =1.98s
# Cumulative duration =14min 55.89999999999998s
#
# 450
# Epoch duration =1.98s
# Cumulative duration =14min 57.879999999999995s
#
# 451
# Epoch duration =2.0s
# Cumulative duration =14min 59.879999999999995s
#
# 452
# Epoch duration =2.01s
# Cumulative duration =15min 1.8899999999999864s
#
# 453
# Epoch duration =1.99s
# Cumulative duration =15min 3.8799999999999955s
#
# 454
# Epoch duration =1.99s
# Cumulative duration =15min 5.8700000000000045s
#
# 455
# Epoch duration =2.06s
# Cumulative duration =15min 7.919999999999959s
#
# 456
# Epoch duration =1.98s
# Cumulative duration =15min 9.899999999999977s
#
# 457
# Epoch duration =1.99s
# Cumulative duration =15min 11.889999999999986s
#
# 458
# Epoch duration =1.99s
# Cumulative duration =15min 13.879999999999995s
#
# 459
# Epoch duration =2.0s
# Cumulative duration =15min 15.879999999999995s
#
# 460
# Epoch duration =2.01s
# Cumulative duration =15min 17.889999999999986s
#
# 461
# Epoch duration =1.99s
# Cumulative duration =15min 19.879999999999995s
#
# 462
# Epoch duration =1.99s
# Cumulative duration =15min 21.870000000000005s
#
# 463
# Epoch duration =1.99s
# Cumulative duration =15min 23.860000000000014s
#
# 464
# Epoch duration =1.99s
# Cumulative duration =15min 25.850000000000023s
#
# 465
# Epoch duration =1.99s
# Cumulative duration =15min 27.840000000000032s
#
# 466
# Epoch duration =1.99s
# Cumulative duration =15min 29.83000000000004s
#
# 467
# Epoch duration =1.99s
# Cumulative duration =15min 31.809999999999945s
#
# 468
# Epoch duration =1.99s
# Cumulative duration =15min 33.799999999999955s
#
# 469
# Epoch duration =1.98s
# Cumulative duration =15min 35.77999999999997s
#
# 470
# Epoch duration =1.98s
# Cumulative duration =15min 37.75999999999999s
#
# 471
# Epoch duration =1.98s
# Cumulative duration =15min 39.74000000000001s
#
# 472
# Epoch duration =1.99s
# Cumulative duration =15min 41.73000000000002s
#
# 473
# Epoch duration =1.98s
# Cumulative duration =15min 43.710000000000036s
#
# 474
# Epoch duration =1.98s
# Cumulative duration =15min 45.690000000000055s
#
# 475
# Epoch duration =1.98s
# Cumulative duration =15min 47.66999999999996s
#
# 476
# Epoch duration =1.99s
# Cumulative duration =15min 49.65999999999997s
#
# 477
# Epoch duration =1.99s
# Cumulative duration =15min 51.639999999999986s
#
# 478
# Epoch duration =1.99s
# Cumulative duration =15min 53.639999999999986s
#
# 479
# Epoch duration =1.99s
# Cumulative duration =15min 55.629999999999995s
#
# 480
# Epoch duration =1.98s
# Cumulative duration =15min 57.610000000000014s
#
# 481
# Epoch duration =1.98s
# Cumulative duration =15min 59.60000000000002s
#
# 482
# Epoch duration =1.97s
# Cumulative duration =16min 1.57000000000005s
#
# 483
# Epoch duration =1.98s
# Cumulative duration =16min 3.5499999999999545s
#
# 484
# Epoch duration =1.99s
# Cumulative duration =16min 5.529999999999973s
#
# 485
# Epoch duration =1.98s
# Cumulative duration =16min 7.509999999999991s
#
# 486
# Epoch duration =1.98s
# Cumulative duration =16min 9.5s
#
# 487
# Epoch duration =1.99s
# Cumulative duration =16min 11.480000000000018s
#
# 488
# Epoch duration =2.0s
# Cumulative duration =16min 13.480000000000018s
#
# 489
# Epoch duration =1.98s
# Cumulative duration =16min 15.450000000000045s
#
# 490
# Epoch duration =2.01s
# Cumulative duration =16min 17.460000000000036s
#
# 491
# Epoch duration =1.97s
# Cumulative duration =16min 19.440000000000055s
#
# 492
# Epoch duration =1.99s
# Cumulative duration =16min 21.41999999999996s
#
# 493
# Epoch duration =1.98s
# Cumulative duration =16min 23.399999999999977s
#
# 494
# Epoch duration =2.0s
# Cumulative duration =16min 25.399999999999977s
#
# 495
# Epoch duration =1.98s
# Cumulative duration =16min 27.379999999999995s
#
# 496
# Epoch duration =1.99s
# Cumulative duration =16min 29.370000000000005s
#
# 497
# Epoch duration =2.01s
# Cumulative duration =16min 31.379999999999995s
#
# 498
# Epoch duration =2.01s
# Cumulative duration =16min 33.389999999999986s
#
# 499
# Epoch duration =1.98s
# Cumulative duration =16min 35.379999999999995s
#
# 500
# Epoch duration =1.99s
# Cumulative duration =16min 37.370000000000005s
#
# 501
# Epoch duration =1.99s
# Cumulative duration =16min 39.360000000000014s
#
# 502
# Epoch duration =2.03s
# Cumulative duration =16min 41.389999999999986s
#
# 503
# Epoch duration =1.99s
# Cumulative duration =16min 43.379999999999995s
#
# 504
# Epoch duration =1.99s
# Cumulative duration =16min 45.370000000000005s
#
# 505
# Epoch duration =1.99s
# Cumulative duration =16min 47.360000000000014s
#
# 506
# Epoch duration =1.99s
# Cumulative duration =16min 49.360000000000014s
#
# 507
# Epoch duration =1.98s
# Cumulative duration =16min 51.34000000000003s
#
# 508
# Epoch duration =2.01s
# Cumulative duration =16min 53.35000000000002s
#
# 509
# Epoch duration =2.04s
# Cumulative duration =16min 55.389999999999986s
#
# 510
# Epoch duration =2.0s
# Cumulative duration =16min 57.389999999999986s
#
# 511
# Epoch duration =1.99s
# Cumulative duration =16min 59.379999999999995s
#
# 512
# Epoch duration =1.98s
# Cumulative duration =17min 1.3600000000000136s
#
# 513
# Epoch duration =1.98s
# Cumulative duration =17min 3.340000000000032s
#
# 514
# Epoch duration =1.99s
# Cumulative duration =17min 5.329999999999927s
#
# 515
# Epoch duration =2.02s
# Cumulative duration =17min 7.349999999999909s
#
# 516
# Epoch duration =1.99s
# Cumulative duration =17min 9.339999999999918s
#
# 517
# Epoch duration =2.01s
# Cumulative duration =17min 11.349999999999909s
#
# 518
# Epoch duration =2.0s
# Cumulative duration =17min 13.339999999999918s
#
# 519
# Epoch duration =1.99s
# Cumulative duration =17min 15.339999999999918s
#
# 520
# Epoch duration =2.0s
# Cumulative duration =17min 17.339999999999918s
#
# 521
# Epoch duration =1.98s
# Cumulative duration =17min 19.319999999999936s
#
# 522
# Epoch duration =1.98s
# Cumulative duration =17min 21.299999999999955s
#
# 523
# Epoch duration =1.98s
# Cumulative duration =17min 23.279999999999973s
#
# 524
# Epoch duration =1.99s
# Cumulative duration =17min 25.269999999999982s
#
# 525
# Epoch duration =1.98s
# Cumulative duration =17min 27.25s
#
# 526
# Epoch duration =1.98s
# Cumulative duration =17min 29.230000000000018s
#
# 527
# Epoch duration =1.97s
# Cumulative duration =17min 31.200000000000045s
#
# 528
# Epoch duration =1.99s
# Cumulative duration =17min 33.200000000000045s
#
# 529
# Epoch duration =1.99s
# Cumulative duration =17min 35.190000000000055s
#
# 530
# Epoch duration =2.02s
# Cumulative duration =17min 37.210000000000036s
#
# 531
# Epoch duration =1.99s
# Cumulative duration =17min 39.200000000000045s
#
# 532
# Epoch duration =1.98s
# Cumulative duration =17min 41.190000000000055s
#
# 533
# Epoch duration =1.98s
# Cumulative duration =17min 43.17000000000007s
#
# 534
# Epoch duration =2.01s
# Cumulative duration =17min 45.180000000000064s
#
# 535
# Epoch duration =1.98s
# Cumulative duration =17min 47.16000000000008s
#
# 536
# Epoch duration =1.98s
# Cumulative duration =17min 49.15000000000009s
#
# 537
# Epoch duration =1.99s
# Cumulative duration =17min 51.1400000000001s
#
# 538
# Epoch duration =2.0s
# Cumulative duration =17min 53.1400000000001s
#
# 539
# Epoch duration =2.01s
# Cumulative duration =17min 55.15000000000009s
#
# 540
# Epoch duration =1.98s
# Cumulative duration =17min 57.13000000000011s
#
# 541
# Epoch duration =1.98s
# Cumulative duration =17min 59.1099999999999s
#
# 542
# Epoch duration =2.03s
# Cumulative duration =18min 1.1400000000001s
#
# 543
# Epoch duration =2.02s
# Cumulative duration =18min 3.150000000000091s
#
# 544
# Epoch duration =1.98s
# Cumulative duration =18min 5.1400000000001s
#
# 545
# Epoch duration =1.99s
# Cumulative duration =18min 7.130000000000109s
#
# 546
# Epoch duration =1.99s
# Cumulative duration =18min 9.11999999999989s
#
# 547
# Epoch duration =1.99s
# Cumulative duration =18min 11.1099999999999s
#
# 548
# Epoch duration =1.99s
# Cumulative duration =18min 13.099999999999909s
#
# 549
# Epoch duration =1.99s
# Cumulative duration =18min 15.089999999999918s
#
# 550
# Epoch duration =2.0s
# Cumulative duration =18min 17.089999999999918s
#
# 551
# Epoch duration =2.02s
# Cumulative duration =18min 19.1099999999999s
#
# 552
# Epoch duration =2.0s
# Cumulative duration =18min 21.09999999999991s
#
# 553
# Epoch duration =1.98s
# Cumulative duration =18min 23.079999999999927s
#
# 554
# Epoch duration =2.01s
# Cumulative duration =18min 25.089999999999918s
#
# 555
# Epoch duration =1.99s
# Cumulative duration =18min 27.079999999999927s
#
# 556
# Epoch duration =1.99s
# Cumulative duration =18min 29.079999999999927s
#
# 557
# Epoch duration =2.03s
# Cumulative duration =18min 31.1099999999999s
#
# 558
# Epoch duration =1.99s
# Cumulative duration =18min 33.09999999999991s
#
# 559
# Epoch duration =1.99s
# Cumulative duration =18min 35.07999999999993s
#
# 560
# Epoch duration =2.0s
# Cumulative duration =18min 37.08999999999992s
#
# 561
# Epoch duration =1.98s
# Cumulative duration =18min 39.069999999999936s
#
# 562
# Epoch duration =1.98s
# Cumulative duration =18min 41.049999999999955s
#
# 563
# Epoch duration =1.99s
# Cumulative duration =18min 43.049999999999955s
#
# 564
# Epoch duration =2.01s
# Cumulative duration =18min 45.049999999999955s
#
# 565
# Epoch duration =2.0s
# Cumulative duration =18min 47.049999999999955s
#
# 566
# Epoch duration =1.99s
# Cumulative duration =18min 49.049999999999955s
#
# 567
# Epoch duration =2.0s
# Cumulative duration =18min 51.049999999999955s
#
# 568
# Epoch duration =2.02s
# Cumulative duration =18min 53.069999999999936s
#
# 569
# Epoch duration =2.02s
# Cumulative duration =18min 55.07999999999993s
#
# 570
# Epoch duration =2.01s
# Cumulative duration =18min 57.08999999999992s
#
# 571
# Epoch duration =2.01s
# Cumulative duration =18min 59.09999999999991s
#
# 572
# Epoch duration =1.99s
# Cumulative duration =19min 1.0899999999999181s
#
# 573
# Epoch duration =2.01s
# Cumulative duration =19min 3.099999999999909s
#
# 574
# Epoch duration =1.99s
# Cumulative duration =19min 5.099999999999909s
#
# 575
# Epoch duration =1.98s
# Cumulative duration =19min 7.079999999999927s
#
# 576
# Epoch duration =2.0s
# Cumulative duration =19min 9.079999999999927s
#
# 577
# Epoch duration =1.99s
# Cumulative duration =19min 11.059999999999945s
#
# 578
# Epoch duration =1.98s
# Cumulative duration =19min 13.039999999999964s
#
# 579
# Epoch duration =1.98s
# Cumulative duration =19min 15.019999999999982s
#
# 580
# Epoch duration =1.99s
# Cumulative duration =19min 17.00999999999999s
#
# 581
# Epoch duration =1.99s
# Cumulative duration =19min 19.0s
#
# 582
# Epoch duration =2.01s
# Cumulative duration =19min 21.00999999999999s
#
# 583
# Epoch duration =2.02s
# Cumulative duration =19min 23.029999999999973s
#
# 584
# Epoch duration =1.99s
# Cumulative duration =19min 25.019999999999982s
#
# 585
# Epoch duration =1.98s
# Cumulative duration =19min 27.0s
#
# 586
# Epoch duration =1.99s
# Cumulative duration =19min 28.99000000000001s
#
# 587
# Epoch duration =2.0s
# Cumulative duration =19min 30.99000000000001s
#
# 588
# Epoch duration =1.99s
# Cumulative duration =19min 32.98000000000002s
#
# 589
# Epoch duration =1.98s
# Cumulative duration =19min 34.960000000000036s
#
# 590
# Epoch duration =1.98s
# Cumulative duration =19min 36.940000000000055s
#
# 591
# Epoch duration =1.99s
# Cumulative duration =19min 38.930000000000064s
#
# 592
# Epoch duration =2.01s
# Cumulative duration =19min 40.950000000000045s
#
# 593
# Epoch duration =1.99s
# Cumulative duration =19min 42.940000000000055s
#
# 594
# Epoch duration =2.01s
# Cumulative duration =19min 44.950000000000045s
#
# 595
# Epoch duration =2.02s
# Cumulative duration =19min 46.97000000000003s
#
# 596
# Epoch duration =2.02s
# Cumulative duration =19min 48.99000000000001s
#
# 597
# Epoch duration =1.98s
# Cumulative duration =19min 50.97000000000003s
#
# 598
# Epoch duration =1.98s
# Cumulative duration =19min 52.960000000000036s
#
# 599
# Epoch duration =1.98s
# Cumulative duration =19min 54.940000000000055s
#
# 600
# Epoch duration =1.99s
# Cumulative duration =19min 56.92000000000007s
#
# 601
# Epoch duration =1.98s
# Cumulative duration =19min 58.90000000000009s
#
# 602
# Epoch duration =1.99s
# Cumulative duration =20min 0.900000000000091s
#
# 603
# Epoch duration =2.04s
# Cumulative duration =20min 2.9400000000000546s
#
# 604
# Epoch duration =2.02s
# Cumulative duration =20min 4.960000000000036s
#
# 605
# Epoch duration =2.01s
# Cumulative duration =20min 6.970000000000027s
#
# 606
# Epoch duration =1.99s
# Cumulative duration =20min 8.970000000000027s
#
# 607
# Epoch duration =2.0s
# Cumulative duration =20min 10.960000000000036s
#
# 608
# Epoch duration =2.01s
# Cumulative duration =20min 12.980000000000018s
#
# 609
# Epoch duration =1.98s
# Cumulative duration =20min 14.950000000000045s
#
# 610
# Epoch duration =2.0s
# Cumulative duration =20min 16.950000000000045s
#
# 611
# Epoch duration =1.99s
# Cumulative duration =20min 18.940000000000055s
#
# 612
# Epoch duration =1.99s
# Cumulative duration =20min 20.940000000000055s
#
# 613
# Epoch duration =2.0s
# Cumulative duration =20min 22.930000000000064s
#
# 614
# Epoch duration =1.97s
# Cumulative duration =20min 24.90000000000009s
#
# 615
# Epoch duration =1.99s
# Cumulative duration =20min 26.8900000000001s
#
# 616
# Epoch duration =1.98s
# Cumulative duration =20min 28.88000000000011s
#
# 617
# Epoch duration =2.0s
# Cumulative duration =20min 30.88000000000011s
#
# 618
# Epoch duration =1.99s
# Cumulative duration =20min 32.88000000000011s
#
# 619
# Epoch duration =1.98s
# Cumulative duration =20min 34.8599999999999s
#
# 620
# Epoch duration =1.97s
# Cumulative duration =20min 36.82999999999993s
#
# 621
# Epoch duration =1.97s
# Cumulative duration =20min 38.799999999999955s
#
# 622
# Epoch duration =1.99s
# Cumulative duration =20min 40.789999999999964s
#
# 623
# Epoch duration =1.99s
# Cumulative duration =20min 42.77999999999997s
#
# 624
# Epoch duration =1.99s
# Cumulative duration =20min 44.76999999999998s
#
# 625
# Epoch duration =2.0s
# Cumulative duration =20min 46.75999999999999s
#
# 626
# Epoch duration =2.0s
# Cumulative duration =20min 48.75999999999999s
#
# 627
# Epoch duration =1.99s
# Cumulative duration =20min 50.75s
#
# 628
# Epoch duration =2.01s
# Cumulative duration =20min 52.75999999999999s
#
# 629
# Epoch duration =2.0s
# Cumulative duration =20min 54.75999999999999s
#
# 630
# Epoch duration =1.99s
# Cumulative duration =20min 56.75s
#
# 631
# Epoch duration =2.02s
# Cumulative duration =20min 58.76999999999998s
#
# 632
# Epoch duration =2.03s
# Cumulative duration =21min 0.8099999999999454s
#
# 633
# Epoch duration =1.99s
# Cumulative duration =21min 2.7999999999999545s
#
# 634
# Epoch duration =1.99s
# Cumulative duration =21min 4.789999999999964s
#
# 635
# Epoch duration =1.99s
# Cumulative duration =21min 6.779999999999973s
#
# 636
# Epoch duration =1.98s
# Cumulative duration =21min 8.759999999999991s
#
# 637
# Epoch duration =1.99s
# Cumulative duration =21min 10.759999999999991s
#
# 638
# Epoch duration =2.0s
# Cumulative duration =21min 12.759999999999991s
#
# 639
# Epoch duration =1.99s
# Cumulative duration =21min 14.740000000000009s
#
# 640
# Epoch duration =1.99s
# Cumulative duration =21min 16.74000000000001s
#
# 641
# Epoch duration =2.0s
# Cumulative duration =21min 18.74000000000001s
#
# 642
# Epoch duration =1.99s
# Cumulative duration =21min 20.730000000000018s
#
# 643
# Epoch duration =1.99s
# Cumulative duration =21min 22.720000000000027s
#
# 644
# Epoch duration =2.01s
# Cumulative duration =21min 24.720000000000027s
#
# 645
# Epoch duration =1.99s
# Cumulative duration =21min 26.720000000000027s
#
# 646
# Epoch duration =2.02s
# Cumulative duration =21min 28.74000000000001s
#
# 647
# Epoch duration =1.98s
# Cumulative duration =21min 30.720000000000027s
#
# 648
# Epoch duration =2.01s
# Cumulative duration =21min 32.73000000000002s
#
# 649
# Epoch duration =1.99s
# Cumulative duration =21min 34.72000000000003s
#
# 650
# Epoch duration =1.99s
# Cumulative duration =21min 36.710000000000036s
#
# 651
# Epoch duration =1.98s
# Cumulative duration =21min 38.690000000000055s
#
# 652
# Epoch duration =2.01s
# Cumulative duration =21min 40.700000000000045s
#
# 653
# Epoch duration =1.98s
# Cumulative duration =21min 42.680000000000064s
#
# 654
# Epoch duration =1.99s
# Cumulative duration =21min 44.67000000000007s
#
# 655
# Epoch duration =1.98s
# Cumulative duration =21min 46.65000000000009s
#
# 656
# Epoch duration =1.97s
# Cumulative duration =21min 48.63000000000011s
#
# 657
# Epoch duration =1.98s
# Cumulative duration =21min 50.6099999999999s
#
# 658
# Epoch duration =1.98s
# Cumulative duration =21min 52.58999999999992s
#
# 659
# Epoch duration =2.02s
# Cumulative duration =21min 54.6099999999999s
#
# 660
# Epoch duration =2.0s
# Cumulative duration =21min 56.6099999999999s
#
# 661
# Epoch duration =1.98s
# Cumulative duration =21min 58.58999999999992s
#
# 662
# Epoch duration =1.98s
# Cumulative duration =22min 0.5799999999999272s
#
# 663
# Epoch duration =1.98s
# Cumulative duration =22min 2.5599999999999454s
#
# 664
# Epoch duration =1.98s
# Cumulative duration =22min 4.539999999999964s
#
# 665
# Epoch duration =1.99s
# Cumulative duration =22min 6.529999999999973s
#
# 666
# Epoch duration =1.98s
# Cumulative duration =22min 8.509999999999991s
#
# 667
# Epoch duration =1.97s
# Cumulative duration =22min 10.480000000000018s
#
# 668
# Epoch duration =1.98s
# Cumulative duration =22min 12.460000000000036s
#
# 669
# Epoch duration =1.98s
# Cumulative duration =22min 14.440000000000055s
#
# 670
# Epoch duration =1.98s
# Cumulative duration =22min 16.420000000000073s
#
# 671
# Epoch duration =1.98s
# Cumulative duration =22min 18.40000000000009s
#
# 672
# Epoch duration =2.0s
# Cumulative duration =22min 20.40000000000009s
#
# 673
# Epoch duration =1.99s
# Cumulative duration =22min 22.3900000000001s
#
# 674
# Epoch duration =1.98s
# ...
#
# 781
# Epoch duration =1.99s
# Cumulative duration =25min 57.27999999999997s
#
# 782
# Epoch duration =1.98s
# Cumulative duration =25min 59.26999999999998s
#
# 783
# Epoch duration =1.99s
# Cumulative duration =26min 1.25s
#
# 784
# Epoch duration =1.98s
# Cumulative duration =26min 3.230000000000018s
#
# 785
# Epoch duration =2.01s
# Cumulative duration =26min 5.25s
#
# 786
# Epoch duration =1.98s
# Cumulative duration =26min 7.230000000000018s
#
# 787
# Epoch duration =1.98s
# Cumulative duration =26min 9.210000000000036s
#
# 788
# Epoch duration =2.0s
# Cumulative duration =26min 11.210000000000036s
#
# 789
# Epoch duration =1.99s
# Cumulative duration =26min 13.190000000000055s
#
# 790
# Epoch duration =1.98s
# Cumulative duration =26min 15.180000000000064s
#
# 791
# Epoch duration =2.03s
# Cumulative duration =26min 17.200000000000045s
#
# 792
# Epoch duration =2.0s
# Cumulative duration =26min 19.200000000000045s
#
# 793
# Epoch duration =1.99s
# Cumulative duration =26min 21.190000000000055s
#
# 794
# Epoch duration =1.98s
# Cumulative duration =26min 23.170000000000073s
#
# 795
# Epoch duration =2.0s
# Cumulative duration =26min 25.170000000000073s
#
# 796
# Epoch duration =1.98s
# Cumulative duration =26min 27.15000000000009s
#
# 797
# Epoch duration =1.99s
# Cumulative duration =26min 29.1400000000001s
#
# 798
# Epoch duration =1.98s
# Cumulative duration =26min 31.11999999999989s
#
# 799
# Epoch duration =1.99s
# Cumulative duration =26min 33.1099999999999s
#
# 800
# Epoch duration =1.99s
# Cumulative duration =26min 35.09999999999991s
#
# 801
# Epoch duration =2.0s
# Cumulative duration =26min 37.09999999999991s
#
# 802
# Epoch duration =1.98s
# Cumulative duration =26min 39.07999999999993s
#
# 803
# Epoch duration =1.99s
# Cumulative duration =26min 41.069999999999936s
#
# 804
# Epoch duration =1.99s
# Cumulative duration =26min 43.069999999999936s
#
# 805
# Epoch duration =1.99s
# Cumulative duration =26min 45.059999999999945s
#
# 806
# Epoch duration =1.98s
# Cumulative duration =26min 47.039999999999964s
#
# 807
# Epoch duration =1.97s
# Cumulative duration =26min 49.00999999999999s
#
# 808
# Epoch duration =1.99s
# Cumulative duration =26min 51.0s
#
# 809
# Epoch duration =2.0s
# Cumulative duration =26min 53.0s
#
# 810
# Epoch duration =2.0s
# Cumulative duration =26min 55.0s
#
# 811
# Epoch duration =1.98s
# Cumulative duration =26min 56.98000000000002s
#
# 812
# Epoch duration =1.98s
# Cumulative duration =26min 58.960000000000036s
#
# 813
# Epoch duration =1.98s
# Cumulative duration =27min 0.9500000000000455s
#
# 814
# Epoch duration =2.03s
# Cumulative duration =27min 2.9700000000000273s
#
# 815
# Epoch duration =2.0s
# Cumulative duration =27min 4.970000000000027s
#
# 816
# Epoch duration =1.99s
# Cumulative duration =27min 6.960000000000036s
#
# 817
# Epoch duration =1.98s
# Cumulative duration =27min 8.940000000000055s
#
# 818
# Epoch duration =1.98s
# Cumulative duration =27min 10.920000000000073s
#
# 819
# Epoch duration =1.98s
# Cumulative duration =27min 12.910000000000082s
#
# 820
# Epoch duration =1.98s
# Cumulative duration =27min 14.8900000000001s
#
# 821
# Epoch duration =1.98s
# Cumulative duration =27min 16.86999999999989s
#
# 822
# Epoch duration =2.0s
# Cumulative duration =27min 18.86999999999989s
#
# 823
# Epoch duration =1.99s
# Cumulative duration =27min 20.84999999999991s
#
# 824
# Epoch duration =1.98s
# Cumulative duration =27min 22.829999999999927s
#
# 825
# Epoch duration =2.0s
# Cumulative duration =27min 24.829999999999927s
#
# 826
# Epoch duration =2.0s
# Cumulative duration =27min 26.829999999999927s
#
# 827
# Epoch duration =1.99s
# Cumulative duration =27min 28.829999999999927s
#
# 828
# Epoch duration =1.99s
# Cumulative duration =27min 30.809999999999945s
#
# 829
# Epoch duration =1.98s
# Cumulative duration =27min 32.789999999999964s
#
# 830
# Epoch duration =1.99s
# Cumulative duration =27min 34.77999999999997s
#
# 831
# Epoch duration =1.98s
# Cumulative duration =27min 36.75999999999999s
#
# 832
# Epoch duration =1.98s
# Cumulative duration =27min 38.74000000000001s
#
# 833
# Epoch duration =1.99s
# Cumulative duration =27min 40.73000000000002s
#
# 834
# Epoch duration =1.99s
# Cumulative duration =27min 42.72000000000003s
#
# 835
# Epoch duration =2.02s
# Cumulative duration =27min 44.74000000000001s
#
# 836
# Epoch duration =1.99s
# Cumulative duration =27min 46.74000000000001s
#
# 837
# Epoch duration =1.99s
# Cumulative duration =27min 48.72000000000003s
#
# 838
# Epoch duration =1.99s
# Cumulative duration =27min 50.710000000000036s
#
# 839
# Epoch duration =1.98s
# Cumulative duration =27min 52.690000000000055s
#
# 840
# Epoch duration =1.98s
# Cumulative duration =27min 54.680000000000064s
#
# 841
# Epoch duration =1.98s
# Cumulative duration =27min 56.65000000000009s
#
# 842
# Epoch duration =1.98s
# Cumulative duration =27min 58.6400000000001s
#
# 843
# Epoch duration =1.99s
# Cumulative duration =28min 0.6300000000001091s
#
# 844
# Epoch duration =2.0s
# Cumulative duration =28min 2.630000000000109s
#
# 845
# Epoch duration =1.98s
# Cumulative duration =28min 4.6099999999999s
#
# 846
# Epoch duration =2.0s
# Cumulative duration =28min 6.599999999999909s
#
# 847
# Epoch duration =1.98s
# Cumulative duration =28min 8.589999999999918s
#
# 848
# Epoch duration =1.98s
# Cumulative duration =28min 10.569999999999936s
#
# 849
# Epoch duration =1.99s
# Cumulative duration =28min 12.559999999999945s
#
# 850
# Epoch duration =1.98s
# Cumulative duration =28min 14.539999999999964s
#
# 851
# Epoch duration =1.99s
# Cumulative duration =28min 16.519999999999982s
#
# 852
# Epoch duration =1.99s
# Cumulative duration =28min 18.519999999999982s
#
# 853
# Epoch duration =1.99s
# Cumulative duration =28min 20.50999999999999s
#
# 854
# Epoch duration =1.98s
# Cumulative duration =28min 22.49000000000001s
#
# 855
# Epoch duration =1.99s
# Cumulative duration =28min 24.480000000000018s
#
# 856
# Epoch duration =1.99s
# Cumulative duration =28min 26.470000000000027s
#
# 857
# Epoch duration =2.0s
# Cumulative duration =28min 28.470000000000027s
#
# 858
# Epoch duration =2.03s
# Cumulative duration =28min 30.50999999999999s
#
# 859
# Epoch duration =1.98s
# Cumulative duration =28min 32.49000000000001s
#
# 860
# Epoch duration =1.98s
# Cumulative duration =28min 34.47000000000003s
#
# 861
# Epoch duration =1.99s
# Cumulative duration =28min 36.460000000000036s
#
# 862
# Epoch duration =1.99s
# Cumulative duration =28min 38.450000000000045s
#
# 863
# Epoch duration =2.0s
# Cumulative duration =28min 40.440000000000055s
#
# 864
# Epoch duration =1.99s
# Cumulative duration =28min 42.430000000000064s
#
# 865
# Epoch duration =1.99s
# Cumulative duration =28min 44.42000000000007s
#
# 866
# Epoch duration =2.0s
# Cumulative duration =28min 46.42000000000007s
#
# 867
# Epoch duration =1.98s
# Cumulative duration =28min 48.40000000000009s
#
# 868
# Epoch duration =1.99s
# Cumulative duration =28min 50.3900000000001s
#
# 869
# Epoch duration =2.01s
# Cumulative duration =28min 52.40000000000009s
#
# 870
# Epoch duration =2.01s
# Cumulative duration =28min 54.41000000000008s
#
# 871
# Epoch duration =2.01s
# Cumulative duration =28min 56.42000000000007s
#
# 872
# Epoch duration =1.98s
# Cumulative duration =28min 58.41000000000008s
#
# 873
# Epoch duration =2.01s
# Cumulative duration =29min 0.42000000000007276s
#
# 874
# Epoch duration =2.04s
# Cumulative duration =29min 2.4500000000000455s
#
# 875
# Epoch duration =1.99s
# Cumulative duration =29min 4.440000000000055s
#
# 876
# Epoch duration =2.03s
# Cumulative duration =29min 6.470000000000027s
#
# 877
# Epoch duration =1.98s
# Cumulative duration =29min 8.460000000000036s
#
# 878
# Epoch duration =2.01s
# Cumulative duration =29min 10.470000000000027s
#
# 879
# Epoch duration =1.98s
# Cumulative duration =29min 12.440000000000055s
#
# 880
# Epoch duration =1.99s
# Cumulative duration =29min 14.430000000000064s
#
# 881
# Epoch duration =1.98s
# Cumulative duration =29min 16.420000000000073s
#
# 882
# Epoch duration =1.99s
# Cumulative duration =29min 18.410000000000082s
#
# 883
# Epoch duration =2.0s
# Cumulative duration =29min 20.410000000000082s
#
# 884
# Epoch duration =2.0s
# Cumulative duration =29min 22.410000000000082s
#
# 885
# Epoch duration =1.97s
# Cumulative duration =29min 24.38000000000011s
#
# 886
# Epoch duration =1.98s
# Cumulative duration =29min 26.34999999999991s
#
# 887
# Epoch duration =1.99s
# Cumulative duration =29min 28.339999999999918s
#
# 888
# Epoch duration =1.98s
# Cumulative duration =29min 30.329999999999927s
#
# 889
# Epoch duration =2.0s
# Cumulative duration =29min 32.319999999999936s
#
# 890
# Epoch duration =2.02s
# Cumulative duration =29min 34.33999999999992s
#
# 891
# Epoch duration =2.0s
# Cumulative duration =29min 36.33999999999992s
#
# 892
# Epoch duration =1.99s
# Cumulative duration =29min 38.32999999999993s
#
# 893
# Epoch duration =2.0s
# Cumulative duration =29min 40.32999999999993s
#
# 894
# Epoch duration =2.0s
# Cumulative duration =29min 42.32999999999993s
#
# 895
# Epoch duration =1.99s
# Cumulative duration =29min 44.319999999999936s
#
# 896
# Epoch duration =1.98s
# Cumulative duration =29min 46.309999999999945s
#
# 897
# Epoch duration =1.98s
# Cumulative duration =29min 48.289999999999964s
#
# 898
# Epoch duration =1.98s
# Cumulative duration =29min 50.26999999999998s
#
# 899
# Epoch duration =2.0s
# Cumulative duration =29min 52.26999999999998s
#
# 900
# Epoch duration =1.99s
# Cumulative duration =29min 54.25999999999999s
#
# 901
# Epoch duration =1.99s
# Cumulative duration =29min 56.25s
#
# 902
# Epoch duration =1.98s
# Cumulative duration =29min 58.24000000000001s
#
# 903
# Epoch duration =1.98s
# Cumulative duration =30min 0.22000000000002728s
#
# 904
# Epoch duration =2.0s
# Cumulative duration =30min 2.2200000000000273s
#
# 905
# Epoch duration =1.98s
# Cumulative duration =30min 4.2000000000000455s
#
# 906
# Epoch duration =1.98s
# Cumulative duration =30min 6.180000000000064s
#
# 907
# Epoch duration =2.01s
# Cumulative duration =30min 8.190000000000055s
#
# 908
# Epoch duration =1.98s
# Cumulative duration =30min 10.170000000000073s
#
# 909
# Epoch duration =1.98s
# Cumulative duration =30min 12.150000000000091s
#
# 910
# Epoch duration =1.99s
# Cumulative duration =30min 14.1400000000001s
#
# 911
# Epoch duration =1.99s
# Cumulative duration =30min 16.11999999999989s
#
# 912
# Epoch duration =1.98s
# Cumulative duration =30min 18.1099999999999s
#
# 913
# Epoch duration =1.99s
# Cumulative duration =30min 20.09999999999991s
#
# 914
# Epoch duration =1.98s
# Cumulative duration =30min 22.069999999999936s
#
# 915
# Epoch duration =1.99s
# Cumulative duration =30min 24.059999999999945s
#
# 916
# Epoch duration =2.01s
# Cumulative duration =30min 26.079999999999927s
#
# 917
# Epoch duration =1.99s
# Cumulative duration =30min 28.069999999999936s
#
# 918
# Epoch duration =1.99s
# Cumulative duration =30min 30.059999999999945s
#
# 919
# Epoch duration =1.99s
# Cumulative duration =30min 32.049999999999955s
#
# 920
# Epoch duration =1.99s
# Cumulative duration =30min 34.02999999999997s
#
# 921
# Epoch duration =1.98s
# Cumulative duration =30min 36.00999999999999s
#
# 922
# Epoch duration =1.98s
# Cumulative duration =30min 37.99000000000001s
#
# 923
# Epoch duration =1.98s
# Cumulative duration =30min 39.960000000000036s
#
# 924
# Epoch duration =1.98s
# Cumulative duration =30min 41.940000000000055s
#
# 925
# Epoch duration =1.98s
# Cumulative duration =30min 43.930000000000064s
#
# 926
# Epoch duration =1.98s
# Cumulative duration =30min 45.90000000000009s
#
# 927
# Epoch duration =2.0s
# Cumulative duration =30min 47.90000000000009s
#
# 928
# Epoch duration =1.99s
# Cumulative duration =30min 49.8900000000001s
#
# 929
# Epoch duration =2.0s
# Cumulative duration =30min 51.8900000000001s
#
# 930
# Epoch duration =1.99s
# Cumulative duration =30min 53.88000000000011s
#
# 931
# Epoch duration =2.02s
# Cumulative duration =30min 55.90000000000009s
#
# 932
# Epoch duration =1.99s
# Cumulative duration =30min 57.8900000000001s
#
# 933
# Epoch duration =1.99s
# Cumulative duration =30min 59.88000000000011s
#
# 934
# Epoch duration =2.01s
# Cumulative duration =31min 1.8900000000001s
#
# 935
# Epoch duration =1.98s
# Cumulative duration =31min 3.869999999999891s
#
# 936
# Epoch duration =2.05s
# Cumulative duration =31min 5.920000000000073s
#
# 937
# Epoch duration =1.99s
# Cumulative duration =31min 7.910000000000082s
#
# 938
# Epoch duration =1.99s
# Cumulative duration =31min 9.900000000000091s
#
# 939
# Epoch duration =1.99s
# Cumulative duration =31min 11.8900000000001s
#
# 940
# Epoch duration =1.99s
# Cumulative duration =31min 13.88000000000011s
#
# 941
# Epoch duration =1.98s
# Cumulative duration =31min 15.86999999999989s
#
# 942
# Epoch duration =1.98s
# Cumulative duration =31min 17.839999999999918s
#
# 943
# Epoch duration =1.99s
# Cumulative duration =31min 19.829999999999927s
#
# 944
# Epoch duration =2.03s
# Cumulative duration =31min 21.86999999999989s
#
# 945
# Epoch duration =1.98s
# Cumulative duration =31min 23.84999999999991s
#
# 946
# Epoch duration =2.0s
# Cumulative duration =31min 25.84999999999991s
#
# 947
# Epoch duration =1.99s
# Cumulative duration =31min 27.839999999999918s
#
# 948
# Epoch duration =2.0s
# Cumulative duration =31min 29.829999999999927s
#
# 949
# Epoch duration =1.98s
# Cumulative duration =31min 31.809999999999945s
#
# 950
# Epoch duration =2.01s
# Cumulative duration =31min 33.819999999999936s
#
# 951
# Epoch duration =1.99s
# Cumulative duration =31min 35.809999999999945s
#
# 952
# Epoch duration =2.03s
# Cumulative duration =31min 37.83999999999992s
#
# 953
# Epoch duration =1.99s
# Cumulative duration =31min 39.82999999999993s
#
# 954
# Epoch duration =2.02s
# Cumulative duration =31min 41.84999999999991s
#
# 955
# Epoch duration =1.99s
# Cumulative duration =31min 43.84999999999991s
#
# 956
# Epoch duration =2.0s
# Cumulative duration =31min 45.83999999999992s
#
# 957
# Epoch duration =1.99s
# Cumulative duration =31min 47.82999999999993s
#
# 958
# Epoch duration =1.99s
# Cumulative duration =31min 49.819999999999936s
#
# 959
# Epoch duration =1.99s
# Cumulative duration =31min 51.809999999999945s
#
# 960
# Epoch duration =1.99s
# Cumulative duration =31min 53.799999999999955s
#
# 961
# Epoch duration =1.98s
# Cumulative duration =31min 55.77999999999997s
#
# 962
# Epoch duration =1.98s
# Cumulative duration =31min 57.75999999999999s
#
# 963
# Epoch duration =2.01s
# Cumulative duration =31min 59.76999999999998s
#
# 964
# Epoch duration =1.98s
# Cumulative duration =32min 1.75s
#
# 965
# Epoch duration =1.99s
# Cumulative duration =32min 3.740000000000009s
#
# 966
# Epoch duration =1.99s
# Cumulative duration =32min 5.730000000000018s
#
# 967
# Epoch duration =1.98s
# Cumulative duration =32min 7.710000000000036s
#
# 968
# Epoch duration =2.02s
# Cumulative duration =32min 9.720000000000027s
#
# 969
# Epoch duration =2.01s
# Cumulative duration =32min 11.740000000000009s
#
# 970
# Epoch duration =1.98s
# Cumulative duration =32min 13.720000000000027s
#
# 971
# Epoch duration =2.0s
# Cumulative duration =32min 15.720000000000027s
#
# 972
# Epoch duration =2.01s
# Cumulative duration =32min 17.720000000000027s
#
# 973
# Epoch duration =1.99s
# Cumulative duration =32min 19.710000000000036s
#
# 974
# Epoch duration =1.98s
# Cumulative duration =32min 21.690000000000055s
#
# 975
# Epoch duration =1.98s
# Cumulative duration =32min 23.670000000000073s
#
# 976
# Epoch duration =1.99s
# Cumulative duration =32min 25.660000000000082s
#
# 977
# Epoch duration =1.98s
# Cumulative duration =32min 27.6400000000001s
#
# 978
# Epoch duration =1.98s
# Cumulative duration =32min 29.61999999999989s
#
# 979
# Epoch duration =1.99s
# Cumulative duration =32min 31.6099999999999s
#
# 980
# Epoch duration =1.98s
# Cumulative duration =32min 33.58999999999992s
#
# 981
# Epoch duration =2.03s
# Cumulative duration =32min 35.61999999999989s
#
# 982
# Epoch duration =2.02s
# Cumulative duration =32min 37.6400000000001s
#
# 983
# Epoch duration =1.99s
# Cumulative duration =32min 39.63000000000011s
#
# 984
# Epoch duration =1.99s
# Cumulative duration =32min 41.61999999999989s
#
# 985
# Epoch duration =1.97s
# Cumulative duration =32min 43.58999999999992s
#
# 986
# Epoch duration =1.99s
# Cumulative duration =32min 45.57999999999993s
#
# 987
# Epoch duration =1.97s
# Cumulative duration =32min 47.559999999999945s
#
# 988
# Epoch duration =1.99s
# Cumulative duration =32min 49.539999999999964s
#
# 989
# Epoch duration =1.99s
# Cumulative duration =32min 51.539999999999964s
#
# 990
# Epoch duration =1.99s
# Cumulative duration =32min 53.51999999999998s
#
# 991
# Epoch duration =1.99s
# Cumulative duration =32min 55.51999999999998s
#
# 992
# Epoch duration =1.99s
# Cumulative duration =32min 57.5s
#
# 993
# Epoch duration =1.98s
# Cumulative duration =32min 59.48000000000002s
#
# 994
# Epoch duration =2.03s
# Cumulative duration =33min 1.509999999999991s
#
# 995
# Epoch duration =2.0s
# Cumulative duration =33min 3.509999999999991s
#
# 996
# Epoch duration =1.99s
# Cumulative duration =33min 5.509999999999991s
#
# 997
# Epoch duration =1.99s
# Cumulative duration =33min 7.5s
#
# 998
# Epoch duration =1.98s
# Cumulative duration =33min 9.480000000000018s
#
# 999
# Epoch duration =1.99s
# Cumulative duration =33min 11.470000000000027s
#
# Saving scores to Arrays/trna_resbindt5_ug_so1000.npy

# %%
#load values
savepath = 'Arrays/trna_resbindt5_ug_so1000.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='RdPu', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, cmap='RdPu', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
