# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/trna_100k_d4.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 10.48s

# %%
simalign_file = '../../../data_RFAM/trnasim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((((<<<<>>>><<<<<>>>>><<<<<>>>>>)))))))'

# %%
ugSS
# Out:
# '(((((((,,<<<<_______>>>>,<<<<<_______>>>>>,,,,<<<<<_______>>>>>))))))):'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/trna'
param_path = os.path.join(save_path, 'resbind_t4')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 513, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=11.30s -- loss=0.14944 -- acc=94.08500%
#
#   valid loss:		0.06205
#   valid accuracy:	0.98195+/-0.00000
#   valid auc-roc:	0.99743+/-0.00000
#   valid auc-pr:		0.99684+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=10.78s -- loss=0.04484 -- acc=98.75333%
#
#   valid loss:		0.02266
#   valid accuracy:	0.99575+/-0.00000
#   valid auc-roc:	0.99956+/-0.00000
#   valid auc-pr:		0.99924+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=10.76s -- loss=0.03029 -- acc=99.25750%
#
#   valid loss:		0.01980
#   valid accuracy:	0.99635+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=10.79s -- loss=0.02476 -- acc=99.47250%
#
#   valid loss:		0.02788
#   valid accuracy:	0.99490+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99965+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=10.74s -- loss=0.02315 -- acc=99.56750%
#
#   valid loss:		0.02601
#   valid accuracy:	0.99570+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99976+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=10.69s -- loss=0.02247 -- acc=99.60000%
#
#   valid loss:		0.02117
#   valid accuracy:	0.99740+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=10.73s -- loss=0.02209 -- acc=99.66083%
#
#   valid loss:		0.02589
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=10.72s -- loss=0.02219 -- acc=99.66417%
#
#   valid loss:		0.02434
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=10.74s -- loss=0.02195 -- acc=99.69167%
#
#   valid loss:		0.02940
#   valid accuracy:	0.99570+/-0.00000
#   valid auc-roc:	0.99958+/-0.00000
#   valid auc-pr:		0.99909+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=10.72s -- loss=0.02073 -- acc=99.75833%
#
#   valid loss:		0.02499
#   valid accuracy:	0.99685+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=10.69s -- loss=0.02210 -- acc=99.71583%
#
#   valid loss:		0.02090
#   valid accuracy:	0.99740+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=10.75s -- loss=0.02090 -- acc=99.76667%
#
#   valid loss:		0.02182
#   valid accuracy:	0.99750+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=10.75s -- loss=0.02105 -- acc=99.76250%
#
#   valid loss:		0.01953
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=10.73s -- loss=0.02066 -- acc=99.77583%
#
#   valid loss:		0.02087
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=10.73s -- loss=0.02109 -- acc=99.77083%
#
#   valid loss:		0.02242
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.02096 -- acc=99.77250%
#
#   valid loss:		0.02085
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=10.75s -- loss=0.02042 -- acc=99.78083%
#
#   valid loss:		0.02115
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=10.81s -- loss=0.01992 -- acc=99.80000%
#
#   valid loss:		0.01989
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=10.85s -- loss=0.01994 -- acc=99.81417%
#
#   valid loss:		0.02156
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=10.86s -- loss=0.01979 -- acc=99.82000%
#
#   valid loss:		0.02046
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=10.86s -- loss=0.01977 -- acc=99.81250%
#
#   valid loss:		0.02120
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.01957 -- acc=99.81917%
#
#   valid loss:		0.02256
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=10.85s -- loss=0.01924 -- acc=99.80917%
#
#   valid loss:		0.02021
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.01868 -- acc=99.84833%
#
#   valid loss:		0.02096
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=10.86s -- loss=0.01969 -- acc=99.80417%
#
#   valid loss:		0.02011
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=10.86s -- loss=0.01904 -- acc=99.83833%
#
#   valid loss:		0.01983
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=10.90s -- loss=0.01936 -- acc=99.82167%
#
#   valid loss:		0.01973
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=10.87s -- loss=0.01881 -- acc=99.85250%
#
#   valid loss:		0.02071
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=10.88s -- loss=0.01878 -- acc=99.82583%
#
#   valid loss:		0.02000
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=10.88s -- loss=0.01782 -- acc=99.86000%
#
#   valid loss:		0.02020
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=10.85s -- loss=0.01896 -- acc=99.82750%
#
#   valid loss:		0.02011
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.01915 -- acc=99.82583%
#
#   valid loss:		0.01887
#   valid accuracy:	0.99870+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=10.90s -- loss=0.01841 -- acc=99.84083%
#
#   valid loss:		0.01862
#   valid accuracy:	0.99895+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=10.87s -- loss=0.01824 -- acc=99.84583%
#
#   valid loss:		0.01895
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=10.88s -- loss=0.01796 -- acc=99.84750%
#
#   valid loss:		0.01838
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=10.84s -- loss=0.01863 -- acc=99.83250%
#
#   valid loss:		0.01873
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=10.93s -- loss=0.01766 -- acc=99.85500%
#
#   valid loss:		0.01921
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=10.88s -- loss=0.01750 -- acc=99.85083%
#
#   valid loss:		0.02063
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.01786 -- acc=99.84417%
#
#   valid loss:		0.01832
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=10.89s -- loss=0.01779 -- acc=99.84417%
#
#   valid loss:		0.01823
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=10.89s -- loss=0.01750 -- acc=99.85250%
#
#   valid loss:		0.01756
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=10.89s -- loss=0.01725 -- acc=99.86667%
#
#   valid loss:		0.02598
#   valid accuracy:	0.99570+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01698 -- acc=99.85917%
#
#   valid loss:		0.01957
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=10.92s -- loss=0.01739 -- acc=99.84667%
#
#   valid loss:		0.02138
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=10.98s -- loss=0.01713 -- acc=99.86417%
#
#   valid loss:		0.01813
#   valid accuracy:	0.99885+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=10.99s -- loss=0.01718 -- acc=99.84833%
#
#   valid loss:		0.01941
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=10.88s -- loss=0.01695 -- acc=99.86167%
#
#   valid loss:		0.02052
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=10.90s -- loss=0.01684 -- acc=99.86250%
#
#   valid loss:		0.01993
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.01712 -- acc=99.85167%
#
#   valid loss:		0.01796
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=10.90s -- loss=0.01709 -- acc=99.84833%
#
#   valid loss:		0.01817
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.01707 -- acc=99.85917%
#
#   valid loss:		0.01851
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=10.90s -- loss=0.01721 -- acc=99.85583%
#
#   valid loss:		0.01975
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=10.90s -- loss=0.01710 -- acc=99.85833%
#
#   valid loss:		0.02010
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=10.92s -- loss=0.01684 -- acc=99.87583%
#
#   valid loss:		0.02040
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=10.90s -- loss=0.01683 -- acc=99.85250%
#
#   valid loss:		0.01805
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=10.92s -- loss=0.01659 -- acc=99.86667%
#
#   valid loss:		0.01813
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=10.89s -- loss=0.01613 -- acc=99.88250%
#
#   valid loss:		0.01834
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=10.92s -- loss=0.01680 -- acc=99.85667%
#
#   valid loss:		0.01670
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.01619 -- acc=99.87250%
#
#   valid loss:		0.01987
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=10.92s -- loss=0.01647 -- acc=99.86667%
#
#   valid loss:		0.01914
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=10.93s -- loss=0.01629 -- acc=99.87083%
#
#   valid loss:		0.01740
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=10.92s -- loss=0.01633 -- acc=99.87333%
#
#   valid loss:		0.01769
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=10.92s -- loss=0.01670 -- acc=99.85667%
#
#   valid loss:		0.01826
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01619 -- acc=99.87417%
#
#   valid loss:		0.01810
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=10.93s -- loss=0.01689 -- acc=99.85583%
#
#   valid loss:		0.02072
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=10.91s -- loss=0.01640 -- acc=99.86333%
#
#   valid loss:		0.01946
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=10.92s -- loss=0.01590 -- acc=99.87667%
#
#   valid loss:		0.01728
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=10.95s -- loss=0.01628 -- acc=99.85583%
#
#   valid loss:		0.01886
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=10.96s -- loss=0.01599 -- acc=99.88417%
#
#   valid loss:		0.01738
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01622 -- acc=99.86833%
#
#   valid loss:		0.01769
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=10.95s -- loss=0.01579 -- acc=99.87833%
#
#   valid loss:		0.01654
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=10.96s -- loss=0.01557 -- acc=99.88000%
#
#   valid loss:		0.01848
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=11.00s -- loss=0.01578 -- acc=99.87500%
#
#   valid loss:		0.01698
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=10.99s -- loss=0.01613 -- acc=99.87000%
#
#   valid loss:		0.01983
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=10.97s -- loss=0.01603 -- acc=99.87500%
#
#   valid loss:		0.01859
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=10.97s -- loss=0.01576 -- acc=99.88250%
#
#   valid loss:		0.01832
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=10.95s -- loss=0.01610 -- acc=99.86333%
#
#   valid loss:		0.01755
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=10.99s -- loss=0.01547 -- acc=99.89250%
#
#   valid loss:		0.01711
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01550 -- acc=99.89167%
#
#   valid loss:		0.01695
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01559 -- acc=99.88167%
#
#   valid loss:		0.01725
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=10.97s -- loss=0.01579 -- acc=99.88500%
#
#   valid loss:		0.01586
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=10.97s -- loss=0.01567 -- acc=99.86917%
#
#   valid loss:		0.01720
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01578 -- acc=99.88333%
#
#   valid loss:		0.01574
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=10.98s -- loss=0.01534 -- acc=99.89083%
#
#   valid loss:		0.01802
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01521 -- acc=99.89583%
#
#   valid loss:		0.01832
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=10.97s -- loss=0.01524 -- acc=99.88417%
#
#   valid loss:		0.01959
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=10.96s -- loss=0.01515 -- acc=99.88167%
#
#   valid loss:		0.01690
#   valid accuracy:	0.99875+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=10.96s -- loss=0.01507 -- acc=99.88917%
#
#   valid loss:		0.01850
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01540 -- acc=99.87750%
#
#   valid loss:		0.01713
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=10.97s -- loss=0.01495 -- acc=99.89750%
#
#   valid loss:		0.01756
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01548 -- acc=99.87917%
#
#   valid loss:		0.01919
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=10.95s -- loss=0.01552 -- acc=99.88083%
#
#   valid loss:		0.01768
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=10.99s -- loss=0.01502 -- acc=99.88333%
#
#   valid loss:		0.01576
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=10.93s -- loss=0.01535 -- acc=99.87083%
#
#   valid loss:		0.01581
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=10.95s -- loss=0.01471 -- acc=99.89500%
#
#   valid loss:		0.01539
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/resbind_t4_best.ckpt
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=10.96s -- loss=0.01512 -- acc=99.87583%
#
#   valid loss:		0.01744
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=10.95s -- loss=0.01506 -- acc=99.88667%
#
#   valid loss:		0.01572
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=10.94s -- loss=0.01478 -- acc=99.89500%
#
#   valid loss:		0.01707
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=10.95s -- loss=0.01499 -- acc=99.88417%
#
#   valid loss:		0.01628
#   valid accuracy:	0.99895+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=10.95s -- loss=0.01582 -- acc=99.86750%
#
#   valid loss:		0.01731
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/trna/resbind_t4_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/trna/resbind_t4_best.ckpt
#   test  loss:		0.01598
#   test  accuracy:	0.99863+/-0.00000
#   test  auc-roc:	0.99995+/-0.00000
#   test  auc-pr:		0.99993+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/trna_resbindt4_ug_so1000.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='off', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/trna_resbindt4_ug_so1000.npy

# %%
#load values
savepath = 'Arrays/trna_resbindt4_ug_so1000.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='RdPu', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, cmap='RdPu', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
