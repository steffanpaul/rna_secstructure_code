# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/trna_100k_d3.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 2.08s

# %%
simalign_file = '../../../data_RFAM/trnasim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((((<<<<>>>><<<<<>>>>><<<<<>>>>>)))))))'

# %%
ugSS
# Out:
# '(((((((,,<<<<_______>>>>,<<<<<_______>>>>>,,,,<<<<<_______>>>>>))))))):'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 22,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/trna'
param_path = os.path.join(save_path, 'mlp_t2_22')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 513, 1, 4)
# layer2: dense_0
# (?, 22)
# layer3: dense_0_batch
# (?, 22)
# layer4: dense_0_active
# (?, 22)
# layer5: dense_0_dropout
# (?, 22)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.30s -- loss=0.43664 -- acc=79.068337%
#
#   valid loss:		0.11770
#   valid accuracy:	0.99130+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99962+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.81s -- loss=0.19777 -- acc=92.277508%
#
#   valid loss:		0.05595
#   valid accuracy:	0.99300+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99976+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.16121 -- acc=93.544174%
#
#   valid loss:		0.03822
#   valid accuracy:	0.99445+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.14908 -- acc=94.072507%
#
#   valid loss:		0.03496
#   valid accuracy:	0.99390+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.14173 -- acc=94.330843%
#
#   valid loss:		0.03005
#   valid accuracy:	0.99505+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.13806 -- acc=94.521672%
#
#   valid loss:		0.03137
#   valid accuracy:	0.99465+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.87s -- loss=0.13386 -- acc=94.575008%
#
#   valid loss:		0.02661
#   valid accuracy:	0.99510+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.13260 -- acc=94.605001%
#
#   valid loss:		0.02658
#   valid accuracy:	0.99430+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.12801 -- acc=94.846675%
#
#   valid loss:		0.02629
#   valid accuracy:	0.99530+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.12697 -- acc=94.840004%
#
#   valid loss:		0.02491
#   valid accuracy:	0.99500+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99972+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.84s -- loss=0.12874 -- acc=94.885849%
#
#   valid loss:		0.02571
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.12532 -- acc=95.266677%
#
#   valid loss:		0.02392
#   valid accuracy:	0.99540+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.12513 -- acc=95.475848%
#
#   valid loss:		0.02464
#   valid accuracy:	0.99500+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.12552 -- acc=95.465847%
#
#   valid loss:		0.02352
#   valid accuracy:	0.99515+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.12156 -- acc=95.526673%
#
#   valid loss:		0.02378
#   valid accuracy:	0.99470+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.58s -- loss=0.12218 -- acc=95.580848%
#
#   valid loss:		0.02339
#   valid accuracy:	0.99495+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.12384 -- acc=95.495000%
#
#   valid loss:		0.02502
#   valid accuracy:	0.99455+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.58s -- loss=0.12016 -- acc=95.516672%
#
#   valid loss:		0.02178
#   valid accuracy:	0.99575+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.12022 -- acc=95.522502%
#
#   valid loss:		0.02446
#   valid accuracy:	0.99485+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.12318 -- acc=95.333343%
#
#   valid loss:		0.02246
#   valid accuracy:	0.99585+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.12195 -- acc=95.281678%
#
#   valid loss:		0.02383
#   valid accuracy:	0.99545+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.12069 -- acc=95.665847%
#
#   valid loss:		0.02259
#   valid accuracy:	0.99585+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.12296 -- acc=95.633343%
#
#   valid loss:		0.02385
#   valid accuracy:	0.99545+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.58s -- loss=0.11897 -- acc=95.720842%
#
#   valid loss:		0.02293
#   valid accuracy:	0.99505+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.12153 -- acc=95.621672%
#
#   valid loss:		0.02209
#   valid accuracy:	0.99620+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.11837 -- acc=95.657506%
#
#   valid loss:		0.02258
#   valid accuracy:	0.99580+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.11715 -- acc=95.585849%
#
#   valid loss:		0.02215
#   valid accuracy:	0.99590+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.11924 -- acc=95.401670%
#
#   valid loss:		0.02161
#   valid accuracy:	0.99570+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_22_best.ckpt
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.11936 -- acc=95.718342%
#
#   valid loss:		0.02288
#   valid accuracy:	0.99580+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.12072 -- acc=95.673347%
#
#   valid loss:		0.02302
#   valid accuracy:	0.99555+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.56s -- loss=0.11951 -- acc=95.630843%
#
#   valid loss:		0.02356
#   valid accuracy:	0.99525+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.55s -- loss=0.12038 -- acc=95.745005%
#
#   valid loss:		0.02373
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.11733 -- acc=95.603340%
#
#   valid loss:		0.02264
#   valid accuracy:	0.99540+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.11900 -- acc=95.615842%
#
#   valid loss:		0.02181
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.11785 -- acc=95.595000%
#
#   valid loss:		0.02210
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.11827 -- acc=95.720002%
#
#   valid loss:		0.02178
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.11749 -- acc=95.551675%
#
#   valid loss:		0.02196
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.12046 -- acc=95.445845%
#
#   valid loss:		0.02232
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.11714 -- acc=95.442504%
#
#   valid loss:		0.02276
#   valid accuracy:	0.99550+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.11847 -- acc=95.493349%
#
#   valid loss:		0.02370
#   valid accuracy:	0.99550+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.11601 -- acc=95.660846%
#
#   valid loss:		0.02276
#   valid accuracy:	0.99590+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.11704 -- acc=95.647505%
#
#   valid loss:		0.02330
#   valid accuracy:	0.99590+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.11891 -- acc=95.473347%
#
#   valid loss:		0.02258
#   valid accuracy:	0.99580+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.11776 -- acc=95.452505%
#
#   valid loss:		0.02218
#   valid accuracy:	0.99620+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.11570 -- acc=95.470847%
#
#   valid loss:		0.02251
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.11891 -- acc=95.490009%
#
#   valid loss:		0.02296
#   valid accuracy:	0.99615+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.11787 -- acc=95.538344%
#
#   valid loss:		0.02293
#   valid accuracy:	0.99545+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=3.57s -- loss=0.11751 -- acc=95.460006%
#
#   valid loss:		0.02405
#   valid accuracy:	0.99555+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.11808 -- acc=95.444174%
#
#   valid loss:		0.02265
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=3.84s -- loss=0.11762 -- acc=95.450845%
#
#   valid loss:		0.02286
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.11600 -- acc=95.562506%
#
#   valid loss:		0.02175
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.11758 -- acc=95.362506%
#
#   valid loss:		0.02314
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.11751 -- acc=95.488349%
#
#   valid loss:		0.02217
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.11594 -- acc=95.595000%
#
#   valid loss:		0.02288
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.11879 -- acc=95.415842%
#
#   valid loss:		0.02269
#   valid accuracy:	0.99575+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=3.76s -- loss=0.11763 -- acc=95.454175%
#
#   valid loss:		0.02239
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.11707 -- acc=95.446675%
#
#   valid loss:		0.02279
#   valid accuracy:	0.99615+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.11760 -- acc=95.503340%
#
#   valid loss:		0.02227
#   valid accuracy:	0.99595+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.11915 -- acc=95.422502%
#
#   valid loss:		0.02285
#   valid accuracy:	0.99620+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.11682 -- acc=95.490849%
#
#   valid loss:		0.02322
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.11893 -- acc=95.678348%
#
#   valid loss:		0.02302
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.11724 -- acc=95.500000%
#
#   valid loss:		0.02358
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.11722 -- acc=95.500000%
#
#   valid loss:		0.02350
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=3.75s -- loss=0.11595 -- acc=95.507501%
#
#   valid loss:		0.02313
#   valid accuracy:	0.99550+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=3.86s -- loss=0.11799 -- acc=95.432503%
#
#   valid loss:		0.02325
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.11769 -- acc=95.583348%
#
#   valid loss:		0.02257
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.11742 -- acc=95.394179%
#
#   valid loss:		0.02328
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.11574 -- acc=95.545845%
#
#   valid loss:		0.02330
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/trna/mlp_t2_22_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/trna/mlp_t2_22_best.ckpt
#   test  loss:		0.02012
#   test  accuracy:	0.99635+/-0.00000
#   test  auc-roc:	0.99989+/-0.00000
#   test  auc-pr:		0.99989+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
savepath = 'Arrays/trna_mlpt2_22_ug_so1000.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='off', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# ----------------Summing complete----------------
# Saving scores to Arrays/trna_mlpt2_22_ug_so1000.npy

# %%
#load values
savepath = 'Arrays/trna_mlpt2_22_ug_so1000.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, vmax=1.0, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
dense = nntrainer.get_activations(sess, test, layer='dense_0_active')
W = nnmodel.get_parameters(sess, layer='dense_0')[0]
W = W.reshape((seqlen,4,dense.shape[1]))

fig = plt.figure(figsize=(10,10))
for neuron in range(10):
    fig.add_subplot(10,1,neuron+1)
    sb.heatmap(W[:, :, neuron].T)
