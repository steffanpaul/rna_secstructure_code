# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/trna_100k_d4.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 1.91s

# %%
simalign_file = '../../../data_RFAM/trnasim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((((<<<<>>>><<<<<>>>>><<<<<>>>>>)))))))'

# %%
ugSS
# Out:
# '(((((((,,<<<<_______>>>>,<<<<<_______>>>>>,,,,<<<<<_______>>>>>))))))):'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/trna'
param_path = os.path.join(save_path, 'mlp_t3_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 513, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=4.20s -- loss=0.25544 -- acc=89.529173%
#
#   valid loss:		0.05207
#   valid accuracy:	0.99385+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.99s -- loss=0.09094 -- acc=96.954175%
#
#   valid loss:		0.02701
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=4.51s -- loss=0.06938 -- acc=97.693339%
#
#   valid loss:		0.02313
#   valid accuracy:	0.99390+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=4.03s -- loss=0.06528 -- acc=97.893339%
#
#   valid loss:		0.01733
#   valid accuracy:	0.99685+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.05771 -- acc=98.181678%
#
#   valid loss:		0.01731
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.78s -- loss=0.05632 -- acc=98.233333%
#
#   valid loss:		0.01692
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.05454 -- acc=98.355836%
#
#   valid loss:		0.01706
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.05470 -- acc=98.360006%
#
#   valid loss:		0.01777
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.91s -- loss=0.05270 -- acc=98.443334%
#
#   valid loss:		0.01687
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.84s -- loss=0.05417 -- acc=98.420832%
#
#   valid loss:		0.01767
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.89s -- loss=0.05096 -- acc=98.551675%
#
#   valid loss:		0.01775
#   valid accuracy:	0.99715+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.90s -- loss=0.05112 -- acc=98.675008%
#
#   valid loss:		0.01770
#   valid accuracy:	0.99720+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.84s -- loss=0.05078 -- acc=98.682508%
#
#   valid loss:		0.01662
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.82s -- loss=0.05050 -- acc=98.727503%
#
#   valid loss:		0.01630
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.04905 -- acc=98.729173%
#
#   valid loss:		0.01750
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.04833 -- acc=98.765837%
#
#   valid loss:		0.01795
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.90s -- loss=0.04837 -- acc=98.833333%
#
#   valid loss:		0.01822
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.88s -- loss=0.04874 -- acc=98.821672%
#
#   valid loss:		0.01709
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.04867 -- acc=98.842504%
#
#   valid loss:		0.01750
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=4.00s -- loss=0.04986 -- acc=98.779178%
#
#   valid loss:		0.01896
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=4.03s -- loss=0.04745 -- acc=98.920002%
#
#   valid loss:		0.01822
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.04742 -- acc=98.843334%
#
#   valid loss:		0.02021
#   valid accuracy:	0.99740+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.04924 -- acc=98.829173%
#
#   valid loss:		0.02008
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.04678 -- acc=98.922502%
#
#   valid loss:		0.01811
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.04597 -- acc=98.966677%
#
#   valid loss:		0.01896
#   valid accuracy:	0.99705+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.04817 -- acc=98.897500%
#
#   valid loss:		0.01803
#   valid accuracy:	0.99750+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.04762 -- acc=98.900830%
#
#   valid loss:		0.01898
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99958+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.04713 -- acc=98.908331%
#
#   valid loss:		0.01898
#   valid accuracy:	0.99715+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.04656 -- acc=98.950005%
#
#   valid loss:		0.01851
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.04718 -- acc=98.918332%
#
#   valid loss:		0.01788
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.04529 -- acc=98.992509%
#
#   valid loss:		0.01967
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.04595 -- acc=98.975008%
#
#   valid loss:		0.01810
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.04768 -- acc=98.992509%
#
#   valid loss:		0.01844
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.04882 -- acc=98.929173%
#
#   valid loss:		0.01968
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.04671 -- acc=98.973337%
#
#   valid loss:		0.01882
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.04835 -- acc=98.926673%
#
#   valid loss:		0.01895
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.04692 -- acc=98.991679%
#
#   valid loss:		0.02011
#   valid accuracy:	0.99755+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.04752 -- acc=98.971677%
#
#   valid loss:		0.01881
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.04572 -- acc=99.001670%
#
#   valid loss:		0.02007
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.04615 -- acc=98.977508%
#
#   valid loss:		0.01952
#   valid accuracy:	0.99750+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.04603 -- acc=98.968337%
#
#   valid loss:		0.01841
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.04679 -- acc=98.962506%
#
#   valid loss:		0.02165
#   valid accuracy:	0.99680+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.04667 -- acc=98.967507%
#
#   valid loss:		0.01996
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.04517 -- acc=99.030833%
#
#   valid loss:		0.01778
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.04750 -- acc=98.987509%
#
#   valid loss:		0.01818
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.04849 -- acc=98.949175%
#
#   valid loss:		0.01881
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.04658 -- acc=98.972507%
#
#   valid loss:		0.01797
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.04607 -- acc=98.979178%
#
#   valid loss:		0.01929
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.04654 -- acc=99.008331%
#
#   valid loss:		0.01852
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.04662 -- acc=99.003330%
#
#   valid loss:		0.01805
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.04813 -- acc=98.965007%
#
#   valid loss:		0.01990
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.04681 -- acc=98.965007%
#
#   valid loss:		0.01944
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.04596 -- acc=99.028333%
#
#   valid loss:		0.02025
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99955+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.04751 -- acc=98.988339%
#
#   valid loss:		0.01915
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99959+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/trna/mlp_t3_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/trna/mlp_t3_44_best.ckpt
#   test  loss:		0.01576
#   test  accuracy:	0.99787+/-0.00000
#   test  auc-roc:	0.99996+/-0.00000
#   test  auc-pr:		0.99996+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/trna_mlpt3_44_ug_so500.npy'

num_summary = 500
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =0.93s
# Cumulative duration =0.93s
#
# 1
# Epoch duration =0.95s
# Cumulative duration =1.88s
#
# 2
# Epoch duration =0.92s
# Cumulative duration =2.81s
#
# 3
# Epoch duration =0.91s
# Cumulative duration =3.72s
#
# 4
# Epoch duration =0.96s
# Cumulative duration =4.68s
#
# 5
# Epoch duration =0.95s
# Cumulative duration =5.63s
#
# 6
# Epoch duration =0.94s
# Cumulative duration =6.57s
#
# 7
# Epoch duration =0.96s
# Cumulative duration =7.53s
#
# 8
# Epoch duration =0.98s
# Cumulative duration =8.51s
#
# 9
# Epoch duration =0.94s
# Cumulative duration =9.45s
#
# 10
# Epoch duration =0.92s
# Cumulative duration =10.38s
#
# 11
# Epoch duration =0.91s
# Cumulative duration =11.28s
#
# 12
# Epoch duration =0.92s
# Cumulative duration =12.21s
#
# 13
# Epoch duration =0.93s
# Cumulative duration =13.14s
#
# 14
# Epoch duration =0.92s
# Cumulative duration =14.05s
#
# 15
# Epoch duration =0.93s
# Cumulative duration =14.98s
#
# 16
# Epoch duration =0.92s
# Cumulative duration =15.9s
#
# 17
# Epoch duration =0.94s
# Cumulative duration =16.84s
#
# 18
# Epoch duration =0.93s
# Cumulative duration =17.77s
#
# 19
# Epoch duration =0.99s
# Cumulative duration =18.76s
#
# 20
# Epoch duration =0.94s
# Cumulative duration =19.7s
#
# 21
# Epoch duration =0.98s
# Cumulative duration =20.68s
#
# 22
# Epoch duration =0.92s
# Cumulative duration =21.6s
#
# 23
# Epoch duration =0.92s
# Cumulative duration =22.52s
#
# 24
# Epoch duration =0.93s
# Cumulative duration =23.45s
#
# 25
# Epoch duration =0.92s
# Cumulative duration =24.37s
#
# 26
# Epoch duration =1.0s
# Cumulative duration =25.37s
#
# 27
# Epoch duration =1.07s
# Cumulative duration =26.45s
#
# 28
# Epoch duration =0.97s
# Cumulative duration =27.42s
#
# 29
# Epoch duration =0.92s
# Cumulative duration =28.34s
#
# 30
# Epoch duration =1.23s
# Cumulative duration =29.57s
#
# 31
# Epoch duration =1.12s
# Cumulative duration =30.69s
#
# 32
# Epoch duration =0.92s
# Cumulative duration =31.61s
#
# 33
# Epoch duration =0.95s
# Cumulative duration =32.56s
#
# 34
# Epoch duration =1.18s
# Cumulative duration =33.74s
#
# 35
# Epoch duration =0.96s
# Cumulative duration =34.7s
#
# 36
# Epoch duration =0.93s
# Cumulative duration =35.63s
#
# 37
# Epoch duration =0.92s
# Cumulative duration =36.55s
#
# 38
# Epoch duration =0.93s
# Cumulative duration =37.48s
#
# 39
# Epoch duration =0.93s
# Cumulative duration =38.42s
#
# 40
# Epoch duration =0.93s
# Cumulative duration =39.35s
#
# 41
# Epoch duration =0.93s
# Cumulative duration =40.28s
#
# 42
# Epoch duration =0.93s
# Cumulative duration =41.21s
#
# 43
# Epoch duration =0.94s
# Cumulative duration =42.15s
#
# 44
# Epoch duration =0.92s
# Cumulative duration =43.08s
#
# 45
# Epoch duration =0.92s
# Cumulative duration =43.99s
#
# 46
# Epoch duration =0.92s
# Cumulative duration =44.91s
#
# 47
# Epoch duration =0.93s
# Cumulative duration =45.84s
#
# 48
# Epoch duration =0.94s
# Cumulative duration =46.79s
#
# 49
# Epoch duration =0.93s
# Cumulative duration =47.72s
#
# 50
# Epoch duration =0.94s
# Cumulative duration =48.65s
#
# 51
# Epoch duration =0.92s
# Cumulative duration =49.57s
#
# 52
# Epoch duration =0.94s
# Cumulative duration =50.51s
#
# 53
# Epoch duration =0.96s
# Cumulative duration =51.47s
#
# 54
# Epoch duration =0.92s
# Cumulative duration =52.39s
#
# 55
# Epoch duration =0.92s
# Cumulative duration =53.32s
#
# 56
# Epoch duration =0.93s
# Cumulative duration =54.25s
#
# 57
# Epoch duration =0.93s
# Cumulative duration =55.17s
#
# 58
# Epoch duration =0.93s
# Cumulative duration =56.11s
#
# 59
# Epoch duration =0.92s
# Cumulative duration =57.03s
#
# 60
# Epoch duration =0.92s
# Cumulative duration =57.95s
#
# 61
# Epoch duration =0.96s
# Cumulative duration =58.91s
#
# 62
# Epoch duration =0.95s
# Cumulative duration =59.86s
#
# 63
# Epoch duration =0.93s
# Cumulative duration =1min 0.7899999999999991s
#
# 64
# Epoch duration =0.94s
# Cumulative duration =1min 1.7199999999999989s
#
# 65
# Epoch duration =0.91s
# Cumulative duration =1min 2.6400000000000006s
#
# 66
# Epoch duration =0.93s
# Cumulative duration =1min 3.5600000000000023s
#
# 67
# Epoch duration =0.93s
# Cumulative duration =1min 4.5s
#
# 68
# Epoch duration =0.91s
# Cumulative duration =1min 5.409999999999997s
#
# 69
# Epoch duration =0.96s
# Cumulative duration =1min 6.3700000000000045s
#
# 70
# Epoch duration =0.93s
# Cumulative duration =1min 7.299999999999997s
#
# 71
# Epoch duration =0.91s
# Cumulative duration =1min 8.209999999999994s
#
# 72
# Epoch duration =0.92s
# Cumulative duration =1min 9.129999999999995s
#
# 73
# Epoch duration =0.98s
# Cumulative duration =1min 10.11s
#
# 74
# Epoch duration =0.93s
# Cumulative duration =1min 11.040000000000006s
#
# 75
# Epoch duration =0.92s
# Cumulative duration =1min 11.950000000000003s
#
# 76
# Epoch duration =0.92s
# Cumulative duration =1min 12.879999999999995s
#
# 77
# Epoch duration =0.91s
# Cumulative duration =1min 13.790000000000006s
#
# 78
# Epoch duration =0.92s
# Cumulative duration =1min 14.709999999999994s
#
# 79
# Epoch duration =0.93s
# Cumulative duration =1min 15.64s
#
# 80
# Epoch duration =0.92s
# Cumulative duration =1min 16.560000000000002s
#
# 81
# Epoch duration =0.92s
# Cumulative duration =1min 17.489999999999995s
#
# 82
# Epoch duration =0.93s
# Cumulative duration =1min 18.42s
#
# 83
# Epoch duration =0.91s
# Cumulative duration =1min 19.33s
#
# 84
# Epoch duration =0.96s
# Cumulative duration =1min 20.290000000000006s
#
# 85
# Epoch duration =0.94s
# Cumulative duration =1min 21.239999999999995s
#
# 86
# Epoch duration =0.94s
# Cumulative duration =1min 22.180000000000007s
#
# 87
# Epoch duration =0.93s
# Cumulative duration =1min 23.099999999999994s
#
# 88
# Epoch duration =0.92s
# Cumulative duration =1min 24.019999999999996s
#
# 89
# Epoch duration =0.94s
# Cumulative duration =1min 24.950000000000003s
#
# 90
# Epoch duration =0.97s
# Cumulative duration =1min 25.930000000000007s
#
# 91
# Epoch duration =0.92s
# Cumulative duration =1min 26.849999999999994s
#
# 92
# Epoch duration =0.93s
# Cumulative duration =1min 27.78s
#
# 93
# Epoch duration =0.92s
# Cumulative duration =1min 28.700000000000003s
#
# 94
# Epoch duration =0.93s
# Cumulative duration =1min 29.629999999999995s
#
# 95
# Epoch duration =0.92s
# Cumulative duration =1min 30.549999999999997s
#
# 96
# Epoch duration =0.93s
# Cumulative duration =1min 31.480000000000004s
#
# 97
# Epoch duration =0.92s
# Cumulative duration =1min 32.400000000000006s
#
# 98
# Epoch duration =0.92s
# Cumulative duration =1min 33.31999999999999s
#
# 99
# Epoch duration =0.92s
# Cumulative duration =1min 34.239999999999995s
#
# 100
# Epoch duration =0.92s
# Cumulative duration =1min 35.17s
#
# 101
# Epoch duration =0.92s
# Cumulative duration =1min 36.09s
#
# 102
# Epoch duration =0.92s
# Cumulative duration =1min 37.010000000000005s
#
# 103
# Epoch duration =0.92s
# Cumulative duration =1min 37.93000000000001s
#
# 104
# Epoch duration =0.94s
# Cumulative duration =1min 38.870000000000005s
#
# 105
# Epoch duration =0.95s
# Cumulative duration =1min 39.81999999999999s
#
# 106
# Epoch duration =0.95s
# Cumulative duration =1min 40.769999999999996s
#
# 107
# Epoch duration =0.94s
# Cumulative duration =1min 41.709999999999994s
#
# 108
# Epoch duration =0.94s
# Cumulative duration =1min 42.650000000000006s
#
# 109
# Epoch duration =0.95s
# Cumulative duration =1min 43.599999999999994s
#
# 110
# Epoch duration =0.97s
# Cumulative duration =1min 44.56999999999999s
#
# 111
# Epoch duration =0.93s
# Cumulative duration =1min 45.5s
#
# 112
# Epoch duration =0.92s
# Cumulative duration =1min 46.42s
#
# 113
# Epoch duration =0.97s
# Cumulative duration =1min 47.39s
#
# 114
# Epoch duration =0.93s
# Cumulative duration =1min 48.31999999999999s
#
# 115
# Epoch duration =0.93s
# Cumulative duration =1min 49.25s
#
# 116
# Epoch duration =0.93s
# Cumulative duration =1min 50.18000000000001s
#
# 117
# Epoch duration =0.92s
# Cumulative duration =1min 51.099999999999994s
#
# 118
# Epoch duration =0.92s
# Cumulative duration =1min 52.019999999999996s
#
# 119
# Epoch duration =0.95s
# Cumulative duration =1min 52.97s
#
# 120
# Epoch duration =0.92s
# Cumulative duration =1min 53.89s
#
# 121
# Epoch duration =0.96s
# Cumulative duration =1min 54.86s
#
# 122
# Epoch duration =0.92s
# Cumulative duration =1min 55.769999999999996s
#
# 123
# Epoch duration =0.91s
# Cumulative duration =1min 56.68000000000001s
#
# 124
# Epoch duration =0.93s
# Cumulative duration =1min 57.61s
#
# 125
# Epoch duration =0.94s
# Cumulative duration =1min 58.55s
#
# 126
# Epoch duration =0.98s
# Cumulative duration =1min 59.53s
#
# 127
# Epoch duration =0.92s
# Cumulative duration =2min 0.45999999999999375s
#
# 128
# Epoch duration =0.97s
# Cumulative duration =2min 1.4300000000000068s
#
# 129
# Epoch duration =0.95s
# Cumulative duration =2min 2.3799999999999955s
#
# 130
# Epoch duration =0.96s
# Cumulative duration =2min 3.3400000000000034s
#
# 131
# Epoch duration =0.96s
# Cumulative duration =2min 4.290000000000006s
#
# 132
# Epoch duration =0.94s
# Cumulative duration =2min 5.239999999999995s
#
# 133
# Epoch duration =0.93s
# Cumulative duration =2min 6.159999999999997s
#
# 134
# Epoch duration =0.93s
# Cumulative duration =2min 7.099999999999994s
#
# 135
# Epoch duration =0.94s
# Cumulative duration =2min 8.039999999999992s
#
# 136
# Epoch duration =0.92s
# Cumulative duration =2min 8.960000000000008s
#
# 137
# Epoch duration =0.91s
# Cumulative duration =2min 9.879999999999995s
#
# 138
# Epoch duration =0.93s
# Cumulative duration =2min 10.800000000000011s
#
# 139
# Epoch duration =0.93s
# Cumulative duration =2min 11.72999999999999s
#
# 140
# Epoch duration =0.94s
# Cumulative duration =2min 12.680000000000007s
#
# 141
# Epoch duration =0.92s
# Cumulative duration =2min 13.599999999999994s
#
# 142
# Epoch duration =0.94s
# Cumulative duration =2min 14.539999999999992s
#
# 143
# Epoch duration =0.93s
# Cumulative duration =2min 15.47999999999999s
#
# 144
# Epoch duration =0.93s
# Cumulative duration =2min 16.409999999999997s
#
# 145
# Epoch duration =0.99s
# Cumulative duration =2min 17.389999999999986s
#
# 146
# Epoch duration =0.95s
# Cumulative duration =2min 18.340000000000003s
#
# 147
# Epoch duration =0.91s
# Cumulative duration =2min 19.25s
#
# 148
# Epoch duration =0.94s
# Cumulative duration =2min 20.19999999999999s
#
# 149
# Epoch duration =0.92s
# Cumulative duration =2min 21.120000000000005s
#
# 150
# Epoch duration =0.93s
# Cumulative duration =2min 22.05000000000001s
#
# 151
# Epoch duration =0.91s
# Cumulative duration =2min 22.960000000000008s
#
# 152
# Epoch duration =0.93s
# Cumulative duration =2min 23.889999999999986s
#
# 153
# Epoch duration =0.93s
# Cumulative duration =2min 24.819999999999993s
#
# 154
# Epoch duration =0.93s
# Cumulative duration =2min 25.75999999999999s
#
# 155
# Epoch duration =0.93s
# Cumulative duration =2min 26.689999999999998s
#
# 156
# Epoch duration =0.92s
# Cumulative duration =2min 27.610000000000014s
#
# 157
# Epoch duration =0.91s
# Cumulative duration =2min 28.52000000000001s
#
# 158
# Epoch duration =0.94s
# Cumulative duration =2min 29.460000000000008s
#
# 159
# Epoch duration =0.96s
# Cumulative duration =2min 30.419999999999987s
#
# 160
# Epoch duration =0.96s
# Cumulative duration =2min 31.379999999999995s
#
# 161
# Epoch duration =0.92s
# Cumulative duration =2min 32.30000000000001s
#
# 162
# Epoch duration =0.94s
# Cumulative duration =2min 33.24000000000001s
#
# 163
# Epoch duration =0.92s
# Cumulative duration =2min 34.16s
#
# 164
# Epoch duration =0.94s
# Cumulative duration =2min 35.099999999999994s
#
# 165
# Epoch duration =0.97s
# Cumulative duration =2min 36.06999999999999s
#
# 166
# Epoch duration =0.92s
# Cumulative duration =2min 36.99000000000001s
#
# 167
# Epoch duration =0.93s
# Cumulative duration =2min 37.91999999999999s
#
# 168
# Epoch duration =0.96s
# Cumulative duration =2min 38.879999999999995s
#
# 169
# Epoch duration =0.94s
# Cumulative duration =2min 39.81999999999999s
#
# 170
# Epoch duration =0.94s
# Cumulative duration =2min 40.75999999999999s
#
# 171
# Epoch duration =0.99s
# Cumulative duration =2min 41.75s
#
# 172
# Epoch duration =0.96s
# Cumulative duration =2min 42.71000000000001s
#
# 173
# Epoch duration =0.92s
# Cumulative duration =2min 43.629999999999995s
#
# 174
# Epoch duration =0.94s
# Cumulative duration =2min 44.58000000000001s
#
# 175
# Epoch duration =0.94s
# Cumulative duration =2min 45.52000000000001s
#
# 176
# Epoch duration =0.93s
# Cumulative duration =2min 46.44999999999999s
#
# 177
# Epoch duration =0.91s
# Cumulative duration =2min 47.349999999999994s
#
# 178
# Epoch duration =0.92s
# Cumulative duration =2min 48.28s
#
# 179
# Epoch duration =0.95s
# Cumulative duration =2min 49.22999999999999s
#
# 180
# Epoch duration =0.94s
# Cumulative duration =2min 50.16999999999999s
#
# 181
# Epoch duration =0.92s
# Cumulative duration =2min 51.09s
#
# 182
# Epoch duration =0.91s
# Cumulative duration =2min 52.0s
#
# 183
# Epoch duration =0.93s
# Cumulative duration =2min 52.93000000000001s
#
# 184
# Epoch duration =0.93s
# Cumulative duration =2min 53.860000000000014s
#
# 185
# Epoch duration =0.94s
# Cumulative duration =2min 54.80000000000001s
#
# 186
# Epoch duration =0.93s
# Cumulative duration =2min 55.72999999999999s
#
# 187
# Epoch duration =0.92s
# Cumulative duration =2min 56.650000000000006s
#
# 188
# Epoch duration =0.92s
# Cumulative duration =2min 57.56999999999999s
#
# 189
# Epoch duration =0.93s
# Cumulative duration =2min 58.5s
#
# 190
# Epoch duration =0.92s
# Cumulative duration =2min 59.41999999999999s
#
# 191
# Epoch duration =0.94s
# Cumulative duration =3min 0.36000000000001364s
#
# 192
# Epoch duration =0.96s
# Cumulative duration =3min 1.3199999999999932s
#
# 193
# Epoch duration =0.91s
# Cumulative duration =3min 2.240000000000009s
#
# 194
# Epoch duration =0.92s
# Cumulative duration =3min 3.1599999999999966s
#
# 195
# Epoch duration =0.92s
# Cumulative duration =3min 4.0800000000000125s
#
# 196
# Epoch duration =0.92s
# Cumulative duration =3min 5.0s
#
# 197
# Epoch duration =0.95s
# Cumulative duration =3min 5.949999999999989s
#
# 198
# Epoch duration =0.94s
# Cumulative duration =3min 6.889999999999986s
#
# 199
# Epoch duration =0.94s
# Cumulative duration =3min 7.8300000000000125s
#
# 200
# Epoch duration =0.94s
# Cumulative duration =3min 8.759999999999991s
#
# 201
# Epoch duration =0.92s
# Cumulative duration =3min 9.680000000000007s
#
# 202
# Epoch duration =0.92s
# Cumulative duration =3min 10.599999999999994s
#
# 203
# Epoch duration =0.92s
# Cumulative duration =3min 11.530000000000001s
#
# 204
# Epoch duration =0.92s
# Cumulative duration =3min 12.449999999999989s
#
# 205
# Epoch duration =0.91s
# Cumulative duration =3min 13.360000000000014s
#
# 206
# Epoch duration =0.93s
# Cumulative duration =3min 14.289999999999992s
#
# 207
# Epoch duration =0.91s
# Cumulative duration =3min 15.199999999999989s
#
# 208
# Epoch duration =0.94s
# Cumulative duration =3min 16.150000000000006s
#
# 209
# Epoch duration =0.92s
# Cumulative duration =3min 17.069999999999993s
#
# 210
# Epoch duration =0.93s
# Cumulative duration =3min 18.0s
#
# 211
# Epoch duration =0.94s
# Cumulative duration =3min 18.930000000000007s
#
# 212
# Epoch duration =0.95s
# Cumulative duration =3min 19.879999999999995s
#
# 213
# Epoch duration =0.95s
# Cumulative duration =3min 20.830000000000013s
#
# 214
# Epoch duration =0.93s
# Cumulative duration =3min 21.75s
#
# 215
# Epoch duration =0.92s
# Cumulative duration =3min 22.669999999999987s
#
# 216
# Epoch duration =0.94s
# Cumulative duration =3min 23.620000000000005s
#
# 217
# Epoch duration =0.92s
# Cumulative duration =3min 24.539999999999992s
#
# 218
# Epoch duration =0.93s
# Cumulative duration =3min 25.47s
#
# 219
# Epoch duration =0.91s
# Cumulative duration =3min 26.389999999999986s
#
# 220
# Epoch duration =0.94s
# Cumulative duration =3min 27.330000000000013s
#
# 221
# Epoch duration =0.94s
# Cumulative duration =3min 28.27000000000001s
#
# 222
# Epoch duration =0.92s
# Cumulative duration =3min 29.19999999999999s
#
# 223
# Epoch duration =0.97s
# Cumulative duration =3min 30.159999999999997s
#
# 224
# Epoch duration =0.96s
# Cumulative duration =3min 31.129999999999995s
#
# 225
# Epoch duration =0.92s
# Cumulative duration =3min 32.03999999999999s
#
# 226
# Epoch duration =0.96s
# Cumulative duration =3min 33.0s
#
# 227
# Epoch duration =0.93s
# Cumulative duration =3min 33.93000000000001s
#
# 228
# Epoch duration =0.93s
# Cumulative duration =3min 34.860000000000014s
#
# 229
# Epoch duration =0.96s
# Cumulative duration =3min 35.83000000000001s
#
# 230
# Epoch duration =0.97s
# Cumulative duration =3min 36.80000000000001s
#
# 231
# Epoch duration =0.94s
# Cumulative duration =3min 37.74000000000001s
#
# 232
# Epoch duration =0.92s
# Cumulative duration =3min 38.66s
#
# 233
# Epoch duration =0.93s
# Cumulative duration =3min 39.59s
#
# 234
# Epoch duration =0.92s
# Cumulative duration =3min 40.50999999999999s
#
# 235
# Epoch duration =0.92s
# Cumulative duration =3min 41.43000000000001s
#
# 236
# Epoch duration =0.97s
# Cumulative duration =3min 42.400000000000006s
#
# 237
# Epoch duration =0.92s
# Cumulative duration =3min 43.31999999999999s
#
# 238
# Epoch duration =0.93s
# Cumulative duration =3min 44.24000000000001s
#
# 239
# Epoch duration =0.93s
# Cumulative duration =3min 45.16999999999999s
#
# 240
# Epoch duration =0.93s
# Cumulative duration =3min 46.099999999999994s
#
# 241
# Epoch duration =0.92s
# Cumulative duration =3min 47.02000000000001s
#
# 242
# Epoch duration =0.99s
# Cumulative duration =3min 48.02000000000001s
#
# 243
# Epoch duration =0.93s
# Cumulative duration =3min 48.94999999999999s
#
# 244
# Epoch duration =0.98s
# Cumulative duration =3min 49.93000000000001s
#
# 245
# Epoch duration =0.93s
# Cumulative duration =3min 50.849999999999994s
#
# 246
# Epoch duration =0.94s
# Cumulative duration =3min 51.80000000000001s
#
# 247
# Epoch duration =0.92s
# Cumulative duration =3min 52.72s
#
# 248
# Epoch duration =0.93s
# Cumulative duration =3min 53.650000000000006s
#
# 249
# Epoch duration =0.92s
# Cumulative duration =3min 54.56999999999999s
#
# 250
# Epoch duration =0.92s
# Cumulative duration =3min 55.49000000000001s
#
# 251
# Epoch duration =0.92s
# Cumulative duration =3min 56.41s
#
# 252
# Epoch duration =0.91s
# Cumulative duration =3min 57.31999999999999s
#
# 253
# Epoch duration =0.94s
# Cumulative duration =3min 58.25999999999999s
#
# 254
# Epoch duration =0.93s
# Cumulative duration =3min 59.19s
#
# 255
# Epoch duration =0.94s
# Cumulative duration =4min 0.13999999999998636s
#
# 256
# Epoch duration =0.92s
# Cumulative duration =4min 1.0600000000000023s
#
# 257
# Epoch duration =0.93s
# Cumulative duration =4min 1.9799999999999898s
#
# 258
# Epoch duration =0.92s
# Cumulative duration =4min 2.9099999999999966s
#
# 259
# Epoch duration =1.0s
# Cumulative duration =4min 3.9000000000000057s
#
# 260
# Epoch duration =0.95s
# Cumulative duration =4min 4.849999999999994s
#
# 261
# Epoch duration =0.91s
# Cumulative duration =4min 5.759999999999991s
#
# 262
# Epoch duration =0.93s
# Cumulative duration =4min 6.699999999999989s
#
# 263
# Epoch duration =0.93s
# Cumulative duration =4min 7.6200000000000045s
#
# 264
# Epoch duration =0.92s
# Cumulative duration =4min 8.539999999999992s
#
# 265
# Epoch duration =0.93s
# Cumulative duration =4min 9.469999999999999s
#
# 266
# Epoch duration =0.95s
# Cumulative duration =4min 10.419999999999987s
#
# 267
# Epoch duration =0.92s
# Cumulative duration =4min 11.340000000000003s
#
# 268
# Epoch duration =0.95s
# Cumulative duration =4min 12.289999999999992s
#
# 269
# Epoch duration =0.92s
# Cumulative duration =4min 13.210000000000008s
#
# 270
# Epoch duration =0.95s
# Cumulative duration =4min 14.159999999999997s
#
# 271
# Epoch duration =0.93s
# Cumulative duration =4min 15.090000000000003s
#
# 272
# Epoch duration =0.91s
# Cumulative duration =4min 16.0s
#
# 273
# Epoch duration =0.92s
# Cumulative duration =4min 16.920000000000016s
#
# 274
# Epoch duration =0.93s
# Cumulative duration =4min 17.850000000000023s
#
# 275
# Epoch duration =0.91s
# Cumulative duration =4min 18.75999999999999s
#
# 276
# Epoch duration =0.92s
# Cumulative duration =4min 19.680000000000007s
#
# 277
# Epoch duration =0.94s
# Cumulative duration =4min 20.620000000000005s
#
# 278
# Epoch duration =0.92s
# Cumulative duration =4min 21.54000000000002s
#
# 279
# Epoch duration =0.94s
# Cumulative duration =4min 22.49000000000001s
#
# 280
# Epoch duration =0.96s
# Cumulative duration =4min 23.44999999999999s
#
# 281
# Epoch duration =0.94s
# Cumulative duration =4min 24.379999999999995s
#
# 282
# Epoch duration =0.93s
# Cumulative duration =4min 25.310000000000002s
#
# 283
# Epoch duration =0.94s
# Cumulative duration =4min 26.25s
#
# 284
# Epoch duration =0.92s
# Cumulative duration =4min 27.180000000000007s
#
# 285
# Epoch duration =0.92s
# Cumulative duration =4min 28.100000000000023s
#
# 286
# Epoch duration =0.94s
# Cumulative duration =4min 29.029999999999973s
#
# 287
# Epoch duration =0.92s
# Cumulative duration =4min 29.94999999999999s
#
# 288
# Epoch duration =1.19s
# Cumulative duration =4min 31.129999999999995s
#
# 289
# Epoch duration =1.39s
# Cumulative duration =4min 32.51999999999998s
#
# 290
# Epoch duration =1.14s
# Cumulative duration =4min 33.660000000000025s
#
# 291
# Epoch duration =1.04s
# Cumulative duration =4min 34.69999999999999s
#
# 292
# Epoch duration =1.05s
# Cumulative duration =4min 35.75s
#
# 293
# Epoch duration =0.96s
# Cumulative duration =4min 36.72000000000003s
#
# 294
# Epoch duration =0.93s
# Cumulative duration =4min 37.64999999999998s
#
# 295
# Epoch duration =0.95s
# Cumulative duration =4min 38.589999999999975s
#
# 296
# Epoch duration =0.92s
# Cumulative duration =4min 39.51999999999998s
#
# 297
# Epoch duration =0.96s
# Cumulative duration =4min 40.47000000000003s
#
# 298
# Epoch duration =0.95s
# Cumulative duration =4min 41.420000000000016s
#
# 299
# Epoch duration =0.92s
# Cumulative duration =4min 42.35000000000002s
#
# 300
# Epoch duration =0.97s
# Cumulative duration =4min 43.31s
#
# 301
# Epoch duration =0.92s
# Cumulative duration =4min 44.24000000000001s
#
# 302
# Epoch duration =0.95s
# Cumulative duration =4min 45.18000000000001s
#
# 303
# Epoch duration =0.91s
# Cumulative duration =4min 46.089999999999975s
#
# 304
# Epoch duration =0.92s
# Cumulative duration =4min 47.00999999999999s
#
# 305
# Epoch duration =0.91s
# Cumulative duration =4min 47.93000000000001s
#
# 306
# Epoch duration =0.93s
# Cumulative duration =4min 48.860000000000014s
#
# 307
# Epoch duration =0.94s
# Cumulative duration =4min 49.80000000000001s
#
# 308
# Epoch duration =0.92s
# Cumulative duration =4min 50.72000000000003s
#
# 309
# Epoch duration =0.93s
# Cumulative duration =4min 51.64999999999998s
#
# 310
# Epoch duration =0.93s
# Cumulative duration =4min 52.579999999999984s
#
# 311
# Epoch duration =0.94s
# Cumulative duration =4min 53.51999999999998s
#
# 312
# Epoch duration =0.94s
# Cumulative duration =4min 54.44999999999999s
#
# 313
# Epoch duration =0.92s
# Cumulative duration =4min 55.370000000000005s
#
# 314
# Epoch duration =0.98s
# Cumulative duration =4min 56.339999999999975s
#
# 315
# Epoch duration =0.93s
# Cumulative duration =4min 57.27999999999997s
#
# 316
# Epoch duration =0.92s
# Cumulative duration =4min 58.19999999999999s
#
# 317
# Epoch duration =0.93s
# Cumulative duration =4min 59.129999999999995s
#
# 318
# Epoch duration =0.92s
# Cumulative duration =5min 0.05000000000001137s
#
# 319
# Epoch duration =0.92s
# Cumulative duration =5min 0.9700000000000273s
#
# 320
# Epoch duration =0.93s
# Cumulative duration =5min 1.8999999999999773s
#
# 321
# Epoch duration =0.98s
# Cumulative duration =5min 2.8799999999999955s
#
# 322
# Epoch duration =0.94s
# Cumulative duration =5min 3.819999999999993s
#
# 323
# Epoch duration =0.93s
# Cumulative duration =5min 4.75s
#
# 324
# Epoch duration =0.96s
# Cumulative duration =5min 5.7099999999999795s
#
# 325
# Epoch duration =0.92s
# Cumulative duration =5min 6.639999999999986s
#
# 326
# Epoch duration =0.93s
# Cumulative duration =5min 7.569999999999993s
#
# 327
# Epoch duration =0.93s
# Cumulative duration =5min 8.5s
#
# 328
# Epoch duration =0.94s
# Cumulative duration =5min 9.439999999999998s
#
# 329
# Epoch duration =0.93s
# Cumulative duration =5min 10.360000000000014s
#
# 330
# Epoch duration =0.94s
# Cumulative duration =5min 11.300000000000011s
#
# 331
# Epoch duration =0.91s
# Cumulative duration =5min 12.20999999999998s
#
# 332
# Epoch duration =0.92s
# Cumulative duration =5min 13.120000000000005s
#
# 333
# Epoch duration =0.92s
# Cumulative duration =5min 14.050000000000011s
#
# 334
# Epoch duration =0.93s
# Cumulative duration =5min 14.980000000000018s
#
# 335
# Epoch duration =0.92s
# Cumulative duration =5min 15.899999999999977s
#
# 336
# Epoch duration =0.95s
# Cumulative duration =5min 16.850000000000023s
#
# 337
# Epoch duration =0.92s
# Cumulative duration =5min 17.779999999999973s
#
# 338
# Epoch duration =0.95s
# Cumulative duration =5min 18.730000000000018s
#
# 339
# Epoch duration =0.92s
# Cumulative duration =5min 19.649999999999977s
#
# 340
# Epoch duration =0.92s
# Cumulative duration =5min 20.579999999999984s
#
# 341
# Epoch duration =0.92s
# Cumulative duration =5min 21.5s
#
# 342
# Epoch duration =0.94s
# Cumulative duration =5min 22.439999999999998s
#
# 343
# Epoch duration =0.99s
# Cumulative duration =5min 23.430000000000007s
#
# 344
# Epoch duration =0.93s
# Cumulative duration =5min 24.360000000000014s
#
# 345
# Epoch duration =0.9s
# Cumulative duration =5min 25.25999999999999s
#
# 346
# Epoch duration =0.94s
# Cumulative duration =5min 26.19999999999999s
#
# 347
# Epoch duration =0.94s
# Cumulative duration =5min 27.139999999999986s
#
# 348
# Epoch duration =0.95s
# Cumulative duration =5min 28.089999999999975s
#
# 349
# Epoch duration =0.94s
# Cumulative duration =5min 29.019999999999982s
#
# 350
# Epoch duration =0.93s
# Cumulative duration =5min 29.94999999999999s
#
# 351
# Epoch duration =0.96s
# Cumulative duration =5min 30.910000000000025s
#
# 352
# Epoch duration =0.94s
# Cumulative duration =5min 31.850000000000023s
#
# 353
# Epoch duration =0.92s
# Cumulative duration =5min 32.76999999999998s
#
# 354
# Epoch duration =0.94s
# Cumulative duration =5min 33.70999999999998s
#
# 355
# Epoch duration =0.93s
# Cumulative duration =5min 34.639999999999986s
#
# 356
# Epoch duration =0.93s
# Cumulative duration =5min 35.579999999999984s
#
# 357
# Epoch duration =0.92s
# Cumulative duration =5min 36.49000000000001s
#
# 358
# Epoch duration =0.94s
# Cumulative duration =5min 37.43000000000001s
#
# 359
# Epoch duration =0.93s
# Cumulative duration =5min 38.360000000000014s
#
# 360
# Epoch duration =0.97s
# Cumulative duration =5min 39.329999999999984s
#
# 361
# Epoch duration =0.92s
# Cumulative duration =5min 40.25999999999999s
#
# 362
# Epoch duration =0.94s
# Cumulative duration =5min 41.19999999999999s
#
# 363
# Epoch duration =0.91s
# Cumulative duration =5min 42.110000000000014s
#
# 364
# Epoch duration =0.92s
# Cumulative duration =5min 43.02999999999997s
#
# 365
# Epoch duration =0.92s
# Cumulative duration =5min 43.94999999999999s
#
# 366
# Epoch duration =0.96s
# Cumulative duration =5min 44.910000000000025s
#
# 367
# Epoch duration =0.92s
# Cumulative duration =5min 45.81999999999999s
#
# 368
# Epoch duration =0.93s
# Cumulative duration =5min 46.75999999999999s
#
# 369
# Epoch duration =0.94s
# Cumulative duration =5min 47.69s
#
# 370
# Epoch duration =0.91s
# Cumulative duration =5min 48.60000000000002s
#
# 371
# Epoch duration =0.94s
# Cumulative duration =5min 49.54000000000002s
#
# 372
# Epoch duration =0.92s
# Cumulative duration =5min 50.47000000000003s
#
# 373
# Epoch duration =0.92s
# Cumulative duration =5min 51.379999999999995s
#
# 374
# Epoch duration =0.93s
# Cumulative duration =5min 52.31s
#
# 375
# Epoch duration =0.94s
# Cumulative duration =5min 53.25s
#
# 376
# Epoch duration =0.93s
# Cumulative duration =5min 54.18000000000001s
#
# 377
# Epoch duration =0.92s
# Cumulative duration =5min 55.10000000000002s
#
# 378
# Epoch duration =0.97s
# Cumulative duration =5min 56.06999999999999s
#
# 379
# Epoch duration =0.94s
# Cumulative duration =5min 57.00999999999999s
#
# 380
# Epoch duration =0.94s
# Cumulative duration =5min 57.94s
#
# 381
# Epoch duration =0.92s
# Cumulative duration =5min 58.860000000000014s
#
# 382
# Epoch duration =0.93s
# Cumulative duration =5min 59.80000000000001s
#
# 383
# Epoch duration =0.93s
# Cumulative duration =6min 0.7300000000000182s
#
# 384
# Epoch duration =0.92s
# Cumulative duration =6min 1.6399999999999864s
#
# 385
# Epoch duration =0.94s
# Cumulative duration =6min 2.579999999999984s
#
# 386
# Epoch duration =0.97s
# Cumulative duration =6min 3.5600000000000023s
#
# 387
# Epoch duration =0.97s
# Cumulative duration =6min 4.529999999999973s
#
# 388
# Epoch duration =0.93s
# Cumulative duration =6min 5.4599999999999795s
#
# 389
# Epoch duration =0.95s
# Cumulative duration =6min 6.410000000000025s
#
# 390
# Epoch duration =0.93s
# Cumulative duration =6min 7.329999999999984s
#
# 391
# Epoch duration =0.92s
# Cumulative duration =6min 8.25s
#
# 392
# Epoch duration =0.96s
# Cumulative duration =6min 9.20999999999998s
#
# 393
# Epoch duration =0.93s
# Cumulative duration =6min 10.149999999999977s
#
# 394
# Epoch duration =0.94s
# Cumulative duration =6min 11.089999999999975s
#
# 395
# Epoch duration =0.94s
# Cumulative duration =6min 12.029999999999973s
#
# 396
# Epoch duration =0.94s
# Cumulative duration =6min 12.970000000000027s
#
# 397
# Epoch duration =0.94s
# Cumulative duration =6min 13.899999999999977s
#
# 398
# Epoch duration =0.92s
# Cumulative duration =6min 14.819999999999993s
#
# 399
# Epoch duration =0.94s
# Cumulative duration =6min 15.759999999999991s
#
# 400
# Epoch duration =0.95s
# Cumulative duration =6min 16.70999999999998s
#
# 401
# Epoch duration =0.92s
# Cumulative duration =6min 17.629999999999995s
#
# 402
# Epoch duration =0.92s
# Cumulative duration =6min 18.55000000000001s
#
# 403
# Epoch duration =0.96s
# Cumulative duration =6min 19.50999999999999s
#
# 404
# Epoch duration =0.94s
# Cumulative duration =6min 20.44999999999999s
#
# 405
# Epoch duration =0.91s
# Cumulative duration =6min 21.370000000000005s
#
# 406
# Epoch duration =0.92s
# Cumulative duration =6min 22.29000000000002s
#
# 407
# Epoch duration =0.96s
# Cumulative duration =6min 23.25s
#
# 408
# Epoch duration =0.93s
# Cumulative duration =6min 24.180000000000007s
#
# 409
# Epoch duration =0.91s
# Cumulative duration =6min 25.100000000000023s
#
# 410
# Epoch duration =0.93s
# Cumulative duration =6min 26.029999999999973s
#
# 411
# Epoch duration =0.92s
# Cumulative duration =6min 26.94999999999999s
#
# 412
# Epoch duration =0.92s
# Cumulative duration =6min 27.879999999999995s
#
# 413
# Epoch duration =0.95s
# Cumulative duration =6min 28.829999999999984s
#
# 414
# Epoch duration =0.92s
# Cumulative duration =6min 29.74000000000001s
#
# 415
# Epoch duration =0.94s
# Cumulative duration =6min 30.689999999999998s
#
# 416
# Epoch duration =0.94s
# Cumulative duration =6min 31.629999999999995s
#
# 417
# Epoch duration =0.94s
# Cumulative duration =6min 32.56999999999999s
#
# 418
# Epoch duration =0.93s
# Cumulative duration =6min 33.5s
#
# 419
# Epoch duration =0.93s
# Cumulative duration =6min 34.43000000000001s
#
# 420
# Epoch duration =0.96s
# Cumulative duration =6min 35.389999999999986s
#
# 421
# Epoch duration =0.93s
# Cumulative duration =6min 36.31999999999999s
#
# 422
# Epoch duration =0.94s
# Cumulative duration =6min 37.26999999999998s
#
# 423
# Epoch duration =0.94s
# Cumulative duration =6min 38.19999999999999s
#
# 424
# Epoch duration =0.94s
# Cumulative duration =6min 39.139999999999986s
#
# 425
# Epoch duration =0.93s
# Cumulative duration =6min 40.06999999999999s
#
# 426
# Epoch duration =0.92s
# Cumulative duration =6min 40.99000000000001s
#
# 427
# Epoch duration =0.95s
# Cumulative duration =6min 41.94s
#
# 428
# Epoch duration =0.94s
# Cumulative duration =6min 42.879999999999995s
#
# 429
# Epoch duration =0.91s
# Cumulative duration =6min 43.80000000000001s
#
# 430
# Epoch duration =0.93s
# Cumulative duration =6min 44.73000000000002s
#
# 431
# Epoch duration =0.94s
# Cumulative duration =6min 45.670000000000016s
#
# 432
# Epoch duration =0.93s
# Cumulative duration =6min 46.60000000000002s
#
# 433
# Epoch duration =0.94s
# Cumulative duration =6min 47.54000000000002s
#
# 434
# Epoch duration =0.91s
# Cumulative duration =6min 48.44999999999999s
#
# 435
# Epoch duration =0.94s
# Cumulative duration =6min 49.389999999999986s
#
# 436
# Epoch duration =0.94s
# Cumulative duration =6min 50.329999999999984s
#
# 437
# Epoch duration =0.92s
# Cumulative duration =6min 51.25s
#
# 438
# Epoch duration =0.93s
# Cumulative duration =6min 52.19s
#
# 439
# Epoch duration =0.95s
# Cumulative duration =6min 53.139999999999986s
#
# 440
# Epoch duration =0.95s
# Cumulative duration =6min 54.089999999999975s
#
# 441
# Epoch duration =0.96s
# Cumulative duration =6min 55.05000000000001s
#
# 442
# Epoch duration =0.95s
# Cumulative duration =6min 56.0s
#
# 443
# Epoch duration =0.96s
# Cumulative duration =6min 56.97000000000003s
#
# 444
# Epoch duration =0.92s
# Cumulative duration =6min 57.889999999999986s
#
# 445
# Epoch duration =0.93s
# Cumulative duration =6min 58.81999999999999s
#
# 446
# Epoch duration =0.93s
# Cumulative duration =6min 59.75s
#
# 447
# Epoch duration =0.94s
# Cumulative duration =7min 0.6800000000000068s
#
# 448
# Epoch duration =0.92s
# Cumulative duration =7min 1.6100000000000136s
#
# 449
# Epoch duration =0.96s
# Cumulative duration =7min 2.569999999999993s
#
# 450
# Epoch duration =0.93s
# Cumulative duration =7min 3.509999999999991s
#
# 451
# Epoch duration =0.93s
# Cumulative duration =7min 4.430000000000007s
#
# 452
# Epoch duration =0.92s
# Cumulative duration =7min 5.360000000000014s
#
# 453
# Epoch duration =0.91s
# Cumulative duration =7min 6.269999999999982s
#
# 454
# Epoch duration =0.94s
# Cumulative duration =7min 7.2099999999999795s
#
# 455
# Epoch duration =0.91s
# Cumulative duration =7min 8.120000000000005s
#
# 456
# Epoch duration =0.94s
# Cumulative duration =7min 9.069999999999993s
#
# 457
# Epoch duration =0.92s
# Cumulative duration =7min 9.990000000000009s
#
# 458
# Epoch duration =0.92s
# Cumulative duration =7min 10.899999999999977s
#
# 459
# Epoch duration =0.93s
# Cumulative duration =7min 11.829999999999984s
#
# 460
# Epoch duration =0.93s
# Cumulative duration =7min 12.759999999999991s
#
# 461
# Epoch duration =0.92s
# Cumulative duration =7min 13.680000000000007s
#
# 462
# Epoch duration =1.0s
# Cumulative duration =7min 14.680000000000007s
#
# 463
# Epoch duration =0.93s
# Cumulative duration =7min 15.610000000000014s
#
# 464
# Epoch duration =0.95s
# Cumulative duration =7min 16.560000000000002s
#
# 465
# Epoch duration =0.93s
# Cumulative duration =7min 17.49000000000001s
#
# 466
# Epoch duration =0.93s
# Cumulative duration =7min 18.430000000000007s
#
# 467
# Epoch duration =0.92s
# Cumulative duration =7min 19.350000000000023s
#
# 468
# Epoch duration =0.92s
# Cumulative duration =7min 20.269999999999982s
#
# 469
# Epoch duration =0.97s
# Cumulative duration =7min 21.25s
#
# 470
# Epoch duration =0.94s
# Cumulative duration =7min 22.180000000000007s
#
# 471
# Epoch duration =0.93s
# Cumulative duration =7min 23.120000000000005s
#
# 472
# Epoch duration =0.94s
# Cumulative duration =7min 24.060000000000002s
#
# 473
# Epoch duration =0.93s
# Cumulative duration =7min 24.99000000000001s
#
# 474
# Epoch duration =0.93s
# Cumulative duration =7min 25.920000000000016s
#
# 475
# Epoch duration =0.92s
# Cumulative duration =7min 26.839999999999975s
#
# 476
# Epoch duration =0.94s
# Cumulative duration =7min 27.779999999999973s
#
# 477
# Epoch duration =0.91s
# Cumulative duration =7min 28.69999999999999s
#
# 478
# Epoch duration =0.92s
# Cumulative duration =7min 29.610000000000014s
#
# 479
# Epoch duration =0.91s
# Cumulative duration =7min 30.529999999999973s
#
# 480
# Epoch duration =0.95s
# Cumulative duration =7min 31.480000000000018s
#
# 481
# Epoch duration =0.94s
# Cumulative duration =7min 32.420000000000016s
#
# 482
# Epoch duration =0.92s
# Cumulative duration =7min 33.339999999999975s
#
# 483
# Epoch duration =0.94s
# Cumulative duration =7min 34.27999999999997s
#
# 484
# Epoch duration =0.94s
# Cumulative duration =7min 35.23000000000002s
#
# 485
# Epoch duration =0.92s
# Cumulative duration =7min 36.14999999999998s
#
# 486
# Epoch duration =0.94s
# Cumulative duration =7min 37.089999999999975s
#
# 487
# Epoch duration =0.93s
# Cumulative duration =7min 38.01999999999998s
#
# 488
# Epoch duration =0.93s
# Cumulative duration =7min 38.94999999999999s
#
# 489
# Epoch duration =0.92s
# Cumulative duration =7min 39.870000000000005s
#
# 490
# Epoch duration =0.93s
# Cumulative duration =7min 40.79000000000002s
#
# 491
# Epoch duration =0.94s
# Cumulative duration =7min 41.73000000000002s
#
# 492
# Epoch duration =0.94s
# Cumulative duration =7min 42.670000000000016s
#
# 493
# Epoch duration =0.94s
# Cumulative duration =7min 43.610000000000014s
#
# 494
# Epoch duration =0.96s
# Cumulative duration =7min 44.56999999999999s
#
# 495
# Epoch duration =0.93s
# Cumulative duration =7min 45.5s
#
# 496
# Epoch duration =0.95s
# Cumulative duration =7min 46.44999999999999s
#
# 497
# Epoch duration =0.94s
# Cumulative duration =7min 47.389999999999986s
#
# 498
# Epoch duration =0.94s
# Cumulative duration =7min 48.339999999999975s
#
# 499
# Epoch duration =0.93s
# Cumulative duration =7min 49.25999999999999s
#
# Saving scores to Arrays/trna_mlpt3_44_ug_so500.npy

# %%
#load values
savepath = 'Arrays/trna_mlpt3_44_ug_so500.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 500
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, vmax=1.0, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
