# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/trna_100k_d5.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 6.12s

# %%
simalign_file = '../../../data_RFAM/trnasim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((((<<<<>>>><<<<<>>>>><<<<<>>>>>)))))))'

# %%
ugSS
# Out:
# '(((((((,,<<<<_______>>>>,<<<<<_______>>>>>,,,,<<<<<_______>>>>>))))))):'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/trna'
param_path = os.path.join(save_path, 'mlp_t3_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 513, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=3.77s -- loss=0.29566 -- acc=87.358336%
#
#   valid loss:		0.05340
#   valid accuracy:	0.99490+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.45s -- loss=0.10478 -- acc=96.548345%
#
#   valid loss:		0.02824
#   valid accuracy:	0.99675+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.08342 -- acc=97.165847%
#
#   valid loss:		0.02906
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.18s -- loss=0.07485 -- acc=97.550835%
#
#   valid loss:		0.01954
#   valid accuracy:	0.99615+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.12s -- loss=0.06855 -- acc=97.772507%
#
#   valid loss:		0.01915
#   valid accuracy:	0.99690+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.14s -- loss=0.06585 -- acc=97.925003%
#
#   valid loss:		0.01748
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.24s -- loss=0.06296 -- acc=98.048335%
#
#   valid loss:		0.01621
#   valid accuracy:	0.99750+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t3_44_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.06506 -- acc=98.029173%
#
#   valid loss:		0.01769
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.06204 -- acc=98.093339%
#
#   valid loss:		0.01684
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.06235 -- acc=98.152505%
#
#   valid loss:		0.01829
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.13s -- loss=0.06134 -- acc=98.178338%
#
#   valid loss:		0.01782
#   valid accuracy:	0.99720+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.06s -- loss=0.05801 -- acc=98.294179%
#
#   valid loss:		0.01726
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.06s -- loss=0.06018 -- acc=98.320832%
#
#   valid loss:		0.01854
#   valid accuracy:	0.99730+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.15s -- loss=0.05799 -- acc=98.354175%
#
#   valid loss:		0.01760
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99966+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.27s -- loss=0.05875 -- acc=98.335004%
#
#   valid loss:		0.01836
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.14s -- loss=0.05760 -- acc=98.389179%
#
#   valid loss:		0.01832
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99971+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.11s -- loss=0.05889 -- acc=98.385009%
#
#   valid loss:		0.01844
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99972+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.05685 -- acc=98.551675%
#
#   valid loss:		0.01838
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.15s -- loss=0.05676 -- acc=98.574177%
#
#   valid loss:		0.01822
#   valid accuracy:	0.99720+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.12s -- loss=0.05652 -- acc=98.600830%
#
#   valid loss:		0.01799
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.05653 -- acc=98.565837%
#
#   valid loss:		0.02049
#   valid accuracy:	0.99720+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.15s -- loss=0.05647 -- acc=98.624172%
#
#   valid loss:		0.02001
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.21s -- loss=0.05721 -- acc=98.578338%
#
#   valid loss:		0.01915
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.16s -- loss=0.05761 -- acc=98.561676%
#
#   valid loss:		0.01878
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99972+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.10s -- loss=0.05671 -- acc=98.635004%
#
#   valid loss:		0.01926
#   valid accuracy:	0.99700+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.05419 -- acc=98.685839%
#
#   valid loss:		0.01890
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.05601 -- acc=98.661676%
#
#   valid loss:		0.01856
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.10s -- loss=0.05573 -- acc=98.676678%
#
#   valid loss:		0.01799
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.05649 -- acc=98.664176%
#
#   valid loss:		0.01954
#   valid accuracy:	0.99750+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99972+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.09s -- loss=0.05585 -- acc=98.680838%
#
#   valid loss:		0.01930
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.15s -- loss=0.05494 -- acc=98.686679%
#
#   valid loss:		0.01986
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.11s -- loss=0.05641 -- acc=98.693339%
#
#   valid loss:		0.01971
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.11s -- loss=0.05712 -- acc=98.689179%
#
#   valid loss:		0.01921
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.14s -- loss=0.05721 -- acc=98.635834%
#
#   valid loss:		0.02195
#   valid accuracy:	0.99685+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99971+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.12s -- loss=0.05565 -- acc=98.704170%
#
#   valid loss:		0.02115
#   valid accuracy:	0.99705+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.15s -- loss=0.05625 -- acc=98.718332%
#
#   valid loss:		0.01980
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.15s -- loss=0.05849 -- acc=98.621672%
#
#   valid loss:		0.02077
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.07s -- loss=0.05394 -- acc=98.755006%
#
#   valid loss:		0.01888
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.13s -- loss=0.05543 -- acc=98.710831%
#
#   valid loss:		0.02011
#   valid accuracy:	0.99730+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.16s -- loss=0.05570 -- acc=98.722502%
#
#   valid loss:		0.02112
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.11s -- loss=0.05447 -- acc=98.763336%
#
#   valid loss:		0.02009
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99973+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.22s -- loss=0.05538 -- acc=98.711671%
#
#   valid loss:		0.02018
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.26s -- loss=0.05467 -- acc=98.734173%
#
#   valid loss:		0.02011
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.17s -- loss=0.05455 -- acc=98.735004%
#
#   valid loss:		0.02114
#   valid accuracy:	0.99750+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99951+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.18s -- loss=0.05504 -- acc=98.769177%
#
#   valid loss:		0.02068
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.14s -- loss=0.05344 -- acc=98.787509%
#
#   valid loss:		0.02014
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99965+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.16s -- loss=0.05398 -- acc=98.747505%
#
#   valid loss:		0.01978
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99966+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/trna/mlp_t3_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/trna/mlp_t3_44_best.ckpt
#   test  loss:		0.01418
#   test  accuracy:	0.99837+/-0.00000
#   test  auc-roc:	0.99996+/-0.00000
#   test  auc-pr:		0.99994+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/trna_mlpt3_44_ug_so500.npy'

num_summary = 500
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =0.91s
# Cumulative duration =0.91s
#
# 1
# Epoch duration =0.9s
# Cumulative duration =1.8s
#
# 2
# Epoch duration =0.91s
# Cumulative duration =2.71s
#
# 3
# Epoch duration =0.9s
# Cumulative duration =3.61s
#
# 4
# Epoch duration =0.93s
# Cumulative duration =4.54s
#
# 5
# Epoch duration =0.9s
# Cumulative duration =5.44s
#
# 6
# Epoch duration =0.91s
# Cumulative duration =6.35s
#
# 7
# Epoch duration =0.9s
# Cumulative duration =7.25s
#
# 8
# Epoch duration =0.89s
# Cumulative duration =8.14s
#
# 9
# Epoch duration =0.9s
# Cumulative duration =9.04s
#
# 10
# Epoch duration =0.9s
# Cumulative duration =9.94s
#
# 11
# Epoch duration =0.89s
# Cumulative duration =10.83s
#
# 12
# Epoch duration =0.9s
# Cumulative duration =11.73s
#
# 13
# Epoch duration =0.89s
# Cumulative duration =12.63s
#
# 14
# Epoch duration =0.91s
# Cumulative duration =13.53s
#
# 15
# Epoch duration =0.9s
# Cumulative duration =14.43s
#
# 16
# Epoch duration =0.9s
# Cumulative duration =15.33s
#
# 17
# Epoch duration =0.89s
# Cumulative duration =16.22s
#
# 18
# Epoch duration =0.9s
# Cumulative duration =17.12s
#
# 19
# Epoch duration =0.91s
# Cumulative duration =18.02s
#
# 20
# Epoch duration =0.89s
# Cumulative duration =18.92s
#
# 21
# Epoch duration =0.91s
# Cumulative duration =19.83s
#
# 22
# Epoch duration =0.89s
# Cumulative duration =20.71s
#
# 23
# Epoch duration =0.9s
# Cumulative duration =21.61s
#
# 24
# Epoch duration =0.9s
# Cumulative duration =22.51s
#
# 25
# Epoch duration =0.91s
# Cumulative duration =23.42s
#
# 26
# Epoch duration =0.9s
# Cumulative duration =24.32s
#
# 27
# Epoch duration =0.9s
# Cumulative duration =25.21s
#
# 28
# Epoch duration =0.89s
# Cumulative duration =26.11s
#
# 29
# Epoch duration =0.94s
# Cumulative duration =27.05s
#
# 30
# Epoch duration =0.9s
# Cumulative duration =27.95s
#
# 31
# Epoch duration =0.89s
# Cumulative duration =28.83s
#
# 32
# Epoch duration =0.91s
# Cumulative duration =29.74s
#
# 33
# Epoch duration =0.9s
# Cumulative duration =30.64s
#
# 34
# Epoch duration =0.89s
# Cumulative duration =31.53s
#
# 35
# Epoch duration =0.89s
# Cumulative duration =32.42s
#
# 36
# Epoch duration =0.91s
# Cumulative duration =33.33s
#
# 37
# Epoch duration =0.91s
# Cumulative duration =34.23s
#
# 38
# Epoch duration =0.95s
# Cumulative duration =35.18s
#
# 39
# Epoch duration =0.9s
# Cumulative duration =36.08s
#
# 40
# Epoch duration =0.89s
# Cumulative duration =36.98s
#
# 41
# Epoch duration =0.9s
# Cumulative duration =37.87s
#
# 42
# Epoch duration =0.9s
# Cumulative duration =38.77s
#
# 43
# Epoch duration =0.9s
# Cumulative duration =39.67s
#
# 44
# Epoch duration =0.95s
# Cumulative duration =40.62s
#
# 45
# Epoch duration =0.89s
# Cumulative duration =41.51s
#
# 46
# Epoch duration =0.89s
# Cumulative duration =42.41s
#
# 47
# Epoch duration =0.91s
# Cumulative duration =43.31s
#
# 48
# Epoch duration =0.89s
# Cumulative duration =44.21s
#
# 49
# Epoch duration =0.89s
# Cumulative duration =45.1s
#
# 50
# Epoch duration =0.91s
# Cumulative duration =46.02s
#
# 51
# Epoch duration =0.93s
# Cumulative duration =46.95s
#
# 52
# Epoch duration =0.89s
# Cumulative duration =47.84s
#
# 53
# Epoch duration =0.9s
# Cumulative duration =48.74s
#
# 54
# Epoch duration =0.9s
# Cumulative duration =49.64s
#
# 55
# Epoch duration =0.89s
# Cumulative duration =50.53s
#
# 56
# Epoch duration =0.91s
# Cumulative duration =51.44s
#
# 57
# Epoch duration =0.92s
# Cumulative duration =52.35s
#
# 58
# Epoch duration =0.91s
# Cumulative duration =53.26s
#
# 59
# Epoch duration =0.9s
# Cumulative duration =54.16s
#
# 60
# Epoch duration =0.93s
# Cumulative duration =55.09s
#
# 61
# Epoch duration =0.9s
# Cumulative duration =55.99s
#
# 62
# Epoch duration =0.91s
# Cumulative duration =56.91s
#
# 63
# Epoch duration =0.89s
# Cumulative duration =57.8s
#
# 64
# Epoch duration =0.89s
# Cumulative duration =58.69s
#
# 65
# Epoch duration =0.89s
# Cumulative duration =59.59s
#
# 66
# Epoch duration =0.92s
# Cumulative duration =1min 0.5s
#
# 67
# Epoch duration =0.93s
# Cumulative duration =1min 1.4299999999999997s
#
# 68
# Epoch duration =0.9s
# Cumulative duration =1min 2.3400000000000034s
#
# 69
# Epoch duration =0.89s
# Cumulative duration =1min 3.229999999999997s
#
# 70
# Epoch duration =0.89s
# Cumulative duration =1min 4.1200000000000045s
#
# 71
# Epoch duration =0.88s
# Cumulative duration =1min 5.0s
#
# 72
# Epoch duration =0.9s
# Cumulative duration =1min 5.900000000000006s
#
# 73
# Epoch duration =0.88s
# Cumulative duration =1min 6.780000000000001s
#
# 74
# Epoch duration =0.9s
# Cumulative duration =1min 7.680000000000007s
#
# 75
# Epoch duration =0.9s
# Cumulative duration =1min 8.579999999999998s
#
# 76
# Epoch duration =0.9s
# Cumulative duration =1min 9.480000000000004s
#
# 77
# Epoch duration =0.91s
# Cumulative duration =1min 10.379999999999995s
#
# 78
# Epoch duration =0.91s
# Cumulative duration =1min 11.299999999999997s
#
# 79
# Epoch duration =0.92s
# Cumulative duration =1min 12.209999999999994s
#
# 80
# Epoch duration =0.9s
# Cumulative duration =1min 13.11s
#
# 81
# Epoch duration =0.9s
# Cumulative duration =1min 14.010000000000005s
#
# 82
# Epoch duration =0.94s
# Cumulative duration =1min 14.950000000000003s
#
# 83
# Epoch duration =0.88s
# Cumulative duration =1min 15.840000000000003s
#
# 84
# Epoch duration =0.91s
# Cumulative duration =1min 16.75s
#
# 85
# Epoch duration =0.91s
# Cumulative duration =1min 17.650000000000006s
#
# 86
# Epoch duration =0.89s
# Cumulative duration =1min 18.540000000000006s
#
# 87
# Epoch duration =0.89s
# Cumulative duration =1min 19.430000000000007s
#
# 88
# Epoch duration =0.9s
# Cumulative duration =1min 20.33s
#
# 89
# Epoch duration =0.89s
# Cumulative duration =1min 21.22s
#
# 90
# Epoch duration =0.9s
# Cumulative duration =1min 22.120000000000005s
#
# 91
# Epoch duration =0.9s
# Cumulative duration =1min 23.019999999999996s
#
# 92
# Epoch duration =0.89s
# Cumulative duration =1min 23.909999999999997s
#
# 93
# Epoch duration =0.9s
# Cumulative duration =1min 24.810000000000002s
#
# 94
# Epoch duration =0.91s
# Cumulative duration =1min 25.72s
#
# 95
# Epoch duration =0.89s
# Cumulative duration =1min 26.61s
#
# 96
# Epoch duration =0.89s
# Cumulative duration =1min 27.5s
#
# 97
# Epoch duration =0.91s
# Cumulative duration =1min 28.42s
#
# 98
# Epoch duration =1.06s
# Cumulative duration =1min 29.480000000000004s
#
# 99
# Epoch duration =0.96s
# Cumulative duration =1min 30.439999999999998s
#
# 100
# Epoch duration =0.89s
# Cumulative duration =1min 31.33s
#
# 101
# Epoch duration =0.89s
# Cumulative duration =1min 32.22s
#
# 102
# Epoch duration =0.91s
# Cumulative duration =1min 33.129999999999995s
#
# 103
# Epoch duration =0.89s
# Cumulative duration =1min 34.010000000000005s
#
# 104
# Epoch duration =0.91s
# Cumulative duration =1min 34.92s
#
# 105
# Epoch duration =0.89s
# Cumulative duration =1min 35.81s
#
# 106
# Epoch duration =0.9s
# Cumulative duration =1min 36.709999999999994s
#
# 107
# Epoch duration =0.91s
# Cumulative duration =1min 37.620000000000005s
#
# 108
# Epoch duration =0.91s
# Cumulative duration =1min 38.53s
#
# 109
# Epoch duration =0.94s
# Cumulative duration =1min 39.47s
#
# 110
# Epoch duration =0.92s
# Cumulative duration =1min 40.39s
#
# 111
# Epoch duration =0.91s
# Cumulative duration =1min 41.3s
#
# 112
# Epoch duration =0.95s
# Cumulative duration =1min 42.25s
#
# 113
# Epoch duration =0.94s
# Cumulative duration =1min 43.19s
#
# 114
# Epoch duration =0.91s
# Cumulative duration =1min 44.099999999999994s
#
# 115
# Epoch duration =0.91s
# Cumulative duration =1min 45.0s
#
# 116
# Epoch duration =0.92s
# Cumulative duration =1min 45.92s
#
# 117
# Epoch duration =0.89s
# Cumulative duration =1min 46.81s
#
# 118
# Epoch duration =0.9s
# Cumulative duration =1min 47.709999999999994s
#
# 119
# Epoch duration =0.88s
# Cumulative duration =1min 48.59s
#
# 120
# Epoch duration =0.9s
# Cumulative duration =1min 49.489999999999995s
#
# 121
# Epoch duration =0.89s
# Cumulative duration =1min 50.39s
#
# 122
# Epoch duration =0.89s
# Cumulative duration =1min 51.28s
#
# 123
# Epoch duration =0.89s
# Cumulative duration =1min 52.17s
#
# 124
# Epoch duration =0.89s
# Cumulative duration =1min 53.06s
#
# 125
# Epoch duration =0.9s
# Cumulative duration =1min 53.959999999999994s
#
# 126
# Epoch duration =0.89s
# Cumulative duration =1min 54.84s
#
# 127
# Epoch duration =0.9s
# Cumulative duration =1min 55.739999999999995s
#
# 128
# Epoch duration =0.9s
# Cumulative duration =1min 56.64s
#
# 129
# Epoch duration =0.92s
# Cumulative duration =1min 57.56s
#
# 130
# Epoch duration =0.9s
# Cumulative duration =1min 58.47s
#
# 131
# Epoch duration =0.91s
# Cumulative duration =1min 59.370000000000005s
#
# 132
# Epoch duration =0.91s
# Cumulative duration =2min 0.28000000000000114s
#
# 133
# Epoch duration =0.92s
# Cumulative duration =2min 1.2000000000000028s
#
# 134
# Epoch duration =0.91s
# Cumulative duration =2min 2.1099999999999994s
#
# 135
# Epoch duration =0.9s
# Cumulative duration =2min 3.010000000000005s
#
# 136
# Epoch duration =0.9s
# Cumulative duration =2min 3.9200000000000017s
#
# 137
# Epoch duration =0.94s
# Cumulative duration =2min 4.849999999999994s
#
# 138
# Epoch duration =0.89s
# Cumulative duration =2min 5.75s
#
# 139
# Epoch duration =0.89s
# Cumulative duration =2min 6.640000000000001s
#
# 140
# Epoch duration =0.9s
# Cumulative duration =2min 7.540000000000006s
#
# 141
# Epoch duration =0.89s
# Cumulative duration =2min 8.430000000000007s
#
# 142
# Epoch duration =0.9s
# Cumulative duration =2min 9.330000000000013s
#
# 143
# Epoch duration =0.89s
# Cumulative duration =2min 10.22999999999999s
#
# 144
# Epoch duration =0.91s
# Cumulative duration =2min 11.129999999999995s
#
# 145
# Epoch duration =0.9s
# Cumulative duration =2min 12.030000000000001s
#
# 146
# Epoch duration =0.89s
# Cumulative duration =2min 12.930000000000007s
#
# 147
# Epoch duration =0.92s
# Cumulative duration =2min 13.849999999999994s
#
# 148
# Epoch duration =0.91s
# Cumulative duration =2min 14.759999999999991s
#
# 149
# Epoch duration =0.9s
# Cumulative duration =2min 15.659999999999997s
#
# 150
# Epoch duration =0.91s
# Cumulative duration =2min 16.569999999999993s
#
# 151
# Epoch duration =0.92s
# Cumulative duration =2min 17.49000000000001s
#
# 152
# Epoch duration =0.96s
# Cumulative duration =2min 18.44999999999999s
#
# 153
# Epoch duration =0.98s
# Cumulative duration =2min 19.430000000000007s
#
# 154
# Epoch duration =0.94s
# Cumulative duration =2min 20.370000000000005s
#
# 155
# Epoch duration =0.9s
# Cumulative duration =2min 21.27000000000001s
#
# 156
# Epoch duration =0.91s
# Cumulative duration =2min 22.180000000000007s
#
# 157
# Epoch duration =0.95s
# Cumulative duration =2min 23.129999999999995s
#
# 158
# Epoch duration =0.91s
# Cumulative duration =2min 24.039999999999992s
#
# 159
# Epoch duration =0.89s
# Cumulative duration =2min 24.930000000000007s
#
# 160
# Epoch duration =0.89s
# Cumulative duration =2min 25.830000000000013s
#
# 161
# Epoch duration =0.9s
# Cumulative duration =2min 26.72999999999999s
#
# 162
# Epoch duration =0.9s
# Cumulative duration =2min 27.629999999999995s
#
# 163
# Epoch duration =0.89s
# Cumulative duration =2min 28.53s
#
# 164
# Epoch duration =0.9s
# Cumulative duration =2min 29.419999999999987s
#
# 165
# Epoch duration =0.92s
# Cumulative duration =2min 30.340000000000003s
#
# 166
# Epoch duration =0.94s
# Cumulative duration =2min 31.289999999999992s
#
# 167
# Epoch duration =0.9s
# Cumulative duration =2min 32.19s
#
# 168
# Epoch duration =0.9s
# Cumulative duration =2min 33.08000000000001s
#
# 169
# Epoch duration =0.9s
# Cumulative duration =2min 33.97999999999999s
#
# 170
# Epoch duration =0.91s
# Cumulative duration =2min 34.900000000000006s
#
# 171
# Epoch duration =0.89s
# Cumulative duration =2min 35.78999999999999s
#
# 172
# Epoch duration =0.9s
# Cumulative duration =2min 36.69s
#
# 173
# Epoch duration =0.9s
# Cumulative duration =2min 37.59s
#
# 174
# Epoch duration =0.9s
# Cumulative duration =2min 38.49000000000001s
#
# 175
# Epoch duration =0.89s
# Cumulative duration =2min 39.379999999999995s
#
# 176
# Epoch duration =0.9s
# Cumulative duration =2min 40.28s
#
# 177
# Epoch duration =0.93s
# Cumulative duration =2min 41.22s
#
# 178
# Epoch duration =0.89s
# Cumulative duration =2min 42.110000000000014s
#
# 179
# Epoch duration =0.89s
# Cumulative duration =2min 43.0s
#
# 180
# Epoch duration =0.91s
# Cumulative duration =2min 43.91s
#
# 181
# Epoch duration =0.89s
# Cumulative duration =2min 44.80000000000001s
#
# 182
# Epoch duration =0.91s
# Cumulative duration =2min 45.71000000000001s
#
# 183
# Epoch duration =0.89s
# Cumulative duration =2min 46.599999999999994s
#
# 184
# Epoch duration =0.9s
# Cumulative duration =2min 47.50999999999999s
#
# 185
# Epoch duration =0.89s
# Cumulative duration =2min 48.400000000000006s
#
# 186
# Epoch duration =0.89s
# Cumulative duration =2min 49.28999999999999s
#
# 187
# Epoch duration =0.91s
# Cumulative duration =2min 50.19999999999999s
#
# 188
# Epoch duration =0.91s
# Cumulative duration =2min 51.110000000000014s
#
# 189
# Epoch duration =0.89s
# Cumulative duration =2min 52.0s
#
# 190
# Epoch duration =0.93s
# Cumulative duration =2min 52.93000000000001s
#
# 191
# Epoch duration =0.9s
# Cumulative duration =2min 53.81999999999999s
#
# 192
# Epoch duration =0.9s
# Cumulative duration =2min 54.72s
#
# 193
# Epoch duration =0.89s
# Cumulative duration =2min 55.620000000000005s
#
# 194
# Epoch duration =0.89s
# Cumulative duration =2min 56.50999999999999s
#
# 195
# Epoch duration =0.91s
# Cumulative duration =2min 57.41999999999999s
#
# 196
# Epoch duration =0.92s
# Cumulative duration =2min 58.34s
#
# 197
# Epoch duration =0.9s
# Cumulative duration =2min 59.24000000000001s
#
# 198
# Epoch duration =0.9s
# Cumulative duration =3min 0.15000000000000568s
#
# 199
# Epoch duration =0.89s
# Cumulative duration =3min 1.0300000000000011s
#
# 200
# Epoch duration =0.9s
# Cumulative duration =3min 1.9399999999999977s
#
# 201
# Epoch duration =0.9s
# Cumulative duration =3min 2.8400000000000034s
#
# 202
# Epoch duration =0.95s
# Cumulative duration =3min 3.789999999999992s
#
# 203
# Epoch duration =0.93s
# Cumulative duration =3min 4.719999999999999s
#
# 204
# Epoch duration =0.9s
# Cumulative duration =3min 5.6200000000000045s
#
# 205
# Epoch duration =0.91s
# Cumulative duration =3min 6.530000000000001s
#
# 206
# Epoch duration =0.95s
# Cumulative duration =3min 7.47999999999999s
#
# 207
# Epoch duration =0.91s
# Cumulative duration =3min 8.389999999999986s
#
# 208
# Epoch duration =0.89s
# Cumulative duration =3min 9.280000000000001s
#
# 209
# Epoch duration =0.89s
# Cumulative duration =3min 10.180000000000007s
#
# 210
# Epoch duration =0.9s
# Cumulative duration =3min 11.069999999999993s
#
# 211
# Epoch duration =0.9s
# Cumulative duration =3min 11.969999999999999s
#
# 212
# Epoch duration =0.91s
# Cumulative duration =3min 12.879999999999995s
#
# 213
# Epoch duration =0.89s
# Cumulative duration =3min 13.77000000000001s
#
# 214
# Epoch duration =0.91s
# Cumulative duration =3min 14.680000000000007s
#
# 215
# Epoch duration =0.93s
# Cumulative duration =3min 15.599999999999994s
#
# 216
# Epoch duration =0.94s
# Cumulative duration =3min 16.539999999999992s
#
# 217
# Epoch duration =0.93s
# Cumulative duration =3min 17.47999999999999s
#
# 218
# Epoch duration =0.89s
# Cumulative duration =3min 18.370000000000005s
#
# 219
# Epoch duration =0.91s
# Cumulative duration =3min 19.28s
#
# 220
# Epoch duration =0.89s
# Cumulative duration =3min 20.169999999999987s
#
# 221
# Epoch duration =0.9s
# Cumulative duration =3min 21.069999999999993s
#
# 222
# Epoch duration =0.92s
# Cumulative duration =3min 21.99000000000001s
#
# 223
# Epoch duration =0.89s
# Cumulative duration =3min 22.889999999999986s
#
# 224
# Epoch duration =0.9s
# Cumulative duration =3min 23.78s
#
# 225
# Epoch duration =0.91s
# Cumulative duration =3min 24.689999999999998s
#
# 226
# Epoch duration =0.91s
# Cumulative duration =3min 25.599999999999994s
#
# 227
# Epoch duration =0.9s
# Cumulative duration =3min 26.5s
#
# 228
# Epoch duration =0.91s
# Cumulative duration =3min 27.409999999999997s
#
# 229
# Epoch duration =0.91s
# Cumulative duration =3min 28.319999999999993s
#
# 230
# Epoch duration =0.92s
# Cumulative duration =3min 29.22999999999999s
#
# 231
# Epoch duration =0.89s
# Cumulative duration =3min 30.120000000000005s
#
# 232
# Epoch duration =0.9s
# Cumulative duration =3min 31.02000000000001s
#
# 233
# Epoch duration =0.92s
# Cumulative duration =3min 31.939999999999998s
#
# 234
# Epoch duration =0.9s
# Cumulative duration =3min 32.84s
#
# 235
# Epoch duration =0.89s
# Cumulative duration =3min 33.72999999999999s
#
# 236
# Epoch duration =0.9s
# Cumulative duration =3min 34.629999999999995s
#
# 237
# Epoch duration =0.91s
# Cumulative duration =3min 35.53s
#
# 238
# Epoch duration =0.9s
# Cumulative duration =3min 36.43000000000001s
#
# 239
# Epoch duration =0.96s
# Cumulative duration =3min 37.389999999999986s
#
# 240
# Epoch duration =0.9s
# Cumulative duration =3min 38.28999999999999s
#
# 241
# Epoch duration =0.9s
# Cumulative duration =3min 39.19s
#
# 242
# Epoch duration =0.9s
# Cumulative duration =3min 40.099999999999994s
#
# 243
# Epoch duration =0.91s
# Cumulative duration =3min 41.0s
#
# 244
# Epoch duration =0.89s
# Cumulative duration =3min 41.889999999999986s
#
# 245
# Epoch duration =0.89s
# Cumulative duration =3min 42.78s
#
# 246
# Epoch duration =0.89s
# Cumulative duration =3min 43.66999999999999s
#
# 247
# Epoch duration =0.96s
# Cumulative duration =3min 44.629999999999995s
#
# 248
# Epoch duration =0.9s
# Cumulative duration =3min 45.53s
#
# 249
# Epoch duration =0.89s
# Cumulative duration =3min 46.41999999999999s
#
# 250
# Epoch duration =0.9s
# Cumulative duration =3min 47.31999999999999s
#
# 251
# Epoch duration =0.9s
# Cumulative duration =3min 48.22s
#
# 252
# Epoch duration =0.89s
# Cumulative duration =3min 49.110000000000014s
#
# 253
# Epoch duration =0.92s
# Cumulative duration =3min 50.03s
#
# 254
# Epoch duration =0.92s
# Cumulative duration =3min 50.94999999999999s
#
# 255
# Epoch duration =0.9s
# Cumulative duration =3min 51.849999999999994s
#
# 256
# Epoch duration =0.92s
# Cumulative duration =3min 52.77000000000001s
#
# 257
# Epoch duration =0.91s
# Cumulative duration =3min 53.68000000000001s
#
# 258
# Epoch duration =0.89s
# Cumulative duration =3min 54.56999999999999s
#
# 259
# Epoch duration =0.89s
# Cumulative duration =3min 55.47s
#
# 260
# Epoch duration =0.92s
# Cumulative duration =3min 56.379999999999995s
#
# 261
# Epoch duration =0.91s
# Cumulative duration =3min 57.30000000000001s
#
# 262
# Epoch duration =0.9s
# Cumulative duration =3min 58.19999999999999s
#
# 263
# Epoch duration =0.9s
# Cumulative duration =3min 59.099999999999994s
#
# 264
# Epoch duration =0.9s
# Cumulative duration =4min 0.0s
#
# 265
# Epoch duration =0.9s
# Cumulative duration =4min 0.9000000000000057s
#
# 266
# Epoch duration =0.9s
# Cumulative duration =4min 1.8000000000000114s
#
# 267
# Epoch duration =0.92s
# Cumulative duration =4min 2.719999999999999s
#
# 268
# Epoch duration =0.9s
# Cumulative duration =4min 3.6200000000000045s
#
# 269
# Epoch duration =0.96s
# Cumulative duration =4min 4.569999999999993s
#
# 270
# Epoch duration =0.91s
# Cumulative duration =4min 5.490000000000009s
#
# 271
# Epoch duration =0.89s
# Cumulative duration =4min 6.3799999999999955s
#
# 272
# Epoch duration =0.91s
# Cumulative duration =4min 7.289999999999992s
#
# 273
# Epoch duration =0.89s
# Cumulative duration =4min 8.180000000000007s
#
# 274
# Epoch duration =0.88s
# Cumulative duration =4min 9.069999999999993s
#
# 275
# Epoch duration =0.89s
# Cumulative duration =4min 9.960000000000008s
#
# 276
# Epoch duration =0.9s
# Cumulative duration =4min 10.849999999999994s
#
# 277
# Epoch duration =0.9s
# Cumulative duration =4min 11.759999999999991s
#
# 278
# Epoch duration =0.9s
# Cumulative duration =4min 12.659999999999997s
#
# 279
# Epoch duration =0.9s
# Cumulative duration =4min 13.560000000000002s
#
# 280
# Epoch duration =0.91s
# Cumulative duration =4min 14.460000000000008s
#
# 281
# Epoch duration =0.91s
# Cumulative duration =4min 15.370000000000005s
#
# 282
# Epoch duration =0.9s
# Cumulative duration =4min 16.269999999999982s
#
# 283
# Epoch duration =0.9s
# Cumulative duration =4min 17.170000000000016s
#
# 284
# Epoch duration =0.89s
# Cumulative duration =4min 18.060000000000002s
#
# 285
# Epoch duration =0.9s
# Cumulative duration =4min 18.95999999999998s
#
# 286
# Epoch duration =0.9s
# Cumulative duration =4min 19.870000000000005s
#
# 287
# Epoch duration =0.92s
# Cumulative duration =4min 20.79000000000002s
#
# 288
# Epoch duration =0.9s
# Cumulative duration =4min 21.680000000000007s
#
# 289
# Epoch duration =0.9s
# Cumulative duration =4min 22.579999999999984s
#
# 290
# Epoch duration =0.89s
# Cumulative duration =4min 23.470000000000027s
#
# 291
# Epoch duration =0.9s
# Cumulative duration =4min 24.370000000000005s
#
# 292
# Epoch duration =0.89s
# Cumulative duration =4min 25.25s
#
# 293
# Epoch duration =0.9s
# Cumulative duration =4min 26.149999999999977s
#
# 294
# Epoch duration =0.89s
# Cumulative duration =4min 27.04000000000002s
#
# 295
# Epoch duration =0.91s
# Cumulative duration =4min 27.94999999999999s
#
# 296
# Epoch duration =0.9s
# Cumulative duration =4min 28.850000000000023s
#
# 297
# Epoch duration =0.89s
# Cumulative duration =4min 29.75s
#
# 298
# Epoch duration =0.94s
# Cumulative duration =4min 30.689999999999998s
#
# 299
# Epoch duration =0.91s
# Cumulative duration =4min 31.600000000000023s
#
# 300
# Epoch duration =0.91s
# Cumulative duration =4min 32.50999999999999s
#
# 301
# Epoch duration =0.9s
# Cumulative duration =4min 33.410000000000025s
#
# 302
# Epoch duration =0.91s
# Cumulative duration =4min 34.31999999999999s
#
# 303
# Epoch duration =0.91s
# Cumulative duration =4min 35.23000000000002s
#
# 304
# Epoch duration =0.89s
# Cumulative duration =4min 36.120000000000005s
#
# 305
# Epoch duration =0.9s
# Cumulative duration =4min 37.01999999999998s
#
# 306
# Epoch duration =0.91s
# Cumulative duration =4min 37.93000000000001s
#
# 307
# Epoch duration =0.9s
# Cumulative duration =4min 38.829999999999984s
#
# 308
# Epoch duration =0.91s
# Cumulative duration =4min 39.74000000000001s
#
# 309
# Epoch duration =0.93s
# Cumulative duration =4min 40.670000000000016s
#
# 310
# Epoch duration =0.89s
# Cumulative duration =4min 41.56s
#
# 311
# Epoch duration =0.89s
# Cumulative duration =4min 42.44999999999999s
#
# 312
# Epoch duration =0.93s
# Cumulative duration =4min 43.379999999999995s
#
# 313
# Epoch duration =0.9s
# Cumulative duration =4min 44.27999999999997s
#
# 314
# Epoch duration =0.93s
# Cumulative duration =4min 45.20999999999998s
#
# 315
# Epoch duration =0.98s
# Cumulative duration =4min 46.19s
#
# 316
# Epoch duration =0.91s
# Cumulative duration =4min 47.10000000000002s
#
# 317
# Epoch duration =0.9s
# Cumulative duration =4min 48.0s
#
# 318
# Epoch duration =0.89s
# Cumulative duration =4min 48.889999999999986s
#
# 319
# Epoch duration =0.9s
# Cumulative duration =4min 49.80000000000001s
#
# 320
# Epoch duration =0.96s
# Cumulative duration =4min 50.75999999999999s
#
# 321
# Epoch duration =0.9s
# Cumulative duration =4min 51.660000000000025s
#
# 322
# Epoch duration =0.89s
# Cumulative duration =4min 52.56s
#
# 323
# Epoch duration =0.89s
# Cumulative duration =4min 53.44999999999999s
#
# 324
# Epoch duration =0.89s
# Cumulative duration =4min 54.339999999999975s
#
# 325
# Epoch duration =0.91s
# Cumulative duration =4min 55.25s
#
# 326
# Epoch duration =0.89s
# Cumulative duration =4min 56.14999999999998s
#
# 327
# Epoch duration =0.92s
# Cumulative duration =4min 57.06999999999999s
#
# 328
# Epoch duration =0.92s
# Cumulative duration =4min 57.99000000000001s
#
# 329
# Epoch duration =0.89s
# Cumulative duration =4min 58.889999999999986s
#
# 330
# Epoch duration =0.9s
# Cumulative duration =4min 59.79000000000002s
#
# 331
# Epoch duration =0.9s
# Cumulative duration =5min 0.6899999999999977s
#
# 332
# Epoch duration =0.9s
# Cumulative duration =5min 1.589999999999975s
#
# 333
# Epoch duration =0.91s
# Cumulative duration =5min 2.5s
#
# 334
# Epoch duration =0.89s
# Cumulative duration =5min 3.3899999999999864s
#
# 335
# Epoch duration =0.89s
# Cumulative duration =5min 4.279999999999973s
#
# 336
# Epoch duration =0.89s
# Cumulative duration =5min 5.170000000000016s
#
# 337
# Epoch duration =0.89s
# Cumulative duration =5min 6.060000000000002s
#
# 338
# Epoch duration =0.89s
# Cumulative duration =5min 6.949999999999989s
#
# 339
# Epoch duration =0.9s
# Cumulative duration =5min 7.850000000000023s
#
# 340
# Epoch duration =0.89s
# Cumulative duration =5min 8.740000000000009s
#
# 341
# Epoch duration =0.89s
# Cumulative duration =5min 9.629999999999995s
#
# 342
# Epoch duration =0.93s
# Cumulative duration =5min 10.560000000000002s
#
# 343
# Epoch duration =0.88s
# Cumulative duration =5min 11.439999999999998s
#
# 344
# Epoch duration =0.9s
# Cumulative duration =5min 12.339999999999975s
#
# 345
# Epoch duration =0.89s
# Cumulative duration =5min 13.230000000000018s
#
# 346
# Epoch duration =0.9s
# Cumulative duration =5min 14.129999999999995s
#
# 347
# Epoch duration =0.91s
# Cumulative duration =5min 15.04000000000002s
#
# 348
# Epoch duration =0.9s
# Cumulative duration =5min 15.939999999999998s
#
# 349
# Epoch duration =0.89s
# Cumulative duration =5min 16.829999999999984s
#
# 350
# Epoch duration =0.9s
# Cumulative duration =5min 17.730000000000018s
#
# 351
# Epoch duration =0.89s
# Cumulative duration =5min 18.620000000000005s
#
# 352
# Epoch duration =0.9s
# Cumulative duration =5min 19.519999999999982s
#
# 353
# Epoch duration =0.9s
# Cumulative duration =5min 20.420000000000016s
#
# 354
# Epoch duration =0.89s
# Cumulative duration =5min 21.310000000000002s
#
# 355
# Epoch duration =0.93s
# Cumulative duration =5min 22.24000000000001s
#
# 356
# Epoch duration =0.9s
# Cumulative duration =5min 23.139999999999986s
#
# 357
# Epoch duration =0.89s
# Cumulative duration =5min 24.029999999999973s
#
# 358
# Epoch duration =0.88s
# Cumulative duration =5min 24.920000000000016s
#
# 359
# Epoch duration =0.89s
# Cumulative duration =5min 25.810000000000002s
#
# 360
# Epoch duration =0.94s
# Cumulative duration =5min 26.75s
#
# 361
# Epoch duration =0.89s
# Cumulative duration =5min 27.639999999999986s
#
# 362
# Epoch duration =0.94s
# Cumulative duration =5min 28.579999999999984s
#
# 363
# Epoch duration =0.91s
# Cumulative duration =5min 29.49000000000001s
#
# 364
# Epoch duration =0.89s
# Cumulative duration =5min 30.389999999999986s
#
# 365
# Epoch duration =0.92s
# Cumulative duration =5min 31.310000000000002s
#
# 366
# Epoch duration =0.9s
# Cumulative duration =5min 32.20999999999998s
#
# 367
# Epoch duration =0.9s
# Cumulative duration =5min 33.110000000000014s
#
# 368
# Epoch duration =0.89s
# Cumulative duration =5min 34.0s
#
# 369
# Epoch duration =0.9s
# Cumulative duration =5min 34.89999999999998s
#
# 370
# Epoch duration =0.87s
# Cumulative duration =5min 35.76999999999998s
#
# 371
# Epoch duration =0.9s
# Cumulative duration =5min 36.670000000000016s
#
# 372
# Epoch duration =0.89s
# Cumulative duration =5min 37.56s
#
# 373
# Epoch duration =0.89s
# Cumulative duration =5min 38.44999999999999s
#
# 374
# Epoch duration =0.89s
# Cumulative duration =5min 39.339999999999975s
#
# 375
# Epoch duration =0.99s
# Cumulative duration =5min 40.329999999999984s
#
# 376
# Epoch duration =0.93s
# Cumulative duration =5min 41.25999999999999s
#
# 377
# Epoch duration =0.9s
# Cumulative duration =5min 42.160000000000025s
#
# 378
# Epoch duration =0.91s
# Cumulative duration =5min 43.079999999999984s
#
# 379
# Epoch duration =0.9s
# Cumulative duration =5min 43.97000000000003s
#
# 380
# Epoch duration =0.88s
# Cumulative duration =5min 44.860000000000014s
#
# 381
# Epoch duration =0.9s
# Cumulative duration =5min 45.75999999999999s
#
# 382
# Epoch duration =0.88s
# Cumulative duration =5min 46.639999999999986s
#
# 383
# Epoch duration =0.89s
# Cumulative duration =5min 47.52999999999997s
#
# 384
# Epoch duration =0.92s
# Cumulative duration =5min 48.44s
#
# 385
# Epoch duration =0.88s
# Cumulative duration =5min 49.329999999999984s
#
# 386
# Epoch duration =0.89s
# Cumulative duration =5min 50.20999999999998s
#
# 387
# Epoch duration =0.91s
# Cumulative duration =5min 51.129999999999995s
#
# 388
# Epoch duration =0.9s
# Cumulative duration =5min 52.01999999999998s
#
# 389
# Epoch duration =0.91s
# Cumulative duration =5min 52.93000000000001s
#
# 390
# Epoch duration =0.89s
# Cumulative duration =5min 53.81999999999999s
#
# 391
# Epoch duration =0.9s
# Cumulative duration =5min 54.72000000000003s
#
# 392
# Epoch duration =0.89s
# Cumulative duration =5min 55.610000000000014s
#
# 393
# Epoch duration =0.91s
# Cumulative duration =5min 56.50999999999999s
#
# 394
# Epoch duration =0.89s
# Cumulative duration =5min 57.39999999999998s
#
# 395
# Epoch duration =0.89s
# Cumulative duration =5min 58.29000000000002s
#
# 396
# Epoch duration =0.89s
# Cumulative duration =5min 59.18000000000001s
#
# 397
# Epoch duration =0.91s
# Cumulative duration =6min 0.10000000000002274s
#
# 398
# Epoch duration =0.88s
# Cumulative duration =6min 0.9800000000000182s
#
# 399
# Epoch duration =0.88s
# Cumulative duration =6min 1.8600000000000136s
#
# 400
# Epoch duration =0.89s
# Cumulative duration =6min 2.75s
#
# 401
# Epoch duration =0.89s
# Cumulative duration =6min 3.6499999999999773s
#
# 402
# Epoch duration =0.95s
# Cumulative duration =6min 4.600000000000023s
#
# 403
# Epoch duration =0.94s
# Cumulative duration =6min 5.5400000000000205s
#
# 404
# Epoch duration =0.91s
# Cumulative duration =6min 6.449999999999989s
#
# 405
# Epoch duration =0.9s
# Cumulative duration =6min 7.350000000000023s
#
# 406
# Epoch duration =0.92s
# Cumulative duration =6min 8.269999999999982s
#
# 407
# Epoch duration =0.89s
# Cumulative duration =6min 9.160000000000025s
#
# 408
# Epoch duration =0.88s
# Cumulative duration =6min 10.04000000000002s
#
# 409
# Epoch duration =0.88s
# Cumulative duration =6min 10.930000000000007s
#
# 410
# Epoch duration =0.94s
# Cumulative duration =6min 11.860000000000014s
#
# 411
# Epoch duration =0.9s
# Cumulative duration =6min 12.759999999999991s
#
# 412
# Epoch duration =0.88s
# Cumulative duration =6min 13.639999999999986s
#
# 413
# Epoch duration =0.89s
# Cumulative duration =6min 14.529999999999973s
#
# 414
# Epoch duration =0.89s
# Cumulative duration =6min 15.430000000000007s
#
# 415
# Epoch duration =0.91s
# Cumulative duration =6min 16.339999999999975s
#
# 416
# Epoch duration =0.94s
# Cumulative duration =6min 17.269999999999982s
#
# 417
# Epoch duration =0.9s
# Cumulative duration =6min 18.180000000000007s
#
# 418
# Epoch duration =0.93s
# Cumulative duration =6min 19.100000000000023s
#
# 419
# Epoch duration =0.9s
# Cumulative duration =6min 20.0s
#
# 420
# Epoch duration =0.88s
# Cumulative duration =6min 20.889999999999986s
#
# 421
# Epoch duration =0.91s
# Cumulative duration =6min 21.79000000000002s
#
# 422
# Epoch duration =0.91s
# Cumulative duration =6min 22.69999999999999s
#
# 423
# Epoch duration =0.89s
# Cumulative duration =6min 23.589999999999975s
#
# 424
# Epoch duration =0.89s
# Cumulative duration =6min 24.480000000000018s
#
# 425
# Epoch duration =0.89s
# Cumulative duration =6min 25.379999999999995s
#
# 426
# Epoch duration =0.9s
# Cumulative duration =6min 26.269999999999982s
#
# 427
# Epoch duration =0.9s
# Cumulative duration =6min 27.180000000000007s
#
# 428
# Epoch duration =0.88s
# Cumulative duration =6min 28.060000000000002s
#
# 429
# Epoch duration =0.89s
# Cumulative duration =6min 28.94999999999999s
#
# 430
# Epoch duration =0.89s
# Cumulative duration =6min 29.850000000000023s
#
# 431
# Epoch duration =0.89s
# Cumulative duration =6min 30.730000000000018s
#
# 432
# Epoch duration =0.9s
# Cumulative duration =6min 31.639999999999986s
#
# 433
# Epoch duration =0.9s
# Cumulative duration =6min 32.52999999999997s
#
# 434
# Epoch duration =0.89s
# Cumulative duration =6min 33.420000000000016s
#
# 435
# Epoch duration =0.89s
# Cumulative duration =6min 34.31s
#
# 436
# Epoch duration =0.89s
# Cumulative duration =6min 35.19999999999999s
#
# 437
# Epoch duration =0.89s
# Cumulative duration =6min 36.079999999999984s
#
# 438
# Epoch duration =0.9s
# Cumulative duration =6min 36.98000000000002s
#
# 439
# Epoch duration =0.9s
# Cumulative duration =6min 37.879999999999995s
#
# 440
# Epoch duration =0.89s
# Cumulative duration =6min 38.76999999999998s
#
# 441
# Epoch duration =0.88s
# Cumulative duration =6min 39.64999999999998s
#
# 442
# Epoch duration =0.9s
# Cumulative duration =6min 40.55000000000001s
#
# 443
# Epoch duration =0.9s
# Cumulative duration =6min 41.44999999999999s
#
# 444
# Epoch duration =0.88s
# Cumulative duration =6min 42.329999999999984s
#
# 445
# Epoch duration =0.89s
# Cumulative duration =6min 43.22000000000003s
#
# 446
# Epoch duration =0.88s
# Cumulative duration =6min 44.10000000000002s
#
# 447
# Epoch duration =0.88s
# Cumulative duration =6min 44.98000000000002s
#
# 448
# Epoch duration =0.89s
# Cumulative duration =6min 45.879999999999995s
#
# 449
# Epoch duration =0.89s
# Cumulative duration =6min 46.75999999999999s
#
# 450
# Epoch duration =0.89s
# Cumulative duration =6min 47.660000000000025s
#
# 451
# Epoch duration =0.89s
# Cumulative duration =6min 48.54000000000002s
#
# 452
# Epoch duration =0.88s
# Cumulative duration =6min 49.43000000000001s
#
# 453
# Epoch duration =0.88s
# Cumulative duration =6min 50.31s
#
# 454
# Epoch duration =0.89s
# Cumulative duration =6min 51.20999999999998s
#
# 455
# Epoch duration =0.89s
# Cumulative duration =6min 52.10000000000002s
#
# 456
# Epoch duration =0.88s
# Cumulative duration =6min 52.98000000000002s
#
# 457
# Epoch duration =0.89s
# Cumulative duration =6min 53.879999999999995s
#
# 458
# Epoch duration =0.88s
# Cumulative duration =6min 54.75999999999999s
#
# 459
# Epoch duration =0.9s
# Cumulative duration =6min 55.670000000000016s
#
# 460
# Epoch duration =0.94s
# Cumulative duration =6min 56.610000000000014s
#
# 461
# Epoch duration =0.93s
# Cumulative duration =6min 57.54000000000002s
#
# 462
# Epoch duration =0.92s
# Cumulative duration =6min 58.45999999999998s
#
# 463
# Epoch duration =0.92s
# Cumulative duration =6min 59.379999999999995s
#
# 464
# Epoch duration =0.92s
# Cumulative duration =7min 0.30000000000001137s
#
# 465
# Epoch duration =0.88s
# Cumulative duration =7min 1.1800000000000068s
#
# 466
# Epoch duration =0.91s
# Cumulative duration =7min 2.1000000000000227s
#
# 467
# Epoch duration =0.89s
# Cumulative duration =7min 2.990000000000009s
#
# 468
# Epoch duration =0.89s
# Cumulative duration =7min 3.8799999999999955s
#
# 469
# Epoch duration =0.89s
# Cumulative duration =7min 4.769999999999982s
#
# 470
# Epoch duration =0.94s
# Cumulative duration =7min 5.7099999999999795s
#
# 471
# Epoch duration =0.91s
# Cumulative duration =7min 6.6200000000000045s
#
# 472
# Epoch duration =0.91s
# Cumulative duration =7min 7.529999999999973s
#
# 473
# Epoch duration =0.89s
# Cumulative duration =7min 8.420000000000016s
#
# 474
# Epoch duration =0.9s
# Cumulative duration =7min 9.319999999999993s
#
# 475
# Epoch duration =0.92s
# Cumulative duration =7min 10.240000000000009s
#
# 476
# Epoch duration =0.89s
# Cumulative duration =7min 11.129999999999995s
#
# 477
# Epoch duration =0.9s
# Cumulative duration =7min 12.04000000000002s
#
# 478
# Epoch duration =0.89s
# Cumulative duration =7min 12.930000000000007s
#
# 479
# Epoch duration =0.94s
# Cumulative duration =7min 13.870000000000005s
#
# 480
# Epoch duration =0.89s
# Cumulative duration =7min 14.759999999999991s
#
# 481
# Epoch duration =0.92s
# Cumulative duration =7min 15.680000000000007s
#
# 482
# Epoch duration =0.89s
# Cumulative duration =7min 16.569999999999993s
#
# 483
# Epoch duration =0.91s
# Cumulative duration =7min 17.480000000000018s
#
# 484
# Epoch duration =0.91s
# Cumulative duration =7min 18.389999999999986s
#
# 485
# Epoch duration =0.91s
# Cumulative duration =7min 19.30000000000001s
#
# 486
# Epoch duration =0.88s
# Cumulative duration =7min 20.189999999999998s
#
# 487
# Epoch duration =0.89s
# Cumulative duration =7min 21.069999999999993s
#
# 488
# Epoch duration =0.89s
# Cumulative duration =7min 21.95999999999998s
#
# 489
# Epoch duration =0.91s
# Cumulative duration =7min 22.879999999999995s
#
# 490
# Epoch duration =0.89s
# Cumulative duration =7min 23.769999999999982s
#
# 491
# Epoch duration =0.89s
# Cumulative duration =7min 24.660000000000025s
#
# 492
# Epoch duration =0.89s
# Cumulative duration =7min 25.55000000000001s
#
# 493
# Epoch duration =0.88s
# Cumulative duration =7min 26.430000000000007s
#
# 494
# Epoch duration =0.94s
# Cumulative duration =7min 27.379999999999995s
#
# 495
# Epoch duration =0.93s
# Cumulative duration =7min 28.30000000000001s
#
# 496
# Epoch duration =0.93s
# Cumulative duration =7min 29.24000000000001s
#
# 497
# Epoch duration =0.91s
# Cumulative duration =7min 30.149999999999977s
#
# 498
# Epoch duration =0.91s
# Cumulative duration =7min 31.060000000000002s
#
# 499
# Epoch duration =0.9s
# Cumulative duration =7min 31.94999999999999s
#
# Saving scores to Arrays/trna_mlpt3_44_ug_so500.npy

# %%
#load values
savepath = 'Arrays/trna_mlpt3_44_ug_so500.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 500
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
