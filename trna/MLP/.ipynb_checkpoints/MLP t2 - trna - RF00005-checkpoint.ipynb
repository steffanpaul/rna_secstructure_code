# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/trna_100k_d3.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 1.88s

# %%
simalign_file = '../../../data_RFAM/trnasim_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((((<<<<>>>><<<<<>>>>><<<<<>>>>>)))))))'

# %%
ugSS
# Out:
# '(((((((,,<<<<_______>>>>,<<<<<_______>>>>>,,,,<<<<<_______>>>>>))))))):'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/trna'
param_path = os.path.join(save_path, 'mlp_t2_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 513, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.33112 -- acc=85.632503%
#
#   valid loss:		0.05821
#   valid accuracy:	0.99590+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.11974 -- acc=95.953345%
#
#   valid loss:		0.03080
#   valid accuracy:	0.99555+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.88s -- loss=0.09310 -- acc=96.908341%
#
#   valid loss:		0.02169
#   valid accuracy:	0.99670+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.08313 -- acc=97.287509%
#
#   valid loss:		0.02017
#   valid accuracy:	0.99670+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.07554 -- acc=97.520832%
#
#   valid loss:		0.01636
#   valid accuracy:	0.99710+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.07060 -- acc=97.760836%
#
#   valid loss:		0.01564
#   valid accuracy:	0.99720+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.06996 -- acc=97.709171%
#
#   valid loss:		0.01888
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.06858 -- acc=97.782508%
#
#   valid loss:		0.01455
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.81s -- loss=0.06555 -- acc=97.904170%
#
#   valid loss:		0.01423
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.06620 -- acc=97.960836%
#
#   valid loss:		0.01342
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.81s -- loss=0.06254 -- acc=98.015832%
#
#   valid loss:		0.01381
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.06257 -- acc=98.055006%
#
#   valid loss:		0.01308
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/trna/mlp_t2_44_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.76s -- loss=0.06393 -- acc=98.046675%
#
#   valid loss:		0.01416
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.06371 -- acc=98.067507%
#
#   valid loss:		0.01406
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.06151 -- acc=98.091679%
#
#   valid loss:		0.01429
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.06188 -- acc=98.108331%
#
#   valid loss:		0.01388
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.77s -- loss=0.05950 -- acc=98.162506%
#
#   valid loss:		0.01443
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.06084 -- acc=98.180008%
#
#   valid loss:		0.01430
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.75s -- loss=0.06023 -- acc=98.156676%
#
#   valid loss:		0.01401
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.77s -- loss=0.06118 -- acc=98.156676%
#
#   valid loss:		0.01417
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.06195 -- acc=98.133333%
#
#   valid loss:		0.01427
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.05927 -- acc=98.276678%
#
#   valid loss:		0.01544
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.05936 -- acc=98.212501%
#
#   valid loss:		0.01465
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.06055 -- acc=98.214171%
#
#   valid loss:		0.01448
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.78s -- loss=0.05834 -- acc=98.254175%
#
#   valid loss:		0.01434
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.77s -- loss=0.05751 -- acc=98.278338%
#
#   valid loss:		0.01473
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.05882 -- acc=98.245005%
#
#   valid loss:		0.01503
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.06040 -- acc=98.223332%
#
#   valid loss:		0.01477
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.05974 -- acc=98.255836%
#
#   valid loss:		0.01617
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.81s -- loss=0.05789 -- acc=98.298330%
#
#   valid loss:		0.01489
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.05689 -- acc=98.374177%
#
#   valid loss:		0.01569
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.75s -- loss=0.05847 -- acc=98.335834%
#
#   valid loss:		0.01658
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.05755 -- acc=98.285009%
#
#   valid loss:		0.01548
#   valid accuracy:	0.99760+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.97s -- loss=0.05851 -- acc=98.265837%
#
#   valid loss:		0.01509
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.81s -- loss=0.06077 -- acc=98.275008%
#
#   valid loss:		0.01486
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.05898 -- acc=98.300000%
#
#   valid loss:		0.01567
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.05890 -- acc=98.322502%
#
#   valid loss:		0.01568
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.05639 -- acc=98.365007%
#
#   valid loss:		0.01500
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.77s -- loss=0.05747 -- acc=98.391679%
#
#   valid loss:		0.01481
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.05659 -- acc=98.334173%
#
#   valid loss:		0.01521
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=4.12s -- loss=0.05838 -- acc=98.296670%
#
#   valid loss:		0.01543
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.82s -- loss=0.05800 -- acc=98.375838%
#
#   valid loss:		0.01569
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.05882 -- acc=98.335004%
#
#   valid loss:		0.01551
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.05744 -- acc=98.375838%
#
#   valid loss:		0.01604
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.82s -- loss=0.05753 -- acc=98.305831%
#
#   valid loss:		0.01542
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.86s -- loss=0.05614 -- acc=98.429173%
#
#   valid loss:		0.01558
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.79s -- loss=0.05673 -- acc=98.345005%
#
#   valid loss:		0.01612
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.05851 -- acc=98.349175%
#
#   valid loss:		0.01588
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=3.76s -- loss=0.05759 -- acc=98.405001%
#
#   valid loss:		0.01607
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=3.76s -- loss=0.05645 -- acc=98.409171%
#
#   valid loss:		0.01555
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=3.76s -- loss=0.05849 -- acc=98.345835%
#
#   valid loss:		0.01523
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=3.91s -- loss=0.05655 -- acc=98.475838%
#
#   valid loss:		0.01644
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
#sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/trna/mlp_t2_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/trna/mlp_t2_44_best.ckpt
#   test  loss:		0.01168
#   test  accuracy:	0.99853+/-0.00000
#   test  auc-roc:	0.99998+/-0.00000
#   test  auc-pr:		0.99998+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/trna_mlpt2_44 _ug_so1000.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =0.93s
# Cumulative duration =0.93s
#
# 1
# Epoch duration =0.91s
# Cumulative duration =1.84s
#
# 2
# Epoch duration =0.93s
# Cumulative duration =2.77s
#
# 3
# Epoch duration =0.94s
# Cumulative duration =3.71s
#
# 4
# Epoch duration =0.91s
# Cumulative duration =4.61s
#
# 5
# Epoch duration =0.91s
# Cumulative duration =5.52s
#
# 6
# Epoch duration =0.91s
# Cumulative duration =6.43s
#
# 7
# Epoch duration =0.91s
# Cumulative duration =7.34s
#
# 8
# Epoch duration =0.91s
# Cumulative duration =8.25s
#
# 9
# Epoch duration =0.92s
# Cumulative duration =9.16s
#
# 10
# Epoch duration =0.91s
# Cumulative duration =10.07s
#
# 11
# Epoch duration =0.92s
# Cumulative duration =10.99s
#
# 12
# Epoch duration =0.91s
# Cumulative duration =11.9s
#
# 13
# Epoch duration =0.92s
# Cumulative duration =12.82s
#
# 14
# Epoch duration =0.92s
# Cumulative duration =13.74s
#
# 15
# Epoch duration =0.93s
# Cumulative duration =14.67s
#
# 16
# Epoch duration =0.91s
# Cumulative duration =15.58s
#
# 17
# Epoch duration =0.92s
# Cumulative duration =16.49s
#
# 18
# Epoch duration =0.91s
# Cumulative duration =17.4s
#
# 19
# Epoch duration =0.92s
# Cumulative duration =18.33s
#
# 20
# Epoch duration =0.91s
# Cumulative duration =19.24s
#
# 21
# Epoch duration =0.92s
# Cumulative duration =20.16s
#
# 22
# Epoch duration =0.92s
# Cumulative duration =21.08s
#
# 23
# Epoch duration =0.93s
# Cumulative duration =22.0s
#
# 24
# Epoch duration =0.91s
# Cumulative duration =22.91s
#
# 25
# Epoch duration =0.92s
# Cumulative duration =23.83s
#
# 26
# Epoch duration =0.91s
# Cumulative duration =24.74s
#
# 27
# Epoch duration =0.93s
# Cumulative duration =25.68s
#
# 28
# Epoch duration =0.91s
# Cumulative duration =26.58s
#
# 29
# Epoch duration =0.92s
# Cumulative duration =27.51s
#
# 30
# Epoch duration =0.91s
# Cumulative duration =28.42s
#
# 31
# Epoch duration =0.91s
# Cumulative duration =29.34s
#
# 32
# Epoch duration =0.9s
# Cumulative duration =30.24s
#
# 33
# Epoch duration =0.91s
# Cumulative duration =31.15s
#
# 34
# Epoch duration =0.91s
# Cumulative duration =32.05s
#
# 35
# Epoch duration =0.91s
# Cumulative duration =32.97s
#
# 36
# Epoch duration =0.91s
# Cumulative duration =33.88s
#
# 37
# Epoch duration =0.91s
# Cumulative duration =34.79s
#
# 38
# Epoch duration =0.93s
# Cumulative duration =35.73s
#
# 39
# Epoch duration =0.92s
# Cumulative duration =36.65s
#
# 40
# Epoch duration =0.91s
# Cumulative duration =37.56s
#
# 41
# Epoch duration =0.92s
# Cumulative duration =38.48s
#
# 42
# Epoch duration =0.91s
# Cumulative duration =39.39s
#
# 43
# Epoch duration =0.92s
# Cumulative duration =40.31s
#
# 44
# Epoch duration =0.9s
# Cumulative duration =41.21s
#
# 45
# Epoch duration =0.92s
# Cumulative duration =42.13s
#
# 46
# Epoch duration =0.93s
# Cumulative duration =43.06s
#
# 47
# Epoch duration =0.92s
# Cumulative duration =43.98s
#
# 48
# Epoch duration =0.92s
# Cumulative duration =44.9s
#
# 49
# Epoch duration =0.92s
# Cumulative duration =45.82s
#
# 50
# Epoch duration =0.91s
# Cumulative duration =46.73s
#
# 51
# Epoch duration =0.91s
# Cumulative duration =47.64s
#
# 52
# Epoch duration =0.93s
# Cumulative duration =48.57s
#
# 53
# Epoch duration =0.91s
# Cumulative duration =49.48s
#
# 54
# Epoch duration =0.91s
# Cumulative duration =50.39s
#
# 55
# Epoch duration =0.92s
# Cumulative duration =51.31s
#
# 56
# Epoch duration =0.91s
# Cumulative duration =52.22s
#
# 57
# Epoch duration =0.91s
# Cumulative duration =53.13s
#
# 58
# Epoch duration =0.91s
# Cumulative duration =54.04s
#
# 59
# Epoch duration =0.91s
# Cumulative duration =54.95s
#
# 60
# Epoch duration =0.91s
# Cumulative duration =55.86s
#
# 61
# Epoch duration =0.91s
# Cumulative duration =56.77s
#
# 62
# Epoch duration =0.93s
# Cumulative duration =57.7s
#
# 63
# Epoch duration =0.92s
# Cumulative duration =58.62s
#
# 64
# Epoch duration =0.92s
# Cumulative duration =59.54s
#
# 65
# Epoch duration =0.91s
# Cumulative duration =1min 0.45000000000000284s
#
# 66
# Epoch duration =0.91s
# Cumulative duration =1min 1.3599999999999994s
#
# 67
# Epoch duration =0.91s
# Cumulative duration =1min 2.270000000000003s
#
# 68
# Epoch duration =0.9s
# Cumulative duration =1min 3.1700000000000017s
#
# 69
# Epoch duration =0.91s
# Cumulative duration =1min 4.090000000000003s
#
# 70
# Epoch duration =0.91s
# Cumulative duration =1min 5.0s
#
# 71
# Epoch duration =0.92s
# Cumulative duration =1min 5.920000000000002s
#
# 72
# Epoch duration =0.91s
# Cumulative duration =1min 6.829999999999998s
#
# 73
# Epoch duration =0.92s
# Cumulative duration =1min 7.75s
#
# 74
# Epoch duration =0.91s
# Cumulative duration =1min 8.659999999999997s
#
# 75
# Epoch duration =0.92s
# Cumulative duration =1min 9.590000000000003s
#
# 76
# Epoch duration =0.91s
# Cumulative duration =1min 10.489999999999995s
#
# 77
# Epoch duration =0.93s
# Cumulative duration =1min 11.430000000000007s
#
# 78
# Epoch duration =0.91s
# Cumulative duration =1min 12.340000000000003s
#
# 79
# Epoch duration =0.93s
# Cumulative duration =1min 13.269999999999996s
#
# 80
# Epoch duration =0.92s
# Cumulative duration =1min 14.189999999999998s
#
# 81
# Epoch duration =0.92s
# Cumulative duration =1min 15.11s
#
# 82
# Epoch duration =0.93s
# Cumulative duration =1min 16.040000000000006s
#
# 83
# Epoch duration =0.91s
# Cumulative duration =1min 16.950000000000003s
#
# 84
# Epoch duration =0.91s
# Cumulative duration =1min 17.86s
#
# 85
# Epoch duration =0.91s
# Cumulative duration =1min 18.760000000000005s
#
# 86
# Epoch duration =0.91s
# Cumulative duration =1min 19.67s
#
# 87
# Epoch duration =0.93s
# Cumulative duration =1min 20.61s
#
# 88
# Epoch duration =0.91s
# Cumulative duration =1min 21.519999999999996s
#
# 89
# Epoch duration =0.91s
# Cumulative duration =1min 22.430000000000007s
#
# 90
# Epoch duration =0.94s
# Cumulative duration =1min 23.370000000000005s
#
# 91
# Epoch duration =0.93s
# Cumulative duration =1min 24.310000000000002s
#
# 92
# Epoch duration =0.93s
# Cumulative duration =1min 25.239999999999995s
#
# 93
# Epoch duration =0.92s
# Cumulative duration =1min 26.150000000000006s
#
# 94
# Epoch duration =0.92s
# Cumulative duration =1min 27.069999999999993s
#
# 95
# Epoch duration =0.92s
# Cumulative duration =1min 27.989999999999995s
#
# 96
# Epoch duration =0.9s
# Cumulative duration =1min 28.89s
#
# 97
# Epoch duration =0.91s
# Cumulative duration =1min 29.810000000000002s
#
# 98
# Epoch duration =0.92s
# Cumulative duration =1min 30.730000000000004s
#
# 99
# Epoch duration =0.91s
# Cumulative duration =1min 31.629999999999995s
#
# 100
# Epoch duration =0.9s
# Cumulative duration =1min 32.540000000000006s
#
# 101
# Epoch duration =0.92s
# Cumulative duration =1min 33.459999999999994s
#
# 102
# Epoch duration =0.91s
# Cumulative duration =1min 34.370000000000005s
#
# 103
# Epoch duration =0.92s
# Cumulative duration =1min 35.290000000000006s
#
# 104
# Epoch duration =0.92s
# Cumulative duration =1min 36.2s
#
# 105
# Epoch duration =0.96s
# Cumulative duration =1min 37.16s
#
# 106
# Epoch duration =0.92s
# Cumulative duration =1min 38.08s
#
# 107
# Epoch duration =0.93s
# Cumulative duration =1min 39.010000000000005s
#
# 108
# Epoch duration =0.91s
# Cumulative duration =1min 39.92s
#
# 109
# Epoch duration =0.92s
# Cumulative duration =1min 40.84s
#
# 110
# Epoch duration =0.91s
# Cumulative duration =1min 41.75s
#
# 111
# Epoch duration =0.94s
# Cumulative duration =1min 42.69s
#
# 112
# Epoch duration =0.92s
# Cumulative duration =1min 43.61s
#
# 113
# Epoch duration =0.91s
# Cumulative duration =1min 44.519999999999996s
#
# 114
# Epoch duration =0.9s
# Cumulative duration =1min 45.42s
#
# 115
# Epoch duration =0.91s
# Cumulative duration =1min 46.33s
#
# 116
# Epoch duration =0.91s
# Cumulative duration =1min 47.239999999999995s
#
# 117
# Epoch duration =0.93s
# Cumulative duration =1min 48.16s
#
# 118
# Epoch duration =0.92s
# Cumulative duration =1min 49.08s
#
# 119
# Epoch duration =0.93s
# Cumulative duration =1min 50.010000000000005s
#
# 120
# Epoch duration =0.91s
# Cumulative duration =1min 50.92s
#
# 121
# Epoch duration =0.92s
# Cumulative duration =1min 51.84s
#
# 122
# Epoch duration =0.9s
# Cumulative duration =1min 52.739999999999995s
#
# 123
# Epoch duration =0.91s
# Cumulative duration =1min 53.650000000000006s
#
# 124
# Epoch duration =0.9s
# Cumulative duration =1min 54.55s
#
# 125
# Epoch duration =0.92s
# Cumulative duration =1min 55.480000000000004s
#
# 126
# Epoch duration =0.92s
# Cumulative duration =1min 56.39s
#
# 127
# Epoch duration =0.91s
# Cumulative duration =1min 57.31s
#
# 128
# Epoch duration =0.9s
# Cumulative duration =1min 58.2s
#
# 129
# Epoch duration =0.91s
# Cumulative duration =1min 59.120000000000005s
#
# 130
# Epoch duration =0.9s
# Cumulative duration =2min 0.01999999999999602s
#
# 131
# Epoch duration =0.93s
# Cumulative duration =2min 0.9599999999999937s
#
# 132
# Epoch duration =0.91s
# Cumulative duration =2min 1.8700000000000045s
#
# 133
# Epoch duration =0.92s
# Cumulative duration =2min 2.7900000000000063s
#
# 134
# Epoch duration =0.91s
# Cumulative duration =2min 3.6899999999999977s
#
# 135
# Epoch duration =0.92s
# Cumulative duration =2min 4.609999999999999s
#
# 136
# Epoch duration =0.92s
# Cumulative duration =2min 5.530000000000001s
#
# 137
# Epoch duration =0.93s
# Cumulative duration =2min 6.459999999999994s
#
# 138
# Epoch duration =0.91s
# Cumulative duration =2min 7.3700000000000045s
#
# 139
# Epoch duration =0.91s
# Cumulative duration =2min 8.280000000000001s
#
# 140
# Epoch duration =0.91s
# Cumulative duration =2min 9.189999999999998s
#
# 141
# Epoch duration =0.91s
# Cumulative duration =2min 10.099999999999994s
#
# 142
# Epoch duration =0.91s
# Cumulative duration =2min 11.009999999999991s
#
# 143
# Epoch duration =0.91s
# Cumulative duration =2min 11.919999999999987s
#
# 144
# Epoch duration =0.92s
# Cumulative duration =2min 12.840000000000003s
#
# 145
# Epoch duration =0.91s
# Cumulative duration =2min 13.759999999999991s
#
# 146
# Epoch duration =0.91s
# Cumulative duration =2min 14.669999999999987s
#
# 147
# Epoch duration =0.91s
# Cumulative duration =2min 15.580000000000013s
#
# 148
# Epoch duration =0.92s
# Cumulative duration =2min 16.49000000000001s
#
# 149
# Epoch duration =0.9s
# Cumulative duration =2min 17.400000000000006s
#
# 150
# Epoch duration =0.91s
# Cumulative duration =2min 18.30000000000001s
#
# 151
# Epoch duration =0.93s
# Cumulative duration =2min 19.22999999999999s
#
# 152
# Epoch duration =0.93s
# Cumulative duration =2min 20.159999999999997s
#
# 153
# Epoch duration =0.91s
# Cumulative duration =2min 21.069999999999993s
#
# 154
# Epoch duration =0.91s
# Cumulative duration =2min 21.97999999999999s
#
# 155
# Epoch duration =0.92s
# Cumulative duration =2min 22.900000000000006s
#
# 156
# Epoch duration =0.9s
# Cumulative duration =2min 23.80000000000001s
#
# 157
# Epoch duration =0.91s
# Cumulative duration =2min 24.710000000000008s
#
# 158
# Epoch duration =0.9s
# Cumulative duration =2min 25.620000000000005s
#
# 159
# Epoch duration =0.93s
# Cumulative duration =2min 26.55000000000001s
#
# 160
# Epoch duration =0.92s
# Cumulative duration =2min 27.47s
#
# 161
# Epoch duration =0.91s
# Cumulative duration =2min 28.379999999999995s
#
# 162
# Epoch duration =0.91s
# Cumulative duration =2min 29.289999999999992s
#
# 163
# Epoch duration =0.91s
# Cumulative duration =2min 30.210000000000008s
#
# 164
# Epoch duration =0.91s
# Cumulative duration =2min 31.120000000000005s
#
# 165
# Epoch duration =0.92s
# Cumulative duration =2min 32.03999999999999s
#
# 166
# Epoch duration =0.92s
# Cumulative duration =2min 32.96000000000001s
#
# 167
# Epoch duration =0.93s
# Cumulative duration =2min 33.879999999999995s
#
# 168
# Epoch duration =0.92s
# Cumulative duration =2min 34.80000000000001s
#
# 169
# Epoch duration =0.91s
# Cumulative duration =2min 35.71000000000001s
#
# 170
# Epoch duration =0.94s
# Cumulative duration =2min 36.650000000000006s
#
# 171
# Epoch duration =0.92s
# Cumulative duration =2min 37.56s
#
# 172
# Epoch duration =0.92s
# Cumulative duration =2min 38.47999999999999s
#
# 173
# Epoch duration =0.91s
# Cumulative duration =2min 39.389999999999986s
#
# 174
# Epoch duration =0.93s
# Cumulative duration =2min 40.31999999999999s
#
# 175
# Epoch duration =0.91s
# Cumulative duration =2min 41.24000000000001s
#
# 176
# Epoch duration =0.92s
# Cumulative duration =2min 42.16s
#
# 177
# Epoch duration =0.92s
# Cumulative duration =2min 43.08000000000001s
#
# 178
# Epoch duration =0.91s
# Cumulative duration =2min 43.99000000000001s
#
# 179
# Epoch duration =0.91s
# Cumulative duration =2min 44.900000000000006s
#
# 180
# Epoch duration =0.92s
# Cumulative duration =2min 45.81999999999999s
#
# 181
# Epoch duration =0.91s
# Cumulative duration =2min 46.72s
#
# 182
# Epoch duration =0.9s
# Cumulative duration =2min 47.629999999999995s
#
# 183
# Epoch duration =0.93s
# Cumulative duration =2min 48.55000000000001s
#
# 184
# Epoch duration =0.92s
# Cumulative duration =2min 49.47999999999999s
#
# 185
# Epoch duration =0.93s
# Cumulative duration =2min 50.41s
#
# 186
# Epoch duration =0.94s
# Cumulative duration =2min 51.349999999999994s
#
# 187
# Epoch duration =0.91s
# Cumulative duration =2min 52.25999999999999s
#
# 188
# Epoch duration =0.92s
# Cumulative duration =2min 53.16999999999999s
#
# 189
# Epoch duration =0.91s
# Cumulative duration =2min 54.09s
#
# 190
# Epoch duration =0.92s
# Cumulative duration =2min 55.0s
#
# 191
# Epoch duration =0.91s
# Cumulative duration =2min 55.91s
#
# 192
# Epoch duration =0.93s
# Cumulative duration =2min 56.84s
#
# 193
# Epoch duration =0.91s
# Cumulative duration =2min 57.75s
#
# 194
# Epoch duration =0.91s
# Cumulative duration =2min 58.650000000000006s
#
# 195
# Epoch duration =0.92s
# Cumulative duration =2min 59.58000000000001s
#
# 196
# Epoch duration =0.92s
# Cumulative duration =3min 0.4900000000000091s
#
# 197
# Epoch duration =0.93s
# Cumulative duration =3min 1.4199999999999875s
#
# 198
# Epoch duration =0.93s
# Cumulative duration =3min 2.3499999999999943s
#
# 199
# Epoch duration =0.91s
# Cumulative duration =3min 3.259999999999991s
#
# 200
# Epoch duration =0.92s
# Cumulative duration =3min 4.180000000000007s
#
# 201
# Epoch duration =0.92s
# Cumulative duration =3min 5.099999999999994s
#
# 202
# Epoch duration =0.93s
# Cumulative duration =3min 6.02000000000001s
#
# 203
# Epoch duration =0.92s
# Cumulative duration =3min 6.949999999999989s
#
# 204
# Epoch duration =0.9s
# Cumulative duration =3min 7.849999999999994s
#
# 205
# Epoch duration =0.91s
# Cumulative duration =3min 8.759999999999991s
#
# 206
# Epoch duration =0.91s
# Cumulative duration =3min 9.669999999999987s
#
# 207
# Epoch duration =0.92s
# Cumulative duration =3min 10.590000000000003s
#
# 208
# Epoch duration =0.91s
# Cumulative duration =3min 11.5s
#
# 209
# Epoch duration =0.94s
# Cumulative duration =3min 12.439999999999998s
#
# 210
# Epoch duration =0.93s
# Cumulative duration =3min 13.370000000000005s
#
# 211
# Epoch duration =0.94s
# Cumulative duration =3min 14.310000000000002s
#
# 212
# Epoch duration =0.93s
# Cumulative duration =3min 15.25s
#
# 213
# Epoch duration =0.92s
# Cumulative duration =3min 16.159999999999997s
#
# 214
# Epoch duration =0.91s
# Cumulative duration =3min 17.080000000000013s
#
# 215
# Epoch duration =0.91s
# Cumulative duration =3min 17.97999999999999s
#
# 216
# Epoch duration =0.9s
# Cumulative duration =3min 18.889999999999986s
#
# 217
# Epoch duration =0.92s
# Cumulative duration =3min 19.810000000000002s
#
# 218
# Epoch duration =0.91s
# Cumulative duration =3min 20.72s
#
# 219
# Epoch duration =0.92s
# Cumulative duration =3min 21.639999999999986s
#
# 220
# Epoch duration =0.91s
# Cumulative duration =3min 22.55000000000001s
#
# 221
# Epoch duration =0.91s
# Cumulative duration =3min 23.460000000000008s
#
# 222
# Epoch duration =0.9s
# Cumulative duration =3min 24.370000000000005s
#
# 223
# Epoch duration =0.92s
# Cumulative duration =3min 25.28s
#
# 224
# Epoch duration =0.91s
# Cumulative duration =3min 26.19999999999999s
#
# 225
# Epoch duration =0.91s
# Cumulative duration =3min 27.099999999999994s
#
# 226
# Epoch duration =0.91s
# Cumulative duration =3min 28.02000000000001s
#
# 227
# Epoch duration =0.93s
# Cumulative duration =3min 28.94999999999999s
#
# 228
# Epoch duration =0.92s
# Cumulative duration =3min 29.870000000000005s
#
# 229
# Epoch duration =0.91s
# Cumulative duration =3min 30.78s
#
# 230
# Epoch duration =0.9s
# Cumulative duration =3min 31.689999999999998s
#
# 231
# Epoch duration =0.91s
# Cumulative duration =3min 32.599999999999994s
#
# 232
# Epoch duration =0.91s
# Cumulative duration =3min 33.50999999999999s
#
# 233
# Epoch duration =0.92s
# Cumulative duration =3min 34.43000000000001s
#
# 234
# Epoch duration =0.92s
# Cumulative duration =3min 35.349999999999994s
#
# 235
# Epoch duration =0.92s
# Cumulative duration =3min 36.25999999999999s
#
# 236
# Epoch duration =0.91s
# Cumulative duration =3min 37.16999999999999s
#
# 237
# Epoch duration =0.9s
# Cumulative duration =3min 38.08000000000001s
#
# 238
# Epoch duration =0.92s
# Cumulative duration =3min 39.0s
#
# 239
# Epoch duration =0.94s
# Cumulative duration =3min 39.94s
#
# 240
# Epoch duration =0.91s
# Cumulative duration =3min 40.849999999999994s
#
# 241
# Epoch duration =0.91s
# Cumulative duration =3min 41.75999999999999s
#
# 242
# Epoch duration =0.93s
# Cumulative duration =3min 42.69s
#
# 243
# Epoch duration =0.92s
# Cumulative duration =3min 43.610000000000014s
#
# 244
# Epoch duration =0.93s
# Cumulative duration =3min 44.53999999999999s
#
# 245
# Epoch duration =0.9s
# Cumulative duration =3min 45.44s
#
# 246
# Epoch duration =0.93s
# Cumulative duration =3min 46.379999999999995s
#
# 247
# Epoch duration =0.92s
# Cumulative duration =3min 47.28999999999999s
#
# 248
# Epoch duration =0.9s
# Cumulative duration =3min 48.19s
#
# 249
# Epoch duration =0.91s
# Cumulative duration =3min 49.110000000000014s
#
# 250
# Epoch duration =0.91s
# Cumulative duration =3min 50.02000000000001s
#
# 251
# Epoch duration =0.92s
# Cumulative duration =3min 50.94s
#
# 252
# Epoch duration =0.92s
# Cumulative duration =3min 51.860000000000014s
#
# 253
# Epoch duration =0.91s
# Cumulative duration =3min 52.77000000000001s
#
# 254
# Epoch duration =0.92s
# Cumulative duration =3min 53.69s
#
# 255
# Epoch duration =0.92s
# Cumulative duration =3min 54.620000000000005s
#
# 256
# Epoch duration =0.92s
# Cumulative duration =3min 55.53999999999999s
#
# 257
# Epoch duration =0.91s
# Cumulative duration =3min 56.44999999999999s
#
# 258
# Epoch duration =0.91s
# Cumulative duration =3min 57.370000000000005s
#
# 259
# Epoch duration =0.9s
# Cumulative duration =3min 58.27000000000001s
#
# 260
# Epoch duration =0.9s
# Cumulative duration =3min 59.16999999999999s
#
# 261
# Epoch duration =0.91s
# Cumulative duration =4min 0.09000000000000341s
#
# 262
# Epoch duration =0.93s
# Cumulative duration =4min 1.0200000000000102s
#
# 263
# Epoch duration =0.94s
# Cumulative duration =4min 1.960000000000008s
#
# 264
# Epoch duration =0.92s
# Cumulative duration =4min 2.8799999999999955s
#
# 265
# Epoch duration =0.9s
# Cumulative duration =4min 3.780000000000001s
#
# 266
# Epoch duration =0.94s
# Cumulative duration =4min 4.72999999999999s
#
# 267
# Epoch duration =0.91s
# Cumulative duration =4min 5.6299999999999955s
#
# 268
# Epoch duration =0.91s
# Cumulative duration =4min 6.550000000000011s
#
# 269
# Epoch duration =0.91s
# Cumulative duration =4min 7.449999999999989s
#
# 270
# Epoch duration =0.92s
# Cumulative duration =4min 8.370000000000005s
#
# 271
# Epoch duration =0.99s
# Cumulative duration =4min 9.360000000000014s
#
# 272
# Epoch duration =0.9s
# Cumulative duration =4min 10.25s
#
# 273
# Epoch duration =0.91s
# Cumulative duration =4min 11.169999999999987s
#
# 274
# Epoch duration =0.91s
# Cumulative duration =4min 12.080000000000013s
#
# 275
# Epoch duration =0.91s
# Cumulative duration =4min 12.990000000000009s
#
# 276
# Epoch duration =0.91s
# Cumulative duration =4min 13.900000000000006s
#
# 277
# Epoch duration =0.91s
# Cumulative duration =4min 14.810000000000002s
#
# 278
# Epoch duration =0.91s
# Cumulative duration =4min 15.719999999999999s
#
# 279
# Epoch duration =0.92s
# Cumulative duration =4min 16.639999999999986s
#
# 280
# Epoch duration =0.91s
# Cumulative duration =4min 17.55000000000001s
#
# 281
# Epoch duration =0.94s
# Cumulative duration =4min 18.49000000000001s
#
# 282
# Epoch duration =0.93s
# Cumulative duration =4min 19.420000000000016s
#
# 283
# Epoch duration =0.92s
# Cumulative duration =4min 20.339999999999975s
#
# 284
# Epoch duration =0.91s
# Cumulative duration =4min 21.24000000000001s
#
# 285
# Epoch duration =0.94s
# Cumulative duration =4min 22.180000000000007s
#
# 286
# Epoch duration =0.92s
# Cumulative duration =4min 23.100000000000023s
#
# 287
# Epoch duration =0.91s
# Cumulative duration =4min 24.00999999999999s
#
# 288
# Epoch duration =0.92s
# Cumulative duration =4min 24.920000000000016s
#
# 289
# Epoch duration =0.91s
# Cumulative duration =4min 25.829999999999984s
#
# 290
# Epoch duration =0.92s
# Cumulative duration =4min 26.75s
#
# 291
# Epoch duration =0.94s
# Cumulative duration =4min 27.689999999999998s
#
# 292
# Epoch duration =0.91s
# Cumulative duration =4min 28.610000000000014s
#
# 293
# Epoch duration =0.92s
# Cumulative duration =4min 29.529999999999973s
#
# 294
# Epoch duration =0.92s
# Cumulative duration =4min 30.44999999999999s
#
# 295
# Epoch duration =0.92s
# Cumulative duration =4min 31.370000000000005s
#
# 296
# Epoch duration =0.91s
# Cumulative duration =4min 32.27999999999997s
#
# 297
# Epoch duration =0.91s
# Cumulative duration =4min 33.19s
#
# 298
# Epoch duration =0.92s
# Cumulative duration =4min 34.120000000000005s
#
# 299
# Epoch duration =0.94s
# Cumulative duration =4min 35.05000000000001s
#
# 300
# Epoch duration =0.93s
# Cumulative duration =4min 35.98000000000002s
#
# 301
# Epoch duration =0.91s
# Cumulative duration =4min 36.889999999999986s
#
# 302
# Epoch duration =0.92s
# Cumulative duration =4min 37.81999999999999s
#
# 303
# Epoch duration =0.91s
# Cumulative duration =4min 38.73000000000002s
#
# 304
# Epoch duration =0.91s
# Cumulative duration =4min 39.639999999999986s
#
# 305
# Epoch duration =0.92s
# Cumulative duration =4min 40.56s
#
# 306
# Epoch duration =0.91s
# Cumulative duration =4min 41.47000000000003s
#
# 307
# Epoch duration =0.91s
# Cumulative duration =4min 42.379999999999995s
#
# 308
# Epoch duration =0.91s
# Cumulative duration =4min 43.29000000000002s
#
# 309
# Epoch duration =0.92s
# Cumulative duration =4min 44.20999999999998s
#
# 310
# Epoch duration =0.91s
# Cumulative duration =4min 45.120000000000005s
#
# 311
# Epoch duration =0.92s
# Cumulative duration =4min 46.04000000000002s
#
# 312
# Epoch duration =0.92s
# Cumulative duration =4min 46.95999999999998s
#
# 313
# Epoch duration =0.93s
# Cumulative duration =4min 47.889999999999986s
#
# 314
# Epoch duration =0.93s
# Cumulative duration =4min 48.81999999999999s
#
# 315
# Epoch duration =0.92s
# Cumulative duration =4min 49.74000000000001s
#
# 316
# Epoch duration =0.92s
# Cumulative duration =4min 50.660000000000025s
#
# 317
# Epoch duration =0.92s
# Cumulative duration =4min 51.579999999999984s
#
# 318
# Epoch duration =0.92s
# Cumulative duration =4min 52.5s
#
# 319
# Epoch duration =0.94s
# Cumulative duration =4min 53.44s
#
# 320
# Epoch duration =0.91s
# Cumulative duration =4min 54.35000000000002s
#
# 321
# Epoch duration =0.91s
# Cumulative duration =4min 55.26999999999998s
#
# 322
# Epoch duration =0.94s
# Cumulative duration =4min 56.20999999999998s
#
# 323
# Epoch duration =0.92s
# Cumulative duration =4min 57.120000000000005s
#
# 324
# Epoch duration =0.91s
# Cumulative duration =4min 58.04000000000002s
#
# 325
# Epoch duration =0.95s
# Cumulative duration =4min 58.98000000000002s
#
# 326
# Epoch duration =0.92s
# Cumulative duration =4min 59.89999999999998s
#
# 327
# Epoch duration =0.91s
# Cumulative duration =5min 0.8199999999999932s
#
# 328
# Epoch duration =0.91s
# Cumulative duration =5min 1.7200000000000273s
#
# 329
# Epoch duration =0.92s
# Cumulative duration =5min 2.6399999999999864s
#
# 330
# Epoch duration =0.91s
# Cumulative duration =5min 3.5500000000000114s
#
# 331
# Epoch duration =0.92s
# Cumulative duration =5min 4.470000000000027s
#
# 332
# Epoch duration =0.92s
# Cumulative duration =5min 5.389999999999986s
#
# 333
# Epoch duration =0.92s
# Cumulative duration =5min 6.319999999999993s
#
# 334
# Epoch duration =0.91s
# Cumulative duration =5min 7.220000000000027s
#
# 335
# Epoch duration =0.91s
# Cumulative duration =5min 8.139999999999986s
#
# 336
# Epoch duration =0.9s
# Cumulative duration =5min 9.04000000000002s
#
# 337
# Epoch duration =0.91s
# Cumulative duration =5min 9.949999999999989s
#
# 338
# Epoch duration =0.91s
# Cumulative duration =5min 10.860000000000014s
#
# 339
# Epoch duration =0.91s
# Cumulative duration =5min 11.779999999999973s
#
# 340
# Epoch duration =0.95s
# Cumulative duration =5min 12.730000000000018s
#
# 341
# Epoch duration =0.91s
# Cumulative duration =5min 13.639999999999986s
#
# 342
# Epoch duration =0.92s
# Cumulative duration =5min 14.550000000000011s
#
# 343
# Epoch duration =0.91s
# Cumulative duration =5min 15.45999999999998s
#
# 344
# Epoch duration =0.91s
# Cumulative duration =5min 16.370000000000005s
#
# 345
# Epoch duration =0.92s
# Cumulative duration =5min 17.29000000000002s
#
# 346
# Epoch duration =0.94s
# Cumulative duration =5min 18.24000000000001s
#
# 347
# Epoch duration =0.93s
# Cumulative duration =5min 19.170000000000016s
#
# 348
# Epoch duration =0.91s
# Cumulative duration =5min 20.069999999999993s
#
# 349
# Epoch duration =0.93s
# Cumulative duration =5min 21.0s
#
# 350
# Epoch duration =0.93s
# Cumulative duration =5min 21.930000000000007s
#
# 351
# Epoch duration =0.91s
# Cumulative duration =5min 22.839999999999975s
#
# 352
# Epoch duration =0.91s
# Cumulative duration =5min 23.75s
#
# 353
# Epoch duration =0.93s
# Cumulative duration =5min 24.680000000000007s
#
# 354
# Epoch duration =0.92s
# Cumulative duration =5min 25.589999999999975s
#
# 355
# Epoch duration =0.91s
# Cumulative duration =5min 26.50999999999999s
#
# 356
# Epoch duration =0.91s
# Cumulative duration =5min 27.420000000000016s
#
# 357
# Epoch duration =0.91s
# Cumulative duration =5min 28.319999999999993s
#
# 358
# Epoch duration =0.91s
# Cumulative duration =5min 29.230000000000018s
#
# 359
# Epoch duration =0.9s
# Cumulative duration =5min 30.139999999999986s
#
# 360
# Epoch duration =0.9s
# Cumulative duration =5min 31.04000000000002s
#
# 361
# Epoch duration =0.91s
# Cumulative duration =5min 31.94999999999999s
#
# 362
# Epoch duration =0.9s
# Cumulative duration =5min 32.85000000000002s
#
# 363
# Epoch duration =0.93s
# Cumulative duration =5min 33.77999999999997s
#
# 364
# Epoch duration =0.91s
# Cumulative duration =5min 34.69s
#
# 365
# Epoch duration =0.91s
# Cumulative duration =5min 35.60000000000002s
#
# 366
# Epoch duration =0.91s
# Cumulative duration =5min 36.50999999999999s
#
# 367
# Epoch duration =0.91s
# Cumulative duration =5min 37.420000000000016s
#
# 368
# Epoch duration =0.91s
# Cumulative duration =5min 38.329999999999984s
#
# 369
# Epoch duration =0.94s
# Cumulative duration =5min 39.26999999999998s
#
# 370
# Epoch duration =0.9s
# Cumulative duration =5min 40.170000000000016s
#
# 371
# Epoch duration =0.93s
# Cumulative duration =5min 41.110000000000014s
#
# 372
# Epoch duration =0.9s
# Cumulative duration =5min 42.00999999999999s
#
# 373
# Epoch duration =0.91s
# Cumulative duration =5min 42.920000000000016s
#
# 374
# Epoch duration =0.93s
# Cumulative duration =5min 43.85000000000002s
#
# 375
# Epoch duration =0.93s
# Cumulative duration =5min 44.77999999999997s
#
# 376
# Epoch duration =0.91s
# Cumulative duration =5min 45.69999999999999s
#
# 377
# Epoch duration =0.94s
# Cumulative duration =5min 46.639999999999986s
#
# 378
# Epoch duration =0.92s
# Cumulative duration =5min 47.55000000000001s
#
# 379
# Epoch duration =0.94s
# Cumulative duration =5min 48.5s
#
# 380
# Epoch duration =0.91s
# Cumulative duration =5min 49.39999999999998s
#
# 381
# Epoch duration =0.94s
# Cumulative duration =5min 50.339999999999975s
#
# 382
# Epoch duration =0.91s
# Cumulative duration =5min 51.25s
#
# 383
# Epoch duration =0.91s
# Cumulative duration =5min 52.14999999999998s
#
# 384
# Epoch duration =0.91s
# Cumulative duration =5min 53.06s
#
# 385
# Epoch duration =0.91s
# Cumulative duration =5min 53.97000000000003s
#
# 386
# Epoch duration =0.92s
# Cumulative duration =5min 54.889999999999986s
#
# 387
# Epoch duration =0.92s
# Cumulative duration =5min 55.81s
#
# 388
# Epoch duration =0.9s
# Cumulative duration =5min 56.70999999999998s
#
# 389
# Epoch duration =0.92s
# Cumulative duration =5min 57.620000000000005s
#
# 390
# Epoch duration =0.92s
# Cumulative duration =5min 58.55000000000001s
#
# 391
# Epoch duration =0.92s
# Cumulative duration =5min 59.47000000000003s
#
# 392
# Epoch duration =0.94s
# Cumulative duration =6min 0.410000000000025s
#
# 393
# Epoch duration =0.91s
# Cumulative duration =6min 1.3199999999999932s
#
# 394
# Epoch duration =0.91s
# Cumulative duration =6min 2.2200000000000273s
#
# 395
# Epoch duration =0.91s
# Cumulative duration =6min 3.1299999999999955s
#
# 396
# Epoch duration =0.92s
# Cumulative duration =6min 4.050000000000011s
#
# 397
# Epoch duration =0.91s
# Cumulative duration =6min 4.9599999999999795s
#
# 398
# Epoch duration =0.91s
# Cumulative duration =6min 5.8700000000000045s
#
# 399
# Epoch duration =0.93s
# Cumulative duration =6min 6.800000000000011s
#
# 400
# Epoch duration =0.92s
# Cumulative duration =6min 7.7099999999999795s
#
# 401
# Epoch duration =0.93s
# Cumulative duration =6min 8.639999999999986s
#
# 402
# Epoch duration =0.95s
# Cumulative duration =6min 9.589999999999975s
#
# 403
# Epoch duration =0.93s
# Cumulative duration =6min 10.519999999999982s
#
# 404
# Epoch duration =0.93s
# Cumulative duration =6min 11.449999999999989s
#
# 405
# Epoch duration =0.93s
# Cumulative duration =6min 12.379999999999995s
#
# 406
# Epoch duration =0.91s
# Cumulative duration =6min 13.300000000000011s
#
# 407
# Epoch duration =0.91s
# Cumulative duration =6min 14.20999999999998s
#
# 408
# Epoch duration =0.91s
# Cumulative duration =6min 15.120000000000005s
#
# 409
# Epoch duration =0.91s
# Cumulative duration =6min 16.019999999999982s
#
# 410
# Epoch duration =0.91s
# Cumulative duration =6min 16.930000000000007s
#
# 411
# Epoch duration =0.94s
# Cumulative duration =6min 17.870000000000005s
#
# 412
# Epoch duration =0.91s
# Cumulative duration =6min 18.769999999999982s
#
# 413
# Epoch duration =0.91s
# Cumulative duration =6min 19.680000000000007s
#
# 414
# Epoch duration =0.91s
# Cumulative duration =6min 20.589999999999975s
#
# 415
# Epoch duration =0.91s
# Cumulative duration =6min 21.50999999999999s
#
# 416
# Epoch duration =0.91s
# Cumulative duration =6min 22.420000000000016s
#
# 417
# Epoch duration =0.92s
# Cumulative duration =6min 23.339999999999975s
#
# 418
# Epoch duration =0.92s
# Cumulative duration =6min 24.269999999999982s
#
# 419
# Epoch duration =0.91s
# Cumulative duration =6min 25.180000000000007s
#
# 420
# Epoch duration =0.91s
# Cumulative duration =6min 26.089999999999975s
#
# 421
# Epoch duration =0.92s
# Cumulative duration =6min 27.00999999999999s
#
# 422
# Epoch duration =0.91s
# Cumulative duration =6min 27.920000000000016s
#
# 423
# Epoch duration =0.94s
# Cumulative duration =6min 28.860000000000014s
#
# 424
# Epoch duration =0.91s
# Cumulative duration =6min 29.75999999999999s
#
# 425
# Epoch duration =0.95s
# Cumulative duration =6min 30.70999999999998s
#
# 426
# Epoch duration =0.92s
# Cumulative duration =6min 31.629999999999995s
#
# 427
# Epoch duration =0.92s
# Cumulative duration =6min 32.55000000000001s
#
# 428
# Epoch duration =0.91s
# Cumulative duration =6min 33.45999999999998s
#
# 429
# Epoch duration =0.92s
# Cumulative duration =6min 34.379999999999995s
#
# 430
# Epoch duration =0.92s
# Cumulative duration =6min 35.30000000000001s
#
# 431
# Epoch duration =0.92s
# Cumulative duration =6min 36.22000000000003s
#
# 432
# Epoch duration =0.9s
# Cumulative duration =6min 37.120000000000005s
#
# 433
# Epoch duration =0.91s
# Cumulative duration =6min 38.02999999999997s
#
# 434
# Epoch duration =0.91s
# Cumulative duration =6min 38.94s
#
# 435
# Epoch duration =0.91s
# Cumulative duration =6min 39.85000000000002s
#
# 436
# Epoch duration =0.92s
# Cumulative duration =6min 40.77999999999997s
#
# 437
# Epoch duration =0.92s
# Cumulative duration =6min 41.69999999999999s
#
# 438
# Epoch duration =0.93s
# Cumulative duration =6min 42.629999999999995s
#
# 439
# Epoch duration =0.93s
# Cumulative duration =6min 43.56s
#
# 440
# Epoch duration =0.9s
# Cumulative duration =6min 44.45999999999998s
#
# 441
# Epoch duration =0.92s
# Cumulative duration =6min 45.379999999999995s
#
# 442
# Epoch duration =0.92s
# Cumulative duration =6min 46.29000000000002s
#
# 443
# Epoch duration =0.91s
# Cumulative duration =6min 47.20999999999998s
#
# 444
# Epoch duration =0.91s
# Cumulative duration =6min 48.120000000000005s
#
# 445
# Epoch duration =0.92s
# Cumulative duration =6min 49.04000000000002s
#
# 446
# Epoch duration =0.9s
# Cumulative duration =6min 49.94s
#
# 447
# Epoch duration =0.91s
# Cumulative duration =6min 50.85000000000002s
#
# 448
# Epoch duration =0.95s
# Cumulative duration =6min 51.80000000000001s
#
# 449
# Epoch duration =0.93s
# Cumulative duration =6min 52.73000000000002s
#
# 450
# Epoch duration =0.91s
# Cumulative duration =6min 53.639999999999986s
#
# 451
# Epoch duration =0.91s
# Cumulative duration =6min 54.55000000000001s
#
# 452
# Epoch duration =0.91s
# Cumulative duration =6min 55.45999999999998s
#
# 453
# Epoch duration =0.9s
# Cumulative duration =6min 56.360000000000014s
#
# 454
# Epoch duration =0.91s
# Cumulative duration =6min 57.26999999999998s
#
# 455
# Epoch duration =0.92s
# Cumulative duration =6min 58.19s
#
# 456
# Epoch duration =0.93s
# Cumulative duration =6min 59.120000000000005s
#
# 457
# Epoch duration =0.91s
# Cumulative duration =7min 0.029999999999972715s
#
# 458
# Epoch duration =0.93s
# Cumulative duration =7min 0.9599999999999795s
#
# 459
# Epoch duration =0.91s
# Cumulative duration =7min 1.8700000000000045s
#
# 460
# Epoch duration =0.9s
# Cumulative duration =7min 2.769999999999982s
#
# 461
# Epoch duration =0.91s
# Cumulative duration =7min 3.680000000000007s
#
# 462
# Epoch duration =0.9s
# Cumulative duration =7min 4.589999999999975s
#
# 463
# Epoch duration =0.92s
# Cumulative duration =7min 5.509999999999991s
#
# 464
# Epoch duration =0.92s
# Cumulative duration =7min 6.430000000000007s
#
# 465
# Epoch duration =0.92s
# Cumulative duration =7min 7.339999999999975s
#
# 466
# Epoch duration =0.94s
# Cumulative duration =7min 8.279999999999973s
#
# 467
# Epoch duration =0.92s
# Cumulative duration =7min 9.199999999999989s
#
# 468
# Epoch duration =0.9s
# Cumulative duration =7min 10.100000000000023s
#
# 469
# Epoch duration =0.92s
# Cumulative duration =7min 11.019999999999982s
#
# 470
# Epoch duration =0.92s
# Cumulative duration =7min 11.939999999999998s
#
# 471
# Epoch duration =0.92s
# Cumulative duration =7min 12.860000000000014s
#
# 472
# Epoch duration =0.9s
# Cumulative duration =7min 13.759999999999991s
#
# 473
# Epoch duration =0.92s
# Cumulative duration =7min 14.680000000000007s
#
# 474
# Epoch duration =0.92s
# Cumulative duration =7min 15.600000000000023s
#
# 475
# Epoch duration =0.91s
# Cumulative duration =7min 16.50999999999999s
#
# 476
# Epoch duration =0.91s
# Cumulative duration =7min 17.420000000000016s
#
# 477
# Epoch duration =0.93s
# Cumulative duration =7min 18.350000000000023s
#
# 478
# Epoch duration =0.94s
# Cumulative duration =7min 19.29000000000002s
#
# 479
# Epoch duration =0.96s
# Cumulative duration =7min 20.25s
#
# 480
# Epoch duration =0.91s
# Cumulative duration =7min 21.160000000000025s
#
# 481
# Epoch duration =0.91s
# Cumulative duration =7min 22.069999999999993s
#
# 482
# Epoch duration =0.9s
# Cumulative duration =7min 22.970000000000027s
#
# 483
# Epoch duration =0.91s
# Cumulative duration =7min 23.889999999999986s
#
# 484
# Epoch duration =0.94s
# Cumulative duration =7min 24.829999999999984s
#
# 485
# Epoch duration =0.92s
# Cumulative duration =7min 25.74000000000001s
#
# 486
# Epoch duration =0.91s
# Cumulative duration =7min 26.649999999999977s
#
# 487
# Epoch duration =0.91s
# Cumulative duration =7min 27.569999999999993s
#
# 488
# Epoch duration =0.9s
# Cumulative duration =7min 28.470000000000027s
#
# 489
# Epoch duration =0.9s
# Cumulative duration =7min 29.370000000000005s
#
# 490
# Epoch duration =0.91s
# Cumulative duration =7min 30.29000000000002s
#
# 491
# Epoch duration =0.91s
# Cumulative duration =7min 31.19999999999999s
#
# 492
# Epoch duration =0.9s
# Cumulative duration =7min 32.10000000000002s
#
# 493
# Epoch duration =0.92s
# Cumulative duration =7min 33.01999999999998s
#
# 494
# Epoch duration =0.93s
# Cumulative duration =7min 33.94999999999999s
#
# 495
# Epoch duration =0.91s
# Cumulative duration =7min 34.860000000000014s
#
# 496
# Epoch duration =0.92s
# Cumulative duration =7min 35.77999999999997s
#
# 497
# Epoch duration =0.91s
# Cumulative duration =7min 36.69s
#
# 498
# Epoch duration =0.94s
# Cumulative duration =7min 37.629999999999995s
#
# 499
# Epoch duration =0.92s
# Cumulative duration =7min 38.55000000000001s
#
# 500
# Epoch duration =0.93s
# Cumulative duration =7min 39.48000000000002s
#
# 501
# Epoch duration =0.94s
# Cumulative duration =7min 40.43000000000001s
#
# 502
# Epoch duration =0.91s
# Cumulative duration =7min 41.339999999999975s
#
# 503
# Epoch duration =0.92s
# Cumulative duration =7min 42.25999999999999s
#
# 504
# Epoch duration =0.92s
# Cumulative duration =7min 43.18000000000001s
#
# 505
# Epoch duration =0.91s
# Cumulative duration =7min 44.089999999999975s
#
# 506
# Epoch duration =0.93s
# Cumulative duration =7min 45.02999999999997s
#
# 507
# Epoch duration =0.91s
# Cumulative duration =7min 45.94s
#
# 508
# Epoch duration =0.9s
# Cumulative duration =7min 46.839999999999975s
#
# 509
# Epoch duration =0.9s
# Cumulative duration =7min 47.74000000000001s
#
# 510
# Epoch duration =0.92s
# Cumulative duration =7min 48.64999999999998s
#
# 511
# Epoch duration =0.91s
# Cumulative duration =7min 49.56s
#
# 512
# Epoch duration =0.9s
# Cumulative duration =7min 50.45999999999998s
#
# 513
# Epoch duration =0.93s
# Cumulative duration =7min 51.389999999999986s
#
# 514
# Epoch duration =0.93s
# Cumulative duration =7min 52.31999999999999s
#
# 515
# Epoch duration =0.92s
# Cumulative duration =7min 53.24000000000001s
#
# 516
# Epoch duration =0.91s
# Cumulative duration =7min 54.14999999999998s
#
# 517
# Epoch duration =0.92s
# Cumulative duration =7min 55.079999999999984s
#
# 518
# Epoch duration =0.92s
# Cumulative duration =7min 56.0s
#
# 519
# Epoch duration =0.9s
# Cumulative duration =7min 56.89999999999998s
#
# 520
# Epoch duration =0.9s
# Cumulative duration =7min 57.80000000000001s
#
# 521
# Epoch duration =0.92s
# Cumulative duration =7min 58.72000000000003s
#
# 522
# Epoch duration =0.91s
# Cumulative duration =7min 59.629999999999995s
#
# 523
# Epoch duration =0.92s
# Cumulative duration =8min 0.5600000000000023s
#
# 524
# Epoch duration =0.91s
# Cumulative duration =8min 1.4700000000000273s
#
# 525
# Epoch duration =0.9s
# Cumulative duration =8min 2.3700000000000045s
#
# 526
# Epoch duration =0.92s
# Cumulative duration =8min 3.2900000000000205s
#
# 527
# Epoch duration =0.92s
# Cumulative duration =8min 4.2099999999999795s
#
# 528
# Epoch duration =0.9s
# Cumulative duration =8min 5.100000000000023s
#
# 529
# Epoch duration =0.92s
# Cumulative duration =8min 6.019999999999982s
#
# 530
# Epoch duration =0.91s
# Cumulative duration =8min 6.930000000000007s
#
# 531
# Epoch duration =0.91s
# Cumulative duration =8min 7.839999999999975s
#
# 532
# Epoch duration =0.91s
# Cumulative duration =8min 8.75s
#
# 533
# Epoch duration =0.91s
# Cumulative duration =8min 9.670000000000016s
#
# 534
# Epoch duration =0.91s
# Cumulative duration =8min 10.579999999999984s
#
# 535
# Epoch duration =0.91s
# Cumulative duration =8min 11.490000000000009s
#
# 536
# Epoch duration =0.91s
# Cumulative duration =8min 12.389999999999986s
#
# 537
# Epoch duration =0.92s
# Cumulative duration =8min 13.310000000000002s
#
# 538
# Epoch duration =0.92s
# Cumulative duration =8min 14.230000000000018s
#
# 539
# Epoch duration =0.93s
# Cumulative duration =8min 15.160000000000025s
#
# 540
# Epoch duration =0.93s
# Cumulative duration =8min 16.079999999999984s
#
# 541
# Epoch duration =0.91s
# Cumulative duration =8min 17.0s
#
# 542
# Epoch duration =0.91s
# Cumulative duration =8min 17.910000000000025s
#
# 543
# Epoch duration =0.92s
# Cumulative duration =8min 18.819999999999993s
#
# 544
# Epoch duration =0.92s
# Cumulative duration =8min 19.74000000000001s
#
# 545
# Epoch duration =0.92s
# Cumulative duration =8min 20.660000000000025s
#
# 546
# Epoch duration =0.91s
# Cumulative duration =8min 21.569999999999993s
#
# 547
# Epoch duration =0.91s
# Cumulative duration =8min 22.480000000000018s
#
# 548
# Epoch duration =0.9s
# Cumulative duration =8min 23.379999999999995s
#
# 549
# Epoch duration =0.92s
# Cumulative duration =8min 24.30000000000001s
#
# 550
# Epoch duration =0.94s
# Cumulative duration =8min 25.24000000000001s
#
# 551
# Epoch duration =0.93s
# Cumulative duration =8min 26.170000000000016s
#
# 552
# Epoch duration =0.91s
# Cumulative duration =8min 27.079999999999984s
#
# 553
# Epoch duration =0.92s
# Cumulative duration =8min 28.00999999999999s
#
# 554
# Epoch duration =0.91s
# Cumulative duration =8min 28.920000000000016s
#
# 555
# Epoch duration =0.91s
# Cumulative duration =8min 29.829999999999984s
#
# 556
# Epoch duration =0.92s
# Cumulative duration =8min 30.75s
#
# 557
# Epoch duration =0.91s
# Cumulative duration =8min 31.660000000000025s
#
# 558
# Epoch duration =0.92s
# Cumulative duration =8min 32.58000000000004s
#
# 559
# Epoch duration =0.95s
# Cumulative duration =8min 33.51999999999998s
#
# 560
# Epoch duration =0.91s
# Cumulative duration =8min 34.42999999999995s
#
# 561
# Epoch duration =0.91s
# Cumulative duration =8min 35.35000000000002s
#
# 562
# Epoch duration =0.9s
# Cumulative duration =8min 36.25s
#
# 563
# Epoch duration =0.91s
# Cumulative duration =8min 37.16999999999996s
#
# 564
# Epoch duration =0.91s
# Cumulative duration =8min 38.08000000000004s
#
# 565
# Epoch duration =0.91s
# Cumulative duration =8min 38.99000000000001s
#
# 566
# Epoch duration =0.92s
# Cumulative duration =8min 39.90999999999997s
#
# 567
# Epoch duration =0.92s
# Cumulative duration =8min 40.83000000000004s
#
# 568
# Epoch duration =0.92s
# Cumulative duration =8min 41.75s
#
# 569
# Epoch duration =0.91s
# Cumulative duration =8min 42.65999999999997s
#
# 570
# Epoch duration =0.92s
# Cumulative duration =8min 43.58000000000004s
#
# 571
# Epoch duration =0.92s
# Cumulative duration =8min 44.50999999999999s
#
# 572
# Epoch duration =0.91s
# Cumulative duration =8min 45.41999999999996s
#
# 573
# Epoch duration =0.91s
# Cumulative duration =8min 46.33000000000004s
#
# 574
# Epoch duration =0.91s
# Cumulative duration =8min 47.25s
#
# 575
# Epoch duration =0.9s
# Cumulative duration =8min 48.14999999999998s
#
# 576
# Epoch duration =0.9s
# Cumulative duration =8min 49.049999999999955s
#
# 577
# Epoch duration =0.92s
# Cumulative duration =8min 49.97000000000003s
#
# 578
# Epoch duration =0.92s
# Cumulative duration =8min 50.89999999999998s
#
# 579
# Epoch duration =0.91s
# Cumulative duration =8min 51.809999999999945s
#
# 580
# Epoch duration =0.92s
# Cumulative duration =8min 52.74000000000001s
#
# 581
# Epoch duration =0.91s
# Cumulative duration =8min 53.64999999999998s
#
# 582
# Epoch duration =0.91s
# Cumulative duration =8min 54.559999999999945s
#
# 583
# Epoch duration =0.93s
# Cumulative duration =8min 55.49000000000001s
#
# 584
# Epoch duration =0.92s
# Cumulative duration =8min 56.40999999999997s
#
# 585
# Epoch duration =0.93s
# Cumulative duration =8min 57.34000000000003s
#
# 586
# Epoch duration =0.95s
# Cumulative duration =8min 58.289999999999964s
#
# 587
# Epoch duration =0.92s
# Cumulative duration =8min 59.210000000000036s
#
# 588
# Epoch duration =0.91s
# Cumulative duration =9min 0.12000000000000455s
#
# 589
# Epoch duration =0.92s
# Cumulative duration =9min 1.0399999999999636s
#
# 590
# Epoch duration =0.91s
# Cumulative duration =9min 1.9500000000000455s
#
# 591
# Epoch duration =0.91s
# Cumulative duration =9min 2.8600000000000136s
#
# 592
# Epoch duration =0.94s
# Cumulative duration =9min 3.7999999999999545s
#
# 593
# Epoch duration =0.93s
# Cumulative duration =9min 4.730000000000018s
#
# 594
# Epoch duration =0.91s
# Cumulative duration =9min 5.639999999999986s
#
# 595
# Epoch duration =0.94s
# Cumulative duration =9min 6.580000000000041s
#
# 596
# Epoch duration =0.93s
# Cumulative duration =9min 7.509999999999991s
#
# 597
# Epoch duration =0.92s
# Cumulative duration =9min 8.419999999999959s
#
# 598
# Epoch duration =0.91s
# Cumulative duration =9min 9.340000000000032s
#
# 599
# Epoch duration =0.92s
# Cumulative duration =9min 10.259999999999991s
#
# 600
# Epoch duration =0.91s
# Cumulative duration =9min 11.169999999999959s
#
# 601
# Epoch duration =0.92s
# Cumulative duration =9min 12.090000000000032s
#
# 602
# Epoch duration =0.92s
# Cumulative duration =9min 13.009999999999991s
#
# 603
# Epoch duration =0.93s
# Cumulative duration =9min 13.92999999999995s
#
# 604
# Epoch duration =0.93s
# Cumulative duration =9min 14.860000000000014s
#
# 605
# Epoch duration =0.93s
# Cumulative duration =9min 15.789999999999964s
#
# 606
# Epoch duration =0.91s
# Cumulative duration =9min 16.700000000000045s
#
# 607
# Epoch duration =0.91s
# Cumulative duration =9min 17.620000000000005s
#
# 608
# Epoch duration =0.91s
# Cumulative duration =9min 18.519999999999982s
#
# 609
# Epoch duration =0.9s
# Cumulative duration =9min 19.42999999999995s
#
# 610
# Epoch duration =0.9s
# Cumulative duration =9min 20.33000000000004s
#
# 611
# Epoch duration =0.91s
# Cumulative duration =9min 21.25s
#
# 612
# Epoch duration =0.93s
# Cumulative duration =9min 22.16999999999996s
#
# 613
# Epoch duration =0.95s
# Cumulative duration =9min 23.120000000000005s
#
# 614
# Epoch duration =0.92s
# Cumulative duration =9min 24.029999999999973s
#
# 615
# Epoch duration =0.92s
# Cumulative duration =9min 24.950000000000045s
#
# 616
# Epoch duration =0.91s
# Cumulative duration =9min 25.870000000000005s
#
# 617
# Epoch duration =0.92s
# Cumulative duration =9min 26.789999999999964s
#
# 618
# Epoch duration =0.91s
# Cumulative duration =9min 27.700000000000045s
#
# 619
# Epoch duration =0.92s
# Cumulative duration =9min 28.620000000000005s
#
# 620
# Epoch duration =0.9s
# Cumulative duration =9min 29.529999999999973s
#
# 621
# Epoch duration =0.92s
# Cumulative duration =9min 30.450000000000045s
#
# 622
# Epoch duration =0.91s
# Cumulative duration =9min 31.350000000000023s
#
# 623
# Epoch duration =0.91s
# Cumulative duration =9min 32.25999999999999s
#
# 624
# Epoch duration =0.9s
# Cumulative duration =9min 33.15999999999997s
#
# 625
# Epoch duration =0.91s
# Cumulative duration =9min 34.08000000000004s
#
# 626
# Epoch duration =0.91s
# Cumulative duration =9min 34.99000000000001s
#
# 627
# Epoch duration =0.91s
# Cumulative duration =9min 35.89999999999998s
#
# 628
# Epoch duration =0.9s
# Cumulative duration =9min 36.789999999999964s
#
# 629
# Epoch duration =0.91s
# Cumulative duration =9min 37.700000000000045s
#
# 630
# Epoch duration =0.91s
# Cumulative duration =9min 38.610000000000014s
#
# 631
# Epoch duration =0.92s
# Cumulative duration =9min 39.52999999999997s
#
# 632
# Epoch duration =0.9s
# Cumulative duration =9min 40.42999999999995s
#
# 633
# Epoch duration =0.92s
# Cumulative duration =9min 41.35000000000002s
#
# 634
# Epoch duration =0.93s
# Cumulative duration =9min 42.26999999999998s
#
# 635
# Epoch duration =0.92s
# Cumulative duration =9min 43.190000000000055s
#
# 636
# Epoch duration =0.91s
# Cumulative duration =9min 44.110000000000014s
#
# 637
# Epoch duration =0.91s
# Cumulative duration =9min 45.01999999999998s
#
# 638
# Epoch duration =0.9s
# Cumulative duration =9min 45.91999999999996s
#
# 639
# Epoch duration =0.93s
# Cumulative duration =9min 46.85000000000002s
#
# 640
# Epoch duration =0.91s
# Cumulative duration =9min 47.75999999999999s
#
# 641
# Epoch duration =0.92s
# Cumulative duration =9min 48.690000000000055s
#
# 642
# Epoch duration =0.92s
# Cumulative duration =9min 49.610000000000014s
#
# 643
# Epoch duration =0.92s
# Cumulative duration =9min 50.52999999999997s
#
# 644
# Epoch duration =0.92s
# Cumulative duration =9min 51.450000000000045s
#
# 645
# Epoch duration =0.91s
# Cumulative duration =9min 52.360000000000014s
#
# 646
# Epoch duration =0.9s
# Cumulative duration =9min 53.25999999999999s
#
# 647
# Epoch duration =0.93s
# Cumulative duration =9min 54.190000000000055s
#
# 648
# Epoch duration =0.9s
# Cumulative duration =9min 55.10000000000002s
#
# 649
# Epoch duration =0.91s
# Cumulative duration =9min 56.00999999999999s
#
# 650
# Epoch duration =0.91s
# Cumulative duration =9min 56.91999999999996s
#
# 651
# Epoch duration =0.92s
# Cumulative duration =9min 57.85000000000002s
#
# 652
# Epoch duration =0.91s
# Cumulative duration =9min 58.75999999999999s
#
# 653
# Epoch duration =0.93s
# Cumulative duration =9min 59.690000000000055s
#
# 654
# Epoch duration =0.91s
# Cumulative duration =10min 0.6000000000000227s
#
# 655
# Epoch duration =0.91s
# Cumulative duration =10min 1.509999999999991s
#
# 656
# Epoch duration =0.9s
# Cumulative duration =10min 2.419999999999959s
#
# 657
# Epoch duration =0.93s
# Cumulative duration =10min 3.3500000000000227s
#
# 658
# Epoch duration =0.92s
# Cumulative duration =10min 4.269999999999982s
#
# 659
# Epoch duration =0.91s
# Cumulative duration =10min 5.17999999999995s
#
# 660
# Epoch duration =0.93s
# Cumulative duration =10min 6.100000000000023s
#
# 661
# Epoch duration =0.91s
# Cumulative duration =10min 7.019999999999982s
#
# 662
# Epoch duration =0.91s
# Cumulative duration =10min 7.92999999999995s
#
# 663
# Epoch duration =0.94s
# Cumulative duration =10min 8.870000000000005s
#
# 664
# Epoch duration =0.9s
# Cumulative duration =10min 9.769999999999982s
#
# 665
# Epoch duration =0.92s
# Cumulative duration =10min 10.690000000000055s
#
# 666
# Epoch duration =0.9s
# Cumulative duration =10min 11.590000000000032s
#
# 667
# Epoch duration =0.91s
# Cumulative duration =10min 12.509999999999991s
#
# 668
# Epoch duration =0.9s
# Cumulative duration =10min 13.399999999999977s
#
# 669
# Epoch duration =0.91s
# Cumulative duration =10min 14.32000000000005s
#
# 670
# Epoch duration =0.91s
# Cumulative duration =10min 15.230000000000018s
#
# 671
# Epoch duration =0.91s
# Cumulative duration =10min 16.139999999999986s
#
# 672
# Epoch duration =0.9s
# Cumulative duration =10min 17.039999999999964s
#
# 673
# Epoch duration =0.92s
# Cumulative duration =10min 17.970000000000027s
#
# 674
# Epoch duration =0.92s
# Cumulative duration =10min 18.879999999999995s
#
# 675
# Epoch duration =0.92s
# Cumulative duration =10min 19.809999999999945s
#
# 676
# Epoch duration =0.9s
# Cumulative duration =10min 20.710000000000036s
#
# 677
# Epoch duration =0.93s
# Cumulative duration =10min 21.639999999999986s
#
# 678
# Epoch duration =0.93s
# Cumulative duration =10min 22.58000000000004s
#
# 679
# Epoch duration =0.92s
# Cumulative duration =10min 23.5s
#
# 680
# Epoch duration =0.9s
# Cumulative duration =10min 24.399999999999977s
#
# 681
# Epoch duration =0.91s
# Cumulative duration =10min 25.32000000000005s
#
# 682
# Epoch duration =0.91s
# Cumulative duration =10min 26.230000000000018s
#
# 683
# Epoch duration =0.91s
# Cumulative duration =10min 27.139999999999986s
#
# 684
# Epoch duration =0.91s
# Cumulative duration =10min 28.049999999999955s
#
# 685
# Epoch duration =0.92s
# Cumulative duration =10min 28.970000000000027s
#
# 686
# Epoch duration =0.92s
# Cumulative duration =10min 29.889999999999986s
#
# 687
# Epoch duration =0.91s
# Cumulative duration =10min 30.809999999999945s
#
# 688
# Epoch duration =0.91s
# Cumulative duration =10min 31.710000000000036s
#
# 689
# Epoch duration =0.91s
# Cumulative duration =10min 32.629999999999995s
#
# 690
# Epoch duration =0.94s
# Cumulative duration =10min 33.57000000000005s
#
# 691
# Epoch duration =0.91s
# Cumulative duration =10min 34.48000000000002s
#
# 692
# Epoch duration =0.91s
# Cumulative duration =10min 35.39999999999998s
#
# 693
# ...
# Cumulative duration =11min 58.22000000000003s
#
# 783
# Epoch duration =0.92s
# Cumulative duration =11min 59.139999999999986s
#
# 784
# Epoch duration =0.94s
# Cumulative duration =12min 0.08000000000004093s
#
# 785
# Epoch duration =0.91s
# Cumulative duration =12min 0.9900000000000091s
#
# 786
# Epoch duration =0.91s
# Cumulative duration =12min 1.9099999999999682s
#
# 787
# Epoch duration =0.92s
# Cumulative duration =12min 2.830000000000041s
#
# 788
# Epoch duration =0.91s
# Cumulative duration =12min 3.740000000000009s
#
# 789
# Epoch duration =0.92s
# Cumulative duration =12min 4.659999999999968s
#
# 790
# Epoch duration =0.91s
# Cumulative duration =12min 5.580000000000041s
#
# 791
# Epoch duration =0.91s
# Cumulative duration =12min 6.490000000000009s
#
# 792
# Epoch duration =0.94s
# Cumulative duration =12min 7.42999999999995s
#
# 793
# Epoch duration =0.93s
# Cumulative duration =12min 8.360000000000014s
#
# 794
# Epoch duration =0.91s
# Cumulative duration =12min 9.269999999999982s
#
# 795
# Epoch duration =0.93s
# Cumulative duration =12min 10.190000000000055s
#
# 796
# Epoch duration =0.91s
# Cumulative duration =12min 11.100000000000023s
#
# 797
# Epoch duration =0.93s
# Cumulative duration =12min 12.029999999999973s
#
# 798
# Epoch duration =0.91s
# Cumulative duration =12min 12.950000000000045s
#
# 799
# Epoch duration =0.92s
# Cumulative duration =12min 13.870000000000005s
#
# 800
# Epoch duration =0.91s
# Cumulative duration =12min 14.779999999999973s
#
# 801
# Epoch duration =0.93s
# Cumulative duration =12min 15.710000000000036s
#
# 802
# Epoch duration =0.94s
# Cumulative duration =12min 16.649999999999977s
#
# 803
# Epoch duration =0.91s
# Cumulative duration =12min 17.559999999999945s
#
# 804
# Epoch duration =0.91s
# Cumulative duration =12min 18.470000000000027s
#
# 805
# Epoch duration =0.92s
# Cumulative duration =12min 19.389999999999986s
#
# 806
# Epoch duration =0.93s
# Cumulative duration =12min 20.32000000000005s
#
# 807
# Epoch duration =0.92s
# Cumulative duration =12min 21.24000000000001s
#
# 808
# Epoch duration =0.9s
# Cumulative duration =12min 22.149999999999977s
#
# 809
# Epoch duration =0.92s
# Cumulative duration =12min 23.07000000000005s
#
# 810
# Epoch duration =0.91s
# Cumulative duration =12min 23.970000000000027s
#
# 811
# Epoch duration =0.93s
# Cumulative duration =12min 24.899999999999977s
#
# 812
# Epoch duration =0.9s
# Cumulative duration =12min 25.799999999999955s
#
# 813
# Epoch duration =0.91s
# Cumulative duration =12min 26.710000000000036s
#
# 814
# Epoch duration =0.92s
# Cumulative duration =12min 27.629999999999995s
#
# 815
# Epoch duration =0.92s
# Cumulative duration =12min 28.549999999999955s
#
# 816
# Epoch duration =0.91s
# Cumulative duration =12min 29.460000000000036s
#
# 817
# Epoch duration =0.92s
# Cumulative duration =12min 30.379999999999995s
#
# 818
# Epoch duration =0.91s
# Cumulative duration =12min 31.289999999999964s
#
# 819
# Epoch duration =0.91s
# Cumulative duration =12min 32.200000000000045s
#
# 820
# Epoch duration =0.9s
# Cumulative duration =12min 33.10000000000002s
#
# 821
# Epoch duration =0.92s
# Cumulative duration =12min 34.01999999999998s
#
# 822
# Epoch duration =0.94s
# Cumulative duration =12min 34.97000000000003s
#
# 823
# Epoch duration =0.92s
# Cumulative duration =12min 35.889999999999986s
#
# 824
# Epoch duration =0.91s
# Cumulative duration =12min 36.789999999999964s
#
# 825
# Epoch duration =0.92s
# Cumulative duration =12min 37.710000000000036s
#
# 826
# Epoch duration =0.92s
# Cumulative duration =12min 38.629999999999995s
#
# 827
# Epoch duration =0.91s
# Cumulative duration =12min 39.539999999999964s
#
# 828
# Epoch duration =0.9s
# Cumulative duration =12min 40.440000000000055s
#
# 829
# Epoch duration =0.92s
# Cumulative duration =12min 41.360000000000014s
#
# 830
# Epoch duration =0.91s
# Cumulative duration =12min 42.26999999999998s
#
# 831
# Epoch duration =0.91s
# Cumulative duration =12min 43.17999999999995s
#
# 832
# Epoch duration =0.94s
# Cumulative duration =12min 44.129999999999995s
#
# 833
# Epoch duration =0.96s
# Cumulative duration =12min 45.08000000000004s
#
# 834
# Epoch duration =0.95s
# Cumulative duration =12min 46.039999999999964s
#
# 835
# Epoch duration =0.95s
# Cumulative duration =12min 46.99000000000001s
#
# 836
# Epoch duration =0.91s
# Cumulative duration =12min 47.89999999999998s
#
# 837
# Epoch duration =0.92s
# Cumulative duration =12min 48.809999999999945s
#
# 838
# Epoch duration =0.91s
# Cumulative duration =12min 49.73000000000002s
#
# 839
# Epoch duration =0.92s
# Cumulative duration =12min 50.64999999999998s
#
# 840
# Epoch duration =0.91s
# Cumulative duration =12min 51.559999999999945s
#
# 841
# Epoch duration =0.92s
# Cumulative duration =12min 52.48000000000002s
#
# 842
# Epoch duration =0.92s
# Cumulative duration =12min 53.389999999999986s
#
# 843
# Epoch duration =0.91s
# Cumulative duration =12min 54.309999999999945s
#
# 844
# Epoch duration =0.91s
# Cumulative duration =12min 55.22000000000003s
#
# 845
# Epoch duration =0.93s
# Cumulative duration =12min 56.14999999999998s
#
# 846
# Epoch duration =0.91s
# Cumulative duration =12min 57.059999999999945s
#
# 847
# Epoch duration =0.91s
# Cumulative duration =12min 57.97000000000003s
#
# 848
# Epoch duration =0.92s
# Cumulative duration =12min 58.889999999999986s
#
# 849
# Epoch duration =0.91s
# Cumulative duration =12min 59.799999999999955s
#
# 850
# Epoch duration =0.91s
# Cumulative duration =13min 0.7100000000000364s
#
# 851
# Epoch duration =0.92s
# Cumulative duration =13min 1.6200000000000045s
#
# 852
# Epoch duration =0.91s
# Cumulative duration =13min 2.5299999999999727s
#
# 853
# Epoch duration =0.92s
# Cumulative duration =13min 3.4600000000000364s
#
# 854
# Epoch duration =0.9s
# Cumulative duration =13min 4.360000000000014s
#
# 855
# Epoch duration =0.91s
# Cumulative duration =13min 5.269999999999982s
#
# 856
# Epoch duration =0.91s
# Cumulative duration =13min 6.17999999999995s
#
# 857
# Epoch duration =0.91s
# Cumulative duration =13min 7.090000000000032s
#
# 858
# Epoch duration =0.91s
# Cumulative duration =13min 8.0s
#
# 859
# Epoch duration =0.92s
# Cumulative duration =13min 8.919999999999959s
#
# 860
# Epoch duration =0.91s
# Cumulative duration =13min 9.830000000000041s
#
# 861
# Epoch duration =0.92s
# Cumulative duration =13min 10.75s
#
# 862
# Epoch duration =0.94s
# Cumulative duration =13min 11.690000000000055s
#
# 863
# Epoch duration =0.92s
# Cumulative duration =13min 12.610000000000014s
#
# 864
# Epoch duration =0.92s
# Cumulative duration =13min 13.529999999999973s
#
# 865
# Epoch duration =0.92s
# Cumulative duration =13min 14.450000000000045s
#
# 866
# Epoch duration =0.91s
# Cumulative duration =13min 15.360000000000014s
#
# 867
# Epoch duration =0.95s
# Cumulative duration =13min 16.309999999999945s
#
# 868
# Epoch duration =0.9s
# Cumulative duration =13min 17.220000000000027s
#
# 869
# Epoch duration =0.92s
# Cumulative duration =13min 18.139999999999986s
#
# 870
# Epoch duration =0.9s
# Cumulative duration =13min 19.039999999999964s
#
# 871
# Epoch duration =0.93s
# Cumulative duration =13min 19.970000000000027s
#
# 872
# Epoch duration =0.91s
# Cumulative duration =13min 20.879999999999995s
#
# 873
# Epoch duration =0.91s
# Cumulative duration =13min 21.799999999999955s
#
# 874
# Epoch duration =0.94s
# Cumulative duration =13min 22.74000000000001s
#
# 875
# Epoch duration =0.94s
# Cumulative duration =13min 23.67999999999995s
#
# 876
# Epoch duration =0.92s
# Cumulative duration =13min 24.600000000000023s
#
# 877
# Epoch duration =0.94s
# Cumulative duration =13min 25.539999999999964s
#
# 878
# Epoch duration =0.9s
# Cumulative duration =13min 26.440000000000055s
#
# 879
# Epoch duration =0.91s
# Cumulative duration =13min 27.350000000000023s
#
# 880
# Epoch duration =0.91s
# Cumulative duration =13min 28.25999999999999s
#
# 881
# Epoch duration =0.93s
# Cumulative duration =13min 29.190000000000055s
#
# 882
# Epoch duration =0.91s
# Cumulative duration =13min 30.100000000000023s
#
# 883
# Epoch duration =0.92s
# Cumulative duration =13min 31.029999999999973s
#
# 884
# Epoch duration =0.94s
# Cumulative duration =13min 31.970000000000027s
#
# 885
# Epoch duration =0.93s
# Cumulative duration =13min 32.89999999999998s
#
# 886
# Epoch duration =0.9s
# Cumulative duration =13min 33.799999999999955s
#
# 887
# Epoch duration =0.92s
# Cumulative duration =13min 34.73000000000002s
#
# 888
# Epoch duration =0.9s
# Cumulative duration =13min 35.629999999999995s
#
# 889
# Epoch duration =0.91s
# Cumulative duration =13min 36.539999999999964s
#
# 890
# Epoch duration =0.91s
# Cumulative duration =13min 37.450000000000045s
#
# 891
# Epoch duration =0.95s
# Cumulative duration =13min 38.39999999999998s
#
# 892
# Epoch duration =0.91s
# Cumulative duration =13min 39.309999999999945s
#
# 893
# Epoch duration =0.95s
# Cumulative duration =13min 40.25999999999999s
#
# 894
# Epoch duration =0.91s
# Cumulative duration =13min 41.15999999999997s
#
# 895
# Epoch duration =0.92s
# Cumulative duration =13min 42.08000000000004s
#
# 896
# Epoch duration =0.92s
# Cumulative duration =13min 43.0s
#
# 897
# Epoch duration =0.94s
# Cumulative duration =13min 43.940000000000055s
#
# 898
# Epoch duration =0.93s
# Cumulative duration =13min 44.870000000000005s
#
# 899
# Epoch duration =0.91s
# Cumulative duration =13min 45.77999999999997s
#
# 900
# Epoch duration =0.9s
# Cumulative duration =13min 46.67999999999995s
#
# 901
# Epoch duration =0.93s
# Cumulative duration =13min 47.60000000000002s
#
# 902
# Epoch duration =0.92s
# Cumulative duration =13min 48.51999999999998s
#
# 903
# Epoch duration =0.91s
# Cumulative duration =13min 49.42999999999995s
#
# 904
# Epoch duration =0.9s
# Cumulative duration =13min 50.34000000000003s
#
# 905
# Epoch duration =0.92s
# Cumulative duration =13min 51.25999999999999s
#
# 906
# Epoch duration =0.92s
# Cumulative duration =13min 52.16999999999996s
#
# 907
# Epoch duration =0.93s
# Cumulative duration =13min 53.10000000000002s
#
# 908
# Epoch duration =0.95s
# Cumulative duration =13min 54.049999999999955s
#
# 909
# Epoch duration =0.92s
# Cumulative duration =13min 54.97000000000003s
#
# 910
# Epoch duration =0.92s
# Cumulative duration =13min 55.879999999999995s
#
# 911
# Epoch duration =0.91s
# Cumulative duration =13min 56.789999999999964s
#
# 912
# Epoch duration =0.9s
# Cumulative duration =13min 57.690000000000055s
#
# 913
# Epoch duration =0.91s
# Cumulative duration =13min 58.60000000000002s
#
# 914
# Epoch duration =0.92s
# Cumulative duration =13min 59.50999999999999s
#
# 915
# Epoch duration =0.94s
# Cumulative duration =14min 0.4500000000000455s
#
# 916
# Epoch duration =0.91s
# Cumulative duration =14min 1.3600000000000136s
#
# 917
# Epoch duration =0.92s
# Cumulative duration =14min 2.2799999999999727s
#
# 918
# Epoch duration =0.91s
# Cumulative duration =14min 3.1900000000000546s
#
# 919
# Epoch duration =0.92s
# Cumulative duration =14min 4.110000000000014s
#
# 920
# Epoch duration =0.93s
# Cumulative duration =14min 5.039999999999964s
#
# 921
# Epoch duration =0.95s
# Cumulative duration =14min 5.990000000000009s
#
# 922
# Epoch duration =0.92s
# Cumulative duration =14min 6.909999999999968s
#
# 923
# Epoch duration =0.93s
# Cumulative duration =14min 7.830000000000041s
#
# 924
# Epoch duration =0.9s
# Cumulative duration =14min 8.740000000000009s
#
# 925
# Epoch duration =0.91s
# Cumulative duration =14min 9.639999999999986s
#
# 926
# Epoch duration =0.91s
# Cumulative duration =14min 10.549999999999955s
#
# 927
# Epoch duration =0.91s
# Cumulative duration =14min 11.460000000000036s
#
# 928
# Epoch duration =0.91s
# Cumulative duration =14min 12.370000000000005s
#
# 929
# Epoch duration =0.95s
# Cumulative duration =14min 13.32000000000005s
#
# 930
# Epoch duration =0.9s
# Cumulative duration =14min 14.220000000000027s
#
# 931
# Epoch duration =0.99s
# Cumulative duration =14min 15.210000000000036s
#
# 932
# Epoch duration =0.91s
# Cumulative duration =14min 16.120000000000005s
#
# 933
# Epoch duration =0.91s
# Cumulative duration =14min 17.029999999999973s
#
# 934
# Epoch duration =0.91s
# Cumulative duration =14min 17.940000000000055s
#
# 935
# Epoch duration =0.91s
# Cumulative duration =14min 18.860000000000014s
#
# 936
# Epoch duration =0.91s
# Cumulative duration =14min 19.769999999999982s
#
# 937
# Epoch duration =0.92s
# Cumulative duration =14min 20.67999999999995s
#
# 938
# Epoch duration =0.91s
# Cumulative duration =14min 21.590000000000032s
#
# 939
# Epoch duration =0.91s
# Cumulative duration =14min 22.50999999999999s
#
# 940
# Epoch duration =0.9s
# Cumulative duration =14min 23.409999999999968s
#
# 941
# Epoch duration =0.91s
# Cumulative duration =14min 24.33000000000004s
#
# 942
# Epoch duration =0.94s
# Cumulative duration =14min 25.25999999999999s
#
# 943
# Epoch duration =0.92s
# Cumulative duration =14min 26.190000000000055s
#
# 944
# Epoch duration =0.9s
# Cumulative duration =14min 27.090000000000032s
#
# 945
# Epoch duration =0.95s
# Cumulative duration =14min 28.039999999999964s
#
# 946
# Epoch duration =0.91s
# Cumulative duration =14min 28.950000000000045s
#
# 947
# Epoch duration =0.95s
# Cumulative duration =14min 29.899999999999977s
#
# 948
# Epoch duration =0.91s
# Cumulative duration =14min 30.809999999999945s
#
# 949
# Epoch duration =0.91s
# Cumulative duration =14min 31.730000000000018s
#
# 950
# Epoch duration =0.9s
# Cumulative duration =14min 32.629999999999995s
#
# 951
# Epoch duration =0.91s
# Cumulative duration =14min 33.539999999999964s
#
# 952
# Epoch duration =0.91s
# Cumulative duration =14min 34.450000000000045s
#
# 953
# Epoch duration =0.94s
# Cumulative duration =14min 35.389999999999986s
#
# 954
# Epoch duration =0.91s
# Cumulative duration =14min 36.299999999999955s
#
# 955
# Epoch duration =0.91s
# Cumulative duration =14min 37.210000000000036s
#
# 956
# Epoch duration =0.9s
# Cumulative duration =14min 38.110000000000014s
#
# 957
# Epoch duration =0.91s
# Cumulative duration =14min 39.02999999999997s
#
# 958
# Epoch duration =0.91s
# Cumulative duration =14min 39.940000000000055s
#
# 959
# Epoch duration =0.92s
# Cumulative duration =14min 40.860000000000014s
#
# 960
# Epoch duration =0.94s
# Cumulative duration =14min 41.799999999999955s
#
# 961
# Epoch duration =0.91s
# Cumulative duration =14min 42.72000000000003s
#
# 962
# Epoch duration =0.91s
# Cumulative duration =14min 43.620000000000005s
#
# 963
# Epoch duration =0.91s
# Cumulative duration =14min 44.52999999999997s
#
# 964
# Epoch duration =0.91s
# Cumulative duration =14min 45.440000000000055s
#
# 965
# Epoch duration =0.91s
# Cumulative duration =14min 46.35000000000002s
#
# 966
# Epoch duration =0.92s
# Cumulative duration =14min 47.26999999999998s
#
# 967
# Epoch duration =0.91s
# Cumulative duration =14min 48.17999999999995s
#
# 968
# Epoch duration =0.9s
# Cumulative duration =14min 49.08000000000004s
#
# 969
# Epoch duration =0.92s
# Cumulative duration =14min 50.00999999999999s
#
# 970
# Epoch duration =0.91s
# Cumulative duration =14min 50.91999999999996s
#
# 971
# Epoch duration =0.97s
# Cumulative duration =14min 51.879999999999995s
#
# 972
# Epoch duration =0.91s
# Cumulative duration =14min 52.799999999999955s
#
# 973
# Epoch duration =0.96s
# Cumulative duration =14min 53.75s
#
# 974
# Epoch duration =0.9s
# Cumulative duration =14min 54.65999999999997s
#
# 975
# Epoch duration =0.91s
# Cumulative duration =14min 55.57000000000005s
#
# 976
# Epoch duration =0.92s
# Cumulative duration =14min 56.48000000000002s
#
# 977
# Epoch duration =0.92s
# Cumulative duration =14min 57.40999999999997s
#
# 978
# Epoch duration =0.92s
# Cumulative duration =14min 58.32000000000005s
#
# 979
# Epoch duration =0.92s
# Cumulative duration =14min 59.24000000000001s
#
# 980
# Epoch duration =0.89s
# Cumulative duration =15min 0.12999999999999545s
#
# 981
# Epoch duration =0.92s
# Cumulative duration =15min 1.0499999999999545s
#
# 982
# Epoch duration =0.91s
# Cumulative duration =15min 1.9600000000000364s
#
# 983
# Epoch duration =0.91s
# Cumulative duration =15min 2.8700000000000045s
#
# 984
# Epoch duration =0.9s
# Cumulative duration =15min 3.769999999999982s
#
# 985
# Epoch duration =0.91s
# Cumulative duration =15min 4.690000000000055s
#
# 986
# Epoch duration =0.9s
# Cumulative duration =15min 5.590000000000032s
#
# 987
# Epoch duration =0.95s
# Cumulative duration =15min 6.5499999999999545s
#
# 988
# Epoch duration =0.91s
# Cumulative duration =15min 7.4500000000000455s
#
# 989
# Epoch duration =0.93s
# Cumulative duration =15min 8.379999999999995s
#
# 990
# Epoch duration =0.93s
# Cumulative duration =15min 9.299999999999955s
#
# 991
# Epoch duration =0.92s
# Cumulative duration =15min 10.220000000000027s
#
# 992
# Epoch duration =0.92s
# Cumulative duration =15min 11.139999999999986s
#
# 993
# Epoch duration =0.92s
# Cumulative duration =15min 12.059999999999945s
#
# 994
# Epoch duration =0.9s
# Cumulative duration =15min 12.960000000000036s
#
# 995
# Epoch duration =0.91s
# Cumulative duration =15min 13.870000000000005s
#
# 996
# Epoch duration =0.91s
# Cumulative duration =15min 14.779999999999973s
#
# 997
# Epoch duration =0.91s
# Cumulative duration =15min 15.690000000000055s
#
# 998
# Epoch duration =0.91s
# Cumulative duration =15min 16.600000000000023s
#
# 999
# Epoch duration =0.91s
# Cumulative duration =15min 17.519999999999982s
#
# Saving scores to Arrays/trna_mlpt2_44 _ug_so1000.npy

# %%
#load values
savepath = 'Arrays/trna_mlpt2_44 _ug_so1000.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, vmax=1.0, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#num_plots=np.linspace(0,20000,5).astype(int)
for ii in range(10): 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    
    norm_heat_mut = mf.fom_heatmap(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, eps=1e-7)
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    norm_heat_mut = np.append(norm_heat_mut, nucpos, axis=0)
    
    
    plt.figure(figsize=(10,1.5))
    plt.title('Sequence score rank: %s' %ii)
    sb.heatmap(norm_heat_mut, vmin=0, vmax=1, yticklabels=['A', 'C', 'G', 'U', 'Gap'])

# %%
len(SS)
# Out:
# 513

# %%
top_neurons=np.argsort(np.squeeze(nnmodel.get_parameters(sess, layer='dense_1')[0]))[::-1]

dense = nntrainer.get_activations(sess, test, layer='dense_0_active')
W = nnmodel.get_parameters(sess, layer='dense_0')[0]
W = W.reshape((seqlen,4,dense.shape[1]))

fig = plt.figure(figsize=(10,50))
for neuron in range(44):
    ax = fig.add_subplot(44,1,neuron+1)
    ax = sb.heatmap(W[:, :, top_neurons[neuron]].T)
