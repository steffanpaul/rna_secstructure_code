# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/riboswitch_100k_d3.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 10.15s

# %%
simalign_file = '../../../data_RFAM/riboswitch_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<>>>>>><<<<<<<<<>>>>>>>>>)))))<<<<>>>>'

# %%
ugSS
# Out:
# ':::::(((((,,,,<-<<<<<____>>>>>><<<--<<<<<<______>>>->>>->>>,,,,,)))))-<<<<____>>>>::::::::::::::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/riboswitch'
param_path = os.path.join(save_path, 'mlp_t1_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 816, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.37727 -- acc=82.184178%
#
#   valid loss:		0.14793
#   valid accuracy:	0.96395+/-0.00000
#   valid auc-roc:	0.99768+/-0.00000
#   valid auc-pr:		0.99762+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.17981 -- acc=93.118342%
#
#   valid loss:		0.07637
#   valid accuracy:	0.97950+/-0.00000
#   valid auc-roc:	0.99930+/-0.00000
#   valid auc-pr:		0.99927+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.13638 -- acc=94.845845%
#
#   valid loss:		0.05335
#   valid accuracy:	0.99055+/-0.00000
#   valid auc-roc:	0.99952+/-0.00000
#   valid auc-pr:		0.99938+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.75s -- loss=0.11769 -- acc=95.751675%
#
#   valid loss:		0.04377
#   valid accuracy:	0.99260+/-0.00000
#   valid auc-roc:	0.99963+/-0.00000
#   valid auc-pr:		0.99961+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.10893 -- acc=96.169177%
#
#   valid loss:		0.03999
#   valid accuracy:	0.99250+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99969+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.57s -- loss=0.10498 -- acc=96.337504%
#
#   valid loss:		0.03764
#   valid accuracy:	0.99420+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99967+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.10065 -- acc=96.596670%
#
#   valid loss:		0.03948
#   valid accuracy:	0.99300+/-0.00000
#   valid auc-roc:	0.99971+/-0.00000
#   valid auc-pr:		0.99968+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.09751 -- acc=96.690849%
#
#   valid loss:		0.03845
#   valid accuracy:	0.99095+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.45s -- loss=0.09605 -- acc=96.786679%
#
#   valid loss:		0.03507
#   valid accuracy:	0.99415+/-0.00000
#   valid auc-roc:	0.99973+/-0.00000
#   valid auc-pr:		0.99972+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.56s -- loss=0.09117 -- acc=96.959176%
#
#   valid loss:		0.03420
#   valid accuracy:	0.99520+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.09211 -- acc=97.020002%
#
#   valid loss:		0.03679
#   valid accuracy:	0.99520+/-0.00000
#   valid auc-roc:	0.99972+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.08967 -- acc=97.123342%
#
#   valid loss:		0.03710
#   valid accuracy:	0.99245+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.45s -- loss=0.08978 -- acc=97.258346%
#
#   valid loss:		0.03718
#   valid accuracy:	0.99320+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.08910 -- acc=97.245845%
#
#   valid loss:		0.03458
#   valid accuracy:	0.99465+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.08851 -- acc=97.277508%
#
#   valid loss:		0.03749
#   valid accuracy:	0.99235+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.08836 -- acc=97.320842%
#
#   valid loss:		0.03524
#   valid accuracy:	0.99460+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.08654 -- acc=97.438344%
#
#   valid loss:		0.03401
#   valid accuracy:	0.99555+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.51s -- loss=0.08756 -- acc=97.438344%
#
#   valid loss:		0.03762
#   valid accuracy:	0.99330+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.08511 -- acc=97.486679%
#
#   valid loss:		0.03451
#   valid accuracy:	0.99430+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.45s -- loss=0.08520 -- acc=97.513331%
#
#   valid loss:		0.03619
#   valid accuracy:	0.99365+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99977+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.46s -- loss=0.08496 -- acc=97.515842%
#
#   valid loss:		0.03650
#   valid accuracy:	0.99420+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.08457 -- acc=97.553345%
#
#   valid loss:		0.03342
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.08412 -- acc=97.621672%
#
#   valid loss:		0.03436
#   valid accuracy:	0.99500+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.45s -- loss=0.08707 -- acc=97.455846%
#
#   valid loss:		0.03505
#   valid accuracy:	0.99495+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.08697 -- acc=97.431673%
#
#   valid loss:		0.03521
#   valid accuracy:	0.99530+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.50s -- loss=0.08450 -- acc=97.562506%
#
#   valid loss:		0.03496
#   valid accuracy:	0.99515+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.52s -- loss=0.08263 -- acc=97.720002%
#
#   valid loss:		0.03518
#   valid accuracy:	0.99535+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.47s -- loss=0.08471 -- acc=97.575838%
#
#   valid loss:		0.03375
#   valid accuracy:	0.99545+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.50s -- loss=0.08423 -- acc=97.585009%
#
#   valid loss:		0.03393
#   valid accuracy:	0.99585+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.41s -- loss=0.08547 -- acc=97.630833%
#
#   valid loss:		0.03515
#   valid accuracy:	0.99505+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.47s -- loss=0.08548 -- acc=97.588349%
#
#   valid loss:		0.03734
#   valid accuracy:	0.99470+/-0.00000
#   valid auc-roc:	0.99977+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.42s -- loss=0.08444 -- acc=97.612501%
#
#   valid loss:		0.03614
#   valid accuracy:	0.99515+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.44s -- loss=0.08079 -- acc=97.767507%
#
#   valid loss:		0.03521
#   valid accuracy:	0.99520+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.08233 -- acc=97.699170%
#
#   valid loss:		0.03566
#   valid accuracy:	0.99495+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.48s -- loss=0.08486 -- acc=97.678338%
#
#   valid loss:		0.03610
#   valid accuracy:	0.99545+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.43s -- loss=0.08486 -- acc=97.664176%
#
#   valid loss:		0.03608
#   valid accuracy:	0.99460+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.49s -- loss=0.08407 -- acc=97.687509%
#
#   valid loss:		0.03508
#   valid accuracy:	0.99465+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=4.25s -- loss=0.08476 -- acc=97.699170%
#
#   valid loss:		0.03646
#   valid accuracy:	0.99505+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=4.23s -- loss=0.08575 -- acc=97.600000%
#
#   valid loss:		0.03485
#   valid accuracy:	0.99565+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.08425 -- acc=97.713331%
#
#   valid loss:		0.03611
#   valid accuracy:	0.99565+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.08594 -- acc=97.666677%
#
#   valid loss:		0.03535
#   valid accuracy:	0.99570+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.08490 -- acc=97.693339%
#
#   valid loss:		0.03428
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.08304 -- acc=97.742504%
#
#   valid loss:		0.03540
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.08517 -- acc=97.693339%
#
#   valid loss:		0.03656
#   valid accuracy:	0.99525+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.08391 -- acc=97.686679%
#
#   valid loss:		0.03586
#   valid accuracy:	0.99530+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.08546 -- acc=97.668337%
#
#   valid loss:		0.03789
#   valid accuracy:	0.99435+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.08406 -- acc=97.741674%
#
#   valid loss:		0.03596
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.08386 -- acc=97.790839%
#
#   valid loss:		0.03665
#   valid accuracy:	0.99475+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.08408 -- acc=97.697500%
#
#   valid loss:		0.03847
#   valid accuracy:	0.99445+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.08264 -- acc=97.748335%
#
#   valid loss:		0.03636
#   valid accuracy:	0.99535+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.08399 -- acc=97.683338%
#
#   valid loss:		0.03806
#   valid accuracy:	0.99460+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.08555 -- acc=97.621672%
#
#   valid loss:		0.03524
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.08317 -- acc=97.744174%
#
#   valid loss:		0.03686
#   valid accuracy:	0.99540+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.08235 -- acc=97.774177%
#
#   valid loss:		0.03611
#   valid accuracy:	0.99595+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.08393 -- acc=97.751675%
#
#   valid loss:		0.03577
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.08358 -- acc=97.800000%
#
#   valid loss:		0.03506
#   valid accuracy:	0.99585+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.08206 -- acc=97.814171%
#
#   valid loss:		0.03539
#   valid accuracy:	0.99565+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.08421 -- acc=97.732503%
#
#   valid loss:		0.03754
#   valid accuracy:	0.99520+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.08312 -- acc=97.785839%
#
#   valid loss:		0.04090
#   valid accuracy:	0.99325+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.08480 -- acc=97.746675%
#
#   valid loss:		0.03863
#   valid accuracy:	0.99505+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.08390 -- acc=97.742504%
#
#   valid loss:		0.03751
#   valid accuracy:	0.99470+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.08415 -- acc=97.770837%
#
#   valid loss:		0.04142
#   valid accuracy:	0.99325+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/riboswitch/mlp_t1_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/riboswitch/mlp_t1_44_best.ckpt
#   test  loss:		0.03278
#   test  accuracy:	0.99563+/-0.00000
#   test  auc-roc:	0.99986+/-0.00000
#   test  auc-pr:		0.99985+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/riboswitch_mlpt1_44_ug_so1k.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =2.33s
# Cumulative duration =2.33s
#
# 1
# Epoch duration =2.36s
# Cumulative duration =4.69s
#
# 2
# Epoch duration =2.37s
# Cumulative duration =7.06s
#
# 3
# Epoch duration =2.38s
# Cumulative duration =9.44s
#
# 4
# Epoch duration =2.33s
# Cumulative duration =11.78s
#
# 5
# Epoch duration =2.35s
# Cumulative duration =14.13s
#
# 6
# Epoch duration =2.33s
# Cumulative duration =16.46s
#
# 7
# Epoch duration =2.31s
# Cumulative duration =18.77s
#
# 8
# Epoch duration =2.32s
# Cumulative duration =21.09s
#
# 9
# Epoch duration =2.35s
# Cumulative duration =23.44s
#
# 10
# Epoch duration =2.32s
# Cumulative duration =25.76s
#
# 11
# Epoch duration =2.32s
# Cumulative duration =28.08s
#
# 12
# Epoch duration =2.33s
# Cumulative duration =30.41s
#
# 13
# Epoch duration =2.34s
# Cumulative duration =32.75s
#
# 14
# Epoch duration =2.35s
# Cumulative duration =35.1s
#
# 15
# Epoch duration =2.33s
# Cumulative duration =37.42s
#
# 16
# Epoch duration =2.35s
# Cumulative duration =39.77s
#
# 17
# Epoch duration =2.45s
# Cumulative duration =42.23s
#
# 18
# Epoch duration =2.36s
# Cumulative duration =44.58s
#
# 19
# Epoch duration =2.33s
# Cumulative duration =46.91s
#
# 20
# Epoch duration =2.36s
# Cumulative duration =49.27s
#
# 21
# Epoch duration =2.33s
# Cumulative duration =51.6s
#
# 22
# Epoch duration =2.32s
# Cumulative duration =53.93s
#
# 23
# Epoch duration =2.32s
# Cumulative duration =56.25s
#
# 24
# Epoch duration =2.33s
# Cumulative duration =58.58s
#
# 25
# Epoch duration =2.34s
# Cumulative duration =1min 0.9200000000000017s
#
# 26
# Epoch duration =2.33s
# Cumulative duration =1min 3.259999999999998s
#
# 27
# Epoch duration =2.32s
# Cumulative duration =1min 5.569999999999993s
#
# 28
# Epoch duration =2.32s
# Cumulative duration =1min 7.890000000000001s
#
# 29
# Epoch duration =2.35s
# Cumulative duration =1min 10.239999999999995s
#
# 30
# Epoch duration =2.35s
# Cumulative duration =1min 12.599999999999994s
#
# 31
# Epoch duration =2.32s
# Cumulative duration =1min 14.909999999999997s
#
# 32
# Epoch duration =2.36s
# Cumulative duration =1min 17.269999999999996s
#
# 33
# Epoch duration =2.38s
# Cumulative duration =1min 19.650000000000006s
#
# 34
# Epoch duration =2.32s
# Cumulative duration =1min 21.97s
#
# 35
# Epoch duration =2.35s
# Cumulative duration =1min 24.319999999999993s
#
# 36
# Epoch duration =2.42s
# Cumulative duration =1min 26.739999999999995s
#
# 37
# Epoch duration =2.39s
# Cumulative duration =1min 29.129999999999995s
#
# 38
# Epoch duration =2.34s
# Cumulative duration =1min 31.47s
#
# 39
# Epoch duration =2.32s
# Cumulative duration =1min 33.790000000000006s
#
# 40
# Epoch duration =2.34s
# Cumulative duration =1min 36.129999999999995s
#
# 41
# Epoch duration =2.34s
# Cumulative duration =1min 38.480000000000004s
#
# 42
# Epoch duration =2.31s
# Cumulative duration =1min 40.790000000000006s
#
# 43
# Epoch duration =2.34s
# Cumulative duration =1min 43.120000000000005s
#
# 44
# Epoch duration =2.33s
# Cumulative duration =1min 45.459999999999994s
#
# 45
# Epoch duration =2.36s
# Cumulative duration =1min 47.81999999999999s
#
# 46
# Epoch duration =2.33s
# Cumulative duration =1min 50.150000000000006s
#
# 47
# Epoch duration =2.32s
# Cumulative duration =1min 52.459999999999994s
#
# 48
# Epoch duration =2.36s
# Cumulative duration =1min 54.83s
#
# 49
# Epoch duration =2.33s
# Cumulative duration =1min 57.150000000000006s
#
# 50
# Epoch duration =2.33s
# Cumulative duration =1min 59.480000000000004s
#
# 51
# Epoch duration =2.33s
# Cumulative duration =2min 1.8199999999999932s
#
# 52
# Epoch duration =2.34s
# Cumulative duration =2min 4.150000000000006s
#
# 53
# Epoch duration =2.37s
# Cumulative duration =2min 6.530000000000001s
#
# 54
# Epoch duration =2.33s
# Cumulative duration =2min 8.849999999999994s
#
# 55
# Epoch duration =2.34s
# Cumulative duration =2min 11.199999999999989s
#
# 56
# Epoch duration =2.34s
# Cumulative duration =2min 13.539999999999992s
#
# 57
# Epoch duration =2.33s
# Cumulative duration =2min 15.870000000000005s
#
# 58
# Epoch duration =2.34s
# Cumulative duration =2min 18.210000000000008s
#
# 59
# Epoch duration =2.32s
# Cumulative duration =2min 20.53s
#
# 60
# Epoch duration =2.32s
# Cumulative duration =2min 22.849999999999994s
#
# 61
# Epoch duration =2.34s
# Cumulative duration =2min 25.189999999999998s
#
# 62
# Epoch duration =2.35s
# Cumulative duration =2min 27.539999999999992s
#
# 63
# Epoch duration =2.35s
# Cumulative duration =2min 29.889999999999986s
#
# 64
# Epoch duration =2.33s
# Cumulative duration =2min 32.22s
#
# 65
# Epoch duration =2.35s
# Cumulative duration =2min 34.56999999999999s
#
# 66
# Epoch duration =2.34s
# Cumulative duration =2min 36.91s
#
# 67
# Epoch duration =2.32s
# Cumulative duration =2min 39.24000000000001s
#
# 68
# Epoch duration =2.32s
# Cumulative duration =2min 41.56s
#
# 69
# Epoch duration =2.39s
# Cumulative duration =2min 43.94999999999999s
#
# 70
# Epoch duration =2.36s
# Cumulative duration =2min 46.31s
#
# 71
# Epoch duration =2.36s
# Cumulative duration =2min 48.68000000000001s
#
# 72
# Epoch duration =2.33s
# Cumulative duration =2min 51.00999999999999s
#
# 73
# Epoch duration =2.34s
# Cumulative duration =2min 53.349999999999994s
#
# 74
# Epoch duration =2.32s
# Cumulative duration =2min 55.66999999999999s
#
# 75
# Epoch duration =2.33s
# Cumulative duration =2min 57.99000000000001s
#
# 76
# Epoch duration =2.32s
# Cumulative duration =3min 0.3199999999999932s
#
# 77
# Epoch duration =2.34s
# Cumulative duration =3min 2.6599999999999966s
#
# 78
# Epoch duration =2.35s
# Cumulative duration =3min 5.0s
#
# 79
# Epoch duration =2.32s
# Cumulative duration =3min 7.319999999999993s
#
# 80
# Epoch duration =2.32s
# Cumulative duration =3min 9.639999999999986s
#
# 81
# Epoch duration =2.35s
# Cumulative duration =3min 11.990000000000009s
#
# 82
# Epoch duration =2.32s
# Cumulative duration =3min 14.310000000000002s
#
# 83
# Epoch duration =2.34s
# Cumulative duration =3min 16.650000000000006s
#
# 84
# Epoch duration =2.33s
# Cumulative duration =3min 18.97999999999999s
#
# 85
# Epoch duration =2.32s
# Cumulative duration =3min 21.30000000000001s
#
# 86
# Epoch duration =2.33s
# Cumulative duration =3min 23.639999999999986s
#
# 87
# Epoch duration =2.35s
# Cumulative duration =3min 25.99000000000001s
#
# 88
# Epoch duration =2.37s
# Cumulative duration =3min 28.360000000000014s
#
# 89
# Epoch duration =2.36s
# Cumulative duration =3min 30.72s
#
# 90
# Epoch duration =2.35s
# Cumulative duration =3min 33.06999999999999s
#
# 91
# Epoch duration =2.36s
# Cumulative duration =3min 35.43000000000001s
#
# 92
# Epoch duration =2.33s
# Cumulative duration =3min 37.75999999999999s
#
# 93
# Epoch duration =2.32s
# Cumulative duration =3min 40.09s
#
# 94
# Epoch duration =2.38s
# Cumulative duration =3min 42.47s
#
# 95
# Epoch duration =2.36s
# Cumulative duration =3min 44.81999999999999s
#
# 96
# Epoch duration =2.35s
# Cumulative duration =3min 47.16999999999999s
#
# 97
# Epoch duration =2.34s
# Cumulative duration =3min 49.50999999999999s
#
# 98
# Epoch duration =2.35s
# Cumulative duration =3min 51.870000000000005s
#
# 99
# Epoch duration =2.34s
# Cumulative duration =3min 54.21000000000001s
#
# 100
# Epoch duration =2.35s
# Cumulative duration =3min 56.56s
#
# 101
# Epoch duration =2.34s
# Cumulative duration =3min 58.900000000000006s
#
# 102
# Epoch duration =2.4s
# Cumulative duration =4min 1.3100000000000023s
#
# 103
# Epoch duration =2.32s
# Cumulative duration =4min 3.6299999999999955s
#
# 104
# Epoch duration =2.33s
# Cumulative duration =4min 5.960000000000008s
#
# 105
# Epoch duration =2.33s
# Cumulative duration =4min 8.289999999999992s
#
# 106
# Epoch duration =2.32s
# Cumulative duration =4min 10.610000000000014s
#
# 107
# Epoch duration =2.35s
# Cumulative duration =4min 12.960000000000008s
#
# 108
# Epoch duration =2.33s
# Cumulative duration =4min 15.280000000000001s
#
# 109
# Epoch duration =2.34s
# Cumulative duration =4min 17.629999999999995s
#
# 110
# Epoch duration =2.34s
# Cumulative duration =4min 19.95999999999998s
#
# 111
# Epoch duration =2.39s
# Cumulative duration =4min 22.350000000000023s
#
# 112
# Epoch duration =2.34s
# Cumulative duration =4min 24.689999999999998s
#
# 113
# Epoch duration =2.38s
# Cumulative duration =4min 27.079999999999984s
#
# 114
# Epoch duration =2.34s
# Cumulative duration =4min 29.420000000000016s
#
# 115
# Epoch duration =2.32s
# Cumulative duration =4min 31.75s
#
# 116
# Epoch duration =2.34s
# Cumulative duration =4min 34.089999999999975s
#
# 117
# Epoch duration =2.34s
# Cumulative duration =4min 36.43000000000001s
#
# 118
# Epoch duration =2.37s
# Cumulative duration =4min 38.80000000000001s
#
# 119
# Epoch duration =2.34s
# Cumulative duration =4min 41.139999999999986s
#
# 120
# Epoch duration =2.34s
# Cumulative duration =4min 43.48000000000002s
#
# 121
# Epoch duration =2.32s
# Cumulative duration =4min 45.80000000000001s
#
# 122
# Epoch duration =2.33s
# Cumulative duration =4min 48.129999999999995s
#
# 123
# Epoch duration =2.32s
# Cumulative duration =4min 50.44999999999999s
#
# 124
# Epoch duration =2.34s
# Cumulative duration =4min 52.79000000000002s
#
# 125
# Epoch duration =2.33s
# Cumulative duration =4min 55.120000000000005s
#
# 126
# Epoch duration =2.33s
# Cumulative duration =4min 57.45999999999998s
#
# 127
# Epoch duration =2.32s
# Cumulative duration =4min 59.77999999999997s
#
# 128
# Epoch duration =2.35s
# Cumulative duration =5min 2.1299999999999955s
#
# 129
# Epoch duration =2.34s
# Cumulative duration =5min 4.470000000000027s
#
# 130
# Epoch duration =2.33s
# Cumulative duration =5min 6.7900000000000205s
#
# 131
# Epoch duration =2.35s
# Cumulative duration =5min 9.139999999999986s
#
# 132
# Epoch duration =2.35s
# Cumulative duration =5min 11.480000000000018s
#
# 133
# Epoch duration =2.37s
# Cumulative duration =5min 13.860000000000014s
#
# 134
# Epoch duration =2.35s
# Cumulative duration =5min 16.20999999999998s
#
# 135
# Epoch duration =2.38s
# Cumulative duration =5min 18.589999999999975s
#
# 136
# Epoch duration =2.33s
# Cumulative duration =5min 20.910000000000025s
#
# 137
# Epoch duration =2.36s
# Cumulative duration =5min 23.269999999999982s
#
# 138
# Epoch duration =2.35s
# Cumulative duration =5min 25.620000000000005s
#
# 139
# Epoch duration =2.31s
# Cumulative duration =5min 27.930000000000007s
#
# 140
# Epoch duration =2.35s
# Cumulative duration =5min 30.279999999999973s
#
# 141
# Epoch duration =2.35s
# Cumulative duration =5min 32.629999999999995s
#
# 142
# Epoch duration =2.33s
# Cumulative duration =5min 34.95999999999998s
#
# 143
# Epoch duration =2.31s
# Cumulative duration =5min 37.26999999999998s
#
# 144
# Epoch duration =2.33s
# Cumulative duration =5min 39.60000000000002s
#
# 145
# Epoch duration =2.35s
# Cumulative duration =5min 41.94999999999999s
#
# 146
# Epoch duration =2.35s
# Cumulative duration =5min 44.30000000000001s
#
# 147
# Epoch duration =2.32s
# Cumulative duration =5min 46.620000000000005s
#
# 148
# Epoch duration =2.36s
# Cumulative duration =5min 48.98000000000002s
#
# 149
# Epoch duration =2.35s
# Cumulative duration =5min 51.329999999999984s
#
# 150
# Epoch duration =2.35s
# Cumulative duration =5min 53.68000000000001s
#
# 151
# Epoch duration =2.33s
# Cumulative duration =5min 56.00999999999999s
#
# 152
# Epoch duration =2.36s
# Cumulative duration =5min 58.370000000000005s
#
# 153
# Epoch duration =2.36s
# Cumulative duration =6min 0.7300000000000182s
#
# 154
# Epoch duration =2.33s
# Cumulative duration =6min 3.0600000000000023s
#
# 155
# Epoch duration =2.35s
# Cumulative duration =6min 5.410000000000025s
#
# 156
# Epoch duration =2.31s
# Cumulative duration =6min 7.720000000000027s
#
# 157
# Epoch duration =2.35s
# Cumulative duration =6min 10.069999999999993s
#
# 158
# Epoch duration =2.35s
# Cumulative duration =6min 12.430000000000007s
#
# 159
# Epoch duration =2.31s
# Cumulative duration =6min 14.740000000000009s
#
# 160
# Epoch duration =2.34s
# Cumulative duration =6min 17.079999999999984s
#
# 161
# Epoch duration =2.33s
# Cumulative duration =6min 19.399999999999977s
#
# 162
# Epoch duration =2.34s
# Cumulative duration =6min 21.75s
#
# 163
# Epoch duration =2.34s
# Cumulative duration =6min 24.089999999999975s
#
# 164
# Epoch duration =2.4s
# Cumulative duration =6min 26.49000000000001s
#
# 165
# Epoch duration =2.35s
# Cumulative duration =6min 28.839999999999975s
#
# 166
# Epoch duration =2.33s
# Cumulative duration =6min 31.170000000000016s
#
# 167
# Epoch duration =2.33s
# Cumulative duration =6min 33.5s
#
# 168
# Epoch duration =2.36s
# Cumulative duration =6min 35.860000000000014s
#
# 169
# Epoch duration =2.35s
# Cumulative duration =6min 38.20999999999998s
#
# 170
# Epoch duration =2.34s
# Cumulative duration =6min 40.55000000000001s
#
# 171
# Epoch duration =2.35s
# Cumulative duration =6min 42.89999999999998s
#
# 172
# Epoch duration =2.31s
# Cumulative duration =6min 45.20999999999998s
#
# 173
# Epoch duration =2.34s
# Cumulative duration =6min 47.55000000000001s
#
# 174
# Epoch duration =2.35s
# Cumulative duration =6min 49.89999999999998s
#
# 175
# Epoch duration =2.34s
# Cumulative duration =6min 52.24000000000001s
#
# 176
# Epoch duration =2.33s
# Cumulative duration =6min 54.56999999999999s
#
# 177
# Epoch duration =2.31s
# Cumulative duration =6min 56.889999999999986s
#
# 178
# Epoch duration =2.36s
# Cumulative duration =6min 59.25s
#
# 179
# Epoch duration =2.32s
# Cumulative duration =7min 1.5699999999999932s
#
# 180
# Epoch duration =2.33s
# Cumulative duration =7min 3.8999999999999773s
#
# 181
# Epoch duration =2.34s
# Cumulative duration =7min 6.240000000000009s
#
# 182
# Epoch duration =2.33s
# Cumulative duration =7min 8.569999999999993s
#
# 183
# Epoch duration =2.39s
# Cumulative duration =7min 10.949999999999989s
#
# 184
# Epoch duration =2.32s
# Cumulative duration =7min 13.279999999999973s
#
# 185
# Epoch duration =2.33s
# Cumulative duration =7min 15.610000000000014s
#
# 186
# Epoch duration =2.32s
# Cumulative duration =7min 17.939999999999998s
#
# 187
# Epoch duration =2.34s
# Cumulative duration =7min 20.279999999999973s
#
# 188
# Epoch duration =2.32s
# Cumulative duration =7min 22.600000000000023s
#
# 189
# Epoch duration =2.36s
# Cumulative duration =7min 24.95999999999998s
#
# 190
# Epoch duration =2.4s
# Cumulative duration =7min 27.360000000000014s
#
# 191
# Epoch duration =2.33s
# Cumulative duration =7min 29.689999999999998s
#
# 192
# Epoch duration =2.31s
# Cumulative duration =7min 32.0s
#
# 193
# Epoch duration =2.32s
# Cumulative duration =7min 34.31999999999999s
#
# 194
# Epoch duration =2.35s
# Cumulative duration =7min 36.670000000000016s
#
# 195
# Epoch duration =2.37s
# Cumulative duration =7min 39.04000000000002s
#
# 196
# Epoch duration =2.33s
# Cumulative duration =7min 41.370000000000005s
#
# 197
# Epoch duration =2.34s
# Cumulative duration =7min 43.70999999999998s
#
# 198
# Epoch duration =2.34s
# Cumulative duration =7min 46.04000000000002s
#
# 199
# Epoch duration =2.32s
# Cumulative duration =7min 48.360000000000014s
#
# 200
# Epoch duration =2.34s
# Cumulative duration =7min 50.69999999999999s
#
# 201
# Epoch duration =2.32s
# Cumulative duration =7min 53.01999999999998s
#
# 202
# Epoch duration =2.36s
# Cumulative duration =7min 55.379999999999995s
#
# 203
# Epoch duration =2.34s
# Cumulative duration =7min 57.72000000000003s
#
# 204
# Epoch duration =2.34s
# Cumulative duration =8min 0.060000000000002274s
#
# 205
# Epoch duration =2.32s
# Cumulative duration =8min 2.3799999999999955s
#
# 206
# Epoch duration =2.32s
# Cumulative duration =8min 4.699999999999989s
#
# 207
# Epoch duration =2.34s
# Cumulative duration =8min 7.0400000000000205s
#
# 208
# Epoch duration =2.34s
# Cumulative duration =8min 9.389999999999986s
#
# 209
# Epoch duration =2.35s
# Cumulative duration =8min 11.740000000000009s
#
# 210
# Epoch duration =2.36s
# Cumulative duration =8min 14.100000000000023s
#
# 211
# Epoch duration =2.33s
# Cumulative duration =8min 16.430000000000007s
#
# 212
# Epoch duration =2.32s
# Cumulative duration =8min 18.75s
#
# 213
# Epoch duration =2.32s
# Cumulative duration =8min 21.069999999999993s
#
# 214
# Epoch duration =2.33s
# Cumulative duration =8min 23.399999999999977s
#
# 215
# Epoch duration =2.34s
# Cumulative duration =8min 25.74000000000001s
#
# 216
# Epoch duration =2.34s
# Cumulative duration =8min 28.079999999999984s
#
# 217
# Epoch duration =2.35s
# Cumulative duration =8min 30.430000000000007s
#
# 218
# Epoch duration =2.39s
# Cumulative duration =8min 32.82000000000005s
#
# 219
# Epoch duration =2.34s
# Cumulative duration =8min 35.15999999999997s
#
# 220
# Epoch duration =2.32s
# Cumulative duration =8min 37.48000000000002s
#
# 221
# Epoch duration =2.34s
# Cumulative duration =8min 39.82000000000005s
#
# 222
# Epoch duration =2.35s
# Cumulative duration =8min 42.16999999999996s
#
# 223
# Epoch duration =2.36s
# Cumulative duration =8min 44.52999999999997s
#
# 224
# Epoch duration =2.41s
# Cumulative duration =8min 46.940000000000055s
#
# 225
# Epoch duration =2.35s
# Cumulative duration =8min 49.289999999999964s
#
# 226
# Epoch duration =2.33s
# Cumulative duration =8min 51.620000000000005s
#
# 227
# Epoch duration =2.34s
# Cumulative duration =8min 53.960000000000036s
#
# 228
# Epoch duration =2.33s
# Cumulative duration =8min 56.289999999999964s
#
# 229
# Epoch duration =2.35s
# Cumulative duration =8min 58.639999999999986s
#
# 230
# Epoch duration =2.41s
# Cumulative duration =9min 1.0499999999999545s
#
# 231
# Epoch duration =2.34s
# Cumulative duration =9min 3.3899999999999864s
#
# 232
# Epoch duration =2.31s
# Cumulative duration =9min 5.690000000000055s
#
# 233
# Epoch duration =2.31s
# Cumulative duration =9min 8.0s
#
# 234
# Epoch duration =2.33s
# Cumulative duration =9min 10.330000000000041s
#
# 235
# Epoch duration =2.36s
# Cumulative duration =9min 12.690000000000055s
#
# 236
# Epoch duration =2.35s
# Cumulative duration =9min 15.039999999999964s
#
# 237
# Epoch duration =2.37s
# Cumulative duration =9min 17.41999999999996s
#
# 238
# Epoch duration =2.35s
# Cumulative duration =9min 19.769999999999982s
#
# 239
# Epoch duration =2.39s
# Cumulative duration =9min 22.159999999999968s
#
# 240
# Epoch duration =2.38s
# Cumulative duration =9min 24.539999999999964s
#
# 241
# Epoch duration =2.33s
# Cumulative duration =9min 26.870000000000005s
#
# 242
# Epoch duration =2.31s
# Cumulative duration =9min 29.17999999999995s
#
# 243
# Epoch duration =2.34s
# Cumulative duration =9min 31.519999999999982s
#
# 244
# Epoch duration =2.33s
# Cumulative duration =9min 33.85000000000002s
#
# 245
# Epoch duration =2.37s
# Cumulative duration =9min 36.210000000000036s
#
# 246
# Epoch duration =2.33s
# Cumulative duration =9min 38.539999999999964s
#
# 247
# Epoch duration =2.33s
# Cumulative duration =9min 40.870000000000005s
#
# 248
# Epoch duration =2.34s
# Cumulative duration =9min 43.210000000000036s
#
# 249
# Epoch duration =2.37s
# Cumulative duration =9min 45.59000000000003s
#
# 250
# Epoch duration =2.31s
# Cumulative duration =9min 47.89999999999998s
#
# 251
# Epoch duration =2.33s
# Cumulative duration =9min 50.22000000000003s
#
# 252
# Epoch duration =2.35s
# Cumulative duration =9min 52.57000000000005s
#
# 253
# Epoch duration =2.34s
# Cumulative duration =9min 54.90999999999997s
#
# 254
# Epoch duration =2.31s
# Cumulative duration =9min 57.22000000000003s
#
# 255
# Epoch duration =2.32s
# Cumulative duration =9min 59.549999999999955s
#
# 256
# Epoch duration =2.33s
# Cumulative duration =10min 1.8799999999999955s
#
# 257
# Epoch duration =2.33s
# Cumulative duration =10min 4.210000000000036s
#
# 258
# Epoch duration =2.33s
# Cumulative duration =10min 6.539999999999964s
#
# 259
# Epoch duration =2.38s
# Cumulative duration =10min 8.92999999999995s
#
# 260
# Epoch duration =2.33s
# Cumulative duration =10min 11.25s
#
# 261
# Epoch duration =2.34s
# Cumulative duration =10min 13.590000000000032s
#
# 262
# Epoch duration =2.32s
# Cumulative duration =10min 15.909999999999968s
#
# 263
# Epoch duration =2.36s
# Cumulative duration =10min 18.25999999999999s
#
# 264
# Epoch duration =2.31s
# Cumulative duration =10min 20.58000000000004s
#
# 265
# Epoch duration =2.33s
# Cumulative duration =10min 22.909999999999968s
#
# 266
# Epoch duration =2.35s
# Cumulative duration =10min 25.25999999999999s
#
# 267
# Epoch duration =2.34s
# Cumulative duration =10min 27.600000000000023s
#
# 268
# Epoch duration =2.33s
# Cumulative duration =10min 29.92999999999995s
#
# 269
# Epoch duration =2.36s
# Cumulative duration =10min 32.27999999999997s
#
# 270
# Epoch duration =2.33s
# Cumulative duration =10min 34.610000000000014s
#
# 271
# Epoch duration =2.34s
# Cumulative duration =10min 36.950000000000045s
#
# 272
# Epoch duration =2.34s
# Cumulative duration =10min 39.289999999999964s
#
# 273
# Epoch duration =2.35s
# Cumulative duration =10min 41.639999999999986s
#
# 274
# Epoch duration =2.39s
# Cumulative duration =10min 44.01999999999998s
#
# 275
# Epoch duration =2.34s
# Cumulative duration =10min 46.360000000000014s
#
# 276
# Epoch duration =2.34s
# Cumulative duration =10min 48.700000000000045s
#
# 277
# Epoch duration =2.33s
# Cumulative duration =10min 51.039999999999964s
#
# 278
# Epoch duration =2.34s
# Cumulative duration =10min 53.379999999999995s
#
# 279
# Epoch duration =2.34s
# Cumulative duration =10min 55.72000000000003s
#
# 280
# Epoch duration =2.35s
# Cumulative duration =10min 58.07000000000005s
#
# 281
# Epoch duration =2.36s
# Cumulative duration =11min 0.4199999999999591s
#
# 282
# Epoch duration =2.31s
# Cumulative duration =11min 2.730000000000018s
#
# 283
# Epoch duration =2.33s
# Cumulative duration =11min 5.059999999999945s
#
# 284
# Epoch duration =2.33s
# Cumulative duration =11min 7.399999999999977s
#
# 285
# Epoch duration =2.34s
# Cumulative duration =11min 9.740000000000009s
#
# 286
# Epoch duration =2.32s
# Cumulative duration =11min 12.059999999999945s
#
# 287
# Epoch duration =2.32s
# Cumulative duration =11min 14.379999999999995s
#
# 288
# Epoch duration =2.32s
# Cumulative duration =11min 16.690000000000055s
#
# 289
# Epoch duration =2.35s
# Cumulative duration =11min 19.049999999999955s
#
# 290
# Epoch duration =2.32s
# Cumulative duration =11min 21.360000000000014s
#
# 291
# Epoch duration =2.38s
# Cumulative duration =11min 23.74000000000001s
#
# 292
# Epoch duration =2.35s
# Cumulative duration =11min 26.090000000000032s
#
# 293
# Epoch duration =2.35s
# Cumulative duration =11min 28.450000000000045s
#
# 294
# Epoch duration =2.33s
# Cumulative duration =11min 30.769999999999982s
#
# 295
# Epoch duration =2.34s
# Cumulative duration =11min 33.120000000000005s
#
# 296
# Epoch duration =2.34s
# Cumulative duration =11min 35.460000000000036s
#
# 297
# Epoch duration =2.31s
# Cumulative duration =11min 37.75999999999999s
#
# 298
# Epoch duration =2.38s
# Cumulative duration =11min 40.139999999999986s
#
# 299
# Epoch duration =2.32s
# Cumulative duration =11min 42.47000000000003s
#
# 300
# Epoch duration =2.35s
# Cumulative duration =11min 44.82000000000005s
#
# 301
# Epoch duration =2.33s
# Cumulative duration =11min 47.14999999999998s
#
# 302
# Epoch duration =2.32s
# Cumulative duration =11min 49.47000000000003s
#
# 303
# Epoch duration =2.38s
# Cumulative duration =11min 51.84000000000003s
#
# 304
# Epoch duration =2.35s
# Cumulative duration =11min 54.190000000000055s
#
# 305
# Epoch duration =2.36s
# Cumulative duration =11min 56.549999999999955s
#
# 306
# Epoch duration =2.33s
# Cumulative duration =11min 58.879999999999995s
#
# 307
# Epoch duration =2.33s
# Cumulative duration =12min 1.2100000000000364s
#
# 308
# Epoch duration =2.34s
# Cumulative duration =12min 3.5399999999999636s
#
# 309
# Epoch duration =2.35s
# Cumulative duration =12min 5.889999999999986s
#
# 310
# Epoch duration =2.34s
# Cumulative duration =12min 8.240000000000009s
#
# 311
# Epoch duration =2.36s
# Cumulative duration =12min 10.600000000000023s
#
# 312
# Epoch duration =2.34s
# Cumulative duration =12min 12.92999999999995s
#
# 313
# Epoch duration =2.35s
# Cumulative duration =12min 15.279999999999973s
#
# 314
# Epoch duration =2.4s
# Cumulative duration =12min 17.67999999999995s
#
# 315
# Epoch duration =2.39s
# Cumulative duration =12min 20.08000000000004s
#
# 316
# Epoch duration =2.38s
# Cumulative duration =12min 22.460000000000036s
#
# 317
# Epoch duration =2.33s
# Cumulative duration =12min 24.789999999999964s
#
# 318
# Epoch duration =2.33s
# Cumulative duration =12min 27.120000000000005s
#
# 319
# Epoch duration =2.34s
# Cumulative duration =12min 29.470000000000027s
#
# 320
# Epoch duration =2.32s
# Cumulative duration =12min 31.789999999999964s
#
# 321
# Epoch duration =2.32s
# Cumulative duration =12min 34.110000000000014s
#
# 322
# Epoch duration =2.33s
# Cumulative duration =12min 36.440000000000055s
#
# 323
# Epoch duration =2.34s
# Cumulative duration =12min 38.77999999999997s
#
# 324
# Epoch duration =2.37s
# Cumulative duration =12min 41.14999999999998s
#
# 325
# Epoch duration =2.36s
# Cumulative duration =12min 43.50999999999999s
#
# 326
# Epoch duration =2.34s
# Cumulative duration =12min 45.85000000000002s
#
# 327
# Epoch duration =2.34s
# Cumulative duration =12min 48.190000000000055s
#
# 328
# Epoch duration =2.32s
# Cumulative duration =12min 50.51999999999998s
#
# 329
# Epoch duration =2.34s
# Cumulative duration =12min 52.860000000000014s
#
# 330
# Epoch duration =2.38s
# Cumulative duration =12min 55.24000000000001s
#
# 331
# Epoch duration =2.33s
# Cumulative duration =12min 57.58000000000004s
#
# 332
# Epoch duration =2.35s
# Cumulative duration =12min 59.92999999999995s
#
# 333
# Epoch duration =2.33s
# Cumulative duration =13min 2.259999999999991s
#
# 334
# Epoch duration =2.35s
# Cumulative duration =13min 4.610000000000014s
#
# 335
# Epoch duration =2.32s
# Cumulative duration =13min 6.940000000000055s
#
# 336
# Epoch duration =2.33s
# Cumulative duration =13min 9.259999999999991s
#
# 337
# Epoch duration =2.35s
# Cumulative duration =13min 11.610000000000014s
#
# 338
# Epoch duration =2.35s
# Cumulative duration =13min 13.960000000000036s
#
# 339
# Epoch duration =2.35s
# Cumulative duration =13min 16.309999999999945s
#
# 340
# Epoch duration =2.33s
# Cumulative duration =13min 18.639999999999986s
#
# 341
# Epoch duration =2.35s
# Cumulative duration =13min 20.99000000000001s
#
# 342
# Epoch duration =2.36s
# Cumulative duration =13min 23.350000000000023s
#
# 343
# Epoch duration =2.37s
# Cumulative duration =13min 25.720000000000027s
#
# 344
# Epoch duration =2.33s
# Cumulative duration =13min 28.049999999999955s
#
# 345
# Epoch duration =2.34s
# Cumulative duration =13min 30.389999999999986s
#
# 346
# Epoch duration =2.37s
# Cumulative duration =13min 32.75999999999999s
#
# 347
# Epoch duration =2.34s
# Cumulative duration =13min 35.10000000000002s
#
# 348
# Epoch duration =2.33s
# Cumulative duration =13min 37.42999999999995s
#
# 349
# Epoch duration =2.37s
# Cumulative duration =13min 39.789999999999964s
#
# 350
# Epoch duration =2.37s
# Cumulative duration =13min 42.16999999999996s
#
# 351
# Epoch duration =2.33s
# Cumulative duration =13min 44.5s
#
# 352
# Epoch duration =2.35s
# Cumulative duration =13min 46.84000000000003s
#
# 353
# Epoch duration =2.34s
# Cumulative duration =13min 49.17999999999995s
#
# 354
# Epoch duration =2.34s
# Cumulative duration =13min 51.51999999999998s
#
# 355
# Epoch duration =2.35s
# Cumulative duration =13min 53.870000000000005s
#
# 356
# Epoch duration =2.34s
# Cumulative duration =13min 56.200000000000045s
#
# 357
# Epoch duration =2.32s
# Cumulative duration =13min 58.52999999999997s
#
# 358
# Epoch duration =2.42s
# Cumulative duration =14min 0.9500000000000455s
#
# 359
# Epoch duration =2.44s
# Cumulative duration =14min 3.3799999999999955s
#
# 360
# Epoch duration =2.37s
# Cumulative duration =14min 5.759999999999991s
#
# 361
# Epoch duration =2.33s
# Cumulative duration =14min 8.080000000000041s
#
# 362
# Epoch duration =2.34s
# Cumulative duration =14min 10.419999999999959s
#
# 363
# Epoch duration =2.32s
# Cumulative duration =14min 12.740000000000009s
#
# 364
# Epoch duration =2.37s
# Cumulative duration =14min 15.120000000000005s
#
# 365
# Epoch duration =2.36s
# Cumulative duration =14min 17.480000000000018s
#
# 366
# Epoch duration =2.34s
# Cumulative duration =14min 19.82000000000005s
#
# 367
# Epoch duration =2.31s
# Cumulative duration =14min 22.139999999999986s
#
# 368
# Epoch duration =2.34s
# Cumulative duration =14min 24.480000000000018s
#
# 369
# Epoch duration =2.33s
# Cumulative duration =14min 26.799999999999955s
#
# 370
# Epoch duration =2.39s
# Cumulative duration =14min 29.190000000000055s
#
# 371
# Epoch duration =2.34s
# Cumulative duration =14min 31.529999999999973s
#
# 372
# Epoch duration =2.31s
# Cumulative duration =14min 33.85000000000002s
#
# 373
# Epoch duration =2.33s
# Cumulative duration =14min 36.16999999999996s
#
# 374
# Epoch duration =2.35s
# Cumulative duration =14min 38.51999999999998s
#
# 375
# Epoch duration =2.31s
# Cumulative duration =14min 40.83000000000004s
#
# 376
# Epoch duration =2.33s
# Cumulative duration =14min 43.15999999999997s
#
# 377
# Epoch duration =2.36s
# Cumulative duration =14min 45.51999999999998s
#
# 378
# Epoch duration =2.37s
# Cumulative duration =14min 47.89999999999998s
#
# 379
# Epoch duration =2.35s
# Cumulative duration =14min 50.25s
#
# 380
# Epoch duration =2.31s
# Cumulative duration =14min 52.559999999999945s
#
# 381
# Epoch duration =2.32s
# Cumulative duration =14min 54.879999999999995s
#
# 382
# Epoch duration =2.38s
# Cumulative duration =14min 57.25999999999999s
#
# 383
# Epoch duration =2.36s
# Cumulative duration =14min 59.620000000000005s
#
# 384
# Epoch duration =2.33s
# Cumulative duration =15min 1.9400000000000546s
#
# 385
# Epoch duration =2.36s
# Cumulative duration =15min 4.2999999999999545s
#
# 386
# Epoch duration =2.34s
# Cumulative duration =15min 6.639999999999986s
#
# 387
# Epoch duration =2.35s
# Cumulative duration =15min 8.990000000000009s
#
# 388
# Epoch duration =2.36s
# Cumulative duration =15min 11.340000000000032s
#
# 389
# Epoch duration =2.4s
# Cumulative duration =15min 13.740000000000009s
#
# 390
# Epoch duration =2.33s
# Cumulative duration =15min 16.08000000000004s
#
# 391
# Epoch duration =2.34s
# Cumulative duration =15min 18.41999999999996s
#
# 392
# Epoch duration =2.33s
# Cumulative duration =15min 20.75s
#
# 393
# Epoch duration =2.36s
# Cumulative duration =15min 23.110000000000014s
#
# 394
# Epoch duration =2.31s
# Cumulative duration =15min 25.41999999999996s
#
# 395
# Epoch duration =2.33s
# Cumulative duration =15min 27.75s
#
# 396
# Epoch duration =2.33s
# Cumulative duration =15min 30.090000000000032s
#
# 397
# Epoch duration =2.32s
# Cumulative duration =15min 32.40999999999997s
#
# 398
# Epoch duration =2.36s
# Cumulative duration =15min 34.77999999999997s
#
# 399
# Epoch duration =2.33s
# Cumulative duration =15min 37.110000000000014s
#
# 400
# Epoch duration =2.32s
# Cumulative duration =15min 39.42999999999995s
#
# 401
# Epoch duration =2.37s
# Cumulative duration =15min 41.799999999999955s
#
# 402
# Epoch duration =2.44s
# Cumulative duration =15min 44.24000000000001s
#
# 403
# Epoch duration =2.34s
# Cumulative duration =15min 46.58000000000004s
#
# 404
# Epoch duration =2.39s
# Cumulative duration =15min 48.97000000000003s
#
# 405
# Epoch duration =2.36s
# Cumulative duration =15min 51.34000000000003s
#
# 406
# Epoch duration =2.33s
# Cumulative duration =15min 53.65999999999997s
#
# 407
# Epoch duration =2.39s
# Cumulative duration =15min 56.059999999999945s
#
# 408
# Epoch duration =2.32s
# Cumulative duration =15min 58.379999999999995s
#
# 409
# Epoch duration =2.34s
# Cumulative duration =16min 0.7300000000000182s
#
# 410
# Epoch duration =2.35s
# Cumulative duration =16min 3.07000000000005s
#
# 411
# Epoch duration =2.34s
# Cumulative duration =16min 5.419999999999959s
#
# 412
# Epoch duration =2.33s
# Cumulative duration =16min 7.75s
#
# 413
# Epoch duration =2.32s
# Cumulative duration =16min 10.07000000000005s
#
# 414
# Epoch duration =2.33s
# Cumulative duration =16min 12.409999999999968s
#
# 415
# Epoch duration =2.35s
# Cumulative duration =16min 14.759999999999991s
#
# 416
# Epoch duration =2.34s
# Cumulative duration =16min 17.100000000000023s
#
# 417
# Epoch duration =2.34s
# Cumulative duration =16min 19.440000000000055s
#
# 418
# Epoch duration =2.34s
# Cumulative duration =16min 21.779999999999973s
#
# 419
# Epoch duration =2.32s
# Cumulative duration =16min 24.110000000000014s
#
# 420
# Epoch duration =2.41s
# Cumulative duration =16min 26.50999999999999s
#
# 421
# Epoch duration =2.37s
# Cumulative duration =16min 28.879999999999995s
#
# 422
# Epoch duration =2.36s
# Cumulative duration =16min 31.24000000000001s
#
# 423
# Epoch duration =2.32s
# Cumulative duration =16min 33.559999999999945s
#
# 424
# Epoch duration =2.35s
# Cumulative duration =16min 35.90999999999997s
#
# 425
# Epoch duration =2.32s
# Cumulative duration =16min 38.22000000000003s
#
# 426
# Epoch duration =2.33s
# Cumulative duration =16min 40.559999999999945s
#
# 427
# Epoch duration =2.33s
# Cumulative duration =16min 42.879999999999995s
#
# 428
# Epoch duration =2.34s
# Cumulative duration =16min 45.22000000000003s
#
# 429
# Epoch duration =2.34s
# Cumulative duration =16min 47.559999999999945s
#
# 430
# Epoch duration =2.35s
# Cumulative duration =16min 49.91999999999996s
#
# 431
# Epoch duration =2.36s
# Cumulative duration =16min 52.26999999999998s
#
# 432
# Epoch duration =2.33s
# Cumulative duration =16min 54.60000000000002s
#
# 433
# Epoch duration =2.39s
# Cumulative duration =16min 56.99000000000001s
#
# 434
# Epoch duration =2.34s
# Cumulative duration =16min 59.33000000000004s
#
# 435
# Epoch duration =2.41s
# Cumulative duration =17min 1.740000000000009s
#
# 436
# Epoch duration =2.34s
# Cumulative duration =17min 4.079999999999927s
#
# 437
# Epoch duration =2.32s
# Cumulative duration =17min 6.400000000000091s
#
# 438
# Epoch duration =2.35s
# Cumulative duration =17min 8.75s
#
# 439
# Epoch duration =2.34s
# Cumulative duration =17min 11.089999999999918s
#
# 440
# Epoch duration =2.35s
# Cumulative duration =17min 13.440000000000055s
#
# 441
# Epoch duration =2.35s
# Cumulative duration =17min 15.789999999999964s
#
# 442
# Epoch duration =2.39s
# Cumulative duration =17min 18.190000000000055s
#
# 443
# Epoch duration =2.37s
# Cumulative duration =17min 20.559999999999945s
#
# 444
# Epoch duration =2.37s
# Cumulative duration =17min 22.920000000000073s
#
# 445
# Epoch duration =2.33s
# Cumulative duration =17min 25.25999999999999s
#
# 446
# Epoch duration =2.32s
# Cumulative duration =17min 27.579999999999927s
#
# 447
# Epoch duration =2.32s
# Cumulative duration =17min 29.90000000000009s
#
# 448
# Epoch duration =2.31s
# Cumulative duration =17min 32.22000000000003s
#
# 449
# Epoch duration =2.33s
# Cumulative duration =17min 34.539999999999964s
#
# 450
# Epoch duration =2.33s
# Cumulative duration =17min 36.88000000000011s
#
# 451
# Epoch duration =2.33s
# Cumulative duration =17min 39.210000000000036s
#
# 452
# Epoch duration =2.32s
# Cumulative duration =17min 41.51999999999998s
#
# 453
# Epoch duration =2.39s
# Cumulative duration =17min 43.92000000000007s
#
# 454
# Epoch duration =2.37s
# Cumulative duration =17min 46.289999999999964s
#
# 455
# Epoch duration =2.35s
# Cumulative duration =17min 48.6400000000001s
#
# 456
# Epoch duration =2.35s
# Cumulative duration =17min 50.99000000000001s
#
# 457
# Epoch duration =2.35s
# Cumulative duration =17min 53.33999999999992s
#
# 458
# Epoch duration =2.35s
# Cumulative duration =17min 55.690000000000055s
#
# 459
# Epoch duration =2.33s
# Cumulative duration =17min 58.01999999999998s
#
# 460
# Epoch duration =2.36s
# Cumulative duration =18min 0.36999999999989086s
#
# 461
# Epoch duration =2.34s
# Cumulative duration =18min 2.7200000000000273s
#
# 462
# Epoch duration =2.32s
# Cumulative duration =18min 5.039999999999964s
#
# 463
# Epoch duration =2.33s
# Cumulative duration =18min 7.369999999999891s
#
# 464
# Epoch duration =2.34s
# Cumulative duration =18min 9.710000000000036s
#
# 465
# Epoch duration =2.35s
# Cumulative duration =18min 12.049999999999955s
#
# 466
# Epoch duration =2.34s
# Cumulative duration =18min 14.3900000000001s
#
# 467
# Epoch duration =2.34s
# Cumulative duration =18min 16.730000000000018s
#
# 468
# Epoch duration =2.33s
# Cumulative duration =18min 19.069999999999936s
#
# 469
# Epoch duration =2.34s
# Cumulative duration =18min 21.410000000000082s
#
# 470
# Epoch duration =2.35s
# Cumulative duration =18min 23.75999999999999s
#
# 471
# Epoch duration =2.32s
# Cumulative duration =18min 26.079999999999927s
#
# 472
# Epoch duration =2.38s
# Cumulative duration =18min 28.460000000000036s
#
# 473
# Epoch duration =2.34s
# Cumulative duration =18min 30.789999999999964s
#
# 474
# Epoch duration =2.32s
# Cumulative duration =18min 33.1099999999999s
#
# 475
# Epoch duration =2.34s
# Cumulative duration =18min 35.450000000000045s
#
# 476
# Epoch duration =2.33s
# Cumulative duration =18min 37.77999999999997s
#
# 477
# Epoch duration =2.32s
# Cumulative duration =18min 40.1099999999999s
#
# 478
# Epoch duration =2.35s
# Cumulative duration =18min 42.460000000000036s
#
# 479
# Epoch duration =2.34s
# Cumulative duration =18min 44.789999999999964s
#
# 480
# Epoch duration =2.32s
# Cumulative duration =18min 47.1099999999999s
#
# 481
# Epoch duration =2.43s
# Cumulative duration =18min 49.539999999999964s
#
# 482
# Epoch duration =2.34s
# Cumulative duration =18min 51.86999999999989s
#
# 483
# Epoch duration =2.35s
# Cumulative duration =18min 54.23000000000002s
#
# 484
# Epoch duration =2.34s
# Cumulative duration =18min 56.569999999999936s
#
# 485
# Epoch duration =2.32s
# Cumulative duration =18min 58.8900000000001s
#
# 486
# Epoch duration =2.34s
# Cumulative duration =19min 1.240000000000009s
#
# 487
# Epoch duration =2.34s
# Cumulative duration =19min 3.5799999999999272s
#
# 488
# Epoch duration =2.34s
# Cumulative duration =19min 5.910000000000082s
#
# 489
# Epoch duration =2.33s
# Cumulative duration =19min 8.240000000000009s
#
# 490
# Epoch duration =2.35s
# Cumulative duration =19min 10.589999999999918s
#
# 491
# Epoch duration =2.32s
# Cumulative duration =19min 12.910000000000082s
#
# 492
# Epoch duration =2.36s
# Cumulative duration =19min 15.279999999999973s
#
# 493
# Epoch duration =2.33s
# Cumulative duration =19min 17.6099999999999s
#
# 494
# Epoch duration =2.37s
# Cumulative duration =19min 19.980000000000018s
#
# 495
# Epoch duration =2.35s
# Cumulative duration =19min 22.329999999999927s
#
# 496
# Epoch duration =2.35s
# Cumulative duration =19min 24.680000000000064s
#
# 497
# Epoch duration =2.38s
# Cumulative duration =19min 27.059999999999945s
#
# 498
# Epoch duration =2.36s
# Cumulative duration =19min 29.420000000000073s
#
# 499
# Epoch duration =2.36s
# Cumulative duration =19min 31.779999999999973s
#
# 500
# Epoch duration =2.34s
# Cumulative duration =19min 34.13000000000011s
#
# 501
# Epoch duration =2.35s
# Cumulative duration =19min 36.47000000000003s
#
# 502
# Epoch duration =2.34s
# Cumulative duration =19min 38.809999999999945s
#
# 503
# Epoch duration =2.32s
# Cumulative duration =19min 41.13000000000011s
#
# 504
# Epoch duration =2.34s
# Cumulative duration =19min 43.47000000000003s
#
# 505
# Epoch duration =2.35s
# Cumulative duration =19min 45.819999999999936s
#
# 506
# Epoch duration =2.35s
# Cumulative duration =19min 48.180000000000064s
#
# 507
# Epoch duration =2.34s
# Cumulative duration =19min 50.51999999999998s
#
# 508
# Epoch duration =2.35s
# Cumulative duration =19min 52.86999999999989s
#
# 509
# Epoch duration =2.34s
# Cumulative duration =19min 55.210000000000036s
#
# 510
# Epoch duration =2.35s
# Cumulative duration =19min 57.559999999999945s
#
# 511
# Epoch duration =2.34s
# Cumulative duration =19min 59.90000000000009s
#
# 512
# Epoch duration =2.33s
# Cumulative duration =20min 2.230000000000018s
#
# 513
# Epoch duration =2.35s
# Cumulative duration =20min 4.579999999999927s
#
# 514
# Epoch duration =2.34s
# Cumulative duration =20min 6.920000000000073s
#
# 515
# Epoch duration =2.36s
# Cumulative duration =20min 9.279999999999973s
#
# 516
# Epoch duration =2.33s
# Cumulative duration =20min 11.61999999999989s
#
# 517
# Epoch duration =2.35s
# Cumulative duration =20min 13.970000000000027s
#
# 518
# Epoch duration =2.34s
# Cumulative duration =20min 16.309999999999945s
#
# 519
# Epoch duration =2.32s
# Cumulative duration =20min 18.63000000000011s
#
# 520
# Epoch duration =2.31s
# Cumulative duration =20min 20.930000000000064s
#
# 521
# Epoch duration =2.36s
# Cumulative duration =20min 23.299999999999955s
#
# 522
# Epoch duration =2.33s
# Cumulative duration =20min 25.63000000000011s
#
# 523
# Epoch duration =2.33s
# Cumulative duration =20min 27.950000000000045s
#
# 524
# Epoch duration =2.36s
# Cumulative duration =20min 30.319999999999936s
#
# 525
# Epoch duration =2.33s
# Cumulative duration =20min 32.65000000000009s
#
# 526
# Epoch duration =2.38s
# Cumulative duration =20min 35.02999999999997s
#
# 527
# Epoch duration =2.32s
# Cumulative duration =20min 37.34999999999991s
#
# 528
# Epoch duration =2.34s
# Cumulative duration =20min 39.690000000000055s
#
# 529
# Epoch duration =2.39s
# Cumulative duration =20min 42.07999999999993s
#
# 530
# Epoch duration =2.35s
# Cumulative duration =20min 44.440000000000055s
#
# 531
# Epoch duration =2.35s
# Cumulative duration =20min 46.77999999999997s
#
# 532
# Epoch duration =2.34s
# Cumulative duration =20min 49.11999999999989s
#
# 533
# Epoch duration =2.34s
# Cumulative duration =20min 51.47000000000003s
#
# 534
# Epoch duration =2.33s
# Cumulative duration =20min 53.789999999999964s
#
# 535
# Epoch duration =2.36s
# Cumulative duration =20min 56.15000000000009s
#
# 536
# Epoch duration =2.35s
# Cumulative duration =20min 58.50999999999999s
#
# 537
# Epoch duration =2.32s
# Cumulative duration =21min 0.8299999999999272s
#
# 538
# Epoch duration =2.36s
# Cumulative duration =21min 3.1800000000000637s
#
# 539
# Epoch duration =2.38s
# Cumulative duration =21min 5.569999999999936s
#
# 540
# Epoch duration =2.32s
# Cumulative duration =21min 7.880000000000109s
#
# 541
# Epoch duration =2.36s
# Cumulative duration =21min 10.240000000000009s
#
# 542
# Epoch duration =2.37s
# Cumulative duration =21min 12.6099999999999s
#
# 543
# Epoch duration =2.36s
# Cumulative duration =21min 14.970000000000027s
#
# 544
# Epoch duration =2.33s
# Cumulative duration =21min 17.299999999999955s
#
# 545
# Epoch duration =2.42s
# Cumulative duration =21min 19.720000000000027s
#
# 546
# Epoch duration =2.34s
# Cumulative duration =21min 22.049999999999955s
#
# 547
# Epoch duration =2.34s
# Cumulative duration =21min 24.40000000000009s
#
# 548
# Epoch duration =2.34s
# Cumulative duration =21min 26.730000000000018s
#
# 549
# Epoch duration =2.39s
# Cumulative duration =21min 29.13000000000011s
#
# 550
# Epoch duration =2.32s
# Cumulative duration =21min 31.450000000000045s
#
# 551
# Epoch duration =2.33s
# Cumulative duration =21min 33.77999999999997s
#
# 552
# Epoch duration =2.34s
# Cumulative duration =21min 36.1099999999999s
#
# 553
# Epoch duration =2.36s
# Cumulative duration =21min 38.47000000000003s
#
# 554
# Epoch duration =2.35s
# Cumulative duration =21min 40.82999999999993s
#
# 555
# Epoch duration =2.34s
# Cumulative duration =21min 43.17000000000007s
#
# 556
# Epoch duration =2.33s
# Cumulative duration =21min 45.5s
#
# 557
# Epoch duration =2.34s
# Cumulative duration =21min 47.83999999999992s
#
# 558
# Epoch duration =2.33s
# Cumulative duration =21min 50.17000000000007s
#
# 559
# Epoch duration =2.32s
# Cumulative duration =21min 52.49000000000001s
#
# 560
# Epoch duration =2.34s
# Cumulative duration =21min 54.82999999999993s
#
# 561
# Epoch duration =2.32s
# Cumulative duration =21min 57.15000000000009s
#
# 562
# Epoch duration =2.32s
# Cumulative duration =21min 59.47000000000003s
#
# 563
# Epoch duration =2.35s
# Cumulative duration =22min 1.8199999999999363s
#
# 564
# Epoch duration =2.33s
# Cumulative duration =22min 4.150000000000091s
#
# 565
# Epoch duration =2.32s
# Cumulative duration =22min 6.470000000000027s
#
# 566
# Epoch duration =2.38s
# Cumulative duration =22min 8.839999999999918s
#
# 567
# Epoch duration =2.32s
# Cumulative duration =22min 11.170000000000073s
#
# 568
# Epoch duration =2.33s
# Cumulative duration =22min 13.490000000000009s
#
# 569
# Epoch duration =2.33s
# Cumulative duration =22min 15.819999999999936s
#
# 570
# Epoch duration =2.35s
# Cumulative duration =22min 18.170000000000073s
#
# 571
# Epoch duration =2.34s
# Cumulative duration =22min 20.50999999999999s
#
# 572
# Epoch duration =2.36s
# Cumulative duration =22min 22.86999999999989s
#
# 573
# Epoch duration =2.35s
# Cumulative duration =22min 25.220000000000027s
#
# 574
# Epoch duration =2.34s
# Cumulative duration =22min 27.569999999999936s
#
# 575
# Epoch duration =2.32s
# Cumulative duration =22min 29.8900000000001s
#
# 576
# Epoch duration =2.35s
# Cumulative duration =22min 32.24000000000001s
#
# 577
# Epoch duration =2.36s
# Cumulative duration =22min 34.59999999999991s
#
# 578
# Epoch duration =2.34s
# Cumulative duration =22min 36.950000000000045s
#
# 579
# Epoch duration =2.39s
# Cumulative duration =22min 39.32999999999993s
#
# 580
# Epoch duration =2.36s
# Cumulative duration =22min 41.690000000000055s
#
# 581
# Epoch duration =2.32s
# Cumulative duration =22min 44.01999999999998s
#
# 582
# Epoch duration =2.33s
# Cumulative duration =22min 46.34999999999991s
#
# 583
# Epoch duration =2.33s
# Cumulative duration =22min 48.680000000000064s
#
# 584
# Epoch duration =2.31s
# Cumulative duration =22min 50.99000000000001s
#
# 585
# Epoch duration =2.32s
# Cumulative duration =22min 53.309999999999945s
#
# 586
# Epoch duration =2.4s
# Cumulative duration =22min 55.700000000000045s
#
# 587
# Epoch duration =2.34s
# Cumulative duration =22min 58.039999999999964s
#
# 588
# Epoch duration =2.39s
# Cumulative duration =23min 0.44000000000005457s
#
# 589
# Epoch duration =2.34s
# Cumulative duration =23min 2.7799999999999727s
#
# 590
# Epoch duration =2.35s
# Cumulative duration =23min 5.130000000000109s
#
# 591
# Epoch duration =2.32s
# Cumulative duration =23min 7.4500000000000455s
#
# 592
# Epoch duration =2.46s
# Cumulative duration =23min 9.910000000000082s
#
# 593
# Epoch duration =2.38s
# Cumulative duration =23min 12.299999999999955s
#
# 594
# Epoch duration =2.35s
# Cumulative duration =23min 14.650000000000091s
#
# 595
# Epoch duration =2.33s
# Cumulative duration =23min 16.980000000000018s
#
# 596
# Epoch duration =2.33s
# Cumulative duration =23min 19.309999999999945s
#
# 597
# Epoch duration =2.34s
# Cumulative duration =23min 21.65000000000009s
#
# 598
# Epoch duration =2.38s
# Cumulative duration =23min 24.029999999999973s
#
# 599
# Epoch duration =2.36s
# Cumulative duration =23min 26.40000000000009s
#
# 600
# Epoch duration =2.33s
# Cumulative duration =23min 28.730000000000018s
#
# 601
# Epoch duration =2.41s
# Cumulative duration =23min 31.1400000000001s
#
# 602
# Epoch duration =2.34s
# Cumulative duration =23min 33.48000000000002s
#
# 603
# Epoch duration =2.32s
# Cumulative duration =23min 35.809999999999945s
#
# 604
# Epoch duration =2.32s
# Cumulative duration =23min 38.13000000000011s
#
# 605
# Epoch duration =2.31s
# Cumulative duration =23min 40.440000000000055s
#
# 606
# Epoch duration =2.36s
# Cumulative duration =23min 42.789999999999964s
#
# 607
# Epoch duration =2.37s
# Cumulative duration =23min 45.16000000000008s
#
# 608
# Epoch duration =2.34s
# Cumulative duration =23min 47.5s
#
# 609
# Epoch duration =2.32s
# Cumulative duration =23min 49.819999999999936s
#
# 610
# Epoch duration =2.4s
# Cumulative duration =23min 52.22000000000003s
#
# 611
# Epoch duration =2.34s
# Cumulative duration =23min 54.559999999999945s
#
# 612
# Epoch duration =2.33s
# Cumulative duration =23min 56.8900000000001s
#
# 613
# Epoch duration =2.33s
# Cumulative duration =23min 59.22000000000003s
#
# 614
# Epoch duration =2.34s
# Cumulative duration =24min 1.5599999999999454s
#
# 615
# Epoch duration =2.32s
# Cumulative duration =24min 3.8900000000001s
#
# 616
# Epoch duration =2.36s
# Cumulative duration =24min 6.240000000000009s
#
# 617
# Epoch duration =2.34s
# Cumulative duration =24min 8.579999999999927s
#
# 618
# Epoch duration =2.34s
# Cumulative duration =24min 10.930000000000064s
#
# 619
# Epoch duration =2.34s
# Cumulative duration =24min 13.259999999999991s
#
# 620
# Epoch duration =2.32s
# Cumulative duration =24min 15.579999999999927s
#
# 621
# Epoch duration =2.33s
# Cumulative duration =24min 17.910000000000082s
#
# 622
# Epoch duration =2.36s
# Cumulative duration =24min 20.269999999999982s
#
# 623
# Epoch duration =2.34s
# Cumulative duration =24min 22.6099999999999s
#
# 624
# Epoch duration =2.35s
# Cumulative duration =24min 24.960000000000036s
#
# 625
# Epoch duration =2.35s
# Cumulative duration =24min 27.309999999999945s
#
# 626
# Epoch duration =2.34s
# Cumulative duration =24min 29.65000000000009s
#
# 627
# Epoch duration =2.33s
# Cumulative duration =24min 31.970000000000027s
#
# 628
# Epoch duration =2.33s
# Cumulative duration =24min 34.309999999999945s
#
# 629
# Epoch duration =2.39s
# Cumulative duration =24min 36.700000000000045s
#
# 630
# Epoch duration =2.36s
# Cumulative duration =24min 39.059999999999945s
#
# 631
# Epoch duration =2.32s
# Cumulative duration =24min 41.36999999999989s
#
# 632
# Epoch duration =2.34s
# Cumulative duration =24min 43.710000000000036s
#
# 633
# Epoch duration =2.32s
# Cumulative duration =24min 46.02999999999997s
#
# 634
# Epoch duration =2.32s
# Cumulative duration =24min 48.34999999999991s
#
# 635
# Epoch duration =2.31s
# Cumulative duration =24min 50.67000000000007s
#
# 636
# Epoch duration =2.37s
# Cumulative duration =24min 53.02999999999997s
#
# 637
# Epoch duration =2.4s
# Cumulative duration =24min 55.430000000000064s
#
# 638
# Epoch duration =2.36s
# Cumulative duration =24min 57.799999999999955s
#
# 639
# Epoch duration =2.33s
# Cumulative duration =25min 0.13000000000010914s
#
# 640
# Epoch duration =2.32s
# Cumulative duration =25min 2.4500000000000455s
#
# 641
# Epoch duration =2.37s
# Cumulative duration =25min 4.819999999999936s
#
# 642
# Epoch duration =2.34s
# Cumulative duration =25min 7.170000000000073s
#
# 643
# Epoch duration =2.39s
# Cumulative duration =25min 9.549999999999955s
#
# 644
# Epoch duration =2.33s
# Cumulative duration =25min 11.88000000000011s
#
# 645
# Epoch duration =2.38s
# Cumulative duration =25min 14.259999999999991s
#
# 646
# Epoch duration =2.37s
# Cumulative duration =25min 16.63000000000011s
#
# 647
# Epoch duration =2.34s
# Cumulative duration =25min 18.970000000000027s
#
# 648
# Epoch duration =2.34s
# Cumulative duration =25min 21.309999999999945s
#
# 649
# Epoch duration =2.33s
# Cumulative duration =25min 23.6400000000001s
#
# 650
# Epoch duration =2.34s
# Cumulative duration =25min 25.980000000000018s
#
# 651
# Epoch duration =2.31s
# Cumulative duration =25min 28.289999999999964s
#
# 652
# Epoch duration =2.33s
# Cumulative duration =25min 30.61999999999989s
#
# 653
# Epoch duration =2.33s
# Cumulative duration =25min 32.950000000000045s
#
# 654
# Epoch duration =2.38s
# Cumulative duration =25min 35.32999999999993s
#
# 655
# Epoch duration =2.3s
# Cumulative duration =25min 37.6400000000001s
#
# 656
# Epoch duration =2.36s
# Cumulative duration =25min 40.0s
#
# 657
# Epoch duration =2.34s
# Cumulative duration =25min 42.33999999999992s
#
# 658
# Epoch duration =2.34s
# Cumulative duration =25min 44.67000000000007s
#
# 659
# Epoch duration =2.32s
# Cumulative duration =25min 46.99000000000001s
#
# 660
# Epoch duration =2.34s
# Cumulative duration =25min 49.33999999999992s
#
# 661
# Epoch duration =2.33s
# Cumulative duration =25min 51.67000000000007s
#
# 662
# Epoch duration =2.35s
# Cumulative duration =25min 54.01999999999998s
#
# 663
# Epoch duration =2.36s
# Cumulative duration =25min 56.38000000000011s
#
# 664
# Epoch duration =2.35s
# Cumulative duration =25min 58.73000000000002s
#
# 665
# Epoch duration =2.32s
# Cumulative duration =26min 1.0499999999999545s
#
# 666
# Epoch duration =2.35s
# Cumulative duration =26min 3.400000000000091s
#
# 667
# Epoch duration =2.33s
# Cumulative duration =26min 5.740000000000009s
#
# 668
# Epoch duration =2.34s
# Cumulative duration =26min 8.079999999999927s
#
# 669
# Epoch duration =2.36s
# ...
# Cumulative duration =30min 33.289999999999964s
#
# 782
# Epoch duration =2.35s
# Cumulative duration =30min 35.6400000000001s
#
# 783
# Epoch duration =2.33s
# Cumulative duration =30min 37.97000000000003s
#
# 784
# Epoch duration =2.35s
# Cumulative duration =30min 40.319999999999936s
#
# 785
# Epoch duration =2.33s
# Cumulative duration =30min 42.65000000000009s
#
# 786
# Epoch duration =2.37s
# Cumulative duration =30min 45.01999999999998s
#
# 787
# Epoch duration =2.36s
# Cumulative duration =30min 47.38000000000011s
#
# 788
# Epoch duration =2.38s
# Cumulative duration =30min 49.75999999999999s
#
# 789
# Epoch duration =2.35s
# Cumulative duration =30min 52.1099999999999s
#
# 790
# Epoch duration =2.33s
# Cumulative duration =30min 54.440000000000055s
#
# 791
# Epoch duration =2.33s
# Cumulative duration =30min 56.76999999999998s
#
# 792
# Epoch duration =2.33s
# Cumulative duration =30min 59.09999999999991s
#
# 793
# Epoch duration =2.41s
# Cumulative duration =31min 1.5s
#
# 794
# Epoch duration =2.58s
# Cumulative duration =31min 4.089999999999918s
#
# 795
# Epoch duration =2.32s
# Cumulative duration =31min 6.410000000000082s
#
# 796
# Epoch duration =2.36s
# Cumulative duration =31min 8.769999999999982s
#
# 797
# Epoch duration =2.36s
# Cumulative duration =31min 11.13000000000011s
#
# 798
# Epoch duration =2.35s
# Cumulative duration =31min 13.480000000000018s
#
# 799
# Epoch duration =2.36s
# Cumulative duration =31min 15.849999999999909s
#
# 800
# Epoch duration =2.34s
# Cumulative duration =31min 18.190000000000055s
#
# 801
# Epoch duration =2.34s
# Cumulative duration =31min 20.529999999999973s
#
# 802
# Epoch duration =2.4s
# Cumulative duration =31min 22.930000000000064s
#
# 803
# Epoch duration =2.34s
# Cumulative duration =31min 25.279999999999973s
#
# 804
# Epoch duration =2.46s
# Cumulative duration =31min 27.74000000000001s
#
# 805
# Epoch duration =2.35s
# Cumulative duration =31min 30.089999999999918s
#
# 806
# Epoch duration =2.36s
# Cumulative duration =31min 32.450000000000045s
#
# 807
# Epoch duration =2.37s
# Cumulative duration =31min 34.819999999999936s
#
# 808
# Epoch duration =2.34s
# Cumulative duration =31min 37.16000000000008s
#
# 809
# Epoch duration =2.35s
# Cumulative duration =31min 39.50999999999999s
#
# 810
# Epoch duration =2.37s
# Cumulative duration =31min 41.88000000000011s
#
# 811
# Epoch duration =2.33s
# Cumulative duration =31min 44.210000000000036s
#
# 812
# Epoch duration =2.31s
# Cumulative duration =31min 46.50999999999999s
#
# 813
# Epoch duration =2.36s
# Cumulative duration =31min 48.86999999999989s
#
# 814
# Epoch duration =2.33s
# Cumulative duration =31min 51.210000000000036s
#
# 815
# Epoch duration =2.35s
# Cumulative duration =31min 53.559999999999945s
#
# 816
# Epoch duration =2.38s
# Cumulative duration =31min 55.940000000000055s
#
# 817
# Epoch duration =2.36s
# Cumulative duration =31min 58.299999999999955s
#
# 818
# Epoch duration =2.3s
# Cumulative duration =32min 0.599999999999909s
#
# 819
# Epoch duration =2.33s
# Cumulative duration =32min 2.9200000000000728s
#
# 820
# Epoch duration =2.33s
# Cumulative duration =32min 5.25s
#
# 821
# Epoch duration =2.41s
# Cumulative duration =32min 7.660000000000082s
#
# 822
# Epoch duration =2.37s
# Cumulative duration =32min 10.019999999999982s
#
# 823
# Epoch duration =2.32s
# Cumulative duration =32min 12.349999999999909s
#
# 824
# Epoch duration =2.34s
# Cumulative duration =32min 14.690000000000055s
#
# 825
# Epoch duration =2.36s
# Cumulative duration =32min 17.059999999999945s
#
# 826
# Epoch duration =2.34s
# Cumulative duration =32min 19.3900000000001s
#
# 827
# Epoch duration =2.36s
# Cumulative duration =32min 21.75s
#
# 828
# Epoch duration =2.33s
# Cumulative duration =32min 24.079999999999927s
#
# 829
# Epoch duration =2.34s
# Cumulative duration =32min 26.420000000000073s
#
# 830
# Epoch duration =2.37s
# Cumulative duration =32min 28.789999999999964s
#
# 831
# Epoch duration =2.35s
# Cumulative duration =32min 31.1400000000001s
#
# 832
# Epoch duration =2.38s
# Cumulative duration =32min 33.52999999999997s
#
# 833
# Epoch duration =2.32s
# Cumulative duration =32min 35.83999999999992s
#
# 834
# Epoch duration =2.36s
# Cumulative duration =32min 38.210000000000036s
#
# 835
# Epoch duration =2.36s
# Cumulative duration =32min 40.569999999999936s
#
# 836
# Epoch duration =2.41s
# Cumulative duration =32min 42.98000000000002s
#
# 837
# Epoch duration =2.37s
# Cumulative duration =32min 45.34999999999991s
#
# 838
# Epoch duration =2.39s
# Cumulative duration =32min 47.74000000000001s
#
# 839
# Epoch duration =2.37s
# Cumulative duration =32min 50.1099999999999s
#
# 840
# Epoch duration =2.41s
# Cumulative duration =32min 52.52999999999997s
#
# 841
# Epoch duration =2.32s
# Cumulative duration =32min 54.84999999999991s
#
# 842
# Epoch duration =2.35s
# Cumulative duration =32min 57.200000000000045s
#
# 843
# Epoch duration =2.31s
# Cumulative duration =32min 59.50999999999999s
#
# 844
# Epoch duration =2.34s
# Cumulative duration =33min 1.849999999999909s
#
# 845
# Epoch duration =2.38s
# Cumulative duration =33min 4.240000000000009s
#
# 846
# Epoch duration =2.36s
# Cumulative duration =33min 6.589999999999918s
#
# 847
# Epoch duration =2.34s
# Cumulative duration =33min 8.940000000000055s
#
# 848
# Epoch duration =2.33s
# Cumulative duration =33min 11.269999999999982s
#
# 849
# Epoch duration =2.33s
# Cumulative duration =33min 13.589999999999918s
#
# 850
# Epoch duration =2.32s
# Cumulative duration =33min 15.910000000000082s
#
# 851
# Epoch duration =2.34s
# Cumulative duration =33min 18.24000000000001s
#
# 852
# Epoch duration =2.38s
# Cumulative duration =33min 20.63000000000011s
#
# 853
# Epoch duration =2.35s
# Cumulative duration =33min 22.970000000000027s
#
# 854
# Epoch duration =2.32s
# Cumulative duration =33min 25.289999999999964s
#
# 855
# Epoch duration =2.37s
# Cumulative duration =33min 27.660000000000082s
#
# 856
# Epoch duration =2.35s
# Cumulative duration =33min 30.00999999999999s
#
# 857
# Epoch duration =2.41s
# Cumulative duration =33min 32.42000000000007s
#
# 858
# Epoch duration =2.33s
# Cumulative duration =33min 34.75s
#
# 859
# Epoch duration =2.33s
# Cumulative duration =33min 37.08999999999992s
#
# 860
# Epoch duration =2.44s
# Cumulative duration =33min 39.52999999999997s
#
# 861
# Epoch duration =2.34s
# Cumulative duration =33min 41.86999999999989s
#
# 862
# Epoch duration =2.43s
# Cumulative duration =33min 44.299999999999955s
#
# 863
# Epoch duration =2.34s
# Cumulative duration =33min 46.6400000000001s
#
# 864
# Epoch duration =2.44s
# Cumulative duration =33min 49.07999999999993s
#
# 865
# Epoch duration =2.36s
# Cumulative duration =33min 51.440000000000055s
#
# 866
# Epoch duration =2.42s
# Cumulative duration =33min 53.8599999999999s
#
# 867
# Epoch duration =2.35s
# Cumulative duration =33min 56.210000000000036s
#
# 868
# Epoch duration =2.33s
# Cumulative duration =33min 58.539999999999964s
#
# 869
# Epoch duration =2.47s
# Cumulative duration =34min 1.009999999999991s
#
# 870
# Epoch duration =2.4s
# Cumulative duration =34min 3.410000000000082s
#
# 871
# Epoch duration =2.41s
# Cumulative duration =34min 5.819999999999936s
#
# 872
# Epoch duration =2.31s
# Cumulative duration =34min 8.13000000000011s
#
# 873
# Epoch duration =2.35s
# Cumulative duration =34min 10.4699999999998s
#
# 874
# Epoch duration =2.33s
# Cumulative duration =34min 12.800000000000182s
#
# 875
# Epoch duration =2.34s
# Cumulative duration =34min 15.139999999999873s
#
# 876
# Epoch duration =2.42s
# Cumulative duration =34min 17.559999999999945s
#
# 877
# Epoch duration =2.41s
# Cumulative duration =34min 19.9699999999998s
#
# 878
# Epoch duration =2.32s
# Cumulative duration =34min 22.289999999999964s
#
# 879
# Epoch duration =2.34s
# Cumulative duration =34min 24.63000000000011s
#
# 880
# Epoch duration =2.34s
# Cumulative duration =34min 26.9699999999998s
#
# 881
# Epoch duration =2.32s
# Cumulative duration =34min 29.289999999999964s
#
# 882
# Epoch duration =2.39s
# Cumulative duration =34min 31.679999999999836s
#
# 883
# Epoch duration =2.36s
# Cumulative duration =34min 34.039999999999964s
#
# 884
# Epoch duration =2.36s
# Cumulative duration =34min 36.38999999999987s
#
# 885
# Epoch duration =2.47s
# Cumulative duration =34min 38.86999999999989s
#
# 886
# Epoch duration =2.39s
# Cumulative duration =34min 41.25s
#
# 887
# Epoch duration =2.39s
# Cumulative duration =34min 43.63999999999987s
#
# 888
# Epoch duration =2.4s
# Cumulative duration =34min 46.039999999999964s
#
# 889
# Epoch duration =2.36s
# Cumulative duration =34min 48.40000000000009s
#
# 890
# Epoch duration =2.34s
# Cumulative duration =34min 50.73999999999978s
#
# 891
# Epoch duration =2.36s
# Cumulative duration =34min 53.09999999999991s
#
# 892
# Epoch duration =2.36s
# Cumulative duration =34min 55.460000000000036s
#
# 893
# Epoch duration =2.34s
# Cumulative duration =34min 57.80000000000018s
#
# 894
# Epoch duration =2.32s
# Cumulative duration =35min 0.13000000000010914s
#
# 895
# Epoch duration =2.31s
# Cumulative duration =35min 2.4299999999998363s
#
# 896
# Epoch duration =2.32s
# Cumulative duration =35min 4.75s
#
# 897
# Epoch duration =2.36s
# Cumulative duration =35min 7.110000000000127s
#
# 898
# Epoch duration =2.35s
# Cumulative duration =35min 9.460000000000036s
#
# 899
# Epoch duration =2.31s
# Cumulative duration =35min 11.769999999999982s
#
# 900
# Epoch duration =2.33s
# Cumulative duration =35min 14.099999999999909s
#
# 901
# Epoch duration =2.36s
# Cumulative duration =35min 16.460000000000036s
#
# 902
# Epoch duration =2.44s
# Cumulative duration =35min 18.90000000000009s
#
# 903
# Epoch duration =2.34s
# Cumulative duration =35min 21.23999999999978s
#
# 904
# Epoch duration =2.33s
# Cumulative duration =35min 23.570000000000164s
#
# 905
# Epoch duration =2.31s
# Cumulative duration =35min 25.88000000000011s
#
# 906
# Epoch duration =2.32s
# Cumulative duration =35min 28.199999999999818s
#
# 907
# Epoch duration =2.31s
# Cumulative duration =35min 30.519999999999982s
#
# 908
# Epoch duration =2.33s
# Cumulative duration =35min 32.840000000000146s
#
# 909
# Epoch duration =2.33s
# Cumulative duration =35min 35.17000000000007s
#
# 910
# Epoch duration =2.32s
# Cumulative duration =35min 37.48999999999978s
#
# 911
# Epoch duration =2.33s
# Cumulative duration =35min 39.820000000000164s
#
# 912
# Epoch duration =2.35s
# Cumulative duration =35min 42.17000000000007s
#
# 913
# Epoch duration =2.4s
# Cumulative duration =35min 44.570000000000164s
#
# 914
# Epoch duration =2.35s
# Cumulative duration =35min 46.92000000000007s
#
# 915
# Epoch duration =2.38s
# Cumulative duration =35min 49.309999999999945s
#
# 916
# Epoch duration =2.35s
# Cumulative duration =35min 51.65000000000009s
#
# 917
# Epoch duration =2.32s
# Cumulative duration =35min 53.9699999999998s
#
# 918
# Epoch duration =2.36s
# Cumulative duration =35min 56.32999999999993s
#
# 919
# Epoch duration =2.32s
# Cumulative duration =35min 58.65000000000009s
#
# 920
# Epoch duration =2.36s
# Cumulative duration =36min 1.0100000000002183s
#
# 921
# Epoch duration =2.31s
# Cumulative duration =36min 3.3099999999999454s
#
# 922
# Epoch duration =2.32s
# Cumulative duration =36min 5.630000000000109s
#
# 923
# Epoch duration =2.34s
# Cumulative duration =36min 7.980000000000018s
#
# 924
# Epoch duration =2.35s
# Cumulative duration =36min 10.329999999999927s
#
# 925
# Epoch duration =2.36s
# Cumulative duration =36min 12.690000000000055s
#
# 926
# Epoch duration =2.33s
# Cumulative duration =36min 15.019999999999982s
#
# 927
# Epoch duration =2.36s
# Cumulative duration =36min 17.38000000000011s
#
# 928
# Epoch duration =2.34s
# Cumulative duration =36min 19.7199999999998s
#
# 929
# Epoch duration =2.34s
# Cumulative duration =36min 22.070000000000164s
#
# 930
# Epoch duration =2.33s
# Cumulative duration =36min 24.40000000000009s
#
# 931
# Epoch duration =2.35s
# Cumulative duration =36min 26.75s
#
# 932
# Epoch duration =2.35s
# Cumulative duration =36min 29.09999999999991s
#
# 933
# Epoch duration =2.41s
# Cumulative duration =36min 31.519999999999982s
#
# 934
# Epoch duration =2.33s
# Cumulative duration =36min 33.84999999999991s
#
# 935
# Epoch duration =2.34s
# Cumulative duration =36min 36.190000000000055s
#
# 936
# Epoch duration =2.33s
# Cumulative duration =36min 38.51999999999998s
#
# 937
# Epoch duration =2.33s
# Cumulative duration =36min 40.84999999999991s
#
# 938
# Epoch duration =2.38s
# Cumulative duration =36min 43.23000000000002s
#
# 939
# Epoch duration =2.37s
# Cumulative duration =36min 45.59999999999991s
#
# 940
# Epoch duration =2.32s
# Cumulative duration =36min 47.92000000000007s
#
# 941
# Epoch duration =2.42s
# Cumulative duration =36min 50.34999999999991s
#
# 942
# Epoch duration =2.35s
# Cumulative duration =36min 52.69999999999982s
#
# 943
# Epoch duration =2.36s
# Cumulative duration =36min 55.059999999999945s
#
# 944
# Epoch duration =2.34s
# Cumulative duration =36min 57.38999999999987s
#
# 945
# Epoch duration =2.34s
# Cumulative duration =36min 59.73000000000002s
#
# 946
# Epoch duration =2.38s
# Cumulative duration =37min 2.1100000000001273s
#
# 947
# Epoch duration =2.34s
# Cumulative duration =37min 4.449999999999818s
#
# 948
# Epoch duration =2.4s
# Cumulative duration =37min 6.860000000000127s
#
# 949
# Epoch duration =2.34s
# Cumulative duration =37min 9.199999999999818s
#
# 950
# Epoch duration =2.35s
# Cumulative duration =37min 11.550000000000182s
#
# 951
# Epoch duration =2.34s
# Cumulative duration =37min 13.88000000000011s
#
# 952
# Epoch duration =2.33s
# Cumulative duration =37min 16.210000000000036s
#
# 953
# Epoch duration =2.32s
# Cumulative duration =37min 18.5300000000002s
#
# 954
# Epoch duration =2.34s
# Cumulative duration =37min 20.88000000000011s
#
# 955
# Epoch duration =2.35s
# Cumulative duration =37min 23.230000000000018s
#
# 956
# Epoch duration =2.35s
# Cumulative duration =37min 25.579999999999927s
#
# 957
# Epoch duration =2.32s
# Cumulative duration =37min 27.90000000000009s
#
# 958
# Epoch duration =2.35s
# Cumulative duration =37min 30.25s
#
# 959
# Epoch duration =2.38s
# Cumulative duration =37min 32.61999999999989s
#
# 960
# Epoch duration =2.33s
# Cumulative duration =37min 34.960000000000036s
#
# 961
# Epoch duration =2.37s
# Cumulative duration =37min 37.32999999999993s
#
# 962
# Epoch duration =2.33s
# Cumulative duration =37min 39.659999999999854s
#
# 963
# Epoch duration =2.32s
# Cumulative duration =37min 41.98000000000002s
#
# 964
# Epoch duration =2.37s
# Cumulative duration =37min 44.340000000000146s
#
# 965
# Epoch duration =2.32s
# Cumulative duration =37min 46.659999999999854s
#
# 966
# Epoch duration =2.33s
# Cumulative duration =37min 48.98999999999978s
#
# 967
# Epoch duration =2.38s
# Cumulative duration =37min 51.36999999999989s
#
# 968
# Epoch duration =2.35s
# Cumulative duration =37min 53.73000000000002s
#
# 969
# Epoch duration =2.33s
# Cumulative duration =37min 56.059999999999945s
#
# 970
# Epoch duration =2.33s
# Cumulative duration =37min 58.38999999999987s
#
# 971
# Epoch duration =2.33s
# Cumulative duration =38min 0.7300000000000182s
#
# 972
# Epoch duration =2.33s
# Cumulative duration =38min 3.0599999999999454s
#
# 973
# Epoch duration =2.35s
# Cumulative duration =38min 5.400000000000091s
#
# 974
# Epoch duration =2.33s
# Cumulative duration =38min 7.739999999999782s
#
# 975
# Epoch duration =2.38s
# Cumulative duration =38min 10.11999999999989s
#
# 976
# Epoch duration =2.33s
# Cumulative duration =38min 12.449999999999818s
#
# 977
# Epoch duration =2.33s
# Cumulative duration =38min 14.7800000000002s
#
# 978
# Epoch duration =2.38s
# Cumulative duration =38min 17.159999999999854s
#
# 979
# Epoch duration =2.4s
# Cumulative duration =38min 19.559999999999945s
#
# 980
# Epoch duration =2.35s
# Cumulative duration =38min 21.909999999999854s
#
# 981
# Epoch duration =2.36s
# Cumulative duration =38min 24.2800000000002s
#
# 982
# Epoch duration =2.35s
# Cumulative duration =38min 26.63000000000011s
#
# 983
# Epoch duration =2.34s
# Cumulative duration =38min 28.9699999999998s
#
# 984
# Epoch duration =2.35s
# Cumulative duration =38min 31.320000000000164s
#
# 985
# Epoch duration =2.37s
# Cumulative duration =38min 33.690000000000055s
#
# 986
# Epoch duration =2.32s
# Cumulative duration =38min 36.01999999999998s
#
# 987
# Epoch duration =2.36s
# Cumulative duration =38min 38.36999999999989s
#
# 988
# Epoch duration =2.34s
# Cumulative duration =38min 40.710000000000036s
#
# 989
# Epoch duration =2.34s
# Cumulative duration =38min 43.05000000000018s
#
# 990
# Epoch duration =2.34s
# Cumulative duration =38min 45.38999999999987s
#
# 991
# Epoch duration =2.39s
# Cumulative duration =38min 47.7800000000002s
#
# 992
# Epoch duration =2.39s
# Cumulative duration =38min 50.17000000000007s
#
# 993
# Epoch duration =2.35s
# Cumulative duration =38min 52.51999999999998s
#
# 994
# Epoch duration =2.31s
# Cumulative duration =38min 54.82999999999993s
#
# 995
# Epoch duration =2.32s
# Cumulative duration =38min 57.15000000000009s
#
# 996
# Epoch duration =2.34s
# Cumulative duration =38min 59.48999999999978s
#
# 997
# Epoch duration =2.39s
# Cumulative duration =39min 1.8800000000001091s
#
# 998
# Epoch duration =2.4s
# Cumulative duration =39min 4.2800000000002s
#
# 999
# Epoch duration =2.38s
# Cumulative duration =39min 6.6599999999998545s
#
# Saving scores to Arrays/riboswitch_mlpt1_44_ug_so1k.npy

# %%
#load values
savepath = 'Arrays/riboswitch_mlpt1_44_ug_so1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, vmax=1.0, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
