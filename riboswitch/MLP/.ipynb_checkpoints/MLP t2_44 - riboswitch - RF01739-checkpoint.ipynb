# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/riboswitch_100k_d4.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 9.2s

# %%
simalign_file = '../../../data_RFAM/riboswitch_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<>>>>>><<<<<<<<<>>>>>>>>>)))))<<<<>>>>'

# %%
ugSS
# Out:
# ':::::(((((,,,,<-<<<<<____>>>>>><<<--<<<<<<______>>>->>>->>>,,,,,)))))-<<<<____>>>>::::::::::::::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/riboswitch'
param_path = os.path.join(save_path, 'mlp_t2_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 816, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=3.75s -- loss=0.42992 -- acc=78.745004%
#
#   valid loss:		0.14934
#   valid accuracy:	0.97375+/-0.00000
#   valid auc-roc:	0.99754+/-0.00000
#   valid auc-pr:		0.99765+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.18967 -- acc=92.955846%
#
#   valid loss:		0.07664
#   valid accuracy:	0.98325+/-0.00000
#   valid auc-roc:	0.99922+/-0.00000
#   valid auc-pr:		0.99925+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.14713 -- acc=94.610001%
#
#   valid loss:		0.05256
#   valid accuracy:	0.98870+/-0.00000
#   valid auc-roc:	0.99946+/-0.00000
#   valid auc-pr:		0.99944+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.75s -- loss=0.13166 -- acc=95.225843%
#
#   valid loss:		0.04630
#   valid accuracy:	0.99130+/-0.00000
#   valid auc-roc:	0.99959+/-0.00000
#   valid auc-pr:		0.99959+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.12042 -- acc=95.756676%
#
#   valid loss:		0.04454
#   valid accuracy:	0.99050+/-0.00000
#   valid auc-roc:	0.99961+/-0.00000
#   valid auc-pr:		0.99960+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.11739 -- acc=95.800000%
#
#   valid loss:		0.04148
#   valid accuracy:	0.99235+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99962+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.11390 -- acc=96.085849%
#
#   valid loss:		0.03877
#   valid accuracy:	0.99340+/-0.00000
#   valid auc-roc:	0.99969+/-0.00000
#   valid auc-pr:		0.99964+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.58s -- loss=0.10927 -- acc=96.290009%
#
#   valid loss:		0.03585
#   valid accuracy:	0.99410+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.52s -- loss=0.10882 -- acc=96.419172%
#
#   valid loss:		0.03570
#   valid accuracy:	0.99450+/-0.00000
#   valid auc-roc:	0.99974+/-0.00000
#   valid auc-pr:		0.99962+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.10721 -- acc=96.389179%
#
#   valid loss:		0.03536
#   valid accuracy:	0.99415+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.10493 -- acc=96.545845%
#
#   valid loss:		0.03548
#   valid accuracy:	0.99485+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.10578 -- acc=96.461676%
#
#   valid loss:		0.03378
#   valid accuracy:	0.99480+/-0.00000
#   valid auc-roc:	0.99975+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.10299 -- acc=96.636674%
#
#   valid loss:		0.03431
#   valid accuracy:	0.99465+/-0.00000
#   valid auc-roc:	0.99976+/-0.00000
#   valid auc-pr:		0.99974+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.10345 -- acc=96.648345%
#
#   valid loss:		0.03466
#   valid accuracy:	0.99510+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.10227 -- acc=96.782508%
#
#   valid loss:		0.03428
#   valid accuracy:	0.99485+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.10270 -- acc=96.775848%
#
#   valid loss:		0.03340
#   valid accuracy:	0.99495+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.10172 -- acc=96.789179%
#
#   valid loss:		0.04010
#   valid accuracy:	0.99245+/-0.00000
#   valid auc-roc:	0.99974+/-0.00000
#   valid auc-pr:		0.99970+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.09928 -- acc=96.870007%
#
#   valid loss:		0.03295
#   valid accuracy:	0.99540+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.09889 -- acc=96.885849%
#
#   valid loss:		0.03524
#   valid accuracy:	0.99390+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.09825 -- acc=96.930003%
#
#   valid loss:		0.03299
#   valid accuracy:	0.99600+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.59s -- loss=0.09900 -- acc=96.926673%
#
#   valid loss:		0.03175
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.09699 -- acc=96.997500%
#
#   valid loss:		0.03325
#   valid accuracy:	0.99550+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.09954 -- acc=96.962506%
#
#   valid loss:		0.03560
#   valid accuracy:	0.99495+/-0.00000
#   valid auc-roc:	0.99981+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.09730 -- acc=96.977508%
#
#   valid loss:		0.03638
#   valid accuracy:	0.99500+/-0.00000
#   valid auc-roc:	0.99972+/-0.00000
#   valid auc-pr:		0.99964+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.62s -- loss=0.09887 -- acc=96.982508%
#
#   valid loss:		0.03418
#   valid accuracy:	0.99570+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.09892 -- acc=96.911671%
#
#   valid loss:		0.03410
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.09597 -- acc=97.102500%
#
#   valid loss:		0.03360
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.09822 -- acc=97.048345%
#
#   valid loss:		0.03531
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.09405 -- acc=97.132503%
#
#   valid loss:		0.03374
#   valid accuracy:	0.99555+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.09797 -- acc=97.066677%
#
#   valid loss:		0.03388
#   valid accuracy:	0.99570+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.09870 -- acc=97.015842%
#
#   valid loss:		0.03372
#   valid accuracy:	0.99590+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.09524 -- acc=97.115842%
#
#   valid loss:		0.03337
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.09630 -- acc=97.069177%
#
#   valid loss:		0.03556
#   valid accuracy:	0.99540+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.09762 -- acc=97.100000%
#
#   valid loss:		0.03433
#   valid accuracy:	0.99575+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.09610 -- acc=97.070007%
#
#   valid loss:		0.03389
#   valid accuracy:	0.99600+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.09637 -- acc=97.097500%
#
#   valid loss:		0.03397
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.09507 -- acc=97.117502%
#
#   valid loss:		0.03502
#   valid accuracy:	0.99565+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.09596 -- acc=97.149175%
#
#   valid loss:		0.03455
#   valid accuracy:	0.99575+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.09536 -- acc=97.167507%
#
#   valid loss:		0.03606
#   valid accuracy:	0.99515+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.09645 -- acc=97.100000%
#
#   valid loss:		0.03439
#   valid accuracy:	0.99575+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.09499 -- acc=97.222502%
#
#   valid loss:		0.03375
#   valid accuracy:	0.99580+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.09648 -- acc=97.135844%
#
#   valid loss:		0.03550
#   valid accuracy:	0.99535+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.09526 -- acc=97.234173%
#
#   valid loss:		0.03744
#   valid accuracy:	0.99500+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.09472 -- acc=97.215842%
#
#   valid loss:		0.03549
#   valid accuracy:	0.99540+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.09683 -- acc=97.191679%
#
#   valid loss:		0.03526
#   valid accuracy:	0.99550+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.09594 -- acc=97.128343%
#
#   valid loss:		0.03483
#   valid accuracy:	0.99590+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.09675 -- acc=97.124172%
#
#   valid loss:		0.03528
#   valid accuracy:	0.99590+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.09635 -- acc=97.140004%
#
#   valid loss:		0.03427
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.09599 -- acc=97.194179%
#
#   valid loss:		0.03520
#   valid accuracy:	0.99595+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.09655 -- acc=97.197500%
#
#   valid loss:		0.03869
#   valid accuracy:	0.99495+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.09780 -- acc=97.149175%
#
#   valid loss:		0.03520
#   valid accuracy:	0.99575+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.09408 -- acc=97.255006%
#
#   valid loss:		0.03543
#   valid accuracy:	0.99585+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.09501 -- acc=97.196670%
#
#   valid loss:		0.03459
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.09602 -- acc=97.215842%
#
#   valid loss:		0.03516
#   valid accuracy:	0.99660+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.09494 -- acc=97.172507%
#
#   valid loss:		0.03455
#   valid accuracy:	0.99615+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.09473 -- acc=97.207501%
#
#   valid loss:		0.03409
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.09397 -- acc=97.257506%
#
#   valid loss:		0.03438
#   valid accuracy:	0.99595+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.09470 -- acc=97.191679%
#
#   valid loss:		0.03487
#   valid accuracy:	0.99580+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.09841 -- acc=97.060846%
#
#   valid loss:		0.03453
#   valid accuracy:	0.99645+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=3.73s -- loss=0.09446 -- acc=97.280008%
#
#   valid loss:		0.03442
#   valid accuracy:	0.99680+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=3.72s -- loss=0.09652 -- acc=97.201670%
#
#   valid loss:		0.03574
#   valid accuracy:	0.99570+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99981+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/riboswitch/mlp_t2_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/riboswitch/mlp_t2_44_best.ckpt
#   test  loss:		0.03200
#   test  accuracy:	0.99595+/-0.00000
#   test  auc-roc:	0.99991+/-0.00000
#   test  auc-pr:		0.99991+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/riboswitch_mlpt2_44_ug_so1k.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =2.55s
# Cumulative duration =2.55s
#
# 1
# Epoch duration =2.36s
# Cumulative duration =4.91s
#
# 2
# Epoch duration =2.43s
# Cumulative duration =7.34s
#
# 3
# Epoch duration =2.34s
# Cumulative duration =9.68s
#
# 4
# Epoch duration =2.37s
# Cumulative duration =12.05s
#
# 5
# Epoch duration =2.38s
# Cumulative duration =14.42s
#
# 6
# Epoch duration =2.33s
# Cumulative duration =16.75s
#
# 7
# Epoch duration =2.38s
# Cumulative duration =19.14s
#
# 8
# Epoch duration =2.33s
# Cumulative duration =21.47s
#
# 9
# Epoch duration =2.35s
# Cumulative duration =23.82s
#
# 10
# Epoch duration =2.36s
# Cumulative duration =26.18s
#
# 11
# Epoch duration =2.33s
# Cumulative duration =28.51s
#
# 12
# Epoch duration =2.37s
# Cumulative duration =30.89s
#
# 13
# Epoch duration =2.37s
# Cumulative duration =33.26s
#
# 14
# Epoch duration =2.34s
# Cumulative duration =35.6s
#
# 15
# Epoch duration =2.34s
# Cumulative duration =37.93s
#
# 16
# Epoch duration =2.36s
# Cumulative duration =40.29s
#
# 17
# Epoch duration =2.29s
# Cumulative duration =42.58s
#
# 18
# Epoch duration =2.32s
# Cumulative duration =44.9s
#
# 19
# Epoch duration =2.33s
# Cumulative duration =47.23s
#
# 20
# Epoch duration =2.33s
# Cumulative duration =49.56s
#
# 21
# Epoch duration =2.33s
# Cumulative duration =51.89s
#
# 22
# Epoch duration =2.31s
# Cumulative duration =54.2s
#
# 23
# Epoch duration =2.34s
# Cumulative duration =56.54s
#
# 24
# Epoch duration =2.32s
# Cumulative duration =58.87s
#
# 25
# Epoch duration =2.34s
# Cumulative duration =1min 1.2100000000000009s
#
# 26
# Epoch duration =2.32s
# Cumulative duration =1min 3.539999999999999s
#
# 27
# Epoch duration =2.34s
# Cumulative duration =1min 5.8799999999999955s
#
# 28
# Epoch duration =2.33s
# Cumulative duration =1min 8.209999999999994s
#
# 29
# Epoch duration =2.33s
# Cumulative duration =1min 10.540000000000006s
#
# 30
# Epoch duration =2.32s
# Cumulative duration =1min 12.870000000000005s
#
# 31
# Epoch duration =2.34s
# Cumulative duration =1min 15.209999999999994s
#
# 32
# Epoch duration =2.32s
# Cumulative duration =1min 17.53s
#
# 33
# Epoch duration =2.35s
# Cumulative duration =1min 19.879999999999995s
#
# 34
# Epoch duration =2.33s
# Cumulative duration =1min 22.209999999999994s
#
# 35
# Epoch duration =2.36s
# Cumulative duration =1min 24.569999999999993s
#
# 36
# Epoch duration =2.35s
# Cumulative duration =1min 26.92s
#
# 37
# Epoch duration =2.34s
# Cumulative duration =1min 29.260000000000005s
#
# 38
# Epoch duration =2.3s
# Cumulative duration =1min 31.560000000000002s
#
# 39
# Epoch duration =2.31s
# Cumulative duration =1min 33.879999999999995s
#
# 40
# Epoch duration =2.36s
# Cumulative duration =1min 36.230000000000004s
#
# 41
# Epoch duration =2.36s
# Cumulative duration =1min 38.599999999999994s
#
# 42
# Epoch duration =2.31s
# Cumulative duration =1min 40.91s
#
# 43
# Epoch duration =2.3s
# Cumulative duration =1min 43.209999999999994s
#
# 44
# Epoch duration =2.34s
# Cumulative duration =1min 45.56s
#
# 45
# Epoch duration =2.34s
# Cumulative duration =1min 47.900000000000006s
#
# 46
# Epoch duration =2.32s
# Cumulative duration =1min 50.22s
#
# 47
# Epoch duration =2.34s
# Cumulative duration =1min 52.56s
#
# 48
# Epoch duration =2.32s
# Cumulative duration =1min 54.879999999999995s
#
# 49
# Epoch duration =2.34s
# Cumulative duration =1min 57.22s
#
# 50
# Epoch duration =2.35s
# Cumulative duration =1min 59.56999999999999s
#
# 51
# Epoch duration =2.34s
# Cumulative duration =2min 1.9000000000000057s
#
# 52
# Epoch duration =2.31s
# Cumulative duration =2min 4.209999999999994s
#
# 53
# Epoch duration =2.32s
# Cumulative duration =2min 6.530000000000001s
#
# 54
# Epoch duration =2.31s
# Cumulative duration =2min 8.840000000000003s
#
# 55
# Epoch duration =2.32s
# Cumulative duration =2min 11.159999999999997s
#
# 56
# Epoch duration =2.39s
# Cumulative duration =2min 13.550000000000011s
#
# 57
# Epoch duration =2.3s
# Cumulative duration =2min 15.849999999999994s
#
# 58
# Epoch duration =2.32s
# Cumulative duration =2min 18.169999999999987s
#
# 59
# Epoch duration =2.32s
# Cumulative duration =2min 20.49000000000001s
#
# 60
# Epoch duration =2.34s
# Cumulative duration =2min 22.819999999999993s
#
# 61
# Epoch duration =2.32s
# Cumulative duration =2min 25.139999999999986s
#
# 62
# Epoch duration =2.39s
# Cumulative duration =2min 27.53s
#
# 63
# Epoch duration =2.31s
# Cumulative duration =2min 29.840000000000003s
#
# 64
# Epoch duration =2.33s
# Cumulative duration =2min 32.16999999999999s
#
# 65
# Epoch duration =2.32s
# Cumulative duration =2min 34.49000000000001s
#
# 66
# Epoch duration =2.34s
# Cumulative duration =2min 36.83000000000001s
#
# 67
# Epoch duration =2.37s
# Cumulative duration =2min 39.19999999999999s
#
# 68
# Epoch duration =2.39s
# Cumulative duration =2min 41.59s
#
# 69
# Epoch duration =2.38s
# Cumulative duration =2min 43.97s
#
# 70
# Epoch duration =2.38s
# Cumulative duration =2min 46.349999999999994s
#
# 71
# Epoch duration =2.33s
# Cumulative duration =2min 48.68000000000001s
#
# 72
# Epoch duration =2.33s
# Cumulative duration =2min 51.00999999999999s
#
# 73
# Epoch duration =2.34s
# Cumulative duration =2min 53.349999999999994s
#
# 74
# Epoch duration =2.33s
# Cumulative duration =2min 55.69s
#
# 75
# Epoch duration =2.34s
# Cumulative duration =2min 58.03s
#
# 76
# Epoch duration =2.35s
# Cumulative duration =3min 0.37999999999999545s
#
# 77
# Epoch duration =2.32s
# Cumulative duration =3min 2.6899999999999977s
#
# 78
# Epoch duration =2.31s
# Cumulative duration =3min 5.0s
#
# 79
# Epoch duration =2.33s
# Cumulative duration =3min 7.3300000000000125s
#
# 80
# Epoch duration =2.36s
# Cumulative duration =3min 9.689999999999998s
#
# 81
# Epoch duration =2.34s
# Cumulative duration =3min 12.039999999999992s
#
# 82
# Epoch duration =2.36s
# Cumulative duration =3min 14.400000000000006s
#
# 83
# Epoch duration =2.32s
# Cumulative duration =3min 16.72s
#
# 84
# Epoch duration =2.35s
# Cumulative duration =3min 19.069999999999993s
#
# 85
# Epoch duration =2.34s
# Cumulative duration =3min 21.400000000000006s
#
# 86
# Epoch duration =2.32s
# Cumulative duration =3min 23.72999999999999s
#
# 87
# Epoch duration =2.32s
# Cumulative duration =3min 26.05000000000001s
#
# 88
# Epoch duration =2.33s
# Cumulative duration =3min 28.370000000000005s
#
# 89
# Epoch duration =2.34s
# Cumulative duration =3min 30.710000000000008s
#
# 90
# Epoch duration =2.32s
# Cumulative duration =3min 33.03s
#
# 91
# Epoch duration =2.34s
# Cumulative duration =3min 35.370000000000005s
#
# 92
# Epoch duration =2.35s
# Cumulative duration =3min 37.72s
#
# 93
# Epoch duration =2.38s
# Cumulative duration =3min 40.099999999999994s
#
# 94
# Epoch duration =2.4s
# Cumulative duration =3min 42.5s
#
# 95
# Epoch duration =2.39s
# Cumulative duration =3min 44.889999999999986s
#
# 96
# Epoch duration =2.38s
# Cumulative duration =3min 47.27000000000001s
#
# 97
# Epoch duration =2.36s
# Cumulative duration =3min 49.639999999999986s
#
# 98
# Epoch duration =2.38s
# Cumulative duration =3min 52.02000000000001s
#
# 99
# Epoch duration =2.34s
# Cumulative duration =3min 54.360000000000014s
#
# 100
# Epoch duration =2.35s
# Cumulative duration =3min 56.72s
#
# 101
# Epoch duration =2.37s
# Cumulative duration =3min 59.08000000000001s
#
# 102
# Epoch duration =2.33s
# Cumulative duration =4min 1.4099999999999966s
#
# 103
# Epoch duration =2.32s
# Cumulative duration =4min 3.740000000000009s
#
# 104
# Epoch duration =2.3s
# Cumulative duration =4min 6.039999999999992s
#
# 105
# Epoch duration =2.32s
# Cumulative duration =4min 8.360000000000014s
#
# 106
# Epoch duration =2.33s
# Cumulative duration =4min 10.689999999999998s
#
# 107
# Epoch duration =2.31s
# Cumulative duration =4min 13.0s
#
# 108
# Epoch duration =2.32s
# Cumulative duration =4min 15.319999999999993s
#
# 109
# Epoch duration =2.35s
# Cumulative duration =4min 17.660000000000025s
#
# 110
# Epoch duration =2.34s
# Cumulative duration =4min 20.0s
#
# 111
# Epoch duration =2.31s
# Cumulative duration =4min 22.319999999999993s
#
# 112
# Epoch duration =2.33s
# Cumulative duration =4min 24.649999999999977s
#
# 113
# Epoch duration =2.33s
# Cumulative duration =4min 26.970000000000027s
#
# 114
# Epoch duration =2.34s
# Cumulative duration =4min 29.319999999999993s
#
# 115
# Epoch duration =2.39s
# Cumulative duration =4min 31.69999999999999s
#
# 116
# Epoch duration =2.34s
# Cumulative duration =4min 34.04000000000002s
#
# 117
# Epoch duration =2.34s
# Cumulative duration =4min 36.379999999999995s
#
# 118
# Epoch duration =2.32s
# Cumulative duration =4min 38.69999999999999s
#
# 119
# Epoch duration =2.32s
# Cumulative duration =4min 41.02999999999997s
#
# 120
# Epoch duration =2.35s
# Cumulative duration =4min 43.379999999999995s
#
# 121
# Epoch duration =2.34s
# Cumulative duration =4min 45.70999999999998s
#
# 122
# Epoch duration =2.34s
# Cumulative duration =4min 48.05000000000001s
#
# 123
# Epoch duration =2.34s
# Cumulative duration =4min 50.389999999999986s
#
# 124
# Epoch duration =2.34s
# Cumulative duration =4min 52.73000000000002s
#
# 125
# Epoch duration =2.33s
# Cumulative duration =4min 55.06999999999999s
#
# 126
# Epoch duration =2.31s
# Cumulative duration =4min 57.379999999999995s
#
# 127
# Epoch duration =2.32s
# Cumulative duration =4min 59.69999999999999s
#
# 128
# Epoch duration =2.33s
# Cumulative duration =5min 2.0299999999999727s
#
# 129
# Epoch duration =2.34s
# Cumulative duration =5min 4.3700000000000045s
#
# 130
# Epoch duration =2.33s
# Cumulative duration =5min 6.699999999999989s
#
# 131
# Epoch duration =2.31s
# Cumulative duration =5min 9.019999999999982s
#
# 132
# Epoch duration =2.32s
# Cumulative duration =5min 11.329999999999984s
#
# 133
# Epoch duration =2.32s
# Cumulative duration =5min 13.649999999999977s
#
# 134
# Epoch duration =2.34s
# Cumulative duration =5min 15.990000000000009s
#
# 135
# Epoch duration =2.32s
# Cumulative duration =5min 18.310000000000002s
#
# 136
# Epoch duration =2.33s
# Cumulative duration =5min 20.639999999999986s
#
# 137
# Epoch duration =2.3s
# Cumulative duration =5min 22.94999999999999s
#
# 138
# Epoch duration =2.33s
# Cumulative duration =5min 25.279999999999973s
#
# 139
# Epoch duration =2.32s
# Cumulative duration =5min 27.600000000000023s
#
# 140
# Epoch duration =2.39s
# Cumulative duration =5min 29.99000000000001s
#
# 141
# Epoch duration =2.32s
# Cumulative duration =5min 32.30000000000001s
#
# 142
# Epoch duration =2.35s
# Cumulative duration =5min 34.64999999999998s
#
# 143
# Epoch duration =2.38s
# Cumulative duration =5min 37.02999999999997s
#
# 144
# Epoch duration =2.33s
# Cumulative duration =5min 39.360000000000014s
#
# 145
# Epoch duration =2.33s
# Cumulative duration =5min 41.69s
#
# 146
# Epoch duration =2.34s
# Cumulative duration =5min 44.02999999999997s
#
# 147
# Epoch duration =2.31s
# Cumulative duration =5min 46.339999999999975s
#
# 148
# Epoch duration =2.35s
# Cumulative duration =5min 48.69s
#
# 149
# Epoch duration =2.31s
# Cumulative duration =5min 51.0s
#
# 150
# Epoch duration =2.32s
# Cumulative duration =5min 53.31999999999999s
#
# 151
# Epoch duration =2.33s
# Cumulative duration =5min 55.64999999999998s
#
# 152
# Epoch duration =2.35s
# Cumulative duration =5min 58.0s
#
# 153
# Epoch duration =2.37s
# Cumulative duration =6min 0.37999999999999545s
#
# 154
# Epoch duration =2.33s
# Cumulative duration =6min 2.6999999999999886s
#
# 155
# Epoch duration =2.35s
# Cumulative duration =6min 5.050000000000011s
#
# 156
# Epoch duration =2.34s
# Cumulative duration =6min 7.389999999999986s
#
# 157
# Epoch duration =2.31s
# Cumulative duration =6min 9.70999999999998s
#
# 158
# Epoch duration =2.35s
# Cumulative duration =6min 12.060000000000002s
#
# 159
# Epoch duration =2.35s
# Cumulative duration =6min 14.410000000000025s
#
# 160
# Epoch duration =2.32s
# Cumulative duration =6min 16.730000000000018s
#
# 161
# Epoch duration =2.31s
# Cumulative duration =6min 19.04000000000002s
#
# 162
# Epoch duration =2.35s
# Cumulative duration =6min 21.389999999999986s
#
# 163
# Epoch duration =2.34s
# Cumulative duration =6min 23.730000000000018s
#
# 164
# Epoch duration =2.35s
# Cumulative duration =6min 26.079999999999984s
#
# 165
# Epoch duration =2.37s
# Cumulative duration =6min 28.45999999999998s
#
# 166
# Epoch duration =2.35s
# Cumulative duration =6min 30.80000000000001s
#
# 167
# Epoch duration =2.32s
# Cumulative duration =6min 33.129999999999995s
#
# 168
# Epoch duration =2.33s
# Cumulative duration =6min 35.44999999999999s
#
# 169
# Epoch duration =2.31s
# Cumulative duration =6min 37.76999999999998s
#
# 170
# Epoch duration =2.34s
# Cumulative duration =6min 40.110000000000014s
#
# 171
# Epoch duration =2.33s
# Cumulative duration =6min 42.44s
#
# 172
# Epoch duration =2.35s
# Cumulative duration =6min 44.80000000000001s
#
# 173
# Epoch duration =2.34s
# Cumulative duration =6min 47.139999999999986s
#
# 174
# Epoch duration =2.31s
# Cumulative duration =6min 49.44s
#
# 175
# Epoch duration =2.34s
# Cumulative duration =6min 51.77999999999997s
#
# 176
# Epoch duration =2.33s
# Cumulative duration =6min 54.110000000000014s
#
# 177
# Epoch duration =2.33s
# Cumulative duration =6min 56.44s
#
# 178
# Epoch duration =2.34s
# Cumulative duration =6min 58.77999999999997s
#
# 179
# Epoch duration =2.38s
# Cumulative duration =7min 1.170000000000016s
#
# 180
# Epoch duration =2.35s
# Cumulative duration =7min 3.509999999999991s
#
# 181
# Epoch duration =2.33s
# Cumulative duration =7min 5.850000000000023s
#
# 182
# Epoch duration =2.31s
# Cumulative duration =7min 8.160000000000025s
#
# 183
# Epoch duration =2.33s
# Cumulative duration =7min 10.480000000000018s
#
# 184
# Epoch duration =2.33s
# Cumulative duration =7min 12.810000000000002s
#
# 185
# Epoch duration =2.34s
# Cumulative duration =7min 15.160000000000025s
#
# 186
# Epoch duration =2.36s
# Cumulative duration =7min 17.519999999999982s
#
# 187
# Epoch duration =2.34s
# Cumulative duration =7min 19.860000000000014s
#
# 188
# Epoch duration =2.33s
# Cumulative duration =7min 22.189999999999998s
#
# 189
# Epoch duration =2.35s
# Cumulative duration =7min 24.54000000000002s
#
# 190
# Epoch duration =2.32s
# Cumulative duration =7min 26.860000000000014s
#
# 191
# Epoch duration =2.32s
# Cumulative duration =7min 29.180000000000007s
#
# 192
# Epoch duration =2.32s
# Cumulative duration =7min 31.5s
#
# 193
# Epoch duration =2.35s
# Cumulative duration =7min 33.860000000000014s
#
# 194
# Epoch duration =2.4s
# Cumulative duration =7min 36.25999999999999s
#
# 195
# Epoch duration =2.32s
# Cumulative duration =7min 38.579999999999984s
#
# 196
# Epoch duration =2.34s
# Cumulative duration =7min 40.920000000000016s
#
# 197
# Epoch duration =2.37s
# Cumulative duration =7min 43.29000000000002s
#
# 198
# Epoch duration =2.34s
# Cumulative duration =7min 45.629999999999995s
#
# 199
# Epoch duration =2.31s
# Cumulative duration =7min 47.94s
#
# 200
# Epoch duration =2.33s
# Cumulative duration =7min 50.26999999999998s
#
# 201
# Epoch duration =2.35s
# Cumulative duration =7min 52.629999999999995s
#
# 202
# Epoch duration =2.35s
# Cumulative duration =7min 54.97000000000003s
#
# 203
# Epoch duration =2.34s
# Cumulative duration =7min 57.31s
#
# 204
# Epoch duration =2.35s
# Cumulative duration =7min 59.660000000000025s
#
# 205
# Epoch duration =2.33s
# Cumulative duration =8min 1.990000000000009s
#
# 206
# Epoch duration =2.34s
# Cumulative duration =8min 4.329999999999984s
#
# 207
# Epoch duration =2.34s
# Cumulative duration =8min 6.670000000000016s
#
# 208
# Epoch duration =2.33s
# Cumulative duration =8min 9.0s
#
# 209
# Epoch duration =2.34s
# Cumulative duration =8min 11.350000000000023s
#
# 210
# Epoch duration =2.36s
# Cumulative duration =8min 13.70999999999998s
#
# 211
# Epoch duration =2.32s
# Cumulative duration =8min 16.029999999999973s
#
# 212
# Epoch duration =2.36s
# Cumulative duration =8min 18.389999999999986s
#
# 213
# Epoch duration =2.35s
# Cumulative duration =8min 20.74000000000001s
#
# 214
# Epoch duration =2.4s
# Cumulative duration =8min 23.139999999999986s
#
# 215
# Epoch duration =2.35s
# Cumulative duration =8min 25.480000000000018s
#
# 216
# Epoch duration =2.35s
# Cumulative duration =8min 27.829999999999984s
#
# 217
# Epoch duration =2.35s
# Cumulative duration =8min 30.189999999999998s
#
# 218
# Epoch duration =2.34s
# Cumulative duration =8min 32.52999999999997s
#
# 219
# Epoch duration =2.33s
# Cumulative duration =8min 34.85000000000002s
#
# 220
# Epoch duration =2.32s
# Cumulative duration =8min 37.16999999999996s
#
# 221
# Epoch duration =2.33s
# Cumulative duration =8min 39.5s
#
# 222
# Epoch duration =2.34s
# Cumulative duration =8min 41.84000000000003s
#
# 223
# Epoch duration =2.33s
# Cumulative duration =8min 44.16999999999996s
#
# 224
# Epoch duration =2.31s
# Cumulative duration =8min 46.48000000000002s
#
# 225
# Epoch duration =2.37s
# Cumulative duration =8min 48.85000000000002s
#
# 226
# Epoch duration =2.37s
# Cumulative duration =8min 51.22000000000003s
#
# 227
# Epoch duration =2.34s
# Cumulative duration =8min 53.57000000000005s
#
# 228
# Epoch duration =2.33s
# Cumulative duration =8min 55.89999999999998s
#
# 229
# Epoch duration =2.36s
# Cumulative duration =8min 58.25999999999999s
#
# 230
# Epoch duration =2.32s
# Cumulative duration =9min 0.5800000000000409s
#
# 231
# Epoch duration =2.36s
# Cumulative duration =9min 2.9400000000000546s
#
# 232
# Epoch duration =2.35s
# Cumulative duration =9min 5.2999999999999545s
#
# 233
# Epoch duration =2.32s
# Cumulative duration =9min 7.6200000000000045s
#
# 234
# Epoch duration =2.32s
# Cumulative duration =9min 9.940000000000055s
#
# 235
# Epoch duration =2.38s
# Cumulative duration =9min 12.330000000000041s
#
# 236
# Epoch duration =2.4s
# Cumulative duration =9min 14.730000000000018s
#
# 237
# Epoch duration =2.34s
# Cumulative duration =9min 17.059999999999945s
#
# 238
# Epoch duration =2.32s
# Cumulative duration =9min 19.389999999999986s
#
# 239
# Epoch duration =2.32s
# Cumulative duration =9min 21.700000000000045s
#
# 240
# Epoch duration =2.34s
# Cumulative duration =9min 24.039999999999964s
#
# 241
# Epoch duration =2.36s
# Cumulative duration =9min 26.399999999999977s
#
# 242
# Epoch duration =2.35s
# Cumulative duration =9min 28.75s
#
# 243
# Epoch duration =2.31s
# Cumulative duration =9min 31.059999999999945s
#
# 244
# Epoch duration =2.33s
# Cumulative duration =9min 33.389999999999986s
#
# 245
# Epoch duration =2.34s
# Cumulative duration =9min 35.73000000000002s
#
# 246
# Epoch duration =2.34s
# Cumulative duration =9min 38.07000000000005s
#
# 247
# Epoch duration =2.34s
# Cumulative duration =9min 40.40999999999997s
#
# 248
# Epoch duration =2.34s
# Cumulative duration =9min 42.75s
#
# 249
# Epoch duration =2.33s
# Cumulative duration =9min 45.09000000000003s
#
# 250
# Epoch duration =2.35s
# Cumulative duration =9min 47.42999999999995s
#
# 251
# Epoch duration =2.31s
# Cumulative duration =9min 49.74000000000001s
#
# 252
# Epoch duration =2.35s
# Cumulative duration =9min 52.09000000000003s
#
# 253
# Epoch duration =2.36s
# Cumulative duration =9min 54.450000000000045s
#
# 254
# Epoch duration =2.34s
# Cumulative duration =9min 56.77999999999997s
#
# 255
# Epoch duration =2.43s
# Cumulative duration =9min 59.22000000000003s
#
# 256
# Epoch duration =2.36s
# Cumulative duration =10min 1.580000000000041s
#
# 257
# Epoch duration =2.32s
# Cumulative duration =10min 3.8999999999999773s
#
# 258
# Epoch duration =2.36s
# Cumulative duration =10min 6.259999999999991s
#
# 259
# Epoch duration =2.32s
# Cumulative duration =10min 8.580000000000041s
#
# 260
# Epoch duration =2.3s
# Cumulative duration =10min 10.879999999999995s
#
# 261
# Epoch duration =2.37s
# Cumulative duration =10min 13.240000000000009s
#
# 262
# Epoch duration =2.37s
# Cumulative duration =10min 15.610000000000014s
#
# 263
# Epoch duration =2.33s
# Cumulative duration =10min 17.940000000000055s
#
# 264
# Epoch duration =2.36s
# Cumulative duration =10min 20.299999999999955s
#
# 265
# Epoch duration =2.37s
# Cumulative duration =10min 22.66999999999996s
#
# 266
# Epoch duration =2.32s
# Cumulative duration =10min 24.99000000000001s
#
# 267
# Epoch duration =2.33s
# Cumulative duration =10min 27.32000000000005s
#
# 268
# Epoch duration =2.34s
# Cumulative duration =10min 29.659999999999968s
#
# 269
# Epoch duration =2.32s
# Cumulative duration =10min 31.980000000000018s
#
# 270
# Epoch duration =2.34s
# Cumulative duration =10min 34.32000000000005s
#
# 271
# Epoch duration =2.33s
# Cumulative duration =10min 36.65999999999997s
#
# 272
# Epoch duration =2.34s
# Cumulative duration =10min 39.0s
#
# 273
# Epoch duration =2.38s
# Cumulative duration =10min 41.379999999999995s
#
# 274
# Epoch duration =2.37s
# Cumulative duration =10min 43.75s
#
# 275
# Epoch duration =2.33s
# Cumulative duration =10min 46.08000000000004s
#
# 276
# Epoch duration =2.32s
# Cumulative duration =10min 48.39999999999998s
#
# 277
# Epoch duration =2.33s
# Cumulative duration =10min 50.74000000000001s
#
# 278
# Epoch duration =2.33s
# Cumulative duration =10min 53.07000000000005s
#
# 279
# Epoch duration =2.36s
# Cumulative duration =10min 55.42999999999995s
#
# 280
# Epoch duration =2.34s
# Cumulative duration =10min 57.76999999999998s
#
# 281
# Epoch duration =2.39s
# Cumulative duration =11min 0.14999999999997726s
#
# 282
# Epoch duration =2.36s
# Cumulative duration =11min 2.509999999999991s
#
# 283
# Epoch duration =2.32s
# Cumulative duration =11min 4.830000000000041s
#
# 284
# Epoch duration =2.32s
# Cumulative duration =11min 7.149999999999977s
#
# 285
# Epoch duration =2.33s
# Cumulative duration =11min 9.480000000000018s
#
# 286
# Epoch duration =2.31s
# Cumulative duration =11min 11.789999999999964s
#
# 287
# Epoch duration =2.35s
# Cumulative duration =11min 14.149999999999977s
#
# 288
# Epoch duration =2.29s
# Cumulative duration =11min 16.440000000000055s
#
# 289
# Epoch duration =2.31s
# Cumulative duration =11min 18.75s
#
# 290
# Epoch duration =2.33s
# Cumulative duration =11min 21.08000000000004s
#
# 291
# Epoch duration =2.32s
# Cumulative duration =11min 23.409999999999968s
#
# 292
# Epoch duration =2.35s
# Cumulative duration =11min 25.75999999999999s
#
# 293
# Epoch duration =2.34s
# Cumulative duration =11min 28.100000000000023s
#
# 294
# Epoch duration =2.31s
# Cumulative duration =11min 30.409999999999968s
#
# 295
# Epoch duration =2.32s
# Cumulative duration =11min 32.73000000000002s
#
# 296
# Epoch duration =2.33s
# Cumulative duration =11min 35.059999999999945s
#
# 297
# Epoch duration =2.31s
# Cumulative duration =11min 37.370000000000005s
#
# 298
# Epoch duration =2.34s
# Cumulative duration =11min 39.710000000000036s
#
# 299
# Epoch duration =2.37s
# Cumulative duration =11min 42.08000000000004s
#
# 300
# Epoch duration =2.32s
# Cumulative duration =11min 44.39999999999998s
#
# 301
# Epoch duration =2.31s
# Cumulative duration =11min 46.72000000000003s
#
# 302
# Epoch duration =2.34s
# Cumulative duration =11min 49.059999999999945s
#
# 303
# Epoch duration =2.34s
# Cumulative duration =11min 51.39999999999998s
#
# 304
# Epoch duration =2.33s
# Cumulative duration =11min 53.73000000000002s
#
# 305
# Epoch duration =2.32s
# Cumulative duration =11min 56.049999999999955s
#
# 306
# Epoch duration =2.31s
# Cumulative duration =11min 58.360000000000014s
#
# 307
# Epoch duration =2.33s
# Cumulative duration =12min 0.6900000000000546s
#
# 308
# Epoch duration =2.38s
# Cumulative duration =12min 3.07000000000005s
#
# 309
# Epoch duration =2.32s
# Cumulative duration =12min 5.389999999999986s
#
# 310
# Epoch duration =2.37s
# Cumulative duration =12min 7.759999999999991s
#
# 311
# Epoch duration =2.35s
# Cumulative duration =12min 10.110000000000014s
#
# 312
# Epoch duration =2.34s
# Cumulative duration =12min 12.450000000000045s
#
# 313
# Epoch duration =2.31s
# Cumulative duration =12min 14.759999999999991s
#
# 314
# Epoch duration =2.32s
# Cumulative duration =12min 17.08000000000004s
#
# 315
# Epoch duration =2.35s
# Cumulative duration =12min 19.42999999999995s
#
# 316
# Epoch duration =2.32s
# Cumulative duration =12min 21.75s
#
# 317
# Epoch duration =2.36s
# Cumulative duration =12min 24.110000000000014s
#
# 318
# Epoch duration =2.38s
# Cumulative duration =12min 26.49000000000001s
#
# 319
# Epoch duration =2.33s
# Cumulative duration =12min 28.82000000000005s
#
# 320
# Epoch duration =2.32s
# Cumulative duration =12min 31.149999999999977s
#
# 321
# Epoch duration =2.35s
# Cumulative duration =12min 33.5s
#
# 322
# Epoch duration =2.32s
# Cumulative duration =12min 35.82000000000005s
#
# 323
# Epoch duration =2.35s
# Cumulative duration =12min 38.16999999999996s
#
# 324
# Epoch duration =2.33s
# Cumulative duration =12min 40.5s
#
# 325
# Epoch duration =2.33s
# Cumulative duration =12min 42.83000000000004s
#
# 326
# Epoch duration =2.33s
# Cumulative duration =12min 45.15999999999997s
#
# 327
# Epoch duration =2.33s
# Cumulative duration =12min 47.49000000000001s
#
# 328
# Epoch duration =2.33s
# Cumulative duration =12min 49.82000000000005s
#
# 329
# Epoch duration =2.35s
# Cumulative duration =12min 52.15999999999997s
#
# 330
# Epoch duration =2.34s
# Cumulative duration =12min 54.50999999999999s
#
# 331
# Epoch duration =2.33s
# Cumulative duration =12min 56.84000000000003s
#
# 332
# Epoch duration =2.33s
# Cumulative duration =12min 59.16999999999996s
#
# 333
# Epoch duration =2.33s
# Cumulative duration =13min 1.5s
#
# 334
# Epoch duration =2.35s
# Cumulative duration =13min 3.840000000000032s
#
# 335
# Epoch duration =2.32s
# Cumulative duration =13min 6.159999999999968s
#
# 336
# Epoch duration =2.36s
# Cumulative duration =13min 8.519999999999982s
#
# 337
# Epoch duration =2.34s
# Cumulative duration =13min 10.850000000000023s
#
# 338
# Epoch duration =2.38s
# Cumulative duration =13min 13.230000000000018s
#
# 339
# Epoch duration =2.33s
# Cumulative duration =13min 15.559999999999945s
#
# 340
# Epoch duration =2.36s
# Cumulative duration =13min 17.91999999999996s
#
# 341
# Epoch duration =2.32s
# Cumulative duration =13min 20.24000000000001s
#
# 342
# Epoch duration =2.32s
# Cumulative duration =13min 22.559999999999945s
#
# 343
# Epoch duration =2.37s
# Cumulative duration =13min 24.92999999999995s
#
# 344
# Epoch duration =2.36s
# Cumulative duration =13min 27.299999999999955s
#
# 345
# Epoch duration =2.35s
# Cumulative duration =13min 29.649999999999977s
#
# 346
# Epoch duration =2.36s
# Cumulative duration =13min 32.00999999999999s
#
# 347
# Epoch duration =2.31s
# Cumulative duration =13min 34.32000000000005s
#
# 348
# Epoch duration =2.35s
# Cumulative duration =13min 36.66999999999996s
#
# 349
# Epoch duration =2.32s
# Cumulative duration =13min 38.99000000000001s
#
# 350
# Epoch duration =2.34s
# Cumulative duration =13min 41.33000000000004s
#
# 351
# Epoch duration =2.36s
# Cumulative duration =13min 43.700000000000045s
#
# 352
# Epoch duration =2.35s
# Cumulative duration =13min 46.039999999999964s
#
# 353
# Epoch duration =2.38s
# Cumulative duration =13min 48.41999999999996s
#
# 354
# Epoch duration =2.32s
# Cumulative duration =13min 50.74000000000001s
#
# 355
# Epoch duration =2.36s
# Cumulative duration =13min 53.10000000000002s
#
# 356
# Epoch duration =2.32s
# Cumulative duration =13min 55.41999999999996s
#
# 357
# Epoch duration =2.33s
# Cumulative duration =13min 57.75s
#
# 358
# Epoch duration =2.38s
# Cumulative duration =14min 0.12999999999999545s
#
# 359
# Epoch duration =2.33s
# Cumulative duration =14min 2.4600000000000364s
#
# 360
# Epoch duration =2.34s
# Cumulative duration =14min 4.7999999999999545s
#
# 361
# Epoch duration =2.34s
# Cumulative duration =14min 7.139999999999986s
#
# 362
# Epoch duration =2.34s
# Cumulative duration =14min 9.480000000000018s
#
# 363
# Epoch duration =2.35s
# Cumulative duration =14min 11.830000000000041s
#
# 364
# Epoch duration =2.36s
# Cumulative duration =14min 14.190000000000055s
#
# 365
# Epoch duration =2.34s
# Cumulative duration =14min 16.529999999999973s
#
# 366
# Epoch duration =2.36s
# Cumulative duration =14min 18.889999999999986s
#
# 367
# Epoch duration =2.34s
# Cumulative duration =14min 21.230000000000018s
#
# 368
# Epoch duration =2.33s
# Cumulative duration =14min 23.549999999999955s
#
# 369
# Epoch duration =2.33s
# Cumulative duration =14min 25.879999999999995s
#
# 370
# Epoch duration =2.33s
# Cumulative duration =14min 28.220000000000027s
#
# 371
# Epoch duration =2.33s
# Cumulative duration =14min 30.549999999999955s
#
# 372
# Epoch duration =2.33s
# Cumulative duration =14min 32.879999999999995s
#
# 373
# Epoch duration =2.33s
# Cumulative duration =14min 35.210000000000036s
#
# 374
# Epoch duration =2.31s
# Cumulative duration =14min 37.51999999999998s
#
# 375
# Epoch duration =2.33s
# Cumulative duration =14min 39.85000000000002s
#
# 376
# Epoch duration =2.34s
# Cumulative duration =14min 42.17999999999995s
#
# 377
# Epoch duration =2.38s
# Cumulative duration =14min 44.57000000000005s
#
# 378
# Epoch duration =2.36s
# Cumulative duration =14min 46.91999999999996s
#
# 379
# Epoch duration =2.31s
# Cumulative duration =14min 49.23000000000002s
#
# 380
# Epoch duration =2.32s
# Cumulative duration =14min 51.549999999999955s
#
# 381
# Epoch duration =2.36s
# Cumulative duration =14min 53.90999999999997s
#
# 382
# Epoch duration =2.34s
# Cumulative duration =14min 56.24000000000001s
#
# 383
# Epoch duration =2.36s
# Cumulative duration =14min 58.610000000000014s
#
# 384
# Epoch duration =2.32s
# Cumulative duration =15min 0.9199999999999591s
#
# 385
# Epoch duration =2.36s
# Cumulative duration =15min 3.2799999999999727s
#
# 386
# Epoch duration =2.33s
# Cumulative duration =15min 5.610000000000014s
#
# 387
# Epoch duration =2.32s
# Cumulative duration =15min 7.940000000000055s
#
# 388
# Epoch duration =2.32s
# Cumulative duration =15min 10.259999999999991s
#
# 389
# Epoch duration =2.35s
# Cumulative duration =15min 12.610000000000014s
#
# 390
# Epoch duration =2.35s
# Cumulative duration =15min 14.960000000000036s
#
# 391
# Epoch duration =2.35s
# Cumulative duration =15min 17.309999999999945s
#
# 392
# Epoch duration =2.34s
# Cumulative duration =15min 19.649999999999977s
#
# 393
# Epoch duration =2.32s
# Cumulative duration =15min 21.970000000000027s
#
# 394
# Epoch duration =2.32s
# Cumulative duration =15min 24.289999999999964s
#
# 395
# Epoch duration =2.4s
# Cumulative duration =15min 26.67999999999995s
#
# 396
# Epoch duration =2.34s
# Cumulative duration =15min 29.019999999999982s
#
# 397
# Epoch duration =2.35s
# Cumulative duration =15min 31.370000000000005s
#
# 398
# Epoch duration =2.35s
# Cumulative duration =15min 33.72000000000003s
#
# 399
# Epoch duration =2.34s
# Cumulative duration =15min 36.059999999999945s
#
# 400
# Epoch duration =2.33s
# Cumulative duration =15min 38.39999999999998s
#
# 401
# Epoch duration =2.33s
# Cumulative duration =15min 40.73000000000002s
#
# 402
# Epoch duration =2.34s
# Cumulative duration =15min 43.07000000000005s
#
# 403
# Epoch duration =2.36s
# Cumulative duration =15min 45.42999999999995s
#
# 404
# Epoch duration =2.32s
# Cumulative duration =15min 47.75999999999999s
#
# 405
# Epoch duration =2.42s
# Cumulative duration =15min 50.16999999999996s
#
# 406
# Epoch duration =2.34s
# Cumulative duration =15min 52.50999999999999s
#
# 407
# Epoch duration =2.34s
# Cumulative duration =15min 54.860000000000014s
#
# 408
# Epoch duration =2.32s
# Cumulative duration =15min 57.17999999999995s
#
# 409
# Epoch duration =2.34s
# Cumulative duration =15min 59.50999999999999s
#
# 410
# Epoch duration =2.33s
# Cumulative duration =16min 1.8500000000000227s
#
# 411
# Epoch duration =2.31s
# Cumulative duration =16min 4.159999999999968s
#
# 412
# Epoch duration =2.33s
# Cumulative duration =16min 6.490000000000009s
#
# 413
# Epoch duration =2.34s
# Cumulative duration =16min 8.830000000000041s
#
# 414
# Epoch duration =2.36s
# Cumulative duration =16min 11.190000000000055s
#
# 415
# Epoch duration =2.35s
# Cumulative duration =16min 13.539999999999964s
#
# 416
# Epoch duration =2.34s
# Cumulative duration =16min 15.879999999999995s
#
# 417
# Epoch duration =2.39s
# Cumulative duration =16min 18.269999999999982s
#
# 418
# Epoch duration =2.32s
# Cumulative duration =16min 20.600000000000023s
#
# 419
# Epoch duration =2.31s
# Cumulative duration =16min 22.909999999999968s
#
# 420
# Epoch duration =2.35s
# Cumulative duration =16min 25.25999999999999s
#
# 421
# Epoch duration =2.32s
# Cumulative duration =16min 27.58000000000004s
#
# 422
# Epoch duration =2.31s
# Cumulative duration =16min 29.889999999999986s
#
# 423
# Epoch duration =2.33s
# Cumulative duration =16min 32.22000000000003s
#
# 424
# Epoch duration =2.34s
# Cumulative duration =16min 34.559999999999945s
#
# 425
# Epoch duration =2.32s
# Cumulative duration =16min 36.889999999999986s
#
# 426
# Epoch duration =2.35s
# Cumulative duration =16min 39.24000000000001s
#
# 427
# Epoch duration =2.35s
# Cumulative duration =16min 41.59000000000003s
#
# 428
# Epoch duration =2.32s
# Cumulative duration =16min 43.89999999999998s
#
# 429
# Epoch duration =2.31s
# Cumulative duration =16min 46.210000000000036s
#
# 430
# Epoch duration =2.32s
# Cumulative duration =16min 48.539999999999964s
#
# 431
# Epoch duration =2.34s
# Cumulative duration =16min 50.879999999999995s
#
# 432
# Epoch duration =2.34s
# Cumulative duration =16min 53.22000000000003s
#
# 433
# Epoch duration =2.34s
# Cumulative duration =16min 55.549999999999955s
#
# 434
# Epoch duration =2.32s
# Cumulative duration =16min 57.870000000000005s
#
# 435
# Epoch duration =2.33s
# Cumulative duration =17min 0.20000000000004547s
#
# 436
# Epoch duration =2.31s
# Cumulative duration =17min 2.509999999999991s
#
# 437
# Epoch duration =2.42s
# Cumulative duration =17min 4.930000000000064s
#
# 438
# Epoch duration =2.37s
# Cumulative duration =17min 7.289999999999964s
#
# 439
# Epoch duration =2.32s
# Cumulative duration =17min 9.61999999999989s
#
# 440
# Epoch duration =2.33s
# Cumulative duration =17min 11.950000000000045s
#
# 441
# Epoch duration =2.32s
# Cumulative duration =17min 14.269999999999982s
#
# 442
# Epoch duration =2.35s
# Cumulative duration =17min 16.6099999999999s
#
# 443
# Epoch duration =2.36s
# Cumulative duration =17min 18.970000000000027s
#
# 444
# Epoch duration =2.31s
# Cumulative duration =17min 21.289999999999964s
#
# 445
# Epoch duration =2.34s
# Cumulative duration =17min 23.63000000000011s
#
# 446
# Epoch duration =2.34s
# Cumulative duration =17min 25.970000000000027s
#
# 447
# Epoch duration =2.32s
# Cumulative duration =17min 28.289999999999964s
#
# 448
# Epoch duration =2.34s
# Cumulative duration =17min 30.63000000000011s
#
# 449
# Epoch duration =2.31s
# Cumulative duration =17min 32.940000000000055s
#
# 450
# Epoch duration =2.35s
# Cumulative duration =17min 35.289999999999964s
#
# 451
# Epoch duration =2.34s
# Cumulative duration =17min 37.63000000000011s
#
# 452
# Epoch duration =2.34s
# Cumulative duration =17min 39.97000000000003s
#
# 453
# Epoch duration =2.34s
# Cumulative duration =17min 42.309999999999945s
#
# 454
# Epoch duration =2.3s
# Cumulative duration =17min 44.6099999999999s
#
# 455
# Epoch duration =2.32s
# Cumulative duration =17min 46.930000000000064s
#
# 456
# Epoch duration =2.32s
# Cumulative duration =17min 49.25s
#
# 457
# Epoch duration =2.34s
# Cumulative duration =17min 51.58999999999992s
#
# 458
# Epoch duration =2.34s
# Cumulative duration =17min 53.92000000000007s
#
# 459
# Epoch duration =2.33s
# Cumulative duration =17min 56.25s
#
# 460
# Epoch duration =2.33s
# Cumulative duration =17min 58.57999999999993s
#
# 461
# Epoch duration =2.33s
# Cumulative duration =18min 0.9100000000000819s
#
# 462
# Epoch duration =2.32s
# Cumulative duration =18min 3.230000000000018s
#
# 463
# Epoch duration =2.34s
# Cumulative duration =18min 5.569999999999936s
#
# 464
# Epoch duration =2.34s
# Cumulative duration =18min 7.910000000000082s
#
# 465
# Epoch duration =2.37s
# Cumulative duration =18min 10.279999999999973s
#
# 466
# Epoch duration =2.34s
# Cumulative duration =18min 12.61999999999989s
#
# 467
# Epoch duration =2.34s
# Cumulative duration =18min 14.960000000000036s
#
# 468
# Epoch duration =2.33s
# Cumulative duration =18min 17.289999999999964s
#
# 469
# Epoch duration =2.32s
# Cumulative duration =18min 19.61999999999989s
#
# 470
# Epoch duration =2.32s
# Cumulative duration =18min 21.930000000000064s
#
# 471
# Epoch duration =2.32s
# Cumulative duration =18min 24.25s
#
# 472
# Epoch duration =2.33s
# Cumulative duration =18min 26.579999999999927s
#
# 473
# Epoch duration =2.38s
# Cumulative duration =18min 28.960000000000036s
#
# 474
# Epoch duration =2.37s
# Cumulative duration =18min 31.339999999999918s
#
# 475
# Epoch duration =2.33s
# Cumulative duration =18min 33.66000000000008s
#
# 476
# Epoch duration =2.33s
# Cumulative duration =18min 35.99000000000001s
#
# 477
# Epoch duration =2.32s
# Cumulative duration =18min 38.309999999999945s
#
# 478
# Epoch duration =2.4s
# Cumulative duration =18min 40.710000000000036s
#
# 479
# Epoch duration =2.31s
# Cumulative duration =18min 43.02999999999997s
#
# 480
# Epoch duration =2.35s
# Cumulative duration =18min 45.38000000000011s
#
# 481
# Epoch duration =2.31s
# Cumulative duration =18min 47.690000000000055s
#
# 482
# Epoch duration =2.33s
# Cumulative duration =18min 50.01999999999998s
#
# 483
# Epoch duration =2.35s
# Cumulative duration =18min 52.36999999999989s
#
# 484
# Epoch duration =2.37s
# Cumulative duration =18min 54.74000000000001s
#
# 485
# Epoch duration =2.35s
# Cumulative duration =18min 57.08999999999992s
#
# 486
# Epoch duration =2.32s
# Cumulative duration =18min 59.41000000000008s
#
# 487
# Epoch duration =2.32s
# Cumulative duration =19min 1.7300000000000182s
#
# 488
# Epoch duration =2.34s
# Cumulative duration =19min 4.069999999999936s
#
# 489
# Epoch duration =2.34s
# Cumulative duration =19min 6.400000000000091s
#
# 490
# Epoch duration =2.32s
# Cumulative duration =19min 8.730000000000018s
#
# 491
# Epoch duration =2.34s
# Cumulative duration =19min 11.069999999999936s
#
# 492
# Epoch duration =2.36s
# Cumulative duration =19min 13.430000000000064s
#
# 493
# Epoch duration =2.36s
# Cumulative duration =19min 15.799999999999955s
#
# 494
# Epoch duration =2.3s
# Cumulative duration =19min 18.09999999999991s
#
# 495
# Epoch duration =2.35s
# Cumulative duration =19min 20.450000000000045s
#
# 496
# Epoch duration =2.31s
# Cumulative duration =19min 22.75999999999999s
#
# 497
# Epoch duration =2.32s
# Cumulative duration =19min 25.079999999999927s
#
# 498
# Epoch duration =2.36s
# Cumulative duration =19min 27.440000000000055s
#
# 499
# Epoch duration =2.35s
# Cumulative duration =19min 29.789999999999964s
#
# 500
# Epoch duration =2.33s
# Cumulative duration =19min 32.11999999999989s
#
# 501
# Epoch duration =2.34s
# Cumulative duration =19min 34.460000000000036s
#
# 502
# Epoch duration =2.33s
# Cumulative duration =19min 36.789999999999964s
#
# 503
# Epoch duration =2.33s
# Cumulative duration =19min 39.13000000000011s
#
# 504
# Epoch duration =2.35s
# Cumulative duration =19min 41.48000000000002s
#
# 505
# Epoch duration =2.31s
# Cumulative duration =19min 43.789999999999964s
#
# 506
# Epoch duration =2.35s
# Cumulative duration =19min 46.1400000000001s
#
# 507
# Epoch duration =2.35s
# Cumulative duration =19min 48.49000000000001s
#
# 508
# Epoch duration =2.32s
# Cumulative duration =19min 50.809999999999945s
#
# 509
# Epoch duration =2.33s
# Cumulative duration =19min 53.1400000000001s
#
# 510
# Epoch duration =2.31s
# Cumulative duration =19min 55.460000000000036s
#
# 511
# Epoch duration =2.37s
# Cumulative duration =19min 57.82999999999993s
#
# 512
# Epoch duration =2.38s
# Cumulative duration =20min 0.21000000000003638s
#
# 513
# Epoch duration =2.36s
# Cumulative duration =20min 2.5799999999999272s
#
# 514
# Epoch duration =2.33s
# Cumulative duration =20min 4.910000000000082s
#
# 515
# Epoch duration =2.32s
# Cumulative duration =20min 7.230000000000018s
#
# 516
# Epoch duration =2.32s
# Cumulative duration =20min 9.549999999999955s
#
# 517
# Epoch duration =2.38s
# Cumulative duration =20min 11.930000000000064s
#
# 518
# Epoch duration =2.35s
# Cumulative duration =20min 14.269999999999982s
#
# 519
# Epoch duration =2.36s
# Cumulative duration =20min 16.63000000000011s
#
# 520
# Epoch duration =2.33s
# Cumulative duration =20min 18.970000000000027s
#
# 521
# Epoch duration =2.34s
# Cumulative duration =20min 21.309999999999945s
#
# 522
# Epoch duration =2.33s
# Cumulative duration =20min 23.6400000000001s
#
# 523
# Epoch duration =2.33s
# Cumulative duration =20min 25.970000000000027s
#
# 524
# Epoch duration =2.33s
# Cumulative duration =20min 28.299999999999955s
#
# 525
# Epoch duration =2.38s
# Cumulative duration =20min 30.680000000000064s
#
# 526
# Epoch duration =2.34s
# Cumulative duration =20min 33.01999999999998s
#
# 527
# Epoch duration =2.31s
# Cumulative duration =20min 35.32999999999993s
#
# 528
# Epoch duration =2.39s
# Cumulative duration =20min 37.72000000000003s
#
# 529
# Epoch duration =2.31s
# Cumulative duration =20min 40.02999999999997s
#
# 530
# Epoch duration =2.34s
# Cumulative duration =20min 42.38000000000011s
#
# 531
# Epoch duration =2.33s
# Cumulative duration =20min 44.710000000000036s
#
# 532
# Epoch duration =2.32s
# Cumulative duration =20min 47.02999999999997s
#
# 533
# Epoch duration =2.33s
# Cumulative duration =20min 49.3599999999999s
#
# 534
# Epoch duration =2.31s
# Cumulative duration =20min 51.67000000000007s
#
# 535
# Epoch duration =2.32s
# Cumulative duration =20min 54.0s
#
# 536
# Epoch duration =2.36s
# Cumulative duration =20min 56.3599999999999s
#
# 537
# Epoch duration =2.36s
# Cumulative duration =20min 58.72000000000003s
#
# 538
# Epoch duration =2.33s
# Cumulative duration =21min 1.0499999999999545s
#
# 539
# Epoch duration =2.31s
# Cumulative duration =21min 3.3599999999999s
#
# 540
# Epoch duration =2.31s
# Cumulative duration =21min 5.680000000000064s
#
# 541
# Epoch duration =2.35s
# Cumulative duration =21min 8.019999999999982s
#
# 542
# Epoch duration =2.37s
# Cumulative duration =21min 10.3900000000001s
#
# 543
# Epoch duration =2.32s
# Cumulative duration =21min 12.710000000000036s
#
# 544
# Epoch duration =2.35s
# Cumulative duration =21min 15.069999999999936s
#
# 545
# Epoch duration =2.38s
# Cumulative duration =21min 17.450000000000045s
#
# 546
# Epoch duration =2.33s
# Cumulative duration =21min 19.779999999999973s
#
# 547
# Epoch duration =2.36s
# Cumulative duration =21min 22.1400000000001s
#
# 548
# Epoch duration =2.33s
# Cumulative duration =21min 24.470000000000027s
#
# 549
# Epoch duration =2.31s
# Cumulative duration =21min 26.779999999999973s
#
# 550
# Epoch duration =2.35s
# Cumulative duration =21min 29.13000000000011s
#
# 551
# Epoch duration =2.36s
# Cumulative duration =21min 31.49000000000001s
#
# 552
# Epoch duration =2.42s
# Cumulative duration =21min 33.91000000000008s
#
# 553
# Epoch duration =2.32s
# Cumulative duration =21min 36.24000000000001s
#
# 554
# Epoch duration =2.31s
# Cumulative duration =21min 38.539999999999964s
#
# 555
# Epoch duration =2.34s
# Cumulative duration =21min 40.88000000000011s
#
# 556
# Epoch duration =2.32s
# Cumulative duration =21min 43.200000000000045s
#
# 557
# Epoch duration =2.34s
# Cumulative duration =21min 45.539999999999964s
#
# 558
# Epoch duration =2.34s
# Cumulative duration =21min 47.88000000000011s
#
# 559
# Epoch duration =2.33s
# Cumulative duration =21min 50.210000000000036s
#
# 560
# Epoch duration =2.35s
# Cumulative duration =21min 52.549999999999955s
#
# 561
# Epoch duration =2.33s
# Cumulative duration =21min 54.8900000000001s
#
# 562
# Epoch duration =2.41s
# Cumulative duration =21min 57.299999999999955s
#
# 563
# Epoch duration =2.34s
# Cumulative duration =21min 59.6400000000001s
#
# 564
# Epoch duration =2.31s
# Cumulative duration =22min 1.9500000000000455s
#
# 565
# Epoch duration =2.38s
# Cumulative duration =22min 4.329999999999927s
#
# 566
# Epoch duration =2.32s
# Cumulative duration =22min 6.660000000000082s
#
# 567
# Epoch duration =2.39s
# Cumulative duration =22min 9.039999999999964s
#
# 568
# Epoch duration =2.41s
# Cumulative duration =22min 11.450000000000045s
#
# 569
# Epoch duration =2.35s
# Cumulative duration =22min 13.789999999999964s
#
# 570
# Epoch duration =2.35s
# Cumulative duration =22min 16.1400000000001s
#
# 571
# Epoch duration =2.36s
# Cumulative duration =22min 18.5s
#
# 572
# Epoch duration =2.41s
# Cumulative duration =22min 20.910000000000082s
#
# 573
# Epoch duration =2.34s
# Cumulative duration =22min 23.25s
#
# 574
# Epoch duration =2.32s
# Cumulative duration =22min 25.569999999999936s
#
# 575
# Epoch duration =2.36s
# Cumulative duration =22min 27.940000000000055s
#
# 576
# Epoch duration =2.34s
# Cumulative duration =22min 30.279999999999973s
#
# 577
# Epoch duration =2.32s
# Cumulative duration =22min 32.59999999999991s
#
# 578
# Epoch duration =2.36s
# Cumulative duration =22min 34.960000000000036s
#
# 579
# Epoch duration =2.33s
# Cumulative duration =22min 37.289999999999964s
#
# 580
# Epoch duration =2.33s
# Cumulative duration =22min 39.61999999999989s
#
# 581
# Epoch duration =2.35s
# Cumulative duration =22min 41.97000000000003s
#
# 582
# Epoch duration =2.38s
# Cumulative duration =22min 44.34999999999991s
#
# 583
# Epoch duration =2.35s
# Cumulative duration =22min 46.700000000000045s
#
# 584
# Epoch duration =2.34s
# Cumulative duration =22min 49.039999999999964s
#
# 585
# Epoch duration =2.33s
# Cumulative duration =22min 51.38000000000011s
#
# 586
# Epoch duration =2.37s
# Cumulative duration =22min 53.75s
#
# 587
# Epoch duration =2.36s
# Cumulative duration =22min 56.1099999999999s
#
# 588
# Epoch duration =2.34s
# Cumulative duration =22min 58.450000000000045s
#
# 589
# Epoch duration =2.33s
# Cumulative duration =23min 0.7899999999999636s
#
# 590
# Epoch duration =2.32s
# Cumulative duration =23min 3.1099999999999s
#
# 591
# Epoch duration =2.35s
# Cumulative duration =23min 5.460000000000036s
#
# 592
# Epoch duration =2.38s
# Cumulative duration =23min 7.839999999999918s
#
# 593
# Epoch duration =2.34s
# Cumulative duration =23min 10.190000000000055s
#
# 594
# Epoch duration =2.33s
# Cumulative duration =23min 12.519999999999982s
#
# 595
# Epoch duration =2.32s
# Cumulative duration =23min 14.839999999999918s
#
# 596
# Epoch duration =2.35s
# Cumulative duration =23min 17.190000000000055s
#
# 597
# Epoch duration =2.4s
# Cumulative duration =23min 19.59999999999991s
#
# 598
# Epoch duration =2.39s
# Cumulative duration =23min 21.980000000000018s
#
# 599
# Epoch duration =2.33s
# Cumulative duration =23min 24.319999999999936s
#
# 600
# Epoch duration =2.33s
# Cumulative duration =23min 26.65000000000009s
#
# 601
# Epoch duration =2.36s
# Cumulative duration =23min 29.0s
#
# 602
# Epoch duration =2.34s
# Cumulative duration =23min 31.339999999999918s
#
# 603
# Epoch duration =2.33s
# Cumulative duration =23min 33.67000000000007s
#
# 604
# Epoch duration =2.32s
# Cumulative duration =23min 35.99000000000001s
#
# 605
# Epoch duration =2.33s
# Cumulative duration =23min 38.319999999999936s
#
# 606
# Epoch duration =2.37s
# Cumulative duration =23min 40.690000000000055s
#
# 607
# Epoch duration =2.34s
# Cumulative duration =23min 43.02999999999997s
#
# 608
# Epoch duration =2.35s
# Cumulative duration =23min 45.38000000000011s
#
# 609
# Epoch duration =2.38s
# Cumulative duration =23min 47.75999999999999s
#
# 610
# Epoch duration =2.35s
# Cumulative duration =23min 50.1099999999999s
#
# 611
# Epoch duration =2.31s
# Cumulative duration =23min 52.42000000000007s
#
# 612
# Epoch duration =2.37s
# Cumulative duration =23min 54.789999999999964s
#
# 613
# Epoch duration =2.35s
# Cumulative duration =23min 57.1400000000001s
#
# 614
# Epoch duration =2.33s
# Cumulative duration =23min 59.47000000000003s
#
# 615
# Epoch duration =2.31s
# Cumulative duration =24min 1.7799999999999727s
#
# 616
# Epoch duration =2.32s
# Cumulative duration =24min 4.099999999999909s
#
# 617
# Epoch duration =2.33s
# Cumulative duration =24min 6.430000000000064s
#
# 618
# Epoch duration =2.32s
# Cumulative duration =24min 8.75s
#
# 619
# Epoch duration =2.33s
# Cumulative duration =24min 11.079999999999927s
#
# 620
# Epoch duration =2.35s
# Cumulative duration =24min 13.430000000000064s
#
# 621
# Epoch duration =2.34s
# Cumulative duration =24min 15.769999999999982s
#
# 622
# Epoch duration =2.31s
# Cumulative duration =24min 18.079999999999927s
#
# 623
# Epoch duration =2.37s
# Cumulative duration =24min 20.450000000000045s
#
# 624
# Epoch duration =2.33s
# Cumulative duration =24min 22.779999999999973s
#
# 625
# Epoch duration =2.36s
# Cumulative duration =24min 25.13000000000011s
#
# 626
# Epoch duration =2.32s
# Cumulative duration =24min 27.450000000000045s
#
# 627
# Epoch duration =2.35s
# Cumulative duration =24min 29.799999999999955s
#
# 628
# Epoch duration =2.33s
# Cumulative duration =24min 32.11999999999989s
#
# 629
# Epoch duration =2.32s
# Cumulative duration =24min 34.440000000000055s
#
# 630
# Epoch duration =2.31s
# Cumulative duration =24min 36.75999999999999s
#
# 631
# Epoch duration =2.3s
# Cumulative duration =24min 39.059999999999945s
#
# 632
# Epoch duration =2.35s
# Cumulative duration =24min 41.41000000000008s
#
# 633
# Epoch duration =2.32s
# Cumulative duration =24min 43.72000000000003s
#
# 634
# Epoch duration =2.35s
# Cumulative duration =24min 46.07999999999993s
#
# 635
# Epoch duration =2.39s
# Cumulative duration =24min 48.460000000000036s
#
# 636
# Epoch duration =2.32s
# Cumulative duration =24min 50.789999999999964s
#
# 637
# Epoch duration =2.35s
# Cumulative duration =24min 53.13000000000011s
#
# 638
# Epoch duration =2.33s
# Cumulative duration =24min 55.460000000000036s
#
# 639
# Epoch duration =2.33s
# Cumulative duration =24min 57.789999999999964s
#
# 640
# Epoch duration =2.33s
# Cumulative duration =25min 0.10999999999989996s
#
# 641
# Epoch duration =2.33s
# Cumulative duration =25min 2.4500000000000455s
#
# 642
# Epoch duration =2.4s
# Cumulative duration =25min 4.849999999999909s
#
# 643
# Epoch duration =2.35s
# Cumulative duration =25min 7.210000000000036s
#
# 644
# Epoch duration =2.3s
# Cumulative duration =25min 9.509999999999991s
#
# 645
# Epoch duration =2.33s
# Cumulative duration =25min 11.839999999999918s
#
# 646
# Epoch duration =2.34s
# Cumulative duration =25min 14.180000000000064s
#
# 647
# Epoch duration =2.32s
# Cumulative duration =25min 16.5s
#
# 648
# Epoch duration =2.33s
# Cumulative duration =25min 18.829999999999927s
#
# 649
# Epoch duration =2.31s
# Cumulative duration =25min 21.1400000000001s
#
# 650
# Epoch duration =2.35s
# Cumulative duration =25min 23.49000000000001s
#
# 651
# Epoch duration =2.32s
# Cumulative duration =25min 25.819999999999936s
#
# 652
# Epoch duration =2.32s
# Cumulative duration =25min 28.1400000000001s
#
# 653
# Epoch duration =2.32s
# Cumulative duration =25min 30.460000000000036s
#
# 654
# Epoch duration =2.34s
# Cumulative duration =25min 32.789999999999964s
#
# 655
# Epoch duration =2.35s
# Cumulative duration =25min 35.15000000000009s
#
# 656
# Epoch duration =2.32s
# Cumulative duration =25min 37.47000000000003s
#
# 657
# Epoch duration =2.32s
# Cumulative duration =25min 39.799999999999955s
#
# 658
# Epoch duration =2.34s
# Cumulative duration =25min 42.1400000000001s
#
# 659
# Epoch duration =2.31s
# Cumulative duration =25min 44.450000000000045s
#
# 660
# Epoch duration =2.33s
# Cumulative duration =25min 46.77999999999997s
#
# 661
# Epoch duration =2.35s
# Cumulative duration =25min 49.13000000000011s
#
# 662
# Epoch duration =2.32s
# Cumulative duration =25min 51.450000000000045s
#
# 663
# Epoch duration =2.35s
# Cumulative duration =25min 53.799999999999955s
#
# 664
# Epoch duration =2.37s
# Cumulative duration =25min 56.17000000000007s
#
# 665
# Epoch duration =2.33s
# Cumulative duration =25min 58.5s
#
# 666
# Epoch duration =2.37s
# Cumulative duration =26min 0.8699999999998909s
#
# 667
# Epoch duration =2.31s
# Cumulative duration =26min 3.1800000000000637s
#
# 668
# Epoch duration =2.33s
# Cumulative duration =26min 5.509999999999991s
#
# 669
# Epoch duration =2.32s
# Cumulative duration =26min 7.829999999999927s
#
# 670
# Epoch duration =2.33s
# Cumulative duration =26min 10.160000000000082s
#
# 671
# Epoch duration =2.34s
# Cumulative duration =26min 12.5s
#
# 672
# Epoch duration =2.34s
# Cumulative duration =26min 14.839999999999918s
#
# 673
# Epoch duration =2.32s
# Cumulative duration =26min 17.160000000000082s
#
# ...
# Cumulative duration =30min 27.59999999999991s
#
# 781
# Epoch duration =2.34s
# Cumulative duration =30min 29.950000000000045s
#
# 782
# Epoch duration =2.32s
# Cumulative duration =30min 32.26999999999998s
#
# 783
# Epoch duration =2.32s
# Cumulative duration =30min 34.58999999999992s
#
# 784
# Epoch duration =2.36s
# Cumulative duration =30min 36.950000000000045s
#
# 785
# Epoch duration =2.43s
# Cumulative duration =30min 39.38000000000011s
#
# 786
# Epoch duration =2.32s
# Cumulative duration =30min 41.700000000000045s
#
# 787
# Epoch duration =2.32s
# Cumulative duration =30min 44.01999999999998s
#
# 788
# Epoch duration =2.34s
# Cumulative duration =30min 46.3599999999999s
#
# 789
# Epoch duration =2.32s
# Cumulative duration =30min 48.680000000000064s
#
# 790
# Epoch duration =2.36s
# Cumulative duration =30min 51.039999999999964s
#
# 791
# Epoch duration =2.32s
# Cumulative duration =30min 53.34999999999991s
#
# 792
# Epoch duration =2.31s
# Cumulative duration =30min 55.66000000000008s
#
# 793
# Epoch duration =2.32s
# Cumulative duration =30min 57.99000000000001s
#
# 794
# Epoch duration =2.35s
# Cumulative duration =31min 0.33999999999991815s
#
# 795
# Epoch duration =2.36s
# Cumulative duration =31min 2.6900000000000546s
#
# 796
# Epoch duration =2.31s
# Cumulative duration =31min 5.0s
#
# 797
# Epoch duration =2.33s
# Cumulative duration =31min 7.329999999999927s
#
# 798
# Epoch duration =2.35s
# Cumulative duration =31min 9.680000000000064s
#
# 799
# Epoch duration =2.33s
# Cumulative duration =31min 12.009999999999991s
#
# 800
# Epoch duration =2.31s
# Cumulative duration =31min 14.319999999999936s
#
# 801
# Epoch duration =2.36s
# Cumulative duration =31min 16.680000000000064s
#
# 802
# Epoch duration =2.31s
# Cumulative duration =31min 18.99000000000001s
#
# 803
# Epoch duration =2.35s
# Cumulative duration =31min 21.339999999999918s
#
# 804
# Epoch duration =2.3s
# Cumulative duration =31min 23.6400000000001s
#
# 805
# Epoch duration =2.32s
# Cumulative duration =31min 25.960000000000036s
#
# 806
# Epoch duration =2.31s
# Cumulative duration =31min 28.269999999999982s
#
# 807
# Epoch duration =2.32s
# Cumulative duration =31min 30.589999999999918s
#
# 808
# Epoch duration =2.33s
# Cumulative duration =31min 32.92000000000007s
#
# 809
# Epoch duration =2.34s
# Cumulative duration =31min 35.25999999999999s
#
# 810
# Epoch duration =2.3s
# Cumulative duration =31min 37.559999999999945s
#
# 811
# Epoch duration =2.3s
# Cumulative duration =31min 39.8599999999999s
#
# 812
# Epoch duration =2.31s
# Cumulative duration =31min 42.17000000000007s
#
# 813
# Epoch duration =2.33s
# Cumulative duration =31min 44.5s
#
# 814
# Epoch duration =2.3s
# Cumulative duration =31min 46.799999999999955s
#
# 815
# Epoch duration =2.33s
# Cumulative duration =31min 49.11999999999989s
#
# 816
# Epoch duration =2.31s
# Cumulative duration =31min 51.440000000000055s
#
# 817
# Epoch duration =2.34s
# Cumulative duration =31min 53.76999999999998s
#
# 818
# Epoch duration =2.33s
# Cumulative duration =31min 56.09999999999991s
#
# 819
# Epoch duration =2.36s
# Cumulative duration =31min 58.460000000000036s
#
# 820
# Epoch duration =2.32s
# Cumulative duration =32min 0.7899999999999636s
#
# 821
# Epoch duration =2.32s
# Cumulative duration =32min 3.1099999999999s
#
# 822
# Epoch duration =2.33s
# Cumulative duration =32min 5.430000000000064s
#
# 823
# Epoch duration =2.33s
# Cumulative duration =32min 7.759999999999991s
#
# 824
# Epoch duration =2.31s
# Cumulative duration =32min 10.069999999999936s
#
# 825
# Epoch duration =2.34s
# Cumulative duration =32min 12.410000000000082s
#
# 826
# Epoch duration =2.35s
# Cumulative duration =32min 14.759999999999991s
#
# 827
# Epoch duration =2.32s
# Cumulative duration =32min 17.079999999999927s
#
# 828
# Epoch duration =2.31s
# Cumulative duration =32min 19.3900000000001s
#
# 829
# Epoch duration =2.31s
# Cumulative duration =32min 21.700000000000045s
#
# 830
# Epoch duration =2.35s
# Cumulative duration =32min 24.059999999999945s
#
# 831
# Epoch duration =2.32s
# Cumulative duration =32min 26.38000000000011s
#
# 832
# Epoch duration =2.41s
# Cumulative duration =32min 28.789999999999964s
#
# 833
# Epoch duration =2.33s
# Cumulative duration =32min 31.11999999999989s
#
# 834
# Epoch duration =2.3s
# Cumulative duration =32min 33.42000000000007s
#
# 835
# Epoch duration =2.31s
# Cumulative duration =32min 35.73000000000002s
#
# 836
# Epoch duration =2.31s
# Cumulative duration =32min 38.039999999999964s
#
# 837
# Epoch duration =2.35s
# Cumulative duration =32min 40.38000000000011s
#
# 838
# Epoch duration =2.34s
# Cumulative duration =32min 42.72000000000003s
#
# 839
# Epoch duration =2.31s
# Cumulative duration =32min 45.02999999999997s
#
# 840
# Epoch duration =2.31s
# Cumulative duration =32min 47.33999999999992s
#
# 841
# Epoch duration =2.34s
# Cumulative duration =32min 49.680000000000064s
#
# 842
# Epoch duration =2.32s
# Cumulative duration =32min 52.0s
#
# 843
# Epoch duration =2.3s
# Cumulative duration =32min 54.299999999999955s
#
# 844
# Epoch duration =2.32s
# Cumulative duration =32min 56.63000000000011s
#
# 845
# Epoch duration =2.33s
# Cumulative duration =32min 58.960000000000036s
#
# 846
# Epoch duration =2.3s
# Cumulative duration =33min 1.259999999999991s
#
# 847
# Epoch duration =2.35s
# Cumulative duration =33min 3.6099999999999s
#
# 848
# Epoch duration =2.31s
# Cumulative duration =33min 5.910000000000082s
#
# 849
# Epoch duration =2.33s
# Cumulative duration =33min 8.240000000000009s
#
# 850
# Epoch duration =2.35s
# Cumulative duration =33min 10.589999999999918s
#
# 851
# Epoch duration =2.31s
# Cumulative duration =33min 12.910000000000082s
#
# 852
# Epoch duration =2.3s
# Cumulative duration =33min 15.210000000000036s
#
# 853
# Epoch duration =2.34s
# Cumulative duration =33min 17.549999999999955s
#
# 854
# Epoch duration =2.31s
# Cumulative duration =33min 19.8599999999999s
#
# 855
# Epoch duration =2.3s
# Cumulative duration =33min 22.160000000000082s
#
# 856
# Epoch duration =2.31s
# Cumulative duration =33min 24.470000000000027s
#
# 857
# Epoch duration =2.31s
# Cumulative duration =33min 26.779999999999973s
#
# 858
# Epoch duration =2.33s
# Cumulative duration =33min 29.1099999999999s
#
# 859
# Epoch duration =2.32s
# Cumulative duration =33min 31.440000000000055s
#
# 860
# Epoch duration =2.3s
# Cumulative duration =33min 33.73000000000002s
#
# 861
# Epoch duration =2.31s
# Cumulative duration =33min 36.039999999999964s
#
# 862
# Epoch duration =2.33s
# Cumulative duration =33min 38.36999999999989s
#
# 863
# Epoch duration =2.33s
# Cumulative duration =33min 40.700000000000045s
#
# 864
# Epoch duration =2.32s
# Cumulative duration =33min 43.01999999999998s
#
# 865
# Epoch duration =2.3s
# Cumulative duration =33min 45.319999999999936s
#
# 866
# Epoch duration =2.31s
# Cumulative duration =33min 47.61999999999989s
#
# 867
# Epoch duration =2.34s
# Cumulative duration =33min 49.960000000000036s
#
# 868
# Epoch duration =2.3s
# Cumulative duration =33min 52.25999999999999s
#
# 869
# Epoch duration =2.32s
# Cumulative duration =33min 54.57999999999993s
#
# 870
# Epoch duration =2.36s
# Cumulative duration =33min 56.930000000000064s
#
# 871
# Epoch duration =2.33s
# Cumulative duration =33min 59.25999999999999s
#
# 872
# Epoch duration =2.33s
# Cumulative duration =34min 1.599999999999909s
#
# 873
# Epoch duration =2.31s
# Cumulative duration =34min 3.900000000000091s
#
# 874
# Epoch duration =2.31s
# Cumulative duration =34min 6.210000000000036s
#
# 875
# Epoch duration =2.32s
# Cumulative duration =34min 8.5300000000002s
#
# 876
# Epoch duration =2.32s
# Cumulative duration =34min 10.849999999999909s
#
# 877
# Epoch duration =2.31s
# Cumulative duration =34min 13.159999999999854s
#
# 878
# Epoch duration =2.36s
# Cumulative duration =34min 15.519999999999982s
#
# 879
# Epoch duration =2.32s
# Cumulative duration =34min 17.84999999999991s
#
# 880
# Epoch duration =2.29s
# Cumulative duration =34min 20.13000000000011s
#
# 881
# Epoch duration =2.3s
# Cumulative duration =34min 22.440000000000055s
#
# 882
# Epoch duration =2.35s
# Cumulative duration =34min 24.789999999999964s
#
# 883
# Epoch duration =2.31s
# Cumulative duration =34min 27.09999999999991s
#
# 884
# Epoch duration =2.33s
# Cumulative duration =34min 29.429999999999836s
#
# 885
# Epoch duration =2.32s
# Cumulative duration =34min 31.75s
#
# 886
# Epoch duration =2.33s
# Cumulative duration =34min 34.07999999999993s
#
# 887
# Epoch duration =2.31s
# Cumulative duration =34min 36.38999999999987s
#
# 888
# Epoch duration =2.32s
# Cumulative duration =34min 38.69999999999982s
#
# 889
# Epoch duration =2.32s
# Cumulative duration =34min 41.0300000000002s
#
# 890
# Epoch duration =2.33s
# Cumulative duration =34min 43.34999999999991s
#
# 891
# Epoch duration =2.31s
# Cumulative duration =34min 45.67000000000007s
#
# 892
# Epoch duration =2.3s
# Cumulative duration =34min 47.9699999999998s
#
# 893
# Epoch duration =2.32s
# Cumulative duration =34min 50.2800000000002s
#
# 894
# Epoch duration =2.41s
# Cumulative duration =34min 52.69999999999982s
#
# 895
# Epoch duration =2.32s
# Cumulative duration =34min 55.01999999999998s
#
# 896
# Epoch duration =2.31s
# Cumulative duration =34min 57.32999999999993s
#
# 897
# Epoch duration =2.3s
# Cumulative duration =34min 59.63000000000011s
#
# 898
# Epoch duration =2.36s
# Cumulative duration =35min 1.9800000000000182s
#
# 899
# Epoch duration =2.33s
# Cumulative duration =35min 4.309999999999945s
#
# 900
# Epoch duration =2.3s
# Cumulative duration =35min 6.610000000000127s
#
# 901
# Epoch duration =2.32s
# Cumulative duration =35min 8.929999999999836s
#
# 902
# Epoch duration =2.32s
# Cumulative duration =35min 11.25s
#
# 903
# Epoch duration =2.33s
# Cumulative duration =35min 13.579999999999927s
#
# 904
# Epoch duration =2.35s
# Cumulative duration =35min 15.929999999999836s
#
# 905
# Epoch duration =2.3s
# Cumulative duration =35min 18.230000000000018s
#
# 906
# Epoch duration =2.32s
# Cumulative duration =35min 20.550000000000182s
#
# 907
# Epoch duration =2.32s
# Cumulative duration =35min 22.86999999999989s
#
# 908
# Epoch duration =2.31s
# Cumulative duration =35min 25.179999999999836s
#
# 909
# Epoch duration =2.3s
# Cumulative duration =35min 27.480000000000018s
#
# 910
# Epoch duration =2.29s
# Cumulative duration =35min 29.76000000000022s
#
# 911
# Epoch duration =2.32s
# Cumulative duration =35min 32.07999999999993s
#
# 912
# Epoch duration =2.31s
# Cumulative duration =35min 34.38999999999987s
#
# 913
# Epoch duration =2.31s
# Cumulative duration =35min 36.69999999999982s
#
# 914
# Epoch duration =2.31s
# Cumulative duration =35min 39.01000000000022s
#
# 915
# Epoch duration =2.31s
# Cumulative duration =35min 41.309999999999945s
#
# 916
# Epoch duration =2.31s
# Cumulative duration =35min 43.63000000000011s
#
# 917
# Epoch duration =2.34s
# Cumulative duration =35min 45.9699999999998s
#
# 918
# Epoch duration =2.32s
# Cumulative duration =35min 48.289999999999964s
#
# 919
# Epoch duration =2.31s
# Cumulative duration =35min 50.59999999999991s
#
# 920
# Epoch duration =2.29s
# Cumulative duration =35min 52.88999999999987s
#
# 921
# Epoch duration =2.32s
# Cumulative duration =35min 55.19999999999982s
#
# 922
# Epoch duration =2.3s
# Cumulative duration =35min 57.51000000000022s
#
# 923
# Epoch duration =2.31s
# Cumulative duration =35min 59.809999999999945s
#
# 924
# Epoch duration =2.32s
# Cumulative duration =36min 2.1399999999998727s
#
# 925
# Epoch duration =2.35s
# Cumulative duration =36min 4.480000000000018s
#
# 926
# Epoch duration =2.34s
# Cumulative duration =36min 6.820000000000164s
#
# 927
# Epoch duration =2.32s
# Cumulative duration =36min 9.150000000000091s
#
# 928
# Epoch duration =2.34s
# Cumulative duration =36min 11.489999999999782s
#
# 929
# Epoch duration =2.32s
# Cumulative duration =36min 13.800000000000182s
#
# 930
# Epoch duration =2.33s
# Cumulative duration =36min 16.139999999999873s
#
# 931
# Epoch duration =2.36s
# Cumulative duration =36min 18.5s
#
# 932
# Epoch duration =2.29s
# Cumulative duration =36min 20.800000000000182s
#
# 933
# Epoch duration =2.35s
# Cumulative duration =36min 23.15000000000009s
#
# 934
# Epoch duration =2.36s
# Cumulative duration =36min 25.5s
#
# 935
# Epoch duration =2.3s
# Cumulative duration =36min 27.809999999999945s
#
# 936
# Epoch duration =2.3s
# Cumulative duration =36min 30.110000000000127s
#
# 937
# Epoch duration =2.31s
# Cumulative duration =36min 32.42000000000007s
#
# 938
# Epoch duration =2.34s
# Cumulative duration =36min 34.76000000000022s
#
# 939
# Epoch duration =2.35s
# Cumulative duration =36min 37.11000000000013s
#
# 940
# Epoch duration =2.34s
# Cumulative duration =36min 39.440000000000055s
#
# 941
# Epoch duration =2.31s
# Cumulative duration =36min 41.76000000000022s
#
# 942
# Epoch duration =2.32s
# Cumulative duration =36min 44.07999999999993s
#
# 943
# Epoch duration =2.31s
# Cumulative duration =36min 46.38999999999987s
#
# 944
# Epoch duration =2.32s
# Cumulative duration =36min 48.710000000000036s
#
# 945
# Epoch duration =2.28s
# Cumulative duration =36min 50.98999999999978s
#
# 946
# Epoch duration =2.33s
# Cumulative duration =36min 53.320000000000164s
#
# 947
# Epoch duration =2.32s
# Cumulative duration =36min 55.63999999999987s
#
# 948
# Epoch duration =2.3s
# Cumulative duration =36min 57.940000000000055s
#
# 949
# Epoch duration =2.31s
# Cumulative duration =37min 0.25s
#
# 950
# Epoch duration =2.33s
# Cumulative duration =37min 2.5700000000001637s
#
# 951
# Epoch duration =2.33s
# Cumulative duration =37min 4.9099999999998545s
#
# 952
# Epoch duration =2.34s
# Cumulative duration =37min 7.25s
#
# 953
# Epoch duration =2.33s
# Cumulative duration =37min 9.579999999999927s
#
# 954
# Epoch duration =2.36s
# Cumulative duration =37min 11.940000000000055s
#
# 955
# Epoch duration =2.3s
# Cumulative duration =37min 14.239999999999782s
#
# 956
# Epoch duration =2.35s
# Cumulative duration =37min 16.590000000000146s
#
# 957
# Epoch duration =2.39s
# Cumulative duration =37min 18.980000000000018s
#
# 958
# Epoch duration =2.34s
# Cumulative duration =37min 21.320000000000164s
#
# 959
# Epoch duration =2.3s
# Cumulative duration =37min 23.61999999999989s
#
# 960
# Epoch duration =2.3s
# Cumulative duration =37min 25.920000000000073s
#
# 961
# Epoch duration =2.34s
# Cumulative duration =37min 28.26000000000022s
#
# 962
# Epoch duration =2.31s
# Cumulative duration =37min 30.570000000000164s
#
# 963
# Epoch duration =2.34s
# Cumulative duration =37min 32.90000000000009s
#
# 964
# Epoch duration =2.32s
# Cumulative duration =37min 35.2199999999998s
#
# 965
# Epoch duration =2.29s
# Cumulative duration =37min 37.51000000000022s
#
# 966
# Epoch duration =2.34s
# Cumulative duration =37min 39.84999999999991s
#
# 967
# Epoch duration =2.31s
# Cumulative duration =37min 42.159999999999854s
#
# 968
# Epoch duration =2.3s
# Cumulative duration =37min 44.460000000000036s
#
# 969
# Epoch duration =2.35s
# Cumulative duration =37min 46.809999999999945s
#
# 970
# Epoch duration =2.32s
# Cumulative duration =37min 49.13000000000011s
#
# 971
# Epoch duration =2.32s
# Cumulative duration =37min 51.44999999999982s
#
# 972
# Epoch duration =2.3s
# Cumulative duration =37min 53.75s
#
# 973
# Epoch duration =2.4s
# Cumulative duration =37min 56.15000000000009s
#
# 974
# Epoch duration =2.32s
# Cumulative duration =37min 58.48000000000002s
#
# 975
# Epoch duration =2.31s
# Cumulative duration =38min 0.7899999999999636s
#
# 976
# Epoch duration =2.3s
# Cumulative duration =38min 3.0900000000001455s
#
# 977
# Epoch duration =2.34s
# Cumulative duration =38min 5.429999999999836s
#
# 978
# Epoch duration =2.34s
# Cumulative duration =38min 7.769999999999982s
#
# 979
# Epoch duration =2.31s
# Cumulative duration =38min 10.079999999999927s
#
# 980
# Epoch duration =2.33s
# Cumulative duration =38min 12.409999999999854s
#
# 981
# Epoch duration =2.38s
# Cumulative duration =38min 14.789999999999964s
#
# 982
# Epoch duration =2.31s
# Cumulative duration =38min 17.09999999999991s
#
# 983
# Epoch duration =2.31s
# Cumulative duration =38min 19.409999999999854s
#
# 984
# Epoch duration =2.32s
# Cumulative duration =38min 21.73999999999978s
#
# 985
# Epoch duration =2.29s
# Cumulative duration =38min 24.0300000000002s
#
# 986
# Epoch duration =2.32s
# Cumulative duration =38min 26.34999999999991s
#
# 987
# Epoch duration =2.3s
# Cumulative duration =38min 28.65000000000009s
#
# 988
# Epoch duration =2.3s
# Cumulative duration =38min 30.960000000000036s
#
# 989
# Epoch duration =2.31s
# Cumulative duration =38min 33.26999999999998s
#
# 990
# Epoch duration =2.31s
# Cumulative duration =38min 35.57999999999993s
#
# 991
# Epoch duration =2.3s
# Cumulative duration =38min 37.88000000000011s
#
# 992
# Epoch duration =2.3s
# Cumulative duration =38min 40.17000000000007s
#
# 993
# Epoch duration =2.3s
# Cumulative duration =38min 42.48000000000002s
#
# 994
# Epoch duration =2.32s
# Cumulative duration =38min 44.80000000000018s
#
# 995
# Epoch duration =2.32s
# Cumulative duration =38min 47.11999999999989s
#
# 996
# Epoch duration =2.31s
# Cumulative duration =38min 49.429999999999836s
#
# 997
# Epoch duration =2.3s
# Cumulative duration =38min 51.73000000000002s
#
# 998
# Epoch duration =2.32s
# Cumulative duration =38min 54.05000000000018s
#
# 999
# Epoch duration =2.3s
# Cumulative duration =38min 56.34999999999991s
#
# Saving scores to Arrays/riboswitch_mlpt2_44_ug_so1k.npy

# %%
#load values
savepath = 'Arrays/riboswitch_mlpt2_44_ug_so1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, vmax=1.0, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
