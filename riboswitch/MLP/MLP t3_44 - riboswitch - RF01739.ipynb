# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/riboswitch_100k_d5.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 10.02s

# %%
simalign_file = '../../../data_RFAM/riboswitch_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<>>>>>><<<<<<<<<>>>>>>>>>)))))<<<<>>>>'

# %%
SS
# Out:
# '.......:.......:......:.......:......:.....(...(.....(....(...(.......,.........,......,......,......<.......-.....<....<...<....<...<..................._....._......_......_.........................>....>....>...>.....>.......>....<...<...<.......-.......-....<...<....<.....<....<...<..............._......._....._....._........_......_..............>....>...>....-........>...>....>.....-..........>....>....>.....,.......................................................,.....,......,......,.............................................................)...)....)....)...).....-....<...<...<....<..........................._........_........_......_........................................>....>.....>....>.......:....:.............:....:....:.......:....:....:....:....:....:.....:......:.....:.....:......:......'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    
    layer2 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                        # concat, embedding, variational_normal, variational_softmax, + more
              'num_units': 44,
              'norm': 'batch',          # if removed, automatically adds bias instead
              'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
              'dropout': 0.5,           # if removed, default is no dropout
             }
    
    layer3 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/riboswitch'
param_path = os.path.join(save_path, 'mlp_t3_44')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 816, 1, 4)
# layer2: dense_0
# (?, 44)
# layer3: dense_0_batch
# (?, 44)
# layer4: dense_0_active
# (?, 44)
# layer5: dense_0_dropout
# (?, 44)
# layer6: dense_1
# (?, 1)
# layer7: dense_1_bias
# (?, 1)
# layer8: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=40, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=3.83s -- loss=0.47656 -- acc=76.343334%
#
#   valid loss:		0.15236
#   valid accuracy:	0.98090+/-0.00000
#   valid auc-roc:	0.99833+/-0.00000
#   valid auc-pr:		0.99844+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.20376 -- acc=92.328343%
#
#   valid loss:		0.07097
#   valid accuracy:	0.99010+/-0.00000
#   valid auc-roc:	0.99946+/-0.00000
#   valid auc-pr:		0.99950+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=3.86s -- loss=0.15891 -- acc=94.120842%
#
#   valid loss:		0.05136
#   valid accuracy:	0.99150+/-0.00000
#   valid auc-roc:	0.99964+/-0.00000
#   valid auc-pr:		0.99966+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.13892 -- acc=94.921672%
#
#   valid loss:		0.04139
#   valid accuracy:	0.99200+/-0.00000
#   valid auc-roc:	0.99974+/-0.00000
#   valid auc-pr:		0.99975+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=3.76s -- loss=0.12941 -- acc=95.277508%
#
#   valid loss:		0.03716
#   valid accuracy:	0.99465+/-0.00000
#   valid auc-roc:	0.99978+/-0.00000
#   valid auc-pr:		0.99978+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=3.88s -- loss=0.12386 -- acc=95.520842%
#
#   valid loss:		0.03515
#   valid accuracy:	0.99420+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=3.90s -- loss=0.11747 -- acc=95.800840%
#
#   valid loss:		0.03127
#   valid accuracy:	0.99435+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.11579 -- acc=95.860006%
#
#   valid loss:		0.03249
#   valid accuracy:	0.99380+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.11297 -- acc=96.039174%
#
#   valid loss:		0.03079
#   valid accuracy:	0.99450+/-0.00000
#   valid auc-roc:	0.99980+/-0.00000
#   valid auc-pr:		0.99980+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.11201 -- acc=96.024172%
#
#   valid loss:		0.02974
#   valid accuracy:	0.99490+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.11038 -- acc=96.183348%
#
#   valid loss:		0.02903
#   valid accuracy:	0.99530+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.10874 -- acc=96.280848%
#
#   valid loss:		0.02818
#   valid accuracy:	0.99545+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.10882 -- acc=96.261676%
#
#   valid loss:		0.02754
#   valid accuracy:	0.99550+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.10668 -- acc=96.272507%
#
#   valid loss:		0.02679
#   valid accuracy:	0.99645+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.10505 -- acc=96.410001%
#
#   valid loss:		0.02772
#   valid accuracy:	0.99585+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=3.61s -- loss=0.10502 -- acc=96.482508%
#
#   valid loss:		0.02792
#   valid accuracy:	0.99555+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.10400 -- acc=96.548345%
#
#   valid loss:		0.02693
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.10658 -- acc=96.414171%
#
#   valid loss:		0.02714
#   valid accuracy:	0.99600+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.10510 -- acc=96.434173%
#
#   valid loss:		0.02719
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.10537 -- acc=96.446675%
#
#   valid loss:		0.02827
#   valid accuracy:	0.99595+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=3.77s -- loss=0.10411 -- acc=96.554175%
#
#   valid loss:		0.02656
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.10063 -- acc=96.581678%
#
#   valid loss:		0.02762
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.10569 -- acc=96.497500%
#
#   valid loss:		0.02780
#   valid accuracy:	0.99585+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.10358 -- acc=96.517502%
#
#   valid loss:		0.02704
#   valid accuracy:	0.99635+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.10285 -- acc=96.539174%
#
#   valid loss:		0.02752
#   valid accuracy:	0.99660+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.10214 -- acc=96.643344%
#
#   valid loss:		0.02772
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.10033 -- acc=96.642504%
#
#   valid loss:		0.02824
#   valid accuracy:	0.99595+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.10320 -- acc=96.629173%
#
#   valid loss:		0.02883
#   valid accuracy:	0.99565+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.09865 -- acc=96.730003%
#
#   valid loss:		0.02750
#   valid accuracy:	0.99665+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.10395 -- acc=96.579178%
#
#   valid loss:		0.02766
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.10101 -- acc=96.681678%
#
#   valid loss:		0.02857
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=3.71s -- loss=0.10341 -- acc=96.625843%
#
#   valid loss:		0.02790
#   valid accuracy:	0.99645+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=3.77s -- loss=0.10065 -- acc=96.667507%
#
#   valid loss:		0.02735
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.10113 -- acc=96.729173%
#
#   valid loss:		0.02780
#   valid accuracy:	0.99670+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.09912 -- acc=96.824172%
#
#   valid loss:		0.02851
#   valid accuracy:	0.99635+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.10291 -- acc=96.695840%
#
#   valid loss:		0.02797
#   valid accuracy:	0.99640+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=3.66s -- loss=0.09849 -- acc=96.753345%
#
#   valid loss:		0.02841
#   valid accuracy:	0.99640+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=3.75s -- loss=0.09962 -- acc=96.783348%
#
#   valid loss:		0.02801
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=3.65s -- loss=0.10090 -- acc=96.733343%
#
#   valid loss:		0.02810
#   valid accuracy:	0.99635+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=3.68s -- loss=0.10025 -- acc=96.766677%
#
#   valid loss:		0.02735
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=3.67s -- loss=0.10225 -- acc=96.649175%
#
#   valid loss:		0.02800
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.10068 -- acc=96.767507%
#
#   valid loss:		0.02844
#   valid accuracy:	0.99660+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=3.89s -- loss=0.09973 -- acc=96.792509%
#
#   valid loss:		0.02798
#   valid accuracy:	0.99660+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.10086 -- acc=96.761676%
#
#   valid loss:		0.02826
#   valid accuracy:	0.99695+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=3.88s -- loss=0.10055 -- acc=96.730843%
#
#   valid loss:		0.02786
#   valid accuracy:	0.99670+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=3.70s -- loss=0.10000 -- acc=96.812501%
#
#   valid loss:		0.02846
#   valid accuracy:	0.99675+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=3.75s -- loss=0.10024 -- acc=96.775848%
#
#   valid loss:		0.02815
#   valid accuracy:	0.99690+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=3.77s -- loss=0.09838 -- acc=96.899170%
#
#   valid loss:		0.02763
#   valid accuracy:	0.99690+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=3.78s -- loss=0.09912 -- acc=96.821672%
#
#   valid loss:		0.02825
#   valid accuracy:	0.99585+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=3.80s -- loss=0.09825 -- acc=96.892509%
#
#   valid loss:		0.02821
#   valid accuracy:	0.99700+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=3.82s -- loss=0.09950 -- acc=96.845845%
#
#   valid loss:		0.02831
#   valid accuracy:	0.99625+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.10077 -- acc=96.767507%
#
#   valid loss:		0.02757
#   valid accuracy:	0.99665+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.09974 -- acc=96.795000%
#
#   valid loss:		0.02847
#   valid accuracy:	0.99665+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.10088 -- acc=96.798340%
#
#   valid loss:		0.02852
#   valid accuracy:	0.99675+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=3.76s -- loss=0.10071 -- acc=96.796670%
#
#   valid loss:		0.02890
#   valid accuracy:	0.99685+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=3.78s -- loss=0.10275 -- acc=96.709171%
#
#   valid loss:		0.02869
#   valid accuracy:	0.99730+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=3.69s -- loss=0.09795 -- acc=96.980008%
#
#   valid loss:		0.02821
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=3.64s -- loss=0.09998 -- acc=96.890009%
#
#   valid loss:		0.02859
#   valid accuracy:	0.99680+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=3.60s -- loss=0.10065 -- acc=96.806671%
#
#   valid loss:		0.02933
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=3.74s -- loss=0.10013 -- acc=96.829173%
#
#   valid loss:		0.02979
#   valid accuracy:	0.99620+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=3.63s -- loss=0.09909 -- acc=96.841674%
#
#   valid loss:		0.02936
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/riboswitch/mlp_t3_44_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/riboswitch/mlp_t3_44_best.ckpt
#   test  loss:		0.02712
#   test  accuracy:	0.99600+/-0.00000
#   test  auc-roc:	0.99990+/-0.00000
#   test  auc-pr:		0.99990+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

# %%
num_plots=np.linspace(0,30000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/riboswitch_mlpt3_44_ug_so1k.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =2.34s
# Cumulative duration =2.34s
#
# 1
# Epoch duration =2.33s
# Cumulative duration =4.68s
#
# 2
# Epoch duration =2.36s
# Cumulative duration =7.04s
#
# 3
# Epoch duration =2.34s
# Cumulative duration =9.38s
#
# 4
# Epoch duration =2.35s
# Cumulative duration =11.73s
#
# 5
# Epoch duration =2.34s
# Cumulative duration =14.07s
#
# 6
# Epoch duration =2.33s
# Cumulative duration =16.4s
#
# 7
# Epoch duration =2.34s
# Cumulative duration =18.74s
#
# 8
# Epoch duration =2.33s
# Cumulative duration =21.07s
#
# 9
# Epoch duration =2.35s
# Cumulative duration =23.42s
#
# 10
# Epoch duration =2.46s
# Cumulative duration =25.88s
#
# 11
# Epoch duration =2.34s
# Cumulative duration =28.22s
#
# 12
# Epoch duration =2.39s
# Cumulative duration =30.61s
#
# 13
# Epoch duration =2.35s
# Cumulative duration =32.96s
#
# 14
# Epoch duration =2.33s
# Cumulative duration =35.29s
#
# 15
# Epoch duration =2.32s
# Cumulative duration =37.62s
#
# 16
# Epoch duration =2.32s
# Cumulative duration =39.94s
#
# 17
# Epoch duration =2.34s
# Cumulative duration =42.28s
#
# 18
# Epoch duration =2.32s
# Cumulative duration =44.6s
#
# 19
# Epoch duration =2.35s
# Cumulative duration =46.94s
#
# 20
# Epoch duration =2.34s
# Cumulative duration =49.28s
#
# 21
# Epoch duration =2.34s
# Cumulative duration =51.62s
#
# 22
# Epoch duration =2.34s
# Cumulative duration =53.96s
#
# 23
# Epoch duration =2.36s
# Cumulative duration =56.32s
#
# 24
# Epoch duration =2.33s
# Cumulative duration =58.66s
#
# 25
# Epoch duration =2.36s
# Cumulative duration =1min 1.009999999999998s
#
# 26
# Epoch duration =2.36s
# Cumulative duration =1min 3.3800000000000026s
#
# 27
# Epoch duration =2.36s
# Cumulative duration =1min 5.730000000000004s
#
# 28
# Epoch duration =2.33s
# Cumulative duration =1min 8.060000000000002s
#
# 29
# Epoch duration =2.32s
# Cumulative duration =1min 10.39s
#
# 30
# Epoch duration =2.41s
# Cumulative duration =1min 12.799999999999997s
#
# 31
# Epoch duration =2.32s
# Cumulative duration =1min 15.120000000000005s
#
# 32
# Epoch duration =2.34s
# Cumulative duration =1min 17.459999999999994s
#
# 33
# Epoch duration =2.31s
# Cumulative duration =1min 19.769999999999996s
#
# 34
# Epoch duration =2.34s
# Cumulative duration =1min 22.120000000000005s
#
# 35
# Epoch duration =2.35s
# Cumulative duration =1min 24.459999999999994s
#
# 36
# Epoch duration =2.34s
# Cumulative duration =1min 26.799999999999997s
#
# 37
# Epoch duration =2.38s
# Cumulative duration =1min 29.180000000000007s
#
# 38
# Epoch duration =2.34s
# Cumulative duration =1min 31.519999999999996s
#
# 39
# Epoch duration =2.34s
# Cumulative duration =1min 33.849999999999994s
#
# 40
# Epoch duration =2.34s
# Cumulative duration =1min 36.19s
#
# 41
# Epoch duration =2.35s
# Cumulative duration =1min 38.540000000000006s
#
# 42
# Epoch duration =2.36s
# Cumulative duration =1min 40.900000000000006s
#
# 43
# Epoch duration =2.35s
# Cumulative duration =1min 43.260000000000005s
#
# 44
# Epoch duration =2.34s
# Cumulative duration =1min 45.59s
#
# 45
# Epoch duration =2.37s
# Cumulative duration =1min 47.959999999999994s
#
# 46
# Epoch duration =2.33s
# Cumulative duration =1min 50.3s
#
# 47
# Epoch duration =2.34s
# Cumulative duration =1min 52.629999999999995s
#
# 48
# Epoch duration =2.36s
# Cumulative duration =1min 54.989999999999995s
#
# 49
# Epoch duration =2.34s
# Cumulative duration =1min 57.34s
#
# 50
# Epoch duration =2.37s
# Cumulative duration =1min 59.709999999999994s
#
# 51
# Epoch duration =2.35s
# Cumulative duration =2min 2.049999999999997s
#
# 52
# Epoch duration =2.34s
# Cumulative duration =2min 4.390000000000001s
#
# 53
# Epoch duration =2.38s
# Cumulative duration =2min 6.769999999999996s
#
# 54
# Epoch duration =2.38s
# Cumulative duration =2min 9.150000000000006s
#
# 55
# Epoch duration =2.36s
# Cumulative duration =2min 11.509999999999991s
#
# 56
# Epoch duration =2.34s
# Cumulative duration =2min 13.849999999999994s
#
# 57
# Epoch duration =2.38s
# Cumulative duration =2min 16.24000000000001s
#
# 58
# Epoch duration =2.36s
# Cumulative duration =2min 18.590000000000003s
#
# 59
# Epoch duration =2.34s
# Cumulative duration =2min 20.930000000000007s
#
# 60
# Epoch duration =2.35s
# Cumulative duration =2min 23.289999999999992s
#
# 61
# Epoch duration =2.34s
# Cumulative duration =2min 25.620000000000005s
#
# 62
# Epoch duration =2.35s
# Cumulative duration =2min 27.97s
#
# 63
# Epoch duration =2.36s
# Cumulative duration =2min 30.340000000000003s
#
# 64
# Epoch duration =2.34s
# Cumulative duration =2min 32.68000000000001s
#
# 65
# Epoch duration =2.35s
# Cumulative duration =2min 35.02000000000001s
#
# 66
# Epoch duration =2.36s
# Cumulative duration =2min 37.389999999999986s
#
# 67
# Epoch duration =2.34s
# Cumulative duration =2min 39.72999999999999s
#
# 68
# Epoch duration =2.35s
# Cumulative duration =2min 42.08000000000001s
#
# 69
# Epoch duration =2.39s
# Cumulative duration =2min 44.47s
#
# 70
# Epoch duration =2.39s
# Cumulative duration =2min 46.860000000000014s
#
# 71
# Epoch duration =2.32s
# Cumulative duration =2min 49.18000000000001s
#
# 72
# Epoch duration =2.33s
# Cumulative duration =2min 51.50999999999999s
#
# 73
# Epoch duration =2.33s
# Cumulative duration =2min 53.84s
#
# 74
# Epoch duration =2.33s
# Cumulative duration =2min 56.18000000000001s
#
# 75
# Epoch duration =2.33s
# Cumulative duration =2min 58.50999999999999s
#
# 76
# Epoch duration =2.38s
# Cumulative duration =3min 0.8899999999999864s
#
# 77
# Epoch duration =2.35s
# Cumulative duration =3min 3.240000000000009s
#
# 78
# Epoch duration =2.31s
# Cumulative duration =3min 5.550000000000011s
#
# 79
# Epoch duration =2.35s
# Cumulative duration =3min 7.900000000000006s
#
# 80
# Epoch duration =2.34s
# Cumulative duration =3min 10.240000000000009s
#
# 81
# Epoch duration =2.32s
# Cumulative duration =3min 12.550000000000011s
#
# 82
# Epoch duration =2.33s
# Cumulative duration =3min 14.879999999999995s
#
# 83
# Epoch duration =2.33s
# Cumulative duration =3min 17.210000000000008s
#
# 84
# Epoch duration =2.38s
# Cumulative duration =3min 19.590000000000003s
#
# 85
# Epoch duration =2.36s
# Cumulative duration =3min 21.94999999999999s
#
# 86
# Epoch duration =2.33s
# Cumulative duration =3min 24.28s
#
# 87
# Epoch duration =2.32s
# Cumulative duration =3min 26.599999999999994s
#
# 88
# Epoch duration =2.33s
# Cumulative duration =3min 28.930000000000007s
#
# 89
# Epoch duration =2.35s
# Cumulative duration =3min 31.28s
#
# 90
# Epoch duration =2.38s
# Cumulative duration =3min 33.66999999999999s
#
# 91
# Epoch duration =2.33s
# Cumulative duration =3min 36.0s
#
# 92
# Epoch duration =2.34s
# Cumulative duration =3min 38.34s
#
# 93
# Epoch duration =2.36s
# Cumulative duration =3min 40.69s
#
# 94
# Epoch duration =2.34s
# Cumulative duration =3min 43.03s
#
# 95
# Epoch duration =2.36s
# Cumulative duration =3min 45.389999999999986s
#
# 96
# Epoch duration =2.34s
# Cumulative duration =3min 47.72999999999999s
#
# 97
# Epoch duration =2.36s
# Cumulative duration =3min 50.09s
#
# 98
# Epoch duration =2.35s
# Cumulative duration =3min 52.44s
#
# 99
# Epoch duration =2.38s
# Cumulative duration =3min 54.81999999999999s
#
# 100
# Epoch duration =2.4s
# Cumulative duration =3min 57.22s
#
# 101
# Epoch duration =2.37s
# Cumulative duration =3min 59.58000000000001s
#
# 102
# Epoch duration =2.36s
# Cumulative duration =4min 1.9499999999999886s
#
# 103
# Epoch duration =2.34s
# Cumulative duration =4min 4.289999999999992s
#
# 104
# Epoch duration =2.33s
# Cumulative duration =4min 6.6200000000000045s
#
# 105
# Epoch duration =2.37s
# Cumulative duration =4min 9.0s
#
# 106
# Epoch duration =2.34s
# Cumulative duration =4min 11.330000000000013s
#
# 107
# Epoch duration =2.37s
# Cumulative duration =4min 13.710000000000008s
#
# 108
# Epoch duration =2.33s
# Cumulative duration =4min 16.04000000000002s
#
# 109
# Epoch duration =2.33s
# Cumulative duration =4min 18.370000000000005s
#
# 110
# Epoch duration =2.43s
# Cumulative duration =4min 20.80000000000001s
#
# 111
# Epoch duration =2.35s
# Cumulative duration =4min 23.149999999999977s
#
# 112
# Epoch duration =2.32s
# Cumulative duration =4min 25.470000000000027s
#
# 113
# Epoch duration =2.34s
# Cumulative duration =4min 27.819999999999993s
#
# 114
# Epoch duration =2.35s
# Cumulative duration =4min 30.160000000000025s
#
# 115
# Epoch duration =2.36s
# Cumulative duration =4min 32.51999999999998s
#
# 116
# Epoch duration =2.35s
# Cumulative duration =4min 34.879999999999995s
#
# 117
# Epoch duration =2.34s
# Cumulative duration =4min 37.22000000000003s
#
# 118
# Epoch duration =2.35s
# Cumulative duration =4min 39.56999999999999s
#
# 119
# Epoch duration =2.36s
# Cumulative duration =4min 41.93000000000001s
#
# 120
# Epoch duration =2.36s
# Cumulative duration =4min 44.29000000000002s
#
# 121
# Epoch duration =2.37s
# Cumulative duration =4min 46.660000000000025s
#
# 122
# Epoch duration =2.34s
# Cumulative duration =4min 49.0s
#
# 123
# Epoch duration =2.34s
# Cumulative duration =4min 51.339999999999975s
#
# 124
# Epoch duration =2.35s
# Cumulative duration =4min 53.69s
#
# 125
# Epoch duration =2.38s
# Cumulative duration =4min 56.06s
#
# 126
# Epoch duration =2.33s
# Cumulative duration =4min 58.39999999999998s
#
# 127
# Epoch duration =2.32s
# Cumulative duration =5min 0.7200000000000273s
#
# 128
# Epoch duration =2.34s
# Cumulative duration =5min 3.0600000000000023s
#
# 129
# Epoch duration =2.36s
# Cumulative duration =5min 5.410000000000025s
#
# 130
# Epoch duration =2.36s
# Cumulative duration =5min 7.769999999999982s
#
# 131
# Epoch duration =2.37s
# Cumulative duration =5min 10.139999999999986s
#
# 132
# Epoch duration =2.36s
# Cumulative duration =5min 12.5s
#
# 133
# Epoch duration =2.35s
# Cumulative duration =5min 14.850000000000023s
#
# 134
# Epoch duration =2.35s
# Cumulative duration =5min 17.19999999999999s
#
# 135
# Epoch duration =2.36s
# Cumulative duration =5min 19.560000000000002s
#
# 136
# Epoch duration =2.35s
# Cumulative duration =5min 21.910000000000025s
#
# 137
# Epoch duration =2.34s
# Cumulative duration =5min 24.25999999999999s
#
# 138
# Epoch duration =2.35s
# Cumulative duration =5min 26.600000000000023s
#
# 139
# Epoch duration =2.35s
# Cumulative duration =5min 28.94999999999999s
#
# 140
# Epoch duration =2.36s
# Cumulative duration =5min 31.310000000000002s
#
# 141
# Epoch duration =2.36s
# Cumulative duration =5min 33.670000000000016s
#
# 142
# Epoch duration =2.4s
# Cumulative duration =5min 36.06999999999999s
#
# 143
# Epoch duration =2.35s
# Cumulative duration =5min 38.420000000000016s
#
# 144
# Epoch duration =2.33s
# Cumulative duration =5min 40.75999999999999s
#
# 145
# Epoch duration =2.36s
# Cumulative duration =5min 43.110000000000014s
#
# 146
# Epoch duration =2.32s
# Cumulative duration =5min 45.44s
#
# 147
# Epoch duration =2.33s
# Cumulative duration =5min 47.76999999999998s
#
# 148
# Epoch duration =2.35s
# Cumulative duration =5min 50.120000000000005s
#
# 149
# Epoch duration =2.36s
# Cumulative duration =5min 52.48000000000002s
#
# 150
# Epoch duration =2.36s
# Cumulative duration =5min 54.829999999999984s
#
# 151
# Epoch duration =2.34s
# Cumulative duration =5min 57.18000000000001s
#
# 152
# Epoch duration =2.33s
# Cumulative duration =5min 59.50999999999999s
#
# 153
# Epoch duration =2.33s
# Cumulative duration =6min 1.839999999999975s
#
# 154
# Epoch duration =2.38s
# Cumulative duration =6min 4.220000000000027s
#
# 155
# Epoch duration =2.36s
# Cumulative duration =6min 6.579999999999984s
#
# 156
# Epoch duration =2.34s
# Cumulative duration =6min 8.930000000000007s
#
# 157
# Epoch duration =2.41s
# Cumulative duration =6min 11.339999999999975s
#
# 158
# Epoch duration =2.35s
# Cumulative duration =6min 13.689999999999998s
#
# 159
# Epoch duration =2.34s
# Cumulative duration =6min 16.029999999999973s
#
# 160
# Epoch duration =2.35s
# Cumulative duration =6min 18.370000000000005s
#
# 161
# Epoch duration =2.34s
# Cumulative duration =6min 20.70999999999998s
#
# 162
# Epoch duration =2.37s
# Cumulative duration =6min 23.079999999999984s
#
# 163
# Epoch duration =2.35s
# Cumulative duration =6min 25.430000000000007s
#
# 164
# Epoch duration =2.34s
# Cumulative duration =6min 27.769999999999982s
#
# 165
# Epoch duration =2.38s
# Cumulative duration =6min 30.160000000000025s
#
# 166
# Epoch duration =2.36s
# Cumulative duration =6min 32.51999999999998s
#
# 167
# Epoch duration =2.35s
# Cumulative duration =6min 34.870000000000005s
#
# 168
# Epoch duration =2.34s
# Cumulative duration =6min 37.20999999999998s
#
# 169
# Epoch duration =2.33s
# Cumulative duration =6min 39.54000000000002s
#
# 170
# Epoch duration =2.36s
# Cumulative duration =6min 41.889999999999986s
#
# 171
# Epoch duration =2.34s
# Cumulative duration =6min 44.24000000000001s
#
# 172
# Epoch duration =2.36s
# Cumulative duration =6min 46.60000000000002s
#
# 173
# Epoch duration =2.35s
# Cumulative duration =6min 48.94999999999999s
#
# 174
# Epoch duration =2.33s
# Cumulative duration =6min 51.27999999999997s
#
# 175
# Epoch duration =2.38s
# Cumulative duration =6min 53.660000000000025s
#
# 176
# Epoch duration =2.35s
# Cumulative duration =6min 56.0s
#
# 177
# Epoch duration =2.32s
# Cumulative duration =6min 58.329999999999984s
#
# 178
# Epoch duration =2.37s
# Cumulative duration =7min 0.6899999999999977s
#
# 179
# Epoch duration =2.37s
# Cumulative duration =7min 3.069999999999993s
#
# 180
# Epoch duration =2.35s
# Cumulative duration =7min 5.420000000000016s
#
# 181
# Epoch duration =2.36s
# Cumulative duration =7min 7.779999999999973s
#
# 182
# Epoch duration =2.86s
# Cumulative duration =7min 10.649999999999977s
#
# 183
# Epoch duration =2.69s
# Cumulative duration =7min 13.329999999999984s
#
# 184
# Epoch duration =2.34s
# Cumulative duration =7min 15.680000000000007s
#
# 185
# Epoch duration =2.34s
# Cumulative duration =7min 18.019999999999982s
#
# 186
# Epoch duration =2.34s
# Cumulative duration =7min 20.370000000000005s
#
# 187
# Epoch duration =2.36s
# Cumulative duration =7min 22.730000000000018s
#
# 188
# Epoch duration =2.34s
# Cumulative duration =7min 25.060000000000002s
#
# 189
# Epoch duration =2.35s
# Cumulative duration =7min 27.410000000000025s
#
# 190
# Epoch duration =2.37s
# Cumulative duration =7min 29.779999999999973s
#
# 191
# Epoch duration =2.34s
# Cumulative duration =7min 32.120000000000005s
#
# 192
# Epoch duration =2.36s
# Cumulative duration =7min 34.48000000000002s
#
# 193
# Epoch duration =2.34s
# Cumulative duration =7min 36.81999999999999s
#
# 194
# Epoch duration =2.32s
# Cumulative duration =7min 39.139999999999986s
#
# 195
# Epoch duration =2.36s
# Cumulative duration =7min 41.5s
#
# 196
# Epoch duration =2.33s
# Cumulative duration =7min 43.829999999999984s
#
# 197
# Epoch duration =2.35s
# Cumulative duration =7min 46.18000000000001s
#
# 198
# Epoch duration =2.36s
# Cumulative duration =7min 48.54000000000002s
#
# 199
# Epoch duration =2.34s
# Cumulative duration =7min 50.879999999999995s
#
# 200
# Epoch duration =2.35s
# Cumulative duration =7min 53.24000000000001s
#
# 201
# Epoch duration =2.38s
# Cumulative duration =7min 55.620000000000005s
#
# 202
# Epoch duration =2.33s
# Cumulative duration =7min 57.94999999999999s
#
# 203
# Epoch duration =2.35s
# Cumulative duration =8min 0.30000000000001137s
#
# 204
# Epoch duration =2.33s
# Cumulative duration =8min 2.6299999999999955s
#
# 205
# Epoch duration =2.35s
# Cumulative duration =8min 4.990000000000009s
#
# 206
# Epoch duration =2.39s
# Cumulative duration =8min 7.3700000000000045s
#
# 207
# Epoch duration =2.35s
# Cumulative duration =8min 9.720000000000027s
#
# 208
# Epoch duration =2.35s
# Cumulative duration =8min 12.069999999999993s
#
# 209
# Epoch duration =2.37s
# Cumulative duration =8min 14.439999999999998s
#
# 210
# Epoch duration =2.36s
# Cumulative duration =8min 16.80000000000001s
#
# 211
# Epoch duration =2.34s
# Cumulative duration =8min 19.149999999999977s
#
# 212
# Epoch duration =2.32s
# Cumulative duration =8min 21.470000000000027s
#
# 213
# Epoch duration =2.36s
# Cumulative duration =8min 23.829999999999984s
#
# 214
# Epoch duration =2.36s
# Cumulative duration =8min 26.189999999999998s
#
# 215
# Epoch duration =2.37s
# Cumulative duration =8min 28.560000000000002s
#
# 216
# Epoch duration =2.37s
# Cumulative duration =8min 30.920000000000016s
#
# 217
# Epoch duration =2.36s
# Cumulative duration =8min 33.27999999999997s
#
# 218
# Epoch duration =2.34s
# Cumulative duration =8min 35.620000000000005s
#
# 219
# Epoch duration =2.34s
# Cumulative duration =8min 37.960000000000036s
#
# 220
# Epoch duration =2.34s
# Cumulative duration =8min 40.309999999999945s
#
# 221
# Epoch duration =2.34s
# Cumulative duration =8min 42.64999999999998s
#
# 222
# Epoch duration =2.34s
# Cumulative duration =8min 45.0s
#
# 223
# Epoch duration =2.34s
# Cumulative duration =8min 47.33000000000004s
#
# 224
# Epoch duration =2.35s
# Cumulative duration =8min 49.690000000000055s
#
# 225
# Epoch duration =2.37s
# Cumulative duration =8min 52.049999999999955s
#
# 226
# Epoch duration =2.34s
# Cumulative duration =8min 54.389999999999986s
#
# 227
# Epoch duration =2.34s
# Cumulative duration =8min 56.73000000000002s
#
# 228
# Epoch duration =2.35s
# Cumulative duration =8min 59.08000000000004s
#
# 229
# Epoch duration =2.37s
# Cumulative duration =9min 1.4500000000000455s
#
# 230
# Epoch duration =2.35s
# Cumulative duration =9min 3.7999999999999545s
#
# 231
# Epoch duration =2.34s
# Cumulative duration =9min 6.149999999999977s
#
# 232
# Epoch duration =2.32s
# Cumulative duration =9min 8.460000000000036s
#
# 233
# Epoch duration =2.38s
# Cumulative duration =9min 10.850000000000023s
#
# 234
# Epoch duration =2.34s
# Cumulative duration =9min 13.190000000000055s
#
# 235
# Epoch duration =2.35s
# Cumulative duration =9min 15.539999999999964s
#
# 236
# Epoch duration =2.35s
# Cumulative duration =9min 17.889999999999986s
#
# 237
# Epoch duration =2.34s
# Cumulative duration =9min 20.230000000000018s
#
# 238
# Epoch duration =2.32s
# Cumulative duration =9min 22.559999999999945s
#
# 239
# Epoch duration =2.34s
# Cumulative duration =9min 24.889999999999986s
#
# 240
# Epoch duration =2.34s
# Cumulative duration =9min 27.230000000000018s
#
# 241
# Epoch duration =2.35s
# Cumulative duration =9min 29.58000000000004s
#
# 242
# Epoch duration =2.36s
# Cumulative duration =9min 31.940000000000055s
#
# 243
# Epoch duration =2.33s
# Cumulative duration =9min 34.26999999999998s
#
# 244
# Epoch duration =2.33s
# Cumulative duration =9min 36.610000000000014s
#
# 245
# Epoch duration =2.38s
# Cumulative duration =9min 38.98000000000002s
#
# 246
# Epoch duration =2.35s
# Cumulative duration =9min 41.34000000000003s
#
# 247
# Epoch duration =2.33s
# Cumulative duration =9min 43.65999999999997s
#
# 248
# Epoch duration =2.35s
# Cumulative duration =9min 46.00999999999999s
#
# 249
# Epoch duration =2.36s
# Cumulative duration =9min 48.370000000000005s
#
# 250
# Epoch duration =2.36s
# Cumulative duration =9min 50.74000000000001s
#
# 251
# Epoch duration =2.35s
# Cumulative duration =9min 53.08000000000004s
#
# 252
# Epoch duration =2.32s
# Cumulative duration =9min 55.39999999999998s
#
# 253
# Epoch duration =2.35s
# Cumulative duration =9min 57.75s
#
# 254
# Epoch duration =2.35s
# Cumulative duration =10min 0.11000000000001364s
#
# 255
# Epoch duration =2.36s
# Cumulative duration =10min 2.4700000000000273s
#
# 256
# Epoch duration =2.37s
# Cumulative duration =10min 4.840000000000032s
#
# 257
# Epoch duration =2.35s
# Cumulative duration =10min 7.190000000000055s
#
# 258
# Epoch duration =2.35s
# Cumulative duration =10min 9.539999999999964s
#
# 259
# Epoch duration =2.34s
# Cumulative duration =10min 11.879999999999995s
#
# 260
# Epoch duration =2.37s
# Cumulative duration =10min 14.25s
#
# 261
# Epoch duration =2.38s
# Cumulative duration =10min 16.629999999999995s
#
# 262
# Epoch duration =2.37s
# Cumulative duration =10min 19.0s
#
# 263
# Epoch duration =2.36s
# Cumulative duration =10min 21.360000000000014s
#
# 264
# Epoch duration =2.36s
# Cumulative duration =10min 23.720000000000027s
#
# 265
# Epoch duration =2.36s
# Cumulative duration =10min 26.08000000000004s
#
# 266
# Epoch duration =2.37s
# Cumulative duration =10min 28.450000000000045s
#
# 267
# Epoch duration =2.37s
# Cumulative duration =10min 30.82000000000005s
#
# 268
# Epoch duration =2.35s
# Cumulative duration =10min 33.16999999999996s
#
# 269
# Epoch duration =2.36s
# Cumulative duration =10min 35.51999999999998s
#
# 270
# Epoch duration =2.34s
# Cumulative duration =10min 37.860000000000014s
#
# 271
# Epoch duration =2.35s
# Cumulative duration =10min 40.210000000000036s
#
# 272
# Epoch duration =2.35s
# Cumulative duration =10min 42.559999999999945s
#
# 273
# Epoch duration =2.34s
# Cumulative duration =10min 44.89999999999998s
#
# 274
# Epoch duration =2.36s
# Cumulative duration =10min 47.25999999999999s
#
# 275
# Epoch duration =2.34s
# Cumulative duration =10min 49.60000000000002s
#
# 276
# Epoch duration =2.34s
# Cumulative duration =10min 51.940000000000055s
#
# 277
# Epoch duration =2.33s
# Cumulative duration =10min 54.25999999999999s
#
# 278
# Epoch duration =2.35s
# Cumulative duration =10min 56.620000000000005s
#
# 279
# Epoch duration =2.32s
# Cumulative duration =10min 58.92999999999995s
#
# 280
# Epoch duration =2.36s
# Cumulative duration =11min 1.2999999999999545s
#
# 281
# Epoch duration =2.36s
# Cumulative duration =11min 3.659999999999968s
#
# 282
# Epoch duration =2.35s
# Cumulative duration =11min 6.009999999999991s
#
# 283
# Epoch duration =2.35s
# Cumulative duration =11min 8.360000000000014s
#
# 284
# Epoch duration =2.33s
# Cumulative duration =11min 10.690000000000055s
#
# 285
# Epoch duration =2.34s
# Cumulative duration =11min 13.039999999999964s
#
# 286
# Epoch duration =2.34s
# Cumulative duration =11min 15.370000000000005s
#
# 287
# Epoch duration =2.35s
# Cumulative duration =11min 17.730000000000018s
#
# 288
# Epoch duration =2.36s
# Cumulative duration =11min 20.08000000000004s
#
# 289
# Epoch duration =2.35s
# Cumulative duration =11min 22.42999999999995s
#
# 290
# Epoch duration =2.35s
# Cumulative duration =11min 24.779999999999973s
#
# 291
# Epoch duration =2.36s
# Cumulative duration =11min 27.149999999999977s
#
# 292
# Epoch duration =2.32s
# Cumulative duration =11min 29.470000000000027s
#
# 293
# Epoch duration =2.35s
# Cumulative duration =11min 31.82000000000005s
#
# 294
# Epoch duration =2.36s
# Cumulative duration =11min 34.17999999999995s
#
# 295
# Epoch duration =2.35s
# Cumulative duration =11min 36.52999999999997s
#
# 296
# Epoch duration =2.35s
# Cumulative duration =11min 38.879999999999995s
#
# 297
# Epoch duration =2.32s
# Cumulative duration =11min 41.200000000000045s
#
# 298
# Epoch duration =2.34s
# Cumulative duration =11min 43.539999999999964s
#
# 299
# Epoch duration =2.4s
# Cumulative duration =11min 45.940000000000055s
#
# 300
# Epoch duration =2.34s
# Cumulative duration =11min 48.27999999999997s
#
# 301
# Epoch duration =2.42s
# Cumulative duration =11min 50.700000000000045s
#
# 302
# Epoch duration =2.35s
# Cumulative duration =11min 53.039999999999964s
#
# 303
# Epoch duration =2.36s
# Cumulative duration =11min 55.40999999999997s
#
# 304
# Epoch duration =2.35s
# Cumulative duration =11min 57.75999999999999s
#
# 305
# Epoch duration =2.34s
# Cumulative duration =12min 0.10000000000002274s
#
# 306
# Epoch duration =2.34s
# Cumulative duration =12min 2.4500000000000455s
#
# 307
# Epoch duration =2.35s
# Cumulative duration =12min 4.7999999999999545s
#
# 308
# Epoch duration =2.34s
# Cumulative duration =12min 7.139999999999986s
#
# 309
# Epoch duration =2.37s
# Cumulative duration =12min 9.509999999999991s
#
# 310
# Epoch duration =2.33s
# Cumulative duration =12min 11.840000000000032s
#
# 311
# Epoch duration =2.35s
# Cumulative duration =12min 14.190000000000055s
#
# 312
# Epoch duration =2.34s
# Cumulative duration =12min 16.529999999999973s
#
# 313
# Epoch duration =2.34s
# Cumulative duration =12min 18.870000000000005s
#
# 314
# Epoch duration =2.32s
# Cumulative duration =12min 21.190000000000055s
#
# 315
# Epoch duration =2.37s
# Cumulative duration =12min 23.559999999999945s
#
# 316
# Epoch duration =2.37s
# Cumulative duration =12min 25.92999999999995s
#
# 317
# Epoch duration =2.36s
# Cumulative duration =12min 28.279999999999973s
#
# 318
# Epoch duration =2.37s
# Cumulative duration =12min 30.659999999999968s
#
# 319
# Epoch duration =2.35s
# Cumulative duration =12min 33.0s
#
# 320
# Epoch duration =2.35s
# Cumulative duration =12min 35.360000000000014s
#
# 321
# Epoch duration =2.33s
# Cumulative duration =12min 37.690000000000055s
#
# 322
# Epoch duration =2.38s
# Cumulative duration =12min 40.07000000000005s
#
# 323
# Epoch duration =2.33s
# Cumulative duration =12min 42.39999999999998s
#
# 324
# Epoch duration =2.4s
# Cumulative duration =12min 44.799999999999955s
#
# 325
# Epoch duration =2.35s
# Cumulative duration =12min 47.14999999999998s
#
# 326
# Epoch duration =2.35s
# Cumulative duration =12min 49.49000000000001s
#
# 327
# Epoch duration =2.37s
# Cumulative duration =12min 51.870000000000005s
#
# 328
# Epoch duration =2.36s
# Cumulative duration =12min 54.22000000000003s
#
# 329
# Epoch duration =2.35s
# Cumulative duration =12min 56.58000000000004s
#
# 330
# Epoch duration =2.35s
# Cumulative duration =12min 58.91999999999996s
#
# 331
# Epoch duration =2.35s
# Cumulative duration =13min 1.2799999999999727s
#
# 332
# Epoch duration =2.34s
# Cumulative duration =13min 3.6200000000000045s
#
# 333
# Epoch duration =2.36s
# Cumulative duration =13min 5.980000000000018s
#
# 334
# Epoch duration =2.37s
# Cumulative duration =13min 8.350000000000023s
#
# 335
# Epoch duration =2.34s
# Cumulative duration =13min 10.690000000000055s
#
# 336
# Epoch duration =2.36s
# Cumulative duration =13min 13.049999999999955s
#
# 337
# Epoch duration =2.32s
# Cumulative duration =13min 15.370000000000005s
#
# 338
# Epoch duration =2.35s
# Cumulative duration =13min 17.720000000000027s
#
# 339
# Epoch duration =2.35s
# Cumulative duration =13min 20.07000000000005s
#
# 340
# Epoch duration =2.33s
# Cumulative duration =13min 22.409999999999968s
#
# 341
# Epoch duration =2.34s
# Cumulative duration =13min 24.75s
#
# 342
# Epoch duration =2.34s
# Cumulative duration =13min 27.090000000000032s
#
# 343
# Epoch duration =2.33s
# Cumulative duration =13min 29.41999999999996s
#
# 344
# Epoch duration =2.38s
# Cumulative duration =13min 31.799999999999955s
#
# 345
# Epoch duration =2.36s
# Cumulative duration =13min 34.15999999999997s
#
# 346
# Epoch duration =2.34s
# Cumulative duration =13min 36.5s
#
# 347
# Epoch duration =2.36s
# Cumulative duration =13min 38.860000000000014s
#
# 348
# Epoch duration =2.34s
# Cumulative duration =13min 41.200000000000045s
#
# 349
# Epoch duration =2.4s
# Cumulative duration =13min 43.60000000000002s
#
# 350
# Epoch duration =2.4s
# Cumulative duration =13min 46.0s
#
# 351
# Epoch duration =2.35s
# Cumulative duration =13min 48.35000000000002s
#
# 352
# Epoch duration =2.34s
# Cumulative duration =13min 50.690000000000055s
#
# 353
# Epoch duration =2.36s
# Cumulative duration =13min 53.049999999999955s
#
# 354
# Epoch duration =2.36s
# Cumulative duration =13min 55.40999999999997s
#
# 355
# Epoch duration =2.33s
# Cumulative duration =13min 57.74000000000001s
#
# 356
# Epoch duration =2.35s
# Cumulative duration =14min 0.09000000000003183s
#
# 357
# Epoch duration =2.37s
# Cumulative duration =14min 2.4600000000000364s
#
# 358
# Epoch duration =2.34s
# Cumulative duration =14min 4.7999999999999545s
#
# 359
# Epoch duration =2.34s
# Cumulative duration =14min 7.139999999999986s
#
# 360
# Epoch duration =2.35s
# Cumulative duration =14min 9.490000000000009s
#
# 361
# Epoch duration =2.37s
# Cumulative duration =14min 11.860000000000014s
#
# 362
# Epoch duration =2.38s
# Cumulative duration =14min 14.240000000000009s
#
# 363
# Epoch duration =2.34s
# Cumulative duration =14min 16.58000000000004s
#
# 364
# Epoch duration =2.34s
# Cumulative duration =14min 18.91999999999996s
#
# 365
# Epoch duration =2.36s
# Cumulative duration =14min 21.279999999999973s
#
# 366
# Epoch duration =2.34s
# Cumulative duration =14min 23.610000000000014s
#
# 367
# Epoch duration =2.37s
# Cumulative duration =14min 25.980000000000018s
#
# 368
# Epoch duration =2.36s
# Cumulative duration =14min 28.340000000000032s
#
# 369
# Epoch duration =2.38s
# Cumulative duration =14min 30.720000000000027s
#
# 370
# Epoch duration =2.35s
# Cumulative duration =14min 33.08000000000004s
#
# 371
# Epoch duration =2.38s
# Cumulative duration =14min 35.450000000000045s
#
# 372
# Epoch duration =2.35s
# Cumulative duration =14min 37.809999999999945s
#
# 373
# Epoch duration =2.36s
# Cumulative duration =14min 40.15999999999997s
#
# 374
# Epoch duration =2.33s
# Cumulative duration =14min 42.5s
#
# 375
# Epoch duration =2.33s
# Cumulative duration =14min 44.83000000000004s
#
# 376
# Epoch duration =2.34s
# Cumulative duration =14min 47.16999999999996s
#
# 377
# Epoch duration =2.36s
# Cumulative duration =14min 49.52999999999997s
#
# 378
# Epoch duration =2.34s
# Cumulative duration =14min 51.870000000000005s
#
# 379
# Epoch duration =2.36s
# Cumulative duration =14min 54.24000000000001s
#
# 380
# Epoch duration =2.34s
# Cumulative duration =14min 56.57000000000005s
#
# 381
# Epoch duration =2.35s
# Cumulative duration =14min 58.92999999999995s
#
# 382
# Epoch duration =2.33s
# Cumulative duration =15min 1.259999999999991s
#
# 383
# Epoch duration =2.36s
# Cumulative duration =15min 3.6200000000000045s
#
# 384
# Epoch duration =2.33s
# Cumulative duration =15min 5.9500000000000455s
#
# 385
# Epoch duration =2.35s
# Cumulative duration =15min 8.299999999999955s
#
# 386
# Epoch duration =2.32s
# Cumulative duration =15min 10.620000000000005s
#
# 387
# Epoch duration =2.34s
# Cumulative duration =15min 12.960000000000036s
#
# 388
# Epoch duration =2.32s
# Cumulative duration =15min 15.289999999999964s
#
# 389
# Epoch duration =2.33s
# Cumulative duration =15min 17.620000000000005s
#
# 390
# Epoch duration =2.33s
# Cumulative duration =15min 19.940000000000055s
#
# 391
# Epoch duration =2.34s
# Cumulative duration =15min 22.279999999999973s
#
# 392
# Epoch duration =2.34s
# Cumulative duration =15min 24.620000000000005s
#
# 393
# Epoch duration =2.34s
# Cumulative duration =15min 26.960000000000036s
#
# 394
# Epoch duration =2.34s
# Cumulative duration =15min 29.299999999999955s
#
# 395
# Epoch duration =2.34s
# Cumulative duration =15min 31.639999999999986s
#
# 396
# Epoch duration =2.35s
# Cumulative duration =15min 33.99000000000001s
#
# 397
# Epoch duration =2.35s
# Cumulative duration =15min 36.34000000000003s
#
# 398
# Epoch duration =2.33s
# Cumulative duration =15min 38.66999999999996s
#
# 399
# Epoch duration =2.35s
# Cumulative duration =15min 41.01999999999998s
#
# 400
# Epoch duration =2.35s
# Cumulative duration =15min 43.370000000000005s
#
# 401
# Epoch duration =2.36s
# Cumulative duration =15min 45.73000000000002s
#
# 402
# Epoch duration =2.33s
# Cumulative duration =15min 48.07000000000005s
#
# 403
# Epoch duration =2.34s
# Cumulative duration =15min 50.39999999999998s
#
# 404
# Epoch duration =2.36s
# Cumulative duration =15min 52.75999999999999s
#
# 405
# Epoch duration =2.35s
# Cumulative duration =15min 55.110000000000014s
#
# 406
# Epoch duration =2.34s
# Cumulative duration =15min 57.460000000000036s
#
# 407
# Epoch duration =2.38s
# Cumulative duration =15min 59.84000000000003s
#
# 408
# Epoch duration =2.33s
# Cumulative duration =16min 2.169999999999959s
#
# 409
# Epoch duration =2.32s
# Cumulative duration =16min 4.490000000000009s
#
# 410
# Epoch duration =2.36s
# Cumulative duration =16min 6.850000000000023s
#
# 411
# Epoch duration =2.37s
# Cumulative duration =16min 9.220000000000027s
#
# 412
# Epoch duration =2.36s
# Cumulative duration =16min 11.580000000000041s
#
# 413
# Epoch duration =2.33s
# Cumulative duration =16min 13.899999999999977s
#
# 414
# Epoch duration =2.35s
# Cumulative duration =16min 16.25s
#
# 415
# Epoch duration =2.34s
# Cumulative duration =16min 18.600000000000023s
#
# 416
# Epoch duration =2.39s
# Cumulative duration =16min 20.99000000000001s
#
# 417
# Epoch duration =2.37s
# Cumulative duration =16min 23.360000000000014s
#
# 418
# Epoch duration =2.34s
# Cumulative duration =16min 25.700000000000045s
#
# 419
# Epoch duration =2.33s
# Cumulative duration =16min 28.039999999999964s
#
# 420
# Epoch duration =2.36s
# Cumulative duration =16min 30.399999999999977s
#
# 421
# Epoch duration =2.36s
# Cumulative duration =16min 32.75999999999999s
#
# 422
# Epoch duration =2.37s
# Cumulative duration =16min 35.129999999999995s
#
# 423
# Epoch duration =2.34s
# Cumulative duration =16min 37.48000000000002s
#
# 424
# Epoch duration =2.37s
# Cumulative duration =16min 39.85000000000002s
#
# 425
# Epoch duration =2.33s
# Cumulative duration =16min 42.16999999999996s
#
# 426
# Epoch duration =2.35s
# Cumulative duration =16min 44.52999999999997s
#
# 427
# Epoch duration =2.34s
# Cumulative duration =16min 46.870000000000005s
#
# 428
# Epoch duration =2.34s
# Cumulative duration =16min 49.210000000000036s
#
# 429
# Epoch duration =2.35s
# Cumulative duration =16min 51.559999999999945s
#
# 430
# Epoch duration =2.35s
# Cumulative duration =16min 53.90999999999997s
#
# 431
# Epoch duration =2.34s
# Cumulative duration =16min 56.25s
#
# 432
# Epoch duration =2.36s
# Cumulative duration =16min 58.610000000000014s
#
# 433
# Epoch duration =2.33s
# Cumulative duration =17min 0.9400000000000546s
#
# 434
# Epoch duration =2.34s
# Cumulative duration =17min 3.2799999999999727s
#
# 435
# Epoch duration =2.34s
# Cumulative duration =17min 5.619999999999891s
#
# 436
# Epoch duration =2.35s
# Cumulative duration =17min 7.970000000000027s
#
# 437
# Epoch duration =2.36s
# Cumulative duration =17min 10.329999999999927s
#
# 438
# Epoch duration =2.35s
# Cumulative duration =17min 12.690000000000055s
#
# 439
# Epoch duration =2.35s
# Cumulative duration =17min 15.039999999999964s
#
# 440
# Epoch duration =2.36s
# Cumulative duration =17min 17.40000000000009s
#
# 441
# Epoch duration =2.34s
# Cumulative duration =17min 19.74000000000001s
#
# 442
# Epoch duration =2.34s
# Cumulative duration =17min 22.079999999999927s
#
# 443
# Epoch duration =2.36s
# Cumulative duration =17min 24.440000000000055s
#
# 444
# Epoch duration =2.37s
# Cumulative duration =17min 26.819999999999936s
#
# 445
# Epoch duration =2.36s
# Cumulative duration =17min 29.170000000000073s
#
# 446
# Epoch duration =2.35s
# Cumulative duration =17min 31.519999999999982s
#
# 447
# Epoch duration =2.35s
# Cumulative duration =17min 33.86999999999989s
#
# 448
# Epoch duration =2.34s
# Cumulative duration =17min 36.210000000000036s
#
# 449
# Epoch duration =2.33s
# Cumulative duration =17min 38.539999999999964s
#
# 450
# Epoch duration =2.33s
# Cumulative duration =17min 40.86999999999989s
#
# 451
# Epoch duration =2.33s
# Cumulative duration =17min 43.210000000000036s
#
# 452
# Epoch duration =2.34s
# Cumulative duration =17min 45.549999999999955s
#
# 453
# Epoch duration =2.38s
# Cumulative duration =17min 47.930000000000064s
#
# 454
# Epoch duration =2.35s
# Cumulative duration =17min 50.27999999999997s
#
# 455
# Epoch duration =2.33s
# Cumulative duration =17min 52.6099999999999s
#
# 456
# Epoch duration =2.74s
# Cumulative duration =17min 55.33999999999992s
#
# 457
# Epoch duration =2.9s
# Cumulative duration =17min 58.25s
#
# 458
# Epoch duration =2.84s
# Cumulative duration =18min 1.0899999999999181s
#
# 459
# Epoch duration =2.7s
# Cumulative duration =18min 3.7899999999999636s
#
# 460
# Epoch duration =2.59s
# Cumulative duration =18min 6.380000000000109s
#
# 461
# Epoch duration =2.34s
# Cumulative duration =18min 8.730000000000018s
#
# 462
# Epoch duration =2.42s
# Cumulative duration =18min 11.150000000000091s
#
# 463
# Epoch duration =2.34s
# Cumulative duration =18min 13.480000000000018s
#
# 464
# Epoch duration =2.35s
# Cumulative duration =18min 15.829999999999927s
#
# 465
# Epoch duration =2.37s
# Cumulative duration =18min 18.200000000000045s
#
# 466
# Epoch duration =2.36s
# Cumulative duration =18min 20.559999999999945s
#
# 467
# Epoch duration =2.35s
# Cumulative duration =18min 22.910000000000082s
#
# 468
# Epoch duration =2.37s
# Cumulative duration =18min 25.269999999999982s
#
# 469
# Epoch duration =2.35s
# Cumulative duration =18min 27.61999999999989s
#
# 470
# Epoch duration =2.33s
# Cumulative duration =18min 29.950000000000045s
#
# 471
# Epoch duration =2.33s
# Cumulative duration =18min 32.289999999999964s
#
# 472
# Epoch duration =2.34s
# Cumulative duration =18min 34.63000000000011s
#
# 473
# Epoch duration =2.33s
# Cumulative duration =18min 36.960000000000036s
#
# 474
# Epoch duration =2.37s
# Cumulative duration =18min 39.32999999999993s
#
# 475
# Epoch duration =2.33s
# Cumulative duration =18min 41.66000000000008s
#
# 476
# Epoch duration =2.35s
# Cumulative duration =18min 44.00999999999999s
#
# 477
# Epoch duration =2.36s
# Cumulative duration =18min 46.36999999999989s
#
# 478
# Epoch duration =2.34s
# Cumulative duration =18min 48.710000000000036s
#
# 479
# Epoch duration =2.36s
# Cumulative duration =18min 51.069999999999936s
#
# 480
# Epoch duration =2.44s
# Cumulative duration =18min 53.51999999999998s
#
# 481
# Epoch duration =2.37s
# Cumulative duration =18min 55.8900000000001s
#
# 482
# Epoch duration =2.36s
# Cumulative duration =18min 58.25s
#
# 483
# Epoch duration =2.35s
# Cumulative duration =19min 0.599999999999909s
#
# 484
# Epoch duration =2.33s
# Cumulative duration =19min 2.9300000000000637s
#
# 485
# Epoch duration =2.35s
# Cumulative duration =19min 5.279999999999973s
#
# 486
# Epoch duration =2.38s
# Cumulative duration =19min 7.660000000000082s
#
# 487
# Epoch duration =2.35s
# Cumulative duration =19min 10.009999999999991s
#
# 488
# Epoch duration =2.39s
# Cumulative duration =19min 12.400000000000091s
#
# 489
# Epoch duration =2.36s
# Cumulative duration =19min 14.759999999999991s
#
# 490
# Epoch duration =2.36s
# Cumulative duration =19min 17.11999999999989s
#
# 491
# Epoch duration =2.35s
# Cumulative duration =19min 19.470000000000027s
#
# 492
# Epoch duration =2.32s
# Cumulative duration =19min 21.789999999999964s
#
# 493
# Epoch duration =2.33s
# Cumulative duration =19min 24.11999999999989s
#
# 494
# Epoch duration =2.34s
# Cumulative duration =19min 26.470000000000027s
#
# 495
# Epoch duration =2.35s
# Cumulative duration =19min 28.819999999999936s
#
# 496
# Epoch duration =2.34s
# Cumulative duration =19min 31.15000000000009s
#
# 497
# Epoch duration =2.37s
# Cumulative duration =19min 33.51999999999998s
#
# 498
# Epoch duration =2.34s
# Cumulative duration =19min 35.8599999999999s
#
# 499
# Epoch duration =2.33s
# Cumulative duration =19min 38.190000000000055s
#
# 500
# Epoch duration =2.36s
# Cumulative duration =19min 40.549999999999955s
#
# 501
# Epoch duration =2.37s
# Cumulative duration =19min 42.91000000000008s
#
# 502
# Epoch duration =2.36s
# Cumulative duration =19min 45.27999999999997s
#
# 503
# Epoch duration =2.33s
# Cumulative duration =19min 47.6099999999999s
#
# 504
# Epoch duration =2.35s
# Cumulative duration =19min 49.960000000000036s
#
# 505
# Epoch duration =2.33s
# Cumulative duration =19min 52.289999999999964s
#
# 506
# Epoch duration =2.34s
# Cumulative duration =19min 54.63000000000011s
#
# 507
# Epoch duration =2.34s
# Cumulative duration =19min 56.97000000000003s
#
# 508
# Epoch duration =2.36s
# Cumulative duration =19min 59.32999999999993s
#
# 509
# Epoch duration =2.33s
# Cumulative duration =20min 1.6600000000000819s
#
# 510
# Epoch duration =2.36s
# Cumulative duration =20min 4.029999999999973s
#
# 511
# Epoch duration =2.35s
# Cumulative duration =20min 6.380000000000109s
#
# 512
# Epoch duration =2.42s
# Cumulative duration =20min 8.799999999999955s
#
# 513
# Epoch duration =2.4s
# Cumulative duration =20min 11.200000000000045s
#
# 514
# Epoch duration =2.35s
# Cumulative duration =20min 13.549999999999955s
#
# 515
# Epoch duration =2.34s
# Cumulative duration =20min 15.8900000000001s
#
# 516
# Epoch duration =2.34s
# Cumulative duration =20min 18.230000000000018s
#
# 517
# Epoch duration =2.36s
# Cumulative duration =20min 20.579999999999927s
#
# 518
# Epoch duration =2.36s
# Cumulative duration =20min 22.950000000000045s
#
# 519
# Epoch duration =2.34s
# Cumulative duration =20min 25.279999999999973s
#
# 520
# Epoch duration =2.38s
# Cumulative duration =20min 27.660000000000082s
#
# 521
# Epoch duration =2.37s
# Cumulative duration =20min 30.029999999999973s
#
# 522
# Epoch duration =2.35s
# Cumulative duration =20min 32.38000000000011s
#
# 523
# Epoch duration =2.33s
# Cumulative duration =20min 34.710000000000036s
#
# 524
# Epoch duration =2.37s
# Cumulative duration =20min 37.07999999999993s
#
# 525
# Epoch duration =2.35s
# Cumulative duration =20min 39.42000000000007s
#
# 526
# Epoch duration =2.34s
# Cumulative duration =20min 41.76999999999998s
#
# 527
# Epoch duration =2.37s
# Cumulative duration =20min 44.1400000000001s
#
# 528
# Epoch duration =2.41s
# Cumulative duration =20min 46.549999999999955s
#
# 529
# Epoch duration =2.33s
# Cumulative duration =20min 48.88000000000011s
#
# 530
# Epoch duration =2.34s
# Cumulative duration =20min 51.22000000000003s
#
# 531
# Epoch duration =2.36s
# Cumulative duration =20min 53.57999999999993s
#
# 532
# Epoch duration =2.37s
# Cumulative duration =20min 55.940000000000055s
#
# 533
# Epoch duration =2.35s
# Cumulative duration =20min 58.299999999999955s
#
# 534
# Epoch duration =2.35s
# Cumulative duration =21min 0.6400000000001s
#
# 535
# Epoch duration =2.38s
# Cumulative duration =21min 3.019999999999982s
#
# 536
# Epoch duration =2.35s
# Cumulative duration =21min 5.369999999999891s
#
# 537
# Epoch duration =2.34s
# Cumulative duration =21min 7.710000000000036s
#
# 538
# Epoch duration =2.36s
# Cumulative duration =21min 10.069999999999936s
#
# 539
# Epoch duration =2.33s
# Cumulative duration =21min 12.3900000000001s
#
# 540
# Epoch duration =2.37s
# Cumulative duration =21min 14.769999999999982s
#
# 541
# Epoch duration =2.34s
# Cumulative duration =21min 17.1099999999999s
#
# 542
# Epoch duration =2.35s
# Cumulative duration =21min 19.460000000000036s
#
# 543
# Epoch duration =2.33s
# Cumulative duration =21min 21.789999999999964s
#
# 544
# Epoch duration =2.34s
# Cumulative duration =21min 24.13000000000011s
#
# 545
# Epoch duration =2.36s
# Cumulative duration =21min 26.49000000000001s
#
# 546
# Epoch duration =2.35s
# Cumulative duration =21min 28.84999999999991s
#
# 547
# Epoch duration =2.34s
# Cumulative duration =21min 31.190000000000055s
#
# 548
# Epoch duration =2.34s
# Cumulative duration =21min 33.52999999999997s
#
# 549
# Epoch duration =2.36s
# Cumulative duration =21min 35.8900000000001s
#
# 550
# Epoch duration =2.35s
# Cumulative duration =21min 38.24000000000001s
#
# 551
# Epoch duration =2.34s
# Cumulative duration =21min 40.58999999999992s
#
# 552
# Epoch duration =2.39s
# Cumulative duration =21min 42.98000000000002s
#
# 553
# Epoch duration =2.34s
# Cumulative duration =21min 45.319999999999936s
#
# 554
# Epoch duration =2.37s
# Cumulative duration =21min 47.690000000000055s
#
# 555
# Epoch duration =2.34s
# Cumulative duration =21min 50.02999999999997s
#
# 556
# Epoch duration =2.35s
# Cumulative duration =21min 52.38000000000011s
#
# 557
# Epoch duration =2.35s
# Cumulative duration =21min 54.74000000000001s
#
# 558
# Epoch duration =2.37s
# Cumulative duration =21min 57.1099999999999s
#
# 559
# Epoch duration =2.36s
# Cumulative duration =21min 59.47000000000003s
#
# 560
# Epoch duration =2.35s
# Cumulative duration =22min 1.8199999999999363s
#
# 561
# Epoch duration =2.34s
# Cumulative duration =22min 4.160000000000082s
#
# 562
# Epoch duration =2.34s
# Cumulative duration =22min 6.509999999999991s
#
# 563
# Epoch duration =2.38s
# Cumulative duration =22min 8.8900000000001s
#
# 564
# Epoch duration =2.35s
# Cumulative duration =22min 11.240000000000009s
#
# 565
# Epoch duration =2.35s
# Cumulative duration =22min 13.579999999999927s
#
# 566
# Epoch duration =2.38s
# Cumulative duration =22min 15.960000000000036s
#
# 567
# Epoch duration =2.34s
# Cumulative duration =22min 18.299999999999955s
#
# 568
# Epoch duration =2.45s
# Cumulative duration =22min 20.75999999999999s
#
# 569
# Epoch duration =2.34s
# Cumulative duration =22min 23.089999999999918s
#
# 570
# Epoch duration =2.33s
# Cumulative duration =22min 25.430000000000064s
#
# 571
# Epoch duration =2.4s
# Cumulative duration =22min 27.829999999999927s
#
# 572
# Epoch duration =2.39s
# Cumulative duration =22min 30.210000000000036s
#
# 573
# Epoch duration =2.34s
# Cumulative duration =22min 32.559999999999945s
#
# 574
# Epoch duration =2.36s
# Cumulative duration =22min 34.91000000000008s
#
# 575
# Epoch duration =2.37s
# Cumulative duration =22min 37.27999999999997s
#
# 576
# Epoch duration =2.35s
# Cumulative duration =22min 39.63000000000011s
#
# 577
# Epoch duration =2.36s
# Cumulative duration =22min 41.99000000000001s
#
# 578
# Epoch duration =2.34s
# Cumulative duration =22min 44.32999999999993s
#
# 579
# Epoch duration =2.37s
# Cumulative duration =22min 46.700000000000045s
#
# 580
# Epoch duration =2.39s
# Cumulative duration =22min 49.08999999999992s
#
# 581
# Epoch duration =2.33s
# Cumulative duration =22min 51.430000000000064s
#
# 582
# Epoch duration =2.34s
# Cumulative duration =22min 53.75999999999999s
#
# 583
# Epoch duration =2.34s
# Cumulative duration =22min 56.09999999999991s
#
# 584
# Epoch duration =2.34s
# Cumulative duration =22min 58.440000000000055s
#
# 585
# Epoch duration =2.36s
# Cumulative duration =23min 0.7999999999999545s
#
# 586
# Epoch duration =2.38s
# Cumulative duration =23min 3.1800000000000637s
#
# 587
# Epoch duration =2.34s
# Cumulative duration =23min 5.519999999999982s
#
# 588
# Epoch duration =2.34s
# Cumulative duration =23min 7.8599999999999s
#
# 589
# Epoch duration =2.35s
# Cumulative duration =23min 10.210000000000036s
#
# 590
# Epoch duration =2.35s
# Cumulative duration =23min 12.569999999999936s
#
# 591
# Epoch duration =2.34s
# Cumulative duration =23min 14.910000000000082s
#
# 592
# Epoch duration =2.36s
# Cumulative duration =23min 17.269999999999982s
#
# 593
# Epoch duration =2.34s
# Cumulative duration =23min 19.6099999999999s
#
# 594
# Epoch duration =2.37s
# Cumulative duration =23min 21.980000000000018s
#
# 595
# Epoch duration =2.42s
# Cumulative duration =23min 24.40000000000009s
#
# 596
# Epoch duration =2.35s
# Cumulative duration =23min 26.74000000000001s
#
# 597
# Epoch duration =2.34s
# Cumulative duration =23min 29.079999999999927s
#
# 598
# Epoch duration =2.35s
# Cumulative duration =23min 31.430000000000064s
#
# 599
# Epoch duration =2.35s
# Cumulative duration =23min 33.77999999999997s
#
# 600
# Epoch duration =2.38s
# Cumulative duration =23min 36.16000000000008s
#
# 601
# Epoch duration =2.37s
# Cumulative duration =23min 38.52999999999997s
#
# 602
# Epoch duration =2.35s
# Cumulative duration =23min 40.88000000000011s
#
# 603
# Epoch duration =2.36s
# Cumulative duration =23min 43.24000000000001s
#
# 604
# Epoch duration =2.32s
# Cumulative duration =23min 45.559999999999945s
#
# 605
# Epoch duration =2.35s
# Cumulative duration =23min 47.91000000000008s
#
# 606
# Epoch duration =2.35s
# Cumulative duration =23min 50.25999999999999s
#
# 607
# Epoch duration =2.34s
# Cumulative duration =23min 52.59999999999991s
#
# 608
# Epoch duration =2.36s
# Cumulative duration =23min 54.960000000000036s
#
# 609
# Epoch duration =2.33s
# Cumulative duration =23min 57.289999999999964s
#
# 610
# Epoch duration =2.38s
# Cumulative duration =23min 59.67000000000007s
#
# 611
# Epoch duration =2.35s
# Cumulative duration =24min 2.0299999999999727s
#
# 612
# Epoch duration =2.34s
# Cumulative duration =24min 4.3599999999999s
#
# 613
# Epoch duration =2.34s
# Cumulative duration =24min 6.7000000000000455s
#
# 614
# Epoch duration =2.37s
# Cumulative duration =24min 9.069999999999936s
#
# 615
# Epoch duration =2.33s
# Cumulative duration =24min 11.410000000000082s
#
# 616
# Epoch duration =2.4s
# Cumulative duration =24min 13.809999999999945s
#
# 617
# Epoch duration =2.34s
# Cumulative duration =24min 16.15000000000009s
#
# 618
# Epoch duration =2.34s
# Cumulative duration =24min 18.49000000000001s
#
# 619
# Epoch duration =2.34s
# Cumulative duration =24min 20.829999999999927s
#
# 620
# Epoch duration =2.35s
# Cumulative duration =24min 23.190000000000055s
#
# 621
# Epoch duration =2.4s
# Cumulative duration =24min 25.589999999999918s
#
# 622
# Epoch duration =2.35s
# Cumulative duration =24min 27.940000000000055s
#
# 623
# Epoch duration =2.38s
# Cumulative duration =24min 30.319999999999936s
#
# 624
# Epoch duration =2.37s
# Cumulative duration =24min 32.690000000000055s
#
# 625
# Epoch duration =2.34s
# Cumulative duration =24min 35.02999999999997s
#
# 626
# Epoch duration =2.36s
# Cumulative duration =24min 37.3900000000001s
#
# 627
# Epoch duration =2.33s
# Cumulative duration =24min 39.72000000000003s
#
# 628
# Epoch duration =2.34s
# Cumulative duration =24min 42.059999999999945s
#
# 629
# Epoch duration =2.37s
# Cumulative duration =24min 44.430000000000064s
#
# 630
# Epoch duration =2.36s
# Cumulative duration =24min 46.789999999999964s
#
# 631
# Epoch duration =2.76s
# Cumulative duration =24min 49.549999999999955s
#
# 632
# Epoch duration =2.77s
# Cumulative duration =24min 52.319999999999936s
#
# 633
# Epoch duration =2.46s
# Cumulative duration =24min 54.76999999999998s
#
# 634
# Epoch duration =2.37s
# Cumulative duration =24min 57.1400000000001s
#
# 635
# Epoch duration =2.36s
# Cumulative duration =24min 59.5s
#
# 636
# Epoch duration =2.36s
# Cumulative duration =25min 1.8599999999999s
#
# 637
# Epoch duration =2.33s
# Cumulative duration =25min 4.190000000000055s
#
# 638
# Epoch duration =2.34s
# Cumulative duration =25min 6.529999999999973s
#
# 639
# Epoch duration =2.33s
# Cumulative duration =25min 8.8599999999999s
#
# 640
# Epoch duration =2.37s
# Cumulative duration =25min 11.230000000000018s
#
# 641
# Epoch duration =2.35s
# Cumulative duration =25min 13.579999999999927s
#
# 642
# Epoch duration =2.34s
# Cumulative duration =25min 15.920000000000073s
#
# 643
# Epoch duration =2.34s
# Cumulative duration =25min 18.25999999999999s
#
# 644
# Epoch duration =2.35s
# Cumulative duration =25min 20.6099999999999s
#
# 645
# Epoch duration =2.38s
# Cumulative duration =25min 22.99000000000001s
#
# 646
# Epoch duration =2.35s
# Cumulative duration =25min 25.339999999999918s
#
# 647
# Epoch duration =2.36s
# Cumulative duration =25min 27.700000000000045s
#
# 648
# Epoch duration =2.34s
# Cumulative duration =25min 30.039999999999964s
#
# 649
# Epoch duration =2.35s
# Cumulative duration =25min 32.3900000000001s
#
# 650
# Epoch duration =2.35s
# Cumulative duration =25min 34.74000000000001s
#
# 651
# Epoch duration =2.34s
# Cumulative duration =25min 37.07999999999993s
#
# 652
# Epoch duration =2.35s
# Cumulative duration =25min 39.430000000000064s
#
# 653
# Epoch duration =2.35s
# Cumulative duration =25min 41.77999999999997s
#
# 654
# Epoch duration =2.37s
# Cumulative duration =25min 44.16000000000008s
#
# 655
# Epoch duration =2.34s
# Cumulative duration =25min 46.5s
#
# 656
# Epoch duration =2.33s
# Cumulative duration =25min 48.82999999999993s
#
# 657
# Epoch duration =2.36s
# Cumulative duration =25min 51.190000000000055s
#
# 658
# Epoch duration =2.34s
# Cumulative duration =25min 53.52999999999997s
#
# 659
# Epoch duration =2.34s
# Cumulative duration =25min 55.86999999999989s
#
# 660
# Epoch duration =2.36s
# Cumulative duration =25min 58.23000000000002s
#
# 661
# Epoch duration =2.36s
# Cumulative duration =26min 0.5899999999999181s
#
# 662
# Epoch duration =2.34s
# Cumulative duration =26min 2.9300000000000637s
#
# 663
# Epoch duration =2.37s
# Cumulative duration =26min 5.2999999999999545s
#
# 664
# Epoch duration =2.34s
# Cumulative duration =26min 7.630000000000109s
#
# 665
# Epoch duration =2.36s
# Cumulative duration =26min 9.990000000000009s
#
# 666
# Epoch duration =2.34s
# Cumulative duration =26min 12.329999999999927s
#
# 667
# Epoch duration =2.33s
# Cumulative duration =26min 14.670000000000073s
#
# 668
# Epoch duration =2.37s
# Cumulative duration =26min 17.039999999999964s
#
# 669
# Epoch duration =2.34s
# Cumulative duration =26min 19.38000000000011s
#
# 670
# Epoch duration =2.37s
# Cumulative duration =26min 21.75999999999999s
#
# 671
# ...
# Cumulative duration =30min 43.039999999999964s
#
# 782
# Epoch duration =2.36s
# Cumulative duration =30min 45.40000000000009s
#
# 783
# Epoch duration =2.35s
# Cumulative duration =30min 47.75s
#
# 784
# Epoch duration =2.35s
# Cumulative duration =30min 50.09999999999991s
#
# 785
# Epoch duration =2.33s
# Cumulative duration =30min 52.430000000000064s
#
# 786
# Epoch duration =2.37s
# Cumulative duration =30min 54.799999999999955s
#
# 787
# Epoch duration =2.36s
# Cumulative duration =30min 57.15000000000009s
#
# 788
# Epoch duration =2.36s
# Cumulative duration =30min 59.50999999999999s
#
# 789
# Epoch duration =2.39s
# Cumulative duration =31min 1.900000000000091s
#
# 790
# Epoch duration =2.33s
# Cumulative duration =31min 4.230000000000018s
#
# 791
# Epoch duration =2.33s
# Cumulative duration =31min 6.569999999999936s
#
# 792
# Epoch duration =2.34s
# Cumulative duration =31min 8.910000000000082s
#
# 793
# Epoch duration =2.37s
# Cumulative duration =31min 11.279999999999973s
#
# 794
# Epoch duration =2.39s
# Cumulative duration =31min 13.670000000000073s
#
# 795
# Epoch duration =2.35s
# Cumulative duration =31min 16.029999999999973s
#
# 796
# Epoch duration =2.35s
# Cumulative duration =31min 18.36999999999989s
#
# 797
# Epoch duration =2.38s
# Cumulative duration =31min 20.75s
#
# 798
# Epoch duration =2.34s
# Cumulative duration =31min 23.089999999999918s
#
# 799
# Epoch duration =2.35s
# Cumulative duration =31min 25.430000000000064s
#
# 800
# Epoch duration =2.34s
# Cumulative duration =31min 27.769999999999982s
#
# 801
# Epoch duration =2.34s
# Cumulative duration =31min 30.1099999999999s
#
# 802
# Epoch duration =2.4s
# Cumulative duration =31min 32.50999999999999s
#
# 803
# Epoch duration =2.39s
# Cumulative duration =31min 34.90000000000009s
#
# 804
# Epoch duration =2.37s
# Cumulative duration =31min 37.26999999999998s
#
# 805
# Epoch duration =2.4s
# Cumulative duration =31min 39.66000000000008s
#
# 806
# Epoch duration =2.34s
# Cumulative duration =31min 42.0s
#
# 807
# Epoch duration =2.32s
# Cumulative duration =31min 44.319999999999936s
#
# 808
# Epoch duration =2.35s
# Cumulative duration =31min 46.67000000000007s
#
# 809
# Epoch duration =2.34s
# Cumulative duration =31min 49.01999999999998s
#
# 810
# Epoch duration =2.33s
# Cumulative duration =31min 51.33999999999992s
#
# 811
# Epoch duration =2.35s
# Cumulative duration =31min 53.700000000000045s
#
# 812
# Epoch duration =2.39s
# Cumulative duration =31min 56.08999999999992s
#
# 813
# Epoch duration =2.34s
# Cumulative duration =31min 58.42000000000007s
#
# 814
# Epoch duration =2.36s
# Cumulative duration =32min 0.7799999999999727s
#
# 815
# Epoch duration =2.35s
# Cumulative duration =32min 3.130000000000109s
#
# 816
# Epoch duration =2.35s
# Cumulative duration =32min 5.480000000000018s
#
# 817
# Epoch duration =2.36s
# Cumulative duration =32min 7.839999999999918s
#
# 818
# Epoch duration =2.36s
# Cumulative duration =32min 10.200000000000045s
#
# 819
# Epoch duration =2.36s
# Cumulative duration =32min 12.559999999999945s
#
# 820
# Epoch duration =2.39s
# Cumulative duration =32min 14.950000000000045s
#
# 821
# Epoch duration =2.35s
# Cumulative duration =32min 17.299999999999955s
#
# 822
# Epoch duration =2.36s
# Cumulative duration =32min 19.660000000000082s
#
# 823
# Epoch duration =2.34s
# Cumulative duration =32min 22.00999999999999s
#
# 824
# Epoch duration =2.35s
# Cumulative duration =32min 24.34999999999991s
#
# 825
# Epoch duration =2.34s
# Cumulative duration =32min 26.700000000000045s
#
# 826
# Epoch duration =2.38s
# Cumulative duration =32min 29.079999999999927s
#
# 827
# Epoch duration =2.35s
# Cumulative duration =32min 31.430000000000064s
#
# 828
# Epoch duration =2.37s
# Cumulative duration =32min 33.799999999999955s
#
# 829
# Epoch duration =2.32s
# Cumulative duration =32min 36.1099999999999s
#
# 830
# Epoch duration =2.31s
# Cumulative duration =32min 38.42000000000007s
#
# 831
# Epoch duration =2.42s
# Cumulative duration =32min 40.82999999999993s
#
# 832
# Epoch duration =2.36s
# Cumulative duration =32min 43.190000000000055s
#
# 833
# Epoch duration =2.35s
# Cumulative duration =32min 45.539999999999964s
#
# 834
# Epoch duration =2.39s
# Cumulative duration =32min 47.940000000000055s
#
# 835
# Epoch duration =2.35s
# Cumulative duration =32min 50.289999999999964s
#
# 836
# Epoch duration =2.35s
# Cumulative duration =32min 52.63000000000011s
#
# 837
# Epoch duration =2.38s
# Cumulative duration =32min 55.00999999999999s
#
# 838
# Epoch duration =2.39s
# Cumulative duration =32min 57.40000000000009s
#
# 839
# Epoch duration =2.34s
# Cumulative duration =32min 59.74000000000001s
#
# 840
# Epoch duration =2.33s
# Cumulative duration =33min 2.0699999999999363s
#
# 841
# Epoch duration =2.38s
# Cumulative duration =33min 4.4500000000000455s
#
# 842
# Epoch duration =2.36s
# Cumulative duration =33min 6.7999999999999545s
#
# 843
# Epoch duration =2.36s
# Cumulative duration =33min 9.170000000000073s
#
# 844
# Epoch duration =2.36s
# Cumulative duration =33min 11.529999999999973s
#
# 845
# Epoch duration =2.34s
# Cumulative duration =33min 13.86999999999989s
#
# 846
# Epoch duration =2.32s
# Cumulative duration =33min 16.190000000000055s
#
# 847
# Epoch duration =2.34s
# Cumulative duration =33min 18.529999999999973s
#
# 848
# Epoch duration =2.35s
# Cumulative duration =33min 20.88000000000011s
#
# 849
# Epoch duration =2.42s
# Cumulative duration =33min 23.309999999999945s
#
# 850
# Epoch duration =2.39s
# Cumulative duration =33min 25.700000000000045s
#
# 851
# Epoch duration =2.43s
# Cumulative duration =33min 28.11999999999989s
#
# 852
# Epoch duration =2.36s
# Cumulative duration =33min 30.480000000000018s
#
# 853
# Epoch duration =2.34s
# Cumulative duration =33min 32.819999999999936s
#
# 854
# Epoch duration =2.33s
# Cumulative duration =33min 35.15000000000009s
#
# 855
# Epoch duration =2.33s
# Cumulative duration =33min 37.48000000000002s
#
# 856
# Epoch duration =2.32s
# Cumulative duration =33min 39.799999999999955s
#
# 857
# Epoch duration =2.35s
# Cumulative duration =33min 42.15000000000009s
#
# 858
# Epoch duration =2.34s
# Cumulative duration =33min 44.49000000000001s
#
# 859
# Epoch duration =2.33s
# Cumulative duration =33min 46.819999999999936s
#
# 860
# Epoch duration =2.34s
# Cumulative duration =33min 49.16000000000008s
#
# 861
# Epoch duration =2.35s
# Cumulative duration =33min 51.50999999999999s
#
# 862
# Epoch duration =2.35s
# Cumulative duration =33min 53.8599999999999s
#
# 863
# Epoch duration =2.33s
# Cumulative duration =33min 56.190000000000055s
#
# 864
# Epoch duration =2.36s
# Cumulative duration =33min 58.549999999999955s
#
# 865
# Epoch duration =2.38s
# Cumulative duration =34min 0.9300000000000637s
#
# 866
# Epoch duration =2.35s
# Cumulative duration =34min 3.2799999999999727s
#
# 867
# Epoch duration =2.36s
# Cumulative duration =34min 5.6400000000001s
#
# 868
# Epoch duration =2.41s
# Cumulative duration =34min 8.059999999999945s
#
# 869
# Epoch duration =2.33s
# Cumulative duration =34min 10.389999999999873s
#
# 870
# Epoch duration =2.39s
# Cumulative duration =34min 12.7800000000002s
#
# 871
# Epoch duration =2.36s
# Cumulative duration =34min 15.139999999999873s
#
# 872
# Epoch duration =2.37s
# Cumulative duration =34min 17.519999999999982s
#
# 873
# Epoch duration =2.41s
# Cumulative duration =34min 19.929999999999836s
#
# 874
# Epoch duration =2.34s
# Cumulative duration =34min 22.269999999999982s
#
# 875
# Epoch duration =2.34s
# Cumulative duration =34min 24.610000000000127s
#
# 876
# Epoch duration =2.36s
# Cumulative duration =34min 26.9699999999998s
#
# 877
# Epoch duration =2.36s
# Cumulative duration =34min 29.329999999999927s
#
# 878
# Epoch duration =2.35s
# Cumulative duration =34min 31.679999999999836s
#
# 879
# Epoch duration =2.36s
# Cumulative duration =34min 34.039999999999964s
#
# 880
# Epoch duration =2.36s
# Cumulative duration =34min 36.409999999999854s
#
# 881
# Epoch duration =2.6s
# Cumulative duration =34min 39.01000000000022s
#
# 882
# Epoch duration =2.67s
# Cumulative duration =34min 41.679999999999836s
#
# 883
# Epoch duration =2.38s
# Cumulative duration =34min 44.05000000000018s
#
# 884
# Epoch duration =2.34s
# Cumulative duration =34min 46.38999999999987s
#
# 885
# Epoch duration =2.36s
# Cumulative duration =34min 48.75s
#
# 886
# Epoch duration =2.38s
# Cumulative duration =34min 51.13000000000011s
#
# 887
# Epoch duration =2.41s
# Cumulative duration =34min 53.55000000000018s
#
# 888
# Epoch duration =2.36s
# Cumulative duration =34min 55.90000000000009s
#
# 889
# Epoch duration =2.35s
# Cumulative duration =34min 58.26000000000022s
#
# 890
# Epoch duration =2.4s
# Cumulative duration =35min 0.6599999999998545s
#
# 891
# Epoch duration =2.36s
# Cumulative duration =35min 3.019999999999982s
#
# 892
# Epoch duration =2.35s
# Cumulative duration =35min 5.369999999999891s
#
# 893
# Epoch duration =2.41s
# Cumulative duration =35min 7.769999999999982s
#
# 894
# Epoch duration =2.38s
# Cumulative duration =35min 10.150000000000091s
#
# 895
# Epoch duration =2.32s
# Cumulative duration =35min 12.4699999999998s
#
# 896
# Epoch duration =2.36s
# Cumulative duration =35min 14.829999999999927s
#
# 897
# Epoch duration =2.34s
# Cumulative duration =35min 17.170000000000073s
#
# 898
# Epoch duration =2.36s
# Cumulative duration =35min 19.5300000000002s
#
# 899
# Epoch duration =2.36s
# Cumulative duration =35min 21.889999999999873s
#
# 900
# Epoch duration =2.34s
# Cumulative duration =35min 24.230000000000018s
#
# 901
# Epoch duration =2.32s
# Cumulative duration =35min 26.559999999999945s
#
# 902
# Epoch duration =2.34s
# Cumulative duration =35min 28.90000000000009s
#
# 903
# Epoch duration =2.36s
# Cumulative duration =35min 31.26000000000022s
#
# 904
# Epoch duration =2.34s
# Cumulative duration =35min 33.59999999999991s
#
# 905
# Epoch duration =2.41s
# Cumulative duration =35min 36.01000000000022s
#
# 906
# Epoch duration =2.36s
# Cumulative duration =35min 38.36999999999989s
#
# 907
# Epoch duration =2.34s
# Cumulative duration =35min 40.710000000000036s
#
# 908
# Epoch duration =2.33s
# Cumulative duration =35min 43.039999999999964s
#
# 909
# Epoch duration =2.4s
# Cumulative duration =35min 45.44999999999982s
#
# 910
# Epoch duration =2.35s
# Cumulative duration =35min 47.80000000000018s
#
# 911
# Epoch duration =2.33s
# Cumulative duration =35min 50.13000000000011s
#
# 912
# Epoch duration =2.35s
# Cumulative duration =35min 52.48000000000002s
#
# 913
# Epoch duration =2.34s
# Cumulative duration =35min 54.820000000000164s
#
# 914
# Epoch duration =2.36s
# Cumulative duration =35min 57.179999999999836s
#
# 915
# Epoch duration =2.36s
# Cumulative duration =35min 59.539999999999964s
#
# 916
# Epoch duration =2.35s
# Cumulative duration =36min 1.8899999999998727s
#
# 917
# Epoch duration =2.35s
# Cumulative duration =36min 4.230000000000018s
#
# 918
# Epoch duration =2.34s
# Cumulative duration =36min 6.570000000000164s
#
# 919
# Epoch duration =2.37s
# Cumulative duration =36min 8.940000000000055s
#
# 920
# Epoch duration =2.34s
# Cumulative duration =36min 11.2800000000002s
#
# 921
# Epoch duration =2.37s
# Cumulative duration =36min 13.650000000000091s
#
# 922
# Epoch duration =2.38s
# Cumulative duration =36min 16.0300000000002s
#
# 923
# Epoch duration =2.32s
# Cumulative duration =36min 18.34999999999991s
#
# 924
# Epoch duration =2.36s
# Cumulative duration =36min 20.710000000000036s
#
# 925
# Epoch duration =2.33s
# Cumulative duration =36min 23.039999999999964s
#
# 926
# Epoch duration =2.36s
# Cumulative duration =36min 25.40000000000009s
#
# 927
# Epoch duration =2.36s
# Cumulative duration =36min 27.75s
#
# 928
# Epoch duration =2.32s
# Cumulative duration =36min 30.070000000000164s
#
# 929
# Epoch duration =2.37s
# Cumulative duration =36min 32.440000000000055s
#
# 930
# Epoch duration =2.35s
# Cumulative duration =36min 34.789999999999964s
#
# 931
# Epoch duration =2.34s
# Cumulative duration =36min 37.13000000000011s
#
# 932
# Epoch duration =2.34s
# Cumulative duration =36min 39.48000000000002s
#
# 933
# Epoch duration =2.4s
# Cumulative duration =36min 41.88000000000011s
#
# 934
# Epoch duration =2.38s
# Cumulative duration =36min 44.26999999999998s
#
# 935
# Epoch duration =2.34s
# Cumulative duration =36min 46.61000000000013s
#
# 936
# Epoch duration =2.4s
# Cumulative duration =36min 49.01000000000022s
#
# 937
# Epoch duration =2.39s
# Cumulative duration =36min 51.38999999999987s
#
# 938
# Epoch duration =2.38s
# Cumulative duration =36min 53.7800000000002s
#
# 939
# Epoch duration =2.35s
# Cumulative duration =36min 56.11999999999989s
#
# 940
# Epoch duration =2.34s
# Cumulative duration =36min 58.460000000000036s
#
# 941
# Epoch duration =2.33s
# Cumulative duration =37min 0.8000000000001819s
#
# 942
# Epoch duration =2.35s
# Cumulative duration =37min 3.150000000000091s
#
# 943
# Epoch duration =2.33s
# Cumulative duration =37min 5.480000000000018s
#
# 944
# Epoch duration =2.4s
# Cumulative duration =37min 7.880000000000109s
#
# 945
# Epoch duration =2.32s
# Cumulative duration =37min 10.210000000000036s
#
# 946
# Epoch duration =2.37s
# Cumulative duration =37min 12.570000000000164s
#
# 947
# Epoch duration =2.37s
# Cumulative duration =37min 14.940000000000055s
#
# 948
# Epoch duration =2.33s
# Cumulative duration =37min 17.2800000000002s
#
# 949
# Epoch duration =2.34s
# Cumulative duration =37min 19.61999999999989s
#
# 950
# Epoch duration =2.34s
# Cumulative duration =37min 21.960000000000036s
#
# 951
# Epoch duration =2.33s
# Cumulative duration =37min 24.289999999999964s
#
# 952
# Epoch duration =2.34s
# Cumulative duration =37min 26.63000000000011s
#
# 953
# Epoch duration =2.32s
# Cumulative duration =37min 28.949999999999818s
#
# 954
# Epoch duration =2.35s
# Cumulative duration =37min 31.300000000000182s
#
# 955
# Epoch duration =2.44s
# Cumulative duration =37min 33.75s
#
# 956
# Epoch duration =2.34s
# Cumulative duration =37min 36.090000000000146s
#
# 957
# Epoch duration =2.36s
# Cumulative duration =37min 38.44999999999982s
#
# 958
# Epoch duration =2.35s
# Cumulative duration =37min 40.80000000000018s
#
# 959
# Epoch duration =2.4s
# Cumulative duration =37min 43.19999999999982s
#
# 960
# Epoch duration =2.4s
# Cumulative duration =37min 45.59999999999991s
#
# 961
# Epoch duration =2.37s
# Cumulative duration =37min 47.98000000000002s
#
# 962
# Epoch duration =2.35s
# Cumulative duration =37min 50.32999999999993s
#
# 963
# Epoch duration =2.36s
# Cumulative duration =37min 52.679999999999836s
#
# 964
# Epoch duration =2.37s
# Cumulative duration =37min 55.05000000000018s
#
# 965
# Epoch duration =2.34s
# Cumulative duration =37min 57.40000000000009s
#
# 966
# Epoch duration =2.37s
# Cumulative duration =37min 59.76000000000022s
#
# 967
# Epoch duration =2.35s
# Cumulative duration =38min 2.119999999999891s
#
# 968
# Epoch duration =2.34s
# Cumulative duration =38min 4.460000000000036s
#
# 969
# Epoch duration =2.39s
# Cumulative duration =38min 6.849999999999909s
#
# 970
# Epoch duration =2.34s
# Cumulative duration =38min 9.199999999999818s
#
# 971
# Epoch duration =2.36s
# Cumulative duration =38min 11.559999999999945s
#
# 972
# Epoch duration =2.39s
# Cumulative duration =38min 13.949999999999818s
#
# 973
# Epoch duration =2.33s
# Cumulative duration =38min 16.269999999999982s
#
# 974
# Epoch duration =2.36s
# Cumulative duration =38min 18.63000000000011s
#
# 975
# Epoch duration =2.36s
# Cumulative duration =38min 20.98999999999978s
#
# 976
# Epoch duration =2.34s
# Cumulative duration =38min 23.329999999999927s
#
# 977
# Epoch duration =2.35s
# Cumulative duration =38min 25.679999999999836s
#
# 978
# Epoch duration =2.33s
# Cumulative duration =38min 28.0s
#
# 979
# Epoch duration =2.35s
# Cumulative duration =38min 30.360000000000127s
#
# 980
# Epoch duration =2.36s
# Cumulative duration =38min 32.7199999999998s
#
# 981
# Epoch duration =2.41s
# Cumulative duration =38min 35.13000000000011s
#
# 982
# Epoch duration =2.36s
# Cumulative duration =38min 37.48999999999978s
#
# 983
# Epoch duration =2.34s
# Cumulative duration =38min 39.820000000000164s
#
# 984
# Epoch duration =2.38s
# Cumulative duration =38min 42.19999999999982s
#
# 985
# Epoch duration =2.34s
# Cumulative duration =38min 44.539999999999964s
#
# 986
# Epoch duration =2.38s
# Cumulative duration =38min 46.92000000000007s
#
# 987
# Epoch duration =2.37s
# Cumulative duration =38min 49.289999999999964s
#
# 988
# Epoch duration =2.34s
# Cumulative duration =38min 51.63000000000011s
#
# 989
# Epoch duration =2.35s
# Cumulative duration =38min 53.98000000000002s
#
# 990
# Epoch duration =2.34s
# Cumulative duration =38min 56.320000000000164s
#
# 991
# Epoch duration =2.36s
# Cumulative duration =38min 58.679999999999836s
#
# 992
# Epoch duration =2.33s
# Cumulative duration =39min 1.0s
#
# 993
# Epoch duration =2.37s
# Cumulative duration =39min 3.369999999999891s
#
# 994
# Epoch duration =2.35s
# Cumulative duration =39min 5.7199999999998s
#
# 995
# Epoch duration =2.33s
# Cumulative duration =39min 8.050000000000182s
#
# 996
# Epoch duration =2.35s
# Cumulative duration =39min 10.400000000000091s
#
# 997
# Epoch duration =2.33s
# Cumulative duration =39min 12.739999999999782s
#
# 998
# Epoch duration =2.33s
# Cumulative duration =39min 15.070000000000164s
#
# 999
# Epoch duration =2.33s
# Cumulative duration =39min 17.40000000000009s
#
# Saving scores to Arrays/riboswitch_mlpt3_44_ug_so1k.npy

# %%
#load values
savepath = 'Arrays/riboswitch_mlpt3_44_ug_so1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

norm_meanhol_mut2 = mf.normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, vmax=1.0, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
