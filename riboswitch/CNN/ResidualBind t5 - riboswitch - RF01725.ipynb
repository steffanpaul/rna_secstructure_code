# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/riboswitch_100k_d5.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 9.51s

# %%
simalign_file = '../../../data_RFAM/riboswitch_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<>>>>>><<<<<<<<<>>>>>>>>>)))))<<<<>>>>'

# %%
ugSS
# Out:
# ':::::(((((,,,,<-<<<<<____>>>>>><<<--<<<<<<______>>>->>>->>>,,,,,)))))-<<<<____>>>>::::::::::::::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/riboswitch'
param_path = os.path.join(save_path, 'resbind_t5')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 816, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=13.89s -- loss=0.37793 -- acc=80.53333%
#
#   valid loss:		0.07013
#   valid accuracy:	0.97645+/-0.00000
#   valid auc-roc:	0.99757+/-0.00000
#   valid auc-pr:		0.99734+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t5_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=13.35s -- loss=0.07619 -- acc=97.54917%
#
#   valid loss:		0.03522
#   valid accuracy:	0.99135+/-0.00000
#   valid auc-roc:	0.99954+/-0.00000
#   valid auc-pr:		0.99950+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t5_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=13.34s -- loss=0.04734 -- acc=98.69083%
#
#   valid loss:		0.02844
#   valid accuracy:	0.99400+/-0.00000
#   valid auc-roc:	0.99979+/-0.00000
#   valid auc-pr:		0.99979+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t5_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=13.44s -- loss=0.04219 -- acc=98.95000%
#
#   valid loss:		0.02754
#   valid accuracy:	0.99545+/-0.00000
#   valid auc-roc:	0.99983+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t5_best.ckpt
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.03755 -- acc=99.16333%
#
#   valid loss:		0.02777
#   valid accuracy:	0.99590+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99983+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=13.59s -- loss=0.03667 -- acc=99.22417%
#
#   valid loss:		0.02957
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=13.60s -- loss=0.03667 -- acc=99.28667%
#
#   valid loss:		0.02958
#   valid accuracy:	0.99635+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=13.58s -- loss=0.03496 -- acc=99.41333%
#
#   valid loss:		0.03189
#   valid accuracy:	0.99560+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=13.51s -- loss=0.03513 -- acc=99.47250%
#
#   valid loss:		0.02819
#   valid accuracy:	0.99700+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=13.87s -- loss=0.03576 -- acc=99.46833%
#
#   valid loss:		0.03013
#   valid accuracy:	0.99665+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=14.20s -- loss=0.03540 -- acc=99.51083%
#
#   valid loss:		0.03184
#   valid accuracy:	0.99645+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=13.57s -- loss=0.03566 -- acc=99.50333%
#
#   valid loss:		0.03614
#   valid accuracy:	0.99540+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=13.46s -- loss=0.03564 -- acc=99.54583%
#
#   valid loss:		0.03162
#   valid accuracy:	0.99660+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=13.46s -- loss=0.03502 -- acc=99.56833%
#
#   valid loss:		0.03517
#   valid accuracy:	0.99615+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.03509 -- acc=99.56750%
#
#   valid loss:		0.03264
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=14.40s -- loss=0.03554 -- acc=99.57833%
#
#   valid loss:		0.03658
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=14.11s -- loss=0.03510 -- acc=99.60917%
#
#   valid loss:		0.03571
#   valid accuracy:	0.99605+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=14.04s -- loss=0.03390 -- acc=99.67583%
#
#   valid loss:		0.03446
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=14.10s -- loss=0.03504 -- acc=99.62417%
#
#   valid loss:		0.03412
#   valid accuracy:	0.99690+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=13.97s -- loss=0.03501 -- acc=99.62167%
#
#   valid loss:		0.03345
#   valid accuracy:	0.99660+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=13.99s -- loss=0.03402 -- acc=99.67917%
#
#   valid loss:		0.03387
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.03504 -- acc=99.65083%
#
#   valid loss:		0.03409
#   valid accuracy:	0.99665+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=14.09s -- loss=0.03515 -- acc=99.64000%
#
#   valid loss:		0.03274
#   valid accuracy:	0.99715+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=14.12s -- loss=0.03390 -- acc=99.70917%
#
#   valid loss:		0.03155
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=14.17s -- loss=0.03416 -- acc=99.67000%
#
#   valid loss:		0.03391
#   valid accuracy:	0.99700+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=14.13s -- loss=0.03458 -- acc=99.66917%
#
#   valid loss:		0.03512
#   valid accuracy:	0.99640+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=14.11s -- loss=0.03338 -- acc=99.70250%
#
#   valid loss:		0.03208
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=14.31s -- loss=0.03383 -- acc=99.68750%
#
#   valid loss:		0.03621
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=14.21s -- loss=0.03376 -- acc=99.69667%
#
#   valid loss:		0.03332
#   valid accuracy:	0.99710+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=14.12s -- loss=0.03321 -- acc=99.71250%
#
#   valid loss:		0.03316
#   valid accuracy:	0.99710+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=14.20s -- loss=0.03388 -- acc=99.69000%
#
#   valid loss:		0.03319
#   valid accuracy:	0.99690+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=14.03s -- loss=0.03295 -- acc=99.72500%
#
#   valid loss:		0.03676
#   valid accuracy:	0.99620+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=14.01s -- loss=0.03370 -- acc=99.71667%
#
#   valid loss:		0.03238
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=14.03s -- loss=0.03289 -- acc=99.72250%
#
#   valid loss:		0.03357
#   valid accuracy:	0.99670+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/riboswitch/resbind_t5_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/riboswitch/resbind_t5_best.ckpt
#   test  loss:		0.02696
#   test  accuracy:	0.99538+/-0.00000
#   test  auc-roc:	0.99987+/-0.00000
#   test  auc-pr:		0.99986+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

plt.figure()
plt.ylabel('Predicted score')
plt.xlabel('Sequences ordered by score')
plt.plot(range(len(plot_index)), predictionsoutput[plot_index])
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/riboswitch_resbindt5_ug_so1k.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =5.25s
# Cumulative duration =5.25s
#
# 1
# Epoch duration =5.22s
# Cumulative duration =10.47s
#
# 2
# Epoch duration =5.26s
# Cumulative duration =15.73s
#
# 3
# Epoch duration =5.22s
# Cumulative duration =20.95s
#
# 4
# Epoch duration =5.24s
# Cumulative duration =26.19s
#
# 5
# Epoch duration =5.21s
# Cumulative duration =31.4s
#
# 6
# Epoch duration =5.21s
# Cumulative duration =36.62s
#
# 7
# Epoch duration =5.23s
# Cumulative duration =41.85s
#
# 8
# Epoch duration =5.23s
# Cumulative duration =47.08s
#
# 9
# Epoch duration =5.22s
# Cumulative duration =52.31s
#
# 10
# Epoch duration =5.25s
# Cumulative duration =57.55s
#
# 11
# Epoch duration =5.21s
# Cumulative duration =1min 2.759999999999998s
#
# 12
# Epoch duration =5.26s
# Cumulative duration =1min 8.010000000000005s
#
# 13
# Epoch duration =5.24s
# Cumulative duration =1min 13.25s
#
# 14
# Epoch duration =5.21s
# Cumulative duration =1min 18.47s
#
# 15
# Epoch duration =5.23s
# Cumulative duration =1min 23.700000000000003s
#
# 16
# Epoch duration =5.24s
# Cumulative duration =1min 28.939999999999998s
#
# 17
# Epoch duration =5.25s
# Cumulative duration =1min 34.19s
#
# 18
# Epoch duration =5.27s
# Cumulative duration =1min 39.459999999999994s
#
# 19
# Epoch duration =5.24s
# Cumulative duration =1min 44.7s
#
# 20
# Epoch duration =5.25s
# Cumulative duration =1min 49.95s
#
# 21
# Epoch duration =5.26s
# Cumulative duration =1min 55.209999999999994s
#
# 22
# Epoch duration =5.23s
# Cumulative duration =2min 0.4399999999999977s
#
# 23
# Epoch duration =5.23s
# Cumulative duration =2min 5.670000000000002s
#
# 24
# Epoch duration =5.23s
# Cumulative duration =2min 10.900000000000006s
#
# 25
# Epoch duration =5.24s
# Cumulative duration =2min 16.139999999999986s
#
# 26
# Epoch duration =5.23s
# Cumulative duration =2min 21.370000000000005s
#
# 27
# Epoch duration =5.25s
# Cumulative duration =2min 26.620000000000005s
#
# 28
# Epoch duration =5.27s
# Cumulative duration =2min 31.900000000000006s
#
# 29
# Epoch duration =5.25s
# Cumulative duration =2min 37.139999999999986s
#
# 30
# Epoch duration =5.24s
# Cumulative duration =2min 42.389999999999986s
#
# 31
# Epoch duration =5.25s
# Cumulative duration =2min 47.639999999999986s
#
# 32
# Epoch duration =5.25s
# Cumulative duration =2min 52.889999999999986s
#
# 33
# Epoch duration =5.27s
# Cumulative duration =2min 58.16s
#
# 34
# Epoch duration =5.23s
# Cumulative duration =3min 3.3799999999999955s
#
# 35
# Epoch duration =5.27s
# Cumulative duration =3min 8.650000000000006s
#
# 36
# Epoch duration =5.23s
# Cumulative duration =3min 13.889999999999986s
#
# 37
# Epoch duration =5.24s
# Cumulative duration =3min 19.129999999999995s
#
# 38
# Epoch duration =5.24s
# Cumulative duration =3min 24.370000000000005s
#
# 39
# Epoch duration =5.26s
# Cumulative duration =3min 29.620000000000005s
#
# 40
# Epoch duration =5.24s
# Cumulative duration =3min 34.860000000000014s
#
# 41
# Epoch duration =5.23s
# Cumulative duration =3min 40.09s
#
# 42
# Epoch duration =5.25s
# Cumulative duration =3min 45.34s
#
# 43
# Epoch duration =5.25s
# Cumulative duration =3min 50.59s
#
# 44
# Epoch duration =5.25s
# Cumulative duration =3min 55.84s
#
# 45
# Epoch duration =5.24s
# Cumulative duration =4min 1.0800000000000125s
#
# 46
# Epoch duration =5.25s
# Cumulative duration =4min 6.3300000000000125s
#
# 47
# Epoch duration =5.28s
# Cumulative duration =4min 11.610000000000014s
#
# 48
# Epoch duration =5.24s
# Cumulative duration =4min 16.850000000000023s
#
# 49
# Epoch duration =5.23s
# Cumulative duration =4min 22.089999999999975s
#
# 50
# Epoch duration =5.25s
# Cumulative duration =4min 27.329999999999984s
#
# 51
# Epoch duration =5.23s
# Cumulative duration =4min 32.56s
#
# 52
# Epoch duration =5.27s
# Cumulative duration =4min 37.839999999999975s
#
# 53
# Epoch duration =5.23s
# Cumulative duration =4min 43.06999999999999s
#
# 54
# Epoch duration =5.23s
# Cumulative duration =4min 48.30000000000001s
#
# 55
# Epoch duration =5.25s
# Cumulative duration =4min 53.55000000000001s
#
# 56
# Epoch duration =5.24s
# Cumulative duration =4min 58.79000000000002s
#
# 57
# Epoch duration =5.22s
# Cumulative duration =5min 4.019999999999982s
#
# 58
# Epoch duration =5.27s
# Cumulative duration =5min 9.29000000000002s
#
# 59
# Epoch duration =5.24s
# Cumulative duration =5min 14.529999999999973s
#
# 60
# Epoch duration =5.24s
# Cumulative duration =5min 19.779999999999973s
#
# 61
# Epoch duration =5.23s
# Cumulative duration =5min 25.00999999999999s
#
# 62
# Epoch duration =5.22s
# Cumulative duration =5min 30.220000000000027s
#
# 63
# Epoch duration =5.23s
# Cumulative duration =5min 35.45999999999998s
#
# 64
# Epoch duration =5.25s
# Cumulative duration =5min 40.69999999999999s
#
# 65
# Epoch duration =5.23s
# Cumulative duration =5min 45.94s
#
# 66
# Epoch duration =5.23s
# Cumulative duration =5min 51.160000000000025s
#
# 67
# Epoch duration =5.23s
# Cumulative duration =5min 56.39999999999998s
#
# 68
# Epoch duration =5.22s
# Cumulative duration =6min 1.6200000000000045s
#
# 69
# Epoch duration =5.25s
# Cumulative duration =6min 6.8700000000000045s
#
# 70
# Epoch duration =5.24s
# Cumulative duration =6min 12.110000000000014s
#
# 71
# Epoch duration =5.24s
# Cumulative duration =6min 17.350000000000023s
#
# 72
# Epoch duration =5.23s
# Cumulative duration =6min 22.579999999999984s
#
# 73
# Epoch duration =5.26s
# Cumulative duration =6min 27.839999999999975s
#
# 74
# Epoch duration =5.23s
# Cumulative duration =6min 33.06999999999999s
#
# 75
# Epoch duration =5.25s
# Cumulative duration =6min 38.31999999999999s
#
# 76
# Epoch duration =5.23s
# Cumulative duration =6min 43.54000000000002s
#
# 77
# Epoch duration =5.23s
# Cumulative duration =6min 48.77999999999997s
#
# 78
# Epoch duration =5.25s
# Cumulative duration =6min 54.02999999999997s
#
# 79
# Epoch duration =5.23s
# Cumulative duration =6min 59.25999999999999s
#
# 80
# Epoch duration =5.27s
# Cumulative duration =7min 4.529999999999973s
#
# 81
# Epoch duration =5.27s
# Cumulative duration =7min 9.800000000000011s
#
# 82
# Epoch duration =5.24s
# Cumulative duration =7min 15.04000000000002s
#
# 83
# Epoch duration =5.24s
# Cumulative duration =7min 20.279999999999973s
#
# 84
# Epoch duration =5.24s
# Cumulative duration =7min 25.519999999999982s
#
# 85
# Epoch duration =5.28s
# Cumulative duration =7min 30.80000000000001s
#
# 86
# Epoch duration =5.23s
# Cumulative duration =7min 36.02999999999997s
#
# 87
# Epoch duration =5.24s
# Cumulative duration =7min 41.26999999999998s
#
# 88
# Epoch duration =5.24s
# Cumulative duration =7min 46.50999999999999s
#
# 89
# Epoch duration =5.26s
# Cumulative duration =7min 51.76999999999998s
#
# 90
# Epoch duration =5.24s
# Cumulative duration =7min 57.00999999999999s
#
# 91
# Epoch duration =5.25s
# Cumulative duration =8min 2.259999999999991s
#
# 92
# Epoch duration =5.23s
# Cumulative duration =8min 7.490000000000009s
#
# 93
# Epoch duration =5.23s
# Cumulative duration =8min 12.720000000000027s
#
# 94
# Epoch duration =5.24s
# Cumulative duration =8min 17.95999999999998s
#
# 95
# Epoch duration =5.25s
# Cumulative duration =8min 23.20999999999998s
#
# 96
# Epoch duration =5.24s
# Cumulative duration =8min 28.44999999999999s
#
# 97
# Epoch duration =5.25s
# Cumulative duration =8min 33.700000000000045s
#
# 98
# Epoch duration =5.33s
# Cumulative duration =8min 39.01999999999998s
#
# 99
# Epoch duration =5.23s
# Cumulative duration =8min 44.25s
#
# 100
# Epoch duration =5.24s
# Cumulative duration =8min 49.5s
#
# 101
# Epoch duration =5.26s
# Cumulative duration =8min 54.75s
#
# 102
# Epoch duration =5.26s
# Cumulative duration =9min 0.009999999999990905s
#
# 103
# Epoch duration =5.24s
# Cumulative duration =9min 5.259999999999991s
#
# 104
# Epoch duration =5.26s
# Cumulative duration =9min 10.509999999999991s
#
# 105
# Epoch duration =5.22s
# Cumulative duration =9min 15.730000000000018s
#
# 106
# Epoch duration =5.26s
# Cumulative duration =9min 20.99000000000001s
#
# 107
# Epoch duration =5.24s
# Cumulative duration =9min 26.24000000000001s
#
# 108
# Epoch duration =5.23s
# Cumulative duration =9min 31.470000000000027s
#
# 109
# Epoch duration =5.24s
# Cumulative duration =9min 36.710000000000036s
#
# 110
# Epoch duration =5.26s
# Cumulative duration =9min 41.97000000000003s
#
# 111
# Epoch duration =5.24s
# Cumulative duration =9min 47.22000000000003s
#
# 112
# Epoch duration =5.24s
# Cumulative duration =9min 52.450000000000045s
#
# 113
# Epoch duration =5.25s
# Cumulative duration =9min 57.700000000000045s
#
# 114
# Epoch duration =5.25s
# Cumulative duration =10min 2.9500000000000455s
#
# 115
# Epoch duration =5.24s
# Cumulative duration =10min 8.190000000000055s
#
# 116
# Epoch duration =5.24s
# Cumulative duration =10min 13.42999999999995s
#
# 117
# Epoch duration =5.24s
# Cumulative duration =10min 18.66999999999996s
#
# 118
# Epoch duration =5.25s
# Cumulative duration =10min 23.91999999999996s
#
# 119
# Epoch duration =5.23s
# Cumulative duration =10min 29.149999999999977s
#
# 120
# Epoch duration =5.23s
# Cumulative duration =10min 34.379999999999995s
#
# 121
# Epoch duration =5.25s
# Cumulative duration =10min 39.629999999999995s
#
# 122
# Epoch duration =5.23s
# Cumulative duration =10min 44.860000000000014s
#
# 123
# Epoch duration =5.24s
# Cumulative duration =10min 50.10000000000002s
#
# 124
# Epoch duration =5.24s
# Cumulative duration =10min 55.34000000000003s
#
# 125
# Epoch duration =5.25s
# Cumulative duration =11min 0.5800000000000409s
#
# 126
# Epoch duration =5.24s
# Cumulative duration =11min 5.82000000000005s
#
# 127
# Epoch duration =5.25s
# Cumulative duration =11min 11.07000000000005s
#
# 128
# Epoch duration =5.24s
# Cumulative duration =11min 16.309999999999945s
#
# 129
# Epoch duration =5.23s
# Cumulative duration =11min 21.539999999999964s
#
# 130
# Epoch duration =5.25s
# Cumulative duration =11min 26.789999999999964s
#
# 131
# Epoch duration =5.26s
# Cumulative duration =11min 32.049999999999955s
#
# 132
# Epoch duration =5.24s
# Cumulative duration =11min 37.289999999999964s
#
# 133
# Epoch duration =5.25s
# Cumulative duration =11min 42.539999999999964s
#
# 134
# Epoch duration =5.26s
# Cumulative duration =11min 47.799999999999955s
#
# 135
# Epoch duration =5.23s
# Cumulative duration =11min 53.02999999999997s
#
# 136
# Epoch duration =5.26s
# Cumulative duration =11min 58.289999999999964s
#
# 137
# Epoch duration =5.25s
# Cumulative duration =12min 3.5399999999999636s
#
# 138
# Epoch duration =5.24s
# Cumulative duration =12min 8.779999999999973s
#
# 139
# Epoch duration =5.23s
# Cumulative duration =12min 14.009999999999991s
#
# 140
# Epoch duration =5.26s
# Cumulative duration =12min 19.269999999999982s
#
# 141
# Epoch duration =5.25s
# Cumulative duration =12min 24.519999999999982s
#
# 142
# Epoch duration =5.24s
# Cumulative duration =12min 29.75s
#
# 143
# Epoch duration =5.26s
# Cumulative duration =12min 35.01999999999998s
#
# 144
# Epoch duration =5.25s
# Cumulative duration =12min 40.25999999999999s
#
# 145
# Epoch duration =5.24s
# Cumulative duration =12min 45.5s
#
# 146
# Epoch duration =5.26s
# Cumulative duration =12min 50.75999999999999s
#
# 147
# Epoch duration =5.22s
# Cumulative duration =12min 55.98000000000002s
#
# 148
# Epoch duration =5.24s
# Cumulative duration =13min 1.2200000000000273s
#
# 149
# Epoch duration =5.23s
# Cumulative duration =13min 6.4500000000000455s
#
# 150
# Epoch duration =5.27s
# Cumulative duration =13min 11.720000000000027s
#
# 151
# Epoch duration =5.23s
# Cumulative duration =13min 16.950000000000045s
#
# 152
# Epoch duration =5.24s
# Cumulative duration =13min 22.17999999999995s
#
# 153
# Epoch duration =5.24s
# Cumulative duration =13min 27.42999999999995s
#
# 154
# Epoch duration =5.24s
# Cumulative duration =13min 32.65999999999997s
#
# 155
# Epoch duration =5.24s
# Cumulative duration =13min 37.89999999999998s
#
# 156
# Epoch duration =5.23s
# Cumulative duration =13min 43.129999999999995s
#
# 157
# Epoch duration =5.23s
# Cumulative duration =13min 48.360000000000014s
#
# 158
# Epoch duration =5.23s
# Cumulative duration =13min 53.59000000000003s
#
# 159
# Epoch duration =5.23s
# Cumulative duration =13min 58.82000000000005s
#
# 160
# Epoch duration =5.26s
# Cumulative duration =14min 4.080000000000041s
#
# 161
# Epoch duration =5.25s
# Cumulative duration =14min 9.330000000000041s
#
# 162
# Epoch duration =5.25s
# Cumulative duration =14min 14.580000000000041s
#
# 163
# Epoch duration =5.23s
# Cumulative duration =14min 19.809999999999945s
#
# 164
# Epoch duration =5.24s
# Cumulative duration =14min 25.049999999999955s
#
# 165
# Epoch duration =5.27s
# Cumulative duration =14min 30.32000000000005s
#
# 166
# Epoch duration =5.25s
# Cumulative duration =14min 35.57000000000005s
#
# 167
# Epoch duration =5.25s
# Cumulative duration =14min 40.82000000000005s
#
# 168
# Epoch duration =5.23s
# Cumulative duration =14min 46.049999999999955s
#
# 169
# Epoch duration =5.22s
# Cumulative duration =14min 51.27999999999997s
#
# 170
# Epoch duration =5.24s
# Cumulative duration =14min 56.51999999999998s
#
# 171
# Epoch duration =5.24s
# Cumulative duration =15min 1.759999999999991s
#
# 172
# Epoch duration =5.24s
# Cumulative duration =15min 7.0s
#
# 173
# Epoch duration =5.24s
# Cumulative duration =15min 12.240000000000009s
#
# 174
# Epoch duration =5.24s
# Cumulative duration =15min 17.49000000000001s
#
# 175
# Epoch duration =5.24s
# Cumulative duration =15min 22.720000000000027s
#
# 176
# Epoch duration =5.23s
# Cumulative duration =15min 27.960000000000036s
#
# 177
# Epoch duration =5.23s
# Cumulative duration =15min 33.190000000000055s
#
# 178
# Epoch duration =5.25s
# Cumulative duration =15min 38.440000000000055s
#
# 179
# Epoch duration =5.22s
# Cumulative duration =15min 43.65999999999997s
#
# 180
# Epoch duration =5.24s
# Cumulative duration =15min 48.89999999999998s
#
# 181
# Epoch duration =5.25s
# Cumulative duration =15min 54.139999999999986s
#
# 182
# Epoch duration =5.25s
# Cumulative duration =15min 59.39999999999998s
#
# 183
# Epoch duration =5.24s
# Cumulative duration =16min 4.6299999999999955s
#
# 184
# Epoch duration =5.22s
# Cumulative duration =16min 9.860000000000014s
#
# 185
# Epoch duration =5.24s
# Cumulative duration =16min 15.100000000000023s
#
# 186
# Epoch duration =5.24s
# Cumulative duration =16min 20.340000000000032s
#
# 187
# Epoch duration =5.28s
# Cumulative duration =16min 25.620000000000005s
#
# 188
# Epoch duration =5.25s
# Cumulative duration =16min 30.870000000000005s
#
# 189
# Epoch duration =5.26s
# Cumulative duration =16min 36.120000000000005s
#
# 190
# Epoch duration =5.27s
# Cumulative duration =16min 41.389999999999986s
#
# 191
# Epoch duration =5.23s
# Cumulative duration =16min 46.629999999999995s
#
# 192
# Epoch duration =5.23s
# Cumulative duration =16min 51.860000000000014s
#
# 193
# Epoch duration =5.24s
# Cumulative duration =16min 57.10000000000002s
#
# 194
# Epoch duration =5.26s
# Cumulative duration =17min 2.3600000000000136s
#
# 195
# Epoch duration =5.24s
# Cumulative duration =17min 7.589999999999918s
#
# 196
# Epoch duration =5.25s
# Cumulative duration =17min 12.839999999999918s
#
# 197
# Epoch duration =5.23s
# Cumulative duration =17min 18.079999999999927s
#
# 198
# Epoch duration =5.23s
# Cumulative duration =17min 23.309999999999945s
#
# 199
# Epoch duration =5.22s
# Cumulative duration =17min 28.539999999999964s
#
# 200
# Epoch duration =5.23s
# Cumulative duration =17min 33.75999999999999s
#
# 201
# Epoch duration =5.23s
# Cumulative duration =17min 39.0s
#
# 202
# Epoch duration =5.23s
# Cumulative duration =17min 44.22000000000003s
#
# 203
# Epoch duration =5.24s
# Cumulative duration =17min 49.460000000000036s
#
# 204
# Epoch duration =5.24s
# Cumulative duration =17min 54.700000000000045s
#
# 205
# Epoch duration =5.27s
# Cumulative duration =17min 59.97000000000003s
#
# 206
# Epoch duration =5.25s
# Cumulative duration =18min 5.220000000000027s
#
# 207
# Epoch duration =5.28s
# Cumulative duration =18min 10.5s
#
# 208
# Epoch duration =5.25s
# Cumulative duration =18min 15.75s
#
# 209
# Epoch duration =5.24s
# Cumulative duration =18min 20.99000000000001s
#
# 210
# Epoch duration =5.24s
# Cumulative duration =18min 26.230000000000018s
#
# 211
# Epoch duration =5.23s
# Cumulative duration =18min 31.470000000000027s
#
# 212
# Epoch duration =5.27s
# Cumulative duration =18min 36.73000000000002s
#
# 213
# Epoch duration =5.24s
# Cumulative duration =18min 41.98000000000002s
#
# 214
# Epoch duration =5.25s
# Cumulative duration =18min 47.22000000000003s
#
# 215
# Epoch duration =5.24s
# Cumulative duration =18min 52.47000000000003s
#
# 216
# Epoch duration =5.26s
# Cumulative duration =18min 57.73000000000002s
#
# 217
# Epoch duration =5.25s
# Cumulative duration =19min 2.980000000000018s
#
# 218
# Epoch duration =5.27s
# Cumulative duration =19min 8.25s
#
# 219
# Epoch duration =5.26s
# Cumulative duration =19min 13.509999999999991s
#
# 220
# Epoch duration =5.24s
# Cumulative duration =19min 18.75s
#
# 221
# Epoch duration =5.25s
# Cumulative duration =19min 24.0s
#
# 222
# Epoch duration =5.24s
# Cumulative duration =19min 29.24000000000001s
#
# 223
# Epoch duration =5.22s
# Cumulative duration =19min 34.460000000000036s
#
# 224
# Epoch duration =5.25s
# Cumulative duration =19min 39.710000000000036s
#
# 225
# Epoch duration =5.26s
# Cumulative duration =19min 44.97000000000003s
#
# 226
# Epoch duration =5.22s
# Cumulative duration =19min 50.190000000000055s
#
# 227
# Epoch duration =5.24s
# Cumulative duration =19min 55.430000000000064s
#
# 228
# Epoch duration =5.25s
# Cumulative duration =20min 0.6700000000000728s
#
# 229
# Epoch duration =5.23s
# Cumulative duration =20min 5.900000000000091s
#
# 230
# Epoch duration =5.24s
# Cumulative duration =20min 11.1400000000001s
#
# 231
# Epoch duration =5.25s
# Cumulative duration =20min 16.3900000000001s
#
# 232
# Epoch duration =5.24s
# Cumulative duration =20min 21.63000000000011s
#
# 233
# Epoch duration =5.25s
# Cumulative duration =20min 26.88000000000011s
#
# 234
# Epoch duration =5.23s
# Cumulative duration =20min 32.09999999999991s
#
# 235
# Epoch duration =5.25s
# Cumulative duration =20min 37.3599999999999s
#
# 236
# Epoch duration =5.24s
# Cumulative duration =20min 42.59999999999991s
#
# 237
# Epoch duration =5.25s
# Cumulative duration =20min 47.83999999999992s
#
# 238
# Epoch duration =5.29s
# Cumulative duration =20min 53.13000000000011s
#
# 239
# Epoch duration =5.24s
# Cumulative duration =20min 58.38000000000011s
#
# 240
# Epoch duration =5.26s
# Cumulative duration =21min 3.6400000000001s
#
# 241
# Epoch duration =5.26s
# Cumulative duration =21min 8.900000000000091s
#
# 242
# Epoch duration =5.23s
# Cumulative duration =21min 14.13000000000011s
#
# 243
# Epoch duration =5.22s
# Cumulative duration =21min 19.34999999999991s
#
# 244
# Epoch duration =5.22s
# Cumulative duration =21min 24.569999999999936s
#
# 245
# Epoch duration =5.27s
# Cumulative duration =21min 29.839999999999918s
#
# 246
# Epoch duration =5.27s
# Cumulative duration =21min 35.1099999999999s
#
# 247
# Epoch duration =5.23s
# Cumulative duration =21min 40.33999999999992s
#
# 248
# Epoch duration =5.26s
# Cumulative duration =21min 45.59999999999991s
#
# 249
# Epoch duration =5.26s
# Cumulative duration =21min 50.84999999999991s
#
# 250
# Epoch duration =5.24s
# Cumulative duration =21min 56.08999999999992s
#
# 251
# Epoch duration =5.26s
# Cumulative duration =22min 1.349999999999909s
#
# 252
# Epoch duration =5.23s
# Cumulative duration =22min 6.579999999999927s
#
# 253
# Epoch duration =5.24s
# Cumulative duration =22min 11.819999999999936s
#
# 254
# Epoch duration =5.23s
# Cumulative duration =22min 17.049999999999955s
#
# 255
# Epoch duration =5.23s
# Cumulative duration =22min 22.279999999999973s
#
# 256
# Epoch duration =5.23s
# Cumulative duration =22min 27.519999999999982s
#
# 257
# Epoch duration =5.23s
# Cumulative duration =22min 32.75s
#
# 258
# Epoch duration =5.22s
# Cumulative duration =22min 37.97000000000003s
#
# 259
# Epoch duration =5.22s
# Cumulative duration =22min 43.180000000000064s
#
# 260
# Epoch duration =5.26s
# Cumulative duration =22min 48.450000000000045s
#
# 261
# Epoch duration =5.25s
# Cumulative duration =22min 53.690000000000055s
#
# 262
# Epoch duration =5.25s
# Cumulative duration =22min 58.940000000000055s
#
# 263
# Epoch duration =5.26s
# Cumulative duration =23min 4.2000000000000455s
#
# 264
# Epoch duration =5.28s
# Cumulative duration =23min 9.480000000000018s
#
# 265
# Epoch duration =5.23s
# Cumulative duration =23min 14.720000000000027s
#
# 266
# Epoch duration =5.24s
# Cumulative duration =23min 19.960000000000036s
#
# 267
# Epoch duration =5.25s
# Cumulative duration =23min 25.210000000000036s
#
# 268
# Epoch duration =5.23s
# Cumulative duration =23min 30.440000000000055s
#
# 269
# Epoch duration =5.22s
# Cumulative duration =23min 35.65000000000009s
#
# 270
# Epoch duration =5.25s
# Cumulative duration =23min 40.91000000000008s
#
# 271
# Epoch duration =5.23s
# Cumulative duration =23min 46.1400000000001s
#
# 272
# Epoch duration =5.23s
# Cumulative duration =23min 51.38000000000011s
#
# 273
# Epoch duration =5.24s
# Cumulative duration =23min 56.61999999999989s
#
# 274
# Epoch duration =5.31s
# Cumulative duration =24min 1.9300000000000637s
#
# 275
# Epoch duration =5.24s
# Cumulative duration =24min 7.170000000000073s
#
# 276
# Epoch duration =5.25s
# Cumulative duration =24min 12.420000000000073s
#
# 277
# Epoch duration =5.24s
# Cumulative duration =24min 17.660000000000082s
#
# 278
# Epoch duration =5.23s
# Cumulative duration =24min 22.88000000000011s
#
# 279
# Epoch duration =5.25s
# Cumulative duration =24min 28.1400000000001s
#
# 280
# Epoch duration =5.23s
# Cumulative duration =24min 33.36999999999989s
#
# 281
# Epoch duration =5.24s
# Cumulative duration =24min 38.6099999999999s
#
# 282
# Epoch duration =5.23s
# Cumulative duration =24min 43.83999999999992s
#
# 283
# Epoch duration =5.23s
# Cumulative duration =24min 49.069999999999936s
#
# 284
# Epoch duration =5.23s
# Cumulative duration =24min 54.309999999999945s
#
# 285
# Epoch duration =5.23s
# Cumulative duration =24min 59.52999999999997s
#
# 286
# Epoch duration =5.26s
# Cumulative duration =25min 4.789999999999964s
#
# 287
# Epoch duration =5.25s
# Cumulative duration =25min 10.039999999999964s
#
# 288
# Epoch duration =5.24s
# Cumulative duration =25min 15.289999999999964s
#
# 289
# Epoch duration =5.25s
# Cumulative duration =25min 20.539999999999964s
#
# 290
# Epoch duration =5.24s
# Cumulative duration =25min 25.779999999999973s
#
# 291
# Epoch duration =5.24s
# Cumulative duration =25min 31.019999999999982s
#
# 292
# Epoch duration =5.23s
# Cumulative duration =25min 36.25999999999999s
#
# 293
# Epoch duration =5.26s
# Cumulative duration =25min 41.51999999999998s
#
# 294
# Epoch duration =5.22s
# Cumulative duration =25min 46.74000000000001s
#
# 295
# Epoch duration =5.24s
# Cumulative duration =25min 51.99000000000001s
#
# 296
# Epoch duration =5.26s
# Cumulative duration =25min 57.24000000000001s
#
# 297
# Epoch duration =5.24s
# Cumulative duration =26min 2.480000000000018s
#
# 298
# Epoch duration =5.23s
# Cumulative duration =26min 7.710000000000036s
#
# 299
# Epoch duration =5.25s
# Cumulative duration =26min 12.970000000000027s
#
# 300
# Epoch duration =5.24s
# Cumulative duration =26min 18.210000000000036s
#
# 301
# Epoch duration =5.25s
# Cumulative duration =26min 23.450000000000045s
#
# 302
# Epoch duration =5.23s
# Cumulative duration =26min 28.690000000000055s
#
# 303
# Epoch duration =5.23s
# Cumulative duration =26min 33.92000000000007s
#
# 304
# Epoch duration =5.26s
# Cumulative duration =26min 39.180000000000064s
#
# 305
# Epoch duration =5.24s
# Cumulative duration =26min 44.430000000000064s
#
# 306
# Epoch duration =5.25s
# Cumulative duration =26min 49.680000000000064s
#
# 307
# Epoch duration =5.23s
# Cumulative duration =26min 54.91000000000008s
#
# 308
# Epoch duration =5.24s
# Cumulative duration =27min 0.15000000000009095s
#
# 309
# Epoch duration =5.24s
# Cumulative duration =27min 5.400000000000091s
#
# 310
# Epoch duration =5.27s
# Cumulative duration =27min 10.670000000000073s
#
# 311
# Epoch duration =5.24s
# Cumulative duration =27min 15.910000000000082s
#
# 312
# Epoch duration =5.23s
# Cumulative duration =27min 21.1400000000001s
#
# 313
# Epoch duration =5.24s
# Cumulative duration =27min 26.3900000000001s
#
# 314
# Epoch duration =5.24s
# Cumulative duration =27min 31.63000000000011s
#
# 315
# Epoch duration =5.25s
# Cumulative duration =27min 36.88000000000011s
#
# 316
# Epoch duration =5.24s
# Cumulative duration =27min 42.11999999999989s
#
# 317
# Epoch duration =5.27s
# Cumulative duration =27min 47.3900000000001s
#
# 318
# Epoch duration =5.23s
# Cumulative duration =27min 52.61999999999989s
#
# 319
# Epoch duration =5.22s
# Cumulative duration =27min 57.83999999999992s
#
# 320
# Epoch duration =5.23s
# Cumulative duration =28min 3.0799999999999272s
#
# 321
# Epoch duration =5.26s
# Cumulative duration =28min 8.339999999999918s
#
# 322
# Epoch duration =5.23s
# Cumulative duration =28min 13.569999999999936s
#
# 323
# Epoch duration =5.25s
# Cumulative duration =28min 18.819999999999936s
#
# 324
# Epoch duration =5.24s
# Cumulative duration =28min 24.059999999999945s
#
# 325
# Epoch duration =5.25s
# Cumulative duration =28min 29.299999999999955s
#
# 326
# Epoch duration =5.25s
# Cumulative duration =28min 34.549999999999955s
#
# 327
# Epoch duration =5.22s
# Cumulative duration =28min 39.76999999999998s
#
# 328
# Epoch duration =5.22s
# Cumulative duration =28min 44.99000000000001s
#
# 329
# Epoch duration =5.26s
# Cumulative duration =28min 50.25999999999999s
#
# 330
# Epoch duration =5.23s
# Cumulative duration =28min 55.48000000000002s
#
# 331
# Epoch duration =5.25s
# Cumulative duration =29min 0.7400000000000091s
#
# 332
# Epoch duration =5.24s
# Cumulative duration =29min 5.980000000000018s
#
# 333
# Epoch duration =5.24s
# Cumulative duration =29min 11.220000000000027s
#
# 334
# Epoch duration =5.21s
# Cumulative duration =29min 16.430000000000064s
#
# 335
# Epoch duration =5.22s
# Cumulative duration =29min 21.65000000000009s
#
# 336
# Epoch duration =5.26s
# Cumulative duration =29min 26.910000000000082s
#
# 337
# Epoch duration =5.23s
# Cumulative duration =29min 32.1400000000001s
#
# 338
# Epoch duration =5.25s
# Cumulative duration =29min 37.3900000000001s
#
# 339
# Epoch duration =5.24s
# Cumulative duration =29min 42.63000000000011s
#
# 340
# Epoch duration =5.24s
# Cumulative duration =29min 47.86999999999989s
#
# 341
# Epoch duration =5.24s
# Cumulative duration =29min 53.11999999999989s
#
# 342
# Epoch duration =5.25s
# Cumulative duration =29min 58.36999999999989s
#
# 343
# Epoch duration =5.23s
# Cumulative duration =30min 3.599999999999909s
#
# 344
# Epoch duration =5.24s
# Cumulative duration =30min 8.839999999999918s
#
# 345
# Epoch duration =5.26s
# Cumulative duration =30min 14.099999999999909s
#
# 346
# Epoch duration =5.23s
# Cumulative duration =30min 19.339999999999918s
#
# 347
# Epoch duration =5.26s
# Cumulative duration =30min 24.589999999999918s
#
# 348
# Epoch duration =5.27s
# Cumulative duration =30min 29.8599999999999s
#
# 349
# Epoch duration =5.24s
# Cumulative duration =30min 35.09999999999991s
#
# 350
# Epoch duration =5.26s
# Cumulative duration =30min 40.3599999999999s
#
# 351
# Epoch duration =5.22s
# Cumulative duration =30min 45.57999999999993s
#
# 352
# Epoch duration =5.24s
# Cumulative duration =30min 50.819999999999936s
#
# 353
# Epoch duration =5.23s
# Cumulative duration =30min 56.049999999999955s
#
# 354
# Epoch duration =5.25s
# Cumulative duration =31min 1.2899999999999636s
#
# 355
# Epoch duration =5.23s
# Cumulative duration =31min 6.519999999999982s
#
# 356
# Epoch duration =5.25s
# Cumulative duration =31min 11.779999999999973s
#
# 357
# Epoch duration =5.26s
# Cumulative duration =31min 17.029999999999973s
#
# 358
# Epoch duration =5.24s
# Cumulative duration =31min 22.269999999999982s
#
# 359
# Epoch duration =5.23s
# Cumulative duration =31min 27.50999999999999s
#
# 360
# Epoch duration =5.26s
# Cumulative duration =31min 32.76999999999998s
#
# 361
# Epoch duration =5.25s
# Cumulative duration =31min 38.01999999999998s
#
# 362
# Epoch duration =5.23s
# Cumulative duration =31min 43.24000000000001s
#
# 363
# Epoch duration =5.25s
# Cumulative duration =31min 48.49000000000001s
#
# 364
# Epoch duration =5.23s
# Cumulative duration =31min 53.73000000000002s
#
# 365
# Epoch duration =5.25s
# Cumulative duration =31min 58.98000000000002s
#
# 366
# Epoch duration =5.24s
# Cumulative duration =32min 4.220000000000027s
#
# 367
# Epoch duration =5.25s
# Cumulative duration =32min 9.470000000000027s
#
# 368
# Epoch duration =5.27s
# Cumulative duration =32min 14.730000000000018s
#
# 369
# Epoch duration =5.23s
# Cumulative duration =32min 19.960000000000036s
#
# 370
# Epoch duration =5.24s
# Cumulative duration =32min 25.200000000000045s
#
# 371
# Epoch duration =5.26s
# Cumulative duration =32min 30.470000000000027s
#
# 372
# Epoch duration =5.28s
# Cumulative duration =32min 35.75s
#
# 373
# Epoch duration =5.25s
# Cumulative duration =32min 41.0s
#
# 374
# Epoch duration =5.25s
# Cumulative duration =32min 46.25999999999999s
#
# 375
# Epoch duration =5.23s
# Cumulative duration =32min 51.48000000000002s
#
# 376
# Epoch duration =5.21s
# Cumulative duration =32min 56.690000000000055s
#
# 377
# Epoch duration =5.24s
# Cumulative duration =33min 1.9300000000000637s
#
# 378
# Epoch duration =5.26s
# Cumulative duration =33min 7.190000000000055s
#
# 379
# Epoch duration =5.25s
# Cumulative duration =33min 12.450000000000045s
#
# 380
# Epoch duration =5.2s
# Cumulative duration =33min 17.65000000000009s
#
# 381
# Epoch duration =5.26s
# Cumulative duration =33min 22.910000000000082s
#
# 382
# Epoch duration =5.25s
# Cumulative duration =33min 28.160000000000082s
#
# 383
# Epoch duration =5.24s
# Cumulative duration =33min 33.40000000000009s
#
# 384
# Epoch duration =5.23s
# Cumulative duration =33min 38.63000000000011s
#
# 385
# Epoch duration =5.23s
# Cumulative duration =33min 43.8599999999999s
#
# 386
# Epoch duration =5.23s
# Cumulative duration =33min 49.08999999999992s
#
# 387
# Epoch duration =5.23s
# Cumulative duration =33min 54.319999999999936s
#
# 388
# Epoch duration =5.28s
# Cumulative duration =33min 59.59999999999991s
#
# 389
# Epoch duration =5.22s
# Cumulative duration =34min 4.829999999999927s
#
# 390
# Epoch duration =5.26s
# Cumulative duration =34min 10.090000000000146s
#
# 391
# Epoch duration =5.24s
# Cumulative duration =34min 15.320000000000164s
#
# 392
# Epoch duration =5.21s
# Cumulative duration =34min 20.539999999999964s
#
# 393
# Epoch duration =5.22s
# Cumulative duration =34min 25.76000000000022s
#
# 394
# Epoch duration =5.24s
# Cumulative duration =34min 31.0s
#
# 395
# Epoch duration =5.25s
# Cumulative duration =34min 36.25s
#
# 396
# Epoch duration =5.24s
# Cumulative duration =34min 41.48999999999978s
#
# 397
# Epoch duration =5.23s
# Cumulative duration =34min 46.7199999999998s
#
# 398
# Epoch duration =5.27s
# Cumulative duration =34min 51.98999999999978s
#
# 399
# Epoch duration =5.25s
# Cumulative duration =34min 57.25s
#
# 400
# Epoch duration =5.26s
# Cumulative duration =35min 2.5100000000002183s
#
# 401
# Epoch duration =5.27s
# Cumulative duration =35min 7.7800000000002s
#
# 402
# Epoch duration =5.22s
# Cumulative duration =35min 13.010000000000218s
#
# 403
# Epoch duration =5.24s
# Cumulative duration =35min 18.25s
#
# 404
# Epoch duration =5.24s
# Cumulative duration =35min 23.48999999999978s
#
# 405
# Epoch duration =5.26s
# Cumulative duration =35min 28.75s
#
# 406
# Epoch duration =5.24s
# Cumulative duration =35min 33.98999999999978s
#
# 407
# Epoch duration =5.22s
# Cumulative duration =35min 39.210000000000036s
#
# 408
# Epoch duration =5.26s
# Cumulative duration =35min 44.4699999999998s
#
# 409
# Epoch duration =5.23s
# Cumulative duration =35min 49.69999999999982s
#
# 410
# Epoch duration =5.25s
# Cumulative duration =35min 54.94999999999982s
#
# 411
# Epoch duration =5.23s
# Cumulative duration =36min 0.1799999999998363s
#
# 412
# Epoch duration =5.23s
# Cumulative duration =36min 5.4099999999998545s
#
# 413
# Epoch duration =5.27s
# Cumulative duration =36min 10.679999999999836s
#
# 414
# Epoch duration =5.23s
# Cumulative duration =36min 15.909999999999854s
#
# 415
# Epoch duration =5.22s
# Cumulative duration =36min 21.139999999999873s
#
# 416
# Epoch duration =5.28s
# Cumulative duration =36min 26.420000000000073s
#
# 417
# Epoch duration =5.24s
# Cumulative duration =36min 31.659999999999854s
#
# 418
# Epoch duration =5.25s
# Cumulative duration =36min 36.909999999999854s
#
# 419
# Epoch duration =5.25s
# Cumulative duration =36min 42.159999999999854s
#
# 420
# Epoch duration =5.26s
# Cumulative duration =36min 47.409999999999854s
#
# 421
# Epoch duration =5.24s
# Cumulative duration =36min 52.659999999999854s
#
# 422
# Epoch duration =5.24s
# Cumulative duration =36min 57.90000000000009s
#
# 423
# Epoch duration =5.25s
# Cumulative duration =37min 3.150000000000091s
#
# 424
# Epoch duration =5.25s
# Cumulative duration =37min 8.400000000000091s
#
# 425
# Epoch duration =5.23s
# Cumulative duration =37min 13.63000000000011s
#
# 426
# Epoch duration =5.24s
# Cumulative duration =37min 18.88000000000011s
#
# 427
# Epoch duration =5.24s
# Cumulative duration =37min 24.11999999999989s
#
# 428
# Epoch duration =5.24s
# Cumulative duration =37min 29.360000000000127s
#
# 429
# Epoch duration =5.25s
# Cumulative duration =37min 34.59999999999991s
#
# 430
# Epoch duration =5.24s
# Cumulative duration =37min 39.84999999999991s
#
# 431
# Epoch duration =5.27s
# Cumulative duration =37min 45.11999999999989s
#
# 432
# Epoch duration =5.25s
# Cumulative duration =37min 50.36999999999989s
#
# 433
# Epoch duration =5.23s
# Cumulative duration =37min 55.59999999999991s
#
# 434
# Epoch duration =5.24s
# Cumulative duration =38min 0.8400000000001455s
#
# 435
# Epoch duration =5.23s
# Cumulative duration =38min 6.070000000000164s
#
# 436
# Epoch duration =5.26s
# Cumulative duration =38min 11.329999999999927s
#
# 437
# Epoch duration =5.25s
# Cumulative duration =38min 16.579999999999927s
#
# 438
# Epoch duration =5.24s
# Cumulative duration =38min 21.820000000000164s
#
# 439
# Epoch duration =5.25s
# Cumulative duration =38min 27.070000000000164s
#
# 440
# Epoch duration =5.22s
# Cumulative duration =38min 32.289999999999964s
#
# 441
# Epoch duration =5.23s
# Cumulative duration =38min 37.51999999999998s
#
# 442
# Epoch duration =5.22s
# Cumulative duration =38min 42.73999999999978s
#
# 443
# Epoch duration =5.26s
# Cumulative duration =38min 48.0s
#
# 444
# Epoch duration =5.29s
# Cumulative duration =38min 53.30000000000018s
#
# 445
# Epoch duration =5.24s
# Cumulative duration =38min 58.539999999999964s
#
# 446
# Epoch duration =5.23s
# Cumulative duration =39min 3.7800000000002s
#
# 447
# Epoch duration =5.26s
# Cumulative duration =39min 9.0300000000002s
#
# 448
# Epoch duration =5.31s
# Cumulative duration =39min 14.340000000000146s
#
# 449
# Epoch duration =5.25s
# Cumulative duration =39min 19.590000000000146s
#
# 450
# Epoch duration =5.24s
# Cumulative duration =39min 24.829999999999927s
#
# 451
# Epoch duration =5.26s
# Cumulative duration =39min 30.090000000000146s
#
# 452
# Epoch duration =5.25s
# Cumulative duration =39min 35.340000000000146s
#
# 453
# Epoch duration =5.24s
# Cumulative duration =39min 40.57999999999993s
#
# 454
# Epoch duration =5.23s
# Cumulative duration =39min 45.80000000000018s
#
# 455
# Epoch duration =5.23s
# Cumulative duration =39min 51.0300000000002s
#
# 456
# Epoch duration =5.23s
# Cumulative duration =39min 56.26000000000022s
#
# 457
# Epoch duration =5.24s
# Cumulative duration =40min 1.5s
#
# 458
# Epoch duration =5.25s
# Cumulative duration =40min 6.75s
#
# 459
# Epoch duration =5.25s
# Cumulative duration =40min 12.0s
#
# 460
# Epoch duration =5.23s
# Cumulative duration =40min 17.230000000000018s
#
# 461
# Epoch duration =5.25s
# Cumulative duration =40min 22.480000000000018s
#
# 462
# Epoch duration =5.25s
# Cumulative duration =40min 27.730000000000018s
#
# 463
# Epoch duration =5.26s
# Cumulative duration =40min 32.98999999999978s
#
# 464
# Epoch duration =5.24s
# Cumulative duration =40min 38.23000000000002s
#
# 465
# Epoch duration =5.25s
# Cumulative duration =40min 43.48000000000002s
#
# 466
# Epoch duration =5.22s
# Cumulative duration =40min 48.69999999999982s
#
# 467
# Epoch duration =5.25s
# Cumulative duration =40min 53.94999999999982s
#
# 468
# Epoch duration =5.23s
# Cumulative duration =40min 59.190000000000055s
#
# 469
# Epoch duration =5.24s
# Cumulative duration =41min 4.429999999999836s
#
# 470
# Epoch duration =5.26s
# Cumulative duration =41min 9.690000000000055s
#
# 471
# Epoch duration =5.26s
# Cumulative duration =41min 14.949999999999818s
#
# 472
# Epoch duration =5.25s
# Cumulative duration =41min 20.199999999999818s
#
# 473
# Epoch duration =5.23s
# Cumulative duration =41min 25.429999999999836s
#
# 474
# Epoch duration =5.24s
# Cumulative duration =41min 30.679999999999836s
#
# 475
# Epoch duration =5.24s
# Cumulative duration =41min 35.92000000000007s
#
# 476
# Epoch duration =5.23s
# Cumulative duration =41min 41.15000000000009s
#
# 477
# Epoch duration =5.24s
# Cumulative duration =41min 46.38000000000011s
#
# 478
# Epoch duration =5.24s
# Cumulative duration =41min 51.63000000000011s
#
# 479
# Epoch duration =5.23s
# Cumulative duration =41min 56.86000000000013s
#
# 480
# Epoch duration =5.22s
# Cumulative duration =42min 2.0799999999999272s
#
# 481
# Epoch duration =5.24s
# Cumulative duration =42min 7.320000000000164s
#
# 482
# Epoch duration =5.24s
# Cumulative duration =42min 12.570000000000164s
#
# 483
# Epoch duration =5.23s
# Cumulative duration =42min 17.789999999999964s
#
# 484
# Epoch duration =5.28s
# Cumulative duration =42min 23.070000000000164s
#
# 485
# Epoch duration =5.26s
# Cumulative duration =42min 28.329999999999927s
#
# 486
# Epoch duration =5.23s
# Cumulative duration =42min 33.559999999999945s
#
# 487
# Epoch duration =5.23s
# Cumulative duration =42min 38.789999999999964s
#
# 488
# Epoch duration =5.24s
# Cumulative duration =42min 44.039999999999964s
#
# 489
# Epoch duration =5.22s
# Cumulative duration =42min 49.25s
#
# 490
# Epoch duration =5.24s
# Cumulative duration =42min 54.48999999999978s
#
# 491
# Epoch duration =5.24s
# Cumulative duration =42min 59.73000000000002s
#
# 492
# Epoch duration =5.24s
# Cumulative duration =43min 4.9699999999998s
#
# 493
# Epoch duration =5.28s
# Cumulative duration =43min 10.25s
#
# 494
# Epoch duration =5.23s
# Cumulative duration =43min 15.480000000000018s
#
# 495
# Epoch duration =5.22s
# Cumulative duration =43min 20.710000000000036s
#
# 496
# Epoch duration =5.26s
# Cumulative duration =43min 25.960000000000036s
#
# 497
# Epoch duration =5.23s
# Cumulative duration =43min 31.199999999999818s
#
# 498
# Epoch duration =5.25s
# Cumulative duration =43min 36.44999999999982s
#
# 499
# Epoch duration =5.25s
# Cumulative duration =43min 41.69999999999982s
#
# 500
# Epoch duration =5.24s
# Cumulative duration =43min 46.940000000000055s
#
# 501
# Epoch duration =5.27s
# Cumulative duration =43min 52.210000000000036s
#
# 502
# Epoch duration =5.24s
# Cumulative duration =43min 57.460000000000036s
#
# 503
# Epoch duration =5.24s
# Cumulative duration =44min 2.6900000000000546s
#
# 504
# Epoch duration =5.25s
# Cumulative duration =44min 7.940000000000055s
#
# 505
# Epoch duration =5.26s
# Cumulative duration =44min 13.199999999999818s
#
# 506
# Epoch duration =5.24s
# Cumulative duration =44min 18.440000000000055s
#
# 507
# Epoch duration =5.24s
# Cumulative duration =44min 23.679999999999836s
#
# 508
# Epoch duration =5.22s
# Cumulative duration =44min 28.90000000000009s
#
# 509
# Epoch duration =5.25s
# Cumulative duration =44min 34.15000000000009s
#
# 510
# Epoch duration =5.24s
# Cumulative duration =44min 39.40000000000009s
#
# 511
# Epoch duration =5.23s
# Cumulative duration =44min 44.63000000000011s
#
# 512
# Epoch duration =5.22s
# Cumulative duration =44min 49.84999999999991s
#
# 513
# Epoch duration =5.26s
# Cumulative duration =44min 55.09999999999991s
#
# 514
# Epoch duration =5.24s
# Cumulative duration =45min 0.3400000000001455s
#
# 515
# Epoch duration =5.26s
# Cumulative duration =45min 5.599999999999909s
#
# 516
# Epoch duration =5.27s
# Cumulative duration =45min 10.86999999999989s
#
# 517
# Epoch duration =5.23s
# Cumulative duration =45min 16.09999999999991s
#
# 518
# Epoch duration =5.24s
# Cumulative duration =45min 21.340000000000146s
#
# 519
# Epoch duration =5.23s
# Cumulative duration =45min 26.570000000000164s
#
# 520
# Epoch duration =5.25s
# Cumulative duration =45min 31.820000000000164s
#
# 521
# Epoch duration =5.23s
# Cumulative duration =45min 37.05000000000018s
#
# 522
# Epoch duration =5.25s
# Cumulative duration =45min 42.30000000000018s
#
# 523
# Epoch duration =5.27s
# Cumulative duration =45min 47.570000000000164s
#
# 524
# Epoch duration =5.27s
# Cumulative duration =45min 52.82999999999993s
#
# 525
# Epoch duration =5.24s
# Cumulative duration =45min 58.070000000000164s
#
# 526
# Epoch duration =5.24s
# Cumulative duration =46min 3.3099999999999454s
#
# 527
# Epoch duration =5.25s
# Cumulative duration =46min 8.559999999999945s
#
# 528
# Epoch duration =5.28s
# Cumulative duration =46min 13.849999999999909s
#
# 529
# Epoch duration =5.27s
# Cumulative duration =46min 19.11999999999989s
#
# 530
# Epoch duration =5.24s
# Cumulative duration =46min 24.34999999999991s
#
# 531
# Epoch duration =5.24s
# Cumulative duration =46min 29.59999999999991s
#
# 532
# Epoch duration =5.26s
# Cumulative duration =46min 34.86000000000013s
#
# 533
# Epoch duration =5.25s
# Cumulative duration =46min 40.11000000000013s
#
# 534
# Epoch duration =5.25s
# Cumulative duration =46min 45.36000000000013s
#
# 535
# Epoch duration =5.23s
# Cumulative duration =46min 50.59999999999991s
#
# 536
# Epoch duration =5.23s
# Cumulative duration =46min 55.82999999999993s
#
# 537
# Epoch duration =5.25s
# Cumulative duration =47min 1.0799999999999272s
#
# 538
# Epoch duration =5.24s
# Cumulative duration =47min 6.309999999999945s
#
# 539
# Epoch duration =5.26s
# Cumulative duration =47min 11.570000000000164s
#
# 540
# Epoch duration =5.24s
# Cumulative duration =47min 16.809999999999945s
#
# 541
# Epoch duration =5.23s
# Cumulative duration =47min 22.039999999999964s
#
# 542
# Epoch duration =5.26s
# Cumulative duration =47min 27.300000000000182s
#
# 543
# Epoch duration =5.25s
# Cumulative duration =47min 32.55000000000018s
#
# 544
# Epoch duration =5.24s
# Cumulative duration =47min 37.789999999999964s
#
# 545
# Epoch duration =5.23s
# Cumulative duration =47min 43.01999999999998s
#
# 546
# Epoch duration =5.23s
# Cumulative duration =47min 48.26000000000022s
#
# 547
# Epoch duration =5.24s
# Cumulative duration =47min 53.5s
#
# 548
# Epoch duration =5.22s
# Cumulative duration =47min 58.7199999999998s
#
# 549
# Epoch duration =5.27s
# Cumulative duration =48min 3.9899999999997817s
#
# 550
# Epoch duration =5.24s
# Cumulative duration =48min 9.239999999999782s
#
# 551
# Epoch duration =5.24s
# Cumulative duration =48min 14.480000000000018s
#
# 552
# Epoch duration =5.23s
# Cumulative duration =48min 19.710000000000036s
#
# 553
# Epoch duration =5.24s
# Cumulative duration =48min 24.940000000000055s
#
# 554
# Epoch duration =5.23s
# Cumulative duration =48min 30.170000000000073s
#
# 555
# Epoch duration =5.27s
# Cumulative duration =48min 35.44999999999982s
#
# 556
# Epoch duration =5.25s
# Cumulative duration =48min 40.69999999999982s
#
# 557
# Epoch duration =5.23s
# Cumulative duration =48min 45.929999999999836s
#
# 558
# Epoch duration =5.22s
# Cumulative duration =48min 51.15000000000009s
#
# 559
# Epoch duration =5.23s
# Cumulative duration =48min 56.38000000000011s
#
# 560
# Epoch duration =5.25s
# Cumulative duration =49min 1.6300000000001091s
#
# 561
# Epoch duration =5.28s
# Cumulative duration =49min 6.9099999999998545s
#
# 562
# Epoch duration =5.24s
# Cumulative duration =49min 12.150000000000091s
#
# 563
# Epoch duration =5.26s
# Cumulative duration =49min 17.409999999999854s
#
# 564
# Epoch duration =5.24s
# Cumulative duration =49min 22.65000000000009s
#
# 565
# Epoch duration =5.25s
# Cumulative duration =49min 27.90000000000009s
#
# 566
# Epoch duration =5.24s
# Cumulative duration =49min 33.13999999999987s
#
# 567
# Epoch duration =5.26s
# Cumulative duration =49min 38.40000000000009s
#
# 568
# Epoch duration =5.22s
# Cumulative duration =49min 43.61000000000013s
#
# 569
# Epoch duration =5.23s
# Cumulative duration =49min 48.840000000000146s
#
# 570
# Epoch duration =5.23s
# Cumulative duration =49min 54.070000000000164s
#
# 571
# Epoch duration =5.24s
# Cumulative duration =49min 59.309999999999945s
#
# 572
# Epoch duration =5.23s
# Cumulative duration =50min 4.539999999999964s
#
# 573
# Epoch duration =5.24s
# Cumulative duration =50min 9.7800000000002s
#
# 574
# Epoch duration =5.23s
# Cumulative duration =50min 15.010000000000218s
#
# 575
# Epoch duration =5.26s
# Cumulative duration =50min 20.2800000000002s
#
# 576
# Epoch duration =5.26s
# Cumulative duration =50min 25.539999999999964s
#
# 577
# Epoch duration =5.25s
# Cumulative duration =50min 30.789999999999964s
#
# 578
# Epoch duration =5.27s
# Cumulative duration =50min 36.05000000000018s
#
# 579
# Epoch duration =5.23s
# Cumulative duration =50min 41.2800000000002s
#
# 580
# Epoch duration =5.25s
# Cumulative duration =50min 46.5300000000002s
#
# 581
# Epoch duration =5.25s
# Cumulative duration =50min 51.7800000000002s
#
# 582
# Epoch duration =5.25s
# Cumulative duration =50min 57.0300000000002s
#
# 583
# Epoch duration =5.25s
# Cumulative duration =51min 2.2899999999999636s
#
# 584
# Epoch duration =5.27s
# Cumulative duration =51min 7.550000000000182s
#
# 585
# Epoch duration =5.24s
# Cumulative duration =51min 12.789999999999964s
#
# 586
# Epoch duration =5.23s
# Cumulative duration =51min 18.019999999999982s
#
# 587
# Epoch duration =5.24s
# Cumulative duration =51min 23.26000000000022s
#
# 588
# Epoch duration =5.21s
# Cumulative duration =51min 28.4699999999998s
#
# 589
# Epoch duration =5.28s
# Cumulative duration =51min 33.75s
#
# 590
# Epoch duration =5.23s
# Cumulative duration =51min 38.98000000000002s
#
# 591
# Epoch duration =5.22s
# Cumulative duration =51min 44.210000000000036s
#
# 592
# Epoch duration =5.24s
# Cumulative duration =51min 49.440000000000055s
#
# 593
# Epoch duration =5.23s
# Cumulative duration =51min 54.67000000000007s
#
# 594
# Epoch duration =5.24s
# Cumulative duration =51min 59.909999999999854s
#
# 595
# Epoch duration =5.21s
# Cumulative duration =52min 5.119999999999891s
#
# 596
# Epoch duration =5.23s
# Cumulative duration =52min 10.360000000000127s
#
# 597
# Epoch duration =5.26s
# Cumulative duration =52min 15.610000000000127s
#
# 598
# Epoch duration =5.24s
# Cumulative duration =52min 20.84999999999991s
#
# 599
# Epoch duration =5.23s
# Cumulative duration =52min 26.079999999999927s
#
# 600
# Epoch duration =5.25s
# Cumulative duration =52min 31.329999999999927s
#
# 601
# Epoch duration =5.23s
# Cumulative duration =52min 36.559999999999945s
#
# 602
# Epoch duration =5.26s
# Cumulative duration =52min 41.820000000000164s
#
# 603
# Epoch duration =5.24s
# Cumulative duration =52min 47.059999999999945s
#
# 604
# Epoch duration =5.23s
# Cumulative duration =52min 52.289999999999964s
#
# 605
# Epoch duration =5.22s
# Cumulative duration =52min 57.51000000000022s
#
# 606
# Epoch duration =5.24s
# Cumulative duration =53min 2.75s
#
# 607
# Epoch duration =5.26s
# Cumulative duration =53min 8.019999999999982s
#
# 608
# Epoch duration =5.28s
# Cumulative duration =53min 13.300000000000182s
#
# 609
# Epoch duration =5.23s
# Cumulative duration =53min 18.5300000000002s
#
# 610
# Epoch duration =5.22s
# Cumulative duration =53min 23.76000000000022s
#
# 611
# Epoch duration =5.21s
# Cumulative duration =53min 28.9699999999998s
#
# 612
# Epoch duration =5.23s
# Cumulative duration =53min 34.19999999999982s
#
# 613
# Epoch duration =5.23s
# Cumulative duration =53min 39.429999999999836s
#
# 614
# Epoch duration =5.23s
# Cumulative duration =53min 44.659999999999854s
#
# 615
# Epoch duration =5.23s
# Cumulative duration =53min 49.88999999999987s
#
# 616
# Epoch duration =7.43s
# Cumulative duration =53min 57.320000000000164s
#
# 617
# Epoch duration =9.11s
# Cumulative duration =54min 6.440000000000055s
#
# 618
# Epoch duration =5.45s
# Cumulative duration =54min 11.889999999999873s
#
# 619
# Epoch duration =5.5s
# Cumulative duration =54min 17.389999999999873s
#
# 620
# Epoch duration =5.48s
# Cumulative duration =54min 22.86999999999989s
#
# 621
# Epoch duration =5.47s
# Cumulative duration =54min 28.329999999999927s
#
# 622
# Epoch duration =5.45s
# Cumulative duration =54min 33.789999999999964s
#
# 623
# Epoch duration =5.48s
# Cumulative duration =54min 39.26000000000022s
#
# 624
# Epoch duration =5.47s
# Cumulative duration =54min 44.73000000000002s
#
# 625
# Epoch duration =5.46s
# Cumulative duration =54min 50.190000000000055s
#
# 626
# Epoch duration =5.49s
# Cumulative duration =54min 55.679999999999836s
#
# 627
# Epoch duration =5.48s
# Cumulative duration =55min 1.150000000000091s
#
# 628
# Epoch duration =5.45s
# Cumulative duration =55min 6.599999999999909s
#
# 629
# Epoch duration =5.56s
# Cumulative duration =55min 12.170000000000073s
#
# 630
# Epoch duration =5.45s
# Cumulative duration =55min 17.610000000000127s
#
# 631
# Epoch duration =5.47s
# Cumulative duration =55min 23.090000000000146s
#
# 632
# Epoch duration =5.52s
# Cumulative duration =55min 28.59999999999991s
#
# 633
# Epoch duration =5.44s
# Cumulative duration =55min 34.039999999999964s
#
# 634
# Epoch duration =5.5s
# Cumulative duration =55min 39.539999999999964s
#
# 635
# Epoch duration =5.47s
# Cumulative duration =55min 45.01000000000022s
#
# 636
# Epoch duration =5.45s
# Cumulative duration =55min 50.460000000000036s
#
# 637
# Epoch duration =5.45s
# Cumulative duration =55min 55.92000000000007s
#
# 638
# Epoch duration =5.49s
# Cumulative duration =56min 1.4099999999998545s
#
# 639
# Epoch duration =5.43s
# Cumulative duration =56min 6.8400000000001455s
#
# 640
# Epoch duration =5.47s
# Cumulative duration =56min 12.309999999999945s
#
# 641
# Epoch duration =5.49s
# Cumulative duration =56min 17.800000000000182s
#
# 642
# Epoch duration =5.44s
# Cumulative duration =56min 23.23999999999978s
#
# 643
# Epoch duration =5.47s
# Cumulative duration =56min 28.710000000000036s
#
# 644
# Epoch duration =5.47s
# Cumulative duration =56min 34.179999999999836s
#
# 645
# Epoch duration =5.49s
# Cumulative duration =56min 39.67000000000007s
#
# 646
# Epoch duration =5.45s
# Cumulative duration =56min 45.11999999999989s
#
# 647
# Epoch duration =5.49s
# Cumulative duration =56min 50.61000000000013s
#
# 648
# Epoch duration =5.48s
# Cumulative duration =56min 56.090000000000146s
#
# 649
# Epoch duration =5.49s
# Cumulative duration =57min 1.5799999999999272s
#
# 650
# Epoch duration =5.59s
# Cumulative duration =57min 7.170000000000073s
#
# 651
# Epoch duration =5.53s
# Cumulative duration =57min 12.699999999999818s
#
# 652
# Epoch duration =5.46s
# Cumulative duration =57min 18.159999999999854s
#
# 653
# Epoch duration =5.45s
# Cumulative duration =57min 23.610000000000127s
#
# 654
# Epoch duration =5.51s
# Cumulative duration =57min 29.11999999999989s
#
# 655
# Epoch duration =5.49s
# Cumulative duration =57min 34.61000000000013s
#
# 656
# Epoch duration =5.49s
# Cumulative duration =57min 40.09999999999991s
#
# 657
# Epoch duration =5.46s
# Cumulative duration =57min 45.559999999999945s
#
# 658
# Epoch duration =5.46s
# Cumulative duration =57min 51.01999999999998s
#
# 659
# Epoch duration =5.48s
# Cumulative duration =57min 56.5s
#
# 660
# Epoch duration =5.45s
# Cumulative duration =58min 1.949999999999818s
#
# 661
# Epoch duration =5.46s
# Cumulative duration =58min 7.4099999999998545s
#
# 662
# Epoch duration =5.46s
# Cumulative duration =58min 12.86999999999989s
#
# 663
# Epoch duration =5.44s
# Cumulative duration =58min 18.309999999999945s
#
# 664
# Epoch duration =5.46s
# Cumulative duration =58min 23.769999999999982s
#
# 665
# Epoch duration =5.45s
# Cumulative duration =58min 29.230000000000018s
#
# 666
# Epoch duration =5.44s
# ...
# Cumulative duration =1hr 10min 4.489999999999782s
#
# 793
# Epoch duration =5.48s
# Cumulative duration =1hr 10min 9.979999999999563s
#
# 794
# Epoch duration =5.51s
# Cumulative duration =1hr 10min 15.489999999999782s
#
# 795
# Epoch duration =5.46s
# Cumulative duration =1hr 10min 20.9399999999996s
#
# 796
# Epoch duration =5.45s
# Cumulative duration =1hr 10min 26.399999999999636s
#
# 797
# Epoch duration =5.41s
# Cumulative duration =1hr 10min 31.8100000000004s
#
# 798
# Epoch duration =5.48s
# Cumulative duration =1hr 10min 37.289999999999964s
#
# 799
# Epoch duration =5.45s
# Cumulative duration =1hr 10min 42.73999999999978s
#
# 800
# Epoch duration =5.47s
# Cumulative duration =1hr 10min 48.210000000000036s
#
# 801
# Epoch duration =5.44s
# Cumulative duration =1hr 10min 53.649999999999636s
#
# 802
# Epoch duration =5.49s
# Cumulative duration =1hr 10min 59.14000000000033s
#
# 803
# Epoch duration =5.49s
# Cumulative duration =1hr 11min 4.630000000000109s
#
# 804
# Epoch duration =5.69s
# Cumulative duration =1hr 11min 10.319999999999709s
#
# 805
# Epoch duration =5.47s
# Cumulative duration =1hr 11min 15.779999999999745s
#
# 806
# Epoch duration =5.5s
# Cumulative duration =1hr 11min 21.289999999999964s
#
# 807
# Epoch duration =5.45s
# Cumulative duration =1hr 11min 26.73999999999978s
#
# 808
# Epoch duration =5.48s
# Cumulative duration =1hr 11min 32.22999999999956s
#
# 809
# Epoch duration =5.46s
# Cumulative duration =1hr 11min 37.68000000000029s
#
# 810
# Epoch duration =5.45s
# Cumulative duration =1hr 11min 43.13000000000011s
#
# 811
# Epoch duration =5.49s
# Cumulative duration =1hr 11min 48.61999999999989s
#
# 812
# Epoch duration =5.45s
# Cumulative duration =1hr 11min 54.06999999999971s
#
# 813
# Epoch duration =5.42s
# Cumulative duration =1hr 11min 59.48999999999978s
#
# 814
# Epoch duration =5.44s
# Cumulative duration =1hr 12min 4.9399999999996s
#
# 815
# Epoch duration =5.44s
# Cumulative duration =1hr 12min 10.36999999999989s
#
# 816
# Epoch duration =5.46s
# Cumulative duration =1hr 12min 15.840000000000146s
#
# 817
# Epoch duration =5.47s
# Cumulative duration =1hr 12min 21.300000000000182s
#
# 818
# Epoch duration =5.46s
# Cumulative duration =1hr 12min 26.770000000000437s
#
# 819
# Epoch duration =5.44s
# Cumulative duration =1hr 12min 32.210000000000036s
#
# 820
# Epoch duration =5.46s
# Cumulative duration =1hr 12min 37.67000000000007s
#
# 821
# Epoch duration =5.47s
# Cumulative duration =1hr 12min 43.14000000000033s
#
# 822
# Epoch duration =5.49s
# Cumulative duration =1hr 12min 48.63000000000011s
#
# 823
# Epoch duration =5.42s
# Cumulative duration =1hr 12min 54.05000000000018s
#
# 824
# Epoch duration =5.46s
# Cumulative duration =1hr 12min 59.51000000000022s
#
# 825
# Epoch duration =5.44s
# Cumulative duration =1hr 13min 4.949999999999818s
#
# 826
# Epoch duration =5.65s
# Cumulative duration =1hr 13min 10.600000000000364s
#
# 827
# Epoch duration =5.46s
# Cumulative duration =1hr 13min 16.0600000000004s
#
# 828
# Epoch duration =5.54s
# Cumulative duration =1hr 13min 21.600000000000364s
#
# 829
# Epoch duration =5.45s
# Cumulative duration =1hr 13min 27.050000000000182s
#
# 830
# Epoch duration =5.46s
# Cumulative duration =1hr 13min 32.51000000000022s
#
# 831
# Epoch duration =5.45s
# Cumulative duration =1hr 13min 37.960000000000036s
#
# 832
# Epoch duration =5.45s
# Cumulative duration =1hr 13min 43.42000000000007s
#
# 833
# Epoch duration =5.48s
# Cumulative duration =1hr 13min 48.89000000000033s
#
# 834
# Epoch duration =5.46s
# Cumulative duration =1hr 13min 54.35999999999967s
#
# 835
# Epoch duration =5.5s
# Cumulative duration =1hr 13min 59.850000000000364s
#
# 836
# Epoch duration =5.44s
# Cumulative duration =1hr 14min 5.300000000000182s
#
# 837
# Epoch duration =5.49s
# Cumulative duration =1hr 14min 10.789999999999964s
#
# 838
# Epoch duration =5.46s
# Cumulative duration =1hr 14min 16.23999999999978s
#
# 839
# Epoch duration =5.47s
# Cumulative duration =1hr 14min 21.720000000000255s
#
# 840
# Epoch duration =5.47s
# Cumulative duration =1hr 14min 27.18000000000029s
#
# 841
# Epoch duration =5.46s
# Cumulative duration =1hr 14min 32.64000000000033s
#
# 842
# Epoch duration =5.46s
# Cumulative duration =1hr 14min 38.100000000000364s
#
# 843
# Epoch duration =5.47s
# Cumulative duration =1hr 14min 43.56999999999971s
#
# 844
# Epoch duration =5.51s
# Cumulative duration =1hr 14min 49.07999999999993s
#
# 845
# Epoch duration =5.47s
# Cumulative duration =1hr 14min 54.55000000000018s
#
# 846
# Epoch duration =5.49s
# Cumulative duration =1hr 15min 0.03999999999996362s
#
# 847
# Epoch duration =5.5s
# Cumulative duration =1hr 15min 5.539999999999964s
#
# 848
# Epoch duration =5.69s
# Cumulative duration =1hr 15min 11.220000000000255s
#
# 849
# Epoch duration =5.44s
# Cumulative duration =1hr 15min 16.659999999999854s
#
# 850
# Epoch duration =5.46s
# Cumulative duration =1hr 15min 22.13000000000011s
#
# 851
# Epoch duration =5.49s
# Cumulative duration =1hr 15min 27.61999999999989s
#
# 852
# Epoch duration =5.46s
# Cumulative duration =1hr 15min 33.07999999999993s
#
# 853
# Epoch duration =5.5s
# Cumulative duration =1hr 15min 38.56999999999971s
#
# 854
# Epoch duration =5.48s
# Cumulative duration =1hr 15min 44.05000000000018s
#
# 855
# Epoch duration =5.45s
# Cumulative duration =1hr 15min 49.5s
#
# 856
# Epoch duration =5.49s
# Cumulative duration =1hr 15min 55.0s
#
# 857
# Epoch duration =5.42s
# Cumulative duration =1hr 16min 0.42000000000007276s
#
# 858
# Epoch duration =5.46s
# Cumulative duration =1hr 16min 5.890000000000327s
#
# 859
# Epoch duration =5.45s
# Cumulative duration =1hr 16min 11.340000000000146s
#
# 860
# Epoch duration =5.45s
# Cumulative duration =1hr 16min 16.789999999999964s
#
# 861
# Epoch duration =5.47s
# Cumulative duration =1hr 16min 22.26000000000022s
#
# 862
# Epoch duration =5.46s
# Cumulative duration =1hr 16min 27.729999999999563s
#
# 863
# Epoch duration =5.47s
# Cumulative duration =1hr 16min 33.19999999999982s
#
# 864
# Epoch duration =5.51s
# Cumulative duration =1hr 16min 38.69999999999982s
#
# 865
# Epoch duration =5.45s
# Cumulative duration =1hr 16min 44.149999999999636s
#
# 866
# Epoch duration =5.47s
# Cumulative duration =1hr 16min 49.63000000000011s
#
# 867
# Epoch duration =5.43s
# Cumulative duration =1hr 16min 55.0600000000004s
#
# 868
# Epoch duration =5.46s
# Cumulative duration =1hr 17min 0.5299999999997453s
#
# 869
# Epoch duration =5.45s
# Cumulative duration =1hr 17min 5.970000000000255s
#
# 870
# Epoch duration =5.55s
# Cumulative duration =1hr 17min 11.520000000000437s
#
# 871
# Epoch duration =5.46s
# Cumulative duration =1hr 17min 16.979999999999563s
#
# 872
# Epoch duration =5.44s
# Cumulative duration =1hr 17min 22.420000000000073s
#
# 873
# Epoch duration =5.44s
# Cumulative duration =1hr 17min 27.86999999999989s
#
# 874
# Epoch duration =5.44s
# Cumulative duration =1hr 17min 33.3100000000004s
#
# 875
# Epoch duration =5.5s
# Cumulative duration =1hr 17min 38.8100000000004s
#
# 876
# Epoch duration =5.47s
# Cumulative duration =1hr 17min 44.279999999999745s
#
# 877
# Epoch duration =5.49s
# Cumulative duration =1hr 17min 49.76000000000022s
#
# 878
# Epoch duration =5.47s
# Cumulative duration =1hr 17min 55.22999999999956s
#
# 879
# Epoch duration =5.45s
# Cumulative duration =1hr 18min 0.680000000000291s
#
# 880
# Epoch duration =5.48s
# Cumulative duration =1hr 18min 6.1599999999998545s
#
# 881
# Epoch duration =5.45s
# Cumulative duration =1hr 18min 11.609999999999673s
#
# 882
# Epoch duration =5.5s
# Cumulative duration =1hr 18min 17.109999999999673s
#
# 883
# Epoch duration =5.45s
# Cumulative duration =1hr 18min 22.56999999999971s
#
# 884
# Epoch duration =5.46s
# Cumulative duration =1hr 18min 28.020000000000437s
#
# 885
# Epoch duration =5.45s
# Cumulative duration =1hr 18min 33.470000000000255s
#
# 886
# Epoch duration =5.5s
# Cumulative duration =1hr 18min 38.970000000000255s
#
# 887
# Epoch duration =5.51s
# Cumulative duration =1hr 18min 44.47999999999956s
#
# 888
# Epoch duration =5.49s
# Cumulative duration =1hr 18min 49.970000000000255s
#
# 889
# Epoch duration =5.47s
# Cumulative duration =1hr 18min 55.4399999999996s
#
# 890
# Epoch duration =5.51s
# Cumulative duration =1hr 19min 0.9499999999998181s
#
# 891
# Epoch duration =5.45s
# Cumulative duration =1hr 19min 6.399999999999636s
#
# 892
# Epoch duration =5.53s
# Cumulative duration =1hr 19min 11.920000000000073s
#
# 893
# Epoch duration =5.46s
# Cumulative duration =1hr 19min 17.38000000000011s
#
# 894
# Epoch duration =5.44s
# Cumulative duration =1hr 19min 22.81999999999971s
#
# 895
# Epoch duration =5.46s
# Cumulative duration =1hr 19min 28.279999999999745s
#
# 896
# Epoch duration =5.45s
# Cumulative duration =1hr 19min 33.72999999999956s
#
# 897
# Epoch duration =5.48s
# Cumulative duration =1hr 19min 39.210000000000036s
#
# 898
# Epoch duration =5.52s
# Cumulative duration =1hr 19min 44.72999999999956s
#
# 899
# Epoch duration =5.49s
# Cumulative duration =1hr 19min 50.220000000000255s
#
# 900
# Epoch duration =5.48s
# Cumulative duration =1hr 19min 55.710000000000036s
#
# 901
# Epoch duration =5.43s
# Cumulative duration =1hr 20min 1.1400000000003274s
#
# 902
# Epoch duration =5.45s
# Cumulative duration =1hr 20min 6.5900000000001455s
#
# 903
# Epoch duration =5.51s
# Cumulative duration =1hr 20min 12.100000000000364s
#
# 904
# Epoch duration =5.46s
# Cumulative duration =1hr 20min 17.5600000000004s
#
# 905
# Epoch duration =5.45s
# Cumulative duration =1hr 20min 23.01000000000022s
#
# 906
# Epoch duration =5.49s
# Cumulative duration =1hr 20min 28.51000000000022s
#
# 907
# Epoch duration =5.45s
# Cumulative duration =1hr 20min 33.94999999999982s
#
# 908
# Epoch duration =5.51s
# Cumulative duration =1hr 20min 39.460000000000036s
#
# 909
# Epoch duration =5.43s
# Cumulative duration =1hr 20min 44.89000000000033s
#
# 910
# Epoch duration =5.46s
# Cumulative duration =1hr 20min 50.35999999999967s
#
# 911
# Epoch duration =5.43s
# Cumulative duration =1hr 20min 55.789999999999964s
#
# 912
# Epoch duration =5.47s
# Cumulative duration =1hr 21min 1.2700000000004366s
#
# 913
# Epoch duration =5.61s
# Cumulative duration =1hr 21min 6.880000000000109s
#
# 914
# Epoch duration =5.53s
# Cumulative duration =1hr 21min 12.409999999999854s
#
# 915
# Epoch duration =5.47s
# Cumulative duration =1hr 21min 17.88000000000011s
#
# 916
# Epoch duration =5.46s
# Cumulative duration =1hr 21min 23.340000000000146s
#
# 917
# Epoch duration =5.46s
# Cumulative duration =1hr 21min 28.800000000000182s
#
# 918
# Epoch duration =5.46s
# Cumulative duration =1hr 21min 34.26000000000022s
#
# 919
# Epoch duration =5.49s
# Cumulative duration =1hr 21min 39.75s
#
# 920
# Epoch duration =5.45s
# Cumulative duration =1hr 21min 45.19999999999982s
#
# 921
# Epoch duration =5.42s
# Cumulative duration =1hr 21min 50.61999999999989s
#
# 922
# Epoch duration =5.5s
# Cumulative duration =1hr 21min 56.11999999999989s
#
# 923
# Epoch duration =5.45s
# Cumulative duration =1hr 22min 1.569999999999709s
#
# 924
# Epoch duration =5.46s
# Cumulative duration =1hr 22min 7.029999999999745s
#
# 925
# Epoch duration =5.47s
# Cumulative duration =1hr 22min 12.510000000000218s
#
# 926
# Epoch duration =5.48s
# Cumulative duration =1hr 22min 17.98999999999978s
#
# 927
# Epoch duration =5.48s
# Cumulative duration =1hr 22min 23.470000000000255s
#
# 928
# Epoch duration =5.48s
# Cumulative duration =1hr 22min 28.949999999999818s
#
# 929
# Epoch duration =5.48s
# Cumulative duration =1hr 22min 34.43000000000029s
#
# 930
# Epoch duration =5.46s
# Cumulative duration =1hr 22min 39.89000000000033s
#
# 931
# Epoch duration =5.47s
# Cumulative duration =1hr 22min 45.35999999999967s
#
# 932
# Epoch duration =5.46s
# Cumulative duration =1hr 22min 50.82999999999993s
#
# 933
# Epoch duration =5.42s
# Cumulative duration =1hr 22min 56.25s
#
# 934
# Epoch duration =5.47s
# Cumulative duration =1hr 23min 1.7200000000002547s
#
# 935
# Epoch duration =5.63s
# Cumulative duration =1hr 23min 7.359999999999673s
#
# 936
# Epoch duration =5.53s
# Cumulative duration =1hr 23min 12.890000000000327s
#
# 937
# Epoch duration =5.46s
# Cumulative duration =1hr 23min 18.350000000000364s
#
# 938
# Epoch duration =5.43s
# Cumulative duration =1hr 23min 23.779999999999745s
#
# 939
# Epoch duration =5.47s
# Cumulative duration =1hr 23min 29.25s
#
# 940
# Epoch duration =5.44s
# Cumulative duration =1hr 23min 34.6899999999996s
#
# 941
# Epoch duration =5.5s
# Cumulative duration =1hr 23min 40.1899999999996s
#
# 942
# Epoch duration =5.48s
# Cumulative duration =1hr 23min 45.67000000000007s
#
# 943
# Epoch duration =5.47s
# Cumulative duration =1hr 23min 51.149999999999636s
#
# 944
# Epoch duration =5.47s
# Cumulative duration =1hr 23min 56.61999999999989s
#
# 945
# Epoch duration =5.47s
# Cumulative duration =1hr 24min 2.0900000000001455s
#
# 946
# Epoch duration =5.5s
# Cumulative duration =1hr 24min 7.5900000000001455s
#
# 947
# Epoch duration =5.48s
# Cumulative duration =1hr 24min 13.069999999999709s
#
# 948
# Epoch duration =5.46s
# Cumulative duration =1hr 24min 18.529999999999745s
#
# 949
# Epoch duration =5.51s
# Cumulative duration =1hr 24min 24.039999999999964s
#
# 950
# Epoch duration =5.51s
# Cumulative duration =1hr 24min 29.550000000000182s
#
# 951
# Epoch duration =5.5s
# Cumulative duration =1hr 24min 35.05000000000018s
#
# 952
# Epoch duration =5.48s
# Cumulative duration =1hr 24min 40.529999999999745s
#
# 953
# Epoch duration =5.43s
# Cumulative duration =1hr 24min 45.960000000000036s
#
# 954
# Epoch duration =5.47s
# Cumulative duration =1hr 24min 51.4399999999996s
#
# 955
# Epoch duration =5.5s
# Cumulative duration =1hr 24min 56.9399999999996s
#
# 956
# Epoch duration =5.46s
# Cumulative duration =1hr 25min 2.399999999999636s
#
# 957
# Epoch duration =5.6s
# Cumulative duration =1hr 25min 8.0s
#
# 958
# Epoch duration =5.45s
# Cumulative duration =1hr 25min 13.449999999999818s
#
# 959
# Epoch duration =5.47s
# Cumulative duration =1hr 25min 18.909999999999854s
#
# 960
# Epoch duration =5.44s
# Cumulative duration =1hr 25min 24.359999999999673s
#
# 961
# Epoch duration =5.45s
# Cumulative duration =1hr 25min 29.8100000000004s
#
# 962
# Epoch duration =5.47s
# Cumulative duration =1hr 25min 35.279999999999745s
#
# 963
# Epoch duration =5.47s
# Cumulative duration =1hr 25min 40.75s
#
# 964
# Epoch duration =5.46s
# Cumulative duration =1hr 25min 46.210000000000036s
#
# 965
# Epoch duration =5.45s
# Cumulative duration =1hr 25min 51.67000000000007s
#
# 966
# Epoch duration =5.49s
# Cumulative duration =1hr 25min 57.149999999999636s
#
# 967
# Epoch duration =5.44s
# Cumulative duration =1hr 26min 2.5900000000001455s
#
# 968
# Epoch duration =5.47s
# Cumulative duration =1hr 26min 8.069999999999709s
#
# 969
# Epoch duration =5.48s
# Cumulative duration =1hr 26min 13.550000000000182s
#
# 970
# Epoch duration =5.45s
# Cumulative duration =1hr 26min 19.0s
#
# 971
# Epoch duration =5.5s
# Cumulative duration =1hr 26min 24.5s
#
# 972
# Epoch duration =5.45s
# Cumulative duration =1hr 26min 29.949999999999818s
#
# 973
# Epoch duration =5.44s
# Cumulative duration =1hr 26min 35.39000000000033s
#
# 974
# Epoch duration =5.51s
# Cumulative duration =1hr 26min 40.909999999999854s
#
# 975
# Epoch duration =5.48s
# Cumulative duration =1hr 26min 46.38000000000011s
#
# 976
# Epoch duration =5.48s
# Cumulative duration =1hr 26min 51.86999999999989s
#
# 977
# Epoch duration =5.44s
# Cumulative duration =1hr 26min 57.3100000000004s
#
# 978
# Epoch duration =5.42s
# Cumulative duration =1hr 27min 2.7299999999995634s
#
# 979
# Epoch duration =5.59s
# Cumulative duration =1hr 27min 8.319999999999709s
#
# 980
# Epoch duration =5.45s
# Cumulative duration =1hr 27min 13.770000000000437s
#
# 981
# Epoch duration =5.47s
# Cumulative duration =1hr 27min 19.23999999999978s
#
# 982
# Epoch duration =5.52s
# Cumulative duration =1hr 27min 24.76000000000022s
#
# 983
# Epoch duration =5.44s
# Cumulative duration =1hr 27min 30.199999999999818s
#
# 984
# Epoch duration =5.5s
# Cumulative duration =1hr 27min 35.69999999999982s
#
# 985
# Epoch duration =5.48s
# Cumulative duration =1hr 27min 41.1899999999996s
#
# 986
# Epoch duration =5.48s
# Cumulative duration =1hr 27min 46.67000000000007s
#
# 987
# Epoch duration =5.46s
# Cumulative duration =1hr 27min 52.13000000000011s
#
# 988
# Epoch duration =5.47s
# Cumulative duration =1hr 27min 57.600000000000364s
#
# 989
# Epoch duration =5.45s
# Cumulative duration =1hr 28min 3.050000000000182s
#
# 990
# Epoch duration =5.51s
# Cumulative duration =1hr 28min 8.550000000000182s
#
# 991
# Epoch duration =5.44s
# Cumulative duration =1hr 28min 13.989999999999782s
#
# 992
# Epoch duration =5.45s
# Cumulative duration =1hr 28min 19.4399999999996s
#
# 993
# Epoch duration =5.48s
# Cumulative duration =1hr 28min 24.920000000000073s
#
# 994
# Epoch duration =5.44s
# Cumulative duration =1hr 28min 30.359999999999673s
#
# 995
# Epoch duration =5.49s
# Cumulative duration =1hr 28min 35.85999999999967s
#
# 996
# Epoch duration =5.51s
# Cumulative duration =1hr 28min 41.35999999999967s
#
# 997
# Epoch duration =5.48s
# Cumulative duration =1hr 28min 46.840000000000146s
#
# 998
# Epoch duration =5.48s
# Cumulative duration =1hr 28min 52.32999999999993s
#
# 999
# Epoch duration =5.46s
# Cumulative duration =1hr 28min 57.789999999999964s
#
# Saving scores to Arrays/riboswitch_resbindt5_ug_so1k.npy

# %%
#load values
savepath = 'Arrays/riboswitch_resbindt5_ug_so1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

def normalize_mut_hol(hol_mut, WTmean, nntrainer, sess, normfactor=None):
    norm_hol_mut = np.copy(hol_mut) - WTmean
    for one in range(hol_mut.shape[0]):
        for two in range(hol_mut.shape[0]):
            norm_hol_mut[one, two] = mf.normalize_hol(hol_mut[one, two], factor=normfactor)
    return norm_hol_mut

norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
