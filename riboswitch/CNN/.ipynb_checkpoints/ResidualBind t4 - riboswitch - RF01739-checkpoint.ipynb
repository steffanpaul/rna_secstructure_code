# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/riboswitch_100k_d4.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 9.72s

# %%
simalign_file = '../../../data_RFAM/riboswitch_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

#Get the bpug information
bpugSQ, bpugidx = mf.bpug(ugidx, bpidx, SQ)

bpSS
# Out:
# '(((((<<<<<<>>>>>><<<<<<<<<>>>>>>>>>)))))<<<<>>>>'

# %%
ugSS
# Out:
# ':::::(((((,,,,<-<<<<<____>>>>>><<<--<<<<<<______>>>->>>->>>,,,,,)))))-<<<<____>>>>::::::::::::::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/riboswitch'
param_path = os.path.join(save_path, 'resbind_t4')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 816, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=13.87s -- loss=0.34444 -- acc=82.15750%
#
#   valid loss:		0.06965
#   valid accuracy:	0.97780+/-0.00000
#   valid auc-roc:	0.99738+/-0.00000
#   valid auc-pr:		0.99712+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t4_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=13.42s -- loss=0.07601 -- acc=97.53584%
#
#   valid loss:		0.03253
#   valid accuracy:	0.99235+/-0.00000
#   valid auc-roc:	0.99942+/-0.00000
#   valid auc-pr:		0.99909+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t4_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=13.36s -- loss=0.04812 -- acc=98.64500%
#
#   valid loss:		0.02627
#   valid accuracy:	0.99445+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99984+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t4_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=13.43s -- loss=0.04081 -- acc=98.99833%
#
#   valid loss:		0.03028
#   valid accuracy:	0.99380+/-0.00000
#   valid auc-roc:	0.99988+/-0.00000
#   valid auc-pr:		0.99988+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=13.34s -- loss=0.03781 -- acc=99.16917%
#
#   valid loss:		0.02866
#   valid accuracy:	0.99470+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=13.34s -- loss=0.03634 -- acc=99.28083%
#
#   valid loss:		0.02689
#   valid accuracy:	0.99615+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=13.33s -- loss=0.03543 -- acc=99.35333%
#
#   valid loss:		0.02881
#   valid accuracy:	0.99620+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=13.36s -- loss=0.03482 -- acc=99.40750%
#
#   valid loss:		0.03122
#   valid accuracy:	0.99500+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=13.32s -- loss=0.03528 -- acc=99.44417%
#
#   valid loss:		0.03017
#   valid accuracy:	0.99610+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=13.27s -- loss=0.03443 -- acc=99.50250%
#
#   valid loss:		0.03106
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=13.34s -- loss=0.03443 -- acc=99.52083%
#
#   valid loss:		0.02867
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=13.30s -- loss=0.03403 -- acc=99.56500%
#
#   valid loss:		0.02976
#   valid accuracy:	0.99700+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=13.32s -- loss=0.03516 -- acc=99.53833%
#
#   valid loss:		0.02968
#   valid accuracy:	0.99730+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=13.29s -- loss=0.03375 -- acc=99.60167%
#
#   valid loss:		0.03249
#   valid accuracy:	0.99650+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=13.31s -- loss=0.03379 -- acc=99.60417%
#
#   valid loss:		0.03153
#   valid accuracy:	0.99695+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=13.35s -- loss=0.03544 -- acc=99.56750%
#
#   valid loss:		0.03246
#   valid accuracy:	0.99690+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=13.39s -- loss=0.03424 -- acc=99.64000%
#
#   valid loss:		0.03275
#   valid accuracy:	0.99705+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=13.39s -- loss=0.03305 -- acc=99.65667%
#
#   valid loss:		0.03021
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=13.46s -- loss=0.03458 -- acc=99.60000%
#
#   valid loss:		0.03227
#   valid accuracy:	0.99695+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=13.43s -- loss=0.03260 -- acc=99.69167%
#
#   valid loss:		0.03330
#   valid accuracy:	0.99630+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=13.46s -- loss=0.03287 -- acc=99.66667%
#
#   valid loss:		0.03587
#   valid accuracy:	0.99580+/-0.00000
#   valid auc-roc:	0.99987+/-0.00000
#   valid auc-pr:		0.99985+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=13.50s -- loss=0.03355 -- acc=99.65417%
#
#   valid loss:		0.03186
#   valid accuracy:	0.99730+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.03365 -- acc=99.66083%
#
#   valid loss:		0.03992
#   valid accuracy:	0.99470+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.03271 -- acc=99.68750%
#
#   valid loss:		0.03339
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99990+/-0.00000
#   valid auc-pr:		0.99989+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=13.61s -- loss=0.03313 -- acc=99.69000%
#
#   valid loss:		0.03265
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=13.55s -- loss=0.03265 -- acc=99.68500%
#
#   valid loss:		0.03370
#   valid accuracy:	0.99645+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=13.44s -- loss=0.03300 -- acc=99.70250%
#
#   valid loss:		0.03251
#   valid accuracy:	0.99700+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=13.45s -- loss=0.03281 -- acc=99.69917%
#
#   valid loss:		0.03233
#   valid accuracy:	0.99670+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=13.44s -- loss=0.03230 -- acc=99.69833%
#
#   valid loss:		0.03106
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=13.48s -- loss=0.03279 -- acc=99.69917%
#
#   valid loss:		0.03313
#   valid accuracy:	0.99645+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=13.50s -- loss=0.03160 -- acc=99.72000%
#
#   valid loss:		0.03183
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=13.48s -- loss=0.03163 -- acc=99.71167%
#
#   valid loss:		0.03224
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=13.52s -- loss=0.03186 -- acc=99.71833%
#
#   valid loss:		0.03237
#   valid accuracy:	0.99755+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/riboswitch/resbind_t4_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/riboswitch/resbind_t4_best.ckpt
#   test  loss:		0.02209
#   test  accuracy:	0.99618+/-0.00000
#   test  auc-roc:	0.99992+/-0.00000
#   test  auc-pr:		0.99991+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

plt.figure()
plt.ylabel('Predicted score')
plt.xlabel('Sequences ordered by score')
plt.plot(range(len(plot_index)), predictionsoutput[plot_index])
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/riboswitch_resbindt4_ug_so1k.npy'

num_summary = 1000
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =5.27s
# Cumulative duration =5.27s
#
# 1
# Epoch duration =5.28s
# Cumulative duration =10.55s
#
# 2
# Epoch duration =5.24s
# Cumulative duration =15.79s
#
# 3
# Epoch duration =5.25s
# Cumulative duration =21.04s
#
# 4
# Epoch duration =5.25s
# Cumulative duration =26.3s
#
# 5
# Epoch duration =5.21s
# Cumulative duration =31.51s
#
# 6
# Epoch duration =5.21s
# Cumulative duration =36.72s
#
# 7
# Epoch duration =5.22s
# Cumulative duration =41.94s
#
# 8
# Epoch duration =5.24s
# Cumulative duration =47.19s
#
# 9
# Epoch duration =5.23s
# Cumulative duration =52.42s
#
# 10
# Epoch duration =5.26s
# Cumulative duration =57.68s
#
# 11
# Epoch duration =5.24s
# Cumulative duration =1min 2.9299999999999997s
#
# 12
# Epoch duration =5.26s
# Cumulative duration =1min 8.189999999999998s
#
# 13
# Epoch duration =5.29s
# Cumulative duration =1min 13.480000000000004s
#
# 14
# Epoch duration =5.25s
# Cumulative duration =1min 18.739999999999995s
#
# 15
# Epoch duration =5.24s
# Cumulative duration =1min 23.980000000000004s
#
# 16
# Epoch duration =5.24s
# Cumulative duration =1min 29.22s
#
# 17
# Epoch duration =5.23s
# Cumulative duration =1min 34.45s
#
# 18
# Epoch duration =5.22s
# Cumulative duration =1min 39.68000000000001s
#
# 19
# Epoch duration =5.23s
# Cumulative duration =1min 44.91s
#
# 20
# Epoch duration =5.24s
# Cumulative duration =1min 50.150000000000006s
#
# 21
# Epoch duration =5.25s
# Cumulative duration =1min 55.41s
#
# 22
# Epoch duration =5.25s
# Cumulative duration =2min 0.6599999999999966s
#
# 23
# Epoch duration =5.23s
# Cumulative duration =2min 5.8799999999999955s
#
# 24
# Epoch duration =5.27s
# Cumulative duration =2min 11.159999999999997s
#
# 25
# Epoch duration =5.23s
# Cumulative duration =2min 16.389999999999986s
#
# 26
# Epoch duration =5.28s
# Cumulative duration =2min 21.669999999999987s
#
# 27
# Epoch duration =5.24s
# Cumulative duration =2min 26.909999999999997s
#
# 28
# Epoch duration =5.27s
# Cumulative duration =2min 32.19s
#
# 29
# Epoch duration =5.24s
# Cumulative duration =2min 37.41999999999999s
#
# 30
# Epoch duration =5.26s
# Cumulative duration =2min 42.68000000000001s
#
# 31
# Epoch duration =5.26s
# Cumulative duration =2min 47.94s
#
# 32
# Epoch duration =5.26s
# Cumulative duration =2min 53.19999999999999s
#
# 33
# Epoch duration =5.25s
# Cumulative duration =2min 58.44999999999999s
#
# 34
# Epoch duration =5.27s
# Cumulative duration =3min 3.719999999999999s
#
# 35
# Epoch duration =5.26s
# Cumulative duration =3min 8.97999999999999s
#
# 36
# Epoch duration =5.27s
# Cumulative duration =3min 14.259999999999991s
#
# 37
# Epoch duration =5.28s
# Cumulative duration =3min 19.539999999999992s
#
# 38
# Epoch duration =5.27s
# Cumulative duration =3min 24.810000000000002s
#
# 39
# Epoch duration =5.27s
# Cumulative duration =3min 30.080000000000013s
#
# 40
# Epoch duration =5.25s
# Cumulative duration =3min 35.33000000000001s
#
# 41
# Epoch duration =5.25s
# Cumulative duration =3min 40.59s
#
# 42
# Epoch duration =5.28s
# Cumulative duration =3min 45.870000000000005s
#
# 43
# Epoch duration =5.27s
# Cumulative duration =3min 51.139999999999986s
#
# 44
# Epoch duration =5.26s
# Cumulative duration =3min 56.400000000000006s
#
# 45
# Epoch duration =5.24s
# Cumulative duration =4min 1.6399999999999864s
#
# 46
# Epoch duration =5.26s
# Cumulative duration =4min 6.900000000000006s
#
# 47
# Epoch duration =5.24s
# Cumulative duration =4min 12.139999999999986s
#
# 48
# Epoch duration =5.23s
# Cumulative duration =4min 17.370000000000005s
#
# 49
# Epoch duration =5.25s
# Cumulative duration =4min 22.610000000000014s
#
# 50
# Epoch duration =5.25s
# Cumulative duration =4min 27.870000000000005s
#
# 51
# Epoch duration =5.24s
# Cumulative duration =4min 33.110000000000014s
#
# 52
# Epoch duration =5.26s
# Cumulative duration =4min 38.370000000000005s
#
# 53
# Epoch duration =5.3s
# Cumulative duration =4min 43.660000000000025s
#
# 54
# Epoch duration =5.26s
# Cumulative duration =4min 48.93000000000001s
#
# 55
# Epoch duration =5.22s
# Cumulative duration =4min 54.14999999999998s
#
# 56
# Epoch duration =5.27s
# Cumulative duration =4min 59.420000000000016s
#
# 57
# Epoch duration =5.24s
# Cumulative duration =5min 4.660000000000025s
#
# 58
# Epoch duration =5.31s
# Cumulative duration =5min 9.970000000000027s
#
# 59
# Epoch duration =5.24s
# Cumulative duration =5min 15.20999999999998s
#
# 60
# Epoch duration =5.26s
# Cumulative duration =5min 20.470000000000027s
#
# 61
# Epoch duration =5.23s
# Cumulative duration =5min 25.69999999999999s
#
# 62
# Epoch duration =5.27s
# Cumulative duration =5min 30.970000000000027s
#
# 63
# Epoch duration =5.27s
# Cumulative duration =5min 36.23000000000002s
#
# 64
# Epoch duration =5.29s
# Cumulative duration =5min 41.52999999999997s
#
# 65
# Epoch duration =5.26s
# Cumulative duration =5min 46.79000000000002s
#
# 66
# Epoch duration =5.28s
# Cumulative duration =5min 52.06999999999999s
#
# 67
# Epoch duration =5.25s
# Cumulative duration =5min 57.31999999999999s
#
# 68
# Epoch duration =5.27s
# Cumulative duration =6min 2.579999999999984s
#
# 69
# Epoch duration =5.26s
# Cumulative duration =6min 7.839999999999975s
#
# 70
# Epoch duration =5.27s
# Cumulative duration =6min 13.110000000000014s
#
# 71
# Epoch duration =5.27s
# Cumulative duration =6min 18.379999999999995s
#
# 72
# Epoch duration =5.24s
# Cumulative duration =6min 23.629999999999995s
#
# 73
# Epoch duration =5.28s
# Cumulative duration =6min 28.910000000000025s
#
# 74
# Epoch duration =5.26s
# Cumulative duration =6min 34.170000000000016s
#
# 75
# Epoch duration =5.24s
# Cumulative duration =6min 39.410000000000025s
#
# 76
# Epoch duration =5.26s
# Cumulative duration =6min 44.670000000000016s
#
# 77
# Epoch duration =5.22s
# Cumulative duration =6min 49.89999999999998s
#
# 78
# Epoch duration =5.26s
# Cumulative duration =6min 55.160000000000025s
#
# 79
# Epoch duration =5.24s
# Cumulative duration =7min 0.39999999999997726s
#
# 80
# Epoch duration =5.24s
# Cumulative duration =7min 5.6299999999999955s
#
# 81
# Epoch duration =5.27s
# Cumulative duration =7min 10.910000000000025s
#
# 82
# Epoch duration =5.25s
# Cumulative duration =7min 16.160000000000025s
#
# 83
# Epoch duration =5.26s
# Cumulative duration =7min 21.420000000000016s
#
# 84
# Epoch duration =5.26s
# Cumulative duration =7min 26.689999999999998s
#
# 85
# Epoch duration =5.25s
# Cumulative duration =7min 31.930000000000007s
#
# 86
# Epoch duration =5.26s
# Cumulative duration =7min 37.19s
#
# 87
# Epoch duration =5.26s
# Cumulative duration =7min 42.44999999999999s
#
# 88
# Epoch duration =5.27s
# Cumulative duration =7min 47.72000000000003s
#
# 89
# Epoch duration =5.24s
# Cumulative duration =7min 52.95999999999998s
#
# 90
# Epoch duration =5.3s
# Cumulative duration =7min 58.25999999999999s
#
# 91
# Epoch duration =5.24s
# Cumulative duration =8min 3.5s
#
# 92
# Epoch duration =5.27s
# Cumulative duration =8min 8.779999999999973s
#
# 93
# Epoch duration =5.28s
# Cumulative duration =8min 14.050000000000011s
#
# 94
# Epoch duration =5.27s
# Cumulative duration =8min 19.329999999999984s
#
# 95
# Epoch duration =5.29s
# Cumulative duration =8min 24.610000000000014s
#
# 96
# Epoch duration =5.27s
# Cumulative duration =8min 29.889999999999986s
#
# 97
# Epoch duration =5.26s
# Cumulative duration =8min 35.139999999999986s
#
# 98
# Epoch duration =5.25s
# Cumulative duration =8min 40.39999999999998s
#
# 99
# Epoch duration =5.25s
# Cumulative duration =8min 45.64999999999998s
#
# 100
# Epoch duration =5.29s
# Cumulative duration =8min 50.940000000000055s
#
# 101
# Epoch duration =5.25s
# Cumulative duration =8min 56.200000000000045s
#
# 102
# Epoch duration =5.24s
# Cumulative duration =9min 1.4400000000000546s
#
# 103
# Epoch duration =5.25s
# Cumulative duration =9min 6.67999999999995s
#
# 104
# Epoch duration =5.3s
# Cumulative duration =9min 11.980000000000018s
#
# 105
# Epoch duration =5.23s
# Cumulative duration =9min 17.210000000000036s
#
# 106
# Epoch duration =5.29s
# Cumulative duration =9min 22.5s
#
# 107
# Epoch duration =5.26s
# Cumulative duration =9min 27.75999999999999s
#
# 108
# Epoch duration =5.27s
# Cumulative duration =9min 33.02999999999997s
#
# 109
# Epoch duration =5.23s
# Cumulative duration =9min 38.25999999999999s
#
# 110
# Epoch duration =5.25s
# Cumulative duration =9min 43.50999999999999s
#
# 111
# Epoch duration =5.26s
# Cumulative duration =9min 48.76999999999998s
#
# 112
# Epoch duration =5.25s
# Cumulative duration =9min 54.01999999999998s
#
# 113
# Epoch duration =5.24s
# Cumulative duration =9min 59.25999999999999s
#
# 114
# Epoch duration =5.26s
# Cumulative duration =10min 4.519999999999982s
#
# 115
# Epoch duration =5.25s
# Cumulative duration =10min 9.769999999999982s
#
# 116
# Epoch duration =5.28s
# Cumulative duration =10min 15.059999999999945s
#
# 117
# Epoch duration =5.25s
# Cumulative duration =10min 20.309999999999945s
#
# 118
# Epoch duration =5.26s
# Cumulative duration =10min 25.57000000000005s
#
# 119
# Epoch duration =5.24s
# Cumulative duration =10min 30.809999999999945s
#
# 120
# Epoch duration =5.28s
# Cumulative duration =10min 36.10000000000002s
#
# 121
# Epoch duration =5.23s
# Cumulative duration =10min 41.33000000000004s
#
# 122
# Epoch duration =5.28s
# Cumulative duration =10min 46.610000000000014s
#
# 123
# Epoch duration =5.25s
# Cumulative duration =10min 51.860000000000014s
#
# 124
# Epoch duration =5.25s
# Cumulative duration =10min 57.110000000000014s
#
# 125
# Epoch duration =5.25s
# Cumulative duration =11min 2.3600000000000136s
#
# 126
# Epoch duration =5.26s
# Cumulative duration =11min 7.6200000000000045s
#
# 127
# Epoch duration =5.26s
# Cumulative duration =11min 12.879999999999995s
#
# 128
# Epoch duration =5.29s
# Cumulative duration =11min 18.159999999999968s
#
# 129
# Epoch duration =5.25s
# Cumulative duration =11min 23.409999999999968s
#
# 130
# Epoch duration =5.24s
# Cumulative duration =11min 28.659999999999968s
#
# 131
# Epoch duration =5.27s
# Cumulative duration =11min 33.92999999999995s
#
# 132
# Epoch duration =5.27s
# Cumulative duration =11min 39.200000000000045s
#
# 133
# Epoch duration =5.27s
# Cumulative duration =11min 44.460000000000036s
#
# 134
# Epoch duration =5.29s
# Cumulative duration =11min 49.75s
#
# 135
# Epoch duration =5.26s
# Cumulative duration =11min 55.00999999999999s
#
# 136
# Epoch duration =5.29s
# Cumulative duration =12min 0.2999999999999545s
#
# 137
# Epoch duration =5.25s
# Cumulative duration =12min 5.5499999999999545s
#
# 138
# Epoch duration =5.3s
# Cumulative duration =12min 10.850000000000023s
#
# 139
# Epoch duration =5.27s
# Cumulative duration =12min 16.120000000000005s
#
# 140
# Epoch duration =5.28s
# Cumulative duration =12min 21.389999999999986s
#
# 141
# Epoch duration =5.25s
# Cumulative duration =12min 26.639999999999986s
#
# 142
# Epoch duration =5.29s
# Cumulative duration =12min 31.92999999999995s
#
# 143
# Epoch duration =5.23s
# Cumulative duration =12min 37.15999999999997s
#
# 144
# Epoch duration =5.25s
# Cumulative duration =12min 42.40999999999997s
#
# 145
# Epoch duration =5.25s
# Cumulative duration =12min 47.64999999999998s
#
# 146
# Epoch duration =5.25s
# Cumulative duration =12min 52.89999999999998s
#
# 147
# Epoch duration =5.24s
# Cumulative duration =12min 58.139999999999986s
#
# 148
# Epoch duration =5.27s
# Cumulative duration =13min 3.409999999999968s
#
# 149
# Epoch duration =5.29s
# Cumulative duration =13min 8.700000000000045s
#
# 150
# Epoch duration =5.28s
# Cumulative duration =13min 13.980000000000018s
#
# 151
# Epoch duration =5.29s
# Cumulative duration =13min 19.269999999999982s
#
# 152
# Epoch duration =5.25s
# Cumulative duration =13min 24.519999999999982s
#
# 153
# Epoch duration =5.25s
# Cumulative duration =13min 29.75999999999999s
#
# 154
# Epoch duration =5.26s
# Cumulative duration =13min 35.01999999999998s
#
# 155
# Epoch duration =5.23s
# Cumulative duration =13min 40.25s
#
# 156
# Epoch duration =5.25s
# Cumulative duration =13min 45.5s
#
# 157
# Epoch duration =5.25s
# Cumulative duration =13min 50.75999999999999s
#
# 158
# Epoch duration =5.28s
# Cumulative duration =13min 56.039999999999964s
#
# 159
# Epoch duration =5.25s
# Cumulative duration =14min 1.2899999999999636s
#
# 160
# Epoch duration =5.26s
# Cumulative duration =14min 6.5499999999999545s
#
# 161
# Epoch duration =5.24s
# Cumulative duration =14min 11.789999999999964s
#
# 162
# Epoch duration =5.26s
# Cumulative duration =14min 17.059999999999945s
#
# 163
# Epoch duration =5.27s
# Cumulative duration =14min 22.33000000000004s
#
# 164
# Epoch duration =5.24s
# Cumulative duration =14min 27.57000000000005s
#
# 165
# Epoch duration =5.24s
# Cumulative duration =14min 32.809999999999945s
#
# 166
# Epoch duration =5.25s
# Cumulative duration =14min 38.059999999999945s
#
# 167
# Epoch duration =5.24s
# Cumulative duration =14min 43.299999999999955s
#
# 168
# Epoch duration =5.27s
# Cumulative duration =14min 48.57000000000005s
#
# 169
# Epoch duration =5.27s
# Cumulative duration =14min 53.84000000000003s
#
# 170
# Epoch duration =5.28s
# Cumulative duration =14min 59.120000000000005s
#
# 171
# Epoch duration =5.25s
# Cumulative duration =15min 4.3700000000000045s
#
# 172
# Epoch duration =5.29s
# Cumulative duration =15min 9.659999999999968s
#
# 173
# Epoch duration =5.25s
# Cumulative duration =15min 14.919999999999959s
#
# 174
# Epoch duration =5.24s
# Cumulative duration =15min 20.159999999999968s
#
# 175
# Epoch duration =5.27s
# Cumulative duration =15min 25.42999999999995s
#
# 176
# Epoch duration =5.25s
# Cumulative duration =15min 30.67999999999995s
#
# 177
# Epoch duration =5.25s
# Cumulative duration =15min 35.92999999999995s
#
# 178
# Epoch duration =5.28s
# Cumulative duration =15min 41.210000000000036s
#
# 179
# Epoch duration =5.23s
# Cumulative duration =15min 46.450000000000045s
#
# 180
# Epoch duration =5.24s
# Cumulative duration =15min 51.690000000000055s
#
# 181
# Epoch duration =5.24s
# Cumulative duration =15min 56.92999999999995s
#
# 182
# Epoch duration =5.25s
# Cumulative duration =16min 2.1900000000000546s
#
# 183
# Epoch duration =5.23s
# Cumulative duration =16min 7.409999999999968s
#
# 184
# Epoch duration =5.24s
# Cumulative duration =16min 12.649999999999977s
#
# 185
# Epoch duration =5.25s
# Cumulative duration =16min 17.909999999999968s
#
# 186
# Epoch duration =5.29s
# Cumulative duration =16min 23.200000000000045s
#
# 187
# Epoch duration =5.26s
# Cumulative duration =16min 28.460000000000036s
#
# 188
# Epoch duration =5.27s
# Cumulative duration =16min 33.73000000000002s
#
# 189
# Epoch duration =5.26s
# Cumulative duration =16min 38.99000000000001s
#
# 190
# Epoch duration =5.28s
# Cumulative duration =16min 44.26999999999998s
#
# 191
# Epoch duration =5.29s
# Cumulative duration =16min 49.559999999999945s
#
# 192
# Epoch duration =5.27s
# Cumulative duration =16min 54.83000000000004s
#
# 193
# Epoch duration =5.27s
# Cumulative duration =17min 0.11000000000001364s
#
# 194
# Epoch duration =5.25s
# Cumulative duration =17min 5.349999999999909s
#
# 195
# Epoch duration =5.28s
# Cumulative duration =17min 10.63000000000011s
#
# 196
# Epoch duration =5.27s
# Cumulative duration =17min 15.900000000000091s
#
# 197
# Epoch duration =5.3s
# Cumulative duration =17min 21.200000000000045s
#
# 198
# Epoch duration =5.27s
# Cumulative duration =17min 26.470000000000027s
#
# 199
# Epoch duration =5.27s
# Cumulative duration =17min 31.730000000000018s
#
# 200
# Epoch duration =5.24s
# Cumulative duration =17min 36.97000000000003s
#
# 201
# Epoch duration =5.23s
# Cumulative duration =17min 42.210000000000036s
#
# 202
# Epoch duration =5.27s
# Cumulative duration =17min 47.48000000000002s
#
# 203
# Epoch duration =5.27s
# Cumulative duration =17min 52.75s
#
# 204
# Epoch duration =5.25s
# Cumulative duration =17min 58.0s
#
# 205
# Epoch duration =5.25s
# Cumulative duration =18min 3.240000000000009s
#
# 206
# Epoch duration =5.26s
# Cumulative duration =18min 8.5s
#
# 207
# Epoch duration =5.25s
# Cumulative duration =18min 13.75s
#
# 208
# Epoch duration =5.34s
# Cumulative duration =18min 19.089999999999918s
#
# 209
# Epoch duration =5.26s
# Cumulative duration =18min 24.34999999999991s
#
# 210
# Epoch duration =5.27s
# Cumulative duration =18min 29.61999999999989s
#
# 211
# Epoch duration =5.25s
# Cumulative duration =18min 34.86999999999989s
#
# 212
# Epoch duration =5.27s
# Cumulative duration =18min 40.1400000000001s
#
# 213
# Epoch duration =5.28s
# Cumulative duration =18min 45.42000000000007s
#
# 214
# Epoch duration =5.26s
# Cumulative duration =18min 50.680000000000064s
#
# 215
# Epoch duration =5.24s
# Cumulative duration =18min 55.92000000000007s
#
# 216
# Epoch duration =5.28s
# Cumulative duration =19min 1.2000000000000455s
#
# 217
# Epoch duration =5.26s
# Cumulative duration =19min 6.460000000000036s
#
# 218
# Epoch duration =5.31s
# Cumulative duration =19min 11.769999999999982s
#
# 219
# Epoch duration =5.25s
# Cumulative duration =19min 17.019999999999982s
#
# 220
# Epoch duration =5.29s
# Cumulative duration =19min 22.309999999999945s
#
# 221
# Epoch duration =5.26s
# Cumulative duration =19min 27.569999999999936s
#
# 222
# Epoch duration =5.29s
# Cumulative duration =19min 32.8599999999999s
#
# 223
# Epoch duration =5.24s
# Cumulative duration =19min 38.09999999999991s
#
# 224
# Epoch duration =5.29s
# Cumulative duration =19min 43.3900000000001s
#
# 225
# Epoch duration =5.25s
# Cumulative duration =19min 48.6400000000001s
#
# 226
# Epoch duration =5.29s
# Cumulative duration =19min 53.92000000000007s
#
# 227
# Epoch duration =5.26s
# Cumulative duration =19min 59.180000000000064s
#
# 228
# Epoch duration =5.28s
# Cumulative duration =20min 4.460000000000036s
#
# 229
# Epoch duration =5.26s
# Cumulative duration =20min 9.720000000000027s
#
# 230
# Epoch duration =5.28s
# Cumulative duration =20min 15.0s
#
# 231
# Epoch duration =5.25s
# Cumulative duration =20min 20.25s
#
# 232
# Epoch duration =5.26s
# Cumulative duration =20min 25.519999999999982s
#
# 233
# Epoch duration =5.24s
# Cumulative duration =20min 30.75999999999999s
#
# 234
# Epoch duration =5.28s
# Cumulative duration =20min 36.039999999999964s
#
# 235
# Epoch duration =5.25s
# Cumulative duration =20min 41.289999999999964s
#
# 236
# Epoch duration =5.26s
# Cumulative duration =20min 46.559999999999945s
#
# 237
# Epoch duration =5.25s
# Cumulative duration =20min 51.809999999999945s
#
# 238
# Epoch duration =5.3s
# Cumulative duration =20min 57.1099999999999s
#
# 239
# Epoch duration =5.26s
# Cumulative duration =21min 2.369999999999891s
#
# 240
# Epoch duration =5.26s
# Cumulative duration =21min 7.630000000000109s
#
# 241
# Epoch duration =5.29s
# Cumulative duration =21min 12.920000000000073s
#
# 242
# Epoch duration =5.26s
# Cumulative duration =21min 18.180000000000064s
#
# 243
# Epoch duration =5.27s
# Cumulative duration =21min 23.450000000000045s
#
# 244
# Epoch duration =5.26s
# Cumulative duration =21min 28.710000000000036s
#
# 245
# Epoch duration =5.24s
# Cumulative duration =21min 33.950000000000045s
#
# 246
# Epoch duration =5.26s
# Cumulative duration =21min 39.210000000000036s
#
# 247
# Epoch duration =5.25s
# Cumulative duration =21min 44.460000000000036s
#
# 248
# Epoch duration =5.29s
# Cumulative duration =21min 49.75s
#
# 249
# Epoch duration =5.25s
# Cumulative duration =21min 55.0s
#
# 250
# Epoch duration =5.29s
# Cumulative duration =22min 0.2999999999999545s
#
# 251
# Epoch duration =5.26s
# Cumulative duration =22min 5.559999999999945s
#
# 252
# Epoch duration =5.3s
# Cumulative duration =22min 10.8599999999999s
#
# 253
# Epoch duration =5.23s
# Cumulative duration =22min 16.089999999999918s
#
# 254
# Epoch duration =5.27s
# Cumulative duration =22min 21.3599999999999s
#
# 255
# Epoch duration =5.22s
# Cumulative duration =22min 26.579999999999927s
#
# 256
# Epoch duration =5.26s
# Cumulative duration =22min 31.84999999999991s
#
# 257
# Epoch duration =5.26s
# Cumulative duration =22min 37.1099999999999s
#
# 258
# Epoch duration =5.27s
# Cumulative duration =22min 42.38000000000011s
#
# 259
# Epoch duration =5.28s
# Cumulative duration =22min 47.66000000000008s
#
# 260
# Epoch duration =5.23s
# Cumulative duration =22min 52.8900000000001s
#
# 261
# Epoch duration =5.26s
# Cumulative duration =22min 58.15000000000009s
#
# 262
# Epoch duration =5.25s
# Cumulative duration =23min 3.400000000000091s
#
# 263
# Epoch duration =5.27s
# Cumulative duration =23min 8.670000000000073s
#
# 264
# Epoch duration =5.25s
# Cumulative duration =23min 13.920000000000073s
#
# 265
# Epoch duration =5.25s
# Cumulative duration =23min 19.170000000000073s
#
# 266
# Epoch duration =5.28s
# Cumulative duration =23min 24.450000000000045s
#
# 267
# Epoch duration =5.23s
# Cumulative duration =23min 29.680000000000064s
#
# 268
# Epoch duration =5.26s
# Cumulative duration =23min 34.940000000000055s
#
# 269
# Epoch duration =5.26s
# Cumulative duration =23min 40.200000000000045s
#
# 270
# Epoch duration =5.24s
# Cumulative duration =23min 45.440000000000055s
#
# 271
# Epoch duration =5.25s
# Cumulative duration =23min 50.690000000000055s
#
# 272
# Epoch duration =5.25s
# Cumulative duration =23min 55.950000000000045s
#
# 273
# Epoch duration =5.29s
# Cumulative duration =24min 1.240000000000009s
#
# 274
# Epoch duration =5.32s
# Cumulative duration =24min 6.5499999999999545s
#
# 275
# Epoch duration =5.26s
# Cumulative duration =24min 11.809999999999945s
#
# 276
# Epoch duration =5.29s
# Cumulative duration =24min 17.09999999999991s
#
# 277
# Epoch duration =5.26s
# Cumulative duration =24min 22.3599999999999s
#
# 278
# Epoch duration =5.25s
# Cumulative duration =24min 27.6099999999999s
#
# 279
# Epoch duration =5.25s
# Cumulative duration =24min 32.86999999999989s
#
# 280
# Epoch duration =5.28s
# Cumulative duration =24min 38.1400000000001s
#
# 281
# Epoch duration =5.25s
# Cumulative duration =24min 43.40000000000009s
#
# 282
# Epoch duration =5.26s
# Cumulative duration =24min 48.66000000000008s
#
# 283
# Epoch duration =5.24s
# Cumulative duration =24min 53.90000000000009s
#
# 284
# Epoch duration =5.25s
# Cumulative duration =24min 59.15000000000009s
#
# 285
# Epoch duration =5.25s
# Cumulative duration =25min 4.400000000000091s
#
# 286
# Epoch duration =5.29s
# Cumulative duration =25min 9.680000000000064s
#
# 287
# Epoch duration =5.25s
# Cumulative duration =25min 14.930000000000064s
#
# 288
# Epoch duration =5.27s
# Cumulative duration =25min 20.200000000000045s
#
# 289
# Epoch duration =5.22s
# Cumulative duration =25min 25.420000000000073s
#
# 290
# Epoch duration =5.27s
# Cumulative duration =25min 30.690000000000055s
#
# 291
# Epoch duration =5.27s
# Cumulative duration =25min 35.960000000000036s
#
# 292
# Epoch duration =5.25s
# Cumulative duration =25min 41.210000000000036s
#
# 293
# Epoch duration =5.28s
# Cumulative duration =25min 46.49000000000001s
#
# 294
# Epoch duration =5.25s
# Cumulative duration =25min 51.74000000000001s
#
# 295
# Epoch duration =5.32s
# Cumulative duration =25min 57.049999999999955s
#
# 296
# Epoch duration =5.26s
# Cumulative duration =26min 2.3099999999999454s
#
# 297
# Epoch duration =5.25s
# Cumulative duration =26min 7.559999999999945s
#
# 298
# Epoch duration =5.25s
# Cumulative duration =26min 12.809999999999945s
#
# 299
# Epoch duration =5.34s
# Cumulative duration =26min 18.15000000000009s
#
# 300
# Epoch duration =5.25s
# Cumulative duration =26min 23.410000000000082s
#
# 301
# Epoch duration =5.25s
# Cumulative duration =26min 28.65000000000009s
#
# 302
# Epoch duration =5.27s
# Cumulative duration =26min 33.92000000000007s
#
# 303
# Epoch duration =5.27s
# Cumulative duration =26min 39.190000000000055s
#
# 304
# Epoch duration =5.3s
# Cumulative duration =26min 44.49000000000001s
#
# 305
# Epoch duration =5.26s
# Cumulative duration =26min 49.75999999999999s
#
# 306
# Epoch duration =5.32s
# Cumulative duration =26min 55.07999999999993s
#
# 307
# Epoch duration =5.23s
# Cumulative duration =27min 0.2999999999999545s
#
# 308
# Epoch duration =5.26s
# Cumulative duration =27min 5.569999999999936s
#
# 309
# Epoch duration =5.28s
# Cumulative duration =27min 10.849999999999909s
#
# 310
# Epoch duration =5.27s
# Cumulative duration =27min 16.1099999999999s
#
# 311
# Epoch duration =5.25s
# Cumulative duration =27min 21.3599999999999s
#
# 312
# Epoch duration =5.24s
# Cumulative duration =27min 26.6099999999999s
#
# 313
# Epoch duration =5.27s
# Cumulative duration =27min 31.88000000000011s
#
# 314
# Epoch duration =5.26s
# Cumulative duration =27min 37.1400000000001s
#
# 315
# Epoch duration =5.24s
# Cumulative duration =27min 42.38000000000011s
#
# 316
# Epoch duration =5.26s
# Cumulative duration =27min 47.6400000000001s
#
# 317
# Epoch duration =5.26s
# Cumulative duration =27min 52.90000000000009s
#
# 318
# Epoch duration =5.27s
# Cumulative duration =27min 58.17000000000007s
#
# 319
# Epoch duration =5.3s
# Cumulative duration =28min 3.4700000000000273s
#
# 320
# Epoch duration =5.31s
# Cumulative duration =28min 8.789999999999964s
#
# 321
# Epoch duration =5.24s
# Cumulative duration =28min 14.029999999999973s
#
# 322
# Epoch duration =5.26s
# Cumulative duration =28min 19.289999999999964s
#
# 323
# Epoch duration =5.27s
# Cumulative duration =28min 24.569999999999936s
#
# 324
# Epoch duration =5.27s
# Cumulative duration =28min 29.829999999999927s
#
# 325
# Epoch duration =5.25s
# Cumulative duration =28min 35.07999999999993s
#
# 326
# Epoch duration =5.25s
# Cumulative duration =28min 40.32999999999993s
#
# 327
# Epoch duration =5.28s
# Cumulative duration =28min 45.6099999999999s
#
# 328
# Epoch duration =5.28s
# Cumulative duration =28min 50.88000000000011s
#
# 329
# Epoch duration =5.24s
# Cumulative duration =28min 56.13000000000011s
#
# 330
# Epoch duration =5.26s
# Cumulative duration =29min 1.3900000000001s
#
# 331
# Epoch duration =5.22s
# Cumulative duration =29min 6.619999999999891s
#
# 332
# Epoch duration =5.29s
# Cumulative duration =29min 11.910000000000082s
#
# 333
# Epoch duration =5.27s
# Cumulative duration =29min 17.170000000000073s
#
# 334
# Epoch duration =5.28s
# Cumulative duration =29min 22.450000000000045s
#
# 335
# Epoch duration =5.26s
# Cumulative duration =29min 27.710000000000036s
#
# 336
# Epoch duration =5.26s
# Cumulative duration =29min 32.97000000000003s
#
# 337
# Epoch duration =5.23s
# Cumulative duration =29min 38.210000000000036s
#
# 338
# Epoch duration =5.24s
# Cumulative duration =29min 43.450000000000045s
#
# 339
# Epoch duration =5.25s
# Cumulative duration =29min 48.690000000000055s
#
# 340
# Epoch duration =5.25s
# Cumulative duration =29min 53.940000000000055s
#
# 341
# Epoch duration =5.24s
# Cumulative duration =29min 59.190000000000055s
#
# 342
# Epoch duration =5.26s
# Cumulative duration =30min 4.440000000000055s
#
# 343
# Epoch duration =5.28s
# Cumulative duration =30min 9.720000000000027s
#
# 344
# Epoch duration =5.25s
# Cumulative duration =30min 14.970000000000027s
#
# 345
# Epoch duration =5.25s
# Cumulative duration =30min 20.230000000000018s
#
# 346
# Epoch duration =5.29s
# Cumulative duration =30min 25.50999999999999s
#
# 347
# Epoch duration =5.25s
# Cumulative duration =30min 30.75999999999999s
#
# 348
# Epoch duration =5.31s
# Cumulative duration =30min 36.059999999999945s
#
# 349
# Epoch duration =5.27s
# Cumulative duration =30min 41.32999999999993s
#
# 350
# Epoch duration =5.26s
# Cumulative duration =30min 46.59999999999991s
#
# 351
# Epoch duration =5.26s
# Cumulative duration =30min 51.8599999999999s
#
# 352
# Epoch duration =5.25s
# Cumulative duration =30min 57.1099999999999s
#
# 353
# Epoch duration =5.25s
# Cumulative duration =31min 2.3599999999999s
#
# 354
# Epoch duration =5.26s
# Cumulative duration =31min 7.619999999999891s
#
# 355
# Epoch duration =5.27s
# Cumulative duration =31min 12.8900000000001s
#
# 356
# Epoch duration =5.24s
# Cumulative duration =31min 18.13000000000011s
#
# 357
# Epoch duration =5.25s
# Cumulative duration =31min 23.38000000000011s
#
# 358
# Epoch duration =5.26s
# Cumulative duration =31min 28.6400000000001s
#
# 359
# Epoch duration =5.25s
# Cumulative duration =31min 33.8900000000001s
#
# 360
# Epoch duration =5.3s
# Cumulative duration =31min 39.190000000000055s
#
# 361
# Epoch duration =5.24s
# Cumulative duration =31min 44.430000000000064s
#
# 362
# Epoch duration =5.26s
# Cumulative duration =31min 49.680000000000064s
#
# 363
# Epoch duration =5.27s
# Cumulative duration =31min 54.950000000000045s
#
# 364
# Epoch duration =5.27s
# Cumulative duration =32min 0.22000000000002728s
#
# 365
# Epoch duration =5.25s
# Cumulative duration =32min 5.470000000000027s
#
# 366
# Epoch duration =5.29s
# Cumulative duration =32min 10.759999999999991s
#
# 367
# Epoch duration =5.23s
# Cumulative duration =32min 16.0s
#
# 368
# Epoch duration =5.29s
# Cumulative duration =32min 21.279999999999973s
#
# 369
# Epoch duration =5.28s
# Cumulative duration =32min 26.559999999999945s
#
# 370
# Epoch duration =5.24s
# Cumulative duration =32min 31.809999999999945s
#
# 371
# Epoch duration =5.25s
# Cumulative duration =32min 37.059999999999945s
#
# 372
# Epoch duration =5.24s
# Cumulative duration =32min 42.299999999999955s
#
# 373
# Epoch duration =5.26s
# Cumulative duration =32min 47.559999999999945s
#
# 374
# Epoch duration =5.26s
# Cumulative duration =32min 52.819999999999936s
#
# 375
# Epoch duration =5.23s
# Cumulative duration =32min 58.049999999999955s
#
# 376
# Epoch duration =5.28s
# Cumulative duration =33min 3.3299999999999272s
#
# 377
# Epoch duration =5.29s
# Cumulative duration =33min 8.61999999999989s
#
# 378
# Epoch duration =5.28s
# Cumulative duration =33min 13.900000000000091s
#
# 379
# Epoch duration =5.28s
# Cumulative duration =33min 19.190000000000055s
#
# 380
# Epoch duration =5.27s
# Cumulative duration =33min 24.460000000000036s
#
# 381
# Epoch duration =5.25s
# Cumulative duration =33min 29.700000000000045s
#
# 382
# Epoch duration =5.26s
# Cumulative duration =33min 34.960000000000036s
#
# 383
# Epoch duration =5.26s
# Cumulative duration =33min 40.210000000000036s
#
# 384
# Epoch duration =5.27s
# Cumulative duration =33min 45.48000000000002s
#
# 385
# Epoch duration =5.25s
# Cumulative duration =33min 50.73000000000002s
#
# 386
# Epoch duration =5.27s
# Cumulative duration =33min 56.00999999999999s
#
# 387
# Epoch duration =5.24s
# Cumulative duration =34min 1.25s
#
# 388
# Epoch duration =5.27s
# Cumulative duration =34min 6.519999999999982s
#
# 389
# Epoch duration =5.24s
# Cumulative duration =34min 11.760000000000218s
#
# 390
# Epoch duration =5.26s
# Cumulative duration =34min 17.019999999999982s
#
# 391
# Epoch duration =5.26s
# Cumulative duration =34min 22.2800000000002s
#
# 392
# Epoch duration =5.29s
# Cumulative duration =34min 27.570000000000164s
#
# 393
# Epoch duration =5.31s
# Cumulative duration =34min 32.88000000000011s
#
# 394
# Epoch duration =5.23s
# Cumulative duration =34min 38.11000000000013s
#
# 395
# Epoch duration =5.25s
# Cumulative duration =34min 43.36999999999989s
#
# 396
# Epoch duration =5.27s
# Cumulative duration =34min 48.63999999999987s
#
# 397
# Epoch duration =5.25s
# Cumulative duration =34min 53.88999999999987s
#
# 398
# Epoch duration =5.26s
# Cumulative duration =34min 59.159999999999854s
#
# 399
# Epoch duration =5.24s
# Cumulative duration =35min 4.400000000000091s
#
# 400
# Epoch duration =5.25s
# Cumulative duration =35min 9.650000000000091s
#
# 401
# Epoch duration =5.25s
# Cumulative duration =35min 14.900000000000091s
#
# 402
# Epoch duration =5.24s
# Cumulative duration =35min 20.139999999999873s
#
# 403
# Epoch duration =5.25s
# Cumulative duration =35min 25.389999999999873s
#
# 404
# Epoch duration =5.25s
# Cumulative duration =35min 30.639999999999873s
#
# 405
# Epoch duration =5.23s
# Cumulative duration =35min 35.88000000000011s
#
# 406
# Epoch duration =5.26s
# Cumulative duration =35min 41.13999999999987s
#
# 407
# Epoch duration =5.23s
# Cumulative duration =35min 46.36999999999989s
#
# 408
# Epoch duration =5.27s
# Cumulative duration =35min 51.63999999999987s
#
# 409
# Epoch duration =5.26s
# Cumulative duration =35min 56.90000000000009s
#
# 410
# Epoch duration =5.25s
# Cumulative duration =36min 2.150000000000091s
#
# 411
# Epoch duration =5.24s
# Cumulative duration =36min 7.380000000000109s
#
# 412
# Epoch duration =5.27s
# Cumulative duration =36min 12.650000000000091s
#
# 413
# Epoch duration =5.23s
# Cumulative duration =36min 17.88000000000011s
#
# 414
# Epoch duration =5.25s
# Cumulative duration =36min 23.13000000000011s
#
# 415
# Epoch duration =5.25s
# Cumulative duration =36min 28.389999999999873s
#
# 416
# Epoch duration =5.27s
# Cumulative duration =36min 33.65000000000009s
#
# 417
# Epoch duration =5.26s
# Cumulative duration =36min 38.909999999999854s
#
# 418
# Epoch duration =5.25s
# Cumulative duration =36min 44.159999999999854s
#
# 419
# Epoch duration =5.26s
# Cumulative duration =36min 49.42000000000007s
#
# 420
# Epoch duration =5.24s
# Cumulative duration =36min 54.67000000000007s
#
# 421
# Epoch duration =5.23s
# Cumulative duration =36min 59.88999999999987s
#
# 422
# Epoch duration =5.25s
# Cumulative duration =37min 5.139999999999873s
#
# 423
# Epoch duration =5.29s
# Cumulative duration =37min 10.429999999999836s
#
# 424
# Epoch duration =5.26s
# Cumulative duration =37min 15.690000000000055s
#
# 425
# Epoch duration =5.23s
# Cumulative duration =37min 20.920000000000073s
#
# 426
# Epoch duration =5.28s
# Cumulative duration =37min 26.199999999999818s
#
# 427
# Epoch duration =5.27s
# Cumulative duration =37min 31.4699999999998s
#
# 428
# Epoch duration =5.28s
# Cumulative duration =37min 36.75s
#
# 429
# Epoch duration =5.26s
# Cumulative duration =37min 42.01000000000022s
#
# 430
# Epoch duration =5.28s
# Cumulative duration =37min 47.2800000000002s
#
# 431
# Epoch duration =5.26s
# Cumulative duration =37min 52.539999999999964s
#
# 432
# Epoch duration =5.29s
# Cumulative duration =37min 57.82999999999993s
#
# 433
# Epoch duration =5.25s
# Cumulative duration =38min 3.0799999999999272s
#
# 434
# Epoch duration =5.29s
# Cumulative duration =38min 8.36999999999989s
#
# 435
# Epoch duration =5.24s
# Cumulative duration =38min 13.610000000000127s
#
# 436
# Epoch duration =5.25s
# Cumulative duration =38min 18.86999999999989s
#
# 437
# Epoch duration =5.25s
# Cumulative duration =38min 24.11999999999989s
#
# 438
# Epoch duration =5.27s
# Cumulative duration =38min 29.389999999999873s
#
# 439
# Epoch duration =5.28s
# Cumulative duration =38min 34.67000000000007s
#
# 440
# Epoch duration =5.26s
# Cumulative duration =38min 39.929999999999836s
#
# 441
# Epoch duration =5.25s
# Cumulative duration =38min 45.190000000000055s
#
# 442
# Epoch duration =5.29s
# Cumulative duration =38min 50.48000000000002s
#
# 443
# Epoch duration =5.24s
# Cumulative duration =38min 55.7199999999998s
#
# 444
# Epoch duration =5.27s
# Cumulative duration =39min 0.9800000000000182s
#
# 445
# Epoch duration =5.23s
# Cumulative duration =39min 6.210000000000036s
#
# 446
# Epoch duration =5.27s
# Cumulative duration =39min 11.480000000000018s
#
# 447
# Epoch duration =5.26s
# Cumulative duration =39min 16.73999999999978s
#
# 448
# Epoch duration =5.27s
# Cumulative duration =39min 22.01000000000022s
#
# 449
# Epoch duration =5.27s
# Cumulative duration =39min 27.2800000000002s
#
# 450
# Epoch duration =5.25s
# Cumulative duration =39min 32.5300000000002s
#
# 451
# Epoch duration =5.24s
# Cumulative duration =39min 37.7800000000002s
#
# 452
# Epoch duration =5.27s
# Cumulative duration =39min 43.039999999999964s
#
# 453
# Epoch duration =5.26s
# Cumulative duration =39min 48.309999999999945s
#
# 454
# Epoch duration =5.25s
# Cumulative duration =39min 53.559999999999945s
#
# 455
# Epoch duration =5.24s
# Cumulative duration =39min 58.80000000000018s
#
# 456
# Epoch duration =5.25s
# Cumulative duration =40min 4.050000000000182s
#
# 457
# Epoch duration =5.23s
# Cumulative duration =40min 9.2800000000002s
#
# 458
# Epoch duration =5.26s
# Cumulative duration =40min 14.539999999999964s
#
# 459
# Epoch duration =5.27s
# Cumulative duration =40min 19.809999999999945s
#
# 460
# Epoch duration =5.27s
# Cumulative duration =40min 25.079999999999927s
#
# 461
# Epoch duration =5.26s
# Cumulative duration =40min 30.340000000000146s
#
# 462
# Epoch duration =5.28s
# Cumulative duration =40min 35.61999999999989s
#
# 463
# Epoch duration =5.3s
# Cumulative duration =40min 40.92000000000007s
#
# 464
# Epoch duration =5.26s
# Cumulative duration =40min 46.179999999999836s
#
# 465
# Epoch duration =5.26s
# Cumulative duration =40min 51.44999999999982s
#
# 466
# Epoch duration =5.28s
# Cumulative duration =40min 56.7199999999998s
#
# 467
# Epoch duration =5.26s
# Cumulative duration =41min 1.9800000000000182s
#
# 468
# Epoch duration =5.26s
# Cumulative duration =41min 7.25s
#
# 469
# Epoch duration =5.3s
# Cumulative duration =41min 12.550000000000182s
#
# 470
# Epoch duration =5.26s
# Cumulative duration =41min 17.800000000000182s
#
# 471
# Epoch duration =5.32s
# Cumulative duration =41min 23.11999999999989s
#
# 472
# Epoch duration =5.27s
# Cumulative duration =41min 28.389999999999873s
#
# 473
# Epoch duration =5.27s
# Cumulative duration =41min 33.65000000000009s
#
# 474
# Epoch duration =5.25s
# Cumulative duration =41min 38.90000000000009s
#
# 475
# Epoch duration =5.26s
# Cumulative duration =41min 44.17000000000007s
#
# 476
# Epoch duration =5.25s
# Cumulative duration =41min 49.42000000000007s
#
# 477
# Epoch duration =5.28s
# Cumulative duration =41min 54.690000000000055s
#
# 478
# Epoch duration =5.26s
# Cumulative duration =41min 59.960000000000036s
#
# 479
# Epoch duration =5.26s
# Cumulative duration =42min 5.2199999999998s
#
# 480
# Epoch duration =5.25s
# Cumulative duration =42min 10.4699999999998s
#
# 481
# Epoch duration =5.28s
# Cumulative duration =42min 15.75s
#
# 482
# Epoch duration =5.28s
# Cumulative duration =42min 21.0300000000002s
#
# 483
# Epoch duration =5.25s
# Cumulative duration =42min 26.2800000000002s
#
# 484
# Epoch duration =5.28s
# Cumulative duration =42min 31.559999999999945s
#
# 485
# Epoch duration =5.25s
# Cumulative duration =42min 36.809999999999945s
#
# 486
# Epoch duration =5.25s
# Cumulative duration =42min 42.059999999999945s
#
# 487
# Epoch duration =5.28s
# Cumulative duration =42min 47.32999999999993s
#
# 488
# Epoch duration =5.27s
# Cumulative duration =42min 52.59999999999991s
#
# 489
# Epoch duration =5.28s
# Cumulative duration =42min 57.88000000000011s
#
# 490
# Epoch duration =5.26s
# Cumulative duration =43min 3.1399999999998727s
#
# 491
# Epoch duration =5.26s
# Cumulative duration =43min 8.400000000000091s
#
# 492
# Epoch duration =5.3s
# Cumulative duration =43min 13.699999999999818s
#
# 493
# Epoch duration =5.25s
# Cumulative duration =43min 18.949999999999818s
#
# 494
# Epoch duration =5.29s
# Cumulative duration =43min 24.23999999999978s
#
# 495
# Epoch duration =5.24s
# Cumulative duration =43min 29.48999999999978s
#
# 496
# Epoch duration =5.27s
# Cumulative duration =43min 34.76000000000022s
#
# 497
# Epoch duration =5.26s
# Cumulative duration =43min 40.01999999999998s
#
# 498
# Epoch duration =5.24s
# Cumulative duration =43min 45.26000000000022s
#
# 499
# Epoch duration =5.26s
# Cumulative duration =43min 50.51999999999998s
#
# 500
# Epoch duration =5.3s
# Cumulative duration =43min 55.809999999999945s
#
# 501
# Epoch duration =5.26s
# Cumulative duration =44min 1.0799999999999272s
#
# 502
# Epoch duration =5.27s
# Cumulative duration =44min 6.3400000000001455s
#
# 503
# Epoch duration =5.23s
# Cumulative duration =44min 11.570000000000164s
#
# 504
# Epoch duration =5.25s
# Cumulative duration =44min 16.820000000000164s
#
# 505
# Epoch duration =5.25s
# Cumulative duration =44min 22.070000000000164s
#
# 506
# Epoch duration =5.46s
# Cumulative duration =44min 27.5300000000002s
#
# 507
# Epoch duration =5.52s
# Cumulative duration =44min 33.05000000000018s
#
# 508
# Epoch duration =5.28s
# Cumulative duration =44min 38.340000000000146s
#
# 509
# Epoch duration =5.25s
# Cumulative duration =44min 43.590000000000146s
#
# 510
# Epoch duration =5.24s
# Cumulative duration =44min 48.820000000000164s
#
# 511
# Epoch duration =5.24s
# Cumulative duration =44min 54.059999999999945s
#
# 512
# Epoch duration =5.25s
# Cumulative duration =44min 59.309999999999945s
#
# 513
# Epoch duration =5.24s
# Cumulative duration =45min 4.559999999999945s
#
# 514
# Epoch duration =5.3s
# Cumulative duration =45min 9.860000000000127s
#
# 515
# Epoch duration =5.24s
# Cumulative duration =45min 15.090000000000146s
#
# 516
# Epoch duration =5.26s
# Cumulative duration =45min 20.360000000000127s
#
# 517
# Epoch duration =5.27s
# Cumulative duration =45min 25.61999999999989s
#
# 518
# Epoch duration =5.29s
# Cumulative duration =45min 30.909999999999854s
#
# 519
# Epoch duration =5.29s
# Cumulative duration =45min 36.19999999999982s
#
# 520
# Epoch duration =5.25s
# Cumulative duration =45min 41.44999999999982s
#
# 521
# Epoch duration =5.24s
# Cumulative duration =45min 46.679999999999836s
#
# 522
# Epoch duration =5.34s
# Cumulative duration =45min 52.01999999999998s
#
# 523
# Epoch duration =5.24s
# Cumulative duration =45min 57.26000000000022s
#
# 524
# Epoch duration =5.27s
# Cumulative duration =46min 2.5300000000002s
#
# 525
# Epoch duration =5.23s
# Cumulative duration =46min 7.760000000000218s
#
# 526
# Epoch duration =5.25s
# Cumulative duration =46min 13.010000000000218s
#
# 527
# Epoch duration =5.24s
# Cumulative duration =46min 18.25s
#
# 528
# Epoch duration =5.24s
# Cumulative duration =46min 23.48999999999978s
#
# 529
# Epoch duration =5.24s
# Cumulative duration =46min 28.730000000000018s
#
# 530
# Epoch duration =5.25s
# Cumulative duration =46min 33.98000000000002s
#
# 531
# Epoch duration =5.27s
# Cumulative duration =46min 39.25s
#
# 532
# Epoch duration =5.24s
# Cumulative duration =46min 44.48999999999978s
#
# 533
# Epoch duration =5.22s
# Cumulative duration =46min 49.710000000000036s
#
# 534
# Epoch duration =5.26s
# Cumulative duration =46min 54.9699999999998s
#
# 535
# Epoch duration =5.26s
# Cumulative duration =47min 0.2300000000000182s
#
# 536
# Epoch duration =5.25s
# Cumulative duration =47min 5.480000000000018s
#
# 537
# Epoch duration =5.26s
# Cumulative duration =47min 10.739999999999782s
#
# 538
# Epoch duration =5.24s
# Cumulative duration =47min 15.980000000000018s
#
# 539
# Epoch duration =5.27s
# Cumulative duration =47min 21.25s
#
# 540
# Epoch duration =5.24s
# Cumulative duration =47min 26.48999999999978s
#
# 541
# Epoch duration =5.23s
# Cumulative duration =47min 31.730000000000018s
#
# 542
# Epoch duration =5.25s
# Cumulative duration =47min 36.98000000000002s
#
# 543
# Epoch duration =5.29s
# Cumulative duration =47min 42.26000000000022s
#
# 544
# Epoch duration =5.27s
# Cumulative duration =47min 47.5300000000002s
#
# 545
# Epoch duration =5.23s
# Cumulative duration =47min 52.76000000000022s
#
# 546
# Epoch duration =5.24s
# Cumulative duration =47min 58.0s
#
# 547
# Epoch duration =5.23s
# Cumulative duration =48min 3.2399999999997817s
#
# 548
# Epoch duration =5.23s
# Cumulative duration =48min 8.4699999999998s
#
# 549
# Epoch duration =5.3s
# Cumulative duration =48min 13.769999999999982s
#
# 550
# Epoch duration =5.27s
# Cumulative duration =48min 19.0300000000002s
#
# 551
# Epoch duration =5.23s
# Cumulative duration =48min 24.269999999999982s
#
# 552
# Epoch duration =5.27s
# Cumulative duration =48min 29.5300000000002s
#
# 553
# Epoch duration =5.23s
# Cumulative duration =48min 34.76000000000022s
#
# 554
# Epoch duration =5.28s
# Cumulative duration =48min 40.039999999999964s
#
# 555
# Epoch duration =5.23s
# Cumulative duration =48min 45.26999999999998s
#
# 556
# Epoch duration =5.26s
# Cumulative duration =48min 50.5300000000002s
#
# 557
# Epoch duration =5.25s
# Cumulative duration =48min 55.76999999999998s
#
# 558
# Epoch duration =5.25s
# Cumulative duration =49min 1.0300000000002s
#
# 559
# Epoch duration =5.23s
# Cumulative duration =49min 6.260000000000218s
#
# 560
# Epoch duration =5.28s
# Cumulative duration =49min 11.5300000000002s
#
# 561
# Epoch duration =5.23s
# Cumulative duration =49min 16.76000000000022s
#
# 562
# Epoch duration =5.24s
# Cumulative duration =49min 22.01000000000022s
#
# 563
# Epoch duration =5.24s
# Cumulative duration =49min 27.25s
#
# 564
# Epoch duration =5.24s
# Cumulative duration =49min 32.48000000000002s
#
# 565
# Epoch duration =5.27s
# Cumulative duration =49min 37.76000000000022s
#
# 566
# Epoch duration =5.25s
# Cumulative duration =49min 43.0s
#
# 567
# Epoch duration =5.26s
# Cumulative duration =49min 48.26000000000022s
#
# 568
# Epoch duration =5.27s
# Cumulative duration =49min 53.539999999999964s
#
# 569
# Epoch duration =5.22s
# Cumulative duration =49min 58.76000000000022s
#
# 570
# Epoch duration =5.24s
# Cumulative duration =50min 4.0s
#
# 571
# Epoch duration =5.24s
# Cumulative duration =50min 9.239999999999782s
#
# 572
# Epoch duration =5.24s
# Cumulative duration =50min 14.489999999999782s
#
# 573
# Epoch duration =5.22s
# Cumulative duration =50min 19.710000000000036s
#
# 574
# Epoch duration =5.24s
# Cumulative duration =50min 24.960000000000036s
#
# 575
# Epoch duration =5.27s
# Cumulative duration =50min 30.230000000000018s
#
# 576
# Epoch duration =5.26s
# Cumulative duration =50min 35.48999999999978s
#
# 577
# Epoch duration =5.25s
# Cumulative duration =50min 40.73999999999978s
#
# 578
# Epoch duration =5.21s
# Cumulative duration =50min 45.94999999999982s
#
# 579
# Epoch duration =5.23s
# Cumulative duration =50min 51.179999999999836s
#
# 580
# Epoch duration =5.31s
# Cumulative duration =50min 56.5s
#
# 581
# Epoch duration =5.23s
# Cumulative duration =51min 1.7300000000000182s
#
# 582
# Epoch duration =5.23s
# Cumulative duration =51min 6.960000000000036s
#
# 583
# Epoch duration =5.26s
# Cumulative duration =51min 12.230000000000018s
#
# 584
# Epoch duration =5.24s
# Cumulative duration =51min 17.4699999999998s
#
# 585
# Epoch duration =5.22s
# Cumulative duration =51min 22.690000000000055s
#
# 586
# Epoch duration =5.25s
# Cumulative duration =51min 27.940000000000055s
#
# 587
# Epoch duration =5.25s
# Cumulative duration =51min 33.19999999999982s
#
# 588
# Epoch duration =5.24s
# Cumulative duration =51min 38.429999999999836s
#
# 589
# Epoch duration =5.25s
# Cumulative duration =51min 43.690000000000055s
#
# 590
# Epoch duration =5.24s
# Cumulative duration =51min 48.929999999999836s
#
# 591
# Epoch duration =5.23s
# Cumulative duration =51min 54.159999999999854s
#
# 592
# Epoch duration =5.25s
# Cumulative duration =51min 59.409999999999854s
#
# 593
# Epoch duration =5.23s
# Cumulative duration =52min 4.639999999999873s
#
# 594
# Epoch duration =5.27s
# Cumulative duration =52min 9.909999999999854s
#
# 595
# Epoch duration =5.26s
# Cumulative duration =52min 15.170000000000073s
#
# 596
# Epoch duration =5.24s
# Cumulative duration =52min 20.409999999999854s
#
# 597
# Epoch duration =5.26s
# Cumulative duration =52min 25.659999999999854s
#
# 598
# Epoch duration =5.24s
# Cumulative duration =52min 30.909999999999854s
#
# 599
# Epoch duration =5.21s
# Cumulative duration =52min 36.11999999999989s
#
# 600
# Epoch duration =5.23s
# Cumulative duration =52min 41.34999999999991s
#
# 601
# Epoch duration =5.22s
# Cumulative duration =52min 46.570000000000164s
#
# 602
# Epoch duration =5.25s
# Cumulative duration =52min 51.82999999999993s
#
# 603
# Epoch duration =5.23s
# Cumulative duration =52min 57.05000000000018s
#
# 604
# Epoch duration =5.24s
# Cumulative duration =53min 2.300000000000182s
#
# 605
# Epoch duration =5.25s
# Cumulative duration =53min 7.550000000000182s
#
# 606
# Epoch duration =5.26s
# Cumulative duration =53min 12.809999999999945s
#
# 607
# Epoch duration =5.22s
# Cumulative duration =53min 18.039999999999964s
#
# 608
# Epoch duration =5.28s
# Cumulative duration =53min 23.320000000000164s
#
# 609
# Epoch duration =5.22s
# Cumulative duration =53min 28.550000000000182s
#
# 610
# Epoch duration =5.25s
# Cumulative duration =53min 33.789999999999964s
#
# 611
# Epoch duration =5.25s
# Cumulative duration =53min 39.039999999999964s
#
# 612
# Epoch duration =5.24s
# Cumulative duration =53min 44.2800000000002s
#
# 613
# Epoch duration =5.24s
# Cumulative duration =53min 49.51999999999998s
#
# 614
# Epoch duration =5.25s
# Cumulative duration =53min 54.76999999999998s
#
# 615
# Epoch duration =5.25s
# Cumulative duration =54min 0.01999999999998181s
#
# 616
# Epoch duration =5.25s
# Cumulative duration =54min 5.269999999999982s
#
# 617
# Epoch duration =5.27s
# Cumulative duration =54min 10.539999999999964s
#
# 618
# Epoch duration =5.25s
# Cumulative duration =54min 15.800000000000182s
#
# 619
# Epoch duration =5.23s
# Cumulative duration =54min 21.0300000000002s
#
# 620
# Epoch duration =5.24s
# Cumulative duration =54min 26.2800000000002s
#
# 621
# Epoch duration =5.23s
# Cumulative duration =54min 31.5s
#
# 622
# Epoch duration =5.23s
# Cumulative duration =54min 36.73000000000002s
#
# 623
# Epoch duration =5.23s
# Cumulative duration =54min 41.960000000000036s
#
# 624
# Epoch duration =5.24s
# Cumulative duration =54min 47.19999999999982s
#
# 625
# Epoch duration =5.25s
# Cumulative duration =54min 52.460000000000036s
#
# 626
# Epoch duration =5.22s
# Cumulative duration =54min 57.679999999999836s
#
# 627
# Epoch duration =5.22s
# Cumulative duration =55min 2.900000000000091s
#
# 628
# Epoch duration =5.22s
# Cumulative duration =55min 8.11999999999989s
#
# 629
# Epoch duration =5.27s
# Cumulative duration =55min 13.400000000000091s
#
# 630
# Epoch duration =5.27s
# Cumulative duration =55min 18.670000000000073s
#
# 631
# Epoch duration =5.24s
# Cumulative duration =55min 23.909999999999854s
#
# 632
# Epoch duration =5.24s
# Cumulative duration =55min 29.15000000000009s
#
# 633
# Epoch duration =5.24s
# Cumulative duration =55min 34.38999999999987s
#
# 634
# Epoch duration =5.25s
# Cumulative duration =55min 39.65000000000009s
#
# 635
# Epoch duration =5.24s
# Cumulative duration =55min 44.88000000000011s
#
# 636
# Epoch duration =5.25s
# Cumulative duration =55min 50.13999999999987s
#
# 637
# Epoch duration =5.24s
# Cumulative duration =55min 55.36999999999989s
#
# 638
# Epoch duration =5.29s
# Cumulative duration =56min 0.6700000000000728s
#
# 639
# Epoch duration =5.27s
# Cumulative duration =56min 5.929999999999836s
#
# 640
# Epoch duration =5.26s
# Cumulative duration =56min 11.190000000000055s
#
# 641
# Epoch duration =5.21s
# Cumulative duration =56min 16.40000000000009s
#
# 642
# Epoch duration =5.24s
# Cumulative duration =56min 21.639999999999873s
#
# 643
# Epoch duration =5.26s
# Cumulative duration =56min 26.90000000000009s
#
# 644
# Epoch duration =5.24s
# Cumulative duration =56min 32.13999999999987s
#
# 645
# Epoch duration =5.23s
# Cumulative duration =56min 37.36999999999989s
#
# 646
# Epoch duration =5.24s
# Cumulative duration =56min 42.61000000000013s
#
# 647
# Epoch duration =5.24s
# Cumulative duration =56min 47.84999999999991s
#
# 648
# Epoch duration =5.23s
# Cumulative duration =56min 53.07999999999993s
#
# 649
# Epoch duration =5.24s
# Cumulative duration =56min 58.32999999999993s
#
# 650
# Epoch duration =5.27s
# Cumulative duration =57min 3.599999999999909s
#
# 651
# Epoch duration =5.23s
# Cumulative duration =57min 8.829999999999927s
#
# 652
# Epoch duration =5.25s
# Cumulative duration =57min 14.090000000000146s
#
# 653
# Epoch duration =5.23s
# Cumulative duration =57min 19.309999999999945s
#
# 654
# Epoch duration =5.23s
# Cumulative duration =57min 24.550000000000182s
#
# 655
# Epoch duration =5.26s
# Cumulative duration =57min 29.809999999999945s
#
# 656
# Epoch duration =5.25s
# Cumulative duration =57min 35.059999999999945s
#
# 657
# Epoch duration =5.24s
# Cumulative duration =57min 40.30000000000018s
#
# 658
# Epoch duration =5.23s
# Cumulative duration =57min 45.5300000000002s
#
# 659
# Epoch duration =5.27s
# Cumulative duration =57min 50.789999999999964s
#
# 660
# Epoch duration =5.24s
# Cumulative duration =57min 56.039999999999964s
#
# 661
# Epoch duration =5.23s
# Cumulative duration =58min 1.2600000000002183s
#
# 662
# Epoch duration =5.25s
# Cumulative duration =58min 6.519999999999982s
#
# 663
# Epoch duration =5.23s
# Cumulative duration =58min 11.75s
#
# 664
# Epoch duration =5.27s
# Cumulative duration =58min 17.019999999999982s
#
# 665
# Epoch duration =5.23s
# Cumulative duration =58min 22.25s
#
# 666
# Epoch duration =5.25s
# ...
#
# 793
# Epoch duration =5.27s
# Cumulative duration =1hr 9min 34.07999999999993s
#
# 794
# Epoch duration =5.24s
# Cumulative duration =1hr 9min 39.31999999999971s
#
# 795
# Epoch duration =5.24s
# Cumulative duration =1hr 9min 44.5600000000004s
#
# 796
# Epoch duration =5.29s
# Cumulative duration =1hr 9min 49.850000000000364s
#
# 797
# Epoch duration =5.23s
# Cumulative duration =1hr 9min 55.07999999999993s
#
# 798
# Epoch duration =5.26s
# Cumulative duration =1hr 10min 0.3400000000001455s
#
# 799
# Epoch duration =5.24s
# Cumulative duration =1hr 10min 5.579999999999927s
#
# 800
# Epoch duration =5.25s
# Cumulative duration =1hr 10min 10.829999999999927s
#
# 801
# Epoch duration =5.22s
# Cumulative duration =1hr 10min 16.050000000000182s
#
# 802
# Epoch duration =5.24s
# Cumulative duration =1hr 10min 21.289999999999964s
#
# 803
# Epoch duration =5.27s
# Cumulative duration =1hr 10min 26.5600000000004s
#
# 804
# Epoch duration =5.24s
# Cumulative duration =1hr 10min 31.800000000000182s
#
# 805
# Epoch duration =5.24s
# Cumulative duration =1hr 10min 37.039999999999964s
#
# 806
# Epoch duration =5.23s
# Cumulative duration =1hr 10min 42.27000000000044s
#
# 807
# Epoch duration =5.22s
# Cumulative duration =1hr 10min 47.48999999999978s
#
# 808
# Epoch duration =5.26s
# Cumulative duration =1hr 10min 52.75s
#
# 809
# Epoch duration =5.21s
# Cumulative duration =1hr 10min 57.960000000000036s
#
# 810
# Epoch duration =5.24s
# Cumulative duration =1hr 11min 3.199999999999818s
#
# 811
# Epoch duration =5.24s
# Cumulative duration =1hr 11min 8.4399999999996s
#
# 812
# Epoch duration =5.25s
# Cumulative duration =1hr 11min 13.699999999999818s
#
# 813
# Epoch duration =5.23s
# Cumulative duration =1hr 11min 18.93000000000029s
#
# 814
# Epoch duration =5.24s
# Cumulative duration =1hr 11min 24.170000000000073s
#
# 815
# Epoch duration =5.22s
# Cumulative duration =1hr 11min 29.390000000000327s
#
# 816
# Epoch duration =5.24s
# Cumulative duration =1hr 11min 34.63000000000011s
#
# 817
# Epoch duration =5.23s
# Cumulative duration =1hr 11min 39.85999999999967s
#
# 818
# Epoch duration =5.25s
# Cumulative duration =1hr 11min 45.10999999999967s
#
# 819
# Epoch duration =5.25s
# Cumulative duration =1hr 11min 50.350000000000364s
#
# 820
# Epoch duration =5.25s
# Cumulative duration =1hr 11min 55.600000000000364s
#
# 821
# Epoch duration =5.23s
# Cumulative duration =1hr 12min 0.8299999999999272s
#
# 822
# Epoch duration =5.24s
# Cumulative duration =1hr 12min 6.079999999999927s
#
# 823
# Epoch duration =5.26s
# Cumulative duration =1hr 12min 11.329999999999927s
#
# 824
# Epoch duration =5.23s
# Cumulative duration =1hr 12min 16.56999999999971s
#
# 825
# Epoch duration =5.23s
# Cumulative duration =1hr 12min 21.789999999999964s
#
# 826
# Epoch duration =5.29s
# Cumulative duration =1hr 12min 27.079999999999927s
#
# 827
# Epoch duration =5.21s
# Cumulative duration =1hr 12min 32.289999999999964s
#
# 828
# Epoch duration =5.23s
# Cumulative duration =1hr 12min 37.52000000000044s
#
# 829
# Epoch duration =5.25s
# Cumulative duration =1hr 12min 42.77000000000044s
#
# 830
# Epoch duration =5.26s
# Cumulative duration =1hr 12min 48.029999999999745s
#
# 831
# Epoch duration =5.25s
# Cumulative duration =1hr 12min 53.279999999999745s
#
# 832
# Epoch duration =5.25s
# Cumulative duration =1hr 12min 58.529999999999745s
#
# 833
# Epoch duration =5.25s
# Cumulative duration =1hr 13min 3.7799999999997453s
#
# 834
# Epoch duration =5.24s
# Cumulative duration =1hr 13min 9.020000000000437s
#
# 835
# Epoch duration =5.27s
# Cumulative duration =1hr 13min 14.289999999999964s
#
# 836
# Epoch duration =5.23s
# Cumulative duration =1hr 13min 19.520000000000437s
#
# 837
# Epoch duration =5.22s
# Cumulative duration =1hr 13min 24.73999999999978s
#
# 838
# Epoch duration =5.25s
# Cumulative duration =1hr 13min 29.98999999999978s
#
# 839
# Epoch duration =5.25s
# Cumulative duration =1hr 13min 35.23999999999978s
#
# 840
# Epoch duration =5.25s
# Cumulative duration =1hr 13min 40.5s
#
# 841
# Epoch duration =5.22s
# Cumulative duration =1hr 13min 45.720000000000255s
#
# 842
# Epoch duration =5.28s
# Cumulative duration =1hr 13min 51.0s
#
# 843
# Epoch duration =5.26s
# Cumulative duration =1hr 13min 56.26000000000022s
#
# 844
# Epoch duration =5.24s
# Cumulative duration =1hr 14min 1.5s
#
# 845
# Epoch duration =5.24s
# Cumulative duration =1hr 14min 6.739999999999782s
#
# 846
# Epoch duration =5.26s
# Cumulative duration =1hr 14min 12.0s
#
# 847
# Epoch duration =5.27s
# Cumulative duration =1hr 14min 17.270000000000437s
#
# 848
# Epoch duration =5.24s
# Cumulative duration =1hr 14min 22.51000000000022s
#
# 849
# Epoch duration =5.24s
# Cumulative duration =1hr 14min 27.75s
#
# 850
# Epoch duration =5.23s
# Cumulative duration =1hr 14min 32.98999999999978s
#
# 851
# Epoch duration =5.23s
# Cumulative duration =1hr 14min 38.210000000000036s
#
# 852
# Epoch duration =5.24s
# Cumulative duration =1hr 14min 43.460000000000036s
#
# 853
# Epoch duration =5.25s
# Cumulative duration =1hr 14min 48.69999999999982s
#
# 854
# Epoch duration =5.24s
# Cumulative duration =1hr 14min 53.9399999999996s
#
# 855
# Epoch duration =5.22s
# Cumulative duration =1hr 14min 59.159999999999854s
#
# 856
# Epoch duration =5.24s
# Cumulative duration =1hr 15min 4.399999999999636s
#
# 857
# Epoch duration =5.23s
# Cumulative duration =1hr 15min 9.63000000000011s
#
# 858
# Epoch duration =5.24s
# Cumulative duration =1hr 15min 14.88000000000011s
#
# 859
# Epoch duration =5.27s
# Cumulative duration =1hr 15min 20.140000000000327s
#
# 860
# Epoch duration =5.26s
# Cumulative duration =1hr 15min 25.399999999999636s
#
# 861
# Epoch duration =5.23s
# Cumulative duration =1hr 15min 30.640000000000327s
#
# 862
# Epoch duration =5.24s
# Cumulative duration =1hr 15min 35.88000000000011s
#
# 863
# Epoch duration =5.25s
# Cumulative duration =1hr 15min 41.13000000000011s
#
# 864
# Epoch duration =5.29s
# Cumulative duration =1hr 15min 46.42000000000007s
#
# 865
# Epoch duration =5.24s
# Cumulative duration =1hr 15min 51.659999999999854s
#
# 866
# Epoch duration =5.33s
# Cumulative duration =1hr 15min 56.98999999999978s
#
# 867
# Epoch duration =5.25s
# Cumulative duration =1hr 16min 2.2399999999997817s
#
# 868
# Epoch duration =5.29s
# Cumulative duration =1hr 16min 7.529999999999745s
#
# 869
# Epoch duration =5.23s
# Cumulative duration =1hr 16min 12.760000000000218s
#
# 870
# Epoch duration =5.24s
# Cumulative duration =1hr 16min 18.01000000000022s
#
# 871
# Epoch duration =5.22s
# Cumulative duration =1hr 16min 23.229999999999563s
#
# 872
# Epoch duration =5.25s
# Cumulative duration =1hr 16min 28.479999999999563s
#
# 873
# Epoch duration =5.22s
# Cumulative duration =1hr 16min 33.69999999999982s
#
# 874
# Epoch duration =5.24s
# Cumulative duration =1hr 16min 38.9399999999996s
#
# 875
# Epoch duration =5.27s
# Cumulative duration =1hr 16min 44.210000000000036s
#
# 876
# Epoch duration =5.27s
# Cumulative duration =1hr 16min 49.47999999999956s
#
# 877
# Epoch duration =5.24s
# Cumulative duration =1hr 16min 54.720000000000255s
#
# 878
# Epoch duration =5.25s
# Cumulative duration =1hr 16min 59.970000000000255s
#
# 879
# Epoch duration =5.22s
# Cumulative duration =1hr 17min 5.199999999999818s
#
# 880
# Epoch duration =5.27s
# Cumulative duration =1hr 17min 10.460000000000036s
#
# 881
# Epoch duration =5.23s
# Cumulative duration =1hr 17min 15.6899999999996s
#
# 882
# Epoch duration =5.24s
# Cumulative duration =1hr 17min 20.9399999999996s
#
# 883
# Epoch duration =5.27s
# Cumulative duration =1hr 17min 26.210000000000036s
#
# 884
# Epoch duration =5.25s
# Cumulative duration =1hr 17min 31.449999999999818s
#
# 885
# Epoch duration =5.26s
# Cumulative duration =1hr 17min 36.710000000000036s
#
# 886
# Epoch duration =5.25s
# Cumulative duration =1hr 17min 41.960000000000036s
#
# 887
# Epoch duration =5.22s
# Cumulative duration =1hr 17min 47.18000000000029s
#
# 888
# Epoch duration =5.26s
# Cumulative duration =1hr 17min 52.4399999999996s
#
# 889
# Epoch duration =5.22s
# Cumulative duration =1hr 17min 57.659999999999854s
#
# 890
# Epoch duration =5.3s
# Cumulative duration =1hr 18min 2.9600000000000364s
#
# 891
# Epoch duration =5.28s
# Cumulative duration =1hr 18min 8.229999999999563s
#
# 892
# Epoch duration =5.24s
# Cumulative duration =1hr 18min 13.470000000000255s
#
# 893
# Epoch duration =5.26s
# Cumulative duration =1hr 18min 18.729999999999563s
#
# 894
# Epoch duration =5.26s
# Cumulative duration =1hr 18min 24.0s
#
# 895
# Epoch duration =5.27s
# Cumulative duration =1hr 18min 29.270000000000437s
#
# 896
# Epoch duration =5.26s
# Cumulative duration =1hr 18min 34.52000000000044s
#
# 897
# Epoch duration =5.24s
# Cumulative duration =1hr 18min 39.77000000000044s
#
# 898
# Epoch duration =5.27s
# Cumulative duration =1hr 18min 45.029999999999745s
#
# 899
# Epoch duration =5.23s
# Cumulative duration =1hr 18min 50.27000000000044s
#
# 900
# Epoch duration =5.27s
# Cumulative duration =1hr 18min 55.539999999999964s
#
# 901
# Epoch duration =5.25s
# Cumulative duration =1hr 19min 0.7799999999997453s
#
# 902
# Epoch duration =5.26s
# Cumulative duration =1hr 19min 6.039999999999964s
#
# 903
# Epoch duration =5.25s
# Cumulative duration =1hr 19min 11.289999999999964s
#
# 904
# Epoch duration =5.25s
# Cumulative duration =1hr 19min 16.539999999999964s
#
# 905
# Epoch duration =5.23s
# Cumulative duration =1hr 19min 21.770000000000437s
#
# 906
# Epoch duration =5.25s
# Cumulative duration =1hr 19min 27.020000000000437s
#
# 907
# Epoch duration =5.21s
# Cumulative duration =1hr 19min 32.22999999999956s
#
# 908
# Epoch duration =5.23s
# Cumulative duration =1hr 19min 37.460000000000036s
#
# 909
# Epoch duration =5.23s
# Cumulative duration =1hr 19min 42.6899999999996s
#
# 910
# Epoch duration =5.24s
# Cumulative duration =1hr 19min 47.9399999999996s
#
# 911
# Epoch duration =5.24s
# Cumulative duration =1hr 19min 53.17000000000007s
#
# 912
# Epoch duration =5.23s
# Cumulative duration =1hr 19min 58.409999999999854s
#
# 913
# Epoch duration =5.22s
# Cumulative duration =1hr 20min 3.630000000000109s
#
# 914
# Epoch duration =5.24s
# Cumulative duration =1hr 20min 8.86999999999989s
#
# 915
# Epoch duration =5.22s
# Cumulative duration =1hr 20min 14.090000000000146s
#
# 916
# Epoch duration =5.26s
# Cumulative duration =1hr 20min 19.350000000000364s
#
# 917
# Epoch duration =5.22s
# Cumulative duration =1hr 20min 24.579999999999927s
#
# 918
# Epoch duration =5.24s
# Cumulative duration =1hr 20min 29.81999999999971s
#
# 919
# Epoch duration =5.24s
# Cumulative duration =1hr 20min 35.0600000000004s
#
# 920
# Epoch duration =5.26s
# Cumulative duration =1hr 20min 40.31999999999971s
#
# 921
# Epoch duration =5.23s
# Cumulative duration =1hr 20min 45.55000000000018s
#
# 922
# Epoch duration =5.24s
# Cumulative duration =1hr 20min 50.80000000000018s
#
# 923
# Epoch duration =5.24s
# Cumulative duration =1hr 20min 56.039999999999964s
#
# 924
# Epoch duration =5.25s
# Cumulative duration =1hr 21min 1.2899999999999636s
#
# 925
# Epoch duration =5.28s
# Cumulative duration =1hr 21min 6.569999999999709s
#
# 926
# Epoch duration =5.27s
# Cumulative duration =1hr 21min 11.840000000000146s
#
# 927
# Epoch duration =5.21s
# Cumulative duration =1hr 21min 17.050000000000182s
#
# 928
# Epoch duration =5.24s
# Cumulative duration =1hr 21min 22.279999999999745s
#
# 929
# Epoch duration =5.23s
# Cumulative duration =1hr 21min 27.51000000000022s
#
# 930
# Epoch duration =5.24s
# Cumulative duration =1hr 21min 32.76000000000022s
#
# 931
# Epoch duration =5.24s
# Cumulative duration =1hr 21min 38.0s
#
# 932
# Epoch duration =5.23s
# Cumulative duration =1hr 21min 43.220000000000255s
#
# 933
# Epoch duration =5.23s
# Cumulative duration =1hr 21min 48.460000000000036s
#
# 934
# Epoch duration =5.26s
# Cumulative duration =1hr 21min 53.720000000000255s
#
# 935
# Epoch duration =5.22s
# Cumulative duration =1hr 21min 58.9399999999996s
#
# 936
# Epoch duration =5.28s
# Cumulative duration =1hr 22min 4.220000000000255s
#
# 937
# Epoch duration =5.22s
# Cumulative duration =1hr 22min 9.449999999999818s
#
# 938
# Epoch duration =5.25s
# Cumulative duration =1hr 22min 14.6899999999996s
#
# 939
# Epoch duration =5.22s
# Cumulative duration =1hr 22min 19.920000000000073s
#
# 940
# Epoch duration =5.23s
# Cumulative duration =1hr 22min 25.149999999999636s
#
# 941
# Epoch duration =5.23s
# Cumulative duration =1hr 22min 30.38000000000011s
#
# 942
# Epoch duration =5.21s
# Cumulative duration =1hr 22min 35.590000000000146s
#
# 943
# Epoch duration =5.24s
# Cumulative duration =1hr 22min 40.82999999999993s
#
# 944
# Epoch duration =5.25s
# Cumulative duration =1hr 22min 46.07999999999993s
#
# 945
# Epoch duration =5.22s
# Cumulative duration =1hr 22min 51.30000000000018s
#
# 946
# Epoch duration =5.27s
# Cumulative duration =1hr 22min 56.56999999999971s
#
# 947
# Epoch duration =5.24s
# Cumulative duration =1hr 23min 1.8100000000004002s
#
# 948
# Epoch duration =5.24s
# Cumulative duration =1hr 23min 7.050000000000182s
#
# 949
# Epoch duration =5.27s
# Cumulative duration =1hr 23min 12.319999999999709s
#
# 950
# Epoch duration =5.3s
# Cumulative duration =1hr 23min 17.61999999999989s
#
# 951
# Epoch duration =5.25s
# Cumulative duration =1hr 23min 22.859999999999673s
#
# 952
# Epoch duration =5.25s
# Cumulative duration =1hr 23min 28.11999999999989s
#
# 953
# Epoch duration =5.25s
# Cumulative duration =1hr 23min 33.36999999999989s
#
# 954
# Epoch duration =5.26s
# Cumulative duration =1hr 23min 38.63000000000011s
#
# 955
# Epoch duration =5.29s
# Cumulative duration =1hr 23min 43.93000000000029s
#
# 956
# Epoch duration =5.29s
# Cumulative duration =1hr 23min 49.220000000000255s
#
# 957
# Epoch duration =5.22s
# Cumulative duration =1hr 23min 54.4399999999996s
#
# 958
# Epoch duration =5.29s
# Cumulative duration =1hr 23min 59.720000000000255s
#
# 959
# Epoch duration =5.25s
# Cumulative duration =1hr 24min 4.979999999999563s
#
# 960
# Epoch duration =5.25s
# Cumulative duration =1hr 24min 10.229999999999563s
#
# 961
# Epoch duration =5.28s
# Cumulative duration =1hr 24min 15.510000000000218s
#
# 962
# Epoch duration =5.22s
# Cumulative duration =1hr 24min 20.729999999999563s
#
# 963
# Epoch duration =5.22s
# Cumulative duration =1hr 24min 25.949999999999818s
#
# 964
# Epoch duration =5.26s
# Cumulative duration =1hr 24min 31.210000000000036s
#
# 965
# Epoch duration =5.26s
# Cumulative duration =1hr 24min 36.470000000000255s
#
# 966
# Epoch duration =5.25s
# Cumulative duration =1hr 24min 41.720000000000255s
#
# 967
# Epoch duration =5.24s
# Cumulative duration =1hr 24min 46.960000000000036s
#
# 968
# Epoch duration =5.25s
# Cumulative duration =1hr 24min 52.210000000000036s
#
# 969
# Epoch duration =5.26s
# Cumulative duration =1hr 24min 57.460000000000036s
#
# 970
# Epoch duration =5.24s
# Cumulative duration =1hr 25min 2.699999999999818s
#
# 971
# Epoch duration =5.28s
# Cumulative duration =1hr 25min 7.979999999999563s
#
# 972
# Epoch duration =5.29s
# Cumulative duration =1hr 25min 13.270000000000437s
#
# 973
# Epoch duration =5.23s
# Cumulative duration =1hr 25min 18.5s
#
# 974
# Epoch duration =5.26s
# Cumulative duration =1hr 25min 23.76000000000022s
#
# 975
# Epoch duration =5.21s
# Cumulative duration =1hr 25min 28.979999999999563s
#
# 976
# Epoch duration =5.25s
# Cumulative duration =1hr 25min 34.22999999999956s
#
# 977
# Epoch duration =5.21s
# Cumulative duration =1hr 25min 39.4399999999996s
#
# 978
# Epoch duration =5.25s
# Cumulative duration =1hr 25min 44.6899999999996s
#
# 979
# Epoch duration =5.23s
# Cumulative duration =1hr 25min 49.92000000000007s
#
# 980
# Epoch duration =5.23s
# Cumulative duration =1hr 25min 55.149999999999636s
#
# 981
# Epoch duration =5.26s
# Cumulative duration =1hr 26min 0.4099999999998545s
#
# 982
# Epoch duration =5.24s
# Cumulative duration =1hr 26min 5.649999999999636s
#
# 983
# Epoch duration =5.23s
# Cumulative duration =1hr 26min 10.86999999999989s
#
# 984
# Epoch duration =5.24s
# Cumulative duration =1hr 26min 16.109999999999673s
#
# 985
# Epoch duration =5.25s
# Cumulative duration =1hr 26min 21.36999999999989s
#
# 986
# Epoch duration =5.24s
# Cumulative duration =1hr 26min 26.609999999999673s
#
# 987
# Epoch duration =5.27s
# Cumulative duration =1hr 26min 31.890000000000327s
#
# 988
# Epoch duration =5.26s
# Cumulative duration =1hr 26min 37.149999999999636s
#
# 989
# Epoch duration =5.24s
# Cumulative duration =1hr 26min 42.39000000000033s
#
# 990
# Epoch duration =5.28s
# Cumulative duration =1hr 26min 47.67000000000007s
#
# 991
# Epoch duration =5.22s
# Cumulative duration =1hr 26min 52.89000000000033s
#
# 992
# Epoch duration =5.26s
# Cumulative duration =1hr 26min 58.149999999999636s
#
# 993
# Epoch duration =5.27s
# Cumulative duration =1hr 27min 3.4099999999998545s
#
# 994
# Epoch duration =5.25s
# Cumulative duration =1hr 27min 8.659999999999854s
#
# 995
# Epoch duration =5.25s
# Cumulative duration =1hr 27min 13.909999999999854s
#
# 996
# Epoch duration =5.23s
# Cumulative duration =1hr 27min 19.149999999999636s
#
# 997
# Epoch duration =5.24s
# Cumulative duration =1hr 27min 24.390000000000327s
#
# 998
# Epoch duration =5.28s
# Cumulative duration =1hr 27min 29.659999999999854s
#
# 999
# Epoch duration =5.27s
# Cumulative duration =1hr 27min 34.9399999999996s
#
# Saving scores to Arrays/riboswitch_resbindt4_ug_so1k.npy

# %%
#load values
savepath = 'Arrays/riboswitch_resbindt4_ug_so1k.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 1000
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

def normalize_mut_hol(hol_mut, WTmean, nntrainer, sess, normfactor=None):
    norm_hol_mut = np.copy(hol_mut) - WTmean
    for one in range(hol_mut.shape[0]):
        for two in range(hol_mut.shape[0]):
            norm_hol_mut[one, two] = mf.normalize_hol(hol_mut[one, two], factor=normfactor)
    return norm_hol_mut

norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the ungapped consensus regions given by infernal')
plt.xlabel('Ungapped nucleotides: pos 1')
plt.ylabel('Ungapped nucleotides: pos 2')
plt.subplot(1,2,2)
sb.heatmap(C[bpugidx][:, bpugidx], xticklabels=bpSS, yticklabels=bpSS, vmin=None, cmap='Reds', linewidth=0.0)
plt.title('Base Pair score for the base paired consensus regions given by infernal')
plt.xlabel('Base Paired nucleotides: pos 1')
plt.ylabel('Base Paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>
