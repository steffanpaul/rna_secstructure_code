# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/riboswitch_100k_t2.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 14.9s

# %%
simalign_file = '../../../data_RFAM/riboswitch_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)
numug = len(ugidx)

bpSS
# Out:
# '(((((<<<<<<>>>>>><<<<<<<<<>>>>>>>>>)))))<<<<>>>>'

# %%
ugSS
# Out:
# ':::::(((((,,,,<-<<<<<____>>>>>><<<--<<<<<<______>>>->>>->>>,,,,,)))))-<<<<____>>>>::::::::::::::::'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/riboswitch'
param_path = os.path.join(save_path, 'resbind_t2')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 816, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=15.36s -- loss=0.01104 -- acc=99.77167%
#
#   valid loss:		0.00697
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=14.56s -- loss=0.00716 -- acc=99.90667%
#
#   valid loss:		0.00689
#   valid accuracy:	0.99910+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=14.10s -- loss=0.00649 -- acc=99.91250%
#
#   valid loss:		0.00542
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=14.06s -- loss=0.00607 -- acc=99.92250%
#
#   valid loss:		0.00604
#   valid accuracy:	0.99915+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=14.59s -- loss=0.00645 -- acc=99.92250%
#
#   valid loss:		0.00697
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=14.39s -- loss=0.00663 -- acc=99.93250%
#
#   valid loss:		0.00640
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=14.93s -- loss=0.00707 -- acc=99.93000%
#
#   valid loss:		0.00715
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=14.85s -- loss=0.00696 -- acc=99.94167%
#
#   valid loss:		0.00780
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=15.52s -- loss=0.00729 -- acc=99.93250%
#
#   valid loss:		0.00792
#   valid accuracy:	0.99925+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=13.26s -- loss=0.00791 -- acc=99.93083%
#
#   valid loss:		0.00724
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=13.34s -- loss=0.00701 -- acc=99.95333%
#
#   valid loss:		0.00771
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=13.18s -- loss=0.00629 -- acc=99.96583%
#
#   valid loss:		0.00714
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=13.16s -- loss=0.00697 -- acc=99.94417%
#
#   valid loss:		0.00747
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=13.41s -- loss=0.00691 -- acc=99.94667%
#
#   valid loss:		0.00669
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=13.22s -- loss=0.00595 -- acc=99.96500%
#
#   valid loss:		0.00686
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=13.18s -- loss=0.00640 -- acc=99.95333%
#
#   valid loss:		0.00756
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=13.19s -- loss=0.00591 -- acc=99.96833%
#
#   valid loss:		0.00611
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=13.28s -- loss=0.00565 -- acc=99.96583%
#
#   valid loss:		0.00624
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=13.22s -- loss=0.00537 -- acc=99.96833%
#
#   valid loss:		0.00573
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=13.27s -- loss=0.00538 -- acc=99.96500%
#
#   valid loss:		0.00614
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=13.25s -- loss=0.00532 -- acc=99.96500%
#
#   valid loss:		0.00680
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=13.47s -- loss=0.00509 -- acc=99.97083%
#
#   valid loss:		0.00536
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=13.84s -- loss=0.00485 -- acc=99.97167%
#
#   valid loss:		0.00592
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.00509 -- acc=99.96583%
#
#   valid loss:		0.00536
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=13.21s -- loss=0.00441 -- acc=99.97917%
#
#   valid loss:		0.00657
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=13.46s -- loss=0.00498 -- acc=99.96500%
#
#   valid loss:		0.00588
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=13.27s -- loss=0.00466 -- acc=99.97000%
#
#   valid loss:		0.00581
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=13.23s -- loss=0.00402 -- acc=99.98333%
#
#   valid loss:		0.00569
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=13.23s -- loss=0.00435 -- acc=99.97333%
#
#   valid loss:		0.00578
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=13.26s -- loss=0.00437 -- acc=99.97250%
#
#   valid loss:		0.00606
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=13.20s -- loss=0.00416 -- acc=99.97833%
#
#   valid loss:		0.00549
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=13.25s -- loss=0.00410 -- acc=99.97667%
#
#   valid loss:		0.00559
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=13.18s -- loss=0.00388 -- acc=99.97667%
#
#   valid loss:		0.00591
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=13.22s -- loss=0.00407 -- acc=99.97750%
#
#   valid loss:		0.00456
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00382 -- acc=99.98083%
#
#   valid loss:		0.00475
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=13.25s -- loss=0.00413 -- acc=99.96750%
#
#   valid loss:		0.00510
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=13.21s -- loss=0.00401 -- acc=99.97333%
#
#   valid loss:		0.00522
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=13.24s -- loss=0.00388 -- acc=99.97250%
#
#   valid loss:		0.00506
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=13.25s -- loss=0.00363 -- acc=99.98083%
#
#   valid loss:		0.00548
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.00414 -- acc=99.97083%
#
#   valid loss:		0.00472
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=13.51s -- loss=0.00347 -- acc=99.98000%
#
#   valid loss:		0.00526
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=13.29s -- loss=0.00326 -- acc=99.98417%
#
#   valid loss:		0.00593
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=13.24s -- loss=0.00365 -- acc=99.97583%
#
#   valid loss:		0.00522
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=13.27s -- loss=0.00364 -- acc=99.97083%
#
#   valid loss:		0.00530
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=13.21s -- loss=0.00386 -- acc=99.97083%
#
#   valid loss:		0.00528
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=13.26s -- loss=0.00353 -- acc=99.97500%
#
#   valid loss:		0.00520
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=13.30s -- loss=0.00336 -- acc=99.98417%
#
#   valid loss:		0.00504
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=13.32s -- loss=0.00331 -- acc=99.97500%
#
#   valid loss:		0.00526
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=13.28s -- loss=0.00362 -- acc=99.97083%
#
#   valid loss:		0.00527
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=13.21s -- loss=0.00323 -- acc=99.98167%
#
#   valid loss:		0.00436
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=13.65s -- loss=0.00325 -- acc=99.98000%
#
#   valid loss:		0.00543
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=13.28s -- loss=0.00318 -- acc=99.98583%
#
#   valid loss:		0.00496
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=13.31s -- loss=0.00335 -- acc=99.97500%
#
#   valid loss:		0.00509
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.00383 -- acc=99.97083%
#
#   valid loss:		0.00445
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=12.97s -- loss=0.00334 -- acc=99.98167%
#
#   valid loss:		0.00513
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=13.20s -- loss=0.00302 -- acc=99.98417%
#
#   valid loss:		0.00534
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=13.22s -- loss=0.00319 -- acc=99.98333%
#
#   valid loss:		0.00431
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=13.98s -- loss=0.00316 -- acc=99.97917%
#
#   valid loss:		0.00426
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=14.83s -- loss=0.00346 -- acc=99.96917%
#
#   valid loss:		0.00554
#   valid accuracy:	0.99930+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=14.94s -- loss=0.00320 -- acc=99.98000%
#
#   valid loss:		0.00552
#   valid accuracy:	0.99935+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=13.08s -- loss=0.00349 -- acc=99.97667%
#
#   valid loss:		0.00453
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=13.65s -- loss=0.00308 -- acc=99.97833%
#
#   valid loss:		0.00504
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=13.31s -- loss=0.00341 -- acc=99.97500%
#
#   valid loss:		0.00457
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=13.39s -- loss=0.00299 -- acc=99.98333%
#
#   valid loss:		0.00410
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=13.37s -- loss=0.00316 -- acc=99.97667%
#
#   valid loss:		0.00449
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=13.54s -- loss=0.00310 -- acc=99.98250%
#
#   valid loss:		0.00587
#   valid accuracy:	0.99940+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=13.26s -- loss=0.00339 -- acc=99.97083%
#
#   valid loss:		0.00397
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=13.31s -- loss=0.00333 -- acc=99.97333%
#
#   valid loss:		0.00395
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=13.32s -- loss=0.00313 -- acc=99.97917%
#
#   valid loss:		0.00471
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=13.36s -- loss=0.00319 -- acc=99.97667%
#
#   valid loss:		0.00450
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=13.35s -- loss=0.00273 -- acc=99.98667%
#
#   valid loss:		0.00423
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=13.35s -- loss=0.00288 -- acc=99.98167%
#
#   valid loss:		0.00384
#   valid accuracy:	0.99980+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=13.33s -- loss=0.00302 -- acc=99.98083%
#
#   valid loss:		0.00402
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=13.30s -- loss=0.00313 -- acc=99.97833%
#
#   valid loss:		0.00385
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=13.31s -- loss=0.00285 -- acc=99.97917%
#
#   valid loss:		0.00465
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=13.36s -- loss=0.00271 -- acc=99.99000%
#
#   valid loss:		0.00434
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=13.30s -- loss=0.00316 -- acc=99.97583%
#
#   valid loss:		0.00448
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=13.27s -- loss=0.00325 -- acc=99.97583%
#
#   valid loss:		0.00396
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=13.37s -- loss=0.00305 -- acc=99.98083%
#
#   valid loss:		0.00445
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=13.32s -- loss=0.00285 -- acc=99.98333%
#
#   valid loss:		0.00434
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=13.32s -- loss=0.00313 -- acc=99.97583%
#
#   valid loss:		0.00435
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=13.29s -- loss=0.00282 -- acc=99.98250%
#
#   valid loss:		0.00407
#   valid accuracy:	0.99975+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=13.46s -- loss=0.00323 -- acc=99.97250%
#
#   valid loss:		0.00482
#   valid accuracy:	0.99950+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=13.38s -- loss=0.00314 -- acc=99.97750%
#
#   valid loss:		0.00452
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=13.38s -- loss=0.00282 -- acc=99.98250%
#
#   valid loss:		0.00408
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=13.32s -- loss=0.00320 -- acc=99.98000%
#
#   valid loss:		0.00413
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=13.31s -- loss=0.00320 -- acc=99.97583%
#
#   valid loss:		0.00439
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=13.30s -- loss=0.00307 -- acc=99.97667%
#
#   valid loss:		0.00395
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=13.28s -- loss=0.00302 -- acc=99.98000%
#
#   valid loss:		0.00409
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=13.30s -- loss=0.00296 -- acc=99.97750%
#
#   valid loss:		0.00482
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=13.30s -- loss=0.00290 -- acc=99.97917%
#
#   valid loss:		0.00447
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=13.28s -- loss=0.00268 -- acc=99.98333%
#
#   valid loss:		0.00486
#   valid accuracy:	0.99960+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 93 out of 100
# [==============================] 100.0% -- elapsed time=13.33s -- loss=0.00311 -- acc=99.97583%
#
#   valid loss:		0.00492
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 94 out of 100
# [==============================] 100.0% -- elapsed time=13.31s -- loss=0.00278 -- acc=99.98583%
#
#   valid loss:		0.00463
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 95 out of 100
# [==============================] 100.0% -- elapsed time=13.33s -- loss=0.00314 -- acc=99.97583%
#
#   valid loss:		0.00585
#   valid accuracy:	0.99945+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 96 out of 100
# [==============================] 100.0% -- elapsed time=13.64s -- loss=0.00319 -- acc=99.97833%
#
#   valid loss:		0.00375
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t2_best.ckpt
# Epoch 97 out of 100
# [==============================] 100.0% -- elapsed time=14.45s -- loss=0.00319 -- acc=99.97583%
#
#   valid loss:		0.00448
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	0.99999+/-0.00000
#   valid auc-pr:		0.99999+/-0.00000
# Epoch 98 out of 100
# [==============================] 100.0% -- elapsed time=13.44s -- loss=0.00327 -- acc=99.97833%
#
#   valid loss:		0.00490
#   valid accuracy:	0.99965+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 99 out of 100
# [==============================] 100.0% -- elapsed time=13.34s -- loss=0.00301 -- acc=99.98000%
#
#   valid loss:		0.00424
#   valid accuracy:	0.99955+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000
# Epoch 100 out of 100
# [==============================] 100.0% -- elapsed time=13.91s -- loss=0.00298 -- acc=99.98083%
#
#   valid loss:		0.00467
#   valid accuracy:	0.99970+/-0.00000
#   valid auc-roc:	1.00000+/-0.00000
#   valid auc-pr:		1.00000+/-0.00000

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/riboswitch/resbind_t2_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/riboswitch/resbind_t2_best.ckpt
#   test  loss:		0.00450
#   test  accuracy:	0.99947+/-0.00000
#   test  auc-roc:	1.00000+/-0.00000
#   test  auc-pr:		1.00000+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

plt.figure()
plt.ylabel('Predicted score')
plt.xlabel('Sequences ordered by score')
plt.plot(range(len(plot_index)), predictionsoutput[plot_index])
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/riboswitch_resbindt2_ug_so100.npy'

num_summary = 100
Xdict = test['inputs'][plot_index[100:200]]

sum_mut2_100_200 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=False, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =5.26s
# Cumulative duration =5.26s
#
# 1
# Epoch duration =5.21s
# Cumulative duration =10.47s
#
# 2
# Epoch duration =5.42s
# Cumulative duration =15.89s
#
# 3
# Epoch duration =5.47s
# Cumulative duration =21.36s
#
# 4
# Epoch duration =5.49s
# Cumulative duration =26.85s
#
# 5
# Epoch duration =5.32s
# Cumulative duration =32.17s
#
# 6
# Epoch duration =5.25s
# Cumulative duration =37.42s
#
# 7
# Epoch duration =5.27s
# Cumulative duration =42.68s
#
# 8
# Epoch duration =5.24s
# Cumulative duration =47.92s
#
# 9
# Epoch duration =5.32s
# Cumulative duration =53.24s
#
# 10
# Epoch duration =5.28s
# Cumulative duration =58.53s
#
# 11
# Epoch duration =5.34s
# Cumulative duration =1min 3.8599999999999994s
#
# 12
# Epoch duration =5.53s
# Cumulative duration =1min 9.39s
#
# 13
# Epoch duration =5.27s
# Cumulative duration =1min 14.659999999999997s
#
# 14
# Epoch duration =5.28s
# Cumulative duration =1min 19.939999999999998s
#
# 15
# Epoch duration =5.28s
# Cumulative duration =1min 25.22s
#
# 16
# Epoch duration =5.29s
# Cumulative duration =1min 30.510000000000005s
#
# 17
# Epoch duration =5.28s
# Cumulative duration =1min 35.790000000000006s
#
# 18
# Epoch duration =5.27s
# Cumulative duration =1min 41.06s
#
# 19
# Epoch duration =5.26s
# Cumulative duration =1min 46.31999999999999s
#
# 20
# Epoch duration =5.27s
# Cumulative duration =1min 51.59s
#
# 21
# Epoch duration =5.3s
# Cumulative duration =1min 56.89s
#
# 22
# Epoch duration =5.29s
# Cumulative duration =2min 2.180000000000007s
#
# 23
# Epoch duration =5.55s
# Cumulative duration =2min 7.730000000000004s
#
# 24
# Epoch duration =5.26s
# Cumulative duration =2min 12.990000000000009s
#
# 25
# Epoch duration =5.22s
# Cumulative duration =2min 18.210000000000008s
#
# 26
# Epoch duration =5.55s
# Cumulative duration =2min 23.75999999999999s
#
# 27
# Epoch duration =5.23s
# Cumulative duration =2min 28.99000000000001s
#
# 28
# Epoch duration =5.21s
# Cumulative duration =2min 34.19999999999999s
#
# 29
# Epoch duration =5.21s
# Cumulative duration =2min 39.41999999999999s
#
# 30
# Epoch duration =5.24s
# Cumulative duration =2min 44.66s
#
# 31
# Epoch duration =5.22s
# Cumulative duration =2min 49.879999999999995s
#
# 32
# Epoch duration =5.78s
# Cumulative duration =2min 55.66s
#
# 33
# Epoch duration =5.31s
# Cumulative duration =3min 0.960000000000008s
#
# 34
# Epoch duration =5.25s
# Cumulative duration =3min 6.210000000000008s
#
# 35
# Epoch duration =5.21s
# Cumulative duration =3min 11.419999999999987s
#
# 36
# Epoch duration =5.27s
# Cumulative duration =3min 16.689999999999998s
#
# 37
# Epoch duration =5.29s
# Cumulative duration =3min 21.99000000000001s
#
# 38
# Epoch duration =5.25s
# Cumulative duration =3min 27.24000000000001s
#
# 39
# Epoch duration =5.3s
# Cumulative duration =3min 32.53999999999999s
#
# 40
# Epoch duration =5.28s
# Cumulative duration =3min 37.83000000000001s
#
# 41
# Epoch duration =5.28s
# Cumulative duration =3min 43.099999999999994s
#
# 42
# Epoch duration =5.28s
# Cumulative duration =3min 48.389999999999986s
#
# 43
# Epoch duration =5.26s
# Cumulative duration =3min 53.650000000000006s
#
# 44
# Epoch duration =5.28s
# Cumulative duration =3min 58.93000000000001s
#
# 45
# Epoch duration =5.29s
# Cumulative duration =4min 4.22999999999999s
#
# 46
# Epoch duration =5.27s
# Cumulative duration =4min 9.490000000000009s
#
# 47
# Epoch duration =5.3s
# Cumulative duration =4min 14.789999999999992s
#
# 48
# Epoch duration =5.28s
# Cumulative duration =4min 20.069999999999993s
#
# 49
# Epoch duration =5.28s
# Cumulative duration =4min 25.350000000000023s
#
# 50
# Epoch duration =5.32s
# Cumulative duration =4min 30.660000000000025s
#
# 51
# Epoch duration =5.28s
# Cumulative duration =4min 35.94999999999999s
#
# 52
# Epoch duration =5.29s
# Cumulative duration =4min 41.24000000000001s
#
# 53
# Epoch duration =5.29s
# Cumulative duration =4min 46.52999999999997s
#
# 54
# Epoch duration =5.27s
# Cumulative duration =4min 51.80000000000001s
#
# 55
# Epoch duration =5.29s
# Cumulative duration =4min 57.089999999999975s
#
# 56
# Epoch duration =5.31s
# Cumulative duration =5min 2.3999999999999773s
#
# 57
# Epoch duration =5.28s
# Cumulative duration =5min 7.680000000000007s
#
# 58
# Epoch duration =5.29s
# Cumulative duration =5min 12.970000000000027s
#
# 59
# Epoch duration =5.29s
# Cumulative duration =5min 18.25999999999999s
#
# 60
# Epoch duration =5.26s
# Cumulative duration =5min 23.519999999999982s
#
# 61
# Epoch duration =5.29s
# Cumulative duration =5min 28.80000000000001s
#
# 62
# Epoch duration =5.3s
# Cumulative duration =5min 34.10000000000002s
#
# 63
# Epoch duration =5.3s
# Cumulative duration =5min 39.39999999999998s
#
# 64
# Epoch duration =5.31s
# Cumulative duration =5min 44.70999999999998s
#
# 65
# Epoch duration =5.29s
# Cumulative duration =5min 50.0s
#
# 66
# Epoch duration =5.26s
# Cumulative duration =5min 55.25999999999999s
#
# 67
# Epoch duration =5.26s
# Cumulative duration =6min 0.5199999999999818s
#
# 68
# Epoch duration =5.3s
# Cumulative duration =6min 5.819999999999993s
#
# 69
# Epoch duration =5.3s
# Cumulative duration =6min 11.120000000000005s
#
# 70
# Epoch duration =5.28s
# Cumulative duration =6min 16.410000000000025s
#
# 71
# Epoch duration =5.28s
# Cumulative duration =6min 21.689999999999998s
#
# 72
# Epoch duration =5.32s
# Cumulative duration =6min 27.0s
#
# 73
# Epoch duration =5.31s
# Cumulative duration =6min 32.31s
#
# 74
# Epoch duration =5.29s
# Cumulative duration =6min 37.60000000000002s
#
# 75
# Epoch duration =5.35s
# Cumulative duration =6min 42.95999999999998s
#
# 76
# Epoch duration =5.3s
# Cumulative duration =6min 48.25s
#
# 77
# Epoch duration =5.31s
# Cumulative duration =6min 53.56999999999999s
#
# 78
# Epoch duration =5.28s
# Cumulative duration =6min 58.839999999999975s
#
# 79
# Epoch duration =5.28s
# Cumulative duration =7min 4.1200000000000045s
#
# 80
# Epoch duration =5.29s
# Cumulative duration =7min 9.410000000000025s
#
# 81
# Epoch duration =5.28s
# Cumulative duration =7min 14.689999999999998s
#
# 82
# Epoch duration =5.31s
# Cumulative duration =7min 20.0s
#
# 83
# Epoch duration =5.29s
# Cumulative duration =7min 25.29000000000002s
#
# 84
# Epoch duration =5.28s
# Cumulative duration =7min 30.569999999999993s
#
# 85
# Epoch duration =5.31s
# Cumulative duration =7min 35.879999999999995s
#
# 86
# Epoch duration =5.29s
# Cumulative duration =7min 41.170000000000016s
#
# 87
# Epoch duration =5.31s
# Cumulative duration =7min 46.48000000000002s
#
# 88
# Epoch duration =5.29s
# Cumulative duration =7min 51.76999999999998s
#
# 89
# Epoch duration =5.29s
# Cumulative duration =7min 57.06s
#
# 90
# Epoch duration =5.27s
# Cumulative duration =8min 2.329999999999984s
#
# 91
# Epoch duration =5.29s
# Cumulative duration =8min 7.6299999999999955s
#
# 92
# Epoch duration =5.31s
# Cumulative duration =8min 12.939999999999998s
#
# 93
# Epoch duration =5.29s
# Cumulative duration =8min 18.230000000000018s
#
# 94
# Epoch duration =5.29s
# Cumulative duration =8min 23.519999999999982s
#
# 95
# Epoch duration =5.3s
# Cumulative duration =8min 28.829999999999984s
#
# 96
# Epoch duration =5.32s
# Cumulative duration =8min 34.14999999999998s
#
# 97
# Epoch duration =5.33s
# Cumulative duration =8min 39.48000000000002s
#
# 98
# Epoch duration =5.24s
# Cumulative duration =8min 44.72000000000003s
#
# 99
# Epoch duration =5.26s
# Cumulative duration =8min 49.98000000000002s

# %%
#load values
savepath = 'Arrays/riboswitch_resbindt2_ug_so200.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 200
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

def normalize_mut_hol(hol_mut, WTmean, nntrainer, sess, normfactor=None):
    norm_hol_mut = np.copy(hol_mut) - WTmean
    for one in range(hol_mut.shape[0]):
        for two in range(hol_mut.shape[0]):
            norm_hol_mut[one, two] = mf.normalize_hol(hol_mut[one, two], factor=normfactor)
    return norm_hol_mut

norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(12,10))
sb.heatmap(C, xticklabels=bpugSQ, yticklabels=bpugSQ, vmin=0., cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base pair consensus regions given by infernal')
plt.xlabel('Base paired nucleotides: pos 1')
plt.ylabel('Base paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
bpugSQ = ['.' for i in range(len(ugidx))]
for i, ix in enumerate(ugidx):
    if ix in bpidx:
        bpugSQ[i] = SQ[ix]

# %%
bpugSQ
# Out:
# ['.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'g',
#  'C',
#  'A',
#  'U',
#  'c',
#  '.',
#  '.',
#  '.',
#  '.',
#  'G',
#  '.',
#  'g',
#  'G',
#  'g',
#  'c',
#  'c',
#  '.',
#  '.',
#  '.',
#  '.',
#  'g',
#  'g',
#  'c',
#  'C',
#  'c',
#  'C',
#  'g',
#  'c',
#  'C',
#  '.',
#  '.',
#  'C',
#  'C',
#  'u',
#  'g',
#  'g',
#  'c',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'g',
#  'c',
#  'c',
#  '.',
#  'a',
#  'G',
#  'G',
#  '.',
#  'G',
#  'g',
#  'c',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'g',
#  'A',
#  'U',
#  'G',
#  'c',
#  '.',
#  'g',
#  'c',
#  'c',
#  'g',
#  '.',
#  '.',
#  '.',
#  '.',
#  'c',
#  'g',
#  'g',
#  'c',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.']
