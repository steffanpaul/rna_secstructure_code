# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os, sys, h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
import tensorflow as tf
from deepomics import neuralnetwork as nn
from deepomics import utils, fit, visualize, saliency
import scipy

import sys
sys.path.append('../../../..')
import mutagenesisfunctions as mf
from Bio import AlignIO
import time as time
import pandas as pd

# %%
starttime = time.time()

#Open data from h5py

data_path = '../../../data_RFAM/riboswitch_100k_t1.hdf5'
with h5py.File(data_path, 'r') as dataset:
    X_data = np.array(dataset['X_data'])
    Y_data = np.array(dataset['Y_data'])
    
numdata, seqlen, _, dims = X_data.shape
dims = dims-1

#remove gaps from sequences
ungapped = True
if ungapped:
    X_data = X_data[:, :, :, :dims]
    
# get validation and test set from training set
test_frac = 0.3
valid_frac = 0.1
N = numdata
split_1 = int(N*(1-valid_frac-test_frac))
split_2 = int(N*(1-test_frac))
shuffle = np.random.permutation(N)

#set up dictionaries
train = {'inputs': X_data[shuffle[:split_1]], 
         'targets': Y_data[shuffle[:split_1]]}
valid = {'inputs': X_data[shuffle[split_1:split_2]], 
         'targets': Y_data[shuffle[split_1:split_2]]}
test = {'inputs': X_data[shuffle[split_2:]], 
         'targets': Y_data[shuffle[split_2:]]}
    
print ('Data extraction and dict construction completed in: ' + mf.sectotime(time.time() - starttime))
# Out:
# Data extraction and dict construction completed in: 14.64s

# %%
simalign_file = '../../../data_RFAM/riboswitch_100k.sto'

#Get the full secondary structure and sequence consensus from the emission
SS = mf.getSSconsensus(simalign_file)
SQ = mf.getSQconsensus(simalign_file)

#Get the ungapped sequence and the indices of ungapped nucleotides
_, ugSS, ugidx = mf.rm_consensus_gaps(X_data, SS)
_, ugSQ, _ = mf.rm_consensus_gaps(X_data, SQ)


#Get the sequence and indices of the conserved base pairs
bpchars = ['(',')','<','>','{','}']
sig_bpchars = ['<','>']
bpidx, bpSS, nonbpidx = mf.sigbasepair(SS, bpchars)
numbp = len(bpidx)

bpSS
# Out:
# '(((((<<<<<<>>>>>><<<<<<<<<>>>>>>>>>)))))<<<<>>>>'

# %%
def cnn_model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input', #41
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d',
            'num_filters': 96,
            'filter_size': input_shape[1]-29,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.3,
            'padding': 'VALID',
            }
    layer3 = {'layer': 'conv1d_residual',
            'filter_size': 5,
            'function': 'relu',
            'dropout_block': 0.1,
            'dropout': 0.3,
            'mean_pool': 10,
            }
    
    layer4 = {'layer': 'dense',        # input, conv1d, dense, conv1d_residual, dense_residual, conv1d_transpose,
                                    # concat, embedding, variational_normal, variational_softmax, + more
          'num_units': 196,
          'norm': 'batch',          # if removed, automatically adds bias instead
          'activation': 'relu',     # or leaky_relu, prelu, sigmoid, tanh, etc
          'dropout': 0.5,           # if removed, default is no dropout
             }

    
    layer5 = {'layer': 'dense',
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    model_layers = [layer1, layer2, layer3, layer4, layer5]

    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.0003,
                  "l2": 1e-5,
                  #"label_smoothing": 0.05,
                  #"l1": 1e-6,
                  }
    return model_layers, optimization

tf.reset_default_graph()

# get shapes of inputs and targets
input_shape = list(train['inputs'].shape)
input_shape[0] = None
output_shape = train['targets'].shape

# load model parameters
model_layers, optimization = cnn_model(input_shape, output_shape)

# build neural network class
nnmodel = nn.NeuralNet(seed=247)
nnmodel.build_layers(model_layers, optimization)

# compile neural trainer
save_path = '../../../results/riboswitch'
param_path = os.path.join(save_path, 'resbind_t1')
nntrainer = nn.NeuralTrainer(nnmodel, save='best', file_path=param_path)

# look at the shapes of each layer
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 816, 1, 4)
# layer2: conv1d_0
# (?, 30, 1, 96)
# layer3: conv1d_0_batch
# (?, 30, 1, 96)
# layer4: conv1d_0_active
# (?, 30, 1, 96)
# layer5: conv1d_0_dropout
# (?, 30, 1, 96)
# layer6: conv1d_residual_0_1resid
# (?, 30, 1, 96)
# layer7: conv1d_residual_0_1resid_norm
# (?, 30, 1, 96)
# layer8: conv1d_residual_0_1resid_active
# (?, 30, 1, 96)
# layer9: conv1d_residual_0_dropout1
# (?, 30, 1, 96)
# layer10: conv1d_residual_0_2resid
# (?, 30, 1, 96)
# layer11: conv1d_residual_0_2resid_norm
# (?, 30, 1, 96)
# layer12: conv1d_residual_0_resid_sum
# (?, 30, 1, 96)
# layer13: conv1d_residual_0_resid
# (?, 30, 1, 96)
# layer14: conv1d_residual_0_meanpool
# (?, 3, 1, 96)
# layer15: conv1d_residual_0_dropout
# (?, 3, 1, 96)
# layer16: dense_0
# (?, 196)
# layer17: dense_0_batch
# (?, 196)
# layer18: dense_0_active
# (?, 196)
# layer19: dense_0_dropout
# (?, 196)
# layer20: dense_1
# (?, 1)
# layer21: dense_1_bias
# (?, 1)
# layer22: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
# initialize session
sess = utils.initialize_session()

# %%
#Train the model

data = {'train': train, 'valid': valid}
fit.train_minibatch(sess, nntrainer, data, 
                    batch_size=100, 
                    num_epochs=100,
                    patience=30, 
                    verbose=2, 
                    shuffle=True, 
                    save_all=False)
# Out:
# Epoch 1 out of 100
# [==============================] 100.0% -- elapsed time=14.48s -- loss=0.03646 -- acc=98.89750%
#
#   valid loss:		0.02026
#   valid accuracy:	0.99505+/-0.00000
#   valid auc-roc:	0.99982+/-0.00000
#   valid auc-pr:		0.99982+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 2 out of 100
# [==============================] 100.0% -- elapsed time=14.13s -- loss=0.02563 -- acc=99.31167%
#
#   valid loss:		0.01918
#   valid accuracy:	0.99550+/-0.00000
#   valid auc-roc:	0.99986+/-0.00000
#   valid auc-pr:		0.99987+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 3 out of 100
# [==============================] 100.0% -- elapsed time=14.14s -- loss=0.02291 -- acc=99.42000%
#
#   valid loss:		0.02265
#   valid accuracy:	0.99485+/-0.00000
#   valid auc-roc:	0.99984+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 4 out of 100
# [==============================] 100.0% -- elapsed time=14.31s -- loss=0.01958 -- acc=99.54500%
#
#   valid loss:		0.02472
#   valid accuracy:	0.99470+/-0.00000
#   valid auc-roc:	0.99985+/-0.00000
#   valid auc-pr:		0.99986+/-0.00000
# Epoch 5 out of 100
# [==============================] 100.0% -- elapsed time=14.33s -- loss=0.01926 -- acc=99.62250%
#
#   valid loss:		0.02404
#   valid accuracy:	0.99500+/-0.00000
#   valid auc-roc:	0.99989+/-0.00000
#   valid auc-pr:		0.99990+/-0.00000
# Epoch 6 out of 100
# [==============================] 100.0% -- elapsed time=14.53s -- loss=0.01804 -- acc=99.71917%
#
#   valid loss:		0.02197
#   valid accuracy:	0.99655+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 7 out of 100
# [==============================] 100.0% -- elapsed time=14.52s -- loss=0.01766 -- acc=99.78583%
#
#   valid loss:		0.02204
#   valid accuracy:	0.99680+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 8 out of 100
# [==============================] 100.0% -- elapsed time=14.49s -- loss=0.01778 -- acc=99.80583%
#
#   valid loss:		0.02380
#   valid accuracy:	0.99675+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 9 out of 100
# [==============================] 100.0% -- elapsed time=14.47s -- loss=0.01798 -- acc=99.81167%
#
#   valid loss:		0.02379
#   valid accuracy:	0.99690+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 10 out of 100
# [==============================] 100.0% -- elapsed time=14.51s -- loss=0.01755 -- acc=99.83750%
#
#   valid loss:		0.02318
#   valid accuracy:	0.99700+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 11 out of 100
# [==============================] 100.0% -- elapsed time=14.50s -- loss=0.01770 -- acc=99.84500%
#
#   valid loss:		0.02284
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 12 out of 100
# [==============================] 100.0% -- elapsed time=14.51s -- loss=0.01768 -- acc=99.86000%
#
#   valid loss:		0.02339
#   valid accuracy:	0.99740+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 13 out of 100
# [==============================] 100.0% -- elapsed time=14.50s -- loss=0.01746 -- acc=99.86833%
#
#   valid loss:		0.02493
#   valid accuracy:	0.99695+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99993+/-0.00000
# Epoch 14 out of 100
# [==============================] 100.0% -- elapsed time=14.49s -- loss=0.01751 -- acc=99.86333%
#
#   valid loss:		0.02103
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 15 out of 100
# [==============================] 100.0% -- elapsed time=14.48s -- loss=0.01654 -- acc=99.88500%
#
#   valid loss:		0.02356
#   valid accuracy:	0.99725+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 16 out of 100
# [==============================] 100.0% -- elapsed time=14.43s -- loss=0.01759 -- acc=99.85500%
#
#   valid loss:		0.02146
#   valid accuracy:	0.99755+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 17 out of 100
# [==============================] 100.0% -- elapsed time=14.33s -- loss=0.01665 -- acc=99.89500%
#
#   valid loss:		0.02230
#   valid accuracy:	0.99765+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 18 out of 100
# [==============================] 100.0% -- elapsed time=14.34s -- loss=0.01661 -- acc=99.88750%
#
#   valid loss:		0.02164
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 19 out of 100
# [==============================] 100.0% -- elapsed time=14.37s -- loss=0.01613 -- acc=99.89750%
#
#   valid loss:		0.02154
#   valid accuracy:	0.99735+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 20 out of 100
# [==============================] 100.0% -- elapsed time=14.30s -- loss=0.01662 -- acc=99.86083%
#
#   valid loss:		0.02507
#   valid accuracy:	0.99670+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 21 out of 100
# [==============================] 100.0% -- elapsed time=14.35s -- loss=0.01594 -- acc=99.89000%
#
#   valid loss:		0.02472
#   valid accuracy:	0.99665+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 22 out of 100
# [==============================] 100.0% -- elapsed time=14.33s -- loss=0.01588 -- acc=99.89000%
#
#   valid loss:		0.01925
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 23 out of 100
# [==============================] 100.0% -- elapsed time=14.34s -- loss=0.01560 -- acc=99.90333%
#
#   valid loss:		0.02119
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 24 out of 100
# [==============================] 100.0% -- elapsed time=14.37s -- loss=0.01533 -- acc=99.89417%
#
#   valid loss:		0.02176
#   valid accuracy:	0.99775+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99991+/-0.00000
# Epoch 25 out of 100
# [==============================] 100.0% -- elapsed time=14.41s -- loss=0.01514 -- acc=99.90333%
#
#   valid loss:		0.01958
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 26 out of 100
# [==============================] 100.0% -- elapsed time=14.42s -- loss=0.01511 -- acc=99.90250%
#
#   valid loss:		0.01854
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 27 out of 100
# [==============================] 100.0% -- elapsed time=14.44s -- loss=0.01492 -- acc=99.90583%
#
#   valid loss:		0.01889
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 28 out of 100
# [==============================] 100.0% -- elapsed time=14.47s -- loss=0.01452 -- acc=99.90917%
#
#   valid loss:		0.01801
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 29 out of 100
# [==============================] 100.0% -- elapsed time=14.44s -- loss=0.01460 -- acc=99.90667%
#
#   valid loss:		0.01979
#   valid accuracy:	0.99770+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 30 out of 100
# [==============================] 100.0% -- elapsed time=14.47s -- loss=0.01445 -- acc=99.90667%
#
#   valid loss:		0.02193
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 31 out of 100
# [==============================] 100.0% -- elapsed time=14.47s -- loss=0.01443 -- acc=99.91000%
#
#   valid loss:		0.01753
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 32 out of 100
# [==============================] 100.0% -- elapsed time=14.46s -- loss=0.01372 -- acc=99.92083%
#
#   valid loss:		0.01914
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 33 out of 100
# [==============================] 100.0% -- elapsed time=14.46s -- loss=0.01381 -- acc=99.92333%
#
#   valid loss:		0.01705
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 34 out of 100
# [==============================] 100.0% -- elapsed time=14.49s -- loss=0.01398 -- acc=99.90833%
#
#   valid loss:		0.01729
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 35 out of 100
# [==============================] 100.0% -- elapsed time=14.52s -- loss=0.01420 -- acc=99.89083%
#
#   valid loss:		0.01862
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 36 out of 100
# [==============================] 100.0% -- elapsed time=14.69s -- loss=0.01338 -- acc=99.92917%
#
#   valid loss:		0.01765
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 37 out of 100
# [==============================] 100.0% -- elapsed time=14.51s -- loss=0.01352 -- acc=99.91000%
#
#   valid loss:		0.01719
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 38 out of 100
# [==============================] 100.0% -- elapsed time=14.53s -- loss=0.01331 -- acc=99.91250%
#
#   valid loss:		0.01866
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 39 out of 100
# [==============================] 100.0% -- elapsed time=14.56s -- loss=0.01308 -- acc=99.91750%
#
#   valid loss:		0.01900
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 40 out of 100
# [==============================] 100.0% -- elapsed time=14.71s -- loss=0.01322 -- acc=99.90583%
#
#   valid loss:		0.01781
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 41 out of 100
# [==============================] 100.0% -- elapsed time=14.53s -- loss=0.01280 -- acc=99.93083%
#
#   valid loss:		0.01713
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 42 out of 100
# [==============================] 100.0% -- elapsed time=14.59s -- loss=0.01297 -- acc=99.91750%
#
#   valid loss:		0.01675
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 43 out of 100
# [==============================] 100.0% -- elapsed time=14.50s -- loss=0.01272 -- acc=99.92083%
#
#   valid loss:		0.01769
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 44 out of 100
# [==============================] 100.0% -- elapsed time=14.53s -- loss=0.01256 -- acc=99.91083%
#
#   valid loss:		0.01824
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 45 out of 100
# [==============================] 100.0% -- elapsed time=14.61s -- loss=0.01223 -- acc=99.92667%
#
#   valid loss:		0.01898
#   valid accuracy:	0.99745+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 46 out of 100
# [==============================] 100.0% -- elapsed time=14.68s -- loss=0.01282 -- acc=99.91000%
#
#   valid loss:		0.01570
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 47 out of 100
# [==============================] 100.0% -- elapsed time=14.55s -- loss=0.01247 -- acc=99.91000%
#
#   valid loss:		0.01633
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 48 out of 100
# [==============================] 100.0% -- elapsed time=14.39s -- loss=0.01201 -- acc=99.93000%
#
#   valid loss:		0.01644
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 49 out of 100
# [==============================] 100.0% -- elapsed time=13.94s -- loss=0.01215 -- acc=99.91833%
#
#   valid loss:		0.01511
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 50 out of 100
# [==============================] 100.0% -- elapsed time=13.71s -- loss=0.01191 -- acc=99.92833%
#
#   valid loss:		0.01672
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 51 out of 100
# [==============================] 100.0% -- elapsed time=13.68s -- loss=0.01261 -- acc=99.90000%
#
#   valid loss:		0.01589
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 52 out of 100
# [==============================] 100.0% -- elapsed time=13.75s -- loss=0.01204 -- acc=99.91083%
#
#   valid loss:		0.01675
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 53 out of 100
# [==============================] 100.0% -- elapsed time=13.68s -- loss=0.01224 -- acc=99.91000%
#
#   valid loss:		0.01844
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 54 out of 100
# [==============================] 100.0% -- elapsed time=13.69s -- loss=0.01159 -- acc=99.92917%
#
#   valid loss:		0.01593
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 55 out of 100
# [==============================] 100.0% -- elapsed time=13.73s -- loss=0.01137 -- acc=99.92417%
#
#   valid loss:		0.01588
#   valid accuracy:	0.99850+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 56 out of 100
# [==============================] 100.0% -- elapsed time=13.85s -- loss=0.01175 -- acc=99.92417%
#
#   valid loss:		0.01549
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 57 out of 100
# [==============================] 100.0% -- elapsed time=13.70s -- loss=0.01179 -- acc=99.91500%
#
#   valid loss:		0.01653
#   valid accuracy:	0.99790+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 58 out of 100
# [==============================] 100.0% -- elapsed time=13.83s -- loss=0.01151 -- acc=99.92167%
#
#   valid loss:		0.01719
#   valid accuracy:	0.99785+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 59 out of 100
# [==============================] 100.0% -- elapsed time=13.82s -- loss=0.01101 -- acc=99.93667%
#
#   valid loss:		0.01639
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 60 out of 100
# [==============================] 100.0% -- elapsed time=13.75s -- loss=0.01184 -- acc=99.91833%
#
#   valid loss:		0.01593
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 61 out of 100
# [==============================] 100.0% -- elapsed time=13.75s -- loss=0.01118 -- acc=99.92750%
#
#   valid loss:		0.01452
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 62 out of 100
# [==============================] 100.0% -- elapsed time=13.81s -- loss=0.01162 -- acc=99.92167%
#
#   valid loss:		0.01354
#   valid accuracy:	0.99870+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
#   lower cross-validation found
#   saving model to:  ../../../results/riboswitch/resbind_t1_best.ckpt
# Epoch 63 out of 100
# [==============================] 100.0% -- elapsed time=13.81s -- loss=0.01145 -- acc=99.92000%
#
#   valid loss:		0.01465
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 64 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.01096 -- acc=99.93583%
#
#   valid loss:		0.01596
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 65 out of 100
# [==============================] 100.0% -- elapsed time=13.85s -- loss=0.01169 -- acc=99.90583%
#
#   valid loss:		0.01603
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99992+/-0.00000
#   valid auc-pr:		0.99992+/-0.00000
# Epoch 66 out of 100
# [==============================] 100.0% -- elapsed time=13.75s -- loss=0.01117 -- acc=99.93250%
#
#   valid loss:		0.01603
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99991+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 67 out of 100
# [==============================] 100.0% -- elapsed time=13.76s -- loss=0.01123 -- acc=99.92000%
#
#   valid loss:		0.01596
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 68 out of 100
# [==============================] 100.0% -- elapsed time=13.86s -- loss=0.01087 -- acc=99.93583%
#
#   valid loss:		0.01882
#   valid accuracy:	0.99780+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 69 out of 100
# [==============================] 100.0% -- elapsed time=13.74s -- loss=0.01108 -- acc=99.93250%
#
#   valid loss:		0.01549
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 70 out of 100
# [==============================] 100.0% -- elapsed time=13.74s -- loss=0.01118 -- acc=99.92000%
#
#   valid loss:		0.01599
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99993+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 71 out of 100
# [==============================] 100.0% -- elapsed time=13.74s -- loss=0.01108 -- acc=99.93250%
#
#   valid loss:		0.01517
#   valid accuracy:	0.99855+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 72 out of 100
# [==============================] 100.0% -- elapsed time=13.84s -- loss=0.01060 -- acc=99.94333%
#
#   valid loss:		0.01795
#   valid accuracy:	0.99810+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99995+/-0.00000
# Epoch 73 out of 100
# [==============================] 100.0% -- elapsed time=13.90s -- loss=0.01053 -- acc=99.93917%
#
#   valid loss:		0.01481
#   valid accuracy:	0.99880+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 74 out of 100
# [==============================] 100.0% -- elapsed time=13.90s -- loss=0.01087 -- acc=99.92333%
#
#   valid loss:		0.01457
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 75 out of 100
# [==============================] 100.0% -- elapsed time=14.44s -- loss=0.01067 -- acc=99.92500%
#
#   valid loss:		0.01599
#   valid accuracy:	0.99805+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 76 out of 100
# [==============================] 100.0% -- elapsed time=14.02s -- loss=0.01054 -- acc=99.93667%
#
#   valid loss:		0.01482
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 77 out of 100
# [==============================] 100.0% -- elapsed time=14.00s -- loss=0.01048 -- acc=99.93000%
#
#   valid loss:		0.01629
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 78 out of 100
# [==============================] 100.0% -- elapsed time=13.99s -- loss=0.01033 -- acc=99.93250%
#
#   valid loss:		0.01461
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 79 out of 100
# [==============================] 100.0% -- elapsed time=14.01s -- loss=0.01038 -- acc=99.92583%
#
#   valid loss:		0.01536
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 80 out of 100
# [==============================] 100.0% -- elapsed time=14.03s -- loss=0.01020 -- acc=99.94000%
#
#   valid loss:		0.01466
#   valid accuracy:	0.99835+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 81 out of 100
# [==============================] 100.0% -- elapsed time=14.05s -- loss=0.01064 -- acc=99.91667%
#
#   valid loss:		0.01452
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 82 out of 100
# [==============================] 100.0% -- elapsed time=14.07s -- loss=0.01047 -- acc=99.92667%
#
#   valid loss:		0.01563
#   valid accuracy:	0.99800+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 83 out of 100
# [==============================] 100.0% -- elapsed time=14.03s -- loss=0.01002 -- acc=99.93750%
#
#   valid loss:		0.01418
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99998+/-0.00000
#   valid auc-pr:		0.99998+/-0.00000
# Epoch 84 out of 100
# [==============================] 100.0% -- elapsed time=14.06s -- loss=0.01015 -- acc=99.93417%
#
#   valid loss:		0.01380
#   valid accuracy:	0.99865+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 85 out of 100
# [==============================] 100.0% -- elapsed time=14.07s -- loss=0.01007 -- acc=99.92917%
#
#   valid loss:		0.01475
#   valid accuracy:	0.99815+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 86 out of 100
# [==============================] 100.0% -- elapsed time=14.06s -- loss=0.00999 -- acc=99.93583%
#
#   valid loss:		0.01486
#   valid accuracy:	0.99830+/-0.00000
#   valid auc-roc:	0.99997+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 87 out of 100
# [==============================] 100.0% -- elapsed time=14.19s -- loss=0.00921 -- acc=99.95833%
#
#   valid loss:		0.01403
#   valid accuracy:	0.99860+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 88 out of 100
# [==============================] 100.0% -- elapsed time=14.18s -- loss=0.01003 -- acc=99.92667%
#
#   valid loss:		0.01393
#   valid accuracy:	0.99845+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Epoch 89 out of 100
# [==============================] 100.0% -- elapsed time=14.11s -- loss=0.00937 -- acc=99.94917%
#
#   valid loss:		0.01497
#   valid accuracy:	0.99795+/-0.00000
#   valid auc-roc:	0.99994+/-0.00000
#   valid auc-pr:		0.99994+/-0.00000
# Epoch 90 out of 100
# [==============================] 100.0% -- elapsed time=14.07s -- loss=0.00999 -- acc=99.92500%
#
#   valid loss:		0.01381
#   valid accuracy:	0.99825+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 91 out of 100
# [==============================] 100.0% -- elapsed time=14.03s -- loss=0.00913 -- acc=99.95000%
#
#   valid loss:		0.01436
#   valid accuracy:	0.99820+/-0.00000
#   valid auc-roc:	0.99995+/-0.00000
#   valid auc-pr:		0.99996+/-0.00000
# Epoch 92 out of 100
# [==============================] 100.0% -- elapsed time=14.13s -- loss=0.00957 -- acc=99.94083%
#
#   valid loss:		0.01380
#   valid accuracy:	0.99840+/-0.00000
#   valid auc-roc:	0.99996+/-0.00000
#   valid auc-pr:		0.99997+/-0.00000
# Patience ran out... Early stopping.

# %%
# initialize session
sess.close()
sess = utils.initialize_session()

# %%
# set best parameters
nntrainer.set_best_parameters(sess)

# test model
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, name='test')
# Out:
# loading model from:  ../../../results/riboswitch/resbind_t1_best.ckpt
# INFO:tensorflow:Restoring parameters from ../../../results/riboswitch/resbind_t1_best.ckpt
#   test  loss:		0.01178
#   test  accuracy:	0.99922+/-0.00000
#   test  auc-roc:	0.99999+/-0.00000
#   test  auc-pr:		0.99999+/-0.00000

# %%
# sort activations
predictionsoutput = nntrainer.get_activations(sess, test, layer='output')
plot_index = np.argsort(predictionsoutput[:,0])[::-1]

plt.figure()
plt.ylabel('Predicted score')
plt.xlabel('Sequences ordered by score')
plt.plot(range(len(plot_index)), predictionsoutput[plot_index])
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
num_plots=np.linspace(0,20000,5).astype(int)
#num_plots = range(5)
for ii in num_plots: 

    X = np.expand_dims(test['inputs'][plot_index[ii]], axis=0)
    
    mf.fom_saliency(X, layer='dense_1_bias', alphabet='rna', nntrainer=nntrainer, sess=sess, figsize=(15,1.5))
# Out:
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /home/peter/anaconda2/envs/tensorflow/lib/python2.7/site-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
#num_plots=np.linspace(0,10000,10).astype(int)
num_plots = range(int(numdata*test_frac))
#for sp, ii in enumerate(num_plots): 
    
def nucpresence(Xdict, ii):
    X = np.expand_dims(Xdict['inputs'][plot_index[ii]], axis=0)
    nuc_index = np.where(np.sum(X, axis=0)!=0)[0]
    nucpos = np.zeros(shape=(1,seqlen))
    nucpos[:, nuc_index] = 1.
    return nucpos

nuc_sequences = [nucpresence(test,ii) for ii in num_plots]
    
plt.figure(figsize=(15,5))
sb.heatmap(np.squeeze(nuc_sequences)[:, bpidx].T, cbar=False)
plt.ylabel('Conserved Base pairs by covariance')
plt.xlabel('Sequence rank number')

# %%
savepath = 'Arrays/riboswitch_resbindt1_ug_so250.npy'

num_summary = 250
Xdict = test['inputs'][plot_index[:num_summary]]

sum_mut2 = mf.som_average_ungapped(Xdict, ungapped_index=ugidx, savepath=savepath, nntrainer=nntrainer, 
                                sess=sess, progress='on', save=True, layer='dense_1_bias', 
                               normalize=False, normfactor=0)
# Out:
# 0
# Epoch duration =5.26s
# Cumulative duration =5.27s
#
# 1
# Epoch duration =7.07s
# Cumulative duration =12.34s
#
# 2
# Epoch duration =5.29s
# Cumulative duration =17.63s
#
# 3
# Epoch duration =7.22s
# Cumulative duration =24.85s
#
# 4
# Epoch duration =5.38s
# Cumulative duration =30.24s
#
# 5
# Epoch duration =7.46s
# Cumulative duration =37.69s
#
# 6
# Epoch duration =5.27s
# Cumulative duration =42.97s
#
# 7
# Epoch duration =7.1s
# Cumulative duration =50.07s
#
# 8
# Epoch duration =5.48s
# Cumulative duration =55.55s
#
# 9
# Epoch duration =7.05s
# Cumulative duration =1min 2.5900000000000034s
#
# 10
# Epoch duration =5.26s
# Cumulative duration =1min 7.849999999999994s
#
# 11
# Epoch duration =7.04s
# Cumulative duration =1min 14.89s
#
# 12
# Epoch duration =5.25s
# Cumulative duration =1min 20.14s
#
# 13
# Epoch duration =7.1s
# Cumulative duration =1min 27.239999999999995s
#
# 14
# Epoch duration =5.22s
# Cumulative duration =1min 32.47s
#
# 15
# Epoch duration =7.05s
# Cumulative duration =1min 39.510000000000005s
#
# 16
# Epoch duration =5.23s
# Cumulative duration =1min 44.75s
#
# 17
# Epoch duration =7.11s
# Cumulative duration =1min 51.849999999999994s
#
# 18
# Epoch duration =5.23s
# Cumulative duration =1min 57.09s
#
# 19
# Epoch duration =7.05s
# Cumulative duration =2min 4.140000000000001s
#
# 20
# Epoch duration =5.24s
# Cumulative duration =2min 9.379999999999995s
#
# 21
# Epoch duration =7.03s
# Cumulative duration =2min 16.409999999999997s
#
# 22
# Epoch duration =5.25s
# Cumulative duration =2min 21.659999999999997s
#
# 23
# Epoch duration =7.04s
# Cumulative duration =2min 28.710000000000008s
#
# 24
# Epoch duration =5.26s
# Cumulative duration =2min 33.97s
#
# 25
# Epoch duration =7.05s
# Cumulative duration =2min 41.02000000000001s
#
# 26
# Epoch duration =5.27s
# Cumulative duration =2min 46.28999999999999s
#
# 27
# Epoch duration =7.1s
# Cumulative duration =2min 53.400000000000006s
#
# 28
# Epoch duration =5.25s
# Cumulative duration =2min 58.639999999999986s
#
# 29
# Epoch duration =7.07s
# Cumulative duration =3min 5.710000000000008s
#
# 30
# Epoch duration =5.24s
# Cumulative duration =3min 10.949999999999989s
#
# 31
# Epoch duration =7.03s
# Cumulative duration =3min 17.97999999999999s
#
# 32
# Epoch duration =5.24s
# Cumulative duration =3min 23.22s
#
# 33
# Epoch duration =7.07s
# Cumulative duration =3min 30.289999999999992s
#
# 34
# Epoch duration =5.25s
# Cumulative duration =3min 35.53999999999999s
#
# 35
# Epoch duration =7.08s
# Cumulative duration =3min 42.620000000000005s
#
# 36
# Epoch duration =5.24s
# Cumulative duration =3min 47.870000000000005s
#
# 37
# Epoch duration =7.07s
# Cumulative duration =3min 54.94s
#
# 38
# Epoch duration =5.25s
# Cumulative duration =4min 0.18999999999999773s
#
# 39
# Epoch duration =7.07s
# Cumulative duration =4min 7.259999999999991s
#
# 40
# Epoch duration =5.25s
# Cumulative duration =4min 12.509999999999991s
#
# 41
# Epoch duration =7.04s
# Cumulative duration =4min 19.560000000000002s
#
# 42
# Epoch duration =5.27s
# Cumulative duration =4min 24.819999999999993s
#
# 43
# Epoch duration =7.07s
# Cumulative duration =4min 31.889999999999986s
#
# 44
# Epoch duration =5.27s
# Cumulative duration =4min 37.160000000000025s
#
# 45
# Epoch duration =7.07s
# Cumulative duration =4min 44.24000000000001s
#
# 46
# Epoch duration =5.24s
# Cumulative duration =4min 49.48000000000002s
#
# 47
# Epoch duration =7.05s
# Cumulative duration =4min 56.51999999999998s
#
# 48
# Epoch duration =5.24s
# Cumulative duration =5min 1.759999999999991s
#
# 49
# Epoch duration =7.1s
# Cumulative duration =5min 8.870000000000005s
#
# 50
# Epoch duration =5.26s
# Cumulative duration =5min 14.120000000000005s
#
# 51
# Epoch duration =7.11s
# Cumulative duration =5min 21.24000000000001s
#
# 52
# Epoch duration =5.27s
# Cumulative duration =5min 26.5s
#
# 53
# Epoch duration =7.09s
# Cumulative duration =5min 33.589999999999975s
#
# 54
# Epoch duration =5.28s
# Cumulative duration =5min 38.870000000000005s
#
# 55
# Epoch duration =7.06s
# Cumulative duration =5min 45.93000000000001s
#
# 56
# Epoch duration =5.28s
# Cumulative duration =5min 51.20999999999998s
#
# 57
# Epoch duration =7.05s
# Cumulative duration =5min 58.25999999999999s
#
# 58
# Epoch duration =5.28s
# Cumulative duration =6min 3.5400000000000205s
#
# 59
# Epoch duration =7.11s
# Cumulative duration =6min 10.649999999999977s
#
# 60
# Epoch duration =5.28s
# Cumulative duration =6min 15.930000000000007s
#
# 61
# Epoch duration =7.04s
# Cumulative duration =6min 22.95999999999998s
#
# 62
# Epoch duration =5.26s
# Cumulative duration =6min 28.220000000000027s
#
# 63
# Epoch duration =7.04s
# Cumulative duration =6min 35.25999999999999s
#
# 64
# Epoch duration =5.27s
# Cumulative duration =6min 40.52999999999997s
#
# 65
# Epoch duration =7.08s
# Cumulative duration =6min 47.610000000000014s
#
# 66
# Epoch duration =5.27s
# Cumulative duration =6min 52.879999999999995s
#
# 67
# Epoch duration =7.07s
# Cumulative duration =6min 59.94999999999999s
#
# 68
# Epoch duration =5.27s
# Cumulative duration =7min 5.220000000000027s
#
# 69
# Epoch duration =7.1s
# Cumulative duration =7min 12.329999999999984s
#
# 70
# Epoch duration =5.26s
# Cumulative duration =7min 17.589999999999975s
#
# 71
# Epoch duration =7.05s
# Cumulative duration =7min 24.639999999999986s
#
# 72
# Epoch duration =5.26s
# Cumulative duration =7min 29.899999999999977s
#
# 73
# Epoch duration =7.06s
# Cumulative duration =7min 36.95999999999998s
#
# 74
# Epoch duration =5.28s
# Cumulative duration =7min 42.23000000000002s
#
# 75
# Epoch duration =7.07s
# Cumulative duration =7min 49.30000000000001s
#
# 76
# Epoch duration =5.27s
# Cumulative duration =7min 54.56999999999999s
#
# 77
# Epoch duration =7.06s
# Cumulative duration =8min 1.6299999999999955s
#
# 78
# Epoch duration =5.24s
# Cumulative duration =8min 6.8700000000000045s
#
# 79
# Epoch duration =7.05s
# Cumulative duration =8min 13.920000000000016s
#
# 80
# Epoch duration =5.29s
# Cumulative duration =8min 19.20999999999998s
#
# 81
# Epoch duration =7.07s
# Cumulative duration =8min 26.279999999999973s
#
# 82
# Epoch duration =5.26s
# Cumulative duration =8min 31.54000000000002s
#
# 83
# Epoch duration =7.06s
# Cumulative duration =8min 38.60000000000002s
#
# 84
# Epoch duration =5.25s
# Cumulative duration =8min 43.85000000000002s
#
# 85
# Epoch duration =7.07s
# Cumulative duration =8min 50.91999999999996s
#
# 86
# Epoch duration =5.25s
# Cumulative duration =8min 56.16999999999996s
#
# 87
# Epoch duration =7.07s
# Cumulative duration =9min 3.240000000000009s
#
# 88
# Epoch duration =5.27s
# Cumulative duration =9min 8.509999999999991s
#
# 89
# Epoch duration =7.11s
# Cumulative duration =9min 15.620000000000005s
#
# 90
# Epoch duration =5.34s
# Cumulative duration =9min 20.970000000000027s
#
# 91
# Epoch duration =7.09s
# Cumulative duration =9min 28.059999999999945s
#
# 92
# Epoch duration =5.25s
# Cumulative duration =9min 33.309999999999945s
#
# 93
# Epoch duration =7.11s
# Cumulative duration =9min 40.41999999999996s
#
# 94
# Epoch duration =5.26s
# Cumulative duration =9min 45.67999999999995s
#
# 95
# Epoch duration =7.09s
# Cumulative duration =9min 52.76999999999998s
#
# 96
# Epoch duration =5.26s
# Cumulative duration =9min 58.02999999999997s
#
# 97
# Epoch duration =7.09s
# Cumulative duration =10min 5.1200000000000045s
#
# 98
# Epoch duration =5.27s
# Cumulative duration =10min 10.389999999999986s
#
# 99
# Epoch duration =7.06s
# Cumulative duration =10min 17.450000000000045s
#
# 100
# Epoch duration =5.28s
# Cumulative duration =10min 22.730000000000018s
#
# 101
# Epoch duration =7.08s
# Cumulative duration =10min 29.809999999999945s
#
# 102
# Epoch duration =5.24s
# Cumulative duration =10min 35.049999999999955s
#
# 103
# Epoch duration =7.08s
# Cumulative duration =10min 42.120000000000005s
#
# 104
# Epoch duration =5.25s
# Cumulative duration =10min 47.370000000000005s
#
# 105
# Epoch duration =7.08s
# Cumulative duration =10min 54.450000000000045s
#
# 106
# Epoch duration =5.26s
# Cumulative duration =10min 59.710000000000036s
#
# 107
# Epoch duration =7.07s
# Cumulative duration =11min 6.779999999999973s
#
# 108
# Epoch duration =5.27s
# Cumulative duration =11min 12.049999999999955s
#
# 109
# Epoch duration =7.06s
# Cumulative duration =11min 19.120000000000005s
#
# 110
# Epoch duration =5.26s
# Cumulative duration =11min 24.379999999999995s
#
# 111
# Epoch duration =7.07s
# Cumulative duration =11min 31.450000000000045s
#
# 112
# Epoch duration =5.26s
# Cumulative duration =11min 36.710000000000036s
#
# 113
# Epoch duration =7.07s
# Cumulative duration =11min 43.76999999999998s
#
# 114
# Epoch duration =5.26s
# Cumulative duration =11min 49.02999999999997s
#
# 115
# Epoch duration =7.02s
# Cumulative duration =11min 56.059999999999945s
#
# 116
# Epoch duration =5.27s
# Cumulative duration =12min 1.330000000000041s
#
# 117
# Epoch duration =7.03s
# Cumulative duration =12min 8.360000000000014s
#
# 118
# Epoch duration =5.27s
# Cumulative duration =12min 13.629999999999995s
#
# 119
# Epoch duration =7.04s
# Cumulative duration =12min 20.66999999999996s
#
# 120
# Epoch duration =5.26s
# Cumulative duration =12min 25.92999999999995s
#
# 121
# Epoch duration =7.04s
# Cumulative duration =12min 32.97000000000003s
#
# 122
# Epoch duration =5.29s
# Cumulative duration =12min 38.25999999999999s
#
# 123
# Epoch duration =7.05s
# Cumulative duration =12min 45.309999999999945s
#
# 124
# Epoch duration =5.25s
# Cumulative duration =12min 50.57000000000005s
#
# 125
# Epoch duration =6.81s
# Cumulative duration =12min 57.379999999999995s
#
# 126
# Epoch duration =5.27s
# Cumulative duration =13min 2.659999999999968s
#
# 127
# Epoch duration =7.07s
# Cumulative duration =13min 9.730000000000018s
#
# 128
# Epoch duration =5.26s
# Cumulative duration =13min 14.990000000000009s
#
# 129
# Epoch duration =7.04s
# Cumulative duration =13min 22.039999999999964s
#
# 130
# Epoch duration =5.27s
# Cumulative duration =13min 27.299999999999955s
#
# 131
# Epoch duration =7.06s
# Cumulative duration =13min 34.370000000000005s
#
# 132
# Epoch duration =5.26s
# Cumulative duration =13min 39.629999999999995s
#
# 133
# Epoch duration =7.1s
# Cumulative duration =13min 46.73000000000002s
#
# 134
# Epoch duration =5.27s
# Cumulative duration =13min 52.0s
#
# 135
# Epoch duration =7.09s
# Cumulative duration =13min 59.09000000000003s
#
# 136
# Epoch duration =5.26s
# Cumulative duration =14min 4.350000000000023s
#
# 137
# Epoch duration =7.08s
# Cumulative duration =14min 11.42999999999995s
#
# 138
# Epoch duration =5.26s
# Cumulative duration =14min 16.690000000000055s
#
# 139
# Epoch duration =7.04s
# Cumulative duration =14min 23.730000000000018s
#
# 140
# Epoch duration =5.25s
# Cumulative duration =14min 28.980000000000018s
#
# 141
# Epoch duration =7.05s
# Cumulative duration =14min 36.02999999999997s
#
# 142
# Epoch duration =5.28s
# Cumulative duration =14min 41.309999999999945s
#
# 143
# Epoch duration =7.09s
# Cumulative duration =14min 48.39999999999998s
#
# 144
# Epoch duration =5.28s
# Cumulative duration =14min 53.690000000000055s
#
# 145
# Epoch duration =7.1s
# Cumulative duration =15min 0.7799999999999727s
#
# 146
# Epoch duration =5.26s
# Cumulative duration =15min 6.039999999999964s
#
# 147
# Epoch duration =7.07s
# Cumulative duration =15min 13.120000000000005s
#
# 148
# Epoch duration =5.27s
# Cumulative duration =15min 18.389999999999986s
#
# 149
# Epoch duration =7.09s
# Cumulative duration =15min 25.470000000000027s
#
# 150
# Epoch duration =5.26s
# Cumulative duration =15min 30.74000000000001s
#
# 151
# Epoch duration =7.1s
# Cumulative duration =15min 37.84000000000003s
#
# 152
# Epoch duration =5.25s
# Cumulative duration =15min 43.09000000000003s
#
# 153
# Epoch duration =7.08s
# Cumulative duration =15min 50.16999999999996s
#
# 154
# Epoch duration =5.27s
# Cumulative duration =15min 55.440000000000055s
#
# 155
# Epoch duration =7.09s
# Cumulative duration =16min 2.5299999999999727s
#
# 156
# Epoch duration =5.26s
# Cumulative duration =16min 7.7999999999999545s
#
# 157
# Epoch duration =7.06s
# Cumulative duration =16min 14.860000000000014s
#
# 158
# Epoch duration =5.25s
# Cumulative duration =16min 20.110000000000014s
#
# 159
# Epoch duration =7.09s
# Cumulative duration =16min 27.200000000000045s
#
# 160
# Epoch duration =5.26s
# Cumulative duration =16min 32.460000000000036s
#
# 161
# Epoch duration =7.03s
# Cumulative duration =16min 39.49000000000001s
#
# 162
# Epoch duration =5.29s
# Cumulative duration =16min 44.77999999999997s
#
# 163
# Epoch duration =7.22s
# Cumulative duration =16min 52.00999999999999s
#
# 164
# Epoch duration =5.45s
# Cumulative duration =16min 57.460000000000036s
#
# 165
# Epoch duration =7.35s
# Cumulative duration =17min 4.809999999999945s
#
# 166
# Epoch duration =5.53s
# Cumulative duration =17min 10.339999999999918s
#
# 167
# Epoch duration =7.13s
# Cumulative duration =17min 17.470000000000027s
#
# 168
# Epoch duration =5.37s
# Cumulative duration =17min 22.839999999999918s
#
# 169
# Epoch duration =7.11s
# Cumulative duration =17min 29.950000000000045s
#
# 170
# Epoch duration =5.26s
# Cumulative duration =17min 35.210000000000036s
#
# 171
# Epoch duration =7.57s
# Cumulative duration =17min 42.77999999999997s
#
# 172
# Epoch duration =5.34s
# Cumulative duration =17min 48.11999999999989s
#
# 173
# Epoch duration =7.56s
# Cumulative duration =17min 55.690000000000055s
#
# 174
# Epoch duration =5.77s
# Cumulative duration =18min 1.4600000000000364s
#
# 175
# Epoch duration =7.25s
# Cumulative duration =18min 8.710000000000036s
#
# 176
# Epoch duration =5.36s
# Cumulative duration =18min 14.079999999999927s
#
# 177
# Epoch duration =7.17s
# Cumulative duration =18min 21.25s
#
# 178
# Epoch duration =5.32s
# Cumulative duration =18min 26.569999999999936s
#
# 179
# Epoch duration =7.18s
# Cumulative duration =18min 33.75s
#
# 180
# Epoch duration =5.33s
# Cumulative duration =18min 39.07999999999993s
#
# 181
# Epoch duration =7.09s
# Cumulative duration =18min 46.17000000000007s
#
# 182
# Epoch duration =5.33s
# Cumulative duration =18min 51.49000000000001s
#
# 183
# Epoch duration =7.2s
# Cumulative duration =18min 58.700000000000045s
#
# 184
# Epoch duration =5.36s
# Cumulative duration =19min 4.0499999999999545s
#
# 185
# Epoch duration =7.25s
# Cumulative duration =19min 11.299999999999955s
#
# 186
# Epoch duration =5.33s
# Cumulative duration =19min 16.63000000000011s
#
# 187
# Epoch duration =7.19s
# Cumulative duration =19min 23.819999999999936s
#
# 188
# Epoch duration =5.34s
# Cumulative duration =19min 29.160000000000082s
#
# 189
# Epoch duration =7.23s
# Cumulative duration =19min 36.3900000000001s
#
# 190
# Epoch duration =5.37s
# Cumulative duration =19min 41.75999999999999s
#
# 191
# Epoch duration =7.27s
# Cumulative duration =19min 49.01999999999998s
#
# 192
# Epoch duration =5.33s
# Cumulative duration =19min 54.3599999999999s
#
# 193
# Epoch duration =7.15s
# Cumulative duration =20min 1.509999999999991s
#
# 194
# Epoch duration =5.34s
# Cumulative duration =20min 6.849999999999909s
#
# 195
# Epoch duration =7.17s
# Cumulative duration =20min 14.019999999999982s
#
# 196
# Epoch duration =5.41s
# Cumulative duration =20min 19.430000000000064s
#
# 197
# Epoch duration =7.7s
# Cumulative duration =20min 27.13000000000011s
#
# 198
# Epoch duration =5.34s
# Cumulative duration =20min 32.47000000000003s
#
# 199
# Epoch duration =7.14s
# Cumulative duration =20min 39.6099999999999s
#
# 200
# Epoch duration =5.34s
# Cumulative duration =20min 44.950000000000045s
#
# 201
# Epoch duration =7.16s
# Cumulative duration =20min 52.1099999999999s
#
# 202
# Epoch duration =5.52s
# Cumulative duration =20min 57.63000000000011s
#
# 203
# Epoch duration =7.74s
# Cumulative duration =21min 5.369999999999891s
#
# 204
# Epoch duration =5.28s
# Cumulative duration =21min 10.6400000000001s
#
# 205
# Epoch duration =7.14s
# Cumulative duration =21min 17.779999999999973s
#
# 206
# Epoch duration =6.14s
# Cumulative duration =21min 23.920000000000073s
#
# 207
# Epoch duration =7.22s
# Cumulative duration =21min 31.1400000000001s
#
# 208
# Epoch duration =5.93s
# Cumulative duration =21min 37.069999999999936s
#
# 209
# Epoch duration =7.71s
# Cumulative duration =21min 44.77999999999997s
#
# 210
# Epoch duration =5.36s
# Cumulative duration =21min 50.1400000000001s
#
# 211
# Epoch duration =7.04s
# Cumulative duration =21min 57.180000000000064s
#
# 212
# Epoch duration =5.27s
# Cumulative duration =22min 2.4500000000000455s
#
# 213
# Epoch duration =7.08s
# Cumulative duration =22min 9.529999999999973s
#
# 214
# Epoch duration =5.26s
# Cumulative duration =22min 14.789999999999964s
#
# 215
# Epoch duration =7.07s
# Cumulative duration =22min 21.86999999999989s
#
# 216
# Epoch duration =5.27s
# Cumulative duration =22min 27.1400000000001s
#
# 217
# Epoch duration =7.04s
# Cumulative duration =22min 34.180000000000064s
#
# 218
# Epoch duration =5.3s
# Cumulative duration =22min 39.48000000000002s
#
# 219
# Epoch duration =7.08s
# Cumulative duration =22min 46.559999999999945s
#
# 220
# Epoch duration =5.29s
# Cumulative duration =22min 51.84999999999991s
#
# 221
# Epoch duration =7.11s
# Cumulative duration =22min 58.960000000000036s
#
# 222
# Epoch duration =5.26s
# Cumulative duration =23min 4.220000000000027s
#
# 223
# Epoch duration =7.02s
# Cumulative duration =23min 11.240000000000009s
#
# 224
# Epoch duration =5.29s
# Cumulative duration =23min 16.529999999999973s
#
# 225
# Epoch duration =7.05s
# Cumulative duration =23min 23.579999999999927s
#
# 226
# Epoch duration =5.27s
# Cumulative duration =23min 28.84999999999991s
#
# 227
# Epoch duration =6.76s
# Cumulative duration =23min 35.6099999999999s
#
# 228
# Epoch duration =5.28s
# Cumulative duration =23min 40.8900000000001s
#
# 229
# Epoch duration =7.1s
# Cumulative duration =23min 47.99000000000001s
#
# 230
# Epoch duration =5.29s
# Cumulative duration =23min 53.27999999999997s
#
# 231
# Epoch duration =7.08s
# Cumulative duration =24min 0.35999999999989996s
#
# 232
# Epoch duration =5.27s
# Cumulative duration =24min 5.630000000000109s
#
# 233
# Epoch duration =7.07s
# Cumulative duration =24min 12.700000000000045s
#
# 234
# Epoch duration =5.27s
# Cumulative duration =24min 17.970000000000027s
#
# 235
# Epoch duration =7.05s
# Cumulative duration =24min 25.019999999999982s
#
# 236
# Epoch duration =5.28s
# Cumulative duration =24min 30.299999999999955s
#
# 237
# Epoch duration =7.07s
# Cumulative duration =24min 37.3599999999999s
#
# 238
# Epoch duration =5.28s
# Cumulative duration =24min 42.6400000000001s
#
# 239
# Epoch duration =7.03s
# Cumulative duration =24min 49.67000000000007s
#
# 240
# Epoch duration =5.27s
# Cumulative duration =24min 54.940000000000055s
#
# 241
# Epoch duration =7.08s
# Cumulative duration =25min 2.019999999999982s
#
# 242
# Epoch duration =5.27s
# Cumulative duration =25min 7.289999999999964s
#
# 243
# Epoch duration =7.05s
# Cumulative duration =25min 14.339999999999918s
#
# 244
# Epoch duration =5.28s
# Cumulative duration =25min 19.61999999999989s
#
# 245
# Epoch duration =7.09s
# Cumulative duration =25min 26.710000000000036s
#
# 246
# Epoch duration =5.26s
# Cumulative duration =25min 31.970000000000027s
#
# 247
# Epoch duration =7.05s
# Cumulative duration =25min 39.01999999999998s
#
# 248
# Epoch duration =5.25s
# Cumulative duration =25min 44.26999999999998s
#
# 249
# Epoch duration =6.81s
# Cumulative duration =25min 51.07999999999993s
#
# Saving scores to Arrays/riboswitch_resbindt1_ug_so250.npy

# %%
numug = len(ugidx)

#load values
savepath = 'Arrays/riboswitch_resbindt1_ug_so250.npy'
sum_mut2 = np.load(savepath)

#average the values
num_summary = 250
mean_mut2 = sum_mut2/num_summary

#Reshape into a holistic tensor organizing the mutations into 4*4 matrices
meanhol_mut2 = mean_mut2.reshape(numug,numug,dims,dims)

# %%
#normalize the holistic mutation scores
WT_mean = np.mean(nntrainer.get_activations(sess, test, layer='dense_1_bias')[plot_index[:500]])

def normalize_mut_hol(hol_mut, WTmean, nntrainer, sess, normfactor=None):
    norm_hol_mut = np.copy(hol_mut) - WTmean
    for one in range(hol_mut.shape[0]):
        for two in range(hol_mut.shape[0]):
            norm_hol_mut[one, two] = mf.normalize_hol(hol_mut[one, two], factor=normfactor)
    return norm_hol_mut
norm_meanhol_mut2 = normalize_mut_hol(meanhol_mut2, WT_mean, nntrainer, sess)

# %%
#Let's try something weird
bpfilter = np.ones((4,4))*-1
for i,j in zip(range(4), range(4)):
    bpfilter[i, -(j+1)] = 1.
    
C = np.sum((norm_meanhol_mut2*bpfilter).reshape(numug,numug,dims*dims), axis=2)
C = C - np.mean(C)
C = C/np.max(C)

plt.figure(figsize=(10,8))
sb.heatmap(C, xticklabels=list(bpSS), yticklabels=list(bpSS), vmin=0.2, cmap='Reds', linewidth=0.01)
plt.title('Base Pair score for the base pair consensus regions given by infernal')
plt.xlabel('Base paired nucleotides: pos 1')
plt.ylabel('Base paired nucleotides: pos 2')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sess.close()

# %%
d
